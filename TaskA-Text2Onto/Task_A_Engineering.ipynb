# %%
import json

def load_jsonl(file_path):
    """
    Loads data from a .jsonl file.

    Args:
        file_path (str): The path to the .jsonl file.

    Returns:
        list: A list of dictionaries, where each dictionary represents a JSON object from a line.
    """
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            try:
                data.append(json.loads(line.strip()))
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON on line: {line.strip()} - {e}")
    return data

# %%
training_data = load_jsonl("engineering/train/documents.jsonl")
len(training_data), training_data[0]
# Out:
# (83,
#  {'id': '0_2',
#   'title': 'The Versatility of Prefixed Units in Measurement',
#   'text': "The realm of measurement encompasses a vast array of units, many of which are modified by prefixes to denote scale. In the domain of physics and engineering, prefixed units are ubiquitous. For instance, units of length such as the centimetre, picometre, and terametre are used to measure distances ranging from the minute to the astronomical. Similarly, forces are measured in femtonewtons and teranewtons, reflecting the vast scales involved in scientific and engineering applications.\n\nEnergy measurements utilize units like the hectojoule, while power is quantified in petawatts and deciwatts. The digital realm relies on units such as the gigabit and gigabyte to measure data. Other physical quantities, including magnetic field strength in yoctoteslas and zeptoteslas, and radioactivity in picobecquerels and petabecquerels, demonstrate the diversity of prefixed units.\n\nFurthermore, the measurement of physical properties like capacitance in picofarads and femtofarads, resistance in picoohms, and inductance (though not directly mentioned, it's related to units like webers) in megawebers, showcases the complexity and precision required in various scientific disciplines. The use of prefixed units facilitates the expression of very large and very small quantities, making it an indispensable tool in science and technology."})

# %%
def load_txt_file_content(filepath):
    """
    Loads the entire content of a text file into a single string.

    Args:
        filepath (str): The path to the text file.

    Returns:
        str: The content of the file, or None if an error occurs.
    """
    try:
        with open(filepath, 'r', encoding='utf-8') as file:
            content = file.readlines()
        return content
    except FileNotFoundError:
        print(f"Error: The file '{filepath}' was not found.")
        return None
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        return None

# %%
def load_json(data_path):
    with open(data_path, "r") as file_1:
        data = json.load(file_1)
    return data

# %%
terms_text_list = load_txt_file_content("engineering/train/types.txt")

# %%
doc_term_types_mapping = []
train_data_term_types = load_json("engineering/train/terms2types.json")
train_data_term_types
# Out:
# [{'term': 'exagram', 'types': ['prefixed unit']},
#  {'term': 'millinewton', 'types': ['prefixed unit']},
#  {'term': 'petahenry', 'types': ['prefixed unit']},
#  {'term': 'petalitre', 'types': ['prefixed unit']},
#  {'term': 'petaweber', 'types': ['prefixed unit']},
#  {'term': '3 to 5 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'hectotesla', 'types': ['prefixed unit']},
#  {'term': 'statohm', 'types': ['singular unit', 'unit']},
#  {'term': 'weber', 'types': ['singular unit', 'unit']},
#  {'term': 'wine glass', 'types': ['unit']},
#  {'term': 'kilohm', 'types': ['prefixed unit']},
#  {'term': 'yottajoule', 'types': ['prefixed unit']},
#  {'term': 'piece', 'types': ['unit']},
#  {'term': '961.78 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'centimetre of mercury', 'types': ['prefixed unit']},
#  {'term': '54.3584 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'zeptopascal', 'types': ['prefixed unit']},
#  {'term': '24.5561 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'ton of refrigeration', 'types': ['singular unit', 'unit']},
#  {'term': 'kilocandela', 'types': ['prefixed unit']},
#  {'term': 'zeptolux', 'types': ['prefixed unit']},
#  {'term': 'light year', 'types': ['singular unit', 'unit']},
#  {'term': 'hectoampere', 'types': ['prefixed unit']},
#  {'term': 'deciwatt', 'types': ['prefixed unit']},
#  {'term': 'point (TeX)', 'types': ['singular unit', 'unit']},
#  {'term': 'grain', 'types': ['singular unit', 'unit']},
#  {'term': 'calorie (International Table)', 'types': ['singular unit', 'unit']},
#  {'term': 'zettabyte', 'types': ['prefixed unit']},
#  {'term': 'furlong (international)', 'types': ['singular unit', 'unit']},
#  {'term': 'megajoule', 'types': ['prefixed unit']},
#  {'term': "ounce (apothecaries')", 'types': ['singular unit', 'unit']},
#  {'term': 'frequency dimension', 'types': ['dimension']},
#  {'term': 'zeptovolt', 'types': ['prefixed unit']},
#  {'term': 'attokatal', 'types': ['prefixed unit']},
#  {'term': 'gigayear', 'types': ['prefixed unit']},
#  {'term': 'nanotesla', 'types': ['prefixed unit']},
#  {'term': 'decikelvin', 'types': ['prefixed unit']},
#  {'term': 'picolumen', 'types': ['prefixed unit']},
#  {'term': 'gigasecond', 'types': ['prefixed unit']},
#  {'term': 'lux', 'types': ['singular unit', 'unit']},
#  {'term': 'kilofarad', 'types': ['prefixed unit']},
#  {'term': 'nanocoulomb', 'types': ['prefixed unit']},
#  {'term': 'petamole', 'types': ['prefixed unit']},
#  {'term': 'exacandela', 'types': ['prefixed unit']},
#  {'term': 'nanocandela', 'types': ['prefixed unit']},
#  {'term': 'kilomole', 'types': ['prefixed unit']},
#  {'term': 'nanokatal', 'types': ['prefixed unit']},
#  {'term': 'nanoohm', 'types': ['prefixed unit']},
#  {'term': 'chemistry', 'types': ['application area']},
#  {'term': 'gigabit', 'types': ['prefixed unit']},
#  {'term': 'one', 'types': ['singular unit', 'unit']},
#  {'term': 'yottapascal', 'types': ['prefixed unit']},
#  {'term': '273.16 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'solar mass', 'types': ['singular unit', 'unit']},
#  {'term': 'picoradian', 'types': ['prefixed unit']},
#  {'term': 'centisiemens', 'types': ['prefixed unit']},
#  {'term': 'ton (short assay)', 'types': ['singular unit', 'unit']},
#  {'term': 'picowatt', 'types': ['prefixed unit']},
#  {'term': 'stathenry', 'types': ['singular unit', 'unit']},
#  {'term': 'zeptogray', 'types': ['prefixed unit']},
#  {'term': 'decanewton', 'types': ['prefixed unit']},
#  {'term': 'thermodynamic temperature dimension', 'types': ['dimension']},
#  {'term': 'milliradian', 'types': ['prefixed unit']},
#  {'term': 'gigabecquerel', 'types': ['prefixed unit']},
#  {'term': 'statcoulomb', 'types': ['singular unit', 'unit']},
#  {'term': 'megakelvin', 'types': ['prefixed unit']},
#  {'term': 'femtomolar', 'types': ['prefixed unit']},
#  {'term': 'micromagnitude', 'types': ['prefixed unit']},
#  {'term': 'South Korean won', 'types': ['singular unit', 'unit']},
#  {'term': 'femtosievert', 'types': ['prefixed unit']},
#  {'term': 'stattesla', 'types': ['singular unit', 'unit']},
#  {'term': 'attocandela', 'types': ['prefixed unit']},
#  {'term': 'shannon', 'types': ['singular unit', 'unit']},
#  {'term': 'nanoradian', 'types': ['prefixed unit']},
#  {'term': '25 millilitre', 'types': ['unit multiple']},
#  {'term': '231.928 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'nanohertz', 'types': ['prefixed unit']},
#  {'term': 'femtocandela', 'types': ['prefixed unit']},
#  {'term': 'mass flow dimension', 'types': ['dimension']},
#  {'term': 'attolumen', 'types': ['prefixed unit']},
#  {'term': 'gigaelectronvolt', 'types': ['prefixed unit']},
#  {'term': 'gigayear cubic kiloparsec', 'types': ['unit multiplication']},
#  {'term': 'abampere', 'types': ['singular unit', 'unit']},
#  {'term': 'centiare', 'types': ['prefixed unit']},
#  {'term': 'petalumen', 'types': ['prefixed unit']},
#  {'term': 'nanosecond', 'types': ['prefixed unit']},
#  {'term': 'capacitance dimension', 'types': ['dimension']},
#  {'term': 'nanomolar', 'types': ['prefixed unit']},
#  {'term': 'yoctolitre', 'types': ['prefixed unit']},
#  {'term': 'decakelvin', 'types': ['prefixed unit']},
#  {'term': 'petasecond', 'types': ['prefixed unit']},
#  {'term': 'decasiemens', 'types': ['prefixed unit']},
#  {'term': 'acceleration dimension', 'types': ['dimension']},
#  {'term': 'gigalitre', 'types': ['prefixed unit']},
#  {'term': 'yoctonewton', 'types': ['prefixed unit']},
#  {'term': 'milligauss', 'types': ['prefixed unit']},
#  {'term': 'petamolar', 'types': ['prefixed unit']},
#  {'term': 'zeptosteradian', 'types': ['prefixed unit']},
#  {'term': 'megacoulomb', 'types': ['prefixed unit']},
#  {'term': 'yoctolumen', 'types': ['prefixed unit']},
#  {'term': 'decilux', 'types': ['prefixed unit']},
#  {'term': 'peck (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'microdegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'femtowatt', 'types': ['prefixed unit']},
#  {'term': 'kilotesla', 'types': ['prefixed unit']},
#  {'term': 'decipascal', 'types': ['prefixed unit']},
#  {'term': 'zeptokelvin', 'types': ['prefixed unit']},
#  {'term': 'solar radius', 'types': ['singular unit', 'unit']},
#  {'term': 'yottafarad', 'types': ['prefixed unit']},
#  {'term': 'pica (Postscript)', 'types': ['singular unit', 'unit']},
#  {'term': 'pressure dimension', 'types': ['dimension']},
#  {'term': 'femtokelvin', 'types': ['prefixed unit']},
#  {'term': 'millipascal', 'types': ['prefixed unit']},
#  {'term': 'microlitre', 'types': ['prefixed unit']},
#  {'term': 'attomolar', 'types': ['prefixed unit']},
#  {'term': 'yobibit', 'types': ['prefixed unit']},
#  {'term': 'teraweber', 'types': ['prefixed unit']},
#  {'term': '13.8033 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'attopascal', 'types': ['prefixed unit']},
#  {'term': 'byte', 'types': ['singular unit', 'unit']},
#  {'term': 'attosteradian', 'types': ['prefixed unit']},
#  {'term': 'centilitre', 'types': ['prefixed unit']},
#  {'term': 'candela steradian', 'types': ['unit multiplication']},
#  {'term': 'picopascal', 'types': ['prefixed unit']},
#  {'term': 'baud', 'types': ['singular unit', 'unit']},
#  {'term': 'barrel (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'megalumen', 'types': ['prefixed unit']},
#  {'term': 'millijoule', 'types': ['prefixed unit']},
#  {'term': 'microradian', 'types': ['prefixed unit']},
#  {'term': 'joule', 'types': ['singular unit', 'unit']},
#  {'term': 'lumen second', 'types': ['unit multiplication']},
#  {'term': 'month', 'types': ['singular unit', 'unit']},
#  {'term': 'exabyte', 'types': ['prefixed unit']},
#  {'term': 'microcandela', 'types': ['prefixed unit']},
#  {'term': 'piconewton', 'types': ['prefixed unit']},
#  {'term': 'dyne', 'types': ['singular unit', 'unit']},
#  {'term': 'tebibit', 'types': ['prefixed unit']},
#  {'term': 'picogram', 'types': ['prefixed unit']},
#  {'term': 'picobecquerel', 'types': ['prefixed unit']},
#  {'term': 'acre foot', 'types': ['singular unit', 'unit']},
#  {'term': 'yottavolt', 'types': ['prefixed unit']},
#  {'term': 'megakatal', 'types': ['prefixed unit']},
#  {'term': 'zeptosecond', 'types': ['prefixed unit']},
#  {'term': 'perm (23 Â°C)', 'types': ['singular unit', 'unit']},
#  {'term': 'nanometre', 'types': ['prefixed unit']},
#  {'term': 'luminous flux dimension', 'types': ['dimension']},
#  {'term': 'millihenry', 'types': ['prefixed unit']},
#  {'term': 'University_Science_Books', 'types': ['Organization']},
#  {'term': 'deep bowl', 'types': ['unit']},
#  {'term': 'hectoohm', 'types': ['prefixed unit']},
#  {'term': 'micronewton metre', 'types': ['unit multiplication']},
#  {'term': 'petajoule', 'types': ['prefixed unit']},
#  {'term': 'picolux', 'types': ['prefixed unit']},
#  {'term': 'microcoulomb', 'types': ['prefixed unit']},
#  {'term': 'zettasecond', 'types': ['prefixed unit']},
#  {'term': 'femtoohm', 'types': ['prefixed unit']},
#  {'term': 'quad', 'types': ['singular unit', 'unit']},
#  {'term': 'degree Celsius', 'types': ['singular unit', 'unit']},
#  {'term': 'tonne of carbon dioxide equivalent',
#   'types': ['singular unit', 'unit']},
#  {'term': 'bowl', 'types': ['unit']},
#  {'term': 'zettanewton', 'types': ['prefixed unit']},
#  {'term': 'yottahertz', 'types': ['prefixed unit']},
#  {'term': 'length dimension', 'types': ['dimension']},
#  {'term': 'petaohm', 'types': ['prefixed unit']},
#  {'term': 'British thermal unit (mean)', 'types': ['singular unit', 'unit']},
#  {'term': 'erg second', 'types': ['unit multiplication']},
#  {'term': 'gilbert', 'types': ['singular unit', 'unit']},
#  {'term': 'zettasievert', 'types': ['prefixed unit']},
#  {'term': '1-10', 'types': ['singular unit', 'unit']},
#  {'term': 'milliwatt', 'types': ['prefixed unit']},
#  {'term': 'attoweber', 'types': ['prefixed unit']},
#  {'term': 'nanogram', 'types': ['prefixed unit']},
#  {'term': 'gigagram', 'types': ['prefixed unit']},
#  {'term': '29.7646 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'mechanics', 'types': ['application area']},
#  {'term': 'decasecond', 'types': ['prefixed unit']},
#  {'term': 'decivolt', 'types': ['prefixed unit']},
#  {'term': 'picokelvin', 'types': ['prefixed unit']},
#  {'term': 'yoctokatal', 'types': ['prefixed unit']},
#  {'term': 'teralux', 'types': ['prefixed unit']},
#  {'term': '-270.15 to -268.15 on the Celsius scale', 'types': ['fixed point']},
#  {'term': '1/0', 'types': ['singular unit', 'unit']},
#  {'term': 'nanolumen', 'types': ['prefixed unit']},
#  {'term': 'glass', 'types': ['unit']},
#  {'term': 'picofarad', 'types': ['prefixed unit']},
#  {'term': 'femtosecond', 'types': ['prefixed unit']},
#  {'term': 'hectojoule', 'types': ['prefixed unit']},
#  {'term': 'luminous energy dimension', 'types': ['dimension']},
#  {'term': 'litre', 'types': ['singular unit', 'unit']},
#  {'term': 'attocoulomb', 'types': ['prefixed unit']},
#  {'term': 'hectohenry', 'types': ['prefixed unit']},
#  {'term': 'zettagray', 'types': ['prefixed unit']},
#  {'term': 'nanoweber', 'types': ['prefixed unit']},
#  {'term': 'yottanewton', 'types': ['prefixed unit']},
#  {'term': 'stere', 'types': ['singular unit', 'unit']},
#  {'term': 'nanobecquerel', 'types': ['prefixed unit']},
#  {'term': 'reciprocal metre kilogram second to the power -2',
#   'types': ['unit multiplication']},
#  {'term': 'British thermal unit (59 Â°F)', 'types': ['singular unit', 'unit']},
#  {'term': 'exabit', 'types': ['prefixed unit']},
#  {'term': 'RussianRuble', 'types': ['singular unit', 'unit']},
#  {'term': '505.078 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'nanomole', 'types': ['prefixed unit']},
#  {'term': '1-5', 'types': ['singular unit', 'unit']},
#  {'term': '234.3156 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'yottaampere', 'types': ['prefixed unit']},
#  {'term': 'petabecquerel', 'types': ['prefixed unit']},
#  {'term': 'decawatt', 'types': ['prefixed unit']},
#  {'term': 'kilolumen', 'types': ['prefixed unit']},
#  {'term': 'wedge', 'types': ['unit']},
#  {'term': 'International_Astronomical_Union', 'types': ['Organization']},
#  {'term': 'Astrophysical_Techniques_chapter3', 'types': ['Chapter']},
#  {'term': 'mole micrometre', 'types': ['unit multiplication']},
#  {'term': 'yoctotesla', 'types': ['prefixed unit']},
#  {'term': 'zeptohertz', 'types': ['prefixed unit']},
#  {'term': 'picodegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'meganewton', 'types': ['prefixed unit']},
#  {'term': 'therm (EC)', 'types': ['singular unit', 'unit']},
#  {'term': 'millikelvin', 'types': ['prefixed unit']},
#  {'term': 'zeptodegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'calorie (thermochemical)', 'types': ['singular unit', 'unit']},
#  {'term': 'decaohm', 'types': ['prefixed unit']},
#  {'term': 'decaampere', 'types': ['prefixed unit']},
#  {'term': 'decihertz', 'types': ['prefixed unit']},
#  {'term': 'femtosiemens', 'types': ['prefixed unit']},
#  {'term': 'yoctosecond', 'types': ['prefixed unit']},
#  {'term': 'millimagnitude', 'types': ['prefixed unit']},
#  {'term': 'kilogram', 'types': ['prefixed unit']},
#  {'term': 'watt', 'types': ['singular unit', 'unit']},
#  {'term': 'femtolumen', 'types': ['prefixed unit']},
#  {'term': 'horsepower (boiler)', 'types': ['singular unit', 'unit']},
#  {'term': 'femtohenry', 'types': ['prefixed unit']},
#  {'term': 'microgram', 'types': ['prefixed unit']},
#  {'term': 'carat (mass)', 'types': ['singular unit', 'unit']},
#  {'term': 'wavenumber dimension', 'types': ['dimension']},
#  {'term': 'rhe', 'types': ['singular unit', 'unit']},
#  {'term': 'megametre', 'types': ['prefixed unit']},
#  {'term': 'phot', 'types': ['singular unit', 'unit']},
#  {'term': 'surface tension dimension', 'types': ['dimension']},
#  {'term': '~20.3 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'kilovolt', 'types': ['prefixed unit']},
#  {'term': 'petanewton', 'types': ['prefixed unit']},
#  {'term': "pound (apthecaries')", 'types': ['singular unit', 'unit']},
#  {'term': 'Birmingham gauge', 'types': ['singular unit', 'unit']},
#  {'term': 'rod (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'degree RÃ©aumur', 'types': ['singular unit', 'unit']},
#  {'term': 'metre of mercury', 'types': ['singular unit', 'unit']},
#  {'term': 'hectare', 'types': ['prefixed unit']},
#  {'term': 'reciprocal square metre reciprocal metre',
#   'types': ['unit multiplication']},
#  {'term': 'zeptotesla', 'types': ['prefixed unit']},
#  {'term': 'megaerg', 'types': ['prefixed unit']},
#  {'term': 'second (angle)', 'types': ['singular unit', 'unit']},
#  {'term': 'zettabecquerel', 'types': ['prefixed unit']},
#  {'term': 'picoweber', 'types': ['prefixed unit']},
#  {'term': 'gigasievert', 'types': ['prefixed unit']},
#  {'term': 'liquid pint (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'pascal second', 'types': ['unit multiplication']},
#  {'term': 'attoohm', 'types': ['prefixed unit']},
#  {'term': 'megatonne', 'types': ['prefixed unit']},
#  {'term': 'footcandle', 'types': ['singular unit', 'unit']},
#  {'term': 'luminous intensity, in a given direction, of a source that emits monochromatic radiation of frequency 540e12 hertz and that has a radiant intensity in that direction of 1/683 watt per steradian',
#   'types': ['luminous intensity']},
#  {'term': 'microkatal', 'types': ['prefixed unit']},
#  {'term': 'centihenry', 'types': ['prefixed unit']},
#  {'term': 'electric current dimension', 'types': ['dimension']},
#  {'term': 'decihenry', 'types': ['prefixed unit']},
#  {'term': 'decatesla', 'types': ['prefixed unit']},
#  {'term': 'petaampere', 'types': ['prefixed unit']},
#  {'term': 'kilogram second to the power -2', 'types': ['unit multiplication']},
#  {'term': 'are', 'types': ['singular unit', 'unit']},
#  {'term': 'megamolar', 'types': ['prefixed unit']},
#  {'term': 'kilobyte', 'types': ['prefixed unit']},
#  {'term': 'cord', 'types': ['singular unit', 'unit']},
#  {'term': 'petatesla', 'types': ['prefixed unit']},
#  {'term': 'thermal conductivity dimension', 'types': ['dimension']},
#  {'term': 'pinch', 'types': ['unit']},
#  {'term': 'pint (imperial)', 'types': ['singular unit', 'unit']},
#  {'term': 'gibibit', 'types': ['prefixed unit']},
#  {'term': 'centikatal', 'types': ['prefixed unit']},
#  {'term': 'attovolt', 'types': ['prefixed unit']},
#  {'term': 'yoctogram', 'types': ['prefixed unit']},
#  {'term': 'micron', 'types': ['singular unit', 'unit']},
#  {'term': 'microsteradian', 'types': ['prefixed unit']},
#  {'term': 'yottagram', 'types': ['prefixed unit']},
#  {'term': 'yottakelvin', 'types': ['prefixed unit']},
#  {'term': 'square metre hertz', 'types': ['unit multiplication']},
#  {'term': 'British thermal unit (60 Â°F)', 'types': ['singular unit', 'unit']},
#  {'term': 'decagram', 'types': ['prefixed unit']},
#  {'term': 'mile (US survey)', 'types': ['singular unit', 'unit']},
#  {'term': 'Astrophysical_Techniques_chapter1', 'types': ['Chapter']},
#  {'term': 'micrometre', 'types': ['prefixed unit']},
#  {'term': 'decisiemens', 'types': ['prefixed unit']},
#  {'term': 'centigram', 'types': ['prefixed unit']},
#  {'term': 'parsec', 'types': ['singular unit', 'unit']},
#  {'term': 'zettalitre', 'types': ['prefixed unit']},
#  {'term': 'deciampere', 'types': ['prefixed unit']},
#  {'term': 'decimole', 'types': ['prefixed unit']},
#  {'term': 'yottasievert', 'types': ['prefixed unit']},
#  {'term': 'exapascal', 'types': ['prefixed unit']},
#  {'term': 'gigajoule', 'types': ['prefixed unit']},
#  {'term': 'year (tropical)', 'types': ['singular unit', 'unit']},
#  {'term': 'dry pint (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'bottle', 'types': ['unit']},
#  {'term': 'zeptoampere', 'types': ['prefixed unit']},
#  {'term': 'pebibyte', 'types': ['prefixed unit']},
#  {'term': 'portion', 'types': ['unit']},
#  {'term': 'fluid mechanics', 'types': ['application area']},
#  {'term': 'hour (hour angle)', 'types': ['singular unit', 'unit']},
#  {'term': 'square metre steradian', 'types': ['unit multiplication']},
#  {'term': 'terasecond', 'types': ['prefixed unit']},
#  {'term': 'attolitre', 'types': ['prefixed unit']},
#  {'term': 'kibibyte', 'types': ['prefixed unit']},
#  {'term': 'megabit', 'types': ['prefixed unit']},
#  {'term': 'centimetre', 'types': ['prefixed unit']},
#  {'term': 'permeability of free space dimension', 'types': ['dimension']},
#  {'term': 'petabyte', 'types': ['prefixed unit']},
#  {'term': 'attosecond', 'types': ['prefixed unit']},
#  {'term': '0-100', 'types': ['singular unit', 'unit']},
#  {'term': 'picosiemens', 'types': ['prefixed unit']},
#  {'term': 'horsepower (metric)', 'types': ['singular unit', 'unit']},
#  {'term': 'attosiemens', 'types': ['prefixed unit']},
#  {'term': 'inch (international)', 'types': ['singular unit', 'unit']},
#  {'term': 'yottasecond', 'types': ['prefixed unit']},
#  {'term': 'faraday', 'types': ['singular unit', 'unit']},
#  {'term': 'gigasiemens', 'types': ['prefixed unit']},
#  {'term': 'kilocalorie (mean)', 'types': ['prefixed unit']},
#  {'term': 'zettahenry', 'types': ['prefixed unit']},
#  {'term': 'gigaampere', 'types': ['prefixed unit']},
#  {'term': 'picokatal', 'types': ['prefixed unit']},
#  {'term': 'siemens', 'types': ['singular unit', 'unit']},
#  {'term': 'petavolt', 'types': ['prefixed unit']},
#  {'term': 'British thermal unit (International Table)',
#   'types': ['singular unit', 'unit']},
#  {'term': 'gill (imperial)', 'types': ['singular unit', 'unit']},
#  {'term': 'acoustics', 'types': ['application area']},
#  {'term': 'minute (sidereal)', 'types': ['singular unit', 'unit']},
#  {'term': 'decicandela', 'types': ['prefixed unit']},
#  {'term': 'electromagnetism', 'types': ['application area']},
#  {'term': 'nanolitre', 'types': ['prefixed unit']},
#  {'term': 'atmosphere (technical)', 'types': ['singular unit', 'unit']},
#  {'term': 'degree', 'types': ['singular unit', 'unit']},
#  {'term': 'horsepower (British)', 'types': ['singular unit', 'unit']},
#  {'term': 'yottalitre', 'types': ['prefixed unit']},
#  {'term': 'picocandela', 'types': ['prefixed unit']},
#  {'term': 'yoctodegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'hectosiemens', 'types': ['prefixed unit']},
#  {'term': 'centisteradian', 'types': ['prefixed unit']},
#  {'term': 'millisecond', 'types': ['prefixed unit']},
#  {'term': 'sievert', 'types': ['singular unit', 'unit']},
#  {'term': 'petakelvin', 'types': ['prefixed unit']},
#  {'term': 'kilowatt', 'types': ['prefixed unit']},
#  {'term': 'henry', 'types': ['singular unit', 'unit']},
#  {'term': 'joule second', 'types': ['unit multiplication']},
#  {'term': 'petagray', 'types': ['prefixed unit']},
#  {'term': 'cup (US customary)', 'types': ['singular unit', 'unit']},
#  {'term': 'femtopascal', 'types': ['prefixed unit']},
#  {'term': 'centiradian', 'types': ['prefixed unit']},
#  {'term': 'centifarad', 'types': ['prefixed unit']},
#  {'term': 'Brazilian real', 'types': ['singular unit', 'unit']},
#  {'term': 'exaohm', 'types': ['prefixed unit']},
#  {'term': 'kilolux', 'types': ['prefixed unit']},
#  {'term': 'catalytic activity dimension', 'types': ['dimension']},
#  {'term': 'yard (international)', 'types': ['singular unit', 'unit']},
#  {'term': 'catalytic activity concentration dimension',
#   'types': ['dimension']},
#  {'term': 'exposure dimension', 'types': ['dimension']},
#  {'term': '100 kilometre', 'types': ['unit multiple']},
#  {'term': 'statvolt', 'types': ['singular unit', 'unit']},
#  {'term': 'terahenry', 'types': ['prefixed unit']},
#  {'term': 'exaampere', 'types': ['prefixed unit']},
#  {'term': 'calorie (mean)', 'types': ['singular unit', 'unit']},
#  {'term': 'femtolitre', 'types': ['prefixed unit']},
#  {'term': 'bar', 'types': ['singular unit', 'unit']},
#  {'term': 'teraohm', 'types': ['prefixed unit']},
#  {'term': 'Cambridge_University_Press', 'types': ['Organization']},
#  {'term': 'yottaohm', 'types': ['prefixed unit']},
#  {'term': 'femtogram', 'types': ['prefixed unit']},
#  {'term': 'micromole', 'types': ['prefixed unit']},
#  {'term': 'millimole', 'types': ['prefixed unit']},
#  {'term': '1064.18 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'exasecond', 'types': ['prefixed unit']},
#  {'term': 'yottabecquerel', 'types': ['prefixed unit']},
#  {'term': 'yoctomole', 'types': ['prefixed unit']},
#  {'term': 'teraampere', 'types': ['prefixed unit']},
#  {'term': 'gal', 'types': ['singular unit', 'unit']},
#  {'term': 'millimolar', 'types': ['prefixed unit']},
#  {'term': 'yoctokelvin', 'types': ['prefixed unit']},
#  {'term': 'exagray', 'types': ['prefixed unit']},
#  {'term': 'petabit', 'types': ['prefixed unit']},
#  {'term': 'calorie (20 Â°C)', 'types': ['singular unit', 'unit']},
#  {'term': 'IntroAstronomicalPhotometry', 'types': ['Book']},
#  {'term': 'number density dimension', 'types': ['dimension']},
#  {'term': 'mebibyte', 'types': ['prefixed unit']},
#  {'term': 'pound (avoirdupois)', 'types': ['singular unit', 'unit']},
#  {'term': 'femtoweber', 'types': ['prefixed unit']},
#  {'term': 'yobibyte', 'types': ['prefixed unit']},
#  {'term': 'statweber', 'types': ['singular unit', 'unit']},
#  {'term': 'pica (ATA)', 'types': ['singular unit', 'unit']},
#  {'term': '429.7485 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'bushel (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'centilux', 'types': ['prefixed unit']},
#  {'term': 'minute (hour angle)', 'types': ['singular unit', 'unit']},
#  {'term': 'decacandela', 'types': ['prefixed unit']},
#  {'term': 'hectowatt', 'types': ['prefixed unit']},
#  {'term': 'nanojoule', 'types': ['prefixed unit']},
#  {'term': 'exalumen', 'types': ['prefixed unit']},
#  {'term': 'zettakelvin', 'types': ['prefixed unit']},
#  {'term': 'newton', 'types': ['singular unit', 'unit']},
#  {'term': 'attosievert', 'types': ['prefixed unit']},
#  {'term': 'kilosecond', 'types': ['prefixed unit']},
#  {'term': 'decisteradian', 'types': ['prefixed unit']},
#  {'term': 'centiohm', 'types': ['prefixed unit']},
#  {'term': 'millikatal', 'types': ['prefixed unit']},
#  {'term': 'Institute_of_Physics_Publishing', 'types': ['Organization']},
#  {'term': 'VU', 'types': ['Organization']},
#  {'term': 'zettasiemens', 'types': ['prefixed unit']},
#  {'term': 'femtokatal', 'types': ['prefixed unit']},
#  {'term': 'Willmann_Bell', 'types': ['Organization']},
#  {'term': 'terahertz', 'types': ['prefixed unit']},
#  {'term': 'South African rand', 'types': ['singular unit', 'unit']},
#  {'term': 'picojoule', 'types': ['prefixed unit']},
#  {'term': 'attolux', 'types': ['prefixed unit']},
#  {'term': 'radian', 'types': ['singular unit', 'unit']},
#  {'term': 'metre kelvin', 'types': ['unit multiplication']},
#  {'term': 'femtocoulomb', 'types': ['prefixed unit']},
#  {'term': 'metre kilogram', 'types': ['unit multiplication']},
#  {'term': 'energy dimension', 'types': ['dimension']},
#  {'term': 'magnetic flux density dimension', 'types': ['dimension']},
#  {'term': 'dry gallon (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'foot poundal', 'types': ['singular unit', 'unit']},
#  {'term': 'hectocoulomb', 'types': ['prefixed unit']},
#  {'term': 'exahenry', 'types': ['prefixed unit']},
#  {'term': '156.5985 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'metre', 'types': ['singular unit', 'unit']},
#  {'term': 'terabyte', 'types': ['prefixed unit']},
#  {'term': 'square metre second', 'types': ['unit multiplication']},
#  {'term': 'exametre', 'types': ['prefixed unit']},
#  {'term': 'gigahenry', 'types': ['prefixed unit']},
#  {'term': 'absorbed dose rate dimension', 'types': ['dimension']},
#  {'term': 'shake', 'types': ['singular unit', 'unit']},
#  {'term': 'microlumen', 'types': ['prefixed unit']},
#  {'term': 'gigamole', 'types': ['prefixed unit']},
#  {'term': 'teragray', 'types': ['prefixed unit']},
#  {'term': 'kiloelectronvolt', 'types': ['prefixed unit']},
#  {'term': 'pascal second square metre', 'types': ['unit multiplication']},
#  {'term': 'point (Didot)', 'types': ['singular unit', 'unit']},
#  {'term': 'kibibit', 'types': ['prefixed unit']},
#  {'term': 'pound-force', 'types': ['singular unit', 'unit']},
#  {'term': 'microjoule', 'types': ['prefixed unit']},
#  {'term': 'zeptosiemens', 'types': ['prefixed unit']},
#  {'term': 'terawatt hour', 'types': ['unit multiplication']},
#  {'term': 'centiwatt', 'types': ['prefixed unit']},
#  {'term': '83.8058 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'millihertz', 'types': ['prefixed unit']},
#  {'term': 'femtolux', 'types': ['prefixed unit']},
#  {'term': 'quart (imperial)', 'types': ['singular unit', 'unit']},
#  {'term': 'mole micrometre reciprocal square centimetre reciprocal second',
#   'types': ['unit multiplication']},
#  {'term': 'petafarad', 'types': ['prefixed unit']},
#  {'term': 'hectogray', 'types': ['prefixed unit']},
#  {'term': 'International Unit', 'types': ['singular unit', 'unit']},
#  {'term': 'thermodynamics', 'types': ['application area']},
#  {'term': 'decinewton', 'types': ['prefixed unit']},
#  {'term': 'femtohertz', 'types': ['prefixed unit']},
#  {'term': 'decamolar', 'types': ['prefixed unit']},
#  {'term': 'centicoulomb', 'types': ['prefixed unit']},
#  {'term': 'decavolt', 'types': ['prefixed unit']},
#  {'term': 'astronomical unit', 'types': ['singular unit', 'unit']},
#  {'term': 'yottatesla', 'types': ['prefixed unit']},
#  {'term': 'exawatt', 'types': ['prefixed unit']},
#  {'term': 'kelvin kilogram', 'types': ['unit multiplication']},
#  {'term': 'kelvin', 'types': ['singular unit', 'unit']},
#  {'term': 'magnetic field dimension', 'types': ['dimension']},
#  {'term': 'British thermal unit (39 Â°F)', 'types': ['singular unit', 'unit']},
#  {'term': 'point (ATA)', 'types': ['singular unit', 'unit']},
#  {'term': 'zettapascal', 'types': ['prefixed unit']},
#  {'term': 'decimolar', 'types': ['prefixed unit']},
#  {'term': 'speed dimension', 'types': ['dimension']},
#  {'term': 'mass dimension', 'types': ['dimension']},
#  {'term': 'centisecond', 'types': ['prefixed unit']},
#  {'term': 'attofarad', 'types': ['prefixed unit']},
#  {'term': 'decibel', 'types': ['prefixed unit']},
#  {'term': 'chapter13_Astronomical_Algorithms', 'types': ['Chapter']},
#  {'term': 'megabecquerel', 'types': ['prefixed unit']},
#  {'term': 'electric charge density dimension', 'types': ['dimension']},
#  {'term': 'terawatt', 'types': ['prefixed unit']},
#  {'term': 'examole', 'types': ['prefixed unit']},
#  {'term': 'day', 'types': ['singular unit', 'unit']},
#  {'term': 'picosecond', 'types': ['prefixed unit']},
#  {'term': 'zettabit', 'types': ['prefixed unit']},
#  {'term': '933.473 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'gigawatt hour', 'types': ['unit multiplication']},
#  {'term': 'kilopascal', 'types': ['prefixed unit']},
#  {'term': 'French gauge', 'types': ['singular unit', 'unit']},
#  {'term': 'yoctoradian', 'types': ['prefixed unit']},
#  {'term': 'attometre', 'types': ['prefixed unit']},
#  {'term': 'pound sterling', 'types': ['singular unit', 'unit']},
#  {'term': 'exavolt', 'types': ['prefixed unit']},
#  {'term': 'gigapascal', 'types': ['prefixed unit']},
#  {'term': 'square metre kelvin', 'types': ['unit multiplication']},
#  {'term': 'stilb', 'types': ['singular unit', 'unit']},
#  {'term': 'abmho', 'types': ['singular unit', 'unit']},
#  {'term': 'rem', 'types': ['singular unit', 'unit']},
#  {'term': 'yoctohertz', 'types': ['prefixed unit']},
#  {'term': 'microgray', 'types': ['prefixed unit']},
#  {'term': 'attotesla', 'types': ['prefixed unit']},
#  {'term': 'yottakatal', 'types': ['prefixed unit']},
#  {'term': 'decalitre', 'types': ['prefixed unit']},
#  {'term': '1/273.16 of the thermodynamic temperature of the triple point of water',
#   'types': ['thermodynamic temperature']},
#  {'term': 'colony forming unit',
#   'types': ['singular unit', 'unit division', 'unit']},
#  {'term': 'luminance dimension', 'types': ['dimension']},
#  {'term': 'tonne', 'types': ['singular unit', 'unit']},
#  {'term': 'lux second', 'types': ['unit multiplication']},
#  {'term': 'kayser', 'types': ['singular unit', 'unit']},
#  {'term': 'electronvolt', 'types': ['singular unit', 'unit']},
#  {'term': 'kilokatal', 'types': ['prefixed unit']},
#  {'term': 'point (Postscript)', 'types': ['singular unit', 'unit']},
#  {'term': '660.323 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'oersted', 'types': ['singular unit', 'unit']},
#  {'term': 'radiance dimension', 'types': ['dimension']},
#  {'term': 'decisievert', 'types': ['prefixed unit']},
#  {'term': 'nanosiemens', 'types': ['prefixed unit']},
#  {'term': 'millicoulomb', 'types': ['prefixed unit']},
#  {'term': 'kilolitre', 'types': ['prefixed unit']},
#  {'term': 'mass of the international prototype of the kilogram',
#   'types': ['mass']},
#  {'term': 'ton (register)', 'types': ['singular unit', 'unit']},
#  {'term': 'yoctofarad', 'types': ['prefixed unit']},
#  {'term': 'luminous intensity dimension', 'types': ['dimension']},
#  {'term': 'kilobit', 'types': ['prefixed unit']},
#  {'term': 'year (sidereal)', 'types': ['singular unit', 'unit']},
#  {'term': 'horsepower (water)', 'types': ['singular unit', 'unit']},
#  {'term': 'nanolux', 'types': ['prefixed unit']},
#  {'term': 'millidegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'pixel', 'types': ['singular unit', 'unit']},
#  {'term': 'nanounified atomic mass unit', 'types': ['prefixed unit']},
#  {'term': 'millimetre', 'types': ['prefixed unit']},
#  {'term': 'yottacoulomb', 'types': ['prefixed unit']},
#  {'term': 'kilocalorie (mean) per day', 'types': ['unit division', 'unit']},
#  {'term': 'foot (US survey)', 'types': ['singular unit', 'unit']},
#  {'term': 'IAUDiv1WG', 'types': ['Organization']},
#  {'term': 'decamole', 'types': ['prefixed unit']},
#  {'term': 'abcoulomb', 'types': ['singular unit', 'unit']},
#  {'term': 'density dimension', 'types': ['dimension']},
#  {'term': 'kilohenry', 'types': ['prefixed unit']},
#  {'term': 'zebibit', 'types': ['prefixed unit']},
#  {'term': 'kilowatt hour', 'types': ['unit multiplication']},
#  {'term': 'Turkish lira', 'types': ['singular unit', 'unit']},
#  {'term': 'petawatt', 'types': ['prefixed unit']},
#  {'term': 'gigamolar', 'types': ['prefixed unit']},
#  {'term': 'attokelvin', 'types': ['prefixed unit']},
#  {'term': 'katal', 'types': ['singular unit', 'unit']},
#  {'term': 'energy density dimension', 'types': ['dimension']},
#  {'term': 'yoctoohm', 'types': ['prefixed unit']},
#  {'term': 'centicandela', 'types': ['prefixed unit']},
#  {'term': 'ohm metre', 'types': ['unit multiplication']},
#  {'term': 'reciprocal square metre reciprocal gram',
#   'types': ['unit multiplication']},
#  {'term': 'knot (international)', 'types': ['singular unit', 'unit']},
#  {'term': '-259.3467 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'degree Rankine', 'types': ['singular unit', 'unit']},
#  {'term': 'gigakelvin', 'types': ['prefixed unit']},
#  {'term': 'Singapore dollar', 'types': ['singular unit', 'unit']},
#  {'term': 'minute (angle)', 'types': ['singular unit', 'unit']},
#  {'term': 'mil (length)', 'types': ['singular unit', 'unit']},
#  {'term': 'molar entropy, molar heat capacity, or gas constant dimension',
#   'types': ['dimension']},
#  {'term': 'fluid ounce (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'fermi', 'types': ['singular unit', 'unit']},
#  {'term': 'exalux', 'types': ['prefixed unit']},
#  {'term': 'hectosievert', 'types': ['prefixed unit']},
#  {'term': 'exaweber', 'types': ['prefixed unit']},
#  {'term': 'terapascal', 'types': ['prefixed unit']},
#  {'term': 'nanodegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'millibecquerel', 'types': ['prefixed unit']},
#  {'term': 'decibar', 'types': ['prefixed unit']},
#  {'term': 'attohenry', 'types': ['prefixed unit']},
#  {'term': 'photometry', 'types': ['application area']},
#  {'term': 'kilobecquerel', 'types': ['prefixed unit']},
#  {'term': 'hour (sidereal)', 'types': ['singular unit', 'unit']},
#  {'term': 'poise', 'types': ['singular unit', 'unit']},
#  {'term': 'volumetric flow rate dimension', 'types': ['dimension']},
#  {'term': '~17 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'Hong Kong dollar', 'types': ['singular unit', 'unit']},
#  {'term': '1357.77 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'hectohertz', 'types': ['prefixed unit']},
#  {'term': 'tebibyte', 'types': ['prefixed unit']},
#  {'term': 'lumen', 'types': ['singular unit', 'unit']},
#  {'term': 'microsievert', 'types': ['prefixed unit']},
#  {'term': 'femtotesla', 'types': ['prefixed unit']},
#  {'term': 'attohertz', 'types': ['prefixed unit']},
#  {'term': 'milliweber', 'types': ['prefixed unit']},
#  {'term': 'micropascal', 'types': ['prefixed unit']},
#  {'term': 'shipping', 'types': ['application area']},
#  {'term': 'Swedish krona', 'types': ['singular unit', 'unit']},
#  {'term': 'zeptomolar', 'types': ['prefixed unit']},
#  {'term': 'picomole', 'types': ['prefixed unit']},
#  {'term': 'gauss', 'types': ['singular unit', 'unit']},
#  {'term': 'picogray', 'types': ['prefixed unit']},
#  {'term': 'exafarad', 'types': ['prefixed unit']},
#  {'term': 'yottaweber', 'types': ['prefixed unit']},
#  {'term': 'picoampere', 'types': ['prefixed unit']},
#  {'term': 'petacandela', 'types': ['prefixed unit']},
#  {'term': 'microwatt', 'types': ['prefixed unit']},
#  {'term': 'nanosievert', 'types': ['prefixed unit']},
#  {'term': 'United States dollar', 'types': ['singular unit', 'unit']},
#  {'term': 'rÃ¶ntgen', 'types': ['singular unit', 'unit']},
#  {'term': 'exanewton', 'types': ['prefixed unit']},
#  {'term': 'teralitre', 'types': ['prefixed unit']},
#  {'term': 'amylase unit', 'types': ['singular unit', 'unit']},
#  {'term': 'decitesla', 'types': ['prefixed unit']},
#  {'term': 'tesla', 'types': ['singular unit', 'unit']},
#  {'term': 'zeptogram', 'types': ['prefixed unit']},
#  {'term': 'permittivity dimension', 'types': ['dimension']},
#  {'term': 'teratesla', 'types': ['prefixed unit']},
#  {'term': 'kilogram of carbon dioxide equivalent per megawatt hour',
#   'types': ['unit division', 'prefixed unit']},
#  {'term': 'amount of substance of a system that contains as many elementary entities as there are atoms in 0.012 kilogram of carbon 12',
#   'types': ['amount of substance']},
#  {'term': 'barn', 'types': ['singular unit', 'unit']},
#  {'term': 'millinewton metre', 'types': ['unit multiplication']},
#  {'term': '~-256.15 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'electrical resistivity dimension', 'types': ['dimension']},
#  {'term': 'attobecquerel', 'types': ['prefixed unit']},
#  {'term': 'femtogray', 'types': ['prefixed unit']},
#  {'term': 'perm (0 Â°C)', 'types': ['singular unit', 'unit']},
#  {'term': 'gigagray', 'types': ['prefixed unit']},
#  {'term': 'gon', 'types': ['singular unit', 'unit']},
#  {'term': 'centigray', 'types': ['prefixed unit']},
#  {'term': 'kilohertz', 'types': ['prefixed unit']},
#  {'term': 'gigalux', 'types': ['prefixed unit']},
#  {'term': 'poundal', 'types': ['singular unit', 'unit']},
#  {'term': 'milliohm', 'types': ['prefixed unit']},
#  {'term': 'barye', 'types': ['singular unit', 'unit']},
#  {'term': 'nanonewton', 'types': ['prefixed unit']},
#  {'term': 'megagray', 'types': ['prefixed unit']},
#  {'term': 'cicero', 'types': ['singular unit', 'unit']},
#  {'term': 'decakatal', 'types': ['prefixed unit']},
#  {'term': 'microvolt', 'types': ['prefixed unit']},
#  {'term': 'terafarad', 'types': ['prefixed unit']},
#  {'term': 'zettalux', 'types': ['prefixed unit']},
#  {'term': 'angstrom', 'types': ['singular unit', 'unit']},
#  {'term': 'microbecquerel', 'types': ['prefixed unit']},
#  {'term': 'centilumen', 'types': ['prefixed unit']},
#  {'term': 'common application area', 'types': ['application area']},
#  {'term': 'centimole', 'types': ['prefixed unit']},
#  {'term': 'picolitre', 'types': ['prefixed unit']},
#  {'term': 'milliampere hour', 'types': ['unit multiplication']},
#  {'term': 'zettaohm', 'types': ['prefixed unit']},
#  {'term': 'farad', 'types': ['singular unit', 'unit']},
#  {'term': 'abvolt', 'types': ['singular unit', 'unit']},
#  {'term': 'millisievert', 'types': ['prefixed unit']},
#  {'term': 'millibar', 'types': ['prefixed unit']},
#  {'term': 'kilocoulomb', 'types': ['prefixed unit']},
#  {'term': 'millisiemens', 'types': ['prefixed unit']},
#  {'term': 'petagram', 'types': ['prefixed unit']},
#  {'term': 'square metre nanometre', 'types': ['unit multiplication']},
#  {'term': 'slug', 'types': ['singular unit', 'unit']},
#  {'term': 'unit pole', 'types': ['singular unit', 'unit']},
#  {'term': 'franklin', 'types': ['singular unit', 'unit']},
#  {'term': 'specific entropy or specific heat capacity dimension',
#   'types': ['dimension']},
#  {'term': 'megasecond', 'types': ['prefixed unit']},
#  {'term': 'decasievert', 'types': ['prefixed unit']},
#  {'term': 'kilonewton', 'types': ['prefixed unit']},
#  {'term': 'slice', 'types': ['unit']},
#  {'term': 'yoctolux', 'types': ['prefixed unit']},
#  {'term': 'statfarad', 'types': ['singular unit', 'unit']},
#  {'term': 'exatesla', 'types': ['prefixed unit']},
#  {'term': 'terajoule', 'types': ['prefixed unit']},
#  {'term': 'zettavolt', 'types': ['prefixed unit']},
#  {'term': 'specific volume dimension', 'types': ['dimension']},
#  {'term': 'current density dimension', 'types': ['dimension']},
#  {'term': 'exabecquerel', 'types': ['prefixed unit']},
#  {'term': 'kilogram of carbon dioxide equivalent', 'types': ['prefixed unit']},
#  {'term': 'megalux', 'types': ['prefixed unit']},
#  {'term': '692.677 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'zeptoweber', 'types': ['prefixed unit']},
#  {'term': 'kiloweber', 'types': ['prefixed unit']},
#  {'term': 'hectomolar', 'types': ['prefixed unit']},
#  {'term': 'hectovolt', 'types': ['prefixed unit']},
#  {'term': 'hectogram', 'types': ['prefixed unit']},
#  {'term': 'millivolt', 'types': ['prefixed unit']},
#  {'term': 'megasievert', 'types': ['prefixed unit']},
#  {'term': 'zeptolumen', 'types': ['prefixed unit']},
#  {'term': 'square metre day', 'types': ['unit multiplication']},
#  {'term': 'hectare day', 'types': ['unit multiplication']},
#  {'term': 'gallon (imperial)', 'types': ['singular unit', 'unit']},
#  {'term': 'stokes', 'types': ['singular unit', 'unit']},
#  {'term': 'decifarad', 'types': ['prefixed unit']},
#  {'term': 'abohm', 'types': ['singular unit', 'unit']},
#  {'term': 'molar energy dimension', 'types': ['dimension']},
#  {'term': 'zeptocoulomb', 'types': ['prefixed unit']},
#  {'term': 'fathom (US survey)', 'types': ['singular unit', 'unit']},
#  {'term': '-248.5939 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'megamole', 'types': ['prefixed unit']},
#  {'term': 'decidegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'gigaohm', 'types': ['prefixed unit']},
#  {'term': 'chemical physics', 'types': ['application area']},
#  {'term': 'gray', 'types': ['singular unit', 'unit']},
#  {'term': 'attogray', 'types': ['prefixed unit']},
#  {'term': 'microsiemens', 'types': ['prefixed unit']},
#  {'term': 'volt second', 'types': ['unit multiplication']},
#  {'term': 'picohertz', 'types': ['prefixed unit']},
#  {'term': 'petametre', 'types': ['prefixed unit']},
#  {'term': 'amount of substance concentration dimension',
#   'types': ['dimension']},
#  {'term': 'megalitre', 'types': ['prefixed unit']},
#  {'term': 'fillet', 'types': ['unit']},
#  {'term': 'exasiemens', 'types': ['prefixed unit']},
#  {'term': 'zeptoradian', 'types': ['prefixed unit']},
#  {'term': 'hundredweight (British)', 'types': ['singular unit', 'unit']},
#  {'term': 'hectocandela', 'types': ['prefixed unit']},
#  {'term': 'decahertz', 'types': ['prefixed unit']},
#  {'term': 'centikelvin', 'types': ['prefixed unit']},
#  {'term': 'attomole', 'types': ['prefixed unit']},
#  {'term': 'geometry', 'types': ['application area']},
#  {'term': 'inductance or permeance (electromagnetic) dimension',
#   'types': ['dimension']},
#  {'term': 'volt', 'types': ['singular unit', 'unit']},
#  {'term': 'second (sidereal)', 'types': ['singular unit', 'unit']},
#  {'term': 'millifarad', 'types': ['prefixed unit']},
#  {'term': 'watt hour', 'types': ['unit multiplication']},
#  {'term': 'mole', 'types': ['singular unit', 'unit']},
#  {'term': 'ampere hour', 'types': ['unit multiplication']},
#  {'term': 'megawatt hour', 'types': ['unit multiplication']},
#  {'term': 'solar luminosity', 'types': ['singular unit', 'unit']},
#  {'term': 'parts per million', 'types': ['singular unit', 'unit']},
#  {'term': 'therm (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'dry quart (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'nanoampere', 'types': ['prefixed unit']},
#  {'term': 'centivolt', 'types': ['prefixed unit']},
#  {'term': 'centipoise', 'types': ['prefixed unit']},
#  {'term': 'hectolitre', 'types': ['prefixed unit']},
#  {'term': 'petalux', 'types': ['prefixed unit']},
#  {'term': 'femtovolt', 'types': ['prefixed unit']},
#  {'term': 'duration of 9 192 631 770 periods of the radiation corresponding to the transition between the two hyperfine levels of the ground state of the cesium 133 atom',
#   'types': ['duration']},
#  {'term': 'fluid ounce (imperial)', 'types': ['singular unit', 'unit']},
#  {'term': 'teravolt', 'types': ['prefixed unit']},
#  {'term': 'megafarad', 'types': ['prefixed unit']},
#  {'term': 'decilumen', 'types': ['prefixed unit']},
#  {'term': 'kilotonne', 'types': ['prefixed unit']},
#  {'term': 'milligray', 'types': ['prefixed unit']},
#  {'term': 'typography', 'types': ['application area']},
#  {'term': 'milliampere', 'types': ['prefixed unit']},
#  {'term': 'hundred count', 'types': ['singular unit', 'unit']},
#  {'term': 'yottametre', 'types': ['prefixed unit']},
#  {'term': 'picometre', 'types': ['prefixed unit']},
#  {'term': 'maxwell', 'types': ['singular unit', 'unit']},
#  {'term': 'terakelvin', 'types': ['prefixed unit']},
#  {'term': 'centipascal', 'types': ['prefixed unit']},
#  {'term': 'abhenry', 'types': ['singular unit', 'unit']},
#  {'term': '1084.62 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'nanosteradian', 'types': ['prefixed unit']},
#  {'term': 'megasiemens', 'types': ['prefixed unit']},
#  {'term': 'coulomb', 'types': ['singular unit', 'unit']},
#  {'term': 'teramole', 'types': ['prefixed unit']},
#  {'term': 'zettatesla', 'types': ['prefixed unit']},
#  {'term': 'zeptokatal', 'types': ['prefixed unit']},
#  {'term': 'decabecquerel', 'types': ['prefixed unit']},
#  {'term': 'yottabyte', 'types': ['prefixed unit']},
#  {'term': 'microfarad', 'types': ['prefixed unit']},
#  {'term': 'gram of carbon dioxide equivalent',
#   'types': ['singular unit', 'unit']},
#  {'term': 'millitesla', 'types': ['prefixed unit']},
#  {'term': 'decagray', 'types': ['prefixed unit']},
#  {'term': 'zeptosievert', 'types': ['prefixed unit']},
#  {'term': 'femtofarad', 'types': ['prefixed unit']},
#  {'term': 'microtesla', 'types': ['prefixed unit']},
#  {'term': 'yoctopascal', 'types': ['prefixed unit']},
#  {'term': 'teracoulomb', 'types': ['prefixed unit']},
#  {'term': 'exposure to x and Î³ rays dimension', 'types': ['dimension']},
#  {'term': 'radiometry and radiobiology', 'types': ['application area']},
#  {'term': 'gigalumen', 'types': ['prefixed unit']},
#  {'term': 'zettafarad', 'types': ['prefixed unit']},
#  {'term': 'nanohenry', 'types': ['prefixed unit']},
#  {'term': 'serving spoon', 'types': ['unit']},
#  {'term': 'acre (US survey)', 'types': ['singular unit', 'unit']},
#  {'term': 'gigawatt', 'types': ['prefixed unit']},
#  {'term': 'micromolar', 'types': ['prefixed unit']},
#  {'term': 'IAU_2012_Resolution_B2', 'types': ['Chapter']},
#  {'term': 'kilosiemens', 'types': ['prefixed unit']},
#  {'term': 'giganewton', 'types': ['prefixed unit']},
#  {'term': 'zeptoohm', 'types': ['prefixed unit']},
#  {'term': 'kilometre', 'types': ['prefixed unit']},
#  {'term': 'exasievert', 'types': ['prefixed unit']},
#  {'term': 'femtoradian', 'types': ['prefixed unit']},
#  {'term': 'action or angular momentum dimension', 'types': ['dimension']},
#  {'term': 'mile (statute)', 'types': ['singular unit', 'unit']},
#  {'term': 'zettacandela', 'types': ['prefixed unit']},
#  {'term': 'decicoulomb', 'types': ['prefixed unit']},
#  {'term': 'gigacandela', 'types': ['prefixed unit']},
#  {'term': 'hectopascal', 'types': ['prefixed unit']},
#  {'term': 'nanovolt', 'types': ['prefixed unit']},
#  {'term': 'gigacoulomb', 'types': ['prefixed unit']},
#  {'term': 'gigayear cubic parsec', 'types': ['unit multiplication']},
#  {'term': 'euro', 'types': ['singular unit', 'unit']},
#  {'term': 'teaspoon (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'yoctowatt', 'types': ['prefixed unit']},
#  {'term': 'zettakatal', 'types': ['prefixed unit']},
#  {'term': 'bar (food)', 'types': ['unit']},
#  {'term': 'chain', 'types': ['singular unit', 'unit']},
#  {'term': 'Crawford1958', 'types': ['Article']},
#  {'term': 'percent', 'types': ['singular unit', 'unit']},
#  {'term': 'decametre', 'types': ['prefixed unit']},
#  {'term': 'megapascal', 'types': ['prefixed unit']},
#  {'term': 'microkelvin', 'types': ['prefixed unit']},
#  {'term': 'millicandela', 'types': ['prefixed unit']},
#  {'term': 'picoohm', 'types': ['prefixed unit']},
#  {'term': 'statampere', 'types': ['singular unit', 'unit']},
#  {'term': 'zettametre', 'types': ['prefixed unit']},
#  {'term': 'dozen', 'types': ['singular unit', 'unit']},
#  {'term': 'zettaampere', 'types': ['prefixed unit']},
#  {'term': 'Swiss franc', 'types': ['singular unit', 'unit']},
#  {'term': 'kinematic viscosity dimension', 'types': ['dimension']},
#  {'term': 'exalitre', 'types': ['prefixed unit']},
#  {'term': 'AFS', 'types': ['singular unit', 'unit']},
#  {'term': 'gigaweber', 'types': ['prefixed unit']},
#  {'term': 'millisteradian', 'types': ['prefixed unit']},
#  {'term': 'chapter23_Astronomical_Algorithms', 'types': ['Chapter']},
#  {'term': 'microhenry', 'types': ['prefixed unit']},
#  {'term': 'megaweber', 'types': ['prefixed unit']},
#  {'term': 'microsecond', 'types': ['prefixed unit']},
#  {'term': 'yottalumen', 'types': ['prefixed unit']},
#  {'term': 'hour', 'types': ['singular unit', 'unit']},
#  {'term': 'hectolumen', 'types': ['prefixed unit']},
#  {'term': '1337.33 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'column number density dimension', 'types': ['dimension']},
#  {'term': 'mho', 'types': ['singular unit', 'unit']},
#  {'term': 'centisievert', 'types': ['prefixed unit']},
#  {'term': 'zettaweber', 'types': ['prefixed unit']},
#  {'term': 'decacoulomb', 'types': ['prefixed unit']},
#  {'term': 'volumetric heat capacity dimension', 'types': ['dimension']},
#  {'term': 'watt square metre', 'types': ['unit multiplication']},
#  {'term': 'specific energy, absorbed dose, or dose equivalent dimension',
#   'types': ['dimension']},
#  {'term': 'petasiemens', 'types': ['prefixed unit']},
#  {'term': 'minute', 'types': ['singular unit', 'unit']},
#  {'term': 'unified atomic mass unit', 'types': ['singular unit', 'unit']},
#  {'term': 'VistasAstronomy', 'types': ['Journal']},
#  {'term': 'steradian square metre hertz', 'types': ['unit multiplication']},
#  {'term': 'astronomy and astrophysics', 'types': ['application area']},
#  {'term': 'teranewton', 'types': ['prefixed unit']},
#  {'term': 'hectosecond', 'types': ['prefixed unit']},
#  {'term': 'attowatt', 'types': ['prefixed unit']},
#  {'term': 'nautical mile (international)', 'types': ['singular unit', 'unit']},
#  {'term': 'attojoule', 'types': ['prefixed unit']},
#  {'term': 'calorie (15 Â°C)', 'types': ['singular unit', 'unit']},
#  {'term': 'exbibit', 'types': ['prefixed unit']},
#  {'term': 'megabyte', 'types': ['prefixed unit']},
#  {'term': 'information capacity of one binary digit',
#   'types': ['information capacity']},
#  {'term': 'tonne of carbon dioxide equivalent per gigawatt hour',
#   'types': ['unit division', 'unit']},
#  {'term': 'biot', 'types': ['singular unit', 'unit']},
#  {'term': 'permeance (materials science) dimension', 'types': ['dimension']},
#  {'term': 'time dimension', 'types': ['dimension']},
#  {'term': 'megaelectronvolt', 'types': ['prefixed unit']},
#  {'term': 'statmho', 'types': ['singular unit', 'unit']},
#  {'term': 'yoctohenry', 'types': ['prefixed unit']},
#  {'term': 'electric field dimension', 'types': ['dimension']},
#  {'term': 'electric dipole moment dimension', 'types': ['dimension']},
#  {'term': 'hertz', 'types': ['singular unit', 'unit']},
#  {'term': '419.527 on the Celsius scale', 'types': ['fixed point']},
#  {'term': 'teracandela', 'types': ['prefixed unit']},
#  {'term': 'thousand piece', 'types': ['singular unit', 'unit']},
#  {'term': 'megavolt', 'types': ['prefixed unit']},
#  {'term': 'zettagram', 'types': ['prefixed unit']},
#  {'term': 'constant current that produces an attractive force of 2eâ€“7 newton per metre of length between two straight, parallel conductors of infinite length and negligible circular cross section placed one metre apart in a vacuum',
#   'types': ['electric current']},
#  {'term': 'abfarad', 'types': ['singular unit', 'unit']},
#  {'term': 'decikatal', 'types': ['prefixed unit']},
#  {'term': 'femtodegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'second (hour angle)', 'types': ['singular unit', 'unit']},
#  {'term': 'scoop', 'types': ['unit']},
#  {'term': 'becquerel', 'types': ['singular unit', 'unit']},
#  {'term': 'kiloparsec', 'types': ['prefixed unit']},
#  {'term': 'centinewton', 'types': ['prefixed unit']},
#  {'term': 'nanopascal', 'types': ['prefixed unit']},
#  {'term': 'deciweber', 'types': ['prefixed unit']},
#  {'term': 'megaampere', 'types': ['prefixed unit']},
#  {'term': 'zettamole', 'types': ['prefixed unit']},
#  {'term': 'petapascal', 'types': ['prefixed unit']},
#  {'term': 'yoctojoule', 'types': ['prefixed unit']},
#  {'term': 'specific catalytic activity dimension', 'types': ['dimension']},
#  {'term': 'zettalumen', 'types': ['prefixed unit']},
#  {'term': 'decijoule', 'types': ['prefixed unit']},
#  {'term': 'thermal resistance dimension', 'types': ['dimension']},
#  {'term': 'megatesla', 'types': ['prefixed unit']},
#  {'term': 'volume dimension', 'types': ['dimension']},
#  {'term': 'exacoulomb', 'types': ['prefixed unit']},
#  {'term': 'megohm', 'types': ['prefixed unit']},
#  {'term': 'hartley', 'types': ['singular unit', 'unit']},
#  {'term': 'femtoampere', 'types': ['prefixed unit']},
#  {'term': 'millimetre of mercury', 'types': ['prefixed unit']},
#  {'term': 'femtometre', 'types': ['prefixed unit']},
#  {'term': 'zettahertz', 'types': ['prefixed unit']},
#  {'term': 'degree Celsius day', 'types': ['unit multiplication']},
#  {'term': 'deciohm', 'types': ['prefixed unit']},
#  {'term': 'microlux', 'types': ['prefixed unit']},
#  {'term': '1234.93 on the Kelvin scale', 'types': ['fixed point']},
#  {'term': 'centiweber', 'types': ['prefixed unit']},
#  {'term': 'ton-force (short)', 'types': ['singular unit', 'unit']},
#  {'term': 'information technology', 'types': ['application area']},
#  {'term': 'electric charge dimension', 'types': ['dimension']},
#  {'term': 'centibecquerel', 'types': ['prefixed unit']},
#  {'term': 'erg', 'types': ['singular unit', 'unit']},
#  {'term': 'kilogray', 'types': ['prefixed unit']},
#  {'term': 'angular acceleration dimension', 'types': ['dimension']},
#  {'term': 'hectonewton', 'types': ['prefixed unit']},
#  {'term': 'microohm', 'types': ['prefixed unit']},
#  {'term': 'area dimension', 'types': ['dimension']},
#  {'term': 'yottamole', 'types': ['prefixed unit']},
#  {'term': 'zettajoule', 'types': ['prefixed unit']},
#  {'term': 'degree Fahrenheit', 'types': ['singular unit', 'unit']},
#  {'term': 'cup', 'types': ['unit']},
#  {'term': 'hectokatal', 'types': ['prefixed unit']},
#  {'term': 'jansky', 'types': ['singular unit', 'unit']},
#  {'term': 'decahenry', 'types': ['prefixed unit']},
#  {'term': 'electrical conductance dimension', 'types': ['dimension']},
#  {'term': 'yoctocandela', 'types': ['prefixed unit']},
#  {'term': 'Glossary_Astronomical_Almanac', 'types': ['BookSection']},
#  {'term': 'sustainability', 'types': ['application area']},
#  {'term': 'dessertspoon', 'types': ['singular unit', 'unit']},
#  {'term': 'economics', 'types': ['application area']},
#  {'term': 'decajoule', 'types': ['prefixed unit']},
#  {'term': 'gram', 'types': ['singular unit', 'unit']},
#  {'term': 'attodegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'picocoulomb', 'types': ['prefixed unit']},
#  {'term': 'British thermal unit (thermochemical)',
#   'types': ['singular unit', 'unit']},
#  {'term': 'bel', 'types': ['singular unit', 'unit']},
#  {'term': 'gibibyte', 'types': ['prefixed unit']},
#  {'term': 'gigahertz', 'types': ['prefixed unit']},
#  {'term': 'microweber', 'types': ['prefixed unit']},
#  {'term': 'bit', 'types': ['singular unit', 'unit']},
#  {'term': 'yottamolar', 'types': ['prefixed unit']},
#  {'term': 'hectofarad', 'types': ['prefixed unit']},
#  {'term': 'centiampere', 'types': ['prefixed unit']},
#  {'term': 'millilitre', 'types': ['prefixed unit']},
#  {'term': 'newton metre', 'types': ['unit multiplication']},
#  {'term': 'illuminance dimension', 'types': ['dimension']},
#  {'term': 'yoctoweber', 'types': ['prefixed unit']},
#  {'term': 'year', 'types': ['singular unit', 'unit']},
#  {'term': 'zettacoulomb', 'types': ['prefixed unit']},
#  {'term': 'megawatt', 'types': ['prefixed unit']},
#  {'term': 'nanogray', 'types': ['prefixed unit']},
#  {'term': 'microhertz', 'types': ['prefixed unit']},
#  {'term': 'attoampere', 'types': ['prefixed unit']},
#  {'term': 'picosteradian', 'types': ['prefixed unit']},
#  {'term': 'ton (short)', 'types': ['singular unit', 'unit']},
#  {'term': 'week', 'types': ['singular unit', 'unit']},
#  {'term': 'millilux', 'types': ['prefixed unit']},
#  {'term': 'Japanese yen', 'types': ['singular unit', 'unit']},
#  {'term': 'electrical resistance dimension', 'types': ['dimension']},
#  {'term': 'centitesla', 'types': ['prefixed unit']},
#  {'term': 'megahertz', 'types': ['prefixed unit']},
#  {'term': 'nanowatt', 'types': ['prefixed unit']},
#  {'term': 'yottawatt', 'types': ['prefixed unit']},
#  {'term': 'centidegree Celsius', 'types': ['prefixed unit']},
#  {'term': 'femtosteradian', 'types': ['prefixed unit']},
#  {'term': 'picohenry', 'types': ['prefixed unit']},
#  {'term': 'centimolar', 'types': ['prefixed unit']},
#  {'term': 'terasiemens', 'types': ['prefixed unit']},
#  {'term': 'examolar', 'types': ['prefixed unit']},
#  {'term': 'power density dimension', 'types': ['dimension']},
#  {'term': 'dynamic viscosity dimension', 'types': ['dimension']},
#  {'term': 'microampere', 'types': ['prefixed unit']},
#  {'term': 'attoradian', 'types': ['prefixed unit']},
#  {'term': 'foot (international)', 'types': ['singular unit', 'unit']},
#  {'term': 'kelvin mole', 'types': ['unit multiplication']},
#  {'term': 'Astrophysical_Techniques', 'types': ['Book']},
#  {'term': 'femtojoule', 'types': ['prefixed unit']},
#  {'term': 'mole micrometre reciprocal square centimetre',
#   'types': ['unit multiplication']},
#  {'term': 'kilogram square metre', 'types': ['unit multiplication']},
#  {'term': 'decafarad', 'types': ['prefixed unit']},
#  {'term': 'torr', 'types': ['singular unit', 'unit']},
#  {'term': 'pica (TeX)', 'types': ['singular unit', 'unit']},
#  {'term': 'yottasiemens', 'types': ['prefixed unit']},
#  {'term': 'circular mil', 'types': ['singular unit', 'unit']},
#  {'term': 'triple point of water thermodynamic temperature',
#   'types': ['thermodynamic temperature']},
#  {'term': 'femtonewton', 'types': ['prefixed unit']},
#  {'term': 'Mexican peso', 'types': ['singular unit', 'unit']},
#  {'term': 'second', 'types': ['singular unit', 'unit']},
#  {'term': 'mil (angle)', 'types': ['singular unit', 'unit']},
#  {'term': 'Australian dollar', 'types': ['singular unit', 'unit']},
#  {'term': 'ton of TNT', 'types': ['singular unit', 'unit']},
#  {'term': 'petasievert', 'types': ['prefixed unit']},
#  {'term': 'hectomole', 'types': ['prefixed unit']},
#  {'term': 'electric flux density dimension', 'types': ['dimension']},
#  {'term': 'pebibit', 'types': ['prefixed unit']},
#  {'term': 'liquid quart (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'kilokelvin', 'types': ['prefixed unit']},
#  {'term': 'centistokes', 'types': ['prefixed unit']},
#  {'term': 'Indian rupee', 'types': ['singular unit', 'unit']},
#  {'term': 'dash', 'types': ['unit']},
#  {'term': 'IntroAstronomicalPhotometry_chapter_2', 'types': ['Chapter']},
#  {'term': 'tablespoon (US)', 'types': ['singular unit', 'unit']},
#  {'term': 'exajoule', 'types': ['prefixed unit']},
#  {'term': 'yoctomolar', 'types': ['prefixed unit']},
#  {'term': 'cosmology', 'types': ['application area']},
#  {'term': '0-5', 'types': ['singular unit', 'unit']},
#  {'term': 'megacandela', 'types': ['prefixed unit']},
#  {'term': 'gigavolt', 'types': ['prefixed unit']},
#  {'term': 'millisecond (angle)', 'types': ['prefixed unit']},
#  {'term': 'hectoweber', 'types': ['prefixed unit']},
#  {'term': 'megahenry', 'types': ['prefixed unit']},
#  {'term': 'coulomb metre', 'types': ['unit multiplication']},
#  {'term': 'darcy', 'types': ['singular unit', 'unit']},
#  {'term': 'zeptomole', 'types': ['prefixed unit']},
#  {'term': 'magnitude', 'types': ['singular unit', 'unit', 'quantity']},
#  {'term': 'decilitre', 'types': ['prefixed unit']},
#  {'term': 'terabit', 'types': ['prefixed unit']},
#  {'term': 'yoctobecquerel', 'types': ['prefixed unit']},
#  {'term': 'decisecond', 'types': ['prefixed unit']},
#  {'term': 'Chinese yuan', 'types': ['singular unit', 'unit']},
#  {'term': 'megagram', 'types': ['prefixed unit']},
#  {'term': 'yoctocoulomb', 'types': ['prefixed unit']},
#  {'term': 'megaeuro', 'types': ['prefixed unit']},
#  ...]

# %%
doc_term_types_mapping = []

# %%
for doc in training_data:
    title=doc['title']
    id= doc['id']
    text =doc['text']
    term_types_pairs = []
    for term_type in train_data_term_types:
        if term_type['term'] in title or term_type['term'] in text:
            term_types_pairs.append(term_type)
    doc_term_types_mapping.append({"title":title, "id":id,"text":text, "term_type_pairs":term_types_pairs})

# %%
doc_term_types_mapping
# Out:
# [{'title': 'The Versatility of Prefixed Units in Measurement',
#   'id': '0_2',
#   'text': "The realm of measurement encompasses a vast array of units, many of which are modified by prefixes to denote scale. In the domain of physics and engineering, prefixed units are ubiquitous. For instance, units of length such as the centimetre, picometre, and terametre are used to measure distances ranging from the minute to the astronomical. Similarly, forces are measured in femtonewtons and teranewtons, reflecting the vast scales involved in scientific and engineering applications.\n\nEnergy measurements utilize units like the hectojoule, while power is quantified in petawatts and deciwatts. The digital realm relies on units such as the gigabit and gigabyte to measure data. Other physical quantities, including magnetic field strength in yoctoteslas and zeptoteslas, and radioactivity in picobecquerels and petabecquerels, demonstrate the diversity of prefixed units.\n\nFurthermore, the measurement of physical properties like capacitance in picofarads and femtofarads, resistance in picoohms, and inductance (though not directly mentioned, it's related to units like webers) in megawebers, showcases the complexity and precision required in various scientific disciplines. The use of prefixed units facilitates the expression of very large and very small quantities, making it an indispensable tool in science and technology.",
#   'term_type_pairs': [{'term': 'weber', 'types': ['singular unit', 'unit']},
#    {'term': 'deciwatt', 'types': ['prefixed unit']},
#    {'term': 'gigabit', 'types': ['prefixed unit']},
#    {'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': 'byte', 'types': ['singular unit', 'unit']},
#    {'term': 'joule', 'types': ['singular unit', 'unit']},
#    {'term': 'picobecquerel', 'types': ['prefixed unit']},
#    {'term': 'picofarad', 'types': ['prefixed unit']},
#    {'term': 'hectojoule', 'types': ['prefixed unit']},
#    {'term': 'petabecquerel', 'types': ['prefixed unit']},
#    {'term': 'yoctotesla', 'types': ['prefixed unit']},
#    {'term': 'watt', 'types': ['singular unit', 'unit']},
#    {'term': 'zeptotesla', 'types': ['prefixed unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'centimetre', 'types': ['prefixed unit']},
#    {'term': 'newton', 'types': ['singular unit', 'unit']},
#    {'term': 'metre', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'petawatt', 'types': ['prefixed unit']},
#    {'term': 'tesla', 'types': ['singular unit', 'unit']},
#    {'term': 'farad', 'types': ['singular unit', 'unit']},
#    {'term': 'picometre', 'types': ['prefixed unit']},
#    {'term': 'femtofarad', 'types': ['prefixed unit']},
#    {'term': 'picoohm', 'types': ['prefixed unit']},
#    {'term': 'megaweber', 'types': ['prefixed unit']},
#    {'term': 'minute', 'types': ['singular unit', 'unit']},
#    {'term': 'teranewton', 'types': ['prefixed unit']},
#    {'term': 'becquerel', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'bit', 'types': ['singular unit', 'unit']},
#    {'term': 'femtonewton', 'types': ['prefixed unit']},
#    {'term': 'terametre', 'types': ['prefixed unit']},
#    {'term': 'ohm', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']},
#    {'term': 'gigabyte', 'types': ['prefixed unit']}]},
#  {'title': 'Dimensions in Units of Measure',
#   'id': '10_0',
#   'text': 'In the realm of units of measure, various physical quantities and properties are defined by their dimensions. Specific volume, mass flow, electric charge, electrical conductance, power density, catalytic activity, dynamic viscosity, luminance, volumetric heat capacity, thermal resistance, permittivity, molar energy, angular speed, fluidity, thermodynamic temperature, electrical resistance, pressure, inductance or permeance (electromagnetic), specific catalytic activity, luminous energy, absorbed dose rate, magnetic flux density, thermal insulance, electric flux density, capacitance, volumetric flow rate, amount of substance concentration, electric field, catalytic activity concentration, electric potential, specific energy (absorbed dose or dose equivalent), reluctance, exposure to X and γ rays, luminous flux, time, entropy or heat capacity, energy density, action or angular momentum, length, molar entropy (molar heat capacity or gas constant), current density, frequency, surface tension, illuminance, electric current, density, energy, column number density, angular acceleration, and force are all recognized dimensions.',
#   'term_type_pairs': [{'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'molar', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Categorization of Body Label Mass in Units of Measure',
#   'id': '43_0',
#   'text': 'In the context of units of measure, "body label mass" is categorized as a specific type of "label mass". This indicates that "body label mass" is a more specialized or specific instance within the broader category of "label mass". The categorization helps in understanding the hierarchy and relationship between different types of masses used in measurement.',
#   'term_type_pairs': [{'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'bel', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Definition of the Second in the International System of Units',
#   'id': '25_0',
#   'text': 'The second is defined as the duration of 9,192,631,770 periods of the radiation corresponding to the transition between the two hyperfine levels of the ground state of the cesium-133 atom. This definition highlights a fundamental unit of time in the International System of Units (SI), illustrating how a specific physical phenomenon is used to quantify duration.',
#   'term_type_pairs': [{'term': 'second', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Understanding Units of Measure: Types and Applications',
#   'id': '1_11',
#   'text': 'In the realm of measurement, various units are utilized across different disciplines. Units such as therm (US), candela, statfarad, röntgen, hour (sidereal), United States dollar, bit, 1/0, shake, acre (international), and percent are recognized as singular units. These units are fundamental in their respective domains, ranging from physics to finance.\n\nFurthermore, units can be categorized into different types based on their characteristics and the quantities they measure. A compound unit, for instance, is a type of unit that is derived from the combination of simpler units. Compound units can be formed through unit multiplication, unit exponentiation, or unit division, each representing a different mathematical operation.\n\nThe hierarchy of units is extensive. For example, length unit, area unit, volume unit, angle unit, solid angle unit, time unit, mass unit, quantity of dimension one unit, number unit, ratio unit, and percentage unit are all types of units. More specifically, font size unit is categorized as a type of length unit. Additionally, there are units like mass fraction unit, area fraction unit, volume fraction unit, and relative humidity unit, which are used to express proportions or ratios.\n\nIn the realm of physics, units such as frequency unit, number density unit, wave number unit, acceleration unit, density unit, specific volume unit, speed unit, force unit, pressure unit, stress unit, torque unit, moment of force unit, energy unit, power unit, specific energy unit, angular speed unit, angular acceleration unit, and dynamic viscosity unit are crucial for describing various physical quantities.',
#   'term_type_pairs': [{'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': '1/0', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'portion', 'types': ['unit']},
#    {'term': 'shake', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'hour (sidereal)', 'types': ['singular unit', 'unit']},
#    {'term': 'United States dollar', 'types': ['singular unit', 'unit']},
#    {'term': 'farad', 'types': ['singular unit', 'unit']},
#    {'term': 'statfarad', 'types': ['singular unit', 'unit']},
#    {'term': 'therm (US)', 'types': ['singular unit', 'unit']},
#    {'term': 'percent', 'types': ['singular unit', 'unit']},
#    {'term': 'hour', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'bit', 'types': ['singular unit', 'unit']},
#    {'term': 'candela', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']},
#    {'term': 'acre (international)', 'types': ['singular unit', 'unit']}]},
#  {'title': 'The Diverse World of Units of Measure: A Comprehensive Overview',
#   'id': '1_3',
#   'text': 'The realm of units of measure is vast and diverse, encompassing a wide array of categories that facilitate the quantification of various physical and abstract quantities. In the domain of length, units such as the mile (statute) and metre are fundamental, with the metre serving as the base unit of length in the International System of Units (SI). Other units like the mil (length) and pica (TeX) cater to more specialized needs, while the metre of mercury is used in specific contexts like pressure measurement.\n\nTime is another critical dimension, with the second being the SI base unit. It is supplemented by larger units such as the minute and year, with sidereal variations accounting for astronomical observations. Energy and work are quantified using units like the British thermal unit (60 °F), quad, and therm (EC), with the joule being the SI unit for energy.\n\nCurrency is a unique category, with units like the euro, Chinese yuan, Singapore dollar, and Japanese yen facilitating global trade and finance. In the realm of physical sciences, units such as the mole (amount of substance), pascal (pressure), and curie (radioactivity) are indispensable. Other units like the weber (magnetic flux), dyne (force), and ohm (electrical resistance) further illustrate the breadth of measurement.\n\nSpecialized fields and industries often adopt their own units; for instance, the delta A450 is used in biochemistry, while terms like deep bowl and pinch are more colloquial. The diversity of units is also evident in cooking, with measurements like the teaspoon (US) and cup (US customary), and in commerce, with units like the carat (mass) for gemstones and the thousand piece for quantities of items.\n\nPower is measured in units such as horsepower (water) and horsepower (British), with the watt being the SI unit. The ton-force (short) is another unit related to force. The variety of units reflects the complexity and richness of human endeavor to quantify and understand the world.',
#   'term_type_pairs': [{'term': 'weber', 'types': ['singular unit', 'unit']},
#    {'term': 'piece', 'types': ['unit']},
#    {'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'chemistry', 'types': ['application area']},
#    {'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': 'joule', 'types': ['singular unit', 'unit']},
#    {'term': 'dyne', 'types': ['singular unit', 'unit']},
#    {'term': 'deep bowl', 'types': ['unit']},
#    {'term': 'quad', 'types': ['singular unit', 'unit']},
#    {'term': 'bowl', 'types': ['unit']},
#    {'term': 'therm (EC)', 'types': ['singular unit', 'unit']},
#    {'term': 'watt', 'types': ['singular unit', 'unit']},
#    {'term': 'carat (mass)', 'types': ['singular unit', 'unit']},
#    {'term': 'metre of mercury', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'pinch', 'types': ['unit']},
#    {'term': 'horsepower (British)', 'types': ['singular unit', 'unit']},
#    {'term': 'cup (US customary)', 'types': ['singular unit', 'unit']},
#    {'term': 'metre', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'horsepower (water)', 'types': ['singular unit', 'unit']},
#    {'term': 'Singapore dollar', 'types': ['singular unit', 'unit']},
#    {'term': 'mil (length)', 'types': ['singular unit', 'unit']},
#    {'term': 'mole', 'types': ['singular unit', 'unit']},
#    {'term': 'mile (statute)', 'types': ['singular unit', 'unit']},
#    {'term': 'euro', 'types': ['singular unit', 'unit']},
#    {'term': 'teaspoon (US)', 'types': ['singular unit', 'unit']},
#    {'term': 'minute', 'types': ['singular unit', 'unit']},
#    {'term': 'thousand piece', 'types': ['singular unit', 'unit']},
#    {'term': 'ton-force (short)', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'cup', 'types': ['unit']},
#    {'term': 'year', 'types': ['singular unit', 'unit']},
#    {'term': 'Japanese yen', 'types': ['singular unit', 'unit']},
#    {'term': 'pica (TeX)', 'types': ['singular unit', 'unit']},
#    {'term': 'second', 'types': ['singular unit', 'unit']},
#    {'term': 'Chinese yuan', 'types': ['singular unit', 'unit']},
#    {'term': 'pascal', 'types': ['singular unit', 'unit']},
#    {'term': 'ohm', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']},
#    {'term': 'curie', 'types': ['singular unit', 'unit']},
#    {'term': 'delta A450', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Types of Distances in Units of Measure',
#   'id': '34_0',
#   'text': 'In the realm of Units of Measure, distance is a fundamental concept that comes in various forms. The distance modulus is categorized as a type of distance. Additionally, there are several other types of distances, including the total 3D start-end distance, xy 2D start-end distance, total distance travelled, and xy distance travelled, all of which fall under the broader category of distance. Understanding these different types of distances is crucial for accurate measurements in various fields.',
#   'term_type_pairs': [{'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Prefixed Units of Measurement Across Various Domains',
#   'id': '0_3',
#   'text': 'The realm of units of measurement is vast and diverse, encompassing a wide array of prefixed units that denote various quantities. Among the units of time, we have the hectosecond, decisecond, and others like the yoctosecond, which represent different scales of time measurement. In the domain of chemistry, units such as the hectomolar, decimole, femtomole, and yoctomolar are used to express molarity. \n\nForce is measured in units like the micronewton and zeptonewton, while pressure is quantified in units such as the picopascal and yoctopascal. Electrical measurements involve units like the millivolt and kiloampere, with larger scales represented by units such as the exaampere. \n\nThe measurement of radioactivity utilizes units like the zettabecquerel, and illumination is quantified in terms of lumens, with units ranging from the microlumen to larger scales. The diversity of these units is further highlighted by the presence of units like the terasiemens and zettasiemens for conductance, and the giganewton for force, demonstrating the extensive range of measurement scales.\n\nOther notable units include the pebibyte and exbibit for digital information, and various units for other physical quantities such as the yottatesla for magnetic field strength, the terakatal for catalytic activity, and the gigalux for illuminance. This array of prefixed units underscores the complexity and the precision required in scientific and technical measurements.',
#   'term_type_pairs': [{'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'chemistry', 'types': ['application area']},
#    {'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': 'byte', 'types': ['singular unit', 'unit']},
#    {'term': 'picopascal', 'types': ['prefixed unit']},
#    {'term': 'yoctosecond', 'types': ['prefixed unit']},
#    {'term': 'zettabecquerel', 'types': ['prefixed unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'micron', 'types': ['singular unit', 'unit']},
#    {'term': 'decimole', 'types': ['prefixed unit']},
#    {'term': 'pebibyte', 'types': ['prefixed unit']},
#    {'term': 'siemens', 'types': ['singular unit', 'unit']},
#    {'term': 'exaampere', 'types': ['prefixed unit']},
#    {'term': 'gal', 'types': ['singular unit', 'unit']},
#    {'term': 'newton', 'types': ['singular unit', 'unit']},
#    {'term': 'zettasiemens', 'types': ['prefixed unit']},
#    {'term': 'microlumen', 'types': ['prefixed unit']},
#    {'term': 'yottatesla', 'types': ['prefixed unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'katal', 'types': ['singular unit', 'unit']},
#    {'term': 'lumen', 'types': ['singular unit', 'unit']},
#    {'term': 'tesla', 'types': ['singular unit', 'unit']},
#    {'term': 'gigalux', 'types': ['prefixed unit']},
#    {'term': 'hectomolar', 'types': ['prefixed unit']},
#    {'term': 'millivolt', 'types': ['prefixed unit']},
#    {'term': 'volt', 'types': ['singular unit', 'unit']},
#    {'term': 'mole', 'types': ['singular unit', 'unit']},
#    {'term': 'yoctopascal', 'types': ['prefixed unit']},
#    {'term': 'giganewton', 'types': ['prefixed unit']},
#    {'term': 'hectosecond', 'types': ['prefixed unit']},
#    {'term': 'exbibit', 'types': ['prefixed unit']},
#    {'term': 'becquerel', 'types': ['singular unit', 'unit']},
#    {'term': 'bit', 'types': ['singular unit', 'unit']},
#    {'term': 'terasiemens', 'types': ['prefixed unit']},
#    {'term': 'second', 'types': ['singular unit', 'unit']},
#    {'term': 'yoctomolar', 'types': ['prefixed unit']},
#    {'term': 'decisecond', 'types': ['prefixed unit']},
#    {'term': 'ampere', 'types': ['singular unit', 'unit']},
#    {'term': 'zeptonewton', 'types': ['prefixed unit']},
#    {'term': 'femtomole', 'types': ['prefixed unit']},
#    {'term': 'pascal', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']},
#    {'term': 'terakatal', 'types': ['prefixed unit']},
#    {'term': 'micronewton', 'types': ['prefixed unit']},
#    {'term': 'molar', 'types': ['singular unit', 'unit']},
#    {'term': 'kiloampere', 'types': ['prefixed unit']}]},
#  {'title': 'Prefixed Units in the Metric System: A Comprehensive Overview',
#   'id': '0_11',
#   'text': "The realm of Units of Measure encompasses a vast array of prefixed units, each serving a specific purpose in quantifying various physical quantities. Starting from the smallest scales, we have units like the attobecquerel, femtokatal, and yoctofarad, which are utilized in measuring radioactivity, catalytic activity, and capacitance, respectively. Moving up the scale, we encounter units such as the microcandela for luminous intensity, megagram for mass, and zettasecond for time, illustrating the breadth of measurement in physics. Furthermore, units like the petacandela, teravolt, and gigavolt are used for luminous intensity and electromotive force, showcasing the range of electrical measurements. The diversity continues with units like the hectopascal for pressure, exalitre for volume, and kilogray for absorbed radiation dose, highlighting the complexity and specificity of measurements across different domains. Other notable mentions include the deciampere and femtoampere for electric current, centisiemens and nanosiemens for conductance, and nanolumen and exalumen for luminous flux. The list extends to include measurements of magnetic flux with units like the femtoweber and nanoweber, and temperature with megakelvin and nanokelvin. The extensive array of prefixed units in the metric system facilitates precise and concise expression of a wide range of quantities, underscoring the system's versatility and utility in science and everyday applications.",
#   'term_type_pairs': [{'term': 'weber', 'types': ['singular unit', 'unit']},
#    {'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'centisiemens', 'types': ['prefixed unit']},
#    {'term': 'megakelvin', 'types': ['prefixed unit']},
#    {'term': 'microcandela', 'types': ['prefixed unit']},
#    {'term': 'zettasecond', 'types': ['prefixed unit']},
#    {'term': 'nanolumen', 'types': ['prefixed unit']},
#    {'term': 'litre', 'types': ['singular unit', 'unit']},
#    {'term': 'nanoweber', 'types': ['prefixed unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'deciampere', 'types': ['prefixed unit']},
#    {'term': 'siemens', 'types': ['singular unit', 'unit']},
#    {'term': 'femtoweber', 'types': ['prefixed unit']},
#    {'term': 'exalumen', 'types': ['prefixed unit']},
#    {'term': 'femtokatal', 'types': ['prefixed unit']},
#    {'term': 'kelvin', 'types': ['singular unit', 'unit']},
#    {'term': 'day', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'nanosiemens', 'types': ['prefixed unit']},
#    {'term': 'yoctofarad', 'types': ['prefixed unit']},
#    {'term': 'katal', 'types': ['singular unit', 'unit']},
#    {'term': 'lumen', 'types': ['singular unit', 'unit']},
#    {'term': 'petacandela', 'types': ['prefixed unit']},
#    {'term': 'attobecquerel', 'types': ['prefixed unit']},
#    {'term': 'farad', 'types': ['singular unit', 'unit']},
#    {'term': 'gray', 'types': ['singular unit', 'unit']},
#    {'term': 'volt', 'types': ['singular unit', 'unit']},
#    {'term': 'teravolt', 'types': ['prefixed unit']},
#    {'term': 'hectopascal', 'types': ['prefixed unit']},
#    {'term': 'exalitre', 'types': ['prefixed unit']},
#    {'term': 'becquerel', 'types': ['singular unit', 'unit']},
#    {'term': 'femtoampere', 'types': ['prefixed unit']},
#    {'term': 'kilogray', 'types': ['prefixed unit']},
#    {'term': 'gram', 'types': ['singular unit', 'unit']},
#    {'term': 'second', 'types': ['singular unit', 'unit']},
#    {'term': 'gigavolt', 'types': ['prefixed unit']},
#    {'term': 'megagram', 'types': ['prefixed unit']},
#    {'term': 'ampere', 'types': ['singular unit', 'unit']},
#    {'term': 'pascal', 'types': ['singular unit', 'unit']},
#    {'term': 'nanokelvin', 'types': ['prefixed unit']},
#    {'term': 'candela', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Understanding g Magnitude in the Context of Thuan and Gunn Magnitude',
#   'id': '50_0',
#   'text': 'In the context of astronomical measurements, the g magnitude is categorized as a specific type of magnitude known as Thuan and Gunn magnitude. This classification indicates that g magnitude is a subset or a particular instance of the broader category of Thuan and Gunn magnitudes, which are used in certain photometric systems to measure the brightness of celestial objects.',
#   'term_type_pairs': [{'term': 'phot', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'magnitude', 'types': ['singular unit', 'unit', 'quantity']}]},
#  {'title': 'The Diversity and Range of Units of Measure Across Various Domains',
#   'id': '1_2',
#   'text': 'The realm of units of measure is vast and diverse, encompassing a wide array of standards and non-standard measurements. Units such as the newton, siemens, and katal are part of the SI system, used to measure force, conductance, and catalytic activity, respectively. Other units like the milligram, gram, and tonne are used to measure mass, with the milligram being a smaller unit and the tonne being much larger. The diversity in units is also seen in measurements of energy, where terms like calorie (mean), British thermal unit (59 °F), and ton of TNT are used, each representing different quantities and contexts of energy measurement.\n\nLength and distance are measured using units such as the astronomical unit, furlong (international), and pica (ATA), showcasing a range from the vastness of astronomical distances to the precision needed in printing measurements. Volume is another area with a multitude of units, including the gallon (US), gill (imperial), cup, and dessertspoon, reflecting various historical and practical contexts.\n\nThe list also includes units related to other physical quantities like time (second, hour), angle (second, gon), and power (horsepower (electric)). Some units, like the colony forming unit and portion, are more related to biological or culinary contexts. The presence of units like the abohm, abmho, and statohm (implied, though not directly listed) points to the historical development of electrical units.\n\nThe units of measure are not limited to physical quantities; there are also units related to currency (Brazilian real), though this is more of a unit of exchange rather than measure. The diversity in units highlights the complexity and the specific needs across different fields and cultures.',
#   'term_type_pairs': [{'term': 'statohm', 'types': ['singular unit', 'unit']},
#    {'term': 'furlong (international)', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'portion', 'types': ['unit']},
#    {'term': 'siemens', 'types': ['singular unit', 'unit']},
#    {'term': 'gill (imperial)', 'types': ['singular unit', 'unit']},
#    {'term': 'Brazilian real', 'types': ['singular unit', 'unit']},
#    {'term': 'calorie (mean)', 'types': ['singular unit', 'unit']},
#    {'term': 'gal', 'types': ['singular unit', 'unit']},
#    {'term': 'pica (ATA)', 'types': ['singular unit', 'unit']},
#    {'term': 'newton', 'types': ['singular unit', 'unit']},
#    {'term': 'astronomical unit', 'types': ['singular unit', 'unit']},
#    {'term': 'abmho', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'colony forming unit',
#     'types': ['singular unit', 'unit division', 'unit']},
#    {'term': 'tonne', 'types': ['singular unit', 'unit']},
#    {'term': 'katal', 'types': ['singular unit', 'unit']},
#    {'term': 'gon', 'types': ['singular unit', 'unit']},
#    {'term': 'abohm', 'types': ['singular unit', 'unit']},
#    {'term': 'hour', 'types': ['singular unit', 'unit']},
#    {'term': 'mho', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'cup', 'types': ['unit']},
#    {'term': 'dessertspoon', 'types': ['singular unit', 'unit']},
#    {'term': 'gram', 'types': ['singular unit', 'unit']},
#    {'term': 'second', 'types': ['singular unit', 'unit']},
#    {'term': 'ton of TNT', 'types': ['singular unit', 'unit']},
#    {'term': 'milligram', 'types': ['prefixed unit']},
#    {'term': 'gallon (US)', 'types': ['singular unit', 'unit']},
#    {'term': 'ohm', 'types': ['singular unit', 'unit']},
#    {'term': 'horsepower (electric)', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Quantities and Quality Marks in Assessing Plant Quality and Longevity',
#   'id': '6_8',
#   'text': 'In the realm of measuring and assessing the quality and condition of plants and their various parts, several key quantities and quality marks are considered crucial. Various conditions can affect the quality and longevity of cut flowers and stored produce. For instance, factors such as nonturgid flowers, dry leaves, yellow leaves, abscised leaves, wilted leaves, rotten leaves, and nonturgid leaves are all considered quantities that can cause the end of vase life or negatively impact the overall quality. Similarly, dry buds, malformed buds, and abscised buds are quantities that can affect the quality of flowers. \n\nQuality marks are another important aspect, with specific attention given to the condition of flowers, leaves, and the total quality. External browning, vascular browning, and pulp browning are specific types of quantities that can indicate deterioration or damage. Other conditions like stem end rot and stick stone are also significant quantities to measure.\n\nIn assessing the quality and freshness of produce, measurements such as acoustic firmness, firmness as measured by a penetrometer (using different methods), and manual firmness are essential quantities. These measurements help in understanding the condition and possibly the longevity of the produce.',
#   'term_type_pairs': [{'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Prefixed Units of Measurement',
#   'id': '0_0',
#   'text': 'The following units of measurement are examples of prefixed units: femtodegree Celsius, attosecond, nanogray, teralitre, millisteradian, yottalitre, zeptocandela, hectogray, microlitre, millimetre, picolitre, yottakatal, examolar, kilocoulomb, zettaohm, decicoulomb, gigalumen, gigagray, microweber, attokatal, microsecond (angle), yoctosecond, teracandela, hectocoulomb, centikatal, petahenry, decikelvin, hectobecquerel, attonewton, femtohertz, megafarad, megabecquerel, petafarad, hectomole, micromole, petalitre, megapascal, nanomolar, gigagram, exalux, picoradian, millisecond (angle), decaohm, kilotonne, yottaohm, millihenry, zettasievert, gigaweber, yottasiemens, and kilokatal. These units are used across various domains such as physics, chemistry, and engineering, and are modified by prefixes that indicate their magnitude relative to a base unit.',
#   'term_type_pairs': [{'term': 'petahenry', 'types': ['prefixed unit']},
#    {'term': 'petalitre', 'types': ['prefixed unit']},
#    {'term': 'weber', 'types': ['singular unit', 'unit']},
#    {'term': 'attokatal', 'types': ['prefixed unit']},
#    {'term': 'decikelvin', 'types': ['prefixed unit']},
#    {'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'chemistry', 'types': ['application area']},
#    {'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': 'picoradian', 'types': ['prefixed unit']},
#    {'term': 'nanomolar', 'types': ['prefixed unit']},
#    {'term': 'microlitre', 'types': ['prefixed unit']},
#    {'term': 'millihenry', 'types': ['prefixed unit']},
#    {'term': 'degree Celsius', 'types': ['singular unit', 'unit']},
#    {'term': 'zettasievert', 'types': ['prefixed unit']},
#    {'term': 'gigagram', 'types': ['prefixed unit']},
#    {'term': 'litre', 'types': ['singular unit', 'unit']},
#    {'term': 'decaohm', 'types': ['prefixed unit']},
#    {'term': 'yoctosecond', 'types': ['prefixed unit']},
#    {'term': 'second (angle)', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'centikatal', 'types': ['prefixed unit']},
#    {'term': 'attosecond', 'types': ['prefixed unit']},
#    {'term': 'siemens', 'types': ['singular unit', 'unit']},
#    {'term': 'degree', 'types': ['singular unit', 'unit']},
#    {'term': 'yottalitre', 'types': ['prefixed unit']},
#    {'term': 'millisecond', 'types': ['prefixed unit']},
#    {'term': 'sievert', 'types': ['singular unit', 'unit']},
#    {'term': 'henry', 'types': ['singular unit', 'unit']},
#    {'term': 'yottaohm', 'types': ['prefixed unit']},
#    {'term': 'micromole', 'types': ['prefixed unit']},
#    {'term': 'gal', 'types': ['singular unit', 'unit']},
#    {'term': 'newton', 'types': ['singular unit', 'unit']},
#    {'term': 'radian', 'types': ['singular unit', 'unit']},
#    {'term': 'hectocoulomb', 'types': ['prefixed unit']},
#    {'term': 'metre', 'types': ['singular unit', 'unit']},
#    {'term': 'petafarad', 'types': ['prefixed unit']},
#    {'term': 'hectogray', 'types': ['prefixed unit']},
#    {'term': 'femtohertz', 'types': ['prefixed unit']},
#    {'term': 'kelvin', 'types': ['singular unit', 'unit']},
#    {'term': 'megabecquerel', 'types': ['prefixed unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'yottakatal', 'types': ['prefixed unit']},
#    {'term': 'tonne', 'types': ['singular unit', 'unit']},
#    {'term': 'kilokatal', 'types': ['prefixed unit']},
#    {'term': 'millimetre', 'types': ['prefixed unit']},
#    {'term': 'katal', 'types': ['singular unit', 'unit']},
#    {'term': 'exalux', 'types': ['prefixed unit']},
#    {'term': 'lumen', 'types': ['singular unit', 'unit']},
#    {'term': 'teralitre', 'types': ['prefixed unit']},
#    {'term': 'gigagray', 'types': ['prefixed unit']},
#    {'term': 'picolitre', 'types': ['prefixed unit']},
#    {'term': 'zettaohm', 'types': ['prefixed unit']},
#    {'term': 'farad', 'types': ['singular unit', 'unit']},
#    {'term': 'kilocoulomb', 'types': ['prefixed unit']},
#    {'term': 'gray', 'types': ['singular unit', 'unit']},
#    {'term': 'mole', 'types': ['singular unit', 'unit']},
#    {'term': 'megafarad', 'types': ['prefixed unit']},
#    {'term': 'kilotonne', 'types': ['prefixed unit']},
#    {'term': 'coulomb', 'types': ['singular unit', 'unit']},
#    {'term': 'gigalumen', 'types': ['prefixed unit']},
#    {'term': 'decicoulomb', 'types': ['prefixed unit']},
#    {'term': 'megapascal', 'types': ['prefixed unit']},
#    {'term': 'gigaweber', 'types': ['prefixed unit']},
#    {'term': 'millisteradian', 'types': ['prefixed unit']},
#    {'term': 'microsecond', 'types': ['prefixed unit']},
#    {'term': 'hertz', 'types': ['singular unit', 'unit']},
#    {'term': 'teracandela', 'types': ['prefixed unit']},
#    {'term': 'femtodegree Celsius', 'types': ['prefixed unit']},
#    {'term': 'becquerel', 'types': ['singular unit', 'unit']},
#    {'term': 'gram', 'types': ['singular unit', 'unit']},
#    {'term': 'microweber', 'types': ['prefixed unit']},
#    {'term': 'nanogray', 'types': ['prefixed unit']},
#    {'term': 'examolar', 'types': ['prefixed unit']},
#    {'term': 'yottasiemens', 'types': ['prefixed unit']},
#    {'term': 'second', 'types': ['singular unit', 'unit']},
#    {'term': 'hectomole', 'types': ['prefixed unit']},
#    {'term': 'millisecond (angle)', 'types': ['prefixed unit']},
#    {'term': 'magnitude', 'types': ['singular unit', 'unit', 'quantity']},
#    {'term': 'zeptocandela', 'types': ['prefixed unit']},
#    {'term': 'pascal', 'types': ['singular unit', 'unit']},
#    {'term': 'steradian', 'types': ['singular unit', 'unit']},
#    {'term': 'candela', 'types': ['singular unit', 'unit']},
#    {'term': 'hectobecquerel', 'types': ['prefixed unit']},
#    {'term': 'ohm', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']},
#    {'term': 'molar', 'types': ['singular unit', 'unit']},
#    {'term': 'attonewton', 'types': ['prefixed unit']},
#    {'term': 'microsecond (angle)', 'types': ['prefixed unit']}]},
#  {'title': 'Understanding Epoch as a Type of Date',
#   'id': '58_0',
#   'text': 'An epoch is considered a specific type of date, marking a significant point or era in time. It serves as a reference from which other dates are measured, providing a foundational moment in history or a particular context.',
#   'term_type_pairs': [{'term': 'are', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Types of Aberration in Physics',
#   'id': '12_0',
#   'text': 'In the realm of physics, particularly in the study of optics and astronomy, the term "aberration" refers to the distortion or deviation of light. There are specific types of aberrations that are noteworthy. For instance, planetary aberration and stellar aberration are both categorized under the broader phenomenon of aberration. Planetary aberration relates to the distortion caused by the motion of planets, while stellar aberration pertains to the distortion caused by the motion of stars relative to the observer. Understanding these concepts is crucial for accurate astronomical measurements and observations.',
#   'term_type_pairs': [{'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Types of Aberration as Angular Displacement in Units of Measure',
#   'id': '17_0',
#   'text': 'In the realm of Units of Measure, various forms of aberration are recognized as types of angular displacement. Aberration, in general, is classified as a type of angular displacement. More specifically, several subcategories of aberration exist, including annual aberration, diurnal aberration, and secular aberration, all of which are considered types of angular displacement. Furthermore, aberration can also be categorized based on its relation to geographical coordinates, resulting in aberration in longitude and aberration in latitude, both of which are also types of angular displacement. Understanding these different forms of aberration is crucial for precise measurements in various scientific and astronomical contexts.',
#   'term_type_pairs': [{'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Types of Strömgren Magnitude',
#   'id': '9_0',
#   'text': 'Strömgren magnitude is a system of measuring the brightness of celestial objects. Within this system, there are several subtypes of magnitude, including u magnitude, v magnitude, b magnitude, y magnitude, β_narrow magnitude, and β_wide magnitude. Each of these subtypes is a specific type of Strömgren magnitude, used to quantify the brightness of objects in different ways. The u, v, b, and y magnitudes are used to measure the brightness of objects in specific wavelength bands, while β_narrow and β_wide magnitudes are used to measure the brightness of objects in narrow and wide bands, respectively.',
#   'term_type_pairs': [{'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'magnitude', 'types': ['singular unit', 'unit', 'quantity']}]},
#  {'title': 'Units of Measurement Across Various Physical Quantities',
#   'id': '1_12',
#   'text': 'Units of measurement are crucial in science and engineering for quantifying various physical properties. In the realm of fluid dynamics and thermodynamics, several units are defined to measure properties such as kinematic viscosity, power density, radiant intensity, and radiance. Kinematic viscosity, for instance, is measured in units that quantify the ratio of viscosity to density. Power density and radiant intensity are other important measures, with their respective units reflecting the amount of power or radiant flux per unit area or solid angle.\n\nTemperature is a fundamental physical quantity with various units, including thermodynamic temperature units like Kelvin, and other scales such as Celsius, Fahrenheit, Rankine, and Réaumur. These temperature units are essential for measuring thermal energy and its effects.\n\nIn the domain of mechanics, units are defined for quantities like action, angular momentum, fluidity, momentum, moment of inertia, shear rate, surface tension, and volumetric flow rate. These units are vital for describing the motion of objects, the behavior of fluids, and the properties of materials under different conditions.\n\nFurthermore, units are used to measure detectivity, mass flow, mass per energy, area density, and column number density, which are important in various scientific and engineering applications.\n\nElectrical properties are measured using units for electric current, magnetomotive force, current density, electric charge, electric potential, capacitance, electrical resistance, and electrical conductance. Additionally, units for electric field, electric charge density, electric flux density, magnetic flux, magnetic field, and magnetic flux density are crucial for understanding and working with electromagnetic phenomena.\n\nThermal properties, including entropy, heat capacity, specific entropy, specific heat capacity, thermal conductivity, thermal insulance, thermal resistance, heat transfer coefficient, and volumetric heat capacity, are measured with their respective units. These are essential for analyzing and predicting the thermal behavior of systems.\n\nIn summary, a wide array of units is used across different disciplines to quantify various physical properties and phenomena. Understanding and using these units correctly is fundamental to scientific research and engineering practices.',
#   'term_type_pairs': [{'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'mechanics', 'types': ['application area']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'radian', 'types': ['singular unit', 'unit']},
#    {'term': 'thermodynamics', 'types': ['application area']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Prefixed Units in Measurement: Enhancing Precision Across Categories',
#   'id': '0_10',
#   'text': 'The realm of units of measurement is vast and diverse, encompassing a wide range of categories including electrical, physical, and digital units. Many of these units are modified by prefixes that indicate their magnitude, making them "prefixed units." \n\nIn the domain of electrical measurement, units such as the ampere, volt, ohm, siemens, farad, henry, and coulomb are frequently used with prefixes like kilo-, mega-, giga-, tera-, and their smaller counterparts milli-, micro-, nano-, pico-, femto-, atto-, zepto-, and yocto-. For instance, kilovolt, millifarad, microkelvin, and yoctoohm are all examples of prefixed units used to express various electrical quantities with precision.\n\nSimilarly, units of mass like the gram are modified by prefixes to yield units such as kilogram, nanogram, and femtogram. Energy measurements, including joule (implied in units like gigajoule, though not directly listed) and calorie, are also subject to prefixing, as seen in kilocalorie.\n\nLuminous intensity is measured in candela, with prefixed units like kilocandela, gigacandela, and yoctocandela covering a wide range of intensities. Digital information is quantified in bits and bytes, with prefixes like kilo-, giga-, tera-, and zetta- being used to denote larger quantities, such as kilobit, gigabit, terabyte, and zettabit, as well as yottabyte.\n\nOther physical quantities like frequency (measured in hertz), force (newton), pressure (pascal), and absorbed dose (gray) also utilize prefixed units, such as decihertz, hectonewton, petapascal, and petagray.\n\nThe use of prefixed units in measurement facilitates the expression of a broad spectrum of quantities in a clear and concise manner, making it an indispensable tool across various scientific, technical, and everyday applications.',
#   'term_type_pairs': [{'term': 'kilocandela', 'types': ['prefixed unit']},
#    {'term': 'gigabit', 'types': ['prefixed unit']},
#    {'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': 'byte', 'types': ['singular unit', 'unit']},
#    {'term': 'joule', 'types': ['singular unit', 'unit']},
#    {'term': 'nanogram', 'types': ['prefixed unit']},
#    {'term': 'decihertz', 'types': ['prefixed unit']},
#    {'term': 'kilogram', 'types': ['prefixed unit']},
#    {'term': 'kilovolt', 'types': ['prefixed unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'gigajoule', 'types': ['prefixed unit']},
#    {'term': 'siemens', 'types': ['singular unit', 'unit']},
#    {'term': 'henry', 'types': ['singular unit', 'unit']},
#    {'term': 'petagray', 'types': ['prefixed unit']},
#    {'term': 'femtogram', 'types': ['prefixed unit']},
#    {'term': 'newton', 'types': ['singular unit', 'unit']},
#    {'term': 'terabyte', 'types': ['prefixed unit']},
#    {'term': 'kelvin', 'types': ['singular unit', 'unit']},
#    {'term': 'day', 'types': ['singular unit', 'unit']},
#    {'term': 'zettabit', 'types': ['prefixed unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'kilobit', 'types': ['prefixed unit']},
#    {'term': 'yoctoohm', 'types': ['prefixed unit']},
#    {'term': 'farad', 'types': ['singular unit', 'unit']},
#    {'term': 'gray', 'types': ['singular unit', 'unit']},
#    {'term': 'volt', 'types': ['singular unit', 'unit']},
#    {'term': 'millifarad', 'types': ['prefixed unit']},
#    {'term': 'coulomb', 'types': ['singular unit', 'unit']},
#    {'term': 'yottabyte', 'types': ['prefixed unit']},
#    {'term': 'gigacandela', 'types': ['prefixed unit']},
#    {'term': 'microkelvin', 'types': ['prefixed unit']},
#    {'term': 'hertz', 'types': ['singular unit', 'unit']},
#    {'term': 'petapascal', 'types': ['prefixed unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'hectonewton', 'types': ['prefixed unit']},
#    {'term': 'yoctocandela', 'types': ['prefixed unit']},
#    {'term': 'gram', 'types': ['singular unit', 'unit']},
#    {'term': 'bit', 'types': ['singular unit', 'unit']},
#    {'term': 'magnitude', 'types': ['singular unit', 'unit', 'quantity']},
#    {'term': 'ampere', 'types': ['singular unit', 'unit']},
#    {'term': 'pascal', 'types': ['singular unit', 'unit']},
#    {'term': 'candela', 'types': ['singular unit', 'unit']},
#    {'term': 'ohm', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Diverse Units of Measurement Across Various Domains',
#   'id': '1_9',
#   'text': 'Units of measurement are fundamental to describing the world around us, quantifying properties such as length, area, volume, force, energy, and more. Various units have been defined to measure these properties. For length, we have units like the mil, angstrom, and foot (international). Area can be measured in acres (US survey) and circular mils. Volume is quantified using units such as the litre and cup (US customary). Force and energy are measured in units like the dyne, foot poundal, and quad. Other physical properties are measured using units such as the weber, statweber, maxwell for magnetic flux; ohm for resistance; and hertz for frequency. The poise and stokes measure viscosity and kinematic viscosity, respectively. Energy and power are also quantified in units like the therm (EC) and horsepower (British and boiler). Radiation is measured in rads and rems. Furthermore, there are units for currency, like the Japanese yen and Hong Kong dollar, and for counting, such as the gross, hundred count, and thousand piece. Other miscellaneous units include the pixel for digital measurement, the slug for mass, and the lambert for luminance. The radian and revolution measure angles, while the degree Réaumur is a unit of temperature. Lastly, the bel and its related units measure sound levels, and the gilbert is used in the context of magnetomotive force.',
#   'term_type_pairs': [{'term': 'weber', 'types': ['singular unit', 'unit']},
#    {'term': 'piece', 'types': ['unit']},
#    {'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'dyne', 'types': ['singular unit', 'unit']},
#    {'term': 'quad', 'types': ['singular unit', 'unit']},
#    {'term': 'gilbert', 'types': ['singular unit', 'unit']},
#    {'term': 'litre', 'types': ['singular unit', 'unit']},
#    {'term': 'therm (EC)', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'degree', 'types': ['singular unit', 'unit']},
#    {'term': 'cup (US customary)', 'types': ['singular unit', 'unit']},
#    {'term': 'statweber', 'types': ['singular unit', 'unit']},
#    {'term': 'radian', 'types': ['singular unit', 'unit']},
#    {'term': 'foot poundal', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'pixel', 'types': ['singular unit', 'unit']},
#    {'term': 'poise', 'types': ['singular unit', 'unit']},
#    {'term': 'Hong Kong dollar', 'types': ['singular unit', 'unit']},
#    {'term': 'poundal', 'types': ['singular unit', 'unit']},
#    {'term': 'angstrom', 'types': ['singular unit', 'unit']},
#    {'term': 'slug', 'types': ['singular unit', 'unit']},
#    {'term': 'stokes', 'types': ['singular unit', 'unit']},
#    {'term': 'hundred count', 'types': ['singular unit', 'unit']},
#    {'term': 'maxwell', 'types': ['singular unit', 'unit']},
#    {'term': 'hertz', 'types': ['singular unit', 'unit']},
#    {'term': 'thousand piece', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'cup', 'types': ['unit']},
#    {'term': 'bel', 'types': ['singular unit', 'unit']},
# ...
#   'term_type_pairs': [{'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'portion', 'types': ['unit']},
#    {'term': 'newton', 'types': ['singular unit', 'unit']},
#    {'term': 'metre', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Understanding Dry Body Mass in Relation to Dry Mass',
#   'id': '47_0',
#   'text': 'Dry body mass is categorized under dry mass, indicating that it is a specific type or subset of dry mass. This relationship highlights that dry body mass shares the general characteristics of dry mass but is more specific in its definition or application.',
#   'term_type_pairs': [{'term': 'are', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Extinction in Different Wavebands: A Specific Case of Extinction at Waveband',
#   'id': '33_0',
#   'text': 'Extinction measured in various photometric bands, such as the V band, B band, and U band, are all specific types of extinction that occur at particular wavebands. In other words, extinction in the V band, extinction in the B band, and extinction in the U band are all categorized under the broader phenomenon of extinction at a specific waveband. This highlights how different measurement units or bands provide more specific insights into the general concept of extinction.',
#   'term_type_pairs': [{'term': 'phot', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Classification of the Glossary of the Astronomical Almanac',
#   'id': '31_0',
#   'text': 'The Glossary of the Astronomical Almanac is classified as a section within a book, indicating it is a part of a larger publication that focuses on astronomical data and related terminology.',
#   'term_type_pairs': []},
#  {'title': 'Prefixed Units of Measurement Across Various Physical Quantities',
#   'id': '0_5',
#   'text': 'In the realm of Units of Measure, various units are modified by prefixes to denote different scales. For instance, units like nanosecond, centibecquerel, and micromagnitude are examples of prefixed units. The nanosecond is a unit of time, the centibecquerel is a unit of radioactivity, and the micromagnitude is a unit related to magnitude, possibly in the context of earthquakes or brightness. Other examples include exaohm (a unit of electrical resistance), yottagray (a unit of absorbed radiation dose), and zeptoweber (a unit of magnetic flux). \n\nFurther examples encompass a wide range of physical quantities: decaweber and yottaweber for magnetic flux, attofarad and microfarad for capacitance, zettamolar and yottamolar for concentration, terawatt for power, pebibit for digital information, megahertz for frequency, petagram for mass, kilokelvin and exakelvin for temperature, megamole for amount of substance, megahenry for inductance, microampere for electric current, yoctolux for illuminance, micropascal for pressure, exabit for digital information, femtojoule for energy, decikatal and hectokatal for catalytic activity, zeptomolar for concentration, nanocandela for luminous intensity, attoweber for magnetic flux, femtosteradian and yoctosteradian for solid angle, centimetre of mercury for pressure, terajoule for energy, decilumen for luminous flux, kilosievert for dose equivalent, yottamole for amount of substance, centipoise for dynamic viscosity, zeptokatal for catalytic activity, picogram for mass, femtogray for absorbed radiation dose, microsecond for time, petasievert for dose equivalent, kilonewton for force, yoctoampere for electric current, decifarad for capacitance, decinewton for force, kilotesla for magnetic field strength, deciohm for electrical resistance, and nanofarad for capacitance.\n\nThese units, with their diverse prefixes, facilitate the expression of a wide range of measurements across different scientific and engineering disciplines.',
#   'term_type_pairs': [{'term': 'weber', 'types': ['singular unit', 'unit']},
#    {'term': 'centimetre of mercury', 'types': ['prefixed unit']},
#    {'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'nanocandela', 'types': ['prefixed unit']},
#    {'term': 'one', 'types': ['singular unit', 'unit']},
#    {'term': 'micromagnitude', 'types': ['prefixed unit']},
#    {'term': 'nanosecond', 'types': ['prefixed unit']},
#    {'term': 'kilotesla', 'types': ['prefixed unit']},
#    {'term': 'joule', 'types': ['singular unit', 'unit']},
#    {'term': 'picogram', 'types': ['prefixed unit']},
#    {'term': 'attoweber', 'types': ['prefixed unit']},
#    {'term': 'exabit', 'types': ['prefixed unit']},
#    {'term': 'watt', 'types': ['singular unit', 'unit']},
#    {'term': 'metre of mercury', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'centimetre', 'types': ['prefixed unit']},
#    {'term': 'sievert', 'types': ['singular unit', 'unit']},
#    {'term': 'henry', 'types': ['singular unit', 'unit']},
#    {'term': 'exaohm', 'types': ['prefixed unit']},
#    {'term': 'newton', 'types': ['singular unit', 'unit']},
#    {'term': 'radian', 'types': ['singular unit', 'unit']},
#    {'term': 'metre', 'types': ['singular unit', 'unit']},
#    {'term': 'decinewton', 'types': ['prefixed unit']},
#    {'term': 'kelvin', 'types': ['singular unit', 'unit']},
#    {'term': 'attofarad', 'types': ['prefixed unit']},
#    {'term': 'terawatt', 'types': ['prefixed unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'katal', 'types': ['singular unit', 'unit']},
#    {'term': 'poise', 'types': ['singular unit', 'unit']},
#    {'term': 'lumen', 'types': ['singular unit', 'unit']},
#    {'term': 'micropascal', 'types': ['prefixed unit']},
#    {'term': 'zeptomolar', 'types': ['prefixed unit']},
#    {'term': 'yottaweber', 'types': ['prefixed unit']},
#    {'term': 'tesla', 'types': ['singular unit', 'unit']},
#    {'term': 'femtogray', 'types': ['prefixed unit']},
#    {'term': 'farad', 'types': ['singular unit', 'unit']},
#    {'term': 'petagram', 'types': ['prefixed unit']},
#    {'term': 'kilonewton', 'types': ['prefixed unit']},
#    {'term': 'yoctolux', 'types': ['prefixed unit']},
#    {'term': 'terajoule', 'types': ['prefixed unit']},
#    {'term': 'zeptoweber', 'types': ['prefixed unit']},
#    {'term': 'decifarad', 'types': ['prefixed unit']},
#    {'term': 'megamole', 'types': ['prefixed unit']},
#    {'term': 'gray', 'types': ['singular unit', 'unit']},
#    {'term': 'mole', 'types': ['singular unit', 'unit']},
#    {'term': 'centipoise', 'types': ['prefixed unit']},
#    {'term': 'decilumen', 'types': ['prefixed unit']},
#    {'term': 'zeptokatal', 'types': ['prefixed unit']},
#    {'term': 'microfarad', 'types': ['prefixed unit']},
#    {'term': 'microsecond', 'types': ['prefixed unit']},
#    {'term': 'hertz', 'types': ['singular unit', 'unit']},
#    {'term': 'decikatal', 'types': ['prefixed unit']},
#    {'term': 'becquerel', 'types': ['singular unit', 'unit']},
#    {'term': 'deciohm', 'types': ['prefixed unit']},
#    {'term': 'centibecquerel', 'types': ['prefixed unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'yottamole', 'types': ['prefixed unit']},
#    {'term': 'hectokatal', 'types': ['prefixed unit']},
#    {'term': 'gram', 'types': ['singular unit', 'unit']},
#    {'term': 'bit', 'types': ['singular unit', 'unit']},
#    {'term': 'yottamolar', 'types': ['prefixed unit']},
#    {'term': 'megahertz', 'types': ['prefixed unit']},
#    {'term': 'femtosteradian', 'types': ['prefixed unit']},
#    {'term': 'microampere', 'types': ['prefixed unit']},
#    {'term': 'femtojoule', 'types': ['prefixed unit']},
#    {'term': 'second', 'types': ['singular unit', 'unit']},
#    {'term': 'petasievert', 'types': ['prefixed unit']},
#    {'term': 'pebibit', 'types': ['prefixed unit']},
#    {'term': 'kilokelvin', 'types': ['prefixed unit']},
#    {'term': 'megahenry', 'types': ['prefixed unit']},
#    {'term': 'magnitude', 'types': ['singular unit', 'unit', 'quantity']},
#    {'term': 'ampere', 'types': ['singular unit', 'unit']},
#    {'term': 'zettamolar', 'types': ['prefixed unit']},
#    {'term': 'yoctoampere', 'types': ['prefixed unit']},
#    {'term': 'decaweber', 'types': ['prefixed unit']},
#    {'term': 'exakelvin', 'types': ['prefixed unit']},
#    {'term': 'yoctosteradian', 'types': ['prefixed unit']},
#    {'term': 'pascal', 'types': ['singular unit', 'unit']},
#    {'term': 'steradian', 'types': ['singular unit', 'unit']},
#    {'term': 'yottagray', 'types': ['prefixed unit']},
#    {'term': 'nanofarad', 'types': ['prefixed unit']},
#    {'term': 'candela', 'types': ['singular unit', 'unit']},
#    {'term': 'ohm', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']},
#    {'term': 'molar', 'types': ['singular unit', 'unit']},
#    {'term': 'kilosievert', 'types': ['prefixed unit']}]},
#  {'title': 'Organizations in Publishing and Academia',
#   'id': '16_0',
#   'text': 'Several prominent organizations are associated with the publication and dissemination of knowledge in various fields. Notably, Cambridge University Press, Institute of Physics Publishing, Willmann Bell, and University Science Books are recognized publishers. Additionally, the International Astronomical Union plays a significant role in the field of astronomy. Furthermore, IAUDiv1WG and VU are also organizations, with VU possibly being related to academic or research institutions.',
#   'term_type_pairs': [{'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'VU', 'types': ['Organization']},
#    {'term': 'IAUDiv1WG', 'types': ['Organization']}]},
#  {'title': 'Application Areas of Units of Measure',
#   'id': '18_0',
#   'text': 'Units of measure have a wide range of applications across various disciplines. Several key areas where units of measure are crucial include mechanics, acoustics, astronomy and astrophysics, fluid mechanics dimensionless numbers, typography, thermodynamics, common applications, photometry, shipping, cosmology, chemistry, economics, geometry, chemical physics, fluid mechanics, sustainability, radiometry and radiobiology, electromagnetism, and information technology. These diverse fields all rely on units of measure for their specific needs, highlighting the broad applicability and importance of standardized measurement systems.',
#   'term_type_pairs': [{'term': 'chemistry', 'types': ['application area']},
#    {'term': 'mechanics', 'types': ['application area']},
#    {'term': 'phot', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'fluid mechanics', 'types': ['application area']},
#    {'term': 'acoustics', 'types': ['application area']},
#    {'term': 'electromagnetism', 'types': ['application area']},
#    {'term': 'thermodynamics', 'types': ['application area']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'photometry', 'types': ['application area']},
#    {'term': 'shipping', 'types': ['application area']},
#    {'term': 'chemical physics', 'types': ['application area']},
#    {'term': 'geometry', 'types': ['application area']},
#    {'term': 'typography', 'types': ['application area']},
#    {'term': 'radiometry and radiobiology', 'types': ['application area']},
#    {'term': 'astronomy and astrophysics', 'types': ['application area']},
#    {'term': 'information technology', 'types': ['application area']},
#    {'term': 'sustainability', 'types': ['application area']},
#    {'term': 'economics', 'types': ['application area']},
#    {'term': 'cosmology', 'types': ['application area']},
#    {'term': 'fluid mechanics dimensionless numbers',
#     'types': ['application area']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Classification and Types of Quantities in Units of Measure',
#   'id': '6_6',
#   'text': "In the realm of Units of Measure, various quantities are defined to quantify different physical and astronomical phenomena. At the forefront are quantities such as dose equivalent, activity, radiant intensity, radiance, exposure to X and γ rays, absorbed dose rate, detectivity, dynamic range, spectral response, magnitude, amplitude, bolometric correction, colour index, extinction, reddening, quantum efficiency, dark noise, normalised detectivity, responsivity, and curvature constant. These quantities are fundamental in describing and measuring various aspects of the physical world.\n\nDose equivalent, for instance, is categorized into several types, including ambient dose equivalent, directional dose equivalent, organ dose equivalent, and personal dose equivalent, each serving a distinct purpose in radiation measurement. Similarly, amplitude is further classified into photographic amplitude and V amplitude, highlighting the diversity within the broader category.\n\nColour index, another significant quantity, is subdivided into intrinsic colour index, which is a measure unaffected by external factors. Extinction, a measure of the absorption or scattering of light, is further detailed as extinction at wavelength and extinction at waveband, depending on the context of measurement. Reddening, related to the change in colour due to extinction, is specified in terms of (B-V) and (U-B), indicating different wavelength comparisons.\n\nIn the context of detectors and measurement tools, quantities like quantum efficiency, detective quantum efficiency, dark noise, and responsivity are crucial. They characterize the performance and sensitivity of detection systems.\n\nCosmological quantities form another significant group, including deceleration parameter, density parameter (with its various types such as for matter, baryonic matter, radiation, and vacuum), Hubble constant (specifically at the present epoch), and cosmological constant. These are pivotal in understanding the universe's expansion and evolution.\n\nLastly, in materials science and earth sciences, permeability and permeance are important, with the former being relevant to earth sciences and the latter to materials science. Viable count, a measure used in biology, is further categorized into viable count (volumetric) and its subtypes like coliform bacteria count (volumetric) and Corynebacterium count (volumetric), illustrating the specificity required in biological measurements.",
#   'term_type_pairs': [{'term': 'phot', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'bar', 'types': ['singular unit', 'unit']},
#    {'term': 'radian', 'types': ['singular unit', 'unit']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'magnitude', 'types': ['singular unit', 'unit', 'quantity']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']}]},
#  {'title': 'Epoch at Maximum Brightness: A Specific Type of Epoch in Astronomical Measurements',
#   'id': '55_0',
#   'text': 'In the context of measuring celestial events, an epoch at maximum brightness is categorized as a specific type of epoch. An epoch, generally, refers to a defined moment in time used as a reference point for measurement. When specified as "at maximum brightness", it narrows down to the moment when a celestial object, such as a star or supernova, is at its brightest. This particular moment is significant for astronomers as it can be used as a reference for various analyses and comparisons.',
#   'term_type_pairs': [{'term': 'rem', 'types': ['singular unit', 'unit']}]}]

# %%
test_data_all= load_jsonl('engineering/test/text2onto_engineering_test_documents.jsonl')
test_data_all
# Out:
# [{'id': '3_7',
#   'title': 'Units of Molar Concentration per Unit Length',
#   'text': 'Units of measurement for molar concentration per unit length are derived from the base unit "mole per metre". This base unit can be modified in two ways: by prefixing the "mole" to indicate different orders of magnitude, or by prefixing the "metre" to denote different units of length. \n\nWhen the "mole" is prefixed, it results in units such as nanomole per metre, femtomole per metre, and others, down to yoctomole per metre and up to yottamole per metre. These units are all categorized as "prefixed mole per metre". Examples include nanomole per metre, kilomole per metre, and gigamole per metre, among others.\n\nOn the other hand, when the "metre" is prefixed, it gives rise to units like mole per centimetre, mole per kilometre, and mole per nanometre. These are classified as "mole per prefixed metre". Other examples include mole per decimetre, mole per megametre, and mole per picometre.\n\nBoth "prefixed mole per metre" and "mole per prefixed metre" are types of unit divisions, indicating a ratio of amount of substance per unit length. They are used to express molar concentration per unit length in various scientific and engineering contexts.'},
#  {'id': '3_5',
#   'title': 'Understanding Units of Measurement: Division and Prefixes',
#   'text': 'Units of measurement are crucial in various scientific and everyday contexts. A key aspect of these units is the concept of division, where one unit is divided by another to express rates or densities. For instance, "gram per prefixed litre" is a type of unit division, where "gram" is a unit of mass and "prefixed litre" is a unit of volume with various prefixes such as kilo-, milli-, nano-, etc. Examples include gram per zeptolitre, gram per microlitre, and gram per gigalitre, all of which are specific instances of gram per prefixed litre.\n\nAnother important category is "prefixed metre per second (time)", also a type of unit division. Here, "prefixed metre" refers to a unit of length with various prefixes, and "per second" indicates the rate of change over time. Examples of this include femtometre per second, petametre per second, and kilometre per second, all of which represent different scales of measuring speed or velocity.\n\nFurthermore, the concept of unit division is not limited to the above examples. "Metre per prefixed second (time)" is another form, where the time unit "second" is prefixed, such as metre per millisecond, metre per nanosecond, and metre per gigasecond. These units are essential in physics and engineering to express various rates and velocities.\n\nIn summary, units of measurement involving division are fundamental in science and everyday applications. Understanding the different types, such as gram per prefixed litre and prefixed metre per second, is crucial for accurate communication and calculation.'},
#  {'id': '3_2',
#   'title': 'Units of Measure: Various Divisions for Quantifying Physical and Scientific Quantities',
#   'text': 'In the realm of Units of Measure, various divisions are utilized to quantify a wide range of physical and scientific quantities. The joule per second is recognized as a unit division, reflecting a rate of energy transfer. Similarly, joule per square metre second is another unit division that measures energy flux. Watt per nanometre is also a unit division, indicating a rate of energy transfer per unit length. In microbiology, 1000 colony forming unit per millilitre is a significant unit division, used to quantify microbial concentration. \n\nKilometre per second per megaparsec is a unit division related to the expansion rate of the universe. In economic terms, megaeuro per megatonne is a unit division that relates economic value to mass. Kilometre per hour is a commonly used unit division for speed, while colony forming unit per gram is used to measure microbial concentration in a substance. Siemens per metre is a unit division that measures electrical conductivity.\n\nMole per kilogram is a unit division used in chemistry to express molality. Mile (statute) per hour is another unit for speed, commonly used in certain countries. Kilogram per gigajoule is a unit division related to energy efficiency. Kilogram per cubic decimetre is a measure of density, as is kilogram per square metre, though the latter is more about mass per unit area.\n\nDelta A450 per second is a unit division used in certain biochemical assays. Gram per square metre metre is related to mass per unit area per unit length. Millimetre per minute is a unit division for rate of change in length. Ampere per volt is a unit division related to electrical conductance, similar to coulomb per volt.\n\nSquare metre per cubic centimetre is a unit division that relates area to volume. Gram per square metre centimetre and gram per megajoule are unit divisions used in different contexts. Megajoule per square metre measures energy per unit area. Micromole per second is a unit division for rates of chemical reactions.\n\nWatt per steradian square metre is a unit division related to radiance. Tonne of carbon dioxide equivalent per gigawatt hour is used in the context of greenhouse gas emissions. Gram per gram and kilogram per kilogram are unit divisions representing ratios or efficiencies.\n\nNanokatal per milligram is a unit division used in enzymology. Kilogram per second is a unit division for mass flow rate. Weber per ampere is related to inductance. Volt per ampere is a unit division representing electrical resistance.\n\nKilojoule per square metre day is a unit division related to energy received per unit area over time. Metre per second is a fundamental unit division for speed. Millimetre per day and centimetre per day are unit divisions used for slow rates of change.\n\nCandela per square metre is a unit division for luminance. Kilogram per pascal second square metre is related to a complex property involving mass, pressure, time, and area. Watt per square metre measures power per unit area.\n\nSolar mass per cubic parsec and solar mass per gigayear cubic parsec are unit divisions used in astrophysics. Ampere per watt is a unit division related to the inverse of electrical resistance. Mole per cubic metre is a unit division used to measure concentration.\n\nJoule per kilogram is a unit division related to specific energy. Magnitude per second (angle) squared is a unit division used in astronomy. Kilojoule per hectogram is another unit division related to specific energy.\n\nSquare metre per square metre is a unit division representing a ratio or efficiency. Kilocalorie (mean) per day is a unit division related to power. Microgram per joule is a unit division used in the context of energy efficiency or pollutant emission per energy.\n\nJoule per square metre day is a unit division measuring energy received per unit area over time.'},
#  {'id': '3_1',
#   'title': 'Derived Units of Measurement: A Key to Quantifying the Physical World',
#   'text': 'Units of measurement are fundamental to quantifying and describing the world around us. They enable us to express the magnitude of physical quantities, facilitating comparison and communication. Among the various types of units, derived units play a crucial role as they are defined in terms of the base units. Many of these derived units are formed through division, representing rates, densities, or other complex quantities.\n\nExamples of such derived units include "square metre kelvin per watt," which could represent a measure of thermal resistance; "gram per cubic metre," a measure of density; and "metre per second squared," representing acceleration. Other units like "litre per 100 kilometre" indicate fuel efficiency, while "watt per square metre steradian" relates to radiance.\n\nFurthermore, units such as "joule per mole" and "kilocalorie (mean) per hectogram" are used in chemistry to express energy changes per amount of substance. In contrast, "radian per second" and "radian per second squared" are used to describe angular velocity and angular acceleration, respectively.\n\nThe diversity of these units highlights the complexity and richness of the physical world we measure and quantify. From "volt per metre" for electric field strength to "colony forming unit per millilitre" in microbiology, each unit serves a specific purpose, enabling precise measurement and analysis in its respective field.'},
#  {'id': '3_3',
#   'title': 'Units of Measurement: Various Unit Divisions',
#   'text': 'Units of measurement are crucial in various fields, including physics, chemistry, and engineering. A unit division is a way of expressing a quantity as a ratio of two units. Several unit divisions are used to describe different physical quantities. For instance, kilogram per mole is a unit division used to express molar mass. Other examples include unified atomic mass unit per cubic angstrom, kilogramPerGigaJoule, cubic metre per mole, milligram per kilometre, and milligram per hectogram. Additionally, megaeuro per petajoule, degree Celsius per hour, and cubic millimetre per cubic millimetre are also unit divisions. Furthermore, watt per steradian square metre hertz, micromole per mole, euro per tonne, coulomb per kilogram, and cubic metre per second are other examples of unit divisions. The list also includes gram per square metre, gram per cubic centimetre, coulomb per square metre, gram per square metre second, and square metre per gram. Moreover, metre per second per metre, gram per litre, gram per square metre day, lumen per square metre, and watt per cubic metre are also unit divisions. The passage also mentions various prefixed metre per second squared units, such as kilometre per second squared, picometre per second squared, and yoctometre per second squared, which are all types of unit divisions. Similarly, metre per prefixed second squared units, such as metre per exasecond squared and metre per decisecond squared, are also unit divisions.'},
#  {'id': '37_0',
#   'title': 'Types of Scales in Measurement',
#   'text': 'In the realm of measurement, various scales are utilized to quantify different physical quantities. Among these, several are categorized as types of scales. Notably, interval scale and ratio scale are fundamental types of scales used across different disciplines. When it comes to measuring temperature, there are multiple scales that have been developed. The thermodynamic temperature scale is a type of scale that is based on the principles of thermodynamics. Other temperature scales include the Celsius temperature scale, Fahrenheit temperature scale, Rankine temperature scale, and Réaumur temperature scale, all of which are used to measure temperature but differ in their reference points and units. The Temperature_scale, in a broad sense, encompasses these various scales used for temperature measurement.'},
#  {'id': '3_0',
#   'title': 'Diverse Units of Measurement Across Scientific Disciplines',
#   'text': 'Units of measurement are fundamental to quantifying and describing the world around us, spanning across various disciplines such as physics, chemistry, biology, and engineering. A unit division, in this context, refers to the ratio of two quantities, often representing rates, densities, or concentrations. \n\nIn physics, units like "watt per square metre nanometre" and "joule per cubic metre" are crucial for describing energy flux and energy density, respectively. Similarly, "ampere per square metre" is used to quantify electric current density, while "newton per square metre" represents pressure or stress.\n\nIn the realm of chemistry and biology, measurements such as "nanomole per hour millilitre" and "colony forming unit per 25 millilitre" are essential for expressing reaction rates and microbial concentrations. "Mole per litre" is a common unit for molarity, a measure of concentration.\n\nThe diversity of unit divisions extends to other areas, including environmental science with "tonne per hectare" for yield or application rates, and "kilogram of carbon dioxide equivalent per megawatt hour" for greenhouse gas emissions per unit of electricity generated. In navigation, "nautical mile per hour" is used as a unit of speed.\n\nThese examples illustrate the vast array of unit divisions used across different scientific and engineering disciplines. Understanding and accurately applying these units is critical for precise communication, calculation, and interpretation of data in their respective fields.'},
#  {'id': '3_4',
#   'title': 'Units of Measure: Acceleration and Density',
#   'text': 'Units of measurement are crucial in various scientific and engineering contexts. Here, we explore units related to acceleration and density. Acceleration is measured in units of distance per time squared. A common unit of acceleration is metre per second squared. Interestingly, there are various prefixed forms of this unit, such as metre per millisecond squared, metre per kilosecond squared, and metre per megasecond squared, among others. All these units are forms of metre per prefixed second squared, where the prefix modifies the unit of time.\n\nAnother important aspect of measurement is density, which is mass per unit volume. The unit "gram per litre" is commonly used to express density. This unit has various prefixed forms as well. For instance, "prefixed gram per litre" includes units like microgram per litre, kilogram per litre, and gigagram per litre. Similarly, "gram per prefixed litre" includes units such as gram per millilitre, gram per kilolitre, and gram per megalitre. These prefixed units allow for more precise and context-specific measurements.'},
#  {'id': '14_0',
#   'title': 'Ratio Scales in Units of Measure: Kelvin and Rankine Scales',
#   'text': 'In the realm of units of measure, certain scales are categorized based on their properties. Notably, both the Kelvin scale and the Rankine scale are classified as ratio scales. This classification signifies that they both possess a true zero point, allowing for meaningful comparisons and ratios between different measurements on these scales.'},
#  {'id': '3_6',
#   'title': 'Unit Division in Units of Measure: Concepts and Examples',
#   'text': 'In the realm of Units of Measure, the concept of unit division plays a crucial role. Unit division refers to the quotient of two measurement units, often used to express rates or concentrations. For instance, "metre per second" is a unit division that measures speed or velocity. When prefixes are applied to the base units, it results in various derived units. For example, metre per microsecond, metre per kilosecond, and metre per picosecond are all types of metre per prefixed second, illustrating different scales of measurement for speed.\n\nAnother significant category under unit division is the measurement of concentration, often expressed in terms of "mole per litre". When prefixes are applied to "mole" and "litre", it gives rise to a multitude of derived units such as femtomole per litre, kilomole per litre, and nanomole per litre. These units are essential in chemistry and related fields for quantifying the concentration of substances in solutions.\n\nFurthermore, the application of prefixes to both the numerator and the denominator in unit divisions, as seen in "prefixed mole per prefixed litre", allows for a wide range of measurements. This is also observed in units like "mole per prefixed litre" and "prefixed mole per metre", where the use of prefixes enables the expression of various scales of measurement.\n\nExamples of specific units under these categories include decimole per metre, which is a prefixed mole per metre, and various "mole per prefixed litre" units such as mole per microlitre and mole per kilolitre. These units highlight the flexibility and precision that the system of unit divisions offers in scientific and practical applications.'},
#  {'id': '24_0',
#   'title': 'Temperature Scales as Interval Scales',
#   'text': 'Temperature is a fundamental physical quantity, and its measurement is crucial in various fields such as science, engineering, and everyday life. There are several scales used to measure temperature, and understanding their characteristics is essential. The Celsius scale, Réaumur scale, and Fahrenheit scale are all classified as interval scales. This means they not only provide a way to order temperatures but also allow for the comparison of differences between temperatures. Being interval scales, these temperature scales enable precise and meaningful arithmetic operations on temperature differences, which is vital for scientific and technical applications.'},
#  {'id': '5_0',
#   'title': 'Statistical Functions in Units of Measure',
#   'text': "In the context of Units of Measure, various statistical functions are utilized to analyze and describe data. These functions are crucial for understanding and interpreting data across different fields. The 'average' is a function that calculates the mean value of a dataset, providing a central tendency. The 'sum' is another fundamental function that aggregates the values of a dataset. For a more detailed analysis, 'count' is used to determine the number of data points. Dispersion is measured using 'standard deviation', which indicates how much the data deviates from the average. The 'median' is a function that finds the middle value in a dataset when it is ordered, useful for understanding the data's distribution. Percentiles, such as the '10th percentile', '20th percentile', '25th percentile', '30th percentile', '40th percentile', '60th percentile', '70th percentile', '80th percentile', and '90th percentile', are functions that divide the data into equal parts, helping to understand the distribution. The 'minimum' and 'maximum' are functions that identify the lowest and highest values in a dataset, respectively. The 'first' and 'last' are functions that can be used to retrieve the initial and final values in a dataset, particularly useful when the data is ordered. Additionally, 'product' is a function that calculates the product of all values in a dataset. These statistical functions are essential tools in data analysis, allowing for a comprehensive understanding of the data's characteristics."},
#  {'id': '21_0',
#   'title': 'Pioneers in Units of Measure and Astronomy',
#   'text': 'The field of units of measure has been shaped by numerous individuals. Notable contributors include Jean Meeus, Osman Demircan, D.L. Crawford, C.R. Kitchin, Kenneth Seidelmann, Hajo Rijgersberg, Edwin Budding, and Brengt Stroemgren, all of whom are recognized for their work. These individuals have played significant roles in advancing our understanding and application of measurement units, particularly in the realm of astronomy. Their contributions have been pivotal in enhancing the precision and consistency of scientific measurements.'},
#  {'id': '42_0',
#   'title': 'Systems of Units in Measurement',
#   'text': 'The International System of Units is a widely recognized standard, but it is not the only system of units that has been developed. Historically, various systems have been used, each with its own set of base units. For instance, the centimetre-gram-second system of units, along with its variants such as the centimetre-gram-second electromagnetic system of units, the centimetre-gram-second electrostatic system of units, and the centimetre-gram-second-biot system of units, were all attempts to create coherent systems for measurement. Other systems like the centimetre-gram-second-franklin system of units and the Gaussian system of units also fall under this category. More modern systems include the metre-kilogram-second-ampere system of units, which represents a step towards the development of the International System of Units.'},
#  {'id': '7_0',
#   'title': 'Understanding Binary Prefixes in Computing',
#   'text': 'In the realm of computing and digital information, binary prefixes are used to denote large quantities of data. The prefixes mebi, pebi, tebi, zebi, gibi, kibi, yobi, and exbi are all classified as binary prefixes because they represent powers of 2. Specifically, kibi represents 2^10, mebi represents 2^20, gibi represents 2^30, tebi represents 2^40, pebi represents 2^50, exbi represents 2^60, zebi represents 2^70, and yobi represents 2^80. These binary prefixes are essential for accurately expressing the capacity of digital storage devices and the size of data in a way that is consistent with the binary system used by computers.'},
#  {'id': '35_0',
#   'title': 'Classification of IAU2012_English.pdf as a Standard',
#   'text': 'The document IAU2012_English.pdf is considered a standard. This classification indicates that it meets specific criteria or requirements that define a standard within its domain.'},
#  {'id': '11_0',
#   'title': 'SI Prefixes in the International System of Units',
#   'text': 'The International System of Units (SI) utilizes a range of prefixes to denote various orders of magnitude. These prefixes are essential for simplifying measurements across different scales. Among the SI prefixes are nano, atto, exa, pico, yotta, centi, kilo, yocto, tera, mega, hecto, zetta, deci, milli, femto, giga, peta, zepto, deca, and micro. Each of these prefixes represents a specific factor by which a unit is multiplied. For instance, "kilo" signifies a thousand times the unit, while "milli" represents one-thousandth of the unit. Understanding these prefixes is crucial for accurately interpreting and communicating measurements in science, technology, and everyday applications. They facilitate the expression of quantities that are either very large or very small, making it easier to comprehend and work with them.'},
#  {'id': '2_0',
#   'title': 'Unit Exponentiations in Measurement: A Diverse Range of Quantities',
#   'text': 'Units of measurement are fundamental to quantifying physical properties and phenomena. A significant aspect of these units is their involvement in exponentiation, which allows for the expression of complex quantities. Various units are classified as unit exponentiations, indicating their role in measuring different physical properties.\n\nArea measurements, such as square metres, square inches, and square miles, are examples of unit exponentiations. Similarly, volume measurements like cubic metres, cubic parsecs, and cubic angstroms are also unit exponentiations. These units are crucial in physics, engineering, and other fields for calculating sizes and volumes.\n\nTime and its reciprocals are also represented as unit exponentiations. For instance, seconds, hours, and years, along with their reciprocals, fall into this category. This classification extends to other physical quantities, including pressure (e.g., reciprocal pascal second), temperature (e.g., reciprocal kelvin, reciprocal degree Celsius), and energy-related measurements (e.g., reciprocal watt).\n\nFurthermore, units like square prefixed metres (e.g., square centimetre, square kilometre) are specific types of unit exponentiations used for area measurements. These demonstrate how the concept of unit exponentiation encompasses a broad range of physical quantities and measurements.\n\nIn summary, unit exponentiations are a diverse group of units that are essential for describing various physical properties and phenomena. They include, but are not limited to, measurements of area, volume, time, and other quantities, highlighting the complexity and richness of the measurement systems used in science and everyday applications.'},
#  {'id': '2_1',
#   'title': 'Units of Measurement: Prefixed Metres and Time Squared',
#   'text': 'In the realm of Units of Measure, various units are derived from the base unit "metre" by applying prefixes and exponents. A range of square units are classified as square prefixed metres, including square micrometre, square picometre, square millimetre, square attometre, square megametre, square decimetre, square femtometre, square zeptometre, square exametre, square petametre, square yoctometre, and square kilometre. These units are obtained by squaring the respective prefixed metres. Furthermore, cubic units such as cubic yottametre, cubic millimetre, cubic yoctometre, cubic gigametre, cubic centimetre, cubic attometre, cubic zettametre, cubic nanometre, cubic exametre, cubic femtometre, cubic micrometre, cubic megametre, cubic petametre, cubic kilometre, cubic picometre, cubic decametre, cubic terametre, cubic zeptometre, cubic decimetre, and cubic hectometre are categorized as cubic prefixed metres, which are a type of unit exponentiation. Additionally, units of time squared, such as attosecond squared, yoctosecond squared, hectosecond squared, megasecond squared, exasecond squared, decisecond squared, nanosecond squared, millisecond squared, centisecond squared, kilosecond squared, yottasecond squared, picosecond squared, gigasecond squared, petasecond squared, zeptosecond squared, and decasecond squared, are classified as prefixed second (time) squared, another form of unit exponentiation.'},
#  {'id': '2_2',
#   'title': 'Prefixed Units of Second Squared in Units of Measure',
#   'text': 'In the realm of units of measure, particularly when dealing with time, the concept of "second squared" is crucial. This unit is further diversified by the application of various prefixes to "second squared," resulting in different scales of measurement. For instance, a terasecond squared is a prefixed unit of second squared, representing a large scale. Similarly, a zettasecond squared is another prefixed form, signifying an even larger quantity. On the opposite end of the scale, a femtosecond squared represents a very small unit of time squared, while a microsecond squared falls somewhere in between, being larger than a femtosecond squared but still relatively small. These prefixed units of second squared are essential in various scientific and technical contexts, providing a way to express different magnitudes of time squared in a clear and concise manner.'},
#  {'id': '57_0',
#   'title': 'Understanding Prefixes in Units of Measurement',
#   'text': 'In the context of units of measurement, prefixes play a crucial role in denoting different scales or magnitudes. There are various types of prefixes, among which SI prefixes and binary prefixes are notable. An SI prefix is a type of prefix used in conjunction with units to indicate decimal multiples or fractions. Similarly, a binary prefix is also a type of prefix, specifically used in computing and information technology to denote powers of two. Both types of prefixes are essential in their respective domains for clarity and precision.'}]

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def find_best_document_by_title(query: str, docs: list[dict]) -> tuple[dict | None, float]:
    """
    Finds the best matching document in a list based on its title.

    Args:
        query (str): The text to search for.
        docs (list[dict]): A list of documents, where each doc is a dictionary
                           with at least a 'title' key.

    Returns:
        tuple[dict | None, float]: A tuple containing the entire best-matching
                                   document dictionary and its similarity score.
                                   Returns (None, 0.0) if the docs list is empty.
    """
    if not docs:
        return None, 0.0

    # 1. Extract all titles from the documents
    titles = [f"{doc['title']}+ {doc['text']} " for doc in docs]

    # 2. Create a corpus by prepending the query to the list of titles
    corpus = [query] + titles
    
    # 3. Initialize and fit the TF-IDF Vectorizer
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(corpus)

    # 4. Calculate cosine similarity between the query (first vector) and all titles
    cosine_similarities = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:]).flatten()

    # 5. Find the index of the highest similarity score
    best_match_index = np.argmax(cosine_similarities)
    best_match_score = cosine_similarities[best_match_index]

    # 6. Retrieve the entire document object using the index
    best_matching_document = docs[best_match_index]

    return best_matching_document, float(best_match_score)

# %%
final_ans = []
from tqdm import tqdm
for test_data in tqdm(test_data_all):
    title= test_data['title']
    text = test_data['text']
    best_match_doc, score = find_best_document_by_title(query=title+text, docs=doc_term_types_mapping)
    final_ans.append({"query_doc":test_data, "relevant_doc":best_match_doc})
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 59.09it/s]

# %%
final_ans[0]
# Out:
# {'query_doc': {'id': '3_7',
#   'title': 'Units of Molar Concentration per Unit Length',
#   'text': 'Units of measurement for molar concentration per unit length are derived from the base unit "mole per metre". This base unit can be modified in two ways: by prefixing the "mole" to indicate different orders of magnitude, or by prefixing the "metre" to denote different units of length. \n\nWhen the "mole" is prefixed, it results in units such as nanomole per metre, femtomole per metre, and others, down to yoctomole per metre and up to yottamole per metre. These units are all categorized as "prefixed mole per metre". Examples include nanomole per metre, kilomole per metre, and gigamole per metre, among others.\n\nOn the other hand, when the "metre" is prefixed, it gives rise to units like mole per centimetre, mole per kilometre, and mole per nanometre. These are classified as "mole per prefixed metre". Other examples include mole per decimetre, mole per megametre, and mole per picometre.\n\nBoth "prefixed mole per metre" and "mole per prefixed metre" are types of unit divisions, indicating a ratio of amount of substance per unit length. They are used to express molar concentration per unit length in various scientific and engineering contexts.'},
#  'relevant_doc': {'title': 'Derived Units of Measurement: A Reflection of Physical Quantities and Properties',
#   'id': '4_0',
#   'text': "Units of measurement are fundamental to quantifying physical properties and phenomena. Various derived units are obtained through the multiplication of base units, reflecting the complexity and diversity of physical quantities. For instance, ohm metre, a unit of resistivity, is derived from the multiplication of resistance (ohm) and length (metre), indicating how resistivity is a measure of a material's opposition to the flow of electric current per unit length.\n\nSimilarly, square metre second, representing a quantity related to volume over time or a similar derived measure, is a product of area (square metre) and time (second). Joule second, another derived unit, combines energy (joule) and time, often related to action or angular momentum in physics.\n\nOther examples include metre kelvin (length times temperature), ampere hour (electric current times time), and watt square metre (power times area), each representing different physical quantities or properties. The terawatt hour, gigawatt hour, megawatt hour, and kilowatt hour are all units of energy, derived from the multiplication of power and time, differing only in scale.\n\nFurthermore, units like newton metre (force times length), lumen second (luminous flux times time), and volt second (electric potential difference times time) are crucial in describing various physical phenomena. The diversity of these derived units underscores the complexity of physical systems and the need for precise measurement.\n\nThe list also includes units related to more specialized or less common measurements, such as steradian square metre hertz (involving solid angle, area, and frequency) and mole micrometre reciprocal square centimetre reciprocal second (involving amount of substance, length, area, and time), highlighting the breadth of physical quantities that can be measured and analyzed.\n\nIn conclusion, the multiplication of base units gives rise to a wide array of derived units that are essential for describing and quantifying the world around us.",
#   'term_type_pairs': [{'term': 'lux', 'types': ['singular unit', 'unit']},
#    {'term': 'joule', 'types': ['singular unit', 'unit']},
#    {'term': 'lumen second', 'types': ['unit multiplication']},
#    {'term': 'mole micrometre', 'types': ['unit multiplication']},
#    {'term': 'watt', 'types': ['singular unit', 'unit']},
#    {'term': 'are', 'types': ['singular unit', 'unit']},
#    {'term': 'square metre hertz', 'types': ['unit multiplication']},
#    {'term': 'micrometre', 'types': ['prefixed unit']},
#    {'term': 'centimetre', 'types': ['prefixed unit']},
#    {'term': 'kilowatt', 'types': ['prefixed unit']},
#    {'term': 'newton', 'types': ['singular unit', 'unit']},
#    {'term': 'radian', 'types': ['singular unit', 'unit']},
#    {'term': 'metre kelvin', 'types': ['unit multiplication']},
#    {'term': 'metre', 'types': ['singular unit', 'unit']},
#    {'term': 'square metre second', 'types': ['unit multiplication']},
#    {'term': 'terawatt hour', 'types': ['unit multiplication']},
#    {'term': 'mole micrometre reciprocal square centimetre reciprocal second',
#     'types': ['unit multiplication']},
#    {'term': 'kelvin', 'types': ['singular unit', 'unit']},
#    {'term': 'terawatt', 'types': ['prefixed unit']},
#    {'term': 'gigawatt hour', 'types': ['unit multiplication']},
#    {'term': 'rem', 'types': ['singular unit', 'unit']},
#    {'term': 'kilowatt hour', 'types': ['unit multiplication']},
#    {'term': 'ohm metre', 'types': ['unit multiplication']},
#    {'term': 'lumen', 'types': ['singular unit', 'unit']},
#    {'term': 'volt second', 'types': ['unit multiplication']},
#    {'term': 'volt', 'types': ['singular unit', 'unit']},
#    {'term': 'watt hour', 'types': ['unit multiplication']},
#    {'term': 'mole', 'types': ['singular unit', 'unit']},
#    {'term': 'ampere hour', 'types': ['unit multiplication']},
#    {'term': 'megawatt hour', 'types': ['unit multiplication']},
#    {'term': 'gigawatt', 'types': ['prefixed unit']},
#    {'term': 'hour', 'types': ['singular unit', 'unit']},
#    {'term': 'watt square metre', 'types': ['unit multiplication']},
#    {'term': 'steradian square metre hertz', 'types': ['unit multiplication']},
#    {'term': 'hertz', 'types': ['singular unit', 'unit']},
#    {'term': 'erg', 'types': ['singular unit', 'unit']},
#    {'term': 'newton metre', 'types': ['unit multiplication']},
#    {'term': 'megawatt', 'types': ['prefixed unit']},
#    {'term': 'mole micrometre reciprocal square centimetre',
#     'types': ['unit multiplication']},
#    {'term': 'second', 'types': ['singular unit', 'unit']},
#    {'term': 'ampere', 'types': ['singular unit', 'unit']},
#    {'term': 'steradian', 'types': ['singular unit', 'unit']},
#    {'term': 'ohm', 'types': ['singular unit', 'unit']},
#    {'term': 'rad', 'types': ['singular unit', 'unit']},
#    {'term': 'steradian square metre', 'types': ['unit multiplication']}]}}

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")

# %%
final_prep_ans = []
i=0

# %%
for data in tqdm(final_ans):
    prompt =f"""You are an expert model specializing in scientific and engineering terminology. Your task is to analyze the provided document (title and text) and extract all measurement units mentioned. For each unit, you must classify it based on its structure and composition.

    **Domain: Engineering**
    The domain is **Engineering**, a broad field applying scientific and mathematical principles to design, build, and analyze structures, machines, and systems. It encompasses various disciplines like mechanical, electrical, chemical, and civil engineering. A core tenet of this domain is the reliance on precise, standardized units of measurement to ensure safety, interoperability, and accuracy in all designs and calculations.

    **Instructions:**
    1.  Read the title and text of the document carefully.
    2.  Identify every distinct measurement unit. These can be single words (e.g., "metre") or complex multi-word phrases (e.g., "mole per centimetre").
    3.  For each unit, assign one or more types from the following categories:
        - `singular unit`: A base unit (e.g., "mole", "metre").
        - `prefixed unit`: A base unit with a standard prefix (e.g., "nanomole", "kilometre").
        - `unit multiplication`: A unit formed by multiplying two or more units (e.g., "newton metre").
        - `unit division`: A unit formed by dividing one unit by another (e.g., "mole per metre").
        - Other specific classifications mentioned in the text (e.g., "prefixed mole per metre").
    4.  The output must be a single, valid JSON object with one key: `"term_type_pairs"`. The value should be a list of objects, where each object contains a `"term"` and a `"types"` key.

    ---
    **EXAMPLE**

    **Document:**
    **Title:** {data['relevant_doc']['title']}
    **Text:** {data['relevant_doc']['text']}

    **Correct Output:**
    {json.dumps({"term_type_pairs": data['relevant_doc']['term_type_pairs']}, indent=2)}

    TASK
    query Document:
    Title: {data['query_doc']['title']}
    Text: {data['query_doc']['text']} """

    print(len(prompt))

    generation_config = {"response_mime_type": "application/json"}
    response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
    final_prep_ans.append(response.text)
    if i%5==0:
        print(response.text)
    i+=1
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# 9701
#   5%|▍         | 1/21 [00:16<05:37, 16.87s/it]
# {
#   "term_type_pairs": [
#     {
#       "term": "centimetre",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "decimetre",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "femtomole",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "femtomole per metre",
#       "types": [
#         "prefixed mole per metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "gigamole",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "gigamole per metre",
#       "types": [
#         "prefixed mole per metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "kilomole",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "kilomole per metre",
#       "types": [
#         "prefixed mole per metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "kilometre",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "megametre",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "metre",
#       "types": [
#         "singular unit"
#       ]
#     },
#     {
#       "term": "mole",
#       "types": [
#         "singular unit"
#       ]
#     },
#     {
#       "term": "mole per centimetre",
#       "types": [
#         "mole per prefixed metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "mole per decimetre",
#       "types": [
#         "mole per prefixed metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "mole per kilometre",
#       "types": [
#         "mole per prefixed metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "mole per megametre",
#       "types": [
#         "mole per prefixed metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "mole per metre",
#       "types": [
#         "unit division"
#       ]
#     },
#     {
#       "term": "mole per nanometre",
#       "types": [
#         "mole per prefixed metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "mole per picometre",
#       "types": [
#         "mole per prefixed metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "nanomole",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "nanomole per metre",
#       "types": [
#         "prefixed mole per metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "nanometre",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "picometre",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "yoctomole",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "yoctomole per metre",
#       "types": [
#         "prefixed mole per metre",
#         "unit division"
#       ]
#     },
#     {
#       "term": "yottamole",
#       "types": [
#         "prefixed unit"
#       ]
#     },
#     {
#       "term": "yottamole per metre",
#       "types": [
#         "prefixed mole per metre",
#         "unit division"
#       ]
#     }
#   ]
# }
# 10109
#  10%|▉         | 2/21 [00:34<05:30, 17.40s/it]
# 9318
#  14%|█▍        | 3/21 [01:09<07:33, 25.17s/it]
# 9989
#  19%|█▉        | 4/21 [01:32<06:53, 24.33s/it]
# 10021
#  24%|██▍       | 5/21 [02:07<07:35, 28.48s/it]
# 3718
#  29%|██▊       | 6/21 [02:16<05:28, 21.87s/it]
# {
#   "term_type_pairs": [
#     {
#       "term": "interval scale",
#       "types": [
#         "scale"
#       ]
#     },
#     {
#       "term": "ratio scale",
#       "types": [
#         "scale"
#       ]
#     },
#     {
#       "term": "thermodynamic temperature scale",
#       "types": [
#         "temperature scale",
#         "scale"
#       ]
#     },
#     {
#       "term": "Celsius temperature scale",
#       "types": [
#         "temperature scale",
#         "scale"
#       ]
#     },
#     {
#       "term": "Fahrenheit temperature scale",
#       "types": [
#         "temperature scale",
#         "scale"
#       ]
#     },
#     {
#       "term": "Rankine temperature scale",
#       "types": [
#         "temperature scale",
#         "scale"
#       ]
#     },
#     {
#       "term": "Réaumur temperature scale",
#       "types": [
#         "temperature scale",
#         "scale"
#       ]
#     },
#     {
#       "term": "Temperature_scale",
#       "types": [
#         "temperature scale",
#         "scale"
#       ]
#     }
#   ]
# }
# 11876
#  33%|███▎      | 7/21 [02:41<05:19, 22.85s/it]
# 11415
#  38%|███▊      | 8/21 [03:04<04:55, 22.73s/it]
# 8153
#  43%|████▎     | 9/21 [03:09<03:25, 17.14s/it]
# 12035
#  48%|████▊     | 10/21 [03:33<03:31, 19.23s/it]
# 3576
#  52%|█████▏    | 11/21 [03:58<03:29, 20.98s/it]
# {
#   "term_type_pairs": [
#     {
#       "term": "Temperature",
#       "types": [
#         "fundamental physical quantity"
#       ]
#     },
#     {
#       "term": "Celsius",
#       "types": [
#         "singular unit"
#       ]
#     },
#     {
#       "term": "Réaumur",
#       "types": [
#         "singular unit"
#       ]
#     },
#     {
#       "term": "Fahrenheit",
#       "types": [
#         "singular unit"
#       ]
#     }
#   ]
# }
# 7317
#  57%|█████▋    | 12/21 [04:05<02:33, 17.01s/it]
# 8334
#  62%|██████▏   | 13/21 [04:23<02:16, 17.07s/it]
# 3364
#  67%|██████▋   | 14/21 [04:38<01:55, 16.54s/it]
# 8624
#  71%|███████▏  | 15/21 [04:50<01:31, 15.23s/it]
# 2573
#  76%|███████▌  | 16/21 [04:53<00:57, 11.60s/it]
# {
#   "term_type_pairs": []
# }
# 8823
#  81%|████████  | 17/21 [05:20<01:04, 16.08s/it]
# 10274
#  86%|████████▌ | 18/21 [05:35<00:47, 15.79s/it]
# 9977
#  90%|█████████ | 19/21 [06:13<00:45, 22.56s/it]
# 9036
#  95%|█████████▌| 20/21 [06:23<00:18, 18.68s/it]
# 8534
# 100%|██████████| 21/21 [06:26<00:00, 18.40s/it]
# {
#   "term_type_pairs": []
# }

# %%
final_prep_ans
# Out:
# ['{\n  "term_type_pairs": [\n    {\n      "term": "centimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "decimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "femtomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "femtomole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "gigamole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gigamole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilomole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "megametre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "mole",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "mole per centimetre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per decimetre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per kilometre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per megametre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per nanometre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per picometre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "nanomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "nanomole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "nanometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "picometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "yoctomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "yoctomole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "yottamole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "yottamole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "gram",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "litre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "prefixed litre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gram per prefixed litre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "zeptolitre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gram per zeptolitre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "microlitre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gram per microlitre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "gigalitre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gram per gigalitre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "second",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "prefixed metre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "prefixed metre per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "femtometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "femtometre per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "petametre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "petametre per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilometre per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "prefixed second",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "metre per prefixed second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "millisecond",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "metre per millisecond",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "nanosecond",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "metre per nanosecond",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "gigasecond",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "metre per gigasecond",\n      "types": [\n        "unit division"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "joule per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "joule per square metre second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Watt per nanometre",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "colony forming unit per millilitre",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Kilometre per second per megaparsec",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "megaeuro per megatonne",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Kilometre per hour",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "colony forming unit per gram",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Siemens per metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Mole per kilogram",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Mile (statute) per hour",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Kilogram per gigajoule",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Kilogram per cubic decimetre",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilogram per square metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Delta A450 per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Gram per square metre metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Millimetre per minute",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Ampere per volt",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "coulomb per volt",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Square metre per cubic centimetre",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Gram per square metre centimetre",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gram per megajoule",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Megajoule per square metre",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Micromole per second",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Watt per steradian square metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Tonne of carbon dioxide equivalent per gigawatt hour",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Gram per gram",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilogram per kilogram",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Nanokatal per milligram",\n      "types": [\n        "unit division",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "Kilogram per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Weber per ampere",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Volt per ampere",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "Kilojoule per square metre day",\n      "types": [\n     ...
#  '{\n  "term_type_pairs": [\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "kelvin",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "watt",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "gram",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "litre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "second",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "steradian",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "joule",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "mole",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "calorie",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "radian",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "volt",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "colony forming unit",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "kilometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilocalorie",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "hectogram",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "millilitre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "square metre",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "cubic metre",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "square second",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "square metre kelvin",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "square metre steradian",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "square metre kelvin per watt",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "gram per cubic metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "metre per second squared",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "litre per kilometre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "watt per square metre steradian",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "joule per mole",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilocalorie per hectogram",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "radian per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "radian per second squared",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "volt per metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "colony forming unit per millilitre",\n      "types": [\n        "unit division"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "angstrom",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "centimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "coulomb",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "coulomb per kilogram",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "coulomb per square metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "cubic angstrom",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "cubic metre",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "cubic metre per mole",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "cubic metre per second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "cubic millimetre",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "cubic millimetre per cubic millimetre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "day",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "decisecond",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "degree Celsius",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "degree Celsius per hour",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "euro",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "euro per tonne",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "exasecond",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gigajoule",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gram",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "gram per cubic centimetre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "gram per litre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "gram per square metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "gram per square metre day",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "gram per square metre second",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "hectogram",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "hertz",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "hour",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "kilogram",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilogram per mole",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilogramPerGigaJoule",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilometre per second squared",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "litre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "lumen",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "lumen per square metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "megaeuro",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "megaeuro per petajoule",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      " ...
#  '{\n  "term_type_pairs": [\n    {\n      "term": "interval scale",\n      "types": [\n        "scale"\n      ]\n    },\n    {\n      "term": "ratio scale",\n      "types": [\n        "scale"\n      ]\n    },\n    {\n      "term": "thermodynamic temperature scale",\n      "types": [\n        "temperature scale",\n        "scale"\n      ]\n    },\n    {\n      "term": "Celsius temperature scale",\n      "types": [\n        "temperature scale",\n        "scale"\n      ]\n    },\n    {\n      "term": "Fahrenheit temperature scale",\n      "types": [\n        "temperature scale",\n        "scale"\n      ]\n    },\n    {\n      "term": "Rankine temperature scale",\n      "types": [\n        "temperature scale",\n        "scale"\n      ]\n    },\n    {\n      "term": "Réaumur temperature scale",\n      "types": [\n        "temperature scale",\n        "scale"\n      ]\n    },\n    {\n      "term": "Temperature_scale",\n      "types": [\n        "temperature scale",\n        "scale"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "ampere",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "ampere per square metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "carbon dioxide equivalent",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "colony forming unit",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "colony forming unit per 25 millilitre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "cubic metre",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "gram",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "hectare",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "hour",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "hour millilitre",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "joule",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "joule per cubic metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilogram",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilogram of carbon dioxide equivalent per megawatt hour",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "litre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "megawatt",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "megawatt hour",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "mile",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "millilitre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "mole",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "mole per litre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "nanomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "nanomole per hour millilitre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "nanometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "nautical mile",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "nautical mile per hour",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "newton",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "newton per square metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "square metre",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "tonne",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "tonne per hectare",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "watt",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "watt per square metre nanometre",\n      "types": [\n        "unit division"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "distance per time squared",\n      "types": [\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "gigagram",\n      "types": [\n        "prefixed unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "gigagram per litre",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "gram",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "gram per kilolitre",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "gram per litre",\n      "types": [\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "gram per megalitre",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "gram per millilitre",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "gram per prefixed litre",\n      "types": [\n        "Other specific classifications mentioned in the text"\n      ]\n    },\n    {\n      "term": "kilogram",\n      "types": [\n        "prefixed unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "kilogram per litre",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "kilolitre",\n      "types": [\n        "prefixed unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "litre",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "mass per unit volume",\n      "types": [\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "megalitre",\n      "types": [\n        "prefixed unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "megasecond",\n      "types": [\n        "prefixed unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "metre per kilosecond squared",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "metre per megasecond squared",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "metre per millisecond squared",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "metre per prefixed second squared",\n      "types": [\n        "Other specific classifications mentioned in the text"\n      ]\n    },\n    {\n      "term": "metre per second squared",\n      "types": [\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "microgram",\n      "types": [\n        "prefixed unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "microgram per litre",\n      "types": [\n        "prefixed unit",\n        "unit division",\n        "unit"\n      ]\n    },\n    {\n      "term": "millilitre",\n      "types": [\n        "prefixed unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "millisecond",\n      "types": [\n        "prefixed unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "prefixed gram per litre",\n      "types": [\n        "Other specific classifications mentioned in the text"\n      ]\n    },\n    {\n      "term": "second",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "Kelvin",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "Rankine",\n      "types": [\n        "singular unit"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "metre per second",\n      "types": [\n        "singular unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "second",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "metre per microsecond",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "metre per kilosecond",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "metre per picosecond",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "metre per prefixed second",\n      "types": [\n        "unit division",\n        "Other specific classifications mentioned in the text"\n      ]\n    },\n    {\n      "term": "mole per litre",\n      "types": [\n        "singular unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "litre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "femtomole per litre",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilomole per litre",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "nanomole per litre",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "prefixed mole per prefixed litre",\n      "types": [\n        "unit division",\n        "Other specific classifications mentioned in the text"\n      ]\n    },\n    {\n      "term": "mole per prefixed litre",\n      "types": [\n        "unit division",\n        "Other specific classifications mentioned in the text"\n      ]\n    },\n    {\n      "term": "prefixed mole per metre",\n      "types": [\n        "unit division",\n        "Other specific classifications mentioned in the text"\n      ]\n    },\n    {\n      "term": "decimole per metre",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per microlitre",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per kilolitre",\n      "types": [\n        "prefixed unit",\n        "unit division"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "Temperature",\n      "types": [\n        "fundamental physical quantity"\n      ]\n    },\n    {\n      "term": "Celsius",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "Réaumur",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "Fahrenheit",\n      "types": [\n        "singular unit"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": []\n}',
#  '{\n  "term_type_pairs": []\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "centimetre",\n      "types": [\n        "singular unit",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gram",\n      "types": [\n        "singular unit",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "second",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "biot",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "franklin",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "kilogram",\n      "types": [\n        "singular unit",\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "ampere",\n      "types": [\n        "singular unit"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "mebi",\n      "types": [\n        "binary prefix"\n      ]\n    },\n    {\n      "term": "pebi",\n      "types": [\n        "binary prefix"\n      ]\n    },\n    {\n      "term": "tebi",\n      "types": [\n        "binary prefix"\n      ]\n    },\n    {\n      "term": "zebi",\n      "types": [\n        "binary prefix"\n      ]\n    },\n    {\n      "term": "gibi",\n      "types": [\n        "binary prefix"\n      ]\n    },\n    {\n      "term": "kibi",\n      "types": [\n        "binary prefix"\n      ]\n    },\n    {\n      "term": "yobi",\n      "types": [\n        "binary prefix"\n      ]\n    },\n    {\n      "term": "exbi",\n      "types": [\n        "binary prefix"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": []\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "magnitude",\n      "types": [\n        "singular unit",\n        "unit",\n        "quantity"\n      ]\n    },\n    {\n      "term": "one",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "angstrom",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "centimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "cubic angstrom",\n      "types": [\n        "unit exponentiation",\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "cubic metre",\n      "types": [\n        "unit exponentiation",\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "cubic parsec",\n      "types": [\n        "unit exponentiation",\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "degree Celsius",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "hour",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "inch",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "kelvin",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "kilometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "mile",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "parsec",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "pascal",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "reciprocal degree Celsius",\n      "types": [\n        "unit division",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "reciprocal kelvin",\n      "types": [\n        "unit division",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "reciprocal pascal second",\n      "types": [\n        "unit division",\n        "unit multiplication",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "reciprocal watt",\n      "types": [\n        "unit division",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "second",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "square centimetre",\n      "types": [\n        "prefixed unit",\n        "unit exponentiation",\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "square inch",\n      "types": [\n        "unit exponentiation",\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "square kilometre",\n      "types": [\n        "prefixed unit",\n        "unit exponentiation",\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "square metre",\n      "types": [\n        "unit exponentiation",\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "square mile",\n      "types": [\n        "unit exponentiation",\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "watt",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    },\n    {\n      "term": "year",\n      "types": [\n        "singular unit",\n        "unit"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": [\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "micrometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "picometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "millimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "attometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "megametre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "decimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "femtometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "zeptometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "exametre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "petametre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "yoctometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "square micrometre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square picometre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square millimetre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square attometre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square megametre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square decimetre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square femtometre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square zeptometre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square exametre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square petametre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square yoctometre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "square kilometre",\n      "types": [\n        "prefixed unit",\n        "unit multiplication",\n        "square prefixed metres",\n        "unit exponentiation"\n      ]\n    },\n    {\n      "term": "yottametre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gigametre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "centimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "nanometre", ...
#  '{\n  "term_type_pairs": [\n    {\n      "term": "second squared",\n      "types": [\n        "unit multiplication"\n      ]\n    },\n    {\n      "term": "terasecond squared",\n      "types": [\n        "prefixed unit",\n        "prefixed unit of second squared"\n      ]\n    },\n    {\n      "term": "zettasecond squared",\n      "types": [\n        "prefixed unit",\n        "prefixed unit of second squared"\n      ]\n    },\n    {\n      "term": "femtosecond squared",\n      "types": [\n        "prefixed unit",\n        "prefixed unit of second squared"\n      ]\n    },\n    {\n      "term": "microsecond squared",\n      "types": [\n        "prefixed unit",\n        "prefixed unit of second squared"\n      ]\n    }\n  ]\n}',
#  '{\n  "term_type_pairs": []\n}']

# %%
final_prep_ans[0]
# Out:
# '{\n  "term_type_pairs": [\n    {\n      "term": "centimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "decimetre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "femtomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "femtomole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "gigamole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "gigamole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "kilomole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "kilometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "megametre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "metre",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "mole",\n      "types": [\n        "singular unit"\n      ]\n    },\n    {\n      "term": "mole per centimetre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per decimetre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per kilometre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per megametre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per metre",\n      "types": [\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per nanometre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "mole per picometre",\n      "types": [\n        "mole per prefixed metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "nanomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "nanomole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "nanometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "picometre",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "yoctomole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "yoctomole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    },\n    {\n      "term": "yottamole",\n      "types": [\n        "prefixed unit"\n      ]\n    },\n    {\n      "term": "yottamole per metre",\n      "types": [\n        "prefixed mole per metre",\n        "unit division"\n      ]\n    }\n  ]\n}'

# %%
unique_types = set()

# %%
import json
import os

# Ensure output directory exists
os.makedirs("engineering/test", exist_ok=True)

all_terms = []
unique_types = set()

# Loop over all JSON strings
for data_1 in final_prep_ans:
    data = json.loads(data_1)
    pairs = data["term_type_pairs"]

    for item in pairs:
        all_terms.append(item["term"])
        for typ in item["types"]:
            unique_types.add(typ)

# Save all terms to one file
with open("engineering/test/2nd_method_terms.txt", "w", encoding="utf-8") as term_file:
    for term in all_terms:
        term_file.write(f"{term}\n")

# Save all unique types to one file
with open("engineering/test/2nd_method_types.txt", "w", encoding="utf-8") as type_file:
    for typ in sorted(unique_types):  # sorted is optional
        type_file.write(f"{typ}\n")
