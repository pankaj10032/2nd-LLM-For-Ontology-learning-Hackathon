# %%
import json

def load_jsonl(file_path):
    """
    Loads data from a .jsonl file.

    Args:
        file_path (str): The path to the .jsonl file.

    Returns:
        list: A list of dictionaries, where each dictionary represents a JSON object from a line.
    """
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            try:
                data.append(json.loads(line.strip()))
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON on line: {line.strip()} - {e}")
    return data

# %%
training_data = load_jsonl("ecology/train/documents.jsonl")
len(training_data), training_data[0]
# Out:
# (2000,
#  {'id': '942_0',
#   'title': 'Drumlin Fields: A Type of Hill Range Shaped by Glaciers',
#   'text': 'A drumlin field is categorized as a type of hill range, typically formed through the movement of glaciers. These landscapes are characteristic of regions where there has been significant glacial activity, shaping the terrain into elongated hill ranges. Drumlin fields are not only fascinating geological formations but also play a crucial role in the local ecosystem and can influence local climate conditions.'})

# %%
def load_txt_file_content(filepath):
    """
    Loads the entire content of a text file into a single string.

    Args:
        filepath (str): The path to the text file.

    Returns:
        str: The content of the file, or None if an error occurs.
    """
    try:
        with open(filepath, 'r', encoding='utf-8') as file:
            content = file.readlines()
        return content
    except FileNotFoundError:
        print(f"Error: The file '{filepath}' was not found.")
        return None
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        return None

# %%
terms_text_list = load_txt_file_content("ecology/train/types.txt")

# %%
# final_term_to_doc_mapping = {}
# for term in terms_text_list:
#     lst_1 = []
#     for data_1 in training_data:
#         if term in data_1['title'] or term in data_1['text']:
#             lst_1.append(data_1['id'])
#     final_term_to_doc_mapping[term]= lst_1

# %%
test_data = load_jsonl('ecology/test/text2onto_ecology_test_documents.jsonl')
# Out:
# Error decoding JSON on line:  - Expecting value: line 1 column 1 (char 0)

# %%
test_data
# Out:
# [{'id': '1012_0',
#   'title': 'Understanding the State of Being Broken',
#   'text': 'When something is broken into two pieces, it is considered to be in a state of being broken. In other words, being broken into two pieces is a specific way in which something can be broken, indicating a more severe or distinct form of damage.'},
#  {'id': '2012_0',
#   'title': 'Classification of Carbon Concentration in Water',
#   'text': 'The concentration of carbon atoms in water is categorized as a specific measure of the amount of carbon atoms present in water. This classification is significant in environmental studies as it helps in understanding the levels and impact of carbon in aquatic systems.'},
#  {'id': '314_0',
#   'title': 'Understanding Permeability: The Role of Permeable and Impermeable Materials in Environmental Science',
#   'text': 'In the context of environmental science, the permeability of materials plays a crucial role in understanding various ecological and geological processes. Permeability refers to the ability of a substance to allow fluids or gases to pass through it. Materials that are considered permeable, such as certain types of rock or soil, enable water or air to permeate through their structure. On the other hand, impermeable materials, like clay or solid rock, prevent or significantly restrict the flow of fluids or gases. Understanding the distinction between permeable and impermeable materials is essential for managing water resources, assessing the risk of groundwater contamination, and designing effective barriers for waste containment. Thus, both permeable and impermeable materials have significant implications for environmental conservation and management practices.'},
#  {'id': '993_0',
#   'title': 'Carbon Dioxide Pooling Disposition: A Specific Type of Carbon Pooling',
#   'text': 'Carbon dioxide pooling disposition is categorized under carbon pooling disposition, indicating a specific type within the broader classification of carbon-related phenomena. This relationship highlights the connection between the disposition of carbon dioxide and the more general concept of carbon pooling, suggesting that carbon dioxide pooling is a particular instance or subset of carbon pooling behaviors or processes.'},
#  {'id': '2189_0',
#   'title': 'Respiratory Electron Transport Chain: A Key Component in Environmental Processes',
#   'text': 'In the context of environmental science, the respiratory electron transport chain plays a significant role. It is categorized as a specific type of electron transport chain, highlighting its importance in various biological processes that are integral to the functioning of ecosystems.'},
#  {'id': '937_0',
#   'title': 'Classification of Calyptra within the Erebinae Subfamily',
#   'text': 'Calyptra, a genus within the family of moths, is classified under the subfamily Erebinae. This categorization highlights the biological relationship between Calyptra and other moths within the Erebinae subfamily, showcasing the diversity within the environmental context.'},
#  {'id': '657_0',
#   'title': 'Classification of Fruit Jelly under US Regulations',
#   'text': 'Fruit jelly, as defined under US CFR regulations, falls under the broader category of products that include fruit butter, jelly, preserves, and other related items. This classification indicates that fruit jelly is considered among the various spreads and preserves that are made from fruits and are subject to specific regulatory standards in the US.'},
#  {'id': '93_0',
#   'title': 'Understanding Amplitude of Air Temperature in Environmental Context',
#   'text': 'In the context of environmental studies, the amplitude of temperature of air is categorized as a type of amplitude. This classification is significant because it helps in understanding various environmental phenomena. The amplitude of temperature of air refers to the variation or range in air temperature, which is a crucial factor in determining weather patterns and climatic conditions. By recognizing it as a subset of amplitude, we can better analyze and discuss its implications on environmental systems.'},
#  {'id': '1298_0',
#   'title': 'Classification of Metabolites in the Environment',
#   'text': 'In the context of environmental science, metabolites play a crucial role. A metabolite is a substance produced during metabolism, and it can be further categorized into different types based on the organism it is derived from. Toxin is classified as a type of metabolite, indicating its role or origin in metabolic processes. Metabolites can also be categorized based on the type of organism they come from. For instance, eukaryotic metabolites are derived from eukaryotes, a domain that includes complex organisms with cells containing a nucleus. Within eukaryotic metabolites, there are further classifications: animal metabolites come from animals, and fungal metabolites are derived from fungi. On the other hand, prokaryotic metabolites originate from prokaryotes, which are simpler organisms lacking a nucleus. Both eukaryotic and prokaryotic metabolites fall under the broader category of metabolites, highlighting the diverse sources and types of metabolic by-products in the environment.'},
#  {'id': '2357_0',
#   'title': 'Understanding Flat Landforms in Environmental Context',
#   'text': 'In the context of environmental geography, a flat is categorized as a type of landform that is characterized as being flattened. This means that a flat area is generally level and even, lacking significant inclines or declines, which can be a result of various natural processes such as erosion or sedimentation.'},
#  {'id': '976_0',
#   'title': 'Material Cooling Processes in Environmental Context',
#   'text': "In the context of environmental studies, the process of material cooling is crucial for various applications. Material cooling can be achieved through different methods, primarily categorized into two types: the cooling of solids and the cooling of fluids. Both of these methods fall under the broader category of material cooling processes. The cooling of a solid is considered a type of material cooling process, where the temperature of a solid is lowered. Similarly, the cooling of a fluid is also a material cooling process, involving the reduction of a fluid's temperature. Understanding these processes is essential for managing and regulating temperatures in various environmental and industrial contexts."},
#  {'id': '2004_0',
#   'title': 'Understanding Carbon Solubility in Environmental Materials',
#   'text': 'The solubility of carbon in environmental materials is a critical aspect of environmental science. Specifically, the dissolved carbon atoms within these materials represent a particular form of carbon solubility. This phenomenon is significant because it directly affects how carbon interacts with and impacts the environment.'},
#  {'id': '343_0',
#   'title': 'Classification of Macronutrients in Ocean Water',
#   'text': "In the context of environmental science, particularly when discussing the components of ocean water, it's essential to understand the classification of macronutrients. Inorganic macronutrients that are dissolved in ocean water are categorized as a type of macronutrient. This classification highlights the importance of these nutrients in the marine ecosystem, as they are crucial for the growth and survival of various marine life forms."},
#  {'id': '2021_0',
#   'title': 'Carbon Concentration in Seawater: A Specific Case of Carbon in Water',
#   'text': 'The concentration of carbon atoms in seawater is a specific instance of the broader category of carbon atom concentrations found in water. This indicates that the measurement of carbon in seawater is part of a larger context of assessing carbon levels in various types of water bodies. Understanding the concentration of carbon in different water environments is crucial for environmental studies, as it helps in assessing the impact of carbon on these ecosystems.'},
#  {'id': '1778_0',
#   'title': 'Classification of Solvents in Environmental Chemistry',
#   'text': 'In the context of environmental chemistry, solvents are categorized based on their properties. A protic solvent is classified as a type of polar solvent. This classification is significant because it influences how these solvents interact with other substances in the environment. Protic solvents, being polar, are capable of forming hydrogen bonds, which makes them useful in various chemical reactions and processes.'},
#  {'id': '72_0',
#   'title': 'Types of Tectonic Earthquakes and Their Characteristics',
#   'text': 'Tectonic earthquakes are a significant area of study within the field of environmental science, particularly in understanding seismic activities. Various types of tectonic earthquakes have been identified, each with distinct characteristics. A megathrust earthquake is categorized as a type of tectonic earthquake, known for its immense power. Similarly, a foreshock, which precedes a major seismic event, is also classified under tectonic earthquakes. The mainshock, being the primary event in a sequence of earthquakes, falls into this category as well. Following the mainshock, aftershocks can occur, and these too are considered a type of tectonic earthquake. Furthermore, a blind thrust earthquake, which occurs without visible surface deformation, is another variant of tectonic earthquakes. Multiplet earthquakes, which involve multiple seismic events closely related in time and space, are also a subset of tectonic earthquakes. The distinction between interplate and intraplate earthquakes is also noteworthy; interplate earthquakes occur at the boundary between two tectonic plates, while intraplate earthquakes happen within a plate. Both are types of tectonic earthquakes, highlighting the diverse nature of seismic activity.'},
#  {'id': '2009_0',
#   'title': 'Dissolved Nitrogen in Environmental Materials: A Specific Case of Dissolved Substances',
#   'text': "In the context of environmental science, a dissolved nitrogen atom in environmental material is considered a specific instance of something that is dissolved. This indicates that the presence of nitrogen in a dissolved state within environmental materials is a subset or a particular case of the broader category of 'dissolved' substances. Understanding this relationship is crucial for analyzing the composition and properties of environmental materials."},
#  {'id': '283_0',
#   'title': 'Categorization of Hydrocarbon Gas Emission Processes',
#   'text': 'In the context of environmental science, various types of gas emission processes are significant. Notably, hydrocarbon gas emission processes are a broad category. Within this category, there are more specific types, including carbon-bearing gas emission processes. Carbon dioxide emission processes are a subset of carbon-bearing gas emission processes, highlighting the specific impact of carbon dioxide. Additionally, methane gas emission processes are directly classified under hydrocarbon gas emission processes, underscoring their relevance. Understanding these different emission processes and their interrelations is crucial for addressing environmental challenges.'},
#  {'id': '1143_0',
#   'title': 'Lumber Production as a Planetary Manufacturing Process',
#   'text': 'The lumber production process is categorized under the broader spectrum of planetary manufacturing processes. This classification underscores the significance of lumber production within the context of environmental and industrial processes that impact the planet. As a type of planetary manufacturing process, lumber production involves the transformation of natural resources into products that are used by humans, highlighting the intricate relationship between industrial activities and environmental sustainability.'},
#  {'id': '207_0',
#   'title': 'Understanding Food Propellants in the Context of Environmental Studies',
#   'text': 'In the context of environmental studies, propellants are substances that are used to propel or drive various products, including aerosol cans and other packaging. A specific category of these substances is referred to as "food propellants." Food propellants are a type of propellant used in the food industry, particularly in products like whipped cream and spray cheese, where they help in dispensing the product in a desired form. Essentially, food propellant is a type of propellant, highlighting the broader classification of propellants that includes substances used not just in food but also in other industries.'},
#  {'id': '2370_0',
#   'title': 'Understanding Hollow Structures in the Environment',
#   'text': 'In environmental contexts, the term "hollow" refers to a type of structure characterized by cavities or empty spaces within it. This concept is significant in understanding various natural and man-made features in our environment.'},
#  {'id': '812_0',
#   'title': 'Understanding Cloud Cover and Snow Cover as Measures of Area Density in Environmental Studies',
#   'text': "In the context of environmental studies, understanding various measures that describe the Earth's surface is crucial. Two significant concepts are cloud cover and snow cover, both of which are categorized under area density. Area density refers to the amount of a particular substance or feature (like clouds or snow) per unit area. Cloud cover, which is the extent to which the sky is covered by clouds, is an essential factor in meteorological studies as it influences weather patterns and temperature. Similarly, snow cover, indicating the area covered by snow, plays a vital role in hydrological cycles and climate studies. Both cloud cover and snow cover are critical for assessing environmental conditions and predicting future changes."},
#  {'id': '2368_0',
#   'title': 'Understanding Brokenness as a Form of Wholeness',
#   'text': 'The concept of brokenness can be understood as a form of wholeness. This perspective may seem counterintuitive at first, as "broken" typically implies something that is damaged or not in a working state, contrasting with the idea of wholeness, which suggests completeness or integrity. However, in a more abstract or philosophical sense, something that is broken can still be considered whole in the sense that it retains its identity or essence as a singular entity, despite being damaged.'},
#  {'id': '731_0',
#   'title': 'Types of Sea Ice Formation Processes',
#   'text': 'Sea ice formation is a complex process that encompasses various stages and types. Among these, several specific processes are categorized under the broader term of sea ice formation processes. These include nilas formation process, young ice formation process, first year ice formation process, second year ice formation, and multiyear ice formation process. Each of these processes represents a distinct aspect or stage in the development and evolution of sea ice. Understanding these different types of ice formation processes is crucial for comprehending the dynamics of sea ice and its impact on the environment.'},
#  {'id': '2374_0',
#   'title': 'Understanding Humidity as a Quality of Gases in the Environment',
#   'text': 'In the context of environmental science, humidity is considered a quality that characterizes the state of a gas. Specifically, it refers to the amount of moisture present in the air, which is a critical factor in understanding weather patterns and atmospheric conditions.'},
#  {'id': '2184_0',
#   'title': 'Classification of Methane Metabolic Process',
#   'text': 'Methane metabolic process is categorized as a specific type of alkane metabolic process. This indicates that any process involving the metabolism of methane is also considered a process involving the metabolism of alkanes, highlighting the broader category under which methane metabolism falls.'},
#  {'id': '759_0',
#   'title': 'Understanding Altitudinal Conditions in Environmental Studies',
#   'text': 'Altitudinal conditions are classifications used to describe different zones or regions based on their elevation. In environmental studies, several key terms are used to categorize these zones. Alpine, subalpine, montane, and nival are all types of altitudinal conditions. The alpine condition refers to the zone above the treeline, typically characterized by low temperatures and limited vegetation. The subalpine condition is the zone just below the alpine zone, often featuring sparse tree cover and harsh climate conditions. The montane condition is generally found at lower elevations than the subalpine and is characterized by forests and a more moderate climate compared to the higher zones. Lastly, the nival condition is associated with the highest elevations, often above the alpine zone, where snow and ice dominate the landscape. Understanding these different altitudinal conditions is crucial for environmental studies and conservation efforts.'},
#  {'id': '2018_0',
#   'title': 'Solubility of Nitrogen in Water within Environmental Context',
#   'text': 'The ability of nitrogen atoms to dissolve in water is classified under the broader category of how nitrogen atoms dissolve in materials found in the environment. This highlights the specific interaction between nitrogen and water as part of the larger environmental context in which nitrogen interacts with various environmental materials.'},
#  {'id': '568_0',
#   'title': 'Types of Ammonia Oxidation Processes in Environmental Context',
#   'text': 'Ammonia oxidation is a process that can occur through different respiratory mechanisms. Specifically, it can be achieved through anaerobic respiration where ammonium acts as the electron donor. Additionally, aerobic respiration that utilizes ammonia as an electron donor is also classified as a type of ammonia oxidation. These processes highlight the diverse ways in which ammonia oxidation can occur in various environmental conditions.'},
#  {'id': '1285_0',
#   'title': 'Understanding Tripartite Branched Systems in the Environment',
#   'text': 'In environmental contexts, structures or systems that are described as tripartite are categorized as a specific type of branched system. This classification is significant as it helps in understanding the complexity and organization of such systems within the environment.'},
#  {'id': '2263_0',
#   'title': 'Ditrysia: A Subgroup of Heteroneura in the Lepidoptera Order',
#   'text': 'Ditrysia, a significant group within the Lepidoptera order, is classified as a type of Heteroneura. Heteroneura is a suborder of Lepidoptera, characterized by distinct differences in the venation of their wings. The classification of Ditrysia under Heteroneura highlights the diverse evolutionary paths within the Lepidoptera, showcasing the complexity and richness of environmental biodiversity.'},
#  {'id': '1752_0',
#   'title': "Classification of Purine Ribonucleoside 5'-Triphosphate",
#   'text': "Purine ribonucleoside 5'-triphosphate is classified as a subtype of ribonucleoside 5'-triphosphate, indicating that it shares the core characteristics of ribonucleoside 5'-triphosphates but is more specifically defined. This relationship highlights the hierarchical structure within the category of ribonucleoside 5'-triphosphates, with purine ribonucleoside 5'-triphosphate being a more specialized form."},
#  {'id': '1799_0',
#   'title': 'Classification of Daphnia Metabolite in Environmental Context',
#   'text': 'In the context of environmental science, metabolites play a crucial role in understanding the ecological balance. Specifically, Daphnia metabolite, which is derived from Daphnia species, is categorized as a type of crustacean metabolite. This classification is significant because it highlights the biochemical processes occurring within crustaceans, such as Daphnia, which are vital components of aquatic ecosystems.'},
#  {'id': '956_0',
#   'title': 'Understanding Excretion as a System Process in Environmental Context',
#   'text': 'Excretion is categorized as a system process, playing a crucial role in the functioning of various environmental and biological systems.'},
#  {'id': '2181_0',
#   'title': 'Understanding Feeding Behavior in Environmental Context',
#   'text': 'In the context of environmental studies, behavior plays a crucial role in understanding how organisms interact with their surroundings. Specifically, feeding behavior is categorized as a type of behavior that significantly influences the dynamics of ecosystems. This classification highlights the importance of feeding behavior in shaping the environment and the organisms within it.'},
#  {'id': '707_0',
#   'title': 'Understanding Water Infiltration into Soil',
#   'text': 'Water infiltration into soil is a specific type of water infiltration process. Water infiltration, in general, refers to the process by which water moves into the soil. This process is crucial in the environment as it helps in recharging groundwater, reducing runoff, and supporting plant growth. When water infiltrates into the soil, it becomes part of the soil moisture that plants rely on for their water needs.'},
#  {'id': '2010_0',
#   'title': 'Classification of Dissolved Carbon in Environmental Materials',
#   'text': 'In the context of environmental science, a dissolved carbon atom within environmental materials is categorized as a type of dissolved substance. This classification highlights the state of carbon atoms when they are dissolved and dispersed within various environmental media, such as water or soil. Understanding the categorization of dissolved substances is crucial for analyzing their impact on the environment and their role in different ecological processes.'},
#  {'id': '132_0',
#   'title': 'Aphanizomenon: A Member of the Aphanizomenonaceae Family',
#   'text': 'Aphanizomenon, a genus of cyanobacteria, belongs to the family Aphanizomenonaceae. This classification is significant in environmental studies as both Aphanizomenon and Aphanizomenonaceae are relevant in understanding water quality and the dynamics of aquatic ecosystems. Aphanizomenon is known for its presence in various water bodies and can be an indicator of environmental conditions.'},
#  {'id': '470_0',
#   'title': 'Types of Seismic Vibration Processes in the Environment',
#   'text': 'Seismic vibration processes are categorized into several types based on their driving factors. These include volcanic seismic vibration, impact-driven seismic vibration, explosion-driven seismic vibration, mass-wasting-driven seismic vibration, collapse-driven seismic vibration, and earthquake-driven seismic vibration. All these types are classified under the broader category of seismic vibration processes, highlighting the diverse causes of seismic activity in the environment.'},
#  {'id': '850_0',
#   'title': 'Solubility of Carbon in Water: An Environmental Perspective',
#   'text': 'The concept of dissolved carbon atoms in water being related to the solubility of carbon atoms in water is an important aspect of environmental science. Solubility refers to the ability of a substance to dissolve in a solvent, and in this context, it pertains to how carbon atoms or compounds containing carbon interact with water. The dissolved carbon in water can come from various sources, including atmospheric carbon dioxide that dissolves in water, forming carbonic acid, or from organic matter decomposition. Understanding the solubility of carbon in water is crucial for assessing water quality and its impact on aquatic life.'},
#  {'id': '1096_0',
#   'title': 'Bacterial Metabolites: A Subset of Prokaryotic Metabolites in Environmental Context',
#   'text': 'In the context of environmental science, metabolites produced by bacteria are categorized under a broader group known as prokaryotic metabolites. Bacterial metabolites, being a type of prokaryotic metabolite, play significant roles in various ecological processes. These compounds are crucial for understanding the complex interactions within microbial communities and their impact on the environment.'},
#  {'id': '263_0',
#   'title': 'Weathering of Plastic: A Specific Type of Weathering Process',
#   'text': "Weathering of plastic is categorized under the broader process of weathering. This indicates that the degradation or breakdown of plastic materials due to environmental factors is considered a specific type of weathering process. Weathering, in general, refers to the breakdown or decomposition of materials, such as rocks, soils, and plastics, at or near the Earth's surface due to exposure to environmental elements like temperature, humidity, and biological activity. The weathering of plastic, therefore, involves the deterioration of plastic materials through similar environmental interactions."},
#  {'id': '1049_0',
#   'title': 'Understanding Photosynthetic Photon Flux in Environmental Science',
#   'text': 'In the context of environmental science, photosynthetic photon flux is categorized as a specific type of flux. Flux, in general, refers to the rate of flow of a physical quantity, such as energy or particles, through a given surface. Photosynthetic photon flux, more specifically, relates to the quantity of photons that are available for photosynthesis, typically measured over a specific area and time. This measure is crucial for understanding the potential rate of photosynthesis in a given environment, which in turn affects plant growth and productivity.'},
#  {'id': '2137_0',
#   'title': 'Classification of Animal Material in Environmental Context',
#   'text': "In the context of environmental studies, it's essential to understand the classification of various materials. Notably, pieces of animal are categorized as a type of animal material. This classification is crucial for understanding the composition of waste, the decomposition process, and the impact of animal-derived materials on the environment. By recognizing that pieces of animal fall under the broader category of animal material, researchers and environmentalists can better analyze and address environmental issues related to waste management and conservation."},
#  {'id': '2371_0',
#   'title': 'Classification of Fluid Flow Rate in Environmental Context',
#   'text': 'In the context of environmental monitoring and fluid dynamics, fluid flow rate is categorized as a specific type of flow rate. This classification is important because it helps in understanding and measuring the rate at which fluids move through various systems, such as rivers, pipelines, and industrial processes. Understanding fluid flow rate is crucial for managing water resources, designing efficient systems, and monitoring environmental changes.'},
#  {'id': '659_0',
#   'title': "Purine Ribonucleoside 5'-Triphosphates in Environmental Context",
#   'text': "In the context of environmental science, certain chemical compounds play crucial roles in various biological and ecological processes. Notably, CHEBI_15422 and CHEBI_15996 are identified as purine ribonucleoside 5'-triphosphates, a class of compounds significant for their involvement in energy transfer within cells. These compounds are vital for the synthesis of RNA and the regulation of cellular metabolism, impacting how organisms respond to environmental changes. Understanding the properties and functions of such biochemicals is essential for assessing their environmental impact and their potential roles in maintaining ecological balance."},
#  {'id': '642_0',
#   'title': 'Classification of Oscillatoria and Phormidium within Oscillatoriaceae',
#   'text': 'In the realm of environmental biology, particularly when studying cyanobacteria, two genera that are often classified under the same family are Oscillatoria and Phormidium. Both Oscillatoria and Phormidium are types of Oscillatoriaceae, a family of cyanobacteria known for their filamentous structure. This classification highlights the close relationship between these genera within the broader context of cyanobacterial diversity.'},
#  {'id': '851_0',
#   'title': 'Glossata: A Diverse Subgroup of Lepidoptera',
#   'text': 'Glossata, a subgroup of Lepidoptera, plays a significant role in the environment. Lepidoptera, which includes butterflies and moths, is one of the most diverse and widespread insect orders. Glossata, being a part of this order, encompasses a vast array of species that are crucial for pollination and serve as a food source for various animals. The classification of Glossata under Lepidoptera highlights the intricate diversity within the insect world and underscores the importance of understanding and preserving these species for ecological balance.'},
#  {'id': '1925_0',
#   'title': 'Astronomical Impact Events and their Environmental Significance',
#   'text': 'In the context of environmental phenomena, an impact between astronomical bodies is categorized as a specific type of impact event. This classification highlights the significant effects that such astronomical impacts can have on the environment.'},
#  {'id': '84_0',
#   'title': 'Biomarkers as Environmental Indicators',
#   'text': 'In the context of environmental studies, a biomarker is considered a specific type of indicator. Biomarkers are typically used to measure the quality or condition of the environment, serving as vital signs that indicate the health of an ecosystem. By understanding that a biomarker falls under the broader category of indicators, researchers can better utilize these biological markers to monitor environmental changes, assess the impact of pollutants, and develop strategies for conservation and sustainability.'},
#  {'id': '7_0',
#   'title': 'Understanding Donors in Environmental Chemistry',
#   'text': 'In the context of environmental chemistry, the concept of a "donor" plays a crucial role. A donor can be categorized into several types, including electron donors, Bronsted acids, and Lewis bases. Notably, an electron donor falls under the broader category of donors, highlighting its role in donating electrons in chemical reactions. Bronsted acids, another type of donor, are particularly significant as they include protic solvents, which are known for their ability to donate protons. Furthermore, Lewis bases, also classified as donors, are closely related to nucleophilic reagents, which are essential in various chemical reactions due to their nucleophilic characteristics. Understanding these concepts and their interrelations is vital for comprehending the mechanisms of chemical reactions that occur in the environment.'},
#  {'id': '436_0',
#   'title': 'Categories of Temperate Climates',
#   'text': 'The temperate climate zone is categorized into different types, including oceanic temperate and continental temperate. Both of these categories fall under the broader classification of temperate, indicating they share certain characteristics typical of temperate climates but also have distinct features that set them apart from one another.'},
#  {'id': '1028_0',
#   'title': 'Understanding Viscosity in Environmental Context',
#   'text': 'In the context of environmental science, increased viscosity is categorized as a form of viscous fluid. This classification is significant because the viscosity of a fluid can affect its flow and behavior in various environmental processes. For instance, the increased viscosity of a liquid can impact its ability to flow through soil or its effect on aquatic life.'},
#  {'id': '685_0',
#   'title': 'Classification of Obtectomera in Environmental Context',
#   'text': 'In the realm of environmental science, particularly when studying insects, understanding the classification of various species is crucial. Obtectomera is categorized as a type of Ditrysia, a group within the Lepidoptera order, which includes moths and butterflies. This classification is significant in environmental studies as it helps in understanding biodiversity and the ecological roles these insects play.'},
#  {'id': '862_0',
#   'title': 'Understanding Ice Cap Climatic Conditions in Polar Regions',
#   'text': "The climatic condition associated with ice caps is categorized as a polar condition. Ice caps, which are large, thick ice masses, play a significant role in the Earth's environmental system. They are typically found in polar regions and have a profound impact on global climate patterns. The condition of these ice caps, in terms of their extent, thickness, and temperature, is a critical aspect of understanding and studying polar climatic conditions."},
#  {'id': '588_0',
#   'title': 'Concentration of Carbon Isotopes in Sea Water: A Key Environmental Indicator',
#   'text': 'In the context of environmental science, understanding the concentration of different carbon isotopes in sea water is crucial. Specifically, the concentration of carbon-13 atoms in sea water and the concentration of carbon-14 atoms in sea water are both specific types of measurements under the broader category of concentration of carbon atoms in sea water. These measurements are significant because they help scientists differentiate between various carbon sources and understand their dynamics in marine environments. By studying these concentrations, researchers can gain insights into various environmental processes, including ocean acidification and the carbon cycle.'},
#  {'id': '2139_0',
#   'title': 'Classification of Animal Products',
#   'text': 'A piece of cow is considered a type of piece of animal, reflecting their hierarchical relationship within the context of food or biological classification. This means that any portion or segment derived from a cow can be categorized under the broader classification of being a part of an animal. This relationship underscores the interconnectedness of different categories within the environmental or biological domain.'},
#  {'id': '774_0',
#   'title': 'Cyclic Carotenes: Beta-Carotene and Alpha-Carotene',
#   'text': 'Both beta-carotene and alpha-carotene are classified as cyclic carotenes, a group of compounds significant in the environment for their roles in photosynthesis and as precursors to vitamin A in the diet of animals. These carotenoids are not only crucial for plants, where they help protect against excessive light energy, but also play a vital role in the food chain by providing antioxidant properties.'},
#  {'id': '194_0',
#   'title': 'Ecosystem Processes and Their Impact on the Environment',
#   'text': 'The environment is affected by numerous ecosystem processes. Ecosystem-wide photosynthesis, coral bleaching, ecosystem fragmentation, ecosystem decay, ecological succession, land degradation, deforestation, forest processes, forest area expansion, algal bloom processes, and algal production are all classified as ecosystem processes. Ecological succession can be further categorized into climactic ecological succession. Ecosystem fragmentation includes habitat fragmentation, while land degradation encompasses soil degradation and desertification. Deforestation can be planned. Algal bloom processes are complex and include phases such as the accumulation and degradation of toxins. These processes are integral to understanding the dynamics of ecosystems and the impact of environmental changes.'},
#  {'id': '593_0',
#   'title': 'Understanding Radioactivity in the Environment',
#   'text': 'In the context of environmental science, radioactive processes are a significant concern. Radioactivity is a type of activity associated with radionuclides. Radionuclides are atoms that have excess nuclear energy, making them unstable. When these atoms undergo radioactive decay, they release radiation, which can have various environmental impacts. Understanding radioactivity is crucial for assessing and mitigating its effects on the environment.'},
#  {'id': '270_0',
#   'title': 'Diversity of Shapes in the Environment',
#   'text': 'Shapes are fundamental to understanding the world around us, particularly in the context of the environment. Various shapes describe the forms and structures of natural elements. The most basic categorization starts with the broad term "shape," under which numerous specific types fall.\n\nShapes can be described in several ways, including their curvature, linearity, and other geometric characteristics. For instance, shapes like curled, undulate, elongated, linear, and filamentous are all categorized under the general description of shape, highlighting the diversity in their forms. Some shapes are characterized by their curvature, such as curved and flattened, which are types of curvature. Others, like sloped and its subtype sloped downward, indicate direction or orientation.\n\nSurface features also play a significant role in describing shapes. Terms like lobate, sculpted surface, and ornamentation fall under the category of surface feature shape, indicating the complexity and variety of surface characteristics. Additionally, shapes can be described by their dimensionality, such as 2-D shapes (including oblong, fan-shaped, and superelliptic) and 3-D shapes (which can be further divided into convex and concave 3-D shapes).\n\nOther shapes are defined by their specific geometric or structural characteristics, such as angular (with V-shaped being a subtype), concavity (with concave as a subtype), and branchiness (characterized by branched structures). Furthermore, shapes like columnar, drooping, straight, slender, and falciform provide more specific descriptions of forms found in the environment.\n\nEdge shapes, such as fringed, and other descriptors like fimbriated, tholiform, broad, funnel-shaped, radiating, and plume-shaped, further expand the vocabulary of shapes used to describe environmental features.'},
#  {'id': '1114_0',
#   'title': 'Classification of Daphnia magna Metabolite in Environmental Context',
#   'text': 'In the context of environmental science, metabolites of various organisms are crucial for understanding ecological interactions. Specifically, Daphnia magna metabolite is categorized as a subtype of Daphnia metabolite, indicating that any metabolite associated with Daphnia magna is also considered a Daphnia metabolite. Daphnia magna, being a small, planktonic crustacean, is often used as a model organism in ecotoxicology and environmental health studies. Therefore, understanding its metabolites can provide insights into the health of aquatic ecosystems.'},
#  {'id': '2016_0',
#   'title': 'Classification of Dissolved Nitrogen in Environmental Materials',
#   'text': 'The concept of dissolved nitrogen atoms in environmental materials is categorized under the broader phenomenon of nitrogen atom solubility in such materials. This classification is significant in understanding various environmental processes.'},
#  {'id': '2005_0',
#   'title': 'Solubility of Carbon in Soil and Environmental Materials',
#   'text': 'The solubility of carbon atoms in soil can be classified under the broader category of solubility of carbon atoms in environmental materials. This indicates that the ability of carbon to dissolve in soil is a specific instance of its ability to dissolve in various environmental media, which could include water, air, and other components of the environment. Understanding this relationship is crucial for assessing how carbon interacts with different aspects of the environment.'},
#  {'id': '1207_0',
#   'title': 'Solubility of Carbon in Soil: A Key Environmental Factor',
#   'text': 'In the context of environmental science, the solubility of carbon atoms in soil is a significant factor. Specifically, the dissolved carbon atom in soil represents a particular type of solubility of carbon atoms within the soil matrix. This distinction is crucial as it highlights the various forms in which carbon can exist in soil, affecting its interaction with the environment.'},
#  {'id': '1059_0',
#   'title': 'Species of Microcystis: A Genus of Cyanobacteria',
#   'text': 'Microcystis, a genus of cyanobacteria, includes various species that are significant in environmental contexts. Two notable species within this genus are Microcystis aeruginosa and Microcystis viridis, both of which are classified under the Microcystis category. These cyanobacteria are often associated with environmental concerns due to their potential to form harmful algal blooms.'},
#  {'id': '753_0',
#   'title': 'Types of Sensitivity to Oxygen in Environmental Context',
#   'text': 'In the context of environmental science, the sensitivity of organisms to oxygen is a crucial factor. There are primarily two categories of this sensitivity: aerobic and anaerobic. Aerobic sensitivity to oxygen refers to one type of response or condition related to the presence of oxygen, while anaerobic sensitivity represents another type related to the absence or different levels of oxygen. Understanding these sensitivities is vital for assessing how different organisms or ecosystems react to varying oxygen levels in their environments.'},
#  {'id': '951_0',
#   'title': 'Soil Bulk Density in Environmental Context',
#   'text': "Soil bulk density is categorized as a type of mass density of soil, a crucial parameter in understanding soil properties within environmental studies. This classification is significant because it helps in assessing the soil's physical characteristics, which are vital for various environmental and agricultural applications."},
#  {'id': '2331_0',
#   'title': 'Understanding Rate of Occurrence in Environmental Context',
#   'text': 'The concept of an increased rate of occurrence falls under the broader category of rate of occurrence. This indicates that any event or phenomenon that is happening at a higher frequency can be described using the term "increased rate of occurrence," which is a specific type of rate of occurrence. In environmental studies, understanding the rate of occurrence of certain events, such as natural disasters or pollution levels, is crucial. When this rate increases, it signifies a potential shift or escalation in these events, which can have significant implications for the environment and ecosystems.'},
#  {'id': '504_0',
#   'title': 'Understanding Spherical Shapes in Environmental Context',
#   'text': "In the context of environmental studies, shapes and forms of objects and phenomena are often described using specific geometric terms. A key concept is that 'spherical' is categorized as a type of 'spheroid'. Understanding this classification is crucial for accurately describing and analyzing various environmental elements."},
#  {'id': '768_0',
#   'title': 'Understanding Increased Frequency in Environmental Context',
#   'text': 'Increased frequency is categorized as a type of increased rate of occurrence. This means that when something happens more frequently, it is considered to be occurring at an increased rate.'},
#  {'id': '2138_0',
#   'title': 'Classification of Cow Material in Environmental Context',
#   'text': 'Cow material is classified under the broader category of animal material. This categorization is significant in environmental studies as it helps in understanding the role and impact of different types of materials, especially those derived from animals, on the ecosystem. Cow material, being a subset of animal material, shares certain characteristics and environmental implications associated with animal-derived materials. Understanding these classifications and their environmental implications is crucial for managing waste, conserving resources, and mitigating environmental degradation.'},
#  {'id': '722_0',
#   'title': "The Role of Adenosine 5'-phosphate Derivatives in Environmental Chemistry",
#   'text': "In the context of environmental chemistry, certain compounds play crucial roles in various biological and ecological processes. One such compound is CHEBI_15422, which is classified as a type of adenosine 5'-phosphate. Adenosine 5'-phosphate, commonly found in living organisms, is significant in energy transfer within cells. The presence and role of such biochemicals in the environment can be pivotal in understanding ecological balance and the impact of external factors on biological systems."},
#  {'id': '368_0',
#   'title': 'Types of Environmental Occurrences',
#   'text': 'In the context of environmental phenomena, occurrences can be categorized based on their frequency and continuity. Sporadic, continuous, and discontinuous are types of occurrences. Sporadic occurrences are those that happen irregularly and infrequently. On the other hand, continuous occurrences are ongoing without interruption. Discontinuous occurrences, however, happen with intervals or breaks in between. Understanding these different types of occurrences is crucial for studying and managing environmental events.'},
#  {'id': '2333_0',
#   'title': 'Understanding Rate of Occurrence in Environmental Context',
#   'text': 'The concept of an increased rate of occurrence falls under the broader category of rate of occurrence. This indicates that any event or phenomenon that is happening at a higher frequency can be described using the term "increased rate of occurrence," which is a specific type of rate of occurrence. In environmental studies, understanding the rate of occurrence of certain events, such as natural disasters or pollution levels, is crucial. When this rate increases, it signifies a potential shift or escalation in these events, which can have significant implications for the environment and ecosystems.'},
#  {'id': '192_0',
#   'title': 'Understanding Environmental Shapes: Arched and Concave Features',
#   'text': 'In the context of environmental features, an arched shape is considered a specific type of concave shape. This classification is important in understanding various natural formations such as arches and caves, which are often characterized by their concave structures.'},
#  {'id': '1037_0',
#   'title': 'Anaerobic Respiration Processes in Environmental Contexts',
#   'text': 'Methanogenesis is a specific form of anaerobic respiration, a process that occurs in environments lacking oxygen. Anaerobic respiration itself is a broader category of processes, including variations where ammonium serves as an electron donor. Both of these processes are crucial in certain environmental contexts, contributing to the cycling of nutrients and elements.'},
#  {'id': '944_0',
#   'title': 'Classification of Trichodesmium and Planktothrix within Microcoleaceae',
#   'text': 'Trichodesmium and Planktothrix are both classified under the family Microcoleaceae. Microcoleaceae is a family of cyanobacteria, commonly found in various environmental settings. Trichodesmium, known for its ability to fix nitrogen, plays a significant role in the marine ecosystem. Similarly, Planktothrix is known to be present in freshwater environments and can be involved in the formation of harmful algal blooms. Both genera are of interest in environmental studies due to their ecological impacts.'},
#  {'id': '486_0',
#   'title': 'Understanding Soil Structure: The Role of Porosity and Composition',
#   'text': 'The structure of soil is a critical aspect of its overall composition and functionality. Two key components that contribute to this structure are its porosity and composition. Porosity refers to the amount of pore space within the soil, which affects its ability to retain water and air. The composition of the soil, on the other hand, refers to the proportion of different materials such as sand, silt, and clay it contains. Both porosity and composition are essential in defining the structure of soil, influencing its fertility and overall health.'},
#  {'id': '967_0',
#   'title': 'Understanding Meteorite Impacts in the Context of Astronomical Events',
#   'text': 'A meteorite impact is categorized as a specific type of impact that occurs between astronomical bodies. This phenomenon involves the collision of a meteorite with a planet or other celestial entity, highlighting the dynamic and sometimes violent interactions within our solar system. Such impacts have been significant in shaping the surfaces of various astronomical bodies and continue to be a subject of study in understanding the history and evolution of our cosmic neighborhood.'},
#  {'id': '1038_0',
#   'title': 'Methanogenesis: A Key Methane Metabolic Process in the Environment',
# ...
#  {'id': '2328_0',
#   'title': 'Understanding Luminous Flux as an Optical Quality in Environmental Context',
#   'text': 'Luminous flux, a measure of the total amount of light emitted by a source, is categorized as a type of optical quality. This classification is significant in the context of environmental studies, where understanding and managing light is crucial. Optical quality, in general, pertains to the characteristics of light and its interaction with the environment. Thus, luminous flux plays a vital role in assessing and maintaining the optical quality of our surroundings.'},
#  {'id': '122_0',
#   'title': 'Types of Speed in Environmental Contexts',
#   'text': 'In the context of environmental studies, the concept of speed is multifaceted, encompassing various phenomena. Atmospheric wind speed, for instance, is categorized as a type of speed, reflecting how fast air moves in the atmosphere. Similarly, the speed of a water current, which pertains to the velocity of water flow in rivers, oceans, or other water bodies, is also a form of speed. The speed at which water infiltrates the soil and the speed at which soil drains water are both specific types of speed, highlighting the dynamics of water movement through the soil. Furthermore, variations in speed, such as increased or decreased speed, are also classified under the broader category of speed, indicating changes or comparisons in the rate of movement or flow. Other specific types of speed include sound speed, which is the speed at which sound waves propagate through a medium, and normal speed, a term that can be used to describe a standard or average rate of movement or flow. These diverse types of speed underscore the complexity and variability of environmental processes.'},
#  {'id': '212_0',
#   'title': 'Types of Biotransformation Processes in Environmental Applications',
#   'text': 'Biotransformation processes are crucial in the environmental sector for various applications. Among these processes, several types stand out. Biotransformation of coal, for instance, is recognized as a significant biotransformation process. Similarly, microbial enhanced oil recovery is another notable example, leveraging microbial activity to improve oil extraction. The microbial solubization of coal also falls under this category, highlighting the role of microbes in transforming coal. Furthermore, the biotransformation of biomass into mixed alcohols is a vital process, contributing to the production of alternative energy sources. These processes collectively underscore the importance of biotransformation in environmental management and energy production.'},
#  {'id': '2274_0',
#   'title': 'Classification of Saurischia within Dinosauria',
#   'text': 'Saurischia, a diverse group of dinosaurs, is classified as a type of Dinosauria, highlighting its place within the broader category of these prehistoric creatures.'},
#  {'id': '2200_0',
#   'title': 'Classification of Modiolinae within the Mytilidae Family',
#   'text': 'Modiolinae, a subfamily of bivalve mollusks, is classified under the family Mytilidae, commonly known as mussels. This taxonomic classification places Modiolinae within a broader group of marine mollusks that are characterized by their mussel-like shells. Mytilidae are a significant part of the marine ecosystem, often found in clusters on rocks and other underwater surfaces. The classification of Modiolinae as a type of Mytilidae highlights the diversity within this family and underscores the complex relationships between different mollusk species in marine environments.'},
#  {'id': '435_0',
#   'title': 'Understanding Width in Environmental Contexts',
#   'text': 'In the context of environmental studies, the term "width" can refer to various measurements, such as the width of a river, a road, or a habitat. The concept of width is crucial as it can significantly impact the environment. There are three primary categories of width: increased width, decreased width, and normal width. Increased width refers to a condition where the measurement across something is larger than what is considered standard or normal. Conversely, decreased width indicates a narrower measurement than the norm. Normal width, on the other hand, represents the typical or expected measurement. Understanding these different types of width is essential for assessing and managing environmental impacts, as changes in width can affect ecosystems and human activities.'},
#  {'id': '293_0',
#   'title': 'Forms of Hydrological Precipitation Processes',
#   'text': 'Hydrological precipitation processes encompass a variety of phenomena, including water-based rainfall, virga, hailfall, snowfall, and precipitation of sleet. Drought is also classified under hydrological precipitation processes. Water-based rainfall further categorizes into freezing rainfall and acid rainfall. Snowfall is diverse and includes heavy snowfall, lake-effect snowfall, and lambing storm. These different forms of precipitation are significant aspects of environmental study.'},
#  {'id': '1923_0',
#   'title': 'Waste Disposal: A Key Aspect of Pollution Control in Environmental Conservation',
#   'text': 'The waste disposal process is categorized under pollution control measures, playing a crucial role in environmental conservation. Effective waste disposal is essential for maintaining a clean and healthy environment, as it directly impacts the quality of air, water, and soil. By managing waste properly, we can significantly reduce the adverse effects of pollution, thereby protecting ecosystems and public health. Thus, the waste disposal process is a vital component of broader pollution control strategies aimed at preserving environmental integrity.'},
#  {'id': '2258_0',
#   'title': 'Classification of Asterids within Pentapetalae',
#   'text': 'In the realm of botanical classification, which is crucial for understanding our environment, asterids are categorized as a subtype of Pentapetalae. This classification is significant because it helps in organizing the vast diversity of plant life into manageable groups based on their evolutionary relationships. Asterids, being a part of the larger group Pentapetalae, share certain characteristics that are vital for their identification and study. Understanding such classifications is essential for environmental studies as it aids in the conservation and study of plant biodiversity.'},
#  {'id': '1118_0',
#   'title': 'Types of Snowstorms: Blizzards and Lake-Effect Snow Storms',
#   'text': 'Snowstorms are significant environmental phenomena that can be categorized into different types based on their characteristics. Among these, blizzards and lake-effect snow storms are notable. A blizzard is classified as a type of snowstorm, distinguished by its severe conditions. Similarly, a lake-effect snow storm is also a type of snowstorm, known for its formation mechanism related to lakes. Both of these types of snowstorms have significant impacts on the environment and human activities.'},
#  {'id': '2316_0',
#   'title': 'Classification of Gunneridae in Environmental Context',
#   'text': 'In the realm of environmental studies, understanding the classification of plants is crucial. Gunneridae is classified as a type of eudicotyledons, a group of flowering plants that are significant in various ecosystems around the world. This classification highlights the diverse nature of plant life and the importance of categorizing them accurately for conservation and research purposes.'},
#  {'id': '120_0',
#   'title': 'Atmospheric Aerosolisation of Dust: A Specific Type of Dust Aerosolisation',
#   'text': 'The process of dust becoming aerosolized in the atmosphere is a specific instance of dust aerosolisation. This phenomenon is significant in the context of environmental studies as it affects air quality and has implications for climate change.'},
#  {'id': '910_0',
#   'title': 'Classification of Sea Cucumbers within Marine Life',
#   'text': 'Holothuroidea, commonly known as sea cucumbers, are classified under the broader category of Echinozoa, a group of marine animals. This classification highlights the close evolutionary relationship between sea cucumbers and other echinozoans, showcasing their shared characteristics as part of the diverse marine ecosystem.'},
#  {'id': '2271_0',
#   'title': 'Classification of Lamiales in the Plant Kingdom',
#   'text': 'Lamiales, an order of flowering plants, is classified under the larger clade known as lamiids. This classification highlights the hierarchical structure within the plant kingdom, showcasing how Lamiales fits into the broader categorization of plants. Understanding such relationships is crucial in environmental studies as it helps in comprehending the diversity and complexity of plant life.'},
#  {'id': '594_0',
#   'title': 'Classification of Extra-Tropical Cyclones in Environmental Context',
#   'text': 'In the realm of environmental studies, various classifications of cyclones are observed based on their characteristics and formation mechanisms. An extra-tropical cyclone is categorized as a type of warm core cyclone. This classification is significant in understanding the dynamics of weather patterns and the impact of such cyclones on global climate conditions. Extra-tropical cyclones, also known as mid-latitude cyclones, play a crucial role in shaping weather phenomena outside the tropical regions.'},
#  {'id': '1791_0',
#   'title': 'The Role of EC 1.* (Oxidoreductase) Inhibitors in Environmental Biochemistry',
#   'text': 'In the context of environmental biochemistry, enzymes play a crucial role in various processes, including the degradation of pollutants and nutrient cycling. Enzyme inhibitors, which are substances that reduce the activity of enzymes, are significant in understanding these processes. A specific class of enzyme inhibitors is the EC 1.* (oxidoreductase) inhibitors. Oxidoreductases are enzymes that catalyze the transfer of electrons from one substance to another, playing a vital role in oxidation-reduction reactions. EC 1.* (oxidoreductase) inhibitors, being a type of enzyme inhibitor, specifically target and inhibit the activity of oxidoreductases. This inhibition can have various implications for environmental processes, including the control of metabolic pathways involved in the breakdown of environmental pollutants.'},
#  {'id': '2320_0',
#   'title': 'Classification of Eutheria within Theria',
#   'text': 'Eutheria, a significant group of mammals, falls under the broader category of Theria. Theria, known for comprising mammals that give birth to live young, is a fundamental classification in understanding mammalian diversity and their adaptation to various environments.'},
#  {'id': '2202_0',
#   'title': 'Classification of Teleostomi within Vertebrates',
#   'text': 'Teleostomi is a subgroup of Gnathostomata, which comprises vertebrates. This classification highlights the biological relationship between Teleostomi and other vertebrates within the broader category of Gnathostomata. Understanding such classifications is crucial in environmental studies as they help in assessing biodiversity and the ecological roles of different species.'},
#  {'id': '2267_0',
#   'title': 'Classification of Arecales in the Plant Kingdom',
#   'text': 'Arecales, an order of flowering plants, is classified as a type of commelinids, a clade within the monocotyledons. This classification highlights the botanical significance of Arecales within the broader context of plant taxonomy and the environment.'},
#  {'id': '2216_0',
#   'title': 'Classification of Petrosaviidae in Environmental Context',
#   'text': 'In the realm of environmental studies, understanding the classification of plant life is crucial. Petrosaviidae is classified as a type of Liliopsida, a significant group within the plant kingdom. This classification aids in comprehending the diversity and complexity of flora in various ecosystems.'},
#  {'id': '1218_0',
#   'title': 'Understanding X-ray Stellar Radiation in the Environment',
#   'text': "In the context of environmental studies, various forms of radiation are significant. X-ray stellar radiation, a specific form of radiation originating from stellar sources, is categorized as a type of X-ray radiation. This classification is important because it helps in understanding the broader impacts of X-ray radiation on the environment, including its effects on living organisms and the Earth's atmosphere."},
#  {'id': '2308_0',
#   'title': 'Classification of Vertebrates: Gnathostomata and Vertebrata',
#   'text': 'In the context of vertebrates within the environment, Gnathostomata is classified as a type of Vertebrata. This indicates that Gnathostomata, which includes jawed vertebrates, is a subset or a more specific classification within the broader category of Vertebrata, which encompasses all vertebrates. This taxonomic relationship highlights the hierarchical organization of vertebrates, with Gnathostomata representing a significant group characterized by the presence of jaws.'},
#  {'id': '2248_0',
#   'title': 'Classification of Amniota within Tetrapoda in Environmental Biology',
#   'text': 'In the realm of environmental biology, Amniota is classified as a subset of Tetrapoda, indicating that Amniota are a specific group within the broader category of Tetrapoda. This classification highlights the intricate relationships among different biological groups and their respective places within the larger taxonomy.'},
#  {'id': '1201_0',
#   'title': 'Classification of Batis Maritima in the Plant Kingdom',
#   'text': 'Batis maritima is a species within the Batis genus, which is classified under the eudicots, a diverse group of flowering plants. As a member of this group, Batis maritima shares characteristics with other eudicots, highlighting its place within the broader context of plant diversity and the environment.'},
#  {'id': '2230_0',
#   'title': 'Classification of Acrididea within Caelifera',
#   'text': 'In the realm of environmental biology, Acrididea, commonly known as short-horned grasshoppers, is categorized under the suborder Caelifera. This classification highlights the hierarchical structure within the insect world, where Acrididea represents a superfamily within the broader group of Caelifera, which encompasses a wide variety of grasshoppers. Understanding such classifications is crucial for studying biodiversity and ecological balance.'},
#  {'id': '2283_0',
#   'title': 'Classification of Commelinids within Petrosaviidae',
#   'text': 'Commelinids belong to a subgroup known as Petrosaviidae, highlighting the diverse classifications within plant taxonomy that are crucial for understanding environmental biodiversity.'},
#  {'id': '228_0',
#   'title': 'Types of Decreased Size in Environmental Contexts',
#   'text': 'In the context of environmental observations, changes in the size of various elements are crucial indicators of broader trends. Decreased size is a significant concept that encompasses several specific types of reductions. Notably, decreased volume, decreased depth, decreased thickness, decreased length, and decreased width all fall under the category of decreased size. Furthermore, decreased perimeter is considered a subtype of decreased length, highlighting the nuanced ways in which size can be measured and reduced. Additionally, decreased area is another form of decreased size, underscoring the multifaceted nature of these changes. Understanding these different aspects of decreased size is essential for a comprehensive analysis of environmental shifts.'}]

# %%
relevant_docs = []
terms_rel = ['type', 'types', 'subtypes', 'subtype', 'Types']
for doc in test_data:
    title= doc['title']
    text= doc['text']
    for term in terms_rel:
        if term in title or term in text:
            if doc not in relevant_docs:
                relevant_docs.append(doc)

# %%
len(training_data)
# Out:
# 2000

# %%
len(relevant_docs)
# Out:
# 300

# %%
len(test_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(test_data)
#
# NameError: name 'test_data' is not defined

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")

# %%
from tqdm import tqdm
final_ans = []

# %%
for i, doc in tqdm(enumerate(relevant_docs[285:])):
        
        prompt=f"""
        You are an expert AI specializing in ecology and information extraction. Your task is to carefully read an article's title and text, identify specific ecological terms, and classify them according to the categories provided within the text.

        ## Domain Description: Ecology
        Ecology is the scientific study of the intricate relationships between living organisms and their physical environment. It examines how organisms interact with each other and with abiotic factors like climate, soil, and water. The domain covers vast topics including biodiversity, population dynamics, ecosystem functioning, and nutrient cycles. This field is critical for understanding and addressing major environmental challenges, from conservation to the impacts of climate change.

        ## Instructions
        1. Read the provided title and text to understand the main concepts and their relationships.
        2. Identify specific, named examples or instances of a broader category mentioned in the text.
        3. For each identified term, find its corresponding parent category or type as defined in the article.
        4. Provide the output as a JSON list of dictionaries. Each dictionary must contain a single key-value pair, where the key is the specific term extracted, and the value is its assigned type.
        5. Only extract terms and types explicitly mentioned in the text. Do not invent terms or categories.

        ## Example
        **Input Document:**
        {json.dumps({
            "id": "1183_0",
            "title": "Types of Environmental Material Temperatures",
            "text": "The temperature of various environmental materials is a crucial aspect of environmental monitoring. Specifically, temperatures of air, soil, and water are categorized under the broader classification of temperature of environmental material. The temperature of air is one such type, playing a significant role in weather patterns and climate conditions. Similarly, the temperature of soil is another important category, influencing plant growth and microbial activity. Lastly, the temperature of water, whether in rivers, lakes, or oceans, affects aquatic life and is a vital component in the Earth's climate system. Understanding these different temperatures is essential for assessing and mitigating the impact of environmental changes."
        })}

        **Correct Output:**
        
        [
            {{"temperature of air": "Temperature of Environmental Material"}},
            {{"temperature of soil": "Temperature of Environmental Material"}},
            {{"temperature of water": "Temperature of Environmental Material"}}
        ]

        ## Your Task
        Process the following document and provide the output in the specified JSON format:

        **Input Document:**
        {doc}
        """

        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%5==0:
            print(response.text)
# Out:
# 1it [00:04,  4.72s/it]
# [
#   {
#     "Atmospheric wind speed": "speed"
#   },
#   {
#     "speed of a water current": "speed"
#   },
#   {
#     "speed at which water infiltrates the soil": "speed"
#   },
#   {
#     "speed at which soil drains water": "speed"
#   },
#   {
#     "increased speed": "speed"
#   },
#   {
#     "decreased speed": "speed"
#   },
#   {
#     "sound speed": "speed"
#   },
#   {
#     "normal speed": "speed"
#   }
# ]
# 6it [00:22,  4.11s/it]
# [
#   {
#     "asterids": "Pentapetalae"
#   }
# ]
# 11it [00:34,  2.62s/it]
# [
#   {
#     "Arecales": "commelinids"
#   },
#   {
#     "commelinids": "monocotyledons"
#   }
# ]
# 15it [00:40,  2.73s/it]

# %%
final_ans
# Out:
# ['[\n  {\n    "certain types of rock": "permeable materials"\n  },\n  {\n    "soil": "permeable materials"\n  },\n  {\n    "clay": "impermeable materials"\n  },\n  {\n    "solid rock": "impermeable materials"\n  }\n]',
#  '[\n  {\n    "carbon dioxide pooling disposition": "carbon pooling disposition"\n  }\n]',
#  '[\n  {\n    "respiratory electron transport chain": "electron transport chain"\n  }\n]',
#  '[\n  {\n    "amplitude of temperature of air": "amplitude"\n  }\n]',
#  '[\n  {\n    "Toxin": "metabolite"\n  },\n  {\n    "eukaryotic metabolites": "metabolite"\n  },\n  {\n    "animal metabolites": "eukaryotic metabolites"\n  },\n  {\n    "fungal metabolites": "eukaryotic metabolites"\n  },\n  {\n    "prokaryotic metabolites": "metabolite"\n  }\n]',
#  '[\n  {\n    "flat": "landform"\n  }\n]',
#  '[\n  {\n    "the cooling of solids": "material cooling process"\n  },\n  {\n    "the cooling of fluids": "material cooling process"\n  }\n]',
#  '[\n  {\n    "Inorganic macronutrients that are dissolved in ocean water": "macronutrient"\n  }\n]',
#  '[\n  {\n    "concentration of carbon atoms in seawater": "carbon atom concentrations found in water"\n  }\n]',
#  '[\n  {\n    "protic solvent": "polar solvent"\n  }\n]',
#  '[\n  {\n    "megathrust earthquake": "tectonic earthquake"\n  },\n  {\n    "foreshock": "tectonic earthquake"\n  },\n  {\n    "mainshock": "tectonic earthquake"\n  },\n  {\n    "aftershock": "tectonic earthquake"\n  },\n  {\n    "blind thrust earthquake": "tectonic earthquake"\n  },\n  {\n    "Multiplet earthquake": "tectonic earthquake"\n  },\n  {\n    "interplate earthquake": "tectonic earthquake"\n  },\n  {\n    "intraplate earthquake": "tectonic earthquake"\n  }\n]',
#  '[\n  {\n    "carbon-bearing gas emission processes": "hydrocarbon gas emission processes"\n  },\n  {\n    "carbon dioxide emission processes": "carbon-bearing gas emission processes"\n  },\n  {\n    "methane gas emission processes": "hydrocarbon gas emission processes"\n  }\n]',
#  '[\n  {\n    "lumber production process": "planetary manufacturing processes"\n  },\n  {\n    "lumber production": "planetary manufacturing process"\n  }\n]',
#  '[\n  {\n    "food propellants": "propellant"\n  }\n]',
#  '[\n    {\n        "hollow": "type of structure"\n    }\n]',
#  '[\n  {\n    "nilas formation process": "sea ice formation processes"\n  },\n  {\n    "young ice formation process": "sea ice formation processes"\n  },\n  {\n    "first year ice formation process": "sea ice formation processes"\n  },\n  {\n    "second year ice formation": "sea ice formation processes"\n  },\n  {\n    "multiyear ice formation process": "sea ice formation processes"\n  }\n]',
#  '[\n  {\n    "Methane metabolic process": "alkane metabolic process"\n  }\n]',
#  '[\n  {\n    "alpine": "altitudinal conditions"\n  },\n  {\n    "subalpine": "altitudinal conditions"\n  },\n  {\n    "montane": "altitudinal conditions"\n  },\n  {\n    "nival": "altitudinal conditions"\n  }\n]',
#  '[\n  {\n    "anaerobic respiration where ammonium acts as the electron donor": "ammonia oxidation"\n  },\n  {\n    "aerobic respiration that utilizes ammonia as the electron donor": "ammonia oxidation"\n  }\n]',
#  '[\n  {\n    "tripartite": "branched system"\n  }\n]',
#  '[\n  {\n    "Ditrysia": "Heteroneura"\n  },\n  {\n    "Heteroneura": "Lepidoptera"\n  }\n]',
#  '[\n  {\n    "Purine ribonucleoside 5\'-triphosphate": "ribonucleoside 5\'-triphosphate"\n  }\n]',
#  '[\n  {\n    "Daphnia metabolite": "crustacean metabolite"\n  }\n]',
#  '[\n  {\n    "feeding behavior": "behavior"\n  }\n]',
#  '[\n  {\n    "Water infiltration into soil": "water infiltration process"\n  }\n]',
#  '[\n  {\n    "dissolved carbon atom within environmental materials": "dissolved substance"\n  }\n]',
#  '[\n  {\n    "volcanic seismic vibration": "seismic vibration processes"\n  },\n  {\n    "impact-driven seismic vibration": "seismic vibration processes"\n  },\n  {\n    "explosion-driven seismic vibration": "seismic vibration processes"\n  },\n  {\n    "mass-wasting-driven seismic vibration": "seismic vibration processes"\n  },\n  {\n    "collapse-driven seismic vibration": "seismic vibration processes"\n  },\n  {\n    "earthquake-driven seismic vibration": "seismic vibration processes"\n  }\n]',
#  '[\n  {\n    "Bacterial metabolites": "prokaryotic metabolites"\n  }\n]',
#  '[\n  {\n    "weathering of plastic": "weathering process"\n  }\n]',
#  '[\n  {\n    "photosynthetic photon flux": "flux"\n  }\n]',
#  '[\n  {\n    "pieces of animal": "animal material"\n  }\n]',
#  '[\n  {\n    "fluid flow rate": "flow rate"\n  }\n]',
#  '[\n  {\n    "Oscillatoria": "Oscillatoriaceae"\n  },\n  {\n    "Phormidium": "Oscillatoriaceae"\n  }\n]',
#  '[\n  {\n    "an impact between astronomical bodies": "impact event"\n  }\n]',
#  '[\n  {\n    "biomarker": "indicator"\n  }\n]',
#  '[\n  {\n    "electron donor": "donor"\n  },\n  {\n    "Bronsted acids": "donor"\n  },\n  {\n    "Lewis bases": "donor"\n  }\n]',
#  '[\n  {\n    "oceanic temperate": "temperate"\n  },\n  {\n    "continental temperate": "temperate"\n  }\n]',
#  '[\n  {\n    "Obtectomera": "Ditrysia"\n  },\n  {\n    "Ditrysia": "Lepidoptera order"\n  }\n]',
#  '[\n  {\n    "concentration of carbon-13 atoms in sea water": "concentration of carbon atoms in sea water"\n  },\n  {\n    "concentration of carbon-14 atoms in sea water": "concentration of carbon atoms in sea water"\n  }\n]',
#  '[\n  {\n    "piece of cow": "piece of animal"\n  }\n]',
#  '[\n  {\n    "Radioactivity": "activity"\n  }\n]',
#  '[\n  {\n    "curled": "shape"\n  },\n  {\n    "undulate": "shape"\n  },\n  {\n    "elongated": "shape"\n  },\n  {\n    "linear": "shape"\n  },\n  {\n    "filamentous": "shape"\n  },\n  {\n    "curved": "curvature"\n  },\n  {\n    "flattened": "curvature"\n  },\n  {\n    "sloped": "direction or orientation"\n  },\n  {\n    "sloped downward": "sloped"\n  },\n  {\n    "lobate": "surface feature shape"\n  },\n  {\n    "sculpted surface": "surface feature shape"\n  },\n  {\n    "ornamentation": "surface feature shape"\n  },\n  {\n    "oblong": "2-D shapes"\n  },\n  {\n    "fan-shaped": "2-D shapes"\n  },\n  {\n    "superelliptic": "2-D shapes"\n  },\n  {\n    "convex": "3-D shapes"\n  },\n  {\n    "concave 3-D shapes": "3-D shapes"\n  },\n  {\n    "V-shaped": "angular"\n  },\n  {\n    "concave": "concavity"\n  },\n  {\n    "branched structures": "branchiness"\n  },\n  {\n    "columnar": "shape"\n  },\n  {\n    "drooping": "shape"\n  },\n  {\n    "straight": "shape"\n  },\n  {\n    "slender": "shape"\n  },\n  {\n    "falciform": "shape"\n  },\n  {\n    "fringed": "Edge shapes"\n  },\n  {\n    "fimbriated": "shape"\n  },\n  {\n    "tholiform": "shape"\n  },\n  {\n    "broad": "shape"\n  },\n  {\n    "funnel-shaped": "shape"\n  },\n  {\n    "radiating": "shape"\n  },\n  {\n    "plume-shaped": "shape"\n  }\n]',
#  '[\n  {\n    "Daphnia magna metabolite": "Daphnia metabolite"\n  }\n]',
#  '[\n  {\n    "dissolved carbon atom in soil": "solubility of carbon atoms within the soil matrix"\n  }\n]',
#  '[\n  {\n    "aerobic sensitivity to oxygen": "sensitivity to oxygen"\n  },\n  {\n    "anaerobic sensitivity": "sensitivity to oxygen"\n  }\n]',
#  '[\n  {\n    "Soil bulk density": "mass density of soil"\n  }\n]',
#  '[\n  {\n    "increased rate of occurrence": "rate of occurrence"\n  }\n]',
#  '[\n  {\n    "spherical": "spheroid"\n  }\n]',
#  '[\n  {\n    "increased frequency": "increased rate of occurrence"\n  }\n]',
#  '[\n  {\n    "Cow material": "animal material"\n  }\n]',
#  '[\n  {\n    "CHEBI_15422": "adenosine 5\'-phosphate"\n  }\n]',
#  '[\n  {\n    "Sporadic occurrences": "occurrences"\n  },\n  {\n    "continuous occurrences": "occurrences"\n  },\n  {\n    "discontinuous occurrences": "occurrences"\n  }\n]',
#  '[\n  {\n    "increased rate of occurrence": "rate of occurrence"\n  }\n]',
#  '[\n  {\n    "arched shape": "concave shape"\n  }\n]',
#  '[\n  {\n    "meteorite impact": "impact that occurs between astronomical bodies"\n  }\n]',
#  '[\n  {\n    "crustacean metabolite": "animal metabolite"\n  }\n]',
#  '[\n  {\n    "Aerobic respiration": "cellular respiration"\n  }\n]',
#  '[\n  {\n    "domed": "curved"\n  }\n]',
#  '[\n  {\n    "transpiration": "water cooling mechanism"\n  }\n]',
#  '[\n  {\n    "Stellar radiation energy": "radiant energy"\n  }\n]',
#  '[\n  {\n    "Generation of precursor metabolites and energy": "metabolic process"\n  },\n  {\n    "biosynthetic process": "metabolic process"\n  },\n  {\n    "photosynthesis": "metabolic process"\n  },\n  {\n    "small molecule metabolic process": "metabolic process"\n  },\n  {\n    "hydrocarbon metabolic process": "metabolic process"\n  },\n  {\n    "energy derivation by oxidation of reduced inorganic compounds": "generation of precursor metabolites and energy"\n  },\n  {\n    "energy derivation by oxidation of organic compounds": "generation of precursor metabolites and energy"\n  },\n  {\n    "electron transport chain": "generation of precursor metabolites and energy"\n  },\n  {\n    "hydrocarbon biosynthetic process": "biosynthetic process"\n  },\n  {\n    "ammonia oxidation": "small molecule metabolic process"\n  },\n  {\n    "alkane metabolic process": "hydrocarbon metabolic process"\n  },\n  {\n    "hydrocarbon biosynthetic process": "hydrocarbon metabolic process"\n  }\n]',
#  '[\n  {\n    "adenosine phosphate": "adenyl ribonucleotide"\n  }\n]',
#  '[\n  {\n    "guanosine 5\'-phosphate": "guanosine phosphate"\n  }\n]',
#  '[\n  {\n    "composition of soil": "composition"\n  },\n  {\n    "composition of water": "composition"\n  },\n  {\n    "being calcified": "composition"\n  },\n  {\n    "granular": "composition"\n  }\n]',
#  '[\n  {\n    "CHEBI_15996": "guanosine 5\'-phosphate"\n  }\n]',
#  '[\n  {\n    "Geothermal energy": "thermal energy"\n  }\n]',
#  '[\n  {\n    "circular shape": "elliptic shape"\n  }\n]',
#  '[\n  {\n    "Fudge": "soft candy"\n  }\n]',
#  '[\n  {\n    "alkane biosynthetic process": "hydrocarbon biosynthetic process"\n  }\n]',
#  '[\n  {\n    "dissolved nitrogen atoms present in soil": "types of dissolved nitrogen atoms in environmental materials"\n  },\n  {\n    "dissolved nitrogen atoms present in water": "types of dissolved nitrogen atoms in environmental materials"\n  }\n]',
#  '[\n  {\n    "being detached from": "attachment quality"\n  }\n]',
#  '[\n  {\n    "refinement process": "chemical engineering process"\n  },\n  {\n    "Haber-Bosch process": "chemical engineering process"\n  },\n  {\n    "hydrogen production process": "chemical engineering process"\n  }\n]',
#  '[\n  {\n    "Animal material": "organism material"\n  }\n]',
#  '[\n  {\n    "aerobic respiration using nitrite": "Aerobic Respiration"\n  },\n  {\n    "aerobic respiration using ammonia": "Aerobic Respiration"\n  },\n  {\n    "aerobic respiration using carbon monoxide": "Aerobic Respiration"\n  },\n  {\n    "aerobic respiration using ferrous ions": "Aerobic Respiration"\n  },\n  {\n    "aerobic respiration using hydrogen": "Aerobic Respiration"\n  },\n  {\n    "aerobic respiration using sulfur or sulfate": "Aerobic Respiration"\n  },\n  {\n    "aerobic respiration using arsenite": "Aerobic Respiration"\n  },\n  {\n    "aerobic electron transport chain": "Aerobic Respiration"\n  }\n]',
#  '[\n  {\n    "increased rate of occurrence": "increased rate"\n  }\n]',
#  '[\n  {\n    "piece of cow": "piece of animal"\n  }\n]',
#  '[\n  {\n    "Propane-1,2-diol": "propane-1,2-diols"\n  }\n]',
#  '[\n  {\n    "sound wave energy": "Mechanical wave energy"\n  },\n  {\n    "wind wave energy": "Mechanical wave energy"\n  }\n]',
#  '[\n  {\n    "humidity of soil": "humidity"\n  },\n  {\n    "increased humidity": "humidity"\n  },\n  {\n    "decreased humidity": "humidity"\n  }\n]',
#  '[\n  {\n    "mammalian metabolite": "animal metabolite"\n  }\n]',
#  '[\n  {\n    "biodegradation of plastic": "biodegradation"\n  }\n]',
#  '[\n  {\n    "obtuse shape": "circular or rounded form"\n  }\n]',
#  '[\n  {\n    "human metabolite": "mammalian metabolite"\n  }\n]',
#  '[\n  {\n    "Beef": "meat"\n  },\n  {\n    "piece of beef": "piece of cow"\n  }\n]',
#  '[\n  {\n    "glacial abrasion": "glacial erosion processes"\n  },\n  {\n    "glacial plucking": "glacial erosion processes"\n  },\n  {\n    "glacial ice thrusting": "glacial erosion processes"\n  }\n]',
#  '[\n  {\n    "increased accumulation": "accumulation"\n  },\n  {\n    "decreased accumulation": "accumulation"\n  }\n]',
#  '[\n  {\n    "irradiation by ionizing radiation": "Irradiation"\n  },\n  {\n    "irradiation by non-ionizing radiation": "Irradiation"\n  },\n  {\n    "photosynthetically active radiation": "non-ionizing radiation"\n  }\n]',
#  '[\n  {\n    "freezing of water into ice": "freezing process"\n  },\n  {\n    "adfreezing": "freezing"\n  }\n]',
#  '[\n  {\n    "dissolved carbon atoms in soil": "dissolved carbon atoms in environmental materials"\n  },\n  {\n    "dissolved carbon atoms in water": "dissolved carbon atoms in environmental materials"\n  }\n]',
#  '[\n  {\n    "sea surface temperature": "water temperature"\n  }\n]',
#  '[\n  {\n    "Mutagens": "genotoxin"\n  }\n]',
#  '[\n  {\n    "Guanosine phosphate": "guanyl ribonucleotide"\n  }\n]',
#  '[\n  {\n    "Purine ribonucleoside 5\'-triphosphate": "ribonucleoside 5\'-triphosphate"\n  }\n]',
#  '[\n  {\n    "upper montane": "montane region"\n  },\n  {\n    "lower montane": "montane region"\n  }\n]',
#  '[\n  {\n    "Adenosine 5\'-phosphate": "adenosine phosphate"\n  }\n]',
#  '[\n  {\n    "coastal flooding": "flooding"\n  },\n  {\n    "storm surges": "coastal flooding"\n  },\n  {\n    "riverine flooding": "flooding"\n  },\n  {\n    "flash flooding": "flooding"\n  },\n  {\n    "areal flooding": "flooding"\n  },\n  {\n    "urban flooding": "flooding"\n  }\n]',
#  '[\n  {\n    "amphiprotic solvent": "protophilic solvent"\n  }\n]',
#  '[\n  {\n    "micronutrients": "nutrients"\n  },\n  {\n    "macronutrients": "nutrients"\n  }\n]',
#  '[\n    {\n        "frequency": "rate of occurrence"\n    }\n]',
#  '[\n  {\n    "dissolved carbon atom": "dissolved substance"\n  }\n]',
#  '[\n  {\n    "alkane biosynthetic process": "alkane metabolic process"\n  }\n]',
#  '[\n  {\n    "Dinophyceae": "Alveolata"\n  }\n]',
#  '[\n  {\n    "concentration of carbon atoms in seawater": "carbon atom concentrations found in water"\n  }\n]',
#  '[\n  {\n    "piece(s) of cow": "cow material"\n  }\n]',
#  '[\n  {\n    "protophilic solvent": "polar solvent"\n  }\n]',
#  '[\n  {\n    "piece(s) of cow": "cow material"\n  }\n]',
#  '[\n  {\n    "protophilic solvent": "Bronsted base"\n  }\n]',
#  '[\n  {\n    "Frazil ice formation": "new ice formation processes"\n  },\n  {\n    "slush formation": "new ice formation processes"\n  },\n  {\n    "shuga formation": "new ice formation processes"\n  }\n]',
#  '[\n  {\n    "Ingestion": "eating behavior"\n  }\n]',
#  '[\n  {\n    "oceanic transient tracer": "transient tracer"\n  }\n]',
#  '[\n  {\n    "Hydraulic fracturing": "well stimulation"\n  }\n]',
#  '[\n  {\n    "Atmospheric wind direction": "direction"\n  },\n  {\n    "down": "relative terms"\n  },\n  {\n    "left": "relative terms"\n  },\n  {\n    "right": "relative terms"\n  },\n  {\n    "front": "relative terms"\n  },\n  {\n    "back": "relative terms"\n  },\n  {\n    "unidirectional": "direction"\n  },\n  {\n    "bi-directional": "direction"\n  },\n  {\n    "circling direction": "direction"\n  },\n  {\n    "north": "cardinal directions"\n  },\n  {\n    "south": "cardinal directions"\n  },\n  {\n    "east": "cardinal directions"\n  },\n  {\n    "west": "cardinal directions"\n  }\n]',
#  '[\n  {\n    "Oscillatoriaceae": "family"\n  },\n  {\n    "Oscillatoriales": "order"\n  }\n]',
#  '[\n  {\n    "submarine groundwater discharge process": "groundwater discharge process"\n  }\n]',
#  '[\n  {\n    "excitatory amino acid antagonist": "antagonist"\n  },\n  {\n    "excitatory amino acids": "neurotransmitter"\n  }\n]',
#  '[\n  {\n    "an impact between astronomical bodies": "impact event"\n  }\n]',
#  '[\n  {\n    "muskmelon (Cucumis melo) fruit food product": "melon fruit food product"\n  },\n  {\n    "cantaloupe fruit food product": "muskmelon (Cucumis melo) fruit food product"\n  },\n  {\n    "citrullus lanatus fruit food product": "melon fruit food product"\n  }\n]',
#  '[\n  {\n    "periglacial process": "frost action process"\n  },\n  {\n    "cryoturbation of soil": "frost action process"\n  },\n  {\n    "frost jacking": "cryoturbation of soil"\n  },\n  {\n    "frost sorting": "cryoturbation of soil"\n  },\n  {\n    "frost wedging": "cryoturbation of soil"\n  },\n  {\n    "frost heaving": "cryoturbation of soil"\n  }\n]',
#  '[\n  {\n    "concentration of nitrite in sea water": "concentration of nitrite found in liquid water"\n  }\n]',
#  '[\n  {\n    "protophilic solvent": "polar solvent"\n  }\n]',
#  '[\n  {\n    "Methanogenesis": "alkane biosynthetic process"\n  }\n]',
#  '[\n  {\n    "elliptic shape": "superelliptic shape"\n  }\n]',
#  '[\n  {\n    "protophilic solvent": "Bronsted base"\n  }\n]',
#  '[\n  {\n    "soil erosion": "planetary erosion"\n  },\n  {\n    "bedrock dissolution": "planetary erosion"\n  },\n  {\n    "glacial erosion processes": "planetary erosion"\n  },\n  {\n    "erosion through nivation": "planetary erosion"\n  }\n]',
#  '[\n  {\n    "raising agent": "food additive"\n  },\n  {\n    "food packaging gas": "food additive"\n  },\n  {\n    "food propellant": "food additive"\n  }\n]',
#  '[\n  {\n    "atmosphere-ocean momentum transfer process": "momentum transfer process"\n  }\n]',
#  '[\n  {\n    "the concentration of nitrate in groundwater": "concentration of nitrate in liquid water"\n  },\n  {\n    "the concentration of nitrate in sea water": "concentration of nitrate in liquid water"\n  }\n]',
#  '[\n  {\n    "atmospheric weather": "weather"\n  },\n  {\n    "space weather": "weather"\n  }\n]',
#  '[\n  {\n    "north": "cardinal direction"\n  },\n  {\n    "east": "cardinal direction"\n  },\n  {\n    "south": "cardinal direction"\n  },\n  {\n    "west": "cardinal direction"\n  }\n]',
#  '[\n  {\n    "aerobic electron transport chain": "respiratory electron transport chain"\n  }\n]',
#  '[\n  {\n    "ice-bearing permafrost thawing process": "permafrost thawing process"\n  }\n]',
#  '[\n  {\n    "Purine ribonucleoside 5\'-triphosphate": "ribonucleoside 5\'-triphosphate"\n  }\n]',
#  '[\n  {\n    "alkane biosynthetic process": "hydrocarbon biosynthetic process"\n  }\n]',
#  '[\n  {\n    "concentration of silicic acid in sea water": "concentration of silicic acid found in liquid water"\n  }\n]',
#  '[\n  {\n    "spheroid": "convex 3-D shape"\n  },\n  {\n    "cylindrical shape": "convex 3-D shape"\n  },\n  {\n    "conical shape": "convex 3-D shape"\n  }\n]',
#  '[\n  {\n    "eating behavior": "feeding behavior"\n  }\n]',
#  '[\n  {\n    "glucosamines": "hexosamine"\n  }\n]',
#  '[\n  {\n    "agronomic process": "agricultural process"\n  },\n  {\n    "animal husbandry": "agricultural process"\n  }\n]',
#  '[\n  {\n    "increased rate of occurrence": "increased rate"\n  }\n]',
#  '[\n  {\n    "Mediterranean climate": "subtropical"\n  },\n  {\n    "humid subtropical": "subtropical"\n  },\n  {\n    "arid subtropical": "subtropical"\n  },\n  {\n    "highland subtropical": "subtropical"\n  }\n]',
#  '[\n  {\n    "road traffic noise": "noise"\n  },\n  {\n    "aircraft noise": "noise"\n  }\n]',
#  '[\n  {\n    "increased frequency": "frequency"\n  },\n  {\n    "decreased frequency": "frequency"\n  }\n]',
#  '[\n  {\n    "alkane biosynthetic process": "alkane metabolic process"\n  }\n]',
#  '[\n  {\n    "temperature of air": "temperature of environmental material"\n  },\n  {\n    "temperature of soil": "temperature of environmental material"\n  },\n  {\n    "temperature of water": "temperature of environmental material"\n  }\n]',
#  '[\n  {\n    "Amphiesmenoptera": "Endopterygota"\n  }\n]',
#  '[\n  {\n    "glacial surface layer velocity": "velocity"\n  },\n  {\n    "angular velocity": "velocity"\n  },\n  {\n    "increased velocity": "velocity"\n  },\n  {\n    "decreased velocity": "velocity"\n  },\n  {\n    "normal velocity": "velocity"\n  }\n]',
#  '[\n  {\n    "increased fluid flow": "fluid flow rates"\n  },\n  {\n    "decreased fluid flow": "fluid flow rates"\n  }\n]',
#  '[\n  {\n    "protic solvent": "polar solvent"\n  }\n]',
#  '[\n  {\n    "aerosolised particle formation events": "aerosolised particle formation processes"\n  }\n]',
#  '[\n  {\n    "Mollusca": "Lophotrochozoa"\n  }\n]',
#  '[\n  {\n    "Caelifera": "Orthoptera"\n  },\n  {\n    "crickets": "Orthoptera"\n  },\n  {\n    "katydids": "Orthoptera"\n  }\n]',
#  '[\n  {\n    "Pinidae": "Pinopsida"\n  }\n]',
#  '[\n  {\n    "biodiversity conservation process": "conservation-focused active ecosystem management process"\n  }\n]',
#  '[\n  {\n    "Fluorescence of water": "fluorescence"\n  }\n]',
#  '[\n  {\n    "macroburst": "downburst"\n  }\n]',
#  '[\n  {\n    "Haplorrhini": "primates"\n  }\n]',
#  '[\n  {\n    "thickness of snow": "thickness"\n  },\n  {\n    "thickness of topsoil": "thickness"\n  },\n  {\n    "increased thickness": "thickness"\n  },\n  {\n    "decreased thickness": "thickness"\n  },\n  {\n    "irregular thickness": "thickness"\n  }\n]',
#  '[\n  {\n    "decreased circumference": "circumference"\n  }\n]',
#  '[\n  {\n    "Laguncularia racemosa": "Laguncularia"\n  }\n]',
#  '[\n  {\n    "Conifers II": "Pinidae"\n  }\n]',
#  '[\n  {\n    "Soil albedo": "albedo"\n  }\n]',
#  '[\n  {\n    "forest fires": "types of land fires"\n  },\n  {\n    "brush fires": "types of land fires"\n  },\n  {\n    "bush fires": "types of land fires"\n  },\n  {\n    "grass fires": "types of land fires"\n  },\n  {\n    "pasture fires": "grass fires"\n  }\n]',
#  '[\n  {\n    "Archosauria": "Archelosauria"\n  }\n]',
#  '[\n  {\n    "color": "optical quality"\n  }\n]',
#  '[\n  {\n    "patchy pattern": "irregular spatial patterns"\n  },\n  {\n    "aggregated pattern": "irregular spatial patterns"\n  },\n  {\n    "trabecular pattern": "irregular spatial patterns"\n  }\n]',
#  '[\n  {\n    "defence against flooding": "anthropogenic modulatory intervention"\n  },\n  {\n    "conservation-focused active ecosystem management": "Active ecosystem management processes"\n  },\n  {\n    "active agri-ecosystem management": "Active ecosystem management processes"\n  },\n  {\n    "planned revegetation": "Active ecosystem management processes"\n  },\n  {\n    "pollution degradation": "anthropogenic modulation of pollution"\n  },\n  {\n    "pollution control": "anthropogenic modulation of pollution"\n  }\n]',
#  '[\n  {\n    "Eudicotyledons": "Mesangiospermae"\n  }\n]',
#  '[\n  {\n    "Dipnotetrapodomorpha": "Sarcopterygii"\n  }\n]',
#  '[\n  {\n    "the process of forming a liquid aerosol from gaseous material within an atmospheric context": "formation of liquid aerosols that occurs in the atmosphere"\n  }\n]',
#  '[\n  {\n    "respiratory-chain inhibitor": "electron-transport chain inhibitor"\n  }\n]',
#  '[\n  {\n    "Pteriomorphia": "Autobranchia"\n  }\n]',
#  '[\n  {\n    "Locusta migratoria": "Locusta"\n  }\n]',
#  '[\n  {\n    "volume of hydrological precipitation": "type of volume"\n  },\n  {\n    "volume of runoff": "type of volume"\n  },\n  {\n    "volume of evaporation": "type of volume"\n  },\n  {\n    "volume of evapotranspiration": "type of volume"\n  },\n  {\n    "volume of rain": "type of volume"\n  }\n]',
#  '[\n  {\n    "ionizing stellar radiation": "types of ionizing radiation"\n  },\n  {\n    "X-ray radiation": "types of ionizing radiation"\n  },\n  {\n    "gamma-ray radiation": "types of ionizing radiation"\n  }\n]',
#  '[\n  {\n    "Sarcopterygii": "Euteleostomi"\n  }\n]',
#  '[\n  {\n    "Elaeis guineensis": "Elaeis genus"\n  }\n]',
#  '[\n  {\n    "perimeter": "one-dimensional extent"\n  }\n]',
#  '[\n  {\n    "inhalation anaesthetic": "general anaesthetic"\n  }\n]',
#  '[\n  {\n    "visible spectrum stellar radiation": "visible spectrum radiation"\n  }\n]',
#  '[\n  {\n    "lamiids": "asterids"\n  }\n]',
#  '[\n  {\n    "WMO blizzard": "type of blizzard"\n  },\n  {\n    "winter blizzard": "type of blizzard"\n  }\n]',
#  '[\n  {\n    "Mytilus": "subfamily Mytilinae"\n  }\n]',
#  '[\n  {\n    "land conversion process": "land consumption process"\n  }\n]',
#  '[\n  {\n    "influenced by": "quality"\n  },\n  {\n    "dispositional property": "quality"\n  },\n  {\n    "young": "Age-related qualities"\n  },\n  {\n    "chronological age": "quality"\n  }\n]',
#  '[\n  {\n    "Avicennia": "Avicennioideae"\n  }\n]',
#  '[\n  {\n    "Volume": "3-D extent"\n  }\n]',
#  '[\n  {\n    "aerosolised particle formation events": "aerosolised particle formation processes"\n  }\n]',
#  '[\n  {\n    "Autobranchia": "Bivalvia"\n  },\n  {\n    "clams": "Bivalvia"\n  },\n  {\n    "mussels": "Bivalvia"\n  },\n  {\n    "oysters": "Bivalvia"\n  },\n  {\n    "scallops": "Bivalvia"\n  }\n]',
#  '[\n  {\n    "increased area": "area"\n  },\n  {\n    "decreased area": "area"\n  },\n  {\n    "normal area": "area"\n  }\n]',
#  '[\n  {\n    "butter product analog": "milk or milk product analog"\n  }\n]',
#  '[\n  {\n    "mass gaseous flow": "mass fluid flow"\n  },\n  {\n    "mass liquid flow": "mass fluid flow"\n  },\n  {\n    "mass plasma flow": "mass fluid flow"\n  },\n  {\n    "atmospheric wind": "mass gaseous flow"\n  },\n  {\n    "planetary wind": "mass gaseous flow"\n  },\n  {\n    "tsunami": "mass liquid flow"\n  },\n  {\n    "lava flow": "mass liquid flow"\n  },\n  {\n    "tidal flow": "mass liquid flow"\n  },\n  {\n    "stellar wind": "mass plasma flow"\n  },\n  {\n    "Cyclonic circulation": "mass fluid flow"\n  }\n]',
#  '[\n  {\n    "Snow water equivalent": "depth"\n  },\n  {\n    "depth of water ice": "depth"\n  },\n  {\n    "top depths of soil layers": "depth"\n  },\n  {\n    "bottom depths of soil layers": "depth"\n  },\n  {\n    "depth of snow": "depth"\n  },\n  {\n    "depth of water": "depth"\n  },\n  {\n    "decreased depth": "depth"\n  },\n  {\n    "increased depth": "depth"\n  },\n  {\n    "normal depth": "depth"\n  }\n]',
#  '[\n  {\n    "hydrocarbon bioremediation": "Bioremediation"\n  },\n  {\n    "metal bioremediation": "Bioremediation"\n  },\n  {\n    "treatment of persistent organic pollutants": "Bioremediation"\n  }\n]',
#  '[\n  {\n    "color patterns": "Spatial pattern"\n  },\n  {\n    "irregular spatial patterns": "Spatial pattern"\n  },\n  {\n    "regular spatial patterns": "Spatial pattern"\n  },\n  {\n    "unilateral patterns": "Spatial pattern"\n  },\n  {\n    "distributed patterns": "Spatial pattern"\n  },\n  {\n    "vertical arrangements": "Spatial pattern"\n  },\n  {\n    "stratification": "Spatial pattern"\n  },\n  {\n    "colorless": "color pattern"\n  },\n  {\n    "increased distribution": "distributed patterns"\n  },\n  {\n    "decreased distribution": "distributed patterns"\n  },\n  {\n    "stratified": "stratification"\n  }\n]',
#  '[\n  {\n    "warm core cyclone": "cyclones"\n  }\n]',
#  '[\n  {\n    "quality of full-spectrum electromagnetic radiation": "quality related to the interaction of substances with electromagnetic radiation"\n  }\n]',
#  '[\n  {\n    "microburst": "downburst"\n  }\n]',
#  '[\n  {\n    "radio wave stellar radiation": "radio wave radiation"\n  }\n]',
#  '[\n  {\n    "permafrost methane explosion": "explosion process"\n  }\n]',
#  '[\n  {\n    "crustacean farming processes": "animal aquaculture processes"\n  },\n  {\n    "finfish farming processes": "animal aquaculture processes"\n  },\n  {\n    "mollusc farming processes": "animal aquaculture processes"\n  }\n]',
#  '[\n  {\n    "diurnal marine tidal flow process": "marine tidal flow processes"\n  },\n  {\n    "semi-diurnal marine tidal flow process": "marine tidal flow processes"\n  }\n]',
#  '[\n  {\n    "Solar radiation": "stellar radiation"\n  },\n  {\n    "microwave": "stellar radiation"\n  },\n  {\n    "radio wave": "stellar radiation"\n  },\n  {\n    "infrared": "stellar radiation"\n  },\n  {\n    "visible spectrum": "stellar radiation"\n  },\n  {\n    "ultraviolet": "stellar radiation"\n  },\n  {\n    "ionizing stellar radiation": "stellar radiation"\n  },\n  {\n    "X-ray stellar radiation": "Ionizing stellar radiation"\n  },\n  {\n    "gamma-ray stellar radiation": "Ionizing stellar radiation"\n  }\n]',
#  '[\n  {\n    "Anthropisation": "anthropogenic ecosystem conversion process"\n  }\n]',
#  '[\n  {\n    "Echinozoa": "Eleutherozoa"\n  }\n]',
#  '[\n  {\n    "pathway inhibitor": "enzyme inhibitor"\n  }\n]',
#  '[\n  {\n    "increased length": "length"\n  },\n  {\n    "decreased length": "length"\n  }\n]',
#  '[\n  {\n    "Schistocerca gregaria": "Schistocerca"\n  }\n]',
#  '[\n  {\n    "seaweed farming": "plant aquaculture processes"\n  },\n  {\n    "freshwater macrophyte farming": "plant aquaculture processes"\n  }\n]',
#  '[\n  {\n    "afforestation": "planned revegetation"\n  },\n  {\n    "reforestation": "planned revegetation"\n  }\n]',
#  '[\n  {\n    "Theropoda": "Saurischia"\n  }\n]',
#  '[\n  {\n    "intercloud lightning": "lightning flashes"\n  },\n  {\n    "intracloud lightning": "lightning flashes"\n  }\n]',
#  '[\n  {\n    "Microwave stellar radiation": "microwave radiation"\n  }\n]',
#  '[\n  {\n    "thunderstorm": "convective storm"\n  }\n]',
#  '[\n  {\n    "land conversion process": "land consumption process"\n  }\n]',
#  '[\n  {\n    "Salicornia subgen. Amerocornia": "Salicornia"\n  }\n]',
#  '[\n  {\n    "Arthropoda": "Panarthropoda"\n  }\n]',
#  '[\n  {\n    "increased perimeter": "increased length"\n  }\n]',
#  '[\n  {\n    "dry macrobursts": "macrobursts"\n  },\n  {\n    "wet macrobursts": "macrobursts"\n  }\n]',
#  '[\n  {\n    "thickness": "one-dimensional extent"\n  },\n  {\n    "thickness of ice caps": "one-dimensional extent"\n  },\n  {\n    "thickness of a particular layer of soil": "one-dimensional extent"\n  }\n]',
#  '[\n  {\n    "Hominoidea": "Catarrhini"\n  }\n]',
#  '[\n  {\n    "direct transformation of gaseous materials into solid particles": "solid aerosol formation in the atmosphere"\n  },\n  {\n    "formation of solid aerosols from liquid materials present in the atmosphere": "solid aerosol formation"\n  },\n  {\n    "glaciation of water droplets within clouds": "formation of solid aerosols from liquid materials present in the atmosphere"\n  }\n]',
#  '[\n  {\n    "Opacity": "optical quality"\n  }\n]',
#  '[\n  {\n    "Dry soil albedo": "soil albedo"\n  },\n  {\n    "moist soil albedo": "soil albedo"\n  }\n]',
#  '[\n  {\n    "color of the soil": "color"\n  },\n  {\n    "blue": "color"\n  },\n  {\n    "white": "color"\n  },\n  {\n    "brown": "color"\n  }\n]',
#  '[\n  {\n    "downburst": "downdraft"\n  }\n]',
#  '[\n  {\n    "wet microbursts": "microbursts"\n  },\n  {\n    "dry microbursts": "microbursts"\n  }\n]',
#  '[\n  {\n    "infrared stellar radiation": "infrared radiation"\n  },\n  {\n    "outgoing longwave radiation": "infrared radiation"\n  },\n  {\n    "mid-infrared radiation": "infrared radiation"\n  },\n  {\n    "near-infrared radiation": "infrared radiation"\n  },\n  {\n    "far-infrared radiation": "infrared radiation"\n  }\n]',
#  '[\n  {\n    "Anthropisation": "anthropogenic ecosystem conversion process"\n  }\n]',
#  '[\n  {\n    "Laguncularia": "plant"\n  }\n]',
#  '[\n  {\n    "circumference": "perimeter"\n  },\n  {\n    "increased perimeter": "perimeter"\n  },\n  {\n    "decreased perimeter": "perimeter"\n  }\n]',
#  '[\n  {\n    "acidic": "medium acidity"\n  },\n  {\n    "alkaline": "medium acidity"\n  }\n]',
#  '[\n  {\n    "Arecaceae": "Arecales"\n  }\n]',
#  '[\n  {\n    "Acridomorpha": "Acrididea"\n  }\n]',
#  '[\n  {\n    "Land fire": "Wildfire"\n  }\n]',
#  '[\n  {\n    "conflagration": "Fire"\n  },\n  {\n    "industrial fire": "Fire"\n  },\n  {\n    "planned burn": "Fire"\n  },\n  {\n    "wildfire": "conflagration"\n  }\n]',
#  '[\n  {\n    "Theria": "Mammalia"\n  }\n]',
#  '[\n  {\n    "downburst": "downdraft"\n  }\n]',
#  '[\n  {\n    "length": "one-dimensional (1-D) extent"\n  }\n]',
#  '[\n  {\n    "Cupressales": "Conifers II"\n  }\n]',
#  '[\n  {\n    "optical quality": "quality related to the interaction of a substance with electromagnetic radiation"\n  }\n]',
#  '[\n  {\n    "Liliopsida": "Mesangiospermae"\n  }\n]',
#  '[\n  {\n    "visible spectrum radiation emitted by a manufactured product": "radiation emitted by manufactured products"\n  }\n]',
#  '[\n  {\n    "EC 3.5.1.4 (amidase) inhibitor": "EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor"\n  }\n]',
#  '[\n  {\n    "Schistocerca": "subfamily Cyrtacanthacridinae"\n  }\n]',
#  '[\n  {\n    "quarrying": "Terrestrial mining"\n  },\n  {\n    "opencast mining": "Terrestrial mining"\n  }\n]',
#  '[\n  {\n    "Dicondylia": "insect"\n  }\n]',
#  '[\n  {\n    "forestry": "land use processes"\n  },\n  {\n    "terrestrial mining": "land use processes"\n  },\n  {\n    "agriculture": "land use processes"\n  }\n]',
#  '[\n  {\n    "land fire": "wildfire"\n  }\n]',
#  '[\n  {\n    "Mammalia": "Amniota"\n  }\n]',
#  '[\n  {\n    "land conversion process": "land consumption process"\n  }\n]',
#  '[\n  {\n    "opaque": "opacity"\n  },\n  {\n    "transparent": "opacity"\n  },\n  {\n    "translucent": "opacity"\n  }\n]',
#  '[\n  {\n    "marine tidal flow process": "tidal flow process"\n  }\n]',
#  '[\n  {\n    "Bora": "fall wind"\n  }\n]',
#  '[\n  {\n    "depth": "one-dimensional extent"\n  }\n]',
#  '[\n  {\n    "particle radiation": "Radiation"\n  },\n  {\n    "electromagnetic radiation": "Radiation"\n  },\n  {\n    "acoustic radiation": "Radiation"\n  },\n  {\n    "particle beam radiation": "Particle radiation"\n  },\n  {\n    "stellar radiation": "Electromagnetic radiation"\n  },\n  {\n    "radiation emitted by manufactured products": "Electromagnetic radiation"\n  },\n  {\n    "shortwave radiation": "Electromagnetic radiation"\n  },\n  {\n    "microwave": "Electromagnetic radiation"\n  },\n  {\n    "radio wave": "Electromagnetic radiation"\n  },\n  {\n    "infrared": "Electromagnetic radiation"\n  },\n  {\n    "visible spectrum": "Electromagnetic radiation"\n  },\n  {\n    "ultraviolet": "Electromagnetic radiation"\n  },\n  {\n    "ionizing radiation": "Electromagnetic radiation"\n  },\n  {\n    "Photosynthetically active radiation": "Electromagnetic radiation"\n  },\n  {\n    "infrasound": "Acoustic radiation"\n  },\n  {\n    "ultrasound radiation": "Acoustic radiation"\n  },\n  {\n    "insolation": "Radiation"\n  }\n]',
#  '[\n  {\n    "Atmospheric aerosol formation": "aerosol formation process"\n  },\n  {\n    "pyrolysis": "aerosol formation process"\n  },\n  {\n    "fires": "Combustion processes"\n  },\n  {\n    "explosion processes": "Combustion processes"\n  }\n]',
#  '[\n  {\n    "misaligned towards": "misaligned with"\n  },\n  {\n    "misaligned away from": "misaligned with"\n  }\n]',
#  '[\n  {\n    "Sauria": "Sauropsida"\n  }\n]',
#  '[\n  {\n    "radiation reflective quality": "full-spectrum electromagnetic (EM) radiation quality"\n  }\n]',
#  '[\n  {\n    "Pinopsida": "Acrogymnospermae"\n  }\n]',
#  '[\n  {\n    "marine tidal flow process": "tidal flow process"\n  }\n]',
#  '[\n  {\n    "width": "one-dimensional extent"\n  }\n]',
#  '[\n  {\n    "Orthoptera": "Polyneoptera"\n  },\n  {\n    "grasshoppers and crickets": "Orthoptera"\n  },\n  {\n    "Polyneoptera": "insects"\n  },\n  {\n    "earwigs": "Polyneoptera"\n  }\n]',
#  '[\n  {\n    "Avicennia germinans": "Avicennia"\n  }\n]',
#  '[\n  {\n    "electron-transport chain inhibitor": "pathway inhibitor"\n  }\n]',
#  '[\n  {\n    "Hexapoda": "Pancrustacea"\n  }\n]',
#  '[\n  {\n    "Archelosauria": "Sauria"\n  }\n]',
#  '[\n  {\n    "foehn wind": "downslope katabatic wind"\n  },\n  {\n    "drainage wind": "downslope katabatic wind"\n  },\n  {\n    "glacier wind": "drainage wind"\n  }\n]',
#  '[\n  {\n    "color": "optical quality"\n  }\n]',
#  '[\n  {\n    "Homo sapiens": "Homo"\n  }\n]',
#  '[\n  {\n    "Soil albedo": "albedo"\n  }\n]',
#  '[\n  {\n    "P450 inhibitors": "EC 1.14.14.1 inhibitor"\n  }\n]',
#  '[\n  {\n    "combustion processes": "thermolysis"\n  },\n  {\n    "pyrolysis": "thermolysis"\n  }\n]',
#  '[\n  {\n    "Anthropisation": "anthropogenic ecosystem conversion process"\n  }\n]',
#  '[\n  {\n    "flush": "position"\n  },\n  {\n    "continuous with": "position"\n  },\n  {\n    "normal position": "position"\n  }\n]',
#  '[\n  {\n    "Benthic deep-sea mining": "marine mining"\n  },\n  {\n    "sea bed mining": "marine mining"\n  }\n]',
#  '[\n  {\n    "katabatic wind": "atmospheric winds"\n  },\n  {\n    "downslope katabatic wind": "katabatic wind"\n  },\n  {\n    "cooling-driven katabatic wind": "katabatic wind"\n  },\n  {\n    "fall wind": "katabatic wind"\n  },\n  {\n    "downdraft": "katabatic wind"\n  },\n  {\n    "squall wind": "atmospheric winds"\n  },\n  {\n    "jet-effect wind": "atmospheric winds"\n  },\n  {\n    "slope flow": "atmospheric winds"\n  },\n  {\n    "anabatic wind": "slope flow"\n  },\n  {\n    "straight-line wind": "atmospheric winds"\n  },\n  {\n    "wind gust": "atmospheric winds"\n  },\n  {\n    "monsoon wind": "atmospheric winds"\n  },\n  {\n    "mountain-gap wind": "jet-effect wind"\n  }\n]',
#  '[\n  {\n    "antiseptic drug": "antiinfective agent"\n  }\n]',
#  '[\n  {\n    "atmospheric aerosolised particle formation event": "aerosolised particle formation event"\n  }\n]',
#  '[\n  {\n    "Drainage wind": "cooling-driven katabatic wind"\n  }\n]',
#  '[\n  {\n    "EC 1.14.14.* inhibitor": "EC 1.14.* inhibitors"\n  }\n]',
#  '[\n  {\n    "Gamma-ray stellar radiation": "gamma-ray radiation"\n  }\n]',
#  '[\n  {\n    "Pentapetalae": "Gunneridae"\n  }\n]',
#  '[\n  {\n    "antiinfective agent": "drug"\n  },\n  {\n    "analgesic": "drug"\n  },\n  {\n    "Cardiovascular drug": "drug"\n  },\n  {\n    "Anaesthetic": "drug"\n  },\n  {\n    "general anaesthetic": "Anaesthetic"\n  }\n]',
#  '[\n  {\n    "Luminous flux": "optical quality"\n  }\n]',
#  '[\n  {\n    "Atmospheric wind speed": "speed"\n  },\n  {\n    "speed of a water current": "speed"\n  },\n  {\n    "speed at which water infiltrates the soil": "speed"\n  },\n  {\n    "speed at which soil drains water": "speed"\n  },\n  {\n    "increased speed": "speed"\n  },\n  {\n    "decreased speed": "speed"\n  },\n  {\n    "sound speed": "speed"\n  },\n  {\n    "normal speed": "speed"\n  }\n]',
#  '[\n  {\n    "Biotransformation of coal": "biotransformation process"\n  },\n  {\n    "microbial enhanced oil recovery": "biotransformation process"\n  },\n  {\n    "microbial solubization of coal": "biotransformation process"\n  },\n  {\n    "biotransformation of biomass into mixed alcohols": "biotransformation process"\n  }\n]',
#  '[\n  {\n    "Saurischia": "Dinosauria"\n  }\n]',
#  '[\n  {\n    "Modiolinae": "Mytilidae"\n  }\n]',
#  '[\n  {\n    "width of a river": "width"\n  },\n  {\n    "width of a road": "width"\n  },\n  {\n    "width of a habitat": "width"\n  },\n  {\n    "increased width": "width"\n  },\n  {\n    "decreased width": "width"\n  },\n  {\n    "normal width": "width"\n  }\n]',
#  '[\n  {\n    "asterids": "Pentapetalae"\n  }\n]',
#  '[\n  {\n    "blizzard": "snowstorm"\n  },\n  {\n    "lake-effect snow storm": "snowstorm"\n  }\n]',
#  '[\n  {\n    "Gunneridae": "eudicotyledons"\n  }\n]',
#  '[\n  {\n    "extra-tropical cyclone": "warm core cyclone"\n  }\n]',
#  '[\n  {\n    "EC 1.* (oxidoreductase) inhibitors": "enzyme inhibitors"\n  },\n  {\n    "Oxidoreductases": "enzymes"\n  }\n]',
#  '[\n  {\n    "Arecales": "commelinids"\n  },\n  {\n    "commelinids": "monocotyledons"\n  }\n]',
#  '[\n  {\n    "Petrosaviidae": "Liliopsida"\n  }\n]',
#  '[\n  {\n    "X-ray stellar radiation": "X-ray radiation"\n  }\n]',
#  '[\n  {\n    "Gnathostomata": "Vertebrata"\n  }\n]',
#  '[\n  {\n    "decreased volume": "decreased size"\n  },\n  {\n    "decreased depth": "decreased size"\n  },\n  {\n    "decreased thickness": "decreased size"\n  },\n  {\n    "decreased length": "decreased size"\n  },\n  {\n    "decreased width": "decreased size"\n  },\n  {\n    "decreased perimeter": "decreased length"\n  },\n  {\n    "decreased area": "decreased size"\n  }\n]']

# %%
term2docs_mapping_test = {}
term2types_mapping_test = {}
for ans in final_ans:
    ans_dict = json.loads(ans)
    for term_type in ans_dict:
        for term, type in term_type.items():
            if term not in term2types_mapping_test.keys():
                term2types_mapping_test[term]=[type]
            else:
                term2types_mapping_test[term].append(type)
term2types_mapping_test
# Out:
# {'certain types of rock': ['permeable materials'],
#  'soil': ['permeable materials'],
#  'clay': ['impermeable materials'],
#  'solid rock': ['impermeable materials'],
#  'carbon dioxide pooling disposition': ['carbon pooling disposition'],
#  'respiratory electron transport chain': ['electron transport chain'],
#  'amplitude of temperature of air': ['amplitude'],
#  'Toxin': ['metabolite'],
#  'eukaryotic metabolites': ['metabolite'],
#  'animal metabolites': ['eukaryotic metabolites'],
#  'fungal metabolites': ['eukaryotic metabolites'],
#  'prokaryotic metabolites': ['metabolite'],
#  'flat': ['landform'],
#  'the cooling of solids': ['material cooling process'],
#  'the cooling of fluids': ['material cooling process'],
#  'Inorganic macronutrients that are dissolved in ocean water': ['macronutrient'],
#  'concentration of carbon atoms in seawater': ['carbon atom concentrations found in water',
#   'carbon atom concentrations found in water'],
#  'protic solvent': ['polar solvent', 'polar solvent'],
#  'megathrust earthquake': ['tectonic earthquake'],
#  'foreshock': ['tectonic earthquake'],
#  'mainshock': ['tectonic earthquake'],
#  'aftershock': ['tectonic earthquake'],
#  'blind thrust earthquake': ['tectonic earthquake'],
#  'Multiplet earthquake': ['tectonic earthquake'],
#  'interplate earthquake': ['tectonic earthquake'],
#  'intraplate earthquake': ['tectonic earthquake'],
#  'carbon-bearing gas emission processes': ['hydrocarbon gas emission processes'],
#  'carbon dioxide emission processes': ['carbon-bearing gas emission processes'],
#  'methane gas emission processes': ['hydrocarbon gas emission processes'],
#  'lumber production process': ['planetary manufacturing processes'],
#  'lumber production': ['planetary manufacturing process'],
#  'food propellants': ['propellant'],
#  'hollow': ['type of structure'],
#  'nilas formation process': ['sea ice formation processes'],
#  'young ice formation process': ['sea ice formation processes'],
#  'first year ice formation process': ['sea ice formation processes'],
#  'second year ice formation': ['sea ice formation processes'],
#  'multiyear ice formation process': ['sea ice formation processes'],
#  'Methane metabolic process': ['alkane metabolic process'],
#  'alpine': ['altitudinal conditions'],
#  'subalpine': ['altitudinal conditions'],
#  'montane': ['altitudinal conditions'],
#  'nival': ['altitudinal conditions'],
#  'anaerobic respiration where ammonium acts as the electron donor': ['ammonia oxidation'],
#  'aerobic respiration that utilizes ammonia as the electron donor': ['ammonia oxidation'],
#  'tripartite': ['branched system'],
#  'Ditrysia': ['Heteroneura', 'Lepidoptera order'],
#  'Heteroneura': ['Lepidoptera'],
#  "Purine ribonucleoside 5'-triphosphate": ["ribonucleoside 5'-triphosphate",
#   "ribonucleoside 5'-triphosphate",
#   "ribonucleoside 5'-triphosphate"],
#  'Daphnia metabolite': ['crustacean metabolite'],
#  'feeding behavior': ['behavior'],
#  'Water infiltration into soil': ['water infiltration process'],
#  'dissolved carbon atom within environmental materials': ['dissolved substance'],
#  'volcanic seismic vibration': ['seismic vibration processes'],
#  'impact-driven seismic vibration': ['seismic vibration processes'],
#  'explosion-driven seismic vibration': ['seismic vibration processes'],
#  'mass-wasting-driven seismic vibration': ['seismic vibration processes'],
#  'collapse-driven seismic vibration': ['seismic vibration processes'],
#  'earthquake-driven seismic vibration': ['seismic vibration processes'],
#  'Bacterial metabolites': ['prokaryotic metabolites'],
#  'weathering of plastic': ['weathering process'],
#  'photosynthetic photon flux': ['flux'],
#  'pieces of animal': ['animal material'],
#  'fluid flow rate': ['flow rate'],
#  'Oscillatoria': ['Oscillatoriaceae'],
#  'Phormidium': ['Oscillatoriaceae'],
#  'an impact between astronomical bodies': ['impact event', 'impact event'],
#  'biomarker': ['indicator'],
#  'electron donor': ['donor'],
#  'Bronsted acids': ['donor'],
#  'Lewis bases': ['donor'],
#  'oceanic temperate': ['temperate'],
#  'continental temperate': ['temperate'],
#  'Obtectomera': ['Ditrysia'],
#  'concentration of carbon-13 atoms in sea water': ['concentration of carbon atoms in sea water'],
#  'concentration of carbon-14 atoms in sea water': ['concentration of carbon atoms in sea water'],
#  'piece of cow': ['piece of animal', 'piece of animal'],
#  'Radioactivity': ['activity'],
#  'curled': ['shape'],
#  'undulate': ['shape'],
#  'elongated': ['shape'],
#  'linear': ['shape'],
#  'filamentous': ['shape'],
#  'curved': ['curvature'],
#  'flattened': ['curvature'],
#  'sloped': ['direction or orientation'],
#  'sloped downward': ['sloped'],
#  'lobate': ['surface feature shape'],
#  'sculpted surface': ['surface feature shape'],
#  'ornamentation': ['surface feature shape'],
#  'oblong': ['2-D shapes'],
#  'fan-shaped': ['2-D shapes'],
#  'superelliptic': ['2-D shapes'],
#  'convex': ['3-D shapes'],
#  'concave 3-D shapes': ['3-D shapes'],
#  'V-shaped': ['angular'],
#  'concave': ['concavity'],
#  'branched structures': ['branchiness'],
#  'columnar': ['shape'],
#  'drooping': ['shape'],
#  'straight': ['shape'],
#  'slender': ['shape'],
#  'falciform': ['shape'],
#  'fringed': ['Edge shapes'],
#  'fimbriated': ['shape'],
#  'tholiform': ['shape'],
#  'broad': ['shape'],
#  'funnel-shaped': ['shape'],
#  'radiating': ['shape'],
#  'plume-shaped': ['shape'],
#  'Daphnia magna metabolite': ['Daphnia metabolite'],
#  'dissolved carbon atom in soil': ['solubility of carbon atoms within the soil matrix'],
#  'aerobic sensitivity to oxygen': ['sensitivity to oxygen'],
#  'anaerobic sensitivity': ['sensitivity to oxygen'],
#  'Soil bulk density': ['mass density of soil'],
#  'increased rate of occurrence': ['rate of occurrence',
#   'rate of occurrence',
#   'increased rate',
#   'increased rate'],
#  'spherical': ['spheroid'],
#  'increased frequency': ['increased rate of occurrence', 'frequency'],
#  'Cow material': ['animal material'],
#  'CHEBI_15422': ["adenosine 5'-phosphate"],
#  'Sporadic occurrences': ['occurrences'],
#  'continuous occurrences': ['occurrences'],
#  'discontinuous occurrences': ['occurrences'],
#  'arched shape': ['concave shape'],
#  'meteorite impact': ['impact that occurs between astronomical bodies'],
#  'crustacean metabolite': ['animal metabolite'],
#  'Aerobic respiration': ['cellular respiration'],
#  'domed': ['curved'],
#  'transpiration': ['water cooling mechanism'],
#  'Stellar radiation energy': ['radiant energy'],
#  'Generation of precursor metabolites and energy': ['metabolic process'],
#  'biosynthetic process': ['metabolic process'],
#  'photosynthesis': ['metabolic process'],
#  'small molecule metabolic process': ['metabolic process'],
#  'hydrocarbon metabolic process': ['metabolic process'],
#  'energy derivation by oxidation of reduced inorganic compounds': ['generation of precursor metabolites and energy'],
#  'energy derivation by oxidation of organic compounds': ['generation of precursor metabolites and energy'],
#  'electron transport chain': ['generation of precursor metabolites and energy'],
#  'hydrocarbon biosynthetic process': ['biosynthetic process',
#   'hydrocarbon metabolic process'],
#  'ammonia oxidation': ['small molecule metabolic process'],
#  'alkane metabolic process': ['hydrocarbon metabolic process'],
#  'adenosine phosphate': ['adenyl ribonucleotide'],
#  "guanosine 5'-phosphate": ['guanosine phosphate'],
#  'composition of soil': ['composition'],
#  'composition of water': ['composition'],
#  'being calcified': ['composition'],
#  'granular': ['composition'],
#  'CHEBI_15996': ["guanosine 5'-phosphate"],
#  'Geothermal energy': ['thermal energy'],
#  'circular shape': ['elliptic shape'],
#  'Fudge': ['soft candy'],
#  'alkane biosynthetic process': ['hydrocarbon biosynthetic process',
#   'alkane metabolic process',
#   'hydrocarbon biosynthetic process',
#   'alkane metabolic process'],
#  'dissolved nitrogen atoms present in soil': ['types of dissolved nitrogen atoms in environmental materials'],
#  'dissolved nitrogen atoms present in water': ['types of dissolved nitrogen atoms in environmental materials'],
#  'being detached from': ['attachment quality'],
#  'refinement process': ['chemical engineering process'],
#  'Haber-Bosch process': ['chemical engineering process'],
#  'hydrogen production process': ['chemical engineering process'],
#  'Animal material': ['organism material'],
#  'aerobic respiration using nitrite': ['Aerobic Respiration'],
#  'aerobic respiration using ammonia': ['Aerobic Respiration'],
#  'aerobic respiration using carbon monoxide': ['Aerobic Respiration'],
#  'aerobic respiration using ferrous ions': ['Aerobic Respiration'],
#  'aerobic respiration using hydrogen': ['Aerobic Respiration'],
#  'aerobic respiration using sulfur or sulfate': ['Aerobic Respiration'],
#  'aerobic respiration using arsenite': ['Aerobic Respiration'],
#  'aerobic electron transport chain': ['Aerobic Respiration',
#   'respiratory electron transport chain'],
#  'Propane-1,2-diol': ['propane-1,2-diols'],
#  'sound wave energy': ['Mechanical wave energy'],
#  'wind wave energy': ['Mechanical wave energy'],
#  'humidity of soil': ['humidity'],
#  'increased humidity': ['humidity'],
#  'decreased humidity': ['humidity'],
#  'mammalian metabolite': ['animal metabolite'],
#  'biodegradation of plastic': ['biodegradation'],
#  'obtuse shape': ['circular or rounded form'],
#  'human metabolite': ['mammalian metabolite'],
#  'Beef': ['meat'],
#  'piece of beef': ['piece of cow'],
#  'glacial abrasion': ['glacial erosion processes'],
#  'glacial plucking': ['glacial erosion processes'],
#  'glacial ice thrusting': ['glacial erosion processes'],
#  'increased accumulation': ['accumulation'],
#  'decreased accumulation': ['accumulation'],
#  'irradiation by ionizing radiation': ['Irradiation'],
#  'irradiation by non-ionizing radiation': ['Irradiation'],
#  'photosynthetically active radiation': ['non-ionizing radiation'],
#  'freezing of water into ice': ['freezing process'],
#  'adfreezing': ['freezing'],
#  'dissolved carbon atoms in soil': ['dissolved carbon atoms in environmental materials'],
#  'dissolved carbon atoms in water': ['dissolved carbon atoms in environmental materials'],
#  'sea surface temperature': ['water temperature'],
#  'Mutagens': ['genotoxin'],
#  'Guanosine phosphate': ['guanyl ribonucleotide'],
#  'upper montane': ['montane region'],
#  'lower montane': ['montane region'],
#  "Adenosine 5'-phosphate": ['adenosine phosphate'],
#  'coastal flooding': ['flooding'],
#  'storm surges': ['coastal flooding'],
#  'riverine flooding': ['flooding'],
#  'flash flooding': ['flooding'],
#  'areal flooding': ['flooding'],
#  'urban flooding': ['flooding'],
#  'amphiprotic solvent': ['protophilic solvent'],
#  'micronutrients': ['nutrients'],
#  'macronutrients': ['nutrients'],
#  'frequency': ['rate of occurrence'],
#  'dissolved carbon atom': ['dissolved substance'],
#  'Dinophyceae': ['Alveolata'],
#  'piece(s) of cow': ['cow material', 'cow material'],
#  'protophilic solvent': ['polar solvent',
#   'Bronsted base',
#   'polar solvent',
#   'Bronsted base'],
#  'Frazil ice formation': ['new ice formation processes'],
#  'slush formation': ['new ice formation processes'],
#  'shuga formation': ['new ice formation processes'],
#  'Ingestion': ['eating behavior'],
#  'oceanic transient tracer': ['transient tracer'],
#  'Hydraulic fracturing': ['well stimulation'],
#  'Atmospheric wind direction': ['direction'],
#  'down': ['relative terms'],
#  'left': ['relative terms'],
#  'right': ['relative terms'],
#  'front': ['relative terms'],
#  'back': ['relative terms'],
#  'unidirectional': ['direction'],
#  'bi-directional': ['direction'],
#  'circling direction': ['direction'],
#  'north': ['cardinal directions', 'cardinal direction'],
#  'south': ['cardinal directions', 'cardinal direction'],
#  'east': ['cardinal directions', 'cardinal direction'],
#  'west': ['cardinal directions', 'cardinal direction'],
#  'Oscillatoriaceae': ['family'],
#  'Oscillatoriales': ['order'],
#  'submarine groundwater discharge process': ['groundwater discharge process'],
#  'excitatory amino acid antagonist': ['antagonist'],
#  'excitatory amino acids': ['neurotransmitter'],
#  'muskmelon (Cucumis melo) fruit food product': ['melon fruit food product'],
#  'cantaloupe fruit food product': ['muskmelon (Cucumis melo) fruit food product'],
#  'citrullus lanatus fruit food product': ['melon fruit food product'],
#  'periglacial process': ['frost action process'],
#  'cryoturbation of soil': ['frost action process'],
#  'frost jacking': ['cryoturbation of soil'],
#  'frost sorting': ['cryoturbation of soil'],
#  'frost wedging': ['cryoturbation of soil'],
#  'frost heaving': ['cryoturbation of soil'],
#  'concentration of nitrite in sea water': ['concentration of nitrite found in liquid water'],
#  'Methanogenesis': ['alkane biosynthetic process'],
#  'elliptic shape': ['superelliptic shape'],
#  'soil erosion': ['planetary erosion'],
#  'bedrock dissolution': ['planetary erosion'],
#  'glacial erosion processes': ['planetary erosion'],
#  'erosion through nivation': ['planetary erosion'],
#  'raising agent': ['food additive'],
#  'food packaging gas': ['food additive'],
#  'food propellant': ['food additive'],
#  'atmosphere-ocean momentum transfer process': ['momentum transfer process'],
#  'the concentration of nitrate in groundwater': ['concentration of nitrate in liquid water'],
#  'the concentration of nitrate in sea water': ['concentration of nitrate in liquid water'],
#  'atmospheric weather': ['weather'],
#  'space weather': ['weather'],
#  'ice-bearing permafrost thawing process': ['permafrost thawing process'],
#  'concentration of silicic acid in sea water': ['concentration of silicic acid found in liquid water'],
#  'spheroid': ['convex 3-D shape'],
#  'cylindrical shape': ['convex 3-D shape'],
#  'conical shape': ['convex 3-D shape'],
#  'eating behavior': ['feeding behavior'],
#  'glucosamines': ['hexosamine'],
#  'agronomic process': ['agricultural process'],
#  'animal husbandry': ['agricultural process'],
#  'Mediterranean climate': ['subtropical'],
#  'humid subtropical': ['subtropical'],
#  'arid subtropical': ['subtropical'],
#  'highland subtropical': ['subtropical'],
#  'road traffic noise': ['noise'],
#  'aircraft noise': ['noise'],
#  'decreased frequency': ['frequency'],
#  'temperature of air': ['temperature of environmental material'],
#  'temperature of soil': ['temperature of environmental material'],
#  'temperature of water': ['temperature of environmental material'],
#  'Amphiesmenoptera': ['Endopterygota'],
#  'glacial surface layer velocity': ['velocity'],
#  'angular velocity': ['velocity'],
#  'increased velocity': ['velocity'],
#  'decreased velocity': ['velocity'],
#  'normal velocity': ['velocity'],
#  'increased fluid flow': ['fluid flow rates'],
#  'decreased fluid flow': ['fluid flow rates'],
#  'aerosolised particle formation events': ['aerosolised particle formation processes',
#   'aerosolised particle formation processes'],
#  'Mollusca': ['Lophotrochozoa'],
#  'Caelifera': ['Orthoptera'],
#  'crickets': ['Orthoptera'],
#  'katydids': ['Orthoptera'],
#  'Pinidae': ['Pinopsida'],
#  'biodiversity conservation process': ['conservation-focused active ecosystem management process'],
#  'Fluorescence of water': ['fluorescence'],
#  'macroburst': ['downburst'],
#  'Haplorrhini': ['primates'],
#  'thickness of snow': ['thickness'],
#  'thickness of topsoil': ['thickness'],
#  'increased thickness': ['thickness'],
#  'decreased thickness': ['thickness', 'decreased size'],
#  'irregular thickness': ['thickness'],
#  'decreased circumference': ['circumference'],
#  'Laguncularia racemosa': ['Laguncularia'],
#  'Conifers II': ['Pinidae'],
#  'Soil albedo': ['albedo', 'albedo'],
#  'forest fires': ['types of land fires'],
#  'brush fires': ['types of land fires'],
#  'bush fires': ['types of land fires'],
#  'grass fires': ['types of land fires'],
#  'pasture fires': ['grass fires'],
#  'Archosauria': ['Archelosauria'],
#  'color': ['optical quality', 'optical quality'],
#  'patchy pattern': ['irregular spatial patterns'],
#  'aggregated pattern': ['irregular spatial patterns'],
#  'trabecular pattern': ['irregular spatial patterns'],
#  'defence against flooding': ['anthropogenic modulatory intervention'],
#  'conservation-focused active ecosystem management': ['Active ecosystem management processes'],
#  'active agri-ecosystem management': ['Active ecosystem management processes'],
#  'planned revegetation': ['Active ecosystem management processes'],
#  'pollution degradation': ['anthropogenic modulation of pollution'],
#  'pollution control': ['anthropogenic modulation of pollution'],
#  'Eudicotyledons': ['Mesangiospermae'],
#  'Dipnotetrapodomorpha': ['Sarcopterygii'],
#  'the process of forming a liquid aerosol from gaseous material within an atmospheric context': ['formation of liquid aerosols that occurs in the atmosphere'],
#  'respiratory-chain inhibitor': ['electron-transport chain inhibitor'],
#  'Pteriomorphia': ['Autobranchia'],
#  'Locusta migratoria': ['Locusta'],
#  'volume of hydrological precipitation': ['type of volume'],
#  'volume of runoff': ['type of volume'],
#  'volume of evaporation': ['type of volume'],
#  'volume of evapotranspiration': ['type of volume'],
#  'volume of rain': ['type of volume'],
#  'ionizing stellar radiation': ['types of ionizing radiation',
#   'stellar radiation'],
#  'X-ray radiation': ['types of ionizing radiation'],
#  'gamma-ray radiation': ['types of ionizing radiation'],
#  'Sarcopterygii': ['Euteleostomi'],
#  'Elaeis guineensis': ['Elaeis genus'],
#  'perimeter': ['one-dimensional extent'],
#  'inhalation anaesthetic': ['general anaesthetic'],
#  'visible spectrum stellar radiation': ['visible spectrum radiation'],
#  'lamiids': ['asterids'],
#  'WMO blizzard': ['type of blizzard'],
#  'winter blizzard': ['type of blizzard'],
#  'Mytilus': ['subfamily Mytilinae'],
#  'land conversion process': ['land consumption process',
#   'land consumption process',
#   'land consumption process'],
#  'influenced by': ['quality'],
#  'dispositional property': ['quality'],
#  'young': ['Age-related qualities'],
#  'chronological age': ['quality'],
#  'Avicennia': ['Avicennioideae'],
#  'Volume': ['3-D extent'],
#  'Autobranchia': ['Bivalvia'],
#  'clams': ['Bivalvia'],
#  'mussels': ['Bivalvia'],
#  'oysters': ['Bivalvia'],
#  'scallops': ['Bivalvia'],
#  'increased area': ['area'],
#  'decreased area': ['area', 'decreased size'],
#  'normal area': ['area'],
#  'butter product analog': ['milk or milk product analog'],
#  'mass gaseous flow': ['mass fluid flow'],
#  'mass liquid flow': ['mass fluid flow'],
#  'mass plasma flow': ['mass fluid flow'],
#  'atmospheric wind': ['mass gaseous flow'],
#  'planetary wind': ['mass gaseous flow'],
#  'tsunami': ['mass liquid flow'],
#  'lava flow': ['mass liquid flow'],
#  'tidal flow': ['mass liquid flow'],
#  'stellar wind': ['mass plasma flow'],
#  'Cyclonic circulation': ['mass fluid flow'],
#  'Snow water equivalent': ['depth'],
#  'depth of water ice': ['depth'],
#  'top depths of soil layers': ['depth'],
#  'bottom depths of soil layers': ['depth'],
#  'depth of snow': ['depth'],
#  'depth of water': ['depth'],
#  'decreased depth': ['depth', 'decreased size'],
#  'increased depth': ['depth'],
#  'normal depth': ['depth'],
#  'hydrocarbon bioremediation': ['Bioremediation'],
#  'metal bioremediation': ['Bioremediation'],
#  'treatment of persistent organic pollutants': ['Bioremediation'],
#  'color patterns': ['Spatial pattern'],
#  'irregular spatial patterns': ['Spatial pattern'],
#  'regular spatial patterns': ['Spatial pattern'],
#  'unilateral patterns': ['Spatial pattern'],
#  'distributed patterns': ['Spatial pattern'],
#  'vertical arrangements': ['Spatial pattern'],
#  'stratification': ['Spatial pattern'],
#  'colorless': ['color pattern'],
#  'increased distribution': ['distributed patterns'],
#  'decreased distribution': ['distributed patterns'],
#  'stratified': ['stratification'],
#  'warm core cyclone': ['cyclones'],
#  'quality of full-spectrum electromagnetic radiation': ['quality related to the interaction of substances with electromagnetic radiation'],
#  'microburst': ['downburst'],
#  'radio wave stellar radiation': ['radio wave radiation'],
#  'permafrost methane explosion': ['explosion process'],
#  'crustacean farming processes': ['animal aquaculture processes'],
#  'finfish farming processes': ['animal aquaculture processes'],
#  'mollusc farming processes': ['animal aquaculture processes'],
#  'diurnal marine tidal flow process': ['marine tidal flow processes'],
#  'semi-diurnal marine tidal flow process': ['marine tidal flow processes'],
#  'Solar radiation': ['stellar radiation'],
#  'microwave': ['stellar radiation', 'Electromagnetic radiation'],
#  'radio wave': ['stellar radiation', 'Electromagnetic radiation'],
#  'infrared': ['stellar radiation', 'Electromagnetic radiation'],
#  'visible spectrum': ['stellar radiation', 'Electromagnetic radiation'],
#  'ultraviolet': ['stellar radiation', 'Electromagnetic radiation'],
#  'X-ray stellar radiation': ['Ionizing stellar radiation', 'X-ray radiation'],
#  'gamma-ray stellar radiation': ['Ionizing stellar radiation'],
#  'Anthropisation': ['anthropogenic ecosystem conversion process',
#   'anthropogenic ecosystem conversion process',
#   'anthropogenic ecosystem conversion process'],
#  'Echinozoa': ['Eleutherozoa'],
#  'pathway inhibitor': ['enzyme inhibitor'],
#  'increased length': ['length'],
#  'decreased length': ['length', 'decreased size'],
#  'Schistocerca gregaria': ['Schistocerca'],
#  'seaweed farming': ['plant aquaculture processes'],
#  'freshwater macrophyte farming': ['plant aquaculture processes'],
#  'afforestation': ['planned revegetation'],
#  'reforestation': ['planned revegetation'],
#  'Theropoda': ['Saurischia'],
#  'intercloud lightning': ['lightning flashes'],
#  'intracloud lightning': ['lightning flashes'],
#  'Microwave stellar radiation': ['microwave radiation'],
#  'thunderstorm': ['convective storm'],
#  'Salicornia subgen. Amerocornia': ['Salicornia'],
#  'Arthropoda': ['Panarthropoda'],
#  'increased perimeter': ['increased length', 'perimeter'],
#  'dry macrobursts': ['macrobursts'],
#  'wet macrobursts': ['macrobursts'],
#  'thickness': ['one-dimensional extent'],
#  'thickness of ice caps': ['one-dimensional extent'],
#  'thickness of a particular layer of soil': ['one-dimensional extent'],
#  'Hominoidea': ['Catarrhini'],
#  'direct transformation of gaseous materials into solid particles': ['solid aerosol formation in the atmosphere'],
#  'formation of solid aerosols from liquid materials present in the atmosphere': ['solid aerosol formation'],
#  'glaciation of water droplets within clouds': ['formation of solid aerosols from liquid materials present in the atmosphere'],
#  'Opacity': ['optical quality'],
#  'Dry soil albedo': ['soil albedo'],
#  'moist soil albedo': ['soil albedo'],
#  'color of the soil': ['color'],
#  'blue': ['color'],
#  'white': ['color'],
#  'brown': ['color'],
#  'downburst': ['downdraft', 'downdraft'],
#  'wet microbursts': ['microbursts'],
#  'dry microbursts': ['microbursts'],
#  'infrared stellar radiation': ['infrared radiation'],
#  'outgoing longwave radiation': ['infrared radiation'],
#  'mid-infrared radiation': ['infrared radiation'],
#  'near-infrared radiation': ['infrared radiation'],
#  'far-infrared radiation': ['infrared radiation'],
#  'Laguncularia': ['plant'],
#  'circumference': ['perimeter'],
#  'decreased perimeter': ['perimeter', 'decreased length'],
#  'acidic': ['medium acidity'],
#  'alkaline': ['medium acidity'],
#  'Arecaceae': ['Arecales'],
#  'Acridomorpha': ['Acrididea'],
#  'Land fire': ['Wildfire'],
#  'conflagration': ['Fire'],
#  'industrial fire': ['Fire'],
#  'planned burn': ['Fire'],
#  'wildfire': ['conflagration'],
#  'Theria': ['Mammalia'],
#  'length': ['one-dimensional (1-D) extent'],
#  'Cupressales': ['Conifers II'],
#  'optical quality': ['quality related to the interaction of a substance with electromagnetic radiation'],
#  'Liliopsida': ['Mesangiospermae'],
#  'visible spectrum radiation emitted by a manufactured product': ['radiation emitted by manufactured products'],
#  'EC 3.5.1.4 (amidase) inhibitor': ['EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor'],
#  'Schistocerca': ['subfamily Cyrtacanthacridinae'],
#  'quarrying': ['Terrestrial mining'],
#  'opencast mining': ['Terrestrial mining'],
#  'Dicondylia': ['insect'],
#  'forestry': ['land use processes'],
#  'terrestrial mining': ['land use processes'],
#  'agriculture': ['land use processes'],
#  'land fire': ['wildfire'],
#  'Mammalia': ['Amniota'],
#  'opaque': ['opacity'],
#  'transparent': ['opacity'],
#  'translucent': ['opacity'],
#  'marine tidal flow process': ['tidal flow process', 'tidal flow process'],
#  'Bora': ['fall wind'],
#  'depth': ['one-dimensional extent'],
#  'particle radiation': ['Radiation'],
#  'electromagnetic radiation': ['Radiation'],
#  'acoustic radiation': ['Radiation'],
#  'particle beam radiation': ['Particle radiation'],
#  'stellar radiation': ['Electromagnetic radiation'],
#  'radiation emitted by manufactured products': ['Electromagnetic radiation'],
#  'shortwave radiation': ['Electromagnetic radiation'],
#  'ionizing radiation': ['Electromagnetic radiation'],
#  'Photosynthetically active radiation': ['Electromagnetic radiation'],
#  'infrasound': ['Acoustic radiation'],
#  'ultrasound radiation': ['Acoustic radiation'],
#  'insolation': ['Radiation'],
#  'Atmospheric aerosol formation': ['aerosol formation process'],
#  'pyrolysis': ['aerosol formation process', 'thermolysis'],
#  'fires': ['Combustion processes'],
#  'explosion processes': ['Combustion processes'],
#  'misaligned towards': ['misaligned with'],
#  'misaligned away from': ['misaligned with'],
#  'Sauria': ['Sauropsida'],
#  'radiation reflective quality': ['full-spectrum electromagnetic (EM) radiation quality'],
#  'Pinopsida': ['Acrogymnospermae'],
#  'width': ['one-dimensional extent'],
#  'Orthoptera': ['Polyneoptera'],
#  'grasshoppers and crickets': ['Orthoptera'],
#  'Polyneoptera': ['insects'],
#  'earwigs': ['Polyneoptera'],
#  'Avicennia germinans': ['Avicennia'],
#  'electron-transport chain inhibitor': ['pathway inhibitor'],
#  'Hexapoda': ['Pancrustacea'],
#  'Archelosauria': ['Sauria'],
#  'foehn wind': ['downslope katabatic wind'],
#  'drainage wind': ['downslope katabatic wind'],
#  'glacier wind': ['drainage wind'],
#  'Homo sapiens': ['Homo'],
#  'P450 inhibitors': ['EC 1.14.14.1 inhibitor'],
#  'combustion processes': ['thermolysis'],
#  'flush': ['position'],
#  'continuous with': ['position'],
#  'normal position': ['position'],
#  'Benthic deep-sea mining': ['marine mining'],
#  'sea bed mining': ['marine mining'],
#  'katabatic wind': ['atmospheric winds'],
#  'downslope katabatic wind': ['katabatic wind'],
#  'cooling-driven katabatic wind': ['katabatic wind'],
#  'fall wind': ['katabatic wind'],
#  'downdraft': ['katabatic wind'],
#  'squall wind': ['atmospheric winds'],
#  'jet-effect wind': ['atmospheric winds'],
#  'slope flow': ['atmospheric winds'],
#  'anabatic wind': ['slope flow'],
#  'straight-line wind': ['atmospheric winds'],
#  'wind gust': ['atmospheric winds'],
#  'monsoon wind': ['atmospheric winds'],
#  'mountain-gap wind': ['jet-effect wind'],
#  'antiseptic drug': ['antiinfective agent'],
#  'atmospheric aerosolised particle formation event': ['aerosolised particle formation event'],
#  'Drainage wind': ['cooling-driven katabatic wind'],
#  'EC 1.14.14.* inhibitor': ['EC 1.14.* inhibitors'],
#  'Gamma-ray stellar radiation': ['gamma-ray radiation'],
#  'Pentapetalae': ['Gunneridae'],
#  'antiinfective agent': ['drug'],
#  'analgesic': ['drug'],
#  'Cardiovascular drug': ['drug'],
#  'Anaesthetic': ['drug'],
#  'general anaesthetic': ['Anaesthetic'],
#  'Luminous flux': ['optical quality'],
#  'Atmospheric wind speed': ['speed'],
#  'speed of a water current': ['speed'],
#  'speed at which water infiltrates the soil': ['speed'],
#  'speed at which soil drains water': ['speed'],
#  'increased speed': ['speed'],
#  'decreased speed': ['speed'],
#  'sound speed': ['speed'],
#  'normal speed': ['speed'],
#  'Biotransformation of coal': ['biotransformation process'],
#  'microbial enhanced oil recovery': ['biotransformation process'],
#  'microbial solubization of coal': ['biotransformation process'],
#  'biotransformation of biomass into mixed alcohols': ['biotransformation process'],
#  'Saurischia': ['Dinosauria'],
#  'Modiolinae': ['Mytilidae'],
#  'width of a river': ['width'],
#  'width of a road': ['width'],
#  'width of a habitat': ['width'],
#  'increased width': ['width'],
#  'decreased width': ['width', 'decreased size'],
#  'normal width': ['width'],
#  'asterids': ['Pentapetalae'],
#  'blizzard': ['snowstorm'],
#  'lake-effect snow storm': ['snowstorm'],
#  'Gunneridae': ['eudicotyledons'],
#  'extra-tropical cyclone': ['warm core cyclone'],
#  'EC 1.* (oxidoreductase) inhibitors': ['enzyme inhibitors'],
#  'Oxidoreductases': ['enzymes'],
#  'Arecales': ['commelinids'],
#  'commelinids': ['monocotyledons'],
#  'Petrosaviidae': ['Liliopsida'],
#  'Gnathostomata': ['Vertebrata'],
#  'decreased volume': ['decreased size']}

# %%
import json

# Save final_clusters_list to JSON file
with open("text_to_ontol_keyword_LLM_ecology.json", "w", encoding="utf-8") as f:
    json.dump(term2types_mapping_test, f, indent=2, ensure_ascii=False)

print("Clusters saved to final_clusters.json ✅")
# Out:
# Clusters saved to final_clusters.json ✅

# %%
len(test_data)
# Out:
# 483

# %%
term2docs_mapping_test = {}
term2types_mapping_test = {}
for ans in final_ans:
    ans_dict = json.loads(ans)
    for term_type in ans_dict:
        for term, type in term_type.items():
            term2docs_mapping_test[term]=[]
            for doc in test_data:
                if term in doc['title'] or term in doc['text']:
                    term2docs_mapping_test[term].append(doc['id'])

# %%
term2docs_mapping_test
# Out:
# {'certain types of rock': ['314_0'],
#  'soil': ['314_0',
#   '707_0',
#   '2010_0',
#   '263_0',
#   '1028_0',
#   '194_0',
#   '2005_0',
#   '1207_0',
#   '951_0',
#   '486_0',
#   '2002_0',
#   '487_0',
#   '432_0',
#   '769_0',
#   '849_0',
#   '952_0',
#   '2227_0',
#   '2014_0',
#   '2008_0',
#   '883_0',
#   '448_0',
#   '515_0',
#   '746_0',
#   '431_0',
#   '2017_0',
#   '1035_0',
#   '1959_0',
#   '1183_0',
#   '1120_0',
#   '847_0',
#   '1996_0',
#   '1924_0',
#   '313_0',
#   '2353_0',
#   '616_0',
#   '66_0',
#   '1921_0',
#   '2355_0',
#   '1922_0',
#   '1995_0',
#   '122_0',
#   '1923_0'],
#  'clay': ['314_0', '486_0'],
#  'solid rock': ['314_0'],
#  'carbon dioxide pooling disposition': [],
#  'respiratory electron transport chain': ['2189_0', '584_0'],
#  'amplitude of temperature of air': ['93_0'],
#  'Toxin': ['1298_0'],
#  'eukaryotic metabolites': ['1298_0'],
#  'animal metabolites': ['1298_0'],
#  'fungal metabolites': ['1298_0', '1069_0'],
#  'prokaryotic metabolites': ['1298_0', '1096_0'],
#  'flat': ['2357_0', '270_0', '639_0'],
#  'the cooling of solids': ['976_0'],
#  'the cooling of fluids': ['976_0', '714_0'],
#  'Inorganic macronutrients that are dissolved in ocean water': ['343_0'],
#  'concentration of carbon atoms in seawater': ['2021_0', '2022_0'],
#  'protic solvent': ['1778_0', '7_0', '914_0', '915_0', '1777_0'],
#  'megathrust earthquake': ['72_0'],
#  'foreshock': ['72_0'],
#  'mainshock': ['72_0'],
#  'aftershock': ['72_0'],
#  'blind thrust earthquake': ['72_0'],
#  'Multiplet earthquake': ['72_0'],
#  'interplate earthquake': ['72_0'],
#  'intraplate earthquake': ['72_0'],
#  'carbon-bearing gas emission processes': ['283_0'],
#  'carbon dioxide emission processes': [],
#  'methane gas emission processes': ['283_0'],
#  'lumber production process': ['1143_0'],
#  'lumber production': ['1143_0'],
#  'food propellants': ['207_0'],
#  'hollow': ['2370_0', '483_0'],
#  'nilas formation process': ['731_0'],
#  'young ice formation process': ['731_0'],
#  'first year ice formation process': ['731_0'],
#  'second year ice formation': ['731_0'],
#  'multiyear ice formation process': ['731_0'],
#  'Methane metabolic process': ['2184_0'],
#  'alpine': ['759_0'],
#  'subalpine': ['759_0'],
#  'montane': ['759_0', '619_0'],
#  'nival': ['759_0'],
#  'anaerobic respiration where ammonium acts as the electron donor': ['568_0'],
#  'aerobic respiration that utilizes ammonia as the electron donor': [],
#  'tripartite': ['1285_0', '471_0'],
#  'Ditrysia': ['2263_0', '685_0'],
#  'Heteroneura': ['2263_0'],
#  "Purine ribonucleoside 5'-triphosphate": ['1752_0', '1750_0', '1751_0'],
#  'Daphnia metabolite': ['1799_0', '1114_0'],
#  'feeding behavior': ['2181_0', '2190_0'],
#  'Water infiltration into soil': ['707_0'],
#  'dissolved carbon atom within environmental materials': ['2010_0', '2008_0'],
#  'volcanic seismic vibration': ['470_0'],
#  'impact-driven seismic vibration': ['470_0'],
#  'explosion-driven seismic vibration': ['470_0'],
#  'mass-wasting-driven seismic vibration': ['470_0'],
#  'collapse-driven seismic vibration': ['470_0'],
#  'earthquake-driven seismic vibration': ['470_0'],
#  'Bacterial metabolites': ['1096_0'],
#  'weathering of plastic': ['263_0'],
#  'photosynthetic photon flux': ['1049_0'],
#  'pieces of animal': ['2137_0'],
#  'fluid flow rate': ['2371_0', '405_0'],
#  'Oscillatoria': ['642_0', '2227_0', '2228_0'],
#  'Phormidium': ['642_0'],
#  'an impact between astronomical bodies': ['1925_0', '1926_0'],
#  'biomarker': ['84_0'],
#  'electron donor': ['568_0', '7_0', '1037_0', '46_0', '45_0'],
#  'Bronsted acids': ['7_0'],
#  'Lewis bases': ['7_0'],
#  'oceanic temperate': ['436_0'],
#  'continental temperate': ['436_0'],
#  'Obtectomera': ['685_0'],
#  'concentration of carbon-13 atoms in sea water': ['588_0'],
#  'concentration of carbon-14 atoms in sea water': ['588_0'],
#  'piece of cow': ['2139_0', '2140_0', '2143_0'],
#  'Radioactivity': ['593_0'],
#  'curled': ['270_0'],
#  'undulate': ['270_0'],
#  'elongated': ['270_0'],
#  'linear': ['270_0', '1796_0', '1225_0'],
#  'filamentous': ['642_0', '270_0'],
#  'curved': ['270_0', '918_0'],
#  'flattened': ['2357_0', '270_0'],
#  'sloped': ['270_0'],
#  'sloped downward': ['270_0'],
#  'lobate': ['270_0'],
#  'sculpted surface': ['270_0'],
#  'ornamentation': ['270_0', '364_0'],
#  'oblong': ['270_0'],
#  'fan-shaped': ['270_0'],
#  'superelliptic': ['270_0', '2360_0'],
#  'convex': ['270_0', '868_0'],
#  'concave 3-D shapes': ['270_0', '471_0'],
#  'V-shaped': ['270_0'],
#  'concave': ['270_0', '192_0', '471_0'],
#  'branched structures': ['270_0'],
#  'columnar': ['270_0'],
#  'drooping': ['270_0'],
#  'straight': ['270_0', '2352_0', '2355_0', '79_0'],
#  'slender': ['270_0'],
#  'falciform': ['270_0'],
#  'fringed': ['270_0'],
#  'fimbriated': ['270_0'],
#  'tholiform': ['270_0'],
#  'broad': ['993_0',
#   '657_0',
#   '1298_0',
#   '976_0',
#   '2021_0',
#   '2009_0',
#   '283_0',
#   '1143_0',
#   '207_0',
#   '731_0',
#   '2184_0',
#   '2018_0',
#   '470_0',
#   '1096_0',
#   '263_0',
#   '2137_0',
#   '642_0',
#   '84_0',
#   '7_0',
#   '436_0',
#   '588_0',
#   '2139_0',
#   '270_0',
#   '2016_0',
#   '2005_0',
#   '2331_0',
#   '2138_0',
#   '2333_0',
#   '1037_0',
#   '2002_0',
#   '697_0',
#   '1790_0',
#   '2182_0',
#   '918_0',
#   '71_0',
#   '1451_0',
#   '487_0',
#   '920_0',
#   '816_0',
#   '2188_0',
#   '2003_0',
#   '517_0',
#   '2178_0',
#   '2335_0',
#   '2140_0',
#   '2334_0',
#   '2183_0',
#   '2332_0',
#   '619_0',
#   '2015_0',
#   '2014_0',
#   '509_0',
#   '1216_0',
#   '2186_0',
#   '2022_0',
#   '2141_0',
#   '2006_0',
#   '714_0',
#   '2142_0',
#   '546_0',
#   '482_0',
#   '2011_0',
#   '2019_0',
#   '448_0',
#   '598_0',
#   '555_0',
#   '515_0',
#   '842_0',
#   '687_0',
#   '2241_0',
#   '828_0',
#   '584_0',
#   '1119_0',
#   '1125_0',
#   '2187_0',
#   '2017_0',
#   '2336_0',
#   '298_0',
#   '525_0',
#   '696_0',
#   '2185_0',
#   '1183_0',
#   '861_0',
#   '2235_0',
#   '1120_0',
#   '2290_0',
#   '2251_0',
#   '1960_0',
#   '2262_0',
#   '2243_0',
#   '1798_0',
#   '890_0',
#   '2292_0',
#   '900_0',
#   '2257_0',
#   '2247_0',
#   '2310_0',
#   '2307_0',
#   '2299_0',
#   '1924_0',
#   '1947_0',
#   '2319_0',
#   '1930_0',
#   '2203_0',
#   '164_0',
#   '141_0',
#   '2237_0',
#   '1901_0',
#   '1920_0',
#   '2306_0',
#   '2233_0',
#   '1128_0',
#   '1900_0',
#   '576_0',
#   '2288_0',
#   '1948_0',
#   '650_0',
#   '2234_0',
#   '2295_0',
#   '378_0',
#   '2245_0',
#   '543_0',
#   '616_0',
#   '66_0',
#   '1796_0',
#   '282_0',
#   '1918_0',
#   '662_0',
#   '2303_0',
#   '821_0',
#   '1921_0',
#   '1225_0',
#   '670_0',
#   '1949_0',
#   '1932_0',
#   '297_0',
#   '1922_0',
#   '843_0',
#   '2250_0',
#   '2365_0',
#   '875_0',
#   '2286_0',
#   '1931_0',
#   '2212_0',
#   '1899_0',
#   '2297_0',
#   '1795_0',
#   '2294_0',
#   '1157_0',
#   '2213_0',
#   '2221_0',
#   '1919_0',
#   '346_0',
#   '79_0',
#   '1005_0',
#   '902_0',
#   '2215_0',
#   '326_0',
#   '1797_0',
#   '1102_0',
#   '122_0',
#   '2274_0',
#   '2200_0',
#   '1923_0',
#   '910_0',
#   '2271_0',
#   '2320_0',
#   '2202_0',
#   '2267_0',
#   '1218_0',
#   '2308_0',
#   '2248_0',
#   '1201_0',
#   '2230_0',
#   '228_0'],
#  'funnel-shaped': ['270_0'],
#  'radiating': ['270_0'],
#  'plume-shaped': ['270_0'],
#  'Daphnia magna metabolite': ['1114_0'],
#  'dissolved carbon atom in soil': ['1207_0'],
#  'aerobic sensitivity to oxygen': [],
#  'anaerobic sensitivity': ['753_0'],
#  'Soil bulk density': ['951_0', '952_0'],
#  'increased rate of occurrence': ['2331_0',
#   '768_0',
#   '2333_0',
#   '2335_0',
#   '2336_0'],
#  'spherical': ['504_0'],
#  'increased frequency': ['696_0'],
#  'Cow material': ['2138_0'],
#  'CHEBI_15422': ['659_0', '722_0'],
#  'Sporadic occurrences': ['368_0'],
#  'continuous occurrences': ['368_0'],
#  'discontinuous occurrences': [],
#  'arched shape': ['192_0'],
#  'meteorite impact': ['967_0'],
#  'crustacean metabolite': ['1799_0', '1790_0'],
#  'Aerobic respiration': ['2182_0', '46_0', '45_0'],
#  'domed': ['918_0'],
#  'transpiration': ['658_0', '116_0'],
#  'Stellar radiation energy': ['71_0'],
#  'Generation of precursor metabolites and energy': ['59_0'],
#  'biosynthetic process': ['59_0',
#   '2188_0',
#   '2186_0',
#   '1039_0',
#   '2187_0',
#   '2185_0'],
#  'photosynthesis': ['1049_0', '774_0', '194_0', '59_0', '624_0', '2235_0'],
#  'small molecule metabolic process': ['59_0'],
#  'hydrocarbon metabolic process': ['59_0'],
#  'energy derivation by oxidation of reduced inorganic compounds': ['59_0'],
#  'energy derivation by oxidation of organic compounds': ['59_0'],
#  'electron transport chain': ['2189_0', '59_0', '46_0', '584_0', '1762_0'],
#  'hydrocarbon biosynthetic process': ['59_0', '2188_0', '2187_0'],
#  'ammonia oxidation': ['568_0', '59_0'],
#  'alkane metabolic process': ['2184_0', '59_0', '2186_0', '2185_0'],
#  'adenosine phosphate': ['1451_0', '1756_0'],
#  "guanosine 5'-phosphate": ['1757_0', '660_0'],
#  'composition of soil': ['487_0'],
#  'composition of water': ['487_0'],
#  'being calcified': ['487_0'],
#  'granular': ['487_0'],
#  'CHEBI_15996': ['659_0', '660_0'],
#  'Geothermal energy': ['1220_0'],
#  'circular shape': ['2358_0'],
#  'Fudge': ['816_0'],
#  'alkane biosynthetic process': ['2188_0',
#   '2186_0',
#   '1039_0',
#   '2187_0',
#   '2185_0'],
#  'dissolved nitrogen atoms present in soil': ['432_0'],
#  'dissolved nitrogen atoms present in water': [],
#  'being detached from': ['1175_0'],
#  'refinement process': ['553_0'],
#  'Haber-Bosch process': ['553_0'],
#  'hydrogen production process': ['553_0'],
#  'Animal material': ['2178_0'],
#  'aerobic respiration using nitrite': ['46_0'],
#  'aerobic respiration using ammonia': [],
#  'aerobic respiration using carbon monoxide': [],
#  'aerobic respiration using ferrous ions': [],
#  'aerobic respiration using hydrogen': [],
#  'aerobic respiration using sulfur or sulfate': [],
#  'aerobic respiration using arsenite': [],
#  'aerobic electron transport chain': ['46_0', '584_0'],
#  'Propane-1,2-diol': ['838_0'],
#  'sound wave energy': ['246_0'],
#  'wind wave energy': ['246_0'],
#  'humidity of soil': ['769_0'],
#  'increased humidity': ['769_0'],
#  'decreased humidity': ['769_0'],
#  'mammalian metabolite': ['1789_0', '881_0'],
#  'biodegradation of plastic': ['433_0'],
#  'obtuse shape': ['1112_0'],
#  'human metabolite': ['881_0'],
#  'Beef': ['2143_0'],
#  'piece of beef': ['2143_0'],
#  'glacial abrasion': ['663_0'],
#  'glacial plucking': ['663_0'],
#  'glacial ice thrusting': ['663_0'],
#  'increased accumulation': [],
#  'decreased accumulation': ['958_0'],
#  'irradiation by ionizing radiation': ['624_0'],
#  'irradiation by non-ionizing radiation': ['624_0'],
#  'photosynthetically active radiation': ['624_0'],
#  'freezing of water into ice': ['737_0'],
#  'adfreezing': ['737_0'],
#  'dissolved carbon atoms in soil': [],
#  'dissolved carbon atoms in water': ['850_0'],
#  'sea surface temperature': ['472_0'],
#  'Mutagens': ['612_0'],
#  'Guanosine phosphate': ['1508_0'],
#  'upper montane': ['619_0'],
#  'lower montane': ['619_0'],
#  "Adenosine 5'-phosphate": ['722_0', '1756_0'],
#  'coastal flooding': ['509_0'],
#  'storm surges': ['509_0'],
#  'riverine flooding': ['509_0'],
#  'flash flooding': ['509_0'],
#  'areal flooding': ['509_0'],
#  'urban flooding': ['509_0'],
#  'amphiprotic solvent': ['914_0', '915_0'],
#  'micronutrients': ['1216_0'],
#  'macronutrients': ['343_0', '1216_0'],
#  'frequency': ['2331_0',
#   '768_0',
#   '368_0',
#   '2333_0',
#   '697_0',
#   '2334_0',
#   '2332_0',
#   '2330_0',
#   '2337_0',
#   '696_0',
#   '2338_0'],
#  'dissolved carbon atom': ['2004_0',
#   '2010_0',
#   '850_0',
#   '1207_0',
#   '2007_0',
#   '849_0',
#   '2008_0'],
#  'Dinophyceae': ['2240_0', '2241_0'],
#  'piece(s) of cow': ['2141_0', '2142_0'],
#  'protophilic solvent': ['915_0', '1780_0', '1781_0', '1779_0', '1782_0'],
#  'Frazil ice formation': ['397_0'],
#  'slush formation': ['397_0'],
#  'shuga formation': ['397_0'],
#  'Ingestion': ['711_0'],
#  'oceanic transient tracer': ['863_0'],
#  'Hydraulic fracturing': ['546_0'],
#  'Atmospheric wind direction': ['138_0'],
#  'down': ['263_0',
#   '270_0',
#   '433_0',
#   '138_0',
#   '746_0',
#   '1972_0',
#   '603_0',
#   '1971_0',
#   '378_0',
#   '1969_0',
#   '1970_0',
#   '2355_0',
#   '35_0',
#   '1185_0',
#   '79_0',
#   '1230_0',
#   '1791_0'],
#  'left': ['138_0'],
#  'right': ['138_0', '1030_0'],
#  'front': ['138_0', '763_0'],
#  'back': ['138_0', '2307_0'],
#  'unidirectional': ['138_0'],
#  'bi-directional': ['138_0'],
#  'circling direction': ['138_0'],
#  'north': ['138_0', '5_0'],
#  'south': ['138_0', '5_0'],
#  'east': ['138_0', '5_0'],
#  'west': ['138_0', '5_0'],
#  'Oscillatoriaceae': ['642_0', '2228_0'],
#  'Oscillatoriales': ['2227_0', '2228_0'],
#  'submarine groundwater discharge process': ['598_0'],
#  'excitatory amino acid antagonist': ['950_0'],
#  'excitatory amino acids': ['950_0'],
#  'muskmelon (Cucumis melo) fruit food product': ['555_0'],
#  'cantaloupe fruit food product': ['555_0'],
#  'citrullus lanatus fruit food product': ['555_0'],
#  'periglacial process': ['515_0'],
#  'cryoturbation of soil': ['515_0'],
#  'frost jacking': ['515_0'],
#  'frost sorting': ['515_0'],
#  'frost wedging': ['515_0'],
#  'frost heaving': ['515_0'],
#  'concentration of nitrite in sea water': ['157_0'],
#  'Methanogenesis': ['1037_0', '1038_0', '45_0', '1039_0'],
#  'elliptic shape': ['2358_0', '2360_0'],
#  'soil erosion': ['746_0'],
#  'bedrock dissolution': ['746_0'],
#  'glacial erosion processes': ['663_0', '746_0'],
#  'erosion through nivation': ['746_0'],
#  'raising agent': ['206_0'],
#  'food packaging gas': ['206_0'],
#  'food propellant': ['207_0', '206_0'],
#  'atmosphere-ocean momentum transfer process': ['687_0'],
#  'the concentration of nitrate in groundwater': ['423_0'],
#  'the concentration of nitrate in sea water': ['423_0'],
#  'atmospheric weather': ['828_0'],
#  'space weather': ['828_0'],
#  'ice-bearing permafrost thawing process': ['1119_0'],
#  'concentration of silicic acid in sea water': ['13_0'],
#  'spheroid': ['504_0', '868_0'],
#  'cylindrical shape': ['482_0', '868_0'],
#  'conical shape': ['868_0'],
#  'eating behavior': ['711_0', '2190_0'],
#  'glucosamines': ['889_0'],
#  'agronomic process': ['1035_0'],
#  'animal husbandry': ['1035_0'],
#  'Mediterranean climate': ['525_0'],
#  'humid subtropical': ['525_0'],
#  'arid subtropical': ['525_0'],
#  'highland subtropical': ['525_0'],
#  'road traffic noise': ['562_0'],
#  'aircraft noise': ['562_0'],
#  'decreased frequency': ['697_0', '696_0'],
#  'temperature of air': ['93_0', '1053_0', '1183_0'],
#  'temperature of soil': ['1183_0'],
#  'temperature of water': ['1183_0'],
#  'Amphiesmenoptera': ['2302_0', '2313_0'],
#  'glacial surface layer velocity': ['861_0'],
#  'angular velocity': ['861_0'],
#  'increased velocity': ['861_0'],
#  'decreased velocity': ['861_0'],
#  'normal velocity': ['861_0'],
#  'increased fluid flow': ['405_0'],
#  'decreased fluid flow': ['405_0'],
#  'aerosolised particle formation events': ['119_0'],
#  'Mollusca': ['2290_0', '2291_0'],
#  'Caelifera': ['2298_0', '2230_0'],
#  'crickets': ['2298_0', '2297_0'],
#  'katydids': ['2298_0'],
#  'Pinidae': ['2251_0', '2239_0'],
#  'biodiversity conservation process': ['1960_0', '662_0'],
#  'Fluorescence of water': ['1158_0'],
#  'macroburst': ['1972_0', '378_0'],
#  'Haplorrhini': ['2264_0', '2244_0'],
#  'thickness of snow': ['847_0', '313_0'],
#  'thickness of topsoil': ['847_0'],
#  'increased thickness': ['847_0'],
#  'decreased thickness': ['847_0', '228_0'],
#  'irregular thickness': ['847_0'],
#  'decreased circumference': ['325_0'],
#  'Laguncularia racemosa': ['1041_0'],
#  'Conifers II': ['2239_0', '2218_0'],
#  'Soil albedo': ['1996_0', '616_0', '1995_0'],
#  'forest fires': ['501_0'],
#  'brush fires': ['501_0'],
#  'bush fires': ['501_0'],
#  'grass fires': ['501_0'],
#  'pasture fires': ['501_0'],
#  'Archosauria': ['2311_0', '2273_0'],
#  'color': ['773_0', '2325_0', '172_0', '66_0', '2326_0'],
#  'patchy pattern': ['80_0'],
#  'aggregated pattern': ['80_0'],
#  'trabecular pattern': ['80_0'],
#  'defence against flooding': ['575_0'],
#  'conservation-focused active ecosystem management': ['1960_0', '575_0'],
#  'active agri-ecosystem management': ['575_0', '670_0'],
#  'planned revegetation': ['575_0', '415_0'],
#  'pollution degradation': ['575_0', '1981_0'],
#  'pollution control': ['575_0',
#   '1924_0',
#   '1921_0',
#   '1922_0',
#   '1185_0',
#   '1923_0'],
#  'Eudicotyledons': ['2280_0'],
#  'Dipnotetrapodomorpha': ['2211_0', '2247_0'],
#  'the process of forming a liquid aerosol from gaseous material within an atmospheric context': [],
#  'respiratory-chain inhibitor': ['1763_0', '1174_0'],
#  'Pteriomorphia': ['2292_0', '2293_0'],
#  'Locusta migratoria': ['900_0'],
#  'volume of hydrological precipitation': ['116_0'],
#  'volume of runoff': ['116_0'],
#  'volume of evaporation': ['116_0'],
#  'volume of evapotranspiration': ['116_0'],
#  'volume of rain': ['116_0'],
#  'ionizing stellar radiation': ['1249_0', '141_0'],
#  'X-ray radiation': ['1249_0', '1218_0'],
#  'gamma-ray radiation': ['1249_0', '941_0'],
#  'Sarcopterygii': ['2211_0', '2310_0'],
#  'Elaeis guineensis': ['980_0'],
#  'perimeter': ['2356_0', '865_0', '864_0', '326_0', '228_0'],
#  'inhalation anaesthetic': ['480_0'],
#  'visible spectrum stellar radiation': ['142_0'],
#  'lamiids': ['2318_0', '2271_0'],
#  'WMO blizzard': ['651_0'],
#  'winter blizzard': ['651_0'],
#  'Mytilus': ['752_0'],
#  'land conversion process': ['1947_0', '1948_0', '1949_0', '1005_0'],
#  'influenced by': ['331_0'],
#  'dispositional property': ['331_0'],
#  'young': ['731_0', '331_0', '2320_0'],
#  'chronological age': ['331_0'],
#  'Avicennia': ['2270_0', '1190_0'],
#  'Volume': ['952_0', '116_0', '2359_0'],
#  'Autobranchia': ['2292_0', '2238_0'],
#  'clams': ['2291_0', '2238_0'],
#  'mussels': ['2291_0',
#   '2293_0',
#   '752_0',
#   '430_0',
#   '2238_0',
#   '945_0',
#   '2201_0',
#   '2199_0',
#   '2294_0',
#   '2200_0'],
#  'oysters': ['2291_0', '2238_0'],
#  'scallops': ['2291_0', '2238_0'],
#  'increased area': ['259_0'],
#  'decreased area': ['259_0', '228_0'],
#  'normal area': ['259_0'],
#  'butter product analog': ['761_0', '2161_0'],
#  'mass gaseous flow': ['357_0'],
#  'mass liquid flow': ['357_0'],
#  'mass plasma flow': ['357_0'],
#  'atmospheric wind': ['357_0', '119_0', '79_0'],
#  'planetary wind': ['357_0'],
#  'tsunami': ['357_0', '875_0'],
#  'lava flow': ['357_0'],
#  'tidal flow': ['357_0', '164_0', '1932_0', '1931_0'],
#  'stellar wind': ['357_0'],
#  'Cyclonic circulation': ['357_0'],
#  'Snow water equivalent': ['313_0'],
#  'depth of water ice': ['313_0'],
#  'top depths of soil layers': [],
#  'bottom depths of soil layers': ['313_0'],
#  'depth of snow': ['313_0'],
#  'depth of water': ['313_0'],
#  'decreased depth': ['313_0', '228_0'],
#  'increased depth': ['313_0'],
#  'normal depth': ['313_0'],
#  'hydrocarbon bioremediation': ['603_0'],
#  'metal bioremediation': ['603_0'],
#  'treatment of persistent organic pollutants': ['603_0'],
#  'color patterns': ['172_0'],
#  'irregular spatial patterns': ['80_0', '172_0'],
#  'regular spatial patterns': ['80_0', '172_0'],
#  'unilateral patterns': ['172_0'],
#  'distributed patterns': ['172_0'],
#  'vertical arrangements': ['172_0'],
#  'stratification': ['172_0'],
#  'colorless': ['172_0'],
#  'increased distribution': ['172_0'],
#  'decreased distribution': ['172_0'],
#  'stratified': ['172_0'],
#  'warm core cyclone': ['1930_0', '594_0'],
#  'quality of full-spectrum electromagnetic radiation': ['2363_0'],
#  'microburst': ['1971_0', '282_0'],
#  'radio wave stellar radiation': ['369_0'],
#  'permafrost methane explosion': ['1030_0'],
#  'crustacean farming processes': ['848_0'],
#  'finfish farming processes': ['848_0'],
#  'mollusc farming processes': ['848_0'],
#  'diurnal marine tidal flow process': ['164_0'],
#  'semi-diurnal marine tidal flow process': ['164_0'],
#  'Solar radiation': ['141_0'],
#  'microwave': ['141_0', '370_0', '297_0'],
#  'radio wave': ['369_0', '141_0', '297_0'],
#  'infrared': ['141_0', '177_0', '297_0'],
#  'visible spectrum': ['142_0', '141_0', '545_0', '297_0'],
#  'ultraviolet': ['141_0', '297_0', '1147_0'],
#  'X-ray stellar radiation': ['1218_0'],
#  'gamma-ray stellar radiation': ['141_0', '941_0'],
#  'Anthropisation': ['1901_0',
#   '1920_0',
#   '1900_0',
#   '1918_0',
#   '1899_0',
#   '1919_0'],
#  'Echinozoa': ['2306_0', '910_0'],
#  'pathway inhibitor': ['1793_0', '1762_0'],
#  'increased length': ['1260_0', '865_0'],
#  'decreased length': ['1260_0', '228_0'],
#  'Schistocerca gregaria': ['991_0'],
#  'seaweed farming': ['745_0'],
#  'freshwater macrophyte farming': ['745_0'],
#  'afforestation': ['415_0'],
#  'reforestation': ['415_0'],
#  'Theropoda': ['2275_0', '2276_0'],
#  'intercloud lightning': ['576_0'],
#  'intracloud lightning': ['576_0'],
#  'Microwave stellar radiation': ['370_0'],
#  'thunderstorm': ['576_0', '621_0', '378_0', '1969_0', '1970_0', '1157_0'],
#  'Salicornia subgen. Amerocornia': ['2234_0'],
#  'Arthropoda': ['2295_0', '2232_0'],
#  'increased perimeter': ['865_0', '864_0'],
#  'dry macrobursts': ['378_0'],
#  'wet macrobursts': ['378_0'],
#  'thickness': ['862_0', '2361_0', '847_0', '313_0', '2353_0', '228_0'],
#  'thickness of ice caps': ['2353_0'],
#  'thickness of a particular layer of soil': ['2353_0'],
#  'Hominoidea': ['2323_0', '2245_0'],
#  'direct transformation of gaseous materials into solid particles': ['543_0'],
#  'formation of solid aerosols from liquid materials present in the atmosphere': ['543_0'],
#  'glaciation of water droplets within clouds': ['543_0'],
#  'Opacity': ['2327_0', '441_0'],
#  'Dry soil albedo': ['616_0'],
#  'moist soil albedo': ['616_0'],
#  'color of the soil': ['66_0'],
#  'blue': ['66_0'],
#  'white': ['66_0'],
#  'brown': ['2235_0', '66_0'],
#  'downburst': ['1972_0', '1971_0', '1969_0', '1970_0'],
#  'wet microbursts': ['282_0'],
#  'dry microbursts': ['282_0'],
#  'infrared stellar radiation': [],
#  'outgoing longwave radiation': ['177_0'],
#  'mid-infrared radiation': ['177_0'],
#  'near-infrared radiation': ['177_0'],
#  'far-infrared radiation': ['177_0'],
#  'Laguncularia': ['1041_0', '2229_0'],
#  'circumference': ['325_0', '864_0', '326_0'],
#  'decreased perimeter': ['864_0', '228_0'],
#  'acidic': ['359_0'],
#  'alkaline': ['359_0'],
#  'Arecaceae': ['2220_0', '2282_0'],
#  'Acridomorpha': ['2319_0', '2303_0'],
#  'Land fire': ['501_0', '1928_0', '1929_0'],
#  'conflagration': ['821_0'],
#  'industrial fire': ['821_0'],
#  'planned burn': ['821_0'],
#  'wildfire': ['1928_0', '821_0', '1929_0'],
#  'Theria': ['2249_0', '2320_0'],
#  'length': ['2356_0', '141_0', '1260_0', '865_0', '2352_0', '2365_0', '228_0'],
#  'Cupressales': ['2256_0', '2218_0'],
#  'optical quality': ['2325_0', '2327_0', '2364_0', '2326_0', '2328_0'],
#  'Liliopsida': ['2279_0', '2216_0'],
#  'visible spectrum radiation emitted by a manufactured product': [],
#  'EC 3.5.1.4 (amidase) inhibitor': ['1225_0'],
#  'Schistocerca': ['991_0', '2301_0'],
#  'quarrying': ['613_0'],
#  'opencast mining': ['613_0'],
#  'Dicondylia': ['1128_0', '2312_0'],
#  'forestry': ['683_0'],
#  'terrestrial mining': ['613_0', '683_0'],
#  'agriculture': ['1216_0', '2141_0', '2142_0', '1035_0', '991_0', '683_0'],
#  'land fire': ['501_0', '1928_0', '1929_0'],
#  'Mammalia': ['2243_0', '2249_0', '2268_0'],
#  'opaque': ['441_0'],
#  'transparent': ['441_0'],
#  'translucent': ['441_0'],
#  'marine tidal flow process': ['164_0', '1932_0', '1931_0'],
#  'Bora': ['110_0'],
#  'depth': ['313_0', '2355_0', '121_0', '228_0'],
#  'particle radiation': ['297_0'],
#  'electromagnetic radiation': ['1158_0',
#   '142_0',
#   '2363_0',
#   '369_0',
#   '141_0',
#   '2364_0',
#   '297_0',
#   '2365_0',
#   '941_0'],
#  'acoustic radiation': ['297_0'],
#  'particle beam radiation': ['297_0'],
#  'stellar radiation': ['71_0',
#   '1249_0',
#   '142_0',
#   '369_0',
#   '141_0',
#   '370_0',
#   '177_0',
#   '297_0',
#   '1147_0',
#   '941_0',
#   '1218_0'],
#  'radiation emitted by manufactured products': ['545_0', '297_0'],
#  'shortwave radiation': ['297_0'],
#  'ionizing radiation': ['624_0', '1249_0', '297_0'],
#  'Photosynthetically active radiation': ['297_0'],
#  'infrasound': ['297_0'],
#  'ultrasound radiation': ['297_0'],
#  'insolation': ['297_0'],
#  'Atmospheric aerosol formation': ['580_0'],
#  'pyrolysis': ['580_0', '581_0'],
#  'fires': ['501_0', '1928_0', '821_0', '1929_0', '580_0'],
#  'explosion processes': ['580_0'],
#  'misaligned towards': ['843_0'],
#  'misaligned away from': ['843_0'],
#  'Sauria': ['2250_0', '2209_0'],
#  'radiation reflective quality': ['2366_0', '2365_0'],
#  'Pinopsida': ['2251_0', '2286_0'],
#  'width': ['2354_0', '435_0', '228_0'],
#  'Orthoptera': ['2298_0', '2297_0'],
#  'grasshoppers and crickets': ['2297_0'],
#  'Polyneoptera': ['2297_0'],
#  'earwigs': ['2297_0'],
#  'Avicennia germinans': ['1190_0'],
#  'electron-transport chain inhibitor': ['1763_0', '1762_0'],
#  'Hexapoda': ['2284_0', '2296_0'],
#  'Archelosauria': ['2311_0', '2209_0'],
#  'foehn wind': ['35_0'],
#  'drainage wind': ['35_0', '1230_0'],
#  'glacier wind': ['35_0'],
#  'Homo sapiens': ['440_0'],
#  'P450 inhibitors': ['1185_0'],
#  'combustion processes': ['580_0', '581_0'],
#  'flush': ['121_1'],
#  'continuous with': ['121_1'],
#  'normal position': ['121_1'],
#  'Benthic deep-sea mining': ['346_0'],
#  'sea bed mining': ['346_0'],
#  'katabatic wind': ['35_0', '79_0', '1230_0'],
#  'downslope katabatic wind': ['35_0', '79_0'],
#  'cooling-driven katabatic wind': ['79_0', '1230_0'],
#  'fall wind': ['110_0', '79_0'],
#  'downdraft': ['378_0', '1969_0', '1970_0', '79_0'],
#  'squall wind': ['79_0'],
#  'jet-effect wind': ['79_0'],
#  'slope flow': ['79_0'],
#  'anabatic wind': ['79_0'],
#  'straight-line wind': ['79_0'],
#  'wind gust': ['79_0'],
#  'monsoon wind': ['79_0'],
#  'mountain-gap wind': ['79_0'],
#  'antiseptic drug': ['833_0'],
#  'atmospheric aerosolised particle formation event': ['119_0', '1086_0'],
#  'Drainage wind': ['1230_0'],
#  'EC 1.14.14.* inhibitor': ['1797_0'],
#  'Gamma-ray stellar radiation': ['941_0'],
#  'Pentapetalae': ['2257_0', '2259_0', '2217_0', '2258_0'],
#  'antiinfective agent': ['833_0', '1102_0'],
#  'analgesic': ['1102_0'],
#  'Cardiovascular drug': ['1102_0'],
#  'Anaesthetic': ['480_0', '1102_0'],
#  'general anaesthetic': ['480_0', '1102_0'],
#  'Luminous flux': ['2328_0'],
#  'Atmospheric wind speed': ['122_0'],
#  'speed of a water current': ['122_0'],
#  'speed at which water infiltrates the soil': ['122_0'],
#  'speed at which soil drains water': ['122_0'],
#  'increased speed': [],
#  'decreased speed': ['122_0'],
#  'sound speed': ['122_0'],
#  'normal speed': ['122_0'],
#  'Biotransformation of coal': ['212_0'],
#  'microbial enhanced oil recovery': ['212_0'],
#  'microbial solubization of coal': ['212_0'],
#  'biotransformation of biomass into mixed alcohols': ['212_0'],
#  'Saurischia': ['2275_0', '2274_0'],
#  'Modiolinae': ['945_0', '2200_0'],
#  'width of a river': ['435_0'],
#  'width of a road': [],
#  'width of a habitat': [],
#  'increased width': ['435_0'],
#  'decreased width': ['435_0', '228_0'],
#  'normal width': ['435_0'],
#  'asterids': ['2318_0', '2258_0'],
#  'blizzard': ['651_0', '119_0', '1118_0'],
#  'lake-effect snow storm': ['1118_0'],
#  'Gunneridae': ['2217_0', '2316_0'],
#  'extra-tropical cyclone': ['594_0'],
#  'EC 1.* (oxidoreductase) inhibitors': ['1791_0'],
#  'Oxidoreductases': ['1798_0', '1791_0'],
#  'Arecales': ['2282_0', '2267_0'],
#  'commelinids': ['2267_0'],
#  'Petrosaviidae': ['2216_0', '2283_0'],
#  'Gnathostomata': ['2202_0', '2308_0'],
#  'decreased volume': ['116_0', '228_0']}

# %%
import json

# Save final_clusters_list to JSON file
with open("text_to_ontol_keyword_LLM_ecology_term_extraction.json", "w", encoding="utf-8") as f:
    json.dump(term2docs_mapping_test, f, indent=2, ensure_ascii=False)

print("Clusters saved to final_clusters.json ✅")
# Out:
# Clusters saved to final_clusters.json ✅

# %%
import json
def load_json(data_path):
    with open(data_path, "r") as file_1:
        pred_data= json.load(file_1)
    return pred_data

pred_data = load_json("text_to_ontol_keyword_LLM_ecology.json")

# %%
import json

# Assuming pred_data is your dictionary of {term: [type1, type2, ...]}
# Here's how to write it properly:
with open("ecology/test/terms.txt", "w", encoding="utf-8") as term_file:
    for key in pred_data.keys():
        term_file.write(f"{key}\n")

with open("ecology/test/types.txt", "w", encoding="utf-8") as type_file:
    for value in pred_data.values():
        # If multiple types are present, join them into one line as JSON list
        type_file.write(json.dumps(value) + "\n")

# %%
# Write keys (terms) to terms.txt
with open("ecology/test/terms.txt", "w", encoding="utf-8") as term_file:
    for key in pred_data.keys():
        term_file.write(f"{key}\n")

# Track and write only unique types (no duplicates)
written_types = set()

with open("ecology/test/types.txt", "w", encoding="utf-8") as type_file:
    for value_list in pred_data.values():
        for val in value_list:
            if val not in written_types:
                type_file.write(f"{val}\n")
                written_types.add(val)
