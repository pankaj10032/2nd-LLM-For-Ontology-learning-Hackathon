# %% [markdown]
# # **Clustering the Training data Term**

# %%
import json
from collections import defaultdict

def cluster_terms_by_shared_word(data):
    word_to_terms = defaultdict(set)
    for idx, entry in enumerate(data):
        words = entry['term'].lower().split()
        for w in words:
            word_to_terms[w].add(idx)

    visited = set()
    clusters = []

    def dfs(term_idx, cluster):
        visited.add(term_idx)
        cluster.add(term_idx)
        for w in data[term_idx]['term'].lower().split():
            for neighbor_idx in word_to_terms[w]:
                if neighbor_idx not in visited:
                    dfs(neighbor_idx, cluster)

    for i in range(len(data)):
        if i not in visited:
            cluster = set()
            dfs(i, cluster)
            clusters.append(cluster)

    clustered_output = []
    for cluster in clusters:
        cluster_terms = []
        cluster_types = set()
        for idx in cluster:
            cluster_terms.append(data[idx]['term'])
            cluster_types.update(data[idx]['types'])
        clustered_output.append({
            'terms': cluster_terms,
            'types': list(cluster_types)
        })
    return clustered_output
import json
import re

def clean_json_string(s):
    """Clean JSON string by replacing problematic Unicode escape sequences."""
    # Replace \u00c2 with middle dot (·)
    s = re.sub(r'\\u00c2', '·', s)
    # Replace \u00b7 with middle dot (·)
    s = re.sub(r'\\u00b7', '·', s)
    # Handle incomplete or malformed sequences like \u00b
    s = re.sub(r'\\u00b(?!\w{2})', '·', s)
    # Convert superscript notation (e.g., s-2 to s⁻²)
    s = re.sub(r's-2', 's⁻²', s)
    s = re.sub(r's-3', 's⁻³', s)
    s = re.sub(r's-4', 's⁻⁴', s)
    s = re.sub(r'm-2', 'm⁻²', s)
    s = re.sub(r'm-4', 'm⁻⁴', s)
    s = re.sub(r'kg-1', 'kg⁻¹', s)
    s = re.sub(r'A-1', 'A⁻¹', s)
    s = re.sub(r'A-2', 'A⁻²', s)
    return s

try:
    # Read the JSON file as raw text to clean it
    with open('OBI/train/term_typing_train_data.json', 'r', encoding='utf-8') as f:
        raw_data = f.read()
    
    # Clean the raw JSON string
    cleaned_data = clean_json_string(raw_data)
    
    # Parse the cleaned JSON string
    data = json.loads(cleaned_data)
    
    # Print all terms to verify correct loading
    print("Successfully loaded JSON data. Terms:")
    # for entry in data:
    #     print(f"ID: {entry['id']}, Term: {entry['term']}, Type: {entry['types'][0]}")

except UnicodeDecodeError as e:
    print(f"UnicodeDecodeError: {e}")
    print("Try a different encoding (e.g., 'latin-1' or 'iso-8859-1') or clean the file.")
except json.JSONDecodeError as e:
    print(f"JSONDecodeError: {e}")
    print("The JSON file may be malformed. Check for invalid characters or syntax.")
except Exception as e:
    print(f"Unexpected error: {e}")

clusters = cluster_terms_by_shared_word(data)
print(json.dumps(clusters, indent=2, ensure_ascii=False))
# Out:
# Successfully loaded JSON data. Terms:
# [
#   {
#     "terms": [
#       "pT3 (kidney)",
#       "pN1 (colon)",
#       "pT4 (lung)",
#       "pT1 (ovary)",
#       "pTis (colon)",
#       "pT3b (ovary)",
#       "pT2 (kidney)",
#       "pN0 (lung)",
#       "cM0 (ovary)",
#       "pT3a (ovary)",
#       "cM0 (lung)",
#       "pT1b (ovary)",
#       "cM1 (lung)",
#       "pT1a (kidney)",
#       "pTis (lung)",
#       "pN1a (colon)",
#       "pN2a (colon)",
#       "pN0 (kidney)",
#       "pT2 (colon)",
#       "cM1a (lung)",
#       "pT0 (ovary)",
#       "pT2 (lung)",
#       "pT2a (lung)",
#       "pT2c (ovary)",
#       "pM1 (ovary)",
#       "pT1 (colon)",
#       "pT0 (colon)",
#       "pN2 (lung)",
#       "pT3c (kidney)",
#       "pT2b (kidney)",
#       "cM0 (colon)",
#       "pT1b (lung)",
#       "pT3 (colon)",
#       "pN0 (ovary)",
#       "pT4a (colon)",
#       "pT3b (kidney)",
#       "pT3c (ovary)",
#       "pM1a (colon)",
#       "pT4b (colon)",
#       "pN3 (lung)",
#       "pM1a (lung)",
#       "pM1 (lung)",
#       "pT0 (kidney)",
#       "pN1 (ovary)",
#       "cM1b (lung)",
#       "pT1a (ovary)",
#       "pT1a (lung)",
#       "pN0 (colon)",
#       "pT4 (kidney)",
#       "pM1 (kidney)",
#       "pT0 (lung)",
#       "pT2b (ovary)",
#       "cM1b (colon)",
#       "pT2a (kidney)",
#       "cM0 (kidney)"
#     ],
#     "types": [
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "GenePattern module SVM",
#       "GenePattern module HierarchicalClusteringViewer",
#       "GenePattern module KMeansClustering",
#       "GenePattern k-means clustering",
#       "GenePattern module KNNXValidation",
#       "GenePattern PCA",
#       "GenePattern LOOCV",
#       "GenePattern k-nearest neighbors",
#       "GenePattern CART",
#       "GenePattern hierarchical clustering",
#       "GenePattern module HeatMapViewer",
#       "GenePattern HeatMapViewer data visualization",
#       "GenePattern module KNN",
#       "GenePattern module CARTXValidation"
#     ],
#     "types": [
#       "clustered data visualization",
#       "principal components analysis dimensionality reduction",
#       "leave one out cross validation method",
#       "GenePattern software",
#       "hierarchical clustering",
#       "CART",
#       "k-means clustering",
#       "k-nearest neighbors"
#     ]
#   },
#   {
#     "terms": [
#       "Stage IIIA (FIGO)",
#       "Stage IIA1 (FIGO)",
#       "Stage 1 (FIGO)",
#       "Stage IIB (AJCC 7th)",
#       "Stage IIA2 (FIGO)",
#       "Stage IIA (FIGO)",
#       "Stage 2A (FIGO)",
#       "Stage IVB (FIGO)",
#       "Stage IVA (FIGO)",
#       "Stage 3B (FIGO)",
#       "Stage 3C (FIGO)",
#       "Stage IB2 (FIGO)",
#       "Stage IIIA (AJCC 7th)",
#       "Stage IIIB (AJCC 7th)",
#       "Stage IVA (AJCC 7th)",
#       "Stage IA1 (FIGO)",
#       "Stage 2 (FIGO)",
#       "Stage 3A (FIGO)",
#       "Stage 2B (FIGO)",
#       "Stage I (AJCC 7th)",
#       "Stage IVB (AJCC 7th)",
#       "Stage IB1 (FIGO)",
#       "Stage 3 (FIGO)",
#       "Stage 1C (FIGO)",
#       "Stage IA2 (FIGO)"
#     ],
#     "types": [
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification"
#     ]
#   },
#   {
#     "terms": [
#       "angstrom"
#     ],
#     "types": [
#       "length unit"
#     ]
#   },
#   {
#     "terms": [
#       "hertz"
#     ],
#     "types": [
#       "frequency unit"
#     ]
#   },
#   {
#     "terms": [
#       "Waters"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "Thermo",
#       "Thermo Fisher Scientific"
#     ],
#     "types": [
#       "organization",
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "Abbott"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "XML"
#     ],
#     "types": [
#       "data format specification"
#     ]
#   },
#   {
#     "terms": [
#       "kilogram"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "ambidexterous"
#     ],
#     "types": [
#       "categorical label"
#     ]
#   },
#   {
#     "terms": [
#       "ready for release"
#     ],
#     "types": [
#       "curation status specification"
#     ]
#   },
#   {
#     "terms": [
#       "nanogram"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "example to be eventually removed",
#       "term split",
#       "placeholder removed",
#       "to be replaced with external ontology term",
#       "term imported"
#     ],
#     "types": [
#       "curation status specification",
#       "obsolescence reason specification"
#     ]
#   },
#   {
#     "terms": [
#       "picogram"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "microgram",
#       "microgram per liter",
#       "gram per deciliter",
#       "mass volume percentage",
#       "mass percentage",
#       "second",
#       "gram per liter",
#       "milliliter per liter",
#       "colony forming unit per volume",
#       "liter",
#       "count per nanomolar second",
#       "molar",
#       "gram",
#       "milligram",
#       "nanomolar",
#       "milligram per milliliter",
#       "count per molar",
#       "count per nanomolar"
#     ],
#     "types": [
#       "mass unit",
#       "volume unit",
#       "time unit",
#       "rate unit",
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "Ambion"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "defined class",
#       "named class expression"
#     ],
#     "types": [
#       "denotator type"
#     ]
#   },
#   {
#     "terms": [
#       "Affymetrix",
#       "Affymetrix"
#     ],
#     "types": [
#       "material supplier",
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "Applied Biosystems"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "micrometer"
#     ],
#     "types": [
#       "length unit"
#     ]
#   },
#   {
#     "terms": [
#       "InBios"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "OWL"
#     ],
#     "types": [
#       "data format specification"
#     ]
#   },
#   {
#     "terms": [
#       "G2 (WHO)",
#       "G4 (Fuhrman)",
#       "G1 (WHO)",
#       "G3 (Fuhrman)",
#       "G4 (WHO)",
#       "G1 (Fuhrman)"
#     ],
#     "types": [
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "histologic grade for ovarian tumor according to the World Health Organization"
#     ]
#   },
#   {
#     "terms": [
#       "centimeter",
#       "cubic decimeter",
#       "cubic centimeter"
#     ],
#     "types": [
#       "length unit",
#       "volume unit"
#     ]
#   },
#   {
#     "terms": [
#       "week"
#     ],
#     "types": [
#       "time unit"
#     ]
#   },
#   {
#     "terms": [
#       "Bruker Daltonics"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "G1: Well differentiated",
#       "G2: Moderately differentiated"
#     ],
#     "types": [
#       "histologic grade according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "FCS"
#     ],
#     "types": [
#       "data format specification"
#     ]
#   },
#   {
#     "terms": [
#       "minute"
#     ],
#     "types": [
#       "time unit"
#     ]
#   },
#   {
#     "terms": [
#       "Oxford Nanopore Technologies",
#       "NanoString Technologies"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "nanometer"
#     ],
#     "types": [
#       "length unit"
#     ]
#   },
#   {
#     "terms": [
#       "Transformation-ML"
#     ],
#     "types": [
#       "data format specification"
#     ]
#   },
#   {
#     "terms": [
#       "requires discussion"
#     ],
#     "types": [
#       "curation status specification"
#     ]
#   },
#   {
#     "terms": [
#       "universal"
#     ],
#     "types": [
#       "denotator type"
#     ]
#   },
#   {
#     "terms": [
#       "Agilent"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "uncurated"
#     ],
#     "types": [
#       "curation status specification"
#     ]
#   },
#   {
#     "terms": [
#       "Compensation-ML"
#     ],
#     "types": [
#       "data format specification"
#     ]
#   },
#   {
#     "terms": [
#       "picomole"
#     ],
#     "types": [
#       "substance unit"
#     ]
#   },
#   {
#     "terms": [
#       "RDF"
#     ],
#     "types": [
#       "data format specification"
#     ]
#   },
#   {
#     "terms": [
#       "Helicos"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "micromolar"
#     ],
#     "types": [
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "Low grade ovarian tumor",
#       "High grade ovarian tumor"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system"
#     ]
#   },
#   {
#     "terms": [
#       "Millipore"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "Invitrogen"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "BIO-RAD"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "Nimblegen"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "meter"
#     ],
#     "types": [
#       "length unit"
#     ]
#   },
#   {
#     "terms": [
#       "Exbio Antibodies"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "UO_0000033"
#     ],
#     "types": [
#       "time unit"
#     ]
#   },
#   {
#     "terms": [
#       "Roche"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "Pacific Biosciences"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "micromole"
#     ],
#     "types": [
#       "substance unit"
#     ]
#   },
#   {
#     "terms": [
#       "Exalpha Biological"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "CytoBuoy"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "left handed"
#     ],
#     "types": [
#       "categorical label"
#     ]
#   },
#   {
#     "terms": [
#       "zip"
#     ],
#     "types": [
#       "data format specification"
#     ]
#   },
#   {
#     "terms": [
#       "60-70: symptomatic but in bed less than 50% of the day",
#       "domain entity does not exist",
#       "1: symptomatic but fully ambulatory",
#       "40-50: symptomatic, in bed more than 50% of the day, but not bed ridden",
#       "out of scope"
#     ],
#     "types": [
#       "obsolescence reason specification",
#       "Karnofsky score vaue specification",
#       "Eastern Cooperative Oncology Group score value specification"
#     ]
#   },
#   {
#     "terms": [
#       "month"
#     ],
#     "types": [
#       "time unit"
#     ]
#   },
#   {
#     "terms": [
#       "UO_0000196"
#     ],
#     "types": [
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "Li-Cor"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "millimeter"
#     ],
#     "types": [
#       "length unit"
#     ]
#   },
#   {
#     "terms": [
#       "Beckman Coulter"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "picomolar"
#     ],
#     "types": [
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "degree Celsius"
#     ],
#     "types": [
#       "temperature unit"
#     ]
#   },
#   {
#     "terms": [
#       "picoliter"
#     ],
#     "types": [
#       "volume unit"
#     ]
#   },
#   {
#     "terms": [
#       "Apogee Flow Systems"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "millimolar"
#     ],
#     "types": [
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "Miltenyi Biotec"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "Bentley Instruments"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "Becton Dickinson (BD Biosciences)"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "J. Mitra"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   }
# ]

# %%
import json
from collections import defaultdict

def cluster_terms_by_shared_word(data):
    word_to_terms = defaultdict(set)
    for idx, entry in enumerate(data):
        words = entry['term'].lower().split()
        for w in words:
            word_to_terms[w].add(idx)

    visited = set()
    clusters = []

    def dfs(term_idx, cluster):
        visited.add(term_idx)
        cluster.add(term_idx)
        for w in data[term_idx]['term'].lower().split():
            for neighbor_idx in word_to_terms[w]:
                if neighbor_idx not in visited:
                    dfs(neighbor_idx, cluster)

    for i in range(len(data)):
        if i not in visited:
            cluster = set()
            dfs(i, cluster)
            clusters.append(cluster)

    clustered_output = []
    for cluster in clusters:
        cluster_terms = []
        for idx in cluster:
            cluster_terms.append(data[idx]['term'])
        clustered_output.append({
            'term_indices': cluster,
            'terms': cluster_terms
        })
    return clustered_output

def get_word_set(term):
    return set(term.lower().split())

def find_best_training_match(new_term, training_data):
    new_words = get_word_set(new_term)
    best_match = None
    best_score = -1
    for train_entry in training_data:
        train_words = get_word_set(train_entry['term'])
        shared_words = new_words.intersection(train_words)
        score = len(shared_words)
        if score > best_score:
            best_score = score
            best_match = train_entry
    return best_match, best_score

# Load your training data (with types)
with open('OBI/train/term_typing_train_data.json', 'r', encoding='utf-8') as f:
    training_data = json.load(f)

# Load your new data (without types)
with open("OBI/test/obi_term_typing_test_data.json", 'r', encoding='utf-8' ) as f:
    new_data = json.load(f)

# Step 1: Cluster new terms by shared words
clusters = cluster_terms_by_shared_word(new_data)

# Step 2: For each cluster, find types from training data based on best matches per term
final_clusters = []
for cluster in clusters:
    cluster_types = set()
    for idx in cluster['term_indices']:
        new_term = new_data[idx]['term']
        best_match, score = find_best_training_match(new_term, training_data)
        if best_match and 'types' in best_match:
            cluster_types.update(best_match['types'])
    final_clusters.append({
        'terms': cluster['terms'],
        'types': list(cluster_types) if cluster_types else ['unknown']
    })

print(json.dumps(final_clusters, indent=2))
# Out:
# [
#   {
#     "terms": [
#       "eBioscience"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "pT3 (lung)",
#       "pT2a (ovary)",
#       "pT1b (kidney)",
#       "pM1b (lung)",
#       "pT1c (ovary)",
#       "cM1 (kidney)",
#       "pN1 (kidney)",
#       "pT3a (kidney)",
#       "pT1 (kidney)",
#       "pN2b (colon)",
#       "pT2 (ovary)",
#       "pT2b (lung)",
#       "cM1a (colon)",
#       "cM1 (colon)",
#       "pT1 (lung)",
#       "pN1c (colon)",
#       "cM1 (ovary)",
#       "pM1 (colon)",
#       "pN1b (colon)",
#       "pN1 (lung)",
#       "pT3 (ovary)",
#       "pN2 (colon)",
#       "pM1b (colon)"
#     ],
#     "types": [
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "80-90: symptomatic but fully ambulatory",
#       "3: symptomatic in bed more than 50% of the day but not bed ridden",
#       "2: symptomatic but in bed less than 50% of the day",
#       "4: bed ridden"
#     ],
#     "types": [
#       "Karnofsky score vaue specification",
#       "Eastern Cooperative Oncology Group score value specification"
#     ]
#   },
#   {
#     "terms": [
#       "Antigenix"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "metadata complete",
#       "metadata incomplete"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "0: asymptomatic",
#       "100: asymptomatic"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Cytopeia"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Edingburgh handedness inventory"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "BioGents"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "year"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Stage IIA (AJCC 7th)",
#       "Stage 4 (FIGO)",
#       "Stage IIIC (AJCC 7th)",
#       "Stage IA (FIGO)",
#       "Stage IB (FIGO)",
#       "Stage 1A (FIGO)",
#       "Stage 2C (FIGO)",
#       "Stage IIIB (FIGO)",
#       "Stage 0 (AJCC 7th)",
#       "Stage IIB (FIGO)",
#       "Stage Unknown (FIGO)",
#       "Stage 1B (FIGO)",
#       "Occult Carcinoma (AJCC 7th)",
#       "Stage IIC (AJCC 7th)"
#     ],
#     "types": [
#       "clinical tumor stage group according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification"
#     ]
#   },
#   {
#     "terms": [
#       "tar"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Advanced Instruments Inc. (AI Companies)"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "nanomole"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Bruker Corporation"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "G3: Poorly differentiated"
#     ],
#     "types": [
#       "histologic grade according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Luminex"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Sysmex Corporation, Kobe, Japan"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "organizational term",
#       "failed exploratory term"
#     ],
#     "types": [
#       "obsolescence reason specification"
#     ]
#   },
#   {
#     "terms": [
#       "count per molar second",
#       "microliters per minute"
#     ],
#     "types": [
#       "concentration unit",
#       "rate unit"
#     ]
#   },
#   {
#     "terms": [
#       "nanoliter"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "milliliter"
#     ],
#     "types": [
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "volume percentage"
#     ],
#     "types": [
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "Gating-ML"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "microliter"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "U.S. Food and Drug Administration"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "terms merged"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "pending final vetting"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "GenePattern module PeakMatch",
#       "GenePattern HierarchicalClusteringViewer data visualization",
#       "GenePattern peak matching",
#       "GenePattern SVM",
#       "GenePattern module PCA",
#       "GenePattern module HierarchicalClustering"
#     ],
#     "types": [
#       "GenePattern software",
#       "clustered data visualization"
#     ]
#   },
#   {
#     "terms": [
#       "Illumina"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Partec"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "right handed"
#     ],
#     "types": [
#       "categorical label"
#     ]
#   },
#   {
#     "terms": [
#       "ACS"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "hour"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "AES Chemunex"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "degree Fahrenheit"
#     ],
#     "types": [
#       "temperature unit"
#     ]
#   },
#   {
#     "terms": [
#       "G3 (WHO)"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to the World Health Organization"
#     ]
#   },
#   {
#     "terms": [
#       "Dako Cytomation"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "G4: Undifferentiated"
#     ],
#     "types": [
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "G2 (Fuhrman)"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to the World Health Organization"
#     ]
#   }
# ]

# %% [markdown]
# # "assigning test term to the nearest cluster"

# %%
import json
from collections import defaultdict

def cluster_terms_by_shared_word(data):
    word_to_terms = defaultdict(set)
    for idx, entry in enumerate(data):
        words = entry['term'].lower().split()
        for w in words:
            word_to_terms[w].add(idx)

    visited = set()
    clusters = []

    def dfs(term_idx, cluster):
        visited.add(term_idx)
        cluster.add(term_idx)
        for w in data[term_idx]['term'].lower().split():
            for neighbor_idx in word_to_terms[w]:
                if neighbor_idx not in visited:
                    dfs(neighbor_idx, cluster)

    for i in range(len(data)):
        if i not in visited:
            cluster = set()
            dfs(i, cluster)
            clusters.append(cluster)

    clustered_output = []
    for cluster in clusters:
        cluster_terms = []
        for idx in cluster:
            cluster_terms.append(data[idx]['term'])
        clustered_output.append({
            'term_indices': cluster,
            'terms': cluster_terms
        })
    return clustered_output

def get_word_set(term):
    return set(term.lower().split())

# Load your training data (with types)
with open('OBI/train/term_typing_train_data.json', 'r', encoding='utf-8') as f:
    training_data = json.load(f)

# Load your new data (without types)
with open("OBI/test/obi_term_typing_test_data.json", 'r', encoding='utf-8') as f:
    new_data = json.load(f)

# Step 1: Cluster training data
training_clusters = cluster_terms_by_shared_word(training_data)

# Step 2: Cluster new/test data
test_clusters = cluster_terms_by_shared_word(new_data)

# Precompute training cluster terms sets (list of word sets per term)
training_cluster_wordsets = []
for cluster in training_clusters:
    cluster_wordsets = []
    for idx in cluster['term_indices']:
        cluster_wordsets.append(get_word_set(training_data[idx]['term']))
    training_cluster_wordsets.append(cluster_wordsets)

# Step 3: For each test term, find best matching training cluster
final_clusters = []

for test_cluster in test_clusters:
    cluster_types = set()
    for test_idx in test_cluster['term_indices']:
        test_term = new_data[test_idx]['term']
        test_words = get_word_set(test_term)

        best_cluster_idx = None
        best_score = 0

        # Compare with each training cluster
        for i, cluster_wordsets in enumerate(training_cluster_wordsets):
            # For each training term in cluster, calculate shared words with test term
            cluster_score = 0
            for train_words in cluster_wordsets:
                shared = test_words.intersection(train_words)
                cluster_score = max(cluster_score, len(shared))
            if cluster_score > best_score:
                best_score = cluster_score
                best_cluster_idx = i

        if best_cluster_idx is not None and best_score > 0:
            # Collect types from that training cluster terms
            # Here collect all types from all terms in that cluster
            for train_idx in training_clusters[best_cluster_idx]['term_indices']:
                if 'types' in training_data[train_idx]:
                    cluster_types.update(training_data[train_idx]['types'])
        else:
            # No good match found for this term
            cluster_types.add('unknown')

    final_clusters.append({
        'terms': test_cluster['terms'],
        'types': list(cluster_types) if cluster_types else ['unknown']
    })

print(json.dumps(final_clusters, indent=2))
# Out:
# [
#   {
#     "terms": [
#       "eBioscience"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "pT3 (lung)",
#       "pT2a (ovary)",
#       "pT1b (kidney)",
#       "pM1b (lung)",
#       "pT1c (ovary)",
#       "cM1 (kidney)",
#       "pN1 (kidney)",
#       "pT3a (kidney)",
#       "pT1 (kidney)",
#       "pN2b (colon)",
#       "pT2 (ovary)",
#       "pT2b (lung)",
#       "cM1a (colon)",
#       "cM1 (colon)",
#       "pT1 (lung)",
#       "pN1c (colon)",
#       "cM1 (ovary)",
#       "pM1 (colon)",
#       "pN1b (colon)",
#       "pN1 (lung)",
#       "pT3 (ovary)",
#       "pN2 (colon)",
#       "pM1b (colon)"
#     ],
#     "types": [
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "80-90: symptomatic but fully ambulatory",
#       "3: symptomatic in bed more than 50% of the day but not bed ridden",
#       "2: symptomatic but in bed less than 50% of the day",
#       "4: bed ridden"
#     ],
#     "types": [
#       "obsolescence reason specification",
#       "Karnofsky score vaue specification",
#       "Eastern Cooperative Oncology Group score value specification"
#     ]
#   },
#   {
#     "terms": [
#       "Antigenix"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "metadata complete",
#       "metadata incomplete"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "0: asymptomatic",
#       "100: asymptomatic"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "Cytopeia"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "Edingburgh handedness inventory"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "BioGents"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "year"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "Stage IIA (AJCC 7th)",
#       "Stage 4 (FIGO)",
#       "Stage IIIC (AJCC 7th)",
#       "Stage IA (FIGO)",
#       "Stage IB (FIGO)",
#       "Stage 1A (FIGO)",
#       "Stage 2C (FIGO)",
#       "Stage IIIB (FIGO)",
#       "Stage 0 (AJCC 7th)",
#       "Stage IIB (FIGO)",
#       "Stage Unknown (FIGO)",
#       "Stage 1B (FIGO)",
#       "Occult Carcinoma (AJCC 7th)",
#       "Stage IIC (AJCC 7th)"
#     ],
#     "types": [
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification"
#     ]
#   },
#   {
#     "terms": [
#       "tar"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "Advanced Instruments Inc. (AI Companies)"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "nanomole"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "Bruker Corporation"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "G3: Poorly differentiated"
#     ],
#     "types": [
#       "histologic grade according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Luminex"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "Sysmex Corporation, Kobe, Japan"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "organizational term",
#       "failed exploratory term"
#     ],
#     "types": [
#       "curation status specification",
#       "obsolescence reason specification"
#     ]
#   },
#   {
#     "terms": [
#       "count per molar second",
#       "microliters per minute"
#     ],
#     "types": [
#       "mass unit",
#       "volume unit",
#       "time unit",
#       "rate unit",
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "nanoliter"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "milliliter"
#     ],
#     "types": [
#       "mass unit",
#       "volume unit",
#       "time unit",
#       "rate unit",
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "volume percentage"
#     ],
#     "types": [
#       "mass unit",
#       "volume unit",
#       "time unit",
#       "rate unit",
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "Gating-ML"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "microliter"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "U.S. Food and Drug Administration"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "terms merged"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "pending final vetting"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "GenePattern module PeakMatch",
#       "GenePattern HierarchicalClusteringViewer data visualization",
#       "GenePattern peak matching",
#       "GenePattern SVM",
#       "GenePattern module PCA",
#       "GenePattern module HierarchicalClustering"
#     ],
#     "types": [
#       "clustered data visualization",
#       "principal components analysis dimensionality reduction",
#       "leave one out cross validation method",
#       "GenePattern software",
#       "hierarchical clustering",
#       "CART",
#       "k-means clustering",
#       "k-nearest neighbors"
#     ]
#   },
#   {
#     "terms": [
#       "Illumina"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "Partec"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "right handed"
#     ],
#     "types": [
#       "categorical label"
#     ]
#   },
#   {
#     "terms": [
#       "ACS"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "hour"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "AES Chemunex"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "degree Fahrenheit"
#     ],
#     "types": [
#       "temperature unit"
#     ]
#   },
#   {
#     "terms": [
#       "G3 (WHO)"
#     ],
#     "types": [
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "histologic grade for ovarian tumor according to the World Health Organization"
#     ]
#   },
#   {
#     "terms": [
#       "Dako Cytomation"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "G4: Undifferentiated"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "G2 (Fuhrman)"
#     ],
#     "types": [
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "histologic grade for ovarian tumor according to the World Health Organization"
#     ]
#   }
# ]

# %%
data
# Out:
# [{'id': 'TT_9bd33766',
#   'term': 'pT3 (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_4c6560da',
#   'term': 'GenePattern module KMeansClustering',
#   'types': ['GenePattern software']},
#  {'id': 'TT_b6596f1b',
#   'term': 'Stage IIIA (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_e6e9e758', 'term': 'angstrom', 'types': ['length unit']},
#  {'id': 'TT_94550005',
#   'term': 'pT1 (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_d0023073',
#   'term': 'Stage 1 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_5b5aa1c3', 'term': 'hertz', 'types': ['frequency unit']},
#  {'id': 'TT_0e0deac9', 'term': 'Waters', 'types': ['manufacturer']},
#  {'id': 'TT_c58ed932',
#   'term': 'pT3b (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_bc607e9c',
#   'term': 'pT2 (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_81ed86a2', 'term': 'Thermo', 'types': ['manufacturer']},
#  {'id': 'TT_55e6ce7b',
#   'term': 'cM0 (ovary)',
#   'types': ['pathologic distant metastases stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_7a25d420',
#   'term': 'pT3a (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_3d3de651', 'term': 'Abbott', 'types': ['manufacturer']},
#  {'id': 'TT_657e1551',
#   'term': 'pT1b (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_2c76621e',
#   'term': 'Stage 2A (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_7214dc4b',
#   'term': 'cM1 (lung)',
#   'types': ['pathologic distant metastases stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_eaf883e3',
#   'term': 'pT1a (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_dcc5f3ca', 'term': 'XML', 'types': ['data format specification']},
#  {'id': 'TT_17ccd198', 'term': 'kilogram', 'types': ['mass unit']},
#  {'id': 'TT_6068ba1b',
#   'term': 'ambidexterous',
#   'types': ['categorical label']},
#  {'id': 'TT_883a0325',
#   'term': 'pN2a (colon)',
#   'types': ['pathologic lymph node stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_68fb07d1',
#   'term': 'ready for release',
#   'types': ['curation status specification']},
#  {'id': 'TT_a66b6532',
#   'term': 'Stage IVB (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_0eb4e499', 'term': 'nanogram', 'types': ['mass unit']},
#  {'id': 'TT_78f62994',
#   'term': 'term imported',
#   'types': ['obsolescence reason specification']},
#  {'id': 'TT_e9687e72', 'term': 'picogram', 'types': ['mass unit']},
#  {'id': 'TT_20c32a48', 'term': 'nanomolar', 'types': ['concentration unit']},
#  {'id': 'TT_9bc660ea',
#   'term': 'pT2 (colon)',
#   'types': ['pathologic primary tumor stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_605344f6', 'term': 'molar', 'types': ['concentration unit']},
#  {'id': 'TT_b25bd924', 'term': 'GenePattern CART', 'types': ['CART']},
#  {'id': 'TT_3991b20a', 'term': 'Ambion', 'types': ['manufacturer']},
#  {'id': 'TT_ee6391c4',
#   'term': 'cM1a (lung)',
#   'types': ['pathologic distant metastases stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_e5622d07', 'term': 'defined class', 'types': ['denotator type']},
#  {'id': 'TT_36ab6b7d', 'term': 'Affymetrix', 'types': ['material supplier']},
#  {'id': 'TT_4b874305',
#   'term': 'Applied Biosystems',
#   'types': ['manufacturer']},
#  {'id': 'TT_05af131a',
#   'term': 'pT0 (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_d4bd9842',
#   'term': 'pT2 (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_1937f53e',
#   'term': 'mass percentage',
#   'types': ['concentration unit']},
#  {'id': 'TT_7aba900b',
#   'term': 'pT2a (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_abb10ac7',
#   'term': 'pT2c (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_bb5e202f',
#   'term': 'Stage IVA (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_26e0c5ee', 'term': 'micrometer', 'types': ['length unit']},
#  {'id': 'TT_523b293a',
#   'term': 'gram per liter',
#   'types': ['concentration unit']},
#  {'id': 'TT_814c97f2', 'term': 'InBios', 'types': ['manufacturer']},
#  {'id': 'TT_f61ab8ea', 'term': 'OWL', 'types': ['data format specification']},
#  {'id': 'TT_8d308379',
#   'term': 'G1 (WHO)',
#   'types': ['histologic grade for ovarian tumor according to the World Health Organization']},
#  {'id': 'TT_0c91b808',
#   'term': 'Stage IB2 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_85dad973',
#   'term': 'pN2 (lung)',
#   'types': ['pathologic lymph node stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_01ff4b29',
#   'term': 'colony forming unit per volume',
#   'types': ['concentration unit']},
#  {'id': 'TT_14f53e1a',
#   'term': 'Stage IIIA (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_5fa25606',
#   'term': 'pT3c (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_18e3ef24', 'term': 'cubic decimeter', 'types': ['volume unit']},
#  {'id': 'TT_98acab18', 'term': 'week', 'types': ['time unit']},
#  {'id': 'TT_20569446', 'term': 'Bruker Daltonics', 'types': ['manufacturer']},
#  {'id': 'TT_47b9fb62',
#   'term': 'to be replaced with external ontology term',
#   'types': ['curation status specification']},
#  {'id': 'TT_f42e16d9',
#   'term': 'G1: Well differentiated',
#   'types': ['histologic grade according to AJCC 7th edition']},
#  {'id': 'TT_faeae7c2',
#   'term': 'pT3 (colon)',
#   'types': ['pathologic primary tumor stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_4fc382af',
#   'term': 'pN0 (ovary)',
#   'types': ['pathologic lymph node stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_39037f68',
#   'term': 'GenePattern PCA',
#   'types': ['principal components analysis dimensionality reduction']},
#  {'id': 'TT_62fa20d2', 'term': 'FCS', 'types': ['data format specification']},
#  {'id': 'TT_30868e97',
#   'term': 'Stage IVA (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_ecd08cc3',
#   'term': 'pT3b (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_7040d4f1', 'term': 'count per nanomolar', 'types': ['rate unit']},
#  {'id': 'TT_ab4fcb3a', 'term': 'Affymetrix', 'types': ['manufacturer']},
#  {'id': 'TT_1b718697',
#   'term': 'GenePattern module HierarchicalClusteringViewer',
#   'types': ['GenePattern software']},
#  {'id': 'TT_003de4fc',
#   'term': 'Stage 2 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_1a7de038', 'term': 'minute', 'types': ['time unit']},
#  {'id': 'TT_5636e285',
#   'term': 'NanoString Technologies',
#   'types': ['manufacturer']},
#  {'id': 'TT_07fc7a95', 'term': 'nanometer', 'types': ['length unit']},
#  {'id': 'TT_5d1b7dac', 'term': 'second', 'types': ['time unit']},
#  {'id': 'TT_df086e15',
#   'term': 'mass volume percentage',
#   'types': ['concentration unit']},
#  {'id': 'TT_dede89f9',
#   'term': 'Transformation-ML',
#   'types': ['data format specification']},
#  {'id': 'TT_2ba30eaf',
#   'term': 'Stage 2B (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_0a674c3c',
#   'term': 'Stage I (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_422b7b0c',
#   'term': 'requires discussion',
#   'types': ['curation status specification']},
#  {'id': 'TT_65641737', 'term': 'universal', 'types': ['denotator type']},
#  {'id': 'TT_d364c4e6',
#   'term': 'G2 (WHO)',
#   'types': ['histologic grade for ovarian tumor according to the World Health Organization']},
#  {'id': 'TT_ee0002c1',
#   'term': 'term split',
#   'types': ['obsolescence reason specification']},
#  {'id': 'TT_553e4075',
#   'term': 'pM1 (lung)',
#   'types': ['pathologic distant metastases stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_0c2da95d',
#   'term': 'pT0 (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_d4b5ebb3',
#   'term': 'placeholder removed',
#   'types': ['obsolescence reason specification']},
#  {'id': 'TT_92928a19',
#   'term': 'Thermo Fisher Scientific',
#   'types': ['organization']},
#  {'id': 'TT_4caa0d40', 'term': 'Agilent', 'types': ['manufacturer']},
#  {'id': 'TT_e30c2d7d',
#   'term': 'Stage IVB (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_6ad91ea9',
#   'term': 'G3 (Fuhrman)',
#   'types': ['histologic grade according to the Fuhrman Nuclear Grading System']},
#  {'id': 'TT_4a30b5aa',
#   'term': 'uncurated',
#   'types': ['curation status specification']},
#  {'id': 'TT_708ae486',
#   'term': 'Stage IB1 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_e90520c2',
#   'term': 'pN1 (ovary)',
#   'types': ['pathologic lymph node stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_ff3fa730',
#   'term': 'Stage 3 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_c07fd6ec',
#   'term': 'cM1b (lung)',
#   'types': ['pathologic distant metastases stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_a5910687',
#   'term': 'Compensation-ML',
#   'types': ['data format specification']},
#  {'id': 'TT_8a8c04f4',
#   'term': 'G1 (Fuhrman)',
#   'types': ['histologic grade according to the Fuhrman Nuclear Grading System']},
#  {'id': 'TT_6c5fbf04', 'term': 'picomole', 'types': ['substance unit']},
#  {'id': 'TT_c89e0ebb',
#   'term': 'pT1a (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_c57b3ee6', 'term': 'RDF', 'types': ['data format specification']},
#  {'id': 'TT_a857198d',
#   'term': 'example to be eventually removed',
#   'types': ['curation status specification']},
#  {'id': 'TT_c9b3be71',
#   'term': 'pT1a (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_08542539',
#   'term': 'pN0 (colon)',
#   'types': ['pathologic lymph node stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_9d2b6bd4',
#   'term': 'pT4 (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_b75f1878',
#   'term': 'microgram per liter',
#   'types': ['concentration unit']},
#  {'id': 'TT_1c3bfc15', 'term': 'Helicos', 'types': ['manufacturer']},
#  {'id': 'TT_dfe4255e',
#   'term': 'gram per deciliter',
#   'types': ['concentration unit']},
#  {'id': 'TT_d84b59e8', 'term': 'micromolar', 'types': ['concentration unit']},
#  {'id': 'TT_8727dad0',
#   'term': 'Stage 1C (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_2bbed016',
#   'term': 'Low grade ovarian tumor',
#   'types': ['histologic grade for ovarian tumor according to a two-tier grading system']},
#  {'id': 'TT_694f79ff', 'term': 'Millipore', 'types': ['manufacturer']},
#  {'id': 'TT_0d6c8c10',
#   'term': 'pM1 (kidney)',
#   'types': ['pathologic distant metastases stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_e0fffdcb', 'term': 'Invitrogen', 'types': ['manufacturer']},
#  {'id': 'TT_885d8bf6', 'term': 'BIO-RAD', 'types': ['manufacturer']},
#  {'id': 'TT_96d3919e',
#   'term': 'G4 (Fuhrman)',
#   'types': ['histologic grade according to the Fuhrman Nuclear Grading System']},
#  {'id': 'TT_3966f1b7',
#   'term': 'pT0 (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_6b26ffdb', 'term': 'Nimblegen', 'types': ['manufacturer']},
#  {'id': 'TT_349d7ef1',
#   'term': 'pT2b (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_fa5d5c2e',
#   'term': 'GenePattern k-nearest neighbors',
#   'types': ['k-nearest neighbors']},
#  {'id': 'TT_e5b3f935',
#   'term': 'count per nanomolar second',
#   'types': ['rate unit']},
#  {'id': 'TT_d8414764',
#   'term': 'cM1b (colon)',
#   'types': ['pathologic distant metastases stage for colon according to AJCC 7th edition']},
#  {'id': 'TT_94c6af55', 'term': 'meter', 'types': ['length unit']},
#  {'id': 'TT_826fbb4e',
#   'term': 'High grade ovarian tumor',
#   'types': ['histologic grade for ovarian tumor according to a two-tier grading system']},
#  {'id': 'TT_dc8304fe',
#   'term': 'GenePattern hierarchical clustering',
#   'types': ['hierarchical clustering']},
#  {'id': 'TT_143c6010', 'term': 'Exbio Antibodies', 'types': ['manufacturer']},
#  {'id': 'TT_5c451799',
#   'term': 'Stage IA2 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_cf9fc5ba',
#   'term': 'pT2a (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_e707584c', 'term': 'UO_0000033', 'types': ['time unit']},
#  {'id': 'TT_581acc6c',
#   'term': 'GenePattern HeatMapViewer data visualization',
#   'types': ['clustered data visualization']},
#  {'id': 'TT_7ce1154b', 'term': 'Roche', 'types': ['manufacturer']},
#  {'id': 'TT_f47a5fee',
#   'term': 'GenePattern module KNN',
#   'types': ['GenePattern software']},
#  {'id': 'TT_e65f00bd',
#   'term': 'cM0 (kidney)',
#   'types': ['pathologic distant metastases stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_dfc2cf83', 'term': 'microgram', 'types': ['mass unit']},
#  {'id': 'TT_558a0e70',
#   'term': 'pN1 (colon)',
#   'types': ['pathologic lymph node stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_d2959554',
#   'term': 'pT4 (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_fd4c47f8',
#   'term': 'Pacific Biosciences',
#   'types': ['manufacturer']},
#  {'id': 'TT_421d851b',
#   'term': 'Stage IIA1 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_743bae35',
#   'term': 'Stage IIB (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_3238be02',
#   'term': 'pTis (colon)',
#   'types': ['pathologic primary tumor stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_298f8185',
#   'term': 'Stage IIA2 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_2174e491',
#   'term': 'Stage IIA (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_edec8f58', 'term': 'micromole', 'types': ['substance unit']},
#  {'id': 'TT_0f614899',
#   'term': 'pN0 (lung)',
#   'types': ['pathologic lymph node stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_88d9ca0b',
#   'term': 'Exalpha Biological',
#   'types': ['manufacturer']},
#  {'id': 'TT_570fa86e',
#   'term': 'milliliter per liter',
#   'types': ['concentration unit']},
#  {'id': 'TT_a0e3cf77',
#   'term': 'named class expression',
#   'types': ['denotator type']},
#  {'id': 'TT_0acb01fd',
#   'term': 'cM0 (lung)',
#   'types': ['pathologic distant metastases stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_821f2e64',
#   'term': 'GenePattern LOOCV',
#   'types': ['leave one out cross validation method']},
#  {'id': 'TT_a3f8d92c', 'term': 'CytoBuoy', 'types': ['manufacturer']},
#  {'id': 'TT_abaf192d',
#   'term': 'pTis (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_bc957440', 'term': 'left handed', 'types': ['categorical label']},
#  {'id': 'TT_c439f606',
#   'term': 'pN1a (colon)',
#   'types': ['pathologic lymph node stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_8ca31a8c', 'term': 'zip', 'types': ['data format specification']},
#  {'id': 'TT_dcd710ae', 'term': 'gram', 'types': ['mass unit']},
#  {'id': 'TT_5c487d9c',
#   'term': '40-50: symptomatic, in bed more than 50% of the day, but not bed ridden',
#   'types': ['Karnofsky score vaue specification']},
#  {'id': 'TT_bf108953', 'term': 'cubic centimeter', 'types': ['volume unit']},
#  {'id': 'TT_e2f371be', 'term': 'month', 'types': ['time unit']},
#  {'id': 'TT_6b0627c3', 'term': 'milligram', 'types': ['mass unit']},
#  {'id': 'TT_6d478ed2',
#   'term': 'pN0 (kidney)',
#   'types': ['pathologic lymph node stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_eb02c243',
#   'term': 'GenePattern module HeatMapViewer',
#   'types': ['GenePattern software']},
#  {'id': 'TT_52ba72b1',
#   'term': 'G2: Moderately differentiated',
#   'types': ['histologic grade according to AJCC 7th edition']},
#  {'id': 'TT_44173727', 'term': 'UO_0000196', 'types': ['concentration unit']},
#  {'id': 'TT_b053af21', 'term': 'Li-Cor', 'types': ['manufacturer']},
#  {'id': 'TT_3aa2dd1a',
#   'term': 'GenePattern module SVM',
#   'types': ['GenePattern software']},
#  {'id': 'TT_970dc9c4',
#   'term': '60-70: symptomatic but in bed less than 50% of the day',
#   'types': ['Karnofsky score vaue specification']},
#  {'id': 'TT_fd3ff81b', 'term': 'millimeter', 'types': ['length unit']},
#  {'id': 'TT_c6e90295',
#   'term': 'GenePattern k-means clustering',
#   'types': ['k-means clustering']},
#  {'id': 'TT_56f8244a', 'term': 'Beckman Coulter', 'types': ['manufacturer']},
#  {'id': 'TT_392415df',
#   'term': 'GenePattern module KNNXValidation',
#   'types': ['GenePattern software']},
#  {'id': 'TT_2fb31d29', 'term': 'picomolar', 'types': ['concentration unit']},
#  {'id': 'TT_d37ec330',
#   'term': 'degree Celsius',
#   'types': ['temperature unit']},
#  {'id': 'TT_02b3c3c5', 'term': 'picoliter', 'types': ['volume unit']},
#  {'id': 'TT_af1598a1',
#   'term': 'Apogee Flow Systems',
#   'types': ['manufacturer']},
#  {'id': 'TT_1db40484',
#   'term': 'Stage 3B (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_980355d1', 'term': 'millimolar', 'types': ['concentration unit']},
#  {'id': 'TT_52e8d75a',
#   'term': 'Stage 3C (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_0772b801', 'term': 'centimeter', 'types': ['length unit']},
#  {'id': 'TT_6d1e6c6f', 'term': 'Miltenyi Biotec', 'types': ['manufacturer']},
#  {'id': 'TT_d645253a',
#   'term': 'Bentley Instruments',
#   'types': ['manufacturer']},
#  {'id': 'TT_6a3a681c',
#   'term': 'pM1 (ovary)',
#   'types': ['pathologic distant metastases stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_ee46797e',
#   'term': 'pT1 (colon)',
#   'types': ['pathologic primary tumor stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_7571f15b',
#   'term': 'pT0 (colon)',
#   'types': ['pathologic primary tumor stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_7769049d', 'term': 'liter', 'types': ['volume unit']},
#  {'id': 'TT_2055d1b6',
#   'term': 'Oxford Nanopore Technologies',
#   'types': ['manufacturer']},
#  {'id': 'TT_e41a6412',
#   'term': 'Becton Dickinson (BD Biosciences)',
#   'types': ['manufacturer']},
#  {'id': 'TT_9f8cd2fc',
#   'term': 'pT2b (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_15a31dcb',
#   'term': '1: symptomatic but fully ambulatory',
#   'types': ['Eastern Cooperative Oncology Group score value specification']},
#  {'id': 'TT_c0dd08d3',
#   'term': 'cM0 (colon)',
#   'types': ['pathologic distant metastases stage for colon according to AJCC 7th edition']},
#  {'id': 'TT_0e360ddc',
#   'term': 'pT1b (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_14d26f3d',
#   'term': 'pT4a (colon)',
#   'types': ['pathologic primary tumor stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_6f5bf410',
#   'term': 'G4 (WHO)',
#   'types': ['histologic grade for ovarian tumor according to the World Health Organization']},
#  {'id': 'TT_14aa01c2',
#   'term': 'Stage IIIB (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_ac49ecc6',
#   'term': 'milligram per milliliter',
#   'types': ['concentration unit']},
#  {'id': 'TT_ffb83a18', 'term': 'count per molar', 'types': ['rate unit']},
#  {'id': 'TT_98313127',
#   'term': 'out of scope',
#   'types': ['obsolescence reason specification']},
#  {'id': 'TT_b6fa757c',
#   'term': 'GenePattern module CARTXValidation',
#   'types': ['GenePattern software']},
#  {'id': 'TT_5538bb11',
#   'term': 'Stage IA1 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification']},
#  {'id': 'TT_fbd5881f',
#   'term': 'pT3c (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_eace9cab',
#   'term': 'Stage 3A (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_d6e4f14c',
#   'term': 'pM1a (colon)',
#   'types': ['pathologic distant metastases stage for colon according to AJCC 7th edition']},
#  {'id': 'TT_7a047daa',
#   'term': 'pT4b (colon)',
#   'types': ['pathologic primary tumor stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_e5fdba1a', 'term': 'J. Mitra', 'types': ['manufacturer']},
#  {'id': 'TT_bec9d74e',
#   'term': 'pN3 (lung)',
#   'types': ['pathologic lymph node stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_46c62879',
#   'term': 'pM1a (lung)',
#   'types': ['pathologic distant metastases stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_c8e65cf0',
#   'term': 'domain entity does not exist',
#   'types': ['obsolescence reason specification']}]

# %%
all_unique_types = []
for data_1 in data:
    if data_1['types'][0] not in all_unique_types:
        all_unique_types.append(data_1['types'][0])

# %%
all_unique_types
# Out:
# ['pathologic primary tumor stage for kidney according to AJCC 7th edition',
#  'GenePattern software',
#  'International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#  'length unit',
#  'pathologic primary tumor stage for ovary according to AJCC 7th edition',
#  'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification',
#  'frequency unit',
#  'manufacturer',
#  'pathologic distant metastases stage for ovary according to AJCC 7th edition',
#  'pathologic distant metastases stage for lung according to AJCC 7th edition',
#  'data format specification',
#  'mass unit',
#  'categorical label',
#  'pathologic lymph node stage for colon and rectum according to AJCC 7th edition',
#  'curation status specification',
#  'obsolescence reason specification',
#  'concentration unit',
#  'pathologic primary tumor stage for colon and rectum according to AJCC 7th edition',
#  'CART',
#  'denotator type',
#  'material supplier',
#  'pathologic primary tumor stage for lung according to AJCC 7th edition',
#  'histologic grade for ovarian tumor according to the World Health Organization',
#  'pathologic lymph node stage for lung according to AJCC 7th edition',
#  'clinical tumor stage group according to AJCC 7th edition',
#  'volume unit',
#  'time unit',
#  'histologic grade according to AJCC 7th edition',
#  'pathologic lymph node stage for ovary according to AJCC 7th edition',
#  'principal components analysis dimensionality reduction',
#  'rate unit',
#  'organization',
#  'histologic grade according to the Fuhrman Nuclear Grading System',
#  'substance unit',
#  'histologic grade for ovarian tumor according to a two-tier grading system',
#  'pathologic distant metastases stage for kidney according to AJCC 7th edition',
#  'k-nearest neighbors',
#  'pathologic distant metastases stage for colon according to AJCC 7th edition',
#  'hierarchical clustering',
#  'clustered data visualization',
#  'leave one out cross validation method',
#  'Karnofsky score vaue specification',
#  'pathologic lymph node stage for kidney according to AJCC 7th edition',
#  'k-means clustering',
#  'temperature unit',
#  'Eastern Cooperative Oncology Group score value specification']

# %%
for test_idx in test_cluster['term_indices']:
    test_term = new_data[test_idx]['term']
    test_words = get_word_set(test_term)  # split test term by spaces to words

    best_cluster_idx = None
    best_score = 0

    # Iterate through each training cluster
    for i, cluster_wordsets in enumerate(training_cluster_wordsets):
        cluster_score = 0
        # Check against each training term in this cluster
        for train_words in cluster_wordsets:
            # train_words is word set of training term
            shared = test_words.intersection(train_words)  # word-based intersection
            cluster_score = max(cluster_score, len(shared))  # take max overlap in this cluster
        if cluster_score > best_score:
            best_score = cluster_score
            best_cluster_idx = i

    # If match found, collect types from best matching training cluster
    if best_cluster_idx is not None and best_score > 0:
        for train_idx in training_clusters[best_cluster_idx]['term_indices']:
            if 'types' in training_data[train_idx]:
                cluster_types.update(training_data[train_idx]['types'])
    else:
        # No match found
        cluster_types.update(all_unique_types)

# %%
cluster_types
# Out:
# {'histologic grade according to the Fuhrman Nuclear Grading System',
#  'histologic grade for ovarian tumor according to the World Health Organization'}

# %%
import json
from collections import defaultdict

def cluster_terms_by_shared_word(data):
    word_to_terms = defaultdict(set)
    for idx, entry in enumerate(data):
        words = entry['term'].lower().split()
        for w in words:
            word_to_terms[w].add(idx)

    visited = set()
    clusters = []

    def dfs(term_idx, cluster):
        visited.add(term_idx)
        cluster.add(term_idx)
        for w in data[term_idx]['term'].lower().split():
            for neighbor_idx in word_to_terms[w]:
                if neighbor_idx not in visited:
                    dfs(neighbor_idx, cluster)

    for i in range(len(data)):
        if i not in visited:
            cluster = set()
            dfs(i, cluster)
            clusters.append(cluster)

    clustered_output = []
    for cluster in clusters:
        cluster_terms = []
        for idx in cluster:
            cluster_terms.append(data[idx]['term'])
        clustered_output.append({
            'term_indices': cluster,
            'terms': cluster_terms
        })
    return clustered_output

def get_word_set(term):
    return set(term.lower().split())

# Load your training data (with types)
with open('OBI/train/term_typing_train_data.json', 'r', encoding='utf-8') as f:
    training_data = json.load(f)

# Load your new data (without types)
with open("OBI/test/obi_term_typing_test_data.json", 'r', encoding='utf-8') as f:
    new_data = json.load(f)

# Precompute all unique types in training data
all_unique_types = set()
for entry in training_data:
    if 'types' in entry:
        all_unique_types.update(entry['types'])

# Step 1: Cluster training data
training_clusters = cluster_terms_by_shared_word(training_data)

# Step 2: Cluster new/test data
test_clusters = cluster_terms_by_shared_word(new_data)

# Precompute training cluster terms sets (list of word sets per term)
training_cluster_wordsets = []
for cluster in training_clusters:
    cluster_wordsets = []
    for idx in cluster['term_indices']:
        cluster_wordsets.append(get_word_set(training_data[idx]['term']))
    training_cluster_wordsets.append(cluster_wordsets)

# Step 3: For each test term, find best matching training cluster
final_clusters = []

for test_cluster in test_clusters:
    cluster_types = set()
    for test_idx in test_cluster['term_indices']:
        test_term = new_data[test_idx]['term']
        test_words = get_word_set(test_term)

        best_cluster_idx = None
        best_score = 0

        # Compare with each training cluster
        for i, cluster_wordsets in enumerate(training_cluster_wordsets):
            cluster_score = 0
            for train_words in cluster_wordsets:
                shared = test_words.intersection(train_words)
                cluster_score = max(cluster_score, len(shared))
            if cluster_score > best_score:
                best_score = cluster_score
                best_cluster_idx = i

        if best_cluster_idx is not None and best_score > 0:
            # Collect types from that training cluster terms
            for train_idx in training_clusters[best_cluster_idx]['term_indices']:
                if 'types' in training_data[train_idx]:
                    cluster_types.update(training_data[train_idx]['types'])
        else:
            # No good match found: assign all unique training types
            cluster_types.update(all_unique_types)

    final_clusters.append({
        'terms': test_cluster['terms'],
        'types': list(cluster_types) if cluster_types else ['unknown']
    })

print(json.dumps(final_clusters, indent=2))
# Out:
# [
#   {
#     "terms": [
#       "eBioscience"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "pT3 (lung)",
#       "pT2a (ovary)",
#       "pT1b (kidney)",
#       "pM1b (lung)",
#       "pT1c (ovary)",
#       "cM1 (kidney)",
#       "pN1 (kidney)",
#       "pT3a (kidney)",
#       "pT1 (kidney)",
#       "pN2b (colon)",
#       "pT2 (ovary)",
#       "pT2b (lung)",
#       "cM1a (colon)",
#       "cM1 (colon)",
#       "pT1 (lung)",
#       "pN1c (colon)",
#       "cM1 (ovary)",
#       "pM1 (colon)",
#       "pN1b (colon)",
#       "pN1 (lung)",
#       "pT3 (ovary)",
#       "pN2 (colon)",
#       "pM1b (colon)"
#     ],
#     "types": [
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "80-90: symptomatic but fully ambulatory",
#       "3: symptomatic in bed more than 50% of the day but not bed ridden",
#       "2: symptomatic but in bed less than 50% of the day",
#       "4: bed ridden"
#     ],
#     "types": [
#       "obsolescence reason specification",
#       "Karnofsky score vaue specification",
#       "Eastern Cooperative Oncology Group score value specification"
#     ]
#   },
#   {
#     "terms": [
#       "Antigenix"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "metadata complete",
#       "metadata incomplete"
#     ],
#     "types": [
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "k-nearest neighbors",
#       "leave one out cross validation method",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "mass unit",
#       "length unit",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "rate unit",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition",
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "concentration unit",
#       "Karnofsky score vaue specification",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "clustered data visualization",
#       "substance unit",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "data format specification",
#       "obsolescence reason specification",
#       "time unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "0: asymptomatic",
#       "100: asymptomatic"
#     ],
#     "types": [
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "k-nearest neighbors",
#       "leave one out cross validation method",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "mass unit",
#       "length unit",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "rate unit",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition",
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "concentration unit",
#       "Karnofsky score vaue specification",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "clustered data visualization",
#       "substance unit",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "data format specification",
#       "obsolescence reason specification",
#       "time unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Cytopeia"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Edingburgh handedness inventory"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "BioGents"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "year"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Stage IIA (AJCC 7th)",
#       "Stage 4 (FIGO)",
#       "Stage IIIC (AJCC 7th)",
#       "Stage IA (FIGO)",
#       "Stage IB (FIGO)",
#       "Stage 1A (FIGO)",
#       "Stage 2C (FIGO)",
#       "Stage IIIB (FIGO)",
#       "Stage 0 (AJCC 7th)",
#       "Stage IIB (FIGO)",
#       "Stage Unknown (FIGO)",
#       "Stage 1B (FIGO)",
#       "Occult Carcinoma (AJCC 7th)",
#       "Stage IIC (AJCC 7th)"
#     ],
#     "types": [
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification"
#     ]
#   },
#   {
#     "terms": [
#       "tar"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Advanced Instruments Inc. (AI Companies)"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "nanomole"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Bruker Corporation"
#     ],
#     "types": [
#       "manufacturer"
#     ]
#   },
#   {
#     "terms": [
#       "G3: Poorly differentiated"
#     ],
#     "types": [
#       "histologic grade according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Luminex"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Sysmex Corporation, Kobe, Japan"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "organizational term",
#       "failed exploratory term"
#     ],
#     "types": [
#       "curation status specification",
#       "obsolescence reason specification"
#     ]
#   },
#   {
#     "terms": [
#       "count per molar second",
#       "microliters per minute"
#     ],
#     "types": [
#       "mass unit",
#       "volume unit",
#       "time unit",
#       "rate unit",
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "nanoliter"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "milliliter"
#     ],
#     "types": [
#       "mass unit",
#       "volume unit",
#       "time unit",
#       "rate unit",
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "volume percentage"
#     ],
#     "types": [
#       "mass unit",
#       "volume unit",
#       "time unit",
#       "rate unit",
#       "concentration unit"
#     ]
#   },
#   {
#     "terms": [
#       "Gating-ML"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "microliter"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "U.S. Food and Drug Administration"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "terms merged"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "pending final vetting"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
# ...
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "Partec"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "right handed"
#     ],
#     "types": [
#       "categorical label"
#     ]
#   },
#   {
#     "terms": [
#       "ACS"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "hour"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "AES Chemunex"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "degree Fahrenheit"
#     ],
#     "types": [
#       "temperature unit"
#     ]
#   },
#   {
#     "terms": [
#       "G3 (WHO)"
#     ],
#     "types": [
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "histologic grade for ovarian tumor according to the World Health Organization"
#     ]
#   },
#   {
#     "terms": [
#       "Dako Cytomation"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "G4: Undifferentiated"
#     ],
#     "types": [
#       "histologic grade for ovarian tumor according to a two-tier grading system",
#       "histologic grade according to AJCC 7th edition",
#       "pathologic primary tumor stage for kidney according to AJCC 7th edition",
#       "GenePattern software",
#       "volume unit",
#       "pathologic lymph node stage for kidney according to AJCC 7th edition",
#       "manufacturer",
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "k-means clustering",
#       "k-nearest neighbors",
#       "Eastern Cooperative Oncology Group score value specification",
#       "principal components analysis dimensionality reduction",
#       "organization",
#       "leave one out cross validation method",
#       "hierarchical clustering",
#       "frequency unit",
#       "CART",
#       "pathologic distant metastases stage for ovary according to AJCC 7th edition",
#       "clinical tumor stage group according to AJCC 7th edition",
#       "concentration unit",
#       "histologic grade for ovarian tumor according to the World Health Organization",
#       "material supplier",
#       "Karnofsky score vaue specification",
#       "mass unit",
#       "pathologic lymph node stage for ovary according to AJCC 7th edition",
#       "length unit",
#       "clustered data visualization",
#       "denotator type",
#       "pathologic lymph node stage for lung according to AJCC 7th edition",
#       "substance unit",
#       "temperature unit",
#       "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification",
#       "pathologic primary tumor stage for colon and rectum according to AJCC 7th edition",
#       "curation status specification",
#       "pathologic primary tumor stage for ovary according to AJCC 7th edition",
#       "categorical label",
#       "pathologic distant metastases stage for colon according to AJCC 7th edition",
#       "pathologic distant metastases stage for kidney according to AJCC 7th edition",
#       "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",
#       "data format specification",
#       "pathologic primary tumor stage for lung according to AJCC 7th edition",
#       "obsolescence reason specification",
#       "time unit",
#       "rate unit",
#       "pathologic distant metastases stage for lung according to AJCC 7th edition",
#       "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"
#     ]
#   },
#   {
#     "terms": [
#       "G2 (Fuhrman)"
#     ],
#     "types": [
#       "histologic grade according to the Fuhrman Nuclear Grading System",
#       "histologic grade for ovarian tumor according to the World Health Organization"
#     ]
#   }
# ]

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")
# Out:
# /Users/panka/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from tqdm import tqdm

# %%
final_ans = []

# %%
final_clusters[0].keys()
# Out:
# dict_keys(['terms', 'types'])

# %%
len(final_clusters)
# Out:
# 40

# %%
for i, terms_types in tqdm(enumerate(final_clusters)):
        list_of_terms = terms_types['terms']
        types_of_terms = terms_types['types']

        prompt = prompt = f"""You are an expert in the Ontology for Biomedical Investigations (OBI) with comprehensive knowledge of biomedical research concepts, including assays, experimental protocols, instruments, reagents, data analysis methods, and biological or chemical entities.  
            You understand the key properties and roles of these entities, such as their function in experiments (e.g., measurement, detection, or analysis), their material properties (e.g., chemical composition), and their relationships in biomedical workflows.  
            You are familiar with measurement units used in biomedical research, such as mole, meter, pascal, and others, as well as OBI-specific terms like 'planned process', 'material entity', 'data transformation', and 'assay'.  
            You have expertise in the structure and classification of terms within the OBI ontology and their practical applications in biomedical experiments, clinical research, and data analysis.  
            You are capable of accurately classifying and categorizing OBI-related terms using your scientific reasoning and up-to-date knowledge of the OBI ontology.  
            You explain your classifications clearly and precisely.

            Your task is to classify a given list of OBI-related terms into one or more appropriate types from a provided list of possible types, ensuring alignment with the OBI ontology structure.

            Please respond strictly with a JSON object where:  
            - Each key is a term (string) from the input list.  
            - Each value is a list of one or more types (strings) assigned to that term based on your expert knowledge of the OBI ontology.

            List of Possible Types: {types_of_terms}

            Examples and also output format:

            {json.dumps({
            "millimolar": ["concentration unit"],
            "Stage 3C (FIGO)": ["International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"],
            "centimeter": ["length unit"],
            "Miltenyi Biotec": ["manufacturer"],
            "Bentley Instruments": ["manufacturer"],
            "pM1 (ovary)": ["pathologic distant metastases stage for ovary according to AJCC 7th edition"],
            "pT1 (colon)": ["pathologic primary tumor stage for colon and rectum according to AJCC 7th edition"],
            "pT0 (colon)": ["pathologic primary tumor stage for colon and rectum according to AJCC 7th edition"],
            "Unknown": ["Unknown"]
            }, indent=4)}

            Now classify the following terms:
            {list_of_terms}"""

        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%20==0:
            print(response.text)
# Out:
# 1it [00:02,  2.77s/it]
# {
#     "eBioscience": [
#         "manufacturer",
#         "material supplier"
#     ]
# }
# 1it [00:24, 24.79s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 39
#       5 prompt = prompt = f"""You are an expert in the Ontology for Biomedical Investigations (OBI) with comprehensive knowledge of biomedical research concepts, including assays, experimental protocols, instruments, reagents, data analysis methods, and biological or chemical entities.
#       6     You understand the key properties and roles of these entities, such as their function in experiments (e.g., measurement, detection, or analysis), their material properties (e.g., chemical composition), and their relationships in biomedical workflows.
#       7     You are familiar with measurement units used in biomedical research, such as mole, meter, pascal, and others, as well as OBI-specific terms like 'planned process', 'material entity', 'data transformation', and 'assay'.
#    (...)
#      34     Now classify the following terms:
#      35     {list_of_terms}"""
#      37 generation_config = {"response_mime_type": "application/json"}
# ---> 39 response = client.models.generate_content(
#      40         contents= prompt,
#      41         config=generation_config,
#      42         model=model
#      43     )
#      44 final_ans.append(response.text)
#      45 if i%20==0:
#
# File ~/Library/Python/3.9/lib/python/site-packages/google/genai/models.py:5738, in Models.generate_content(self, model, contents, config)
#    5736 while remaining_remote_calls_afc > 0:
#    5737   i += 1
# -> 5738   response = self._generate_content(
#    5739       model=model, contents=contents, config=parsed_config
#    5740   )
#    5741   logger.info(f'AFC remote call {i} is done.')
#    5742   remaining_remote_calls_afc -= 1
#
# File ~/Library/Python/3.9/lib/python/site-packages/google/genai/models.py:4678, in Models._generate_content(self, model, contents, config)
#    4675 request_dict = _common.convert_to_dict(request_dict)
#    4676 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4678 response = self._api_client.request(
#    4679     'post', path, request_dict, http_options
#    4680 )
#    4682 response_dict = '' if not response.body else json.loads(response.body)
#    4684 if self._api_client.vertexai:
#
# File ~/Library/Python/3.9/lib/python/site-packages/google/genai/_api_client.py:1077, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1067 def request(
#    1068     self,
#    1069     http_method: str,
#    (...)
#    1072     http_options: Optional[HttpOptionsOrDict] = None,
#    1073 ) -> SdkHttpResponse:
#    1074   http_request = self._build_request(
#    1075       http_method, path, request_dict, http_options
#    1076   )
# -> 1077   response = self._request(http_request, stream=False)
#    1078   response_body = (
#    1079       response.response_stream[0] if response.response_stream else ''
#    1080   )
#    1081   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/Library/Python/3.9/lib/python/site-packages/google/genai/_api_client.py:968, in BaseApiClient._request(self, http_request, stream)
#     963 def _request(
#     964     self,
#     965     http_request: HttpRequest,
#     966     stream: bool = False,
#     967 ) -> HttpResponse:
# --> 968   return self._retry(self._request_once, http_request, stream)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/Library/Python/3.9/lib/python/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Library/Python/3.9/lib/python/site-packages/google/genai/_api_client.py:951, in BaseApiClient._request_once(self, http_request, stream)
#     947   return HttpResponse(
#     948       response.headers, response if stream else [response.text]
#     949   )
#     950 else:
# --> 951   response = self._httpx_client.request(
#     952       method=http_request.method,
#     953       url=http_request.url,
#     954       headers=http_request.headers,
#     955       content=data,
#     956       timeout=http_request.timeout,
#     957   )
#     958   errors.APIError.raise_for_response(response)
#     959   return HttpResponse(
#     960       response.headers, response if stream else [response.text]
#     961   )
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Library/Python/3.9/lib/python/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1226, in SSLSocket.recv(self, buflen, flags)
#    1222     if flags != 0:
#    1223         raise ValueError(
#    1224             "non-zero flags not allowed in calls to recv() on %s" %
#    1225             self.__class__)
# -> 1226     return self.read(buflen)
#    1227 else:
#    1228     return super().recv(buflen, flags)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1101, in SSLSocket.read(self, len, buffer)
#    1099         return self._sslobj.read(len, buffer)
#    1100     else:
# -> 1101         return self._sslobj.read(len)
#    1102 except SSLError as x:
#    1103     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
final_ans
# Out:
# ['{\n    "eBioscience": [\n        "manufacturer",\n        "material supplier"\n    ]\n}',
#  '{\n  "pT3 (lung)": [\n    "pathologic primary tumor stage for lung according to AJCC 7th edition"\n  ],\n  "pT2a (ovary)": [\n    "pathologic primary tumor stage for ovary according to AJCC 7th edition"\n  ],\n  "pT1b (kidney)": [\n    "pathologic primary tumor stage for kidney according to AJCC 7th edition"\n  ],\n  "pM1b (lung)": [\n    "pathologic distant metastases stage for lung according to AJCC 7th edition"\n  ],\n  "pT1c (ovary)": [\n    "pathologic primary tumor stage for ovary according to AJCC 7th edition"\n  ],\n  "cM1 (kidney)": [\n    "Unknown"\n  ],\n  "pN1 (kidney)": [\n    "pathologic lymph node stage for kidney according to AJCC 7th edition"\n  ],\n  "pT3a (kidney)": [\n    "pathologic primary tumor stage for kidney according to AJCC 7th edition"\n  ],\n  "pT1 (kidney)": [\n    "pathologic primary tumor stage for kidney according to AJCC 7th edition"\n  ],\n  "pN2b (colon)": [\n    "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"\n  ],\n  "pT2 (ovary)": [\n    "pathologic primary tumor stage for ovary according to AJCC 7th edition"\n  ],\n  "pT2b (lung)": [\n    "pathologic primary tumor stage for lung according to AJCC 7th edition"\n  ],\n  "cM1a (colon)": [\n    "Unknown"\n  ],\n  "cM1 (colon)": [\n    "Unknown"\n  ],\n  "pT1 (lung)": [\n    "pathologic primary tumor stage for lung according to AJCC 7th edition"\n  ],\n  "pN1c (colon)": [\n    "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"\n  ],\n  "cM1 (ovary)": [\n    "Unknown"\n  ],\n  "pM1 (colon)": [\n    "pathologic distant metastases stage for colon according to AJCC 7th edition"\n  ],\n  "pN1b (colon)": [\n    "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"\n  ],\n  "pN1 (lung)": [\n    "pathologic lymph node stage for lung according to AJCC 7th edition"\n  ],\n  "pT3 (ovary)": [\n    "pathologic primary tumor stage for ovary according to AJCC 7th edition"\n  ],\n  "pN2 (colon)": [\n    "pathologic lymph node stage for colon and rectum according to AJCC 7th edition"\n  ],\n  "pM1b (colon)": [\n    "pathologic distant metastases stage for colon according to AJCC 7th edition"\n  ]\n}',
#  '{\n  "80-90: symptomatic but fully ambulatory": [\n    "Karnofsky score vaue specification"\n  ],\n  "3: symptomatic in bed more than 50% of the day but not bed ridden": [\n    "Eastern Cooperative Oncology Group score value specification"\n  ],\n  "2: symptomatic but in bed less than 50% of the day": [\n    "Eastern Cooperative Oncology Group score value specification"\n  ],\n  "4: bed ridden": [\n    "Eastern Cooperative Oncology Group score value specification"\n  ]\n}',
#  '{\n  "Antigenix": [\n    "manufacturer"\n  ]\n}',
#  '{\n    "metadata complete": [\n        "curation status specification"\n    ],\n    "metadata incomplete": [\n        "curation status specification"\n    ]\n}',
#  '{\n  "0: asymptomatic": [\n    "Eastern Cooperative Oncology Group score value specification"\n  ],\n  "100: asymptomatic": [\n    "Karnofsky score vaue specification"\n  ]\n}',
#  '{\n    "Cytopeia": [\n        "manufacturer"\n    ]\n}',
#  '{\n  "Edingburgh handedness inventory": [\n    "categorical label"\n  ]\n}',
#  '{\n    "BioGents": [\n        "manufacturer"\n    ]\n}',
#  '{\n    "year": [\n        "time unit"\n    ]\n}',
#  '{\n  "Stage IIA (AJCC 7th)": [\n    "clinical tumor stage group according to AJCC 7th edition"\n  ],\n  "Stage 4 (FIGO)": [\n    "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Stage IIIC (AJCC 7th)": [\n    "clinical tumor stage group according to AJCC 7th edition"\n  ],\n  "Stage IA (FIGO)": [\n    "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Stage IB (FIGO)": [\n    "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Stage 1A (FIGO)": [\n    "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Stage 2C (FIGO)": [\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Stage IIIB (FIGO)": [\n    "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Stage 0 (AJCC 7th)": [\n    "clinical tumor stage group according to AJCC 7th edition"\n  ],\n  "Stage IIB (FIGO)": [\n    "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Stage Unknown (FIGO)": [\n    "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Stage 1B (FIGO)": [\n    "International Federation of Gynecology and Obstetrics cervical cancer stage value specification",\n    "International Federation of Gynecology and Obstetrics ovarian cancer stage value specification"\n  ],\n  "Occult Carcinoma (AJCC 7th)": [\n    "clinical tumor stage group according to AJCC 7th edition"\n  ],\n  "Stage IIC (AJCC 7th)": [\n    "clinical tumor stage group according to AJCC 7th edition"\n  ]\n}',
#  '{\n  "tar": [\n    "data format specification"\n  ]\n}',
#  '{\n    "Advanced Instruments Inc. (AI Companies)": [\n        "manufacturer"\n    ]\n}',
#  '{\n    "nanomole": [\n        "substance unit"\n    ]\n}',
#  '{\n    "Bruker Corporation": [\n        "manufacturer"\n    ]\n}',
#  '{\n    "G3: Poorly differentiated": [\n        "histologic grade according to AJCC 7th edition"\n    ]\n}',
#  '{\n    "Luminex": [\n        "manufacturer"\n    ]\n}',
#  '{\n    "Sysmex Corporation, Kobe, Japan": [\n        "manufacturer"\n    ]\n}',
#  '{\n  "organizational term": [\n    "organizational term"\n  ],\n  "failed exploratory term": [\n    "curation status specification"\n  ]\n}',
#  '{\n  "count per molar second": [\n    "rate unit"\n  ],\n  "microliters per minute": [\n    "rate unit"\n  ]\n}',
#  '{\n    "nanoliter": [\n        "volume unit"\n    ]\n}',
#  '{\n    "milliliter": [\n        "volume unit"\n    ]\n}',
#  '{\n    "volume percentage": [\n        "concentration unit"\n    ]\n}',
#  '{\n    "Gating-ML": [\n        "data format specification"\n    ]\n}',
#  '{\n    "microliter": [\n        "volume unit"\n    ]\n}',
#  '{\n    "U.S. Food and Drug Administration": [\n        "organization"\n    ]\n}',
#  '{\n    "terms merged": [\n        "obsolescence reason specification"\n    ]\n}',
#  '{\n    "pending final vetting": [\n        "curation status specification"\n    ]\n}',
#  '{\n  "GenePattern module PeakMatch": [\n    "GenePattern software"\n  ],\n  "GenePattern HierarchicalClusteringViewer data visualization": [\n    "clustered data visualization",\n    "hierarchical clustering",\n    "GenePattern software"\n  ],\n  "GenePattern peak matching": [\n    "GenePattern software"\n  ],\n  "GenePattern SVM": [\n    "GenePattern software"\n  ],\n  "GenePattern module PCA": [\n    "principal components analysis dimensionality reduction",\n    "GenePattern software"\n  ],\n  "GenePattern module HierarchicalClustering": [\n    "hierarchical clustering",\n    "GenePattern software"\n  ]\n}',
#  '{\n    "Illumina": [\n        "manufacturer"\n    ]\n}',
#  '{\n    "Partec": [\n        "manufacturer"\n    ]\n}',
#  '{\n    "right handed": [\n        "categorical label"\n    ]\n}',
#  '{\n    "ACS": [\n        "organization"\n    ]\n}',
#  '{\n    "hour": [\n        "time unit"\n    ]\n}',
#  '{\n    "AES Chemunex": [\n        "manufacturer"\n    ]\n}',
#  '{\n    "degree Fahrenheit": [\n        "temperature unit"\n    ]\n}',
#  '{\n    "G3 (WHO)": [\n        "histologic grade for ovarian tumor according to the World Health Organization"\n    ]\n}',
#  '{\n    "Dako Cytomation": [\n        "manufacturer"\n    ]\n}',
#  '{\n    "G4: Undifferentiated": [\n        "histologic grade according to AJCC 7th edition"\n    ]\n}',
#  '{\n    "G2 (Fuhrman)": [\n        "histologic grade according to the Fuhrman Nuclear Grading System"\n    ]\n}']

# %%
new_data
# Out:
# [{'id': 'TT_5a5763f5', 'term': 'newton'},
#  {'id': 'TT_c4f339b8', 'term': 'newton meter'},
#  {'id': 'TT_ce5417fc', 'term': 'newton per meter'},
#  {'id': 'TT_25014bd4', 'term': 'coulomb per square meter'},
#  {'id': 'TT_46dad9e9', 'term': 'm2·m-2'},
#  {'id': 'TT_49ab10c7', 'term': 'mole per cubic meter'},
#  {'id': 'TT_ab5a8ad6', 'term': 'per ampere'},
#  {'id': 'TT_08f9b767', 'term': 'farad'},
#  {'id': 'TT_4cff4fec', 'term': 'dalton'},
#  {'id': 'TT_ce2b537c', 'term': 'second power 4'},
#  {'id': 'TT_dae2a7a6', 'term': 'per kilogram'},
#  {'id': 'TT_f8e74193', 'term': 'radian'},
#  {'id': 'TT_8a920749', 'term': 'joule per mole'},
#  {'id': 'TT_a0402f84', 'term': 'becquerel'},
#  {'id': 'TT_14fbac11', 'term': 'byte'},
#  {'id': 'TT_f1361175', 'term': 'coulomb per kilogram'},
#  {'id': 'TT_981df168', 'term': 'ampere per square meter'},
#  {'id': 'TT_4c87c381', 'term': 'unit_kelvin_-1'},
#  {'id': 'TT_f15ef7cd', 'term': 'joule'},
#  {'id': 'TT_40a02db8', 'term': 'meter squared'},
#  {'id': 'TT_d714834e', 'term': 'unit_electron_volt'},
#  {'id': 'TT_a9f30802', 'term': 'joule per kilogram per kelvin'},
#  {'id': 'TT_8182f530', 'term': 'per steradian'},
#  {'id': 'TT_ab85a470', 'term': 'second per mole'},
#  {'id': 'TT_b8e7ebae', 'term': 'coulomb per cubic meter'},
#  {'id': 'TT_9aec366c', 'term': 'joule per mole per kelvin'},
#  {'id': 'TT_b9a7fd17', 'term': 'lumen'},
#  {'id': 'TT_5ba78869', 'term': 'hertz'},
#  {'id': 'TT_9e7440e4', 'term': 'watt per meter per kelvin'},
#  {'id': 'TT_177b58ec', 'term': 'micrometer'},
#  {'id': 'TT_e707b15a', 'term': 'unit_gigapascal'},
#  {'id': 'TT_fac88931', 'term': 'unit_megapascal'},
#  {'id': 'TT_300a8cf0', 'term': 'reciprocal second'},
#  {'id': 'TT_e2c90a21', 'term': 'fahrenheit'},
#  {'id': 'TT_71796178', 'term': 'tesla'},
#  {'id': 'TT_e8ee7e46', 'term': 'watt'},
#  {'id': 'TT_4e46b6d7', 'term': 'gray per second'}]

# %%
term_to_id_mapping = {}
for data_n in new_data:
    term_to_id_mapping[data_n['term']]= data_n['id']

# %%
term_to_id_mapping
# Out:
# {'eBioscience': 'TT_d539e3e1',
#  'pT3 (lung)': 'TT_65da10e1',
#  '3: symptomatic in bed more than 50% of the day but not bed ridden': 'TT_a3dc97d0',
#  'Antigenix': 'TT_05e33e44',
#  'metadata complete': 'TT_1ea4dbdc',
#  '100: asymptomatic': 'TT_a9116815',
#  'Cytopeia': 'TT_0f6a960e',
#  'Edingburgh handedness inventory': 'TT_ea06d5c3',
#  'BioGents': 'TT_47e2f629',
#  'year': 'TT_c69005f8',
#  'Stage IA (FIGO)': 'TT_da557411',
#  'tar': 'TT_65393c3a',
#  'pT2a (ovary)': 'TT_163f5980',
#  'Stage 1A (FIGO)': 'TT_ccb5234f',
#  'Advanced Instruments Inc. (AI Companies)': 'TT_90fdf1cb',
#  'Stage IIIB (FIGO)': 'TT_93c33c2e',
#  'nanomole': 'TT_2fd89cce',
#  'Stage IIB (FIGO)': 'TT_e67be5a3',
#  'pT1b (kidney)': 'TT_9b926ad9',
#  'Bruker Corporation': 'TT_b9588c69',
#  'pM1b (lung)': 'TT_ad01c533',
#  'G3: Poorly differentiated': 'TT_9ccf6d5f',
#  'pT1c (ovary)': 'TT_0bc56139',
#  'Stage Unknown (FIGO)': 'TT_ed5377fb',
#  'Luminex': 'TT_2afe465c',
#  'cM1 (kidney)': 'TT_cdedd71b',
#  'Occult Carcinoma (AJCC 7th)': 'TT_cd693ff4',
#  'Stage IIC (AJCC 7th)': 'TT_d0334c13',
#  'pN1 (kidney)': 'TT_cdbdc786',
#  'Sysmex Corporation, Kobe, Japan': 'TT_433908f2',
#  'failed exploratory term': 'TT_2011db40',
#  'metadata incomplete': 'TT_084634b3',
#  'count per molar second': 'TT_850875ef',
#  'pT3a (kidney)': 'TT_c47ba797',
#  'organizational term': 'TT_a1509e48',
#  'nanoliter': 'TT_fcd2848f',
#  'pT1 (kidney)': 'TT_80f3d792',
#  'Stage IIIC (AJCC 7th)': 'TT_60e75ce9',
#  'pN2b (colon)': 'TT_efce7b98',
#  'pT2 (ovary)': 'TT_43c5fb24',
#  'milliliter': 'TT_b05448bd',
#  '4: bed ridden': 'TT_91c750a8',
#  'pT2b (lung)': 'TT_83dd02db',
#  'volume percentage': 'TT_0039c388',
#  'Gating-ML': 'TT_31d42069',
#  'cM1a (colon)': 'TT_18e34e9c',
#  'cM1 (colon)': 'TT_4df6ebf6',
#  'pT1 (lung)': 'TT_8fc89d82',
#  'Stage 0 (AJCC 7th)': 'TT_121bebb2',
#  'microliter': 'TT_acb30e3a',
#  'U.S. Food and Drug Administration': 'TT_ced2dffc',
#  '2: symptomatic but in bed less than 50% of the day': 'TT_5cfcfb4b',
#  'terms merged': 'TT_3f3c582e',
#  'pN1c (colon)': 'TT_ebe87765',
#  'cM1 (ovary)': 'TT_3b85bb65',
#  'pending final vetting': 'TT_74c463fc',
#  'Stage 1B (FIGO)': 'TT_cd20bf04',
#  '80-90: symptomatic but fully ambulatory': 'TT_9848d593',
#  'GenePattern module HierarchicalClustering': 'TT_049df733',
#  'Illumina': 'TT_f404121d',
#  'Partec': 'TT_d45eb816',
#  'right handed': 'TT_2fa33051',
#  'ACS': 'TT_2cb446e6',
#  'hour': 'TT_eec8e57b',
#  'Stage IIA (AJCC 7th)': 'TT_81deaaf0',
#  '0: asymptomatic': 'TT_fafe3ddf',
#  'pM1 (colon)': 'TT_afb73856',
#  'Stage 4 (FIGO)': 'TT_3831734a',
#  'GenePattern module PeakMatch': 'TT_b1d25f4b',
#  'GenePattern HierarchicalClusteringViewer data visualization': 'TT_e2231f84',
#  'microliters per minute': 'TT_b3dc9f32',
#  'pN1b (colon)': 'TT_d7b3544b',
#  'AES Chemunex': 'TT_d6dcaedc',
#  'pN1 (lung)': 'TT_1be9b5b1',
#  'GenePattern peak matching': 'TT_ea731405',
#  'degree Fahrenheit': 'TT_fcf479b0',
#  'Stage IB (FIGO)': 'TT_ba88c0c2',
#  'Stage 2C (FIGO)': 'TT_e5315cd9',
#  'G3 (WHO)': 'TT_ed4e48b5',
#  'Dako Cytomation': 'TT_f8bc4ca1',
#  'G4: Undifferentiated': 'TT_95daf138',
#  'pT3 (ovary)': 'TT_77002ba2',
#  'G2 (Fuhrman)': 'TT_a878ad94',
#  'GenePattern SVM': 'TT_cb7b354a',
#  'pN2 (colon)': 'TT_4dc447c1',
#  'GenePattern module PCA': 'TT_bb059332',
#  'pM1b (colon)': 'TT_f3dcf0ad'}

# %%
result = []
for ans_1 in final_ans:
    ans_dict = json.loads(ans_1)
    for term, type in ans_dict.items():
        result.append({"id":term_to_id_mapping[term], "term":term, "types":type})

# %%
result
# Out:
# [{'id': 'TT_d539e3e1',
#   'term': 'eBioscience',
#   'types': ['manufacturer', 'material supplier']},
#  {'id': 'TT_65da10e1',
#   'term': 'pT3 (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_163f5980',
#   'term': 'pT2a (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_9b926ad9',
#   'term': 'pT1b (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_ad01c533',
#   'term': 'pM1b (lung)',
#   'types': ['pathologic distant metastases stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_0bc56139',
#   'term': 'pT1c (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_cdedd71b', 'term': 'cM1 (kidney)', 'types': ['Unknown']},
#  {'id': 'TT_cdbdc786',
#   'term': 'pN1 (kidney)',
#   'types': ['pathologic lymph node stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_c47ba797',
#   'term': 'pT3a (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_80f3d792',
#   'term': 'pT1 (kidney)',
#   'types': ['pathologic primary tumor stage for kidney according to AJCC 7th edition']},
#  {'id': 'TT_efce7b98',
#   'term': 'pN2b (colon)',
#   'types': ['pathologic lymph node stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_43c5fb24',
#   'term': 'pT2 (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_83dd02db',
#   'term': 'pT2b (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_18e34e9c', 'term': 'cM1a (colon)', 'types': ['Unknown']},
#  {'id': 'TT_4df6ebf6', 'term': 'cM1 (colon)', 'types': ['Unknown']},
#  {'id': 'TT_8fc89d82',
#   'term': 'pT1 (lung)',
#   'types': ['pathologic primary tumor stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_ebe87765',
#   'term': 'pN1c (colon)',
#   'types': ['pathologic lymph node stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_3b85bb65', 'term': 'cM1 (ovary)', 'types': ['Unknown']},
#  {'id': 'TT_afb73856',
#   'term': 'pM1 (colon)',
#   'types': ['pathologic distant metastases stage for colon according to AJCC 7th edition']},
#  {'id': 'TT_d7b3544b',
#   'term': 'pN1b (colon)',
#   'types': ['pathologic lymph node stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_1be9b5b1',
#   'term': 'pN1 (lung)',
#   'types': ['pathologic lymph node stage for lung according to AJCC 7th edition']},
#  {'id': 'TT_77002ba2',
#   'term': 'pT3 (ovary)',
#   'types': ['pathologic primary tumor stage for ovary according to AJCC 7th edition']},
#  {'id': 'TT_4dc447c1',
#   'term': 'pN2 (colon)',
#   'types': ['pathologic lymph node stage for colon and rectum according to AJCC 7th edition']},
#  {'id': 'TT_f3dcf0ad',
#   'term': 'pM1b (colon)',
#   'types': ['pathologic distant metastases stage for colon according to AJCC 7th edition']},
#  {'id': 'TT_9848d593',
#   'term': '80-90: symptomatic but fully ambulatory',
#   'types': ['Karnofsky score vaue specification']},
#  {'id': 'TT_a3dc97d0',
#   'term': '3: symptomatic in bed more than 50% of the day but not bed ridden',
#   'types': ['Eastern Cooperative Oncology Group score value specification']},
#  {'id': 'TT_5cfcfb4b',
#   'term': '2: symptomatic but in bed less than 50% of the day',
#   'types': ['Eastern Cooperative Oncology Group score value specification']},
#  {'id': 'TT_91c750a8',
#   'term': '4: bed ridden',
#   'types': ['Eastern Cooperative Oncology Group score value specification']},
#  {'id': 'TT_05e33e44', 'term': 'Antigenix', 'types': ['manufacturer']},
#  {'id': 'TT_1ea4dbdc',
#   'term': 'metadata complete',
#   'types': ['curation status specification']},
#  {'id': 'TT_084634b3',
#   'term': 'metadata incomplete',
#   'types': ['curation status specification']},
#  {'id': 'TT_fafe3ddf',
#   'term': '0: asymptomatic',
#   'types': ['Eastern Cooperative Oncology Group score value specification']},
#  {'id': 'TT_a9116815',
#   'term': '100: asymptomatic',
#   'types': ['Karnofsky score vaue specification']},
#  {'id': 'TT_0f6a960e', 'term': 'Cytopeia', 'types': ['manufacturer']},
#  {'id': 'TT_ea06d5c3',
#   'term': 'Edingburgh handedness inventory',
#   'types': ['categorical label']},
#  {'id': 'TT_47e2f629', 'term': 'BioGents', 'types': ['manufacturer']},
#  {'id': 'TT_c69005f8', 'term': 'year', 'types': ['time unit']},
#  {'id': 'TT_81deaaf0',
#   'term': 'Stage IIA (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_3831734a',
#   'term': 'Stage 4 (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#    'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_60e75ce9',
#   'term': 'Stage IIIC (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_da557411',
#   'term': 'Stage IA (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#    'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_ba88c0c2',
#   'term': 'Stage IB (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#    'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_ccb5234f',
#   'term': 'Stage 1A (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#    'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_e5315cd9',
#   'term': 'Stage 2C (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_93c33c2e',
#   'term': 'Stage IIIB (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#    'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_121bebb2',
#   'term': 'Stage 0 (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_e67be5a3',
#   'term': 'Stage IIB (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#    'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_ed5377fb',
#   'term': 'Stage Unknown (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#    'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_cd20bf04',
#   'term': 'Stage 1B (FIGO)',
#   'types': ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification',
#    'International Federation of Gynecology and Obstetrics ovarian cancer stage value specification']},
#  {'id': 'TT_cd693ff4',
#   'term': 'Occult Carcinoma (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_d0334c13',
#   'term': 'Stage IIC (AJCC 7th)',
#   'types': ['clinical tumor stage group according to AJCC 7th edition']},
#  {'id': 'TT_65393c3a', 'term': 'tar', 'types': ['data format specification']},
#  {'id': 'TT_90fdf1cb',
#   'term': 'Advanced Instruments Inc. (AI Companies)',
#   'types': ['manufacturer']},
#  {'id': 'TT_2fd89cce', 'term': 'nanomole', 'types': ['substance unit']},
#  {'id': 'TT_b9588c69',
#   'term': 'Bruker Corporation',
#   'types': ['manufacturer']},
#  {'id': 'TT_9ccf6d5f',
#   'term': 'G3: Poorly differentiated',
#   'types': ['histologic grade according to AJCC 7th edition']},
#  {'id': 'TT_2afe465c', 'term': 'Luminex', 'types': ['manufacturer']},
#  {'id': 'TT_433908f2',
#   'term': 'Sysmex Corporation, Kobe, Japan',
#   'types': ['manufacturer']},
#  {'id': 'TT_a1509e48',
#   'term': 'organizational term',
#   'types': ['organizational term']},
#  {'id': 'TT_2011db40',
#   'term': 'failed exploratory term',
#   'types': ['curation status specification']},
#  {'id': 'TT_850875ef',
#   'term': 'count per molar second',
#   'types': ['rate unit']},
#  {'id': 'TT_b3dc9f32',
#   'term': 'microliters per minute',
#   'types': ['rate unit']},
#  {'id': 'TT_fcd2848f', 'term': 'nanoliter', 'types': ['volume unit']},
#  {'id': 'TT_b05448bd', 'term': 'milliliter', 'types': ['volume unit']},
#  {'id': 'TT_0039c388',
#   'term': 'volume percentage',
#   'types': ['concentration unit']},
#  {'id': 'TT_31d42069',
#   'term': 'Gating-ML',
#   'types': ['data format specification']},
#  {'id': 'TT_acb30e3a', 'term': 'microliter', 'types': ['volume unit']},
#  {'id': 'TT_ced2dffc',
#   'term': 'U.S. Food and Drug Administration',
#   'types': ['organization']},
#  {'id': 'TT_3f3c582e',
#   'term': 'terms merged',
#   'types': ['obsolescence reason specification']},
#  {'id': 'TT_74c463fc',
#   'term': 'pending final vetting',
#   'types': ['curation status specification']},
#  {'id': 'TT_b1d25f4b',
#   'term': 'GenePattern module PeakMatch',
#   'types': ['GenePattern software']},
#  {'id': 'TT_e2231f84',
#   'term': 'GenePattern HierarchicalClusteringViewer data visualization',
#   'types': ['clustered data visualization',
#    'hierarchical clustering',
#    'GenePattern software']},
#  {'id': 'TT_ea731405',
#   'term': 'GenePattern peak matching',
#   'types': ['GenePattern software']},
#  {'id': 'TT_cb7b354a',
#   'term': 'GenePattern SVM',
#   'types': ['GenePattern software']},
#  {'id': 'TT_bb059332',
#   'term': 'GenePattern module PCA',
#   'types': ['principal components analysis dimensionality reduction',
#    'GenePattern software']},
#  {'id': 'TT_049df733',
#   'term': 'GenePattern module HierarchicalClustering',
#   'types': ['hierarchical clustering', 'GenePattern software']},
#  {'id': 'TT_f404121d', 'term': 'Illumina', 'types': ['manufacturer']},
#  {'id': 'TT_d45eb816', 'term': 'Partec', 'types': ['manufacturer']},
#  {'id': 'TT_2fa33051', 'term': 'right handed', 'types': ['categorical label']},
#  {'id': 'TT_2cb446e6', 'term': 'ACS', 'types': ['organization']},
#  {'id': 'TT_eec8e57b', 'term': 'hour', 'types': ['time unit']},
#  {'id': 'TT_d6dcaedc', 'term': 'AES Chemunex', 'types': ['manufacturer']},
#  {'id': 'TT_fcf479b0',
#   'term': 'degree Fahrenheit',
#   'types': ['temperature unit']},
#  {'id': 'TT_ed4e48b5',
#   'term': 'G3 (WHO)',
#   'types': ['histologic grade for ovarian tumor according to the World Health Organization']},
#  {'id': 'TT_f8bc4ca1', 'term': 'Dako Cytomation', 'types': ['manufacturer']},
#  {'id': 'TT_95daf138',
#   'term': 'G4: Undifferentiated',
#   'types': ['histologic grade according to AJCC 7th edition']},
#  {'id': 'TT_a878ad94',
#   'term': 'G2 (Fuhrman)',
#   'types': ['histologic grade according to the Fuhrman Nuclear Grading System']}]

# %%
import json

with open("Task_B_term_types_OBI.json", "w", encoding="utf-8") as f:
    json.dump(result, f, indent=2, ensure_ascii=False)
