# %% [markdown]
# # **Clustering the Training data Term**

# %%
import json
from collections import defaultdict

def cluster_terms_by_shared_word(data):
    word_to_terms = defaultdict(set)
    for idx, entry in enumerate(data):
        words = entry['term'].lower().split()
        for w in words:
            word_to_terms[w].add(idx)

    visited = set()
    clusters = []

    def dfs(term_idx, cluster):
        visited.add(term_idx)
        cluster.add(term_idx)
        for w in data[term_idx]['term'].lower().split():
            for neighbor_idx in word_to_terms[w]:
                if neighbor_idx not in visited:
                    dfs(neighbor_idx, cluster)

    for i in range(len(data)):
        if i not in visited:
            cluster = set()
            dfs(i, cluster)
            clusters.append(cluster)

    clustered_output = []
    for cluster in clusters:
        cluster_terms = []
        cluster_types = set()
        for idx in cluster:
            cluster_terms.append(data[idx]['term'])
            cluster_types.update(data[idx]['types'])
        clustered_output.append({
            'terms': cluster_terms,
            'types': list(cluster_types)
        })
    return clustered_output
import json
import re

def clean_json_string(s):
    """Clean JSON string by replacing problematic Unicode escape sequences."""
    # Replace \u00c2 with middle dot (·)
    s = re.sub(r'\\u00c2', '·', s)
    # Replace \u00b7 with middle dot (·)
    s = re.sub(r'\\u00b7', '·', s)
    # Handle incomplete or malformed sequences like \u00b
    s = re.sub(r'\\u00b(?!\w{2})', '·', s)
    # Convert superscript notation (e.g., s-2 to s⁻²)
    s = re.sub(r's-2', 's⁻²', s)
    s = re.sub(r's-3', 's⁻³', s)
    s = re.sub(r's-4', 's⁻⁴', s)
    s = re.sub(r'm-2', 'm⁻²', s)
    s = re.sub(r'm-4', 'm⁻⁴', s)
    s = re.sub(r'kg-1', 'kg⁻¹', s)
    s = re.sub(r'A-1', 'A⁻¹', s)
    s = re.sub(r'A-2', 'A⁻²', s)
    return s

try:
    # Read the JSON file as raw text to clean it
    with open('MatOnto/train/term_typing_train_data.json', 'r', encoding='utf-8') as f:
        raw_data = f.read()
    
    # Clean the raw JSON string
    cleaned_data = clean_json_string(raw_data)
    
    # Parse the cleaned JSON string
    data = json.loads(cleaned_data)
    
    # Print all terms to verify correct loading
    print("Successfully loaded JSON data. Terms:")
    # for entry in data:
    #     print(f"ID: {entry['id']}, Term: {entry['term']}, Type: {entry['types'][0]}")

except UnicodeDecodeError as e:
    print(f"UnicodeDecodeError: {e}")
    print("Try a different encoding (e.g., 'latin-1' or 'iso-8859-1') or clean the file.")
except json.JSONDecodeError as e:
    print(f"JSONDecodeError: {e}")
    print("The JSON file may be malformed. Check for invalid characters or syntax.")
except Exception as e:
    print(f"Unexpected error: {e}")

clusters = cluster_terms_by_shared_word(data)
print(json.dumps(clusters, indent=2, ensure_ascii=False))
# Out:
# Successfully loaded JSON data. Terms:
# [
#   {
#     "terms": [
#       "kilogram",
#       "pascal root meter",
#       "per meter",
#       "radian per second squared",
#       "kilogram per kilogram",
#       "joule per kelvin",
#       "root meter",
#       "per squared meter",
#       "pascal per second",
#       "kilogram per cubic meter",
#       "candela per square meter",
#       "kilogram per meter per second squared",
#       "second cubed",
#       "farad per meter",
#       "meter per second squared",
#       "ampere squared",
#       "cubic meter",
#       "meter kilogram per second squared",
#       "joule per cubic meter",
#       "steradian",
#       "meter per second",
#       "watt per steradian",
#       "second ampere",
#       "per volt",
#       "cubic angstrom",
#       "ampere per meter",
#       "henry",
#       "per second squared",
#       "candela",
#       "joule per kilogram",
#       "ampere",
#       "per ampere squared",
#       "second",
#       "per mole",
#       "kilogram squared meter per second squared",
#       "per second squared",
#       "per kilogram squared",
#       "centimeter",
#       "watt per square meter per steradian",
#       "radian per second",
#       "katal per cubic meter",
#       "per kilogram cubed",
#       "kelvin",
#       "watt per square meter",
#       "cubic meter per kilogram",
#       "henry per meter",
#       "katal",
#       "volt",
#       "per meter power 4",
#       "volt per meter",
#       "per cubic meter",
#       "per cubic centimeter",
#       "pascal",
#       "kilogram meter squared per second cubed",
#       "mole",
#       "meter"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "solid angle unit",
#       "dynamic viscosity unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "specific energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "entropy unit",
#       "radiance unit"
#     ]
#   },
#   {
#     "terms": [
#       "kJ/mol"
#     ],
#     "types": [
#       "molar energy unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_lux"
#     ],
#     "types": [
#       "illuminance unit"
#     ]
#   },
#   {
#     "terms": [
#       "weber"
#     ],
#     "types": [
#       "magnetic flux unit"
#     ]
#   },
#   {
#     "terms": [
#       "'degree"
#     ],
#     "types": [
#       "plane angle unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_ohm"
#     ],
#     "types": [
#       "electric resistance unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2·m⁻⁴·cd"
#     ],
#     "types": [
#       "illuminance unit"
#     ]
#   },
#   {
#     "terms": [
#       "gray"
#     ],
#     "types": [
#       "absorbed dose unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_second_-3"
#     ],
#     "types": [
#       "unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2·kg·s⁻²·A⁻¹"
#     ],
#     "types": [
#       "magnetic flux unit"
#     ]
#   },
#   {
#     "terms": [
#       "coulomb"
#     ],
#     "types": [
#       "electric charge unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2·kg·s⁻²·A⁻²"
#     ],
#     "types": [
#       "inductance unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2·s⁻²"
#     ],
#     "types": [
#       "absorbed dose unit"
#     ]
#   },
#   {
#     "terms": [
#       "hectopascal"
#     ],
#     "types": [
#       "pressure unit"
#     ]
#   },
#   {
#     "terms": [
#       "kilopascal"
#     ],
#     "types": [
#       "pressure unit"
#     ]
#   },
#   {
#     "terms": [
#       "m⁻²·kg⁻¹·s3·A2"
#     ],
#     "types": [
#       "electric conduction unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2·kg·s⁻³·A⁻²"
#     ],
#     "types": [
#       "electric resistance unit"
#     ]
#   },
#   {
#     "terms": [
#       "sievert"
#     ],
#     "types": [
#       "dose equivalent unit"
#     ]
#   },
#   {
#     "terms": [
#       "g/cm3"
#     ],
#     "types": [
#       "volume density unit"
#     ]
#   },
#   {
#     "terms": [
#       "siemens"
#     ],
#     "types": [
#       "electric conduction unit"
#     ]
#   },
#   {
#     "terms": [
#       "g/mL"
#     ],
#     "types": [
#       "volume density unit"
#     ]
#   },
#   {
#     "terms": [
#       "kg·s⁻²·A⁻¹"
#     ],
#     "types": [
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "Bohr magneton"
#     ],
#     "types": [
#       "unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_gram"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "m⁻²·kg⁻¹·s4·A2"
#     ],
#     "types": [
#       "capacitance unit"
#     ]
#   },
#   {
#     "terms": [
#       "bit"
#     ],
#     "types": [
#       "information unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2·kg·s⁻³·A⁻¹"
#     ],
#     "types": [
#       "potential difference unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_milliliter"
#     ],
#     "types": [
#       "volume unit"
#     ]
#   },
#   {
#     "terms": [
#       "celcius"
#     ],
#     "types": [
#       "temperature unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2·m⁻²·cd"
#     ],
#     "types": [
#       "luminous flux unit"
#     ]
#   }
# ]

# %%
import json
from collections import defaultdict

def cluster_terms_by_shared_word(data):
    word_to_terms = defaultdict(set)
    for idx, entry in enumerate(data):
        words = entry['term'].lower().split()
        for w in words:
            word_to_terms[w].add(idx)

    visited = set()
    clusters = []

    def dfs(term_idx, cluster):
        visited.add(term_idx)
        cluster.add(term_idx)
        for w in data[term_idx]['term'].lower().split():
            for neighbor_idx in word_to_terms[w]:
                if neighbor_idx not in visited:
                    dfs(neighbor_idx, cluster)

    for i in range(len(data)):
        if i not in visited:
            cluster = set()
            dfs(i, cluster)
            clusters.append(cluster)

    clustered_output = []
    for cluster in clusters:
        cluster_terms = []
        for idx in cluster:
            cluster_terms.append(data[idx]['term'])
        clustered_output.append({
            'term_indices': cluster,
            'terms': cluster_terms
        })
    return clustered_output

def get_word_set(term):
    return set(term.lower().split())

def find_best_training_match(new_term, training_data):
    new_words = get_word_set(new_term)
    best_match = None
    best_score = -1
    for train_entry in training_data:
        train_words = get_word_set(train_entry['term'])
        shared_words = new_words.intersection(train_words)
        score = len(shared_words)
        if score > best_score:
            best_score = score
            best_match = train_entry
    return best_match, best_score

# Load your training data (with types)
with open('MatOnto/train/term_typing_train_data.json', 'r', encoding='utf-8') as f:
    training_data = json.load(f)

# Load your new data (without types)
with open("MatOnto/test/matonto_term_typing_test_data.json", 'r', encoding='utf-8' ) as f:
    new_data = json.load(f)

# Step 1: Cluster new terms by shared words
clusters = cluster_terms_by_shared_word(new_data)

# Step 2: For each cluster, find types from training data based on best matches per term
final_clusters = []
for cluster in clusters:
    cluster_types = set()
    for idx in cluster['term_indices']:
        new_term = new_data[idx]['term']
        best_match, score = find_best_training_match(new_term, training_data)
        if best_match and 'types' in best_match:
            cluster_types.update(best_match['types'])
    final_clusters.append({
        'terms': cluster['terms'],
        'types': list(cluster_types) if cluster_types else ['unknown']
    })

print(json.dumps(final_clusters, indent=2))
# Out:
# [
#   {
#     "terms": [
#       "newton",
#       "newton meter",
#       "newton per meter",
#       "coulomb per square meter",
#       "mole per cubic meter",
#       "per ampere",
#       "second power 4",
#       "per kilogram",
#       "joule per mole",
#       "coulomb per kilogram",
#       "ampere per square meter",
#       "joule",
#       "meter squared",
#       "joule per kilogram per kelvin",
#       "per steradian",
#       "second per mole",
#       "coulomb per cubic meter",
#       "joule per mole per kelvin",
#       "watt per meter per kelvin",
#       "reciprocal second",
#       "watt",
#       "gray per second"
#     ],
#     "types": [
#       "angular acceleration unit",
#       "radiant intensity unit",
#       "unit",
#       "magnetic field strength",
#       "volume density unit",
#       "entropy unit",
#       "luminance unit",
#       "mass unit",
#       "radiance unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2\u00b7m-2"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "farad"
#     ],
#     "types": [
#       "permittivity unit"
#     ]
#   },
#   {
#     "terms": [
#       "dalton"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "radian"
#     ],
#     "types": [
#       "angular acceleration unit"
#     ]
#   },
#   {
#     "terms": [
#       "becquerel"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "byte"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_kelvin_-1"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_electron_volt"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "lumen"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "hertz"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "micrometer"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_gigapascal"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_megapascal"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "fahrenheit"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   },
#   {
#     "terms": [
#       "tesla"
#     ],
#     "types": [
#       "mass unit"
#     ]
#   }
# ]

# %% [markdown]
# # "assigning test term to the nearest cluster"

# %%
import json
from collections import defaultdict

def cluster_terms_by_shared_word(data):
    word_to_terms = defaultdict(set)
    for idx, entry in enumerate(data):
        words = entry['term'].lower().split()
        for w in words:
            word_to_terms[w].add(idx)

    visited = set()
    clusters = []

    def dfs(term_idx, cluster):
        visited.add(term_idx)
        cluster.add(term_idx)
        for w in data[term_idx]['term'].lower().split():
            for neighbor_idx in word_to_terms[w]:
                if neighbor_idx not in visited:
                    dfs(neighbor_idx, cluster)

    for i in range(len(data)):
        if i not in visited:
            cluster = set()
            dfs(i, cluster)
            clusters.append(cluster)

    clustered_output = []
    for cluster in clusters:
        cluster_terms = []
        for idx in cluster:
            cluster_terms.append(data[idx]['term'])
        clustered_output.append({
            'term_indices': cluster,
            'terms': cluster_terms
        })
    return clustered_output

def get_word_set(term):
    return set(term.lower().split())

# Load your training data (with types)
with open('MatOnto/train/term_typing_train_data.json', 'r', encoding='utf-8') as f:
    training_data = json.load(f)

# Load your new data (without types)
with open("MatOnto/test/matonto_term_typing_test_data.json", 'r', encoding='utf-8') as f:
    new_data = json.load(f)

# Step 1: Cluster training data
training_clusters = cluster_terms_by_shared_word(training_data)

# Step 2: Cluster new/test data
test_clusters = cluster_terms_by_shared_word(new_data)

# Precompute training cluster terms sets (list of word sets per term)
training_cluster_wordsets = []
for cluster in training_clusters:
    cluster_wordsets = []
    for idx in cluster['term_indices']:
        cluster_wordsets.append(get_word_set(training_data[idx]['term']))
    training_cluster_wordsets.append(cluster_wordsets)

# Step 3: For each test term, find best matching training cluster
final_clusters = []

for test_cluster in test_clusters:
    cluster_types = set()
    for test_idx in test_cluster['term_indices']:
        test_term = new_data[test_idx]['term']
        test_words = get_word_set(test_term)

        best_cluster_idx = None
        best_score = 0

        # Compare with each training cluster
        for i, cluster_wordsets in enumerate(training_cluster_wordsets):
            # For each training term in cluster, calculate shared words with test term
            cluster_score = 0
            for train_words in cluster_wordsets:
                shared = test_words.intersection(train_words)
                cluster_score = max(cluster_score, len(shared))
            if cluster_score > best_score:
                best_score = cluster_score
                best_cluster_idx = i

        if best_cluster_idx is not None and best_score > 0:
            # Collect types from that training cluster terms
            # Here collect all types from all terms in that cluster
            for train_idx in training_clusters[best_cluster_idx]['term_indices']:
                if 'types' in training_data[train_idx]:
                    cluster_types.update(training_data[train_idx]['types'])
        else:
            # No good match found for this term
            cluster_types.add('unknown')

    final_clusters.append({
        'terms': test_cluster['terms'],
        'types': list(cluster_types) if cluster_types else ['unknown']
    })

print(json.dumps(final_clusters, indent=2))
# Out:
# [
#   {
#     "terms": [
#       "newton",
#       "newton meter",
#       "newton per meter",
#       "coulomb per square meter",
#       "mole per cubic meter",
#       "per ampere",
#       "second power 4",
#       "per kilogram",
#       "joule per mole",
#       "coulomb per kilogram",
#       "ampere per square meter",
#       "joule",
#       "meter squared",
#       "joule per kilogram per kelvin",
#       "per steradian",
#       "second per mole",
#       "coulomb per cubic meter",
#       "joule per mole per kelvin",
#       "watt per meter per kelvin",
#       "reciprocal second",
#       "watt",
#       "gray per second"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "unknown",
#       "acceleration unit",
#       "solid angle unit",
#       "dynamic viscosity unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "specific energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "entropy unit",
#       "radiance unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2\u00b7m-2"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "farad"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "solid angle unit",
#       "dynamic viscosity unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "specific energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "entropy unit",
#       "radiance unit"
#     ]
#   },
#   {
#     "terms": [
#       "dalton"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "radian"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "solid angle unit",
#       "dynamic viscosity unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "specific energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "entropy unit",
#       "radiance unit"
#     ]
#   },
#   {
#     "terms": [
#       "becquerel"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "byte"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "unit_kelvin_-1"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "unit_electron_volt"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "lumen"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "hertz"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "micrometer"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "unit_gigapascal"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "unit_megapascal"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "fahrenheit"
#     ],
#     "types": [
#       "unknown"
#     ]
#   },
#   {
#     "terms": [
#       "tesla"
#     ],
#     "types": [
#       "unknown"
#     ]
#   }
# ]

# %%
data
# Out:
# [{'id': 'TT_778fb090', 'term': 'kilogram', 'types': ['mass unit']},
#  {'id': 'TT_30a06554', 'term': 'pascal root meter', 'types': ['unit']},
#  {'id': 'TT_0f529528', 'term': 'per meter', 'types': ['unit']},
#  {'id': 'TT_59cd3f71', 'term': 'kJ/mol', 'types': ['molar energy unit']},
#  {'id': 'TT_57dd933e', 'term': 'unit_lux', 'types': ['illuminance unit']},
#  {'id': 'TT_45bde25c',
#   'term': 'radian per second squared',
#   'types': ['angular acceleration unit']},
#  {'id': 'TT_0720443e', 'term': 'kilogram per kilogram', 'types': ['unit']},
#  {'id': 'TT_2a5fd547', 'term': 'weber', 'types': ['magnetic flux unit']},
#  {'id': 'TT_6a031e6e', 'term': "'degree", 'types': ['plane angle unit']},
#  {'id': 'TT_11273acb', 'term': 'joule per kelvin', 'types': ['entropy unit']},
#  {'id': 'TT_e4e7b7f2',
#   'term': 'unit_ohm',
#   'types': ['electric resistance unit']},
#  {'id': 'TT_e45431ca', 'term': 'root meter', 'types': ['unit']},
#  {'id': 'TT_7942e2ca', 'term': 'per squared meter', 'types': ['unit']},
#  {'id': 'TT_2efc0a52',
#   'term': 'pascal per second',
#   'types': ['dynamic viscosity unit']},
#  {'id': 'TT_ac7d07c9',
#   'term': 'kilogram per cubic meter',
#   'types': ['volume density unit']},
#  {'id': 'TT_8ed553c9',
#   'term': 'candela per square meter',
#   'types': ['luminance unit']},
#  {'id': 'TT_51290e8b',
#   'term': 'kilogram per meter per second squared',
#   'types': ['pressure unit']},
#  {'id': 'TT_4bbb6a87', 'term': 'second cubed', 'types': ['unit']},
#  {'id': 'TT_2d035e8b', 'term': 'm2·m⁻⁴·cd', 'types': ['illuminance unit']},
#  {'id': 'TT_7679dc9d',
#   'term': 'farad per meter',
#   'types': ['permittivity unit']},
#  {'id': 'TT_e94e0a9f', 'term': 'gray', 'types': ['absorbed dose unit']},
#  {'id': 'TT_a0429d1c',
#   'term': 'meter per second squared',
#   'types': ['acceleration unit']},
#  {'id': 'TT_b24fd50d', 'term': 'ampere squared', 'types': ['unit']},
#  {'id': 'TT_4574f1df', 'term': 'unit_second_-3', 'types': ['unit']},
#  {'id': 'TT_12d0cc60', 'term': 'cubic meter', 'types': ['volume unit']},
#  {'id': 'TT_ea627c2f',
#   'term': 'm2·kg·s⁻²·A⁻¹',
#   'types': ['magnetic flux unit']},
#  {'id': 'TT_a3cd5291',
#   'term': 'meter kilogram per second squared',
#   'types': ['force unit']},
#  {'id': 'TT_62d175d7', 'term': 'coulomb', 'types': ['electric charge unit']},
#  {'id': 'TT_958b9202', 'term': 'm2·kg·s⁻²·A⁻²', 'types': ['inductance unit']},
#  {'id': 'TT_58c483c9', 'term': 'm2·s⁻²', 'types': ['absorbed dose unit']},
#  {'id': 'TT_1df160b6', 'term': 'hectopascal', 'types': ['pressure unit']},
#  {'id': 'TT_ac853aad',
#   'term': 'joule per cubic meter',
#   'types': ['energy density unit']},
#  {'id': 'TT_04dcf03b', 'term': 'steradian', 'types': ['solid angle unit']},
#  {'id': 'TT_8b311fe6', 'term': 'kilopascal', 'types': ['pressure unit']},
#  {'id': 'TT_53eaf412', 'term': 'meter per second', 'types': ['velocity unit']},
#  {'id': 'TT_9835ee17',
#   'term': 'm⁻²·kg⁻¹·s3·A2',
#   'types': ['electric conduction unit']},
#  {'id': 'TT_554d4205',
#   'term': 'm2·kg·s⁻³·A⁻²',
#   'types': ['electric resistance unit']},
#  {'id': 'TT_d3c815e7', 'term': 'sievert', 'types': ['dose equivalent unit']},
#  {'id': 'TT_90f97e65',
#   'term': 'watt per steradian',
#   'types': ['radiant intensity unit']},
#  {'id': 'TT_36aa8c18',
#   'term': 'second ampere',
#   'types': ['electric charge unit']},
#  {'id': 'TT_cccac23e', 'term': 'per volt', 'types': ['unit']},
#  {'id': 'TT_f464e9a8', 'term': 'g/cm3', 'types': ['volume density unit']},
#  {'id': 'TT_c4432aee', 'term': 'cubic angstrom', 'types': ['volume unit']},
#  {'id': 'TT_6b9d0337',
#   'term': 'ampere per meter',
#   'types': ['magnetic field strength']},
#  {'id': 'TT_22a6863e', 'term': 'henry', 'types': ['inductance unit']},
#  {'id': 'TT_2ef3510f', 'term': 'per second squared', 'types': ['unit']},
#  {'id': 'TT_a2190e08',
#   'term': 'candela',
#   'types': ['luminous intensity unit']},
#  {'id': 'TT_307a1fc2',
#   'term': 'joule per kilogram',
#   'types': ['specific energy unit']},
#  {'id': 'TT_fc75936c',
#   'term': 'siemens',
#   'types': ['electric conduction unit']},
#  {'id': 'TT_8918218e', 'term': 'ampere', 'types': ['electric current unit']},
#  {'id': 'TT_f7a1b19c', 'term': 'per ampere squared', 'types': ['unit']},
#  {'id': 'TT_ac55b242', 'term': 'g/mL', 'types': ['volume density unit']},
#  {'id': 'TT_62dd1b02', 'term': 'second', 'types': ['time unit']},
#  {'id': 'TT_ac478cbf',
#   'term': 'kg·s⁻²·A⁻¹',
#   'types': ['magnetic flux density unit']},
#  {'id': 'TT_97403c16', 'term': 'per mole', 'types': ['unit']},
#  {'id': 'TT_53d113c0', 'term': 'Bohr magneton', 'types': ['unit']},
#  {'id': 'TT_ce05750d', 'term': 'unit_gram', 'types': ['mass unit']},
#  {'id': 'TT_db230dd3',
#   'term': 'kilogram squared meter per second squared',
#   'types': ['energy unit']},
#  {'id': 'TT_13ef9af1', 'term': 'per second squared', 'types': ['unit']},
#  {'id': 'TT_b509b2de', 'term': 'per kilogram squared', 'types': ['unit']},
#  {'id': 'TT_715cdc32', 'term': 'centimeter', 'types': ['length unit']},
#  {'id': 'TT_fe95aceb',
#   'term': 'watt per square meter per steradian',
#   'types': ['radiance unit']},
#  {'id': 'TT_fd74efb5',
#   'term': 'radian per second',
#   'types': ['angular velocity unit']},
#  {'id': 'TT_e4207513',
#   'term': 'm⁻²·kg⁻¹·s4·A2',
#   'types': ['capacitance unit']},
#  {'id': 'TT_5deb76b3',
#   'term': 'katal per cubic meter',
#   'types': ['catalytic concentration unit']},
#  {'id': 'TT_59713489', 'term': 'per kilogram cubed', 'types': ['unit']},
#  {'id': 'TT_feed0b79', 'term': 'kelvin', 'types': ['temperature unit']},
#  {'id': 'TT_7ec0d704',
#   'term': 'watt per square meter',
#   'types': ['irradiance unit']},
#  {'id': 'TT_e644f6e7',
#   'term': 'cubic meter per kilogram',
#   'types': ['specific volume unit']},
#  {'id': 'TT_26503d22',
#   'term': 'henry per meter',
#   'types': ['permeability unit']},
#  {'id': 'TT_45fb5003', 'term': 'katal', 'types': ['catalytic activity unit']},
#  {'id': 'TT_0a39b1a5', 'term': 'volt', 'types': ['potential difference unit']},
#  {'id': 'TT_f283fecb', 'term': 'bit', 'types': ['information unit']},
#  {'id': 'TT_3946c33a', 'term': 'per meter power 4', 'types': ['unit']},
#  {'id': 'TT_0d981bd3',
#   'term': 'm2·kg·s⁻³·A⁻¹',
#   'types': ['potential difference unit']},
#  {'id': 'TT_9b0f29ec', 'term': 'unit_milliliter', 'types': ['volume unit']},
#  {'id': 'TT_4c8ddbb7',
#   'term': 'volt per meter',
#   'types': ['electric field strength unit']},
#  {'id': 'TT_8827409a', 'term': 'celcius', 'types': ['temperature unit']},
#  {'id': 'TT_4b7ca53c', 'term': 'per cubic meter', 'types': ['unit']},
#  {'id': 'TT_b0554ba4', 'term': 'per cubic centimeter', 'types': ['unit']},
#  {'id': 'TT_8dcfb809', 'term': 'm2·m⁻²·cd', 'types': ['luminous flux unit']},
#  {'id': 'TT_44f7c840', 'term': 'pascal', 'types': ['pressure unit']},
#  {'id': 'TT_ab7f77d0',
#   'term': 'kilogram meter squared per second cubed',
#   'types': ['power unit']},
#  {'id': 'TT_c02012d3', 'term': 'mole', 'types': ['amount of substance unit']},
#  {'id': 'TT_dcb721f9', 'term': 'meter', 'types': ['length unit']}]

# %%
all_unique_types = []
for data_1 in data:
    if data_1['types'][0] not in all_unique_types:
        all_unique_types.append(data_1['types'][0])

# %%
all_unique_types
# Out:
# ['mass unit',
#  'unit',
#  'molar energy unit',
#  'illuminance unit',
#  'angular acceleration unit',
#  'magnetic flux unit',
#  'plane angle unit',
#  'entropy unit',
#  'electric resistance unit',
#  'dynamic viscosity unit',
#  'volume density unit',
#  'luminance unit',
#  'pressure unit',
#  'permittivity unit',
#  'absorbed dose unit',
#  'acceleration unit',
#  'volume unit',
#  'force unit',
#  'electric charge unit',
#  'inductance unit',
#  'energy density unit',
#  'solid angle unit',
#  'velocity unit',
#  'electric conduction unit',
#  'dose equivalent unit',
#  'radiant intensity unit',
#  'magnetic field strength',
#  'luminous intensity unit',
#  'specific energy unit',
#  'electric current unit',
#  'time unit',
#  'magnetic flux density unit',
#  'energy unit',
#  'length unit',
#  'radiance unit',
#  'angular velocity unit',
#  'capacitance unit',
#  'catalytic concentration unit',
#  'temperature unit',
#  'irradiance unit',
#  'specific volume unit',
#  'permeability unit',
#  'catalytic activity unit',
#  'potential difference unit',
#  'information unit',
#  'electric field strength unit',
#  'luminous flux unit',
#  'power unit',
#  'amount of substance unit']

# %%
for test_idx in test_cluster['term_indices']:
    test_term = new_data[test_idx]['term']
    test_words = get_word_set(test_term)  # split test term by spaces to words

    best_cluster_idx = None
    best_score = 0

    # Iterate through each training cluster
    for i, cluster_wordsets in enumerate(training_cluster_wordsets):
        cluster_score = 0
        # Check against each training term in this cluster
        for train_words in cluster_wordsets:
            # train_words is word set of training term
            shared = test_words.intersection(train_words)  # word-based intersection
            cluster_score = max(cluster_score, len(shared))  # take max overlap in this cluster
        if cluster_score > best_score:
            best_score = cluster_score
            best_cluster_idx = i

    # If match found, collect types from best matching training cluster
    if best_cluster_idx is not None and best_score > 0:
        for train_idx in training_clusters[best_cluster_idx]['term_indices']:
            if 'types' in training_data[train_idx]:
                cluster_types.update(training_data[train_idx]['types'])
    else:
        # No match found
        cluster_types.update(all_unique_types)

# %%
cluster_types
# Out:
# {'absorbed dose unit',
#  'acceleration unit',
#  'amount of substance unit',
#  'angular acceleration unit',
#  'angular velocity unit',
#  'capacitance unit',
#  'catalytic activity unit',
#  'catalytic concentration unit',
#  'dose equivalent unit',
#  'dynamic viscosity unit',
#  'electric charge unit',
#  'electric conduction unit',
#  'electric current unit',
#  'electric field strength unit',
#  'electric resistance unit',
#  'energy density unit',
#  'energy unit',
#  'entropy unit',
#  'force unit',
#  'illuminance unit',
#  'inductance unit',
#  'information unit',
#  'irradiance unit',
#  'length unit',
#  'luminance unit',
#  'luminous flux unit',
#  'luminous intensity unit',
#  'magnetic field strength',
#  'magnetic flux density unit',
#  'magnetic flux unit',
#  'mass unit',
#  'molar energy unit',
#  'permeability unit',
#  'permittivity unit',
#  'plane angle unit',
#  'potential difference unit',
#  'power unit',
#  'pressure unit',
#  'radiance unit',
#  'radiant intensity unit',
#  'solid angle unit',
#  'specific energy unit',
#  'specific volume unit',
#  'temperature unit',
#  'time unit',
#  'unit',
#  'unknown',
#  'velocity unit',
#  'volume density unit',
#  'volume unit'}

# %%
import json
from collections import defaultdict

def cluster_terms_by_shared_word(data):
    word_to_terms = defaultdict(set)
    for idx, entry in enumerate(data):
        words = entry['term'].lower().split()
        for w in words:
            word_to_terms[w].add(idx)

    visited = set()
    clusters = []

    def dfs(term_idx, cluster):
        visited.add(term_idx)
        cluster.add(term_idx)
        for w in data[term_idx]['term'].lower().split():
            for neighbor_idx in word_to_terms[w]:
                if neighbor_idx not in visited:
                    dfs(neighbor_idx, cluster)

    for i in range(len(data)):
        if i not in visited:
            cluster = set()
            dfs(i, cluster)
            clusters.append(cluster)

    clustered_output = []
    for cluster in clusters:
        cluster_terms = []
        for idx in cluster:
            cluster_terms.append(data[idx]['term'])
        clustered_output.append({
            'term_indices': cluster,
            'terms': cluster_terms
        })
    return clustered_output

def get_word_set(term):
    return set(term.lower().split())

# Load your training data (with types)
with open('MatOnto/train/term_typing_train_data.json', 'r', encoding='utf-8') as f:
    training_data = json.load(f)

# Load your new data (without types)
with open("MatOnto/test/matonto_term_typing_test_data.json", 'r', encoding='utf-8') as f:
    new_data = json.load(f)

# Precompute all unique types in training data
all_unique_types = set()
for entry in training_data:
    if 'types' in entry:
        all_unique_types.update(entry['types'])

# Step 1: Cluster training data
training_clusters = cluster_terms_by_shared_word(training_data)

# Step 2: Cluster new/test data
test_clusters = cluster_terms_by_shared_word(new_data)

# Precompute training cluster terms sets (list of word sets per term)
training_cluster_wordsets = []
for cluster in training_clusters:
    cluster_wordsets = []
    for idx in cluster['term_indices']:
        cluster_wordsets.append(get_word_set(training_data[idx]['term']))
    training_cluster_wordsets.append(cluster_wordsets)

# Step 3: For each test term, find best matching training cluster
final_clusters = []

for test_cluster in test_clusters:
    cluster_types = set()
    for test_idx in test_cluster['term_indices']:
        test_term = new_data[test_idx]['term']
        test_words = get_word_set(test_term)

        best_cluster_idx = None
        best_score = 0

        # Compare with each training cluster
        for i, cluster_wordsets in enumerate(training_cluster_wordsets):
            cluster_score = 0
            for train_words in cluster_wordsets:
                shared = test_words.intersection(train_words)
                cluster_score = max(cluster_score, len(shared))
            if cluster_score > best_score:
                best_score = cluster_score
                best_cluster_idx = i

        if best_cluster_idx is not None and best_score > 0:
            # Collect types from that training cluster terms
            for train_idx in training_clusters[best_cluster_idx]['term_indices']:
                if 'types' in training_data[train_idx]:
                    cluster_types.update(training_data[train_idx]['types'])
        else:
            # No good match found: assign all unique training types
            cluster_types.update(all_unique_types)

    final_clusters.append({
        'terms': test_cluster['terms'],
        'types': list(cluster_types) if cluster_types else ['unknown']
    })

print(json.dumps(final_clusters, indent=2))
# Out:
# [
#   {
#     "terms": [
#       "newton",
#       "newton meter",
#       "newton per meter",
#       "coulomb per square meter",
#       "mole per cubic meter",
#       "per ampere",
#       "second power 4",
#       "per kilogram",
#       "joule per mole",
#       "coulomb per kilogram",
#       "ampere per square meter",
#       "joule",
#       "meter squared",
#       "joule per kilogram per kelvin",
#       "per steradian",
#       "second per mole",
#       "coulomb per cubic meter",
#       "joule per mole per kelvin",
#       "watt per meter per kelvin",
#       "reciprocal second",
#       "watt",
#       "gray per second"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "m2\u00b7m-2"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "farad"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "solid angle unit",
#       "dynamic viscosity unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "specific energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "entropy unit",
#       "radiance unit"
#     ]
#   },
#   {
#     "terms": [
#       "dalton"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "radian"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "solid angle unit",
#       "dynamic viscosity unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "specific energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "entropy unit",
#       "radiance unit"
#     ]
#   },
#   {
#     "terms": [
#       "becquerel"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "byte"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_kelvin_-1"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_electron_volt"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "lumen"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "hertz"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "micrometer"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_gigapascal"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "unit_megapascal"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "fahrenheit"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   },
#   {
#     "terms": [
#       "tesla"
#     ],
#     "types": [
#       "amount of substance unit",
#       "permittivity unit",
#       "length unit",
#       "energy density unit",
#       "angular velocity unit",
#       "electric current unit",
#       "inductance unit",
#       "volume density unit",
#       "mass unit",
#       "angular acceleration unit",
#       "illuminance unit",
#       "electric resistance unit",
#       "velocity unit",
#       "volume unit",
#       "pressure unit",
#       "magnetic flux unit",
#       "unit",
#       "absorbed dose unit",
#       "magnetic field strength",
#       "temperature unit",
#       "luminance unit",
#       "time unit",
#       "potential difference unit",
#       "luminous intensity unit",
#       "permeability unit",
#       "electric field strength unit",
#       "power unit",
#       "acceleration unit",
#       "dynamic viscosity unit",
#       "solid angle unit",
#       "radiant intensity unit",
#       "specific volume unit",
#       "catalytic activity unit",
#       "irradiance unit",
#       "dose equivalent unit",
#       "specific energy unit",
#       "molar energy unit",
#       "electric charge unit",
#       "energy unit",
#       "force unit",
#       "catalytic concentration unit",
#       "plane angle unit",
#       "entropy unit",
#       "luminous flux unit",
#       "capacitance unit",
#       "electric conduction unit",
#       "information unit",
#       "radiance unit",
#       "magnetic flux density unit"
#     ]
#   }
# ]

# %%
from google import genai
model = "gemini-2.5-pro"
client= genai.Client(api_key="")

# %%
from tqdm import tqdm

# %%
final_ans = []

# %%
final_clusters[0].keys()
# Out:
# dict_keys(['terms', 'types'])

# %%
for i, terms_types in tqdm(enumerate(final_clusters)):
        list_of_terms = terms_types['terms']
        types_of_terms = terms_types['types']

        prompt = f"""You are a material science expert with deep and comprehensive knowledge of metals, ceramics, polymers, composites, and semiconductors.  
            You understand the key material properties, including mechanical (strength, hardness), thermal (conductivity, expansion), electrical (resistivity, conductivity), optical, magnetic, and chemical properties.  
            You are familiar with measurement units used in material science such as mole, meter, pascal, newton, and others.  
            You have expertise in the structure-property relationships and the practical applications of materials in engineering, electronics, energy, and aerospace.  
            You are capable of accurately classifying and categorizing material-related terms using your scientific reasoning and up-to-date knowledge of the field.  
            You explain your classifications clearly and precisely.

            Your task is to classify a given list of material-related terms into one or more appropriate types from a provided list of possible types.

            Please respond strictly with a JSON object where:  
            - Each key is a term (string) from the input list.  
            - Each value is a list of one or more types (strings) assigned to that term based on your expert knowledge.

            List of Possible Types: {types_of_terms}

            Examples and also output format:

            {json.dumps({
            "mole": ["amount of substance unit"],
            "meter": ["length unit"],
            "kilogram": ["mass unit"],
            "celsius": ["temperature unit"],
            "steel": ["material"],
            "density": ["property"],
            "velocity": ["Unknown"]
            })}

            Now classify the following terms:
            {list_of_terms}"""
        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%20==0:
            print(response.text)
# Out:
# 1it [00:49, 49.38s/it]
# {
#     "newton": [
#         "force unit"
#     ],
#     "newton meter": [
#         "energy unit"
#     ],
#     "newton per meter": [
#         "unit"
#     ],
#     "coulomb per square meter": [
#         "unit"
#     ],
#     "mole per cubic meter": [
#         "unit"
#     ],
#     "per ampere": [
#         "unit"
#     ],
#     "second power 4": [
#         "unit"
#     ],
#     "per kilogram": [
#         "unit"
#     ],
#     "joule per mole": [
#         "molar energy unit"
#     ],
#     "coulomb per kilogram": [
#         "unit"
#     ],
#     "ampere per square meter": [
#         "unit"
#     ],
#     "joule": [
#         "energy unit"
#     ],
#     "meter squared": [
#         "unit"
#     ],
#     "joule per kilogram per kelvin": [
#         "unit"
#     ],
#     "per steradian": [
#         "unit"
#     ],
#     "second per mole": [
#         "unit"
#     ],
#     "coulomb per cubic meter": [
#         "unit"
#     ],
#     "joule per mole per kelvin": [
#         "entropy unit"
#     ],
#     "watt per meter per kelvin": [
#         "unit"
#     ],
#     "reciprocal second": [
#         "angular velocity unit"
#     ],
#     "watt": [
#         "power unit"
#     ],
#     "gray per second": [
#         "unit"
#     ]
# }
# 16it [06:19, 23.70s/it]

# %%
final_ans
# Out:
# ['{\n    "newton": [\n        "force unit"\n    ],\n    "newton meter": [\n        "energy unit"\n    ],\n    "newton per meter": [\n        "unit"\n    ],\n    "coulomb per square meter": [\n        "unit"\n    ],\n    "mole per cubic meter": [\n        "unit"\n    ],\n    "per ampere": [\n        "unit"\n    ],\n    "second power 4": [\n        "unit"\n    ],\n    "per kilogram": [\n        "unit"\n    ],\n    "joule per mole": [\n        "molar energy unit"\n    ],\n    "coulomb per kilogram": [\n        "unit"\n    ],\n    "ampere per square meter": [\n        "unit"\n    ],\n    "joule": [\n        "energy unit"\n    ],\n    "meter squared": [\n        "unit"\n    ],\n    "joule per kilogram per kelvin": [\n        "unit"\n    ],\n    "per steradian": [\n        "unit"\n    ],\n    "second per mole": [\n        "unit"\n    ],\n    "coulomb per cubic meter": [\n        "unit"\n    ],\n    "joule per mole per kelvin": [\n        "entropy unit"\n    ],\n    "watt per meter per kelvin": [\n        "unit"\n    ],\n    "reciprocal second": [\n        "angular velocity unit"\n    ],\n    "watt": [\n        "power unit"\n    ],\n    "gray per second": [\n        "unit"\n    ]\n}',
#  '{\n    "m2·m-2": [\n        "solid angle unit",\n        "plane angle unit"\n    ]\n}',
#  '{\n    "farad": [\n        "permittivity unit"\n    ]\n}',
#  '{\n    "dalton": [\n        "mass unit"\n    ]\n}',
#  '{\n    "radian": [\n        "solid angle unit"\n    ]\n}',
#  '{\n    "becquerel": [\n        "unit"\n    ]\n}',
#  '{\n    "byte": [\n        "information unit"\n    ]\n}',
#  '{\n    "unit_kelvin_-1": [\n        "unit"\n    ]\n}',
#  '{\n  "unit_electron_volt": [\n    "energy unit"\n  ]\n}',
#  '{\n    "lumen": [\n        "luminous flux unit"\n    ]\n}',
#  '{\n    "hertz": [\n        "unit"\n    ]\n}',
#  '{\n    "micrometer": [\n        "length unit"\n    ]\n}',
#  '{\n  "unit_gigapascal": [\n    "pressure unit",\n    "unit"\n  ]\n}',
#  '{\n    "unit_megapascal": [\n        "pressure unit",\n        "unit"\n    ]\n}',
#  '{\n    "fahrenheit": [\n        "temperature unit"\n    ]\n}',
#  '{\n    "tesla": [\n        "magnetic flux density unit",\n        "unit"\n    ]\n}']

# %%
new_data
# Out:
# [{'id': 'TT_5a5763f5', 'term': 'newton'},
#  {'id': 'TT_c4f339b8', 'term': 'newton meter'},
#  {'id': 'TT_ce5417fc', 'term': 'newton per meter'},
#  {'id': 'TT_25014bd4', 'term': 'coulomb per square meter'},
#  {'id': 'TT_46dad9e9', 'term': 'm2·m-2'},
#  {'id': 'TT_49ab10c7', 'term': 'mole per cubic meter'},
#  {'id': 'TT_ab5a8ad6', 'term': 'per ampere'},
#  {'id': 'TT_08f9b767', 'term': 'farad'},
#  {'id': 'TT_4cff4fec', 'term': 'dalton'},
#  {'id': 'TT_ce2b537c', 'term': 'second power 4'},
#  {'id': 'TT_dae2a7a6', 'term': 'per kilogram'},
#  {'id': 'TT_f8e74193', 'term': 'radian'},
#  {'id': 'TT_8a920749', 'term': 'joule per mole'},
#  {'id': 'TT_a0402f84', 'term': 'becquerel'},
#  {'id': 'TT_14fbac11', 'term': 'byte'},
#  {'id': 'TT_f1361175', 'term': 'coulomb per kilogram'},
#  {'id': 'TT_981df168', 'term': 'ampere per square meter'},
#  {'id': 'TT_4c87c381', 'term': 'unit_kelvin_-1'},
#  {'id': 'TT_f15ef7cd', 'term': 'joule'},
#  {'id': 'TT_40a02db8', 'term': 'meter squared'},
#  {'id': 'TT_d714834e', 'term': 'unit_electron_volt'},
#  {'id': 'TT_a9f30802', 'term': 'joule per kilogram per kelvin'},
#  {'id': 'TT_8182f530', 'term': 'per steradian'},
#  {'id': 'TT_ab85a470', 'term': 'second per mole'},
#  {'id': 'TT_b8e7ebae', 'term': 'coulomb per cubic meter'},
#  {'id': 'TT_9aec366c', 'term': 'joule per mole per kelvin'},
#  {'id': 'TT_b9a7fd17', 'term': 'lumen'},
#  {'id': 'TT_5ba78869', 'term': 'hertz'},
#  {'id': 'TT_9e7440e4', 'term': 'watt per meter per kelvin'},
#  {'id': 'TT_177b58ec', 'term': 'micrometer'},
#  {'id': 'TT_e707b15a', 'term': 'unit_gigapascal'},
#  {'id': 'TT_fac88931', 'term': 'unit_megapascal'},
#  {'id': 'TT_300a8cf0', 'term': 'reciprocal second'},
#  {'id': 'TT_e2c90a21', 'term': 'fahrenheit'},
#  {'id': 'TT_71796178', 'term': 'tesla'},
#  {'id': 'TT_e8ee7e46', 'term': 'watt'},
#  {'id': 'TT_4e46b6d7', 'term': 'gray per second'}]

# %%
term_to_id_mapping = {}
for data_n in new_data:
    term_to_id_mapping[data_n['term']]= data_n['id']

# %%
term_to_id_mapping
# Out:
# {'newton': 'TT_5a5763f5',
#  'newton meter': 'TT_c4f339b8',
#  'newton per meter': 'TT_ce5417fc',
#  'coulomb per square meter': 'TT_25014bd4',
#  'm2·m-2': 'TT_46dad9e9',
#  'mole per cubic meter': 'TT_49ab10c7',
#  'per ampere': 'TT_ab5a8ad6',
#  'farad': 'TT_08f9b767',
#  'dalton': 'TT_4cff4fec',
#  'second power 4': 'TT_ce2b537c',
#  'per kilogram': 'TT_dae2a7a6',
#  'radian': 'TT_f8e74193',
#  'joule per mole': 'TT_8a920749',
#  'becquerel': 'TT_a0402f84',
#  'byte': 'TT_14fbac11',
#  'coulomb per kilogram': 'TT_f1361175',
#  'ampere per square meter': 'TT_981df168',
#  'unit_kelvin_-1': 'TT_4c87c381',
#  'joule': 'TT_f15ef7cd',
#  'meter squared': 'TT_40a02db8',
#  'unit_electron_volt': 'TT_d714834e',
#  'joule per kilogram per kelvin': 'TT_a9f30802',
#  'per steradian': 'TT_8182f530',
#  'second per mole': 'TT_ab85a470',
#  'coulomb per cubic meter': 'TT_b8e7ebae',
#  'joule per mole per kelvin': 'TT_9aec366c',
#  'lumen': 'TT_b9a7fd17',
#  'hertz': 'TT_5ba78869',
#  'watt per meter per kelvin': 'TT_9e7440e4',
#  'micrometer': 'TT_177b58ec',
#  'unit_gigapascal': 'TT_e707b15a',
#  'unit_megapascal': 'TT_fac88931',
#  'reciprocal second': 'TT_300a8cf0',
#  'fahrenheit': 'TT_e2c90a21',
#  'tesla': 'TT_71796178',
#  'watt': 'TT_e8ee7e46',
#  'gray per second': 'TT_4e46b6d7'}

# %%
result = []
for ans_1 in final_ans:
    ans_dict = json.loads(ans_1)
    for term, type in ans_dict.items():
        result.append({"id":term_to_id_mapping[term], "term":term, "types":type})

# %%
result
# Out:
# [{'id': 'TT_5a5763f5', 'term': 'newton', 'types': ['force unit']},
#  {'id': 'TT_c4f339b8', 'term': 'newton meter', 'types': ['energy unit']},
#  {'id': 'TT_ce5417fc', 'term': 'newton per meter', 'types': ['unit']},
#  {'id': 'TT_25014bd4', 'term': 'coulomb per square meter', 'types': ['unit']},
#  {'id': 'TT_49ab10c7', 'term': 'mole per cubic meter', 'types': ['unit']},
#  {'id': 'TT_ab5a8ad6', 'term': 'per ampere', 'types': ['unit']},
#  {'id': 'TT_ce2b537c', 'term': 'second power 4', 'types': ['unit']},
#  {'id': 'TT_dae2a7a6', 'term': 'per kilogram', 'types': ['unit']},
#  {'id': 'TT_8a920749',
#   'term': 'joule per mole',
#   'types': ['molar energy unit']},
#  {'id': 'TT_f1361175', 'term': 'coulomb per kilogram', 'types': ['unit']},
#  {'id': 'TT_981df168', 'term': 'ampere per square meter', 'types': ['unit']},
#  {'id': 'TT_f15ef7cd', 'term': 'joule', 'types': ['energy unit']},
#  {'id': 'TT_40a02db8', 'term': 'meter squared', 'types': ['unit']},
#  {'id': 'TT_a9f30802',
#   'term': 'joule per kilogram per kelvin',
#   'types': ['unit']},
#  {'id': 'TT_8182f530', 'term': 'per steradian', 'types': ['unit']},
#  {'id': 'TT_ab85a470', 'term': 'second per mole', 'types': ['unit']},
#  {'id': 'TT_b8e7ebae', 'term': 'coulomb per cubic meter', 'types': ['unit']},
#  {'id': 'TT_9aec366c',
#   'term': 'joule per mole per kelvin',
#   'types': ['entropy unit']},
#  {'id': 'TT_9e7440e4', 'term': 'watt per meter per kelvin', 'types': ['unit']},
#  {'id': 'TT_300a8cf0',
#   'term': 'reciprocal second',
#   'types': ['angular velocity unit']},
#  {'id': 'TT_e8ee7e46', 'term': 'watt', 'types': ['power unit']},
#  {'id': 'TT_4e46b6d7', 'term': 'gray per second', 'types': ['unit']},
#  {'id': 'TT_46dad9e9',
#   'term': 'm2·m-2',
#   'types': ['solid angle unit', 'plane angle unit']},
#  {'id': 'TT_08f9b767', 'term': 'farad', 'types': ['permittivity unit']},
#  {'id': 'TT_4cff4fec', 'term': 'dalton', 'types': ['mass unit']},
#  {'id': 'TT_f8e74193', 'term': 'radian', 'types': ['solid angle unit']},
#  {'id': 'TT_a0402f84', 'term': 'becquerel', 'types': ['unit']},
#  {'id': 'TT_14fbac11', 'term': 'byte', 'types': ['information unit']},
#  {'id': 'TT_4c87c381', 'term': 'unit_kelvin_-1', 'types': ['unit']},
#  {'id': 'TT_d714834e', 'term': 'unit_electron_volt', 'types': ['energy unit']},
#  {'id': 'TT_b9a7fd17', 'term': 'lumen', 'types': ['luminous flux unit']},
#  {'id': 'TT_5ba78869', 'term': 'hertz', 'types': ['unit']},
#  {'id': 'TT_177b58ec', 'term': 'micrometer', 'types': ['length unit']},
#  {'id': 'TT_e707b15a',
#   'term': 'unit_gigapascal',
#   'types': ['pressure unit', 'unit']},
#  {'id': 'TT_fac88931',
#   'term': 'unit_megapascal',
#   'types': ['pressure unit', 'unit']},
#  {'id': 'TT_e2c90a21', 'term': 'fahrenheit', 'types': ['temperature unit']},
#  {'id': 'TT_71796178',
#   'term': 'tesla',
#   'types': ['magnetic flux density unit', 'unit']}]

# %%
import json

with open("Task_B_term_types_matonto.json", "w", encoding="utf-8") as f:
    json.dump(result, f, indent=2, ensure_ascii=False)
