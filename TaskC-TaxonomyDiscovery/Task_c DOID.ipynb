# %%
import json
def load_json(data_path):
    with open(data_path, "r", encoding="utf-8") as file_1:
        data = json.load(file_1)
    return data

# %%
data = load_json("DOID/train/doid_train_pairs.json")

# %%
len(data), data[:5]
# Out:
# (28924,
#  [{'ID': 'TR_2ed4e26c',
#    'parent': 'autosomal dominant disease',
#    'child': 'autosomal dominant Emery-Dreifuss muscular dystrophy 5'},
#   {'ID': 'TR_18d3b799',
#    'parent': 'autosomal recessive disease',
#    'child': 'congenital disorder of glycosylation Iq'},
#   {'ID': 'TR_934e161f',
#    'parent': 'squamous cell carcinoma',
#    'child': 'tonsil squamous cell carcinoma'},
#   {'ID': 'TR_bc701c51',
#    'parent': 'retinoschisis',
#    'child': 'X-linked juvenile retinoschisis 1'},
#   {'ID': 'TR_932695e9',
#    'parent': 'lymph node disease',
#    'child': 'lymph node tuberculosis'}])

# %%
from collections import defaultdict

class UnionFind:
    def __init__(self):
        self.parent = {}

    def find(self, x):
        # Path compression
        if x != self.parent.setdefault(x, x):
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        self.parent[self.find(x)] = self.find(y)

def build_clusters(relationships):
    uf = UnionFind()
    
    for rel in relationships:
        parent = rel["parent"]
        child = rel["child"]
        uf.union(parent, child)

    clusters = defaultdict(set)
    for term in set([item for rel in relationships for item in (rel["parent"], rel["child"])]):
        root = uf.find(term)
        clusters[root].add(term)

    # Add isolated nodes (no parent/child relationship)
    all_terms = set()
    for rel in relationships:
        all_terms.add(rel["parent"])
        all_terms.add(rel["child"])
    for term in all_terms:
        if term not in uf.parent:
            clusters[term].add(term)

    return list(clusters.values())

# %%
clusters = build_clusters(data)

# %%
len(clusters)
# Out:
# 75

# %%
clusters
# Out:
# [{'PO_0000055',
#   'aerial tuber axillary vegetative bud',
#   'areole bud',
#   'axillary bud',
#   'axillary flower bud',
#   'axillary inflorescence bud',
#   'axillary reproductive bud',
#   'axillary shoot system',
#   'axillary strobilus bud',
#   'axillary vegetative bud',
#   'bostryx inflorescence',
#   'bulb',
#   'capitulum inflorescence',
#   'catkin inflorescence',
#   'cincinnus inflorescence',
#   'compound cincinnus inflorescence',
#   'compound drepanium inflorescence',
#   'compound raceme inflorescence',
#   'compound spike inflorescence',
#   'compound umbel inflorescence',
#   'corm',
#   'corymb inflorescence',
#   'cyme inflorescence',
#   'determinate thyrse inflorescence',
#   'disk flower',
#   'ear floret',
#   'ear inflorescence',
#   'ear infructescence',
#   'ear sessile spikelet',
#   'ear spikelet',
#   'flower',
#   'flower bud',
#   'gametophore',
#   'gametophore bud',
#   'indeterminate thyrse inflorescence',
#   'inflorescence',
#   'inflorescence branch crown',
#   'inflorescence bud',
#   'infructescence',
#   'long shoot',
#   'lower floret of pedicellate spikelet of ear',
#   'lower floret of pedicellate spikelet of tassel',
#   'lower floret of sessile spikelet of ear',
#   'lower floret of sessile spikelet of tassel',
#   'megasporangiate strobilus',
#   'microsporangiate strobilus',
#   'pistillate flower',
#   'pistillate inflorescence',
#   'primary shoot system',
#   'ray flower',
#   'reproductive bud',
#   'reproductive shoot system',
#   'rhipidium inflorescence',
#   'second order inflorescence',
#   'second order infructescence',
#   'shoot axis tuber axillary vegetative bud',
#   'shoot system',
#   'shoot-borne shoot system',
#   'spike inflorescence',
#   'spikelet',
#   'spikelet floret',
#   'staminate flower',
#   'staminate inflorescence',
#   'strobilus',
#   'strobilus bud',
#   'subterranean tuber axillary vegetative bud',
#   'tassel floret',
#   'tassel inflorescence',
#   'tassel pedicellate spikelet',
#   'tassel spikelet',
#   'terminal bud',
#   'terminal flower bud',
#   'terminal inflorescence bud',
#   'terminal reproductive bud',
#   'terminal strobilus bud',
#   'terminal vegetative bud',
#   'umbel inflorescence',
#   'upper floret of pedicellate spikelet of ear',
#   'upper floret of pedicellate spikelet of tassel',
#   'upper floret of sessile spikelet of ear',
#   'upper floret of sessile spikelet of tassel',
#   'vegetative bud',
#   'vegetative shoot system'},
#  {'1 main shoot growth stage',
#   '1 pattern formation stage',
#   '2 endoreduplication stage',
#   '2 formation of axillary shoot stage',
#   '2.01 main shoot and axillary shoots visible at one node stage',
#   '2.02 main shoot and axillary shoots visible at two nodes stage',
#   '2.04 main shoot and axillary shoots visible at four nodes stage',
#   '2.05 main shoot and axillary shoots visible at five nodes stage',
#   '2.06 main shoot and axillary shoots visible at six nodes stage',
#   '2.07 main shoot and axillary shoots visible at seven nodes stage',
#   '2.08 main shoot and axillary shoots visible at eight nodes stage',
#   '2.09 main shoot and axillary shoots visible at nine or more nodes stage',
#   '3 branch formation stage',
#   'A megaspore mother cell enlarges stage',
#   'A microsporogenous mass stage',
#   'B meiosis of megaspore mother cell stage',
#   'BFO_0000015',
#   'C callose wall formation in pollen mother cells stage',
#   'C tetrad of megaspores stage',
#   'D megaspore degeneration stage',
#   'D pollen mother cell meiosis stage',
#   'FL.00 first flower(s) open stage',
#   'FL.02 1/2 of flowers open stage',
#   'FL.03 3/4 of flowers open stage',
#   'FL.04 end of flowering stage',
#   'G early unicellular microspore stage',
#   'H late unicellular microspore stage',
#   'I first mitotic division stage',
#   'IL.00 inflorescence just visible stage',
#   'J bicellular pollen stage',
#   'LP.01 one leaf visible stage',
#   'LP.03 three leaves visible stage',
#   'LP.07 seven leaves visible stage',
#   'LP.08 eight leaves visible stage',
#   'LP.10 ten leaves visible stage',
#   'LP.11 eleven leaves visible stage',
#   'LP.12 twelve leaves visible stage',
#   'LP.13 thirteen leaves visible stage',
#   'LP.14 fourteen leaves visible stage',
#   'LP.15 fifteen leaves visible stage',
#   'LP.16 sixteen leaves visible stage',
#   'LP.17 seventeen leaves visible stage',
#   'LP.18 eighteen leaves visible stage',
#   'LP.19 nineteen leaves visible stage',
#   'LP.20 twenty or more leaves whorls visible stage',
#   'bud development stage',
#   'cell death stage of secondary xylem',
#   'cell differentiation stage of secondary xylem',
#   'cell division stage of secondary xylem',
#   'chalazal and micropylar domain establishment stage',
#   'coleoptile emergence stage',
#   'collective plant organ structure development stage',
#   'developing seed stage',
#   'dry seed stage',
#   'early rosette growth stage',
#   'early whole plant fruit ripening stage',
#   'endosperm development stage',
#   'epicotyl emergence stage',
#   'fertilized ovule stage',
#   'floral organ differentiation stage',
#   'floral organ formation stage',
#   'floral organ meristem development stage',
#   'floral organ primordium development stage',
#   'formation of aleurone and starchy layers stage',
#   'fruit development stage',
#   'fruit formation stage',
#   'fruit initiation stage',
#   'fruit ripening stage',
#   'fruit size 10 to 30% stage',
#   'fruit size 30 to 50% stage',
#   'fruit size 50 to 70% stage',
#   'fruit size 70% to final size stage',
#   'fully expanded lemma stage',
#   'fully expanded lodicule stage',
#   'fully expanded palea stage',
#   'functional specialization of the endosperm stage',
#   'gametophore vegetative whole plant development stage',
#   'gametophyte development stage',
#   'gametophyte reproductive stage',
#   'gametophyte senescent stage',
#   'gametophyte vegetative stage',
#   'late rosette growth stage',
#   'leaf development stage',
#   'leaf production stage',
#   'leaf trichome development stage',
#   'lemma development stage',
#   'lemma differentiation and expansion stage',
#   'lemma primordia visible stage',
#   'lodicule development stage',
#   'lodicule differentiation and expansion stage',
#   'lodicule primordia visible stage',
#   'mature plant embryo stage',
#   'megagametophyte development stage',
#   'microgametophyte development stage',
#   'mid whole plant fruit ripening stage',
#   'multi-tissue plant structure development stage',
#   'palea development stage',
#   'palea primordia visible stage',
#   'phloem development stage',
#   'phyllome development stage',
#   'plant embryo bilateral stage',
#   'plant embryo coleoptilar stage',
#   'plant embryo cotyledonary stage',
#   'plant embryo development stage',
#   'plant embryo dormant stage',
#   'plant embryo globular stage',
#   'plant embryo true leaf formation stage',
#   'plant organ development stage',
#   'plant proembryo stage',
#   'plant spore stage',
#   'plant structure development stage',
#   'plant tissue development stage',
#   'plant zygote stage',
#   'pollen development stage',
#   'primary endosperm cell stage',
#   'protonema whole plant development stage',
#   'rosette growth complete stage',
#   'rosette growth stage',
#   'secondary xylem development stage',
#   'secondary xylem parenchyma cell death stage of secondary xylem',
#   'seed development stage',
#   'seed dormant stage',
#   'seed germination stage',
#   'seed imbibition stage',
#   'seed maturation stage',
#   'seed trichome development stage',
#   'seed trichome initiation stage',
#   'seed trichome maturation stage',
#   'seed trichome secondary wall biosynthesis stage',
#   'seedling development stage',
#   'seedling shoot emergence stage',
#   'shoot system development stage',
#   'sporophyte development stage',
#   'sporophyte dormant stage',
#   'sporophyte reproductive stage',
#   'sporophyte senescent stage',
#   'sporophyte vegetative stage',
#   'thallus vegetative whole plant development stage',
#   'tracheary element death stage of secondary xylem',
#   'trichome development stage',
#   'vascular leaf development stage',
#   'vascular leaf differentiation stage',
#   'vascular leaf post-expansion stage',
#   'vascular leaf senescent stage',
#   'vascular tissue development stage',
#   'whole plant development stage',
#   'whole plant flowering stage',
#   'whole plant fruit development stage',
#   'whole plant fruit formation stage',
#   'whole plant fruit formation stage 10 to 30%',
#   'whole plant fruit formation stage 50 to 70%',
#   'whole plant fruit formation stage 70% to final size',
#   'whole plant fruit ripening complete stage',
#   'whole plant fruit ripening stage',
#   'whole plant inflorescence detectable stage',
#   'xylem development stage'},
#  {'PO_0025349',
#   'abaxial nucellar projection',
#   'abaxial protoderm',
#   'abscission zone',
#   'adaxial nucellar projection',
#   'adult vascular leaf',
#   'adventitious root nodule',
#   'aerenchyma',
#   'aerial tuber cortex',
#   'aerial tuber interfascicular region',
#   'aerial tuber periderm',
#   'aerial tuber perimedullary zone',
#   'aerial tuber pith',
#   'alar cell',
#   'albuminous cell',
#   'aleurone layer',
#   'androecium',
#   'anther',
#   'anther dehiscence zone',
#   'anther septum',
#   'anther theca',
#   'anther wall',
#   'anther wall exothecium',
#   'anther wall middle layer',
#   'anther wall outer secondary parietal cell layer',
#   'anther wall primary parietal cell layer',
#   'anther wall secondary parietal cell layer',
#   'anther wall tapetum',
#   'antheridium',
#   'antheridium head',
#   'antheridium jacket layer',
#   'antheridium jacket layer cell',
#   'antheridium microgametophyte',
#   'antheridium sperm cell',
#   'antiraphe',
#   'apical hook',
#   'apical meristem',
#   'archegonium',
#   'archegonium central cell',
#   'archegonium egg cell',
#   'archegonium head',
#   'archegonium megagametophyte',
#   'archegonium neck',
#   'archegonium neck canal cell',
#   'archesporial cell',
#   'archesporium',
#   'aril',
#   'arillode',
#   'arilloid',
#   'articulated laticifer',
#   'axial secondary xylem parenchyma',
#   'axial secondary xylem parenchyma cell',
#   'axillary hair',
#   'axillary hair basal cell',
#   'axillary hair base',
#   'axillary hair terminal cell',
#   'bark',
#   'basal endosperm transfer cell',
#   'berry fruit',
#   'brachycyte',
#   'bract',
#   'bract abaxial epidermis',
#   'bract adaxial epidermis',
#   'bract anlagen',
#   'bract base',
#   'bract epidermis',
#   'bract margin',
#   'bracteole',
#   'branch epidermis',
#   'branch internode differentiation zone',
#   'branch internode elongation zone',
#   'branch stele',
#   'branch trichome',
#   'bulliform cell',
#   'bundle sheath',
#   'bundle sheath cell',
#   'bundle sheath chlorenchyma cell',
#   'callus parenchyma cell',
#   'calyptra corolla',
#   'calyx',
#   'cambial zone',
#   'cambium',
#   'capsule fruit',
#   'cardinal organ part',
#   'cardinal part of multi-tissue plant structure',
#   'carpel',
#   'carpel abaxial epidermis',
#   'carpel adaxial epidermis',
#   'carpel anlagen',
#   'carpel epidermis',
#   'carpel margin',
#   'caruncle',
#   'caryopsis fruit',
#   'caryopsis hull',
#   'cauline leaf',
#   'caulonema',
#   'caulonema cell',
#   'cellular endosperm',
#   'central endosperm',
#   'central root cap',
#   'central root cap of lateral root',
#   'central root cap of primary root',
#   'central strand',
#   'central zone',
#   'central zone of the leaf lamina',
#   'central zone of the petiole',
#   'ceonosorus',
#   'chalaza',
#   'chalazal cyst',
#   'chlorenchyma',
#   'chlorenchyma cell',
#   'chloronema cell',
#   'cigar leaf',
#   'cigar leaf lamina abaxial epidermis',
#   'circumscissile capsule fruit',
#   'coccarium capsule fruit',
#   'coleoptile',
#   'coleorhiza',
#   'collective organ part structure',
#   'collective phyllome structure',
#   'collective plant organ structure',
#   'collective plant structure',
#   'collective tepal structure',
#   'collenchyma',
#   'columella',
#   'columella root cap cell',
#   'coma',
#   'companion cell',
#   'compound leaf',
#   'connective',
#   'cork cambium',
#   'corolla',
#   'corolla spur',
#   'cortex',
#   'cotyledon',
#   'cotyledon abaxial epidermis',
#   'cotyledon adaxial epidermis',
#   'cotyledon anlagen',
#   'cotyledon epidermis',
#   'cotyledon margin',
#   'cultured plant callus',
#   'cultured plant cell',
#   'cultured plant embryo',
#   'cultured somatic plant embryo',
#   'cultured zygote-derived plant embryo',
#   'cuticular wax',
#   'cutin',
#   'dehiscence zone',
#   'drupe fruit',
#   'ear apical meristem',
#   'ear inflorescence axillary meristem',
#   'ear meristem',
#   'ear spikelet meristem',
#   'ear spikelet pair meristem',
#   'early wood tracheary element',
#   'egg apparatus',
#   'embryo basal cell',
#   'embryo coleorhiza',
#   'embryo cortex',
#   'embryo hypocotyl',
#   'embryo hypophysis',
#   'embryo leaf',
#   'embryo mesocotyl',
#   'embryo plant cell',
#   'embryo plant structure',
#   'embryo sac',
#   'embryo sac egg cell',
#   'embryogenic callus',
#   'endocarp',
#   'endodermis cell',
#   'endosperm',
#   'endotegmen',
#   'endotesta',
#   'endothelium',
#   'ensiform vascular leaf',
#   'epiblast',
#   'epicalyx',
#   'epicalyx bract',
#   'epicotyl',
#   'epidermal cork cell',
#   'epidermal rhizoid',
#   'epiphragm',
#   'epithem cell',
#   'exocarp',
#   'exodermis',
#   'exotegmen',
#   'exothecium',
#   'female archesporial cell',
#   'fertile lemma',
#   'filament epidermis',
#   'flag leaf',
#   'floral organ',
#   'floral organ abscission zone',
#   'flower bract',
#   'flower meristem',
#   'flower nectary',
#   'flower pedicel abscission zone',
#   'follicle fruit',
#   'free sepal',
#   'free tepal',
#   'fruit',
#   'fruit columella',
#   'fruit dehiscence zone',
#   'fruit distal end',
#   'fruit pedicel abscission zone',
#   'fruit placenta',
#   'fruit proximal end',
#   'fruit replum',
#   'fruit septum',
#   'fused calyx',
#   'fused collective tepal structure',
#   'fused corolla',
#   'fused perianth',
#   'fused petal',
#   'fused sepal',
#   'fused tepal',
#   'gametophore axillary hair',
#   'gametophore axillary hair basal cell',
#   'gametophore axillary hair base',
#   'gametophore axillary hair terminal cell',
#   'gametophyte coma',
#   'gametophyte perianth',
#   'glume',
#   'glume awn',
#   'glume of ear spikelet',
#   'glume of tassel spikelet',
#   'ground tissue cell',
#   'guard cell',
#   'guard mother cell',
#   'gynoecium',
#   'helobial endosperm',
#   'hesperidium fruit',
#   'hilum',
#   'hydroid',
#   'hyperphyll',
#   'hypocotyl',
#   'hypocotyl epidermis',
#   'hypodermis',
#   'in vitro plant structure',
#   'inflorescence apical meristem',
#   'inflorescence axillary meristem',
#   'inflorescence axis internode',
#   'inflorescence bract',
#   'inflorescence branch pulvinus',
#   'inflorescence meristem',
#   'intercuticular wax',
#   'interfascicular cambium',
#   'interfascicular region',
#   'involucre',
#   'juice sac tissue',
#   'juvenile vascular leaf',
#   'keel',
#   'keel petal',
#   'lamina',
#   'late wood tracheary element',
#   'lateral meristem',
#   'lateral root apical meristem',
#   'lateral root cap',
#   'lateral root cap of lateral root',
#   'lateral root cap of primary root',
#   'lateral root differentiation zone',
#   'lateral root tip',
#   'leaf',
#   'leaf abaxial epidermis',
#   'leaf abaxial pavement cell',
#   'leaf abscission zone',
#   'leaf adaxial epidermis',
#   'leaf aerenchyma',
#   'leaf base',
#   'leaf collar',
#   'leaf epidermis',
#   'leaf guard cell',
#   'leaf lamina',
#   'leaf lamina abaxial epidermis',
#   'leaf lamina adaxial epidermis',
#   'leaf lamina areole',
#   'leaf lamina base',
#   'leaf lamina crena',
#   'leaf lamina epidermis',
#   'leaf lamina lobe',
#   'leaf lamina margin',
#   'leaf margin',
#   'leaf marginal meristem',
#   'leaf mesophyll',
#   'leaf papilla cell',
#   'leaf pavement cell',
#   'leaf plate meristem',
#   'leaf procambial cell',
#   'leaf sheath',
#   'leaf sheath adaxial epidermis',
#   'leaf sheath auricle',
#   'leaf sheath epidermis',
#   'leaf sheath margin',
#   'leaf sheath pulvinus',
#   'leaf tendril',
#   'leaf tip',
#   'leaf-derived cultured plant cell',
#   'leaflet',
#   'leaflet margin',
#   'legume fruit',
#   'lemma',
#   'lemma apiculus',
#   'lemma awn',
#   'lenticel',
#   'leptoid',
#   'leptome',
#   'ligule',
#   'loculicidal capsule fruit',
#   'lodicule',
#   'lodicule anlagen',
#   'loment fruit',
#   'long cell',
#   'long lateral tassel branch meristem',
#   'lower glume',
#   'lower glume of ear spikelet',
#   'lower glume of pedicellate spikelet of ear',
#   'lower glume of pedicellate spikelet of tassel',
#   'lower glume of sessile spikelet of ear',
#   'lower glume of sessile spikelet of tassel',
#   'lower glume of tassel spikelet',
#   'male archesporial cell',
#   'megagametophyte',
#   'megasporangium endothecium',
#   'megasporangium exothecium',
#   'megasporangium tapetum',
#   'megasporangium tapetum cell',
#   'megasporangium wall',
#   'megasporocyte',
#   'megasporophyll',
#   'mericarp',
#   'meristem L1 layer',
#   'meristem L2 layer',
#   'meristem L3 layer',
#   'meristematic cell',
#   'mesocarp',
#   'mesocotyl',
#   'mesophyll',
#   'mesophyll cell',
#   'metaxylem tracheary element',
#   'metaxylem vessel member',
#   'microgametophyte',
#   'micropylar endosperm',
#   'microsporangium',
#   'microsporangium exothecium',
#   'microsporangium tapetum',
#   'microsporangium tapetum cell',
#   'microsporangium wall',
#   'microspore-derived cultured plant embryo',
#   'microsporocyte',
#   'multi-tissue plant structure',
#   'multicellular plant gametangium',
#   'multicellular trichome',
#   'multicellular trichome branch cell',
#   'multicellular trichome tip',
#   'myrosin cell',
#   'native plant cell',
#   'nectary',
#   'nectary epidermis',
#   'nectary parenchyma',
#   'non-hair root epidermal cell',
#   'non-vascular leaf',
#   'nucellar epidermis',
#   'nucellar projection',
#   'nut fruit',
#   'ordinary companion cell',
#   'organogenic callus',
#   'ovuliferous scale ovule',
#   'palea',
#   'palea apiculus',
#   'palea awn',
#   'palisade mesophyll',
#   'palisade mesophyll cell',
#   'palmate leaf',
#   'papilla cell',
#   'pappus',
#   'pappus element',
#   'paraclade cortex',
#   'paraphyllium',
#   'paraphysis',
#   'parenchyma',
#   'parenchyma cell',
#   'pedicel cortex',
#   'peduncle epidermis',
#   'peduncle trichome',
#   'pepo fruit',
#   'perianth',
#   'pericarp',
#   'perichaetal bract',
#   'pericycle',
#   'periderm',
#   'perigonial bract',
#   'perimedullary zone',
#   'peripheral zone',
#   'perisperm',
#   'peristome',
#   'peristome tooth',
#   'persistent sepal',
#   'persistent stamen',
#   'persistent tepal',
#   'petal',
#   'petal abaxial epidermis',
#   'petal adaxial epidermis',
#   'petal apex',
#   'petal base',
#   'petal epidermis',
#   'petal margin',
#   'petal mesophyll',
#   'petal parenchyma',
#   'petal tip',
#   'petiole abaxial epidermis',
#   'petiole cortex',
#   'petiole distal end',
#   'petiole epidermis',
#   'petiole lamina',
#   'petiole margin',
#   'petiole parenchyma',
#   'petiole proximal end',
#   'petiole pulvinus',
#   'phellem',
#   'phelloderm',
#   'phloem sap',
#   'phyllode leaf',
#   'phyllome',
#   'phyllome abaxial meristem',
#   'phyllome adaxial meristem',
#   'phyllome anlagen',
#   'phyllome apex',
#   'phyllome base',
#   'phyllome epidermis',
#   'phyllome founder cell',
#   'phyllome guard cell',
#   'phyllome lamina',
#   'phyllome lamina areole',
#   'phyllome lamina crena',
#   'phyllome lamina lobe',
#   'phyllome lamina tooth',
#   'phyllome margin',
#   'phyllome marginal meristem',
#   'phyllome plate meristem',
#   'phyllome tip',
#   'pinnate leaf',
#   'pistillode',
#   'pith',
#   'placenta',
#   'placentoid',
#   'plant anatomical entity',
#   'plant axis differentiation zone',
#   'plant axis elongation zone',
#   'plant callus',
#   'plant cell',
#   'plant cuticle proper',
#   'plant egg cell',
#   'plant embryo',
#   'plant embryo coleoptile',
#   'plant embryo proper',
#   'plant epidermal cell',
#   'plant epidermis',
#   'plant gall',
#   'plant gamete',
#   'plant organ',
#   'plant organ lamina',
#   'plant organ margin',
#   'plant ovary',
#   'plant ovary epidermis',
#   'plant ovary ovule',
#   'plant ovary placenta',
#   'plant ovary septum',
#   'plant ovary wall',
#   'plant ovary wall middle layer',
#   'plant ovule',
#   'plant ovule inner integument',
#   'plant ovule integument',
#   'plant ovule outer integument',
#   'plant sap',
#   'plant sperm cell',
#   'plant structure',
#   'plant zygote',
#   'plerome',
#   'pollen sac',
#   'pollen sperm cell',
#   'pollen tube cell',
#   'pome fruit',
#   'portion of embryo plant tissue',
#   'portion of ground tissue',
#   'portion of meristem tissue',
#   'portion of plant substance',
#   'portion of plant tissue',
#   'portion of secretory tissue',
#   'portion of transfusion tissue',
#   'portion of transmitting tissue',
#   'primary parietal cell',
#   'primary phloem sieve cell',
#   'primary phloem sieve element',
#   'primary root differentiation zone',
#   'primary root elongation zone',
#   'primary root tip',
#   'primary sporogenous cell',
#   'primary xylem tracheary element',
#   'primary xylem vessel member',
#   'procambial cell',
#   'procumbent ray secondary xylem parenchyma cell',
#   'prophyll',
#   'prophyll margin',
#   'prophyll tendril',
#   'protective layer',
#   'prothallial cell',
#   'protoderm',
#   'protonema',
#   'protosporangium endothecium',
#   'protoxylem tracheary element',
#   'pseudostem',
#   'pulvinus',
#   'quiescent center',
#   'raphe',
#   'ray secondary xylem parenchyma',
#   'ray secondary xylem parenchyma cell',
#   'receptacle cortex',
#   'reproductive shoot apical meristem',
#   'resin cell',
#   'rhizoid',
#   'rhizome internode',
#   'rib zone',
#   'root aerenchyma',
#   'root anlagen',
#   'root apical meristem',
#   'root cap',
#   'root cap of lateral root',
#   'root cap of primary root',
#   'root cork cambium',
#   'root cortex',
#   'root differentiation zone',
#   'root elongation zone',
#   'root epidermal cell',
#   'root epidermis',
#   'root giant cell',
#   'root hair cell',
#   'root lateral meristem',
#   'root meristem',
#   'root nodule',
#   'root nodule meristem',
#   'root parenchyma',
#   'root periderm',
#   'root periderm scar',
#   'root perimedullary zone',
#   'root pith',
#   'root secondary thickening meristem',
#   'root stele',
#   'root syncytium cell',
#   'root system phloem sap',
#   'root system xylem sap',
#   'root tip',
#   'root vascular cambium',
#   'root-derived cultured plant cell',
#   'rosette leaf',
#   'salt gland',
#   'samara fruit',
#   'scale leaf margin',
#   'schizocarp fruit',
#   'sclerenchyma',
#   'scutellar epithelium',
#   'scutellum',
#   'secondary phloem sieve cell',
#   'secondary phloem sieve element',
#   'secondary thickening meristem',
#   'secondary xylem parenchyma',
#   'secondary xylem parenchyma cell',
#   'secondary xylem tracheary element',
#   'secondary xylem tracheid',
#   'secondary xylem vessel member',
#   'seed',
#   'seed chalaza',
#   'seed coat',
#   'seed coat epidermis',
#   'seed funicle',
#   'seed obturator',
#   'seed operculum',
#   'seed raphe',
#   'seed trichome',
#   'seedling',
#   'seedling coleoptile',
#   'seedling coleorhiza',
#   'seedling cotyledon',
#   'seedling epicotyl',
#   'seedling hypocotyl',
#   'seedling mesocotyl',
#   'sepal',
#   'sepal abaxial epidermis',
#   'sepal anlagen',
#   'sepal apex',
#   'sepal base',
#   'sepal epidermis',
#   'sepal epidermis giant cell',
#   'sepal margin',
#   'sepal mesophyll',
#   'sepal parenchyma',
#   'sepal tip',
#   'separation layer',
#   'septicidal capsule fruit',
#   'septum',
#   'shoot apical meristem',
#   'shoot axis cambial zone',
#   'shoot axis cork cambium',
#   'shoot axis cortex',
#   'shoot axis epidermis',
#   'shoot axis hypodermis',
#   'shoot axis internode',
#   'shoot axis internode elongation zone',
#   'shoot axis periderm',
#   'shoot axis perimedullary zone',
#   'shoot axis pith',
#   'shoot axis stele',
#   'shoot axis tegument layer',
#   'shoot axis trichome',
#   'shoot axis tuber epidermis',
#   'shoot axis tuber periderm',
#   'shoot epidermal cell',
#   'shoot epidermal pavement cell',
#   'shoot internode differentiation zone',
#   'shoot system epidermis',
#   'shoot system meristem',
#   'shoot system phloem sap',
#   'shoot-borne root epidermis',
#   'short cell',
#   'short tassel branch meristem',
#   'sieve cell',
#   'sieve element',
#   'silica cell',
#   'silk',
#   'silk scar',
#   'simple leaf',
#   'somatic plant embryo',
#   'sorus',
#   'spikelet meristem',
#   'spikelet pair meristem',
#   'spine leaf',
#   'spine stipule',
#   'spongy mesophyll',
#   'spongy mesophyll cell',
#   'sporangium',
#   'sporangium theca',
#   'sporangium wall',
#   'sporangium wall endothecium',
#   'spore capsule annulus',
#   'spore capsule calyptra',
#   'spore capsule columella',
#   'spore capsule operculum',
#   'spore capsule valve',
#   'sporocyte',
#   'sporophyll',
#   'sporophyll margin',
#   'sporophyte foot',
#   'stamen anlagen',
#   'stamen epidermis',
#   'stamen margin',
#   'stele',
#   'stem aerenchyma',
#   'stem base',
#   'stem epidermis',
#   'stem hypodermis',
#   'stem internode',
#   'stem internode differentiation zone',
#   'stem internode elongation zone',
#   'stem secondary thickening meristem',
#   'stem stele',
#   'stem tegument layer',
#   'stem trichome',
#   'stereid',
#   'stereome',
#   'sterile lemma',
#   'stigma',
#   'stigma epidermis',
#   'stigma papilla cell',
#   'stipel',
#   'stipule',
#   'strophiole',
#   'style',
#   'style epidermis',
#   'subsidiary cell',
#   'subterranean tuber cortex',
#   'subterranean tuber epidermis',
#   'subterranean tuber interfascicular region',
#   'subterranean tuber periderm',
#   'subterranean tuber pith',
#   'suspensor',
#   'tapetum',
#   'tapetum cell',
#   'tassel apical meristem',
#   'tassel inflorescence axillary meristem',
#   'tassel meristem',
#   'tassel spikelet meristem',
#   'tassel spikelet pair meristem',
#   'tepal',
#   'tepal abaxial epidermis',
#   'tepal adaxial epidermis',
#   'tepal apex',
#   'tepal base',
#   'tepal epidermis',
#   'tepal margin',
#   'tepal tip',
#   'terete vascular leaf',
#   'testa',
#   'tetrad of megaspores',
#   'tetrad of microspores',
#   'thallus',
#   'tile cell',
#   'tmema',
#   'tmema cell',
#   'tracheary element',
#   'tracheid',
#   'transfer cell',
#   'transfer companion cell',
#   'transition phyllode leaf',
#   'transition vascular leaf',
#   'transition zone',
#   'trichoblast',
#   'trichome',
#   'trichome apex',
#   'trichome cell',
#   'trichome tip',
#   'tuber cortex',
#   'tuber interfascicular region',
#   'tuber perimedullary zone',
#   'tuber pith',
#   'tubercle',
#   'unicellular plant gametangium',
#   'unicellular trichome',
#   'unifacial vascular leaf',
#   'upright ray secondary xylem parenchyma cell',
#   'utricle capsule fruit',
#   'valve',
#   'vascular cambium',
#   'vascular leaf',
#   'vascular leaf abaxial meristem',
#   'vascular leaf adaxial meristem',
#   'vascular leaf founder cell',
#   'velamen',
#   'venter',
#   'whole plant',
#   'wing petal',
#   'xylem sap',
#   'xylem vessel member',
#   'zygotic plant embryo'},
#  {'leaf lamina intramarginal vein',
#   'leaf lamina vein',
#   'leaf midvein',
#   'pericarp vascular bundle',
#   'petiole vascular bundle',
#   'phyllome lamina vein',
#   'primary leaf vein',
#   'quaternary leaf vein',
#   'vascular bundle'},
#  {'accessory paraclade',
#   'adventitious shoot axis',
#   'cauline paraclade',
#   'cladode',
#   'ear infructescence axis',
#   'ear spikelet rachilla',
#   'eighth order inflorescence axis',
#   'fifth order inflorescence axis',
#   'first order inflorescence axis',
#   'first order infructescence axis',
#   'first order tassel inflorescence axis',
#   'flower pedicel',
#   'fourth order inflorescence axis',
#   'gametophore axis',
#   'gametophore stem',
#   'gynophore',
#   'higher order inflorescence axis',
#   'inflorescence axis',
#   'inflorescence flower pedicel',
#   'infructescence axis',
#   'pedicel',
#   'pedicel of ear spikelet',
#   'pedicel of tassel spikelet',
#   'plant axis',
#   'plant embryo axis',
#   'pseudopodium',
#   'rachilla of pedicellate spikelet of ear',
#   'rachilla of pedicellate spikelet of tassel',
#   'rachilla of sessile spikelet of tassel',
#   'rosette paraclade',
#   'second order inflorescence axis',
#   'shoot axis',
#   'shoot axis tuber',
#   'spikelet pedicel',
#   'spikelet rachilla',
#   'stem',
#   'stem apex tendril',
#   'subterranean shoot axis tuber',
#   'tassel inflorescence branch',
#   'tassel spikelet rachilla',
#   'third order inflorescence axis',
#   'tuber',
#   'tuberous root tuber'},
#  {'anther pore',
#   'hydathode pore',
#   'intercellular space',
#   'leaf mesophyll intercellular space',
#   'leaf sinus',
#   'leaf stomatal pore',
#   'leaf substomatal cavity',
#   'palisade mesophyll intercellular space',
#   'phyllome sinus',
#   'phyllome stomatal pore',
#   'phyllome substomatal cavity',
#   'plant anatomical space',
#   'plant ovule micropyle',
#   'seed micropyle',
#   'spongy mesophyll intercellular space',
#   'spore capsule mouth',
#   'stomatal pore',
#   'stomium',
#   'substomatal cavity'},
#  {'pericycle cell', 'phloem pole pericycle cell', 'xylem pole pericycle cell'},
#  {'SE.01 one node or internode visible stage',
#   'SE.02 two nodes or internodes visible stage',
#   'SE.03 three nodes or internodes visible stage',
#   'SE.04 four nodes or internodes visible stage',
#   'SE.05 five nodes or internodes visible stage',
#   'SE.06 six nodes or internodes visible stage',
#   'SE.07 seven nodes or internodes visible stage',
#   'SE.09 nine nodes or internodes visible stage',
#   'SE.10 ten nodes or internodes visible stage',
#   'SE.11 eleven nodes or internodes visible stage',
#   'SE.12 twelve nodes or internodes visible stage',
#   'SE.14 fourteen nodes or internodes visible stage',
#   'SE.15 fifteen nodes or internodes visible stage',
#   'SE.97 flag leaf visible stage',
#   'stem elongation stage'},
#  {'antipodal cell',
#   'embryo sac cell',
#   'embryo sac central cell',
#   'primary endosperm cell',
#   'synergid'},
#  {'fifth order infructescence axis',
#   'fourth order infructescence axis',
#   'higher order infructescence axis',
#   'ninth order infructescence axis',
#   'second order infructescence axis',
#   'sixth order infructescence axis',
#   'third order infructescence axis'},
#  {'anther vascular system',
#   'carpel vascular system',
#   'centarch protoxylem',
#   'compression wood',
#   'cotyledon vascular system',
#   'diarch protoxylem',
#   'early wood',
#   'exarch protoxylem',
#   'filament vascular system',
#   'flower vascular system',
#   'fruit vascular system',
#   'growth ring',
#   'growth ring boundary',
#   'heartwood',
#   'hypocotyl vascular system',
#   'late wood',
#   'leaf lamina vascular system',
#   'mesarch protoxylem',
#   'metaxylem',
#   'pedicel vascular system',
#   'pentarch protoxylem',
#   'petal vascular system',
#   'petiole vascular system',
#   'phyllome vascular system',
#   'plant embryo vascular system',
#   'portion of vascular tissue',
#   'primary vascular tissue',
#   'primary xylem',
#   'primary xylem vessel',
#   'protoxylem',
#   'ray system',
#   'reaction wood',
#   'root system exarch protoxylem',
#   'root vascular system',
#   'sapwood',
#   'scutellum vascular system',
#   'secondary vascular tissue',
#   'secondary xylem',
#   'secondary xylem vessel',
#   'sepal vascular system',
#   'shoot axis vascular system',
#   'shoot system exarch protoxylem',
#   'shoot system vascular system',
#   'stamen vascular system',
#   'stigma vascular system',
#   'tepal vascular system',
#   'tetrarch protoxylem',
#   'triarch protoxylem',
#   'vascular system',
#   'xylem',
#   'xylem vessel'},
#  {'internal phloem',
#   'metaphloem',
#   'phloem',
#   'primary phloem',
#   'protophloem',
#   'secondary phloem',
#   'sieve tube'},
#  {'formation of ligule primordium stage',
#   'formation of vascular leaflet primordia stage',
#   'vascular leaf expansion stage'},
#  {'antheridiophore',
#   'antheridium stalk',
#   'archegoniophore',
#   'archegonium stalk',
#   'funicle',
#   'petiole',
#   'petiolule',
#   'seta',
#   'stalk'},
#  {'sclerenchyma cell', 'sclerid cell'},
#  {'axil', 'bract axil', 'branch axil', 'leaf axil'},
#  {'abaxial petiole canal',
#   'adaxial petiole canal',
#   'archegonium neck canal',
#   'canal',
#   'hilum groove',
#   'petiole canal',
#   'resin canal'},
#  {'primary thickening meristem', 'shoot lateral meristem'},
#  {'bract stomatal complex',
#   'carpel stomatal complex',
#   'petal stomatal complex',
#   'phyllome stomatal complex',
#   'sepal stomatal complex',
#   'stamen stomatal complex',
#   'stomatal complex',
#   'tepal stomatal complex'},
#  {'chloronema meristematic apical cell',
#   'embryo apical cell',
#   'gametophore axis meristematic apical cell',
#   'gametophore meristematic apical cell',
#   'gametophyte meristematic apical cell',
#   'leaf meristematic apical cell',
#   'meristematic apical cell',
#   'non-vascular leaf meristematic apical cell',
#   'protonema meristematic apical cell',
#   'rhizoid meristematic apical cell',
#   'root meristematic apical cell',
#   'seta meristematic apical cell',
#   'shoot axis meristematic apical cell',
#   'shoot meristematic apical cell',
#   'sporophyte meristematic apical cell',
#   'thallus meristematic apical cell',
#   'vascular leaf meristematic apical cell',
#   'vascular shoot axis meristematic apical cell'},
#  {'anther primordium',
#   'basal root primordium',
#   'bract primordium',
#   'carpel primordium',
#   'cotyledon primordium',
#   'floral organ primordium',
#   'flower bract primordium',
#   'gynoecium primordium',
#   'leaflet primordium',
#   'lodicule primordium',
#   'ovule primordium',
#   'petal primordium',
#   'phyllome primordium',
#   'primordium',
#   'root primordium',
#   'sepal primordium',
#   'shoot-borne root primordium',
#   'stamen primordium',
#   'vascular leaf primordium',
#   'vascular leaf primordium abaxial side',
#   'vascular leaf primordium adaxial side'},
#  {'archegonium initial cell',
#   'columella root cap initial cell',
#   'cortex-endodermis initial cell',
#   'epidermal rhizoid initial cell',
#   'initial cell',
#   'lateral root cap epidermal initial cell',
#   'non-vascular leaf initial cell',
#   'plant epidermal initial cell',
#   'protonema side branch initial cell',
#   'protonema sub-apical initial cell',
#   'protonemal side branch rhizoid initial cell',
#   'root initial cell',
#   'stomatal initial cell'},
#  {'B formation of primary parietal and sporogenous cells stage',
#   'D locules established stage',
#   'G anther dehiscence stage',
#   'H anther senescence stage',
#   'androecium development stage',
#   'anther development stage',
#   'calyx development stage',
#   'collective phyllome structure development stage',
#   'corolla development stage',
#   'fully expanded petal stage',
#   'fully expanded sepal stage',
#   'petal primordium visible stage',
#   'sepal differentiation and expansion stage',
#   'sepals enclosing flower bud stage',
#   'sepals enclosing meristem stage',
#   'stamen primordium visible stage'},
#  {'embryo endodermis',
#   'endodermis',
#   'hypocotyl endodermis',
#   'leaf endodermis',
#   'root endodermis',
#   'shoot axis endodermis'},
#  {'leaf apex', 'leaf apex tendril'},
#  {'branch apex',
#   'plumule',
#   'reproductive shoot apex',
#   'shoot axis apex',
#   'vegetative shoot apex'},
#  {'bract trichome',
#   'carpel trichome',
#   'leaf abaxial trichome',
#   'leaf adaxial trichome',
#   'leaf trichome',
#   'petal trichome',
#   'phyllome trichome',
#   'sepal trichome',
#   'stamen trichome',
#   'tepal trichome'},
#  {'branch node',
#   'cotyledonary node',
#   'inflorescence axis node',
#   'scutellar node',
#   'shoot axis node',
#   'stem node'},
#  {'bud scale leaf', 'scale leaf'},
#  {'leaf prickle', 'prickle', 'root prickle', 'shoot axis prickle'},
#  {'lateral root',
#   'lateral root spine',
#   'non-pericyclic lateral root',
#   'pericyclic lateral root',
#   'pneumatophore'},
#  {'cambial initial cell', 'phloem mother cell', 'ray initial cell'},
#  {'fiber tracheid',
#   'gelatinous fiber cell',
#   'libriform fiber cell',
#   'phloem fiber cell',
#   'plant fiber cell',
#   'septate fiber cell',
#   'septate fiber tracheid',
#   'septate libriform fiber cell',
#   'septate phloem fiber cell',
#   'xylem fiber cell'},
#  {'IE.00 inflorescence tip just visible above flag leaf sheath stage',
#   'IE.02 1/2 of inflorescence emerged from flag leaf sheath stage',
#   'IE.04 inflorescence fully emerged from flag leaf sheath stage',
#   'inflorescence emergence stage'},
#  {'1 root primordium formation stage',
#   '2 root meristem formation stage',
#   '3 establishment of tissue systems stage',
#   '4 root elongation stage',
#   '5 root hair formation stage',
#   'coleorhiza emergence stage',
#   'lateral root primordium formation stage',
#   'primary root primordium formation stage',
#   'radicle emergence stage',
#   'root cap formation stage',
#   'root cortex differentiation stage',
#   'root development stage',
#   'root vascular cylinder differentiation stage'},
#  {'branch procambium',
#   'leaf procambium',
#   'procambium',
#   'root procambium',
#   'shoot axis procambium',
#   'shoot procambium',
#   'stem procambium'},
#  {'megasporangium', 'nucellus'},
#  {'inner integument epidermis',
#   'integument epidermis',
#   'outer integument epidermis'},
#  {'aerial tuber axillary shoot',
#   'subterranean tuber axillary shoot',
#   'tuber axillary shoot'},
#  {'crown root emergence stage', 'root emergence stage'},
#  {'ground meristem',
#   'root system ground meristem',
#   'shoot system ground meristem'},
#  {'basal root', 'shoot-borne internode root'},
#  {'upper glume',
#   'upper glume of ear spikelet',
#   'upper glume of pedicellate spikelet of ear',
#   'upper glume of pedicellate spikelet of tassel',
#   'upper glume of sessile spikelet of ear',
#   'upper glume of sessile spikelet of tassel',
#   'upper glume of tassel spikelet'},
#  {'vascular leaf anlagen formation stage',
#   'vascular leaf initiation stage',
#   'vascular leaf primordium formation stage',
#   'vascular leaf primordium polarity determination stage'},
#  {'anther locule',
#   'fruit locule',
#   'locule',
#   'plant ovary locule',
#   'sporangium locule'},
#  {'lateral root primordium',
#   'non-pericyclic lateral root primordium',
#   'pericyclic lateral root primordium'},
#  {'primary phloem sieve tube element',
#   'secondary phloem sieve tube element',
#   'sieve tube element'},
#  {'flower development stage',
#   'flower meristem transition stage',
#   'flowering stage',
#   'reproductive shoot system development stage'},
#  {'articulated laticifer cell', 'laticifer cell'},
#  {'degenerate megaspore',
#   'functional megaspore',
#   'megaspore',
#   'microspore',
#   'plant spore'},
#  {'fruit pedicel', 'infructescence fruit pedicel'},
#  {'embryo shoot apical meristem', 'vegetative shoot apical meristem'},
#  {'aerial tuber storage parenchyma',
#   'endosperm parenchyma',
#   'seed storage parenchyma',
#   'storage parenchyma',
#   'subterranean tuber storage parenchyma',
#   'tuber storage parenchyma'},
#  {'embryo root', 'radicle', 'seedling radicle', 'seminal root'},
#  {'branch', 'branch tendril', 'gametophore branch', 'stolon'},
#  {'leaf abaxial stomatal complex',
#   'leaf adaxial stomatal complex',
#   'leaf stomatal complex',
#   'petiole stomatal complex'},
#  {'leaf rachis', 'leaf rachis tendril'},
#  {'gametophyte dormant stage', 'plant spore dormant stage'},
#  {'microsporophyll', 'stamen', 'staminode'},
#  {'lateral leaf vein', 'secondary leaf vein'},
#  {'BO.00 booting begins stage',
#   'BO.02 mid boot stage',
#   'BO.03 late boot stage',
#   'BO.04 flag leaf sheath opening stage',
#   'booting stage'},
#  {'embryo hypocotyl-root junction',
#   'hypocotyl-root junction',
#   'seedling hypocotyl-root junction'},
#  {'glandular trichome', 'lupulin gland'},
#  {'crown root',
#   'prop root',
#   'shoot-borne nodal root',
#   'shoot-borne root',
#   'shoot-borne root spine'},
#  {'endodermal passage cell', 'exodermal passage cell', 'passage cell'},
#  {'generative cell', 'spermatogenous cell'},
#  {'axillary bud meristem',
#   'shoot axis tuber axillary bud meristem',
#   'subterranean tuber axillary bud meristem'},
#  {'inflorescence development stage', 'inflorescence initiation stage'},
#  {'plant cuticle', 'plant cuticle ridge'},
#  {'carpel primordium visible stage',
#   'closure of carpel(s) stage',
#   'gynoecium development stage',
#   'gynoecium differentiation and expansion stage',
#   'ovule development stage',
#   'ovule primordium visible stage',
#   'stigma cell differentiation stage'},
#  {'intercalary meristem',
#   'leaf intercalary meristem',
#   'stem intercalary meristem'},
#  {'integument initiation stage', 'ovule differentiation and expansion stage'},
#  {'ear peduncle', 'peduncle'},
#  {'collective leaf structure', 'rosette'},
#  {'anther wall endothecium', 'microsporangium endothecium'}]

# %%
# Load a text file in Python
final_content = []
with open("PO/test/po_test_types.txt", "r", encoding="utf-8") as f:
    contents = f.readlines()
    for content in contents:
        final_content.append(content.strip('\n'))


print(contents[:500])  # Print first 500 characters
# Out:
# ['leaf lamina tooth\n', 'parenchyma cell\n', 'vascular leaf initiation stage\n', 'embryo hypocotyl\n', 'basal endosperm transfer layer\n', 'phloem\n', 'phyllome abaxial meristem\n', 'root cap\n', 'socket cell\n', 'root apical meristem\n', 'anthela inflorescence\n', 'axillary hair basal cell\n', 'thorn\n', 'xylem vessel\n', 'seminal root\n', 'root lateral meristem\n', 'microsporophyll\n', 'papilla cell\n', 'megasporangium endothecium\n', 'modified aleurone\n', 'plant axis differentiation zone\n', 'anther theca\n', 'stem base\n', 'tassel spikelet pair meristem\n', 'rhizoid meristematic apical cell\n', 'monarch protoxylem\n', 'endodermis\n', 'sporangium\n', 'portion of vascular tissue\n', 'intermediary companion cell\n', 'axillary inflorescence bud\n', 'root emergence stage\n', 'leaf substomatal cavity\n', 'plant ovule micropyle\n', 'xylem\n', 'scale leaf margin\n', 'seed chalaza\n', 'phyllome development stage\n', 'persistent sepal\n', 'plant structure\n', 'gynoecium ridge\n', 'apical meristem\n', 'embryo apical cell\n', 'leaf vascular system\n', 'intercalary meristem\n', 'leaf adaxial epidermis\n', 'shoot-borne root\n', 'flower pedicel abscission zone\n', 'adaxial nucellar projection\n', 'LP.04 four leaves visible stage\n', 'LP.06 six leaves visible stage\n', 'crown root primordium formation stage\n', 'leaf trichome development stage\n', 'hypocotyl epidermis\n', 'locule\n', 'ear spikelet pair meristem\n', 'root cap of primary root\n', 'megasporangium\n', 'palisade mesophyll intercellular space\n', 'leaf lamina adaxial epidermis\n', 'integument epidermis\n', 'leaf abaxial trichome\n', 'tuberous root tuber\n', 'sieve element\n', 'cambial zone\n', 'drepanium inflorescence\n', 'shoot axis pith\n', '1 root primordium formation stage\n', 'plant ovary wall\n', 'secondary phloem\n', 'seed coat epidermis\n', 'root differentiation zone\n', 'stigma vascular system\n', 'phyllome founder cell\n', 'petiole cortex\n', 'axillary shoot system\n', 'gametophyte reproductive stage\n', 'fused calyx\n', 'ventral canal cell\n', 'vegetative bud\n', 'SE.16 sixteen or more nodes or internodes visible stage\n', 'cotyledon emergence stage\n', 'plant organ margin\n', 'vascular leaf adaxial meristem\n', 'phelloderm\n', 'fruit storage parenchyma\n', 'ear inflorescence axillary meristem\n', 'hypocotyl-root junction\n', 'trichome tip\n', 'lower glume of tassel spikelet\n', 'upper glume\n', 'seedling development stage\n', 'phyllome margin\n', 'root cortex\n', 'plant embryo coleoptile\n', 'stem hypodermis\n', 'sepal parenchyma\n', 'cambial initial cell\n', 'chlorenchyma\n', 'inflorescence axis\n', 'ceonosorus\n', 'peristome tooth\n', 'ear spikelet meristem\n', 'fruit replum\n', 'spikelet pair meristem\n', 'LP.09 nine leaves visible stage\n', 'exotegmen\n', 'seta\n', 'IL.03 full inflorescence length reached stage\n', 'articulated laticifer cell\n', 'septate phloem fiber cell\n', 'basal axillary shoot system\n', 'plant anatomical space\n', 'eighth order infructescence axis\n', 'phyllome primordium\n', 'tuber pith\n', 'fascicular cambium\n', 'callus parenchyma cell\n', 'cotyledonary node rhizoid\n', 'phyllome guard cell\n', 'root initial cell\n', 'developing seed stage\n', 'aerial tuber storage parenchyma\n', 'parenchyma\n', 'unicellular trichome\n', 'sporophyte foot\n', 'tepal margin\n', 'whole plant fruit formation stage\n', 'subterranean tuber pith\n', 'ear meristem\n', 'fiber tracheid\n', 'plant zygote\n', 'peduncle trichome\n', 'phyllome lamina\n', 'BFO_0000040\n', 'mature plant embryo stage\n', 'cardinal organ part\n', 'pericycle cell\n', 'septum\n', 'IL.00 inflorescence just visible stage\n', 'leaf mesophyll intercellular space\n', 'plant organ\n', 'sheath cell\n', 'bud burst stage\n', 'leaf stomatal pore\n', 'tassel inflorescence branch\n', 'spermatogenous cell\n', 'bract\n', 'inflorescence axis internode\n', 'tassel floret\n', 'septate fiber tracheid\n', 'peristome\n', 'fusiform initial cell\n', 'bract base\n', 'plant embryo true leaf formation stage\n', ' ...

# %%
len(contents), contents[0]
# Out:
# (916, 'leaf lamina tooth\n')

# %%
len(final_content), final_content[0]
# Out:
# (916, 'leaf lamina tooth')

# %%
# Step 3: Assign function
from collections import Counter
from tqdm.notebook import tqdm
def assign_term_to_cluster(new_term, clusters):
    new_words = new_term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for term in cluster:
            for word in term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)
    
    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]
    
    if max_score == 0:
        return None  # No match
    return best_cluster_index

# Step 4: Assign all new terms
final_clusters = [set(cluster) for cluster in clusters]  # copy original clusters

for term in tqdm(final_content):
    assigned_idx = assign_term_to_cluster(term, final_clusters)
    if assigned_idx is not None:
        final_clusters[assigned_idx].add(term)
    else:
        # Create new cluster if no match found
        final_clusters.append(set([term]))

# Step 5: Convert to list of lists and return
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

# Display final clusters
for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")
# Out:
#   0%|          | 0/916 [00:00<?, ?it/s]
# Cluster 1: ['PO_0000055', 'aerial tuber axillary vegetative bud', 'anthela inflorescence', 'areole bud', 'axillary bud', 'axillary flower bud', 'axillary inflorescence bud', 'axillary reproductive bud', 'axillary shoot system', 'axillary strobilus bud', 'axillary vegetative bud', 'bostryx inflorescence', 'bulb', 'capitulum inflorescence', 'catkin inflorescence', 'cincinnus inflorescence', 'compound capitulum inflorescence', 'compound cincinnus inflorescence', 'compound drepanium inflorescence', 'compound raceme inflorescence', 'compound spike inflorescence', 'compound umbel inflorescence', 'corm', 'corymb inflorescence', 'cyme inflorescence', 'determinate thyrse inflorescence', 'disk flower', 'drepanium inflorescence', 'ear floret', 'ear inflorescence', 'ear infructescence', 'ear sessile spikelet', 'ear spikelet', 'flower', 'flower bud', 'flower fascicle', 'gametophore', 'gametophore bud', 'indeterminate thyrse inflorescence', 'inflorescence', 'inflorescence bract', 'inflorescence bract primordium', 'inflorescence branch crown', 'inflorescence bud', 'infructescence', 'long shoot', 'lower floret of pedicellate spikelet of ear', 'lower floret of pedicellate spikelet of tassel', 'lower floret of sessile spikelet of ear', 'lower floret of sessile spikelet of tassel', 'megasporangiate strobilus', 'microsporangiate strobilus', 'panicle inflorescence', 'pistillate flower', 'pistillate inflorescence', 'primary shoot system', 'raceme inflorescence', 'ray flower', 'reproductive bud', 'reproductive shoot system', 'rhipidium inflorescence', 'second order inflorescence', 'second order infructescence', 'shoot axis tuber axillary vegetative bud', 'shoot system', 'shoot-borne shoot system', 'spadix inflorescence', 'spike inflorescence', 'spikelet', 'spikelet floret', 'staminate flower', 'staminate inflorescence', 'strobilus', 'strobilus bud', 'subterranean tuber axillary vegetative bud', 'tassel floret', 'tassel inflorescence', 'tassel inflorescence branch', 'tassel pedicellate spikelet', 'tassel spikelet', 'terminal bud', 'terminal flower bud', 'terminal inflorescence bud', 'terminal reproductive bud', 'terminal strobilus bud', 'terminal vegetative bud', 'umbel inflorescence', 'upper floret of pedicellate spikelet of ear', 'upper floret of pedicellate spikelet of tassel', 'upper floret of sessile spikelet of ear', 'upper floret of sessile spikelet of tassel', 'vegetative bud', 'vegetative shoot system']
# Cluster 2: ['1 main shoot growth stage', '1 pattern formation stage', '1 root primordium formation stage', '2 endoreduplication stage', '2 formation of axillary shoot stage', '2.01 main shoot and axillary shoots visible at one node stage', '2.02 main shoot and axillary shoots visible at two nodes stage', '2.03 main shoot and axillary shoots visible at three nodes stage', '2.04 main shoot and axillary shoots visible at four nodes stage', '2.05 main shoot and axillary shoots visible at five nodes stage', '2.06 main shoot and axillary shoots visible at six nodes stage', '2.07 main shoot and axillary shoots visible at seven nodes stage', '2.08 main shoot and axillary shoots visible at eight nodes stage', '2.09 main shoot and axillary shoots visible at nine or more nodes stage', '3 branch formation stage', '3 establishment of tissue systems stage', '4 growth directionality stage', '4 root elongation stage', 'A archesporial cells visible stage', 'A megaspore mother cell enlarges stage', 'A microsporogenous mass stage', 'B enlarged microsporocyte stage', 'B meiosis of megaspore mother cell stage', 'BFO_0000015', 'BO.01 early boot stage', 'BO.05 flag leaf sheath opened stage', 'C callose wall formation in pollen mother cells stage', 'C four anther lobes formed stage', 'C tetrad of megaspores stage', 'D megaspore degeneration stage', 'D pollen mother cell meiosis stage', 'E anther wall tapetum degeneration initiated stage', 'E tetrad stage', 'E two nucleate megagametophyte stage', 'F bilocular anther stage', 'F four nucleate megagametophyte stage', 'F microspore release stage', 'FL.00 first flower(s) open stage', 'FL.01 1/4 of flowers open stage', 'FL.02 1/2 of flowers open stage', 'FL.03 3/4 of flowers open stage', 'FL.04 end of flowering stage', 'G early unicellular microspore stage', 'G eight nucleate megagametophyte stage', 'H late unicellular microspore stage', 'I first mitotic division stage', 'IE.01 1/4 of inflorescence emerged from flag leaf sheath stage', 'IE.03 3/4 of inflorescence emerged from flag leaf sheath stage', 'IL.00 inflorescence just visible stage', 'IL.01 1/4 inflorescence length reached stage', 'IL.02 1/2 inflorescence length reached stage', 'IL.03 full inflorescence length reached stage', 'J bicellular pollen stage', 'K second mitotic division stage', 'L mature pollen stage', 'LP.01 one leaf visible stage', 'LP.02 two leaves visible stage', 'LP.03 three leaves visible stage', 'LP.04 four leaves visible stage', 'LP.05 five leaves visible stage', 'LP.06 six leaves visible stage', 'LP.07 seven leaves visible stage', 'LP.08 eight leaves visible stage', 'LP.09 nine leaves visible stage', 'LP.10 ten leaves visible stage', 'LP.11 eleven leaves visible stage', 'LP.12 twelve leaves visible stage', 'LP.13 thirteen leaves visible stage', 'LP.14 fourteen leaves visible stage', 'LP.15 fifteen leaves visible stage', 'LP.16 sixteen leaves visible stage', 'LP.17 seventeen leaves visible stage', 'LP.18 eighteen leaves visible stage', 'LP.19 nineteen leaves visible stage', 'LP.20 twenty or more leaves whorls visible stage', 'M germinated pollen stage', 'SE.00 stem elongation begins stage', 'SE.08 eight nodes or internodes visible stage', 'SE.13 thirteen nodes or internodes visible stage', 'SE.16 sixteen or more nodes or internodes visible stage', 'SE.99 maximum stem length reached stage', 'androecium development stage', 'anther development stage', 'beginning of whole plant fruit ripening stage', 'booting stage', 'bud burst stage', 'bud development stage', 'bud dormancy stage', 'bud swell stage', 'calyx development stage', 'cell death stage of secondary xylem', 'cell differentiation stage of secondary xylem', 'cell division stage of secondary xylem', 'cell expansion stage of secondary xylem', 'chalazal and micropylar domain establishment stage', 'coleoptile emergence stage', 'collective phyllome structure development stage', 'collective plant organ structure development stage', 'corolla development stage', 'cotyledon emergence sta ...
# Cluster 3: ['PO_0025349', 'abaxial nucellar projection', 'abaxial protoderm', 'abscission zone', 'achene fruit', 'adaxial nucellar projection', 'adaxial protoderm', 'adult vascular leaf', 'adventitious root nodule', 'aerenchyma', 'aerial tuber', 'aerial tuber axillary bud meristem', 'aerial tuber axillary shoot', 'aerial tuber cortex', 'aerial tuber epidermis', 'aerial tuber interfascicular region', 'aerial tuber periderm', 'aerial tuber perimedullary zone', 'aerial tuber pith', 'aerial tuber storage parenchyma', 'alar cell', 'albuminous cell', 'aleurone layer', 'androecium', 'anther', 'anther dehiscence zone', 'anther locule', 'anther septum', 'anther theca', 'anther wall', 'anther wall exothecium', 'anther wall inner secondary parietal cell layer', 'anther wall middle layer', 'anther wall outer secondary parietal cell layer', 'anther wall primary parietal cell layer', 'anther wall secondary parietal cell layer', 'anther wall tapetum', 'anther wall tapetum cell', 'antheridium', 'antheridium head', 'antheridium jacket layer', 'antheridium jacket layer cell', 'antheridium microgametophyte', 'antheridium sperm cell', 'antheridium stalk', 'antiraphe', 'apical hook', 'apical meristem', 'archegonium', 'archegonium central cell', 'archegonium egg cell', 'archegonium head', 'archegonium megagametophyte', 'archegonium neck', 'archegonium neck canal cell', 'archesporial cell', 'archesporium', 'aril', 'arillode', 'arilloid', 'articulated laticifer', 'articulated laticifer cell', 'axial secondary xylem parenchyma', 'axial secondary xylem parenchyma cell', 'axillary bud meristem', 'axillary hair', 'axillary hair basal cell', 'axillary hair base', 'axillary hair terminal cell', 'axillary shoot system', 'banner petal', 'bark', 'basal axillary shoot system', 'basal endosperm transfer cell', 'basal endosperm transfer layer', 'berry fruit', 'body cell', 'brachycyte', 'bract', 'bract abaxial epidermis', 'bract adaxial epidermis', 'bract anlagen', 'bract apex', 'bract base', 'bract epidermis', 'bract margin', 'bract tip', 'bract trichome', 'bracteole', 'branch', 'branch epidermis', 'branch internode', 'branch internode differentiation zone', 'branch internode elongation zone', 'branch node', 'branch stele', 'branch trichome', 'bulliform cell', 'bundle sheath', 'bundle sheath cell', 'bundle sheath chlorenchyma cell', 'bundle sheath extension', 'callus parenchyma cell', 'calyptra calyx', 'calyptra corolla', 'calyx', 'cambial initial cell', 'cambial zone', 'cambium', 'capsule fruit', 'cardinal organ part', 'cardinal part of multi-tissue plant structure', 'carpel', 'carpel abaxial epidermis', 'carpel adaxial epidermis', 'carpel anlagen', 'carpel epidermis', 'carpel margin', 'caruncle', 'caryopsis fruit', 'caryopsis hull', 'cauline axillary shoot', 'cauline leaf', 'caulonema', 'caulonema cell', 'caulonema meristematic apical cell', 'cellular endosperm', 'central endosperm', 'central root cap', 'central root cap of lateral root', 'central root cap of primary root', 'central strand', 'central zone', 'central zone of the leaf lamina', 'central zone of the petiole', 'ceonosorus', 'chalaza', 'chalazal cyst', 'chlorenchyma', 'chlorenchyma cell', 'chloronema', 'chloronema cell', 'cigar leaf', 'cigar leaf lamina abaxial epidermis', 'circumscissile capsule fruit', 'coccarium capsule fruit', 'coleoptile', 'coleorhiza', 'collective leaf structure', 'collective organ part structure', 'collective phyllome structure', 'collective plant organ structure', 'collective plant structure', 'collective tepal structure', 'collenchyma', 'collenchyma cell', 'columella', 'columella root cap cell', 'coma', 'companion cell', 'compound leaf', 'connective', 'cork cambium', 'corolla', 'corolla spur', 'cortex', 'cotyledon', 'cotyledon abaxial epidermis', 'cotyledon adaxial epidermis', 'cotyledon anlagen', 'cotyledon epidermis', 'cotyledon margin', 'cultured plant callus', 'cultured plant cell', 'cultured plant embryo', 'cultured somatic plant embryo', 'cultured zygote-derived plant ...
# Cluster 4: ['leaf lamina intramarginal vein', 'leaf lamina vein', 'leaf midvein', 'pericarp vascular bundle', 'petiole vascular bundle', 'phyllome lamina vein', 'primary leaf vein', 'quaternary leaf vein', 'vascular bundle']
# Cluster 5: ['accessory paraclade', 'adventitious shoot axis', 'cauline paraclade', 'cladode', 'ear infructescence axis', 'ear spikelet rachilla', 'eighth order inflorescence axis', 'eighth order infructescence axis', 'fifth order inflorescence axis', 'first order ear inflorescence axis', 'first order inflorescence axis', 'first order infructescence axis', 'first order tassel inflorescence axis', 'flower pedicel', 'fourth order inflorescence axis', 'gametophore axis', 'gametophore stem', 'gynophore', 'higher order inflorescence axis', 'higher order infructescence axis', 'inflorescence axis', 'inflorescence axis node', 'inflorescence flower pedicel', 'infructescence axis', 'ninth order inflorescence axis', 'pedicel', 'pedicel of ear spikelet', 'pedicel of tassel spikelet', 'plant axis', 'plant embryo axis', 'pseudopodium', 'rachilla of pedicellate spikelet of ear', 'rachilla of pedicellate spikelet of tassel', 'rachilla of sessile spikelet of tassel', 'rosette paraclade', 'second order inflorescence axis', 'second order infructescence', 'seventh order inflorescence axis', 'seventh order infructescence axis', 'shoot axis', 'shoot axis tuber', 'sixth order inflorescence axis', 'spikelet pedicel', 'spikelet rachilla', 'stem', 'stem apex tendril', 'subterranean shoot axis tuber', 'tassel inflorescence branch', 'tassel spikelet rachilla', 'tenth order inflorescence axis', 'tenth order infructescence axis', 'third order inflorescence axis', 'tuber', 'tuberous root tuber']
# Cluster 6: ['anther pore', 'hydathode', 'hydathode pore', 'intercellular space', 'leaf mesophyll intercellular space', 'leaf sinus', 'leaf stomatal pore', 'leaf substomatal cavity', 'palisade mesophyll intercellular space', 'phyllome sinus', 'phyllome stomatal pore', 'phyllome substomatal cavity', 'plant anatomical space', 'plant ovule micropyle', 'seed micropyle', 'spongy mesophyll intercellular space', 'spore capsule mouth', 'stomatal pore', 'stomium', 'substomatal cavity']
# Cluster 7: ['pericycle cell', 'phloem pole pericycle cell', 'xylem pole pericycle cell']
# Cluster 8: ['SE.01 one node or internode visible stage', 'SE.02 two nodes or internodes visible stage', 'SE.03 three nodes or internodes visible stage', 'SE.04 four nodes or internodes visible stage', 'SE.05 five nodes or internodes visible stage', 'SE.06 six nodes or internodes visible stage', 'SE.07 seven nodes or internodes visible stage', 'SE.09 nine nodes or internodes visible stage', 'SE.10 ten nodes or internodes visible stage', 'SE.11 eleven nodes or internodes visible stage', 'SE.12 twelve nodes or internodes visible stage', 'SE.14 fourteen nodes or internodes visible stage', 'SE.15 fifteen nodes or internodes visible stage', 'SE.97 flag leaf visible stage', 'stem elongation stage']
# Cluster 9: ['antipodal cell', 'embryo sac cell', 'embryo sac central cell', 'primary endosperm cell', 'synergid']
# Cluster 10: ['fifth order infructescence axis', 'fourth order infructescence axis', 'higher order infructescence axis', 'ninth order infructescence axis', 'second order infructescence axis', 'sixth order infructescence axis', 'third order infructescence axis']
# Cluster 11: ['anther vascular system', 'axial system', 'carpel vascular system', 'centarch protoxylem', 'compression wood', 'cotyledon vascular system', 'diarch protoxylem', 'early wood', 'endarch protoxylem', 'exarch protoxylem', 'filament vascular system', 'flower vascular system', 'fruit vascular system', 'growth ring', 'growth ring boundary', 'heartwood', 'hypocotyl vascular system', 'included vascular cambium', 'inflorescence vascular system', 'late wood', 'leaf lamina vascular system', 'mesarch protoxylem', 'metaxylem', 'monarch protoxylem', 'pedicel vascular system', 'pentarch protoxylem', 'petal vascular system', 'petiole vascular system', 'phyllome vascular system', 'plant embryo vascular system', 'polyarch protoxylem', 'portion of vascular tissue', 'primary vascular tissue', 'primary xylem', 'primary xylem vessel', 'protoxylem', 'ray system', 'reaction wood', 'root system exarch protoxylem', 'root vascular system', 'sapwood', 'scutellum vascular system', 'secondary vascular tissue', 'secondary xylem', 'secondary xylem vessel', 'sepal vascular system', 'shoot axis vascular system', 'shoot system exarch protoxylem', 'shoot system vascular system', 'stamen vascular system', 'stigma vascular system', 'tension wood', 'tepal vascular system', 'tetrarch protoxylem', 'triarch protoxylem', 'vascular bundle', 'vascular cambium', 'vascular system', 'xylem', 'xylem vessel']
# Cluster 12: ['internal phloem', 'metaphloem', 'phloem', 'primary phloem', 'protophloem', 'secondary phloem', 'sieve tube']
# Cluster 13: ['formation of ligule primordium stage', 'formation of vascular leaflet primordia stage', 'vascular leaf expansion stage']
# Cluster 14: ['antheridiophore', 'antheridium stalk', 'archegoniophore', 'archegonium stalk', 'funicle', 'petiole', 'petiolule', 'seta', 'stalk']
# Cluster 15: ['sclerenchyma cell', 'sclerid cell']
# Cluster 16: ['axil', 'bract axil', 'branch axil', 'leaf axil']
# Cluster 17: ['abaxial petiole canal', 'adaxial petiole canal', 'archegonium neck canal', 'canal', 'hilum groove', 'petiole canal', 'resin canal']
# Cluster 18: ['primary thickening meristem', 'shoot lateral meristem']
# Cluster 19: ['bract stomatal complex', 'carpel stomatal complex', 'petal stomatal complex', 'phyllome stomatal complex', 'sepal stomatal complex', 'stamen stomatal complex', 'stomatal complex', 'tepal stomatal complex']
# Cluster 20: ['chloronema meristematic apical cell', 'embryo apical cell', 'gametophore axis meristematic apical cell', 'gametophore meristematic apical cell', 'gametophyte meristematic apical cell', 'leaf meristematic apical cell', 'meristematic apical cell', 'non-vascular leaf meristematic apical cell', 'protonema meristematic apical cell', 'rhizoid meristematic apical cell', 'root meristematic apical cell', 'seta meristematic apical cell', 'shoot axis meristematic apical cell', 'shoot meristematic apical cell', 'sporophyte meristematic apical cell', 'thallus meristematic apical cell', 'vascular leaf meristematic apical cell', 'vascular shoot axis meristematic apical cell']
# Cluster 21: ['androecium primordium', 'anther primordium', 'basal root primordium', 'bract primordium', 'carpel primordium', 'cotyledon primordium', 'floral organ primordium', 'flower bract primordium', 'gynoecium primordium', 'leaflet primordium', 'lodicule primordium', 'ovule primordium', 'petal primordium', 'phyllome primordium', 'primordium', 'root primordium', 'sepal primordium', 'shoot-borne root primordium', 'stamen primordium', 'vascular leaf primordium', 'vascular leaf primordium abaxial side', 'vascular leaf primordium adaxial side']
# Cluster 22: ['archegonium initial cell', 'columella root cap initial cell', 'cortex-endodermis initial cell', 'epidermal rhizoid initial cell', 'initial cell', 'lateral root cap epidermal initial cell', 'non-vascular leaf initial cell', 'plant epidermal initial cell', 'protonema side branch initial cell', 'protonema sub-apical initial cell', 'protonemal side branch rhizoid initial cell', 'root initial cell', 'stomatal initial cell']
# Cluster 23: ['B formation of primary parietal and sporogenous cells stage', 'D locules established stage', 'G anther dehiscence stage', 'H anther senescence stage', 'androecium development stage', 'anther development stage', 'calyx development stage', 'collective phyllome structure development stage', 'corolla development stage', 'fully expanded petal stage', 'fully expanded sepal stage', 'petal primordium visible stage', 'sepal differentiation and expansion stage', 'sepals enclosing flower bud stage', 'sepals enclosing meristem stage', 'stamen primordium visible stage']
# Cluster 24: ['embryo endodermis', 'endodermis', 'hypocotyl endodermis', 'leaf endodermis', 'root endodermis', 'shoot axis endodermis']
# Cluster 25: ['leaf apex', 'leaf apex tendril']
# Cluster 26: ['branch apex', 'plumule', 'reproductive shoot apex', 'shoot axis apex', 'vegetative shoot apex']
# Cluster 27: ['bract trichome', 'carpel trichome', 'leaf abaxial trichome', 'leaf adaxial trichome', 'leaf trichome', 'petal trichome', 'phyllome trichome', 'sepal trichome', 'stamen trichome', 'tepal trichome']
# Cluster 28: ['branch node', 'cotyledonary node', 'cotyledonary node rhizoid', 'inflorescence axis node', 'scutellar node', 'shoot axis node', 'stem node']
# Cluster 29: ['bud scale leaf', 'scale leaf']
# Cluster 30: ['leaf prickle', 'prickle', 'root prickle', 'shoot axis prickle']
# Cluster 31: ['lateral root', 'lateral root spine', 'non-pericyclic lateral root', 'pericyclic lateral root', 'pneumatophore']
# Cluster 32: ['cambial initial cell', 'phloem mother cell', 'ray initial cell']
# Cluster 33: ['fiber tracheid', 'gelatinous fiber cell', 'libriform fiber cell', 'phloem fiber cell', 'plant fiber cell', 'septate fiber cell', 'septate fiber tracheid', 'septate libriform fiber cell', 'septate phloem fiber cell', 'xylem fiber cell']
# Cluster 34: ['IE.00 inflorescence tip just visible above flag leaf sheath stage', 'IE.02 1/2 of inflorescence emerged from flag leaf sheath stage', 'IE.04 inflorescence fully emerged from flag leaf sheath stage', 'inflorescence emergence stage']
# Cluster 35: ['1 root primordium formation stage', '2 root meristem formation stage', '3 establishment of tissue systems stage', '4 root elongation stage', '5 root hair formation stage', 'coleorhiza emergence stage', 'lateral root primordium formation stage', 'primary root primordium formation stage', 'radicle emergence stage', 'root cap formation stage', 'root cortex differentiation stage', 'root development stage', 'root vascular cylinder differentiation stage']
# Cluster 36: ['branch procambium', 'leaf procambium', 'procambium', 'root procambium', 'shoot axis procambium', 'shoot procambium', 'stem procambium']
# Cluster 37: ['megasporangium', 'nucellus']
# Cluster 38: ['inner integument epidermis', 'integument epidermis', 'outer integument epidermis']
# Cluster 39: ['aerial tuber axillary shoot', 'subterranean tuber axillary shoot', 'tuber axillary shoot']
# Cluster 40: ['crown root emergence stage', 'root emergence stage']
# Cluster 41: ['ground meristem', 'root system ground meristem', 'shoot system ground meristem']
# Cluster 42: ['basal root', 'shoot-borne internode root']
# Cluster 43: ['upper glume', 'upper glume of ear spikelet', 'upper glume of pedicellate spikelet of ear', 'upper glume of pedicellate spikelet of tassel', 'upper glume of sessile spikelet of ear', 'upper glume of sessile spikelet of tassel', 'upper glume of tassel spikelet']
# Cluster 44: ['vascular leaf anlagen formation stage', 'vascular leaf initiation stage', 'vascular leaf primordium formation stage', 'vascular leaf primordium polarity determination stage']
# Cluster 45: ['anther locule', 'fruit locule', 'locule', 'plant ovary locule', 'sporangium locule']
# Cluster 46: ['lateral root primordium', 'non-pericyclic lateral root primordium', 'pericyclic lateral root primordium']
# Cluster 47: ['primary phloem sieve tube element', 'secondary phloem sieve tube element', 'sieve tube element']
# Cluster 48: ['flower development stage', 'flower meristem transition stage', 'flowering stage', 'reproductive shoot system development stage']
# Cluster 49: ['articulated laticifer cell', 'laticifer cell']
# Cluster 50: ['degenerate megaspore', 'functional megaspore', 'megaspore', 'microspore', 'plant spore']
# Cluster 51: ['fruit pedicel', 'infructescence fruit pedicel']
# Cluster 52: ['embryo shoot apical meristem', 'vegetative shoot apical meristem']
# Cluster 53: ['aerial tuber storage parenchyma', 'endosperm parenchyma', 'seed storage parenchyma', 'storage parenchyma', 'subterranean tuber storage parenchyma', 'tuber storage parenchyma']
# Cluster 54: ['embryo root', 'radicle', 'seedling radicle', 'seminal root']
# Cluster 55: ['branch', 'branch tendril', 'gametophore branch', 'stolon']
# Cluster 56: ['leaf abaxial stomatal complex', 'leaf adaxial stomatal complex', 'leaf stomatal complex', 'petiole stomatal complex']
# Cluster 57: ['leaf rachis', 'leaf rachis tendril']
# Cluster 58: ['gametophyte dormant stage', 'plant spore dormant stage']
# Cluster 59: ['microsporophyll', 'stamen', 'staminode']
# Cluster 60: ['lateral leaf vein', 'secondary leaf vein']
# Cluster 61: ['BO.00 booting begins stage', 'BO.02 mid boot stage', 'BO.03 late boot stage', 'BO.04 flag leaf sheath opening stage', 'booting stage']
# Cluster 62: ['embryo hypocotyl-root junction', 'hypocotyl-root junction', 'seedling hypocotyl-root junction']
# Cluster 63: ['glandular trichome', 'lupulin gland']
# Cluster 64: ['crown root', 'prop root', 'shoot-borne nodal root', 'shoot-borne root', 'shoot-borne root spine']
# Cluster 65: ['endodermal passage cell', 'exodermal passage cell', 'passage cell']
# Cluster 66: ['generative cell', 'spermatogenous cell']
# Cluster 67: ['axillary bud meristem', 'shoot axis tuber axillary bud meristem', 'subterranean tuber axillary bud meristem']
# Cluster 68: ['inflorescence development stage', 'inflorescence initiation stage']
# Cluster 69: ['plant cuticle', 'plant cuticle ridge']
# Cluster 70: ['carpel primordium visible stage', 'closure of carpel(s) stage', 'gynoecium', 'gynoecium development stage', 'gynoecium differentiation and expansion stage', 'gynoecium ridge', 'ovule development stage', 'ovule primordium visible stage', 'stigma cell differentiation stage']
# Cluster 71: ['intercalary meristem', 'leaf intercalary meristem', 'stem intercalary meristem']
# Cluster 72: ['integument initiation stage', 'ovule differentiation and expansion stage']
# Cluster 73: ['ear peduncle', 'peduncle']
# Cluster 74: ['collective leaf structure', 'rosette']
# Cluster 75: ['anther wall endothecium', 'microsporangium endothecium']
# Cluster 76: ['thorn']
# Cluster 77: ['BFO_0000040']
# Cluster 78: ['costa']
# Cluster 79: ['pneumatorhiza']
# Cluster 80: ['hypanthium']
# Cluster 81: ['exotesta']
# Cluster 82: ['periblem']
# Cluster 83: ['amphithecium']
# Cluster 84: ['gemma']
# Cluster 85: ['idioblast']
# Cluster 86: ['elaiosome']
# Cluster 87: ['tegmen']
# Cluster 88: ['perigynium']
# Cluster 89: ['hydrome']

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")

# %%
final_ans = []
for i, list_of_elements in tqdm(enumerate(final_clusters_list)):
    if len(list_of_elements)>1:
        prompt = f""""Analyze the following list of biological terms and identify all direct and indirect **parent-child relationships**.

        A **parent-child relationship** exists when one term (the parent) is a broader, more general category or a whole that conceptually encompasses or contains another term (the child). The child term is a more specific instance, a part, or a developmental stage of the parent term.

        **Guidelines for identifying relationships:**
        * **"Is-a" relationship:** e.g., "A 'leaf procambium' **is a** type of 'procambium'." (Parent: procambium, Child: leaf procambium)
        * **"Part-of" relationship:** e.g., "A 'petal' **is part of** a 'flower'." (Parent: flower, Child: petal)
        * **Developmental sequence:** e.g., "'Petal primordium visible stage' **is a stage in** 'petal development'." (Parent: petal development, Child: petal primordium visible stage)
        * **Anatomical hierarchy:** e.g., "'Root endodermis' **is part of** 'root' and **is a type of** 'endodermis'." (Parent: root and endodermis, Child: root endodermis)

        **List of Elements:**
        {list_of_elements}
        **Output Format:**
        Provide the output as a single JSON array. Each element in the array must be a JSON object with two keys: `"parent"` and `"child"`, whose values are the corresponding terms.

        **Example Output (Illustrative, showing the expected JSON structure):**
        {json.dumps({"Answer":[
        {
            "parent": "procambium",
            "child": "branch procambium"
        },
        {
            "parent": "procambium",
            "child": "leaf procambium"
        },
        {
            "parent": "shoot system",
            "child": "axillary shoot system"
        },
        {
            "parent": "flower",
            "child": "petal"
        },
        {
            "parent": "flower development",
            "child": "petal primordium visible stage"
        }
        ]})}
        """
        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%20==0:
            print(response.text)
# Out:
# 0it [00:00, ?it/s]
# [
#   {
#     "parent": "shoot system",
#     "child": "axillary shoot system"
#   },
#   {
#     "parent": "shoot system",
#     "child": "primary shoot system"
#   },
#   {
#     "parent": "shoot system",
#     "child": "reproductive shoot system"
#   },
#   {
#     "parent": "shoot system",
#     "child": "vegetative shoot system"
#   },
#   {
#     "parent": "shoot system",
#     "child": "shoot-borne shoot system"
#   },
#   {
#     "parent": "axillary bud",
#     "child": "axillary flower bud"
#   },
#   {
#     "parent": "flower bud",
#     "child": "axillary flower bud"
#   },
#   {
#     "parent": "axillary bud",
#     "child": "axillary inflorescence bud"
#   },
#   {
#     "parent": "inflorescence bud",
#     "child": "axillary inflorescence bud"
#   },
#   {
#     "parent": "axillary bud",
#     "child": "axillary reproductive bud"
#   },
#   {
#     "parent": "reproductive bud",
#     "child": "axillary reproductive bud"
#   },
#   {
#     "parent": "axillary bud",
#     "child": "axillary strobilus bud"
#   },
#   {
#     "parent": "strobilus bud",
#     "child": "axillary strobilus bud"
#   },
#   {
#     "parent": "axillary bud",
#     "child": "axillary vegetative bud"
#   },
#   {
#     "parent": "vegetative bud",
#     "child": "axillary vegetative bud"
#   },
#   {
#     "parent": "terminal bud",
#     "child": "terminal flower bud"
#   },
#   {
#     "parent": "flower bud",
#     "child": "terminal flower bud"
#   },
#   {
#     "parent": "terminal bud",
#     "child": "terminal inflorescence bud"
#   },
#   {
#     "parent": "inflorescence bud",
#     "child": "terminal inflorescence bud"
#   },
#   {
#     "parent": "terminal bud",
#     "child": "terminal reproductive bud"
#   },
#   {
#     "parent": "reproductive bud",
#     "child": "terminal reproductive bud"
#   },
#   {
#     "parent": "terminal bud",
#     "child": "terminal strobilus bud"
#   },
#   {
#     "parent": "strobilus bud",
#     "child": "terminal strobilus bud"
#   },
#   {
#     "parent": "terminal bud",
#     "child": "terminal vegetative bud"
#   },
#   {
#     "parent": "vegetative bud",
#     "child": "terminal vegetative bud"
#   },
#   {
#     "parent": "axillary vegetative bud",
#     "child": "aerial tuber axillary vegetative bud"
#   },
#   {
#     "parent": "axillary vegetative bud",
#     "child": "shoot axis tuber axillary vegetative bud"
#   },
#   {
#     "parent": "axillary vegetative bud",
#     "child": "subterranean tuber axillary vegetative bud"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "anthela inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "bostryx inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "capitulum inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "catkin inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "cincinnus inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "corymb inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "cyme inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "determinate thyrse inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "drepanium inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "ear inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "indeterminate thyrse inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "panicle inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "pistillate inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "raceme inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "rhipidium inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "spadix inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "spike inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "staminate inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "tassel inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "umbel inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "second order inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "flower fascicle"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "compound capitulum inflorescence"
#   },
#   {
#     "parent": "capitulum inflorescence",
#     "child": "compound capitulum inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "compound cincinnus inflorescence"
#   },
#   {
#     "parent": "cincinnus inflorescence",
#     "child": "compound cincinnus inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "compound drepanium inflorescence"
#   },
#   {
#     "parent": "drepanium inflorescence",
#     "child": "compound drepanium inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "compound raceme inflorescence"
#   },
#   {
#     "parent": "raceme inflorescence",
#     "child": "compound raceme inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "compound spike inflorescence"
#   },
#   {
#     "parent": "spike inflorescence",
#     "child": "compound spike inflorescence"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "compound umbel inflorescence"
#   },
#   {
#     "parent": "umbel inflorescence",
#     "child": "compound umbel inflorescence"
#   },
#   {
#     "parent": "flower",
#     "child": "disk flower"
#   },
#   {
#     "parent": "flower",
#     "child": "pistillate flower"
#   },
#   {
#     "parent": "flower",
#     "child": "ray flower"
#   },
#   {
#     "parent": "flower",
#     "child": "staminate flower"
#   },
#   {
#     "parent": "flower",
#     "child": "ear floret"
#   },
#   {
#     "parent": "ear inflorescence",
#     "child": "ear floret"
#   },
#   {
#     "parent": "flower",
#     "child": "spikelet floret"
#   },
#   {
#     "parent": "spikelet",
#     "child": "spikelet floret"
#   },
#   {
#     "parent": "flower",
#     "child": "tassel floret"
#   },
#   {
#     "parent": "tassel inflorescence",
#     "child": "tassel floret"
#   },
#   {
#     "parent": "spikelet",
#     "child": "ear sessile spikelet"
#   },
#   {
#     "parent": "ear spikelet",
#     "child": "ear sessile spikelet"
#   },
#   {
#     "parent": "spikelet",
#     "child": "ear spikelet"
#   },
#   {
#     "parent": "spikelet",
#     "child": "tassel pedicellate spikelet"
#   },
#   {
#     "parent": "spikelet",
#     "child": "tassel spikelet"
#   },
#   {
#     "parent": "strobilus",
#     "child": "megasporangiate strobilus"
#   },
#   {
#     "parent": "strobilus",
#     "child": "microsporangiate strobilus"
#   },
#   {
#     "parent": "infructescence",
#     "child": "ear infructescence"
#   },
#   {
#     "parent": "infructescence",
#     "child": "second order infructescence"
#   },
#   {
#     "parent": "gametophore",
#     "child": "gametophore bud"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "inflorescence bract"
#   },
#   {
#     "parent": "inflorescence bract",
#     "child": "inflorescence bract primordium"
#   },
#   {
#     "parent": "inflorescence",
#     "child": "inflorescence branch crown"
#   },
#   {
#     "parent": "flower fascicle",
#     "child": "flower"
#   },
#   {
#     "parent": "flower",
#     "child": "lower floret of pedicellate spikelet of ear"
#   },
#   {
#     "parent": "ear spikelet",
#     "child": "lower floret of pedicellate spikelet of ear"
#   },
#   {
#     "parent": "flower",
#     "child": "lower floret of pedicellate spikelet of tassel"
#   },
#   {
#     "parent": "tassel pedicellate spikelet",
#     "child": "lower floret of pedicellate spikelet of tassel"
#   },
#   {
#     "parent": "flower",
#     "child": "lower floret of sessile spikelet of ear"
#   },
#   {
#     "parent": "ear sessile spikelet",
#     "child": "lower floret of sessile spikelet of ear"
#   },
#   {
#     "parent": "flower",
#     "child": "lower floret of sessile spikelet of tassel"
#   },
#   {
#     "parent": "tassel spikelet",
#     "child": "lower floret of sessile spikelet of tassel"
#   },
#   {
#     "parent": "flower",
#     "child": "upper floret of pedicellate spikelet of ear"
#   },
#   {
#     "parent": "ear spikelet",
#     "child": "upper floret of pedicellate spikelet of ear"
#   },
#   {
#     "parent": "flower",
#     "child": "upper floret of pedicellate spikelet of tassel"
#   },
#   {
#     "parent": "tassel pedicellate spikelet",
#     "child": "upper floret of pedicellate spikelet of tassel"
#   },
#   {
#     "parent": "flower",
#     "child": "upper floret of sessile spikelet of ear"
#   },
#   {
#     "parent": "ear sessile spikelet",
#     "child": "upper floret of sessile spikelet of ear"
#   },
#   {
#     "parent": "flower",
#     "child": "upper floret of sessile spikelet of tassel"
#   },
#   {
#     "parent": "tassel spikelet",
#     "child": "upper floret of sessile spikelet of tassel"
#   },
#   {
#     "parent": "tassel inflorescence",
#     "child": "tassel inflorescence branch"
#   }
# ]
# [
#   {
#     "parent": "primordium",
#     "child": "phyllome primordium"
#   },
#   {
#     "parent": "primordium",
#     "child": "root primordium"
#   },
#   {
#     "parent": "phyllome primordium",
#     "child": "bract primordium"
#   },
#   {
#     "parent": "phyllome primordium",
#     "child": "cotyledon primordium"
#   },
#   {
#     "parent": "phyllome primordium",
#     "child": "floral organ primordium"
#   },
#   {
#     "parent": "phyllome primordium",
#     "child": "leaflet primordium"
#   },
#   {
#     "parent": "phyllome primordium",
#     "child": "vascular leaf primordium"
#   },
#   {
#     "parent": "root primordium",
#     "child": "basal root primordium"
#   },
#   {
#     "parent": "root primordium",
#     "child": "shoot-borne root primordium"
#   },
#   {
#     "parent": "bract primordium",
#     "child": "flower bract primordium"
#   },
#   {
#     "parent": "vascular leaf primordium",
#     "child": "vascular leaf primordium abaxial side"
#   },
#   {
#     "parent": "vascular leaf primordium",
#     "child": "vascular leaf primordium adaxial side"
#   },
#   {
#     "parent": "floral organ primordium",
#     "child": "androecium primordium"
#   },
#   {
#     "parent": "floral organ primordium",
#     "child": "gynoecium primordium"
#   },
#   {
#     "parent": "floral organ primordium",
#     "child": "lodicule primordium"
#   },
#   {
#     "parent": "floral organ primordium",
#     "child": "petal primordium"
#   },
#   {
#     "parent": "floral organ primordium",
#     "child": "sepal primordium"
#   },
#   {
#     "parent": "androecium primordium",
#     "child": "stamen primordium"
#   },
#   {
#     "parent": "stamen primordium",
#     "child": "anther primordium"
#   },
#   {
#     "parent": "gynoecium primordium",
#     "child": "carpel primordium"
#   },
#   {
#     "parent": "gynoecium primordium",
#     "child": "ovule primordium"
#   }
# ]
# [
#   {
#     "parent": "ground meristem",
#     "child": "root system ground meristem"
#   },
#   {
#     "parent": "ground meristem",
#     "child": "shoot system ground meristem"
#   }
# ]
# [
#   {
#     "parent": "booting stage",
#     "child": "BO.00 booting begins stage"
#   },
#   {
#     "parent": "booting stage",
#     "child": "BO.02 mid boot stage"
#   },
#   {
#     "parent": "booting stage",
#     "child": "BO.03 late boot stage"
#   },
#   {
#     "parent": "booting stage",
#     "child": "BO.04 flag leaf sheath opening stage"
#   }
# ]

# %%
final_ans
# Out:
# ['[\n  {\n    "parent": "shoot system",\n    "child": "axillary shoot system"\n  },\n  {\n    "parent": "shoot system",\n    "child": "primary shoot system"\n  },\n  {\n    "parent": "shoot system",\n    "child": "reproductive shoot system"\n  },\n  {\n    "parent": "shoot system",\n    "child": "vegetative shoot system"\n  },\n  {\n    "parent": "shoot system",\n    "child": "shoot-borne shoot system"\n  },\n  {\n    "parent": "axillary bud",\n    "child": "axillary flower bud"\n  },\n  {\n    "parent": "flower bud",\n    "child": "axillary flower bud"\n  },\n  {\n    "parent": "axillary bud",\n    "child": "axillary inflorescence bud"\n  },\n  {\n    "parent": "inflorescence bud",\n    "child": "axillary inflorescence bud"\n  },\n  {\n    "parent": "axillary bud",\n    "child": "axillary reproductive bud"\n  },\n  {\n    "parent": "reproductive bud",\n    "child": "axillary reproductive bud"\n  },\n  {\n    "parent": "axillary bud",\n    "child": "axillary strobilus bud"\n  },\n  {\n    "parent": "strobilus bud",\n    "child": "axillary strobilus bud"\n  },\n  {\n    "parent": "axillary bud",\n    "child": "axillary vegetative bud"\n  },\n  {\n    "parent": "vegetative bud",\n    "child": "axillary vegetative bud"\n  },\n  {\n    "parent": "terminal bud",\n    "child": "terminal flower bud"\n  },\n  {\n    "parent": "flower bud",\n    "child": "terminal flower bud"\n  },\n  {\n    "parent": "terminal bud",\n    "child": "terminal inflorescence bud"\n  },\n  {\n    "parent": "inflorescence bud",\n    "child": "terminal inflorescence bud"\n  },\n  {\n    "parent": "terminal bud",\n    "child": "terminal reproductive bud"\n  },\n  {\n    "parent": "reproductive bud",\n    "child": "terminal reproductive bud"\n  },\n  {\n    "parent": "terminal bud",\n    "child": "terminal strobilus bud"\n  },\n  {\n    "parent": "strobilus bud",\n    "child": "terminal strobilus bud"\n  },\n  {\n    "parent": "terminal bud",\n    "child": "terminal vegetative bud"\n  },\n  {\n    "parent": "vegetative bud",\n    "child": "terminal vegetative bud"\n  },\n  {\n    "parent": "axillary vegetative bud",\n    "child": "aerial tuber axillary vegetative bud"\n  },\n  {\n    "parent": "axillary vegetative bud",\n    "child": "shoot axis tuber axillary vegetative bud"\n  },\n  {\n    "parent": "axillary vegetative bud",\n    "child": "subterranean tuber axillary vegetative bud"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "anthela inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "bostryx inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "capitulum inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "catkin inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "cincinnus inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "corymb inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "cyme inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "determinate thyrse inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "drepanium inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "ear inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "indeterminate thyrse inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "panicle inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "pistillate inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "raceme inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "rhipidium inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "spadix inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "spike inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "staminate inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n    "child": "tassel inflorescence"\n  },\n  {\n    "parent": "inflorescence",\n ...
#  '[\n  {\n    "parent": "whole plant development stage",\n    "child": "life of whole plant stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "gametophore reproductive whole plant development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "gametophore vegetative whole plant development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "thallus reproductive whole plant development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "thallus vegetative whole plant development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "protonema whole plant development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "whole plant flowering stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "whole plant fruit development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "whole plant inflorescence detectable stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "seedling development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "gametophyte development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "sporophyte development stage"\n  },\n  {\n    "parent": "whole plant development stage",\n    "child": "plant structure development stage"\n  },\n  {\n    "parent": "plant structure development stage",\n    "child": "multi-tissue plant structure development stage"\n  },\n  {\n    "parent": "plant structure development stage",\n    "child": "plant organ development stage"\n  },\n  {\n    "parent": "plant structure development stage",\n    "child": "plant tissue development stage"\n  },\n  {\n    "parent": "plant structure development stage",\n    "child": "collective plant organ structure development stage"\n  },\n  {\n    "parent": "plant organ development stage",\n    "child": "phyllome development stage"\n  },\n  {\n    "parent": "plant organ development stage",\n    "child": "root development stage"\n  },\n  {\n    "parent": "plant organ development stage",\n    "child": "shoot system development stage"\n  },\n  {\n    "parent": "plant organ development stage",\n    "child": "inflorescence development stage"\n  },\n  {\n    "parent": "plant organ development stage",\n    "child": "flower development stage"\n  },\n  {\n    "parent": "plant organ development stage",\n    "child": "fruit development stage"\n  },\n  {\n    "parent": "plant organ development stage",\n    "child": "ovule development stage"\n  },\n  {\n    "parent": "plant tissue development stage",\n    "child": "establishment of tissue systems stage"\n  },\n  {\n    "parent": "plant tissue development stage",\n    "child": "vascular tissue development stage"\n  },\n  {\n    "parent": "vascular tissue development stage",\n    "child": "xylem development stage"\n  },\n  {\n    "parent": "vascular tissue development stage",\n    "child": "phloem development stage"\n  },\n  {\n    "parent": "xylem development stage",\n    "child": "secondary xylem development stage"\n  },\n  {\n    "parent": "secondary xylem development stage",\n    "child": "cell division stage of secondary xylem"\n  },\n  {\n    "parent": "secondary xylem development stage",\n    "child": "cell expansion stage of secondary xylem"\n  },\n  {\n    "parent": "secondary xylem development stage",\n    "child": "cell differentiation stage of secondary xylem"\n  },\n  {\n    "parent": "secondary xylem development stage",\n    "child": "secondary cell wall formation stage of secondary xylem"\n  },\n  {\n    "parent": "secondary xylem development stage",\n    "child": "cell death stage of secondary xylem"\n  },\n  {\n    "parent": "secondary xylem development stage",\n    "child": "tracheary element death stage of secondary xylem"\n  },\n  {\n    "parent": "secondary xylem development stage",\n    ...
#  '{\n  "Answer": [\n    {\n      "parent": "plant anatomical entity",\n      "child": "abaxial nucellar projection"\n    },\n    {\n      "parent": "protoderm",\n      "child": "abaxial protoderm"\n    },\n    {\n      "parent": "plant anatomical entity",\n      "child": "abscission zone"\n    },\n    {\n      "parent": "fruit",\n      "child": "achene fruit"\n    },\n    {\n      "parent": "plant anatomical entity",\n      "child": "adaxial nucellar projection"\n    },\n    {\n      "parent": "protoderm",\n      "child": "adaxial protoderm"\n    },\n    {\n      "parent": "vascular leaf",\n      "child": "adult vascular leaf"\n    },\n    {\n      "parent": "root nodule",\n      "child": "adventitious root nodule"\n    },\n    {\n      "parent": "parenchyma",\n      "child": "aerenchyma"\n    },\n    {\n      "parent": "tuber",\n      "child": "aerial tuber"\n    },\n    {\n      "parent": "aerial tuber",\n      "child": "aerial tuber axillary bud meristem"\n    },\n    {\n      "parent": "axillary shoot system",\n      "child": "aerial tuber axillary shoot"\n    },\n    {\n      "parent": "aerial tuber",\n      "child": "aerial tuber cortex"\n    },\n    {\n      "parent": "aerial tuber",\n      "child": "aerial tuber epidermis"\n    },\n    {\n      "parent": "aerial tuber",\n      "child": "aerial tuber interfascicular region"\n    },\n    {\n      "parent": "aerial tuber",\n      "child": "aerial tuber periderm"\n    },\n    {\n      "parent": "aerial tuber",\n      "child": "aerial tuber perimedullary zone"\n    },\n    {\n      "parent": "aerial tuber",\n      "child": "aerial tuber pith"\n    },\n    {\n      "parent": "aerial tuber",\n      "child": "aerial tuber storage parenchyma"\n    },\n    {\n      "parent": "plant cell",\n      "child": "alar cell"\n    },\n    {\n      "parent": "plant cell",\n      "child": "albuminous cell"\n    },\n    {\n      "parent": "endosperm",\n      "child": "aleurone layer"\n    },\n    {\n      "parent": "flower",\n      "child": "androecium"\n    },\n    {\n      "parent": "stamen",\n      "child": "anther"\n    },\n    {\n      "parent": "anther",\n      "child": "anther dehiscence zone"\n    },\n    {\n      "parent": "anther",\n      "child": "anther locule"\n    },\n    {\n      "parent": "anther",\n      "child": "anther septum"\n    },\n    {\n      "parent": "anther",\n      "child": "anther theca"\n    },\n    {\n      "parent": "anther",\n      "child": "anther wall"\n    },\n    {\n      "parent": "exothecium",\n      "child": "anther wall exothecium"\n    },\n    {\n      "parent": "anther wall secondary parietal cell layer",\n      "child": "anther wall inner secondary parietal cell layer"\n    },\n    {\n      "parent": "anther wall",\n      "child": "anther wall middle layer"\n    },\n    {\n      "parent": "anther wall secondary parietal cell layer",\n      "child": "anther wall outer secondary parietal cell layer"\n    },\n    {\n      "parent": "anther wall",\n      "child": "anther wall primary parietal cell layer"\n    },\n    {\n      "parent": "anther wall",\n      "child": "anther wall secondary parietal cell layer"\n    },\n    {\n      "parent": "anther wall",\n      "child": "anther wall tapetum"\n    },\n    {\n      "parent": "tapetum cell",\n      "child": "anther wall tapetum cell"\n    },\n    {\n      "parent": "gametophyte",\n      "child": "antheridium"\n    },\n    {\n      "parent": "antheridium",\n      "child": "antheridium head"\n    },\n    {\n      "parent": "antheridium",\n      "child": "antheridium jacket layer"\n    },\n    {\n      "parent": "antheridium jacket layer",\n      "child": "antheridium jacket layer cell"\n    },\n    {\n      "parent": "antheridium",\n      "child": "antheridium microgametophyte"\n    },\n    {\n      "parent": "plant sperm cell",\n      "child": "antheridium sperm cell"\n    },\n    {\n      "parent": "antheridium",\n      "child": "antheridium stalk"\n    },\n    {\n      "parent": "seed",\n      "child": ...
#  '[\n  {\n    "parent": "vascular bundle",\n    "child": "pericarp vascular bundle"\n  },\n  {\n    "parent": "vascular bundle",\n    "child": "petiole vascular bundle"\n  },\n  {\n    "parent": "vascular bundle",\n    "child": "phyllome lamina vein"\n  },\n  {\n    "parent": "phyllome lamina vein",\n    "child": "leaf lamina vein"\n  },\n  {\n    "parent": "leaf lamina vein",\n    "child": "leaf lamina intramarginal vein"\n  },\n  {\n    "parent": "leaf lamina vein",\n    "child": "leaf midvein"\n  },\n  {\n    "parent": "leaf lamina vein",\n    "child": "primary leaf vein"\n  },\n  {\n    "parent": "leaf lamina vein",\n    "child": "quaternary leaf vein"\n  }\n]',
#  '[\n  {\n    "parent": "plant axis",\n    "child": "shoot axis"\n  },\n  {\n    "parent": "plant axis",\n    "child": "inflorescence axis"\n  },\n  {\n    "parent": "plant axis",\n    "child": "infructescence axis"\n  },\n  {\n    "parent": "plant axis",\n    "child": "gametophore axis"\n  },\n  {\n    "parent": "plant axis",\n    "child": "plant embryo axis"\n  },\n  {\n    "parent": "plant axis",\n    "child": "pseudopodium"\n  },\n  {\n    "parent": "shoot axis",\n    "child": "adventitious shoot axis"\n  },\n  {\n    "parent": "shoot axis",\n    "child": "stem"\n  },\n  {\n    "parent": "shoot axis",\n    "child": "shoot axis tuber"\n  },\n  {\n    "parent": "shoot axis",\n    "child": "accessory paraclade"\n  },\n  {\n    "parent": "shoot axis",\n    "child": "cauline paraclade"\n  },\n  {\n    "parent": "shoot axis",\n    "child": "rosette paraclade"\n  },\n  {\n    "parent": "stem",\n    "child": "gametophore stem"\n  },\n  {\n    "parent": "stem",\n    "child": "cladode"\n  },\n  {\n    "parent": "stem",\n    "child": "gynophore"\n  },\n  {\n    "parent": "stem",\n    "child": "stem apex tendril"\n  },\n  {\n    "parent": "tuber",\n    "child": "shoot axis tuber"\n  },\n  {\n    "parent": "tuber",\n    "child": "tuberous root tuber"\n  },\n  {\n    "parent": "shoot axis tuber",\n    "child": "subterranean shoot axis tuber"\n  },\n  {\n    "parent": "inflorescence axis",\n    "child": "first order inflorescence axis"\n  },\n  {\n    "parent": "inflorescence axis",\n    "child": "higher order inflorescence axis"\n  },\n  {\n    "parent": "inflorescence axis",\n    "child": "inflorescence axis node"\n  },\n  {\n    "parent": "inflorescence axis",\n    "child": "tassel inflorescence branch"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "second order inflorescence axis"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "third order inflorescence axis"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "fourth order inflorescence axis"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "fifth order inflorescence axis"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "sixth order inflorescence axis"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "seventh order inflorescence axis"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "eighth order inflorescence axis"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "ninth order inflorescence axis"\n  },\n  {\n    "parent": "higher order inflorescence axis",\n    "child": "tenth order inflorescence axis"\n  },\n  {\n    "parent": "first order inflorescence axis",\n    "child": "first order ear inflorescence axis"\n  },\n  {\n    "parent": "first order inflorescence axis",\n    "child": "first order tassel inflorescence axis"\n  },\n  {\n    "parent": "infructescence axis",\n    "child": "first order infructescence axis"\n  },\n  {\n    "parent": "infructescence axis",\n    "child": "higher order infructescence axis"\n  },\n  {\n    "parent": "infructescence axis",\n    "child": "ear infructescence axis"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "second order infructescence"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "seventh order infructescence axis"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "eighth order infructescence axis"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "tenth order infructescence axis"\n  },\n  {\n    "parent": "pedicel",\n    "child": "flower pedicel"\n  },\n  {\n    "parent": "pedicel",\n    "child": "spikelet pedicel"\n  },\n  {\n    "parent": "flower pedicel",\n    "child": "inflorescence flower pedicel"\n  },\n  {\n    "parent": "spikelet pedicel",\n    "child": "pedicel of ear spikelet"\n  },\n  {\n    "parent": "spikelet p ...
#  '[\n  {\n    "parent": "hydathode",\n    "child": "hydathode pore"\n  },\n  {\n    "parent": "intercellular space",\n    "child": "leaf mesophyll intercellular space"\n  },\n  {\n    "parent": "intercellular space",\n    "child": "palisade mesophyll intercellular space"\n  },\n  {\n    "parent": "intercellular space",\n    "child": "spongy mesophyll intercellular space"\n  },\n  {\n    "parent": "leaf mesophyll intercellular space",\n    "child": "palisade mesophyll intercellular space"\n  },\n  {\n    "parent": "leaf mesophyll intercellular space",\n    "child": "spongy mesophyll intercellular space"\n  },\n  {\n    "parent": "phyllome sinus",\n    "child": "leaf sinus"\n  },\n  {\n    "parent": "phyllome stomatal pore",\n    "child": "leaf stomatal pore"\n  },\n  {\n    "parent": "phyllome substomatal cavity",\n    "child": "leaf substomatal cavity"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "anther pore"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "hydathode pore"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "intercellular space"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "leaf mesophyll intercellular space"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "leaf sinus"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "leaf stomatal pore"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "leaf substomatal cavity"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "palisade mesophyll intercellular space"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "phyllome sinus"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "phyllome stomatal pore"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "phyllome substomatal cavity"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "plant ovule micropyle"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "seed micropyle"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "spongy mesophyll intercellular space"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "spore capsule mouth"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "stomatal pore"\n  },\n  {\n    "parent": "plant anatomical space",\n    "child": "substomatal cavity"\n  },\n  {\n    "parent": "plant ovule micropyle",\n    "child": "seed micropyle"\n  },\n  {\n    "parent": "stomatal pore",\n    "child": "leaf stomatal pore"\n  },\n  {\n    "parent": "stomatal pore",\n    "child": "phyllome stomatal pore"\n  },\n  {\n    "parent": "substomatal cavity",\n    "child": "leaf substomatal cavity"\n  },\n  {\n    "parent": "substomatal cavity",\n    "child": "phyllome substomatal cavity"\n  }\n]',
#  '[\n  {\n    "parent": "pericycle cell",\n    "child": "phloem pole pericycle cell"\n  },\n  {\n    "parent": "pericycle cell",\n    "child": "xylem pole pericycle cell"\n  }\n]',
#  '[\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.01 one node or internode visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.02 two nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.03 three nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.04 four nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.05 five nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.06 six nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.07 seven nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.09 nine nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.10 ten nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.11 eleven nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.12 twelve nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.14 fourteen nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.15 fifteen nodes or internodes visible stage"\n  },\n  {\n    "parent": "stem elongation stage",\n    "child": "SE.97 flag leaf visible stage"\n  }\n]',
#  '[\n  {\n    "parent": "embryo sac cell",\n    "child": "antipodal cell"\n  },\n  {\n    "parent": "embryo sac cell",\n    "child": "embryo sac central cell"\n  },\n  {\n    "parent": "embryo sac cell",\n    "child": "synergid"\n  },\n  {\n    "parent": "embryo sac central cell",\n    "child": "primary endosperm cell"\n  }\n]',
#  '[\n  {\n    "parent": "higher order infructescence axis",\n    "child": "fifth order infructescence axis"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "fourth order infructescence axis"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "ninth order infructescence axis"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "second order infructescence axis"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "sixth order infructescence axis"\n  },\n  {\n    "parent": "higher order infructescence axis",\n    "child": "third order infructescence axis"\n  }\n]',
#  '[\n  {\n    "parent": "vascular system",\n    "child": "root vascular system"\n  },\n  {\n    "parent": "vascular system",\n    "child": "shoot system vascular system"\n  },\n  {\n    "parent": "vascular system",\n    "child": "plant embryo vascular system"\n  },\n  {\n    "parent": "vascular system",\n    "child": "portion of vascular tissue"\n  },\n  {\n    "parent": "vascular system",\n    "child": "primary vascular tissue"\n  },\n  {\n    "parent": "vascular system",\n    "child": "secondary vascular tissue"\n  },\n  {\n    "parent": "vascular system",\n    "child": "xylem"\n  },\n  {\n    "parent": "portion of vascular tissue",\n    "child": "vascular bundle"\n  },\n  {\n    "parent": "primary vascular tissue",\n    "child": "primary xylem"\n  },\n  {\n    "parent": "secondary vascular tissue",\n    "child": "secondary xylem"\n  },\n  {\n    "parent": "secondary vascular tissue",\n    "child": "axial system"\n  },\n  {\n    "parent": "secondary vascular tissue",\n    "child": "ray system"\n  },\n  {\n    "parent": "xylem",\n    "child": "primary xylem"\n  },\n  {\n    "parent": "xylem",\n    "child": "secondary xylem"\n  },\n  {\n    "parent": "xylem",\n    "child": "protoxylem"\n  },\n  {\n    "parent": "xylem",\n    "child": "metaxylem"\n  },\n  {\n    "parent": "xylem",\n    "child": "xylem vessel"\n  },\n  {\n    "parent": "primary xylem",\n    "child": "protoxylem"\n  },\n  {\n    "parent": "primary xylem",\n    "child": "metaxylem"\n  },\n  {\n    "parent": "primary xylem",\n    "child": "primary xylem vessel"\n  },\n  {\n    "parent": "secondary xylem",\n    "child": "secondary xylem vessel"\n  },\n  {\n    "parent": "secondary xylem",\n    "child": "early wood"\n  },\n  {\n    "parent": "secondary xylem",\n    "child": "late wood"\n  },\n  {\n    "parent": "secondary xylem",\n    "child": "heartwood"\n  },\n  {\n    "parent": "secondary xylem",\n    "child": "sapwood"\n  },\n  {\n    "parent": "secondary xylem",\n    "child": "reaction wood"\n  },\n  {\n    "parent": "secondary xylem",\n    "child": "axial system"\n  },\n  {\n    "parent": "secondary xylem",\n    "child": "ray system"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "monarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "diarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "triarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "tetrarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "pentarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "polyarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "endarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "exarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "mesarch protoxylem"\n  },\n  {\n    "parent": "protoxylem",\n    "child": "centarch protoxylem"\n  },\n  {\n    "parent": "xylem vessel",\n    "child": "primary xylem vessel"\n  },\n  {\n    "parent": "xylem vessel",\n    "child": "secondary xylem vessel"\n  },\n  {\n    "parent": "growth ring",\n    "child": "early wood"\n  },\n  {\n    "parent": "growth ring",\n    "child": "late wood"\n  },\n  {\n    "parent": "growth ring",\n    "child": "growth ring boundary"\n  },\n  {\n    "parent": "reaction wood",\n    "child": "compression wood"\n  },\n  {\n    "parent": "reaction wood",\n    "child": "tension wood"\n  },\n  {\n    "parent": "vascular cambium",\n    "child": "included vascular cambium"\n  },\n  {\n    "parent": "shoot system vascular system",\n    "child": "shoot axis vascular system"\n  },\n  {\n    "parent": "shoot system vascular system",\n    "child": "inflorescence vascular system"\n  },\n  {\n    "parent": "shoot system vascular system",\n    "child": "phyllome vascular system"\n  },\n  {\n    "parent": "shoot system vascular system",\n    "child": "flower vascular system"\n  },\n  {\n    "parent": "shoot system vascular system",\n    "child": "shoot system exarch protoxyl ...
#  '[\n  {\n    "parent": "phloem",\n    "child": "primary phloem"\n  },\n  {\n    "parent": "phloem",\n    "child": "secondary phloem"\n  },\n  {\n    "parent": "phloem",\n    "child": "internal phloem"\n  },\n  {\n    "parent": "phloem",\n    "child": "sieve tube"\n  },\n  {\n    "parent": "primary phloem",\n    "child": "protophloem"\n  },\n  {\n    "parent": "primary phloem",\n    "child": "metaphloem"\n  }\n]',
#  '[\n  {\n    "parent": "formation of ligule primordium",\n    "child": "formation of ligule primordium stage"\n  },\n  {\n    "parent": "formation of vascular leaflet primordia",\n    "child": "formation of vascular leaflet primordia stage"\n  },\n  {\n    "parent": "vascular leaf expansion",\n    "child": "vascular leaf expansion stage"\n  }\n]',
#  '[\n  {\n    "parent": "stalk",\n    "child": "antheridiophore"\n  },\n  {\n    "parent": "stalk",\n    "child": "antheridium stalk"\n  },\n  {\n    "parent": "stalk",\n    "child": "archegoniophore"\n  },\n  {\n    "parent": "stalk",\n    "child": "archegonium stalk"\n  },\n  {\n    "parent": "stalk",\n    "child": "funicle"\n  },\n  {\n    "parent": "stalk",\n    "child": "petiole"\n  },\n  {\n    "parent": "stalk",\n    "child": "petiolule"\n  },\n  {\n    "parent": "stalk",\n    "child": "seta"\n  }\n]',
#  '[\n  {\n    "parent": "sclerenchyma cell",\n    "child": "sclerid cell"\n  }\n]',
#  '[\n  {\n    "parent": "axil",\n    "child": "bract axil"\n  },\n  {\n    "parent": "axil",\n    "child": "branch axil"\n  },\n  {\n    "parent": "axil",\n    "child": "leaf axil"\n  }\n]',
#  '[\n  {\n    "parent": "canal",\n    "child": "petiole canal"\n  },\n  {\n    "parent": "canal",\n    "child": "archegonium neck canal"\n  },\n  {\n    "parent": "canal",\n    "child": "resin canal"\n  },\n  {\n    "parent": "petiole canal",\n    "child": "abaxial petiole canal"\n  },\n  {\n    "parent": "petiole canal",\n    "child": "adaxial petiole canal"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "stomatal complex",\n    "child": "phyllome stomatal complex"\n  },\n  {\n    "parent": "phyllome stomatal complex",\n    "child": "bract stomatal complex"\n  },\n  {\n    "parent": "phyllome stomatal complex",\n    "child": "carpel stomatal complex"\n  },\n  {\n    "parent": "phyllome stomatal complex",\n    "child": "petal stomatal complex"\n  },\n  {\n    "parent": "phyllome stomatal complex",\n    "child": "sepal stomatal complex"\n  },\n  {\n    "parent": "phyllome stomatal complex",\n    "child": "stamen stomatal complex"\n  },\n  {\n    "parent": "phyllome stomatal complex",\n    "child": "tepal stomatal complex"\n  },\n  {\n    "parent": "stomatal complex",\n    "child": "bract stomatal complex"\n  },\n  {\n    "parent": "stomatal complex",\n    "child": "carpel stomatal complex"\n  },\n  {\n    "parent": "stomatal complex",\n    "child": "petal stomatal complex"\n  },\n  {\n    "parent": "stomatal complex",\n    "child": "sepal stomatal complex"\n  },\n  {\n    "parent": "stomatal complex",\n    "child": "stamen stomatal complex"\n  },\n  {\n    "parent": "stomatal complex",\n    "child": "tepal stomatal complex"\n  }\n]',
#  '[\n  {\n    "parent": "meristematic apical cell",\n    "child": "chloronema meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "embryo apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "gametophore axis meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "gametophore meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "gametophyte meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "leaf meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "non-vascular leaf meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "protonema meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "rhizoid meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "root meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "seta meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "shoot axis meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "shoot meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "sporophyte meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "thallus meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "vascular leaf meristematic apical cell"\n  },\n  {\n    "parent": "meristematic apical cell",\n    "child": "vascular shoot axis meristematic apical cell"\n  },\n  {\n    "parent": "gametophyte meristematic apical cell",\n    "child": "gametophore meristematic apical cell"\n  },\n  {\n    "parent": "gametophyte meristematic apical cell",\n    "child": "protonema meristematic apical cell"\n  },\n  {\n    "parent": "gametophyte meristematic apical cell",\n    "child": "rhizoid meristematic apical cell"\n  },\n  {\n    "parent": "gametophyte meristematic apical cell",\n    "child": "thallus meristematic apical cell"\n  },\n  {\n    "parent": "gametophyte meristematic apical cell",\n    "child": "gametophore axis meristematic apical cell"\n  },\n  {\n    "parent": "gametophyte meristematic apical cell",\n    "child": "chloronema meristematic apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "embryo apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "seta meristematic apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "root meristematic apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "leaf meristematic apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "shoot meristematic apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "non-vascular leaf meristematic apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "vascular leaf meristematic apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "shoot axis meristematic apical cell"\n  },\n  {\n    "parent": "sporophyte meristematic apical cell",\n    "child": "vascular shoot axis meristematic apical cell"\n  },\n  {\n    "parent": "gametophore meristematic apical cell",\n    "child": "gametophore axis meristematic apical cell"\n  },\n  {\n    "parent": "protonema meristematic apical cell",\n    "child": "chloronema meristematic apical cell"\n  },\n  {\n    "parent": "leaf meristematic apical cell",\n    "child": "non-vascular leaf meristematic apical cell"\n  },\n  {\n    "parent": "leaf meristematic apical cell",\n    "child": "vascular leaf meristematic apical cell"\n  },\n  ...
#  '[\n  {\n    "parent": "primordium",\n    "child": "phyllome primordium"\n  },\n  {\n    "parent": "primordium",\n    "child": "root primordium"\n  },\n  {\n    "parent": "phyllome primordium",\n    "child": "bract primordium"\n  },\n  {\n    "parent": "phyllome primordium",\n    "child": "cotyledon primordium"\n  },\n  {\n    "parent": "phyllome primordium",\n    "child": "floral organ primordium"\n  },\n  {\n    "parent": "phyllome primordium",\n    "child": "leaflet primordium"\n  },\n  {\n    "parent": "phyllome primordium",\n    "child": "vascular leaf primordium"\n  },\n  {\n    "parent": "root primordium",\n    "child": "basal root primordium"\n  },\n  {\n    "parent": "root primordium",\n    "child": "shoot-borne root primordium"\n  },\n  {\n    "parent": "bract primordium",\n    "child": "flower bract primordium"\n  },\n  {\n    "parent": "vascular leaf primordium",\n    "child": "vascular leaf primordium abaxial side"\n  },\n  {\n    "parent": "vascular leaf primordium",\n    "child": "vascular leaf primordium adaxial side"\n  },\n  {\n    "parent": "floral organ primordium",\n    "child": "androecium primordium"\n  },\n  {\n    "parent": "floral organ primordium",\n    "child": "gynoecium primordium"\n  },\n  {\n    "parent": "floral organ primordium",\n    "child": "lodicule primordium"\n  },\n  {\n    "parent": "floral organ primordium",\n    "child": "petal primordium"\n  },\n  {\n    "parent": "floral organ primordium",\n    "child": "sepal primordium"\n  },\n  {\n    "parent": "androecium primordium",\n    "child": "stamen primordium"\n  },\n  {\n    "parent": "stamen primordium",\n    "child": "anther primordium"\n  },\n  {\n    "parent": "gynoecium primordium",\n    "child": "carpel primordium"\n  },\n  {\n    "parent": "gynoecium primordium",\n    "child": "ovule primordium"\n  }\n]',
#  '[\n  {\n    "parent": "initial cell",\n    "child": "archegonium initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "columella root cap initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "cortex-endodermis initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "epidermal rhizoid initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "lateral root cap epidermal initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "non-vascular leaf initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "plant epidermal initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "protonema side branch initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "protonema sub-apical initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "protonemal side branch rhizoid initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "root initial cell"\n  },\n  {\n    "parent": "initial cell",\n    "child": "stomatal initial cell"\n  },\n  {\n    "parent": "plant epidermal initial cell",\n    "child": "epidermal rhizoid initial cell"\n  },\n  {\n    "parent": "plant epidermal initial cell",\n    "child": "lateral root cap epidermal initial cell"\n  },\n  {\n    "parent": "plant epidermal initial cell",\n    "child": "stomatal initial cell"\n  },\n  {\n    "parent": "root initial cell",\n    "child": "columella root cap initial cell"\n  },\n  {\n    "parent": "root initial cell",\n    "child": "cortex-endodermis initial cell"\n  },\n  {\n    "parent": "root initial cell",\n    "child": "lateral root cap epidermal initial cell"\n  },\n  {\n    "parent": "protonema side branch initial cell",\n    "child": "protonemal side branch rhizoid initial cell"\n  }\n]',
#  '[\n  {\n    "parent": "collective phyllome structure development stage",\n    "child": "calyx development stage"\n  },\n  {\n    "parent": "collective phyllome structure development stage",\n    "child": "corolla development stage"\n  },\n  {\n    "parent": "calyx development stage",\n    "child": "sepal differentiation and expansion stage"\n  },\n  {\n    "parent": "calyx development stage",\n    "child": "fully expanded sepal stage"\n  },\n  {\n    "parent": "calyx development stage",\n    "child": "sepals enclosing flower bud stage"\n  },\n  {\n    "parent": "calyx development stage",\n    "child": "sepals enclosing meristem stage"\n  },\n  {\n    "parent": "corolla development stage",\n    "child": "petal primordium visible stage"\n  },\n  {\n    "parent": "corolla development stage",\n    "child": "fully expanded petal stage"\n  },\n  {\n    "parent": "androecium development stage",\n    "child": "stamen primordium visible stage"\n  },\n  {\n    "parent": "androecium development stage",\n    "child": "anther development stage"\n  },\n  {\n    "parent": "anther development stage",\n    "child": "B formation of primary parietal and sporogenous cells stage"\n  },\n  {\n    "parent": "anther development stage",\n    "child": "D locules established stage"\n  },\n  {\n    "parent": "anther development stage",\n    "child": "G anther dehiscence stage"\n  },\n  {\n    "parent": "anther development stage",\n    "child": "H anther senescence stage"\n  },\n  {\n    "parent": "collective phyllome structure development stage",\n    "child": "sepal differentiation and expansion stage"\n  },\n  {\n    "parent": "collective phyllome structure development stage",\n    "child": "fully expanded sepal stage"\n  },\n  {\n    "parent": "collective phyllome structure development stage",\n    "child": "sepals enclosing flower bud stage"\n  },\n  {\n    "parent": "collective phyllome structure development stage",\n    "child": "sepals enclosing meristem stage"\n  },\n  {\n    "parent": "collective phyllome structure development stage",\n    "child": "petal primordium visible stage"\n  },\n  {\n    "parent": "collective phyllome structure development stage",\n    "child": "fully expanded petal stage"\n  },\n  {\n    "parent": "androecium development stage",\n    "child": "B formation of primary parietal and sporogenous cells stage"\n  },\n  {\n    "parent": "androecium development stage",\n    "child": "D locules established stage"\n  },\n  {\n    "parent": "androecium development stage",\n    "child": "G anther dehiscence stage"\n  },\n  {\n    "parent": "androecium development stage",\n    "child": "H anther senescence stage"\n  }\n]',
#  '[\n  {\n    "parent": "endodermis",\n    "child": "embryo endodermis"\n  },\n  {\n    "parent": "endodermis",\n    "child": "hypocotyl endodermis"\n  },\n  {\n    "parent": "endodermis",\n    "child": "leaf endodermis"\n  },\n  {\n    "parent": "endodermis",\n    "child": "root endodermis"\n  },\n  {\n    "parent": "endodermis",\n    "child": "shoot axis endodermis"\n  }\n]',
#  '[\n  {\n    "parent": "leaf apex",\n    "child": "leaf apex tendril"\n  }\n]',
#  '[\n  {\n    "parent": "shoot axis apex",\n    "child": "branch apex"\n  },\n  {\n    "parent": "shoot axis apex",\n    "child": "reproductive shoot apex"\n  },\n  {\n    "parent": "shoot axis apex",\n    "child": "vegetative shoot apex"\n  }\n]',
#  '[\n  {\n    "parent": "phyllome trichome",\n    "child": "bract trichome"\n  },\n  {\n    "parent": "phyllome trichome",\n    "child": "carpel trichome"\n  },\n  {\n    "parent": "phyllome trichome",\n    "child": "leaf trichome"\n  },\n  {\n    "parent": "phyllome trichome",\n    "child": "petal trichome"\n  },\n  {\n    "parent": "phyllome trichome",\n    "child": "sepal trichome"\n  },\n  {\n    "parent": "phyllome trichome",\n    "child": "stamen trichome"\n  },\n  {\n    "parent": "phyllome trichome",\n    "child": "tepal trichome"\n  },\n  {\n    "parent": "leaf trichome",\n    "child": "leaf abaxial trichome"\n  },\n  {\n    "parent": "leaf trichome",\n    "child": "leaf adaxial trichome"\n  }\n]',
#  '[\n  {\n    "parent": "shoot axis node",\n    "child": "stem node"\n  },\n  {\n    "parent": "shoot axis node",\n    "child": "cotyledonary node"\n  },\n  {\n    "parent": "shoot axis node",\n    "child": "inflorescence axis node"\n  },\n  {\n    "parent": "shoot axis node",\n    "child": "scutellar node"\n  },\n  {\n    "parent": "cotyledonary node",\n    "child": "cotyledonary node rhizoid"\n  },\n  {\n    "parent": "stem node",\n    "child": "branch node"\n  },\n  {\n    "parent": "shoot axis node",\n    "child": "branch node"\n  },\n  {\n    "parent": "shoot axis node",\n    "child": "cotyledonary node rhizoid"\n  }\n]',
#  '[\n  {\n    "parent": "scale leaf",\n    "child": "bud scale leaf"\n  }\n]',
#  '[\n  {\n    "parent": "prickle",\n    "child": "leaf prickle"\n  },\n  {\n    "parent": "prickle",\n    "child": "root prickle"\n  },\n  {\n    "parent": "prickle",\n    "child": "shoot axis prickle"\n  }\n]',
#  '[\n  {\n    "parent": "lateral root",\n    "child": "lateral root spine"\n  },\n  {\n    "parent": "lateral root",\n    "child": "non-pericyclic lateral root"\n  },\n  {\n    "parent": "lateral root",\n    "child": "pericyclic lateral root"\n  }\n]',
#  '[\n  {\n    "parent": "cambial initial cell",\n    "child": "phloem mother cell"\n  },\n  {\n    "parent": "cambial initial cell",\n    "child": "ray initial cell"\n  }\n]',
#  '[\n  {\n    "parent": "plant fiber cell",\n    "child": "xylem fiber cell"\n  },\n  {\n    "parent": "plant fiber cell",\n    "child": "phloem fiber cell"\n  },\n  {\n    "parent": "plant fiber cell",\n    "child": "gelatinous fiber cell"\n  },\n  {\n    "parent": "plant fiber cell",\n    "child": "septate fiber cell"\n  },\n  {\n    "parent": "xylem fiber cell",\n    "child": "fiber tracheid"\n  },\n  {\n    "parent": "plant fiber cell",\n    "child": "fiber tracheid"\n  },\n  {\n    "parent": "xylem fiber cell",\n    "child": "libriform fiber cell"\n  },\n  {\n    "parent": "plant fiber cell",\n    "child": "libriform fiber cell"\n  },\n  {\n    "parent": "fiber tracheid",\n    "child": "septate fiber tracheid"\n  },\n  {\n    "parent": "septate fiber cell",\n    "child": "septate fiber tracheid"\n  },\n  {\n    "parent": "xylem fiber cell",\n    "child": "septate fiber tracheid"\n  },\n  {\n    "parent": "plant fiber cell",\n    "child": "septate fiber tracheid"\n  },\n  {\n    "parent": "libriform fiber cell",\n    "child": "septate libriform fiber cell"\n  },\n  {\n    "parent": "septate fiber cell",\n    "child": "septate libriform fiber cell"\n  },\n  {\n    "parent": "xylem fiber cell",\n    "child": "septate libriform fiber cell"\n  },\n  {\n    "parent": "plant fiber cell",\n    "child": "septate libriform fiber cell"\n  },\n  {\n    "parent": "phloem fiber cell",\n    "child": "septate phloem fiber cell"\n  },\n  {\n    "parent": "septate fiber cell",\n    "child": "septate phloem fiber cell"\n  },\n  {\n    "parent": "plant fiber cell",\n    "child": "septate phloem fiber cell"\n  }\n]',
#  '[\n  {\n    "parent": "inflorescence emergence stage",\n    "child": "IE.00 inflorescence tip just visible above flag leaf sheath stage"\n  },\n  {\n    "parent": "inflorescence emergence stage",\n    "child": "IE.02 1/2 of inflorescence emerged from flag leaf sheath stage"\n  },\n  {\n    "parent": "inflorescence emergence stage",\n    "child": "IE.04 inflorescence fully emerged from flag leaf sheath stage"\n  }\n]',
#  '[\n  {\n    "parent": "root development stage",\n    "child": "1 root primordium formation stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "2 root meristem formation stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "3 establishment of tissue systems stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "4 root elongation stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "5 root hair formation stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "coleorhiza emergence stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "radicle emergence stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "root cap formation stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "root cortex differentiation stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "root vascular cylinder differentiation stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "primary root primordium formation stage"\n  },\n  {\n    "parent": "root development stage",\n    "child": "lateral root primordium formation stage"\n  },\n  {\n    "parent": "1 root primordium formation stage",\n    "child": "primary root primordium formation stage"\n  },\n  {\n    "parent": "1 root primordium formation stage",\n    "child": "lateral root primordium formation stage"\n  }\n]',
#  '[\n  {\n    "parent": "procambium",\n    "child": "root procambium"\n  },\n  {\n    "parent": "procambium",\n    "child": "shoot procambium"\n  },\n  {\n    "parent": "shoot procambium",\n    "child": "branch procambium"\n  },\n  {\n    "parent": "shoot procambium",\n    "child": "leaf procambium"\n  },\n  {\n    "parent": "shoot procambium",\n    "child": "shoot axis procambium"\n  },\n  {\n    "parent": "shoot axis procambium",\n    "child": "stem procambium"\n  }\n]',
#  '[\n  {\n    "parent": "megasporangium",\n    "child": "nucellus"\n  }\n]',
#  '[\n  {\n    "parent": "integument epidermis",\n    "child": "inner integument epidermis"\n  },\n  {\n    "parent": "integument epidermis",\n    "child": "outer integument epidermis"\n  }\n]',
#  '[\n  {\n    "parent": "tuber axillary shoot",\n    "child": "aerial tuber axillary shoot"\n  },\n  {\n    "parent": "tuber axillary shoot",\n    "child": "subterranean tuber axillary shoot"\n  }\n]',
#  '[\n  {\n    "parent": "root emergence stage",\n    "child": "crown root emergence stage"\n  }\n]',
#  '[\n  {\n    "parent": "ground meristem",\n    "child": "root system ground meristem"\n  },\n  {\n    "parent": "ground meristem",\n    "child": "shoot system ground meristem"\n  }\n]',
#  '[\n  {\n    "parent": "root",\n    "child": "basal root"\n  },\n  {\n    "parent": "root",\n    "child": "shoot-borne internode root"\n  }\n]',
#  '[\n  {\n    "parent": "upper glume",\n    "child": "upper glume of ear spikelet"\n  },\n  {\n    "parent": "upper glume",\n    "child": "upper glume of tassel spikelet"\n  },\n  {\n    "parent": "upper glume of ear spikelet",\n    "child": "upper glume of pedicellate spikelet of ear"\n  },\n  {\n    "parent": "upper glume of ear spikelet",\n    "child": "upper glume of sessile spikelet of ear"\n  },\n  {\n    "parent": "upper glume of tassel spikelet",\n    "child": "upper glume of pedicellate spikelet of tassel"\n  },\n  {\n    "parent": "upper glume of tassel spikelet",\n    "child": "upper glume of sessile spikelet of tassel"\n  },\n  {\n    "parent": "upper glume",\n    "child": "upper glume of pedicellate spikelet of ear"\n  },\n  {\n    "parent": "upper glume",\n    "child": "upper glume of sessile spikelet of ear"\n  },\n  {\n    "parent": "upper glume",\n    "child": "upper glume of pedicellate spikelet of tassel"\n  },\n  {\n    "parent": "upper glume",\n    "child": "upper glume of sessile spikelet of tassel"\n  }\n]',
#  '[\n  {\n    "parent": "vascular leaf initiation stage",\n    "child": "vascular leaf anlagen formation stage"\n  },\n  {\n    "parent": "vascular leaf initiation stage",\n    "child": "vascular leaf primordium formation stage"\n  },\n  {\n    "parent": "vascular leaf primordium formation stage",\n    "child": "vascular leaf primordium polarity determination stage"\n  }\n]',
#  '[\n  {\n    "parent": "locule",\n    "child": "anther locule"\n  },\n  {\n    "parent": "locule",\n    "child": "fruit locule"\n  },\n  {\n    "parent": "locule",\n    "child": "plant ovary locule"\n  },\n  {\n    "parent": "locule",\n    "child": "sporangium locule"\n  },\n  {\n    "parent": "sporangium locule",\n    "child": "anther locule"\n  },\n  {\n    "parent": "plant ovary locule",\n    "child": "fruit locule"\n  }\n]',
#  '[\n  {\n    "parent": "lateral root primordium",\n    "child": "non-pericyclic lateral root primordium"\n  },\n  {\n    "parent": "lateral root primordium",\n    "child": "pericyclic lateral root primordium"\n  }\n]',
#  '[\n  {\n    "parent": "sieve tube element",\n    "child": "primary phloem sieve tube element"\n  },\n  {\n    "parent": "sieve tube element",\n    "child": "secondary phloem sieve tube element"\n  }\n]',
#  '[\n  {\n    "parent": "reproductive shoot system development stage",\n    "child": "flower development stage"\n  },\n  {\n    "parent": "reproductive shoot system development stage",\n    "child": "flowering stage"\n  },\n  {\n    "parent": "reproductive shoot system development stage",\n    "child": "flower meristem transition stage"\n  },\n  {\n    "parent": "flower development stage",\n    "child": "flowering stage"\n  },\n  {\n    "parent": "flower development stage",\n    "child": "flower meristem transition stage"\n  }\n]',
#  '[\n  {\n    "parent": "laticifer cell",\n    "child": "articulated laticifer cell"\n  }\n]',
#  '[\n  {\n    "parent": "plant spore",\n    "child": "megaspore"\n  },\n  {\n    "parent": "plant spore",\n    "child": "microspore"\n  },\n  {\n    "parent": "megaspore",\n    "child": "degenerate megaspore"\n  },\n  {\n    "parent": "megaspore",\n    "child": "functional megaspore"\n  }\n]',
#  '[\n  {\n    "parent": "fruit pedicel",\n    "child": "infructescence fruit pedicel"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "storage parenchyma",\n    "child": "tuber storage parenchyma"\n  },\n  {\n    "parent": "storage parenchyma",\n    "child": "seed storage parenchyma"\n  },\n  {\n    "parent": "tuber storage parenchyma",\n    "child": "aerial tuber storage parenchyma"\n  },\n  {\n    "parent": "tuber storage parenchyma",\n    "child": "subterranean tuber storage parenchyma"\n  },\n  {\n    "parent": "seed storage parenchyma",\n    "child": "endosperm parenchyma"\n  }\n]',
#  '[\n  {\n    "parent": "embryo root",\n    "child": "radicle"\n  },\n  {\n    "parent": "radicle",\n    "child": "seedling radicle"\n  }\n]',
#  '[\n  {\n    "parent": "branch",\n    "child": "branch tendril"\n  },\n  {\n    "parent": "branch",\n    "child": "gametophore branch"\n  },\n  {\n    "parent": "branch",\n    "child": "stolon"\n  }\n]',
#  '[\n  {\n    "parent": "leaf stomatal complex",\n    "child": "leaf abaxial stomatal complex"\n  },\n  {\n    "parent": "leaf stomatal complex",\n    "child": "leaf adaxial stomatal complex"\n  }\n]',
#  '[\n  {\n    "parent": "leaf rachis",\n    "child": "leaf rachis tendril"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "microsporophyll",\n    "child": "stamen"\n  },\n  {\n    "parent": "stamen",\n    "child": "staminode"\n  },\n  {\n    "parent": "microsporophyll",\n    "child": "staminode"\n  }\n]',
#  '[\n  {\n    "parent": "lateral leaf vein",\n    "child": "secondary leaf vein"\n  }\n]',
#  '[\n  {\n    "parent": "booting stage",\n    "child": "BO.00 booting begins stage"\n  },\n  {\n    "parent": "booting stage",\n    "child": "BO.02 mid boot stage"\n  },\n  {\n    "parent": "booting stage",\n    "child": "BO.03 late boot stage"\n  },\n  {\n    "parent": "booting stage",\n    "child": "BO.04 flag leaf sheath opening stage"\n  }\n]',
#  '[\n  {\n    "parent": "hypocotyl-root junction",\n    "child": "embryo hypocotyl-root junction"\n  },\n  {\n    "parent": "hypocotyl-root junction",\n    "child": "seedling hypocotyl-root junction"\n  }\n]',
#  '[\n  {\n    "parent": "glandular trichome",\n    "child": "lupulin gland"\n  }\n]',
#  '[\n  {\n    "parent": "shoot-borne root",\n    "child": "crown root"\n  },\n  {\n    "parent": "shoot-borne root",\n    "child": "prop root"\n  },\n  {\n    "parent": "shoot-borne root",\n    "child": "shoot-borne nodal root"\n  },\n  {\n    "parent": "shoot-borne root",\n    "child": "shoot-borne root spine"\n  }\n]',
#  '[\n  {\n    "parent": "passage cell",\n    "child": "endodermal passage cell"\n  },\n  {\n    "parent": "passage cell",\n    "child": "exodermal passage cell"\n  }\n]',
#  '[\n  {\n    "parent": "spermatogenous cell",\n    "child": "generative cell"\n  }\n]',
#  '[\n  {\n    "parent": "axillary bud meristem",\n    "child": "shoot axis tuber axillary bud meristem"\n  },\n  {\n    "parent": "axillary bud meristem",\n    "child": "subterranean tuber axillary bud meristem"\n  }\n]',
#  '[\n  {\n    "parent": "inflorescence development stage",\n    "child": "inflorescence initiation stage"\n  }\n]',
#  '[\n  {\n    "parent": "plant cuticle",\n    "child": "plant cuticle ridge"\n  }\n]',
#  '[\n  {\n    "parent": "gynoecium development stage",\n    "child": "gynoecium differentiation and expansion stage"\n  },\n  {\n    "parent": "gynoecium development stage",\n    "child": "carpel primordium visible stage"\n  },\n  {\n    "parent": "gynoecium development stage",\n    "child": "closure of carpel(s) stage"\n  },\n  {\n    "parent": "gynoecium development stage",\n    "child": "ovule development stage"\n  },\n  {\n    "parent": "ovule development stage",\n    "child": "ovule primordium visible stage"\n  },\n  {\n    "parent": "gynoecium differentiation and expansion stage",\n    "child": "stigma cell differentiation stage"\n  },\n  {\n    "parent": "gynoecium",\n    "child": "gynoecium ridge"\n  },\n  {\n    "parent": "gynoecium development stage",\n    "child": "stigma cell differentiation stage"\n  },\n  {\n    "parent": "gynoecium development stage",\n    "child": "ovule primordium visible stage"\n  }\n]',
#  '[\n  {\n    "parent": "intercalary meristem",\n    "child": "leaf intercalary meristem"\n  },\n  {\n    "parent": "intercalary meristem",\n    "child": "stem intercalary meristem"\n  }\n]',
#  '[\n  {\n    "parent": "ovule differentiation and expansion stage",\n    "child": "integument initiation stage"\n  }\n]',
#  '[\n  {\n    "parent": "peduncle",\n    "child": "ear peduncle"\n  }\n]',
#  '[\n  {\n    "parent": "collective leaf structure",\n    "child": "rosette"\n  }\n]',
#  '[\n  {\n    "parent": "anther wall endothecium",\n    "child": "microsporangium endothecium"\n  }\n]']

# %%
final_result = []
for ans in final_ans:
    ans_1 = json.loads(ans)
    for an in ans_1:
        if an!="Answer":
            final_result.append(an)

# %%
len(final_result)
# Out:
# 849

# %%
final_result
# Out:
# [{'parent': 'shoot system', 'child': 'axillary shoot system'},
#  {'parent': 'shoot system', 'child': 'primary shoot system'},
#  {'parent': 'shoot system', 'child': 'reproductive shoot system'},
#  {'parent': 'shoot system', 'child': 'vegetative shoot system'},
#  {'parent': 'shoot system', 'child': 'shoot-borne shoot system'},
#  {'parent': 'axillary bud', 'child': 'axillary flower bud'},
#  {'parent': 'flower bud', 'child': 'axillary flower bud'},
#  {'parent': 'axillary bud', 'child': 'axillary inflorescence bud'},
#  {'parent': 'inflorescence bud', 'child': 'axillary inflorescence bud'},
#  {'parent': 'axillary bud', 'child': 'axillary reproductive bud'},
#  {'parent': 'reproductive bud', 'child': 'axillary reproductive bud'},
#  {'parent': 'axillary bud', 'child': 'axillary strobilus bud'},
#  {'parent': 'strobilus bud', 'child': 'axillary strobilus bud'},
#  {'parent': 'axillary bud', 'child': 'axillary vegetative bud'},
#  {'parent': 'vegetative bud', 'child': 'axillary vegetative bud'},
#  {'parent': 'terminal bud', 'child': 'terminal flower bud'},
#  {'parent': 'flower bud', 'child': 'terminal flower bud'},
#  {'parent': 'terminal bud', 'child': 'terminal inflorescence bud'},
#  {'parent': 'inflorescence bud', 'child': 'terminal inflorescence bud'},
#  {'parent': 'terminal bud', 'child': 'terminal reproductive bud'},
#  {'parent': 'reproductive bud', 'child': 'terminal reproductive bud'},
#  {'parent': 'terminal bud', 'child': 'terminal strobilus bud'},
#  {'parent': 'strobilus bud', 'child': 'terminal strobilus bud'},
#  {'parent': 'terminal bud', 'child': 'terminal vegetative bud'},
#  {'parent': 'vegetative bud', 'child': 'terminal vegetative bud'},
#  {'parent': 'axillary vegetative bud',
#   'child': 'aerial tuber axillary vegetative bud'},
#  {'parent': 'axillary vegetative bud',
#   'child': 'shoot axis tuber axillary vegetative bud'},
#  {'parent': 'axillary vegetative bud',
#   'child': 'subterranean tuber axillary vegetative bud'},
#  {'parent': 'inflorescence', 'child': 'anthela inflorescence'},
#  {'parent': 'inflorescence', 'child': 'bostryx inflorescence'},
#  {'parent': 'inflorescence', 'child': 'capitulum inflorescence'},
#  {'parent': 'inflorescence', 'child': 'catkin inflorescence'},
#  {'parent': 'inflorescence', 'child': 'cincinnus inflorescence'},
#  {'parent': 'inflorescence', 'child': 'corymb inflorescence'},
#  {'parent': 'inflorescence', 'child': 'cyme inflorescence'},
#  {'parent': 'inflorescence', 'child': 'determinate thyrse inflorescence'},
#  {'parent': 'inflorescence', 'child': 'drepanium inflorescence'},
#  {'parent': 'inflorescence', 'child': 'ear inflorescence'},
#  {'parent': 'inflorescence', 'child': 'indeterminate thyrse inflorescence'},
#  {'parent': 'inflorescence', 'child': 'panicle inflorescence'},
#  {'parent': 'inflorescence', 'child': 'pistillate inflorescence'},
#  {'parent': 'inflorescence', 'child': 'raceme inflorescence'},
#  {'parent': 'inflorescence', 'child': 'rhipidium inflorescence'},
#  {'parent': 'inflorescence', 'child': 'spadix inflorescence'},
#  {'parent': 'inflorescence', 'child': 'spike inflorescence'},
#  {'parent': 'inflorescence', 'child': 'staminate inflorescence'},
#  {'parent': 'inflorescence', 'child': 'tassel inflorescence'},
#  {'parent': 'inflorescence', 'child': 'umbel inflorescence'},
#  {'parent': 'inflorescence', 'child': 'second order inflorescence'},
#  {'parent': 'inflorescence', 'child': 'flower fascicle'},
#  {'parent': 'inflorescence', 'child': 'compound capitulum inflorescence'},
#  {'parent': 'capitulum inflorescence',
#   'child': 'compound capitulum inflorescence'},
#  {'parent': 'inflorescence', 'child': 'compound cincinnus inflorescence'},
#  {'parent': 'cincinnus inflorescence',
#   'child': 'compound cincinnus inflorescence'},
#  {'parent': 'inflorescence', 'child': 'compound drepanium inflorescence'},
#  {'parent': 'drepanium inflorescence',
#   'child': 'compound drepanium inflorescence'},
#  {'parent': 'inflorescence', 'child': 'compound raceme inflorescence'},
#  {'parent': 'raceme inflorescence', 'child': 'compound raceme inflorescence'},
#  {'parent': 'inflorescence', 'child': 'compound spike inflorescence'},
#  {'parent': 'spike inflorescence', 'child': 'compound spike inflorescence'},
#  {'parent': 'inflorescence', 'child': 'compound umbel inflorescence'},
#  {'parent': 'umbel inflorescence', 'child': 'compound umbel inflorescence'},
#  {'parent': 'flower', 'child': 'disk flower'},
#  {'parent': 'flower', 'child': 'pistillate flower'},
#  {'parent': 'flower', 'child': 'ray flower'},
#  {'parent': 'flower', 'child': 'staminate flower'},
#  {'parent': 'flower', 'child': 'ear floret'},
#  {'parent': 'ear inflorescence', 'child': 'ear floret'},
#  {'parent': 'flower', 'child': 'spikelet floret'},
#  {'parent': 'spikelet', 'child': 'spikelet floret'},
#  {'parent': 'flower', 'child': 'tassel floret'},
#  {'parent': 'tassel inflorescence', 'child': 'tassel floret'},
#  {'parent': 'spikelet', 'child': 'ear sessile spikelet'},
#  {'parent': 'ear spikelet', 'child': 'ear sessile spikelet'},
#  {'parent': 'spikelet', 'child': 'ear spikelet'},
#  {'parent': 'spikelet', 'child': 'tassel pedicellate spikelet'},
#  {'parent': 'spikelet', 'child': 'tassel spikelet'},
#  {'parent': 'strobilus', 'child': 'megasporangiate strobilus'},
#  {'parent': 'strobilus', 'child': 'microsporangiate strobilus'},
#  {'parent': 'infructescence', 'child': 'ear infructescence'},
#  {'parent': 'infructescence', 'child': 'second order infructescence'},
#  {'parent': 'gametophore', 'child': 'gametophore bud'},
#  {'parent': 'inflorescence', 'child': 'inflorescence bract'},
#  {'parent': 'inflorescence bract', 'child': 'inflorescence bract primordium'},
#  {'parent': 'inflorescence', 'child': 'inflorescence branch crown'},
#  {'parent': 'flower fascicle', 'child': 'flower'},
#  {'parent': 'flower', 'child': 'lower floret of pedicellate spikelet of ear'},
#  {'parent': 'ear spikelet',
#   'child': 'lower floret of pedicellate spikelet of ear'},
#  {'parent': 'flower',
#   'child': 'lower floret of pedicellate spikelet of tassel'},
#  {'parent': 'tassel pedicellate spikelet',
#   'child': 'lower floret of pedicellate spikelet of tassel'},
#  {'parent': 'flower', 'child': 'lower floret of sessile spikelet of ear'},
#  {'parent': 'ear sessile spikelet',
#   'child': 'lower floret of sessile spikelet of ear'},
#  {'parent': 'flower', 'child': 'lower floret of sessile spikelet of tassel'},
#  {'parent': 'tassel spikelet',
#   'child': 'lower floret of sessile spikelet of tassel'},
#  {'parent': 'flower', 'child': 'upper floret of pedicellate spikelet of ear'},
#  {'parent': 'ear spikelet',
#   'child': 'upper floret of pedicellate spikelet of ear'},
#  {'parent': 'flower',
#   'child': 'upper floret of pedicellate spikelet of tassel'},
#  {'parent': 'tassel pedicellate spikelet',
#   'child': 'upper floret of pedicellate spikelet of tassel'},
#  {'parent': 'flower', 'child': 'upper floret of sessile spikelet of ear'},
#  {'parent': 'ear sessile spikelet',
#   'child': 'upper floret of sessile spikelet of ear'},
#  {'parent': 'flower', 'child': 'upper floret of sessile spikelet of tassel'},
#  {'parent': 'tassel spikelet',
#   'child': 'upper floret of sessile spikelet of tassel'},
#  {'parent': 'tassel inflorescence', 'child': 'tassel inflorescence branch'},
#  {'parent': 'whole plant development stage',
#   'child': 'life of whole plant stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'gametophore reproductive whole plant development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'gametophore vegetative whole plant development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'thallus reproductive whole plant development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'thallus vegetative whole plant development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'protonema whole plant development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'whole plant flowering stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'whole plant fruit development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'whole plant inflorescence detectable stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'seedling development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'gametophyte development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'sporophyte development stage'},
#  {'parent': 'whole plant development stage',
#   'child': 'plant structure development stage'},
#  {'parent': 'plant structure development stage',
#   'child': 'multi-tissue plant structure development stage'},
#  {'parent': 'plant structure development stage',
#   'child': 'plant organ development stage'},
#  {'parent': 'plant structure development stage',
#   'child': 'plant tissue development stage'},
#  {'parent': 'plant structure development stage',
#   'child': 'collective plant organ structure development stage'},
#  {'parent': 'plant organ development stage',
#   'child': 'phyllome development stage'},
#  {'parent': 'plant organ development stage',
#   'child': 'root development stage'},
#  {'parent': 'plant organ development stage',
#   'child': 'shoot system development stage'},
#  {'parent': 'plant organ development stage',
#   'child': 'inflorescence development stage'},
#  {'parent': 'plant organ development stage',
#   'child': 'flower development stage'},
#  {'parent': 'plant organ development stage',
#   'child': 'fruit development stage'},
#  {'parent': 'plant organ development stage',
#   'child': 'ovule development stage'},
#  {'parent': 'plant tissue development stage',
#   'child': 'establishment of tissue systems stage'},
#  {'parent': 'plant tissue development stage',
#   'child': 'vascular tissue development stage'},
#  {'parent': 'vascular tissue development stage',
#   'child': 'xylem development stage'},
#  {'parent': 'vascular tissue development stage',
#   'child': 'phloem development stage'},
#  {'parent': 'xylem development stage',
#   'child': 'secondary xylem development stage'},
#  {'parent': 'secondary xylem development stage',
#   'child': 'cell division stage of secondary xylem'},
#  {'parent': 'secondary xylem development stage',
#   'child': 'cell expansion stage of secondary xylem'},
#  {'parent': 'secondary xylem development stage',
#   'child': 'cell differentiation stage of secondary xylem'},
#  {'parent': 'secondary xylem development stage',
#   'child': 'secondary cell wall formation stage of secondary xylem'},
#  {'parent': 'secondary xylem development stage',
#   'child': 'cell death stage of secondary xylem'},
#  {'parent': 'secondary xylem development stage',
#   'child': 'tracheary element death stage of secondary xylem'},
#  {'parent': 'secondary xylem development stage',
#   'child': 'secondary xylem parenchyma cell death stage of secondary xylem'},
#  {'parent': 'phyllome development stage',
#   'child': 'collective phyllome structure development stage'},
#  {'parent': 'phyllome development stage', 'child': 'leaf development stage'},
#  {'parent': 'leaf development stage',
#   'child': 'vascular leaf development stage'},
#  {'parent': 'leaf development stage',
#   'child': 'non-vascular leaf development stage'},
#  {'parent': 'leaf development stage', 'child': 'leaf production stage'},
#  {'parent': 'leaf development stage',
#   'child': 'leaf trichome development stage'},
#  {'parent': 'leaf development stage',
#   'child': 'rapid elongation of leaf sheath stage'},
#  {'parent': 'leaf development stage',
#   'child': 'rapid elongation of vascular leaf lamina stage'},
#  {'parent': 'leaf production stage', 'child': 'LP.01 one leaf visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.02 two leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.03 three leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.04 four leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.05 five leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.06 six leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.07 seven leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.08 eight leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.09 nine leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.10 ten leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.11 eleven leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.12 twelve leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.13 thirteen leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.14 fourteen leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.15 fifteen leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.16 sixteen leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.17 seventeen leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.18 eighteen leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.19 nineteen leaves visible stage'},
#  {'parent': 'leaf production stage',
#   'child': 'LP.20 twenty or more leaves whorls visible stage'},
#  {'parent': 'vascular leaf development stage',
#   'child': 'vascular leaf initiation stage'},
#  {'parent': 'vascular leaf development stage',
#   'child': 'vascular leaf primordium formation stage'},
#  {'parent': 'vascular leaf development stage',
#   'child': 'vascular leaf differentiation stage'},
#  {'parent': 'vascular leaf development stage',
#   'child': 'vascular leaf expansion stage'},
#  {'parent': 'vascular leaf development stage',
#   'child': 'vascular leaf post-expansion stage'},
#  {'parent': 'vascular leaf development stage',
#   'child': 'vascular leaf senescent stage'},
#  {'parent': 'root development stage',
#   'child': '1 root primordium formation stage'},
#  {'parent': 'root development stage', 'child': '4 root elongation stage'},
#  {'parent': 'root development stage',
#   'child': 'crown root primordium formation stage'},
#  {'parent': 'root development stage', 'child': 'lateral root emergence stage'},
#  {'parent': 'root development stage',
#   'child': 'root epidermal differentiation stage'},
#  {'parent': 'inflorescence development stage',
#   'child': 'IL.00 inflorescence just visible stage'},
#  {'parent': 'inflorescence development stage',
#   'child': 'IL.01 1/4 inflorescence length reached stage'},
#  {'parent': 'inflorescence development stage',
#   'child': 'IL.02 1/2 inflorescence length reached stage'},
#  {'parent': 'inflorescence development stage',
#   'child': 'IL.03 full inflorescence length reached stage'},
#  {'parent': 'inflorescence development stage',
#   'child': 'inflorescence bifurcation stage'},
#  {'parent': 'inflorescence development stage',
#   'child': 'inflorescence emergence stage'},
#  {'parent': 'inflorescence emergence stage',
#   'child': 'IE.01 1/4 of inflorescence emerged from flag leaf sheath stage'},
#  {'parent': 'inflorescence emergence stage',
#   'child': 'IE.03 3/4 of inflorescence emerged from flag leaf sheath stage'},
#  {'parent': 'flower development stage',
#   'child': 'floral organ formation stage'},
#  {'parent': 'flower development stage', 'child': 'calyx development stage'},
#  {'parent': 'flower development stage', 'child': 'corolla development stage'},
#  {'parent': 'flower development stage',
#   'child': 'androecium development stage'},
#  {'parent': 'flower development stage',
#   'child': 'gynoecium development stage'},
#  {'parent': 'flower development stage', 'child': 'booting stage'},
#  {'parent': 'flower development stage', 'child': 'lemma development stage'},
#  {'parent': 'flower development stage', 'child': 'lodicule development stage'},
#  {'parent': 'flower development stage', 'child': 'palea development stage'},
#  {'parent': 'flower development stage',
#   'child': 'FL.00 first flower(s) open stage'},
#  {'parent': 'flower development stage',
#   'child': 'FL.01 1/4 of flowers open stage'},
#  {'parent': 'flower development stage',
#   'child': 'FL.02 1/2 of flowers open stage'},
#  {'parent': 'flower development stage',
#   'child': 'FL.03 3/4 of flowers open stage'},
#  {'parent': 'flower development stage',
#   'child': 'FL.04 end of flowering stage'},
#  {'parent': 'flower development stage', 'child': 'lemma'},
#  {'parent': 'flower development stage', 'child': 'lodicule'},
#  {'parent': 'flower development stage', 'child': 'palea'},
#  {'parent': 'floral organ formation stage',
#   'child': 'floral organ primordium development stage'},
#  {'parent': 'floral organ formation stage',
#   'child': 'floral organ differentiation stage'},
#  {'parent': 'floral organ formation stage',
#   'child': 'floral organ meristem development stage'},
#  {'parent': 'floral organ formation stage',
#   'child': 'hood-shaped primordium stage'},
#  {'parent': 'calyx development stage',
#   'child': 'sepal primordium visible stage'},
#  {'parent': 'androecium development stage',
#   'child': 'anther development stage'},
#  {'parent': 'androecium development stage',
#   'child': 'pollen development stage'},
#  {'parent': 'anther development stage',
#   'child': 'A archesporial cells visible stage'},
#  {'parent': 'anther development stage',
#   'child': 'A microsporogenous mass stage'},
#  {'parent': 'anther development stage',
#   'child': 'C four anther lobes formed stage'},
#  {'parent': 'anther development stage',
#   'child': 'E anther wall tapetum degeneration initiated stage'},
#  {'parent': 'anther development stage', 'child': 'F bilocular anther stage'},
#  {'parent': 'pollen development stage',
#   'child': 'microgametophyte development stage'},
#  {'parent': 'pollen development stage',
#   'child': 'B enlarged microsporocyte stage'},
#  {'parent': 'pollen development stage',
#   'child': 'D pollen mother cell meiosis stage'},
#  {'parent': 'pollen development stage',
#   'child': 'C callose wall formation in pollen mother cells stage'},
#  {'parent': 'pollen development stage', 'child': 'E tetrad stage'},
#  {'parent': 'pollen development stage', 'child': 'F microspore release stage'},
#  {'parent': 'pollen development stage',
#   'child': 'G early unicellular microspore stage'},
#  {'parent': 'pollen development stage',
#   'child': 'H late unicellular microspore stage'},
#  {'parent': 'pollen development stage',
#   'child': 'I first mitotic division stage'},
#  {'parent': 'pollen development stage', 'child': 'J bicellular pollen stage'},
#  {'parent': 'pollen development stage',
#   'child': 'K second mitotic division stage'},
#  {'parent': 'pollen development stage', 'child': 'L mature pollen stage'},
#  {'parent': 'pollen development stage', 'child': 'M germinated pollen stage'},
#  {'parent': 'microsporocyte', 'child': 'B enlarged microsporocyte stage'},
#  {'parent': 'L mature pollen stage', 'child': 'pollen'},
#  {'parent': 'gynoecium development stage', 'child': 'ovule development stage'},
#  {'parent': 'gynoecium development stage',
#   'child': 'megagametophyte development stage'},
#  {'parent': 'ovule development stage',
#   'child': 'A megaspore mother cell enlarges stage'},
#  {'parent': 'ovule development stage',
#   'child': 'B meiosis of megaspore mother cell stage'},
#  {'parent': 'ovule development stage',
#   'child': 'C tetrad of megaspores stage'},
#  {'parent': 'ovule development stage',
#   'child': 'D megaspore degeneration stage'},
#  {'parent': 'ovule development stage',
#   'child': 'E two nucleate megagametophyte stage'},
#  {'parent': 'ovule development stage',
#   'child': 'F four nucleate megagametophyte stage'},
#  {'parent': 'ovule development stage',
#   'child': 'G eight nucleate megagametophyte stage'},
#  {'parent': 'ovule development stage',
#   'child': 'chalazal and micropylar domain establishment stage'},
#  {'parent': 'ovule development stage',
#   'child': 'ovule differentiation and expansion stage'},
#  {'parent': 'megagametophyte development stage', 'child': 'megagametophyte'},
#  {'parent': 'booting stage', 'child': 'BO.01 early boot stage'},
#  {'parent': 'booting stage', 'child': 'BO.05 flag leaf sheath opened stage'},
#  {'parent': 'lemma development stage',
#   'child': 'lemma primordia visible stage'},
#  {'parent': 'lemma development stage',
#   'child': 'lemma differentiation and expansion stage'},
#  {'parent': 'lemma development stage', 'child': 'fully expanded lemma stage'},
#  {'parent': 'lodicule development stage',
#   'child': 'lodicule primordia visible stage'},
#  {'parent': 'lodicule development stage',
#   'child': 'lodicule differentiation and expansion stage'},
#  {'parent': 'lodicule development stage',
#   'child': 'fully expanded lodicule stage'},
#  {'parent': 'palea development stage',
#   'child': 'palea primordia visible stage'},
#  {'parent': 'palea development stage',
#   'child': 'palea differentiation and expansion stage'},
#  {'parent': 'palea development stage', 'child': 'fully expanded palea stage'},
#  {'parent': 'corolla development stage',
#   'child': 'petal differentiation and expansion stage'},
#  {'parent': 'fruit development stage', 'child': 'fruit formation stage'},
#  {'parent': 'fruit development stage', 'child': 'fruit ripening stage'},
#  {'parent': 'whole plant fruit development stage',
#   'child': 'fruit development stage'},
#  {'parent': 'fruit formation stage', 'child': 'fruit initiation stage'},
#  {'parent': 'fruit formation stage', 'child': 'fruit size up to 10% stage'},
#  {'parent': 'fruit formation stage', 'child': 'fruit size 10 to 30% stage'},
#  {'parent': 'fruit formation stage', 'child': 'fruit size 30 to 50% stage'},
#  {'parent': 'fruit formation stage', 'child': 'fruit size 50 to 70% stage'},
#  {'parent': 'fruit formation stage',
#   'child': 'fruit size 70% to final size stage'},
#  {'parent': 'whole plant fruit formation stage',
#   'child': 'whole plant fruit formation stage up to 10%'},
#  {'parent': 'whole plant fruit formation stage',
#   'child': 'whole plant fruit formation stage 10 to 30%'},
#  {'parent': 'whole plant fruit formation stage',
#   'child': 'whole plant fruit formation stage 30 to 50%'},
#  {'parent': 'whole plant fruit formation stage',
#   'child': 'whole plant fruit formation stage 50 to 70%'},
#  {'parent': 'whole plant fruit formation stage',
#   'child': 'whole plant fruit formation stage 70% to final size'},
#  {'parent': 'fruit ripening stage',
#   'child': 'beginning of whole plant fruit ripening stage'},
#  {'parent': 'fruit ripening stage',
#   'child': 'early whole plant fruit ripening stage'},
#  {'parent': 'fruit ripening stage',
#   'child': 'mid whole plant fruit ripening stage'},
#  {'parent': 'fruit ripening stage',
#   'child': 'late whole plant fruit ripening stage'},
#  {'parent': 'fruit ripening stage',
#   'child': 'whole plant fruit ripening complete stage'},
#  {'parent': 'fruit ripening stage',
#   'child': 'whole plant fruit ripening stage'},
#  {'parent': 'seed development stage', 'child': 'fertilized ovule stage'},
#  {'parent': 'seed development stage', 'child': 'developing seed stage'},
#  {'parent': 'seed development stage', 'child': 'seed maturation stage'},
#  {'parent': 'seed development stage', 'child': 'dry seed stage'},
#  {'parent': 'seed development stage', 'child': 'seed dormant stage'},
#  {'parent': 'seed development stage', 'child': 'endosperm development stage'},
#  {'parent': 'seed development stage',
#   'child': 'plant embryo development stage'},
#  {'parent': 'seed development stage',
#   'child': 'seed trichome development stage'},
#  {'parent': 'seed development stage', 'child': 'seed chalaza'},
#  {'parent': 'seed development stage', 'child': 'seed funicle'},
#  {'parent': 'seed development stage', 'child': 'seed obturator'},
#  {'parent': 'endosperm development stage',
#   'child': 'primary endosperm cell stage'},
#  {'parent': 'endosperm development stage',
#   'child': 'formation of aleurone and starchy layers stage'},
#  {'parent': 'endosperm development stage',
#   'child': 'functional specialization of the endosperm stage'},
#  {'parent': 'formation of aleurone and starchy layers stage',
#   'child': 'modified aleurone'},
#  {'parent': 'plant embryo development stage', 'child': 'plant zygote stage'},
#  {'parent': 'plant embryo development stage',
#   'child': 'plant proembryo stage'},
#  {'parent': 'plant embryo development stage',
#   'child': 'plant embryo globular stage'},
#  {'parent': 'plant embryo development stage',
#   'child': 'plant embryo bilateral stage'},
#  {'parent': 'plant embryo development stage',
#   'child': 'plant embryo cotyledonary stage'},
#  {'parent': 'plant embryo development stage',
#   'child': 'plant embryo coleoptilar stage'},
#  {'parent': 'plant embryo development stage',
#   'child': 'plant embryo true leaf formation stage'},
#  {'parent': 'plant embryo development stage',
#   'child': 'mature plant embryo stage'},
#  {'parent': 'plant embryo development stage',
#   'child': 'plant embryo dormant stage'},
#  {'parent': 'seed germination stage', 'child': 'seed imbibition stage'},
#  {'parent': 'seed germination stage', 'child': 'coleoptile emergence stage'},
#  {'parent': 'seed germination stage', 'child': 'hypocotyl emergence stage'},
#  {'parent': 'seed germination stage', 'child': 'epicotyl emergence stage'},
#  {'parent': 'seed germination stage', 'child': 'cotyledon emergence stage'},
#  {'parent': 'seed germination stage', 'child': 'root emergence stage'},
#  {'parent': 'seed germination stage',
#   'child': 'seedling shoot emergence stage'},
#  {'parent': 'seedling development stage', 'child': 'rosette growth stage'},
#  {'parent': 'seedling development stage', 'child': 'bud development stage'},
#  {'parent': 'rosette growth stage', 'child': 'early rosette growth stage'},
#  {'parent': 'rosette growth stage', 'child': 'mid rosette growth stage'},
#  {'parent': 'rosette growth stage', 'child': 'late rosette growth stage'},
#  {'parent': 'rosette growth stage', 'child': 'rosette growth complete stage'},
#  {'parent': 'bud development stage', 'child': 'bud burst stage'},
#  {'parent': 'bud development stage', 'child': 'bud dormancy stage'},
#  {'parent': 'bud development stage', 'child': 'bud swell stage'},
#  {'parent': 'shoot system development stage',
#   'child': '1 main shoot growth stage'},
#  {'parent': 'shoot system development stage',
#   'child': 'reproductive shoot system development stage'},
#  {'parent': 'shoot system development stage',
#   'child': 'stem elongation stage'},
#  {'parent': '1 main shoot growth stage',
#   'child': '2 formation of axillary shoot stage'},
#  {'parent': '1 main shoot growth stage', 'child': '3 branch formation stage'},
#  {'parent': '1 main shoot growth stage',
#   'child': '4 growth directionality stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.01 main shoot and axillary shoots visible at one node stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.02 main shoot and axillary shoots visible at two nodes stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.03 main shoot and axillary shoots visible at three nodes stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.04 main shoot and axillary shoots visible at four nodes stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.05 main shoot and axillary shoots visible at five nodes stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.06 main shoot and axillary shoots visible at six nodes stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.07 main shoot and axillary shoots visible at seven nodes stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.08 main shoot and axillary shoots visible at eight nodes stage'},
#  {'parent': '2 formation of axillary shoot stage',
#   'child': '2.09 main shoot and axillary shoots visible at nine or more nodes stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.00 stem elongation begins stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.08 eight nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.13 thirteen nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.16 sixteen or more nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.99 maximum stem length reached stage'},
#  {'parent': 'trichome development stage',
#   'child': 'leaf trichome development stage'},
#  {'parent': 'trichome development stage',
#   'child': 'seed trichome development stage'},
#  {'parent': 'seed trichome development stage',
#   'child': 'seed trichome initiation stage'},
#  {'parent': 'seed trichome development stage',
#   'child': 'seed trichome elongation stage'},
#  {'parent': 'seed trichome development stage',
#   'child': 'seed trichome secondary wall biosynthesis stage'},
#  {'parent': 'seed trichome development stage',
#   'child': 'seed trichome maturation stage'},
#  {'parent': 'gametophyte development stage',
#   'child': 'gametophyte dormant stage'},
#  {'parent': 'gametophyte development stage',
#   'child': 'gametophyte vegetative stage'},
#  {'parent': 'gametophyte development stage',
#   'child': 'gametophyte reproductive stage'},
#  {'parent': 'gametophyte development stage',
#   'child': 'gametophyte senescent stage'},
#  {'parent': 'sporophyte development stage',
#   'child': 'sporophyte dormant stage'},
#  {'parent': 'sporophyte development stage',
#   'child': 'sporophyte vegetative stage'},
#  {'parent': 'sporophyte development stage',
#   'child': 'sporophyte reproductive stage'},
#  {'parent': 'sporophyte development stage',
#   'child': 'sporophyte senescent stage'},
#  {'parent': 'sporophyte development stage', 'child': 'sporophyte foot'},
#  {'parent': 'obturator', 'child': 'seed obturator'},
#  {'parent': 'vascular bundle', 'child': 'pericarp vascular bundle'},
#  {'parent': 'vascular bundle', 'child': 'petiole vascular bundle'},
#  {'parent': 'vascular bundle', 'child': 'phyllome lamina vein'},
#  {'parent': 'phyllome lamina vein', 'child': 'leaf lamina vein'},
#  {'parent': 'leaf lamina vein', 'child': 'leaf lamina intramarginal vein'},
#  {'parent': 'leaf lamina vein', 'child': 'leaf midvein'},
#  {'parent': 'leaf lamina vein', 'child': 'primary leaf vein'},
#  {'parent': 'leaf lamina vein', 'child': 'quaternary leaf vein'},
#  {'parent': 'plant axis', 'child': 'shoot axis'},
#  {'parent': 'plant axis', 'child': 'inflorescence axis'},
#  {'parent': 'plant axis', 'child': 'infructescence axis'},
#  {'parent': 'plant axis', 'child': 'gametophore axis'},
#  {'parent': 'plant axis', 'child': 'plant embryo axis'},
#  {'parent': 'plant axis', 'child': 'pseudopodium'},
#  {'parent': 'shoot axis', 'child': 'adventitious shoot axis'},
#  {'parent': 'shoot axis', 'child': 'stem'},
#  {'parent': 'shoot axis', 'child': 'shoot axis tuber'},
#  {'parent': 'shoot axis', 'child': 'accessory paraclade'},
#  {'parent': 'shoot axis', 'child': 'cauline paraclade'},
#  {'parent': 'shoot axis', 'child': 'rosette paraclade'},
#  {'parent': 'stem', 'child': 'gametophore stem'},
#  {'parent': 'stem', 'child': 'cladode'},
#  {'parent': 'stem', 'child': 'gynophore'},
#  {'parent': 'stem', 'child': 'stem apex tendril'},
#  {'parent': 'tuber', 'child': 'shoot axis tuber'},
#  {'parent': 'tuber', 'child': 'tuberous root tuber'},
#  {'parent': 'shoot axis tuber', 'child': 'subterranean shoot axis tuber'},
#  {'parent': 'inflorescence axis', 'child': 'first order inflorescence axis'},
#  {'parent': 'inflorescence axis', 'child': 'higher order inflorescence axis'},
#  {'parent': 'inflorescence axis', 'child': 'inflorescence axis node'},
#  {'parent': 'inflorescence axis', 'child': 'tassel inflorescence branch'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'second order inflorescence axis'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'third order inflorescence axis'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'fourth order inflorescence axis'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'fifth order inflorescence axis'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'sixth order inflorescence axis'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'seventh order inflorescence axis'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'eighth order inflorescence axis'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'ninth order inflorescence axis'},
#  {'parent': 'higher order inflorescence axis',
#   'child': 'tenth order inflorescence axis'},
#  {'parent': 'first order inflorescence axis',
#   'child': 'first order ear inflorescence axis'},
#  {'parent': 'first order inflorescence axis',
#   'child': 'first order tassel inflorescence axis'},
#  {'parent': 'infructescence axis', 'child': 'first order infructescence axis'},
#  {'parent': 'infructescence axis',
#   'child': 'higher order infructescence axis'},
#  {'parent': 'infructescence axis', 'child': 'ear infructescence axis'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'second order infructescence'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'seventh order infructescence axis'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'eighth order infructescence axis'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'tenth order infructescence axis'},
#  {'parent': 'pedicel', 'child': 'flower pedicel'},
#  {'parent': 'pedicel', 'child': 'spikelet pedicel'},
#  {'parent': 'flower pedicel', 'child': 'inflorescence flower pedicel'},
#  {'parent': 'spikelet pedicel', 'child': 'pedicel of ear spikelet'},
#  {'parent': 'spikelet pedicel', 'child': 'pedicel of tassel spikelet'},
#  {'parent': 'spikelet rachilla', 'child': 'ear spikelet rachilla'},
#  {'parent': 'spikelet rachilla', 'child': 'tassel spikelet rachilla'},
#  {'parent': 'ear spikelet rachilla',
#   'child': 'rachilla of pedicellate spikelet of ear'},
#  {'parent': 'tassel spikelet rachilla',
#   'child': 'rachilla of pedicellate spikelet of tassel'},
#  {'parent': 'tassel spikelet rachilla',
#   'child': 'rachilla of sessile spikelet of tassel'},
#  {'parent': 'hydathode', 'child': 'hydathode pore'},
#  {'parent': 'intercellular space',
#   'child': 'leaf mesophyll intercellular space'},
#  {'parent': 'intercellular space',
#   'child': 'palisade mesophyll intercellular space'},
#  {'parent': 'intercellular space',
#   'child': 'spongy mesophyll intercellular space'},
#  {'parent': 'leaf mesophyll intercellular space',
#   'child': 'palisade mesophyll intercellular space'},
#  {'parent': 'leaf mesophyll intercellular space',
#   'child': 'spongy mesophyll intercellular space'},
#  {'parent': 'phyllome sinus', 'child': 'leaf sinus'},
#  {'parent': 'phyllome stomatal pore', 'child': 'leaf stomatal pore'},
#  {'parent': 'phyllome substomatal cavity', 'child': 'leaf substomatal cavity'},
#  {'parent': 'plant anatomical space', 'child': 'anther pore'},
#  {'parent': 'plant anatomical space', 'child': 'hydathode pore'},
#  {'parent': 'plant anatomical space', 'child': 'intercellular space'},
#  {'parent': 'plant anatomical space',
#   'child': 'leaf mesophyll intercellular space'},
#  {'parent': 'plant anatomical space', 'child': 'leaf sinus'},
#  {'parent': 'plant anatomical space', 'child': 'leaf stomatal pore'},
#  {'parent': 'plant anatomical space', 'child': 'leaf substomatal cavity'},
#  {'parent': 'plant anatomical space',
#   'child': 'palisade mesophyll intercellular space'},
#  {'parent': 'plant anatomical space', 'child': 'phyllome sinus'},
#  {'parent': 'plant anatomical space', 'child': 'phyllome stomatal pore'},
#  {'parent': 'plant anatomical space', 'child': 'phyllome substomatal cavity'},
#  {'parent': 'plant anatomical space', 'child': 'plant ovule micropyle'},
#  {'parent': 'plant anatomical space', 'child': 'seed micropyle'},
#  {'parent': 'plant anatomical space',
#   'child': 'spongy mesophyll intercellular space'},
#  {'parent': 'plant anatomical space', 'child': 'spore capsule mouth'},
#  {'parent': 'plant anatomical space', 'child': 'stomatal pore'},
#  {'parent': 'plant anatomical space', 'child': 'substomatal cavity'},
#  {'parent': 'plant ovule micropyle', 'child': 'seed micropyle'},
#  {'parent': 'stomatal pore', 'child': 'leaf stomatal pore'},
#  {'parent': 'stomatal pore', 'child': 'phyllome stomatal pore'},
#  {'parent': 'substomatal cavity', 'child': 'leaf substomatal cavity'},
#  {'parent': 'substomatal cavity', 'child': 'phyllome substomatal cavity'},
#  {'parent': 'pericycle cell', 'child': 'phloem pole pericycle cell'},
#  {'parent': 'pericycle cell', 'child': 'xylem pole pericycle cell'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.01 one node or internode visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.02 two nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.03 three nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.04 four nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.05 five nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.06 six nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.07 seven nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.09 nine nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.10 ten nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.11 eleven nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.12 twelve nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.14 fourteen nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage',
#   'child': 'SE.15 fifteen nodes or internodes visible stage'},
#  {'parent': 'stem elongation stage', 'child': 'SE.97 flag leaf visible stage'},
#  {'parent': 'embryo sac cell', 'child': 'antipodal cell'},
#  {'parent': 'embryo sac cell', 'child': 'embryo sac central cell'},
#  {'parent': 'embryo sac cell', 'child': 'synergid'},
#  {'parent': 'embryo sac central cell', 'child': 'primary endosperm cell'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'fifth order infructescence axis'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'fourth order infructescence axis'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'ninth order infructescence axis'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'second order infructescence axis'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'sixth order infructescence axis'},
#  {'parent': 'higher order infructescence axis',
#   'child': 'third order infructescence axis'},
#  {'parent': 'vascular system', 'child': 'root vascular system'},
#  {'parent': 'vascular system', 'child': 'shoot system vascular system'},
#  {'parent': 'vascular system', 'child': 'plant embryo vascular system'},
#  {'parent': 'vascular system', 'child': 'portion of vascular tissue'},
#  {'parent': 'vascular system', 'child': 'primary vascular tissue'},
#  {'parent': 'vascular system', 'child': 'secondary vascular tissue'},
#  {'parent': 'vascular system', 'child': 'xylem'},
#  {'parent': 'portion of vascular tissue', 'child': 'vascular bundle'},
#  {'parent': 'primary vascular tissue', 'child': 'primary xylem'},
#  {'parent': 'secondary vascular tissue', 'child': 'secondary xylem'},
#  {'parent': 'secondary vascular tissue', 'child': 'axial system'},
#  {'parent': 'secondary vascular tissue', 'child': 'ray system'},
#  {'parent': 'xylem', 'child': 'primary xylem'},
#  {'parent': 'xylem', 'child': 'secondary xylem'},
#  {'parent': 'xylem', 'child': 'protoxylem'},
#  {'parent': 'xylem', 'child': 'metaxylem'},
#  {'parent': 'xylem', 'child': 'xylem vessel'},
#  {'parent': 'primary xylem', 'child': 'protoxylem'},
#  {'parent': 'primary xylem', 'child': 'metaxylem'},
#  {'parent': 'primary xylem', 'child': 'primary xylem vessel'},
#  {'parent': 'secondary xylem', 'child': 'secondary xylem vessel'},
#  {'parent': 'secondary xylem', 'child': 'early wood'},
#  {'parent': 'secondary xylem', 'child': 'late wood'},
#  {'parent': 'secondary xylem', 'child': 'heartwood'},
#  {'parent': 'secondary xylem', 'child': 'sapwood'},
#  {'parent': 'secondary xylem', 'child': 'reaction wood'},
#  {'parent': 'secondary xylem', 'child': 'axial system'},
#  {'parent': 'secondary xylem', 'child': 'ray system'},
#  {'parent': 'protoxylem', 'child': 'monarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'diarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'triarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'tetrarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'pentarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'polyarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'endarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'exarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'mesarch protoxylem'},
#  {'parent': 'protoxylem', 'child': 'centarch protoxylem'},
#  {'parent': 'xylem vessel', 'child': 'primary xylem vessel'},
#  {'parent': 'xylem vessel', 'child': 'secondary xylem vessel'},
#  {'parent': 'growth ring', 'child': 'early wood'},
#  {'parent': 'growth ring', 'child': 'late wood'},
#  {'parent': 'growth ring', 'child': 'growth ring boundary'},
#  {'parent': 'reaction wood', 'child': 'compression wood'},
#  {'parent': 'reaction wood', 'child': 'tension wood'},
#  {'parent': 'vascular cambium', 'child': 'included vascular cambium'},
#  {'parent': 'shoot system vascular system',
#   'child': 'shoot axis vascular system'},
#  {'parent': 'shoot system vascular system',
#   'child': 'inflorescence vascular system'},
#  {'parent': 'shoot system vascular system',
#   'child': 'phyllome vascular system'},
#  {'parent': 'shoot system vascular system', 'child': 'flower vascular system'},
#  {'parent': 'shoot system vascular system',
#   'child': 'shoot system exarch protoxylem'},
#  {'parent': 'inflorescence vascular system',
#   'child': 'flower vascular system'},
#  {'parent': 'flower vascular system', 'child': 'pedicel vascular system'},
#  {'parent': 'flower vascular system', 'child': 'sepal vascular system'},
#  {'parent': 'flower vascular system', 'child': 'petal vascular system'},
#  {'parent': 'flower vascular system', 'child': 'tepal vascular system'},
#  {'parent': 'flower vascular system', 'child': 'stamen vascular system'},
#  {'parent': 'flower vascular system', 'child': 'carpel vascular system'},
#  {'parent': 'flower vascular system', 'child': 'fruit vascular system'},
#  {'parent': 'phyllome vascular system',
#   'child': 'leaf lamina vascular system'},
#  {'parent': 'phyllome vascular system', 'child': 'petiole vascular system'},
#  {'parent': 'stamen vascular system', 'child': 'anther vascular system'},
#  {'parent': 'stamen vascular system', 'child': 'filament vascular system'},
#  {'parent': 'carpel vascular system', 'child': 'stigma vascular system'},
#  {'parent': 'plant embryo vascular system',
#   'child': 'cotyledon vascular system'},
#  {'parent': 'plant embryo vascular system',
#   'child': 'hypocotyl vascular system'},
#  {'parent': 'plant embryo vascular system',
#   'child': 'scutellum vascular system'},
#  {'parent': 'exarch protoxylem', 'child': 'root system exarch protoxylem'},
#  {'parent': 'exarch protoxylem', 'child': 'shoot system exarch protoxylem'},
#  {'parent': 'root vascular system', 'child': 'root system exarch protoxylem'},
#  {'parent': 'phloem', 'child': 'primary phloem'},
#  {'parent': 'phloem', 'child': 'secondary phloem'},
#  {'parent': 'phloem', 'child': 'internal phloem'},
#  {'parent': 'phloem', 'child': 'sieve tube'},
#  {'parent': 'primary phloem', 'child': 'protophloem'},
#  {'parent': 'primary phloem', 'child': 'metaphloem'},
#  {'parent': 'formation of ligule primordium',
#   'child': 'formation of ligule primordium stage'},
#  {'parent': 'formation of vascular leaflet primordia',
#   'child': 'formation of vascular leaflet primordia stage'},
#  {'parent': 'vascular leaf expansion',
#   'child': 'vascular leaf expansion stage'},
#  {'parent': 'stalk', 'child': 'antheridiophore'},
#  {'parent': 'stalk', 'child': 'antheridium stalk'},
#  {'parent': 'stalk', 'child': 'archegoniophore'},
#  {'parent': 'stalk', 'child': 'archegonium stalk'},
#  {'parent': 'stalk', 'child': 'funicle'},
#  {'parent': 'stalk', 'child': 'petiole'},
#  {'parent': 'stalk', 'child': 'petiolule'},
#  {'parent': 'stalk', 'child': 'seta'},
#  {'parent': 'sclerenchyma cell', 'child': 'sclerid cell'},
#  {'parent': 'axil', 'child': 'bract axil'},
#  {'parent': 'axil', 'child': 'branch axil'},
#  {'parent': 'axil', 'child': 'leaf axil'},
#  {'parent': 'canal', 'child': 'petiole canal'},
#  {'parent': 'canal', 'child': 'archegonium neck canal'},
#  {'parent': 'canal', 'child': 'resin canal'},
#  {'parent': 'petiole canal', 'child': 'abaxial petiole canal'},
#  {'parent': 'petiole canal', 'child': 'adaxial petiole canal'},
#  {'parent': 'stomatal complex', 'child': 'phyllome stomatal complex'},
#  {'parent': 'phyllome stomatal complex', 'child': 'bract stomatal complex'},
#  {'parent': 'phyllome stomatal complex', 'child': 'carpel stomatal complex'},
#  {'parent': 'phyllome stomatal complex', 'child': 'petal stomatal complex'},
#  {'parent': 'phyllome stomatal complex', 'child': 'sepal stomatal complex'},
#  {'parent': 'phyllome stomatal complex', 'child': 'stamen stomatal complex'},
#  {'parent': 'phyllome stomatal complex', 'child': 'tepal stomatal complex'},
#  {'parent': 'stomatal complex', 'child': 'bract stomatal complex'},
#  {'parent': 'stomatal complex', 'child': 'carpel stomatal complex'},
#  {'parent': 'stomatal complex', 'child': 'petal stomatal complex'},
#  {'parent': 'stomatal complex', 'child': 'sepal stomatal complex'},
#  {'parent': 'stomatal complex', 'child': 'stamen stomatal complex'},
#  {'parent': 'stomatal complex', 'child': 'tepal stomatal complex'},
#  {'parent': 'meristematic apical cell',
#   'child': 'chloronema meristematic apical cell'},
#  {'parent': 'meristematic apical cell', 'child': 'embryo apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'gametophore axis meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'gametophore meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'gametophyte meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'leaf meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'non-vascular leaf meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'protonema meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'rhizoid meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'root meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'seta meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'shoot axis meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'shoot meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'sporophyte meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'thallus meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'vascular leaf meristematic apical cell'},
#  {'parent': 'meristematic apical cell',
#   'child': 'vascular shoot axis meristematic apical cell'},
#  {'parent': 'gametophyte meristematic apical cell',
#   'child': 'gametophore meristematic apical cell'},
#  {'parent': 'gametophyte meristematic apical cell',
#   'child': 'protonema meristematic apical cell'},
#  {'parent': 'gametophyte meristematic apical cell',
#   'child': 'rhizoid meristematic apical cell'},
#  {'parent': 'gametophyte meristematic apical cell',
#   'child': 'thallus meristematic apical cell'},
#  {'parent': 'gametophyte meristematic apical cell',
#   'child': 'gametophore axis meristematic apical cell'},
#  {'parent': 'gametophyte meristematic apical cell',
#   'child': 'chloronema meristematic apical cell'},
#  {'parent': 'sporophyte meristematic apical cell',
#   'child': 'embryo apical cell'},
#  {'parent': 'sporophyte meristematic apical cell',
#   'child': 'seta meristematic apical cell'},
#  {'parent': 'sporophyte meristematic apical cell',
#   'child': 'root meristematic apical cell'},
#  {'parent': 'sporophyte meristematic apical cell',
#   'child': 'leaf meristematic apical cell'},
#  {'parent': 'sporophyte meristematic apical cell',
#   'child': 'shoot meristematic apical cell'},
#  {'parent': 'sporophyte meristematic apical cell',
#   'child': 'non-vascular leaf meristematic apical cell'},
#  {'parent': 'sporophyte meristematic apical cell',
#   'child': 'vascular leaf meristematic apical cell'},
# ...
#  {'parent': 'initial cell', 'child': 'epidermal rhizoid initial cell'},
#  {'parent': 'initial cell',
#   'child': 'lateral root cap epidermal initial cell'},
#  {'parent': 'initial cell', 'child': 'non-vascular leaf initial cell'},
#  {'parent': 'initial cell', 'child': 'plant epidermal initial cell'},
#  {'parent': 'initial cell', 'child': 'protonema side branch initial cell'},
#  {'parent': 'initial cell', 'child': 'protonema sub-apical initial cell'},
#  {'parent': 'initial cell',
#   'child': 'protonemal side branch rhizoid initial cell'},
#  {'parent': 'initial cell', 'child': 'root initial cell'},
#  {'parent': 'initial cell', 'child': 'stomatal initial cell'},
#  {'parent': 'plant epidermal initial cell',
#   'child': 'epidermal rhizoid initial cell'},
#  {'parent': 'plant epidermal initial cell',
#   'child': 'lateral root cap epidermal initial cell'},
#  {'parent': 'plant epidermal initial cell', 'child': 'stomatal initial cell'},
#  {'parent': 'root initial cell', 'child': 'columella root cap initial cell'},
#  {'parent': 'root initial cell', 'child': 'cortex-endodermis initial cell'},
#  {'parent': 'root initial cell',
#   'child': 'lateral root cap epidermal initial cell'},
#  {'parent': 'protonema side branch initial cell',
#   'child': 'protonemal side branch rhizoid initial cell'},
#  {'parent': 'collective phyllome structure development stage',
#   'child': 'calyx development stage'},
#  {'parent': 'collective phyllome structure development stage',
#   'child': 'corolla development stage'},
#  {'parent': 'calyx development stage',
#   'child': 'sepal differentiation and expansion stage'},
#  {'parent': 'calyx development stage', 'child': 'fully expanded sepal stage'},
#  {'parent': 'calyx development stage',
#   'child': 'sepals enclosing flower bud stage'},
#  {'parent': 'calyx development stage',
#   'child': 'sepals enclosing meristem stage'},
#  {'parent': 'corolla development stage',
#   'child': 'petal primordium visible stage'},
#  {'parent': 'corolla development stage',
#   'child': 'fully expanded petal stage'},
#  {'parent': 'androecium development stage',
#   'child': 'stamen primordium visible stage'},
#  {'parent': 'androecium development stage',
#   'child': 'anther development stage'},
#  {'parent': 'anther development stage',
#   'child': 'B formation of primary parietal and sporogenous cells stage'},
#  {'parent': 'anther development stage',
#   'child': 'D locules established stage'},
#  {'parent': 'anther development stage', 'child': 'G anther dehiscence stage'},
#  {'parent': 'anther development stage', 'child': 'H anther senescence stage'},
#  {'parent': 'collective phyllome structure development stage',
#   'child': 'sepal differentiation and expansion stage'},
#  {'parent': 'collective phyllome structure development stage',
#   'child': 'fully expanded sepal stage'},
#  {'parent': 'collective phyllome structure development stage',
#   'child': 'sepals enclosing flower bud stage'},
#  {'parent': 'collective phyllome structure development stage',
#   'child': 'sepals enclosing meristem stage'},
#  {'parent': 'collective phyllome structure development stage',
#   'child': 'petal primordium visible stage'},
#  {'parent': 'collective phyllome structure development stage',
#   'child': 'fully expanded petal stage'},
#  {'parent': 'androecium development stage',
#   'child': 'B formation of primary parietal and sporogenous cells stage'},
#  {'parent': 'androecium development stage',
#   'child': 'D locules established stage'},
#  {'parent': 'androecium development stage',
#   'child': 'G anther dehiscence stage'},
#  {'parent': 'androecium development stage',
#   'child': 'H anther senescence stage'},
#  {'parent': 'endodermis', 'child': 'embryo endodermis'},
#  {'parent': 'endodermis', 'child': 'hypocotyl endodermis'},
#  {'parent': 'endodermis', 'child': 'leaf endodermis'},
#  {'parent': 'endodermis', 'child': 'root endodermis'},
#  {'parent': 'endodermis', 'child': 'shoot axis endodermis'},
#  {'parent': 'leaf apex', 'child': 'leaf apex tendril'},
#  {'parent': 'shoot axis apex', 'child': 'branch apex'},
#  {'parent': 'shoot axis apex', 'child': 'reproductive shoot apex'},
#  {'parent': 'shoot axis apex', 'child': 'vegetative shoot apex'},
#  {'parent': 'phyllome trichome', 'child': 'bract trichome'},
#  {'parent': 'phyllome trichome', 'child': 'carpel trichome'},
#  {'parent': 'phyllome trichome', 'child': 'leaf trichome'},
#  {'parent': 'phyllome trichome', 'child': 'petal trichome'},
#  {'parent': 'phyllome trichome', 'child': 'sepal trichome'},
#  {'parent': 'phyllome trichome', 'child': 'stamen trichome'},
#  {'parent': 'phyllome trichome', 'child': 'tepal trichome'},
#  {'parent': 'leaf trichome', 'child': 'leaf abaxial trichome'},
#  {'parent': 'leaf trichome', 'child': 'leaf adaxial trichome'},
#  {'parent': 'shoot axis node', 'child': 'stem node'},
#  {'parent': 'shoot axis node', 'child': 'cotyledonary node'},
#  {'parent': 'shoot axis node', 'child': 'inflorescence axis node'},
#  {'parent': 'shoot axis node', 'child': 'scutellar node'},
#  {'parent': 'cotyledonary node', 'child': 'cotyledonary node rhizoid'},
#  {'parent': 'stem node', 'child': 'branch node'},
#  {'parent': 'shoot axis node', 'child': 'branch node'},
#  {'parent': 'shoot axis node', 'child': 'cotyledonary node rhizoid'},
#  {'parent': 'scale leaf', 'child': 'bud scale leaf'},
#  {'parent': 'prickle', 'child': 'leaf prickle'},
#  {'parent': 'prickle', 'child': 'root prickle'},
#  {'parent': 'prickle', 'child': 'shoot axis prickle'},
#  {'parent': 'lateral root', 'child': 'lateral root spine'},
#  {'parent': 'lateral root', 'child': 'non-pericyclic lateral root'},
#  {'parent': 'lateral root', 'child': 'pericyclic lateral root'},
#  {'parent': 'cambial initial cell', 'child': 'phloem mother cell'},
#  {'parent': 'cambial initial cell', 'child': 'ray initial cell'},
#  {'parent': 'plant fiber cell', 'child': 'xylem fiber cell'},
#  {'parent': 'plant fiber cell', 'child': 'phloem fiber cell'},
#  {'parent': 'plant fiber cell', 'child': 'gelatinous fiber cell'},
#  {'parent': 'plant fiber cell', 'child': 'septate fiber cell'},
#  {'parent': 'xylem fiber cell', 'child': 'fiber tracheid'},
#  {'parent': 'plant fiber cell', 'child': 'fiber tracheid'},
#  {'parent': 'xylem fiber cell', 'child': 'libriform fiber cell'},
#  {'parent': 'plant fiber cell', 'child': 'libriform fiber cell'},
#  {'parent': 'fiber tracheid', 'child': 'septate fiber tracheid'},
#  {'parent': 'septate fiber cell', 'child': 'septate fiber tracheid'},
#  {'parent': 'xylem fiber cell', 'child': 'septate fiber tracheid'},
#  {'parent': 'plant fiber cell', 'child': 'septate fiber tracheid'},
#  {'parent': 'libriform fiber cell', 'child': 'septate libriform fiber cell'},
#  {'parent': 'septate fiber cell', 'child': 'septate libriform fiber cell'},
#  {'parent': 'xylem fiber cell', 'child': 'septate libriform fiber cell'},
#  {'parent': 'plant fiber cell', 'child': 'septate libriform fiber cell'},
#  {'parent': 'phloem fiber cell', 'child': 'septate phloem fiber cell'},
#  {'parent': 'septate fiber cell', 'child': 'septate phloem fiber cell'},
#  {'parent': 'plant fiber cell', 'child': 'septate phloem fiber cell'},
#  {'parent': 'inflorescence emergence stage',
#   'child': 'IE.00 inflorescence tip just visible above flag leaf sheath stage'},
#  {'parent': 'inflorescence emergence stage',
#   'child': 'IE.02 1/2 of inflorescence emerged from flag leaf sheath stage'},
#  {'parent': 'inflorescence emergence stage',
#   'child': 'IE.04 inflorescence fully emerged from flag leaf sheath stage'},
#  {'parent': 'root development stage',
#   'child': '1 root primordium formation stage'},
#  {'parent': 'root development stage',
#   'child': '2 root meristem formation stage'},
#  {'parent': 'root development stage',
#   'child': '3 establishment of tissue systems stage'},
#  {'parent': 'root development stage', 'child': '4 root elongation stage'},
#  {'parent': 'root development stage', 'child': '5 root hair formation stage'},
#  {'parent': 'root development stage', 'child': 'coleorhiza emergence stage'},
#  {'parent': 'root development stage', 'child': 'radicle emergence stage'},
#  {'parent': 'root development stage', 'child': 'root cap formation stage'},
#  {'parent': 'root development stage',
#   'child': 'root cortex differentiation stage'},
#  {'parent': 'root development stage',
#   'child': 'root vascular cylinder differentiation stage'},
#  {'parent': 'root development stage',
#   'child': 'primary root primordium formation stage'},
#  {'parent': 'root development stage',
#   'child': 'lateral root primordium formation stage'},
#  {'parent': '1 root primordium formation stage',
#   'child': 'primary root primordium formation stage'},
#  {'parent': '1 root primordium formation stage',
#   'child': 'lateral root primordium formation stage'},
#  {'parent': 'procambium', 'child': 'root procambium'},
#  {'parent': 'procambium', 'child': 'shoot procambium'},
#  {'parent': 'shoot procambium', 'child': 'branch procambium'},
#  {'parent': 'shoot procambium', 'child': 'leaf procambium'},
#  {'parent': 'shoot procambium', 'child': 'shoot axis procambium'},
#  {'parent': 'shoot axis procambium', 'child': 'stem procambium'},
#  {'parent': 'megasporangium', 'child': 'nucellus'},
#  {'parent': 'integument epidermis', 'child': 'inner integument epidermis'},
#  {'parent': 'integument epidermis', 'child': 'outer integument epidermis'},
#  {'parent': 'tuber axillary shoot', 'child': 'aerial tuber axillary shoot'},
#  {'parent': 'tuber axillary shoot',
#   'child': 'subterranean tuber axillary shoot'},
#  {'parent': 'root emergence stage', 'child': 'crown root emergence stage'},
#  {'parent': 'ground meristem', 'child': 'root system ground meristem'},
#  {'parent': 'ground meristem', 'child': 'shoot system ground meristem'},
#  {'parent': 'root', 'child': 'basal root'},
#  {'parent': 'root', 'child': 'shoot-borne internode root'},
#  {'parent': 'upper glume', 'child': 'upper glume of ear spikelet'},
#  {'parent': 'upper glume', 'child': 'upper glume of tassel spikelet'},
#  {'parent': 'upper glume of ear spikelet',
#   'child': 'upper glume of pedicellate spikelet of ear'},
#  {'parent': 'upper glume of ear spikelet',
#   'child': 'upper glume of sessile spikelet of ear'},
#  {'parent': 'upper glume of tassel spikelet',
#   'child': 'upper glume of pedicellate spikelet of tassel'},
#  {'parent': 'upper glume of tassel spikelet',
#   'child': 'upper glume of sessile spikelet of tassel'},
#  {'parent': 'upper glume',
#   'child': 'upper glume of pedicellate spikelet of ear'},
#  {'parent': 'upper glume', 'child': 'upper glume of sessile spikelet of ear'},
#  {'parent': 'upper glume',
#   'child': 'upper glume of pedicellate spikelet of tassel'},
#  {'parent': 'upper glume',
#   'child': 'upper glume of sessile spikelet of tassel'},
#  {'parent': 'vascular leaf initiation stage',
#   'child': 'vascular leaf anlagen formation stage'},
#  {'parent': 'vascular leaf initiation stage',
#   'child': 'vascular leaf primordium formation stage'},
#  {'parent': 'vascular leaf primordium formation stage',
#   'child': 'vascular leaf primordium polarity determination stage'},
#  {'parent': 'locule', 'child': 'anther locule'},
#  {'parent': 'locule', 'child': 'fruit locule'},
#  {'parent': 'locule', 'child': 'plant ovary locule'},
#  {'parent': 'locule', 'child': 'sporangium locule'},
#  {'parent': 'sporangium locule', 'child': 'anther locule'},
#  {'parent': 'plant ovary locule', 'child': 'fruit locule'},
#  {'parent': 'lateral root primordium',
#   'child': 'non-pericyclic lateral root primordium'},
#  {'parent': 'lateral root primordium',
#   'child': 'pericyclic lateral root primordium'},
#  {'parent': 'sieve tube element',
#   'child': 'primary phloem sieve tube element'},
#  {'parent': 'sieve tube element',
#   'child': 'secondary phloem sieve tube element'},
#  {'parent': 'reproductive shoot system development stage',
#   'child': 'flower development stage'},
#  {'parent': 'reproductive shoot system development stage',
#   'child': 'flowering stage'},
#  {'parent': 'reproductive shoot system development stage',
#   'child': 'flower meristem transition stage'},
#  {'parent': 'flower development stage', 'child': 'flowering stage'},
#  {'parent': 'flower development stage',
#   'child': 'flower meristem transition stage'},
#  {'parent': 'laticifer cell', 'child': 'articulated laticifer cell'},
#  {'parent': 'plant spore', 'child': 'megaspore'},
#  {'parent': 'plant spore', 'child': 'microspore'},
#  {'parent': 'megaspore', 'child': 'degenerate megaspore'},
#  {'parent': 'megaspore', 'child': 'functional megaspore'},
#  {'parent': 'fruit pedicel', 'child': 'infructescence fruit pedicel'},
#  {'parent': 'storage parenchyma', 'child': 'tuber storage parenchyma'},
#  {'parent': 'storage parenchyma', 'child': 'seed storage parenchyma'},
#  {'parent': 'tuber storage parenchyma',
#   'child': 'aerial tuber storage parenchyma'},
#  {'parent': 'tuber storage parenchyma',
#   'child': 'subterranean tuber storage parenchyma'},
#  {'parent': 'seed storage parenchyma', 'child': 'endosperm parenchyma'},
#  {'parent': 'embryo root', 'child': 'radicle'},
#  {'parent': 'radicle', 'child': 'seedling radicle'},
#  {'parent': 'branch', 'child': 'branch tendril'},
#  {'parent': 'branch', 'child': 'gametophore branch'},
#  {'parent': 'branch', 'child': 'stolon'},
#  {'parent': 'leaf stomatal complex', 'child': 'leaf abaxial stomatal complex'},
#  {'parent': 'leaf stomatal complex', 'child': 'leaf adaxial stomatal complex'},
#  {'parent': 'leaf rachis', 'child': 'leaf rachis tendril'},
#  {'parent': 'microsporophyll', 'child': 'stamen'},
#  {'parent': 'stamen', 'child': 'staminode'},
#  {'parent': 'microsporophyll', 'child': 'staminode'},
#  {'parent': 'lateral leaf vein', 'child': 'secondary leaf vein'},
#  {'parent': 'booting stage', 'child': 'BO.00 booting begins stage'},
#  {'parent': 'booting stage', 'child': 'BO.02 mid boot stage'},
#  {'parent': 'booting stage', 'child': 'BO.03 late boot stage'},
#  {'parent': 'booting stage', 'child': 'BO.04 flag leaf sheath opening stage'},
#  {'parent': 'hypocotyl-root junction',
#   'child': 'embryo hypocotyl-root junction'},
#  {'parent': 'hypocotyl-root junction',
#   'child': 'seedling hypocotyl-root junction'},
#  {'parent': 'glandular trichome', 'child': 'lupulin gland'},
#  {'parent': 'shoot-borne root', 'child': 'crown root'},
#  {'parent': 'shoot-borne root', 'child': 'prop root'},
#  {'parent': 'shoot-borne root', 'child': 'shoot-borne nodal root'},
#  {'parent': 'shoot-borne root', 'child': 'shoot-borne root spine'},
#  {'parent': 'passage cell', 'child': 'endodermal passage cell'},
#  {'parent': 'passage cell', 'child': 'exodermal passage cell'},
#  {'parent': 'spermatogenous cell', 'child': 'generative cell'},
#  {'parent': 'axillary bud meristem',
#   'child': 'shoot axis tuber axillary bud meristem'},
#  {'parent': 'axillary bud meristem',
#   'child': 'subterranean tuber axillary bud meristem'},
#  {'parent': 'inflorescence development stage',
#   'child': 'inflorescence initiation stage'},
#  {'parent': 'plant cuticle', 'child': 'plant cuticle ridge'},
#  {'parent': 'gynoecium development stage',
#   'child': 'gynoecium differentiation and expansion stage'},
#  {'parent': 'gynoecium development stage',
#   'child': 'carpel primordium visible stage'},
#  {'parent': 'gynoecium development stage',
#   'child': 'closure of carpel(s) stage'},
#  {'parent': 'gynoecium development stage', 'child': 'ovule development stage'},
#  {'parent': 'ovule development stage',
#   'child': 'ovule primordium visible stage'},
#  {'parent': 'gynoecium differentiation and expansion stage',
#   'child': 'stigma cell differentiation stage'},
#  {'parent': 'gynoecium', 'child': 'gynoecium ridge'},
#  {'parent': 'gynoecium development stage',
#   'child': 'stigma cell differentiation stage'},
#  {'parent': 'gynoecium development stage',
#   'child': 'ovule primordium visible stage'},
#  {'parent': 'intercalary meristem', 'child': 'leaf intercalary meristem'},
#  {'parent': 'intercalary meristem', 'child': 'stem intercalary meristem'},
#  {'parent': 'ovule differentiation and expansion stage',
#   'child': 'integument initiation stage'},
#  {'parent': 'peduncle', 'child': 'ear peduncle'},
#  {'parent': 'collective leaf structure', 'child': 'rosette'},
#  {'parent': 'anther wall endothecium', 'child': 'microsporangium endothecium'}]

# %%
with open("predictions_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

# %%
import json

# Save final_clusters_list to JSON file
with open("final_result_keywords_c_po.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

print("Clusters saved to final_clusters.json ✅")
# Out:
# Clusters saved to final_clusters.json ✅

# %%
with open("_pairs.jsonl", "w", encoding="utf-8") as f:
    for entry in final_result:
        json.dump(entry, f)
        f.write("\n")
