# %%
import json
def load_json(data_path):
    with open(data_path, "r", encoding="utf-8") as file_1:
        data = json.load(file_1)
    return data

# %%
data = load_json("MatOnto/train/matonto_train_pairs.json")

# %%
len(data), data[:5]
# Out:
# (840,
#  [{'ID': 'TR_7e0265b4', 'parent': 'measured property', 'child': 'area'},
#   {'ID': 'TR_75953334', 'parent': 'element', 'child': 'Lanthanum'},
#   {'ID': 'TR_ffd73cfe',
#    'parent': 'measured property',
#    'child': 'molecular mass'},
#   {'ID': 'TR_8f425977', 'parent': 'measured property', 'child': 'frequency'},
#   {'ID': 'TR_69a9e06b', 'parent': 'element', 'child': 'Europium'}])

# %%
from collections import defaultdict

class UnionFind:
    def __init__(self):
        self.parent = {}

    def find(self, x):
        # Path compression
        if x != self.parent.setdefault(x, x):
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        self.parent[self.find(x)] = self.find(y)

def build_clusters(relationships):
    uf = UnionFind()
    
    for rel in relationships:
        parent = rel["parent"]
        child = rel["child"]
        uf.union(parent, child)

    clusters = defaultdict(set)
    for term in set([item for rel in relationships for item in (rel["parent"], rel["child"])]):
        root = uf.find(term)
        clusters[root].add(term)

    # Add isolated nodes (no parent/child relationship)
    all_terms = set()
    for rel in relationships:
        all_terms.add(rel["parent"])
        all_terms.add(rel["child"])
    for term in all_terms:
        if term not in uf.parent:
            clusters[term].add(term)

    return list(clusters.values())

# %%
clusters = build_clusters(data)

# %%
len(clusters)
# Out:
# 29

# %%
clusters
# Out:
# [{'Actinium',
#   'Arsenic',
#   'Barium',
#   'Beryllium',
#   'Boron',
#   'Bromine',
#   'Cadmium',
#   'Caesium',
#   'Calcium',
#   'Californium',
#   'Cerium',
#   'Curium',
#   'Darmstadtium',
#   'Dysprosium',
#   'Einsteinium',
#   'Erbium',
#   'Europium',
#   'Fluorine',
#   'Gadolinium',
#   'Germanium',
#   'Gold',
#   'Hafnium',
#   'Holmium',
#   'Hydrogen',
#   'Iron',
#   'Krypton',
#   'Lanthanum',
#   'Lawrencium',
#   'Lead',
#   'Lithium',
#   'Lutetium',
#   'Magnesium',
#   'Meitnerium',
#   'Mercury',
#   'Molybdenum',
#   'Osmium',
#   'Oxygen',
#   'Palladium',
#   'Phosphorus',
#   'Plutonium',
#   'Praseodymium',
#   'Promethium',
#   'Radium',
#   'Radon',
#   'Rubidium',
#   'Ruthenium',
#   'Rutherfordium',
#   'Scandium',
#   'Seaborgium',
#   'Selenium',
#   'Silver',
#   'Sodium',
#   'Strontium',
#   'Sulfur',
#   'Tellurium',
#   'Terbium',
#   'Tin',
#   'Titanium',
#   'Tungsten',
#   'Ununbium',
#   'Ununhexium',
#   'Ununnilium',
#   'Ununoctium',
#   'Ununquadium',
#   'Ununseptium',
#   'Ununtrium',
#   'Uranium',
#   'Vanadium',
#   'Xenon',
#   'Yttrium',
#   'Zinc',
#   'Zirconium',
#   'element'},
#  {'Actinium Atom',
#   'Alloy',
#   'Aluminium Atom',
#   'Americium Atom',
#   'Argon Atom',
#   'Arsenic Atom',
#   'Astatine Atom',
#   'Base',
#   'Bismuth Atom',
#   'Boron Atom',
#   'Cadmium Atom',
#   'Caesium Atom',
#   'Calcium Atom',
#   'Californium Atom',
#   'Cerium Atom',
#   'Chemical Class',
#   'Chemical Family',
#   'Chemical Formula',
#   'Cobalt Atom',
#   'Cofactor',
#   'Concentration',
#   'Curium Atom',
#   'DerivedUnit',
#   'Electronegativity',
#   'Empirical Formula',
#   'Erbium Atom',
#   'Europium Atom',
#   'Fermium Atom',
#   'Francium Atom',
#   'Gallium Atom',
#   'Germanium Atom',
#   'Gibbs free energy',
#   'HalogenAtom',
#   'Hardness',
#   'Hassium Atom',
#   'Helium Atom',
#   'Helmholtz free energy',
#   'HeteroAtom',
#   'Holmium Atom',
#   'Hydrogen Atom',
#   'Indium Atom',
#   'Iridium Atom',
#   'Iron Atom',
#   'Krypton Atom',
#   'Lattice Parameter',
#   'Lawrencium Atom',
#   'Lithium Atom',
#   'Lutetium Atom',
#   'Magnesium Atom',
#   'Manganese Atom',
#   'Melting Point',
#   'Mendelevium Atom',
#   'Mercury Atom',
#   'Molecular Formula',
#   'MolecularQuality',
#   'MoleculeComponentCount',
#   'Oxygen Atom',
#   'Palladium Atom',
#   'Phase Equilibrium',
#   'Platinum Atom',
#   'Polonium Atom',
#   'Potassium Atom',
#   'Praseodymium Atom',
#   'Product',
#   'Protactinium Atom',
#   'Radium Atom',
#   'Radon Atom',
#   'Reactant',
#   'Reagent',
#   'Rhenium Atom',
#   'Rhodium Atom',
#   'Rubidium Atom',
#   'Samarium Atom',
#   'Selenium Atom',
#   'Silicon Atom',
#   'Solution',
#   'Stress',
#   'Strontium Atom',
#   'Structure Type',
#   'Sulfur Atom',
#   'Tantalum Atom',
#   'Tellurium Atom',
#   'Temperature Range',
#   'Temperature Range Lower Bound',
#   'Temperature Range Upper Bound',
#   'Terbium Atom',
#   'Thallium Atom',
#   'Thermal Expansion',
#   'Thulium Atom',
#   'Tin Atom',
#   'Tungsten Atom',
#   'Ununbium Atom',
#   'Ununhexium Atom',
#   'Ununnilium Atom',
#   'Ununoctium Atom',
#   'Ununpentium Atom',
#   'Ununquadium Atom',
#   'Ununseptium Atom',
#   'Ununtrium Atom',
#   'Unununium Atom',
#   'Uranium Atom',
#   'Vanadium Atom',
#   'Xenon Atom',
#   'Ytterbium Atom',
#   'Yttrium Atom',
#   'absorbed dose',
#   'absorbed dose rate',
#   'absorbed dose rate unit',
#   'absorbed dose unit',
#   'acceleration',
#   'acceleration unit',
#   'acid',
#   'acidity',
#   'acyclic',
#   'acyl group',
#   'allotrope',
#   'amide group',
#   'amount of substance',
#   'amount of substance concentration',
#   'amount of substance concentration unit',
#   'angle',
#   'angle unit',
#   'angular acceleration',
#   'angular acceleration unit',
#   'angular velocity',
#   'angular velocity unit',
#   'area',
#   'area density',
#   'area density unit',
#   'area unit',
#   'aromatic',
#   'aromatic ring',
#   'aromaticity',
#   'aryl',
#   'atom',
#   'atom property',
#   'atto scaled unit',
#   'band gap',
#   'binary compound',
#   'capacitance',
#   'capacitance unit',
#   'carbon group',
#   'carbonyl group',
#   'carboxylic acid group',
#   'catalyst',
#   'catalytic activity',
#   'catalytic activity unit',
#   'catalytic concentration',
#   'catalytic concentration unit',
#   'centi scaled unit',
#   'chemical quality',
#   'chemical substance',
#   'chiral center',
#   'closed thermodynamic system',
#   'complex',
#   'component count',
#   'compound',
#   'concentration unit',
#   'conduction',
#   'conduction unit',
#   'continuant',
#   'count',
#   'crystal system',
#   'currency unit',
#   'cyclic',
#   'cyclicity',
#   'deci scaled unit',
#   'defined stereo bond count',
#   'deka scaled unit',
#   'density',
#   'density unit',
#   'dependent_continuant',
#   'disposition',
#   'dose equivalent unit',
#   'dynamic viscosity unit',
#   'elastic modulus',
#   'electric charge',
#   'electric charge density',
#   'electric charge density unit',
#   'electric conduction',
#   'electric conduction unit',
#   'electric current',
#   'electric current density',
#   'electric current density unit',
#   'electric current unit',
#   'electric field strength',
#   'electric field strength unit',
#   'electric flux density',
#   'electric flux density unit',
#   'electric resistance',
#   'electric resistance unit',
#   'electromagnetic radation',
#   'electromagnetic radiation unit',
#   'energy',
#   'energy density unit',
#   'energy unit',
#   'enthalpy',
#   'enthalpy unit',
#   'entropy',
#   'entropy unit',
#   'equivalent dose',
#   'ester group',
#   'exa scaled unit',
#   'exposure',
#   'exposure unit',
#   'femto scaled unit',
#   'fiat_object_part',
#   'flexural modulus',
#   'flexural strength',
#   'force',
#   'force unit',
#   'fracture toughness',
#   'frequency',
#   'frequency unit',
#   'function',
#   'general sulfinic acid group',
#   'giga scaled unit',
#   'grain size',
#   'hecto scaled unit',
#   'homo cyclic ring',
#   'homocyclic',
#   'homogeneous mixture',
#   'hybridization',
#   'hydrogen bond acceptor count',
#   'hydrogen bond donor count',
#   'hydrophobic',
#   'hydrophobicity',
#   'identifier',
#   'illuminance',
#   'illuminance unit',
#   'imine group',
#   'implicit valence',
#   'independent_continuant',
#   'inductance',
#   'inductance unit',
#   'intensive property',
#   'internal energy',
#   'ionic compound',
#   'irradiance',
#   'irradiance unit',
#   'isolated thermodynamic system',
#   'isomer',
#   'isomeric smiles',
#   'isotopic atom count',
#   'ketone group',
#   'kilo scaled unit',
#   'length',
#   'length unit',
#   'linear density',
#   'linear density unit',
#   'linear molecular geometry',
#   'luminance',
#   'luminance unit',
#   'luminous flux',
#   'luminous flux unit',
#   'luminous intensity',
#   'magnetic field strength',
#   'magnetic flux',
#   'magnetic flux density',
#   'magnetic flux density unit',
#   'magnetic flux unit',
#   'mass',
#   'mass density',
#   'mass unit',
#   'material quality',
#   'measured property',
#   'metal complex',
#   'methyl group',
#   'milli scaled unit',
#   'mixture',
#   'molality',
#   'molality unit',
#   'molar energy',
#   'molar energy unit',
#   'molar entropy',
#   'molar entropy unit',
#   'molar mass',
#   'molar mass unit',
#   'molecular center',
#   'molecular formula',
#   'molecular geometry',
#   'molecular mass',
#   'molecular mass unit',
#   'molecule',
#   'moment of force',
#   'moment of force unit',
#   'mulliken electronegativity',
#   'nano scaled unit',
#   'neutral acidity',
#   'neutral phase',
#   'non aromatic',
#   'non aromatic ring',
#   'object',
#   'object_boundary',
#   'octahedral molecular geometry',
#   'open thermodynamic system',
#   'organic group',
#   'organic nitrogen group',
#   'organic phosphate group',
#   'organic sulfur group',
#   'pH',
#   'pH unit',
#   'partition coefficient',
#   'parts per notation',
#   'pauling electronegativity',
#   'permeability',
#   'permeability unit',
#   'permittivity',
#   'permittivity unit',
#   'peta scaled unit',
#   'pico scaled unit',
#   'plane angle',
#   'plane angle unit',
#   'polar surface area',
#   'potential difference',
#   'potential difference unit',
#   'power',
#   'power unit',
#   'precipitate',
#   'pressure',
#   'pressure unit',
#   'pure substance',
#   'quality',
#   'racemic mixture',
#   'radiance',
#   'radiance unit',
#   'radiant intensity',
#   'radiant intensity unit',
#   'radiation',
#   'radiation unit',
#   'radical',
#   'radical center',
#   'radioactivity activity',
#   'realizable_entity',
#   'ring',
#   'rotatable bond count',
#   'scaled unit',
#   'secondary amine group',
#   'shifted unit',
#   'site',
#   'solid angle',
#   'solid angle unit',
#   'solvent',
#   'source',
#   'space group number',
#   'space group property',
#   'spatial_region',
#   'specific energy',
#   'specific energy unit',
#   'specific entropy',
#   'specific entropy unit',
#   'specific heat',
#   'specific volume',
#   'specific volume unit',
#   'square planar molecular geometry',
#   'square pyramidal molecular geometry',
#   'structural isomer',
#   'substrate',
#   'sulfonic acid derivative group',
#   'sulfonic acid group',
#   'sulfoxide group',
#   'surface tension',
#   'surface tension unit',
#   'tautomer count',
#   'temperature',
#   'temperature unit',
#   'tera scaled unit',
#   'tertiary amine group',
#   'thermal conduction',
#   'thermal conduction unit',
#   'thermodynamic system',
#   'thiol group',
#   'three_dimensional_region',
#   'time',
#   'topological complex',
#   'trigonal bipyramidal molecular geometry',
#   'trigonal pyramidal molecular geometry',
#   'two_dimensional_region',
#   'ultimate tensile strength',
#   'undefined stereo atom count',
#   'undefined stereo bond count',
#   'unit',
#   'velocity',
#   'velocity unit',
#   'viscosity',
#   'volume',
#   'volume density unit',
#   'volume unit',
#   'wavenumber',
#   'wavenumber unit',
#   'weibull modulus',
#   'yocto scaled unit',
#   'yotta scaled unit',
#   'zepto scaled unit',
#   'zero_dimensional_region'},
#  {'non polar', 'polar', 'polarity'},
#  {'ChemicalDegradationPathway',
#   'ChemicalSynthesisPathway',
#   'acid-base reaction',
#   'aromatic bond',
#   'bond',
#   'catalyzed reaction',
#   'cation pi interaction',
#   'chemical interaction',
#   'chemical reaction',
#   'chemical reaction pathway',
#   'decomposition reaction',
#   'dipole-dipole interaction',
#   'double bond',
#   'electronic interaction',
#   'electrostatic interaction',
#   'fiat_process_part',
#   'hydrogen bond',
#   'hydrophobic interaction',
#   'inorganic reaction',
#   'intermolecular interaction',
#   'ionic bond',
#   'isomerization',
#   'molecular complex assembly',
#   'molecular complex disassociation',
#   'molecular complex formation',
#   'organic reaction',
#   'polar bond',
#   'process',
#   'process_aggregate',
#   'processual_entity',
#   'redox reaction',
#   'single bond',
#   'stereo bond',
#   'stereo hash bond',
#   'stereo wedge bond',
#   'synthesis reaction',
#   'triple bond'},
#  {'unit raised to power',
#   'unit raised to power of negative one',
#   'unit raised to power of negative three',
#   'unit raised to power of negative two',
#   'unit raised to power of one',
#   'unit raised to power of three',
#   'unit raised to power of two'},
#  {'alkali metal',
#   'alkaline earth metal',
#   'boron group element',
#   'chalcogen',
#   'd-block element',
#   'f-block element',
#   'g-block element',
#   'group 1 element',
#   'group 10 element',
#   'group 11 element',
#   'group 13 element',
#   'group 14 element',
#   'group 15 element',
#   'group 16 element',
#   'group 17 element',
#   'group 18 element',
#   'group 4 element',
#   'group 7 element',
#   'group 9 element',
#   'group element',
#   'halogen',
#   'lanthanide',
#   'metalloid',
#   'nitrogen group element',
#   'noble gas',
#   'non metal',
#   'p-block element',
#   'period 1 element',
#   'period 2 element',
#   'period 3 element',
#   'period 4 element',
#   'period 5 element',
#   'period 6 element',
#   'period 7 element',
#   'period element',
#   'periodic block',
#   'periodic table element',
#   'series element',
#   'transition metal'},
#  {'aggregated carbon nanorods',
#   'carbon allotrope',
#   'chaoite',
#   'fullerene',
#   'glassy carbon',
#   'lonsdaleite'},
#  {'acyl compound',
#   'aldehyde',
#   'amine',
#   'carbonyl compound',
#   'imine',
#   'ketone',
#   'organic compound',
#   'organic sulfur compound',
#   'primary amine',
#   'tertiary amine'},
#  {'connected_spatiotemporal_region',
#   'entity',
#   'occurrent',
#   'spatiotemporal_instant',
#   'spatiotemporal_interval',
#   'spatiotemporal_region'},
#  {'chemical phase',
#   'common chemical phase',
#   'crystalline phase',
#   'ferromagnetic phase',
#   'gas phase',
#   'liquid crystal phase',
#   'paramagnetic phase',
#   'plasma phase',
#   'solid phase',
#   'strange matter phase',
#   'super solid phase',
#   'uncommon chemical phase'},
#  {'addition reaction',
#   'electrophilic addition reaction',
#   'nucleophilic addition reaction',
#   'polar addition reaction'},
#  {'conformer', 'diastereomer', 'rotamer'},
#  {'extensive property', 'heat capacity'},
#  {'Wikipedia',
#   'anti conformation',
#   'anticlinal conformation',
#   'chemical conformation',
#   'gauche conformation',
#   'periplanar conformation'},
#  {'ceramics',
#   'composites',
#   'elastomers',
#   'glasses',
#   'material category',
#   'metals',
#   'nanomaterials',
#   'polymers',
#   'refactory'},
#  {'Enantiomer', 'stereoisomer'},
#  {'AcylBromideGroup',
#   'acyl chloride group',
#   'acyl halide group',
#   'acyl iodide group'},
#  {'acyl bromide', 'acyl chloride', 'acyl halide', 'acyl iodide'},
#  {'displacement reaction', 'single displacement reaction'},
#  {'connected_temporal_region', 'temporal_instant', 'temporal_interval'},
#  {'name', 'systematic name', 'traditional name'},
#  {'D isomer',
#   'D or L isomer',
#   'OpticalIsomer',
#   'R isomer',
#   'R or S isomer',
#   'S isomer'},
#  {'covalent bond', 'disulfide bond'},
#  {'Hardness Range',
#   'Hardness Range Lower Bound',
#   'Hardness Range Upper Bound'},
#  {'Ion', 'anion', 'cation'},
#  {'Ceramic Material', 'material'},
#  {'cis isomer', 'cis/trans isomer', 'trans isomer'},
#  {'free radical addition', 'non polar addition reaction'},
#  {'chemical agent', 'oxidizing agent', 'reducing agent'}]

# %%
# Load a text file in Python
final_content = []
with open("MatOnto/test/matonto_test_types.txt", "r", encoding="utf-8") as f:
    contents = f.readlines()
    for content in contents:
        final_content.append(content.strip('\n'))


print(contents[:500])  # Print first 500 characters
# Out:
# ['carbon allotrope\n', 'Silicon\n', 'specific volume\n', 'Lattice Parameter B\n', 'element\n', 'carbon group\n', 'Carbon\n', 'addition reaction\n', 'Hardness Range Lower Bound\n', 'carboxylic acid\n', 'bose einstein condensate\n', 'energy density unit\n', 'molar energy unit\n', 'Antimony Atom\n', 'parts per notation\n', 'conduction\n', 'organic compound\n', 'displacement reaction\n', 'super fluid phase\n', 'exposure unit\n', 'point group\n', 'object_aggregate\n', 'pH\n', 'flexural strength\n', 'role\n', 'process\n', 'hydrophilic\n', 'electric charge density\n', 'Tantalum\n', 'group 6 element\n', 'Barium Atom\n', 'Chromium Atom\n', 'unit\n', 'Lattice Parameter A\n', 'inorganic reaction\n', 'catalytic activity\n', 'Ununpentium\n', 'radiant intensity\n', 'area density\n', 'Ytterbium\n', 'hydrocarbon\n', 'partition coefficient\n', 'secondary amine\n', 'organic reaction\n', 'elastic modulus\n', 'polarity\n', 'acid-base reaction\n', 'youngs modulus\n', 'Iridium\n', 'electric current\n', 'amount of substance unit\n', 'catalytic concentration unit\n', 'Antimony\n', 'three_dimensional_region\n', 'Hassium\n', 'volume density unit\n', 'ring\n', 'Fluorine Atom\n', 'electric field strength unit\n', 'covalent bond\n', 'syn conformation\n', 'Cobalt\n', 'polymers\n', 'ionic bond\n', 'molecular geometry\n', 'group 12 element\n', 'Chromium\n', 'molar entropy\n', 'radiant intensity unit\n', 'information unit\n', 'Stress\n', 'canonical smiles\n', 'specific energy\n', 'Zinc Atom\n', 'irradiance unit\n', 'graphite\n', 'secondary amine group\n', 'uncommon chemical phase\n', 'D or L isomer\n', 'solute\n', 'molecule\n', 'Hardness Range\n', 'Helium\n', 'processual_context\n', 'carbon group element\n', 'energy density\n', 'stereoisomer\n', 'nonpolar solvent\n', 'realizable_entity\n', 'time unit\n', 'allotrope\n', 'temporal_region\n', 'electronic interaction\n', 'band gap\n', 'chemical agent\n', 'Berkelium\n', 'chemical phase\n', 'electric resistance unit\n', 'Rutherfordium Atom\n', 'Copper Atom\n', 'Temperature Range Lower Bound\n', 'angular acceleration\n', 'connected_temporal_region\n', 'Concentration\n', 'one_dimensional_region\n', 'Rhodium\n', 'ether\n', 'CAS name\n', 'acyl halide\n', 'compound\n', 'Thorium\n', 'Hafnium Atom\n', 'intensive property\n', 'group 8 element\n', 'velocity unit\n', 'series element\n', 'Lattice Parameter C\n', 'magnetic flux\n', 'organic group\n', 'luminous intensity unit\n', 'plane angle\n', 'Hardness\n', 'electromagnetic radiation unit\n', 'Scandium Atom\n', 'angle unit\n', 'amine group\n', 'Carbon Atom\n', 'Molybdenum Atom\n', 'Berkelium Atom\n', 'cyclic\n', 'hall\n', 'pubchem cid\n', 'atom\n', 'Lead Atom\n', 'clinal conformation\n', 'bulk modulus\n', 'ether group\n', 'amine\n', 'occurrent\n', 'temperature\n', 'Technetium Atom\n', 'diastereomer\n', 'luminous flux unit\n', 'luminance\n', 'OpticalIsomer\n', 'Polonium\n', 'group element\n', 'electric current density unit\n', 'scattered_spatiotemporal_region\n', 'Ruthenium Atom\n', 'aldehyde group\n', 'Technetium\n', 'Temperature Range\n', 'Sodium Atom\n', 'spatial_region\n', 'energy\n', 'material\n', 'chemical substance\n', 'scattered_temporal_region\n', 'amide\n', 'actinide\n', 'Francium\n', 'band gap unit\n', 'radioactivity activity\n', 'Chlorine\n', 'Copper\n', 'process_boundary\n', 'heat capacity\n', 'pressure\n', 'illuminance\n', 'hydrophobicity\n', 'entity\n', 's-block element\n', 'isomer\n', 'Bohrium Atom\n', 'Beryllium Atom\n', 'MoleculeComponentCount\n', 'power\n', 'processual_entity\n', 'Indium\n', 'Dubnium\n', 'Manganese\n', 'continuant\n', 'area\n', 'Roentgenium\n', 'specific volume unit\n', 'thermal conduction unit\n', 'common chemical phase\n', 'wavenumber unit\n', 'acyl halide group\n', 'spatiotemporal_region\n', 'object\n', 'molar energy\n', 'magnetic flux density\n', 'electric charge density unit\n', 'electric charge unit\n', 'Dysprosium Atom\n', 'scaled unit\n', 'carbon nanofoam\n', 'fermionic condensate\n', 'ultimate tensile strength\n', 'staggered confor ...

# %%
len(contents), contents[0]
# Out:
# (370, 'carbon allotrope\n')

# %%
len(final_content), final_content[0]
# Out:
# (370, 'carbon allotrope')

# %%
# Step 3: Assign function
from collections import Counter
from tqdm.notebook import tqdm
def assign_term_to_cluster(new_term, clusters):
    new_words = new_term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for term in cluster:
            for word in term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)
    
    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]
    
    if max_score == 0:
        return None  # No match
    return best_cluster_index

# Step 4: Assign all new terms
final_clusters = [set(cluster) for cluster in clusters]  # copy original clusters

for term in tqdm(final_content):
    assigned_idx = assign_term_to_cluster(term, final_clusters)
    if assigned_idx is not None:
        final_clusters[assigned_idx].add(term)
    else:
        # Create new cluster if no match found
        final_clusters.append(set([term]))

# Step 5: Convert to list of lists and return
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

# Display final clusters
for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")
# Out:
#   0%|          | 0/370 [00:00<?, ?it/s]
# Cluster 1: ['Actinium', 'Arsenic', 'Barium', 'Beryllium', 'Boron', 'Bromine', 'Cadmium', 'Caesium', 'Calcium', 'Californium', 'Cerium', 'Curium', 'Darmstadtium', 'Dysprosium', 'Einsteinium', 'Erbium', 'Europium', 'Fluorine', 'Gadolinium', 'Germanium', 'Gold', 'Hafnium', 'Holmium', 'Hydrogen', 'Iron', 'Krypton', 'Lanthanum', 'Lawrencium', 'Lead', 'Lithium', 'Lutetium', 'Magnesium', 'Meitnerium', 'Mercury', 'Molybdenum', 'Osmium', 'Oxygen', 'Palladium', 'Phosphorus', 'Plutonium', 'Praseodymium', 'Promethium', 'Radium', 'Radon', 'Rubidium', 'Ruthenium', 'Rutherfordium', 'Scandium', 'Seaborgium', 'Selenium', 'Silver', 'Sodium', 'Strontium', 'Sulfur', 'Tellurium', 'Terbium', 'Tin', 'Titanium', 'Tungsten', 'Ununbium', 'Ununhexium', 'Ununnilium', 'Ununoctium', 'Ununquadium', 'Ununseptium', 'Ununtrium', 'Uranium', 'Vanadium', 'Xenon', 'Yttrium', 'Zinc', 'Zirconium', 'element']
# Cluster 2: ['Actinium Atom', 'Alloy', 'Aluminium', 'Aluminium Atom', 'Americium', 'Americium Atom', 'Antimony', 'Antimony Atom', 'Argon', 'Argon Atom', 'Arsenic Atom', 'Astatine', 'Astatine Atom', 'Barium Atom', 'Base', 'Berkelium Atom', 'Beryllium Atom', 'Bismuth', 'Bismuth Atom', 'Bohrium', 'Bohrium Atom', 'Boron Atom', 'Bromine Atom', 'Cadmium Atom', 'Caesium Atom', 'Calcium Atom', 'Californium Atom', 'Carbon Atom', 'Cerium Atom', 'Chemical Class', 'Chemical Family', 'Chemical Formula', 'Chlorine Atom', 'Chromium', 'Chromium Atom', 'Cobalt', 'Cobalt Atom', 'Cofactor', 'Concentration', 'Copper', 'Copper Atom', 'Curium Atom', 'DerivedUnit', 'Dubnium Atom', 'Dysprosium Atom', 'Einsteinium Atom', 'Electronegativity', 'Empirical Formula', 'Erbium Atom', 'Europium Atom', 'Fermium', 'Fermium Atom', 'Fluorine Atom', 'Francium', 'Francium Atom', 'Gadolinium Atom', 'Gallium', 'Gallium Atom', 'Germanium Atom', 'Gibbs free energy', 'Gold Atom', 'Hafnium Atom', 'HalogenAtom', 'Hardness', 'Hassium', 'Hassium Atom', 'Helium', 'Helium Atom', 'Helmholtz free energy', 'HeteroAtom', 'Holmium Atom', 'Hydrogen Atom', 'Indium', 'Indium Atom', 'Iodine Atom', 'Iridium', 'Iridium Atom', 'Iron Atom', 'Krypton Atom', 'Lanthanum Atom', 'Lattice Parameter', 'Lattice Parameter A', 'Lattice Parameter B', 'Lattice Parameter C', 'Lawrencium Atom', 'Lead Atom', 'Lithium Atom', 'Lutetium Atom', 'Magnesium Atom', 'Manganese', 'Manganese Atom', 'Meitnerium Atom', 'Melting Point', 'Mendelevium', 'Mendelevium Atom', 'Mercury Atom', 'Molecular Formula', 'MolecularQuality', 'MoleculeComponentCount', 'Molybdenum Atom', 'Osmium Atom', 'Oxygen Atom', 'Palladium Atom', 'Phase Equilibrium', 'Phosphorus Atom', 'Platinum', 'Platinum Atom', 'Plutonium Atom', 'Polonium', 'Polonium Atom', 'Potassium', 'Potassium Atom', 'Praseodymium Atom', 'Product', 'Promethium Atom', 'Protactinium', 'Protactinium Atom', 'Radium Atom', 'Radon Atom', 'Reactant', 'Reagent', 'Rhenium', 'Rhenium Atom', 'Rhodium', 'Rhodium Atom', 'Rubidium Atom', 'Ruthenium Atom', 'Rutherfordium Atom', 'Samarium', 'Samarium Atom', 'Scandium Atom', 'Seaborgium Atom', 'Selenium Atom', 'Silicon', 'Silicon Atom', 'Silver Atom', 'Sodium Atom', 'Solution', 'Stress', 'Strontium Atom', 'Structure Type', 'Sulfur Atom', 'Tantalum', 'Tantalum Atom', 'Technetium', 'Technetium Atom', 'Tellurium Atom', 'Temperature Range', 'Temperature Range Lower Bound', 'Temperature Range Upper Bound', 'Terbium Atom', 'Thallium', 'Thallium Atom', 'Thermal Expansion', 'Thorium Atom', 'Thulium', 'Thulium Atom', 'Tin Atom', 'Titanium Atom', 'Tungsten Atom', 'Ununbium Atom', 'Ununhexium Atom', 'Ununnilium Atom', 'Ununoctium Atom', 'Ununpentium', 'Ununpentium Atom', 'Ununquadium Atom', 'Ununseptium Atom', 'Ununtrium Atom', 'Unununium', 'Unununium Atom', 'Uranium Atom', 'Vanadium Atom', 'Xenon Atom', 'Ytterbium', 'Ytterbium Atom', 'Yttrium Atom', 'Zinc Atom', 'Zirconium Atom', 'absorbed dose', 'absorbed dose rate', 'absorbed dose rate unit', 'absorbed dose unit', 'acceleration', 'acceleration unit', 'acid', 'acidity', 'acyclic', 'acyl fluoride', 'acyl fluoride group', 'acyl group', 'acyl halide group', 'aldehyde group', 'allotrope', 'amide', 'amide group', 'amine', 'amine group', 'amount of substance', 'amount of substance concentration', 'amount of substance concentration unit', 'amount of substance unit', 'angle', 'angle unit', 'angular acceleration', 'angular acceleration unit', 'angular velocity', 'angular velocity unit', 'area', 'area density', 'area density unit', 'area unit', 'aromatic', 'aromatic ring', 'aromaticity', 'aryl', 'atom', 'atom property', 'atomic number', 'atto scaled unit', 'band gap', 'band gap unit', 'binary compound', 'bulk modulus', 'canonical smiles', 'capacitance', 'capacitance unit', 'carbon group', 'carbonyl group', 'carboxylic acid', 'carboxylic acid group', 'catalyst', 'catalytic activity', 'catalytic activity unit', 'catalytic concentration', 'catalytic concentration unit', 'centi scaled unit', 'chemical agent', ' ...
# Cluster 3: ['non polar', 'polar', 'polarity']
# Cluster 4: ['ChemicalDegradationPathway', 'ChemicalSynthesisPathway', 'acid-base reaction', 'addition reaction', 'aromatic bond', 'bond', 'catalyzed reaction', 'cation pi interaction', 'chemical interaction', 'chemical reaction', 'chemical reaction pathway', 'covalent bond', 'decomposition reaction', 'dipole-dipole interaction', 'displacement reaction', 'disulfide bond', 'double bond', 'electronic interaction', 'electrostatic interaction', 'fiat_process_part', 'hydrogen bond', 'hydrophobic interaction', 'inorganic reaction', 'intermolecular interaction', 'ionic bond', 'isomerization', 'molecular complex assembly', 'molecular complex disassociation', 'molecular complex formation', 'non polar addition reaction', 'organic reaction', 'polar bond', 'precipitation reaction', 'process', 'process_aggregate', 'processual_entity', 'redox reaction', 'single bond', 'stereo bond', 'stereo hash bond', 'stereo wedge bond', 'synthesis reaction', 'triple bond', "van der Waal's interaction"]
# Cluster 5: ['power', 'unit raised to power', 'unit raised to power of negative one', 'unit raised to power of negative three', 'unit raised to power of negative two', 'unit raised to power of one', 'unit raised to power of three', 'unit raised to power of two']
# Cluster 6: ['alkali metal', 'alkaline earth metal', 'boron group element', 'carbon group element', 'chalcogen', 'd-block element', 'element', 'f-block element', 'g-block element', 'group 1 element', 'group 10 element', 'group 11 element', 'group 12 element', 'group 13 element', 'group 14 element', 'group 15 element', 'group 16 element', 'group 17 element', 'group 18 element', 'group 2 element', 'group 3 element', 'group 4 element', 'group 5 element', 'group 6 element', 'group 7 element', 'group 8 element', 'group 9 element', 'group element', 'halogen', 'lanthanide', 'metalloid', 'nitrogen group element', 'noble gas', 'non metal', 'p-block element', 'period 1 element', 'period 2 element', 'period 3 element', 'period 4 element', 'period 5 element', 'period 6 element', 'period 7 element', 'period element', 'periodic block', 'periodic table element', 'poor metal', 's-block element', 'series element', 'transition metal']
# Cluster 7: ['Carbon', 'aggregated carbon nanorods', 'amorphous carbon', 'carbon allotrope', 'carbon nanofoam', 'chaoite', 'fullerene', 'glassy carbon', 'lonsdaleite']
# Cluster 8: ['acyl compound', 'aldehyde', 'amine', 'carbonyl compound', 'imine', 'ketone', 'organic compound', 'organic sulfur compound', 'primary amine', 'tertiary amine']
# Cluster 9: ['connected_spatiotemporal_region', 'entity', 'occurrent', 'spatiotemporal_instant', 'spatiotemporal_interval', 'spatiotemporal_region']
# Cluster 10: ['chemical phase', 'common chemical phase', 'crystalline phase', 'ferromagnetic phase', 'gas phase', 'liquid crystal phase', 'liquid phase', 'paramagnetic phase', 'plasma phase', 'quark gluon plasma phase', 'solid phase', 'strange matter phase', 'super fluid phase', 'super solid phase', 'uncommon chemical phase']
# Cluster 11: ['addition reaction', 'electrophilic addition reaction', 'nucleophilic addition reaction', 'polar addition reaction']
# Cluster 12: ['conformer', 'diastereomer', 'rotamer']
# Cluster 13: ['extensive property', 'heat capacity']
# Cluster 14: ['Wikipedia', 'anti conformation', 'anticlinal conformation', 'chemical conformation', 'clinal conformation', 'eclipsed conformation', 'gauche conformation', 'periplanar conformation', 'staggered conformation', 'syn conformation']
# Cluster 15: ['ceramics', 'composites', 'elastomers', 'glasses', 'material category', 'metals', 'nanomaterials', 'polymers', 'refactory']
# Cluster 16: ['Enantiomer', 'stereoisomer']
# Cluster 17: ['AcylBromideGroup', 'acyl chloride group', 'acyl halide group', 'acyl iodide group']
# Cluster 18: ['acyl bromide', 'acyl chloride', 'acyl halide', 'acyl iodide']
# Cluster 19: ['displacement reaction', 'single displacement reaction']
# Cluster 20: ['connected_temporal_region', 'temporal_instant', 'temporal_interval']
# Cluster 21: ['CAS name', 'name', 'systematic name', 'traditional name']
# Cluster 22: ['D isomer', 'D or L isomer', 'OpticalIsomer', 'R isomer', 'R or S isomer', 'S isomer', 'cis/trans isomer', 'isomer']
# Cluster 23: ['covalent bond', 'disulfide bond']
# Cluster 24: ['Hardness', 'Hardness Range', 'Hardness Range Lower Bound', 'Hardness Range Upper Bound']
# Cluster 25: ['Ion', 'anion', 'cation']
# Cluster 26: ['Ceramic Material', 'material']
# Cluster 27: ['cis isomer', 'cis/trans isomer', 'trans isomer']
# Cluster 28: ['free radical addition', 'non polar addition reaction']
# Cluster 29: ['chemical agent', 'oxidizing agent', 'reducing agent']
# Cluster 30: ['bose einstein condensate', 'fermionic condensate']
# Cluster 31: ['object_aggregate']
# Cluster 32: ['role']
# Cluster 33: ['hydrophilic']
# Cluster 34: ['hydrocarbon']
# Cluster 35: ['graphite']
# Cluster 36: ['solute']
# Cluster 37: ['processual_context']
# Cluster 38: ['temporal_region']
# Cluster 39: ['Berkelium']
# Cluster 40: ['one_dimensional_region']
# Cluster 41: ['ether']
# Cluster 42: ['Thorium']
# Cluster 43: ['hall']
# Cluster 44: ['pubchem cid']
# Cluster 45: ['scattered_spatiotemporal_region']
# Cluster 46: ['scattered_temporal_region']
# Cluster 47: ['actinide']
# Cluster 48: ['Chlorine']
# Cluster 49: ['process_boundary']
# Cluster 50: ['Dubnium']
# Cluster 51: ['Roentgenium']
# Cluster 52: ['LIsomer']
# Cluster 53: ['inchi']
# Cluster 54: ['plastics']
# Cluster 55: ['diamond']
# Cluster 56: ['DoubleDisplacementReaction']
# Cluster 57: ['basic']
# Cluster 58: ['alcohol']
# Cluster 59: ['Iodine']
# Cluster 60: ['alkyl']
# Cluster 61: ['monoisotopic weight']
# Cluster 62: ['acidic']
# Cluster 63: ['heterocyclic']

# %%
from google import genai
model = "gemini-2.5-pro"
client= genai.Client(="AIzaSyBUn48DZUNrfLO7OsOoU1wEWOOQV3Fx_44")

# %%
for i, list_of_elements in tqdm(enumerate(final_clusters_list[24:])):
    if len(list_of_elements)>1:
        prompt = f""""Analyze the following list of biological terms and identify all direct and indirect **parent-child relationships**.

        A **parent-child relationship** exists when one term (the parent) is a broader, more general category or a whole that conceptually encompasses or contains another term (the child). The child term is a more specific instance, a part, or a developmental stage of the parent term.

        **Guidelines for identifying relationships:**
        * **"Is-a" relationship:** e.g., "A 'leaf procambium' **is a** type of 'procambium'." (Parent: procambium, Child: leaf procambium)
        * **"Part-of" relationship:** e.g., "A 'petal' **is part of** a 'flower'." (Parent: flower, Child: petal)
        * **Developmental sequence:** e.g., "'Petal primordium visible stage' **is a stage in** 'petal development'." (Parent: petal development, Child: petal primordium visible stage)
        * **Anatomical hierarchy:** e.g., "'Root endodermis' **is part of** 'root' and **is a type of** 'endodermis'." (Parent: root and endodermis, Child: root endodermis)

        **List of Elements:**
        {list_of_elements}
        **Output Format:**
        Provide the output as a single JSON array. Each element in the array must be a JSON object with two keys: `"parent"` and `"child"`, whose values are the corresponding terms.

        **Example Output (Illustrative, showing the expected JSON structure):**
        {json.dumps({"Answer":[
        {
            "parent": "procambium",
            "child": "branch procambium"
        },
        {
            "parent": "procambium",
            "child": "leaf procambium"
        },
        {
            "parent": "shoot system",
            "child": "axillary shoot system"
        },
        {
            "parent": "flower",
            "child": "petal"
        },
        {
            "parent": "flower development",
            "child": "petal primordium visible stage"
        }
        ]})}
        """
        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%20==0:
            print(response.text)
# Out:
# 0it [00:00, ?it/s]
# [
#   {
#     "parent": "Ion",
#     "child": "anion"
#   },
#   {
#     "parent": "Ion",
#     "child": "cation"
#   }
# ]

# %%
final_ans
# Out:
# ['[\n  {\n    "parent": "element",\n    "child": "Actinium"\n  },\n  {\n    "parent": "element",\n    "child": "Arsenic"\n  },\n  {\n    "parent": "element",\n    "child": "Barium"\n  },\n  {\n    "parent": "element",\n    "child": "Beryllium"\n  },\n  {\n    "parent": "element",\n    "child": "Boron"\n  },\n  {\n    "parent": "element",\n    "child": "Bromine"\n  },\n  {\n    "parent": "element",\n    "child": "Cadmium"\n  },\n  {\n    "parent": "element",\n    "child": "Caesium"\n  },\n  {\n    "parent": "element",\n    "child": "Calcium"\n  },\n  {\n    "parent": "element",\n    "child": "Californium"\n  },\n  {\n    "parent": "element",\n    "child": "Cerium"\n  },\n  {\n    "parent": "element",\n    "child": "Curium"\n  },\n  {\n    "parent": "element",\n    "child": "Darmstadtium"\n  },\n  {\n    "parent": "element",\n    "child": "Dysprosium"\n  },\n  {\n    "parent": "element",\n    "child": "Einsteinium"\n  },\n  {\n    "parent": "element",\n    "child": "Erbium"\n  },\n  {\n    "parent": "element",\n    "child": "Europium"\n  },\n  {\n    "parent": "element",\n    "child": "Fluorine"\n  },\n  {\n    "parent": "element",\n    "child": "Gadolinium"\n  },\n  {\n    "parent": "element",\n    "child": "Germanium"\n  },\n  {\n    "parent": "element",\n    "child": "Gold"\n  },\n  {\n    "parent": "element",\n    "child": "Hafnium"\n  },\n  {\n    "parent": "element",\n    "child": "Holmium"\n  },\n  {\n    "parent": "element",\n    "child": "Hydrogen"\n  },\n  {\n    "parent": "element",\n    "child": "Iron"\n  },\n  {\n    "parent": "element",\n    "child": "Krypton"\n  },\n  {\n    "parent": "element",\n    "child": "Lanthanum"\n  },\n  {\n    "parent": "element",\n    "child": "Lawrencium"\n  },\n  {\n    "parent": "element",\n    "child": "Lead"\n  },\n  {\n    "parent": "element",\n    "child": "Lithium"\n  },\n  {\n    "parent": "element",\n    "child": "Lutetium"\n  },\n  {\n    "parent": "element",\n    "child": "Magnesium"\n  },\n  {\n    "parent": "element",\n    "child": "Meitnerium"\n  },\n  {\n    "parent": "element",\n    "child": "Mercury"\n  },\n  {\n    "parent": "element",\n    "child": "Molybdenum"\n  },\n  {\n    "parent": "element",\n    "child": "Osmium"\n  },\n  {\n    "parent": "element",\n    "child": "Oxygen"\n  },\n  {\n    "parent": "element",\n    "child": "Palladium"\n  },\n  {\n    "parent": "element",\n    "child": "Phosphorus"\n  },\n  {\n    "parent": "element",\n    "child": "Plutonium"\n  },\n  {\n    "parent": "element",\n    "child": "Praseodymium"\n  },\n  {\n    "parent": "element",\n    "child": "Promethium"\n  },\n  {\n    "parent": "element",\n    "child": "Radium"\n  },\n  {\n    "parent": "element",\n    "child": "Radon"\n  },\n  {\n    "parent": "element",\n    "child": "Rubidium"\n  },\n  {\n    "parent": "element",\n    "child": "Ruthenium"\n  },\n  {\n    "parent": "element",\n    "child": "Rutherfordium"\n  },\n  {\n    "parent": "element",\n    "child": "Scandium"\n  },\n  {\n    "parent": "element",\n    "child": "Seaborgium"\n  },\n  {\n    "parent": "element",\n    "child": "Selenium"\n  },\n  {\n    "parent": "element",\n    "child": "Silver"\n  },\n  {\n    "parent": "element",\n    "child": "Sodium"\n  },\n  {\n    "parent": "element",\n    "child": "Strontium"\n  },\n  {\n    "parent": "element",\n    "child": "Sulfur"\n  },\n  {\n    "parent": "element",\n    "child": "Tellurium"\n  },\n  {\n    "parent": "element",\n    "child": "Terbium"\n  },\n  {\n    "parent": "element",\n    "child": "Tin"\n  },\n  {\n    "parent": "element",\n    "child": "Titanium"\n  },\n  {\n    "parent": "element",\n    "child": "Tungsten"\n  },\n  {\n    "parent": "element",\n    "child": "Ununbium"\n  },\n  {\n    "parent": "element",\n    "child": "Ununhexium"\n  },\n  {\n    "parent": "element",\n    "child": "Ununnilium"\n  },\n  {\n    "parent": "element",\n    "child": "Ununoctium"\n  },\n  {\n    "parent": "element",\n    "child": "Ununquadium"\n  },\n  {\n    "parent": "element" ...
#  '[\n  {\n    "parent": "continuant",\n    "child": "dependent_continuant"\n  },\n  {\n    "parent": "continuant",\n    "child": "independent_continuant"\n  },\n  {\n    "parent": "independent_continuant",\n    "child": "object"\n  },\n  {\n    "parent": "independent_continuant",\n    "child": "spatial_region"\n  },\n  {\n    "parent": "dependent_continuant",\n    "child": "quality"\n  },\n  {\n    "parent": "dependent_continuant",\n    "child": "realizable_entity"\n  },\n  {\n    "parent": "dependent_continuant",\n    "child": "information"\n  },\n  {\n    "parent": "object",\n    "child": "chemical substance"\n  },\n  {\n    "parent": "object",\n    "child": "thermodynamic system"\n  },\n  {\n    "parent": "object",\n    "child": "fiat_object_part"\n  },\n  {\n    "parent": "thermodynamic system",\n    "child": "open thermodynamic system"\n  },\n  {\n    "parent": "thermodynamic system",\n    "child": "closed thermodynamic system"\n  },\n  {\n    "parent": "thermodynamic system",\n    "child": "isolated thermodynamic system"\n  },\n  {\n    "parent": "spatial_region",\n    "child": "site"\n  },\n  {\n    "parent": "spatial_region",\n    "child": "object_boundary"\n  },\n  {\n    "parent": "spatial_region",\n    "child": "zero_dimensional_region"\n  },\n  {\n    "parent": "spatial_region",\n    "child": "two_dimensional_region"\n  },\n  {\n    "parent": "spatial_region",\n    "child": "three_dimensional_region"\n  },\n  {\n    "parent": "site",\n    "child": "molecular center"\n  },\n  {\n    "parent": "site",\n    "child": "radical center"\n  },\n  {\n    "parent": "molecular center",\n    "child": "chiral center"\n  },\n  {\n    "parent": "quality",\n    "child": "measured property"\n  },\n  {\n    "parent": "quality",\n    "child": "chemical quality"\n  },\n  {\n    "parent": "quality",\n    "child": "material quality"\n  },\n  {\n    "parent": "quality",\n    "child": "MolecularQuality"\n  },\n  {\n    "parent": "quality",\n    "child": "atom property"\n  },\n  {\n    "parent": "quality",\n    "child": "count"\n  },\n  {\n    "parent": "realizable_entity",\n    "child": "disposition"\n  },\n  {\n    "parent": "realizable_entity",\n    "child": "function"\n  },\n  {\n    "parent": "disposition",\n    "child": "acidity"\n  },\n  {\n    "parent": "disposition",\n    "child": "hydrophobicity"\n  },\n  {\n    "parent": "function",\n    "child": "Cofactor"\n  },\n  {\n    "parent": "function",\n    "child": "chemical agent"\n  },\n  {\n    "parent": "chemical agent",\n    "child": "Reagent"\n  },\n  {\n    "parent": "chemical agent",\n    "child": "Product"\n  },\n  {\n    "parent": "chemical agent",\n    "child": "catalyst"\n  },\n  {\n    "parent": "chemical agent",\n    "child": "solvent"\n  },\n  {\n    "parent": "chemical agent",\n    "child": "source"\n  },\n  {\n    "parent": "Reagent",\n    "child": "Reactant"\n  },\n  {\n    "parent": "Reactant",\n    "child": "substrate"\n  },\n  {\n    "parent": "Product",\n    "child": "precipitate"\n  },\n  {\n    "parent": "solvent",\n    "child": "polar solvent"\n  },\n  {\n    "parent": "solvent",\n    "child": "nonpolar solvent"\n  },\n  {\n    "parent": "chemical substance",\n    "child": "pure substance"\n  },\n  {\n    "parent": "chemical substance",\n    "child": "mixture"\n  },\n  {\n    "parent": "chemical substance",\n    "child": "molecule"\n  },\n  {\n    "parent": "chemical substance",\n    "child": "radical"\n  },\n  {\n    "parent": "chemical substance",\n    "child": "acid"\n  },\n  {\n    "parent": "chemical substance",\n    "child": "Base"\n  },\n  {\n    "parent": "pure substance",\n    "child": "compound"\n  },\n  {\n    "parent": "pure substance",\n    "child": "atom"\n  },\n  {\n    "parent": "pure substance",\n    "child": "allotrope"\n  },\n  {\n    "parent": "mixture",\n    "child": "homogeneous mixture"\n  },\n  {\n    "parent": "mixture",\n    "child": "heterogeneous mixture"\n  },\n  {\n    "parent": "mixture",\n    "child": "Alloy"\n  },\n  {\n    "par ...
#  '[\n  {\n    "parent": "polarity",\n    "child": "non polar"\n  },\n  {\n    "parent": "polarity",\n    "child": "polar"\n  }\n]',
#  '[\n  {\n    "parent": "processual_entity",\n    "child": "process"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "process_aggregate"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "fiat_process_part"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "chemical interaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "intermolecular interaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "chemical reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "covalent bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "ionic bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "stereo bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "aromatic bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "disulfide bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "double bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "polar bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "single bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "triple bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "stereo hash bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "stereo wedge bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "electronic interaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "hydrophobic interaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "van der Waal\'s interaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "electrostatic interaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "cation pi interaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "dipole-dipole interaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "hydrogen bond"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "acid-base reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "addition reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "catalyzed reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "decomposition reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "displacement reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "inorganic reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "isomerization"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "organic reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "precipitation reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "redox reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "synthesis reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "non polar addition reaction"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "molecular complex disassociation"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "molecular complex formation"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "molecular complex assembly"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "chemical reaction pathway"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "ChemicalDegradationPathway"\n  },\n  {\n    "parent": "processual_entity",\n    "child": "ChemicalSynthesisPathway"\n  },\n  {\n    "parent": "process",\n    "child": "chemical interaction"\n  },\n  {\n    "parent": "process",\n    "child": "bond"\n  },\n  {\n    "parent": "process",\n    "child": "intermolecular interaction"\n  },\n  {\n    "parent": "process",\n    "child": "chemical reaction"\n  },\n  {\n    "parent": "process",\n    "child": "covalent bond"\n  },\n  {\n    "parent": "process",\n    "child": "ionic bond"\n  },\n  {\n    "parent": "process",\n    "child":  ...
#  '[\n  {\n    "parent": "power",\n    "child": "unit raised to power"\n  },\n  {\n    "parent": "unit raised to power",\n    "child": "unit raised to power of negative one"\n  },\n  {\n    "parent": "unit raised to power",\n    "child": "unit raised to power of negative three"\n  },\n  {\n    "parent": "unit raised to power",\n    "child": "unit raised to power of negative two"\n  },\n  {\n    "parent": "unit raised to power",\n    "child": "unit raised to power of one"\n  },\n  {\n    "parent": "unit raised to power",\n    "child": "unit raised to power of three"\n  },\n  {\n    "parent": "unit raised to power",\n    "child": "unit raised to power of two"\n  }\n]',
#  '[\n  {\n    "parent": "element",\n    "child": "periodic table element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "s-block element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "p-block element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "d-block element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "f-block element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "g-block element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "group element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "period element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "series element"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "non metal"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "metalloid"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "poor metal"\n  },\n  {\n    "parent": "periodic table element",\n    "child": "transition metal"\n  },\n  {\n    "parent": "group element",\n    "child": "group 1 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 2 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 3 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 4 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 5 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 6 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 7 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 8 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 9 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 10 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 11 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 12 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 13 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 14 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 15 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 16 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 17 element"\n  },\n  {\n    "parent": "group element",\n    "child": "group 18 element"\n  },\n  {\n    "parent": "period element",\n    "child": "period 1 element"\n  },\n  {\n    "parent": "period element",\n    "child": "period 2 element"\n  },\n  {\n    "parent": "period element",\n    "child": "period 3 element"\n  },\n  {\n    "parent": "period element",\n    "child": "period 4 element"\n  },\n  {\n    "parent": "period element",\n    "child": "period 5 element"\n  },\n  {\n    "parent": "period element",\n    "child": "period 6 element"\n  },\n  {\n    "parent": "period element",\n    "child": "period 7 element"\n  },\n  {\n    "parent": "s-block element",\n    "child": "group 1 element"\n  },\n  {\n    "parent": "s-block element",\n    "child": "group 2 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 3 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 4 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 5 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 6 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 7 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 8 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 9 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 10 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 11 element"\n  },\n  {\n    "parent": "d-block element",\n    "child": "group 12 element"\n  },\n  {\n    "parent": "p-block element",\n    "child": "group 13 element"\n  },\n  {\n    "parent": "p-block  ...
#  '[\n    {\n        "parent": "Carbon",\n        "child": "carbon allotrope"\n    },\n    {\n        "parent": "carbon allotrope",\n        "child": "amorphous carbon"\n    },\n    {\n        "parent": "carbon allotrope",\n        "child": "carbon nanofoam"\n    },\n    {\n        "parent": "carbon allotrope",\n        "child": "chaoite"\n    },\n    {\n        "parent": "carbon allotrope",\n        "child": "fullerene"\n    },\n    {\n        "parent": "carbon allotrope",\n        "child": "lonsdaleite"\n    },\n    {\n        "parent": "amorphous carbon",\n        "child": "glassy carbon"\n    },\n    {\n        "parent": "Carbon",\n        "child": "aggregated carbon nanorods"\n    }\n]',
#  '[\n  {\n    "parent": "organic compound",\n    "child": "acyl compound"\n  },\n  {\n    "parent": "organic compound",\n    "child": "aldehyde"\n  },\n  {\n    "parent": "organic compound",\n    "child": "amine"\n  },\n  {\n    "parent": "organic compound",\n    "child": "carbonyl compound"\n  },\n  {\n    "parent": "organic compound",\n    "child": "imine"\n  },\n  {\n    "parent": "organic compound",\n    "child": "ketone"\n  },\n  {\n    "parent": "organic compound",\n    "child": "organic sulfur compound"\n  },\n  {\n    "parent": "carbonyl compound",\n    "child": "acyl compound"\n  },\n  {\n    "parent": "carbonyl compound",\n    "child": "aldehyde"\n  },\n  {\n    "parent": "carbonyl compound",\n    "child": "ketone"\n  },\n  {\n    "parent": "amine",\n    "child": "primary amine"\n  },\n  {\n    "parent": "amine",\n    "child": "tertiary amine"\n  }\n]',
#  '[\n  {\n    "parent": "entity",\n    "child": "occurrent"\n  },\n  {\n    "parent": "entity",\n    "child": "spatiotemporal_region"\n  },\n  {\n    "parent": "spatiotemporal_region",\n    "child": "connected_spatiotemporal_region"\n  },\n  {\n    "parent": "entity",\n    "child": "connected_spatiotemporal_region"\n  },\n  {\n    "parent": "spatiotemporal_region",\n    "child": "spatiotemporal_instant"\n  },\n  {\n    "parent": "spatiotemporal_region",\n    "child": "spatiotemporal_interval"\n  },\n  {\n    "parent": "connected_spatiotemporal_region",\n    "child": "spatiotemporal_instant"\n  },\n  {\n    "parent": "connected_spatiotemporal_region",\n    "child": "spatiotemporal_interval"\n  },\n  {\n    "parent": "entity",\n    "child": "spatiotemporal_instant"\n  },\n  {\n    "parent": "entity",\n    "child": "spatiotemporal_interval"\n  }\n]',
#  '[\n  {\n    "parent": "chemical phase",\n    "child": "common chemical phase"\n  },\n  {\n    "parent": "chemical phase",\n    "child": "uncommon chemical phase"\n  },\n  {\n    "parent": "common chemical phase",\n    "child": "gas phase"\n  },\n  {\n    "parent": "common chemical phase",\n    "child": "liquid phase"\n  },\n  {\n    "parent": "common chemical phase",\n    "child": "solid phase"\n  },\n  {\n    "parent": "common chemical phase",\n    "child": "plasma phase"\n  },\n  {\n    "parent": "solid phase",\n    "child": "crystalline phase"\n  },\n  {\n    "parent": "solid phase",\n    "child": "super solid phase"\n  },\n  {\n    "parent": "liquid phase",\n    "child": "liquid crystal phase"\n  },\n  {\n    "parent": "liquid phase",\n    "child": "super fluid phase"\n  },\n  {\n    "parent": "plasma phase",\n    "child": "quark gluon plasma phase"\n  },\n  {\n    "parent": "uncommon chemical phase",\n    "child": "ferromagnetic phase"\n  },\n  {\n    "parent": "uncommon chemical phase",\n    "child": "paramagnetic phase"\n  },\n  {\n    "parent": "uncommon chemical phase",\n    "child": "strange matter phase"\n  },\n  {\n    "parent": "uncommon chemical phase",\n    "child": "liquid crystal phase"\n  },\n  {\n    "parent": "uncommon chemical phase",\n    "child": "super fluid phase"\n  },\n  {\n    "parent": "uncommon chemical phase",\n    "child": "super solid phase"\n  },\n  {\n    "parent": "uncommon chemical phase",\n    "child": "quark gluon plasma phase"\n  }\n]',
#  '[\n  {\n    "parent": "addition reaction",\n    "child": "electrophilic addition reaction"\n  },\n  {\n    "parent": "addition reaction",\n    "child": "nucleophilic addition reaction"\n  },\n  {\n    "parent": "addition reaction",\n    "child": "polar addition reaction"\n  },\n  {\n    "parent": "polar addition reaction",\n    "child": "electrophilic addition reaction"\n  },\n  {\n    "parent": "polar addition reaction",\n    "child": "nucleophilic addition reaction"\n  }\n]',
#  '[\n  {\n    "parent": "diastereomer",\n    "child": "conformer"\n  },\n  {\n    "parent": "conformer",\n    "child": "rotamer"\n  },\n  {\n    "parent": "diastereomer",\n    "child": "rotamer"\n  }\n]',
#  '[\n  {\n    "parent": "extensive property",\n    "child": "heat capacity"\n  }\n]',
#  '[\n  {\n    "parent": "chemical conformation",\n    "child": "eclipsed conformation"\n  },\n  {\n    "parent": "chemical conformation",\n    "child": "staggered conformation"\n  },\n  {\n    "parent": "chemical conformation",\n    "child": "periplanar conformation"\n  },\n  {\n    "parent": "chemical conformation",\n    "child": "clinal conformation"\n  },\n  {\n    "parent": "staggered conformation",\n    "child": "gauche conformation"\n  },\n  {\n    "parent": "staggered conformation",\n    "child": "anti conformation"\n  },\n  {\n    "parent": "periplanar conformation",\n    "child": "syn conformation"\n  },\n  {\n    "parent": "periplanar conformation",\n    "child": "anti conformation"\n  },\n  {\n    "parent": "clinal conformation",\n    "child": "gauche conformation"\n  },\n  {\n    "parent": "clinal conformation",\n    "child": "anticlinal conformation"\n  },\n  {\n    "parent": "eclipsed conformation",\n    "child": "syn conformation"\n  }\n]',
#  '[\n  {\n    "parent": "material category",\n    "child": "ceramics"\n  },\n  {\n    "parent": "material category",\n    "child": "composites"\n  },\n  {\n    "parent": "material category",\n    "child": "metals"\n  },\n  {\n    "parent": "material category",\n    "child": "polymers"\n  },\n  {\n    "parent": "material category",\n    "child": "nanomaterials"\n  },\n  {\n    "parent": "polymers",\n    "child": "elastomers"\n  },\n  {\n    "parent": "ceramics",\n    "child": "glasses"\n  },\n  {\n    "parent": "ceramics",\n    "child": "refactory"\n  }\n]',
#  '[\n  {\n    "parent": "stereoisomer",\n    "child": "Enantiomer"\n  }\n]',
#  '[\n  {\n    "parent": "acyl halide group",\n    "child": "AcylBromideGroup"\n  },\n  {\n    "parent": "acyl halide group",\n    "child": "acyl chloride group"\n  },\n  {\n    "parent": "acyl halide group",\n    "child": "acyl iodide group"\n  }\n]',
#  '[\n    {\n        "parent": "acyl halide",\n        "child": "acyl bromide"\n    },\n    {\n        "parent": "acyl halide",\n        "child": "acyl chloride"\n    },\n    {\n        "parent": "acyl halide",\n        "child": "acyl iodide"\n    }\n]',
#  '[\n  {\n    "parent": "displacement reaction",\n    "child": "single displacement reaction"\n  }\n]',
#  '[\n  {\n    "parent": "connected_temporal_region",\n    "child": "temporal_interval"\n  },\n  {\n    "parent": "connected_temporal_region",\n    "child": "temporal_instant"\n  }\n]',
#  '[\n  {\n    "parent": "name",\n    "child": "CAS name"\n  },\n  {\n    "parent": "name",\n    "child": "systematic name"\n  },\n  {\n    "parent": "name",\n    "child": "traditional name"\n  }\n]',
#  '[\n  {\n    "parent": "isomer",\n    "child": "cis/trans isomer"\n  },\n  {\n    "parent": "isomer",\n    "child": "OpticalIsomer"\n  },\n  {\n    "parent": "OpticalIsomer",\n    "child": "D or L isomer"\n  },\n  {\n    "parent": "OpticalIsomer",\n    "child": "R or S isomer"\n  },\n  {\n    "parent": "D or L isomer",\n    "child": "D isomer"\n  },\n  {\n    "parent": "R or S isomer",\n    "child": "R isomer"\n  },\n  {\n    "parent": "R or S isomer",\n    "child": "S isomer"\n  },\n  {\n    "parent": "isomer",\n    "child": "D or L isomer"\n  },\n  {\n    "parent": "isomer",\n    "child": "R or S isomer"\n  },\n  {\n    "parent": "isomer",\n    "child": "D isomer"\n  },\n  {\n    "parent": "isomer",\n    "child": "R isomer"\n  },\n  {\n    "parent": "isomer",\n    "child": "S isomer"\n  },\n  {\n    "parent": "OpticalIsomer",\n    "child": "D isomer"\n  },\n  {\n    "parent": "OpticalIsomer",\n    "child": "R isomer"\n  },\n  {\n    "parent": "OpticalIsomer",\n    "child": "S isomer"\n  }\n]',
#  '[\n    {\n        "parent": "covalent bond",\n        "child": "disulfide bond"\n    }\n]',
#  '[\n  {\n    "parent": "Hardness",\n    "child": "Hardness Range"\n  },\n  {\n    "parent": "Hardness",\n    "child": "Hardness Range Lower Bound"\n  },\n  {\n    "parent": "Hardness",\n    "child": "Hardness Range Upper Bound"\n  },\n  {\n    "parent": "Hardness Range",\n    "child": "Hardness Range Lower Bound"\n  },\n  {\n    "parent": "Hardness Range",\n    "child": "Hardness Range Upper Bound"\n  }\n]',
#  '[\n  {\n    "parent": "Ion",\n    "child": "anion"\n  },\n  {\n    "parent": "Ion",\n    "child": "cation"\n  }\n]',
#  '[\n  {\n    "parent": "Ion",\n    "child": "anion"\n  },\n  {\n    "parent": "Ion",\n    "child": "cation"\n  }\n]',
#  '[\n  {\n    "parent": "material",\n    "child": "Ceramic Material"\n  }\n]',
#  '[\n  {\n    "parent": "cis/trans isomer",\n    "child": "cis isomer"\n  },\n  {\n    "parent": "cis/trans isomer",\n    "child": "trans isomer"\n  }\n]',
#  '[\n  {\n    "parent": "non polar addition reaction",\n    "child": "free radical addition"\n  }\n]',
#  '[\n  {\n    "parent": "chemical agent",\n    "child": "oxidizing agent"\n  },\n  {\n    "parent": "chemical agent",\n    "child": "reducing agent"\n  }\n]',
#  '[]']

# %%
final_result = []
for ans in final_ans:
    ans_1 = json.loads(ans)
    for an in ans_1:
        if an!="Answer":
            if an not in final_result:
                final_result.append(an)

# %%
len(final_result)
# Out:
# 915

# %%
final_result
# Out:
# [{'parent': 'element', 'child': 'Actinium'},
#  {'parent': 'element', 'child': 'Arsenic'},
#  {'parent': 'element', 'child': 'Barium'},
#  {'parent': 'element', 'child': 'Beryllium'},
#  {'parent': 'element', 'child': 'Boron'},
#  {'parent': 'element', 'child': 'Bromine'},
#  {'parent': 'element', 'child': 'Cadmium'},
#  {'parent': 'element', 'child': 'Caesium'},
#  {'parent': 'element', 'child': 'Calcium'},
#  {'parent': 'element', 'child': 'Californium'},
#  {'parent': 'element', 'child': 'Cerium'},
#  {'parent': 'element', 'child': 'Curium'},
#  {'parent': 'element', 'child': 'Darmstadtium'},
#  {'parent': 'element', 'child': 'Dysprosium'},
#  {'parent': 'element', 'child': 'Einsteinium'},
#  {'parent': 'element', 'child': 'Erbium'},
#  {'parent': 'element', 'child': 'Europium'},
#  {'parent': 'element', 'child': 'Fluorine'},
#  {'parent': 'element', 'child': 'Gadolinium'},
#  {'parent': 'element', 'child': 'Germanium'},
#  {'parent': 'element', 'child': 'Gold'},
#  {'parent': 'element', 'child': 'Hafnium'},
#  {'parent': 'element', 'child': 'Holmium'},
#  {'parent': 'element', 'child': 'Hydrogen'},
#  {'parent': 'element', 'child': 'Iron'},
#  {'parent': 'element', 'child': 'Krypton'},
#  {'parent': 'element', 'child': 'Lanthanum'},
#  {'parent': 'element', 'child': 'Lawrencium'},
#  {'parent': 'element', 'child': 'Lead'},
#  {'parent': 'element', 'child': 'Lithium'},
#  {'parent': 'element', 'child': 'Lutetium'},
#  {'parent': 'element', 'child': 'Magnesium'},
#  {'parent': 'element', 'child': 'Meitnerium'},
#  {'parent': 'element', 'child': 'Mercury'},
#  {'parent': 'element', 'child': 'Molybdenum'},
#  {'parent': 'element', 'child': 'Osmium'},
#  {'parent': 'element', 'child': 'Oxygen'},
#  {'parent': 'element', 'child': 'Palladium'},
#  {'parent': 'element', 'child': 'Phosphorus'},
#  {'parent': 'element', 'child': 'Plutonium'},
#  {'parent': 'element', 'child': 'Praseodymium'},
#  {'parent': 'element', 'child': 'Promethium'},
#  {'parent': 'element', 'child': 'Radium'},
#  {'parent': 'element', 'child': 'Radon'},
#  {'parent': 'element', 'child': 'Rubidium'},
#  {'parent': 'element', 'child': 'Ruthenium'},
#  {'parent': 'element', 'child': 'Rutherfordium'},
#  {'parent': 'element', 'child': 'Scandium'},
#  {'parent': 'element', 'child': 'Seaborgium'},
#  {'parent': 'element', 'child': 'Selenium'},
#  {'parent': 'element', 'child': 'Silver'},
#  {'parent': 'element', 'child': 'Sodium'},
#  {'parent': 'element', 'child': 'Strontium'},
#  {'parent': 'element', 'child': 'Sulfur'},
#  {'parent': 'element', 'child': 'Tellurium'},
#  {'parent': 'element', 'child': 'Terbium'},
#  {'parent': 'element', 'child': 'Tin'},
#  {'parent': 'element', 'child': 'Titanium'},
#  {'parent': 'element', 'child': 'Tungsten'},
#  {'parent': 'element', 'child': 'Ununbium'},
#  {'parent': 'element', 'child': 'Ununhexium'},
#  {'parent': 'element', 'child': 'Ununnilium'},
#  {'parent': 'element', 'child': 'Ununoctium'},
#  {'parent': 'element', 'child': 'Ununquadium'},
#  {'parent': 'element', 'child': 'Ununseptium'},
#  {'parent': 'element', 'child': 'Ununtrium'},
#  {'parent': 'element', 'child': 'Uranium'},
#  {'parent': 'element', 'child': 'Vanadium'},
#  {'parent': 'element', 'child': 'Xenon'},
#  {'parent': 'element', 'child': 'Yttrium'},
#  {'parent': 'element', 'child': 'Zinc'},
#  {'parent': 'element', 'child': 'Zirconium'},
#  {'parent': 'continuant', 'child': 'dependent_continuant'},
#  {'parent': 'continuant', 'child': 'independent_continuant'},
#  {'parent': 'independent_continuant', 'child': 'object'},
#  {'parent': 'independent_continuant', 'child': 'spatial_region'},
#  {'parent': 'dependent_continuant', 'child': 'quality'},
#  {'parent': 'dependent_continuant', 'child': 'realizable_entity'},
#  {'parent': 'dependent_continuant', 'child': 'information'},
#  {'parent': 'object', 'child': 'chemical substance'},
#  {'parent': 'object', 'child': 'thermodynamic system'},
#  {'parent': 'object', 'child': 'fiat_object_part'},
#  {'parent': 'thermodynamic system', 'child': 'open thermodynamic system'},
#  {'parent': 'thermodynamic system', 'child': 'closed thermodynamic system'},
#  {'parent': 'thermodynamic system', 'child': 'isolated thermodynamic system'},
#  {'parent': 'spatial_region', 'child': 'site'},
#  {'parent': 'spatial_region', 'child': 'object_boundary'},
#  {'parent': 'spatial_region', 'child': 'zero_dimensional_region'},
#  {'parent': 'spatial_region', 'child': 'two_dimensional_region'},
#  {'parent': 'spatial_region', 'child': 'three_dimensional_region'},
#  {'parent': 'site', 'child': 'molecular center'},
#  {'parent': 'site', 'child': 'radical center'},
#  {'parent': 'molecular center', 'child': 'chiral center'},
#  {'parent': 'quality', 'child': 'measured property'},
#  {'parent': 'quality', 'child': 'chemical quality'},
#  {'parent': 'quality', 'child': 'material quality'},
#  {'parent': 'quality', 'child': 'MolecularQuality'},
#  {'parent': 'quality', 'child': 'atom property'},
#  {'parent': 'quality', 'child': 'count'},
#  {'parent': 'realizable_entity', 'child': 'disposition'},
#  {'parent': 'realizable_entity', 'child': 'function'},
#  {'parent': 'disposition', 'child': 'acidity'},
#  {'parent': 'disposition', 'child': 'hydrophobicity'},
#  {'parent': 'function', 'child': 'Cofactor'},
#  {'parent': 'function', 'child': 'chemical agent'},
#  {'parent': 'chemical agent', 'child': 'Reagent'},
#  {'parent': 'chemical agent', 'child': 'Product'},
#  {'parent': 'chemical agent', 'child': 'catalyst'},
#  {'parent': 'chemical agent', 'child': 'solvent'},
#  {'parent': 'chemical agent', 'child': 'source'},
#  {'parent': 'Reagent', 'child': 'Reactant'},
#  {'parent': 'Reactant', 'child': 'substrate'},
#  {'parent': 'Product', 'child': 'precipitate'},
#  {'parent': 'solvent', 'child': 'polar solvent'},
#  {'parent': 'solvent', 'child': 'nonpolar solvent'},
#  {'parent': 'chemical substance', 'child': 'pure substance'},
#  {'parent': 'chemical substance', 'child': 'mixture'},
#  {'parent': 'chemical substance', 'child': 'molecule'},
#  {'parent': 'chemical substance', 'child': 'radical'},
#  {'parent': 'chemical substance', 'child': 'acid'},
#  {'parent': 'chemical substance', 'child': 'Base'},
#  {'parent': 'pure substance', 'child': 'compound'},
#  {'parent': 'pure substance', 'child': 'atom'},
#  {'parent': 'pure substance', 'child': 'allotrope'},
#  {'parent': 'mixture', 'child': 'homogeneous mixture'},
#  {'parent': 'mixture', 'child': 'heterogeneous mixture'},
#  {'parent': 'mixture', 'child': 'Alloy'},
#  {'parent': 'mixture', 'child': 'racemic mixture'},
#  {'parent': 'homogeneous mixture', 'child': 'Solution'},
#  {'parent': 'compound', 'child': 'organic compound'},
#  {'parent': 'compound', 'child': 'ionic compound'},
#  {'parent': 'compound', 'child': 'binary compound'},
#  {'parent': 'compound', 'child': 'complex'},
#  {'parent': 'molecule', 'child': 'isomer'},
#  {'parent': 'isomer', 'child': 'structural isomer'},
#  {'parent': 'complex', 'child': 'metal complex'},
#  {'parent': 'complex', 'child': 'topological complex'},
#  {'parent': 'acid', 'child': 'carboxylic acid'},
#  {'parent': 'Base', 'child': 'amine'},
#  {'parent': 'organic compound', 'child': 'amine'},
#  {'parent': 'organic compound', 'child': 'amide'},
#  {'parent': 'organic compound', 'child': 'ester'},
#  {'parent': 'organic compound', 'child': 'carboxylic acid'},
#  {'parent': 'amine', 'child': 'secondary amine'},
#  {'parent': 'fiat_object_part', 'child': 'organic group'},
#  {'parent': 'organic group', 'child': 'acyl group'},
#  {'parent': 'organic group', 'child': 'carbonyl group'},
#  {'parent': 'organic group', 'child': 'organic nitrogen group'},
#  {'parent': 'organic group', 'child': 'organic sulfur group'},
#  {'parent': 'organic group', 'child': 'organic phosphate group'},
#  {'parent': 'organic group', 'child': 'ring'},
#  {'parent': 'organic group', 'child': 'aryl'},
#  {'parent': 'organic group', 'child': 'ether group'},
#  {'parent': 'organic group', 'child': 'hydroxyl group'},
#  {'parent': 'organic group', 'child': 'methyl group'},
#  {'parent': 'acyl group', 'child': 'acyl halide group'},
#  {'parent': 'acyl halide group', 'child': 'acyl fluoride group'},
#  {'parent': 'carbonyl group', 'child': 'aldehyde group'},
#  {'parent': 'carbonyl group', 'child': 'ketone group'},
#  {'parent': 'carbonyl group', 'child': 'carboxylic acid group'},
#  {'parent': 'carbonyl group', 'child': 'ester group'},
#  {'parent': 'carbonyl group', 'child': 'amide group'},
#  {'parent': 'organic nitrogen group', 'child': 'amine group'},
#  {'parent': 'organic nitrogen group', 'child': 'amide group'},
#  {'parent': 'organic nitrogen group', 'child': 'imine group'},
#  {'parent': 'amine group', 'child': 'primary amine group'},
#  {'parent': 'amine group', 'child': 'secondary amine group'},
#  {'parent': 'amine group', 'child': 'tertiary amine group'},
#  {'parent': 'organic sulfur group', 'child': 'thiol group'},
#  {'parent': 'organic sulfur group', 'child': 'sulfoxide group'},
#  {'parent': 'organic sulfur group', 'child': 'sulfonic acid group'},
#  {'parent': 'organic sulfur group', 'child': 'general sulfinic acid group'},
#  {'parent': 'sulfonic acid group', 'child': 'sulfonic acid derivative group'},
#  {'parent': 'sulfonic acid derivative group',
#   'child': 'sulfonyl halide group'},
#  {'parent': 'ring', 'child': 'aromatic ring'},
#  {'parent': 'ring', 'child': 'non aromatic ring'},
#  {'parent': 'ring', 'child': 'hetero cyclic ring'},
#  {'parent': 'ring', 'child': 'homo cyclic ring'},
#  {'parent': 'information', 'child': 'identifier'},
#  {'parent': 'identifier', 'child': 'Chemical Formula'},
#  {'parent': 'identifier', 'child': 'canonical smiles'},
#  {'parent': 'identifier', 'child': 'isomeric smiles'},
#  {'parent': 'Chemical Formula', 'child': 'Molecular Formula'},
#  {'parent': 'Chemical Formula', 'child': 'Empirical Formula'},
#  {'parent': 'Chemical Class', 'child': 'Chemical Family'},
#  {'parent': 'Chemical Class', 'child': 'acid'},
#  {'parent': 'Chemical Class', 'child': 'Base'},
#  {'parent': 'Chemical Family', 'child': 'carbon group'},
#  {'parent': 'atom', 'child': 'Actinium Atom'},
#  {'parent': 'atom', 'child': 'Aluminium Atom'},
#  {'parent': 'atom', 'child': 'Americium Atom'},
#  {'parent': 'atom', 'child': 'Antimony Atom'},
#  {'parent': 'atom', 'child': 'Argon Atom'},
#  {'parent': 'atom', 'child': 'Arsenic Atom'},
#  {'parent': 'atom', 'child': 'Astatine Atom'},
#  {'parent': 'atom', 'child': 'Barium Atom'},
#  {'parent': 'atom', 'child': 'Berkelium Atom'},
#  {'parent': 'atom', 'child': 'Beryllium Atom'},
#  {'parent': 'atom', 'child': 'Bismuth Atom'},
#  {'parent': 'atom', 'child': 'Bohrium Atom'},
#  {'parent': 'atom', 'child': 'Boron Atom'},
#  {'parent': 'atom', 'child': 'Bromine Atom'},
#  {'parent': 'atom', 'child': 'Cadmium Atom'},
#  {'parent': 'atom', 'child': 'Caesium Atom'},
#  {'parent': 'atom', 'child': 'Calcium Atom'},
#  {'parent': 'atom', 'child': 'Californium Atom'},
#  {'parent': 'atom', 'child': 'Carbon Atom'},
#  {'parent': 'atom', 'child': 'Cerium Atom'},
#  {'parent': 'atom', 'child': 'Chlorine Atom'},
#  {'parent': 'atom', 'child': 'Chromium Atom'},
#  {'parent': 'atom', 'child': 'Cobalt Atom'},
#  {'parent': 'atom', 'child': 'Copper Atom'},
#  {'parent': 'atom', 'child': 'Curium Atom'},
#  {'parent': 'atom', 'child': 'Dubnium Atom'},
#  {'parent': 'atom', 'child': 'Dysprosium Atom'},
#  {'parent': 'atom', 'child': 'Einsteinium Atom'},
#  {'parent': 'atom', 'child': 'Erbium Atom'},
#  {'parent': 'atom', 'child': 'Europium Atom'},
#  {'parent': 'atom', 'child': 'Fermium Atom'},
#  {'parent': 'atom', 'child': 'Fluorine Atom'},
#  {'parent': 'atom', 'child': 'Francium Atom'},
#  {'parent': 'atom', 'child': 'Gadolinium Atom'},
#  {'parent': 'atom', 'child': 'Gallium Atom'},
#  {'parent': 'atom', 'child': 'Germanium Atom'},
#  {'parent': 'atom', 'child': 'Gold Atom'},
#  {'parent': 'atom', 'child': 'Hafnium Atom'},
#  {'parent': 'atom', 'child': 'Hassium Atom'},
#  {'parent': 'atom', 'child': 'Helium Atom'},
#  {'parent': 'atom', 'child': 'Holmium Atom'},
#  {'parent': 'atom', 'child': 'Hydrogen Atom'},
#  {'parent': 'atom', 'child': 'Indium Atom'},
#  {'parent': 'atom', 'child': 'Iodine Atom'},
#  {'parent': 'atom', 'child': 'Iridium Atom'},
#  {'parent': 'atom', 'child': 'Iron Atom'},
#  {'parent': 'atom', 'child': 'Krypton Atom'},
#  {'parent': 'atom', 'child': 'Lanthanum Atom'},
#  {'parent': 'atom', 'child': 'Lawrencium Atom'},
#  {'parent': 'atom', 'child': 'Lead Atom'},
#  {'parent': 'atom', 'child': 'Lithium Atom'},
#  {'parent': 'atom', 'child': 'Lutetium Atom'},
#  {'parent': 'atom', 'child': 'Magnesium Atom'},
#  {'parent': 'atom', 'child': 'Manganese Atom'},
#  {'parent': 'atom', 'child': 'Meitnerium Atom'},
#  {'parent': 'atom', 'child': 'Mendelevium Atom'},
#  {'parent': 'atom', 'child': 'Mercury Atom'},
#  {'parent': 'atom', 'child': 'Molybdenum Atom'},
#  {'parent': 'atom', 'child': 'Osmium Atom'},
#  {'parent': 'atom', 'child': 'Oxygen Atom'},
#  {'parent': 'atom', 'child': 'Palladium Atom'},
#  {'parent': 'atom', 'child': 'Phosphorus Atom'},
#  {'parent': 'atom', 'child': 'Platinum Atom'},
#  {'parent': 'atom', 'child': 'Plutonium Atom'},
#  {'parent': 'atom', 'child': 'Polonium Atom'},
#  {'parent': 'atom', 'child': 'Potassium Atom'},
#  {'parent': 'atom', 'child': 'Praseodymium Atom'},
#  {'parent': 'atom', 'child': 'Promethium Atom'},
#  {'parent': 'atom', 'child': 'Protactinium Atom'},
#  {'parent': 'atom', 'child': 'Radium Atom'},
#  {'parent': 'atom', 'child': 'Radon Atom'},
#  {'parent': 'atom', 'child': 'Rhenium Atom'},
#  {'parent': 'atom', 'child': 'Rhodium Atom'},
#  {'parent': 'atom', 'child': 'Rubidium Atom'},
#  {'parent': 'atom', 'child': 'Ruthenium Atom'},
#  {'parent': 'atom', 'child': 'Rutherfordium Atom'},
#  {'parent': 'atom', 'child': 'Samarium Atom'},
#  {'parent': 'atom', 'child': 'Scandium Atom'},
#  {'parent': 'atom', 'child': 'Seaborgium Atom'},
#  {'parent': 'atom', 'child': 'Selenium Atom'},
#  {'parent': 'atom', 'child': 'Silicon Atom'},
#  {'parent': 'atom', 'child': 'Silver Atom'},
#  {'parent': 'atom', 'child': 'Sodium Atom'},
#  {'parent': 'atom', 'child': 'Strontium Atom'},
#  {'parent': 'atom', 'child': 'Sulfur Atom'},
#  {'parent': 'atom', 'child': 'Tantalum Atom'},
#  {'parent': 'atom', 'child': 'Technetium Atom'},
#  {'parent': 'atom', 'child': 'Tellurium Atom'},
#  {'parent': 'atom', 'child': 'Terbium Atom'},
#  {'parent': 'atom', 'child': 'Thallium Atom'},
#  {'parent': 'atom', 'child': 'Thorium Atom'},
#  {'parent': 'atom', 'child': 'Thulium Atom'},
#  {'parent': 'atom', 'child': 'Tin Atom'},
#  {'parent': 'atom', 'child': 'Titanium Atom'},
#  {'parent': 'atom', 'child': 'Tungsten Atom'},
#  {'parent': 'atom', 'child': 'Ununbium Atom'},
#  {'parent': 'atom', 'child': 'Ununhexium Atom'},
#  {'parent': 'atom', 'child': 'Ununnilium Atom'},
#  {'parent': 'atom', 'child': 'Ununoctium Atom'},
#  {'parent': 'atom', 'child': 'Ununpentium Atom'},
#  {'parent': 'atom', 'child': 'Ununquadium Atom'},
#  {'parent': 'atom', 'child': 'Ununseptium Atom'},
#  {'parent': 'atom', 'child': 'Ununtrium Atom'},
#  {'parent': 'atom', 'child': 'Unununium Atom'},
#  {'parent': 'atom', 'child': 'Uranium Atom'},
#  {'parent': 'atom', 'child': 'Vanadium Atom'},
#  {'parent': 'atom', 'child': 'Xenon Atom'},
#  {'parent': 'atom', 'child': 'Ytterbium Atom'},
#  {'parent': 'atom', 'child': 'Yttrium Atom'},
#  {'parent': 'atom', 'child': 'Zinc Atom'},
#  {'parent': 'atom', 'child': 'Zirconium Atom'},
#  {'parent': 'atom', 'child': 'HalogenAtom'},
#  {'parent': 'atom', 'child': 'HeteroAtom'},
#  {'parent': 'HalogenAtom', 'child': 'Astatine Atom'},
#  {'parent': 'HalogenAtom', 'child': 'Bromine Atom'},
#  {'parent': 'HalogenAtom', 'child': 'Chlorine Atom'},
#  {'parent': 'HalogenAtom', 'child': 'Fluorine Atom'},
#  {'parent': 'HalogenAtom', 'child': 'Iodine Atom'},
#  {'parent': 'HeteroAtom', 'child': 'Oxygen Atom'},
#  {'parent': 'HeteroAtom', 'child': 'Phosphorus Atom'},
#  {'parent': 'HeteroAtom', 'child': 'Sulfur Atom'},
#  {'parent': 'HeteroAtom', 'child': 'Selenium Atom'},
#  {'parent': 'MolecularQuality', 'child': 'aromaticity'},
#  {'parent': 'MolecularQuality', 'child': 'cyclicity'},
#  {'parent': 'MolecularQuality', 'child': 'molecular geometry'},
#  {'parent': 'MolecularQuality', 'child': 'point group'},
#  {'parent': 'aromaticity', 'child': 'aromatic'},
#  {'parent': 'aromaticity', 'child': 'non aromatic'},
#  {'parent': 'cyclicity', 'child': 'cyclic'},
#  {'parent': 'cyclicity', 'child': 'acyclic'},
#  {'parent': 'cyclicity', 'child': 'homocyclic'},
#  {'parent': 'molecular geometry', 'child': 'linear molecular geometry'},
#  {'parent': 'molecular geometry', 'child': 'octahedral molecular geometry'},
#  {'parent': 'molecular geometry', 'child': 'square planar molecular geometry'},
#  {'parent': 'molecular geometry',
#   'child': 'square pyramidal molecular geometry'},
#  {'parent': 'molecular geometry', 'child': 'tetrahedral molecular geometry'},
#  {'parent': 'molecular geometry',
#   'child': 'trigonal bipyramidal molecular geometry'},
#  {'parent': 'molecular geometry',
#   'child': 'trigonal planar molecular geometry'},
#  {'parent': 'molecular geometry',
#   'child': 'trigonal pyramidal molecular geometry'},
#  {'parent': 'atom property', 'child': 'atomic number'},
#  {'parent': 'atom property', 'child': 'electronegativity'},
#  {'parent': 'atom property', 'child': 'formal charge'},
#  {'parent': 'atom property', 'child': 'hybridization'},
#  {'parent': 'atom property', 'child': 'implicit valence'},
#  {'parent': 'electronegativity', 'child': 'pauling electronegativity'},
#  {'parent': 'electronegativity', 'child': 'mulliken electronegativity'},
#  {'parent': 'formal charge', 'child': 'total formal charge'},
#  {'parent': 'count', 'child': 'component count'},
#  {'parent': 'count', 'child': 'hydrogen bond acceptor count'},
#  {'parent': 'count', 'child': 'hydrogen bond donor count'},
#  {'parent': 'count', 'child': 'isotopic atom count'},
#  {'parent': 'count', 'child': 'non hydrogen atom count'},
#  {'parent': 'count', 'child': 'rotatable bond count'},
#  {'parent': 'count', 'child': 'tautomer count'},
#  {'parent': 'count', 'child': 'defined stereo atom count'},
#  {'parent': 'count', 'child': 'undefined stereo atom count'},
#  {'parent': 'count', 'child': 'defined stereo bond count'},
#  {'parent': 'count', 'child': 'undefined stereo bond count'},
#  {'parent': 'component count', 'child': 'MoleculeComponentCount'},
#  {'parent': 'measured property', 'child': 'extensive property'},
#  {'parent': 'measured property', 'child': 'intensive property'},
#  {'parent': 'measured property', 'child': 'concentration'},
#  {'parent': 'measured property', 'child': 'angle'},
#  {'parent': 'measured property', 'child': 'area'},
#  {'parent': 'measured property', 'child': 'length'},
#  {'parent': 'measured property', 'child': 'temperature'},
#  {'parent': 'measured property', 'child': 'time'},
#  {'parent': 'measured property', 'child': 'pressure'},
#  {'parent': 'measured property', 'child': 'force'},
#  {'parent': 'measured property', 'child': 'velocity'},
#  {'parent': 'measured property', 'child': 'acceleration'},
#  {'parent': 'measured property', 'child': 'power'},
#  {'parent': 'measured property', 'child': 'conduction'},
#  {'parent': 'measured property', 'child': 'electric charge'},
#  {'parent': 'measured property', 'child': 'electric current'},
#  {'parent': 'measured property', 'child': 'potential difference'},
#  {'parent': 'measured property', 'child': 'electric resistance'},
#  {'parent': 'measured property', 'child': 'Stress'},
#  {'parent': 'measured property', 'child': 'frequency'},
#  {'parent': 'measured property', 'child': 'wavenumber'},
#  {'parent': 'extensive property', 'child': 'mass'},
#  {'parent': 'extensive property', 'child': 'volume'},
#  {'parent': 'extensive property', 'child': 'energy'},
#  {'parent': 'extensive property', 'child': 'entropy'},
#  {'parent': 'extensive property', 'child': 'amount of substance'},
#  {'parent': 'intensive property', 'child': 'density'},
#  {'parent': 'intensive property', 'child': 'temperature'},
#  {'parent': 'intensive property', 'child': 'pressure'},
#  {'parent': 'intensive property', 'child': 'viscosity'},
#  {'parent': 'intensive property', 'child': 'molar energy'},
#  {'parent': 'intensive property', 'child': 'molar entropy'},
#  {'parent': 'intensive property', 'child': 'specific energy'},
#  {'parent': 'intensive property', 'child': 'specific entropy'},
#  {'parent': 'intensive property', 'child': 'specific heat'},
#  {'parent': 'intensive property', 'child': 'specific volume'},
#  {'parent': 'intensive property', 'child': 'surface tension'},
#  {'parent': 'concentration', 'child': 'amount of substance concentration'},
#  {'parent': 'concentration', 'child': 'molality'},
#  {'parent': 'concentration', 'child': 'catalytic concentration'},
#  {'parent': 'density', 'child': 'area density'},
#  {'parent': 'density', 'child': 'linear density'},
#  {'parent': 'density', 'child': 'mass density'},
#  {'parent': 'density', 'child': 'energy density'},
#  {'parent': 'density', 'child': 'electric charge density'},
#  {'parent': 'density', 'child': 'electric current density'},
#  {'parent': 'density', 'child': 'electric flux density'},
#  {'parent': 'density', 'child': 'magnetic flux density'},
#  {'parent': 'mass', 'child': 'molar mass'},
#  {'parent': 'mass', 'child': 'molecular mass'},
#  {'parent': 'energy', 'child': 'Gibbs free energy'},
#  {'parent': 'energy', 'child': 'Helmholtz free energy'},
#  {'parent': 'energy', 'child': 'enthalpy'},
#  {'parent': 'energy', 'child': 'internal energy'},
#  {'parent': 'energy', 'child': 'specific energy'},
#  {'parent': 'energy', 'child': 'molar energy'},
#  {'parent': 'entropy', 'child': 'molar entropy'},
#  {'parent': 'entropy', 'child': 'specific entropy'},
#  {'parent': 'temperature', 'child': 'Melting Point'},
#  {'parent': 'angle', 'child': 'plane angle'},
#  {'parent': 'angle', 'child': 'solid angle'},
#  {'parent': 'area', 'child': 'polar surface area'},
#  {'parent': 'length', 'child': 'grain size'},
#  {'parent': 'force', 'child': 'moment of force'},
#  {'parent': 'velocity', 'child': 'angular velocity'},
#  {'parent': 'acceleration', 'child': 'angular acceleration'},
#  {'parent': 'conduction', 'child': 'electric conduction'},
#  {'parent': 'conduction', 'child': 'thermal conduction'},
#  {'parent': 'electric charge', 'child': 'positive charge'},
#  {'parent': 'electric charge', 'child': 'negative charge'},
#  {'parent': 'radiation', 'child': 'electromagnetic radation'},
#  {'parent': 'Stress', 'child': 'ultimate tensile strength'},
#  {'parent': 'Stress', 'child': 'flexural strength'},
#  {'parent': 'material quality', 'child': 'Hardness'},
#  {'parent': 'material quality', 'child': 'Lattice Parameter'},
#  {'parent': 'material quality', 'child': 'elastic modulus'},
#  {'parent': 'material quality', 'child': 'Thermal Expansion'},
#  {'parent': 'material quality', 'child': 'fracture toughness'},
#  {'parent': 'material quality', 'child': 'permeability'},
#  {'parent': 'material quality', 'child': 'permittivity'},
#  {'parent': 'material quality', 'child': 'Structure Type'},
#  {'parent': 'material quality', 'child': 'crystal system'},
#  {'parent': 'material quality', 'child': 'space group property'},
#  {'parent': 'material quality', 'child': 'band gap'},
#  {'parent': 'material quality', 'child': 'weibull modulus'},
#  {'parent': 'Lattice Parameter', 'child': 'Lattice Parameter A'},
#  {'parent': 'Lattice Parameter', 'child': 'Lattice Parameter B'},
#  {'parent': 'Lattice Parameter', 'child': 'Lattice Parameter C'},
#  {'parent': 'elastic modulus', 'child': 'youngs modulus'},
#  {'parent': 'elastic modulus', 'child': 'shear modulus'},
#  {'parent': 'elastic modulus', 'child': 'bulk modulus'},
#  {'parent': 'elastic modulus', 'child': 'flexural modulus'},
#  {'parent': 'space group property', 'child': 'space group number'},
#  {'parent': 'Temperature Range', 'child': 'Temperature Range Lower Bound'},
#  {'parent': 'Temperature Range', 'child': 'Temperature Range Upper Bound'},
#  {'parent': 'unit', 'child': 'scaled unit'},
#  {'parent': 'unit', 'child': 'shifted unit'},
#  {'parent': 'unit', 'child': 'DerivedUnit'},
#  {'parent': 'unit', 'child': 'unit raised to power'},
#  {'parent': 'unit', 'child': 'currency unit'},
#  {'parent': 'unit', 'child': 'absorbed dose unit'},
#  {'parent': 'unit', 'child': 'acceleration unit'},
#  {'parent': 'unit', 'child': 'amount of substance unit'},
#  {'parent': 'unit', 'child': 'angle unit'},
#  {'parent': 'unit', 'child': 'area unit'},
#  {'parent': 'unit', 'child': 'band gap unit'},
#  {'parent': 'unit', 'child': 'capacitance unit'},
#  {'parent': 'unit', 'child': 'catalytic activity unit'},
#  {'parent': 'unit', 'child': 'concentration unit'},
#  {'parent': 'unit', 'child': 'conduction unit'},
#  {'parent': 'unit', 'child': 'density unit'},
#  {'parent': 'unit', 'child': 'electric charge unit'},
#  {'parent': 'unit', 'child': 'electric current unit'},
#  {'parent': 'unit', 'child': 'electric field strength unit'},
#  {'parent': 'unit', 'child': 'electric resistance unit'},
#  {'parent': 'unit', 'child': 'energy unit'},
#  {'parent': 'unit', 'child': 'entropy unit'},
#  {'parent': 'unit', 'child': 'force unit'},
#  {'parent': 'unit', 'child': 'frequency unit'},
#  {'parent': 'unit', 'child': 'illuminance unit'},
#  {'parent': 'unit', 'child': 'inductance unit'},
#  {'parent': 'unit', 'child': 'information unit'},
#  {'parent': 'unit', 'child': 'irradiance unit'},
#  {'parent': 'unit', 'child': 'length unit'},
#  {'parent': 'unit', 'child': 'luminance unit'},
#  {'parent': 'unit', 'child': 'luminous flux unit'},
#  {'parent': 'unit', 'child': 'luminous intensity unit'},
#  {'parent': 'unit', 'child': 'magnetic flux unit'},
#  {'parent': 'unit', 'child': 'mass unit'},
#  {'parent': 'unit', 'child': 'permeability unit'},
#  {'parent': 'unit', 'child': 'permittivity unit'},
#  {'parent': 'unit', 'child': 'pH unit'},
#  {'parent': 'unit', 'child': 'potential difference unit'},
#  {'parent': 'unit', 'child': 'power unit'},
#  {'parent': 'unit', 'child': 'pressure unit'},
#  {'parent': 'unit', 'child': 'radiation unit'},
#  {'parent': 'unit', 'child': 'surface tension unit'},
#  {'parent': 'unit', 'child': 'temperature unit'},
#  {'parent': 'unit', 'child': 'time unit'},
#  {'parent': 'unit', 'child': 'velocity unit'},
#  {'parent': 'unit', 'child': 'volume unit'},
#  {'parent': 'unit', 'child': 'wavenumber unit'},
#  {'parent': 'scaled unit', 'child': 'atto scaled unit'},
#  {'parent': 'scaled unit', 'child': 'centi scaled unit'},
#  {'parent': 'scaled unit', 'child': 'deci scaled unit'},
#  {'parent': 'scaled unit', 'child': 'deka scaled unit'},
#  {'parent': 'scaled unit', 'child': 'exa scaled unit'},
#  {'parent': 'scaled unit', 'child': 'femto scaled unit'},
#  {'parent': 'scaled unit', 'child': 'giga scaled unit'},
#  {'parent': 'scaled unit', 'child': 'hecto scaled unit'},
#  {'parent': 'scaled unit', 'child': 'kilo scaled unit'},
#  {'parent': 'scaled unit', 'child': 'mega scaled unit'},
#  {'parent': 'scaled unit', 'child': 'micro scaled unit'},
#  {'parent': 'scaled unit', 'child': 'milli scaled unit'},
#  {'parent': 'scaled unit', 'child': 'nano scaled unit'},
#  {'parent': 'scaled unit', 'child': 'peta scaled unit'},
#  {'parent': 'scaled unit', 'child': 'pico scaled unit'},
#  {'parent': 'scaled unit', 'child': 'tera scaled unit'},
#  {'parent': 'scaled unit', 'child': 'yocto scaled unit'},
#  {'parent': 'scaled unit', 'child': 'yotta scaled unit'},
#  {'parent': 'scaled unit', 'child': 'zepto scaled unit'},
#  {'parent': 'scaled unit', 'child': 'zetta scaled unit'},
#  {'parent': 'concentration unit',
#   'child': 'amount of substance concentration unit'},
#  {'parent': 'concentration unit', 'child': 'catalytic concentration unit'},
#  {'parent': 'concentration unit', 'child': 'molality unit'},
#  {'parent': 'concentration unit', 'child': 'parts per notation'},
#  {'parent': 'radiation unit', 'child': 'absorbed dose unit'},
#  {'parent': 'radiation unit', 'child': 'dose equivalent unit'},
#  {'parent': 'radiation unit', 'child': 'electromagnetic radiation unit'},
#  {'parent': 'radiation unit', 'child': 'exposure unit'},
#  {'parent': 'radiation unit', 'child': 'radiance unit'},
#  {'parent': 'radiation unit', 'child': 'radiant intensity unit'},
#  {'parent': 'absorbed dose unit', 'child': 'absorbed dose rate unit'},
#  {'parent': 'energy unit', 'child': 'enthalpy unit'},
#  {'parent': 'energy unit', 'child': 'molar energy unit'},
#  {'parent': 'energy unit', 'child': 'specific energy unit'},
#  {'parent': 'entropy unit', 'child': 'molar entropy unit'},
#  {'parent': 'entropy unit', 'child': 'specific entropy unit'},
#  {'parent': 'mass unit', 'child': 'molar mass unit'},
#  {'parent': 'mass unit', 'child': 'molecular mass unit'},
#  {'parent': 'angle unit', 'child': 'plane angle unit'},
#  {'parent': 'angle unit', 'child': 'solid angle unit'},
#  {'parent': 'acceleration unit', 'child': 'angular acceleration unit'},
#  {'parent': 'velocity unit', 'child': 'angular velocity unit'},
#  {'parent': 'force unit', 'child': 'moment of force unit'},
#  {'parent': 'density unit', 'child': 'area density unit'},
#  {'parent': 'density unit', 'child': 'linear density unit'},
#  {'parent': 'density unit', 'child': 'electric charge density unit'},
#  {'parent': 'density unit', 'child': 'electric current density unit'},
#  {'parent': 'density unit', 'child': 'electric flux density unit'},
#  {'parent': 'density unit', 'child': 'energy density unit'},
#  {'parent': 'density unit', 'child': 'magnetic flux density unit'},
#  {'parent': 'density unit', 'child': 'volume density unit'},
#  {'parent': 'conduction unit', 'child': 'electric conduction unit'},
#  {'parent': 'conduction unit', 'child': 'thermal conduction unit'},
#  {'parent': 'volume unit', 'child': 'specific volume unit'},
#  {'parent': 'polarity', 'child': 'non polar'},
#  {'parent': 'polarity', 'child': 'polar'},
#  {'parent': 'processual_entity', 'child': 'process'},
#  {'parent': 'processual_entity', 'child': 'process_aggregate'},
#  {'parent': 'processual_entity', 'child': 'fiat_process_part'},
#  {'parent': 'processual_entity', 'child': 'chemical interaction'},
#  {'parent': 'processual_entity', 'child': 'bond'},
#  {'parent': 'processual_entity', 'child': 'intermolecular interaction'},
#  {'parent': 'processual_entity', 'child': 'chemical reaction'},
#  {'parent': 'processual_entity', 'child': 'covalent bond'},
#  {'parent': 'processual_entity', 'child': 'ionic bond'},
#  {'parent': 'processual_entity', 'child': 'stereo bond'},
#  {'parent': 'processual_entity', 'child': 'aromatic bond'},
#  {'parent': 'processual_entity', 'child': 'disulfide bond'},
#  {'parent': 'processual_entity', 'child': 'double bond'},
#  {'parent': 'processual_entity', 'child': 'polar bond'},
#  {'parent': 'processual_entity', 'child': 'single bond'},
#  {'parent': 'processual_entity', 'child': 'triple bond'},
#  {'parent': 'processual_entity', 'child': 'stereo hash bond'},
#  {'parent': 'processual_entity', 'child': 'stereo wedge bond'},
#  {'parent': 'processual_entity', 'child': 'electronic interaction'},
#  {'parent': 'processual_entity', 'child': 'hydrophobic interaction'},
#  {'parent': 'processual_entity', 'child': "van der Waal's interaction"},
#  {'parent': 'processual_entity', 'child': 'electrostatic interaction'},
#  {'parent': 'processual_entity', 'child': 'cation pi interaction'},
#  {'parent': 'processual_entity', 'child': 'dipole-dipole interaction'},
#  {'parent': 'processual_entity', 'child': 'hydrogen bond'},
#  {'parent': 'processual_entity', 'child': 'acid-base reaction'},
#  {'parent': 'processual_entity', 'child': 'addition reaction'},
#  {'parent': 'processual_entity', 'child': 'catalyzed reaction'},
#  {'parent': 'processual_entity', 'child': 'decomposition reaction'},
#  {'parent': 'processual_entity', 'child': 'displacement reaction'},
#  {'parent': 'processual_entity', 'child': 'inorganic reaction'},
#  {'parent': 'processual_entity', 'child': 'isomerization'},
#  {'parent': 'processual_entity', 'child': 'organic reaction'},
#  {'parent': 'processual_entity', 'child': 'precipitation reaction'},
#  {'parent': 'processual_entity', 'child': 'redox reaction'},
#  {'parent': 'processual_entity', 'child': 'synthesis reaction'},
#  {'parent': 'processual_entity', 'child': 'non polar addition reaction'},
#  {'parent': 'processual_entity', 'child': 'molecular complex disassociation'},
#  {'parent': 'processual_entity', 'child': 'molecular complex formation'},
#  {'parent': 'processual_entity', 'child': 'molecular complex assembly'},
#  {'parent': 'processual_entity', 'child': 'chemical reaction pathway'},
#  {'parent': 'processual_entity', 'child': 'ChemicalDegradationPathway'},
#  {'parent': 'processual_entity', 'child': 'ChemicalSynthesisPathway'},
#  {'parent': 'process', 'child': 'chemical interaction'},
#  {'parent': 'process', 'child': 'bond'},
#  {'parent': 'process', 'child': 'intermolecular interaction'},
#  {'parent': 'process', 'child': 'chemical reaction'},
#  {'parent': 'process', 'child': 'covalent bond'},
#  {'parent': 'process', 'child': 'ionic bond'},
#  {'parent': 'process', 'child': 'stereo bond'},
#  {'parent': 'process', 'child': 'aromatic bond'},
#  {'parent': 'process', 'child': 'disulfide bond'},
#  {'parent': 'process', 'child': 'double bond'},
#  {'parent': 'process', 'child': 'polar bond'},
#  {'parent': 'process', 'child': 'single bond'},
#  {'parent': 'process', 'child': 'triple bond'},
#  {'parent': 'process', 'child': 'stereo hash bond'},
#  {'parent': 'process', 'child': 'stereo wedge bond'},
#  {'parent': 'process', 'child': 'electronic interaction'},
#  {'parent': 'process', 'child': 'hydrophobic interaction'},
#  {'parent': 'process', 'child': "van der Waal's interaction"},
#  {'parent': 'process', 'child': 'electrostatic interaction'},
#  {'parent': 'process', 'child': 'cation pi interaction'},
#  {'parent': 'process', 'child': 'dipole-dipole interaction'},
#  {'parent': 'process', 'child': 'hydrogen bond'},
#  {'parent': 'process', 'child': 'acid-base reaction'},
#  {'parent': 'process', 'child': 'addition reaction'},
#  {'parent': 'process', 'child': 'catalyzed reaction'},
#  {'parent': 'process', 'child': 'decomposition reaction'},
#  {'parent': 'process', 'child': 'displacement reaction'},
#  {'parent': 'process', 'child': 'inorganic reaction'},
#  {'parent': 'process', 'child': 'isomerization'},
#  {'parent': 'process', 'child': 'organic reaction'},
#  {'parent': 'process', 'child': 'precipitation reaction'},
#  {'parent': 'process', 'child': 'redox reaction'},
#  {'parent': 'process', 'child': 'synthesis reaction'},
#  {'parent': 'process', 'child': 'non polar addition reaction'},
#  {'parent': 'process', 'child': 'molecular complex disassociation'},
#  {'parent': 'process', 'child': 'molecular complex formation'},
#  {'parent': 'process', 'child': 'molecular complex assembly'},
#  {'parent': 'chemical interaction', 'child': 'bond'},
#  {'parent': 'chemical interaction', 'child': 'intermolecular interaction'},
#  {'parent': 'chemical interaction', 'child': 'chemical reaction'},
#  {'parent': 'chemical interaction', 'child': 'covalent bond'},
#  {'parent': 'chemical interaction', 'child': 'ionic bond'},
#  {'parent': 'chemical interaction', 'child': 'stereo bond'},
#  {'parent': 'chemical interaction', 'child': 'aromatic bond'},
#  {'parent': 'chemical interaction', 'child': 'disulfide bond'},
#  {'parent': 'chemical interaction', 'child': 'double bond'},
#  {'parent': 'chemical interaction', 'child': 'polar bond'},
#  {'parent': 'chemical interaction', 'child': 'single bond'},
#  {'parent': 'chemical interaction', 'child': 'triple bond'},
#  {'parent': 'chemical interaction', 'child': 'stereo hash bond'},
#  {'parent': 'chemical interaction', 'child': 'stereo wedge bond'},
#  {'parent': 'chemical interaction', 'child': 'electronic interaction'},
#  {'parent': 'chemical interaction', 'child': 'hydrophobic interaction'},
#  {'parent': 'chemical interaction', 'child': "van der Waal's interaction"},
#  {'parent': 'chemical interaction', 'child': 'electrostatic interaction'},
#  {'parent': 'chemical interaction', 'child': 'cation pi interaction'},
#  {'parent': 'chemical interaction', 'child': 'dipole-dipole interaction'},
#  {'parent': 'chemical interaction', 'child': 'hydrogen bond'},
#  {'parent': 'chemical interaction', 'child': 'acid-base reaction'},
#  {'parent': 'chemical interaction', 'child': 'addition reaction'},
#  {'parent': 'chemical interaction', 'child': 'catalyzed reaction'},
#  {'parent': 'chemical interaction', 'child': 'decomposition reaction'},
#  {'parent': 'chemical interaction', 'child': 'displacement reaction'},
#  {'parent': 'chemical interaction', 'child': 'inorganic reaction'},
#  {'parent': 'chemical interaction', 'child': 'isomerization'},
#  {'parent': 'chemical interaction', 'child': 'organic reaction'},
#  {'parent': 'chemical interaction', 'child': 'precipitation reaction'},
#  {'parent': 'chemical interaction', 'child': 'redox reaction'},
#  {'parent': 'chemical interaction', 'child': 'synthesis reaction'},
#  {'parent': 'chemical interaction', 'child': 'non polar addition reaction'},
#  {'parent': 'chemical interaction',
#   'child': 'molecular complex disassociation'},
#  {'parent': 'chemical interaction', 'child': 'molecular complex formation'},
#  {'parent': 'chemical interaction', 'child': 'molecular complex assembly'},
#  {'parent': 'bond', 'child': 'covalent bond'},
#  {'parent': 'bond', 'child': 'ionic bond'},
#  {'parent': 'bond', 'child': 'stereo bond'},
#  {'parent': 'bond', 'child': 'aromatic bond'},
#  {'parent': 'bond', 'child': 'disulfide bond'},
#  {'parent': 'bond', 'child': 'double bond'},
#  {'parent': 'bond', 'child': 'polar bond'},
#  {'parent': 'bond', 'child': 'single bond'},
#  {'parent': 'bond', 'child': 'triple bond'},
#  {'parent': 'bond', 'child': 'stereo hash bond'},
#  {'parent': 'bond', 'child': 'stereo wedge bond'},
#  {'parent': 'covalent bond', 'child': 'aromatic bond'},
#  {'parent': 'covalent bond', 'child': 'disulfide bond'},
#  {'parent': 'covalent bond', 'child': 'double bond'},
#  {'parent': 'covalent bond', 'child': 'polar bond'},
#  {'parent': 'covalent bond', 'child': 'single bond'},
#  {'parent': 'covalent bond', 'child': 'triple bond'},
#  {'parent': 'stereo bond', 'child': 'stereo hash bond'},
#  {'parent': 'stereo bond', 'child': 'stereo wedge bond'},
#  {'parent': 'intermolecular interaction', 'child': 'electronic interaction'},
#  {'parent': 'intermolecular interaction', 'child': 'hydrophobic interaction'},
#  {'parent': 'intermolecular interaction',
#   'child': "van der Waal's interaction"},
#  {'parent': 'intermolecular interaction',
#   'child': 'electrostatic interaction'},
#  {'parent': 'intermolecular interaction', 'child': 'cation pi interaction'},
#  {'parent': 'intermolecular interaction',
#   'child': 'dipole-dipole interaction'},
#  {'parent': 'intermolecular interaction', 'child': 'hydrogen bond'},
#  {'parent': 'electronic interaction', 'child': 'electrostatic interaction'},
#  {'parent': 'electronic interaction', 'child': 'cation pi interaction'},
#  {'parent': 'electronic interaction', 'child': 'dipole-dipole interaction'},
#  {'parent': 'electronic interaction', 'child': 'hydrogen bond'},
#  {'parent': 'electrostatic interaction', 'child': 'cation pi interaction'},
#  {'parent': 'electrostatic interaction', 'child': 'dipole-dipole interaction'},
#  {'parent': 'electrostatic interaction', 'child': 'hydrogen bond'},
#  {'parent': 'dipole-dipole interaction', 'child': 'hydrogen bond'},
#  {'parent': 'chemical reaction', 'child': 'acid-base reaction'},
#  {'parent': 'chemical reaction', 'child': 'addition reaction'},
#  {'parent': 'chemical reaction', 'child': 'catalyzed reaction'},
#  {'parent': 'chemical reaction', 'child': 'decomposition reaction'},
#  {'parent': 'chemical reaction', 'child': 'displacement reaction'},
#  {'parent': 'chemical reaction', 'child': 'inorganic reaction'},
#  {'parent': 'chemical reaction', 'child': 'isomerization'},
#  {'parent': 'chemical reaction', 'child': 'organic reaction'},
#  {'parent': 'chemical reaction', 'child': 'precipitation reaction'},
#  {'parent': 'chemical reaction', 'child': 'redox reaction'},
#  {'parent': 'chemical reaction', 'child': 'synthesis reaction'},
#  {'parent': 'chemical reaction', 'child': 'non polar addition reaction'},
#  {'parent': 'chemical reaction', 'child': 'molecular complex disassociation'},
#  {'parent': 'chemical reaction', 'child': 'molecular complex formation'},
#  {'parent': 'chemical reaction', 'child': 'molecular complex assembly'},
#  {'parent': 'addition reaction', 'child': 'non polar addition reaction'},
#  {'parent': 'decomposition reaction',
#   'child': 'molecular complex disassociation'},
#  {'parent': 'synthesis reaction', 'child': 'molecular complex formation'},
#  {'parent': 'synthesis reaction', 'child': 'molecular complex assembly'},
#  {'parent': 'molecular complex formation',
#   'child': 'molecular complex assembly'},
#  {'parent': 'process_aggregate', 'child': 'chemical reaction pathway'},
#  {'parent': 'process_aggregate', 'child': 'ChemicalDegradationPathway'},
#  {'parent': 'process_aggregate', 'child': 'ChemicalSynthesisPathway'},
#  {'parent': 'chemical reaction pathway',
#   'child': 'ChemicalDegradationPathway'},
#  {'parent': 'chemical reaction pathway', 'child': 'ChemicalSynthesisPathway'},
#  {'parent': 'power', 'child': 'unit raised to power'},
#  {'parent': 'unit raised to power',
#   'child': 'unit raised to power of negative one'},
#  {'parent': 'unit raised to power',
#   'child': 'unit raised to power of negative three'},
#  {'parent': 'unit raised to power',
#   'child': 'unit raised to power of negative two'},
#  {'parent': 'unit raised to power', 'child': 'unit raised to power of one'},
#  {'parent': 'unit raised to power', 'child': 'unit raised to power of three'},
#  {'parent': 'unit raised to power', 'child': 'unit raised to power of two'},
#  {'parent': 'element', 'child': 'periodic table element'},
#  {'parent': 'periodic table element', 'child': 's-block element'},
#  {'parent': 'periodic table element', 'child': 'p-block element'},
#  {'parent': 'periodic table element', 'child': 'd-block element'},
#  {'parent': 'periodic table element', 'child': 'f-block element'},
#  {'parent': 'periodic table element', 'child': 'g-block element'},
#  {'parent': 'periodic table element', 'child': 'group element'},
#  {'parent': 'periodic table element', 'child': 'period element'},
#  {'parent': 'periodic table element', 'child': 'series element'},
#  {'parent': 'periodic table element', 'child': 'non metal'},
#  {'parent': 'periodic table element', 'child': 'metalloid'},
#  {'parent': 'periodic table element', 'child': 'poor metal'},
#  {'parent': 'periodic table element', 'child': 'transition metal'},
#  {'parent': 'group element', 'child': 'group 1 element'},
#  {'parent': 'group element', 'child': 'group 2 element'},
#  {'parent': 'group element', 'child': 'group 3 element'},
#  {'parent': 'group element', 'child': 'group 4 element'},
#  {'parent': 'group element', 'child': 'group 5 element'},
#  {'parent': 'group element', 'child': 'group 6 element'},
#  {'parent': 'group element', 'child': 'group 7 element'},
#  {'parent': 'group element', 'child': 'group 8 element'},
#  {'parent': 'group element', 'child': 'group 9 element'},
#  {'parent': 'group element', 'child': 'group 10 element'},
#  {'parent': 'group element', 'child': 'group 11 element'},
#  {'parent': 'group element', 'child': 'group 12 element'},
#  {'parent': 'group element', 'child': 'group 13 element'},
#  {'parent': 'group element', 'child': 'group 14 element'},
#  {'parent': 'group element', 'child': 'group 15 element'},
#  {'parent': 'group element', 'child': 'group 16 element'},
#  {'parent': 'group element', 'child': 'group 17 element'},
#  {'parent': 'group element', 'child': 'group 18 element'},
#  {'parent': 'period element', 'child': 'period 1 element'},
#  {'parent': 'period element', 'child': 'period 2 element'},
#  {'parent': 'period element', 'child': 'period 3 element'},
#  {'parent': 'period element', 'child': 'period 4 element'},
#  {'parent': 'period element', 'child': 'period 5 element'},
#  {'parent': 'period element', 'child': 'period 6 element'},
#  {'parent': 'period element', 'child': 'period 7 element'},
#  {'parent': 's-block element', 'child': 'group 1 element'},
#  {'parent': 's-block element', 'child': 'group 2 element'},
#  {'parent': 'd-block element', 'child': 'group 3 element'},
#  {'parent': 'd-block element', 'child': 'group 4 element'},
#  {'parent': 'd-block element', 'child': 'group 5 element'},
#  {'parent': 'd-block element', 'child': 'group 6 element'},
#  {'parent': 'd-block element', 'child': 'group 7 element'},
#  {'parent': 'd-block element', 'child': 'group 8 element'},
#  {'parent': 'd-block element', 'child': 'group 9 element'},
#  {'parent': 'd-block element', 'child': 'group 10 element'},
#  {'parent': 'd-block element', 'child': 'group 11 element'},
#  {'parent': 'd-block element', 'child': 'group 12 element'},
#  {'parent': 'p-block element', 'child': 'group 13 element'},
#  {'parent': 'p-block element', 'child': 'group 14 element'},
#  {'parent': 'p-block element', 'child': 'group 15 element'},
#  {'parent': 'p-block element', 'child': 'group 16 element'},
#  {'parent': 'p-block element', 'child': 'group 17 element'},
#  {'parent': 'p-block element', 'child': 'group 18 element'},
#  {'parent': 'group 1 element', 'child': 'alkali metal'},
#  {'parent': 'group 2 element', 'child': 'alkaline earth metal'},
#  {'parent': 'group 13 element', 'child': 'boron group element'},
#  {'parent': 'group 14 element', 'child': 'carbon group element'},
#  {'parent': 'group 15 element', 'child': 'nitrogen group element'},
#  {'parent': 'group 16 element', 'child': 'chalcogen'},
#  {'parent': 'group 17 element', 'child': 'halogen'},
#  {'parent': 'group 18 element', 'child': 'noble gas'},
#  {'parent': 'd-block element', 'child': 'transition metal'},
#  {'parent': 'series element', 'child': 'lanthanide'},
#  {'parent': 'f-block element', 'child': 'lanthanide'},
#  {'parent': 'period 6 element', 'child': 'lanthanide'},
#  {'parent': 'p-block element', 'child': 'poor metal'},
#  {'parent': 'p-block element', 'child': 'metalloid'},
#  {'parent': 'non metal', 'child': 'halogen'},
#  {'parent': 'non metal', 'child': 'noble gas'},
#  {'parent': 'Carbon', 'child': 'carbon allotrope'},
#  {'parent': 'carbon allotrope', 'child': 'amorphous carbon'},
#  {'parent': 'carbon allotrope', 'child': 'carbon nanofoam'},
#  {'parent': 'carbon allotrope', 'child': 'chaoite'},
#  {'parent': 'carbon allotrope', 'child': 'fullerene'},
#  {'parent': 'carbon allotrope', 'child': 'lonsdaleite'},
#  {'parent': 'amorphous carbon', 'child': 'glassy carbon'},
#  {'parent': 'Carbon', 'child': 'aggregated carbon nanorods'},
#  {'parent': 'organic compound', 'child': 'acyl compound'},
#  {'parent': 'organic compound', 'child': 'aldehyde'},
#  {'parent': 'organic compound', 'child': 'carbonyl compound'},
#  {'parent': 'organic compound', 'child': 'imine'},
#  {'parent': 'organic compound', 'child': 'ketone'},
#  {'parent': 'organic compound', 'child': 'organic sulfur compound'},
#  {'parent': 'carbonyl compound', 'child': 'acyl compound'},
#  {'parent': 'carbonyl compound', 'child': 'aldehyde'},
#  {'parent': 'carbonyl compound', 'child': 'ketone'},
#  {'parent': 'amine', 'child': 'primary amine'},
#  {'parent': 'amine', 'child': 'tertiary amine'},
#  {'parent': 'entity', 'child': 'occurrent'},
#  {'parent': 'entity', 'child': 'spatiotemporal_region'},
#  {'parent': 'spatiotemporal_region',
#   'child': 'connected_spatiotemporal_region'},
#  {'parent': 'entity', 'child': 'connected_spatiotemporal_region'},
#  {'parent': 'spatiotemporal_region', 'child': 'spatiotemporal_instant'},
#  {'parent': 'spatiotemporal_region', 'child': 'spatiotemporal_interval'},
#  {'parent': 'connected_spatiotemporal_region',
#   'child': 'spatiotemporal_instant'},
#  {'parent': 'connected_spatiotemporal_region',
#   'child': 'spatiotemporal_interval'},
#  {'parent': 'entity', 'child': 'spatiotemporal_instant'},
#  {'parent': 'entity', 'child': 'spatiotemporal_interval'},
#  {'parent': 'chemical phase', 'child': 'common chemical phase'},
#  {'parent': 'chemical phase', 'child': 'uncommon chemical phase'},
#  {'parent': 'common chemical phase', 'child': 'gas phase'},
#  {'parent': 'common chemical phase', 'child': 'liquid phase'},
#  {'parent': 'common chemical phase', 'child': 'solid phase'},
#  {'parent': 'common chemical phase', 'child': 'plasma phase'},
#  {'parent': 'solid phase', 'child': 'crystalline phase'},
#  {'parent': 'solid phase', 'child': 'super solid phase'},
#  {'parent': 'liquid phase', 'child': 'liquid crystal phase'},
#  {'parent': 'liquid phase', 'child': 'super fluid phase'},
#  {'parent': 'plasma phase', 'child': 'quark gluon plasma phase'},
#  {'parent': 'uncommon chemical phase', 'child': 'ferromagnetic phase'},
#  {'parent': 'uncommon chemical phase', 'child': 'paramagnetic phase'},
#  {'parent': 'uncommon chemical phase', 'child': 'strange matter phase'},
#  {'parent': 'uncommon chemical phase', 'child': 'liquid crystal phase'},
#  {'parent': 'uncommon chemical phase', 'child': 'super fluid phase'},
#  {'parent': 'uncommon chemical phase', 'child': 'super solid phase'},
#  {'parent': 'uncommon chemical phase', 'child': 'quark gluon plasma phase'},
#  {'parent': 'addition reaction', 'child': 'electrophilic addition reaction'},
#  {'parent': 'addition reaction', 'child': 'nucleophilic addition reaction'},
#  {'parent': 'addition reaction', 'child': 'polar addition reaction'},
#  {'parent': 'polar addition reaction',
#   'child': 'electrophilic addition reaction'},
#  {'parent': 'polar addition reaction',
#   'child': 'nucleophilic addition reaction'},
#  {'parent': 'diastereomer', 'child': 'conformer'},
#  {'parent': 'conformer', 'child': 'rotamer'},
#  {'parent': 'diastereomer', 'child': 'rotamer'},
#  {'parent': 'extensive property', 'child': 'heat capacity'},
#  {'parent': 'chemical conformation', 'child': 'eclipsed conformation'},
#  {'parent': 'chemical conformation', 'child': 'staggered conformation'},
#  {'parent': 'chemical conformation', 'child': 'periplanar conformation'},
#  {'parent': 'chemical conformation', 'child': 'clinal conformation'},
#  {'parent': 'staggered conformation', 'child': 'gauche conformation'},
#  {'parent': 'staggered conformation', 'child': 'anti conformation'},
#  {'parent': 'periplanar conformation', 'child': 'syn conformation'},
#  {'parent': 'periplanar conformation', 'child': 'anti conformation'},
#  {'parent': 'clinal conformation', 'child': 'gauche conformation'},
#  {'parent': 'clinal conformation', 'child': 'anticlinal conformation'},
#  {'parent': 'eclipsed conformation', 'child': 'syn conformation'},
#  {'parent': 'material category', 'child': 'ceramics'},
#  {'parent': 'material category', 'child': 'composites'},
#  {'parent': 'material category', 'child': 'metals'},
#  {'parent': 'material category', 'child': 'polymers'},
#  {'parent': 'material category', 'child': 'nanomaterials'},
#  {'parent': 'polymers', 'child': 'elastomers'},
#  {'parent': 'ceramics', 'child': 'glasses'},
#  {'parent': 'ceramics', 'child': 'refactory'},
#  {'parent': 'stereoisomer', 'child': 'Enantiomer'},
#  {'parent': 'acyl halide group', 'child': 'AcylBromideGroup'},
#  {'parent': 'acyl halide group', 'child': 'acyl chloride group'},
#  {'parent': 'acyl halide group', 'child': 'acyl iodide group'},
#  {'parent': 'acyl halide', 'child': 'acyl bromide'},
#  {'parent': 'acyl halide', 'child': 'acyl chloride'},
#  {'parent': 'acyl halide', 'child': 'acyl iodide'},
#  {'parent': 'displacement reaction', 'child': 'single displacement reaction'},
#  {'parent': 'connected_temporal_region', 'child': 'temporal_interval'},
#  {'parent': 'connected_temporal_region', 'child': 'temporal_instant'},
#  {'parent': 'name', 'child': 'CAS name'},
#  {'parent': 'name', 'child': 'systematic name'},
#  {'parent': 'name', 'child': 'traditional name'},
#  {'parent': 'isomer', 'child': 'cis/trans isomer'},
#  {'parent': 'isomer', 'child': 'OpticalIsomer'},
#  {'parent': 'OpticalIsomer', 'child': 'D or L isomer'},
#  {'parent': 'OpticalIsomer', 'child': 'R or S isomer'},
#  {'parent': 'D or L isomer', 'child': 'D isomer'},
#  {'parent': 'R or S isomer', 'child': 'R isomer'},
#  {'parent': 'R or S isomer', 'child': 'S isomer'},
#  {'parent': 'isomer', 'child': 'D or L isomer'},
#  {'parent': 'isomer', 'child': 'R or S isomer'},
#  {'parent': 'isomer', 'child': 'D isomer'},
#  {'parent': 'isomer', 'child': 'R isomer'},
#  {'parent': 'isomer', 'child': 'S isomer'},
#  {'parent': 'OpticalIsomer', 'child': 'D isomer'},
#  {'parent': 'OpticalIsomer', 'child': 'R isomer'},
#  {'parent': 'OpticalIsomer', 'child': 'S isomer'},
#  {'parent': 'Hardness', 'child': 'Hardness Range'},
#  {'parent': 'Hardness', 'child': 'Hardness Range Lower Bound'},
#  {'parent': 'Hardness', 'child': 'Hardness Range Upper Bound'},
#  {'parent': 'Hardness Range', 'child': 'Hardness Range Lower Bound'},
#  {'parent': 'Hardness Range', 'child': 'Hardness Range Upper Bound'},
#  {'parent': 'Ion', 'child': 'anion'},
#  {'parent': 'Ion', 'child': 'cation'},
#  {'parent': 'material', 'child': 'Ceramic Material'},
#  {'parent': 'cis/trans isomer', 'child': 'cis isomer'},
#  {'parent': 'cis/trans isomer', 'child': 'trans isomer'},
#  {'parent': 'non polar addition reaction', 'child': 'free radical addition'},
#  {'parent': 'chemical agent', 'child': 'oxidizing agent'},
#  {'parent': 'chemical agent', 'child': 'reducing agent'}]

# %%
with open("predictions_c_Matonto_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

# %%
import json

# Save final_clusters_list to JSON file
with open("final_result_keywords_c_po.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

print("Clusters saved to final_clusters.json ✅")
# Out:
# Clusters saved to final_clusters.json ✅

# %%
with open("_pairs.jsonl", "w", encoding="utf-8") as f:
    for entry in final_result:
        json.dump(entry, f)
        f.write("\n")
