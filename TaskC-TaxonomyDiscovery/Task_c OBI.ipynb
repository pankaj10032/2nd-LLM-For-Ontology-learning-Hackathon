# %%
import json
def load_json(data_path):
    with open(data_path, "r", encoding="utf-8") as file_1:
        data = json.load(file_1)
    return data

# %%
data = load_json("OBI/train/obi_train_pairs.json")

# %%
len(data), data[:5]
# Out:
# (8249,
#  [{'ID': 'TR_bb9941a6',
#    'parent': 'hemoglobin assay',
#    'child': 'cooximitery arterial blood hemoglobin assay'},
#   {'ID': 'TR_a5a2af93',
#    'parent': 'signal conversion function',
#    'child': 'signal amplification function'},
#   {'ID': 'TR_e2e1a388',
#    'parent': 'exclusion criterion',
#    'child': 'chemotherapy treatment exclusion criterion'},
#   {'ID': 'TR_5ad85031',
#    'parent': 'automatic tissue processor',
#    'child': 'Leica Peloris rapid tissue processor'},
#   {'ID': 'TR_f2e67ac9',
#    'parent': 'cytometry assay',
#    'child': 'cerebrospinal fluid mesothelial cell count assay'}])

# %%
from collections import defaultdict

class UnionFind:
    def __init__(self):
        self.parent = {}

    def find(self, x):
        # Path compression
        if x != self.parent.setdefault(x, x):
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        self.parent[self.find(x)] = self.find(y)

def build_clusters(relationships):
    uf = UnionFind()
    
    for rel in relationships:
        parent = rel["parent"]
        child = rel["child"]
        uf.union(parent, child)

    clusters = defaultdict(set)
    for term in set([item for rel in relationships for item in (rel["parent"], rel["child"])]):
        root = uf.find(term)
        clusters[root].add(term)

    # Add isolated nodes (no parent/child relationship)
    all_terms = set()
    for rel in relationships:
        all_terms.add(rel["parent"])
        all_terms.add(rel["child"])
    for term in all_terms:
        if term not in uf.parent:
            clusters[term].add(term)

    return list(clusters.values())

# %%
clusters = build_clusters(data)

# %%
len(clusters)
# Out:
# 159

# %%
for cluster in clusters:
    print(len(cluster))
# Out:
# 1906
# 24
# 1030
# 113
# 14
# 172
# 3
# 2
# 17
# 16
# 15
# 2
# 103
# 3
# 49
# 20
# 3
# 6
# 14
# 6
# 3
# 2
# 36
# 6
# 9
# 2
# 2
# 2
# 6
# 12
# 35
# 3
# 2
# 5
# 25
# 9
# 7
# 9
# 6
# 5
# 5
# 2
# 14
# 82
# 3
# 3
# 2
# 26
# 2
# 9
# 4
# 3
# 11
# 15
# 2
# 5
# 4
# 4
# 4
# 3
# 5
# 5
# 4
# 3
# 15
# 11
# 3
# 6
# 5
# 4
# 2
# 4
# 4
# 4
# 8
# 4
# 4
# 5
# 2
# 4
# 2
# 3
# 2
# 2
# 2
# 2
# 9
# 3
# 2
# 2
# 3
# 2
# 2
# 2
# 2
# 3
# 3
# 5
# 8
# 2
# 2
# 2
# 3
# 4
# 2
# 4
# 2
# 3
# 2
# 3
# 4
# 6
# 2
# 3
# 6
# 3
# 2
# 3
# 2
# 4
# 3
# 2
# 4
# 3
# 2
# 3
# 3
# 3
# 3
# 3
# 9
# 3
# 2
# 3
# 3
# 2
# 3
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 2
# 2
# 2
# 2
# 4
# 2
# 3
# 2
# 3
# 2
# 2
# 2
# 2
# 2

# %%
# Load a text file in Python
final_content = []
with open("OBI/test/obi_test_types.txt", "r", encoding="utf-8") as f:
    contents = f.readlines()
    for content in contents:
        final_content.append(content.strip('\n'))


print(contents[:500])  # Print first 500 characters
# Out:
# ['GEM premier blood gas venous blood ionized calcium assay\n', 'standard deviation calculation\n', 'insecticide resistance by detecting carboxylic ester hydrolase activity assay\n', 'age measurement datum\n', 'intracellular cytokine staining assay measuring epitope specific interleukin-22 production by T cells\n', 'creatinine clearance urine creatinine assay\n', 'brachioradialis functionality\n', 'ELISA measuring epitope specific macrophage inflammatory protein-1 alpha production by T cells\n', 'hemoglobin oxygen saturation arterial blood oxygen assay\n', 'areola\n', 'disposition to cause an allergic reaction\n', 'direct venous blood bilirubin assay\n', 'spatial region\n', 'POC chem8 arterial blood sodium assay\n', 'assay measuring epitope specific interleukin-27 production by T cells\n', 'material sample\n', 'solid NMR probe\n', 'B cell epitope specific antibody-dependent cellular cytotoxicity\n', 'machine learning\n', 'laser\n', 'umbilical cord blood specimen\n', 'photomultiplier tube\n', 'cortex of kidney specimen\n', 'low-density lipoprotein cholesterol assay\n', 'ELISA measuring epitope specific interferon-beta production by T cells\n', 'adjuvant role\n', 'cerebrospinal fluid microbiology assay\n', 'multi-unit recording\n', 'small-animal image acquisition device\n', 'dye role\n', 'Illumina HiSeq 1500\n', 'cultured CD4-/CD8- T cell population\n', 'TSH reflex Free T4 venous blood thyroid stimulating hormone assay\n', 'role of independent data monitoring committee\n', 'trough venous blood tobramycin assay\n', 'blood gas venous blood bicarbonate assay\n', 'ABL90 panel arterial blood hematocrit assay\n', '16s ribosomal gene sequencing assay\n', 'plasma cell\n', 'establishing cell line\n', 'cytometric bead array assay measuring epitope specific interleukin-17A production by T cells\n', 'electrophoresis system\n', 'isolation of adherent cells\n', 'ultrasound machine\n', 'epithelial cell\n', 'mouse MHC class I protein complex with H2-b haplotype\n', 'total venous blood T3 assay\n', 'intracellular cytokine staining assay measuring epitope specific interleukin-3 production by T cells\n', 'Amniota\n', 'efficacy of epitope intervention experiment\n', 'transcription profiling by RT-PCR design\n', 'interleukin-9 production\n', 'family wise error rate correction method\n', 'centroid mass spectrum analysis\n', 'inside-out patch clamp assay\n', 'data set of predicted values according to fitted curve\n', 'venous blood ammonia assay\n', 'cluster study group role\n', "3,3',5'-triiodothyronine\n", 'array scanner\n', 'antigen role\n', 'assay measuring epitope specific monocyte chemotactic protein-1 production by T cells\n', 'T cell mediated cytotoxicity\n', 'categorical measurement datum\n', 'amplicon sequencing assay\n', 'antibody binding detection by fluorescence quenching\n', 'promyelocyte assay\n', 'SPEP protein electrophoresis venous blood albumin assay\n', 'ELISPOT assay measuring epitope specific interleukin-1 alpha production by T cells\n', 'C-reactive protein assay\n', 'organism detection by PCR assay\n', 'material anatomical entity\n', 'cell culture splitting\n', 'node quality calculation\n', 'induced sputum microbiology assay\n', 'vancomycin\n', 'cell culture analyte detection bioassay measuring epitope specific interleukin-6 production by T cells\n', 'radioactivity detection assay measuring competitive binding of a cell-bound-MHC:ligand complex\n', 'intraoperative venous blood PTH assay\n', 'T2 weighted magnetic resonance image data set\n', 'MHC tetramer/multimer assay measuring binding of a T cell epitope:MHC:TCR complex\n', 'folic acids assay\n', 'computed tomography imaging assay\n', 'total venous blood cholesterol assay\n', 'catalytic activity\n', 'genomic SELEX\n', 'electrolytes urine potassium assay\n', 'cDNA library\n', 'image creation\n', 'specimen collection process\n', 'enzyme-linked immunospot assay\n', 'extraction date\n', 'curated information\n', 'establishing cell culture\n', 'ELISPOT assay measuring epitope specific  ...

# %%
len(contents), contents[0]
# Out:
# (2821, 'GEM premier blood gas venous blood ionized calcium assay\n')

# %%
len(final_content), final_content[0]
# Out:
# (2821, 'GEM premier blood gas venous blood ionized calcium assay')

# %%
# Step 3: Assign function
from collections import Counter
from tqdm.notebook import tqdm
def assign_term_to_cluster(new_term, clusters):
    new_words = new_term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for term in cluster:
            for word in term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)
    
    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]
    
    if max_score == 0:
        return None  # No match
    return best_cluster_index

# Step 4: Assign all new terms
final_clusters = [set(cluster) for cluster in clusters]  # copy original clusters

for term in tqdm(final_content):
    assigned_idx = assign_term_to_cluster(term, final_clusters)
    if assigned_idx is not None:
        final_clusters[assigned_idx].add(term)
    else:
        # Create new cluster if no match found
        final_clusters.append(set([term]))

# Step 5: Convert to list of lists and return
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

# Display final clusters
for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")
# Out:
#   0%|          | 0/2821 [00:00<?, ?it/s]
# Cluster 1: ['16s ribosomal gene sequencing assay', '24 hour total urine volume assay', '24 hour urine creatinine assay', '24 hour urine protein assay', '25-hydroxyvitamin D2', '293-T cell line', "3,3',5'-triiodothyronine", "3,3',5'-triiodothyronine assay", "3,3',5'-triiodothyronine concentration assay", '3-hydroxybutyric acid', '3-hydroxybutyric acid assay', '3D cell structure determination assay', '3D molecular structure determination assay', '3D molecular structure determination assay of a MHC:ligand complex', '3D molecular structure determination assay of a T cell epitope:MHC:TCR complex', '3D molecular structure determination assay of an antigen:antibody complex', '3D neural cell structure determination assay', '3D structure determination assay', '3D structure determination of bound molecular complex assay', '3H-thymidine assay measuring epitope specific proliferation of T cells', "5'-nucleotidase activity level assay", '51 chromium assay measuring epitope specific T cell killing', '96-well neutralization assay', 'ABG/electrolytes arterial blood carbon dioxide assay', 'ABG/electrolytes arterial blood ionized calcium assay', 'ABG/electrolytes arterial blood oxygen assay', 'ABI 377 automated sequencer', 'ABL90 panel arterial blood bicarbonate assay', 'ABL90 panel arterial blood calcium assay', 'ABL90 panel arterial blood carbon dioxide assay', 'ABL90 panel arterial blood chloride assay', 'ABL90 panel arterial blood glucose assay', 'ABL90 panel arterial blood hematocrit assay', 'ABL90 panel arterial blood hemoglobin assay', 'ABL90 panel arterial blood lactic acid assay', 'ABL90 panel arterial blood methemoglobin assay', 'ABL90 panel arterial blood oxygen assay', 'ABL90 panel arterial blood potassium assay', 'ABL90 panel arterial blood sodium assay', 'ABL90 panel arterial blood temperature assay', 'ABL90 panel venous blood bicarbonate assay', 'ABL90 panel venous blood carbon dioxide assay', 'ABL90 panel venous blood chloride assay', 'ABL90 panel venous blood glucose assay', 'ABL90 panel venous blood hematocrit assay', 'ABL90 panel venous blood hemoglobin assay', 'ABL90 panel venous blood ionized calcium assay', 'ABL90 panel venous blood lactic acid assay', 'ABL90 panel venous blood methemoglobin assay', 'ABL90 panel venous blood oxygen assay', 'ABL90 panel venous blood potassium assay', 'ABL90 panel venous blood sodium assay', 'ANOVA', 'ATP bioluminescence assay', 'Advantage Chikungunya IgM Card kit', 'Affymetrix Human Exon Junction Array', 'Affymetrix Human Genome U219 Array', 'Affymetrix Mouse Gene 2.1 ST Array', 'Affymetrix Rhesus Macaque Genome Array', 'Annexin V staining', 'B cell', 'B cell epitope assay', 'B cell epitope specific antibody-dependent cellular cytotoxicity', 'B cell epitope specific immune complex formation', 'B cell epitope specific immune intervention', 'B cell receptor complex', 'B cell receptor repertoire sequencing assay', 'Benjamini and Hochberg false discovery rate correction method', 'Benjamini and Yekutieli false discovery rate correction method', 'Bernoulli trial', 'Biosite cardiac panel arterial blood creatine kinase MB assay', 'BrdU assay measuring epitope specific proliferation of T cells', 'BrdU incorporation assay', 'Bruker high resolution probe', 'C-reactive protein assay', 'C1R cell line', 'CART', 'CBC venous blood RBC count assay', 'CBC venous blood WBC count assay', 'CBC venous blood hematocrit assay', 'CBC venous blood hemoglobin assay', 'CBC venous blood platelet count assay', 'CBC with automated differential venous blood RBC count assay', 'CBC with automated differential venous blood WBC count assay', 'CBC with automated differential venous blood hematocrit assay', 'CBC with automated differential venous blood hemoglobin assay', 'CBC with automated differential venous blood nucleated RBC count assay', 'CBC with automated differential venous blood platelet count assay', 'CBC with manual differential venous blood WBC count assay', 'CBC with manual differential venous blood band neutrophi ...
# Cluster 2: ['Amnis ImageStream', 'SPECT scanner', 'array scanner', 'bead array reader', 'computed tomography scanner', 'confocal microscope', 'digital camera', 'digital microscope', 'electron microscope', 'gel imaging system', 'image creation device', 'image cytometer', 'immunoblot scanner', 'infrared image acquisition device', 'laser capture microdissection microscope', 'laser scanning confocal microscope', 'microscope', 'multispectral imaging flow cytometer', 'optical microscope', 'positron emission tomography scanner', 'programmable array microscope', 'radiography instrument', 'scanning force microscope', 'small-animal image acquisition device', 'spinning-disk confocal microscope', 'stereo microscope', 'ultrasound machine']
# Cluster 3: ['(S)-1-(4-bromoacetamidobenzyl)EDTA', '1,1-dihydroxy-3-ethoxy-2-butanone', '1M-Duo Infinium HD BeadChip', '2x2 factorial design', '454 Genome Sequence 20', '454 Genome Sequencer FLX', "5'-adenylyl sulfate", "5-bromo-2'-deoxyuridine", 'A10-Analyzer', 'AB SOLiD System', 'Affymetrix Clariom S Assay, Human', 'Affymetrix Clariom S Assay, Mouse', 'Affymetrix Human Exon Junction Array', 'Affymetrix Human Gene 2.0 ST Array', 'Affymetrix Human Genome U219 Array', 'Affymetrix Human Transcriptome Array 2.0', 'Affymetrix Mouse Exon Junction Array', 'Affymetrix Mouse Gene 1.0 ST Array', 'Affymetrix Mouse Gene 2.1 ST Array', 'Affymetrix Mouse Genome 430 2.0 Array', 'Affymetrix Mouse Genome 430A 2.0 Array', 'Affymetrix Rhesus Macaque Genome Array', 'Agilent-026655 Whole Mouse Genome Microarray 4x44K v2', 'Agilent-030493 SurePrint G3 Mouse Exon 4x180K Microarray', 'Agilent-074809 SurePrint G3 Mouse GE v2 8x60K Microarray', 'Alexa Fluor 532', 'Alexa Fluor 546', 'Alexa Fluor 555', 'B cell', 'BG-Counter', 'BG-Sentinel trap', 'BG-lure scent dispenser', 'BMI range inclusion criterion', 'Bactiflow', 'Berichrom(r) Antithrombin III (A) Kit', 'BioSorter1000', 'BioSorter250', 'BioSorter500', 'Bruker BEST NMR system', 'Bruker SampleRail system', 'C-reactive protein', 'CD3 subunit with immunoglobulin domain', 'CD4 molecule', 'CHEBI_15422', 'CYFlow ML', 'Cell Lab Quanta SC', 'ChIP-chip by tiling array design', 'ChIP-chip design', 'ChIP-seq design', 'Cy3 dye', 'Cy5 dye', 'CyFlow SL', 'CyFlow SL3', 'CyFlow Space', 'Cyan', 'CytoBuoy flow cytometer analyzer', 'CytoSub', 'DNA extraction/purification instrument', 'DNA ligase', 'DNA methylation profiling by array design', 'DNA methylation profiling by high throughput sequencing design', 'DNA microarray', 'DNA polymerase complex', 'DNA sequencer', 'DNA synthesizer', "Dulbecco's modified Eagle medium", 'EDTA(4-)', 'EL-4 cell line', 'ELISA microplate reader', 'ELISA microplate washer', 'ERCC RNA spike-in', 'Epstein Barr virus transformed B cell', 'FACS Calibur', 'FACS Canto', 'FACS Canto2', 'FACS Scan', 'FACSvantage', 'FC 500', 'FFPE specimen', 'Faraday cage', 'Follicle stimulating hormone', 'GenePattern software', 'Guava EasyCyte Mini', 'Guava EasyCyte Plus', 'Guava Personal Cell Analysis', 'HIV exclusion criterion', 'HeLa cell line', 'HeliScope Single Molecule Sequencer', 'Human 2.1M Whole-Genome CGH Tiling Array v2.0', 'Human 3x720K Whole Genome CGH Tiling Array', 'Human 6x630K CGH Whole Genome Tiling Array', 'Human Exon 1.0 ST tilling array', 'Human Genome U133 Plus 2.0 tiling array', 'Human Genome U133 tiling array', 'IgA immunoglobulin complex', 'IgE immunoglobulin complex', 'IgG immunoglobulin complex', 'IgM immunoglobulin complex', 'Illumina BeadChip', 'Illumina Genome Analyzer', 'Illumina Genome Analyzer II', 'Illumina Genome Analyzer IIe', 'Illumina Genome Analyzer IIx', 'Illumina HiSeq 1000', 'Illumina HiSeq 1500', 'Illumina HiSeq 2000', 'Illumina HiSeq 2500', 'Illumina HiSeq 3000', 'Illumina HiSeq 4000', 'Illumina HiSeq X Ten', 'Illumina HiSeq series instrument', 'Illumina HumanHT-12 V4.0 expression beadchip', 'Illumina Infinium MethylationEPIC v1.0 BeadChip', 'Illumina Infinium MethylationEPIC v2.0 BeadChip', 'Illumina Infinium Omni5Exome-4 Kit', 'Illumina MiSeq', 'Illumina MiniSeq', 'Illumina MouseRef-8 v2.0 beadchip', 'Illumina NextSeq 1000', 'Illumina NextSeq 500', 'Illumina NextSeq 550', 'Illumina NextSeq series instrument', 'Illumina NovaSeq 6000', 'Illumina NovaSeq X', 'Illumina NovaSeq X Plus', 'Illumina NovaSeq series instrument', 'Illumina methylation BeadChip', 'Ion 314 Chip v2', 'Ion 316 Chip v2', 'Ion 318 Chip v2', 'JAWS II cell line', 'JEOL NMR instrument', 'JY cell line', 'Jurkat cell line', 'L cell line', 'LSR2', 'LSRFortessa X-20', 'LactoScope C4', 'Leica Peloris rapid tissue processor', 'Li-Cor 4300 DNA Analysis System', 'Luteinizing hormone', 'MACS Quant', 'MHC:ligand complex', 'Methylation 27K BeadChip', 'Methylation 450K BeadChip', 'Microm Ergostar HM200', 'Mosquito Magn ...
# Cluster 4: ['F minus mating type', 'IP-10 production', 'Saccharomyces cerevisiae mating type', 'Schizosaccharomyces pombe mating type', 'XCL1 production', 'amphiregulin production', 'bacterial mating type', 'chemokine (C-C motif) ligand 1 production', 'chemokine (C-C motif) ligand 19 production', 'chemokine (C-C motif) ligand 21 production', 'chemokine (C-C motif) ligand 22 production', 'chemokine (C-C motif) ligand 4 production', 'chemokine (C-C motif) ligand 5 production', 'chemokine (C-X-C motif) ligand 12 production', 'chemokine (C-X-C motif) ligand 13 production', 'chemokine (C-X-C motif) ligand 16 production', 'chemokine (C-X-C motif) ligand 9 production', 'chemokine production', 'connective tissue growth factor production', 'cytokine production', 'cytokine production involved in immune response', 'cytokine production involved in inflammatory response', 'denotator type', 'epitope specific GM-CSF release by T cells', 'epitope specific IFN-g release by T cells', 'epitope specific IL-10 release by T cells', 'epitope specific IL-12 release by T cells', 'epitope specific IL-13 release by T cells', 'epitope specific IL-17 release by T cells', 'epitope specific IL-18 release by T cells', 'epitope specific IL-1b release by T cells', 'epitope specific IL-2 release by T cells', 'epitope specific IL-4 release by T cells', 'epitope specific IL-5 release by T cells', 'epitope specific IL-6 release by T cells', 'epitope specific IP-10 production by T cells', 'epitope specific RANTES production by T cells', 'epitope specific TNF release by T cells', 'epitope specific XCL1 release by T cells', 'epitope specific chemokine (C-C motif) ligand 1 production by T cells', 'epitope specific chemokine (C-C motif) ligand 19 production by T cells', 'epitope specific chemokine (C-C motif) ligand 21 production by T cells', 'epitope specific chemokine (C-C motif) ligand 22 production by T cells', 'epitope specific chemokine (C-C motif) ligand 4 production by T cells', 'epitope specific chemokine (C-X-C motif) ligand 12 production by T cells', 'epitope specific chemokine (C-X-C motif) ligand 13 production by T cells', 'epitope specific chemokine (C-X-C motif) ligand 16 production by T cells', 'epitope specific chemokine (C-X-C motif) ligand 9 production by T cells', 'epitope specific cytokine production by T cells', 'epitope specific granulocyte colony stimulating factor production by T cells', 'epitope specific interferon-beta production by T cells', 'epitope specific interleukin-1 alpha production by T cells', 'epitope specific interleukin-15 production by T cells', 'epitope specific interleukin-16 production by T cells', 'epitope specific interleukin-17A production by T cells', 'epitope specific interleukin-17F production by T cells', 'epitope specific interleukin-21 production by T cells', 'epitope specific interleukin-22 production by T cells', 'epitope specific interleukin-23 production by T cells', 'epitope specific interleukin-3 production by T cells', 'epitope specific interleukin-7 production by T cells', 'epitope specific interleukin-8 production by T cells', 'epitope specific interleukin-9 production by T cells', 'epitope specific lymphotoxin A production by T cells', 'epitope specific macrophage inflammatory protein-1 alpha production by T cells', 'epitope specific macrophage inflammatory protein-1 gamma production by T cells', 'epitope specific monocyte chemotactic protein-1 production by T cells', 'epitope specific transforming growth factor-beta production by T cells', 'epitope specific tumor necrosis factor (ligand) superfamily member 11 production by T cells', 'epitope specific tumor necrosis factor superfamily cytokine production by T cells', 'epitope specific vascular endothelial growth factor production by T cells', 'granulocyte colony-stimulating factor production', 'granulocyte macrophage colony-stimulating factor production', 'interferon-alpha production', 'interferon-beta production', 'interleukin-1 alpha production', 'interle ...
# Cluster 5: ['Bioinformatics Resource Center', 'Bioinformatics Resource Center contact person', 'biomedical laboratory organization', 'courier organization', 'grant agency', 'hospital organization', 'molecular analysis facility organization', 'organization', 'organization of Bioinformatics Resource Center contact person', 'organization of sequencing facility contact person', 'organization of specimen collector', 'organization of specimen provider principal investigator', 'regulatory agency', 'research organization', 'sequencing facility organization', 'specimen repository organization']
# Cluster 6: ['3D structural organization datum', '50% dissociation of binding temperature (Tm)', 'DNA methylation profiling data', 'DNA sequence data', 'EC50 binding datum', 'Edinburgh score', 'Eukaryota', 'FWER adjusted p-value', 'IC50 binding datum', 'PDB file', 'adapter sequence data', 'adapter-trimmed sequence data', 'age measurement datum', 'age since birth at time of enrollment', 'age since birth at time of visit', 'age since birth measurement datum', 'age since coitus measurement datum', 'age since culture seeding measurement datum', 'age since eclosion measurement datum', 'age since egg laying measurement datum', 'age since fertilization measurement datum', 'age since germination measurement datum', 'age since hatching measurement datum', 'age since planting measurement datum', 'age since sowing measurement datum', 'age when gave birth to first child', 'aligned sequence data', 'allele information', 'altitude measurement datum', 'antigen specific antibodies assay datum', 'antigen specific antibodies in blood assay datum', 'antigen specific antibodies in milk assay datum', 'average value', 'axillary temperature measurement datum', 'bacteria in blood datum', 'bacteria in feces datum', 'bacteria in induced sputum datum', 'bacteria in lung datum', 'bacteria in pleural fluid datum', 'binding constant', 'binding datum', 'binding off rate measurement datum (koff)', 'binding on rate measurement datum (kon)', 'blood assay datum', 'blood microbiology datum', 'bone marrow microbiology datum', 'categorical binding datum', 'categorical label', 'categorical measurement datum', 'categorical value specification', 'center value', 'cerebrospinal fluid assay datum', 'cerebrospinal fluid microbiology datum', 'classified data set', 'cluster', 'computation run time', 'conditional specification', 'curated information', 'curation status specification', 'data about an ontology part', 'data item', 'data set', 'date process started', 'datum label', 'demultiplexed sequence data', 'diagnosis', 'diagnosis of hepatitis B', 'diagnosis of infectious disease', 'differential expression analysis data', 'dose', 'easting coordinate measurement datum', 'endotracheal aspirate assay datum', 'endotracheal tube aspirate microbiology datum', 'entomological data item', 'equilibrium association constant (KA)', 'equilibrium dissociation constant (KD)', 'equilibrium dissociation constant (KD) approximated by EC50', 'equilibrium dissociation constant (KD) approximated by IC50', 'error corrected data set', 'eukaryota in blood datum', 'eukaryota in induced sputum datum', 'eukaryota in lung datum', 'eukaryota in placental blood datum', 'eukaryota in pleural fluid datum', 'eukaryota in umbilical cord blood datum', 'feces assay datum', 'feces microbiology datum', 'fluorescent reporter intensity', 'full karyotype information', 'genetic alteration information', 'genetic characteristics information', 'genetic population background information', 'genome coverage', 'genotype information', 'half life datum (t 1/2)', 'half life of binding datum', 'half maximal effective concentration (EC50)', 'half maximal inhibitory concentration (IC50)', 'handedness categorical measurement datum', 'human leukocyte antigen mismatch count', 'induced sputum assay datum', 'induced sputum microbiology datum', 'input gene sequence stop site', 'input protein sequence stop site', 'insecticide resistance datum', 'karyotype information', 'latitude coordinate measurement datum', 'length measurement datum', 'longitude coordinate measurement datum', 'lower limit of detection', 'lung microbiology datum', 'mass measurement datum', 'mass value specification', 'maximum age value specification', 'measured expression level', 'measurement datum', 'measurement device', 'measurement unit label', 'medication dose value specification', 'medication time value specification', 'merged aligned sequence data', 'mid-upper arm circumference datum', 'milk assay datum', 'minimal inhibitory concentration', 'minimum age value spe ...
# Cluster 7: ['disposable patient gown', 'patient gown', 'reusable patient gown']
# Cluster 8: ['background correction objective', 'correction objective']
# Cluster 9: ['PATO_0000011', 'activity (of a radionuclide)', 'circular', 'device setting', 'frozen', 'mass', 'mixed sex', 'movement quality', 'organismal quality', 'phenotype', 'physical object quality', 'physical quality', 'population quality', 'pressure', 'quality', 'quality of a substance', 'relational quality', 'temperature', 'time']
# Cluster 10: ['International Federation of Gynecology and Obstetrics cervical cancer stage value specification', 'categorical value specification', 'clinical tumor stage group according to AJCC 7th edition', 'histologic grade according to AJCC 7th edition', 'histologic grade according to the Fuhrman Nuclear Grading System', 'hypertension grade', 'life cycle stage', 'ordinal value specification', 'pathologic distant metastases stage for colon according to AJCC 7th edition', 'pathologic distant metastases stage for kidney according to AJCC 7th edition', 'pathologic distant metastases stage for lung according to AJCC 7th edition', 'pathologic distant metastases stage for ovary according to AJCC 7th edition', 'pathologic lymph node stage for colon and rectum according to AJCC 7th edition', 'pathologic lymph node stage for kidney according to AJCC 7th edition', 'pathologic lymph node stage for lung according to AJCC 7th edition', 'pathologic lymph node stage for ovary according to AJCC 7th edition', 'pathologic primary tumor stage for kidney according to AJCC 7th edition', 'pathologic primary tumor stage for lung according to AJCC 7th edition', 'pathologic primary tumor stage for ovary according to AJCC 7th edition', 'presence or over-threshold value specification']
# Cluster 11: ['Amniota', 'Arthropoda', 'Bilateria', 'Caenorhabditis elegans', 'Danio rerio', 'Diptera', 'Drosophila melanogaster', 'Ecdysozoa', 'Euteleostomi', 'Gallus gallus', 'Metazoa', 'Pancrustacea', 'Tetrapoda', 'Vertebrata <vertebrates>', 'Xenopus <genus>']
# Cluster 12: ['antibody purification of H2-IA protein complex', 'antibody purification of H2-IAg7 protein complex']
# Cluster 13: ['Insulin resistance', 'accessed material role', 'adjuvant role', 'allergy', 'analyte role', 'antigen role', 'array manufacturer role', 'arthropod attractor role', 'assay antigen role', 'autoimmune disease', 'barcode target locus role', 'baseline participant role', 'biological replicate role', 'buffer role', 'calibration substance role', 'cancer', 'case role in case-control study', 'centrifuge pellet role', 'clinical research coordinator role', 'cloning insert role', 'cloning vector role', 'cluster study group role', 'cohort role', 'complementary nucleotide probe role', 'complete nutrient role', 'compound study group role', 'contact representative role', 'contract research organization role', 'control role in case-control study', 'crossover population role', 'detector reagent role', 'disease', 'disposition', 'disposition to be a product of antigen processing and presentation', 'disposition to be bound by an MHC protein complex', 'disposition to be bound by an adaptive immune receptor', 'disposition to cause an allergic reaction', 'disposition to infect an organism', 'donor role', 'drug role', 'dye role', 'dye swap quality control role', 'evaluant role', 'feed role', 'health care provider role', 'hospital role', 'host of immune response role', 'host role', 'human pathogenicity disposition', 'immune epitope carrier role', 'immunogen role', 'immunologic adjuvant role', 'infectious disease', 'investigation agent role', 'magnetic resonance imaging evaluant role', 'manufacturer role', 'material amplification role', 'material sample role', 'material sequencing library preparation role', 'material supplier role', 'material to be added role', 'measurand role', 'negative reference substance role', 'notified body role', 'nucleic acid template role', 'nutrient role', 'obsolete health care provider role', 'obsolete_label role', 'obsolete_protocol service provider role', 'pH indicator dye role', 'participant under investigation role', 'pathogen role', 'pathogenic disposition', 'pathologist role', 'patient role', 'placebo role', 'plan', 'positive reference substance role', 'primer role', 'principal investigator role', 'proxy respondent role', 'randomized group participant role', 'reactant role', 'reagent', 'reagent role', 'realizable entity', 'reference genome role', 'reference subject role', 'reference substance role', 'regulation-assigned role', 'regulator role', 'regulatory role', 'reporting party role', 'responsible party role', 'restricting MHC role', 'role', 'role of Institutional Review Board', 'role of certified IRB professional', 'role of impartial witness', 'role of pathology review board', 'role of regulator of consumables and medical devices', 'sequence annotation reporting role', 'service consumer role', 'service provider role', 'solute role', 'specimen collector role', 'specimen role', 'spike-in quality control role', 'sponsor role', 'study group role', 'sub-investigator role', 'supernatant role', 'target of material addition role', 'technical replicate role', 'test substance role', 'to be treated with active ingredient role', 'to be treated with placebo role', 'trial monitor role', 'trial statistician role', 'worker role']
# Cluster 14: ['long pass filter', 'optical filter', 'short pass filter']
# Cluster 15: ['Obsolete Class', 'obsolete B cell epitope competitive binding assay', 'obsolete B cell epitope direct binding assay', 'obsolete B cell epitope specific X-ray crystallography assay', 'obsolete MHC multimer staining assay', 'obsolete T cell recognition of eluted MHC ligand assay', 'obsolete biological vector role', 'obsolete cell bound MHC binding constant determination assay', 'obsolete cell bound MHC direct binding assay', 'obsolete cell lysate MHC binding constant determination assay', 'obsolete hospital', 'obsolete intracellular cytokine staining assay', 'obsolete intracellular material detection by flow cytometry assay', 'obsolete molecular label role', 'obsolete performing a diagnosis', 'obsolete purified MHC direct binding assay', 'obsolete_DNA ligase', 'obsolete_activation', 'obsolete_adipose tissue', 'obsolete_ambidexterious handedness', 'obsolete_anatomical entity', 'obsolete_blinded medication role', 'obsolete_cell line cell', 'obsolete_collection (of entities of organismal origin)', 'obsolete_defined processes', 'obsolete_defined_material', 'obsolete_diethyl pyrocarbonate', 'obsolete_disease', 'obsolete_documenting', 'obsolete_dropout role', 'obsolete_enrollment', 'obsolete_handedness', 'obsolete_heart', 'obsolete_identification', 'obsolete_immortal cell line culture', 'obsolete_liver', 'obsolete_material access provider role', 'obsolete_molecular concentration', 'obsolete_occurrence of disease', 'obsolete_peritoneum', 'obsolete_primary structure of protein', 'obsolete_primary structure of sequence macromolecule', 'obsolete_qualitative binding detection assay', 'obsolete_right handedness', 'obsolete_role of being first subject treated', 'obsolete_specimen fixation function', 'obsolete_study result', 'obsolete_training service provider role', 'obsolete_trypsinized material', 'obsolete_upper respiratory specimen']
# Cluster 16: ['brother clinical history of cancer', 'clinical history', 'clinical history of cancer', 'daughter clinical history of cancer', 'exposure to second hand smoke', 'exposure to second hand smoke in household during childhood', 'family clinical history of cancer', 'father clinical history of cancer', 'grandfather clinical history of cancer', 'grandmother clinical history of cancer', 'gynecologic surgery history', 'history', 'hormonal birth control use history', 'hormonal replacement therapy history', 'hysterectomy history', 'neither hysterectomy nor oophorectomy history', 'nephew clinical history of cancer', 'niece clinical history of cancer', 'passage history record', 'pregnancy history', 'sister clinical history of cancer', 'uncle clinical history of cancer', 'unilateral oophorectomy history', 'unknown clinical history of cancer']
# Cluster 17: ['epitope specific granulysin production by T cells', 'granulysin production', 'granulysin release during T cell degranulation']
# Cluster 18: ['cytological stain role', 'dye role', 'molecular label role', 'radiolabel role', 'reagent role', 'vital dye role']
# Cluster 19: ['analysis subset ontology module', 'base ontology module', 'blot module', 'bridge ontology module', 'curation subset ontology module', 'editors ontology module', 'exclusion subset ontology module', 'generated ontology module', 'import ontology module', 'main release ontology module', 'obo basic subset ontology module', 'ontology module', 'ontology module subsetted by expressivity', 'reasoned ontology module', 'single layer subset ontology module', 'species subset ontology module', 'subset ontology module', 'taxonomic bridge ontology module', 'template generated ontology module']
# Cluster 20: ['endotracheal aspirate specimen', 'endotracheal tube specimen', 'lower respiratory tract aspirate specimen', 'lower respiratory tract specimen', 'lung specimen', 'tracheal aspirate specimen']
# Cluster 21: ['cultured CD4- T cell population', 'cultured CD4-/CD8- T cell population', 'cultured CD8- T cell population']
# Cluster 22: ['transcription profiling identification objective', 'transcription start site identification objective']
# Cluster 23: ['adaptive immune effector function', 'antigen presentation function', 'cell transfer function', 'connection function', 'consume data function', 'contain function', 'containing a specimen function', 'cool function', 'current amplification function', 'display function', 'effector T cell function', 'electricity supply function', 'energy supply function', 'environment control function', 'excitation function', 'filter function', 'freeze function', 'function', 'gas filter function', 'heat function', 'image acquisition function', 'information processor function', 'injection function', 'ionization function', 'light emission function', 'liquid filter function', 'magnify function', 'material combination function', 'material separation function', 'measure function', 'mechanical function', 'perturb function', 'pump function', 'reagent application function', 'record function', 'signal amplification function', 'signal conversion function', 'solid support function', 'sort function', 'specimen fixation function', 'stabilization function', 'sterilization function', 'synthesizing function', 'transfer function']
# Cluster 24: ['antibody purification of HLA protein complex with DQ3 serotype', 'antibody purification of MHC class II protein complex', 'antibody purification of cattle MHC class II protein complex', 'antibody purification of human MHC class II protein complex', 'antibody purification of mouse MHC class II protein complex', 'antibody purification of mouse MHC class II protein complex and/or rat MHC class II protein complex with RT1-A haplotype']
# Cluster 25: ['DNASE 1 structure mapping assay', 'RNA ADA I RNA structure mapping assay', 'RNASE CL3 structure mapping assay', 'RNASE T1 structure mapping assay', 'RNASE T2 structure mapping assay', 'RNASE U2 structure mapping assay', 'RNASE V1 structure mapping assay', 'parallel analysis of RNA structure assay', 'single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing']
# Cluster 26: ['histologic grade for ovarian tumor', 'histologic grade for ovarian tumor according to the World Health Organization']
# Cluster 27: ['brain specimen', 'cerebellum', 'cerebellum specimen']
# Cluster 28: ['B cell epitope specific opsonization', 'opsonization']
# Cluster 29: ['AVANCE II spectrometer', 'Bruker AC series NMR instrument', 'Bruker AMX series NMR instrument', 'Bruker Capillary LC-NMR platform', 'Bruker LC-NMR platform', 'Bruker LC-NMR/MS platform', 'Bruker Metabolic Profiler', 'Bruker NMR Case sample changer', 'Bruker NMR instrument', 'Bruker NMR magnet', 'Bruker NMR probe', 'Bruker SPE-NMR platform', 'Bruker UltraShield NMR magnet', 'Bruker UltraShield Plus NMR magnet', 'Bruker autosampler', 'Bruker micro imaging probe', 'JEOL ECX NMR spectrometer', 'tecmag NMR console']
# Cluster 30: ['disposable footwear cover', 'footwear cover', 'laboratory coat', 'medical cap', 'medical glove', 'medical gown', 'personal protective clothing item', 'personal protective device', 'personal protective glove', 'protective apron', 'protective coverall', 'protective sleeve', 'reusable footwear cover', 'scrubs', 'surgical gown']
# Cluster 31: ['ankle joint', 'bulbar assessment', 'comparative phenotypic assessment', 'deep tendon reflex assessment', 'deep tendon reflex assessment of the ankle joint', 'deep tendon reflex assessment of the brachioradialis', 'deep tendon reflex assessment of the knee joint', 'deep tendon reflex assessment of the tendon of biceps brachii', 'dysmetria assessment', 'facial atrophy assessment', 'finger taps assessment', 'finger to finger assessment', 'forced cough assessment', 'functional assessment of individual', 'gait assessment', 'heel along shin assessment', 'heel to shin assessment', 'limb coordination assessment', 'limits of stability assessment', 'lower limb coordination assessment', 'muscle atrophy assessment', 'muscle weakness assessment', 'nervous system functionality assessment', 'nose to finger assessment', 'position', 'position sense assessment', 'rapid alternating hands assessment', 'sitting posture assessment', 'speech test assessment', 'spontaneous speech assessment', 'stance feet apart assessment', 'stance feet apart assessment, with eyes closed', 'stance feet together assessment', 'stance feet together assessment, with eyes closed', 'stance on one foot assessment', 'tandem stance assessment', 'tandem walk assessment', 'upper limb coordination assessment', 'upright stability assessment', 'vibratory sense assessment']
# Cluster 32: ['lowess global transformation', 'lowess group transformation', 'lowess transformation']
# Cluster 33: ['JEOL CapNMR probe', 'JEOL NMR probe']
# Cluster 34: ['CD4-positive, alpha-beta T cell', 'CD8-positive, alpha-beta T cell', 'CD8-positive, alpha-beta cytotoxic T cell', 'alpha-beta T cell', 'mature NK T cell']
# Cluster 35: ['H2-Dq protein complex', 'H2-IA protein complex', 'H2-IAd protein complex', 'H2-IAg7 protein complex', 'H2-Kb protein complex', 'H2-Kd protein complex', 'H2-Kq protein complex', 'H2-Ks protein complex', 'HLA protein complex with A2 serotype', 'HLA protein complex with A24 serotype', 'HLA protein complex with A28 serotype', 'HLA protein complex with A29 serotype', 'HLA protein complex with DQ3 serotype', 'HLA-C protein complex', 'MHC class I protein complex', 'MHC class II protein complex', 'MHC protein complex', 'cattle MHC class I protein complex', 'cattle MHC class II protein complex', 'human MHC class I protein complex', 'mouse MHC class I protein complex', 'mouse MHC class I protein complex with H2-b haplotype', 'mouse MHC class II protein complex', 'mouse MHC protein complex with H2-p haplotype', 'rat MHC class II protein complex with RT1-A haplotype']
# Cluster 36: ['DNA replication identification objective', 'biological feature identification objective', 'cellular feature identification objective', 'cellular structure feature identification objective', 'detection of pathogenic organisms objective', 'mathematical feature', 'molecular feature identification objective', 'molecular function identification objective', 'organism feature identification objective', 'organism species detection objective']
# Cluster 37: ['Advantage Chikungunya IgM Card kit', 'Panbio Dengue Early ELISA kit', 'Panbio Dengue IgM capture ELISA kit', 'SD Bioline Chikungunya IgM RDT kit', 'SD Bioline Chikungunya IgM capture ELISA kit', 'Scrub Typhus Detect IgM ELISA kit', 'assay kit']
# Cluster 38: ['ankle joint functionality', 'biological attribute', 'brachioradialis functionality', 'knee joint functionality', 'limb coordination efficacy', 'lower limb coordination efficacy', 'peripheral nervous system function', 'tendon of biceps brachii functionality', 'upper limb coordination efficacy', 'whole organism stability']
# Cluster 39: ['composition', 'damage', 'damaged', 'morphology', 'size', 'structure']
# Cluster 40: ['artificial pit shelter', 'resting arthropod trap', 'resting bucket', 'resting clay pot trap', 'sticky resting bucket']
# Cluster 41: ['gas chromatography equipment', 'gas chromatography oven', 'gas generator', 'hydrogen generator', 'nitrogen generator']
# Cluster 42: ['APOLLO console', 'tecmag NMR console']
# Cluster 43: ['CMCT structure mapping assay', 'DEPC structure mapping assay', 'DMS structure mapping assay', 'ENU structure mapping assay', 'Fe-BABE RNA structure mapping assay', 'Lead structure mapping assay', 'MPE-Fe(II) structure mapping assay', 'OH-radical structure mapping assay', 'Rhodium DNA structure mapping assay', 'Ruthenium structure mapping assay', 'Terbium RNA structure mapping assay', 'inline probing RNA structure mapping assay', 'kethoxal structure mapping assay', 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing']
# Cluster 44: ["5'-nucleotidase activity", 'B cell epitope specific complement-dependent cytotoxicity', 'B cell epitope specific hypersensitivity', 'B cell epitope specific immune complex formation', 'B cell epitope specific immunoglobulin-mediated neutralization', 'B cell tolerance induction', 'DNA damage response', 'DNA polymerase activity', 'L-alanine:2-oxoglutarate aminotransferase activity', 'L-aspartate:2-oxoglutarate aminotransferase activity', 'L-iditol 2-dehydrogenase (NAD+) activity', 'MHC protein complex binding to ligand', 'MHC:epitope complex binding to TCR', 'RNA nuclease activity', 'acetylcholinesterase activity', 'actin polymerization-dependent cell motility', 'action potential', 'acyl-CoA oxidase activity', 'adaptive immune response', 'alkaline phosphatase activity', 'allergic reaction', 'amylase activity', 'antibody-dependent cellular cytotoxicity', 'antigen binding', 'antigen processing and presentation', 'beta-N-acetylglucosaminidase activity', 'binding', 'biological_process', 'blood coagulation', 'carboxylic ester hydrolase activity', 'catalytic activity', 'cell cycle', 'cell killing', 'cell population proliferation', 'cellular process', 'cholinesterase activity', 'chromosome organization', 'complement-dependent cytotoxicity', 'contact to pathogen carrying biological vector', 'core promoter sequence-specific DNA binding', 'cytotoxic T cell degranulation', 'disease stage', 'environmental proximity to infectious agent', 'epitope binding by adaptive immune receptor', 'epitope specific T cell enhancement of B cell mediated immune response', 'epitope specific granzyme A production by T cells', 'epitope specific perforin production by T cells', 'fertilization', 'glutathione transferase activity', 'granzyme A production', 'granzyme A release during T cell degranulation', 'helper T cell enhancement of B cell mediated immune response', 'helper T cell enhancement of adaptive immune response', 'hemopoiesis', 'hydrolase activity, acting on ester bonds', 'hypersensitivity', 'immune complex formation', 'immune response', 'immunoglobulin binding to epitope', 'immunoglobulin mediated histamine release', 'immunoglobulin mediated immune response', 'immunoglobulin-mediated neutralization', 'infection process', 'isocitrate dehydrogenase [NAD(P)+] activity', 'lactate dehydrogenase activity', 'living in endemic area', 'living with infected household contact', 'macromolecule localization', 'molecular_function', 'monoatomic ion channel activity', 'pathologic process', 'perforin production', 'perforin release during T cell degranulation', 'phagocytosis', 'planning', 'process', 'protein domain specific binding', 'response to stimulus', 'scratching', 'sequence-specific DNA binding', 'tolerance induction', 'unplanned occurrence effecting an investigation']
# Cluster 45: ['band form neutrophil', 'immature neutrophil', 'neutrophil']
# Cluster 46: ['clonal cDNA library', 'phage display library', 'recombinant vector']
# Cluster 47: ['epitope specific interleukin-27 production by T cells', 'interleukin-27 production']
# Cluster 48: ['T1 lesion mask', 'T1 weighted GRE magnetic resonance image data set', 'T1 weighted SE magnetic resonance image data set', 'T1 weighted magnetic resonance image data set', 'T2 FLAIR lesion mask', 'T2 weighted FLAIR magnetic resonance image data set', 'T2 weighted FSE  magnetic resonance image data set', 'T2 weighted SE magnetic resonance image data set', 'T2 weighted STIR magnetic resonance image data set', 'T2 weighted magnetic resonance image data set', 'T2* weighted GRE magnetic resonance image data set', 'background corrected data set', 'baseline high resolution T1 weighted magnetic resonance image data set', 'brain region atlas image data set', 'clustered data set', 'computed image data set', 'data set', 'deterministic brain region atlas image data set', 'diffusion weighted magnetic resonance image data set', 'follow-up high resolution T1 weighted magnetic resonance image data set', 'functional magnetic resonance image data set', 'guanyl-specific ribonuclease T1', 'high resolution T1 weighted magnetic resonance image data set', 'image creation', 'image creation device', 'image cytometer', 'image data set', 'image segmentation map', 'infrared image acquisition device', 'lesion mask', 'magnetic resonance image data set', 'normalized data set', 'oligonucleotide primer set', 'perfusion weighted magnetic resonance image data set', 'post-Gd T1 weighted magnetic resonance image data set', 'probabilistic brain region atlas image dataset', 'proton density magnetic resonance image data set', 'raw image data set', 'raw magnetic resonance image data set', 'raw magnetic resonance image data set reconstruction', 'reconstructed magnetic resonance image data set', 'resting state functional magnetic resonance image data set', 'small-animal image acquisition device', 'task-based functional magnetic resonance image data set', 'topologically preserved clustered data set', 'weighted network graph construction']
# Cluster 49: ['Saccharomyces cerevisiae mating type', 'a mating type (yeast)']
# Cluster 50: ['TF_binding_site', 'assembly', 'experimental_feature', 'miRNA', 'polypeptide', 'primary structure of DNA macromolecule', 'primary structure of RNA molecule', 'region', 'regulatory_region']
# Cluster 51: ['exposure to asbestos history', 'exposure to diesel exhaust history', 'exposure to environmental and workplace carcinogens history', 'exposure to silica history']
# Cluster 52: ['acclimatization', 'exposure of material to environment', 'waiting']
# Cluster 53: ['bile', 'blood', 'bodily fluid', 'capillary blood', 'cerebrospinal fluid', 'cervical mucus', 'milk', 'pericardial fluid', 'placental blood', 'synovial fluid', 'venous blood']
# Cluster 54: ['Arabidopsis thaliana', 'Bacteria', 'Dictyostelium discoideum', 'Eukaryota', 'Orientia tsutsugamushi', 'Plasmodium', 'Plasmodium gametocyte', 'Treponema pallidum', 'blood meal source organism', 'chimera', 'genetically modified organism', 'host of immune response', 'infectious agent', 'organism', 'transgenic organism']
# Cluster 55: ['one-dimensional temporal region', 'temporal region']
# Cluster 56: ['Ascomycota', 'Opisthokonta', 'Saccharomyces cerevisiae', 'Schizosaccharomyces pombe', 'saccharomyceta']
# Cluster 57: ['chemical mutagenesis', 'irradiation mutagenesis', 'random mutagenesis', 'transgenic mutagenesis', 'transposon-induced mutagenesis']
# Cluster 58: ['H&E-stained fixed tissue slide specimen', 'IHC-stained fixed tissue slide specimen', 'fixed tissue slide specimen', 'fixed tissue specimen']
# Cluster 59: ['hormonal birth control current use history', 'hormonal birth control former use history', 'hormonal birth control use history', 'no hormonal birth control use history']
# Cluster 60: ['OBI_0002204', 'cannot be assessed determination', 'reason for lack of data item']
# Cluster 61: ['anterior to', 'dorsal to', 'lateral to', 'position', 'right side of']
# Cluster 62: ['anatomical structure quality', 'cellular quality', 'diploid', 'euploid', 'ploidy']
# Cluster 63: ['animal care protocol', 'magnetic resonance pulse sequence protocol', 'protocol', 'specimen collection protocol']
# Cluster 64: ['disease course', 'occurrence of allergy', 'occurrence of infectious disease']
# Cluster 65: ['alive', 'ambidextrous handedness', 'behavioral quality', 'biological sex', 'dead', 'fasted', 'female', 'handedness', 'hermaphrodite', 'left handedness', 'male', 'obsolete_left handedness', 'organismal quality', 'phenotypic sex', 'right handedness', 'viability']
# Cluster 66: ['GenBank ID', 'PubMed ID', 'SRS identifier', 'centrally registered identifier symbol', 'digital object identifier', 'grant identifier', 'individual organism identifier', 'investigation identifier', 'participant identifier', 'specimen identifier', 'specimen identifier assigned by sequencing facility', 'specimen identifier assigned by specimen repository', 'symbol']
# Cluster 67: ['antibody purification of H2-Dd protein complex', 'antibody purification of H2-Dd protein complex and/or H2-Kd protein complex', 'antibody purification of H2-Kd protein complex']
# Cluster 68: ['algorithm', 'alignment counting algorithm', 'base calling algorithm', 'probabilistic algorithm', 'reference genome-transcriptome alignment algorithm', 'sequence assembly algorithm', 'star algorithm', 'verse algorithm']
# Cluster 69: ['chronic allograft damage index score', 'clinical data item', 'multidimensional fatigue inventory score', "physician's global assessment of disease activity", 'sequential organ failure assessment score']
# Cluster 70: ['cellular_component', 'chromosome', 'membrane-bounded organelle', 'mitochondrion']
# Cluster 71: ['mating type', 'yeast mating type']
# Cluster 72: ['Cytomegalovirus', 'Orthoherpesviridae', 'Viruses', 'human gammaherpesvirus 4']
# Cluster 73: ['bacteria in nasopharyngeal or oropharyngeal swab datum', 'eukaryota in nasopharyngeal or oropharyngeal swab datum', 'nasopharyngeal or oropharyngeal swab microbiology datum', 'virus in nasopharyngeal or oropharyngeal swab datum']
# Cluster 74: ['antibody purification of H2-Db protein complex', 'antibody purification of H2-Ld protein complex, H2-Db protein complex, and/or H2-Dq protein complex', 'antibody purification of mouse MHC class I protein complex', 'antibody purification of mouse MHC class I protein complex with H2-b haplotype and/or mouse MHC protein complex with H2-p haplotype']
# Cluster 75: ['Chikungunya virus', 'HIV-1 group O', 'Human immunodeficiency virus 1', 'Human immunodeficiency virus 2', 'Kitrinoviricota', 'Lentivirus', 'Revtraviricetes', 'Riboviria']
# Cluster 76: ['assay measuring epitope specific Ig-mediated histamine release', 'assay measuring epitope specific activation of additional immune response in vitro', 'assay measuring epitope specific complement-dependent cytotoxicity', 'assay measuring epitope specific immune complex formation']
# Cluster 77: ['device creation objective', 'genetic transformation objective', 'material combination objective', 'material transformation objective']
# Cluster 78: ['cell-attached patch clamp assay', 'inside-out patch clamp assay', 'outside-out patch clamp assay', 'patch clamp assay', 'whole-cell patch clamp assay']
# Cluster 79: ['capsule shell', 'filled capsule', 'pill']
# Cluster 80: ['Bruker B-ACS system', 'Bruker SampleJet system', 'Bruker autosampler', 'autosampler']
# Cluster 81: ['oral administration', 'oral ingestion of pill']
# Cluster 82: ['Kaplan Meier', 'proportional hazards model estimation', 'survival analysis data transformation']
# Cluster 83: ['knockdown arthropod specimen collection by pyrethrum spray', 'knockdown arthropod specimen collection process']
# Cluster 84: ['optical microscope', 'stereo microscope']
# Cluster 85: ['material maintenance service', 'material storage service']
# Cluster 86: ['enhanced cross-linking immunoprecipitation high-throughput sequencing assay', 'individual-nucleotide resolution cross-linking and immunoprecipitation sequencing assay']
# Cluster 87: ['dendrogram', 'dose response curve', 'dot plot', 'graph', 'heatmap', 'histogram', 'line graph', 'scatter plot', 'survival curve']
# Cluster 88: ['precursor role', 'reactant role', 'solvent role']
# Cluster 89: ['DNA restriction enzyme digestion', 'specific enzymatic cleavage']
# Cluster 90: ['JEOL ECA NMR spectrometer', 'JEOL NMR instrument']
# Cluster 91: ['HLA-DP protein complex', 'HLA-DR protein complex', 'human MHC class II protein complex']
# Cluster 92: ['atmosphere', 'growth environment']
# Cluster 93: ['F mating type', 'bacterial mating type']
# Cluster 94: ['eye specimen', 'vitreous humor', 'vitreous humor specimen']
# Cluster 95: ['DNA extract', 'high molecular weight DNA extract']
# Cluster 96: ['enhancer-trap mutagenesis', 'gene-trap mutagenesis', 'transgenic mutagenesis']
# Cluster 97: ['insecticide resistance time response assay', 'insecticide resistance time response by WHO paper kit assay', 'insecticide resistance time response by bottle assay']
# Cluster 98: ['exponential base', 'log base', 'mathematical feature', 'number of variables', 'polynomial degree']
# Cluster 99: ['RNA extraction', 'cytoplasmic RNA extraction', 'extraction', 'extraction date', 'nuclear RNA extraction', 'nucleic acid extraction', 'organellar RNA extraction', 'polyA RNA extraction', 'row submatrix extraction', 'submatrix extraction', 'viral RNA extraction']
# Cluster 100: ['EL++ ontology module', 'ontology module subsetted by OWL profile']
# Cluster 101: ['transcription profiling by array assay', 'transcription profiling by tiling array assay']
# Cluster 102: ['liquid extraction robot', 'liquid handler']
# Cluster 103: ['Schizosaccharomyces pombe mating type', 'h minus', 'h plus']
# Cluster 104: ['K-fold cross validation method', 'boostrapping', 'leave one out cross validation method', 'statistical model validation']
# Cluster 105: ['Centers for Disease Control and Prevention light trap', 'odor baited CDC light trap']
# Cluster 106: ['entity', 'occurrent', 'process boundary', 'spatiotemporal region']
# Cluster 107: ['high performance liquid chromatography instrument', 'liquid chromatography instrument']
# Cluster 108: ['TALEN mediated mutagenesis', 'cas mediated mutagenesis', 'endonuclease mediated mutagenesis']
# Cluster 109: ['global modularity calculation', 'network graph quality calculation']
# Cluster 110: ['flow rate', 'fluid flow rate', 'movement quality']
# Cluster 111: ['fluorescence', 'luminous flux', 'optical quality', 'quality of interaction of a substance with electromagnetic radiation']
# Cluster 112: ['amniotic fluid', 'organism substance', 'respiratory system fluid/secretion', 'saliva', 'sputum', 'urine']
# Cluster 113: ['secondary structure of RNA molecule', 'secondary structure of sequence macromolecule']
# Cluster 114: ['Bruker high resolution probe', 'flow high resolution probe', 'high resolution magic angle spin probe', 'tecmag EAGLE probe']
# Cluster 115: ['Varian GEMINI spectrometer', 'Varian MERCURY spectrometer', 'Varian NMR instrument', 'Varian UNITY INOVA spectrometer', 'Varian UNITY spectrometer', 'Varian VXR spectrometer']
# Cluster 116: ['Dengue virus', 'Flaviviridae', 'Hepacivirus hominis']
# Cluster 117: ['material separation objective', 'separation into different composition objective']
# Cluster 118: ['concentration of', 'molecular quality', 'osmolality']
# Cluster 119: ['dye swap merge', 'replicate analysis']
# Cluster 120: ['computed tomography imaging assay', 'imaging assay', 'magnetic resonance imaging assay', 'positron emission tomography imaging assay']
# Cluster 121: ['protein and DNA interaction identification objective', 'protein and RNA interaction identification objective', 'sequence feature identification objective']
# Cluster 122: ['human specimen set', 'specimens collected in one encounter']
# Cluster 123: ["3' rapid amplification of cDNA ends", "5' RNA ligase mediated rapid amplification of cDNA ends", "5' rapid amplification of cDNA ends", 'rapid amplification of cDNA ends']
# Cluster 124: ['cross over design', 'n-to-1 design', 'repeated measure design']
# Cluster 125: ['sequence_assembly', 'supercontig']
# Cluster 126: ['light trap', 'light trap for indoor use', 'light trap for outdoor use']
# Cluster 127: ['Immunization in vivo', 'Individual epitope immunization in vivo', 'immunization']
# Cluster 128: ['T cell tolerance induction', 'epitope specific T cell tolerance induction', 'epitope specific tolerance induction by T cells']
# Cluster 129: ['Euarchontoglires', 'Mammalia', 'Rodentia']
# Cluster 130: ['face mask', 'face shield', 'medical mask', 'non-medical mask']
# Cluster 131: ['concentration unit', 'frequency unit', 'length unit', 'mass unit', 'measurement unit label', 'pressure unit', 'substance unit', 'time unit', 'volume unit']
# Cluster 132: ['Bruker NMR magnet', 'Bruker US 2 NMR magnet', 'Bruker Ultrastabilized NMR magnet']
# Cluster 133: ['Homo sapiens', 'specimen collector']
# Cluster 134: ['machine learning', 'supervised machine learning', 'ultrasound machine', 'unsupervised machine learning']
# Cluster 135: ['epithelial cell', 'hepatocyte', 'mesothelial cell']
# Cluster 136: ['adapter-sequence trimming', 'sequence trimming']
# Cluster 137: ['Eastern Cooperative Oncology Group score value specification', 'Karnofsky score vaue specification', 'performance status value specification']
# Cluster 138: ['external import ontology module', 'import ontology module']
# Cluster 139: ['epitope specific type IV hypersensitivity by T cells', 'type IV hypersensitivity']
# Cluster 140: ['BCL format', 'data format specification']
# Cluster 141: ['DNA adenine methyltransferase identification assay', 'DamID-seq']
# Cluster 142: ['hydrogen/deuterium exchange footprinting assay', 'hydrogen/deuterium exchange footprinting assay measuring binding of a B cell epitope:antibody complex']
# Cluster 143: ['nasopharyngeal aspirate specimen', 'nasopharyngeal swab specimen', 'nasopharynx specimen']
# Cluster 144: ['Cell DIVE multiplexed imaging assay', 'co-detection by indexing assay', 'multiplexed fluorescent antibody imaging assay']
# Cluster 145: ['methodology testing objective', 'protocol optimization objective', 'protocol testing objective']
# Cluster 146: ['directed mutagenesis', 'targeted mutagenesis']
# Cluster 147: ['B cell receptor repertoire sequencing assay', 'single cell B cell receptor repertoire sequencing assay']
# Cluster 148: ['B cell epitope specific histamine secretion mediated by immunoglobulin', 'histamine secretion mediated by immunoglobulin']
# Cluster 149: ['peptide', 'synthetic peptide']
# Cluster 150: ['Bruker 1mm MicroProbe', 'Bruker CryoProbe', 'Bruker NMR probe', 'Bruker solid magic angle spinning probe']
# Cluster 151: ['collection of specimens', 'specimens collected longitudinally']
# Cluster 152: ['epitope specific granzyme B production by T cells', 'granzyme B production', 'granzyme B release during T cell degranulation']
# Cluster 153: ['material information bearer', 'random access memory']
# Cluster 154: ['Murinae', 'Mus musculus', 'Rattus norvegicus']
# Cluster 155: ['edge betweenness calculation', 'edge quality calculation']
# Cluster 156: ['figure', 'image']
# Cluster 157: ['feces', 'meconium']
# Cluster 158: ['capillary electrophoresis instrument', 'electrophoresis system']
# Cluster 159: ['arterial blood', 'umbilical cord blood']
# Cluster 160: ['areola']
# Cluster 161: ['BioSorter2000']
# Cluster 162: ['nitrile glove']
# Cluster 163: ['ovitrap']
# Cluster 164: ['contig']
# Cluster 165: ['EDTA methidiumpropylamide']
# Cluster 166: ['mouth']
# Cluster 167: ['Luminex 100', 'Luminex 200']
# Cluster 168: ['obsolete_platform']
# Cluster 169: ['adverse event trigger']
# Cluster 170: ['OBI_0002203']
# Cluster 171: ['obsolete_polymer']
# Cluster 172: ['cloaca']
# Cluster 173: ['biomaterial purity']
# Cluster 174: ['transthyretin']
# Cluster 175: ['antibacterial']
# Cluster 176: ['soil']
# Cluster 177: ['MosquiTRAP']
# Cluster 178: ['obsolete_defined_output']
# Cluster 179: ['microcentrifuge']
# Cluster 180: ['1-D extent', '3-D extent']
# Cluster 181: ['aneuploid']
# Cluster 182: ['inductive reasoning']
# Cluster 183: ['diluted']
# Cluster 184: ['modular decomposition']
# Cluster 185: ['expectation maximization']
# Cluster 186: ['haploid']
# Cluster 187: ['parameter threshold']
# Cluster 188: ['podzol']
# Cluster 189: ['chart recorder']
# Cluster 190: ['polyploid']
# Cluster 191: ['questionnaire']
# Cluster 192: ['dichroic mirror']
# Cluster 193: ['A40-MiniFCM']
# Cluster 194: ['serotransferrin']
# Cluster 195: ['Culicidae']
# Cluster 196: ['ileum']
# Cluster 197: ['Daphnia']
# Cluster 198: ['OBI_0002202']
# Cluster 199: ['MoFlo']
# Cluster 200: ['Archaea']
# Cluster 201: ['trypsination']
# Cluster 202: ['FACSAria']
# Cluster 203: ['microhardness tester']
# Cluster 204: ['radioactive']
# Cluster 205: ['CytoSence']

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")

# %%
final_ans = []

# %%
for i, list_of_elements in tqdm(enumerate(final_clusters_list[24:])):
    if len(list_of_elements)>1:
        prompt = f""""Analyze the following list of biological terms and identify all direct and indirect **parent-child relationships**.

        A **parent-child relationship** exists when one term (the parent) is a broader, more general category or a whole that conceptually encompasses or contains another term (the child). The child term is a more specific instance, a part, or a developmental stage of the parent term.

        **Guidelines for identifying relationships:**
        * **"Is-a" relationship:** e.g., "A 'leaf procambium' **is a** type of 'procambium'." (Parent: procambium, Child: leaf procambium)
        * **"Part-of" relationship:** e.g., "A 'petal' **is part of** a 'flower'." (Parent: flower, Child: petal)
        * **Developmental sequence:** e.g., "'Petal primordium visible stage' **is a stage in** 'petal development'." (Parent: petal development, Child: petal primordium visible stage)
        * **Anatomical hierarchy:** e.g., "'Root endodermis' **is part of** 'root' and **is a type of** 'endodermis'." (Parent: root and endodermis, Child: root endodermis)

        **List of Elements:**
        {list_of_elements}
        **Output Format:**
        Provide the output as a single JSON array. Each element in the array must be a JSON object with two keys: `"parent"` and `"child"`, whose values are the corresponding terms.

        **Example Output (Illustrative, showing the expected JSON structure):**
        {json.dumps({"Answer":[
        {
            "parent": "procambium",
            "child": "branch procambium"
        },
        {
            "parent": "procambium",
            "child": "leaf procambium"
        },
        {
            "parent": "shoot system",
            "child": "axillary shoot system"
        },
        {
            "parent": "flower",
            "child": "petal"
        },
        {
            "parent": "flower development",
            "child": "petal primordium visible stage"
        }
        ]})}
        """
        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%20==0:
            print(response.text)
# Out:
# 0it [00:00, ?it/s]
# [
#   {
#     "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",
#     "child": "DNASE 1 structure mapping assay"
#   },
#   {
#     "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",
#     "child": "RNA ADA I RNA structure mapping assay"
#   },
#   {
#     "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",
#     "child": "RNASE CL3 structure mapping assay"
#   },
#   {
#     "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",
#     "child": "RNASE T1 structure mapping assay"
#   },
#   {
#     "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",
#     "child": "RNASE T2 structure mapping assay"
#   },
#   {
#     "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",
#     "child": "RNASE U2 structure mapping assay"
#   },
#   {
#     "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",
#     "child": "RNASE V1 structure mapping assay"
#   },
#   {
#     "parent": "parallel analysis of RNA structure assay",
#     "child": "RNA ADA I RNA structure mapping assay"
#   },
#   {
#     "parent": "parallel analysis of RNA structure assay",
#     "child": "RNASE CL3 structure mapping assay"
#   },
#   {
#     "parent": "parallel analysis of RNA structure assay",
#     "child": "RNASE T1 structure mapping assay"
#   },
#   {
#     "parent": "parallel analysis of RNA structure assay",
#     "child": "RNASE T2 structure mapping assay"
#   },
#   {
#     "parent": "parallel analysis of RNA structure assay",
#     "child": "RNASE U2 structure mapping assay"
#   },
#   {
#     "parent": "parallel analysis of RNA structure assay",
#     "child": "RNASE V1 structure mapping assay"
#   }
# ]
# [
#   {
#     "parent": "neutrophil",
#     "child": "immature neutrophil"
#   },
#   {
#     "parent": "immature neutrophil",
#     "child": "band form neutrophil"
#   },
#   {
#     "parent": "neutrophil",
#     "child": "band form neutrophil"
#   }
# ]
# [
#   {
#     "parent": "organismal quality",
#     "child": "behavioral quality"
#   },
#   {
#     "parent": "organismal quality",
#     "child": "viability"
#   },
#   {
#     "parent": "organismal quality",
#     "child": "biological sex"
#   },
#   {
#     "parent": "organismal quality",
#     "child": "fasted"
#   },
#   {
#     "parent": "behavioral quality",
#     "child": "handedness"
#   },
#   {
#     "parent": "viability",
#     "child": "alive"
#   },
#   {
#     "parent": "biological sex",
#     "child": "phenotypic sex"
#   },
#   {
#     "parent": "biological sex",
#     "child": "female"
#   },
#   {
#     "parent": "biological sex",
#     "child": "male"
#   },
#   {
#     "parent": "biological sex",
#     "child": "hermaphrodite"
#   },
#   {
#     "parent": "phenotypic sex",
#     "child": "female"
#   },
#   {
#     "parent": "phenotypic sex",
#     "child": "male"
#   },
#   {
#     "parent": "phenotypic sex",
#     "child": "hermaphrodite"
#   },
#   {
#     "parent": "handedness",
#     "child": "ambidextrous handedness"
#   },
#   {
#     "parent": "handedness",
#     "child": "left handedness"
#   },
#   {
#     "parent": "handedness",
#     "child": "right handedness"
#   },
#   {
#     "parent": "handedness",
#     "child": "obsolete_left handedness"
#   }
# ]
# []
# [
#   {
#     "parent": "Centers for Disease Control and Prevention light trap",
#     "child": "odor baited CDC light trap"
#   }
# ]
# [
#   {
#     "parent": "sequence_assembly",
#     "child": "supercontig"
#   }
# ]
# [
#   {
#     "parent": "methodology testing objective",
#     "child": "protocol testing objective"
#   }
# ]

# %%
final_ans
# Out:
# ['[\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",\n    "child": "DNASE 1 structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",\n    "child": "RNA ADA I RNA structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",\n    "child": "RNASE CL3 structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",\n    "child": "RNASE T1 structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",\n    "child": "RNASE T2 structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",\n    "child": "RNASE U2 structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing",\n    "child": "RNASE V1 structure mapping assay"\n  },\n  {\n    "parent": "parallel analysis of RNA structure assay",\n    "child": "RNA ADA I RNA structure mapping assay"\n  },\n  {\n    "parent": "parallel analysis of RNA structure assay",\n    "child": "RNASE CL3 structure mapping assay"\n  },\n  {\n    "parent": "parallel analysis of RNA structure assay",\n    "child": "RNASE T1 structure mapping assay"\n  },\n  {\n    "parent": "parallel analysis of RNA structure assay",\n    "child": "RNASE T2 structure mapping assay"\n  },\n  {\n    "parent": "parallel analysis of RNA structure assay",\n    "child": "RNASE U2 structure mapping assay"\n  },\n  {\n    "parent": "parallel analysis of RNA structure assay",\n    "child": "RNASE V1 structure mapping assay"\n  }\n]',
#  '[\n  {\n    "parent": "histologic grade for ovarian tumor",\n    "child": "histologic grade for ovarian tumor according to the World Health Organization"\n  }\n]',
#  '[\n  {\n    "parent": "brain",\n    "child": "cerebellum"\n  },\n  {\n    "parent": "brain",\n    "child": "brain specimen"\n  },\n  {\n    "parent": "cerebellum",\n    "child": "cerebellum specimen"\n  },\n  {\n    "parent": "brain specimen",\n    "child": "cerebellum specimen"\n  }\n]',
#  '[\n  {\n    "parent": "opsonization",\n    "child": "B cell epitope specific opsonization"\n  }\n]',
#  '[\n  {\n    "parent": "Bruker NMR instrument",\n    "child": "AVANCE II spectrometer"\n  },\n  {\n    "parent": "Bruker NMR instrument",\n    "child": "Bruker AC series NMR instrument"\n  },\n  {\n    "parent": "Bruker NMR instrument",\n    "child": "Bruker AMX series NMR instrument"\n  },\n  {\n    "parent": "Bruker NMR instrument",\n    "child": "Bruker LC-NMR platform"\n  },\n  {\n    "parent": "Bruker NMR instrument",\n    "child": "Bruker SPE-NMR platform"\n  },\n  {\n    "parent": "Bruker NMR instrument",\n    "child": "Bruker NMR magnet"\n  },\n  {\n    "parent": "Bruker NMR instrument",\n    "child": "Bruker NMR probe"\n  },\n  {\n    "parent": "Bruker NMR instrument",\n    "child": "Bruker autosampler"\n  },\n  {\n    "parent": "Bruker NMR magnet",\n    "child": "Bruker UltraShield NMR magnet"\n  },\n  {\n    "parent": "Bruker NMR magnet",\n    "child": "Bruker UltraShield Plus NMR magnet"\n  },\n  {\n    "parent": "Bruker NMR probe",\n    "child": "Bruker micro imaging probe"\n  },\n  {\n    "parent": "Bruker autosampler",\n    "child": "Bruker NMR Case sample changer"\n  },\n  {\n    "parent": "Bruker LC-NMR platform",\n    "child": "Bruker Capillary LC-NMR platform"\n  },\n  {\n    "parent": "Bruker LC-NMR platform",\n    "child": "Bruker LC-NMR/MS platform"\n  }\n]',
#  '[\n  {\n    "parent": "personal protective device",\n    "child": "personal protective clothing item"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "footwear cover"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "laboratory coat"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "medical cap"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "medical gown"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "personal protective glove"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "protective apron"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "protective coverall"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "protective sleeve"\n  },\n  {\n    "parent": "personal protective clothing item",\n    "child": "scrubs"\n  },\n  {\n    "parent": "footwear cover",\n    "child": "disposable footwear cover"\n  },\n  {\n    "parent": "footwear cover",\n    "child": "reusable footwear cover"\n  },\n  {\n    "parent": "medical gown",\n    "child": "surgical gown"\n  },\n  {\n    "parent": "personal protective glove",\n    "child": "medical glove"\n  }\n]',
#  '[\n  {\n    "parent": "functional assessment of individual",\n    "child": "nervous system functionality assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "bulbar assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "muscle atrophy assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "muscle weakness assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "deep tendon reflex assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "limb coordination assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "dysmetria assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "gait assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "upright stability assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "position sense assessment"\n  },\n  {\n    "parent": "nervous system functionality assessment",\n    "child": "vibratory sense assessment"\n  },\n  {\n    "parent": "bulbar assessment",\n    "child": "speech test assessment"\n  },\n  {\n    "parent": "bulbar assessment",\n    "child": "forced cough assessment"\n  },\n  {\n    "parent": "speech test assessment",\n    "child": "spontaneous speech assessment"\n  },\n  {\n    "parent": "muscle atrophy assessment",\n    "child": "facial atrophy assessment"\n  },\n  {\n    "parent": "deep tendon reflex assessment",\n    "child": "deep tendon reflex assessment of the ankle joint"\n  },\n  {\n    "parent": "deep tendon reflex assessment",\n    "child": "deep tendon reflex assessment of the brachioradialis"\n  },\n  {\n    "parent": "deep tendon reflex assessment",\n    "child": "deep tendon reflex assessment of the knee joint"\n  },\n  {\n    "parent": "deep tendon reflex assessment",\n    "child": "deep tendon reflex assessment of the tendon of biceps brachii"\n  },\n  {\n    "parent": "limb coordination assessment",\n    "child": "upper limb coordination assessment"\n  },\n  {\n    "parent": "limb coordination assessment",\n    "child": "lower limb coordination assessment"\n  },\n  {\n    "parent": "upper limb coordination assessment",\n    "child": "finger taps assessment"\n  },\n  {\n    "parent": "upper limb coordination assessment",\n    "child": "finger to finger assessment"\n  },\n  {\n    "parent": "upper limb coordination assessment",\n    "child": "nose to finger assessment"\n  },\n  {\n    "parent": "upper limb coordination assessment",\n    "child": "rapid alternating hands assessment"\n  },\n  {\n    "parent": "lower limb coordination assessment",\n    "child": "heel along shin assessment"\n  },\n  {\n    "parent": "lower limb coordination assessment",\n    "child": "heel to shin assessment"\n  },\n  {\n    "parent": "gait assessment",\n    "child": "tandem walk assessment"\n  },\n  {\n    "parent": "upright stability assessment",\n    "child": "limits of stability assessment"\n  },\n  {\n    "parent": "upright stability assessment",\n    "child": "sitting posture assessment"\n  },\n  {\n    "parent": "upright stability assessment",\n    "child": "stance feet apart assessment"\n  },\n  {\n    "parent": "stance feet apart assessment",\n    "child": "stance feet apart assessment, with eyes closed"\n  },\n  {\n    "parent": "upright stability assessment",\n    "child": "stance feet together assessment"\n  },\n  {\n    "parent": "stance feet together assessment",\n    "child": "stance feet together assessment, with eyes closed"\n  },\n  {\n    "parent": "upright stability assessment",\n    "child": "stance on one foot assessment"\n  },\n  {\n    "parent": "upright stability assessment",\n    "child": "tandem stance assessment"\n  }\n]',
#  '[\n  {\n    "parent": "lowess transformation",\n    "child": "lowess global transformation"\n  },\n  {\n    "parent": "lowess transformation",\n    "child": "lowess group transformation"\n  }\n]',
#  '[\n  {\n    "parent": "JEOL NMR probe",\n    "child": "JEOL CapNMR probe"\n  }\n]',
#  '[\n  {\n    "parent": "alpha-beta T cell",\n    "child": "CD4-positive, alpha-beta T cell"\n  },\n  {\n    "parent": "alpha-beta T cell",\n    "child": "CD8-positive, alpha-beta T cell"\n  },\n  {\n    "parent": "CD8-positive, alpha-beta T cell",\n    "child": "CD8-positive, alpha-beta cytotoxic T cell"\n  }\n]',
#  '[\n  {\n    "parent": "MHC protein complex",\n    "child": "MHC class I protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "MHC class II protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "mouse MHC protein complex with H2-p haplotype"\n  },\n  {\n    "parent": "MHC class I protein complex",\n    "child": "human MHC class I protein complex"\n  },\n  {\n    "parent": "MHC class I protein complex",\n    "child": "mouse MHC class I protein complex"\n  },\n  {\n    "parent": "MHC class I protein complex",\n    "child": "cattle MHC class I protein complex"\n  },\n  {\n    "parent": "MHC class II protein complex",\n    "child": "cattle MHC class II protein complex"\n  },\n  {\n    "parent": "MHC class II protein complex",\n    "child": "mouse MHC class II protein complex"\n  },\n  {\n    "parent": "MHC class II protein complex",\n    "child": "rat MHC class II protein complex with RT1-A haplotype"\n  },\n  {\n    "parent": "MHC class II protein complex",\n    "child": "HLA protein complex with DQ3 serotype"\n  },\n  {\n    "parent": "human MHC class I protein complex",\n    "child": "HLA protein complex with A2 serotype"\n  },\n  {\n    "parent": "human MHC class I protein complex",\n    "child": "HLA protein complex with A24 serotype"\n  },\n  {\n    "parent": "human MHC class I protein complex",\n    "child": "HLA protein complex with A28 serotype"\n  },\n  {\n    "parent": "human MHC class I protein complex",\n    "child": "HLA protein complex with A29 serotype"\n  },\n  {\n    "parent": "human MHC class I protein complex",\n    "child": "HLA-C protein complex"\n  },\n  {\n    "parent": "mouse MHC class I protein complex",\n    "child": "H2-Dq protein complex"\n  },\n  {\n    "parent": "mouse MHC class I protein complex",\n    "child": "H2-Kb protein complex"\n  },\n  {\n    "parent": "mouse MHC class I protein complex",\n    "child": "H2-Kd protein complex"\n  },\n  {\n    "parent": "mouse MHC class I protein complex",\n    "child": "H2-Kq protein complex"\n  },\n  {\n    "parent": "mouse MHC class I protein complex",\n    "child": "H2-Ks protein complex"\n  },\n  {\n    "parent": "mouse MHC class I protein complex",\n    "child": "mouse MHC class I protein complex with H2-b haplotype"\n  },\n  {\n    "parent": "mouse MHC class II protein complex",\n    "child": "H2-IA protein complex"\n  },\n  {\n    "parent": "mouse MHC class II protein complex",\n    "child": "H2-IAd protein complex"\n  },\n  {\n    "parent": "mouse MHC class II protein complex",\n    "child": "H2-IAg7 protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "human MHC class I protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "mouse MHC class I protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "cattle MHC class I protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "cattle MHC class II protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "mouse MHC class II protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "rat MHC class II protein complex with RT1-A haplotype"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "HLA protein complex with DQ3 serotype"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "HLA protein complex with A2 serotype"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "HLA protein complex with A24 serotype"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "HLA protein complex with A28 serotype"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "HLA protein complex with A29 serotype"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "HLA-C protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "H2-Dq protein complex"\n  },\n  {\n    "parent": "MHC protein complex",\n    "child": "H2-Kb protein complex"\n  },\n  {\n    ...
#  '[\n  {\n    "parent": "biological feature identification objective",\n    "child": "cellular feature identification objective"\n  },\n  {\n    "parent": "biological feature identification objective",\n    "child": "molecular feature identification objective"\n  },\n  {\n    "parent": "biological feature identification objective",\n    "child": "organism feature identification objective"\n  },\n  {\n    "parent": "cellular feature identification objective",\n    "child": "cellular structure feature identification objective"\n  },\n  {\n    "parent": "molecular feature identification objective",\n    "child": "DNA replication identification objective"\n  },\n  {\n    "parent": "molecular feature identification objective",\n    "child": "molecular function identification objective"\n  },\n  {\n    "parent": "organism feature identification objective",\n    "child": "organism species detection objective"\n  },\n  {\n    "parent": "organism species detection objective",\n    "child": "detection of pathogenic organisms objective"\n  }\n]',
#  '[\n  {\n    "parent": "assay kit",\n    "child": "Advantage Chikungunya IgM Card kit"\n  },\n  {\n    "parent": "assay kit",\n    "child": "Panbio Dengue Early ELISA kit"\n  },\n  {\n    "parent": "assay kit",\n    "child": "Panbio Dengue IgM capture ELISA kit"\n  },\n  {\n    "parent": "assay kit",\n    "child": "SD Bioline Chikungunya IgM RDT kit"\n  },\n  {\n    "parent": "assay kit",\n    "child": "SD Bioline Chikungunya IgM capture ELISA kit"\n  },\n  {\n    "parent": "assay kit",\n    "child": "Scrub Typhus Detect IgM ELISA kit"\n  }\n]',
#  '[\n  {\n    "parent": "biological attribute",\n    "child": "ankle joint functionality"\n  },\n  {\n    "parent": "biological attribute",\n    "child": "brachioradialis functionality"\n  },\n  {\n    "parent": "biological attribute",\n    "child": "knee joint functionality"\n  },\n  {\n    "parent": "biological attribute",\n    "child": "limb coordination efficacy"\n  },\n  {\n    "parent": "biological attribute",\n    "child": "lower limb coordination efficacy"\n  },\n  {\n    "parent": "biological attribute",\n    "child": "peripheral nervous system function"\n  },\n  {\n    "parent": "biological attribute",\n    "child": "tendon of biceps brachii functionality"\n  },\n  {\n    "parent": "biological attribute",\n    "child": "upper limb coordination efficacy"\n  },\n  {\n    "parent": "biological attribute",\n    "child": "whole organism stability"\n  },\n  {\n    "parent": "whole organism stability",\n    "child": "limb coordination efficacy"\n  },\n  {\n    "parent": "limb coordination efficacy",\n    "child": "lower limb coordination efficacy"\n  },\n  {\n    "parent": "limb coordination efficacy",\n    "child": "upper limb coordination efficacy"\n  },\n  {\n    "parent": "lower limb coordination efficacy",\n    "child": "ankle joint functionality"\n  },\n  {\n    "parent": "lower limb coordination efficacy",\n    "child": "knee joint functionality"\n  },\n  {\n    "parent": "upper limb coordination efficacy",\n    "child": "brachioradialis functionality"\n  },\n  {\n    "parent": "upper limb coordination efficacy",\n    "child": "tendon of biceps brachii functionality"\n  },\n  {\n    "parent": "peripheral nervous system function",\n    "child": "limb coordination efficacy"\n  },\n  {\n    "parent": "peripheral nervous system function",\n    "child": "ankle joint functionality"\n  },\n  {\n    "parent": "peripheral nervous system function",\n    "child": "brachioradialis functionality"\n  },\n  {\n    "parent": "peripheral nervous system function",\n    "child": "knee joint functionality"\n  },\n  {\n    "parent": "peripheral nervous system function",\n    "child": "tendon of biceps brachii functionality"\n  }\n]',
#  '[\n  {\n    "parent": "morphology",\n    "child": "size"\n  },\n  {\n    "parent": "morphology",\n    "child": "structure"\n  },\n  {\n    "parent": "structure",\n    "child": "composition"\n  },\n  {\n    "parent": "damage",\n    "child": "damaged"\n  }\n]',
#  '[\n  {\n    "parent": "resting arthropod trap",\n    "child": "artificial pit shelter"\n  },\n  {\n    "parent": "resting arthropod trap",\n    "child": "resting bucket"\n  },\n  {\n    "parent": "resting arthropod trap",\n    "child": "resting clay pot trap"\n  },\n  {\n    "parent": "resting bucket",\n    "child": "sticky resting bucket"\n  }\n]',
#  '[\n  {\n    "parent": "gas chromatography equipment",\n    "child": "gas chromatography oven"\n  },\n  {\n    "parent": "gas generator",\n    "child": "hydrogen generator"\n  },\n  {\n    "parent": "gas generator",\n    "child": "nitrogen generator"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "CMCT structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "DEPC structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "DMS structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "ENU structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "Fe-BABE RNA structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "Lead structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "MPE-Fe(II) structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "OH-radical structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "Rhodium DNA structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "Ruthenium structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "Terbium RNA structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "inline probing RNA structure mapping assay"\n  },\n  {\n    "parent": "single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing",\n    "child": "kethoxal structure mapping assay"\n  }\n]',
#  '[\n  {\n    "parent": "process",\n    "child": "biological_process"\n  },\n  {\n    "parent": "process",\n    "child": "pathologic process"\n  },\n  {\n    "parent": "process",\n    "child": "environmental proximity to infectious agent"\n  },\n  {\n    "parent": "process",\n    "child": "planning"\n  },\n  {\n    "parent": "process",\n    "child": "scratching"\n  },\n  {\n    "parent": "process",\n    "child": "unplanned occurrence effecting an investigation"\n  },\n  {\n    "parent": "molecular_function",\n    "child": "binding"\n  },\n  {\n    "parent": "molecular_function",\n    "child": "catalytic activity"\n  },\n  {\n    "parent": "molecular_function",\n    "child": "monoatomic ion channel activity"\n  },\n  {\n    "parent": "biological_process",\n    "child": "cellular process"\n  },\n  {\n    "parent": "biological_process",\n    "child": "response to stimulus"\n  },\n  {\n    "parent": "biological_process",\n    "child": "blood coagulation"\n  },\n  {\n    "parent": "biological_process",\n    "child": "fertilization"\n  },\n  {\n    "parent": "biological_process",\n    "child": "hemopoiesis"\n  },\n  {\n    "parent": "biological_process",\n    "child": "granzyme A production"\n  },\n  {\n    "parent": "biological_process",\n    "child": "perforin production"\n  },\n  {\n    "parent": "cellular process",\n    "child": "action potential"\n  },\n  {\n    "parent": "cellular process",\n    "child": "actin polymerization-dependent cell motility"\n  },\n  {\n    "parent": "cellular process",\n    "child": "cell cycle"\n  },\n  {\n    "parent": "cellular process",\n    "child": "cell killing"\n  },\n  {\n    "parent": "cellular process",\n    "child": "cell population proliferation"\n  },\n  {\n    "parent": "cellular process",\n    "child": "chromosome organization"\n  },\n  {\n    "parent": "cellular process",\n    "child": "cytotoxic T cell degranulation"\n  },\n  {\n    "parent": "cellular process",\n    "child": "macromolecule localization"\n  },\n  {\n    "parent": "cellular process",\n    "child": "phagocytosis"\n  },\n  {\n    "parent": "cell killing",\n    "child": "antibody-dependent cellular cytotoxicity"\n  },\n  {\n    "parent": "cell killing",\n    "child": "complement-dependent cytotoxicity"\n  },\n  {\n    "parent": "complement-dependent cytotoxicity",\n    "child": "B cell epitope specific complement-dependent cytotoxicity"\n  },\n  {\n    "parent": "cytotoxic T cell degranulation",\n    "child": "granzyme A release during T cell degranulation"\n  },\n  {\n    "parent": "cytotoxic T cell degranulation",\n    "child": "perforin release during T cell degranulation"\n  },\n  {\n    "parent": "response to stimulus",\n    "child": "DNA damage response"\n  },\n  {\n    "parent": "response to stimulus",\n    "child": "immune response"\n  },\n  {\n    "parent": "immune response",\n    "child": "adaptive immune response"\n  },\n  {\n    "parent": "immune response",\n    "child": "hypersensitivity"\n  },\n  {\n    "parent": "immune response",\n    "child": "tolerance induction"\n  },\n  {\n    "parent": "adaptive immune response",\n    "child": "antigen processing and presentation"\n  },\n  {\n    "parent": "adaptive immune response",\n    "child": "B cell tolerance induction"\n  },\n  {\n    "parent": "adaptive immune response",\n    "child": "epitope binding by adaptive immune receptor"\n  },\n  {\n    "parent": "adaptive immune response",\n    "child": "helper T cell enhancement of adaptive immune response"\n  },\n  {\n    "parent": "adaptive immune response",\n    "child": "immunoglobulin mediated immune response"\n  },\n  {\n    "parent": "tolerance induction",\n    "child": "B cell tolerance induction"\n  },\n  {\n    "parent": "hypersensitivity",\n    "child": "allergic reaction"\n  },\n  {\n    "parent": "hypersensitivity",\n    "child": "B cell epitope specific hypersensitivity"\n  },\n  {\n    "parent": "immunoglobulin mediated immune response",\n    "child": "immune complex formation"\n  },\n  {\n    "pare ...
#  '[\n  {\n    "parent": "neutrophil",\n    "child": "immature neutrophil"\n  },\n  {\n    "parent": "immature neutrophil",\n    "child": "band form neutrophil"\n  },\n  {\n    "parent": "neutrophil",\n    "child": "band form neutrophil"\n  }\n]',
#  '[\n  {\n    "parent": "clonal cDNA library",\n    "child": "recombinant vector"\n  },\n  {\n    "parent": "phage display library",\n    "child": "recombinant vector"\n  }\n]',
#  '[\n  {\n    "parent": "interleukin-27 production",\n    "child": "epitope specific interleukin-27 production by T cells"\n  }\n]',
#  '[\n  {\n    "parent": "data set",\n    "child": "computed image data set"\n  },\n  {\n    "parent": "data set",\n    "child": "image data set"\n  },\n  {\n    "parent": "data set",\n    "child": "clustered data set"\n  },\n  {\n    "parent": "data set",\n    "child": "normalized data set"\n  },\n  {\n    "parent": "data set",\n    "child": "background corrected data set"\n  },\n  {\n    "parent": "image data set",\n    "child": "magnetic resonance image data set"\n  },\n  {\n    "parent": "image data set",\n    "child": "brain region atlas image data set"\n  },\n  {\n    "parent": "image data set",\n    "child": "image segmentation map"\n  },\n  {\n    "parent": "image data set",\n    "child": "raw image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "T1 weighted magnetic resonance image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "T2 weighted magnetic resonance image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "T2* weighted GRE magnetic resonance image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "diffusion weighted magnetic resonance image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "perfusion weighted magnetic resonance image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "proton density magnetic resonance image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "functional magnetic resonance image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "raw magnetic resonance image data set"\n  },\n  {\n    "parent": "magnetic resonance image data set",\n    "child": "reconstructed magnetic resonance image data set"\n  },\n  {\n    "parent": "T1 weighted magnetic resonance image data set",\n    "child": "T1 weighted GRE magnetic resonance image data set"\n  },\n  {\n    "parent": "T1 weighted magnetic resonance image data set",\n    "child": "T1 weighted SE magnetic resonance image data set"\n  },\n  {\n    "parent": "T1 weighted magnetic resonance image data set",\n    "child": "high resolution T1 weighted magnetic resonance image data set"\n  },\n  {\n    "parent": "T1 weighted magnetic resonance image data set",\n    "child": "post-Gd T1 weighted magnetic resonance image data set"\n  },\n  {\n    "parent": "T2 weighted magnetic resonance image data set",\n    "child": "T2 weighted FLAIR magnetic resonance image data set"\n  },\n  {\n    "parent": "T2 weighted magnetic resonance image data set",\n    "child": "T2 weighted FSE  magnetic resonance image data set"\n  },\n  {\n    "parent": "T2 weighted magnetic resonance image data set",\n    "child": "T2 weighted SE magnetic resonance image data set"\n  },\n  {\n    "parent": "T2 weighted magnetic resonance image data set",\n    "child": "T2 weighted STIR magnetic resonance image data set"\n  },\n  {\n    "parent": "high resolution T1 weighted magnetic resonance image data set",\n    "child": "baseline high resolution T1 weighted magnetic resonance image data set"\n  },\n  {\n    "parent": "high resolution T1 weighted magnetic resonance image data set",\n    "child": "follow-up high resolution T1 weighted magnetic resonance image data set"\n  },\n  {\n    "parent": "functional magnetic resonance image data set",\n    "child": "resting state functional magnetic resonance image data set"\n  },\n  {\n    "parent": "functional magnetic resonance image data set",\n    "child": "task-based functional magnetic resonance image data set"\n  },\n  {\n    "parent": "brain region atlas image data set",\n    "child": "deterministic brain region atlas image data set"\n  },\n  {\n    "parent": "brain region atlas image data set",\n    "child": "probabilistic brain region atlas image dataset"\n  },\n  {\n    "parent": "clustered data set",\n    "child": "topologically preser ...
#  '[\n  {\n    "parent": "Saccharomyces cerevisiae mating type",\n    "child": "a mating type (yeast)"\n  }\n]',
#  '[\n  {\n    "parent": "region",\n    "child": "regulatory_region"\n  },\n  {\n    "parent": "regulatory_region",\n    "child": "TF_binding_site"\n  },\n  {\n    "parent": "region",\n    "child": "TF_binding_site"\n  },\n  {\n    "parent": "primary structure of RNA molecule",\n    "child": "miRNA"\n  },\n  {\n    "parent": "primary structure of DNA macromolecule",\n    "child": "regulatory_region"\n  },\n  {\n    "parent": "primary structure of DNA macromolecule",\n    "child": "TF_binding_site"\n  }\n]',
#  '[\n  {\n    "parent": "exposure to environmental and workplace carcinogens history",\n    "child": "exposure to asbestos history"\n  },\n  {\n    "parent": "exposure to environmental and workplace carcinogens history",\n    "child": "exposure to diesel exhaust history"\n  },\n  {\n    "parent": "exposure to environmental and workplace carcinogens history",\n    "child": "exposure to silica history"\n  }\n]',
#  '[\n  {\n    "parent": "acclimatization",\n    "child": "exposure of material to environment"\n  },\n  {\n    "parent": "exposure of material to environment",\n    "child": "waiting"\n  },\n  {\n    "parent": "acclimatization",\n    "child": "waiting"\n  }\n]',
#  '[\n  {\n    "parent": "bodily fluid",\n    "child": "bile"\n  },\n  {\n    "parent": "bodily fluid",\n    "child": "blood"\n  },\n  {\n    "parent": "bodily fluid",\n    "child": "cerebrospinal fluid"\n  },\n  {\n    "parent": "bodily fluid",\n    "child": "cervical mucus"\n  },\n  {\n    "parent": "bodily fluid",\n    "child": "milk"\n  },\n  {\n    "parent": "bodily fluid",\n    "child": "pericardial fluid"\n  },\n  {\n    "parent": "bodily fluid",\n    "child": "synovial fluid"\n  },\n  {\n    "parent": "blood",\n    "child": "capillary blood"\n  },\n  {\n    "parent": "blood",\n    "child": "placental blood"\n  },\n  {\n    "parent": "blood",\n    "child": "venous blood"\n  }\n]',
#  '[\n  {\n    "parent": "Bacteria",\n    "child": "Orientia tsutsugamushi"\n  },\n  {\n    "parent": "Bacteria",\n    "child": "Treponema pallidum"\n  },\n  {\n    "parent": "Eukaryota",\n    "child": "Arabidopsis thaliana"\n  },\n  {\n    "parent": "Eukaryota",\n    "child": "Dictyostelium discoideum"\n  },\n  {\n    "parent": "Eukaryota",\n    "child": "Plasmodium"\n  },\n  {\n    "parent": "Eukaryota",\n    "child": "Plasmodium gametocyte"\n  },\n  {\n    "parent": "genetically modified organism",\n    "child": "transgenic organism"\n  },\n  {\n    "parent": "infectious agent",\n    "child": "Bacteria"\n  },\n  {\n    "parent": "infectious agent",\n    "child": "Orientia tsutsugamushi"\n  },\n  {\n    "parent": "infectious agent",\n    "child": "Plasmodium"\n  },\n  {\n    "parent": "infectious agent",\n    "child": "Plasmodium gametocyte"\n  },\n  {\n    "parent": "infectious agent",\n    "child": "Treponema pallidum"\n  },\n  {\n    "parent": "organism",\n    "child": "Arabidopsis thaliana"\n  },\n  {\n    "parent": "organism",\n    "child": "Bacteria"\n  },\n  {\n    "parent": "organism",\n    "child": "Dictyostelium discoideum"\n  },\n  {\n    "parent": "organism",\n    "child": "Eukaryota"\n  },\n  {\n    "parent": "organism",\n    "child": "Orientia tsutsugamushi"\n  },\n  {\n    "parent": "organism",\n    "child": "Plasmodium"\n  },\n  {\n    "parent": "organism",\n    "child": "Plasmodium gametocyte"\n  },\n  {\n    "parent": "organism",\n    "child": "Treponema pallidum"\n  },\n  {\n    "parent": "organism",\n    "child": "blood meal source organism"\n  },\n  {\n    "parent": "organism",\n    "child": "chimera"\n  },\n  {\n    "parent": "organism",\n    "child": "genetically modified organism"\n  },\n  {\n    "parent": "organism",\n    "child": "host of immune response"\n  },\n  {\n    "parent": "organism",\n    "child": "transgenic organism"\n  },\n  {\n    "parent": "Plasmodium",\n    "child": "Plasmodium gametocyte"\n  }\n]',
#  '[\n  {\n    "parent": "temporal region",\n    "child": "one-dimensional temporal region"\n  }\n]',
#  '[\n  {\n    "parent": "Opisthokonta",\n    "child": "Ascomycota"\n  },\n  {\n    "parent": "Ascomycota",\n    "child": "saccharomyceta"\n  },\n  {\n    "parent": "saccharomyceta",\n    "child": "Saccharomyces cerevisiae"\n  },\n  {\n    "parent": "Ascomycota",\n    "child": "Schizosaccharomyces pombe"\n  }\n]',
#  '[\n  {\n    "parent": "random mutagenesis",\n    "child": "chemical mutagenesis"\n  },\n  {\n    "parent": "random mutagenesis",\n    "child": "irradiation mutagenesis"\n  },\n  {\n    "parent": "random mutagenesis",\n    "child": "transposon-induced mutagenesis"\n  }\n]',
#  '[\n  {\n    "parent": "fixed tissue specimen",\n    "child": "fixed tissue slide specimen"\n  },\n  {\n    "parent": "fixed tissue slide specimen",\n    "child": "H&E-stained fixed tissue slide specimen"\n  },\n  {\n    "parent": "fixed tissue slide specimen",\n    "child": "IHC-stained fixed tissue slide specimen"\n  },\n  {\n    "parent": "fixed tissue specimen",\n    "child": "H&E-stained fixed tissue slide specimen"\n  },\n  {\n    "parent": "fixed tissue specimen",\n    "child": "IHC-stained fixed tissue slide specimen"\n  }\n]',
#  '[\n  {\n    "parent": "hormonal birth control use history",\n    "child": "hormonal birth control current use history"\n  },\n  {\n    "parent": "hormonal birth control use history",\n    "child": "hormonal birth control former use history"\n  }\n]',
#  '[\n  {\n    "parent": "reason for lack of data item",\n    "child": "cannot be assessed determination"\n  }\n]',
#  '[\n  {\n    "parent": "position",\n    "child": "anterior to"\n  },\n  {\n    "parent": "position",\n    "child": "dorsal to"\n  },\n  {\n    "parent": "position",\n    "child": "lateral to"\n  },\n  {\n    "parent": "position",\n    "child": "right side of"\n  }\n]',
#  '[\n  {\n    "parent": "cellular quality",\n    "child": "ploidy"\n  },\n  {\n    "parent": "ploidy",\n    "child": "euploid"\n  },\n  {\n    "parent": "euploid",\n    "child": "diploid"\n  }\n]',
#  '[\n  {\n    "parent": "protocol",\n    "child": "animal care protocol"\n  },\n  {\n    "parent": "protocol",\n    "child": "magnetic resonance pulse sequence protocol"\n  },\n  {\n    "parent": "protocol",\n    "child": "specimen collection protocol"\n  }\n]',
#  '[\n  {\n    "parent": "disease course",\n    "child": "occurrence of allergy"\n  },\n  {\n    "parent": "disease course",\n    "child": "occurrence of infectious disease"\n  }\n]',
#  '[\n  {\n    "parent": "organismal quality",\n    "child": "behavioral quality"\n  },\n  {\n    "parent": "organismal quality",\n    "child": "viability"\n  },\n  {\n    "parent": "organismal quality",\n    "child": "biological sex"\n  },\n  {\n    "parent": "organismal quality",\n    "child": "fasted"\n  },\n  {\n    "parent": "behavioral quality",\n    "child": "handedness"\n  },\n  {\n    "parent": "viability",\n    "child": "alive"\n  },\n  {\n    "parent": "biological sex",\n    "child": "phenotypic sex"\n  },\n  {\n    "parent": "biological sex",\n    "child": "female"\n  },\n  {\n    "parent": "biological sex",\n    "child": "male"\n  },\n  {\n    "parent": "biological sex",\n    "child": "hermaphrodite"\n  },\n  {\n    "parent": "phenotypic sex",\n    "child": "female"\n  },\n  {\n    "parent": "phenotypic sex",\n    "child": "male"\n  },\n  {\n    "parent": "phenotypic sex",\n    "child": "hermaphrodite"\n  },\n  {\n    "parent": "handedness",\n    "child": "ambidextrous handedness"\n  },\n  {\n    "parent": "handedness",\n    "child": "left handedness"\n  },\n  {\n    "parent": "handedness",\n    "child": "right handedness"\n  },\n  {\n    "parent": "handedness",\n    "child": "obsolete_left handedness"\n  }\n]',
#  '[\n  {\n    "parent": "symbol",\n    "child": "centrally registered identifier symbol"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "GenBank ID"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "PubMed ID"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "SRS identifier"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "digital object identifier"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "grant identifier"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "individual organism identifier"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "investigation identifier"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "participant identifier"\n  },\n  {\n    "parent": "centrally registered identifier symbol",\n    "child": "specimen identifier"\n  },\n  {\n    "parent": "specimen identifier",\n    "child": "specimen identifier assigned by sequencing facility"\n  },\n  {\n    "parent": "specimen identifier",\n    "child": "specimen identifier assigned by specimen repository"\n  }\n]',
#  '[\n  {\n    "parent": "antibody purification of H2-Dd protein complex and/or H2-Kd protein complex",\n    "child": "antibody purification of H2-Dd protein complex"\n  },\n  {\n    "parent": "antibody purification of H2-Dd protein complex and/or H2-Kd protein complex",\n    "child": "antibody purification of H2-Kd protein complex"\n  }\n]',
#  '[\n  {\n    "parent": "algorithm",\n    "child": "alignment counting algorithm"\n  },\n  {\n    "parent": "algorithm",\n    "child": "base calling algorithm"\n  },\n  {\n    "parent": "algorithm",\n    "child": "probabilistic algorithm"\n  },\n  {\n    "parent": "algorithm",\n    "child": "reference genome-transcriptome alignment algorithm"\n  },\n  {\n    "parent": "algorithm",\n    "child": "sequence assembly algorithm"\n  },\n  {\n    "parent": "algorithm",\n    "child": "verse algorithm"\n  },\n  {\n    "parent": "reference genome-transcriptome alignment algorithm",\n    "child": "star algorithm"\n  }\n]',
#  '[\n  {\n    "parent": "clinical data item",\n    "child": "chronic allograft damage index score"\n  },\n  {\n    "parent": "clinical data item",\n    "child": "multidimensional fatigue inventory score"\n  },\n  {\n    "parent": "clinical data item",\n    "child": "physician\'s global assessment of disease activity"\n  },\n  {\n    "parent": "clinical data item",\n    "child": "sequential organ failure assessment score"\n  }\n]',
#  '[\n  {\n    "parent": "cellular_component",\n    "child": "chromosome"\n  },\n  {\n    "parent": "cellular_component",\n    "child": "membrane-bounded organelle"\n  },\n  {\n    "parent": "cellular_component",\n    "child": "mitochondrion"\n  },\n  {\n    "parent": "membrane-bounded organelle",\n    "child": "mitochondrion"\n  }\n]',
#  '[\n  {\n    "parent": "mating type",\n    "child": "yeast mating type"\n  }\n]',
#  '[\n  {\n    "parent": "Viruses",\n    "child": "Orthoherpesviridae"\n  },\n  {\n    "parent": "Orthoherpesviridae",\n    "child": "Cytomegalovirus"\n  },\n  {\n    "parent": "Orthoherpesviridae",\n    "child": "human gammaherpesvirus 4"\n  }\n]',
#  '[\n  {\n    "parent": "nasopharyngeal or oropharyngeal swab microbiology datum",\n    "child": "bacteria in nasopharyngeal or oropharyngeal swab datum"\n  },\n  {\n    "parent": "nasopharyngeal or oropharyngeal swab microbiology datum",\n    "child": "eukaryota in nasopharyngeal or oropharyngeal swab datum"\n  },\n  {\n    "parent": "nasopharyngeal or oropharyngeal swab microbiology datum",\n    "child": "virus in nasopharyngeal or oropharyngeal swab datum"\n  }\n]',
#  '[\n  {\n    "parent": "antibody purification of mouse MHC class I protein complex",\n    "child": "antibody purification of H2-Db protein complex"\n  },\n  {\n    "parent": "antibody purification of mouse MHC class I protein complex",\n    "child": "antibody purification of H2-Ld protein complex, H2-Db protein complex, and/or H2-Dq protein complex"\n  },\n  {\n    "parent": "antibody purification of mouse MHC class I protein complex",\n    "child": "antibody purification of mouse MHC class I protein complex with H2-b haplotype and/or mouse MHC protein complex with H2-p haplotype"\n  },\n  {\n    "parent": "antibody purification of H2-Ld protein complex, H2-Db protein complex, and/or H2-Dq protein complex",\n    "child": "antibody purification of H2-Db protein complex"\n  },\n  {\n    "parent": "antibody purification of mouse MHC class I protein complex with H2-b haplotype and/or mouse MHC protein complex with H2-p haplotype",\n    "child": "antibody purification of H2-Db protein complex"\n  }\n]',
#  '[\n  {\n    "parent": "Riboviria",\n    "child": "Revtraviricetes"\n  },\n  {\n    "parent": "Riboviria",\n    "child": "Kitrinoviricota"\n  },\n  {\n    "parent": "Revtraviricetes",\n    "child": "Lentivirus"\n  },\n  {\n    "parent": "Lentivirus",\n    "child": "Human immunodeficiency virus 1"\n  },\n  {\n    "parent": "Lentivirus",\n    "child": "Human immunodeficiency virus 2"\n  },\n  {\n    "parent": "Human immunodeficiency virus 1",\n    "child": "HIV-1 group O"\n  },\n  {\n    "parent": "Kitrinoviricota",\n    "child": "Chikungunya virus"\n  }\n]',
#  '[\n  {\n    "parent": "assay measuring epitope specific",\n    "child": "assay measuring epitope specific Ig-mediated histamine release"\n  },\n  {\n    "parent": "assay measuring epitope specific",\n    "child": "assay measuring epitope specific activation of additional immune response in vitro"\n  },\n  {\n    "parent": "assay measuring epitope specific",\n    "child": "assay measuring epitope specific complement-dependent cytotoxicity"\n  },\n  {\n    "parent": "assay measuring epitope specific",\n    "child": "assay measuring epitope specific immune complex formation"\n  }\n]',
#  '[\n  {\n    "parent": "material transformation objective",\n    "child": "genetic transformation objective"\n  }\n]',
#  '[\n  {\n    "parent": "patch clamp assay",\n    "child": "cell-attached patch clamp assay"\n  },\n  {\n    "parent": "patch clamp assay",\n    "child": "inside-out patch clamp assay"\n  },\n  {\n    "parent": "patch clamp assay",\n    "child": "outside-out patch clamp assay"\n  },\n  {\n    "parent": "patch clamp assay",\n    "child": "whole-cell patch clamp assay"\n  }\n]',
#  '[\n  {\n    "parent": "filled capsule",\n    "child": "capsule shell"\n  },\n  {\n    "parent": "pill",\n    "child": "filled capsule"\n  }\n]',
#  '[\n  {\n    "parent": "autosampler",\n    "child": "Bruker autosampler"\n  },\n  {\n    "parent": "autosampler",\n    "child": "Bruker B-ACS system"\n  },\n  {\n    "parent": "autosampler",\n    "child": "Bruker SampleJet system"\n  },\n  {\n    "parent": "Bruker autosampler",\n    "child": "Bruker B-ACS system"\n  },\n  {\n    "parent": "Bruker autosampler",\n    "child": "Bruker SampleJet system"\n  }\n]',
#  '[\n  {\n    "parent": "oral administration",\n    "child": "oral ingestion of pill"\n  }\n]',
#  '[]',
#  '{\n  "Answer": [\n    {\n      "parent": "knockdown arthropod specimen collection process",\n      "child": "knockdown arthropod specimen collection by pyrethrum spray"\n    }\n  ]\n}',
#  '[\n  {\n    "parent": "optical microscope",\n    "child": "stereo microscope"\n  }\n]',
#  '[]',
#  '[]',
#  '[\n  {\n    "parent": "graph",\n    "child": "dendrogram"\n  },\n  {\n    "parent": "graph",\n    "child": "dot plot"\n  },\n  {\n    "parent": "graph",\n    "child": "heatmap"\n  },\n  {\n    "parent": "graph",\n    "child": "histogram"\n  },\n  {\n    "parent": "graph",\n    "child": "line graph"\n  },\n  {\n    "parent": "graph",\n    "child": "scatter plot"\n  },\n  {\n    "parent": "line graph",\n    "child": "survival curve"\n  },\n  {\n    "parent": "line graph",\n    "child": "dose response curve"\n  },\n  {\n    "parent": "scatter plot",\n    "child": "dose response curve"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "specific enzymatic cleavage",\n    "child": "DNA restriction enzyme digestion"\n  }\n]',
#  '[\n  {\n    "parent": "JEOL NMR instrument",\n    "child": "JEOL ECA NMR spectrometer"\n  }\n]',
#  '[\n  {\n    "parent": "human MHC class II protein complex",\n    "child": "HLA-DP protein complex"\n  },\n  {\n    "parent": "human MHC class II protein complex",\n    "child": "HLA-DR protein complex"\n  }\n]',
#  '[\n  {\n    "parent": "growth environment",\n    "child": "atmosphere"\n  }\n]',
#  '[\n  {\n    "parent": "bacterial mating type",\n    "child": "F mating type"\n  }\n]',
#  '[\n  {\n    "parent": "vitreous humor",\n    "child": "vitreous humor specimen"\n  },\n  {\n    "parent": "eye specimen",\n    "child": "vitreous humor"\n  },\n  {\n    "parent": "eye specimen",\n    "child": "vitreous humor specimen"\n  }\n]',
#  '[\n  {\n    "parent": "DNA extract",\n    "child": "high molecular weight DNA extract"\n  }\n]',
#  '[\n  {\n    "parent": "transgenic mutagenesis",\n    "child": "enhancer-trap mutagenesis"\n  },\n  {\n    "parent": "transgenic mutagenesis",\n    "child": "gene-trap mutagenesis"\n  }\n]',
#  '[\n  {\n    "parent": "insecticide resistance time response assay",\n    "child": "insecticide resistance time response by WHO paper kit assay"\n  },\n  {\n    "parent": "insecticide resistance time response assay",\n    "child": "insecticide resistance time response by bottle assay"\n  }\n]',
#  '[\n  {\n    "parent": "mathematical feature",\n    "child": "exponential base"\n  },\n  {\n    "parent": "mathematical feature",\n    "child": "log base"\n  },\n  {\n    "parent": "mathematical feature",\n    "child": "number of variables"\n  },\n  {\n    "parent": "mathematical feature",\n    "child": "polynomial degree"\n  }\n]',
#  '[\n  {\n    "parent": "extraction",\n    "child": "nucleic acid extraction"\n  },\n  {\n    "parent": "extraction",\n    "child": "submatrix extraction"\n  },\n  {\n    "parent": "extraction",\n    "child": "RNA extraction"\n  },\n  {\n    "parent": "extraction",\n    "child": "cytoplasmic RNA extraction"\n  },\n  {\n    "parent": "extraction",\n    "child": "nuclear RNA extraction"\n  },\n  {\n    "parent": "extraction",\n    "child": "organellar RNA extraction"\n  },\n  {\n    "parent": "extraction",\n    "child": "polyA RNA extraction"\n  },\n  {\n    "parent": "extraction",\n    "child": "viral RNA extraction"\n  },\n  {\n    "parent": "extraction",\n    "child": "row submatrix extraction"\n  },\n  {\n    "parent": "nucleic acid extraction",\n    "child": "RNA extraction"\n  },\n  {\n    "parent": "nucleic acid extraction",\n    "child": "cytoplasmic RNA extraction"\n  },\n  {\n    "parent": "nucleic acid extraction",\n    "child": "nuclear RNA extraction"\n  },\n  {\n    "parent": "nucleic acid extraction",\n    "child": "organellar RNA extraction"\n  },\n  {\n    "parent": "nucleic acid extraction",\n    "child": "polyA RNA extraction"\n  },\n  {\n    "parent": "nucleic acid extraction",\n    "child": "viral RNA extraction"\n  },\n  {\n    "parent": "RNA extraction",\n    "child": "cytoplasmic RNA extraction"\n  },\n  {\n    "parent": "RNA extraction",\n    "child": "nuclear RNA extraction"\n  },\n  {\n    "parent": "RNA extraction",\n    "child": "organellar RNA extraction"\n  },\n  {\n    "parent": "RNA extraction",\n    "child": "polyA RNA extraction"\n  },\n  {\n    "parent": "RNA extraction",\n    "child": "viral RNA extraction"\n  },\n  {\n    "parent": "submatrix extraction",\n    "child": "row submatrix extraction"\n  }\n]',
#  '[\n  {\n    "parent": "ontology module subsetted by OWL profile",\n    "child": "EL++ ontology module"\n  }\n]',
#  '[\n  {\n    "parent": "transcription profiling by array assay",\n    "child": "transcription profiling by tiling array assay"\n  }\n]',
#  '[\n  {\n    "parent": "liquid handler",\n    "child": "liquid extraction robot"\n  }\n]',
#  '[\n  {\n    "parent": "Schizosaccharomyces pombe mating type",\n    "child": "h minus"\n  },\n  {\n    "parent": "Schizosaccharomyces pombe mating type",\n    "child": "h plus"\n  }\n]',
#  '[\n  {\n    "parent": "statistical model validation",\n    "child": "K-fold cross validation method"\n  },\n  {\n    "parent": "statistical model validation",\n    "child": "boostrapping"\n  },\n  {\n    "parent": "K-fold cross validation method",\n    "child": "leave one out cross validation method"\n  },\n  {\n    "parent": "statistical model validation",\n    "child": "leave one out cross validation method"\n  }\n]',
#  '[\n  {\n    "parent": "Centers for Disease Control and Prevention light trap",\n    "child": "odor baited CDC light trap"\n  }\n]',
#  '[\n  {\n    "parent": "entity",\n    "child": "occurrent"\n  },\n  {\n    "parent": "entity",\n    "child": "spatiotemporal region"\n  },\n  {\n    "parent": "spatiotemporal region",\n    "child": "process boundary"\n  }\n]',
#  '[\n  {\n    "parent": "liquid chromatography instrument",\n    "child": "high performance liquid chromatography instrument"\n  }\n]',
#  '[\n  {\n    "parent": "endonuclease mediated mutagenesis",\n    "child": "TALEN mediated mutagenesis"\n  },\n  {\n    "parent": "endonuclease mediated mutagenesis",\n    "child": "cas mediated mutagenesis"\n  }\n]',
#  '[\n  {\n    "parent": "network graph quality calculation",\n    "child": "global modularity calculation"\n  }\n]',
#  '[\n  {\n    "parent": "flow rate",\n    "child": "fluid flow rate"\n  }\n]',
#  '[\n  {\n    "parent": "quality of interaction of a substance with electromagnetic radiation",\n    "child": "fluorescence"\n  },\n  {\n    "parent": "quality of interaction of a substance with electromagnetic radiation",\n    "child": "optical quality"\n  }\n]',
#  '[\n  {\n    "parent": "organism substance",\n    "child": "amniotic fluid"\n  },\n  {\n    "parent": "organism substance",\n    "child": "respiratory system fluid/secretion"\n  },\n  {\n    "parent": "organism substance",\n    "child": "saliva"\n  },\n  {\n    "parent": "organism substance",\n    "child": "sputum"\n  },\n  {\n    "parent": "organism substance",\n    "child": "urine"\n  },\n  {\n    "parent": "respiratory system fluid/secretion",\n    "child": "sputum"\n  }\n]',
#  '[\n  {\n    "parent": "secondary structure of sequence macromolecule",\n    "child": "secondary structure of RNA molecule"\n  }\n]',
#  '[\n  {\n    "parent": "high resolution probe",\n    "child": "Bruker high resolution probe"\n  },\n  {\n    "parent": "high resolution probe",\n    "child": "flow high resolution probe"\n  },\n  {\n    "parent": "high resolution probe",\n    "child": "high resolution magic angle spin probe"\n  },\n  {\n    "parent": "probe",\n    "child": "tecmag EAGLE probe"\n  },\n  {\n    "parent": "probe",\n    "child": "high resolution probe"\n  }\n]',
#  '{\n  "Answer": [\n    {\n      "parent": "Varian NMR instrument",\n      "child": "Varian GEMINI spectrometer"\n    },\n    {\n      "parent": "Varian NMR instrument",\n      "child": "Varian MERCURY spectrometer"\n    },\n    {\n      "parent": "Varian NMR instrument",\n      "child": "Varian UNITY spectrometer"\n    },\n    {\n      "parent": "Varian NMR instrument",\n      "child": "Varian VXR spectrometer"\n    },\n    {\n      "parent": "Varian UNITY spectrometer",\n      "child": "Varian UNITY INOVA spectrometer"\n    }\n  ]\n}',
#  '[\n  {\n    "parent": "Flaviviridae",\n    "child": "Dengue virus"\n  },\n  {\n    "parent": "Flaviviridae",\n    "child": "Hepacivirus hominis"\n  }\n]',
#  '{\n  "Answer": [\n    {\n      "parent": "material separation objective",\n      "child": "separation into different composition objective"\n    }\n  ]\n}',
#  '[\n  {\n    "parent": "concentration of",\n    "child": "osmolality"\n  },\n  {\n    "parent": "molecular quality",\n    "child": "concentration of"\n  },\n  {\n    "parent": "molecular quality",\n    "child": "osmolality"\n  }\n]',
#  '[\n  {\n    "parent": "replicate analysis",\n    "child": "dye swap merge"\n  }\n]',
#  '[\n  {\n    "parent": "imaging assay",\n    "child": "computed tomography imaging assay"\n  },\n  {\n    "parent": "imaging assay",\n    "child": "magnetic resonance imaging assay"\n  },\n  {\n    "parent": "imaging assay",\n    "child": "positron emission tomography imaging assay"\n  }\n]',
#  '[\n  {\n    "parent": "sequence feature identification objective",\n    "child": "protein and DNA interaction identification objective"\n  },\n  {\n    "parent": "sequence feature identification objective",\n    "child": "protein and RNA interaction identification objective"\n  }\n]',
#  '[\n  {\n    "parent": "human specimen set",\n    "child": "specimens collected in one encounter"\n  }\n]',
#  '[\n  {\n    "parent": "rapid amplification of cDNA ends",\n    "child": "3\' rapid amplification of cDNA ends"\n  },\n  {\n    "parent": "rapid amplification of cDNA ends",\n    "child": "5\' rapid amplification of cDNA ends"\n  },\n  {\n    "parent": "5\' rapid amplification of cDNA ends",\n    "child": "5\' RNA ligase mediated rapid amplification of cDNA ends"\n  }\n]',
#  '[\n  {\n    "parent": "repeated measure design",\n    "child": "cross over design"\n  },\n  {\n    "parent": "repeated measure design",\n    "child": "n-to-1 design"\n  }\n]',
#  '[\n  {\n    "parent": "sequence_assembly",\n    "child": "supercontig"\n  }\n]',
#  '[\n  {\n    "parent": "light trap",\n    "child": "light trap for indoor use"\n  },\n  {\n    "parent": "light trap",\n    "child": "light trap for outdoor use"\n  }\n]',
#  '[\n  {\n    "parent": "immunization",\n    "child": "Immunization in vivo"\n  },\n  {\n    "parent": "Immunization in vivo",\n    "child": "Individual epitope immunization in vivo"\n  }\n]',
#  '[\n  {\n    "parent": "T cell tolerance induction",\n    "child": "epitope specific T cell tolerance induction"\n  },\n  {\n    "parent": "T cell tolerance induction",\n    "child": "epitope specific tolerance induction by T cells"\n  }\n]',
#  '[\n  {\n    "parent": "Mammalia",\n    "child": "Euarchontoglires"\n  },\n  {\n    "parent": "Euarchontoglires",\n    "child": "Rodentia"\n  }\n]',
#  '[\n  {\n    "parent": "face mask",\n    "child": "medical mask"\n  },\n  {\n    "parent": "face mask",\n    "child": "non-medical mask"\n  }\n]',
#  '{\n  "Answer": [\n    {\n      "parent": "measurement unit label",\n      "child": "concentration unit"\n    },\n    {\n      "parent": "measurement unit label",\n      "child": "frequency unit"\n    },\n    {\n      "parent": "measurement unit label",\n      "child": "length unit"\n    },\n    {\n      "parent": "measurement unit label",\n      "child": "mass unit"\n    },\n    {\n      "parent": "measurement unit label",\n      "child": "pressure unit"\n    },\n    {\n      "parent": "measurement unit label",\n      "child": "substance unit"\n    },\n    {\n      "parent": "measurement unit label",\n      "child": "time unit"\n    },\n    {\n      "parent": "measurement unit label",\n      "child": "volume unit"\n    }\n  ]\n}',
#  '[\n  {\n    "parent": "Bruker NMR magnet",\n    "child": "Bruker Ultrastabilized NMR magnet"\n  },\n  {\n    "parent": "Bruker Ultrastabilized NMR magnet",\n    "child": "Bruker US 2 NMR magnet"\n  },\n  {\n    "parent": "Bruker NMR magnet",\n    "child": "Bruker US 2 NMR magnet"\n  }\n]',
#  '[\n  {\n    "parent": "Homo sapiens",\n    "child": "specimen collector"\n  }\n]',
#  '[\n  {\n    "parent": "machine learning",\n    "child": "supervised machine learning"\n  },\n  {\n    "parent": "machine learning",\n    "child": "unsupervised machine learning"\n  }\n]',
#  '[\n  {\n    "parent": "epithelial cell",\n    "child": "hepatocyte"\n  },\n  {\n    "parent": "epithelial cell",\n    "child": "mesothelial cell"\n  }\n]',
#  '[\n  {\n    "parent": "sequence trimming",\n    "child": "adapter-sequence trimming"\n  }\n]',
#  '[\n  {\n    "parent": "performance status value specification",\n    "child": "Eastern Cooperative Oncology Group score value specification"\n  },\n  {\n    "parent": "performance status value specification",\n    "child": "Karnofsky score vaue specification"\n  }\n]',
#  '[\n  {\n    "parent": "import ontology module",\n    "child": "external import ontology module"\n  }\n]',
#  '[\n  {\n    "parent": "type IV hypersensitivity",\n    "child": "epitope specific type IV hypersensitivity by T cells"\n  }\n]',
#  '[\n  {\n    "parent": "data format specification",\n    "child": "BCL format"\n  }\n]',
#  '[\n  {\n    "parent": "DNA adenine methyltransferase identification assay",\n    "child": "DamID-seq"\n  }\n]',
#  '[\n  {\n    "parent": "hydrogen/deuterium exchange footprinting assay",\n    "child": "hydrogen/deuterium exchange footprinting assay measuring binding of a B cell epitope:antibody complex"\n  }\n]',
#  '[\n  {\n    "parent": "nasopharynx specimen",\n    "child": "nasopharyngeal aspirate specimen"\n  },\n  {\n    "parent": "nasopharynx specimen",\n    "child": "nasopharyngeal swab specimen"\n  }\n]',
#  '[\n  {\n    "parent": "multiplexed fluorescent antibody imaging assay",\n    "child": "Cell DIVE multiplexed imaging assay"\n  },\n  {\n    "parent": "multiplexed fluorescent antibody imaging assay",\n    "child": "co-detection by indexing assay"\n  }\n]',
#  '[\n  {\n    "parent": "methodology testing objective",\n    "child": "protocol testing objective"\n  }\n]',
#  '{\n  "Answer": [\n    {\n      "parent": "directed mutagenesis",\n      "child": "targeted mutagenesis"\n    }\n  ]\n}',
#  '[\n  {\n    "parent": "B cell receptor repertoire sequencing assay",\n    "child": "single cell B cell receptor repertoire sequencing assay"\n  }\n]',
#  '[\n  {\n    "parent": "histamine secretion mediated by immunoglobulin",\n    "child": "B cell epitope specific histamine secretion mediated by immunoglobulin"\n  }\n]',
#  '[\n  {\n    "parent": "peptide",\n    "child": "synthetic peptide"\n  }\n]',
#  '[\n  {\n    "parent": "Bruker NMR probe",\n    "child": "Bruker 1mm MicroProbe"\n  },\n  {\n    "parent": "Bruker NMR probe",\n    "child": "Bruker CryoProbe"\n  },\n  {\n    "parent": "Bruker NMR probe",\n    "child": "Bruker solid magic angle spinning probe"\n  }\n]',
#  '[\n  {\n    "parent": "collection of specimens",\n    "child": "specimens collected longitudinally"\n  }\n]',
#  '[\n  {\n    "parent": "granzyme B production",\n    "child": "epitope specific granzyme B production by T cells"\n  }\n]',
#  '[\n  {\n    "parent": "material information bearer",\n    "child": "random access memory"\n  }\n]',
#  '[\n  {\n    "parent": "Murinae",\n    "child": "Mus musculus"\n  },\n  {\n    "parent": "Murinae",\n    "child": "Rattus norvegicus"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "figure",\n    "child": "image"\n  }\n]',
#  '[\n  {\n    "parent": "feces",\n    "child": "meconium"\n  }\n]',
#  '[\n  {\n    "parent": "electrophoresis system",\n    "child": "capillary electrophoresis instrument"\n  }\n]',
#  '[]',
#  '{"Answer": []}',
#  '[]']

# %%
final_result = []
for ans in final_ans:
    ans_1 = json.loads(ans)
    if "Answer" not in ans_1:
        for an in ans_1:
            # print(an)
            # if an!="Answer":
                if an not in final_result:
                    final_result.append(an)
    else:
        for an in ans_1['Answer']:
                if an not in final_result:
                    final_result.append(an)

# %%
len(final_result)
# Out:
# 652

# %%
final_result
# Out:
# [{'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing',
#   'child': 'DNASE 1 structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing',
#   'child': 'RNA ADA I RNA structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing',
#   'child': 'RNASE CL3 structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing',
#   'child': 'RNASE T1 structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing',
#   'child': 'RNASE T2 structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing',
#   'child': 'RNASE U2 structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using enzymatic probing',
#   'child': 'RNASE V1 structure mapping assay'},
#  {'parent': 'parallel analysis of RNA structure assay',
#   'child': 'RNA ADA I RNA structure mapping assay'},
#  {'parent': 'parallel analysis of RNA structure assay',
#   'child': 'RNASE CL3 structure mapping assay'},
#  {'parent': 'parallel analysis of RNA structure assay',
#   'child': 'RNASE T1 structure mapping assay'},
#  {'parent': 'parallel analysis of RNA structure assay',
#   'child': 'RNASE T2 structure mapping assay'},
#  {'parent': 'parallel analysis of RNA structure assay',
#   'child': 'RNASE U2 structure mapping assay'},
#  {'parent': 'parallel analysis of RNA structure assay',
#   'child': 'RNASE V1 structure mapping assay'},
#  {'parent': 'histologic grade for ovarian tumor',
#   'child': 'histologic grade for ovarian tumor according to the World Health Organization'},
#  {'parent': 'brain', 'child': 'cerebellum'},
#  {'parent': 'brain', 'child': 'brain specimen'},
#  {'parent': 'cerebellum', 'child': 'cerebellum specimen'},
#  {'parent': 'brain specimen', 'child': 'cerebellum specimen'},
#  {'parent': 'opsonization', 'child': 'B cell epitope specific opsonization'},
#  {'parent': 'Bruker NMR instrument', 'child': 'AVANCE II spectrometer'},
#  {'parent': 'Bruker NMR instrument',
#   'child': 'Bruker AC series NMR instrument'},
#  {'parent': 'Bruker NMR instrument',
#   'child': 'Bruker AMX series NMR instrument'},
#  {'parent': 'Bruker NMR instrument', 'child': 'Bruker LC-NMR platform'},
#  {'parent': 'Bruker NMR instrument', 'child': 'Bruker SPE-NMR platform'},
#  {'parent': 'Bruker NMR instrument', 'child': 'Bruker NMR magnet'},
#  {'parent': 'Bruker NMR instrument', 'child': 'Bruker NMR probe'},
#  {'parent': 'Bruker NMR instrument', 'child': 'Bruker autosampler'},
#  {'parent': 'Bruker NMR magnet', 'child': 'Bruker UltraShield NMR magnet'},
#  {'parent': 'Bruker NMR magnet',
#   'child': 'Bruker UltraShield Plus NMR magnet'},
#  {'parent': 'Bruker NMR probe', 'child': 'Bruker micro imaging probe'},
#  {'parent': 'Bruker autosampler', 'child': 'Bruker NMR Case sample changer'},
#  {'parent': 'Bruker LC-NMR platform',
#   'child': 'Bruker Capillary LC-NMR platform'},
#  {'parent': 'Bruker LC-NMR platform', 'child': 'Bruker LC-NMR/MS platform'},
#  {'parent': 'personal protective device',
#   'child': 'personal protective clothing item'},
#  {'parent': 'personal protective clothing item', 'child': 'footwear cover'},
#  {'parent': 'personal protective clothing item', 'child': 'laboratory coat'},
#  {'parent': 'personal protective clothing item', 'child': 'medical cap'},
#  {'parent': 'personal protective clothing item', 'child': 'medical gown'},
#  {'parent': 'personal protective clothing item',
#   'child': 'personal protective glove'},
#  {'parent': 'personal protective clothing item', 'child': 'protective apron'},
#  {'parent': 'personal protective clothing item',
#   'child': 'protective coverall'},
#  {'parent': 'personal protective clothing item', 'child': 'protective sleeve'},
#  {'parent': 'personal protective clothing item', 'child': 'scrubs'},
#  {'parent': 'footwear cover', 'child': 'disposable footwear cover'},
#  {'parent': 'footwear cover', 'child': 'reusable footwear cover'},
#  {'parent': 'medical gown', 'child': 'surgical gown'},
#  {'parent': 'personal protective glove', 'child': 'medical glove'},
#  {'parent': 'functional assessment of individual',
#   'child': 'nervous system functionality assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'bulbar assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'muscle atrophy assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'muscle weakness assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'deep tendon reflex assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'limb coordination assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'dysmetria assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'gait assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'upright stability assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'position sense assessment'},
#  {'parent': 'nervous system functionality assessment',
#   'child': 'vibratory sense assessment'},
#  {'parent': 'bulbar assessment', 'child': 'speech test assessment'},
#  {'parent': 'bulbar assessment', 'child': 'forced cough assessment'},
#  {'parent': 'speech test assessment',
#   'child': 'spontaneous speech assessment'},
#  {'parent': 'muscle atrophy assessment', 'child': 'facial atrophy assessment'},
#  {'parent': 'deep tendon reflex assessment',
#   'child': 'deep tendon reflex assessment of the ankle joint'},
#  {'parent': 'deep tendon reflex assessment',
#   'child': 'deep tendon reflex assessment of the brachioradialis'},
#  {'parent': 'deep tendon reflex assessment',
#   'child': 'deep tendon reflex assessment of the knee joint'},
#  {'parent': 'deep tendon reflex assessment',
#   'child': 'deep tendon reflex assessment of the tendon of biceps brachii'},
#  {'parent': 'limb coordination assessment',
#   'child': 'upper limb coordination assessment'},
#  {'parent': 'limb coordination assessment',
#   'child': 'lower limb coordination assessment'},
#  {'parent': 'upper limb coordination assessment',
#   'child': 'finger taps assessment'},
#  {'parent': 'upper limb coordination assessment',
#   'child': 'finger to finger assessment'},
#  {'parent': 'upper limb coordination assessment',
#   'child': 'nose to finger assessment'},
#  {'parent': 'upper limb coordination assessment',
#   'child': 'rapid alternating hands assessment'},
#  {'parent': 'lower limb coordination assessment',
#   'child': 'heel along shin assessment'},
#  {'parent': 'lower limb coordination assessment',
#   'child': 'heel to shin assessment'},
#  {'parent': 'gait assessment', 'child': 'tandem walk assessment'},
#  {'parent': 'upright stability assessment',
#   'child': 'limits of stability assessment'},
#  {'parent': 'upright stability assessment',
#   'child': 'sitting posture assessment'},
#  {'parent': 'upright stability assessment',
#   'child': 'stance feet apart assessment'},
#  {'parent': 'stance feet apart assessment',
#   'child': 'stance feet apart assessment, with eyes closed'},
#  {'parent': 'upright stability assessment',
#   'child': 'stance feet together assessment'},
#  {'parent': 'stance feet together assessment',
#   'child': 'stance feet together assessment, with eyes closed'},
#  {'parent': 'upright stability assessment',
#   'child': 'stance on one foot assessment'},
#  {'parent': 'upright stability assessment',
#   'child': 'tandem stance assessment'},
#  {'parent': 'lowess transformation', 'child': 'lowess global transformation'},
#  {'parent': 'lowess transformation', 'child': 'lowess group transformation'},
#  {'parent': 'JEOL NMR probe', 'child': 'JEOL CapNMR probe'},
#  {'parent': 'alpha-beta T cell', 'child': 'CD4-positive, alpha-beta T cell'},
#  {'parent': 'alpha-beta T cell', 'child': 'CD8-positive, alpha-beta T cell'},
#  {'parent': 'CD8-positive, alpha-beta T cell',
#   'child': 'CD8-positive, alpha-beta cytotoxic T cell'},
#  {'parent': 'MHC protein complex', 'child': 'MHC class I protein complex'},
#  {'parent': 'MHC protein complex', 'child': 'MHC class II protein complex'},
#  {'parent': 'MHC protein complex',
#   'child': 'mouse MHC protein complex with H2-p haplotype'},
#  {'parent': 'MHC class I protein complex',
#   'child': 'human MHC class I protein complex'},
#  {'parent': 'MHC class I protein complex',
#   'child': 'mouse MHC class I protein complex'},
#  {'parent': 'MHC class I protein complex',
#   'child': 'cattle MHC class I protein complex'},
#  {'parent': 'MHC class II protein complex',
#   'child': 'cattle MHC class II protein complex'},
#  {'parent': 'MHC class II protein complex',
#   'child': 'mouse MHC class II protein complex'},
#  {'parent': 'MHC class II protein complex',
#   'child': 'rat MHC class II protein complex with RT1-A haplotype'},
#  {'parent': 'MHC class II protein complex',
#   'child': 'HLA protein complex with DQ3 serotype'},
#  {'parent': 'human MHC class I protein complex',
#   'child': 'HLA protein complex with A2 serotype'},
#  {'parent': 'human MHC class I protein complex',
#   'child': 'HLA protein complex with A24 serotype'},
#  {'parent': 'human MHC class I protein complex',
#   'child': 'HLA protein complex with A28 serotype'},
#  {'parent': 'human MHC class I protein complex',
#   'child': 'HLA protein complex with A29 serotype'},
#  {'parent': 'human MHC class I protein complex',
#   'child': 'HLA-C protein complex'},
#  {'parent': 'mouse MHC class I protein complex',
#   'child': 'H2-Dq protein complex'},
#  {'parent': 'mouse MHC class I protein complex',
#   'child': 'H2-Kb protein complex'},
#  {'parent': 'mouse MHC class I protein complex',
#   'child': 'H2-Kd protein complex'},
#  {'parent': 'mouse MHC class I protein complex',
#   'child': 'H2-Kq protein complex'},
#  {'parent': 'mouse MHC class I protein complex',
#   'child': 'H2-Ks protein complex'},
#  {'parent': 'mouse MHC class I protein complex',
#   'child': 'mouse MHC class I protein complex with H2-b haplotype'},
#  {'parent': 'mouse MHC class II protein complex',
#   'child': 'H2-IA protein complex'},
#  {'parent': 'mouse MHC class II protein complex',
#   'child': 'H2-IAd protein complex'},
#  {'parent': 'mouse MHC class II protein complex',
#   'child': 'H2-IAg7 protein complex'},
#  {'parent': 'MHC protein complex',
#   'child': 'human MHC class I protein complex'},
#  {'parent': 'MHC protein complex',
#   'child': 'mouse MHC class I protein complex'},
#  {'parent': 'MHC protein complex',
#   'child': 'cattle MHC class I protein complex'},
#  {'parent': 'MHC protein complex',
#   'child': 'cattle MHC class II protein complex'},
#  {'parent': 'MHC protein complex',
#   'child': 'mouse MHC class II protein complex'},
#  {'parent': 'MHC protein complex',
#   'child': 'rat MHC class II protein complex with RT1-A haplotype'},
#  {'parent': 'MHC protein complex',
#   'child': 'HLA protein complex with DQ3 serotype'},
#  {'parent': 'MHC protein complex',
#   'child': 'HLA protein complex with A2 serotype'},
#  {'parent': 'MHC protein complex',
#   'child': 'HLA protein complex with A24 serotype'},
#  {'parent': 'MHC protein complex',
#   'child': 'HLA protein complex with A28 serotype'},
#  {'parent': 'MHC protein complex',
#   'child': 'HLA protein complex with A29 serotype'},
#  {'parent': 'MHC protein complex', 'child': 'HLA-C protein complex'},
#  {'parent': 'MHC protein complex', 'child': 'H2-Dq protein complex'},
#  {'parent': 'MHC protein complex', 'child': 'H2-Kb protein complex'},
#  {'parent': 'MHC protein complex', 'child': 'H2-Kd protein complex'},
#  {'parent': 'MHC protein complex', 'child': 'H2-Kq protein complex'},
#  {'parent': 'MHC protein complex', 'child': 'H2-Ks protein complex'},
#  {'parent': 'MHC protein complex',
#   'child': 'mouse MHC class I protein complex with H2-b haplotype'},
#  {'parent': 'MHC protein complex', 'child': 'H2-IA protein complex'},
#  {'parent': 'MHC protein complex', 'child': 'H2-IAd protein complex'},
#  {'parent': 'MHC protein complex', 'child': 'H2-IAg7 protein complex'},
#  {'parent': 'MHC class I protein complex',
#   'child': 'HLA protein complex with A2 serotype'},
#  {'parent': 'MHC class I protein complex',
#   'child': 'HLA protein complex with A24 serotype'},
#  {'parent': 'MHC class I protein complex',
#   'child': 'HLA protein complex with A28 serotype'},
#  {'parent': 'MHC class I protein complex',
#   'child': 'HLA protein complex with A29 serotype'},
#  {'parent': 'MHC class I protein complex', 'child': 'HLA-C protein complex'},
#  {'parent': 'MHC class I protein complex', 'child': 'H2-Dq protein complex'},
#  {'parent': 'MHC class I protein complex', 'child': 'H2-Kb protein complex'},
#  {'parent': 'MHC class I protein complex', 'child': 'H2-Kd protein complex'},
#  {'parent': 'MHC class I protein complex', 'child': 'H2-Kq protein complex'},
#  {'parent': 'MHC class I protein complex', 'child': 'H2-Ks protein complex'},
#  {'parent': 'MHC class I protein complex',
#   'child': 'mouse MHC class I protein complex with H2-b haplotype'},
#  {'parent': 'MHC class II protein complex', 'child': 'H2-IA protein complex'},
#  {'parent': 'MHC class II protein complex', 'child': 'H2-IAd protein complex'},
#  {'parent': 'MHC class II protein complex',
#   'child': 'H2-IAg7 protein complex'},
#  {'parent': 'biological feature identification objective',
#   'child': 'cellular feature identification objective'},
#  {'parent': 'biological feature identification objective',
#   'child': 'molecular feature identification objective'},
#  {'parent': 'biological feature identification objective',
#   'child': 'organism feature identification objective'},
#  {'parent': 'cellular feature identification objective',
#   'child': 'cellular structure feature identification objective'},
#  {'parent': 'molecular feature identification objective',
#   'child': 'DNA replication identification objective'},
#  {'parent': 'molecular feature identification objective',
#   'child': 'molecular function identification objective'},
#  {'parent': 'organism feature identification objective',
#   'child': 'organism species detection objective'},
#  {'parent': 'organism species detection objective',
#   'child': 'detection of pathogenic organisms objective'},
#  {'parent': 'assay kit', 'child': 'Advantage Chikungunya IgM Card kit'},
#  {'parent': 'assay kit', 'child': 'Panbio Dengue Early ELISA kit'},
#  {'parent': 'assay kit', 'child': 'Panbio Dengue IgM capture ELISA kit'},
#  {'parent': 'assay kit', 'child': 'SD Bioline Chikungunya IgM RDT kit'},
#  {'parent': 'assay kit',
#   'child': 'SD Bioline Chikungunya IgM capture ELISA kit'},
#  {'parent': 'assay kit', 'child': 'Scrub Typhus Detect IgM ELISA kit'},
#  {'parent': 'biological attribute', 'child': 'ankle joint functionality'},
#  {'parent': 'biological attribute', 'child': 'brachioradialis functionality'},
#  {'parent': 'biological attribute', 'child': 'knee joint functionality'},
#  {'parent': 'biological attribute', 'child': 'limb coordination efficacy'},
#  {'parent': 'biological attribute',
#   'child': 'lower limb coordination efficacy'},
#  {'parent': 'biological attribute',
#   'child': 'peripheral nervous system function'},
#  {'parent': 'biological attribute',
#   'child': 'tendon of biceps brachii functionality'},
#  {'parent': 'biological attribute',
#   'child': 'upper limb coordination efficacy'},
#  {'parent': 'biological attribute', 'child': 'whole organism stability'},
#  {'parent': 'whole organism stability', 'child': 'limb coordination efficacy'},
#  {'parent': 'limb coordination efficacy',
#   'child': 'lower limb coordination efficacy'},
#  {'parent': 'limb coordination efficacy',
#   'child': 'upper limb coordination efficacy'},
#  {'parent': 'lower limb coordination efficacy',
#   'child': 'ankle joint functionality'},
#  {'parent': 'lower limb coordination efficacy',
#   'child': 'knee joint functionality'},
#  {'parent': 'upper limb coordination efficacy',
#   'child': 'brachioradialis functionality'},
#  {'parent': 'upper limb coordination efficacy',
#   'child': 'tendon of biceps brachii functionality'},
#  {'parent': 'peripheral nervous system function',
#   'child': 'limb coordination efficacy'},
#  {'parent': 'peripheral nervous system function',
#   'child': 'ankle joint functionality'},
#  {'parent': 'peripheral nervous system function',
#   'child': 'brachioradialis functionality'},
#  {'parent': 'peripheral nervous system function',
#   'child': 'knee joint functionality'},
#  {'parent': 'peripheral nervous system function',
#   'child': 'tendon of biceps brachii functionality'},
#  {'parent': 'morphology', 'child': 'size'},
#  {'parent': 'morphology', 'child': 'structure'},
#  {'parent': 'structure', 'child': 'composition'},
#  {'parent': 'damage', 'child': 'damaged'},
#  {'parent': 'resting arthropod trap', 'child': 'artificial pit shelter'},
#  {'parent': 'resting arthropod trap', 'child': 'resting bucket'},
#  {'parent': 'resting arthropod trap', 'child': 'resting clay pot trap'},
#  {'parent': 'resting bucket', 'child': 'sticky resting bucket'},
#  {'parent': 'gas chromatography equipment',
#   'child': 'gas chromatography oven'},
#  {'parent': 'gas generator', 'child': 'hydrogen generator'},
#  {'parent': 'gas generator', 'child': 'nitrogen generator'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'CMCT structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'DEPC structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'DMS structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'ENU structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'Fe-BABE RNA structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'Lead structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'MPE-Fe(II) structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'OH-radical structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'Rhodium DNA structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'Ruthenium structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'Terbium RNA structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'inline probing RNA structure mapping assay'},
#  {'parent': 'single-nucleotide-resolution nucleic acid structure mapping assay using chemical probing',
#   'child': 'kethoxal structure mapping assay'},
#  {'parent': 'process', 'child': 'biological_process'},
#  {'parent': 'process', 'child': 'pathologic process'},
#  {'parent': 'process', 'child': 'environmental proximity to infectious agent'},
#  {'parent': 'process', 'child': 'planning'},
#  {'parent': 'process', 'child': 'scratching'},
#  {'parent': 'process',
#   'child': 'unplanned occurrence effecting an investigation'},
#  {'parent': 'molecular_function', 'child': 'binding'},
#  {'parent': 'molecular_function', 'child': 'catalytic activity'},
#  {'parent': 'molecular_function', 'child': 'monoatomic ion channel activity'},
#  {'parent': 'biological_process', 'child': 'cellular process'},
#  {'parent': 'biological_process', 'child': 'response to stimulus'},
#  {'parent': 'biological_process', 'child': 'blood coagulation'},
#  {'parent': 'biological_process', 'child': 'fertilization'},
#  {'parent': 'biological_process', 'child': 'hemopoiesis'},
#  {'parent': 'biological_process', 'child': 'granzyme A production'},
#  {'parent': 'biological_process', 'child': 'perforin production'},
#  {'parent': 'cellular process', 'child': 'action potential'},
#  {'parent': 'cellular process',
#   'child': 'actin polymerization-dependent cell motility'},
#  {'parent': 'cellular process', 'child': 'cell cycle'},
#  {'parent': 'cellular process', 'child': 'cell killing'},
#  {'parent': 'cellular process', 'child': 'cell population proliferation'},
#  {'parent': 'cellular process', 'child': 'chromosome organization'},
#  {'parent': 'cellular process', 'child': 'cytotoxic T cell degranulation'},
#  {'parent': 'cellular process', 'child': 'macromolecule localization'},
#  {'parent': 'cellular process', 'child': 'phagocytosis'},
#  {'parent': 'cell killing',
#   'child': 'antibody-dependent cellular cytotoxicity'},
#  {'parent': 'cell killing', 'child': 'complement-dependent cytotoxicity'},
#  {'parent': 'complement-dependent cytotoxicity',
#   'child': 'B cell epitope specific complement-dependent cytotoxicity'},
#  {'parent': 'cytotoxic T cell degranulation',
#   'child': 'granzyme A release during T cell degranulation'},
#  {'parent': 'cytotoxic T cell degranulation',
#   'child': 'perforin release during T cell degranulation'},
#  {'parent': 'response to stimulus', 'child': 'DNA damage response'},
#  {'parent': 'response to stimulus', 'child': 'immune response'},
#  {'parent': 'immune response', 'child': 'adaptive immune response'},
#  {'parent': 'immune response', 'child': 'hypersensitivity'},
#  {'parent': 'immune response', 'child': 'tolerance induction'},
#  {'parent': 'adaptive immune response',
#   'child': 'antigen processing and presentation'},
#  {'parent': 'adaptive immune response', 'child': 'B cell tolerance induction'},
#  {'parent': 'adaptive immune response',
#   'child': 'epitope binding by adaptive immune receptor'},
#  {'parent': 'adaptive immune response',
#   'child': 'helper T cell enhancement of adaptive immune response'},
#  {'parent': 'adaptive immune response',
#   'child': 'immunoglobulin mediated immune response'},
#  {'parent': 'tolerance induction', 'child': 'B cell tolerance induction'},
#  {'parent': 'hypersensitivity', 'child': 'allergic reaction'},
#  {'parent': 'hypersensitivity',
#   'child': 'B cell epitope specific hypersensitivity'},
#  {'parent': 'immunoglobulin mediated immune response',
#   'child': 'immune complex formation'},
#  {'parent': 'immunoglobulin mediated immune response',
#   'child': 'immunoglobulin mediated histamine release'},
#  {'parent': 'immunoglobulin mediated immune response',
#   'child': 'immunoglobulin-mediated neutralization'},
#  {'parent': 'immune complex formation',
#   'child': 'B cell epitope specific immune complex formation'},
#  {'parent': 'immunoglobulin-mediated neutralization',
#   'child': 'B cell epitope specific immunoglobulin-mediated neutralization'},
#  {'parent': 'helper T cell enhancement of adaptive immune response',
#   'child': 'helper T cell enhancement of B cell mediated immune response'},
#  {'parent': 'helper T cell enhancement of B cell mediated immune response',
#   'child': 'epitope specific T cell enhancement of B cell mediated immune response'},
#  {'parent': 'granzyme A production',
#   'child': 'epitope specific granzyme A production by T cells'},
#  {'parent': 'perforin production',
#   'child': 'epitope specific perforin production by T cells'},
#  {'parent': 'pathologic process', 'child': 'disease stage'},
#  {'parent': 'pathologic process', 'child': 'infection process'},
#  {'parent': 'environmental proximity to infectious agent',
#   'child': 'contact to pathogen carrying biological vector'},
#  {'parent': 'environmental proximity to infectious agent',
#   'child': 'living in endemic area'},
#  {'parent': 'environmental proximity to infectious agent',
#   'child': 'living with infected household contact'},
#  {'parent': 'catalytic activity', 'child': "5'-nucleotidase activity"},
#  {'parent': 'catalytic activity', 'child': 'acyl-CoA oxidase activity'},
#  {'parent': 'catalytic activity', 'child': 'alkaline phosphatase activity'},
#  {'parent': 'catalytic activity', 'child': 'amylase activity'},
#  {'parent': 'catalytic activity',
#   'child': 'beta-N-acetylglucosaminidase activity'},
#  {'parent': 'catalytic activity', 'child': 'DNA polymerase activity'},
#  {'parent': 'catalytic activity', 'child': 'glutathione transferase activity'},
#  {'parent': 'catalytic activity',
#   'child': 'hydrolase activity, acting on ester bonds'},
#  {'parent': 'catalytic activity',
#   'child': 'isocitrate dehydrogenase [NAD(P)+] activity'},
#  {'parent': 'catalytic activity',
#   'child': 'L-alanine:2-oxoglutarate aminotransferase activity'},
#  {'parent': 'catalytic activity',
#   'child': 'L-aspartate:2-oxoglutarate aminotransferase activity'},
#  {'parent': 'catalytic activity',
#   'child': 'L-iditol 2-dehydrogenase (NAD+) activity'},
#  {'parent': 'catalytic activity', 'child': 'lactate dehydrogenase activity'},
#  {'parent': 'catalytic activity', 'child': 'RNA nuclease activity'},
#  {'parent': 'hydrolase activity, acting on ester bonds',
#   'child': 'carboxylic ester hydrolase activity'},
#  {'parent': 'carboxylic ester hydrolase activity',
#   'child': 'acetylcholinesterase activity'},
#  {'parent': 'carboxylic ester hydrolase activity',
#   'child': 'cholinesterase activity'},
#  {'parent': 'binding', 'child': 'antigen binding'},
#  {'parent': 'binding', 'child': 'MHC protein complex binding to ligand'},
#  {'parent': 'binding', 'child': 'protein domain specific binding'},
#  {'parent': 'binding', 'child': 'sequence-specific DNA binding'},
#  {'parent': 'antigen binding',
#   'child': 'epitope binding by adaptive immune receptor'},
#  {'parent': 'epitope binding by adaptive immune receptor',
#   'child': 'immunoglobulin binding to epitope'},
#  {'parent': 'MHC protein complex binding to ligand',
#   'child': 'MHC:epitope complex binding to TCR'},
#  {'parent': 'sequence-specific DNA binding',
#   'child': 'core promoter sequence-specific DNA binding'},
#  {'parent': 'neutrophil', 'child': 'immature neutrophil'},
#  {'parent': 'immature neutrophil', 'child': 'band form neutrophil'},
#  {'parent': 'neutrophil', 'child': 'band form neutrophil'},
#  {'parent': 'clonal cDNA library', 'child': 'recombinant vector'},
#  {'parent': 'phage display library', 'child': 'recombinant vector'},
#  {'parent': 'interleukin-27 production',
#   'child': 'epitope specific interleukin-27 production by T cells'},
#  {'parent': 'data set', 'child': 'computed image data set'},
#  {'parent': 'data set', 'child': 'image data set'},
#  {'parent': 'data set', 'child': 'clustered data set'},
#  {'parent': 'data set', 'child': 'normalized data set'},
#  {'parent': 'data set', 'child': 'background corrected data set'},
#  {'parent': 'image data set', 'child': 'magnetic resonance image data set'},
#  {'parent': 'image data set', 'child': 'brain region atlas image data set'},
#  {'parent': 'image data set', 'child': 'image segmentation map'},
#  {'parent': 'image data set', 'child': 'raw image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'T1 weighted magnetic resonance image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'T2 weighted magnetic resonance image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'T2* weighted GRE magnetic resonance image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'diffusion weighted magnetic resonance image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'perfusion weighted magnetic resonance image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'proton density magnetic resonance image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'functional magnetic resonance image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'raw magnetic resonance image data set'},
#  {'parent': 'magnetic resonance image data set',
#   'child': 'reconstructed magnetic resonance image data set'},
#  {'parent': 'T1 weighted magnetic resonance image data set',
#   'child': 'T1 weighted GRE magnetic resonance image data set'},
#  {'parent': 'T1 weighted magnetic resonance image data set',
#   'child': 'T1 weighted SE magnetic resonance image data set'},
#  {'parent': 'T1 weighted magnetic resonance image data set',
#   'child': 'high resolution T1 weighted magnetic resonance image data set'},
#  {'parent': 'T1 weighted magnetic resonance image data set',
#   'child': 'post-Gd T1 weighted magnetic resonance image data set'},
#  {'parent': 'T2 weighted magnetic resonance image data set',
#   'child': 'T2 weighted FLAIR magnetic resonance image data set'},
#  {'parent': 'T2 weighted magnetic resonance image data set',
#   'child': 'T2 weighted FSE  magnetic resonance image data set'},
#  {'parent': 'T2 weighted magnetic resonance image data set',
#   'child': 'T2 weighted SE magnetic resonance image data set'},
#  {'parent': 'T2 weighted magnetic resonance image data set',
#   'child': 'T2 weighted STIR magnetic resonance image data set'},
#  {'parent': 'high resolution T1 weighted magnetic resonance image data set',
#   'child': 'baseline high resolution T1 weighted magnetic resonance image data set'},
#  {'parent': 'high resolution T1 weighted magnetic resonance image data set',
#   'child': 'follow-up high resolution T1 weighted magnetic resonance image data set'},
#  {'parent': 'functional magnetic resonance image data set',
#   'child': 'resting state functional magnetic resonance image data set'},
#  {'parent': 'functional magnetic resonance image data set',
#   'child': 'task-based functional magnetic resonance image data set'},
#  {'parent': 'brain region atlas image data set',
#   'child': 'deterministic brain region atlas image data set'},
#  {'parent': 'brain region atlas image data set',
#   'child': 'probabilistic brain region atlas image dataset'},
#  {'parent': 'clustered data set',
#   'child': 'topologically preserved clustered data set'},
#  {'parent': 'lesion mask', 'child': 'T1 lesion mask'},
#  {'parent': 'lesion mask', 'child': 'T2 FLAIR lesion mask'},
#  {'parent': 'image creation device', 'child': 'image cytometer'},
#  {'parent': 'image creation device',
#   'child': 'infrared image acquisition device'},
#  {'parent': 'image creation device',
#   'child': 'small-animal image acquisition device'},
#  {'parent': 'Saccharomyces cerevisiae mating type',
#   'child': 'a mating type (yeast)'},
#  {'parent': 'region', 'child': 'regulatory_region'},
#  {'parent': 'regulatory_region', 'child': 'TF_binding_site'},
#  {'parent': 'region', 'child': 'TF_binding_site'},
#  {'parent': 'primary structure of RNA molecule', 'child': 'miRNA'},
#  {'parent': 'primary structure of DNA macromolecule',
#   'child': 'regulatory_region'},
#  {'parent': 'primary structure of DNA macromolecule',
#   'child': 'TF_binding_site'},
#  {'parent': 'exposure to environmental and workplace carcinogens history',
#   'child': 'exposure to asbestos history'},
#  {'parent': 'exposure to environmental and workplace carcinogens history',
#   'child': 'exposure to diesel exhaust history'},
#  {'parent': 'exposure to environmental and workplace carcinogens history',
#   'child': 'exposure to silica history'},
#  {'parent': 'acclimatization', 'child': 'exposure of material to environment'},
#  {'parent': 'exposure of material to environment', 'child': 'waiting'},
#  {'parent': 'acclimatization', 'child': 'waiting'},
#  {'parent': 'bodily fluid', 'child': 'bile'},
#  {'parent': 'bodily fluid', 'child': 'blood'},
#  {'parent': 'bodily fluid', 'child': 'cerebrospinal fluid'},
#  {'parent': 'bodily fluid', 'child': 'cervical mucus'},
#  {'parent': 'bodily fluid', 'child': 'milk'},
#  {'parent': 'bodily fluid', 'child': 'pericardial fluid'},
#  {'parent': 'bodily fluid', 'child': 'synovial fluid'},
#  {'parent': 'blood', 'child': 'capillary blood'},
#  {'parent': 'blood', 'child': 'placental blood'},
#  {'parent': 'blood', 'child': 'venous blood'},
#  {'parent': 'Bacteria', 'child': 'Orientia tsutsugamushi'},
#  {'parent': 'Bacteria', 'child': 'Treponema pallidum'},
#  {'parent': 'Eukaryota', 'child': 'Arabidopsis thaliana'},
#  {'parent': 'Eukaryota', 'child': 'Dictyostelium discoideum'},
#  {'parent': 'Eukaryota', 'child': 'Plasmodium'},
#  {'parent': 'Eukaryota', 'child': 'Plasmodium gametocyte'},
#  {'parent': 'genetically modified organism', 'child': 'transgenic organism'},
#  {'parent': 'infectious agent', 'child': 'Bacteria'},
#  {'parent': 'infectious agent', 'child': 'Orientia tsutsugamushi'},
#  {'parent': 'infectious agent', 'child': 'Plasmodium'},
#  {'parent': 'infectious agent', 'child': 'Plasmodium gametocyte'},
#  {'parent': 'infectious agent', 'child': 'Treponema pallidum'},
#  {'parent': 'organism', 'child': 'Arabidopsis thaliana'},
#  {'parent': 'organism', 'child': 'Bacteria'},
#  {'parent': 'organism', 'child': 'Dictyostelium discoideum'},
#  {'parent': 'organism', 'child': 'Eukaryota'},
#  {'parent': 'organism', 'child': 'Orientia tsutsugamushi'},
#  {'parent': 'organism', 'child': 'Plasmodium'},
#  {'parent': 'organism', 'child': 'Plasmodium gametocyte'},
#  {'parent': 'organism', 'child': 'Treponema pallidum'},
#  {'parent': 'organism', 'child': 'blood meal source organism'},
#  {'parent': 'organism', 'child': 'chimera'},
#  {'parent': 'organism', 'child': 'genetically modified organism'},
#  {'parent': 'organism', 'child': 'host of immune response'},
#  {'parent': 'organism', 'child': 'transgenic organism'},
#  {'parent': 'Plasmodium', 'child': 'Plasmodium gametocyte'},
#  {'parent': 'temporal region', 'child': 'one-dimensional temporal region'},
#  {'parent': 'Opisthokonta', 'child': 'Ascomycota'},
#  {'parent': 'Ascomycota', 'child': 'saccharomyceta'},
#  {'parent': 'saccharomyceta', 'child': 'Saccharomyces cerevisiae'},
#  {'parent': 'Ascomycota', 'child': 'Schizosaccharomyces pombe'},
#  {'parent': 'random mutagenesis', 'child': 'chemical mutagenesis'},
#  {'parent': 'random mutagenesis', 'child': 'irradiation mutagenesis'},
#  {'parent': 'random mutagenesis', 'child': 'transposon-induced mutagenesis'},
#  {'parent': 'fixed tissue specimen', 'child': 'fixed tissue slide specimen'},
#  {'parent': 'fixed tissue slide specimen',
#   'child': 'H&E-stained fixed tissue slide specimen'},
#  {'parent': 'fixed tissue slide specimen',
#   'child': 'IHC-stained fixed tissue slide specimen'},
#  {'parent': 'fixed tissue specimen',
#   'child': 'H&E-stained fixed tissue slide specimen'},
#  {'parent': 'fixed tissue specimen',
#   'child': 'IHC-stained fixed tissue slide specimen'},
#  {'parent': 'hormonal birth control use history',
#   'child': 'hormonal birth control current use history'},
#  {'parent': 'hormonal birth control use history',
#   'child': 'hormonal birth control former use history'},
#  {'parent': 'reason for lack of data item',
#   'child': 'cannot be assessed determination'},
#  {'parent': 'position', 'child': 'anterior to'},
#  {'parent': 'position', 'child': 'dorsal to'},
#  {'parent': 'position', 'child': 'lateral to'},
#  {'parent': 'position', 'child': 'right side of'},
#  {'parent': 'cellular quality', 'child': 'ploidy'},
#  {'parent': 'ploidy', 'child': 'euploid'},
#  {'parent': 'euploid', 'child': 'diploid'},
#  {'parent': 'protocol', 'child': 'animal care protocol'},
#  {'parent': 'protocol', 'child': 'magnetic resonance pulse sequence protocol'},
#  {'parent': 'protocol', 'child': 'specimen collection protocol'},
#  {'parent': 'disease course', 'child': 'occurrence of allergy'},
#  {'parent': 'disease course', 'child': 'occurrence of infectious disease'},
#  {'parent': 'organismal quality', 'child': 'behavioral quality'},
#  {'parent': 'organismal quality', 'child': 'viability'},
#  {'parent': 'organismal quality', 'child': 'biological sex'},
#  {'parent': 'organismal quality', 'child': 'fasted'},
#  {'parent': 'behavioral quality', 'child': 'handedness'},
#  {'parent': 'viability', 'child': 'alive'},
#  {'parent': 'biological sex', 'child': 'phenotypic sex'},
#  {'parent': 'biological sex', 'child': 'female'},
#  {'parent': 'biological sex', 'child': 'male'},
#  {'parent': 'biological sex', 'child': 'hermaphrodite'},
#  {'parent': 'phenotypic sex', 'child': 'female'},
#  {'parent': 'phenotypic sex', 'child': 'male'},
#  {'parent': 'phenotypic sex', 'child': 'hermaphrodite'},
#  {'parent': 'handedness', 'child': 'ambidextrous handedness'},
#  {'parent': 'handedness', 'child': 'left handedness'},
#  {'parent': 'handedness', 'child': 'right handedness'},
#  {'parent': 'handedness', 'child': 'obsolete_left handedness'},
#  {'parent': 'symbol', 'child': 'centrally registered identifier symbol'},
#  {'parent': 'centrally registered identifier symbol', 'child': 'GenBank ID'},
#  {'parent': 'centrally registered identifier symbol', 'child': 'PubMed ID'},
#  {'parent': 'centrally registered identifier symbol',
#   'child': 'SRS identifier'},
#  {'parent': 'centrally registered identifier symbol',
#   'child': 'digital object identifier'},
#  {'parent': 'centrally registered identifier symbol',
#   'child': 'grant identifier'},
#  {'parent': 'centrally registered identifier symbol',
#   'child': 'individual organism identifier'},
#  {'parent': 'centrally registered identifier symbol',
#   'child': 'investigation identifier'},
#  {'parent': 'centrally registered identifier symbol',
#   'child': 'participant identifier'},
#  {'parent': 'centrally registered identifier symbol',
#   'child': 'specimen identifier'},
#  {'parent': 'specimen identifier',
#   'child': 'specimen identifier assigned by sequencing facility'},
#  {'parent': 'specimen identifier',
#   'child': 'specimen identifier assigned by specimen repository'},
#  {'parent': 'antibody purification of H2-Dd protein complex and/or H2-Kd protein complex',
#   'child': 'antibody purification of H2-Dd protein complex'},
#  {'parent': 'antibody purification of H2-Dd protein complex and/or H2-Kd protein complex',
#   'child': 'antibody purification of H2-Kd protein complex'},
#  {'parent': 'algorithm', 'child': 'alignment counting algorithm'},
#  {'parent': 'algorithm', 'child': 'base calling algorithm'},
#  {'parent': 'algorithm', 'child': 'probabilistic algorithm'},
#  {'parent': 'algorithm',
#   'child': 'reference genome-transcriptome alignment algorithm'},
#  {'parent': 'algorithm', 'child': 'sequence assembly algorithm'},
#  {'parent': 'algorithm', 'child': 'verse algorithm'},
#  {'parent': 'reference genome-transcriptome alignment algorithm',
#   'child': 'star algorithm'},
#  {'parent': 'clinical data item',
#   'child': 'chronic allograft damage index score'},
#  {'parent': 'clinical data item',
#   'child': 'multidimensional fatigue inventory score'},
#  {'parent': 'clinical data item',
#   'child': "physician's global assessment of disease activity"},
#  {'parent': 'clinical data item',
#   'child': 'sequential organ failure assessment score'},
#  {'parent': 'cellular_component', 'child': 'chromosome'},
#  {'parent': 'cellular_component', 'child': 'membrane-bounded organelle'},
#  {'parent': 'cellular_component', 'child': 'mitochondrion'},
#  {'parent': 'membrane-bounded organelle', 'child': 'mitochondrion'},
#  {'parent': 'mating type', 'child': 'yeast mating type'},
#  {'parent': 'Viruses', 'child': 'Orthoherpesviridae'},
#  {'parent': 'Orthoherpesviridae', 'child': 'Cytomegalovirus'},
#  {'parent': 'Orthoherpesviridae', 'child': 'human gammaherpesvirus 4'},
#  {'parent': 'nasopharyngeal or oropharyngeal swab microbiology datum',
#   'child': 'bacteria in nasopharyngeal or oropharyngeal swab datum'},
#  {'parent': 'nasopharyngeal or oropharyngeal swab microbiology datum',
#   'child': 'eukaryota in nasopharyngeal or oropharyngeal swab datum'},
#  {'parent': 'nasopharyngeal or oropharyngeal swab microbiology datum',
#   'child': 'virus in nasopharyngeal or oropharyngeal swab datum'},
#  {'parent': 'antibody purification of mouse MHC class I protein complex',
#   'child': 'antibody purification of H2-Db protein complex'},
#  {'parent': 'antibody purification of mouse MHC class I protein complex',
#   'child': 'antibody purification of H2-Ld protein complex, H2-Db protein complex, and/or H2-Dq protein complex'},
#  {'parent': 'antibody purification of mouse MHC class I protein complex',
#   'child': 'antibody purification of mouse MHC class I protein complex with H2-b haplotype and/or mouse MHC protein complex with H2-p haplotype'},
#  {'parent': 'antibody purification of H2-Ld protein complex, H2-Db protein complex, and/or H2-Dq protein complex',
#   'child': 'antibody purification of H2-Db protein complex'},
#  {'parent': 'antibody purification of mouse MHC class I protein complex with H2-b haplotype and/or mouse MHC protein complex with H2-p haplotype',
#   'child': 'antibody purification of H2-Db protein complex'},
#  {'parent': 'Riboviria', 'child': 'Revtraviricetes'},
#  {'parent': 'Riboviria', 'child': 'Kitrinoviricota'},
#  {'parent': 'Revtraviricetes', 'child': 'Lentivirus'},
#  {'parent': 'Lentivirus', 'child': 'Human immunodeficiency virus 1'},
#  {'parent': 'Lentivirus', 'child': 'Human immunodeficiency virus 2'},
#  {'parent': 'Human immunodeficiency virus 1', 'child': 'HIV-1 group O'},
#  {'parent': 'Kitrinoviricota', 'child': 'Chikungunya virus'},
#  {'parent': 'assay measuring epitope specific',
#   'child': 'assay measuring epitope specific Ig-mediated histamine release'},
#  {'parent': 'assay measuring epitope specific',
#   'child': 'assay measuring epitope specific activation of additional immune response in vitro'},
#  {'parent': 'assay measuring epitope specific',
#   'child': 'assay measuring epitope specific complement-dependent cytotoxicity'},
#  {'parent': 'assay measuring epitope specific',
#   'child': 'assay measuring epitope specific immune complex formation'},
#  {'parent': 'material transformation objective',
#   'child': 'genetic transformation objective'},
#  {'parent': 'patch clamp assay', 'child': 'cell-attached patch clamp assay'},
#  {'parent': 'patch clamp assay', 'child': 'inside-out patch clamp assay'},
#  {'parent': 'patch clamp assay', 'child': 'outside-out patch clamp assay'},
#  {'parent': 'patch clamp assay', 'child': 'whole-cell patch clamp assay'},
#  {'parent': 'filled capsule', 'child': 'capsule shell'},
#  {'parent': 'pill', 'child': 'filled capsule'},
#  {'parent': 'autosampler', 'child': 'Bruker autosampler'},
#  {'parent': 'autosampler', 'child': 'Bruker B-ACS system'},
#  {'parent': 'autosampler', 'child': 'Bruker SampleJet system'},
#  {'parent': 'Bruker autosampler', 'child': 'Bruker B-ACS system'},
#  {'parent': 'Bruker autosampler', 'child': 'Bruker SampleJet system'},
#  {'parent': 'oral administration', 'child': 'oral ingestion of pill'},
#  {'parent': 'knockdown arthropod specimen collection process',
#   'child': 'knockdown arthropod specimen collection by pyrethrum spray'},
#  {'parent': 'optical microscope', 'child': 'stereo microscope'},
#  {'parent': 'graph', 'child': 'dendrogram'},
#  {'parent': 'graph', 'child': 'dot plot'},
#  {'parent': 'graph', 'child': 'heatmap'},
#  {'parent': 'graph', 'child': 'histogram'},
#  {'parent': 'graph', 'child': 'line graph'},
#  {'parent': 'graph', 'child': 'scatter plot'},
#  {'parent': 'line graph', 'child': 'survival curve'},
#  {'parent': 'line graph', 'child': 'dose response curve'},
#  {'parent': 'scatter plot', 'child': 'dose response curve'},
#  {'parent': 'specific enzymatic cleavage',
#   'child': 'DNA restriction enzyme digestion'},
#  {'parent': 'JEOL NMR instrument', 'child': 'JEOL ECA NMR spectrometer'},
#  {'parent': 'human MHC class II protein complex',
#   'child': 'HLA-DP protein complex'},
#  {'parent': 'human MHC class II protein complex',
#   'child': 'HLA-DR protein complex'},
#  {'parent': 'growth environment', 'child': 'atmosphere'},
#  {'parent': 'bacterial mating type', 'child': 'F mating type'},
#  {'parent': 'vitreous humor', 'child': 'vitreous humor specimen'},
#  {'parent': 'eye specimen', 'child': 'vitreous humor'},
#  {'parent': 'eye specimen', 'child': 'vitreous humor specimen'},
#  {'parent': 'DNA extract', 'child': 'high molecular weight DNA extract'},
#  {'parent': 'transgenic mutagenesis', 'child': 'enhancer-trap mutagenesis'},
#  {'parent': 'transgenic mutagenesis', 'child': 'gene-trap mutagenesis'},
#  {'parent': 'insecticide resistance time response assay',
#   'child': 'insecticide resistance time response by WHO paper kit assay'},
#  {'parent': 'insecticide resistance time response assay',
#   'child': 'insecticide resistance time response by bottle assay'},
#  {'parent': 'mathematical feature', 'child': 'exponential base'},
#  {'parent': 'mathematical feature', 'child': 'log base'},
#  {'parent': 'mathematical feature', 'child': 'number of variables'},
#  {'parent': 'mathematical feature', 'child': 'polynomial degree'},
#  {'parent': 'extraction', 'child': 'nucleic acid extraction'},
#  {'parent': 'extraction', 'child': 'submatrix extraction'},
#  {'parent': 'extraction', 'child': 'RNA extraction'},
#  {'parent': 'extraction', 'child': 'cytoplasmic RNA extraction'},
#  {'parent': 'extraction', 'child': 'nuclear RNA extraction'},
#  {'parent': 'extraction', 'child': 'organellar RNA extraction'},
#  {'parent': 'extraction', 'child': 'polyA RNA extraction'},
#  {'parent': 'extraction', 'child': 'viral RNA extraction'},
#  {'parent': 'extraction', 'child': 'row submatrix extraction'},
#  {'parent': 'nucleic acid extraction', 'child': 'RNA extraction'},
#  {'parent': 'nucleic acid extraction', 'child': 'cytoplasmic RNA extraction'},
#  {'parent': 'nucleic acid extraction', 'child': 'nuclear RNA extraction'},
#  {'parent': 'nucleic acid extraction', 'child': 'organellar RNA extraction'},
#  {'parent': 'nucleic acid extraction', 'child': 'polyA RNA extraction'},
#  {'parent': 'nucleic acid extraction', 'child': 'viral RNA extraction'},
#  {'parent': 'RNA extraction', 'child': 'cytoplasmic RNA extraction'},
#  {'parent': 'RNA extraction', 'child': 'nuclear RNA extraction'},
#  {'parent': 'RNA extraction', 'child': 'organellar RNA extraction'},
#  {'parent': 'RNA extraction', 'child': 'polyA RNA extraction'},
#  {'parent': 'RNA extraction', 'child': 'viral RNA extraction'},
#  {'parent': 'submatrix extraction', 'child': 'row submatrix extraction'},
#  {'parent': 'ontology module subsetted by OWL profile',
#   'child': 'EL++ ontology module'},
#  {'parent': 'transcription profiling by array assay',
#   'child': 'transcription profiling by tiling array assay'},
#  {'parent': 'liquid handler', 'child': 'liquid extraction robot'},
#  {'parent': 'Schizosaccharomyces pombe mating type', 'child': 'h minus'},
#  {'parent': 'Schizosaccharomyces pombe mating type', 'child': 'h plus'},
#  {'parent': 'statistical model validation',
#   'child': 'K-fold cross validation method'},
#  {'parent': 'statistical model validation', 'child': 'boostrapping'},
#  {'parent': 'K-fold cross validation method',
#   'child': 'leave one out cross validation method'},
#  {'parent': 'statistical model validation',
#   'child': 'leave one out cross validation method'},
#  {'parent': 'Centers for Disease Control and Prevention light trap',
#   'child': 'odor baited CDC light trap'},
#  {'parent': 'entity', 'child': 'occurrent'},
#  {'parent': 'entity', 'child': 'spatiotemporal region'},
#  {'parent': 'spatiotemporal region', 'child': 'process boundary'},
#  {'parent': 'liquid chromatography instrument',
#   'child': 'high performance liquid chromatography instrument'},
#  {'parent': 'endonuclease mediated mutagenesis',
#   'child': 'TALEN mediated mutagenesis'},
#  {'parent': 'endonuclease mediated mutagenesis',
#   'child': 'cas mediated mutagenesis'},
#  {'parent': 'network graph quality calculation',
#   'child': 'global modularity calculation'},
#  {'parent': 'flow rate', 'child': 'fluid flow rate'},
#  {'parent': 'quality of interaction of a substance with electromagnetic radiation',
#   'child': 'fluorescence'},
#  {'parent': 'quality of interaction of a substance with electromagnetic radiation',
#   'child': 'optical quality'},
#  {'parent': 'organism substance', 'child': 'amniotic fluid'},
#  {'parent': 'organism substance',
#   'child': 'respiratory system fluid/secretion'},
#  {'parent': 'organism substance', 'child': 'saliva'},
#  {'parent': 'organism substance', 'child': 'sputum'},
#  {'parent': 'organism substance', 'child': 'urine'},
#  {'parent': 'respiratory system fluid/secretion', 'child': 'sputum'},
#  {'parent': 'secondary structure of sequence macromolecule',
#   'child': 'secondary structure of RNA molecule'},
#  {'parent': 'high resolution probe', 'child': 'Bruker high resolution probe'},
#  {'parent': 'high resolution probe', 'child': 'flow high resolution probe'},
#  {'parent': 'high resolution probe',
#   'child': 'high resolution magic angle spin probe'},
#  {'parent': 'probe', 'child': 'tecmag EAGLE probe'},
#  {'parent': 'probe', 'child': 'high resolution probe'},
#  {'parent': 'Varian NMR instrument', 'child': 'Varian GEMINI spectrometer'},
#  {'parent': 'Varian NMR instrument', 'child': 'Varian MERCURY spectrometer'},
#  {'parent': 'Varian NMR instrument', 'child': 'Varian UNITY spectrometer'},
#  {'parent': 'Varian NMR instrument', 'child': 'Varian VXR spectrometer'},
#  {'parent': 'Varian UNITY spectrometer',
#   'child': 'Varian UNITY INOVA spectrometer'},
#  {'parent': 'Flaviviridae', 'child': 'Dengue virus'},
#  {'parent': 'Flaviviridae', 'child': 'Hepacivirus hominis'},
#  {'parent': 'material separation objective',
#   'child': 'separation into different composition objective'},
#  {'parent': 'concentration of', 'child': 'osmolality'},
#  {'parent': 'molecular quality', 'child': 'concentration of'},
#  {'parent': 'molecular quality', 'child': 'osmolality'},
#  {'parent': 'replicate analysis', 'child': 'dye swap merge'},
#  {'parent': 'imaging assay', 'child': 'computed tomography imaging assay'},
#  {'parent': 'imaging assay', 'child': 'magnetic resonance imaging assay'},
#  {'parent': 'imaging assay',
#   'child': 'positron emission tomography imaging assay'},
#  {'parent': 'sequence feature identification objective',
#   'child': 'protein and DNA interaction identification objective'},
#  {'parent': 'sequence feature identification objective',
#   'child': 'protein and RNA interaction identification objective'},
#  {'parent': 'human specimen set',
#   'child': 'specimens collected in one encounter'},
#  {'parent': 'rapid amplification of cDNA ends',
#   'child': "3' rapid amplification of cDNA ends"},
#  {'parent': 'rapid amplification of cDNA ends',
#   'child': "5' rapid amplification of cDNA ends"},
#  {'parent': "5' rapid amplification of cDNA ends",
#   'child': "5' RNA ligase mediated rapid amplification of cDNA ends"},
#  {'parent': 'repeated measure design', 'child': 'cross over design'},
#  {'parent': 'repeated measure design', 'child': 'n-to-1 design'},
#  {'parent': 'sequence_assembly', 'child': 'supercontig'},
#  {'parent': 'light trap', 'child': 'light trap for indoor use'},
#  {'parent': 'light trap', 'child': 'light trap for outdoor use'},
#  {'parent': 'immunization', 'child': 'Immunization in vivo'},
#  {'parent': 'Immunization in vivo',
#   'child': 'Individual epitope immunization in vivo'},
#  {'parent': 'T cell tolerance induction',
#   'child': 'epitope specific T cell tolerance induction'},
#  {'parent': 'T cell tolerance induction',
#   'child': 'epitope specific tolerance induction by T cells'},
#  {'parent': 'Mammalia', 'child': 'Euarchontoglires'},
#  {'parent': 'Euarchontoglires', 'child': 'Rodentia'},
#  {'parent': 'face mask', 'child': 'medical mask'},
#  {'parent': 'face mask', 'child': 'non-medical mask'},
#  {'parent': 'measurement unit label', 'child': 'concentration unit'},
#  {'parent': 'measurement unit label', 'child': 'frequency unit'},
#  {'parent': 'measurement unit label', 'child': 'length unit'},
#  {'parent': 'measurement unit label', 'child': 'mass unit'},
#  {'parent': 'measurement unit label', 'child': 'pressure unit'},
#  {'parent': 'measurement unit label', 'child': 'substance unit'},
#  {'parent': 'measurement unit label', 'child': 'time unit'},
#  {'parent': 'measurement unit label', 'child': 'volume unit'},
#  {'parent': 'Bruker NMR magnet', 'child': 'Bruker Ultrastabilized NMR magnet'},
#  {'parent': 'Bruker Ultrastabilized NMR magnet',
#   'child': 'Bruker US 2 NMR magnet'},
#  {'parent': 'Bruker NMR magnet', 'child': 'Bruker US 2 NMR magnet'},
#  {'parent': 'Homo sapiens', 'child': 'specimen collector'},
#  {'parent': 'machine learning', 'child': 'supervised machine learning'},
#  {'parent': 'machine learning', 'child': 'unsupervised machine learning'},
#  {'parent': 'epithelial cell', 'child': 'hepatocyte'},
#  {'parent': 'epithelial cell', 'child': 'mesothelial cell'},
#  {'parent': 'sequence trimming', 'child': 'adapter-sequence trimming'},
#  {'parent': 'performance status value specification',
#   'child': 'Eastern Cooperative Oncology Group score value specification'},
#  {'parent': 'performance status value specification',
#   'child': 'Karnofsky score vaue specification'},
#  {'parent': 'import ontology module',
#   'child': 'external import ontology module'},
#  {'parent': 'type IV hypersensitivity',
#   'child': 'epitope specific type IV hypersensitivity by T cells'},
#  {'parent': 'data format specification', 'child': 'BCL format'},
#  {'parent': 'DNA adenine methyltransferase identification assay',
#   'child': 'DamID-seq'},
#  {'parent': 'hydrogen/deuterium exchange footprinting assay',
#   'child': 'hydrogen/deuterium exchange footprinting assay measuring binding of a B cell epitope:antibody complex'},
#  {'parent': 'nasopharynx specimen',
#   'child': 'nasopharyngeal aspirate specimen'},
#  {'parent': 'nasopharynx specimen', 'child': 'nasopharyngeal swab specimen'},
#  {'parent': 'multiplexed fluorescent antibody imaging assay',
#   'child': 'Cell DIVE multiplexed imaging assay'},
#  {'parent': 'multiplexed fluorescent antibody imaging assay',
#   'child': 'co-detection by indexing assay'},
#  {'parent': 'methodology testing objective',
#   'child': 'protocol testing objective'},
#  {'parent': 'directed mutagenesis', 'child': 'targeted mutagenesis'},
#  {'parent': 'B cell receptor repertoire sequencing assay',
#   'child': 'single cell B cell receptor repertoire sequencing assay'},
#  {'parent': 'histamine secretion mediated by immunoglobulin',
#   'child': 'B cell epitope specific histamine secretion mediated by immunoglobulin'},
#  {'parent': 'peptide', 'child': 'synthetic peptide'},
#  {'parent': 'Bruker NMR probe', 'child': 'Bruker 1mm MicroProbe'},
#  {'parent': 'Bruker NMR probe', 'child': 'Bruker CryoProbe'},
#  {'parent': 'Bruker NMR probe',
#   'child': 'Bruker solid magic angle spinning probe'},
#  {'parent': 'collection of specimens',
#   'child': 'specimens collected longitudinally'},
#  {'parent': 'granzyme B production',
#   'child': 'epitope specific granzyme B production by T cells'},
#  {'parent': 'material information bearer', 'child': 'random access memory'},
#  {'parent': 'Murinae', 'child': 'Mus musculus'},
#  {'parent': 'Murinae', 'child': 'Rattus norvegicus'},
#  {'parent': 'figure', 'child': 'image'},
#  {'parent': 'feces', 'child': 'meconium'},
#  {'parent': 'electrophoresis system',
#   'child': 'capillary electrophoresis instrument'}]

# %%
with open("predictions_c_simple_method_keyword_OBI_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

# %%
import json

# Save final_clusters_list to JSON file
with open("final_result_keywords_c_po.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

print("Clusters saved to final_clusters.json ✅")
# Out:
# Clusters saved to final_clusters.json ✅

# %%
with open("_pairs.jsonl", "w", encoding="utf-8") as f:
    for entry in final_result:
        json.dump(entry, f)
        f.write("\n")
