# %%
import json
def load_json(data_path):
    with open(data_path, "r", encoding="utf-8") as file_1:
        data = json.load(file_1)
    return data

# %%
data = load_json("PROCO/train/proco_train_pairs.json")

# %%
len(data), data[:5]
# Out:
# (1313,
#  [{'ID': 'TR_ad6670cf', 'parent': 'AFE_0001128', 'child': 'Bunsen burner'},
#   {'ID': 'TR_a990a3ed',
#    'parent': 'document part',
#    'child': 'CTA Section 3.2.S.2.4 Controls of Critical Steps and Intermediates'},
#   {'ID': 'TR_cca21ca5',
#    'parent': 'electron acceptor',
#    'child': 'hydrogen acceptor'},
#   {'ID': 'TR_515d09c1',
#    'parent': 'distillation',
#    'child': 'simple distillation'},
#   {'ID': 'TR_0696fbe0',
#    'parent': 'directive information entity',
#    'child': 'plan specification'}])

# %%
from collections import defaultdict

class UnionFind:
    def __init__(self):
        self.parent = {}

    def find(self, x):
        # Path compression
        if x != self.parent.setdefault(x, x):
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        self.parent[self.find(x)] = self.find(y)

def build_clusters(relationships):
    uf = UnionFind()
    
    for rel in relationships:
        parent = rel["parent"]
        child = rel["child"]
        uf.union(parent, child)

    clusters = defaultdict(set)
    for term in set([item for rel in relationships for item in (rel["parent"], rel["child"])]):
        root = uf.find(term)
        clusters[root].add(term)

    # Add isolated nodes (no parent/child relationship)
    all_terms = set()
    for rel in relationships:
        all_terms.add(rel["parent"])
        all_terms.add(rel["child"])
    for term in all_terms:
        if term not in uf.parent:
            clusters[term].add(term)

    return list(clusters.values())

# %%
clusters = build_clusters(data)

# %%
len(clusters)
# Out:
# 30

# %%
clusters
# Out:
# [{'dihexagonal-dipyramidal',
#   'dihexagonal-pyramidal',
#   'diploidal',
#   'ditetragonal-dipyramidal',
#   'ditetragonal-pyramidal',
#   'ditrigonal-dipyramidal',
#   'ditrigonal-pyramidal',
#   'ditrigonal-scalenohedral',
#   'domatic',
#   'gyroidal',
#   'hexagonal-dipyrimidal',
#   'hexagonal-pyrimidal',
#   'hexagonal-trapezohedral',
#   'hexoctahedral',
#   'hextetrahedral',
#   'pedial',
#   'pinacoidal',
#   'point group symmetry',
#   'prismatic',
#   'rhombic-dipyramidal',
#   'rhombic-disphenoidal',
#   'rhombic-pyramidal',
#   'rhombohedral',
#   'sphenoidal',
#   'tetartoidal',
#   'tetragonal-dipyramidal',
#   'tetragonal-disphenoidal',
#   'tetragonal-pyramidal',
#   'tetragonal-scalenohedral',
#   'tetragonal-trapezohedral',
#   'trigonal-dipyramidal',
#   'trigonal-pyramidal',
#   'trigonal-trapezohedral'},
#  {'1,4-dioxane',
#   'AFE_0000354',
#   'AFE_0000407',
#   'AFE_0001128',
#   'AFFN_0000014',
#   'AFFN_0000055',
#   'AFFN_0000111',
#   'AFFN_0000127',
#   'AFFN_0000128',
#   'AFFN_0000137',
#   'AFM_0001034',
#   'AFM_0001038',
#   'AFP_0003306',
#   'AFP_0003312',
#   'AFP_0003348',
#   'AFP_0003359',
#   'AFP_0003486',
#   'AFP_0003551',
#   'AFP_0003563',
#   'AFP_0003620',
#   'AFR_0000916',
#   'AFR_0000923',
#   'AFR_0000992',
#   'Bunsen burner',
#   'CHEBI_24870',
#   'CQA specification',
#   'CTA Section 3.2.S.1.1 Nomenclature',
#   'CTA Section 3.2.S.1.2 Structure',
#   'CTA Section 3.2.S.1.3 General Properties',
#   'CTA Section 3.2.S.2.1 Manufacturers',
#   'CTA Section 3.2.S.2.2 Description of Manufacturing Process and Process Controls',
#   'CTA Section 3.2.S.2.4 Controls of Critical Steps and Intermediates',
#   'CTA Section 3.2.S.3.1 Elucidation of Structure and other Characteristics',
#   'CTA Section 3.2.S.3.2 Impurities',
#   'DEREK Mutagen Prediction',
#   'DNA polymerase complex',
#   'GLP synthetic process',
#   'GMP synthetic process',
#   'Gibbs free energy change',
#   'Gibbs free energy of activation',
#   'ICH Guideline',
#   'ICH M7 Assessment and Control of DNA Reactive (Mutagenic) Impurities in Pharmaceuticals To Limit Potential Carcinogenic Risk',
#   'ICH Q11 Guidance for Development and Manufacture of Drug Substances',
#   'ICH Q3A Impurities in New Drug Substances',
#   'ICH Q3D Guidance for Elemental Impurities',
#   'MCASE Mutagen Prediction',
#   'Ostwald ripening',
#   'PCR product',
#   'Plackett–Burman design',
#   'Powder Indexing',
#   'Q7 Good Manufacturing Practice Guide for Active Pharmaceutical Ingredients',
#   'Snyder column',
#   'acetone',
#   'acetonitrile',
#   'action specification',
#   'affinity precipitation',
#   'ageing',
#   'alcohol',
#   'algorithm',
#   'aliphatic alcohol',
#   'aliphatic nitrile',
#   'alkyl alcohol',
#   'alkylbenzene',
#   'amide',
#   'amino acid',
#   'amino-acid anion',
#   'ammonia',
#   'ammonium',
#   'amplified DNA',
#   'anion',
#   'annulene',
#   'arene',
#   'aromatic annulene',
#   'aromatic compound',
#   'assay',
#   'assay objective',
#   'assessed ionisability purge factor',
#   'assessed reactivity purge factor',
#   'assessed solubility purge factor',
#   'assessed volatility purge factor',
#   'atom',
#   'atomic nucleus',
#   'azane',
#   'azanide',
#   'ball milling',
#   'baryon',
#   'batch distillation',
#   'batch manufacturing record',
#   'beaker',
#   'benzene',
#   'benzenes',
#   'benzenoid aromatic compound',
#   'blow drying',
#   'butan-2-one',
#   'butanone',
#   'calculated datum',
#   'calculation',
#   'carbamate',
#   'carbamic acid',
#   'carbocyclic compound',
#   'carbon atom',
#   'carbon group element atom',
#   'carbon group molecular entity',
#   'carbon oxoacid',
#   'carbonyl compound',
#   'carboxamide',
#   'carboximidic acid',
#   'carboxy group',
#   'carboxylic acid',
#   'carboxylic acid anion',
#   'cation',
#   'centrally registered identifier',
#   'centrally registered identifier symbol',
#   'centrifugal evaporation',
#   'certificate of analysis',
#   'chalcogen',
#   'chalcogen molecular entity',
#   'charging material',
#   'chemical abstracts number',
#   'chemical drawing',
#   'chemical entity',
#   'chemical impurity',
#   'chemical process development',
#   'chemical product',
#   'chemometrics',
#   'chromatography column',
#   'co-crystal',
#   'co-precipitation',
#   'cocrystallisation',
#   'coextraction',
#   'common technical document',
#   'competency question',
#   'composite particle',
#   'concentrating',
#   'concentration profile',
#   'conclusion based on data',
#   'concomitant polymorphs',
#   'continuant',
#   'continuous distillation',
#   'critical process parameter',
#   'critical process parameter specification',
#   'crucible',
#   'crystal structure predictions',
#   'crystalline solid',
#   'crystalline solid thermodynamic phase',
#   'crystallisation',
#   'crystallization',
#   'cubic unit cell',
#   'curation status specification',
#   'cyanide',
#   'cyanides',
#   'cyano group',
#   'cyclic compound',
#   'cyclic ether',
#   'cyclic hydrocarbon',
#   'data about an ontology part',
#   'data item',
#   'data set',
#   'data set of predicted values according to fitted curve',
#   'data transformation',
#   'data transformation objective',
#   'datum label',
#   'degassing',
#   'deionisation method',
#   'deoxyribonucleic acid',
#   'design space',
#   'device',
#   'dialkyl ketone',
#   'dielectric drying',
#   'differential kinetic measurement',
#   'diffusion coefficient',
#   'dioxane',
#   'dioxanes',
#   'direct drying',
#   'directive information entity',
#   'disposition',
#   'distillation',
#   'divalent inorganic anion',
#   'document',
#   'document part',
#   'documenting',
#   'double-stranded DNA',
#   'drawing a conclusion based on data',
#   'drum drying',
#   'effective catalytic rate',
#   'electron',
#   'end reaction monitoring',
#   'entity',
#   'environmental control device',
#   'enzyme',
#   'equation',
#   'ether',
#   'eutectic',
#   'evaporation',
#   'experiment',
#   'experimental design',
#   'explosion',
#   'exponential time constant',
#   'extraction',
#   'factor',
#   'factorial analysis',
#   'fate of impurity',
#   'fatty acid',
#   'fatty acid anion',
#   'fatty acid derivative',
#   'fatty alcohol',
#   'fermentation',
#   'fermion',
#   'fiat object part',
#   'filtering',
#   'filtration',
#   'foam fractionation',
#   'formamide',
#   'formamides',
#   'formate',
#   'formic acid',
#   'formimidic acid',
#   'fractional distillation',
#   'fractional sublimation',
#   'fractionating column',
#   'fractionation',
#   'freeze distillation',
#   'freeze drying',
#   'function',
#   'fundamental particle',
#   'gas antisolvent technique',
#   'gas molecular entity',
#   'generically dependent continuant',
#   'graphical rate equation',
#   'grinding',
#   'group',
#   'hadron',
#   'half-life',
#   'half-life of an exponential decay',
#   'heating mantle',
#   'heteroatomic molecular entity',
#   'heterocyclic compound',
#   'heterocyclic organic fundamental parent',
#   'heteromonocyclic compound',
#   'heteroorganic entity',
#   'high-speed ball milling',
#   'high-vacuum sublimation',
#   'homogenisation',
#   'hydracid',
#   'hydrides',
#   'hydridonitrate(2-)',
#   'hydrocarbon',
#   'hydrogen atom',
#   'hydrogen cyanide',
#   'hydrogen isocyanide',
#   'hydrogen molecular entity',
#   'hydroxides',
#   'hydroxy group',
#   'identifier',
#   'imidic acid',
#   'impurity fate and purge determination',
#   'in-silico modeling',
#   'independent continuant',
#   'information content entity',
#   'inorganic anion',
#   'inorganic cation',
#   'inorganic group',
#   'inorganic hydride',
#   'inorganic ion',
#   'inorganic molecular entity',
#   'intermediate material for synthesis',
#   'international nonproprietary name',
#   'investigation',
#   'ionothermal synthesis',
#   'ketone',
#   'ketone body',
#   'kinetic constant',
#   'kinetic order',
#   'kinetic reaction property',
#   'laboratory notebook',
#   'laboratory notebook experiment identifier',
#   'lepton',
#   'lipid',
#   'liquid-assisted grinding',
#   'liquid-solid extraction',
#   'liquid–liquid extraction',
#   'macromolecule',
#   'magnetic stirring',
#   'main group element atom',
#   'main group molecular entity',
#   'material component separation',
#   'material entity',
#   'material flow profile in synthesis process',
#   'material processing',
#   'measurement datum',
#   'measurement unit label',
#   'mechanistic and kinetic determination',
#   'membrane extraction',
#   'methanol',
#   'method of initial rates',
#   'methoxide',
#   'methyl ketone',
#   'methylbenzene',
#   'micro-filtration',
#   'mixing',
#   'molecular complex',
#   'molecular entity',
#   'molecular_function',
#   'molecule',
#   'monoanion',
#   'monocarboxylic acid',
#   'monocarboxylic acid amide',
#   'monocarboxylic acid anion',
#   'monocyclic arene',
#   'monocyclic compound',
#   'monocyclic hydrocarbon',
#   'mononuclear parent hydride',
#   'monovalent inorganic anion',
#   'monovalent inorganic cation',
#   'multi-parallel experimentation',
#   'nano-filtration',
#   'nitrile',
#   'nitrogen atom',
#   'nitrogen hydride',
#   'nitrogen molecular entity',
#   'nonmetal atom',
#   'nuclear particle',
#   'nucleic acid',
#   'nucleon',
#   'object aggregate',
#   'objective specification',
#   'occurrent',
#   'one-carbon compound',
#   'onium cation',
#   'onium compound',
#   'organic acid',
#   'organic amino compound',
#   'organic anion',
#   'organic aromatic compound',
#   'organic cyclic compound',
#   'organic fundamental parent',
#   'organic group',
#   'organic heterocyclic compound',
#   'organic heteromonocyclic compound',
#   'organic hydride',
#   'organic hydroxy compound',
#   'organic ion',
#   'organic molecular entity',
#   'organic molecule',
#   'organic oxo compound',
#   'organic univalent group',
#   'organochalcogen compound',
#   'organonitrogen compound',
#   'organooxygen compound',
#   'organyl group',
#   'orthorhombic unit cell',
#   'oven drying',
#   'overall assessed purge factor',
#   'overall reaction order',
#   'oxacycle',
#   'oxide',
#   'oxo group',
#   'oxoacid',
#   'oxoacid derivative',
#   'oxoanion',
#   'oxolane',
#   'oxolanes',
#   'oxygen atom',
#   'oxygen molecular entity',
#   'p-block element atom',
#   'p-block molecular entity',
#   'peptide',
#   'physical blending',
#   'pipette',
#   'plan specification',
#   'planned process',
#   'planning',
#   'pnictogen',
#   'pnictogen hydride',
#   'pnictogen molecular entity',
#   'polyatomic anion',
#   'polyatomic entity',
#   'polyatomic ion',
#   'polyatomic monoanion',
#   'polymer',
#   'polymorph and solvate screening design',
#   'portion of material',
#   'postprecipitation',
#   'pre-exponential factor',
#   'precipitation',
#   'precipitation with compressed antisolvent',
#   'preferred IUPAC name',
#   'pressure measurement',
#   'pressurised-fluid extraction',
#   'primary alcohol',
#   'primary amide',
#   'prior art',
#   'process',
#   'process analytical technology',
#   'process chemistry datum',
#   'process chemistry filing',
#   'process chemistry workflow plan',
#   'process environmental factor',
#   'process excellence index',
#   'process mass intensity',
#   'process monitoring',
#   'process profile',
#   'process profile specification',
#   'process safety',
#   'process validation',
#   'processed material',
#   'product stream',
#   'propan-2-ol',
#   'propanones',
#   'protein',
#   'protein-containing complex',
#   'protocol',
#   'pseudohalide anion',
#   'pseudohalo group',
#   'purge factor',
#   'purification',
#   'purification objective',
#   'quality process profile',
#   'quality service level',
#   'quality specification',
#   'quantitative systems description parameter',
#   'rate constant',
#   'rate equation',
#   'rate measurement datum',
#   'reaction property',
#   'reaction screening design',
#   'realizable entity',
#   'recrystallisation',
#   'redox potential change',
#   'redox reaction property',
#   'reprecipitation',
#   'reverse osmosis',
#   'risk assessment',
#   'route validation',
#   's-block element atom',
#   's-block molecular entity',
#   'sample deposition',
#   'sample drying',
#   'sample heating',
#   'sample solidification',
#   'sample sublimation',
#   'saturated organic heterocyclic parent',
#   'saturated organic heteromonocyclic parent',
#   'scalar measurement datum',
#   'screening design',
#   'secondary alcohol',
#   'secondary fatty alcohol',
#   'separation method',
#   'shake-flask extraction',
#   'simple distillation',
#   'solid dispersion',
#   'solid–liquid extraction',
#   'solubility screening design',
#   'solution pH datum',
#   'solvent evaporation',
#   'solvent extraction',
#   'solvothermal synthesis',
#   'specific rotation datum',
#   'spray drying',
#   'starting material for synthesis',
#   'state',
#   'steady-state approximation analysis',
#   'steam distillation',
#   'stir rate profile',
#   'stirring',
#   'study design',
#   'subatomic particle',
#   'substoichiometric extraction',
#   'suction filtration',
#   'supercritical antisolvent technique',
#   'supercritical fluid extraction',
#   'supercritical fluid method',
#   'supported liquid membrane extraction',
#   'symbol',
#   'synthesis flow chart',
#   'synthesis method',
#   'synthesizing function',
#   'synthetic chemical process',
#   'synthetic step specification',
#   'syringe pump',
#   'temperature measurement',
#   'temporal measure',
#   'tetragonal unit cell',
#   'textual entity',
#   'thermodynamic phase',
#   'thermodynamic reaction property',
#   'toluene',
#   'toluenes',
#   'transferring device',
#   'triclinic unit cell',
#   'trigonal unit cell',
#   'ultra-filtration',
#   'unit cell',
#   'unit operation in chemical processing',
#   'vacuum drying',
#   'vacuum sublimation',
#   'volatile organic compound',
#   'waste stream',
#   'wet grinding',
#   'written name'},
#  {'AFRL_0000020',
#   'AFRL_0000085',
#   'AFRL_0000167',
#   'AFRL_0000216',
#   'AFRL_0000217',
#   'AFRL_0000221',
#   'AFRL_0000223',
#   'AFRL_0000229',
#   'AFRL_0000231',
#   'AFRL_0000249',
#   'AFRL_0000289',
#   'AFRL_0000344',
#   'AFRL_0000345',
#   'AFRL_0000351',
#   'AFRL_0000359',
#   'AFRL_0000360',
#   'AFRL_0000361',
#   'AFRL_0000362',
#   'AFRL_0000364',
#   'AFRL_0000365',
#   'AFRL_0000366',
#   'AFRL_0000367',
#   'AFRL_0000420',
#   'AFRL_0000421',
#   'AFRL_0000424',
#   'AFRL_0000425',
#   'AFRL_0000426',
#   'AFRL_0000427',
#   'AFRL_0000428',
#   'AFRL_0000430',
#   'AFRL_0000510',
#   'AFRL_0000511',
#   'AFRL_0000512',
#   'Bronsted acid',
#   'Bronsted base',
#   'EC 1.* (oxidoreductase) inhibitor',
#   'EC 1.9.* (oxidoreductase acting on donor heme group) inhibitor',
#   'EC 1.9.3.* (oxidoreductase acting on donor heme group, oxygen as acceptor) inhibitor',
#   'EC 1.9.3.1 (cytochrome c oxidase) inhibitor',
#   'EC 3.* (hydrolase) inhibitor',
#   'EC 3.5.* (hydrolases acting on non-peptide C-N bonds) inhibitor',
#   "Good's buffer substance",
#   'Lewis acid',
#   'Lewis base',
#   'OBI_0000571',
#   'acceptor',
#   'acid',
#   'aetiopathogenetic role',
#   'amphiprotic solvent',
#   'antioxidant',
#   'application',
#   'aprotic solvent',
#   'astringent',
#   'base',
#   'biochemical role',
#   'biological role',
#   'biophysical role',
#   'bolaamphiphile',
#   'buffer',
#   'carcinogenic agent',
#   'chain carrier',
#   'chelator',
#   'chemical role',
#   'cofactor',
#   'copper chelator',
#   'corrosion inhibitor',
#   'detergent',
#   'donor',
#   'drug',
#   'electron acceptor',
#   'electron donor',
#   'electron-transport chain inhibitor',
#   'electrophilic reagent',
#   'environmental contaminant',
#   'environmental food contaminant',
#   'enzyme inhibitor',
#   'evaluant role',
#   'film-forming compound',
#   'fluorescence quencher',
#   'food additive',
#   'food antioxidant',
#   'food component',
#   'food emulsifier',
#   'food preservative',
#   'fuel additive',
#   'greenhouse gas',
#   'hepatotoxic agent',
#   'hydrogen acceptor',
#   'impurity',
#   'inhibitor',
#   'inorganic acid',
#   'ionophore',
#   'iron chelator',
#   'iron ionophore',
#   'iron(3+) chelator',
#   'ligand',
#   'luciferin',
#   'membrane transport modulator',
#   'mitochondrial respiratory-chain inhibitor',
#   'mother liquor role',
#   'mutagenic impurity',
#   'neurotoxin',
#   'nitric oxide donor',
#   'non-polar solvent',
#   'nonionic surfactant',
#   'nucleic acid template role',
#   'nucleophilic reagent',
#   'nutrient',
#   'pathway inhibitor',
#   'pharmaceutical',
#   'photobiochemical role',
#   'photochemical role',
#   'physiological role',
#   'phytosiderophore',
#   'poison',
#   'polar aprotic solvent',
#   'polar solvent',
#   'precipitate role',
#   'protective agent',
#   'protic solvent',
#   'protophilic solvent',
#   'reaction intermediate',
#   'reactive oxygen species generator',
#   'reagent',
#   'reagent role',
#   'reducing agent',
#   'reference substance role',
#   'refrigerant',
#   'respiratory-chain inhibitor',
#   'role',
#   'sequestrant',
#   'sideramine',
#   'siderophore',
#   'solvent',
#   'surfactant',
#   'ultraviolet filter'},
#  {'AFQ_0000111',
#   'AFQ_0000115',
#   'AFQ_0000168',
#   'AFQ_0000250',
#   'AFQ_0000256',
#   'AFQ_0000279',
#   'X-Ray diffractivity',
#   'bulk substance quality',
#   'centrosymmetric point symmetry',
#   'chemical structure',
#   'concentration of',
#   'critical quality attribute',
#   'crystalline state',
#   'enantiomorphic point symmetry',
#   'flow rate',
#   'habit',
#   'length',
#   'mass',
#   'molecular formula',
#   'molecular quality',
#   'morphology',
#   'non-centrosymmetric achiral symmetry',
#   'non-centrosymmetric point symmetry',
#   'point symmetry',
#   'polar point symmetry',
#   'quality',
#   'solubility',
#   'space group',
#   'specifically dependent continuant',
#   'symmetry',
#   'unit cell Z value',
#   "unit cell Z' value",
#   'unit cell a-axis length',
#   'unit cell alpha internal angle',
#   'unit cell beta internal angle',
#   'unit cell c-axis length',
#   'unit cell quality',
#   'unit cell volume'},
#  {'Escherichia coli metabolite',
#   'Mycoplasma genitalium metabolite',
#   'Saccharomyces cerevisiae metabolite',
#   'bacterial metabolite',
#   'eukaryotic metabolite',
#   'fungal metabolite',
#   'metabolite',
#   'prokaryotic metabolite'},
#  {'GMP specification of synthetic process', 'route specification'},
#  {'centrifugation', 'low-speed centrifugation', 'sequential centrifugation'},
#  {'enzymatic amplification', 'polymerase chain reaction'},
#  {'Dimroth condenser',
#   'Frederichs condensor',
#   'Graham condensor',
#   'Liebig condenser',
#   'coil condenser',
#   'cold finger',
#   'condensor'},
#  {'Erlenmeyer flask', 'flask', 'volumetric flask'},
#  {'drug product approval milestone',
#   'drug product filing milestone',
#   'process boundary',
#   'product approval milestone',
#   'product filing milestone',
#   'route selection milestone'},
#  {'integral kinetic measurement', 'method of flooding'},
#  {'adsorption chromatography',
#   'chromatography',
#   'column chromatography',
#   'displacement chromatography'},
#  {'animal metabolite', 'mammalian metabolite'},
#  {'supercritical carbon dioxide drying', 'supercritical drying'},
#  {'route development optimization',
#   'route related process',
#   'route scouting',
#   'route selection'},
#  {'ionic salt', 'solid solution'},
#  {'antibacterial agent', 'antimicrobial agent'},
#  {'induction period', 'synthesis reaction time', 'temporal region'},
#  {'ICH Q6A Class 1 Solvent',
#   'ICH Q6A Class 2 Solvent',
#   'ICH Q6A Class 3 Solvent',
#   'residual solvent impurity'},
#  {'molecular distillation', 'vacuum distillation'},
#  {'carbonyl group', 'organic divalent group', 'organodiyl group'},
#  {'sandwich sublimation', 'seeded sublimation'},
#  {'acyl group',
#   'carbamoyl group',
#   'carboacyl group',
#   'univalent carboacyl group'},
#  {'cholinergic antagonist',
#   'cholinergic drug',
#   'neurotransmitter agent',
#   'pharmacological role'},
#  {'EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor',
#   'EC 3.5.1.4 (amidase) inhibitor'},
#  {'AFRL_0000244', 'AFRL_0000363'},
#  {'Czochralski process',
#   'Lely method',
#   'Verneuil process',
#   'crystal growth method'},
#  {'scalar value specification', 'value specification'},
#  {'hydrate', 'solvate'}]

# %%
# Load a text file in Python
final_content = []
with open("PROCO/test/proco_test_types.txt", "r", encoding="utf-8") as f:
    contents = f.readlines()
    for content in contents:
        final_content.append(content.strip('\n'))


print(contents[:500])  # Print first 500 characters
# Out:
# ['application\n', 'chromophore\n', 'process chemistry datum\n', 'methanol\n', 'Ostwald ripening\n', 'rhombohedral\n', 'commercial chemical product\n', 'washing\n', 'heterocyclic compound\n', 'macronutrient\n', 'annealing\n', 'carboxylic acid\n', 'AFRL_0000423\n', 'AFFN_0000187\n', 'organic heterocyclic compound\n', 'AFQ_0000113\n', 'Variable Time Normalisation Analysis\n', 'redox reaction property\n', 'ditrigonal-dipyramidal\n', 'mouse metabolite\n', 'elution\n', 'tetartoidal\n', 'rhombic-pyramidal\n', 'factorial design\n', 'eukaryotic metabolite\n', 'organooxygen compound\n', 'generically dependent continuant\n', 'iron(3+) chelator\n', 'quality specification\n', 'mathematical constant\n', 'AFRL_0000364\n', 'propanones\n', 'AFRL_0000249\n', 'obsolescence reason specification\n', 'annulene\n', 'chemical role\n', 'chemical product\n', 'DNA polymerase complex\n', 'sample quenching\n', 'role\n', 'secondary fatty alcohol\n', 'chemical abstracts name\n', 'luciferin\n', 'fatty acid anion\n', 'hexagonal-pyrimidal\n', 'methyl ketone\n', 'carbonyl compound\n', 'butan-2-one\n', 'value specification\n', 'ethanol extraction\n', 'PCR product\n', 'Acheson method\n', 'realizable entity\n', 'ribonucleic acid\n', 'diploidal\n', 'amphiphile\n', 'food component\n', 'dioxane\n', 'organic ion\n', 'membrane extraction\n', 'integral kinetic measurement\n', 'acyl group\n', 'catalytic activity\n', 'saturated organic heteromonocyclic parent\n', 'concentrating\n', 'prismatic\n', 'oxolanes\n', 'unit cell gamma internal angle\n', 'nucleon\n', 'gas molecular entity\n', 'hydrocarbon\n', 'evaporation\n', 'hexoctahedral\n', 'membrane extraction with a sorbent interface\n', 'aromatic compound\n', 'concomitant polymorphs\n', 'acetone\n', 'Davies condenser\n', 'iron(2+) chelator\n', 'carbon oxoacid\n', 'planned process\n', 'AFRL_0000289\n', 'solvent evaporation\n', 'one-carbon compound\n', 'reactive distillation\n', 'protective agent\n', 'mammalian metabolite\n', 'AFRL_0000344\n', 'solvent extraction\n', 'tetragonal-trapezohedral\n', 'ditrigonal-pyramidal\n', 'formamide\n', 'thermal degradation product\n', 'gas–liquid extraction\n', 'route specification\n', 'electron donor\n', 'CQA specification\n', 'monovalent inorganic cation\n', 'AFM_0001038\n', 'molecular complex\n', 'AFRL_0000510\n', 'organic acid\n', 'AFRL_0000533\n', 'product filing documentation\n', 'AFQ_0000114\n', 'nuclear particle\n', 'trigonal-trapezohedral\n', 'organic anion\n', 'objective specification\n', 'plan specification\n', 'AFQ_0000250\n', 'biophysical role\n', 'formic acid\n', 'molecule\n', 'specifically dependent continuant\n', 'ageing\n', 'organic heteromonocyclic compound\n', 'methylbenzene\n', 'ditetragonal-pyramidal\n', 'aromatic annulene\n', 'air-sensitive vacuum distillation\n', 'molecular entity\n', 'emulsifier\n', 'supercritical fluid method\n', 'ammonia\n', 'polymerisation monomer\n', 'hydrogen isocyanide\n', 'unit cell crystal density\n', 'biological role\n', 'pharmacological role\n', 'purge factor\n', 'reagent\n', 'hydrides\n', 'protophilic solvent\n', 'dioxanes\n', 'hydrogen donor\n', 'carbon atom\n', 'solid solution\n', 'AFRL_0000020\n', 'written name\n', 'oxolane\n', 'protein precipitation\n', 'pseudohalide anion\n', 'supercritical drying\n', 'sample heating\n', 'chemical impurity\n', 'persistent organic pollutant\n', 'propan-2-ol\n', 'process profile specification\n', 'study design execution\n', 'amplified DNA\n', 'neurotransmitter agent\n', 'assessed solubility purge factor\n', 'CHEBI_24870\n', 'organic cyclic compound\n', 'flask\n', 'experimental design\n', 'centrifugation\n', 'volatile organic compound\n', 'polyatomic ion\n', 'chromatography\n', 'AFQ_0000256\n', 'material processing\n', 'ether\n', 'oxide\n', 'lumiphore\n', 'amino acid\n', 'scalar measurement datum\n', 'route development optimization\n', 'nucleophilic reagent\n', 'AFRL_0000231\n', 'antioxidant\n', 'crystalline solid\n', 'organochalcogen compound\n', 'critical process parameter specification\n', 'AFRL_000036 ...

# %%
len(contents), contents[0]
# Out:
# (530, 'application\n')

# %%
len(final_content), final_content[0]
# Out:
# (530, 'application')

# %%
# Step 3: Assign function
from collections import Counter
from tqdm.notebook import tqdm
def assign_term_to_cluster(new_term, clusters):
    new_words = new_term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for term in cluster:
            for word in term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)
    
    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]
    
    if max_score == 0:
        return None  # No match
    return best_cluster_index

# Step 4: Assign all new terms
final_clusters = [set(cluster) for cluster in clusters]  # copy original clusters

for term in tqdm(final_content):
    assigned_idx = assign_term_to_cluster(term, final_clusters)
    if assigned_idx is not None:
        final_clusters[assigned_idx].add(term)
    else:
        # Create new cluster if no match found
        final_clusters.append(set([term]))

# Step 5: Convert to list of lists and return
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

# Display final clusters
for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")
# Out:
#   0%|          | 0/530 [00:00<?, ?it/s]
# Cluster 1: ['dihexagonal-dipyramidal', 'dihexagonal-pyramidal', 'diploidal', 'ditetragonal-dipyramidal', 'ditetragonal-pyramidal', 'ditrigonal-dipyramidal', 'ditrigonal-pyramidal', 'ditrigonal-scalenohedral', 'domatic', 'gyroidal', 'hexagonal-dipyrimidal', 'hexagonal-pyrimidal', 'hexagonal-trapezohedral', 'hexoctahedral', 'hextetrahedral', 'pedial', 'pinacoidal', 'point group symmetry', 'prismatic', 'rhombic-dipyramidal', 'rhombic-disphenoidal', 'rhombic-pyramidal', 'rhombohedral', 'sphenoidal', 'tetartoidal', 'tetragonal-dipyramidal', 'tetragonal-disphenoidal', 'tetragonal-pyramidal', 'tetragonal-scalenohedral', 'tetragonal-trapezohedral', 'trigonal-dipyramidal', 'trigonal-pyramidal', 'trigonal-trapezohedral']
# Cluster 2: ['1,4-dioxane', 'AFE_0000354', 'AFE_0000407', 'AFE_0001128', 'AFFN_0000014', 'AFFN_0000055', 'AFFN_0000111', 'AFFN_0000127', 'AFFN_0000128', 'AFFN_0000137', 'AFM_0001034', 'AFM_0001038', 'AFP_0003306', 'AFP_0003312', 'AFP_0003348', 'AFP_0003359', 'AFP_0003486', 'AFP_0003551', 'AFP_0003563', 'AFP_0003620', 'AFR_0000916', 'AFR_0000923', 'AFR_0000992', 'Acheson method', 'Arhennius equation', 'Box–Behnken design', 'Bridgeman technique', 'Bunsen burner', 'CHEBI_24870', 'CQA specification', 'CTA Section 3.2.S.1.1 Nomenclature', 'CTA Section 3.2.S.1.2 Structure', 'CTA Section 3.2.S.1.3 General Properties', 'CTA Section 3.2.S.2.1 Manufacturers', 'CTA Section 3.2.S.2.2 Description of Manufacturing Process and Process Controls', 'CTA Section 3.2.S.2.3 Control of Materials', 'CTA Section 3.2.S.2.4 Controls of Critical Steps and Intermediates', 'CTA Section 3.2.S.3.1 Elucidation of Structure and other Characteristics', 'CTA Section 3.2.S.3.2 Impurities', 'Central Composite Design', 'Control Strategy', 'DEREK Mutagen Prediction', 'DNA polymerase activity', 'DNA polymerase complex', 'GLP synthetic process', 'GMP starting material', 'GMP synthetic process', 'Gibbs free energy change', 'Gibbs free energy of activation', 'ICH Guideline', 'ICH M7 Assessment and Control of DNA Reactive (Mutagenic) Impurities in Pharmaceuticals To Limit Potential Carcinogenic Risk', 'ICH Q11 Guidance for Development and Manufacture of Drug Substances', 'ICH Q3A Impurities in New Drug Substances', 'ICH Q3C Residual Solvents', 'ICH Q3D Guidance for Elemental Impurities', 'ICH Q6A Specifications: Test Procedures and Acceptance Criteria for Chemical Substances', 'Lewis acid', 'MCASE Mutagen Prediction', 'Maillard reaction product', 'Ostwald ripening', 'PCR product', 'Plackett–Burman design', 'Powder Indexing', 'Q7 Good Manufacturing Practice Guide for Active Pharmaceutical Ingredients', 'Reaction Progress Kinetic Analysis', 'Snyder column', 'Variable Time Normalisation Analysis', 'Vigreux column', 'Widmer column', 'acetone', 'acetonitrile', 'action specification', 'acyl group', 'affinity precipitation', 'ageing', 'air-sensitive vacuum distillation', 'alcohol', 'algorithm', 'aliphatic alcohol', 'aliphatic nitrile', 'alkyl alcohol', 'alkylbenzene', 'alpha-1-microglobulin-Ig alpha complex chromophores', 'amide', 'amino acid', 'amino-acid anion', 'ammonia', 'ammonium', 'amplified DNA', 'anhydrous phase', 'anion', 'annulene', 'appearance datum', 'arene', 'aromatic annulene', 'aromatic compound', 'assay', 'assay objective', 'assessed ionisability purge factor', 'assessed reactivity purge factor', 'assessed solubility purge factor', 'assessed volatility purge factor', 'atom', 'atomic nucleus', 'azane', 'azanide', 'azeotropic distillation', 'ball milling', 'baryon', 'batch campaign', 'batch distillation', 'batch manufacturing record', 'beaker', 'benzene', 'benzenes', 'benzenoid aromatic compound', 'bill of materials', 'blow drying', 'butan-2-one', 'butanone', 'calculated datum', 'calculation', 'carbamate', 'carbamic acid', 'carbocyclic compound', 'carbon atom', 'carbon group element atom', 'carbon group molecular entity', 'carbon oxoacid', 'carbonyl compound', 'carboxamide', 'carboximidic acid', 'carboxy group', 'carboxylic acid', 'carboxylic acid anion', 'catalytic activity', 'cation', 'centrally registered identifier', 'centrally registered identifier registry', 'centrally registered identifier symbol', 'centrifugal evaporation', 'certificate of analysis', 'chalcogen', 'chalcogen molecular entity', 'charging material', 'chemical abstracts name', 'chemical abstracts number', 'chemical drawing', 'chemical entity', 'chemical impurity', 'chemical process development', 'chemical product', 'chemical vapour transport', 'chemometrics', 'chromatography column', 'cloud-point extraction', 'co-crystal', 'co-precipitation', 'cocrystallisation', 'coextraction', 'commercial chemical product', 'common technical document', 'competency question', 'composite particle', 'concentrat ...
# Cluster 3: ['AFRL_0000020', 'AFRL_0000085', 'AFRL_0000167', 'AFRL_0000216', 'AFRL_0000217', 'AFRL_0000221', 'AFRL_0000223', 'AFRL_0000229', 'AFRL_0000231', 'AFRL_0000249', 'AFRL_0000289', 'AFRL_0000344', 'AFRL_0000345', 'AFRL_0000351', 'AFRL_0000359', 'AFRL_0000360', 'AFRL_0000361', 'AFRL_0000362', 'AFRL_0000364', 'AFRL_0000365', 'AFRL_0000366', 'AFRL_0000367', 'AFRL_0000420', 'AFRL_0000421', 'AFRL_0000424', 'AFRL_0000425', 'AFRL_0000426', 'AFRL_0000427', 'AFRL_0000428', 'AFRL_0000430', 'AFRL_0000510', 'AFRL_0000511', 'AFRL_0000512', 'Bronsted acid', 'Bronsted base', 'EC 1.* (oxidoreductase) inhibitor', 'EC 1.9.* (oxidoreductase acting on donor heme group) inhibitor', 'EC 1.9.3.* (oxidoreductase acting on donor heme group, oxygen as acceptor) inhibitor', 'EC 1.9.3.1 (cytochrome c oxidase) inhibitor', 'EC 3.* (hydrolase) inhibitor', 'EC 3.5.* (hydrolases acting on non-peptide C-N bonds) inhibitor', 'EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor', "Good's buffer substance", 'Lewis acid', 'Lewis base', 'OBI_0000571', 'acceptor', 'acid', 'acyl donor', 'aetiopathogenetic role', 'amphiprotic solvent', 'antimicrobial agent', 'antioxidant', 'antisolvent role', 'application', 'aprotic solvent', 'astringent', 'base', 'biochemical role', 'biological role', 'biophysical role', 'bolaamphiphile', 'buffer', 'carcinogenic agent', 'chain carrier', 'chelator', 'chemical role', 'cofactor', 'copper chelator', 'corrosion inhibitor', 'deaminating agent', 'detergent', 'donor', 'drug', 'electron acceptor', 'electron donor', 'electron-transport chain inhibitor', 'electrophilic reagent', 'emulsifier', 'environmental contaminant', 'environmental food contaminant', 'enzyme inhibitor', 'evaluant role', 'film-forming compound', 'fluorescence quencher', 'food additive', 'food antioxidant', 'food component', 'food emulsifier', 'food preservative', 'fuel', 'fuel additive', 'greenhouse gas', 'hepatotoxic agent', 'hydrogen acceptor', 'hydrogen donor', 'impurity', 'inhibitor', 'inorganic acid', 'ionophore', 'iron chelator', 'iron ionophore', 'iron(2+) chelator', 'iron(3+) chelator', 'ligand', 'luciferin', 'membrane transport modulator', 'mitochondrial respiratory-chain inhibitor', 'mother liquor role', 'mutagenic impurity', 'neuroprotective agent', 'neurotoxin', 'neurotransmitter agent', 'nitric oxide donor', 'non-polar solvent', 'nonionic surfactant', 'nucleic acid template role', 'nucleophilic reagent', 'nutrient', 'oxidising agent', 'pathway inhibitor', 'pharmaceutical', 'pharmacological role', 'photobiochemical role', 'photochemical role', 'physiological role', 'phytosiderophore', 'poison', 'polar aprotic solvent', 'polar solvent', 'precipitate role', 'protective agent', 'protic solvent', 'protophilic solvent', 'reaction intermediate', 'reactive oxygen species generator', 'reagent', 'reagent role', 'reducing agent', 'reference substance role', 'refrigerant', 'residual solvent impurity', 'respiratory-chain inhibitor', 'role', 'seed role', 'sequestrant', 'sideramine', 'siderophore', 'solvent', 'solvent evaporation', 'solvent precipitation', 'surfactant', 'ultraviolet filter']
# Cluster 4: ['AFQ_0000111', 'AFQ_0000115', 'AFQ_0000168', 'AFQ_0000250', 'AFQ_0000256', 'AFQ_0000279', 'X-Ray diffractivity', 'bulk substance quality', 'centrosymmetric point symmetry', 'chemical structure', 'concentration of', 'critical quality attribute', 'crystalline state', 'enantiomorphic point symmetry', 'flow rate', 'habit', 'hexagonal unit cell', 'length', 'mass', 'molecular formula', 'molecular quality', 'monoclinic unit cell', 'morphology', 'non-centrosymmetric achiral symmetry', 'non-centrosymmetric point symmetry', 'point symmetry', 'polar point symmetry', 'quality', 'solubility', 'space group', 'specifically dependent continuant', 'symmetry', 'unit cell', 'unit cell Z value', "unit cell Z' value", 'unit cell a-axis length', 'unit cell alpha internal angle', 'unit cell b-axis length', 'unit cell beta internal angle', 'unit cell c-axis length', 'unit cell crystal density', 'unit cell gamma internal angle', 'unit cell quality', 'unit cell volume']
# Cluster 5: ['Escherichia coli metabolite', 'Mycoplasma genitalium metabolite', 'Saccharomyces cerevisiae metabolite', 'animal metabolite', 'bacterial metabolite', 'eukaryotic metabolite', 'fungal metabolite', 'human metabolite', 'mammalian metabolite', 'metabolite', 'mouse metabolite', 'prokaryotic metabolite']
# Cluster 6: ['GMP specification of synthetic process', 'route specification']
# Cluster 7: ['centrifugation', 'differential centrifugation', 'low-speed centrifugation', 'preparative centrifugation', 'sequential centrifugation']
# Cluster 8: ['enzymatic amplification', 'polymerase chain reaction']
# Cluster 9: ['Allihn condenser', 'Davies condenser', 'Dimroth condenser', 'Frederichs condensor', 'Graham condensor', 'Liebig condenser', 'coil condenser', 'cold finger', 'condensor']
# Cluster 10: ['Erlenmeyer flask', 'flask', 'round bottom flask', 'volumetric flask']
# Cluster 11: ['drug product approval milestone', 'drug product filing milestone', 'process boundary', 'product approval milestone', 'product filing milestone', 'route selection milestone']
# Cluster 12: ['integral kinetic measurement', 'method of flooding']
# Cluster 13: ['adsorption chromatography', 'affinity chromatography', 'chromatography', 'column chromatography', 'displacement chromatography']
# Cluster 14: ['animal metabolite', 'mammalian metabolite']
# Cluster 15: ['supercritical carbon dioxide drying', 'supercritical drying']
# Cluster 16: ['route development optimization', 'route related process', 'route scouting', 'route selection']
# Cluster 17: ['ionic salt', 'solid solution']
# Cluster 18: ['antibacterial agent', 'antimicrobial agent']
# Cluster 19: ['induction period', 'synthesis reaction time', 'temporal region']
# Cluster 20: ['ICH Q6A Class 1 Solvent', 'ICH Q6A Class 2 Solvent', 'ICH Q6A Class 3 Solvent', 'residual solvent impurity']
# Cluster 21: ['molecular distillation', 'vacuum distillation']
# Cluster 22: ['carbonyl group', 'organic divalent group', 'organodiyl group']
# Cluster 23: ['sandwich sublimation', 'seeded sublimation']
# Cluster 24: ['acyl group', 'carbamoyl group', 'carboacyl group', 'univalent carboacyl group']
# Cluster 25: ['cholinergic antagonist', 'cholinergic drug', 'neurotransmitter agent', 'pharmacological role']
# Cluster 26: ['EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor', 'EC 3.5.1.4 (amidase) inhibitor']
# Cluster 27: ['AFRL_0000244', 'AFRL_0000363']
# Cluster 28: ['Czochralski process', 'Lely method', 'Verneuil process', 'crystal growth method']
# Cluster 29: ['scalar value specification', 'value specification']
# Cluster 30: ['hydrate', 'solvate']
# Cluster 31: ['chromophore', 'phytochrome chromophore']
# Cluster 32: ['washing']
# Cluster 33: ['macronutrient']
# Cluster 34: ['annealing']
# Cluster 35: ['AFRL_0000423']
# Cluster 36: ['AFFN_0000187']
# Cluster 37: ['AFQ_0000113']
# Cluster 38: ['elution']
# Cluster 39: ['amphiphile']
# Cluster 40: ['AFRL_0000533']
# Cluster 41: ['AFQ_0000114']
# Cluster 42: ['polymerisation monomer']
# Cluster 43: ['lumiphore']
# Cluster 44: ['AFRL_0000429']
# Cluster 45: ['explosive']
# Cluster 46: ['trituration']
# Cluster 47: ['AFRL_0000508']
# Cluster 48: ['AFQ_0000112']
# Cluster 49: ['oxidized luciferins']
# Cluster 50: ['AFM_0001035']
# Cluster 51: ['flocculant']
# Cluster 52: ['radical scavenger']
# Cluster 53: ['isomorphic desolvate']
# Cluster 54: ['catalyst', 'phase-transfer catalyst']
# Cluster 55: ['dissolving']
# Cluster 56: ['AFM_0001097']
# Cluster 57: ['AFFN_0000139']
# Cluster 58: ['AFRL_0000422']
# Cluster 59: ['spiking']
# Cluster 60: ['slurry']
# Cluster 61: ['AFFN_0000044']
# Cluster 62: ['AFRL_0000513']
# Cluster 63: ['Permitted Daily Exposure']

# %%
from google import genai
model = "gemini-2.5-pro"
client= genai.Client(api_key="")

# %%
final_ans = []
for i, list_of_elements in tqdm(enumerate(final_clusters_list)):
    if len(list_of_elements)>1:
        prompt = f""""Analyze the following list of biological terms and identify all direct and indirect **parent-child relationships**.

        A **parent-child relationship** exists when one term (the parent) is a broader, more general category or a whole that conceptually encompasses or contains another term (the child). The child term is a more specific instance, a part, or a developmental stage of the parent term.

        **Guidelines for identifying relationships:**
        * **"Is-a" relationship:** e.g., "A 'leaf procambium' **is a** type of 'procambium'." (Parent: procambium, Child: leaf procambium)
        * **"Part-of" relationship:** e.g., "A 'petal' **is part of** a 'flower'." (Parent: flower, Child: petal)
        * **Developmental sequence:** e.g., "'Petal primordium visible stage' **is a stage in** 'petal development'." (Parent: petal development, Child: petal primordium visible stage)
        * **Anatomical hierarchy:** e.g., "'Root endodermis' **is part of** 'root' and **is a type of** 'endodermis'." (Parent: root and endodermis, Child: root endodermis)

        **List of Elements:**
        {list_of_elements}
        **Output Format:**
        Provide the output as a single JSON array. Each element in the array must be a JSON object with two keys: `"parent"` and `"child"`, whose values are the corresponding terms.

        **Example Output (Illustrative, showing the expected JSON structure):**
        {json.dumps({"Answer":[
        {
            "parent": "procambium",
            "child": "branch procambium"
        },
        {
            "parent": "procambium",
            "child": "leaf procambium"
        },
        {
            "parent": "shoot system",
            "child": "axillary shoot system"
        },
        {
            "parent": "flower",
            "child": "petal"
        },
        {
            "parent": "flower development",
            "child": "petal primordium visible stage"
        }
        ]})}
        """
        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%20==0:
            print(response.text)
# Out:
# 0it [00:00, ?it/s]
# [
#   {
#     "parent": "point group symmetry",
#     "child": "dihexagonal-dipyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "dihexagonal-pyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "diploidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "ditetragonal-dipyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "ditetragonal-pyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "ditrigonal-dipyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "ditrigonal-pyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "ditrigonal-scalenohedral"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "domatic"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "gyroidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "hexagonal-dipyrimidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "hexagonal-pyrimidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "hexagonal-trapezohedral"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "hexoctahedral"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "hextetrahedral"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "pedial"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "pinacoidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "prismatic"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "rhombic-dipyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "rhombic-disphenoidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "rhombic-pyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "rhombohedral"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "sphenoidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "tetartoidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "tetragonal-dipyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "tetragonal-disphenoidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "tetragonal-pyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "tetragonal-scalenohedral"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "tetragonal-trapezohedral"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "trigonal-dipyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "trigonal-pyramidal"
#   },
#   {
#     "parent": "point group symmetry",
#     "child": "trigonal-trapezohedral"
#   }
# ]
# [
#   {
#     "parent": "vacuum distillation",
#     "child": "molecular distillation"
#   }
# ]

# %%
final_ans
# Out:
# ['[\n  {\n    "parent": "point group symmetry",\n    "child": "dihexagonal-dipyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "dihexagonal-pyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "diploidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "ditetragonal-dipyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "ditetragonal-pyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "ditrigonal-dipyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "ditrigonal-pyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "ditrigonal-scalenohedral"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "domatic"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "gyroidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "hexagonal-dipyrimidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "hexagonal-pyrimidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "hexagonal-trapezohedral"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "hexoctahedral"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "hextetrahedral"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "pedial"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "pinacoidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "prismatic"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "rhombic-dipyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "rhombic-disphenoidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "rhombic-pyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "rhombohedral"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "sphenoidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "tetartoidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "tetragonal-dipyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "tetragonal-disphenoidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "tetragonal-pyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "tetragonal-scalenohedral"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "tetragonal-trapezohedral"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "trigonal-dipyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "trigonal-pyramidal"\n  },\n  {\n    "parent": "point group symmetry",\n    "child": "trigonal-trapezohedral"\n  }\n]',
#  '[\n  {\n    "parent": "entity",\n    "child": "continuant"\n  },\n  {\n    "parent": "entity",\n    "child": "occurrent"\n  },\n  {\n    "parent": "entity",\n    "child": "realizable entity"\n  },\n  {\n    "parent": "continuant",\n    "child": "generically dependent continuant"\n  },\n  {\n    "parent": "continuant",\n    "child": "independent continuant"\n  },\n  {\n    "parent": "independent continuant",\n    "child": "fiat object part"\n  },\n  {\n    "parent": "independent continuant",\n    "child": "material entity"\n  },\n  {\n    "parent": "fiat object part",\n    "child": "process boundary"\n  },\n  {\n    "parent": "material entity",\n    "child": "chemical entity"\n  },\n  {\n    "parent": "material entity",\n    "child": "device"\n  },\n  {\n    "parent": "material entity",\n    "child": "object aggregate"\n  },\n  {\n    "parent": "material entity",\n    "child": "portion of material"\n  },\n  {\n    "parent": "material entity",\n    "child": "subatomic particle"\n  },\n  {\n    "parent": "material entity",\n    "child": "thermodynamic phase"\n  },\n  {\n    "parent": "thermodynamic phase",\n    "child": "crystalline solid thermodynamic phase"\n  },\n  {\n    "parent": "crystalline solid",\n    "child": "crystalline solid thermodynamic phase"\n  },\n  {\n    "parent": "portion of material",\n    "child": "anhydrous phase"\n  },\n  {\n    "parent": "portion of material",\n    "child": "co-crystal"\n  },\n  {\n    "parent": "portion of material",\n    "child": "crystalline solid"\n  },\n  {\n    "parent": "portion of material",\n    "child": "eutectic"\n  },\n  {\n    "parent": "portion of material",\n    "child": "gas molecular entity"\n  },\n  {\n    "parent": "portion of material",\n    "child": "intermediate material for synthesis"\n  },\n  {\n    "parent": "portion of material",\n    "child": "processed material"\n  },\n  {\n    "parent": "portion of material",\n    "child": "product stream"\n  },\n  {\n    "parent": "portion of material",\n    "child": "solid dispersion"\n  },\n  {\n    "parent": "portion of material",\n    "child": "solid solution"\n  },\n  {\n    "parent": "portion of material",\n    "child": "solvate"\n  },\n  {\n    "parent": "portion of material",\n    "child": "starting material for synthesis"\n  },\n  {\n    "parent": "portion of material",\n    "child": "waste stream"\n  },\n  {\n    "parent": "starting material for synthesis",\n    "child": "GMP starting material"\n  },\n  {\n    "parent": "subatomic particle",\n    "child": "composite particle"\n  },\n  {\n    "parent": "subatomic particle",\n    "child": "fundamental particle"\n  },\n  {\n    "parent": "composite particle",\n    "child": "hadron"\n  },\n  {\n    "parent": "hadron",\n    "child": "baryon"\n  },\n  {\n    "parent": "baryon",\n    "child": "nucleon"\n  },\n  {\n    "parent": "atom",\n    "child": "atomic nucleus"\n  },\n  {\n    "parent": "atomic nucleus",\n    "child": "nucleon"\n  },\n  {\n    "parent": "nucleon",\n    "child": "nuclear particle"\n  },\n  {\n    "parent": "fundamental particle",\n    "child": "electron"\n  },\n  {\n    "parent": "fundamental particle",\n    "child": "fermion"\n  },\n  {\n    "parent": "fundamental particle",\n    "child": "lepton"\n  },\n  {\n    "parent": "fermion",\n    "child": "baryon"\n  },\n  {\n    "parent": "fermion",\n    "child": "lepton"\n  },\n  {\n    "parent": "lepton",\n    "child": "electron"\n  },\n  {\n    "parent": "occurrent",\n    "child": "process"\n  },\n  {\n    "parent": "occurrent",\n    "child": "state"\n  },\n  {\n    "parent": "process",\n    "child": "calculation"\n  },\n  {\n    "parent": "process",\n    "child": "chemical process development"\n  },\n  {\n    "parent": "process",\n    "child": "documenting"\n  },\n  {\n    "parent": "process",\n    "child": "experiment"\n  },\n  {\n    "parent": "process",\n    "child": "investigation"\n  },\n  {\n    "parent": "process",\n    "child": "material processing"\n  },\n  {\n    "parent": "process",\n    "c ...
#  '[\n  {\n    "parent": "role",\n    "child": "chemical role"\n  },\n  {\n    "parent": "role",\n    "child": "biological role"\n  },\n  {\n    "parent": "role",\n    "child": "application"\n  },\n  {\n    "parent": "role",\n    "child": "evaluant role"\n  },\n  {\n    "parent": "role",\n    "child": "aetiopathogenetic role"\n  },\n  {\n    "parent": "chemical role",\n    "child": "reagent role"\n  },\n  {\n    "parent": "chemical role",\n    "child": "photochemical role"\n  },\n  {\n    "parent": "chemical role",\n    "child": "antisolvent role"\n  },\n  {\n    "parent": "chemical role",\n    "child": "mother liquor role"\n  },\n  {\n    "parent": "chemical role",\n    "child": "precipitate role"\n  },\n  {\n    "parent": "chemical role",\n    "child": "seed role"\n  },\n  {\n    "parent": "chemical role",\n    "child": "reaction intermediate"\n  },\n  {\n    "parent": "biological role",\n    "child": "biochemical role"\n  },\n  {\n    "parent": "biological role",\n    "child": "biophysical role"\n  },\n  {\n    "parent": "biological role",\n    "child": "pharmacological role"\n  },\n  {\n    "parent": "biological role",\n    "child": "physiological role"\n  },\n  {\n    "parent": "biochemical role",\n    "child": "photobiochemical role"\n  },\n  {\n    "parent": "biochemical role",\n    "child": "nucleic acid template role"\n  },\n  {\n    "parent": "evaluant role",\n    "child": "reference substance role"\n  },\n  {\n    "parent": "application",\n    "child": "fuel"\n  },\n  {\n    "parent": "application",\n    "child": "fuel additive"\n  },\n  {\n    "parent": "application",\n    "child": "refrigerant"\n  },\n  {\n    "parent": "application",\n    "child": "ultraviolet filter"\n  },\n  {\n    "parent": "application",\n    "child": "pharmaceutical"\n  },\n  {\n    "parent": "application",\n    "child": "film-forming compound"\n  },\n  {\n    "parent": "acid",\n    "child": "Bronsted acid"\n  },\n  {\n    "parent": "acid",\n    "child": "Lewis acid"\n  },\n  {\n    "parent": "acid",\n    "child": "inorganic acid"\n  },\n  {\n    "parent": "base",\n    "child": "Bronsted base"\n  },\n  {\n    "parent": "base",\n    "child": "Lewis base"\n  },\n  {\n    "parent": "inhibitor",\n    "child": "enzyme inhibitor"\n  },\n  {\n    "parent": "inhibitor",\n    "child": "electron-transport chain inhibitor"\n  },\n  {\n    "parent": "inhibitor",\n    "child": "pathway inhibitor"\n  },\n  {\n    "parent": "inhibitor",\n    "child": "corrosion inhibitor"\n  },\n  {\n    "parent": "electron-transport chain inhibitor",\n    "child": "respiratory-chain inhibitor"\n  },\n  {\n    "parent": "respiratory-chain inhibitor",\n    "child": "mitochondrial respiratory-chain inhibitor"\n  },\n  {\n    "parent": "enzyme inhibitor",\n    "child": "EC 1.* (oxidoreductase) inhibitor"\n  },\n  {\n    "parent": "EC 1.* (oxidoreductase) inhibitor",\n    "child": "EC 1.9.* (oxidoreductase acting on donor heme group) inhibitor"\n  },\n  {\n    "parent": "EC 1.9.* (oxidoreductase acting on donor heme group) inhibitor",\n    "child": "EC 1.9.3.* (oxidoreductase acting on donor heme group, oxygen as acceptor) inhibitor"\n  },\n  {\n    "parent": "EC 1.9.3.* (oxidoreductase acting on donor heme group, oxygen as acceptor) inhibitor",\n    "child": "EC 1.9.3.1 (cytochrome c oxidase) inhibitor"\n  },\n  {\n    "parent": "enzyme inhibitor",\n    "child": "EC 3.* (hydrolase) inhibitor"\n  },\n  {\n    "parent": "EC 3.* (hydrolase) inhibitor",\n    "child": "EC 3.5.* (hydrolases acting on non-peptide C-N bonds) inhibitor"\n  },\n  {\n    "parent": "EC 3.5.* (hydrolases acting on non-peptide C-N bonds) inhibitor",\n    "child": "EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor"\n  },\n  {\n    "parent": "solvent",\n    "child": "polar solvent"\n  },\n  {\n    "parent": "solvent",\n    "child": "non-polar solvent"\n  },\n  {\n    "parent": "solvent",\n    "child": "protic solvent"\n  },\n  {\n    "parent": "solvent",\n    "child": "aprotic solvent"\n  },\n  {\ ...
#  '[\n  {\n    "parent": "specifically dependent continuant",\n    "child": "quality"\n  },\n  {\n    "parent": "quality",\n    "child": "bulk substance quality"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "bulk substance quality"\n  },\n  {\n    "parent": "quality",\n    "child": "molecular quality"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "molecular quality"\n  },\n  {\n    "parent": "quality",\n    "child": "unit cell quality"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "unit cell quality"\n  },\n  {\n    "parent": "quality",\n    "child": "symmetry"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "symmetry"\n  },\n  {\n    "parent": "quality",\n    "child": "length"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "length"\n  },\n  {\n    "parent": "quality",\n    "child": "mass"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "mass"\n  },\n  {\n    "parent": "quality",\n    "child": "solubility"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "solubility"\n  },\n  {\n    "parent": "quality",\n    "child": "AFQ_0000168"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "AFQ_0000168"\n  },\n  {\n    "parent": "quality",\n    "child": "concentration of"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "concentration of"\n  },\n  {\n    "parent": "quality",\n    "child": "flow rate"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "flow rate"\n  },\n  {\n    "parent": "quality",\n    "child": "critical quality attribute"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "critical quality attribute"\n  },\n  {\n    "parent": "bulk substance quality",\n    "child": "crystalline state"\n  },\n  {\n    "parent": "quality",\n    "child": "crystalline state"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "crystalline state"\n  },\n  {\n    "parent": "bulk substance quality",\n    "child": "morphology"\n  },\n  {\n    "parent": "quality",\n    "child": "morphology"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "morphology"\n  },\n  {\n    "parent": "morphology",\n    "child": "habit"\n  },\n  {\n    "parent": "bulk substance quality",\n    "child": "habit"\n  },\n  {\n    "parent": "quality",\n    "child": "habit"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "habit"\n  },\n  {\n    "parent": "bulk substance quality",\n    "child": "X-Ray diffractivity"\n  },\n  {\n    "parent": "quality",\n    "child": "X-Ray diffractivity"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "X-Ray diffractivity"\n  },\n  {\n    "parent": "bulk substance quality",\n    "child": "AFQ_0000279"\n  },\n  {\n    "parent": "quality",\n    "child": "AFQ_0000279"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "AFQ_0000279"\n  },\n  {\n    "parent": "molecular quality",\n    "child": "chemical structure"\n  },\n  {\n    "parent": "quality",\n    "child": "chemical structure"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "chemical structure"\n  },\n  {\n    "parent": "molecular quality",\n    "child": "molecular formula"\n  },\n  {\n    "parent": "quality",\n    "child": "molecular formula"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "molecular formula"\n  },\n  {\n    "parent": "symmetry",\n    "child": "point symmetry"\n  },\n  {\n    "parent": "quality",\n    "child": "point symmetry"\n  },\n  {\n    "parent": "specifically dependent continuant",\n    "child": "point symmetry"\n  },\n  {\n    "parent": "symmetry",\n    "child": "space group"\n  },\n  {\n    "parent": "quality",\n    "child": "space group"\n  },\n  {\n    "parent ...
#  '[\n  {\n    "parent": "metabolite",\n    "child": "eukaryotic metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "prokaryotic metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "animal metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "fungal metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "bacterial metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "mammalian metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "Saccharomyces cerevisiae metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "human metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "mouse metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "Escherichia coli metabolite"\n  },\n  {\n    "parent": "metabolite",\n    "child": "Mycoplasma genitalium metabolite"\n  },\n  {\n    "parent": "eukaryotic metabolite",\n    "child": "animal metabolite"\n  },\n  {\n    "parent": "eukaryotic metabolite",\n    "child": "fungal metabolite"\n  },\n  {\n    "parent": "eukaryotic metabolite",\n    "child": "mammalian metabolite"\n  },\n  {\n    "parent": "eukaryotic metabolite",\n    "child": "Saccharomyces cerevisiae metabolite"\n  },\n  {\n    "parent": "eukaryotic metabolite",\n    "child": "human metabolite"\n  },\n  {\n    "parent": "eukaryotic metabolite",\n    "child": "mouse metabolite"\n  },\n  {\n    "parent": "prokaryotic metabolite",\n    "child": "bacterial metabolite"\n  },\n  {\n    "parent": "prokaryotic metabolite",\n    "child": "Escherichia coli metabolite"\n  },\n  {\n    "parent": "prokaryotic metabolite",\n    "child": "Mycoplasma genitalium metabolite"\n  },\n  {\n    "parent": "animal metabolite",\n    "child": "mammalian metabolite"\n  },\n  {\n    "parent": "animal metabolite",\n    "child": "human metabolite"\n  },\n  {\n    "parent": "animal metabolite",\n    "child": "mouse metabolite"\n  },\n  {\n    "parent": "fungal metabolite",\n    "child": "Saccharomyces cerevisiae metabolite"\n  },\n  {\n    "parent": "bacterial metabolite",\n    "child": "Escherichia coli metabolite"\n  },\n  {\n    "parent": "bacterial metabolite",\n    "child": "Mycoplasma genitalium metabolite"\n  },\n  {\n    "parent": "mammalian metabolite",\n    "child": "human metabolite"\n  },\n  {\n    "parent": "mammalian metabolite",\n    "child": "mouse metabolite"\n  }\n]',
#  '[\n  {\n    "parent": "route specification",\n    "child": "GMP specification of synthetic process"\n  }\n]',
#  '[\n  {\n    "parent": "centrifugation",\n    "child": "preparative centrifugation"\n  },\n  {\n    "parent": "centrifugation",\n    "child": "sequential centrifugation"\n  },\n  {\n    "parent": "centrifugation",\n    "child": "differential centrifugation"\n  },\n  {\n    "parent": "centrifugation",\n    "child": "low-speed centrifugation"\n  },\n  {\n    "parent": "preparative centrifugation",\n    "child": "differential centrifugation"\n  },\n  {\n    "parent": "sequential centrifugation",\n    "child": "differential centrifugation"\n  },\n  {\n    "parent": "differential centrifugation",\n    "child": "low-speed centrifugation"\n  }\n]',
#  '[\n  {\n    "parent": "enzymatic amplification",\n    "child": "polymerase chain reaction"\n  }\n]',
#  '[\n  {\n    "parent": "condensor",\n    "child": "Allihn condenser"\n  },\n  {\n    "parent": "condensor",\n    "child": "Davies condenser"\n  },\n  {\n    "parent": "condensor",\n    "child": "Dimroth condenser"\n  },\n  {\n    "parent": "condensor",\n    "child": "Frederichs condensor"\n  },\n  {\n    "parent": "condensor",\n    "child": "Graham condensor"\n  },\n  {\n    "parent": "condensor",\n    "child": "Liebig condenser"\n  },\n  {\n    "parent": "condensor",\n    "child": "coil condenser"\n  },\n  {\n    "parent": "condensor",\n    "child": "cold finger"\n  },\n  {\n    "parent": "coil condenser",\n    "child": "Graham condensor"\n  },\n  {\n    "parent": "coil condenser",\n    "child": "Dimroth condenser"\n  }\n]',
#  '[\n  {\n    "parent": "flask",\n    "child": "Erlenmeyer flask"\n  },\n  {\n    "parent": "flask",\n    "child": "round bottom flask"\n  },\n  {\n    "parent": "flask",\n    "child": "volumetric flask"\n  }\n]',
#  '[\n    {\n        "parent": "product approval milestone",\n        "child": "drug product approval milestone"\n    },\n    {\n        "parent": "product filing milestone",\n        "child": "drug product filing milestone"\n    }\n]',
#  '[\n  {\n    "parent": "integral kinetic measurement",\n    "child": "method of flooding"\n  }\n]',
#  '[\n  {\n    "parent": "chromatography",\n    "child": "adsorption chromatography"\n  },\n  {\n    "parent": "chromatography",\n    "child": "affinity chromatography"\n  },\n  {\n    "parent": "chromatography",\n    "child": "column chromatography"\n  },\n  {\n    "parent": "chromatography",\n    "child": "displacement chromatography"\n  },\n  {\n    "parent": "column chromatography",\n    "child": "adsorption chromatography"\n  },\n  {\n    "parent": "column chromatography",\n    "child": "affinity chromatography"\n  },\n  {\n    "parent": "column chromatography",\n    "child": "displacement chromatography"\n  }\n]',
#  '[\n  {\n    "parent": "animal metabolite",\n    "child": "mammalian metabolite"\n  }\n]',
#  '[\n  {\n    "parent": "supercritical drying",\n    "child": "supercritical carbon dioxide drying"\n  }\n]',
#  '[\n  {\n    "parent": "route related process",\n    "child": "route development optimization"\n  },\n  {\n    "parent": "route related process",\n    "child": "route scouting"\n  },\n  {\n    "parent": "route related process",\n    "child": "route selection"\n  }\n]',
#  '{\n  "Answer": []\n}',
#  '[\n  {\n    "parent": "antimicrobial agent",\n    "child": "antibacterial agent"\n  }\n]',
#  '[\n  {\n    "parent": "synthesis reaction time",\n    "child": "induction period"\n  }\n]',
#  '[\n  {\n    "parent": "residual solvent impurity",\n    "child": "ICH Q6A Class 1 Solvent"\n  },\n  {\n    "parent": "residual solvent impurity",\n    "child": "ICH Q6A Class 2 Solvent"\n  },\n  {\n    "parent": "residual solvent impurity",\n    "child": "ICH Q6A Class 3 Solvent"\n  }\n]',
#  '[\n  {\n    "parent": "vacuum distillation",\n    "child": "molecular distillation"\n  }\n]',
#  '[\n  {\n    "parent": "organic divalent group",\n    "child": "carbonyl group"\n  },\n  {\n    "parent": "organodiyl group",\n    "child": "carbonyl group"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "acyl group",\n    "child": "carbamoyl group"\n  },\n  {\n    "parent": "acyl group",\n    "child": "carboacyl group"\n  },\n  {\n    "parent": "carboacyl group",\n    "child": "univalent carboacyl group"\n  },\n  {\n    "parent": "acyl group",\n    "child": "univalent carboacyl group"\n  }\n]',
#  '[\n  {\n    "parent": "cholinergic drug",\n    "child": "cholinergic antagonist"\n  },\n  {\n    "parent": "neurotransmitter agent",\n    "child": "cholinergic drug"\n  },\n  {\n    "parent": "pharmacological role",\n    "child": "neurotransmitter agent"\n  },\n  {\n    "parent": "neurotransmitter agent",\n    "child": "cholinergic antagonist"\n  },\n  {\n    "parent": "pharmacological role",\n    "child": "cholinergic drug"\n  },\n  {\n    "parent": "pharmacological role",\n    "child": "cholinergic antagonist"\n  }\n]',
#  '[\n  {\n    "parent": "EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor",\n    "child": "EC 3.5.1.4 (amidase) inhibitor"\n  }\n]',
#  '[\n    {\n        "parent": "AFRL_0000363",\n        "child": "AFRL_0000244"\n    }\n]',
#  '[\n  {\n    "parent": "crystal growth method",\n    "child": "Czochralski process"\n  },\n  {\n    "parent": "crystal growth method",\n    "child": "Lely method"\n  },\n  {\n    "parent": "crystal growth method",\n    "child": "Verneuil process"\n  }\n]',
#  '[\n    {\n        "parent": "value specification",\n        "child": "scalar value specification"\n    }\n]',
#  '[\n    {\n        "parent": "solvate",\n        "child": "hydrate"\n    }\n]',
#  '{\n    "Answer": [\n        {\n            "parent": "chromophore",\n            "child": "phytochrome chromophore"\n        }\n    ]\n}',
#  '[\n  {\n    "parent": "catalyst",\n    "child": "phase-transfer catalyst"\n  }\n]']

# %%
final_result = []
for ans in final_ans:
    ans_1 = json.loads(ans)
    for an in ans_1:
        if an!="Answer":
            final_result.append(an)

# %%
len(final_result)
# Out:
# 929

# %%
final_result
# Out:
# [{'parent': 'point group symmetry', 'child': 'dihexagonal-dipyramidal'},
#  {'parent': 'point group symmetry', 'child': 'dihexagonal-pyramidal'},
#  {'parent': 'point group symmetry', 'child': 'diploidal'},
#  {'parent': 'point group symmetry', 'child': 'ditetragonal-dipyramidal'},
#  {'parent': 'point group symmetry', 'child': 'ditetragonal-pyramidal'},
#  {'parent': 'point group symmetry', 'child': 'ditrigonal-dipyramidal'},
#  {'parent': 'point group symmetry', 'child': 'ditrigonal-pyramidal'},
#  {'parent': 'point group symmetry', 'child': 'ditrigonal-scalenohedral'},
#  {'parent': 'point group symmetry', 'child': 'domatic'},
#  {'parent': 'point group symmetry', 'child': 'gyroidal'},
#  {'parent': 'point group symmetry', 'child': 'hexagonal-dipyrimidal'},
#  {'parent': 'point group symmetry', 'child': 'hexagonal-pyrimidal'},
#  {'parent': 'point group symmetry', 'child': 'hexagonal-trapezohedral'},
#  {'parent': 'point group symmetry', 'child': 'hexoctahedral'},
#  {'parent': 'point group symmetry', 'child': 'hextetrahedral'},
#  {'parent': 'point group symmetry', 'child': 'pedial'},
#  {'parent': 'point group symmetry', 'child': 'pinacoidal'},
#  {'parent': 'point group symmetry', 'child': 'prismatic'},
#  {'parent': 'point group symmetry', 'child': 'rhombic-dipyramidal'},
#  {'parent': 'point group symmetry', 'child': 'rhombic-disphenoidal'},
#  {'parent': 'point group symmetry', 'child': 'rhombic-pyramidal'},
#  {'parent': 'point group symmetry', 'child': 'rhombohedral'},
#  {'parent': 'point group symmetry', 'child': 'sphenoidal'},
#  {'parent': 'point group symmetry', 'child': 'tetartoidal'},
#  {'parent': 'point group symmetry', 'child': 'tetragonal-dipyramidal'},
#  {'parent': 'point group symmetry', 'child': 'tetragonal-disphenoidal'},
#  {'parent': 'point group symmetry', 'child': 'tetragonal-pyramidal'},
#  {'parent': 'point group symmetry', 'child': 'tetragonal-scalenohedral'},
#  {'parent': 'point group symmetry', 'child': 'tetragonal-trapezohedral'},
#  {'parent': 'point group symmetry', 'child': 'trigonal-dipyramidal'},
#  {'parent': 'point group symmetry', 'child': 'trigonal-pyramidal'},
#  {'parent': 'point group symmetry', 'child': 'trigonal-trapezohedral'},
#  {'parent': 'entity', 'child': 'continuant'},
#  {'parent': 'entity', 'child': 'occurrent'},
#  {'parent': 'entity', 'child': 'realizable entity'},
#  {'parent': 'continuant', 'child': 'generically dependent continuant'},
#  {'parent': 'continuant', 'child': 'independent continuant'},
#  {'parent': 'independent continuant', 'child': 'fiat object part'},
#  {'parent': 'independent continuant', 'child': 'material entity'},
#  {'parent': 'fiat object part', 'child': 'process boundary'},
#  {'parent': 'material entity', 'child': 'chemical entity'},
#  {'parent': 'material entity', 'child': 'device'},
#  {'parent': 'material entity', 'child': 'object aggregate'},
#  {'parent': 'material entity', 'child': 'portion of material'},
#  {'parent': 'material entity', 'child': 'subatomic particle'},
#  {'parent': 'material entity', 'child': 'thermodynamic phase'},
#  {'parent': 'thermodynamic phase',
#   'child': 'crystalline solid thermodynamic phase'},
#  {'parent': 'crystalline solid',
#   'child': 'crystalline solid thermodynamic phase'},
#  {'parent': 'portion of material', 'child': 'anhydrous phase'},
#  {'parent': 'portion of material', 'child': 'co-crystal'},
#  {'parent': 'portion of material', 'child': 'crystalline solid'},
#  {'parent': 'portion of material', 'child': 'eutectic'},
#  {'parent': 'portion of material', 'child': 'gas molecular entity'},
#  {'parent': 'portion of material',
#   'child': 'intermediate material for synthesis'},
#  {'parent': 'portion of material', 'child': 'processed material'},
#  {'parent': 'portion of material', 'child': 'product stream'},
#  {'parent': 'portion of material', 'child': 'solid dispersion'},
#  {'parent': 'portion of material', 'child': 'solid solution'},
#  {'parent': 'portion of material', 'child': 'solvate'},
#  {'parent': 'portion of material', 'child': 'starting material for synthesis'},
#  {'parent': 'portion of material', 'child': 'waste stream'},
#  {'parent': 'starting material for synthesis',
#   'child': 'GMP starting material'},
#  {'parent': 'subatomic particle', 'child': 'composite particle'},
#  {'parent': 'subatomic particle', 'child': 'fundamental particle'},
#  {'parent': 'composite particle', 'child': 'hadron'},
#  {'parent': 'hadron', 'child': 'baryon'},
#  {'parent': 'baryon', 'child': 'nucleon'},
#  {'parent': 'atom', 'child': 'atomic nucleus'},
#  {'parent': 'atomic nucleus', 'child': 'nucleon'},
#  {'parent': 'nucleon', 'child': 'nuclear particle'},
#  {'parent': 'fundamental particle', 'child': 'electron'},
#  {'parent': 'fundamental particle', 'child': 'fermion'},
#  {'parent': 'fundamental particle', 'child': 'lepton'},
#  {'parent': 'fermion', 'child': 'baryon'},
#  {'parent': 'fermion', 'child': 'lepton'},
#  {'parent': 'lepton', 'child': 'electron'},
#  {'parent': 'occurrent', 'child': 'process'},
#  {'parent': 'occurrent', 'child': 'state'},
#  {'parent': 'process', 'child': 'calculation'},
#  {'parent': 'process', 'child': 'chemical process development'},
#  {'parent': 'process', 'child': 'documenting'},
#  {'parent': 'process', 'child': 'experiment'},
#  {'parent': 'process', 'child': 'investigation'},
#  {'parent': 'process', 'child': 'material processing'},
#  {'parent': 'process', 'child': 'planning'},
#  {'parent': 'process', 'child': 'process monitoring'},
#  {'parent': 'process', 'child': 'process validation'},
#  {'parent': 'process', 'child': 'route validation'},
#  {'parent': 'process', 'child': 'synthetic chemical process'},
#  {'parent': 'process', 'child': 'unit operation in chemical processing'},
#  {'parent': 'material processing', 'child': 'concentrating'},
#  {'parent': 'material processing', 'child': 'grinding'},
#  {'parent': 'material processing', 'child': 'homogenisation'},
#  {'parent': 'material processing', 'child': 'material component separation'},
#  {'parent': 'material processing', 'child': 'purification'},
#  {'parent': 'material processing', 'child': 'sample deposition'},
#  {'parent': 'material processing', 'child': 'sample drying'},
#  {'parent': 'material processing', 'child': 'sample heating'},
#  {'parent': 'material processing', 'child': 'sample quenching'},
#  {'parent': 'material processing', 'child': 'sample solidification'},
#  {'parent': 'concentrating', 'child': 'evaporation'},
#  {'parent': 'purification', 'child': 'crystallisation'},
#  {'parent': 'purification', 'child': 'distillation'},
#  {'parent': 'purification', 'child': 'recrystallisation'},
#  {'parent': 'crystallisation', 'child': 'ageing'},
#  {'parent': 'crystallisation', 'child': 'cocrystallisation'},
#  {'parent': 'crystallisation', 'child': 'crystallization'},
#  {'parent': 'crystallisation', 'child': 'fractional crystallisation'},
#  {'parent': 'crystallisation', 'child': 'Ostwald ripening'},
#  {'parent': 'distillation', 'child': 'azeotropic distillation'},
#  {'parent': 'distillation', 'child': 'batch distillation'},
#  {'parent': 'distillation', 'child': 'continuous distillation'},
#  {'parent': 'distillation', 'child': 'extractive distillation'},
#  {'parent': 'distillation', 'child': 'fractional distillation'},
#  {'parent': 'distillation', 'child': 'freeze distillation'},
#  {'parent': 'distillation', 'child': 'reactive distillation'},
#  {'parent': 'distillation', 'child': 'simple distillation'},
#  {'parent': 'distillation', 'child': 'steam distillation'},
#  {'parent': 'distillation', 'child': 'vacuum distillation'},
#  {'parent': 'vacuum distillation',
#   'child': 'air-sensitive vacuum distillation'},
#  {'parent': 'evaporation', 'child': 'centrifugal evaporation'},
#  {'parent': 'evaporation', 'child': 'rotary evaporation'},
#  {'parent': 'evaporation', 'child': 'solvent evaporation'},
#  {'parent': 'filtration', 'child': 'micro-filtration'},
#  {'parent': 'filtration', 'child': 'nano-filtration'},
#  {'parent': 'filtration', 'child': 'suction filtration'},
#  {'parent': 'filtration', 'child': 'ultra-filtration'},
#  {'parent': 'filtering', 'child': 'filtration'},
#  {'parent': 'fractionation', 'child': 'foam fractionation'},
#  {'parent': 'fractionation', 'child': 'fractional crystallisation'},
#  {'parent': 'fractionation', 'child': 'fractional distillation'},
#  {'parent': 'fractionation', 'child': 'fractional sublimation'},
#  {'parent': 'grinding', 'child': 'ball milling'},
#  {'parent': 'grinding', 'child': 'liquid-assisted grinding'},
#  {'parent': 'grinding', 'child': 'wet grinding'},
#  {'parent': 'ball milling', 'child': 'high-energy ball milling'},
#  {'parent': 'high-energy ball milling', 'child': 'high-speed ball milling'},
#  {'parent': 'precipitation', 'child': 'affinity precipitation'},
#  {'parent': 'precipitation', 'child': 'co-precipitation'},
#  {'parent': 'precipitation', 'child': 'postprecipitation'},
#  {'parent': 'precipitation',
#   'child': 'precipitation with compressed antisolvent'},
#  {'parent': 'precipitation', 'child': 'protein precipitation'},
#  {'parent': 'precipitation', 'child': 'reprecipitation'},
#  {'parent': 'sample drying', 'child': 'blow drying'},
#  {'parent': 'sample drying', 'child': 'dielectric drying'},
#  {'parent': 'sample drying', 'child': 'direct drying'},
#  {'parent': 'sample drying', 'child': 'drum drying'},
#  {'parent': 'sample drying', 'child': 'freeze drying'},
#  {'parent': 'sample drying', 'child': 'oven drying'},
#  {'parent': 'sample drying', 'child': 'spray drying'},
#  {'parent': 'sample drying', 'child': 'supercritical drying'},
#  {'parent': 'sample drying', 'child': 'vacuum drying'},
#  {'parent': 'sample sublimation', 'child': 'fractional sublimation'},
#  {'parent': 'sample sublimation', 'child': 'high-vacuum sublimation'},
#  {'parent': 'sample sublimation', 'child': 'seeded sublimation'},
#  {'parent': 'sample sublimation', 'child': 'vacuum sublimation'},
#  {'parent': 'separation method', 'child': 'crystallisation'},
#  {'parent': 'separation method', 'child': 'deionisation method'},
#  {'parent': 'separation method', 'child': 'distillation'},
#  {'parent': 'separation method', 'child': 'extraction'},
#  {'parent': 'separation method', 'child': 'filtration'},
#  {'parent': 'separation method', 'child': 'fractionation'},
#  {'parent': 'separation method', 'child': 'precipitation'},
#  {'parent': 'separation method', 'child': 'reverse osmosis'},
#  {'parent': 'separation method', 'child': 'sample sublimation'},
#  {'parent': 'extraction', 'child': 'cloud-point extraction'},
#  {'parent': 'extraction', 'child': 'coextraction'},
#  {'parent': 'extraction', 'child': 'dispersive solid phase extraction'},
#  {'parent': 'extraction', 'child': 'dual-phase extraction'},
#  {'parent': 'extraction', 'child': 'ethanol extraction'},
#  {'parent': 'extraction', 'child': 'gas–liquid extraction'},
#  {'parent': 'extraction', 'child': 'liquid–liquid extraction'},
#  {'parent': 'extraction', 'child': 'membrane extraction'},
#  {'parent': 'extraction', 'child': 'pressurised-fluid extraction'},
#  {'parent': 'extraction', 'child': 'sequentional extraction'},
#  {'parent': 'extraction', 'child': 'shake-flask extraction'},
#  {'parent': 'extraction', 'child': 'solid–liquid extraction'},
#  {'parent': 'extraction', 'child': 'solvent extraction'},
#  {'parent': 'extraction', 'child': 'substoichiometric extraction'},
#  {'parent': 'extraction', 'child': 'supercritical fluid extraction'},
#  {'parent': 'extraction', 'child': 'vapour-phase extraction'},
#  {'parent': 'solid–liquid extraction', 'child': 'liquid-solid extraction'},
#  {'parent': 'membrane extraction',
#   'child': 'membrane extraction with a sorbent interface'},
#  {'parent': 'membrane extraction', 'child': 'polymeric membrane extraction'},
#  {'parent': 'membrane extraction',
#   'child': 'supported liquid membrane extraction'},
#  {'parent': 'planning', 'child': 'planned process'},
#  {'parent': 'planned process', 'child': 'process chemistry workflow plan'},
#  {'parent': 'planned process', 'child': 'study design'},
#  {'parent': 'study design', 'child': 'experimental design'},
#  {'parent': 'experiment', 'child': 'assay'},
#  {'parent': 'experiment', 'child': 'multi-parallel experimentation'},
#  {'parent': 'experiment', 'child': 'study design execution'},
#  {'parent': 'experimental design', 'child': 'Box–Behnken design'},
#  {'parent': 'experimental design', 'child': 'Central Composite Design'},
#  {'parent': 'experimental design', 'child': 'factorial design'},
#  {'parent': 'experimental design',
#   'child': 'one-factor-at-a-time experimental design'},
#  {'parent': 'experimental design',
#   'child': 'polymorph and solvate screening design'},
#  {'parent': 'experimental design', 'child': 'reaction screening design'},
#  {'parent': 'experimental design', 'child': 'screening design'},
#  {'parent': 'experimental design', 'child': 'solubility screening design'},
#  {'parent': 'factorial design', 'child': 'Box–Behnken design'},
#  {'parent': 'factorial design', 'child': 'Central Composite Design'},
#  {'parent': 'screening design', 'child': 'Plackett–Burman design'},
#  {'parent': 'screening design',
#   'child': 'polymorph and solvate screening design'},
#  {'parent': 'screening design', 'child': 'reaction screening design'},
#  {'parent': 'screening design', 'child': 'solubility screening design'},
#  {'parent': 'investigation', 'child': 'impurity fate and purge determination'},
#  {'parent': 'investigation', 'child': 'mechanistic and kinetic determination'},
#  {'parent': 'investigation', 'child': 'review of prior art'},
#  {'parent': 'investigation', 'child': 'risk assessment'},
#  {'parent': 'process monitoring', 'child': 'end reaction monitoring'},
#  {'parent': 'synthetic chemical process', 'child': 'GLP synthetic process'},
#  {'parent': 'synthetic chemical process', 'child': 'GMP synthetic process'},
#  {'parent': 'unit operation in chemical processing',
#   'child': 'charging material'},
#  {'parent': 'unit operation in chemical processing', 'child': 'filtering'},
#  {'parent': 'unit operation in chemical processing',
#   'child': 'material component separation'},
#  {'parent': 'unit operation in chemical processing', 'child': 'mixing'},
#  {'parent': 'unit operation in chemical processing', 'child': 'stirring'},
#  {'parent': 'stirring', 'child': 'magnetic stirring'},
#  {'parent': 'material component separation', 'child': 'separation method'},
#  {'parent': 'calculation', 'child': 'chemometrics'},
#  {'parent': 'calculation', 'child': 'data transformation'},
#  {'parent': 'calculation', 'child': 'drawing a conclusion based on data'},
#  {'parent': 'calculation', 'child': 'factorial analysis'},
#  {'parent': 'data transformation',
#   'child': 'curve fitting data transformation'},
#  {'parent': 'drawing a conclusion based on data',
#   'child': 'conclusion based on data'},
#  {'parent': 'crystal growth method', 'child': 'Bridgeman technique'},
#  {'parent': 'crystal growth method', 'child': 'chemical vapour transport'},
#  {'parent': 'chemical vapour transport',
#   'child': 'surface-assisted chemical vapour transport'},
#  {'parent': 'synthesis method', 'child': 'Acheson method'},
#  {'parent': 'synthesis method', 'child': 'ionothermal synthesis'},
#  {'parent': 'synthesis method', 'child': 'solvothermal synthesis'},
#  {'parent': 'supercritical fluid method',
#   'child': 'gas antisolvent technique'},
#  {'parent': 'supercritical fluid method',
#   'child': 'supercritical antisolvent technique'},
#  {'parent': 'supercritical fluid method',
#   'child': 'supercritical fluid extraction'},
#  {'parent': 'polymerase chain reaction', 'child': 'PCR product'},
#  {'parent': 'realizable entity', 'child': 'disposition'},
#  {'parent': 'realizable entity', 'child': 'function'},
#  {'parent': 'function', 'child': 'molecular_function'},
#  {'parent': 'function', 'child': 'synthesizing function'},
#  {'parent': 'molecular_function', 'child': 'catalytic activity'},
#  {'parent': 'molecular_function', 'child': 'membrane transport modulator'},
#  {'parent': 'catalytic activity', 'child': 'DNA polymerase activity'},
#  {'parent': 'catalytic activity', 'child': 'effective catalytic rate'},
#  {'parent': 'generically dependent continuant',
#   'child': 'specifically dependent continuant'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'information content entity'},
#  {'parent': 'specifically dependent continuant', 'child': 'molecular quality'},
#  {'parent': 'specifically dependent continuant', 'child': 'process profile'},
#  {'parent': 'specifically dependent continuant', 'child': 'reaction property'},
#  {'parent': 'process profile', 'child': 'concentration profile'},
#  {'parent': 'process profile',
#   'child': 'material flow profile in synthesis process'},
#  {'parent': 'process profile', 'child': 'quality process profile'},
#  {'parent': 'process profile', 'child': 'reaction process profile'},
#  {'parent': 'process profile', 'child': 'reaction rate profile'},
#  {'parent': 'process profile', 'child': 'stir rate profile'},
#  {'parent': 'process profile',
#   'child': 'temperature profile in synthesis process'},
#  {'parent': 'reaction property', 'child': 'kinetic reaction property'},
#  {'parent': 'reaction property', 'child': 'redox reaction property'},
#  {'parent': 'reaction property', 'child': 'thermodynamic reaction property'},
#  {'parent': 'kinetic reaction property', 'child': 'kinetic constant'},
#  {'parent': 'kinetic reaction property', 'child': 'kinetic order'},
#  {'parent': 'kinetic reaction property', 'child': 'reaction rate'},
#  {'parent': 'kinetic constant', 'child': 'exponential time constant'},
#  {'parent': 'kinetic constant', 'child': 'rate constant'},
#  {'parent': 'rate constant', 'child': 'pre-exponential factor'},
#  {'parent': 'temporal measure', 'child': 'half-life'},
#  {'parent': 'half-life', 'child': 'half-life of an exponential decay'},
#  {'parent': 'kinetic order', 'child': 'overall reaction order'},
#  {'parent': 'kinetic order', 'child': 'partial rate order'},
#  {'parent': 'redox reaction property', 'child': 'redox potential change'},
#  {'parent': 'thermodynamic reaction property',
#   'child': 'Gibbs free energy change'},
#  {'parent': 'thermodynamic reaction property',
#   'child': 'Gibbs free energy of activation'},
#  {'parent': 'information content entity', 'child': 'data item'},
#  {'parent': 'information content entity',
#   'child': 'directive information entity'},
#  {'parent': 'information content entity', 'child': 'plan specification'},
#  {'parent': 'data item', 'child': 'calculated datum'},
#  {'parent': 'data item', 'child': 'data about an ontology part'},
#  {'parent': 'data item', 'child': 'data set'},
#  {'parent': 'data item', 'child': 'document'},
#  {'parent': 'data item', 'child': 'identifier'},
#  {'parent': 'data item', 'child': 'measurement datum'},
#  {'parent': 'data item', 'child': 'process chemistry datum'},
#  {'parent': 'data item', 'child': 'symbol'},
#  {'parent': 'data item', 'child': 'textual entity'},
#  {'parent': 'data set',
#   'child': 'data set of predicted values according to fitted curve'},
#  {'parent': 'document', 'child': 'batch manufacturing record'},
#  {'parent': 'document', 'child': 'bill of materials'},
#  {'parent': 'document', 'child': 'certificate of analysis'},
#  {'parent': 'document', 'child': 'chemical drawing'},
#  {'parent': 'document', 'child': 'common technical document'},
#  {'parent': 'document', 'child': 'document part'},
#  {'parent': 'document', 'child': 'ICH Guideline'},
#  {'parent': 'document', 'child': 'laboratory notebook'},
#  {'parent': 'document', 'child': 'master formula record'},
#  {'parent': 'document', 'child': 'product filing documentation'},
#  {'parent': 'document', 'child': 'synthesis flow chart'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.1.1 Nomenclature'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.1.2 Structure'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.1.3 General Properties'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.2.1 Manufacturers'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.2.2 Description of Manufacturing Process and Process Controls'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.2.3 Control of Materials'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.2.4 Controls of Critical Steps and Intermediates'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.3.1 Elucidation of Structure and other Characteristics'},
#  {'parent': 'common technical document',
#   'child': 'CTA Section 3.2.S.3.2 Impurities'},
#  {'parent': 'document part', 'child': 'CTA Section 3.2.S.1.1 Nomenclature'},
#  {'parent': 'document part', 'child': 'CTA Section 3.2.S.1.2 Structure'},
#  {'parent': 'document part',
#   'child': 'CTA Section 3.2.S.1.3 General Properties'},
#  {'parent': 'document part', 'child': 'CTA Section 3.2.S.2.1 Manufacturers'},
#  {'parent': 'document part',
#   'child': 'CTA Section 3.2.S.2.2 Description of Manufacturing Process and Process Controls'},
#  {'parent': 'document part',
#   'child': 'CTA Section 3.2.S.2.3 Control of Materials'},
#  {'parent': 'document part',
#   'child': 'CTA Section 3.2.S.2.4 Controls of Critical Steps and Intermediates'},
#  {'parent': 'document part',
#   'child': 'CTA Section 3.2.S.3.1 Elucidation of Structure and other Characteristics'},
#  {'parent': 'document part', 'child': 'CTA Section 3.2.S.3.2 Impurities'},
#  {'parent': 'product filing documentation',
#   'child': 'process chemistry filing'},
#  {'parent': 'ICH Guideline',
#   'child': 'ICH M7 Assessment and Control of DNA Reactive (Mutagenic) Impurities in Pharmaceuticals To Limit Potential Carcinogenic Risk'},
#  {'parent': 'ICH Guideline',
#   'child': 'ICH Q11 Guidance for Development and Manufacture of Drug Substances'},
#  {'parent': 'ICH Guideline',
#   'child': 'ICH Q3A Impurities in New Drug Substances'},
#  {'parent': 'ICH Guideline', 'child': 'ICH Q3C Residual Solvents'},
#  {'parent': 'ICH Guideline',
#   'child': 'ICH Q3D Guidance for Elemental Impurities'},
#  {'parent': 'ICH Guideline',
#   'child': 'ICH Q6A Specifications: Test Procedures and Acceptance Criteria for Chemical Substances'},
#  {'parent': 'ICH Guideline',
#   'child': 'Q7 Good Manufacturing Practice Guide for Active Pharmaceutical Ingredients'},
#  {'parent': 'identifier', 'child': 'centrally registered identifier'},
#  {'parent': 'identifier', 'child': 'chemical abstracts number'},
#  {'parent': 'identifier',
#   'child': 'laboratory notebook experiment identifier'},
#  {'parent': 'centrally registered identifier registry',
#   'child': 'centrally registered identifier'},
#  {'parent': 'centrally registered identifier',
#   'child': 'centrally registered identifier symbol'},
#  {'parent': 'symbol', 'child': 'centrally registered identifier symbol'},
#  {'parent': 'measurement datum', 'child': 'appearance datum'},
#  {'parent': 'measurement datum', 'child': 'pressure measurement'},
#  {'parent': 'measurement datum', 'child': 'rate measurement datum'},
#  {'parent': 'measurement datum', 'child': 'scalar measurement datum'},
#  {'parent': 'measurement datum', 'child': 'temperature measurement'},
#  {'parent': 'scalar measurement datum', 'child': 'solution pH datum'},
#  {'parent': 'scalar measurement datum', 'child': 'specific rotation datum'},
#  {'parent': 'textual entity', 'child': 'algorithm'},
#  {'parent': 'textual entity', 'child': 'datum label'},
#  {'parent': 'textual entity', 'child': 'equation'},
#  {'parent': 'textual entity', 'child': 'written name'},
#  {'parent': 'algorithm', 'child': 'in-silico modeling'},
#  {'parent': 'in-silico modeling', 'child': 'DEREK Mutagen Prediction'},
#  {'parent': 'in-silico modeling', 'child': 'MCASE Mutagen Prediction'},
#  {'parent': 'in-silico modeling', 'child': 'crystal structure predictions'},
#  {'parent': 'datum label', 'child': 'measurement unit label'},
#  {'parent': 'equation', 'child': 'Arhennius equation'},
#  {'parent': 'equation', 'child': 'rate equation'},
#  {'parent': 'rate equation', 'child': 'graphical rate equation'},
#  {'parent': 'written name', 'child': 'chemical abstracts name'},
#  {'parent': 'written name', 'child': 'international nonproprietary name'},
#  {'parent': 'written name', 'child': 'preferred IUPAC name'},
#  {'parent': 'directive information entity', 'child': 'action specification'},
#  {'parent': 'directive information entity', 'child': 'CQA specification'},
#  {'parent': 'directive information entity',
#   'child': 'critical process parameter specification'},
#  {'parent': 'directive information entity',
#   'child': 'curation status specification'},
#  {'parent': 'directive information entity',
#   'child': 'objective specification'},
#  {'parent': 'directive information entity',
#   'child': 'obsolescence reason specification'},
#  {'parent': 'directive information entity',
#   'child': 'process profile specification'},
#  {'parent': 'directive information entity', 'child': 'protocol'},
#  {'parent': 'directive information entity', 'child': 'quality specification'},
#  {'parent': 'directive information entity', 'child': 'route specification'},
#  {'parent': 'directive information entity',
#   'child': 'synthetic step specification'},
#  {'parent': 'directive information entity', 'child': 'value specification'},
#  {'parent': 'objective specification', 'child': 'assay objective'},
#  {'parent': 'objective specification', 'child': 'curve fitting objective'},
#  {'parent': 'objective specification',
#   'child': 'data transformation objective'},
#  {'parent': 'objective specification',
#   'child': 'material transformation objective'},
#  {'parent': 'objective specification', 'child': 'purification objective'},
#  {'parent': 'plan specification', 'child': 'study design'},
#  {'parent': 'device', 'child': 'beaker'},
#  {'parent': 'device', 'child': 'Bunsen burner'},
#  {'parent': 'device', 'child': 'chromatography column'},
#  {'parent': 'device', 'child': 'crucible'},
#  {'parent': 'device', 'child': 'environmental control device'},
#  {'parent': 'device', 'child': 'evaporation device'},
#  {'parent': 'device', 'child': 'heating mantle'},
#  {'parent': 'device', 'child': 'transferring device'},
#  {'parent': 'chromatography column', 'child': 'fractionating column'},
#  {'parent': 'fractionating column', 'child': 'Snyder column'},
#  {'parent': 'fractionating column', 'child': 'Vigreux column'},
#  {'parent': 'fractionating column', 'child': 'Widmer column'},
#  {'parent': 'evaporation device', 'child': 'rotary evaporation'},
#  {'parent': 'transferring device', 'child': 'pipette'},
#  {'parent': 'transferring device', 'child': 'syringe pump'},
#  {'parent': 'chemical entity', 'child': 'atom'},
#  {'parent': 'chemical entity', 'child': 'chemical impurity'},
#  {'parent': 'chemical entity', 'child': 'chemical product'},
#  {'parent': 'chemical entity', 'child': 'group'},
#  {'parent': 'chemical entity', 'child': 'ion'},
#  {'parent': 'chemical entity', 'child': 'molecular entity'},
#  {'parent': 'atom', 'child': 'hydrogen atom'},
#  {'parent': 'atom', 'child': 'main group element atom'},
#  {'parent': 'main group element atom', 'child': 'p-block element atom'},
#  {'parent': 'main group element atom', 'child': 's-block element atom'},
#  {'parent': 'p-block element atom', 'child': 'carbon group element atom'},
#  {'parent': 'p-block element atom', 'child': 'chalcogen'},
#  {'parent': 'p-block element atom', 'child': 'nonmetal atom'},
#  {'parent': 'p-block element atom', 'child': 'pnictogen'},
#  {'parent': 'carbon group element atom', 'child': 'carbon atom'},
#  {'parent': 'chalcogen', 'child': 'oxygen atom'},
#  {'parent': 'nonmetal atom', 'child': 'nitrogen atom'},
#  {'parent': 'nonmetal atom', 'child': 'oxygen atom'},
#  {'parent': 'pnictogen', 'child': 'nitrogen atom'},
#  {'parent': 'chemical impurity', 'child': 'persistent organic pollutant'},
#  {'parent': 'chemical product', 'child': 'commercial chemical product'},
#  {'parent': 'chemical product', 'child': 'drug'},
#  {'parent': 'chemical product', 'child': 'Maillard reaction product'},
#  {'parent': 'chemical product', 'child': 'PCR product'},
#  {'parent': 'chemical product', 'child': 'thermal degradation product'},
#  {'parent': 'group', 'child': 'inorganic group'},
#  {'parent': 'group', 'child': 'organic group'},
#  {'parent': 'organic group', 'child': 'acyl group'},
#  {'parent': 'organic group', 'child': 'carboxy group'},
#  {'parent': 'organic group', 'child': 'cyano group'},
#  {'parent': 'organic group', 'child': 'hydroxy group'},
#  {'parent': 'organic group', 'child': 'organic divalent group'},
#  {'parent': 'organic group', 'child': 'organic univalent group'},
#  {'parent': 'organic group', 'child': 'organyl group'},
#  {'parent': 'organic group', 'child': 'oxo group'},
#  {'parent': 'organic group', 'child': 'pseudohalo group'},
#  {'parent': 'ion', 'child': 'anion'},
#  {'parent': 'ion', 'child': 'cation'},
#  {'parent': 'ion', 'child': 'polyatomic ion'},
#  {'parent': 'anion', 'child': 'divalent inorganic anion'},
#  {'parent': 'anion', 'child': 'inorganic anion'},
#  {'parent': 'anion', 'child': 'monoanion'},
#  {'parent': 'anion', 'child': 'organic anion'},
#  {'parent': 'anion', 'child': 'oxoanion'},
#  {'parent': 'anion', 'child': 'polyatomic anion'},
#  {'parent': 'anion', 'child': 'pseudohalide anion'},
#  {'parent': 'inorganic anion', 'child': 'cyanide'},
#  {'parent': 'inorganic anion', 'child': 'divalent inorganic anion'},
#  {'parent': 'inorganic anion', 'child': 'hydroxides'},
#  {'parent': 'inorganic anion', 'child': 'monovalent inorganic anion'},
#  {'parent': 'inorganic anion', 'child': 'oxide'},
#  {'parent': 'cyanides', 'child': 'cyanide'},
#  {'parent': 'divalent inorganic anion', 'child': 'hydridonitrate(2-)'},
#  {'parent': 'monovalent inorganic anion', 'child': 'azanide'},
#  {'parent': 'monoanion', 'child': 'monovalent inorganic anion'},
#  {'parent': 'monoanion', 'child': 'polyatomic monoanion'},
#  {'parent': 'organic anion', 'child': 'carboxylic acid anion'},
#  {'parent': 'carboxylic acid anion', 'child': 'monocarboxylic acid anion'},
#  {'parent': 'monocarboxylic acid anion', 'child': 'amino-acid anion'},
#  {'parent': 'monocarboxylic acid anion', 'child': 'fatty acid anion'},
#  {'parent': 'monocarboxylic acid anion', 'child': 'formate'},
#  {'parent': 'polyatomic anion', 'child': 'polyatomic monoanion'},
#  {'parent': 'cation', 'child': 'inorganic cation'},
#  {'parent': 'cation', 'child': 'onium cation'},
#  {'parent': 'inorganic cation', 'child': 'monovalent inorganic cation'},
#  {'parent': 'monovalent inorganic cation', 'child': 'ammonium'},
#  {'parent': 'onium compound', 'child': 'onium cation'},
#  {'parent': 'polyatomic ion', 'child': 'onium cation'},
#  {'parent': 'polyatomic ion', 'child': 'polyatomic anion'},
#  {'parent': 'molecular entity', 'child': 'carbon group molecular entity'},
#  {'parent': 'molecular entity', 'child': 'chalcogen molecular entity'},
#  {'parent': 'molecular entity', 'child': 'heteroatomic molecular entity'},
#  {'parent': 'molecular entity', 'child': 'hydrogen molecular entity'},
#  {'parent': 'molecular entity', 'child': 'inorganic molecular entity'},
#  {'parent': 'molecular entity', 'child': 'main group molecular entity'},
#  {'parent': 'molecular entity', 'child': 'molecular complex'},
#  {'parent': 'molecular entity', 'child': 'molecule'},
#  {'parent': 'molecular entity', 'child': 'organic molecular entity'},
#  {'parent': 'molecular entity', 'child': 'p-block molecular entity'},
#  {'parent': 'molecular entity', 'child': 'pnictogen molecular entity'},
#  {'parent': 'molecular entity', 'child': 'polyatomic entity'},
#  {'parent': 'molecular entity', 'child': 's-block molecular entity'},
#  {'parent': 'molecular complex', 'child': 'DNA polymerase complex'},
#  {'parent': 'molecular complex',
#   'child': 'alpha-1-microglobulin-Ig alpha complex chromophores'},
#  {'parent': 'molecular complex', 'child': 'protein-containing complex'},
#  {'parent': 'protein-containing complex', 'child': 'DNA polymerase complex'},
#  {'parent': 'molecule', 'child': 'macromolecule'},
#  {'parent': 'molecule', 'child': 'organic molecule'},
#  {'parent': 'macromolecule', 'child': 'nucleic acid'},
#  {'parent': 'macromolecule', 'child': 'polymer'},
#  {'parent': 'macromolecule', 'child': 'protein'},
#  {'parent': 'nucleic acid', 'child': 'deoxyribonucleic acid'},
#  {'parent': 'nucleic acid', 'child': 'ribonucleic acid'},
#  {'parent': 'deoxyribonucleic acid', 'child': 'double-stranded DNA'},
#  {'parent': 'protein', 'child': 'enzyme'},
#  {'parent': 'protein', 'child': 'peptide'},
#  {'parent': 'organic molecular entity', 'child': 'heteroorganic entity'},
#  {'parent': 'organic molecular entity', 'child': 'organic fundamental parent'},
#  {'parent': 'organic molecular entity', 'child': 'organic hydride'},
#  {'parent': 'organic molecular entity', 'child': 'organic ion'},
#  {'parent': 'organic molecular entity', 'child': 'organic molecule'},
#  {'parent': 'organic molecular entity', 'child': 'organochalcogen compound'},
#  {'parent': 'organic molecular entity', 'child': 'organonitrogen compound'},
#  {'parent': 'organic molecular entity', 'child': 'organooxygen compound'},
#  {'parent': 'organic fundamental parent',
#   'child': 'heterocyclic organic fundamental parent'},
#  {'parent': 'heterocyclic organic fundamental parent',
#   'child': 'saturated organic heterocyclic parent'},
#  {'parent': 'saturated organic heterocyclic parent',
#   'child': 'saturated organic heteromonocyclic parent'},
#  {'parent': 'organic ion', 'child': 'organic anion'},
#  {'parent': 'organooxygen compound', 'child': 'alcohol'},
#  {'parent': 'organooxygen compound', 'child': 'ether'},
#  {'parent': 'organooxygen compound', 'child': 'ketone'},
#  {'parent': 'organooxygen compound', 'child': 'organic acid'},
#  {'parent': 'organooxygen compound', 'child': 'organic hydroxy compound'},
#  {'parent': 'organooxygen compound', 'child': 'organic oxo compound'},
#  {'parent': 'organic acid', 'child': 'carboxylic acid'},
#  {'parent': 'organic hydroxy compound', 'child': 'alcohol'},
#  {'parent': 'organic oxo compound', 'child': 'amide'},
#  {'parent': 'organic oxo compound', 'child': 'carboxylic acid'},
#  {'parent': 'organic oxo compound', 'child': 'ketone'},
#  {'parent': 'alcohol', 'child': 'aliphatic alcohol'},
#  {'parent': 'alcohol', 'child': 'fatty alcohol'},
#  {'parent': 'alcohol', 'child': 'methanol'},
#  {'parent': 'alcohol', 'child': 'propan-2-ol'},
#  {'parent': 'aliphatic alcohol', 'child': 'alkyl alcohol'},
#  {'parent': 'alkyl alcohol', 'child': 'primary alcohol'},
#  {'parent': 'alkyl alcohol', 'child': 'secondary alcohol'},
#  {'parent': 'primary alcohol', 'child': 'methanol'},
#  {'parent': 'secondary alcohol', 'child': 'propan-2-ol'},
#  {'parent': 'fatty alcohol', 'child': 'secondary fatty alcohol'},
#  {'parent': 'ether', 'child': 'cyclic ether'},
#  {'parent': 'cyclic ether', 'child': 'dioxane'},
#  {'parent': 'cyclic ether', 'child': 'oxolane'},
#  {'parent': 'dioxanes', 'child': 'dioxane'},
#  {'parent': 'dioxane', 'child': '1,4-dioxane'},
#  {'parent': 'oxolanes', 'child': 'oxolane'},
#  {'parent': 'ketone', 'child': 'dialkyl ketone'},
#  {'parent': 'ketone', 'child': 'ketone body'},
#  {'parent': 'ketone', 'child': 'methyl ketone'},
#  {'parent': 'ketone', 'child': 'propanones'},
#  {'parent': 'dialkyl ketone', 'child': 'butanone'},
#  {'parent': 'butanone', 'child': 'butan-2-one'},
#  {'parent': 'methyl ketone', 'child': 'acetone'},
#  {'parent': 'propanones', 'child': 'acetone'},
#  {'parent': 'carboxylic acid', 'child': 'amino acid'},
#  {'parent': 'carboxylic acid', 'child': 'monocarboxylic acid'},
#  {'parent': 'monocarboxylic acid', 'child': 'fatty acid'},
#  {'parent': 'monocarboxylic acid', 'child': 'formic acid'},
#  {'parent': 'lipid', 'child': 'fatty acid derivative'},
#  {'parent': 'fatty acid derivative', 'child': 'fatty acid'},
#  {'parent': 'organonitrogen compound', 'child': 'amide'},
#  {'parent': 'organonitrogen compound', 'child': 'carbamate'},
#  {'parent': 'organonitrogen compound', 'child': 'nitrile'},
#  {'parent': 'organonitrogen compound', 'child': 'organic amino compound'},
#  {'parent': 'amide', 'child': 'carboxamide'},
#  {'parent': 'carboxamide', 'child': 'monocarboxylic acid amide'},
#  {'parent': 'carboxamide', 'child': 'primary amide'},
#  {'parent': 'monocarboxylic acid amide', 'child': 'formamide'},
#  {'parent': 'formamides', 'child': 'formamide'},
#  {'parent': 'nitrile', 'child': 'aliphatic nitrile'},
#  {'parent': 'aliphatic nitrile', 'child': 'acetonitrile'},
#  {'parent': 'cyclic compound', 'child': 'carbocyclic compound'},
#  {'parent': 'cyclic compound', 'child': 'heterocyclic compound'},
#  {'parent': 'cyclic compound', 'child': 'monocyclic compound'},
#  {'parent': 'organic cyclic compound',
#   'child': 'organic heterocyclic compound'},
#  {'parent': 'organic heterocyclic compound',
#   'child': 'organic heteromonocyclic compound'},
#  {'parent': 'organic heteromonocyclic compound', 'child': 'oxacycle'},
#  {'parent': 'carbocyclic compound', 'child': 'homocyclic compound'},
#  {'parent': 'heterocyclic compound', 'child': 'heteromonocyclic compound'},
#  {'parent': 'heterocyclic compound', 'child': 'oxacycle'},
#  {'parent': 'oxacycle', 'child': 'cyclic ether'},
#  {'parent': 'hydrocarbon', 'child': 'alkylbenzene'},
#  {'parent': 'hydrocarbon', 'child': 'arene'},
#  {'parent': 'hydrocarbon', 'child': 'cyclic hydrocarbon'},
#  {'parent': 'aromatic compound', 'child': 'arene'},
#  {'parent': 'aromatic compound', 'child': 'aromatic annulene'},
#  {'parent': 'aromatic compound', 'child': 'organic aromatic compound'},
#  {'parent': 'organic aromatic compound', 'child': 'arene'},
#  {'parent': 'organic aromatic compound',
#   'child': 'benzenoid aromatic compound'},
#  {'parent': 'arene', 'child': 'alkylbenzene'},
#  {'parent': 'arene', 'child': 'benzene'},
#  {'parent': 'arene', 'child': 'benzenes'},
#  {'parent': 'arene', 'child': 'monocyclic arene'},
#  {'parent': 'benzenoid aromatic compound', 'child': 'benzene'},
#  {'parent': 'benzenes', 'child': 'benzene'},
#  {'parent': 'alkylbenzene', 'child': 'toluene'},
#  {'parent': 'toluenes', 'child': 'toluene'},
#  {'parent': 'cyclic hydrocarbon', 'child': 'annulene'},
#  {'parent': 'cyclic hydrocarbon', 'child': 'monocyclic hydrocarbon'},
#  {'parent': 'annulene', 'child': 'aromatic annulene'},
#  {'parent': 'monocyclic hydrocarbon', 'child': 'monocyclic arene'},
#  {'parent': 'monocyclic arene', 'child': 'benzene'},
#  {'parent': 'oxoacid', 'child': 'carbamic acid'},
#  {'parent': 'oxoacid', 'child': 'carbon oxoacid'},
#  {'parent': 'oxoacid', 'child': 'carboxylic acid'},
#  {'parent': 'oxoacid', 'child': 'imidic acid'},
#  {'parent': 'one-carbon compound', 'child': 'carbon oxoacid'},
#  {'parent': 'one-carbon compound', 'child': 'formamide'},
#  {'parent': 'one-carbon compound', 'child': 'formate'},
#  {'parent': 'one-carbon compound', 'child': 'formic acid'},
#  {'parent': 'one-carbon compound', 'child': 'hydrogen cyanide'},
#  {'parent': 'one-carbon compound', 'child': 'hydrogen isocyanide'},
#  {'parent': 'one-carbon compound', 'child': 'methanol'},
#  {'parent': 'one-carbon compound', 'child': 'methoxide'},
#  {'parent': 'oxoacid derivative', 'child': 'carbamate'},
#  {'parent': 'oxoacid derivative', 'child': 'carboxamide'},
#  {'parent': 'oxoacid derivative', 'child': 'oxoanion'},
#  {'parent': 'imidic acid', 'child': 'carboximidic acid'},
#  {'parent': 'carboximidic acid', 'child': 'formimidic acid'},
#  {'parent': 'inorganic molecular entity', 'child': 'inorganic hydride'},
#  {'parent': 'inorganic molecular entity', 'child': 'inorganic ion'},
#  {'parent': 'hydrides', 'child': 'inorganic hydride'},
#  {'parent': 'hydrides', 'child': 'mononuclear parent hydride'},
#  {'parent': 'hydrides', 'child': 'organic hydride'},
#  {'parent': 'inorganic hydride', 'child': 'nitrogen hydride'},
#  {'parent': 'inorganic hydride', 'child': 'pnictogen hydride'},
#  {'parent': 'pnictogen hydride', 'child': 'nitrogen hydride'},
#  {'parent': 'nitrogen hydride', 'child': 'azane'},
#  {'parent': 'azane', 'child': 'ammonia'},
#  {'parent': 'hydracid', 'child': 'hydrogen cyanide'},
#  {'parent': 'hydracid', 'child': 'hydrogen isocyanide'},
#  {'parent': 'volatile organic compound', 'child': '1,4-dioxane'},
#  {'parent': 'volatile organic compound', 'child': 'acetone'},
#  {'parent': 'volatile organic compound', 'child': 'acetonitrile'},
#  {'parent': 'volatile organic compound', 'child': 'benzene'},
#  {'parent': 'volatile organic compound', 'child': 'butan-2-one'},
#  {'parent': 'volatile organic compound', 'child': 'methanol'},
#  {'parent': 'volatile organic compound', 'child': 'propan-2-ol'},
#  {'parent': 'volatile organic compound', 'child': 'toluene'},
#  {'parent': 'unit cell', 'child': 'cubic unit cell'},
#  {'parent': 'unit cell', 'child': 'orthorhombic unit cell'},
#  {'parent': 'unit cell', 'child': 'tetragonal unit cell'},
#  {'parent': 'unit cell', 'child': 'triclinic unit cell'},
#  {'parent': 'unit cell', 'child': 'trigonal unit cell'},
#  {'parent': 'purge factor', 'child': 'assessed ionisability purge factor'},
#  {'parent': 'purge factor', 'child': 'assessed reactivity purge factor'},
#  {'parent': 'purge factor', 'child': 'assessed solubility purge factor'},
#  {'parent': 'purge factor', 'child': 'assessed volatility purge factor'},
#  {'parent': 'purge factor', 'child': 'overall assessed purge factor'},
#  {'parent': 'PCR product', 'child': 'amplified DNA'},
#  {'parent': 'role', 'child': 'chemical role'},
#  {'parent': 'role', 'child': 'biological role'},
#  {'parent': 'role', 'child': 'application'},
#  {'parent': 'role', 'child': 'evaluant role'},
#  {'parent': 'role', 'child': 'aetiopathogenetic role'},
#  {'parent': 'chemical role', 'child': 'reagent role'},
#  {'parent': 'chemical role', 'child': 'photochemical role'},
#  {'parent': 'chemical role', 'child': 'antisolvent role'},
#  {'parent': 'chemical role', 'child': 'mother liquor role'},
#  {'parent': 'chemical role', 'child': 'precipitate role'},
#  {'parent': 'chemical role', 'child': 'seed role'},
#  {'parent': 'chemical role', 'child': 'reaction intermediate'},
#  {'parent': 'biological role', 'child': 'biochemical role'},
#  {'parent': 'biological role', 'child': 'biophysical role'},
#  {'parent': 'biological role', 'child': 'pharmacological role'},
#  {'parent': 'biological role', 'child': 'physiological role'},
#  {'parent': 'biochemical role', 'child': 'photobiochemical role'},
#  {'parent': 'biochemical role', 'child': 'nucleic acid template role'},
#  {'parent': 'evaluant role', 'child': 'reference substance role'},
#  {'parent': 'application', 'child': 'fuel'},
#  {'parent': 'application', 'child': 'fuel additive'},
#  {'parent': 'application', 'child': 'refrigerant'},
#  {'parent': 'application', 'child': 'ultraviolet filter'},
#  {'parent': 'application', 'child': 'pharmaceutical'},
#  {'parent': 'application', 'child': 'film-forming compound'},
#  {'parent': 'acid', 'child': 'Bronsted acid'},
#  {'parent': 'acid', 'child': 'Lewis acid'},
#  {'parent': 'acid', 'child': 'inorganic acid'},
#  {'parent': 'base', 'child': 'Bronsted base'},
#  {'parent': 'base', 'child': 'Lewis base'},
#  {'parent': 'inhibitor', 'child': 'enzyme inhibitor'},
#  {'parent': 'inhibitor', 'child': 'electron-transport chain inhibitor'},
#  {'parent': 'inhibitor', 'child': 'pathway inhibitor'},
#  {'parent': 'inhibitor', 'child': 'corrosion inhibitor'},
#  {'parent': 'electron-transport chain inhibitor',
#   'child': 'respiratory-chain inhibitor'},
#  {'parent': 'respiratory-chain inhibitor',
#   'child': 'mitochondrial respiratory-chain inhibitor'},
#  {'parent': 'enzyme inhibitor', 'child': 'EC 1.* (oxidoreductase) inhibitor'},
#  {'parent': 'EC 1.* (oxidoreductase) inhibitor',
#   'child': 'EC 1.9.* (oxidoreductase acting on donor heme group) inhibitor'},
#  {'parent': 'EC 1.9.* (oxidoreductase acting on donor heme group) inhibitor',
#   'child': 'EC 1.9.3.* (oxidoreductase acting on donor heme group, oxygen as acceptor) inhibitor'},
#  {'parent': 'EC 1.9.3.* (oxidoreductase acting on donor heme group, oxygen as acceptor) inhibitor',
#   'child': 'EC 1.9.3.1 (cytochrome c oxidase) inhibitor'},
#  {'parent': 'enzyme inhibitor', 'child': 'EC 3.* (hydrolase) inhibitor'},
#  {'parent': 'EC 3.* (hydrolase) inhibitor',
#   'child': 'EC 3.5.* (hydrolases acting on non-peptide C-N bonds) inhibitor'},
#  {'parent': 'EC 3.5.* (hydrolases acting on non-peptide C-N bonds) inhibitor',
#   'child': 'EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor'},
#  {'parent': 'solvent', 'child': 'polar solvent'},
#  {'parent': 'solvent', 'child': 'non-polar solvent'},
#  {'parent': 'solvent', 'child': 'protic solvent'},
#  {'parent': 'solvent', 'child': 'aprotic solvent'},
#  {'parent': 'polar solvent', 'child': 'protic solvent'},
#  {'parent': 'polar solvent', 'child': 'polar aprotic solvent'},
#  {'parent': 'aprotic solvent', 'child': 'polar aprotic solvent'},
#  {'parent': 'protic solvent', 'child': 'amphiprotic solvent'},
#  {'parent': 'protic solvent', 'child': 'protophilic solvent'},
#  {'parent': 'reagent', 'child': 'oxidising agent'},
#  {'parent': 'reagent', 'child': 'reducing agent'},
#  {'parent': 'reagent', 'child': 'electrophilic reagent'},
#  {'parent': 'reagent', 'child': 'nucleophilic reagent'},
#  {'parent': 'reagent', 'child': 'deaminating agent'},
#  {'parent': 'reducing agent', 'child': 'antioxidant'},
#  {'parent': 'donor', 'child': 'electron donor'},
#  {'parent': 'donor', 'child': 'acyl donor'},
#  {'parent': 'donor', 'child': 'nitric oxide donor'},
#  {'parent': 'electron donor', 'child': 'hydrogen donor'},
#  {'parent': 'acceptor', 'child': 'electron acceptor'},
#  {'parent': 'electron acceptor', 'child': 'hydrogen acceptor'},
#  {'parent': 'ligand', 'child': 'chelator'},
#  {'parent': 'ligand', 'child': 'ionophore'},
#  {'parent': 'chelator', 'child': 'iron chelator'},
#  {'parent': 'chelator', 'child': 'copper chelator'},
#  {'parent': 'chelator', 'child': 'sequestrant'},
#  {'parent': 'iron chelator', 'child': 'iron(2+) chelator'},
#  {'parent': 'iron chelator', 'child': 'iron(3+) chelator'},
#  {'parent': 'iron chelator', 'child': 'siderophore'},
#  {'parent': 'siderophore', 'child': 'phytosiderophore'},
#  {'parent': 'siderophore', 'child': 'sideramine'},
#  {'parent': 'ionophore', 'child': 'iron ionophore'},
#  {'parent': 'surfactant', 'child': 'detergent'},
#  {'parent': 'surfactant', 'child': 'emulsifier'},
#  {'parent': 'surfactant', 'child': 'nonionic surfactant'},
#  {'parent': 'surfactant', 'child': 'bolaamphiphile'},
#  {'parent': 'emulsifier', 'child': 'food emulsifier'},
#  {'parent': 'food component', 'child': 'food additive'},
#  {'parent': 'food component', 'child': 'nutrient'},
#  {'parent': 'food component', 'child': 'environmental food contaminant'},
#  {'parent': 'food additive', 'child': 'food emulsifier'},
#  {'parent': 'food additive', 'child': 'food antioxidant'},
#  {'parent': 'food additive', 'child': 'food preservative'},
#  {'parent': 'food additive', 'child': 'sequestrant'},
#  {'parent': 'antioxidant', 'child': 'food antioxidant'},
#  {'parent': 'environmental contaminant',
#   'child': 'environmental food contaminant'},
#  {'parent': 'environmental contaminant', 'child': 'greenhouse gas'},
#  {'parent': 'pharmaceutical', 'child': 'drug'},
#  {'parent': 'poison', 'child': 'neurotoxin'},
#  {'parent': 'poison', 'child': 'hepatotoxic agent'},
#  {'parent': 'impurity', 'child': 'mutagenic impurity'},
#  {'parent': 'impurity', 'child': 'residual solvent impurity'},
#  {'parent': 'buffer', 'child': "Good's buffer substance"},
#  {'parent': 'protective agent', 'child': 'neuroprotective agent'},
#  {'parent': 'specifically dependent continuant', 'child': 'quality'},
#  {'parent': 'quality', 'child': 'bulk substance quality'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'bulk substance quality'},
#  {'parent': 'quality', 'child': 'molecular quality'},
#  {'parent': 'specifically dependent continuant', 'child': 'molecular quality'},
#  {'parent': 'quality', 'child': 'unit cell quality'},
#  {'parent': 'specifically dependent continuant', 'child': 'unit cell quality'},
#  {'parent': 'quality', 'child': 'symmetry'},
#  {'parent': 'specifically dependent continuant', 'child': 'symmetry'},
#  {'parent': 'quality', 'child': 'length'},
#  {'parent': 'specifically dependent continuant', 'child': 'length'},
#  {'parent': 'quality', 'child': 'mass'},
#  {'parent': 'specifically dependent continuant', 'child': 'mass'},
#  {'parent': 'quality', 'child': 'solubility'},
#  {'parent': 'specifically dependent continuant', 'child': 'solubility'},
#  {'parent': 'quality', 'child': 'AFQ_0000168'},
#  {'parent': 'specifically dependent continuant', 'child': 'AFQ_0000168'},
#  {'parent': 'quality', 'child': 'concentration of'},
#  {'parent': 'specifically dependent continuant', 'child': 'concentration of'},
#  {'parent': 'quality', 'child': 'flow rate'},
#  {'parent': 'specifically dependent continuant', 'child': 'flow rate'},
#  {'parent': 'quality', 'child': 'critical quality attribute'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'critical quality attribute'},
#  {'parent': 'bulk substance quality', 'child': 'crystalline state'},
#  {'parent': 'quality', 'child': 'crystalline state'},
#  {'parent': 'specifically dependent continuant', 'child': 'crystalline state'},
#  {'parent': 'bulk substance quality', 'child': 'morphology'},
#  {'parent': 'quality', 'child': 'morphology'},
#  {'parent': 'specifically dependent continuant', 'child': 'morphology'},
#  {'parent': 'morphology', 'child': 'habit'},
#  {'parent': 'bulk substance quality', 'child': 'habit'},
#  {'parent': 'quality', 'child': 'habit'},
#  {'parent': 'specifically dependent continuant', 'child': 'habit'},
#  {'parent': 'bulk substance quality', 'child': 'X-Ray diffractivity'},
#  {'parent': 'quality', 'child': 'X-Ray diffractivity'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'X-Ray diffractivity'},
#  {'parent': 'bulk substance quality', 'child': 'AFQ_0000279'},
#  {'parent': 'quality', 'child': 'AFQ_0000279'},
#  {'parent': 'specifically dependent continuant', 'child': 'AFQ_0000279'},
#  {'parent': 'molecular quality', 'child': 'chemical structure'},
#  {'parent': 'quality', 'child': 'chemical structure'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'chemical structure'},
#  {'parent': 'molecular quality', 'child': 'molecular formula'},
#  {'parent': 'quality', 'child': 'molecular formula'},
#  {'parent': 'specifically dependent continuant', 'child': 'molecular formula'},
#  {'parent': 'symmetry', 'child': 'point symmetry'},
#  {'parent': 'quality', 'child': 'point symmetry'},
#  {'parent': 'specifically dependent continuant', 'child': 'point symmetry'},
#  {'parent': 'symmetry', 'child': 'space group'},
#  {'parent': 'quality', 'child': 'space group'},
#  {'parent': 'specifically dependent continuant', 'child': 'space group'},
#  {'parent': 'symmetry', 'child': 'AFQ_0000250'},
#  {'parent': 'quality', 'child': 'AFQ_0000250'},
#  {'parent': 'specifically dependent continuant', 'child': 'AFQ_0000250'},
#  {'parent': 'point symmetry', 'child': 'centrosymmetric point symmetry'},
#  {'parent': 'symmetry', 'child': 'centrosymmetric point symmetry'},
#  {'parent': 'quality', 'child': 'centrosymmetric point symmetry'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'centrosymmetric point symmetry'},
#  {'parent': 'point symmetry', 'child': 'non-centrosymmetric point symmetry'},
#  {'parent': 'symmetry', 'child': 'non-centrosymmetric point symmetry'},
#  {'parent': 'quality', 'child': 'non-centrosymmetric point symmetry'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'non-centrosymmetric point symmetry'},
#  {'parent': 'non-centrosymmetric point symmetry',
#   'child': 'enantiomorphic point symmetry'},
#  {'parent': 'point symmetry', 'child': 'enantiomorphic point symmetry'},
#  {'parent': 'symmetry', 'child': 'enantiomorphic point symmetry'},
#  {'parent': 'quality', 'child': 'enantiomorphic point symmetry'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'enantiomorphic point symmetry'},
#  {'parent': 'non-centrosymmetric point symmetry',
#   'child': 'polar point symmetry'},
#  {'parent': 'point symmetry', 'child': 'polar point symmetry'},
#  {'parent': 'symmetry', 'child': 'polar point symmetry'},
#  {'parent': 'quality', 'child': 'polar point symmetry'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'polar point symmetry'},
#  {'parent': 'non-centrosymmetric point symmetry',
#   'child': 'non-centrosymmetric achiral symmetry'},
#  {'parent': 'point symmetry', 'child': 'non-centrosymmetric achiral symmetry'},
#  {'parent': 'symmetry', 'child': 'non-centrosymmetric achiral symmetry'},
#  {'parent': 'quality', 'child': 'non-centrosymmetric achiral symmetry'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'non-centrosymmetric achiral symmetry'},
#  {'parent': 'unit cell', 'child': 'hexagonal unit cell'},
#  {'parent': 'unit cell', 'child': 'monoclinic unit cell'},
#  {'parent': 'unit cell', 'child': 'AFQ_0000256'},
#  {'parent': 'unit cell quality', 'child': 'unit cell Z value'},
#  {'parent': 'quality', 'child': 'unit cell Z value'},
#  {'parent': 'specifically dependent continuant', 'child': 'unit cell Z value'},
#  {'parent': 'unit cell quality', 'child': 'AFQ_0000111'},
#  {'parent': 'quality', 'child': 'AFQ_0000111'},
#  {'parent': 'specifically dependent continuant', 'child': 'AFQ_0000111'},
#  {'parent': 'unit cell quality', 'child': "unit cell Z' value"},
#  {'parent': 'quality', 'child': "unit cell Z' value"},
#  {'parent': 'specifically dependent continuant',
#   'child': "unit cell Z' value"},
#  {'parent': 'unit cell quality', 'child': 'unit cell crystal density'},
#  {'parent': 'quality', 'child': 'unit cell crystal density'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'unit cell crystal density'},
#  {'parent': 'unit cell quality', 'child': 'AFQ_0000115'},
#  {'parent': 'quality', 'child': 'AFQ_0000115'},
#  {'parent': 'specifically dependent continuant', 'child': 'AFQ_0000115'},
#  {'parent': 'unit cell quality', 'child': 'unit cell volume'},
#  {'parent': 'quality', 'child': 'unit cell volume'},
#  {'parent': 'specifically dependent continuant', 'child': 'unit cell volume'},
#  {'parent': 'unit cell quality', 'child': 'unit cell a-axis length'},
#  {'parent': 'length', 'child': 'unit cell a-axis length'},
#  {'parent': 'quality', 'child': 'unit cell a-axis length'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'unit cell a-axis length'},
#  {'parent': 'unit cell quality', 'child': 'unit cell b-axis length'},
#  {'parent': 'length', 'child': 'unit cell b-axis length'},
#  {'parent': 'quality', 'child': 'unit cell b-axis length'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'unit cell b-axis length'},
#  {'parent': 'unit cell quality', 'child': 'unit cell c-axis length'},
#  {'parent': 'length', 'child': 'unit cell c-axis length'},
#  {'parent': 'quality', 'child': 'unit cell c-axis length'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'unit cell c-axis length'},
#  {'parent': 'unit cell quality', 'child': 'unit cell alpha internal angle'},
#  {'parent': 'quality', 'child': 'unit cell alpha internal angle'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'unit cell alpha internal angle'},
#  {'parent': 'unit cell quality', 'child': 'unit cell beta internal angle'},
#  {'parent': 'quality', 'child': 'unit cell beta internal angle'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'unit cell beta internal angle'},
#  {'parent': 'unit cell quality', 'child': 'unit cell gamma internal angle'},
#  {'parent': 'quality', 'child': 'unit cell gamma internal angle'},
#  {'parent': 'specifically dependent continuant',
#   'child': 'unit cell gamma internal angle'},
#  {'parent': 'metabolite', 'child': 'eukaryotic metabolite'},
#  {'parent': 'metabolite', 'child': 'prokaryotic metabolite'},
#  {'parent': 'metabolite', 'child': 'animal metabolite'},
#  {'parent': 'metabolite', 'child': 'fungal metabolite'},
#  {'parent': 'metabolite', 'child': 'bacterial metabolite'},
#  {'parent': 'metabolite', 'child': 'mammalian metabolite'},
#  {'parent': 'metabolite', 'child': 'Saccharomyces cerevisiae metabolite'},
#  {'parent': 'metabolite', 'child': 'human metabolite'},
#  {'parent': 'metabolite', 'child': 'mouse metabolite'},
#  {'parent': 'metabolite', 'child': 'Escherichia coli metabolite'},
#  {'parent': 'metabolite', 'child': 'Mycoplasma genitalium metabolite'},
#  {'parent': 'eukaryotic metabolite', 'child': 'animal metabolite'},
#  {'parent': 'eukaryotic metabolite', 'child': 'fungal metabolite'},
#  {'parent': 'eukaryotic metabolite', 'child': 'mammalian metabolite'},
#  {'parent': 'eukaryotic metabolite',
#   'child': 'Saccharomyces cerevisiae metabolite'},
#  {'parent': 'eukaryotic metabolite', 'child': 'human metabolite'},
#  {'parent': 'eukaryotic metabolite', 'child': 'mouse metabolite'},
#  {'parent': 'prokaryotic metabolite', 'child': 'bacterial metabolite'},
#  {'parent': 'prokaryotic metabolite', 'child': 'Escherichia coli metabolite'},
#  {'parent': 'prokaryotic metabolite',
#   'child': 'Mycoplasma genitalium metabolite'},
#  {'parent': 'animal metabolite', 'child': 'mammalian metabolite'},
#  {'parent': 'animal metabolite', 'child': 'human metabolite'},
#  {'parent': 'animal metabolite', 'child': 'mouse metabolite'},
#  {'parent': 'fungal metabolite',
#   'child': 'Saccharomyces cerevisiae metabolite'},
#  {'parent': 'bacterial metabolite', 'child': 'Escherichia coli metabolite'},
#  {'parent': 'bacterial metabolite',
#   'child': 'Mycoplasma genitalium metabolite'},
#  {'parent': 'mammalian metabolite', 'child': 'human metabolite'},
#  {'parent': 'mammalian metabolite', 'child': 'mouse metabolite'},
#  {'parent': 'route specification',
#   'child': 'GMP specification of synthetic process'},
#  {'parent': 'centrifugation', 'child': 'preparative centrifugation'},
#  {'parent': 'centrifugation', 'child': 'sequential centrifugation'},
#  {'parent': 'centrifugation', 'child': 'differential centrifugation'},
#  {'parent': 'centrifugation', 'child': 'low-speed centrifugation'},
#  {'parent': 'preparative centrifugation',
#   'child': 'differential centrifugation'},
#  {'parent': 'sequential centrifugation',
#   'child': 'differential centrifugation'},
#  {'parent': 'differential centrifugation',
#   'child': 'low-speed centrifugation'},
#  {'parent': 'enzymatic amplification', 'child': 'polymerase chain reaction'},
#  {'parent': 'condensor', 'child': 'Allihn condenser'},
#  {'parent': 'condensor', 'child': 'Davies condenser'},
#  {'parent': 'condensor', 'child': 'Dimroth condenser'},
#  {'parent': 'condensor', 'child': 'Frederichs condensor'},
#  {'parent': 'condensor', 'child': 'Graham condensor'},
#  {'parent': 'condensor', 'child': 'Liebig condenser'},
#  {'parent': 'condensor', 'child': 'coil condenser'},
#  {'parent': 'condensor', 'child': 'cold finger'},
#  {'parent': 'coil condenser', 'child': 'Graham condensor'},
#  {'parent': 'coil condenser', 'child': 'Dimroth condenser'},
#  {'parent': 'flask', 'child': 'Erlenmeyer flask'},
#  {'parent': 'flask', 'child': 'round bottom flask'},
#  {'parent': 'flask', 'child': 'volumetric flask'},
#  {'parent': 'product approval milestone',
#   'child': 'drug product approval milestone'},
#  {'parent': 'product filing milestone',
#   'child': 'drug product filing milestone'},
#  {'parent': 'integral kinetic measurement', 'child': 'method of flooding'},
#  {'parent': 'chromatography', 'child': 'adsorption chromatography'},
#  {'parent': 'chromatography', 'child': 'affinity chromatography'},
#  {'parent': 'chromatography', 'child': 'column chromatography'},
#  {'parent': 'chromatography', 'child': 'displacement chromatography'},
#  {'parent': 'column chromatography', 'child': 'adsorption chromatography'},
#  {'parent': 'column chromatography', 'child': 'affinity chromatography'},
#  {'parent': 'column chromatography', 'child': 'displacement chromatography'},
#  {'parent': 'animal metabolite', 'child': 'mammalian metabolite'},
#  {'parent': 'supercritical drying',
#   'child': 'supercritical carbon dioxide drying'},
#  {'parent': 'route related process',
#   'child': 'route development optimization'},
#  {'parent': 'route related process', 'child': 'route scouting'},
#  {'parent': 'route related process', 'child': 'route selection'},
#  {'parent': 'antimicrobial agent', 'child': 'antibacterial agent'},
#  {'parent': 'synthesis reaction time', 'child': 'induction period'},
#  {'parent': 'residual solvent impurity', 'child': 'ICH Q6A Class 1 Solvent'},
#  {'parent': 'residual solvent impurity', 'child': 'ICH Q6A Class 2 Solvent'},
#  {'parent': 'residual solvent impurity', 'child': 'ICH Q6A Class 3 Solvent'},
#  {'parent': 'vacuum distillation', 'child': 'molecular distillation'},
#  {'parent': 'organic divalent group', 'child': 'carbonyl group'},
#  {'parent': 'organodiyl group', 'child': 'carbonyl group'},
#  {'parent': 'acyl group', 'child': 'carbamoyl group'},
#  {'parent': 'acyl group', 'child': 'carboacyl group'},
#  {'parent': 'carboacyl group', 'child': 'univalent carboacyl group'},
#  {'parent': 'acyl group', 'child': 'univalent carboacyl group'},
#  {'parent': 'cholinergic drug', 'child': 'cholinergic antagonist'},
#  {'parent': 'neurotransmitter agent', 'child': 'cholinergic drug'},
#  {'parent': 'pharmacological role', 'child': 'neurotransmitter agent'},
#  {'parent': 'neurotransmitter agent', 'child': 'cholinergic antagonist'},
#  {'parent': 'pharmacological role', 'child': 'cholinergic drug'},
#  {'parent': 'pharmacological role', 'child': 'cholinergic antagonist'},
#  {'parent': 'EC 3.5.1.* (non-peptide linear amide C-N hydrolase) inhibitor',
#   'child': 'EC 3.5.1.4 (amidase) inhibitor'},
#  {'parent': 'AFRL_0000363', 'child': 'AFRL_0000244'},
#  {'parent': 'crystal growth method', 'child': 'Czochralski process'},
#  {'parent': 'crystal growth method', 'child': 'Lely method'},
#  {'parent': 'crystal growth method', 'child': 'Verneuil process'},
#  {'parent': 'value specification', 'child': 'scalar value specification'},
#  {'parent': 'solvate', 'child': 'hydrate'},
#  {'parent': 'catalyst', 'child': 'phase-transfer catalyst'}]

# %%
with open("predictions_c_proco_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

# %%
import json

# Save final_clusters_list to JSON file
with open("final_result_keywords_c_po.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

print("Clusters saved to final_clusters.json ✅")
# Out:
# Clusters saved to final_clusters.json ✅

# %%
with open("_pairs.jsonl", "w", encoding="utf-8") as f:
    for entry in final_result:
        json.dump(entry, f)
        f.write("\n")
