# %%
import json
def load_json(data_path):
    with open(data_path, "r", encoding="utf-8") as file_1:
        data = json.load(file_1)
    return data

# %%
data = load_json("SchemaOrg/train/schemaorg_train_pairs.json")

# %%
len(data), data[:5]
# Out:
# (723,
#  [{'ID': 'TR_56ac8cd6', 'parent': 'Enumeration', 'child': 'WarrantyScope'},
#   {'ID': 'TR_f00fae20', 'parent': 'Text', 'child': 'CssSelectorType'},
#   {'ID': 'TR_0d2dca15',
#    'parent': 'Intangible',
#    'child': 'HealthInsurancePlan'},
#   {'ID': 'TR_e6303dd1', 'parent': 'PerformingGroup', 'child': 'TheaterGroup'},
#   {'ID': 'TR_5a0a6adc', 'parent': 'Event', 'child': 'TheaterEvent'}])

# %%
from collections import defaultdict

class UnionFind:
    def __init__(self):
        self.parent = {}

    def find(self, x):
        # Path compression
        if x != self.parent.setdefault(x, x):
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        self.parent[self.find(x)] = self.find(y)

def build_clusters(relationships):
    uf = UnionFind()
    
    for rel in relationships:
        parent = rel["parent"]
        child = rel["child"]
        uf.union(parent, child)

    clusters = defaultdict(set)
    for term in set([item for rel in relationships for item in (rel["parent"], rel["child"])]):
        root = uf.find(term)
        clusters[root].add(term)

    # Add isolated nodes (no parent/child relationship)
    all_terms = set()
    for rel in relationships:
        all_terms.add(rel["parent"])
        all_terms.add(rel["child"])
    for term in all_terms:
        if term not in uf.parent:
            clusters[term].add(term)

    return list(clusters.values())

# %%
clusters = build_clusters(data)

# %%
len(clusters)
# Out:
# 44

# %%
clusters
# Out:
# [{'3DModel',
#   'APIReference',
#   'AboutPage',
#   'ActionStatusType',
#   'AdultOrientedEnumeration',
#   'AdvertiserContentArticle',
#   'AggregateRating',
#   'AmpStory',
#   'AnatomicalStructure',
#   'ApprovedIndication',
#   'ArchiveComponent',
#   'Article',
#   'Audience',
#   'Audiobook',
#   'BedDetails',
#   'BlogPosting',
#   'BoardingPolicyType',
#   'BoatReservation',
#   'BoatTrip',
#   'Bone',
#   'Book',
#   'BookFormatType',
#   'BookSeries',
#   'BrainStructure',
#   'BroadcastChannel',
#   'BroadcastService',
#   'BusTrip',
#   'BusinessAudience',
#   'BusinessEntityType',
#   'BusinessEvent',
#   'BusinessFunction',
#   'CableOrSatelliteService',
#   'CarUsageType',
#   'Certification',
#   'CertificationStatusEnumeration',
#   'Chapter',
#   'CheckoutPage',
#   'Claim',
#   'Code',
#   'Collection',
#   'CollectionPage',
#   'ComedyEvent',
#   'ComicCoverArt',
#   'ComicIssue',
#   'ComicStory',
#   'CompoundPriceSpecification',
#   'ConstraintNode',
#   'ContactPage',
#   'ContactPoint',
#   'ContactPointOption',
#   'Conversation',
#   'Course',
#   'CourseInstance',
#   'CoverArt',
#   'CreativeWork',
#   'CreativeWorkSeason',
#   'CreativeWorkSeries',
#   'DanceEvent',
#   'DataCatalog',
#   'DataDownload',
#   'DataFeedItem',
#   'DatedMoneySpecification',
#   'DayOfWeek',
#   'DefinedRegion',
#   'DeliveryChargeSpecification',
#   'DeliveryEvent',
#   'DeliveryMethod',
#   'DiagnosticProcedure',
#   'Diet',
#   'DigitalDocument',
#   'DigitalDocumentPermissionType',
#   'DigitalPlatformEnumeration',
#   'DoseSchedule',
#   'Drawing',
#   'DrugClass',
#   'DrugCost',
#   'DrugCostCategory',
#   'DrugLegalStatus',
#   'DrugPrescriptionStatus',
#   'EducationEvent',
#   'EducationalAudience',
#   'EducationalOccupationalCredential',
#   'EducationalOccupationalProgram',
#   'EmployerAggregateRating',
#   'EndorsementRating',
#   'EnergyConsumptionDetails',
#   'EngineSpecification',
#   'EntryPoint',
#   'Enumeration',
#   'Event',
#   'EventAttendanceModeEnumeration',
#   'EventReservation',
#   'EventSeries',
#   'EventStatusType',
#   'ExercisePlan',
#   'ExhibitionEvent',
#   'FAQPage',
#   'Festival',
#   'Flight',
#   'FlightReservation',
#   'FoodEvent',
#   'FoodService',
#   'Game',
#   'GameAvailabilityEnumeration',
#   'GamePlayMode',
#   'GameServerStatus',
#   'GenderType',
#   'GeoCircle',
#   'GeoCoordinates',
#   'GeoShape',
#   'GeospatialGeometry',
#   'GovernmentBenefitsType',
#   'GovernmentPermit',
#   'GovernmentService',
#   'Grant',
#   'Hackathon',
#   'HealthAspectEnumeration',
#   'HealthInsurancePlan',
#   'HealthPlanFormulary',
#   'HowToDirection',
#   'HowToItem',
#   'HowToSection',
#   'HowToStep',
#   'HowToTip',
#   'HowToTool',
#   'HyperTocEntry',
#   'IPTCDigitalSourceEnumeration',
#   'InfectiousAgentClass',
#   'Intangible',
#   'Invoice',
#   'ItemList',
#   'ItemListOrderType',
#   'ItemPage',
#   'JobPosting',
#   'Joint',
#   'LearningResource',
#   'LegalForceStatus',
#   'LegalValueLevel',
#   'Legislation',
#   'LegislationObject',
#   'LifestyleModification',
#   'ListItem',
#   'LiveBlogPosting',
#   'LocationFeatureSpecification',
#   'LodgingReservation',
#   'LymphaticVessel',
#   'Manuscript',
#   'Map',
#   'MaximumDoseSchedule',
#   'MeasurementMethodEnum',
#   'MeasurementTypeEnumeration',
#   'MediaEnumeration',
#   'MediaManipulationRatingEnumeration',
#   'MediaObject',
#   'MediaReviewItem',
#   'MediaSubscription',
#   'MedicalAudience',
#   'MedicalCause',
#   'MedicalCode',
#   'MedicalConditionStage',
#   'MedicalDevice',
#   'MedicalDevicePurpose',
#   'MedicalEntity',
#   'MedicalEnumeration',
#   'MedicalEvidenceLevel',
#   'MedicalGuideline',
#   'MedicalGuidelineContraindication',
#   'MedicalImagingTechnique',
#   'MedicalIndication',
#   'MedicalIntangible',
#   'MedicalObservationalStudyDesign',
#   'MedicalProcedure',
#   'MedicalRiskEstimator',
#   'MedicalRiskFactor',
#   'MedicalRiskScore',
#   'MedicalScholarlyArticle',
#   'MedicalSpecialty',
#   'MedicalStudy',
#   'MedicalTherapy',
#   'MedicalTrial',
#   'MedicalTrialDesign',
#   'MedicalWebPage',
#   'MedicineSystem',
#   'MemberProgram',
#   'Menu',
#   'MenuItem',
#   'MerchantReturnPolicySeasonalOverride',
#   'MobileApplication',
#   'MonetaryAmount',
#   'MonetaryAmountDistribution',
#   'MonetaryGrant',
#   'MovieSeries',
#   'MusicAlbum',
#   'MusicAlbumProductionType',
#   'MusicAlbumReleaseType',
#   'MusicEvent',
#   'MusicPlaylist',
#   'MusicRelease',
#   'MusicReleaseFormatType',
#   'MusicVideoObject',
#   'Observation',
#   'Occupation',
#   'OccupationalExperienceRequirements',
#   'OccupationalTherapy',
#   'OfferCatalog',
#   'OfferShippingDetails',
#   'OpeningHoursSpecification',
#   'OrderItem',
#   'OrderStatus',
#   'OwnershipInfo',
#   'Painting',
#   'PalliativeProcedure',
#   'ParcelDelivery',
#   'ParentAudience',
#   'Patient',
#   'PaymentChargeSpecification',
#   'PaymentMethodType',
#   'PaymentStatusType',
#   'PeopleAudience',
#   'Permit',
#   'Person',
#   'Photograph',
#   'PhysicalActivity',
#   'PhysicalActivityCategory',
#   'PhysicalExam',
#   'Play',
#   'PodcastSeason',
#   'PodcastSeries',
#   'PostalAddress',
#   'Poster',
#   'PresentationDigitalDocument',
#   'PriceComponentTypeEnumeration',
#   'PriceSpecification',
#   'PriceTypeEnumeration',
#   'ProductReturnEnumeration',
#   'ProfilePage',
#   'Property',
#   'PropertyValue',
#   'PsychologicalTreatment',
#   'PublicationIssue',
#   'QAPage',
#   'QuantitativeValue',
#   'QuantitativeValueDistribution',
#   'Quiz',
#   'Quotation',
#   'RadiationTherapy',
#   'RadioBroadcastService',
#   'RadioSeason',
#   'RadioSeries',
#   'Rating',
#   'RefundTypeEnumeration',
#   'Researcher',
#   'Reservation',
#   'ReservationPackage',
#   'ReservationStatusType',
#   'RestrictedDiet',
#   'ReturnFeesEnumeration',
#   'ReturnLabelSourceEnumeration',
#   'ReturnMethodEnumeration',
#   'RsvpResponseType',
#   'SaleEvent',
#   'Schedule',
#   'ScholarlyArticle',
#   'ScreeningEvent',
#   'Sculpture',
#   'SearchResultsPage',
#   'Seat',
#   'Series',
#   'Service',
#   'SheetMusic',
#   'ShippingDeliveryTime',
#   'ShortStory',
#   'SizeGroupEnumeration',
#   'SocialMediaPosting',
#   'SoftwareApplication',
#   'SpeakableSpecification',
#   'Specialty',
#   'SportsEvent',
#   'Statement',
#   'StatisticalVariable',
#   'StatusEnumeration',
#   'StructuredValue',
#   'SuperficialAnatomy',
#   'SurgicalProcedure',
#   'TVSeason',
#   'TVSeries',
#   'TaxiService',
#   'TechArticle',
#   'TelevisionChannel',
#   'TextDigitalDocument',
#   'TheaterEvent',
#   'TherapeuticProcedure',
#   'Ticket',
#   'TierBenefitEnumeration',
#   'TouristTrip',
#   'TrainTrip',
#   'Trip',
#   'TypeAndQuantityNode',
#   'UnitPriceSpecification',
#   'UserBlocks',
#   'UserCheckins',
#   'UserComments',
#   'UserDownloads',
#   'UserInteraction',
#   'UserLikes',
#   'UserPageVisits',
#   'UserPlays',
#   'UserPlusOnes',
#   'UserTweets',
#   'Vein',
#   'Vessel',
#   'VideoGame',
#   'VideoGameSeries',
#   'VirtualLocation',
#   'VisualArtwork',
#   'WarrantyScope',
#   'WearableMeasurementTypeEnumeration',
#   'WearableSizeGroupEnumeration',
#   'WebPage',
#   'WorkBasedProgram'},
#  {'Accommodation',
#   'Apartment',
#   'CampingPitch',
#   'House',
#   'MeetingRoom',
#   'Room',
#   'SingleFamilyResidence',
#   'Suite'},
#  {'AchieveAction',
#   'Action',
#   'ActivateAction',
#   'AllocateAction',
#   'ApplyAction',
#   'AssignAction',
#   'AuthorizeAction',
#   'BookmarkAction',
#   'BorrowAction',
#   'BuyAction',
#   'CheckAction',
#   'ConsumeAction',
#   'ControlAction',
#   'CookAction',
#   'CreateAction',
#   'DeactivateAction',
#   'DepartAction',
#   'DiscoverAction',
#   'DrawAction',
#   'DrinkAction',
#   'EatAction',
#   'ExerciseAction',
#   'FindAction',
#   'GiveAction',
#   'InstallAction',
#   'MoneyTransfer',
#   'MoveAction',
#   'OrderAction',
#   'OrganizeAction',
#   'PaintAction',
#   'PayAction',
#   'PerformAction',
#   'PlayAction',
#   'QuoteAction',
#   'ReadAction',
#   'RejectAction',
#   'ReplaceAction',
#   'ResumeAction',
#   'ReturnAction',
#   'SearchAction',
#   'SellAction',
#   'SuspendAction',
#   'TakeAction',
#   'TieAction',
#   'TipAction',
#   'TrackAction',
#   'TradeAction',
#   'TransferAction',
#   'TravelAction',
#   'UpdateAction',
#   'UseAction',
#   'ViewAction',
#   'WatchAction',
#   'WearAction',
#   'WinAction',
#   'WriteAction'},
#  {'BioChemEntity', 'Protein'},
#  {'Airline',
#   'Airport',
#   'AmusementPark',
#   'AnimalShelter',
#   'Aquarium',
#   'ArchiveOrganization',
#   'Attorney',
#   'AutoPartsStore',
#   'AutoRental',
#   'AutoRepair',
#   'AutoWash',
#   'AutomotiveBusiness',
#   'Bakery',
#   'BarOrPub',
#   'BeautySalon',
#   'BedAndBreakfast',
#   'BikeStore',
#   'BoatTerminal',
#   'BodyOfWater',
#   'BookStore',
#   'BusStation',
#   'BusStop',
#   'CafeOrCoffeeShop',
#   'Campground',
#   'Casino',
#   'Cemetery',
#   'ChildCare',
#   'CivicStructure',
#   'ClothingStore',
#   'CollegeOrUniversity',
#   'ComedyClub',
#   'ComputerStore',
#   'Continent',
#   'ConvenienceStore',
#   'Corporation',
#   'CovidTestingFacility',
#   'Crematorium',
#   'DaySpa',
#   'Dentist',
#   'Distillery',
#   'EducationalOrganization',
#   'ElementarySchool',
#   'EmergencyService',
#   'EmploymentAgency',
#   'EntertainmentBusiness',
#   'EventVenue',
#   'ExerciseGym',
#   'FastFoodRestaurant',
#   'FireStation',
#   'Florist',
#   'FoodEstablishment',
#   'FundingAgency',
#   'FundingScheme',
#   'FurnitureStore',
#   'GardenStore',
#   'GasStation',
#   'GovernmentOffice',
#   'GovernmentOrganization',
#   'GroceryStore',
#   'HairSalon',
#   'HardwareStore',
#   'HealthAndBeautyBusiness',
#   'HealthClub',
#   'HighSchool',
#   'HobbyShop',
#   'HomeGoodsStore',
#   'Hospital',
#   'Hotel',
#   'IndividualPhysician',
#   'InternetCafe',
#   'JewelryStore',
#   'LakeBodyOfWater',
#   'Landform',
#   'LegalService',
#   'Library',
#   'LiquorStore',
#   'LocalBusiness',
#   'LodgingBusiness',
#   'MedicalBusiness',
#   'MedicalClinic',
#   'MedicalOrganization',
#   'MiddleSchool',
#   'Motel',
#   'MotorcycleRepair',
#   'Mountain',
#   'MovieRentalStore',
#   'MovieTheater',
#   'Museum',
#   'MusicGroup',
#   'OceanBodyOfWater',
#   'OfficeEquipmentStore',
#   'OnlineBusiness',
#   'Optician',
#   'Organization',
#   'Park',
#   'ParkingFacility',
#   'PawnShop',
#   'PerformingGroup',
#   'Pharmacy',
#   'Physician',
#   'PhysiciansOffice',
#   'Place',
#   'PoliceStation',
#   'PoliticalParty',
#   'Preschool',
#   'ProfessionalService',
#   'Project',
#   'PublicSwimmingPool',
#   'PublicToilet',
#   'RealEstateAgent',
#   'RecyclingCenter',
#   'ResearchOrganization',
#   'ResearchProject',
#   'Reservoir',
#   'Residence',
#   'Resort',
#   'Restaurant',
#   'RiverBodyOfWater',
#   'School',
#   'SeaBodyOfWater',
#   'SearchRescueOrganization',
#   'ShoeStore',
#   'SkiResort',
#   'SportingGoodsStore',
#   'SportsActivityLocation',
#   'StadiumOrArena',
#   'Store',
#   'SubwayStation',
#   'TattooParlor',
#   'TaxiStand',
#   'TelevisionStation',
#   'TennisComplex',
#   'TheaterGroup',
#   'TireShop',
#   'TouristAttraction',
#   'TouristDestination',
#   'ToyStore',
#   'TrainStation',
#   'TravelAgency',
#   'VacationRental',
#   'VeterinaryCare',
#   'Volcano',
#   'Waterfall',
#   'WholesaleStore',
#   'Winery',
#   'WorkersUnion',
#   'Zoo'},
#  {'Boolean',
#   'CssSelectorType',
#   'DataType',
#   'Date',
#   'DateTime',
#   'PronounceableText',
#   'Text',
#   'Time',
#   'URL'},
#  {'BusOrCoach',
#   'DietarySupplement',
#   'Drug',
#   'Product',
#   'ProductCollection',
#   'ProductGroup',
#   'ProductModel',
#   'SomeProducts',
#   'Substance',
#   'Vehicle'},
#  {'AdministrativeArea', 'City', 'Country', 'SchoolDistrict', 'State'},
#  {'BankAccount',
#   'BrokerageAccount',
#   'CreditCard',
#   'CurrencyConversionService',
#   'DepositAccount',
#   'FinancialProduct',
#   'InvestmentOrDeposit',
#   'LoanOrCredit',
#   'MortgageLoan',
#   'PaymentCard',
#   'PaymentMethod',
#   'PaymentService'},
#  {'SiteNavigationElement',
#   'WPAdBlock',
#   'WPFooter',
#   'WPSideBar',
#   'WebPageElement'},
#  {'Episode', 'RadioEpisode', 'TVEpisode'},
#  {'Electrician',
#   'GeneralContractor',
#   'HVACBusiness',
#   'HomeAndConstructionBusiness',
#   'HousePainter',
#   'MovingCompany',
#   'Plumber',
#   'RoofingContractor'},
#  {'HowTo', 'Recipe'},
#  {'AutomatedTeller',
#   'BankOrCreditUnion',
#   'FinancialService',
#   'InsuranceAgency'},
#  {'AskAction',
#   'CheckInAction',
#   'CheckOutAction',
#   'CommunicateAction',
#   'InformAction',
#   'InteractAction',
#   'InviteAction',
#   'JoinAction',
#   'MarryAction',
#   'ReplyAction',
#   'RsvpAction',
#   'ShareAction',
#   'SubscribeAction'},
#  {'CompleteDataFeed', 'DataFeed', 'Dataset'},
#  {'HealthTopicContent', 'WebContent'},
#  {'Distance', 'Energy', 'Mass', 'Quantity'},
#  {'Clip', 'MovieClip', 'RadioClip', 'TVClip', 'VideoGameClip'},
#  {'ClaimReview', 'EmployerReview', 'Recommendation', 'Review', 'UserReview'},
#  {'MedicalSign', 'VitalSign'},
#  {'EmailMessage', 'Message'},
#  {'CityHall',
#   'Courthouse',
#   'DefenceEstablishment',
#   'Embassy',
#   'GovernmentBuilding',
#   'LegislativeBuilding'},
#  {'BuddhistTemple', 'PlaceOfWorship'},
#  {'SportsOrganization', 'SportsTeam'},
#  {'BedType',
#   'DriveWheelConfigurationValue',
#   'QualitativeValue',
#   'SizeSpecification'},
#  {'Answer', 'Comment', 'CorrectionComment', 'Question'},
#  {'CriticReview', 'ReviewNewsArticle'},
#  {'AggregateOffer', 'Offer', 'OfferForPurchase'},
#  {'ImagingTest', 'MedicalTest'},
#  {'AMRadioChannel', 'FMRadioChannel', 'RadioChannel'},
#  {'VideoObject', 'VideoObjectSnapshot'},
#  {'AddAction', 'InsertAction', 'PrependAction'},
#  {'SizeSystemEnumeration', 'WearableSizeSystemEnumeration'},
#  {'BroadcastEvent', 'OnDemandEvent', 'PublicationEvent'},
#  {'EmployeeRole', 'OrganizationRole', 'Role'},
#  {'EnergyEfficiencyEnumeration', 'EnergyStarEnergyEfficiencyEnumeration'},
#  {'PlanAction', 'ReserveAction', 'ScheduleAction'},
#  {'AssessAction',
#   'ChooseAction',
#   'EndorseAction',
#   'IgnoreAction',
#   'LikeAction',
#   'ReactAction',
#   'ReviewAction'},
#  {'Barcode', 'ImageObject', 'ImageObjectSnapshot'},
#  {'CatholicChurch', 'Church'},
#  {'CategoryCodeSet', 'DefinedTermSet'},
#  {'ComicSeries', 'Periodical'},
#  {'MedicalCondition', 'MedicalSignOrSymptom', 'MedicalSymptom'}]

# %%
# Load a text file in Python
final_content = []
with open("SchemaOrg/test/schemaorg_test_types.txt", "r", encoding="utf-8") as f:
    contents = f.readlines()
    for content in contents:
        final_content.append(content.strip('\n'))


print(contents[:500])  # Print first 500 characters
# Out:
# ['FollowAction\n', 'PreOrderAction\n', 'InteractionCounter\n', 'SoftwareSourceCode\n', 'MedicalRiskCalculator\n', 'InteractAction\n', 'MedicalAudience\n', 'MotorcycleDealer\n', 'OnlineBusiness\n', 'Mosque\n', 'Language\n', 'Order\n', 'Pharmacy\n', 'HotelRoom\n', 'DryCleaningOrLaundry\n', 'Synagogue\n', 'MemberProgramTier\n', 'Consortium\n', 'PublicationVolume\n', 'MediaReview\n', 'RealEstateListing\n', 'IceCreamShop\n', 'Vessel\n', 'Organization\n', 'ChemicalSubstance\n', 'VideoGallery\n', 'MediaGallery\n', 'DisagreeAction\n', 'InvestmentFund\n', 'PlayGameAction\n', 'Locksmith\n', 'SpecialAnnouncement\n', 'EUEnergyEfficiencyEnumeration\n', 'AutoPartsStore\n', 'Message\n', 'ComputerLanguage\n', 'LendAction\n', 'CommentAction\n', 'TouristInformationCenter\n', 'VisualArtsEvent\n', 'Brand\n', 'StructuredValue\n', 'CreateAction\n', 'HealthPlanNetwork\n', 'VoteAction\n', 'Pond\n', 'LearningResource\n', 'MedicalGuidelineRecommendation\n', 'Course\n', 'MapCategoryType\n', 'Service\n', 'Car\n', 'ExercisePlan\n', 'OfferForLease\n', 'ElectronicsStore\n', 'Syllabus\n', 'MedicalCondition\n', 'RadioChannel\n', 'MedicalStudy\n', 'SportsClub\n', 'Movie\n', 'AmpStory\n', 'RepaymentSpecification\n', 'WantAction\n', 'MedicalTestPanel\n', 'Article\n', 'CivicStructure\n', 'MenuSection\n', 'LegislationObject\n', 'Class\n', 'TextObject\n', 'EnergyEfficiencyEnumeration\n', 'Ligament\n', 'WebApplication\n', 'StatisticalPopulation\n', 'CreditCard\n', 'Intangible\n', 'LoanOrCredit\n', 'WebContent\n', 'MoveAction\n', 'InvestmentOrDeposit\n', 'Clip\n', 'PaymentMethod\n', 'AdultEntertainment\n', 'CommunicateAction\n', 'QualitativeValue\n', 'EntertainmentBusiness\n', 'ReportedDoseSchedule\n', 'Action\n', 'Room\n', 'Store\n', 'AdministrativeArea\n', 'MusicVenue\n', 'MovieTheater\n', 'Person\n', 'WebPageElement\n', 'AutoDealer\n', 'RecommendedDoseSchedule\n', 'Vehicle\n', 'TaxiReservation\n', 'OutletStore\n', 'AutoBodyShop\n', 'AddAction\n', 'MedicalSpecialty\n', 'Collection\n', 'AudioObjectSnapshot\n', 'AssessAction\n', 'SatiricalArticle\n', 'MedicalProcedureType\n', 'BroadcastChannel\n', 'MedicalOrganization\n', 'Event\n', 'ProductReturnPolicy\n', 'TVSeason\n', 'DigitalDocument\n', 'OfferItemCondition\n', 'MusicComposition\n', 'MediaObject\n', 'HowToDirection\n', 'Residence\n', 'PerformanceRole\n', 'MedicalClinic\n', 'MedicalContraindication\n', 'ReactAction\n', 'SizeSystemEnumeration\n', 'MedicalIntangible\n', 'BodyOfWater\n', 'HealthAndBeautyBusiness\n', 'PodcastEpisode\n', 'SeekToAction\n', 'MedicalAudienceType\n', 'MobilePhoneStore\n', 'DepartmentStore\n', 'ArriveAction\n', 'MedicalTherapy\n', 'PhysicalExam\n', 'ItemList\n', 'PostalCodeRangeSpecification\n', 'Periodical\n', 'TVSeries\n', 'RVPark\n', 'ChooseAction\n', 'ProgramMembership\n', 'ComicStory\n', 'DownloadAction\n', 'MotorizedBicycle\n', 'Hospital\n', 'FilmAction\n', 'RentalCarReservation\n', 'AutomotiveBusiness\n', 'PropertyValueSpecification\n', 'SendAction\n', 'SoftwareApplication\n', 'ProductCollection\n', 'AgreeAction\n', 'AccountingService\n', 'DanceGroup\n', 'Beach\n', 'ArtGallery\n', 'CollectionPage\n', 'AnatomicalSystem\n', 'OrganizeAction\n', 'ShippingRateSettings\n', 'ItemAvailability\n', 'Muscle\n', 'LibrarySystem\n', 'Book\n', 'ListenAction\n', 'Atlas\n', 'PlaceOfWorship\n', 'RegisterAction\n', 'Demand\n', 'TradeAction\n', 'LodgingBusiness\n', 'DonateAction\n', 'BloodTest\n', 'DataType\n', 'FoodEstablishmentReservation\n', 'DefinedTerm\n', 'PeopleAudience\n', 'Dataset\n', 'MedicalStudyStatus\n', 'HealthPlanCostSharingSpecification\n', 'Episode\n', 'HinduTemple\n', 'Series\n', 'FinancialService\n', 'SportsActivityLocation\n', 'Quantity\n', 'Artery\n', 'DiscussionForumPosting\n', 'FireStation\n', 'RentAction\n', 'DiagnosticLab\n', 'PublicationEvent\n', 'LocalBusiness\n', 'Product\n', 'DefinedTermSet\n', 'HowToTip\n', 'CriticReview\n', 'StadiumOrArena\n', 'MathSolver\n', 'Patient\n', 'ApartmentComplex\n', 'ConsumeAction\n', 'PerformingGroup\n', 'PhysicalTherapy\n', 'ImageGallery\n', ' ...

# %%
len(contents), contents[0]
# Out:
# (359, 'FollowAction\n')

# %%
len(final_content), final_content[0]
# Out:
# (359, 'FollowAction')

# %%
# Step 3: Assign function
from collections import Counter
from tqdm.notebook import tqdm
def assign_term_to_cluster(new_term, clusters):
    new_words = new_term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for term in cluster:
            for word in term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)
    
    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]
    
    if max_score == 0:
        return None  # No match
    return best_cluster_index

# Step 4: Assign all new terms
final_clusters = [set(cluster) for cluster in clusters]  # copy original clusters

for term in tqdm(final_content):
    assigned_idx = assign_term_to_cluster(term, final_clusters)
    if assigned_idx is not None:
        final_clusters[assigned_idx].add(term)
    else:
        # Create new cluster if no match found
        final_clusters.append(set([term]))

# Step 5: Convert to list of lists and return
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

# Display final clusters
for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")
# Out:
#   0%|          | 0/359 [00:00<?, ?it/s]
# Cluster 1: ['3DModel', 'APIReference', 'AboutPage', 'ActionStatusType', 'AdultOrientedEnumeration', 'AdvertiserContentArticle', 'AggregateRating', 'AmpStory', 'AnatomicalStructure', 'ApprovedIndication', 'ArchiveComponent', 'Article', 'Audience', 'Audiobook', 'BedDetails', 'BlogPosting', 'BoardingPolicyType', 'BoatReservation', 'BoatTrip', 'Bone', 'Book', 'BookFormatType', 'BookSeries', 'BrainStructure', 'BroadcastChannel', 'BroadcastService', 'BusTrip', 'BusinessAudience', 'BusinessEntityType', 'BusinessEvent', 'BusinessFunction', 'CableOrSatelliteService', 'CarUsageType', 'Certification', 'CertificationStatusEnumeration', 'Chapter', 'CheckoutPage', 'Claim', 'Code', 'Collection', 'CollectionPage', 'ComedyEvent', 'ComicCoverArt', 'ComicIssue', 'ComicStory', 'CompoundPriceSpecification', 'ConstraintNode', 'ContactPage', 'ContactPoint', 'ContactPointOption', 'Conversation', 'Course', 'CourseInstance', 'CoverArt', 'CreativeWork', 'CreativeWorkSeason', 'CreativeWorkSeries', 'DanceEvent', 'DataCatalog', 'DataDownload', 'DataFeedItem', 'DatedMoneySpecification', 'DayOfWeek', 'DefinedRegion', 'DeliveryChargeSpecification', 'DeliveryEvent', 'DeliveryMethod', 'DiagnosticProcedure', 'Diet', 'DigitalDocument', 'DigitalDocumentPermissionType', 'DigitalPlatformEnumeration', 'DoseSchedule', 'Drawing', 'DrugClass', 'DrugCost', 'DrugCostCategory', 'DrugLegalStatus', 'DrugPrescriptionStatus', 'EducationEvent', 'EducationalAudience', 'EducationalOccupationalCredential', 'EducationalOccupationalProgram', 'EmployerAggregateRating', 'EndorsementRating', 'EnergyConsumptionDetails', 'EngineSpecification', 'EntryPoint', 'Enumeration', 'Event', 'EventAttendanceModeEnumeration', 'EventReservation', 'EventSeries', 'EventStatusType', 'ExercisePlan', 'ExhibitionEvent', 'FAQPage', 'Festival', 'Flight', 'FlightReservation', 'FoodEvent', 'FoodService', 'Game', 'GameAvailabilityEnumeration', 'GamePlayMode', 'GameServerStatus', 'GenderType', 'GeoCircle', 'GeoCoordinates', 'GeoShape', 'GeospatialGeometry', 'GovernmentBenefitsType', 'GovernmentPermit', 'GovernmentService', 'Grant', 'Hackathon', 'HealthAspectEnumeration', 'HealthInsurancePlan', 'HealthPlanFormulary', 'HowToDirection', 'HowToItem', 'HowToSection', 'HowToStep', 'HowToTip', 'HowToTool', 'HyperTocEntry', 'IPTCDigitalSourceEnumeration', 'InfectiousAgentClass', 'Intangible', 'Invoice', 'ItemList', 'ItemListOrderType', 'ItemPage', 'JobPosting', 'Joint', 'LearningResource', 'LegalForceStatus', 'LegalValueLevel', 'Legislation', 'LegislationObject', 'LifestyleModification', 'ListItem', 'LiveBlogPosting', 'LocationFeatureSpecification', 'LodgingReservation', 'LymphaticVessel', 'Manuscript', 'Map', 'MaximumDoseSchedule', 'MeasurementMethodEnum', 'MeasurementTypeEnumeration', 'MediaEnumeration', 'MediaManipulationRatingEnumeration', 'MediaObject', 'MediaReviewItem', 'MediaSubscription', 'MedicalAudience', 'MedicalCause', 'MedicalCode', 'MedicalConditionStage', 'MedicalDevice', 'MedicalDevicePurpose', 'MedicalEntity', 'MedicalEnumeration', 'MedicalEvidenceLevel', 'MedicalGuideline', 'MedicalGuidelineContraindication', 'MedicalImagingTechnique', 'MedicalIndication', 'MedicalIntangible', 'MedicalObservationalStudyDesign', 'MedicalProcedure', 'MedicalRiskEstimator', 'MedicalRiskFactor', 'MedicalRiskScore', 'MedicalScholarlyArticle', 'MedicalSpecialty', 'MedicalStudy', 'MedicalTherapy', 'MedicalTrial', 'MedicalTrialDesign', 'MedicalWebPage', 'MedicineSystem', 'MemberProgram', 'Menu', 'MenuItem', 'MerchantReturnPolicySeasonalOverride', 'MobileApplication', 'MonetaryAmount', 'MonetaryAmountDistribution', 'MonetaryGrant', 'MovieSeries', 'MusicAlbum', 'MusicAlbumProductionType', 'MusicAlbumReleaseType', 'MusicEvent', 'MusicPlaylist', 'MusicRelease', 'MusicReleaseFormatType', 'MusicVideoObject', 'Observation', 'Occupation', 'OccupationalExperienceRequirements', 'OccupationalTherapy', 'OfferCatalog', 'OfferShippingDetails', 'OpeningHoursSpecification', 'OrderItem', 'OrderStatus', 'OwnershipInfo', 'Painting', 'Palliative ...
# Cluster 2: ['Accommodation', 'Apartment', 'CampingPitch', 'House', 'MeetingRoom', 'Room', 'SingleFamilyResidence', 'Suite']
# Cluster 3: ['AchieveAction', 'Action', 'ActivateAction', 'AllocateAction', 'ApplyAction', 'AssignAction', 'AuthorizeAction', 'BookmarkAction', 'BorrowAction', 'BuyAction', 'CheckAction', 'ConsumeAction', 'ControlAction', 'CookAction', 'CreateAction', 'DeactivateAction', 'DepartAction', 'DiscoverAction', 'DrawAction', 'DrinkAction', 'EatAction', 'ExerciseAction', 'FindAction', 'GiveAction', 'InstallAction', 'MoneyTransfer', 'MoveAction', 'OrderAction', 'OrganizeAction', 'PaintAction', 'PayAction', 'PerformAction', 'PlayAction', 'QuoteAction', 'ReadAction', 'RejectAction', 'ReplaceAction', 'ResumeAction', 'ReturnAction', 'SearchAction', 'SellAction', 'SuspendAction', 'TakeAction', 'TieAction', 'TipAction', 'TrackAction', 'TradeAction', 'TransferAction', 'TravelAction', 'UpdateAction', 'UseAction', 'ViewAction', 'WatchAction', 'WearAction', 'WinAction', 'WriteAction']
# Cluster 4: ['BioChemEntity', 'Protein']
# Cluster 5: ['Airline', 'Airport', 'AmusementPark', 'AnimalShelter', 'Aquarium', 'ArchiveOrganization', 'Attorney', 'AutoPartsStore', 'AutoRental', 'AutoRepair', 'AutoWash', 'AutomotiveBusiness', 'Bakery', 'BarOrPub', 'BeautySalon', 'BedAndBreakfast', 'BikeStore', 'BoatTerminal', 'BodyOfWater', 'BookStore', 'BusStation', 'BusStop', 'CafeOrCoffeeShop', 'Campground', 'Casino', 'Cemetery', 'ChildCare', 'CivicStructure', 'ClothingStore', 'CollegeOrUniversity', 'ComedyClub', 'ComputerStore', 'Continent', 'ConvenienceStore', 'Corporation', 'CovidTestingFacility', 'Crematorium', 'DaySpa', 'Dentist', 'Distillery', 'EducationalOrganization', 'ElementarySchool', 'EmergencyService', 'EmploymentAgency', 'EntertainmentBusiness', 'EventVenue', 'ExerciseGym', 'FastFoodRestaurant', 'FireStation', 'Florist', 'FoodEstablishment', 'FundingAgency', 'FundingScheme', 'FurnitureStore', 'GardenStore', 'GasStation', 'GovernmentOffice', 'GovernmentOrganization', 'GroceryStore', 'HairSalon', 'HardwareStore', 'HealthAndBeautyBusiness', 'HealthClub', 'HighSchool', 'HobbyShop', 'HomeGoodsStore', 'Hospital', 'Hotel', 'IndividualPhysician', 'InternetCafe', 'JewelryStore', 'LakeBodyOfWater', 'Landform', 'LegalService', 'Library', 'LiquorStore', 'LocalBusiness', 'LodgingBusiness', 'MedicalBusiness', 'MedicalClinic', 'MedicalOrganization', 'MiddleSchool', 'Motel', 'MotorcycleRepair', 'Mountain', 'MovieRentalStore', 'MovieTheater', 'Museum', 'MusicGroup', 'OceanBodyOfWater', 'OfficeEquipmentStore', 'OnlineBusiness', 'Optician', 'Organization', 'Park', 'ParkingFacility', 'PawnShop', 'PerformingGroup', 'Pharmacy', 'Physician', 'PhysiciansOffice', 'Place', 'PoliceStation', 'PoliticalParty', 'Preschool', 'ProfessionalService', 'Project', 'PublicSwimmingPool', 'PublicToilet', 'RealEstateAgent', 'RecyclingCenter', 'ResearchOrganization', 'ResearchProject', 'Reservoir', 'Residence', 'Resort', 'Restaurant', 'RiverBodyOfWater', 'School', 'SeaBodyOfWater', 'SearchRescueOrganization', 'ShoeStore', 'SkiResort', 'SportingGoodsStore', 'SportsActivityLocation', 'StadiumOrArena', 'Store', 'SubwayStation', 'TattooParlor', 'TaxiStand', 'TelevisionStation', 'TennisComplex', 'TheaterGroup', 'TireShop', 'TouristAttraction', 'TouristDestination', 'ToyStore', 'TrainStation', 'TravelAgency', 'VacationRental', 'VeterinaryCare', 'Volcano', 'Waterfall', 'WholesaleStore', 'Winery', 'WorkersUnion', 'Zoo']
# Cluster 6: ['Boolean', 'CssSelectorType', 'DataType', 'Date', 'DateTime', 'PronounceableText', 'Text', 'Time', 'URL']
# Cluster 7: ['BusOrCoach', 'DietarySupplement', 'Drug', 'Product', 'ProductCollection', 'ProductGroup', 'ProductModel', 'SomeProducts', 'Substance', 'Vehicle']
# Cluster 8: ['AdministrativeArea', 'City', 'Country', 'SchoolDistrict', 'State']
# Cluster 9: ['BankAccount', 'BrokerageAccount', 'CreditCard', 'CurrencyConversionService', 'DepositAccount', 'FinancialProduct', 'InvestmentOrDeposit', 'LoanOrCredit', 'MortgageLoan', 'PaymentCard', 'PaymentMethod', 'PaymentService']
# Cluster 10: ['SiteNavigationElement', 'WPAdBlock', 'WPFooter', 'WPSideBar', 'WebPageElement']
# Cluster 11: ['Episode', 'RadioEpisode', 'TVEpisode']
# Cluster 12: ['Electrician', 'GeneralContractor', 'HVACBusiness', 'HomeAndConstructionBusiness', 'HousePainter', 'MovingCompany', 'Plumber', 'RoofingContractor']
# Cluster 13: ['HowTo', 'Recipe']
# Cluster 14: ['AutomatedTeller', 'BankOrCreditUnion', 'FinancialService', 'InsuranceAgency']
# Cluster 15: ['AskAction', 'CheckInAction', 'CheckOutAction', 'CommunicateAction', 'InformAction', 'InteractAction', 'InviteAction', 'JoinAction', 'MarryAction', 'ReplyAction', 'RsvpAction', 'ShareAction', 'SubscribeAction']
# Cluster 16: ['CompleteDataFeed', 'DataFeed', 'Dataset']
# Cluster 17: ['HealthTopicContent', 'WebContent']
# Cluster 18: ['Distance', 'Energy', 'Mass', 'Quantity']
# Cluster 19: ['Clip', 'MovieClip', 'RadioClip', 'TVClip', 'VideoGameClip']
# Cluster 20: ['ClaimReview', 'EmployerReview', 'Recommendation', 'Review', 'UserReview']
# Cluster 21: ['MedicalSign', 'VitalSign']
# Cluster 22: ['EmailMessage', 'Message']
# Cluster 23: ['CityHall', 'Courthouse', 'DefenceEstablishment', 'Embassy', 'GovernmentBuilding', 'LegislativeBuilding']
# Cluster 24: ['BuddhistTemple', 'PlaceOfWorship']
# Cluster 25: ['SportsOrganization', 'SportsTeam']
# Cluster 26: ['BedType', 'DriveWheelConfigurationValue', 'QualitativeValue', 'SizeSpecification']
# Cluster 27: ['Answer', 'Comment', 'CorrectionComment', 'Question']
# Cluster 28: ['CriticReview', 'ReviewNewsArticle']
# Cluster 29: ['AggregateOffer', 'Offer', 'OfferForPurchase']
# Cluster 30: ['ImagingTest', 'MedicalTest']
# Cluster 31: ['AMRadioChannel', 'FMRadioChannel', 'RadioChannel']
# Cluster 32: ['VideoObject', 'VideoObjectSnapshot']
# Cluster 33: ['AddAction', 'InsertAction', 'PrependAction']
# Cluster 34: ['SizeSystemEnumeration', 'WearableSizeSystemEnumeration']
# Cluster 35: ['BroadcastEvent', 'OnDemandEvent', 'PublicationEvent']
# Cluster 36: ['EmployeeRole', 'OrganizationRole', 'Role']
# Cluster 37: ['EnergyEfficiencyEnumeration', 'EnergyStarEnergyEfficiencyEnumeration']
# Cluster 38: ['PlanAction', 'ReserveAction', 'ScheduleAction']
# Cluster 39: ['AssessAction', 'ChooseAction', 'EndorseAction', 'IgnoreAction', 'LikeAction', 'ReactAction', 'ReviewAction']
# Cluster 40: ['Barcode', 'ImageObject', 'ImageObjectSnapshot']
# Cluster 41: ['CatholicChurch', 'Church']
# Cluster 42: ['CategoryCodeSet', 'DefinedTermSet']
# Cluster 43: ['ComicSeries', 'Periodical']
# Cluster 44: ['MedicalCondition', 'MedicalSignOrSymptom', 'MedicalSymptom']
# Cluster 45: ['FollowAction']
# Cluster 46: ['PreOrderAction']
# Cluster 47: ['InteractionCounter']
# Cluster 48: ['SoftwareSourceCode']
# Cluster 49: ['MedicalRiskCalculator']
# Cluster 50: ['MotorcycleDealer']
# Cluster 51: ['Mosque']
# Cluster 52: ['Language']
# Cluster 53: ['Order']
# Cluster 54: ['HotelRoom']
# Cluster 55: ['DryCleaningOrLaundry']
# Cluster 56: ['Synagogue']
# Cluster 57: ['MemberProgramTier']
# Cluster 58: ['Consortium']
# Cluster 59: ['PublicationVolume']
# Cluster 60: ['MediaReview']
# Cluster 61: ['RealEstateListing']
# Cluster 62: ['IceCreamShop']
# Cluster 63: ['ChemicalSubstance']
# Cluster 64: ['VideoGallery']
# Cluster 65: ['MediaGallery']
# Cluster 66: ['DisagreeAction']
# Cluster 67: ['InvestmentFund']
# Cluster 68: ['PlayGameAction']
# Cluster 69: ['Locksmith']
# Cluster 70: ['SpecialAnnouncement']
# Cluster 71: ['EUEnergyEfficiencyEnumeration']
# Cluster 72: ['ComputerLanguage']
# Cluster 73: ['LendAction']
# Cluster 74: ['CommentAction']
# Cluster 75: ['TouristInformationCenter']
# Cluster 76: ['VisualArtsEvent']
# Cluster 77: ['Brand']
# Cluster 78: ['HealthPlanNetwork']
# Cluster 79: ['VoteAction']
# Cluster 80: ['Pond']
# Cluster 81: ['MedicalGuidelineRecommendation']
# Cluster 82: ['MapCategoryType']
# Cluster 83: ['Car']
# Cluster 84: ['OfferForLease']
# Cluster 85: ['ElectronicsStore']
# Cluster 86: ['Syllabus']
# Cluster 87: ['SportsClub']
# Cluster 88: ['Movie']
# Cluster 89: ['RepaymentSpecification']
# Cluster 90: ['WantAction']
# Cluster 91: ['MedicalTestPanel']
# Cluster 92: ['MenuSection']
# Cluster 93: ['Class']
# Cluster 94: ['TextObject']
# Cluster 95: ['Ligament']
# Cluster 96: ['WebApplication']
# Cluster 97: ['StatisticalPopulation']
# Cluster 98: ['AdultEntertainment']
# Cluster 99: ['ReportedDoseSchedule']
# Cluster 100: ['MusicVenue']
# Cluster 101: ['AutoDealer']
# Cluster 102: ['RecommendedDoseSchedule']
# Cluster 103: ['TaxiReservation']
# Cluster 104: ['OutletStore']
# Cluster 105: ['AutoBodyShop']
# Cluster 106: ['AudioObjectSnapshot']
# Cluster 107: ['SatiricalArticle']
# Cluster 108: ['MedicalProcedureType']
# Cluster 109: ['ProductReturnPolicy']
# Cluster 110: ['OfferItemCondition']
# Cluster 111: ['MusicComposition']
# Cluster 112: ['PerformanceRole']
# Cluster 113: ['MedicalContraindication']
# Cluster 114: ['PodcastEpisode']
# Cluster 115: ['SeekToAction']
# Cluster 116: ['MedicalAudienceType']
# Cluster 117: ['MobilePhoneStore']
# Cluster 118: ['DepartmentStore']
# Cluster 119: ['ArriveAction']
# Cluster 120: ['PostalCodeRangeSpecification']
# Cluster 121: ['RVPark']
# Cluster 122: ['ProgramMembership']
# Cluster 123: ['DownloadAction']
# Cluster 124: ['MotorizedBicycle']
# Cluster 125: ['FilmAction']
# Cluster 126: ['RentalCarReservation']
# Cluster 127: ['PropertyValueSpecification']
# Cluster 128: ['SendAction']
# Cluster 129: ['AgreeAction']
# Cluster 130: ['AccountingService']
# Cluster 131: ['DanceGroup']
# Cluster 132: ['Beach']
# Cluster 133: ['ArtGallery']
# Cluster 134: ['AnatomicalSystem']
# Cluster 135: ['ShippingRateSettings']
# Cluster 136: ['ItemAvailability']
# Cluster 137: ['Muscle']
# Cluster 138: ['LibrarySystem']
# Cluster 139: ['ListenAction']
# Cluster 140: ['Atlas']
# Cluster 141: ['RegisterAction']
# Cluster 142: ['Demand']
# Cluster 143: ['DonateAction']
# Cluster 144: ['BloodTest']
# Cluster 145: ['FoodEstablishmentReservation']
# Cluster 146: ['DefinedTerm']
# Cluster 147: ['MedicalStudyStatus']
# Cluster 148: ['HealthPlanCostSharingSpecification']
# Cluster 149: ['HinduTemple']
# Cluster 150: ['Artery']
# Cluster 151: ['DiscussionForumPosting']
# Cluster 152: ['RentAction']
# Cluster 153: ['DiagnosticLab']
# Cluster 154: ['MathSolver']
# Cluster 155: ['ApartmentComplex']
# Cluster 156: ['PhysicalTherapy']
# Cluster 157: ['ImageGallery']
# Cluster 158: ['LiteraryEvent']
# Cluster 159: ['BodyMeasurementTypeEnumeration']
# Cluster 160: ['WPHeader']
# Cluster 161: ['PetStore']
# Cluster 162: ['Playground']
# Cluster 163: ['MusicRecording']
# Cluster 164: ['GatedResidenceCommunity']
# Cluster 165: ['PreventionIndication']
# Cluster 166: ['Bridge']
# Cluster 167: ['SocialEvent']
# Cluster 168: ['TrainReservation']
# Cluster 169: ['Table']
# Cluster 170: ['DeliveryTimeSettings']
# Cluster 171: ['WarrantyPromise']
# Cluster 172: ['PostOffice']
# Cluster 173: ['FloorPlan']
# Cluster 174: ['Season']
# Cluster 175: ['MolecularEntity']
# Cluster 176: ['LandmarksOrHistoricalBuildings']
# Cluster 177: ['IndividualProduct']
# Cluster 178: ['MusicStore']
# Cluster 179: ['MerchantReturnEnumeration']
# Cluster 180: ['ServiceChannel']
# Cluster 181: ['XPathType']
# Cluster 182: ['GolfCourse']
# Cluster 183: ['ChildrensEvent']
# Cluster 184: ['OnlineStore']
# Cluster 185: ['BowlingAlley']
# Cluster 186: ['ShoppingCenter']
# Cluster 187: ['MerchantReturnPolicy']
# Cluster 188: ['InfectiousDisease']
# Cluster 189: ['LoseAction']
# Cluster 190: ['AlignmentObject']
# Cluster 191: ['ExchangeRateSpecification']
# Cluster 192: ['DDxElement']
# Cluster 193: ['HowToSupply']
# Cluster 194: ['DeleteAction']
# Cluster 195: ['CategoryCode']
# Cluster 196: ['RadioStation']
# Cluster 197: ['AcceptAction']
# Cluster 198: ['TreatmentIndication']
# Cluster 199: ['ReceiveAction']
# Cluster 200: ['BreadcrumbList']
# Cluster 201: ['BefriendAction']
# Cluster 202: ['MensClothingStore']
# Cluster 203: ['PathologyTest']
# Cluster 204: ['DrugPregnancyCategory']
# Cluster 205: ['Blog']
# Cluster 206: ['Canal']
# Cluster 207: ['BusReservation']
# Cluster 208: ['LeaveAction']
# Cluster 209: ['Duration']
# Cluster 210: ['SolveMathAction']
# Cluster 211: ['DigitalDocumentPermission']
# Cluster 212: ['CDCPMDRecord']
# Cluster 213: ['Brewery']
# Cluster 214: ['LinkRole']
# Cluster 215: ['Motorcycle']
# Cluster 216: ['DrugStrength']
# Cluster 217: ['CancelAction']
# Cluster 218: ['MedicalObservationalStudy']
# Cluster 219: ['SpreadsheetDigitalDocument']
# Cluster 220: ['Thesis']
# Cluster 221: ['Hostel']
# Cluster 222: ['WebSite']
# Cluster 223: ['BroadcastFrequencySpecification']
# Cluster 224: ['UnRegisterAction']
# Cluster 225: ['DislikeAction']
# Cluster 226: ['WebAPI']
# Cluster 227: ['GameServer']
# Cluster 228: ['ConfirmAction']
# Cluster 229: ['Guide']
# Cluster 230: ['SteeringPositionValue']
# Cluster 231: ['SelfStorage']
# Cluster 232: ['Gene']
# Cluster 233: ['Report']
# Cluster 234: ['PhotographAction']
# Cluster 235: ['ActionAccessSpecification']
# Cluster 236: ['AppendAction']
# Cluster 237: ['HyperToc']
# Cluster 238: ['PerformingArtsTheater']
# Cluster 239: ['AudioObject']
# Cluster 240: ['Taxi']

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")

# %%
final_ans = []

# %%
for i, list_of_elements in tqdm(enumerate(final_clusters_list)):
    if len(list_of_elements)>1:
        prompt = f""""Analyze the following list of biological terms and identify all direct and indirect **parent-child relationships**.

        A **parent-child relationship** exists when one term (the parent) is a broader, more general category or a whole that conceptually encompasses or contains another term (the child). The child term is a more specific instance, a part, or a developmental stage of the parent term.

        **Guidelines for identifying relationships:**
        * **"Is-a" relationship:** e.g., "A 'leaf procambium' **is a** type of 'procambium'." (Parent: procambium, Child: leaf procambium)
        * **"Part-of" relationship:** e.g., "A 'petal' **is part of** a 'flower'." (Parent: flower, Child: petal)
        * **Developmental sequence:** e.g., "'Petal primordium visible stage' **is a stage in** 'petal development'." (Parent: petal development, Child: petal primordium visible stage)
        * **Anatomical hierarchy:** e.g., "'Root endodermis' **is part of** 'root' and **is a type of** 'endodermis'." (Parent: root and endodermis, Child: root endodermis)

        **List of Elements:**
        {list_of_elements}
        **Output Format:**
        Provide the output as a single JSON array. Each element in the array must be a JSON object with two keys: `"parent"` and `"child"`, whose values are the corresponding terms.

        **Example Output (Illustrative, showing the expected JSON structure):**
        {json.dumps({"Answer":[
        {
            "parent": "procambium",
            "child": "branch procambium"
        },
        {
            "parent": "procambium",
            "child": "leaf procambium"
        },
        {
            "parent": "shoot system",
            "child": "axillary shoot system"
        },
        {
            "parent": "flower",
            "child": "petal"
        },
        {
            "parent": "flower development",
            "child": "petal primordium visible stage"
        }
        ]})}
        """
        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%20==0:
            print(response.text)
# Out:
# 0it [00:00, ?it/s]
# [
#   {
#     "parent": "AnatomicalStructure",
#     "child": "Bone"
#   },
#   {
#     "parent": "AnatomicalStructure",
#     "child": "BrainStructure"
#   },
#   {
#     "parent": "AnatomicalStructure",
#     "child": "Joint"
#   },
#   {
#     "parent": "AnatomicalStructure",
#     "child": "LymphaticVessel"
#   },
#   {
#     "parent": "AnatomicalStructure",
#     "child": "SuperficialAnatomy"
#   },
#   {
#     "parent": "AnatomicalStructure",
#     "child": "Vein"
#   },
#   {
#     "parent": "AnatomicalStructure",
#     "child": "Vessel"
#   },
#   {
#     "parent": "Article",
#     "child": "AdvertiserContentArticle"
#   },
#   {
#     "parent": "Article",
#     "child": "BlogPosting"
#   },
#   {
#     "parent": "Article",
#     "child": "LiveBlogPosting"
#   },
#   {
#     "parent": "Article",
#     "child": "MedicalScholarlyArticle"
#   },
#   {
#     "parent": "Article",
#     "child": "ScholarlyArticle"
#   },
#   {
#     "parent": "Article",
#     "child": "TechArticle"
#   },
#   {
#     "parent": "Audience",
#     "child": "BusinessAudience"
#   },
#   {
#     "parent": "Audience",
#     "child": "EducationalAudience"
#   },
#   {
#     "parent": "Audience",
#     "child": "MedicalAudience"
#   },
#   {
#     "parent": "Audience",
#     "child": "ParentAudience"
#   },
#   {
#     "parent": "Audience",
#     "child": "PeopleAudience"
#   },
#   {
#     "parent": "Certification",
#     "child": "EducationalOccupationalCredential"
#   },
#   {
#     "parent": "Certification",
#     "child": "GovernmentPermit"
#   },
#   {
#     "parent": "Certification",
#     "child": "Permit"
#   },
#   {
#     "parent": "Collection",
#     "child": "OfferCatalog"
#   },
#   {
#     "parent": "CoverArt",
#     "child": "ComicCoverArt"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "3DModel"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "AboutPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "AdvertiserContentArticle"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "AmpStory"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Article"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Audiobook"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "BlogPosting"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Book"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "BookSeries"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Chapter"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "CheckoutPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Claim"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Code"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "CollectionPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "ComicCoverArt"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "ComicIssue"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "ComicStory"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "ContactPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Conversation"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Course"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "CoverArt"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "CreativeWorkSeason"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "CreativeWorkSeries"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "DataCatalog"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "DataDownload"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "DigitalDocument"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Drawing"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "FAQPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Game"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "HowToDirection"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "HowToItem"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "HowToSection"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "HowToStep"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "HowToTip"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "HowToTool"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "ItemPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "LearningResource"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Legislation"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "LegislationObject"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "LiveBlogPosting"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Manuscript"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Map"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MediaObject"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MediaReviewItem"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MedicalScholarlyArticle"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MedicalWebPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MobileApplication"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MovieSeries"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MusicAlbum"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MusicPlaylist"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MusicRelease"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "MusicVideoObject"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Painting"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Photograph"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Play"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "PodcastSeason"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "PodcastSeries"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Poster"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "PresentationDigitalDocument"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "ProfilePage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "PublicationIssue"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "QAPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Quiz"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Quotation"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "RadioSeason"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "RadioSeries"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "ScholarlyArticle"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Sculpture"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "SearchResultsPage"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "SheetMusic"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "ShortStory"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "SocialMediaPosting"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "SoftwareApplication"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "Statement"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "TechArticle"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "TextDigitalDocument"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "TVSeason"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "TVSeries"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "VideoGame"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "VideoGameSeries"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "VisualArtwork"
#   },
#   {
#     "parent": "CreativeWork",
#     "child": "WebPage"
#   },
#   {
#     "parent": "CreativeWorkSeason",
#     "child": "PodcastSeason"
#   },
#   {
#     "parent": "CreativeWorkSeason",
#     "child": "RadioSeason"
#   },
#   {
#     "parent": "CreativeWorkSeason",
#     "child": "TVSeason"
#   },
#   {
#     "parent": "CreativeWorkSeries",
#     "child": "BookSeries"
#   },
#   {
#     "parent": "CreativeWorkSeries",
#     "child": "MovieSeries"
#   },
#   {
#     "parent": "CreativeWorkSeries",
#     "child": "PodcastSeries"
#   },
#   {
#     "parent": "CreativeWorkSeries",
#     "child": "RadioSeries"
#   },
#   {
#     "parent": "CreativeWorkSeries",
#     "child": "TVSeries"
#   },
#   {
#     "parent": "CreativeWorkSeries",
#     "child": "VideoGameSeries"
#   },
#   {
#     "parent": "DigitalDocument",
#     "child": "PresentationDigitalDocument"
#   },
#   {
#     "parent": "DigitalDocument",
#     "child": "TextDigitalDocument"
#   },
#   {
#     "parent": "Diet",
#     "child": "RestrictedDiet"
#   },
#   {
#     "parent": "DoseSchedule",
#     "child": "MaximumDoseSchedule"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "ActionStatusType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "AdultOrientedEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "BoardingPolicyType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "BookFormatType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "BusinessEntityType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "CarUsageType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "CertificationStatusEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "ContactPointOption"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "DayOfWeek"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "DeliveryMethod"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "DigitalDocumentPermissionType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "DigitalPlatformEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "EventAttendanceModeEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "EventStatusType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "GameAvailabilityEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "GamePlayMode"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "GameServerStatus"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "GenderType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "HealthAspectEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "IPTCDigitalSourceEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "ItemListOrderType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "LegalForceStatus"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "LegalValueLevel"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MeasurementMethodEnum"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MeasurementTypeEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MediaEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MediaManipulationRatingEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MedicalDevicePurpose"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MedicalEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MedicalEvidenceLevel"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MusicAlbumProductionType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MusicAlbumReleaseType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "MusicReleaseFormatType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "OrderStatus"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "PaymentMethodType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "PaymentStatusType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "PriceComponentTypeEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "PriceTypeEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "ProductReturnEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "RefundTypeEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "ReservationStatusType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "ReturnFeesEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "ReturnLabelSourceEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "ReturnMethodEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "RsvpResponseType"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "SizeGroupEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "StatusEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "TierBenefitEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "WearableMeasurementTypeEnumeration"
#   },
#   {
#     "parent": "Enumeration",
#     "child": "WearableSizeGroupEnumeration"
#   },
#   {
#     "parent": "Event",
#     "child": "BusinessEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "ComedyEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "DanceEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "DeliveryEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "EducationEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "ExhibitionEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "Festival"
#   },
#   {
#     "parent": "Event",
#     "child": "FoodEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "Hackathon"
#   },
#   {
#     "parent": "Event",
#     "child": "MusicEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "SaleEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "ScreeningEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "SportsEvent"
#   },
#   {
#     "parent": "Event",
#     "child": "TheaterEvent"
#   },
#   {
#     "parent": "Game",
#     "child": "VideoGame"
#   },
#   {
#     "parent": "GeoShape",
#     "child": "GeoCircle"
#   },
#   {
#     "parent": "GeospatialGeometry",
#     "child": "GeoCircle"
#   },
#   {
#     "parent": "GeospatialGeometry",
#     "child": "GeoShape"
#   },
#   {
#     "parent": "Grant",
#     "child": "MonetaryGrant"
#   },
#   {
#     "parent": "HowToSection",
#     "child": "HowToDirection"
#   },
#   {
#     "parent": "HowToSection",
#     "child": "HowToItem"
#   },
#   {
#     "parent": "HowToSection",
#     "child": "HowToStep"
#   },
#   {
#     "parent": "HowToSection",
#     "child": "HowToTip"
#   },
#   {
#     "parent": "HowToSection",
#     "child": "HowToTool"
#   },
#   {
#     "parent": "Intangible",
#     "child": "APIReference"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Audience"
#   },
#   {
#     "parent": "Intangible",
#     "child": "BedDetails"
#   },
#   {
#     "parent": "Intangible",
#     "child": "BroadcastChannel"
#   },
#   {
#     "parent": "Intangible",
#     "child": "BroadcastService"
#   },
#   {
#     "parent": "Intangible",
#     "child": "BusinessAudience"
#   },
#   {
#     "parent": "Intangible",
#     "child": "BusinessFunction"
#   },
#   {
#     "parent": "Intangible",
#     "child": "CableOrSatelliteService"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Certification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Collection"
#   },
#   {
#     "parent": "Intangible",
#     "child": "ContactPoint"
#   },
#   {
#     "parent": "Intangible",
#     "child": "ConstraintNode"
#   },
#   {
#     "parent": "Intangible",
#     "child": "CourseInstance"
#   },
#   {
#     "parent": "Intangible",
#     "child": "DataFeedItem"
#   },
#   {
#     "parent": "Intangible",
#     "child": "DatedMoneySpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "DefinedRegion"
#   },
#   {
#     "parent": "Intangible",
#     "child": "DeliveryChargeSpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "DigitalDocumentPermissionType"
#   },
#   {
#     "parent": "Intangible",
#     "child": "DoseSchedule"
#   },
#   {
#     "parent": "Intangible",
#     "child": "EducationalAudience"
#   },
#   {
#     "parent": "Intangible",
#     "child": "EducationalOccupationalCredential"
#   },
#   {
#     "parent": "Intangible",
#     "child": "EducationalOccupationalProgram"
#   },
#   {
#     "parent": "Intangible",
#     "child": "EmployerAggregateRating"
#   },
#   {
#     "parent": "Intangible",
#     "child": "EndorsementRating"
#   },
#   {
#     "parent": "Intangible",
#     "child": "EnergyConsumptionDetails"
#   },
#   {
#     "parent": "Intangible",
#     "child": "EngineSpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "EntryPoint"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Enumeration"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Flight"
#   },
#   {
#     "parent": "Intangible",
#     "child": "FoodService"
#   },
#   {
#     "parent": "Intangible",
#     "child": "GeoCircle"
#   },
#   {
#     "parent": "Intangible",
#     "child": "GeoCoordinates"
#   },
#   {
#     "parent": "Intangible",
#     "child": "GeoShape"
#   },
#   {
#     "parent": "Intangible",
#     "child": "GeospatialGeometry"
#   },
#   {
#     "parent": "Intangible",
#     "child": "GovernmentBenefitsType"
#   },
#   {
#     "parent": "Intangible",
#     "child": "GovernmentPermit"
#   },
#   {
#     "parent": "Intangible",
#     "child": "GovernmentService"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Grant"
#   },
#   {
#     "parent": "Intangible",
#     "child": "HealthInsurancePlan"
#   },
#   {
#     "parent": "Intangible",
#     "child": "HealthPlanFormulary"
#   },
#   {
#     "parent": "Intangible",
#     "child": "HyperTocEntry"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Invoice"
#   },
#   {
#     "parent": "Intangible",
#     "child": "ItemList"
#   },
#   {
#     "parent": "Intangible",
#     "child": "JobPosting"
#   },
#   {
#     "parent": "Intangible",
#     "child": "LegalForceStatus"
#   },
#   {
#     "parent": "Intangible",
#     "child": "LegalValueLevel"
#   },
#   {
#     "parent": "Intangible",
#     "child": "ListItem"
#   },
#   {
#     "parent": "Intangible",
#     "child": "LocationFeatureSpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MedicalAudience"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MedicalIntangible"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MediaSubscription"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MemberProgram"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Menu"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MenuItem"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MerchantReturnPolicySeasonalOverride"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MonetaryAmount"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MonetaryAmountDistribution"
#   },
#   {
#     "parent": "Intangible",
#     "child": "MonetaryGrant"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Occupation"
#   },
#   {
#     "parent": "Intangible",
#     "child": "OccupationalExperienceRequirements"
#   },
#   {
#     "parent": "Intangible",
#     "child": "OfferCatalog"
#   },
#   {
#     "parent": "Intangible",
#     "child": "OfferShippingDetails"
#   },
#   {
#     "parent": "Intangible",
#     "child": "OpeningHoursSpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "OrderItem"
#   },
#   {
#     "parent": "Intangible",
#     "child": "OwnershipInfo"
#   },
#   {
#     "parent": "Intangible",
#     "child": "ParcelDelivery"
#   },
#   {
#     "parent": "Intangible",
#     "child": "ParentAudience"
#   },
#   {
#     "parent": "Intangible",
#     "child": "PaymentChargeSpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Permit"
#   },
#   {
#     "parent": "Intangible",
#     "child": "PeopleAudience"
#   },
#   {
#     "parent": "Intangible",
#     "child": "PostalAddress"
#   },
#   {
#     "parent": "Intangible",
#     "child": "PriceSpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Property"
#   },
#   {
#     "parent": "Intangible",
#     "child": "PropertyValue"
#   },
#   {
#     "parent": "Intangible",
#     "child": "QuantitativeValue"
#   },
#   {
#     "parent": "Intangible",
#     "child": "QuantitativeValueDistribution"
#   },
#   {
#     "parent": "Intangible",
#     "child": "RadioBroadcastService"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Rating"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Reservation"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Schedule"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Seat"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Series"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Service"
#   },
#   {
#     "parent": "Intangible",
#     "child": "ShippingDeliveryTime"
#   },
#   {
#     "parent": "Intangible",
#     "child": "SpeakableSpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Specialty"
#   },
#   {
#     "parent": "Intangible",
#     "child": "StatisticalVariable"
#   },
#   {
#     "parent": "Intangible",
#     "child": "StructuredValue"
#   },
#   {
#     "parent": "Intangible",
#     "child": "TaxiService"
#   },
#   {
#     "parent": "Intangible",
#     "child": "TelevisionChannel"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Ticket"
#   },
#   {
#     "parent": "Intangible",
#     "child": "TouristTrip"
#   },
#   {
#     "parent": "Intangible",
#     "child": "TrainTrip"
#   },
#   {
#     "parent": "Intangible",
#     "child": "Trip"
#   },
#   {
#     "parent": "Intangible",
#     "child": "TypeAndQuantityNode"
#   },
#   {
#     "parent": "Intangible",
#     "child": "UnitPriceSpecification"
#   },
#   {
#     "parent": "Intangible",
#     "child": "VirtualLocation"
#   },
#   {
#     "parent": "Intangible",
#     "child": "WarrantyScope"
#   },
#   {
#     "parent": "Intangible",
#     "child": "WorkBasedProgram"
#   },
#   {
#     "parent": "ItemList",
#     "child": "ListItem"
#   },
#   {
#     "parent": "LegalValueLevel",
#     "child": "LegalForceStatus"
#   },
#   {
#     "parent": "LifestyleModification",
#     "child": "Diet"
#   },
#   {
#     "parent": "LifestyleModification",
#     "child": "ExercisePlan"
#   },
#   {
#     "parent": "LifestyleModification",
#     "child": "PhysicalActivity"
#   },
#   {
#     "parent": "LifestyleModification",
#     "child": "PhysicalActivityCategory"
#   },
#   {
#     "parent": "LifestyleModification",
#     "child": "RestrictedDiet"
#   },
#   {
#     "parent": "MediaObject",
#     "child": "MusicVideoObject"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "AnatomicalStructure"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "ApprovedIndication"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "Bone"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "BrainStructure"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "Diet"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "DiagnosticProcedure"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "DrugClass"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "DrugCost"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "DrugCostCategory"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "DrugLegalStatus"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "DrugPrescriptionStatus"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "ExercisePlan"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "InfectiousAgentClass"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "Joint"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "LifestyleModification"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "LymphaticVessel"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalCause"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalCode"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalConditionStage"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalDevice"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalDevicePurpose"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalGuideline"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalGuidelineContraindication"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalImagingTechnique"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalIndication"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalIntangible"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalObservationalStudyDesign"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalProcedure"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalRiskEstimator"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalRiskFactor"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalRiskScore"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalScholarlyArticle"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalSpecialty"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalStudy"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalTherapy"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalTrial"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicalTrialDesign"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "MedicineSystem"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "Observation"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "OccupationalTherapy"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "PalliativeProcedure"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "PhysicalActivity"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "PhysicalActivityCategory"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "PhysicalExam"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "PsychologicalTreatment"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "RadiationTherapy"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "RestrictedDiet"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "SurgicalProcedure"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "SuperficialAnatomy"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "TherapeuticProcedure"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "Vein"
#   },
#   {
#     "parent": "MedicalEntity",
#     "child": "Vessel"
#   },
#   {
#     "parent": "MedicalEnumeration",
#     "child": "MedicalDevicePurpose"
#   },
#   {
#     "parent": "MedicalGuideline",
#     "child": "MedicalGuidelineContraindication"
#   },
#   {
#     "parent": "MedicalIndication",
#     "child": "ApprovedIndication"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "ApprovedIndication"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "DrugClass"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "DrugCost"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "DrugCostCategory"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "DrugLegalStatus"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "DrugPrescriptionStatus"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "InfectiousAgentClass"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "MedicalCode"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "MedicalDevicePurpose"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "MedicalIndication"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "MedicalRiskEstimator"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "MedicalRiskFactor"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "MedicalRiskScore"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "MedicineSystem"
#   },
#   {
#     "parent": "MedicalIntangible",
#     "child": "Observation"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "DiagnosticProcedure"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "MedicalImagingTechnique"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "MedicalTherapy"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "OccupationalTherapy"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "PalliativeProcedure"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "PhysicalExam"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "PsychologicalTreatment"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "RadiationTherapy"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "SurgicalProcedure"
#   },
#   {
#     "parent": "MedicalProcedure",
#     "child": "TherapeuticProcedure"
#   },
#   {
#     "parent": "MedicalStudy",
#     "child": "MedicalObservationalStudyDesign"
#   },
#   {
#     "parent": "MedicalStudy",
#     "child": "MedicalTrial"
#   },
#   {
#     "parent": "MedicalStudy",
#     "child": "MedicalTrialDesign"
#   },
#   {
#     "parent": "MedicalTherapy",
#     "child": "OccupationalTherapy"
#   },
#   {
#     "parent": "MedicalTherapy",
#     "child": "PhysicalActivity"
#   },
#   {
#     "parent": "MedicalTherapy",
#     "child": "PsychologicalTreatment"
#   },
#   {
#     "parent": "MedicalTherapy",
#     "child": "RadiationTherapy"
#   },
#   {
#     "parent": "MedicalTrial",
#     "child": "MedicalTrialDesign"
#   },
#   {
#     "parent": "Menu",
#     "child": "MenuItem"
#   },
#   {
#     "parent": "MonetaryAmount",
#     "child": "MonetaryAmountDistribution"
#   },
#   {
#     "parent": "MusicPlaylist",
#     "child": "MusicAlbum"
#   },
#   {
#     "parent": "MusicPlaylist",
#     "child": "MusicRelease"
#   },
#   {
#     "parent": "Permit",
#     "child": "GovernmentPermit"
#   },
#   {
#     "parent": "Person",
#     "child": "Patient"
#   },
#   {
#     "parent": "Person",
#     "child": "Researcher"
#   },
#   {
#     "parent": "PriceSpecification",
#     "child": "CompoundPriceSpecification"
#   },
#   {
#     "parent": "PriceSpecification",
#     "child": "DatedMoneySpecification"
#   },
#   {
#     "parent": "PriceSpecification",
#     "child": "DeliveryChargeSpecification"
#   },
#   {
#     "parent": "PriceSpecification",
#     "child": "PaymentChargeSpecification"
#   },
#   {
#     "parent": "PriceSpecification",
#     "child": "UnitPriceSpecification"
#   },
#   {
#     "parent": "QuantitativeValue",
#     "child": "QuantitativeValueDistribution"
#   },
#   {
#     "parent": "Rating",
#     "child": "AggregateRating"
#   },
#   {
#     "parent": "Rating",
#     "child": "EmployerAggregateRating"
#   },
#   {
#     "parent": "Rating",
#     "child": "EndorsementRating"
#   },
#   {
#     "parent": "Reservation",
#     "child": "BoatReservation"
#   },
#   {
#     "parent": "Reservation",
#     "child": "EventReservation"
#   },
#   {
#     "parent": "Reservation",
#     "child": "FlightReservation"
#   },
#   {
#     "parent": "Reservation",
#     "child": "LodgingReservation"
#   },
#   {
#     "parent": "Reservation",
#     "child": "ReservationPackage"
#   },
#   {
#     "parent": "ScholarlyArticle",
#     "child": "MedicalScholarlyArticle"
#   },
#   {
#     "parent": "Series",
#     "child": "BookSeries"
#   },
#   {
#     "parent": "Series",
#     "child": "CreativeWorkSeason"
#   },
#   {
#     "parent": "Series",
#     "child": "CreativeWorkSeries"
#   },
#   {
#     "parent": "Series",
#     "child": "EventSeries"
#   },
#   {
#     "parent": "Series",
#     "child": "MovieSeries"
#   },
#   {
#     "parent": "Series",
#     "child": "PodcastSeason"
#   },
#   {
#     "parent": "Series",
#     "child": "PodcastSeries"
#   },
#   {
#     "parent": "Series",
#     "child": "RadioSeason"
#   },
#   {
#     "parent": "Series",
#     "child": "RadioSeries"
#   },
#   {
#     "parent": "Series",
#     "child": "TVSeason"
#   },
#   {
#     "parent": "Series",
#     "child": "TVSeries"
#   },
#   {
#     "parent": "Series",
#     "child": "Trip"
#   },
#   {
#     "parent": "Series",
#     "child": "VideoGameSeries"
#   },
#   {
#     "parent": "Service",
#     "child": "BroadcastService"
#   },
#   {
#     "parent": "Service",
#     "child": "CableOrSatelliteService"
#   },
#   {
#     "parent": "Service",
#     "child": "FoodService"
#   },
#   {
#     "parent": "Service",
#     "child": "GovernmentService"
#   },
#   {
#     "parent": "Service",
#     "child": "RadioBroadcastService"
#   },
#   {
#     "parent": "Service",
#     "child": "TaxiService"
#   },
#   {
#     "parent": "Service",
#     "child": "TelevisionChannel"
#   },
#   {
#     "parent": "SoftwareApplication",
#     "child": "MobileApplication"
#   },
#   {
#     "parent": "StructuredValue",
#     "child": "MonetaryAmount"
#   },
#   {
#     "parent": "StructuredValue",
#     "child": "MonetaryAmountDistribution"
#   },
#   {
#     "parent": "StructuredValue",
#     "child": "OpeningHoursSpecification"
#   },
#   {
#     "parent": "StructuredValue",
#     "child": "PropertyValue"
#   },
#   {
#     "parent": "StructuredValue",
#     "child": "QuantitativeValue"
#   },
#   {
#     "parent": "StructuredValue",
#     "child": "QuantitativeValueDistribution"
#   },
#   {
#     "parent": "StructuredValue",
#     "child": "TypeAndQuantityNode"
#   },
#   {
#     "parent": "Trip",
#     "child": "BoatTrip"
#   },
#   {
#     "parent": "Trip",
#     "child": "BusTrip"
#   },
#   {
#     "parent": "Trip",
#     "child": "Flight"
#   },
#   {
#     "parent": "Trip",
#     "child": "TouristTrip"
#   },
#   {
#     "parent": "Trip",
#     "child": "TrainTrip"
#   },
#   {
#     "parent": "VisualArtwork",
#     "child": "ComicCoverArt"
#   },
#   {
#     "parent": "VisualArtwork",
#     "child": "CoverArt"
#   },
#   {
#     "parent": "VisualArtwork",
#     "child": "Drawing"
#   },
#   {
#     "parent": "VisualArtwork",
#     "child": "Painting"
#   },
#   {
#     "parent": "VisualArtwork",
#     "child": "Photograph"
#   },
#   {
#     "parent": "VisualArtwork",
#     "child": "Sculpture"
#   },
#   {
#     "parent": "Vessel",
#     "child": "Vein"
#   },
#   {
#     "parent": "WebPage",
#     "child": "AboutPage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "AmpStory"
#   },
#   {
#     "parent": "WebPage",
#     "child": "CheckoutPage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "CollectionPage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "ContactPage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "FAQPage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "ItemPage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "MedicalWebPage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "ProfilePage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "QAPage"
#   },
#   {
#     "parent": "WebPage",
#     "child": "SearchResultsPage"
#   }
# ]
# [
#   {
#     "parent": "MedicalSign",
#     "child": "VitalSign"
#   }
# ]
# [
#   {
#     "parent": "Church",
#     "child": "CatholicChurch"
#   }
# ]

# %%
final_ans
# Out:
# ['[\n  {\n    "parent": "AnatomicalStructure",\n    "child": "Bone"\n  },\n  {\n    "parent": "AnatomicalStructure",\n    "child": "BrainStructure"\n  },\n  {\n    "parent": "AnatomicalStructure",\n    "child": "Joint"\n  },\n  {\n    "parent": "AnatomicalStructure",\n    "child": "LymphaticVessel"\n  },\n  {\n    "parent": "AnatomicalStructure",\n    "child": "SuperficialAnatomy"\n  },\n  {\n    "parent": "AnatomicalStructure",\n    "child": "Vein"\n  },\n  {\n    "parent": "AnatomicalStructure",\n    "child": "Vessel"\n  },\n  {\n    "parent": "Article",\n    "child": "AdvertiserContentArticle"\n  },\n  {\n    "parent": "Article",\n    "child": "BlogPosting"\n  },\n  {\n    "parent": "Article",\n    "child": "LiveBlogPosting"\n  },\n  {\n    "parent": "Article",\n    "child": "MedicalScholarlyArticle"\n  },\n  {\n    "parent": "Article",\n    "child": "ScholarlyArticle"\n  },\n  {\n    "parent": "Article",\n    "child": "TechArticle"\n  },\n  {\n    "parent": "Audience",\n    "child": "BusinessAudience"\n  },\n  {\n    "parent": "Audience",\n    "child": "EducationalAudience"\n  },\n  {\n    "parent": "Audience",\n    "child": "MedicalAudience"\n  },\n  {\n    "parent": "Audience",\n    "child": "ParentAudience"\n  },\n  {\n    "parent": "Audience",\n    "child": "PeopleAudience"\n  },\n  {\n    "parent": "Certification",\n    "child": "EducationalOccupationalCredential"\n  },\n  {\n    "parent": "Certification",\n    "child": "GovernmentPermit"\n  },\n  {\n    "parent": "Certification",\n    "child": "Permit"\n  },\n  {\n    "parent": "Collection",\n    "child": "OfferCatalog"\n  },\n  {\n    "parent": "CoverArt",\n    "child": "ComicCoverArt"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "3DModel"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "AboutPage"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "AdvertiserContentArticle"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "AmpStory"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Article"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Audiobook"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "BlogPosting"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Book"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "BookSeries"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Chapter"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "CheckoutPage"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Claim"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Code"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "CollectionPage"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "ComicCoverArt"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "ComicIssue"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "ComicStory"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "ContactPage"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Conversation"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Course"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "CoverArt"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "CreativeWorkSeason"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "CreativeWorkSeries"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "DataCatalog"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "DataDownload"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "DigitalDocument"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Drawing"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "FAQPage"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "Game"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "HowToDirection"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "HowToItem"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "HowToSection"\n  },\n  {\n    "parent": "CreativeWork",\n    "child": "HowToStep"\n  },\n  {\n    "parent": "CreativeWork", ...
#  '[\n  {\n    "parent": "Accommodation",\n    "child": "Apartment"\n  },\n  {\n    "parent": "Accommodation",\n    "child": "CampingPitch"\n  },\n  {\n    "parent": "Accommodation",\n    "child": "House"\n  },\n  {\n    "parent": "Accommodation",\n    "child": "MeetingRoom"\n  },\n  {\n    "parent": "Accommodation",\n    "child": "Room"\n  },\n  {\n    "parent": "Accommodation",\n    "child": "SingleFamilyResidence"\n  },\n  {\n    "parent": "Accommodation",\n    "child": "Suite"\n  },\n  {\n    "parent": "Apartment",\n    "child": "MeetingRoom"\n  },\n  {\n    "parent": "Apartment",\n    "child": "Room"\n  },\n  {\n    "parent": "Apartment",\n    "child": "Suite"\n  },\n  {\n    "parent": "House",\n    "child": "MeetingRoom"\n  },\n  {\n    "parent": "House",\n    "child": "Room"\n  },\n  {\n    "parent": "House",\n    "child": "SingleFamilyResidence"\n  },\n  {\n    "parent": "House",\n    "child": "Suite"\n  },\n  {\n    "parent": "Room",\n    "child": "MeetingRoom"\n  },\n  {\n    "parent": "Room",\n    "child": "Suite"\n  }\n]',
#  '[\n  {\n    "parent": "Action",\n    "child": "AchieveAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ActivateAction"\n  },\n  {\n    "parent": "Action",\n    "child": "AllocateAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ApplyAction"\n  },\n  {\n    "parent": "Action",\n    "child": "AssignAction"\n  },\n  {\n    "parent": "Action",\n    "child": "AuthorizeAction"\n  },\n  {\n    "parent": "Action",\n    "child": "BookmarkAction"\n  },\n  {\n    "parent": "Action",\n    "child": "CheckAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ConsumeAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ControlAction"\n  },\n  {\n    "parent": "Action",\n    "child": "CookAction"\n  },\n  {\n    "parent": "Action",\n    "child": "CreateAction"\n  },\n  {\n    "parent": "Action",\n    "child": "DeactivateAction"\n  },\n  {\n    "parent": "Action",\n    "child": "DepartAction"\n  },\n  {\n    "parent": "Action",\n    "child": "DiscoverAction"\n  },\n  {\n    "parent": "Action",\n    "child": "DrawAction"\n  },\n  {\n    "parent": "Action",\n    "child": "DrinkAction"\n  },\n  {\n    "parent": "Action",\n    "child": "EatAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ExerciseAction"\n  },\n  {\n    "parent": "Action",\n    "child": "FindAction"\n  },\n  {\n    "parent": "Action",\n    "child": "InstallAction"\n  },\n  {\n    "parent": "Action",\n    "child": "MoveAction"\n  },\n  {\n    "parent": "MoveAction",\n    "child": "TravelAction"\n  },\n  {\n    "parent": "Action",\n    "child": "OrderAction"\n  },\n  {\n    "parent": "Action",\n    "child": "OrganizeAction"\n  },\n  {\n    "parent": "Action",\n    "child": "PaintAction"\n  },\n  {\n    "parent": "Action",\n    "child": "PerformAction"\n  },\n  {\n    "parent": "Action",\n    "child": "PlayAction"\n  },\n  {\n    "parent": "Action",\n    "child": "QuoteAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ReadAction"\n  },\n  {\n    "parent": "Action",\n    "child": "RejectAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ReplaceAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ResumeAction"\n  },\n  {\n    "parent": "Action",\n    "child": "SearchAction"\n  },\n  {\n    "parent": "Action",\n    "child": "SuspendAction"\n  },\n  {\n    "parent": "Action",\n    "child": "TakeAction"\n  },\n  {\n    "parent": "TransferAction",\n    "child": "TakeAction"\n  },\n  {\n    "parent": "Action",\n    "child": "TieAction"\n  },\n  {\n    "parent": "Action",\n    "child": "TrackAction"\n  },\n  {\n    "parent": "Action",\n    "child": "TradeAction"\n  },\n  {\n    "parent": "TradeAction",\n    "child": "BuyAction"\n  },\n  {\n    "parent": "TradeAction",\n    "child": "SellAction"\n  },\n  {\n    "parent": "Action",\n    "child": "TransferAction"\n  },\n  {\n    "parent": "TransferAction",\n    "child": "MoneyTransfer"\n  },\n  {\n    "parent": "TransferAction",\n    "child": "BorrowAction"\n  },\n  {\n    "parent": "TransferAction",\n    "child": "GiveAction"\n  },\n  {\n    "parent": "TransferAction",\n    "child": "ReturnAction"\n  },\n  {\n    "parent": "MoneyTransfer",\n    "child": "PayAction"\n  },\n  {\n    "parent": "MoneyTransfer",\n    "child": "TipAction"\n  },\n  {\n    "parent": "Action",\n    "child": "UpdateAction"\n  },\n  {\n    "parent": "Action",\n    "child": "UseAction"\n  },\n  {\n    "parent": "Action",\n    "child": "ViewAction"\n  },\n  {\n    "parent": "Action",\n    "child": "WatchAction"\n  },\n  {\n    "parent": "Action",\n    "child": "WearAction"\n  },\n  {\n    "parent": "Action",\n    "child": "WinAction"\n  },\n  {\n    "parent": "Action",\n    "child": "WriteAction"\n  }\n]',
#  '[\n  {\n    "parent": "BioChemEntity",\n    "child": "Protein"\n  }\n]',
#  '{\n  "Answer": [\n    {\n      "parent": "Organization",\n      "child": "Airline"\n    },\n    {\n      "parent": "Organization",\n      "child": "ArchiveOrganization"\n    },\n    {\n      "parent": "Organization",\n      "child": "Corporation"\n    },\n    {\n      "parent": "Organization",\n      "child": "EducationalOrganization"\n    },\n    {\n      "parent": "Organization",\n      "child": "EmergencyService"\n    },\n    {\n      "parent": "Organization",\n      "child": "EmploymentAgency"\n    },\n    {\n      "parent": "Organization",\n      "child": "FundingAgency"\n    },\n    {\n      "parent": "Organization",\n      "child": "GovernmentOrganization"\n    },\n    {\n      "parent": "Organization",\n      "child": "MedicalOrganization"\n    },\n    {\n      "parent": "Organization",\n      "child": "PerformingGroup"\n    },\n    {\n      "parent": "Organization",\n      "child": "PoliticalParty"\n    },\n    {\n      "parent": "Organization",\n      "child": "ProfessionalService"\n    },\n    {\n      "parent": "Organization",\n      "child": "ResearchOrganization"\n    },\n    {\n      "parent": "Organization",\n      "child": "TelevisionStation"\n    },\n    {\n      "parent": "Organization",\n      "child": "TravelAgency"\n    },\n    {\n      "parent": "Organization",\n      "child": "WorkersUnion"\n    },\n    {\n      "parent": "EducationalOrganization",\n      "child": "CollegeOrUniversity"\n    },\n    {\n      "parent": "EducationalOrganization",\n      "child": "ElementarySchool"\n    },\n    {\n      "parent": "EducationalOrganization",\n      "child": "HighSchool"\n    },\n    {\n      "parent": "EducationalOrganization",\n      "child": "MiddleSchool"\n    },\n    {\n      "parent": "EducationalOrganization",\n      "child": "Preschool"\n    },\n    {\n      "parent": "EducationalOrganization",\n      "child": "School"\n    },\n    {\n      "parent": "School",\n      "child": "ElementarySchool"\n    },\n    {\n      "parent": "School",\n      "child": "HighSchool"\n    },\n    {\n      "parent": "School",\n      "child": "MiddleSchool"\n    },\n    {\n      "parent": "School",\n      "child": "Preschool"\n    },\n    {\n      "parent": "GovernmentOrganization",\n      "child": "FireStation"\n    },\n    {\n      "parent": "GovernmentOrganization",\n      "child": "GovernmentOffice"\n    },\n    {\n      "parent": "GovernmentOrganization",\n      "child": "PoliceStation"\n    },\n    {\n      "parent": "MedicalOrganization",\n      "child": "Crematorium"\n    },\n    {\n      "parent": "MedicalOrganization",\n      "child": "Hospital"\n    },\n    {\n      "parent": "MedicalOrganization",\n      "child": "MedicalClinic"\n    },\n    {\n      "parent": "MedicalOrganization",\n      "child": "Pharmacy"\n    },\n    {\n      "parent": "MedicalOrganization",\n      "child": "PhysiciansOffice"\n    },\n    {\n      "parent": "MedicalOrganization",\n      "child": "VeterinaryCare"\n    },\n    {\n      "parent": "PerformingGroup",\n      "child": "MusicGroup"\n    },\n    {\n      "parent": "PerformingGroup",\n      "child": "TheaterGroup"\n    },\n    {\n      "parent": "EmergencyService",\n      "child": "FireStation"\n    },\n    {\n      "parent": "EmergencyService",\n      "child": "PoliceStation"\n    },\n    {\n      "parent": "EmergencyService",\n      "child": "SearchRescueOrganization"\n    },\n    {\n      "parent": "Project",\n      "child": "ResearchProject"\n    },\n    {\n      "parent": "Place",\n      "child": "BodyOfWater"\n    },\n    {\n      "parent": "Place",\n      "child": "CivicStructure"\n    },\n    {\n      "parent": "Place",\n      "child": "Landform"\n    },\n    {\n      "parent": "Place",\n      "child": "LocalBusiness"\n    },\n    {\n      "parent": "Place",\n      "child": "Residence"\n    },\n    {\n      "parent": "Place",\n      "child": "SportsActivityLocation"\n    },\n    {\n      "parent": "Place",\n      "child": "TouristAttraction"\n    },\n    {\n      "parent":  ...
#  '[\n  {\n    "parent": "DataType",\n    "child": "Boolean"\n  },\n  {\n    "parent": "DataType",\n    "child": "Date"\n  },\n  {\n    "parent": "DataType",\n    "child": "DateTime"\n  },\n  {\n    "parent": "DataType",\n    "child": "Text"\n  },\n  {\n    "parent": "DataType",\n    "child": "Time"\n  },\n  {\n    "parent": "DataType",\n    "child": "URL"\n  },\n  {\n    "parent": "Text",\n    "child": "PronounceableText"\n  },\n  {\n    "parent": "Text",\n    "child": "URL"\n  },\n  {\n    "parent": "DateTime",\n    "child": "Date"\n  },\n  {\n    "parent": "DateTime",\n    "child": "Time"\n  }\n]',
#  '[\n  {"parent": "Product", "child": "DietarySupplement"},\n  {"parent": "Product", "child": "Drug"},\n  {"parent": "Product", "child": "Vehicle"},\n  {"parent": "Product", "child": "ProductModel"},\n  {"parent": "Product", "child": "ProductCollection"},\n  {"parent": "Substance", "child": "DietarySupplement"},\n  {"parent": "Substance", "child": "Drug"},\n  {"parent": "Vehicle", "child": "BusOrCoach"},\n  {"parent": "ProductCollection", "child": "ProductGroup"},\n  {"parent": "ProductCollection", "child": "SomeProducts"},\n  {"parent": "ProductCollection", "child": "Product"},\n  {"parent": "ProductGroup", "child": "Product"}\n]',
#  '[\n  {\n    "parent": "AdministrativeArea",\n    "child": "Country"\n  },\n  {\n    "parent": "AdministrativeArea",\n    "child": "State"\n  },\n  {\n    "parent": "AdministrativeArea",\n    "child": "City"\n  },\n  {\n    "parent": "AdministrativeArea",\n    "child": "SchoolDistrict"\n  },\n  {\n    "parent": "Country",\n    "child": "State"\n  },\n  {\n    "parent": "State",\n    "child": "City"\n  },\n  {\n    "parent": "State",\n    "child": "SchoolDistrict"\n  }\n]',
#  '[\n  {\n    "parent": "FinancialProduct",\n    "child": "InvestmentOrDeposit"\n  },\n  {\n    "parent": "FinancialProduct",\n    "child": "LoanOrCredit"\n  },\n  {\n    "parent": "InvestmentOrDeposit",\n    "child": "DepositAccount"\n  },\n  {\n    "parent": "InvestmentOrDeposit",\n    "child": "BrokerageAccount"\n  },\n  {\n    "parent": "LoanOrCredit",\n    "child": "MortgageLoan"\n  },\n  {\n    "parent": "LoanOrCredit",\n    "child": "CreditCard"\n  },\n  {\n    "parent": "DepositAccount",\n    "child": "BankAccount"\n  },\n  {\n    "parent": "PaymentService",\n    "child": "PaymentMethod"\n  },\n  {\n    "parent": "PaymentService",\n    "child": "CurrencyConversionService"\n  },\n  {\n    "parent": "PaymentMethod",\n    "child": "PaymentCard"\n  },\n  {\n    "parent": "PaymentMethod",\n    "child": "BankAccount"\n  },\n  {\n    "parent": "PaymentMethod",\n    "child": "CreditCard"\n  },\n  {\n    "parent": "PaymentCard",\n    "child": "CreditCard"\n  }\n]',
#  '[\n  {\n    "parent": "WebPageElement",\n    "child": "SiteNavigationElement"\n  },\n  {\n    "parent": "WebPageElement",\n    "child": "WPAdBlock"\n  },\n  {\n    "parent": "WebPageElement",\n    "child": "WPFooter"\n  },\n  {\n    "parent": "WebPageElement",\n    "child": "WPSideBar"\n  }\n]',
#  '[\n  {\n    "parent": "Episode",\n    "child": "RadioEpisode"\n  },\n  {\n    "parent": "Episode",\n    "child": "TVEpisode"\n  }\n]',
#  '{\n  "Answer": [\n    {\n      "parent": "HomeAndConstructionBusiness",\n      "child": "GeneralContractor"\n    },\n    {\n      "parent": "HomeAndConstructionBusiness",\n      "child": "HVACBusiness"\n    },\n    {\n      "parent": "HomeAndConstructionBusiness",\n      "child": "HousePainter"\n    },\n    {\n      "parent": "HomeAndConstructionBusiness",\n      "child": "Electrician"\n    },\n    {\n      "parent": "HomeAndConstructionBusiness",\n      "child": "Plumber"\n    },\n    {\n      "parent": "HomeAndConstructionBusiness",\n      "child": "RoofingContractor"\n    },\n    {\n      "parent": "GeneralContractor",\n      "child": "Electrician"\n    },\n    {\n      "parent": "GeneralContractor",\n      "child": "HVACBusiness"\n    },\n    {\n      "parent": "GeneralContractor",\n      "child": "HousePainter"\n    },\n    {\n      "parent": "GeneralContractor",\n      "child": "Plumber"\n    },\n    {\n      "parent": "GeneralContractor",\n      "child": "RoofingContractor"\n    }\n  ]\n}',
#  '[\n  {\n    "parent": "HowTo",\n    "child": "Recipe"\n  }\n]',
#  '[\n  {\n    "parent": "FinancialService",\n    "child": "BankOrCreditUnion"\n  },\n  {\n    "parent": "FinancialService",\n    "child": "InsuranceAgency"\n  },\n  {\n    "parent": "BankOrCreditUnion",\n    "child": "AutomatedTeller"\n  }\n]',
#  '[\n  {\n    "parent": "InteractAction",\n    "child": "CommunicateAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "JoinAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "AskAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "InformAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "ReplyAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "ShareAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "InviteAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "RsvpAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "CheckInAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "CheckOutAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "SubscribeAction"\n  },\n  {\n    "parent": "InteractAction",\n    "child": "MarryAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "AskAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "InformAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "ReplyAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "ShareAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "InviteAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "RsvpAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "CheckInAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "CheckOutAction"\n  },\n  {\n    "parent": "CommunicateAction",\n    "child": "SubscribeAction"\n  },\n  {\n    "parent": "InformAction",\n    "child": "CheckInAction"\n  },\n  {\n    "parent": "InformAction",\n    "child": "CheckOutAction"\n  },\n  {\n    "parent": "InformAction",\n    "child": "SubscribeAction"\n  },\n  {\n    "parent": "JoinAction",\n    "child": "MarryAction"\n  }\n]',
#  '[\n  {\n    "parent": "DataFeed",\n    "child": "CompleteDataFeed"\n  },\n  {\n    "parent": "DataFeed",\n    "child": "Dataset"\n  }\n]',
#  '[\n  {\n    "parent": "WebContent",\n    "child": "HealthTopicContent"\n  }\n]',
#  '[\n  {\n    "parent": "Quantity",\n    "child": "Distance"\n  },\n  {\n    "parent": "Quantity",\n    "child": "Energy"\n  },\n  {\n    "parent": "Quantity",\n    "child": "Mass"\n  }\n]',
#  '[\n  {\n    "parent": "Clip",\n    "child": "MovieClip"\n  },\n  {\n    "parent": "Clip",\n    "child": "RadioClip"\n  },\n  {\n    "parent": "Clip",\n    "child": "TVClip"\n  },\n  {\n    "parent": "Clip",\n    "child": "VideoGameClip"\n  }\n]',
#  '[\n  {\n    "parent": "Review",\n    "child": "ClaimReview"\n  },\n  {\n    "parent": "Review",\n    "child": "EmployerReview"\n  },\n  {\n    "parent": "Review",\n    "child": "UserReview"\n  }\n]',
#  '[\n  {\n    "parent": "MedicalSign",\n    "child": "VitalSign"\n  }\n]',
#  '[\n  {\n    "parent": "Message",\n    "child": "EmailMessage"\n  }\n]',
#  '[\n  {\n    "parent": "GovernmentBuilding",\n    "child": "CityHall"\n  },\n  {\n    "parent": "GovernmentBuilding",\n    "child": "Courthouse"\n  },\n  {\n    "parent": "GovernmentBuilding",\n    "child": "DefenceEstablishment"\n  },\n  {\n    "parent": "GovernmentBuilding",\n    "child": "Embassy"\n  },\n  {\n    "parent": "GovernmentBuilding",\n    "child": "LegislativeBuilding"\n  }\n]',
#  '{\n  "Answer": [\n    {\n      "parent": "PlaceOfWorship",\n      "child": "BuddhistTemple"\n    }\n  ]\n}',
#  '[\n  {\n    "parent": "SportsOrganization",\n    "child": "SportsTeam"\n  }\n]',
#  '[\n  {\n    "parent": "QualitativeValue",\n    "child": "BedType"\n  },\n  {\n    "parent": "QualitativeValue",\n    "child": "DriveWheelConfigurationValue"\n  }\n]',
#  '[\n  {\n    "parent": "Comment",\n    "child": "CorrectionComment"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "Offer",\n    "child": "AggregateOffer"\n  },\n  {\n    "parent": "Offer",\n    "child": "OfferForPurchase"\n  }\n]',
#  '[\n  {\n    "parent": "MedicalTest",\n    "child": "ImagingTest"\n  }\n]',
#  '[\n  {\n    "parent": "RadioChannel",\n    "child": "AMRadioChannel"\n  },\n  {\n    "parent": "RadioChannel",\n    "child": "FMRadioChannel"\n  }\n]',
#  '[\n  {\n    "parent": "VideoObject",\n    "child": "VideoObjectSnapshot"\n  }\n]',
#  '[\n  {\n    "parent": "AddAction",\n    "child": "InsertAction"\n  },\n  {\n    "parent": "InsertAction",\n    "child": "PrependAction"\n  }\n]',
#  '[\n  {\n    "parent": "SizeSystemEnumeration",\n    "child": "WearableSizeSystemEnumeration"\n  }\n]',
#  '[]',
#  '[\n  {\n    "parent": "Role",\n    "child": "OrganizationRole"\n  },\n  {\n    "parent": "OrganizationRole",\n    "child": "EmployeeRole"\n  }\n]',
#  '[\n  {\n    "parent": "EnergyEfficiencyEnumeration",\n    "child": "EnergyStarEnergyEfficiencyEnumeration"\n  }\n]',
#  '[\n  {\n    "parent": "PlanAction",\n    "child": "ReserveAction"\n  },\n  {\n    "parent": "PlanAction",\n    "child": "ScheduleAction"\n  }\n]',
#  '[\n  {\n    "parent": "ReactAction",\n    "child": "AssessAction"\n  },\n  {\n    "parent": "ReactAction",\n    "child": "ChooseAction"\n  },\n  {\n    "parent": "ReactAction",\n    "child": "EndorseAction"\n  },\n  {\n    "parent": "ReactAction",\n    "child": "IgnoreAction"\n  },\n  {\n    "parent": "ReactAction",\n    "child": "LikeAction"\n  },\n  {\n    "parent": "ReactAction",\n    "child": "ReviewAction"\n  }\n]',
#  '[\n  {\n    "parent": "ImageObject",\n    "child": "ImageObjectSnapshot"\n  }\n]',
#  '[\n  {\n    "parent": "Church",\n    "child": "CatholicChurch"\n  }\n]',
#  '[\n  {\n    "parent": "DefinedTermSet",\n    "child": "CategoryCodeSet"\n  }\n]',
#  '[\n  {\n    "parent": "Periodical",\n    "child": "ComicSeries"\n  }\n]',
#  '[\n  {\n    "parent": "MedicalSignOrSymptom",\n    "child": "MedicalSymptom"\n  }\n]']

# %%
final_result = []
for ans in final_ans:
    ans_1 = json.loads(ans)
    for an in ans_1:
        if an!="Answer":
            if an not in final_result:
                final_result.append(an)

# %%
len(final_result)
# Out:
# 659

# %%
final_result
# Out:
# [{'parent': 'AnatomicalStructure', 'child': 'Bone'},
#  {'parent': 'AnatomicalStructure', 'child': 'BrainStructure'},
#  {'parent': 'AnatomicalStructure', 'child': 'Joint'},
#  {'parent': 'AnatomicalStructure', 'child': 'LymphaticVessel'},
#  {'parent': 'AnatomicalStructure', 'child': 'SuperficialAnatomy'},
#  {'parent': 'AnatomicalStructure', 'child': 'Vein'},
#  {'parent': 'AnatomicalStructure', 'child': 'Vessel'},
#  {'parent': 'Article', 'child': 'AdvertiserContentArticle'},
#  {'parent': 'Article', 'child': 'BlogPosting'},
#  {'parent': 'Article', 'child': 'LiveBlogPosting'},
#  {'parent': 'Article', 'child': 'MedicalScholarlyArticle'},
#  {'parent': 'Article', 'child': 'ScholarlyArticle'},
#  {'parent': 'Article', 'child': 'TechArticle'},
#  {'parent': 'Audience', 'child': 'BusinessAudience'},
#  {'parent': 'Audience', 'child': 'EducationalAudience'},
#  {'parent': 'Audience', 'child': 'MedicalAudience'},
#  {'parent': 'Audience', 'child': 'ParentAudience'},
#  {'parent': 'Audience', 'child': 'PeopleAudience'},
#  {'parent': 'Certification', 'child': 'EducationalOccupationalCredential'},
#  {'parent': 'Certification', 'child': 'GovernmentPermit'},
#  {'parent': 'Certification', 'child': 'Permit'},
#  {'parent': 'Collection', 'child': 'OfferCatalog'},
#  {'parent': 'CoverArt', 'child': 'ComicCoverArt'},
#  {'parent': 'CreativeWork', 'child': '3DModel'},
#  {'parent': 'CreativeWork', 'child': 'AboutPage'},
#  {'parent': 'CreativeWork', 'child': 'AdvertiserContentArticle'},
#  {'parent': 'CreativeWork', 'child': 'AmpStory'},
#  {'parent': 'CreativeWork', 'child': 'Article'},
#  {'parent': 'CreativeWork', 'child': 'Audiobook'},
#  {'parent': 'CreativeWork', 'child': 'BlogPosting'},
#  {'parent': 'CreativeWork', 'child': 'Book'},
#  {'parent': 'CreativeWork', 'child': 'BookSeries'},
#  {'parent': 'CreativeWork', 'child': 'Chapter'},
#  {'parent': 'CreativeWork', 'child': 'CheckoutPage'},
#  {'parent': 'CreativeWork', 'child': 'Claim'},
#  {'parent': 'CreativeWork', 'child': 'Code'},
#  {'parent': 'CreativeWork', 'child': 'CollectionPage'},
#  {'parent': 'CreativeWork', 'child': 'ComicCoverArt'},
#  {'parent': 'CreativeWork', 'child': 'ComicIssue'},
#  {'parent': 'CreativeWork', 'child': 'ComicStory'},
#  {'parent': 'CreativeWork', 'child': 'ContactPage'},
#  {'parent': 'CreativeWork', 'child': 'Conversation'},
#  {'parent': 'CreativeWork', 'child': 'Course'},
#  {'parent': 'CreativeWork', 'child': 'CoverArt'},
#  {'parent': 'CreativeWork', 'child': 'CreativeWorkSeason'},
#  {'parent': 'CreativeWork', 'child': 'CreativeWorkSeries'},
#  {'parent': 'CreativeWork', 'child': 'DataCatalog'},
#  {'parent': 'CreativeWork', 'child': 'DataDownload'},
#  {'parent': 'CreativeWork', 'child': 'DigitalDocument'},
#  {'parent': 'CreativeWork', 'child': 'Drawing'},
#  {'parent': 'CreativeWork', 'child': 'FAQPage'},
#  {'parent': 'CreativeWork', 'child': 'Game'},
#  {'parent': 'CreativeWork', 'child': 'HowToDirection'},
#  {'parent': 'CreativeWork', 'child': 'HowToItem'},
#  {'parent': 'CreativeWork', 'child': 'HowToSection'},
#  {'parent': 'CreativeWork', 'child': 'HowToStep'},
#  {'parent': 'CreativeWork', 'child': 'HowToTip'},
#  {'parent': 'CreativeWork', 'child': 'HowToTool'},
#  {'parent': 'CreativeWork', 'child': 'ItemPage'},
#  {'parent': 'CreativeWork', 'child': 'LearningResource'},
#  {'parent': 'CreativeWork', 'child': 'Legislation'},
#  {'parent': 'CreativeWork', 'child': 'LegislationObject'},
#  {'parent': 'CreativeWork', 'child': 'LiveBlogPosting'},
#  {'parent': 'CreativeWork', 'child': 'Manuscript'},
#  {'parent': 'CreativeWork', 'child': 'Map'},
#  {'parent': 'CreativeWork', 'child': 'MediaObject'},
#  {'parent': 'CreativeWork', 'child': 'MediaReviewItem'},
#  {'parent': 'CreativeWork', 'child': 'MedicalScholarlyArticle'},
#  {'parent': 'CreativeWork', 'child': 'MedicalWebPage'},
#  {'parent': 'CreativeWork', 'child': 'MobileApplication'},
#  {'parent': 'CreativeWork', 'child': 'MovieSeries'},
#  {'parent': 'CreativeWork', 'child': 'MusicAlbum'},
#  {'parent': 'CreativeWork', 'child': 'MusicPlaylist'},
#  {'parent': 'CreativeWork', 'child': 'MusicRelease'},
#  {'parent': 'CreativeWork', 'child': 'MusicVideoObject'},
#  {'parent': 'CreativeWork', 'child': 'Painting'},
#  {'parent': 'CreativeWork', 'child': 'Photograph'},
#  {'parent': 'CreativeWork', 'child': 'Play'},
#  {'parent': 'CreativeWork', 'child': 'PodcastSeason'},
#  {'parent': 'CreativeWork', 'child': 'PodcastSeries'},
#  {'parent': 'CreativeWork', 'child': 'Poster'},
#  {'parent': 'CreativeWork', 'child': 'PresentationDigitalDocument'},
#  {'parent': 'CreativeWork', 'child': 'ProfilePage'},
#  {'parent': 'CreativeWork', 'child': 'PublicationIssue'},
#  {'parent': 'CreativeWork', 'child': 'QAPage'},
#  {'parent': 'CreativeWork', 'child': 'Quiz'},
#  {'parent': 'CreativeWork', 'child': 'Quotation'},
#  {'parent': 'CreativeWork', 'child': 'RadioSeason'},
#  {'parent': 'CreativeWork', 'child': 'RadioSeries'},
#  {'parent': 'CreativeWork', 'child': 'ScholarlyArticle'},
#  {'parent': 'CreativeWork', 'child': 'Sculpture'},
#  {'parent': 'CreativeWork', 'child': 'SearchResultsPage'},
#  {'parent': 'CreativeWork', 'child': 'SheetMusic'},
#  {'parent': 'CreativeWork', 'child': 'ShortStory'},
#  {'parent': 'CreativeWork', 'child': 'SocialMediaPosting'},
#  {'parent': 'CreativeWork', 'child': 'SoftwareApplication'},
#  {'parent': 'CreativeWork', 'child': 'Statement'},
#  {'parent': 'CreativeWork', 'child': 'TechArticle'},
#  {'parent': 'CreativeWork', 'child': 'TextDigitalDocument'},
#  {'parent': 'CreativeWork', 'child': 'TVSeason'},
#  {'parent': 'CreativeWork', 'child': 'TVSeries'},
#  {'parent': 'CreativeWork', 'child': 'VideoGame'},
#  {'parent': 'CreativeWork', 'child': 'VideoGameSeries'},
#  {'parent': 'CreativeWork', 'child': 'VisualArtwork'},
#  {'parent': 'CreativeWork', 'child': 'WebPage'},
#  {'parent': 'CreativeWorkSeason', 'child': 'PodcastSeason'},
#  {'parent': 'CreativeWorkSeason', 'child': 'RadioSeason'},
#  {'parent': 'CreativeWorkSeason', 'child': 'TVSeason'},
#  {'parent': 'CreativeWorkSeries', 'child': 'BookSeries'},
#  {'parent': 'CreativeWorkSeries', 'child': 'MovieSeries'},
#  {'parent': 'CreativeWorkSeries', 'child': 'PodcastSeries'},
#  {'parent': 'CreativeWorkSeries', 'child': 'RadioSeries'},
#  {'parent': 'CreativeWorkSeries', 'child': 'TVSeries'},
#  {'parent': 'CreativeWorkSeries', 'child': 'VideoGameSeries'},
#  {'parent': 'DigitalDocument', 'child': 'PresentationDigitalDocument'},
#  {'parent': 'DigitalDocument', 'child': 'TextDigitalDocument'},
#  {'parent': 'Diet', 'child': 'RestrictedDiet'},
#  {'parent': 'DoseSchedule', 'child': 'MaximumDoseSchedule'},
#  {'parent': 'Enumeration', 'child': 'ActionStatusType'},
#  {'parent': 'Enumeration', 'child': 'AdultOrientedEnumeration'},
#  {'parent': 'Enumeration', 'child': 'BoardingPolicyType'},
#  {'parent': 'Enumeration', 'child': 'BookFormatType'},
#  {'parent': 'Enumeration', 'child': 'BusinessEntityType'},
#  {'parent': 'Enumeration', 'child': 'CarUsageType'},
#  {'parent': 'Enumeration', 'child': 'CertificationStatusEnumeration'},
#  {'parent': 'Enumeration', 'child': 'ContactPointOption'},
#  {'parent': 'Enumeration', 'child': 'DayOfWeek'},
#  {'parent': 'Enumeration', 'child': 'DeliveryMethod'},
#  {'parent': 'Enumeration', 'child': 'DigitalDocumentPermissionType'},
#  {'parent': 'Enumeration', 'child': 'DigitalPlatformEnumeration'},
#  {'parent': 'Enumeration', 'child': 'EventAttendanceModeEnumeration'},
#  {'parent': 'Enumeration', 'child': 'EventStatusType'},
#  {'parent': 'Enumeration', 'child': 'GameAvailabilityEnumeration'},
#  {'parent': 'Enumeration', 'child': 'GamePlayMode'},
#  {'parent': 'Enumeration', 'child': 'GameServerStatus'},
#  {'parent': 'Enumeration', 'child': 'GenderType'},
#  {'parent': 'Enumeration', 'child': 'HealthAspectEnumeration'},
#  {'parent': 'Enumeration', 'child': 'IPTCDigitalSourceEnumeration'},
#  {'parent': 'Enumeration', 'child': 'ItemListOrderType'},
#  {'parent': 'Enumeration', 'child': 'LegalForceStatus'},
#  {'parent': 'Enumeration', 'child': 'LegalValueLevel'},
#  {'parent': 'Enumeration', 'child': 'MeasurementMethodEnum'},
#  {'parent': 'Enumeration', 'child': 'MeasurementTypeEnumeration'},
#  {'parent': 'Enumeration', 'child': 'MediaEnumeration'},
#  {'parent': 'Enumeration', 'child': 'MediaManipulationRatingEnumeration'},
#  {'parent': 'Enumeration', 'child': 'MedicalDevicePurpose'},
#  {'parent': 'Enumeration', 'child': 'MedicalEnumeration'},
#  {'parent': 'Enumeration', 'child': 'MedicalEvidenceLevel'},
#  {'parent': 'Enumeration', 'child': 'MusicAlbumProductionType'},
#  {'parent': 'Enumeration', 'child': 'MusicAlbumReleaseType'},
#  {'parent': 'Enumeration', 'child': 'MusicReleaseFormatType'},
#  {'parent': 'Enumeration', 'child': 'OrderStatus'},
#  {'parent': 'Enumeration', 'child': 'PaymentMethodType'},
#  {'parent': 'Enumeration', 'child': 'PaymentStatusType'},
#  {'parent': 'Enumeration', 'child': 'PriceComponentTypeEnumeration'},
#  {'parent': 'Enumeration', 'child': 'PriceTypeEnumeration'},
#  {'parent': 'Enumeration', 'child': 'ProductReturnEnumeration'},
#  {'parent': 'Enumeration', 'child': 'RefundTypeEnumeration'},
#  {'parent': 'Enumeration', 'child': 'ReservationStatusType'},
#  {'parent': 'Enumeration', 'child': 'ReturnFeesEnumeration'},
#  {'parent': 'Enumeration', 'child': 'ReturnLabelSourceEnumeration'},
#  {'parent': 'Enumeration', 'child': 'ReturnMethodEnumeration'},
#  {'parent': 'Enumeration', 'child': 'RsvpResponseType'},
#  {'parent': 'Enumeration', 'child': 'SizeGroupEnumeration'},
#  {'parent': 'Enumeration', 'child': 'StatusEnumeration'},
#  {'parent': 'Enumeration', 'child': 'TierBenefitEnumeration'},
#  {'parent': 'Enumeration', 'child': 'WearableMeasurementTypeEnumeration'},
#  {'parent': 'Enumeration', 'child': 'WearableSizeGroupEnumeration'},
#  {'parent': 'Event', 'child': 'BusinessEvent'},
#  {'parent': 'Event', 'child': 'ComedyEvent'},
#  {'parent': 'Event', 'child': 'DanceEvent'},
#  {'parent': 'Event', 'child': 'DeliveryEvent'},
#  {'parent': 'Event', 'child': 'EducationEvent'},
#  {'parent': 'Event', 'child': 'ExhibitionEvent'},
#  {'parent': 'Event', 'child': 'Festival'},
#  {'parent': 'Event', 'child': 'FoodEvent'},
#  {'parent': 'Event', 'child': 'Hackathon'},
#  {'parent': 'Event', 'child': 'MusicEvent'},
#  {'parent': 'Event', 'child': 'SaleEvent'},
#  {'parent': 'Event', 'child': 'ScreeningEvent'},
#  {'parent': 'Event', 'child': 'SportsEvent'},
#  {'parent': 'Event', 'child': 'TheaterEvent'},
#  {'parent': 'Game', 'child': 'VideoGame'},
#  {'parent': 'GeoShape', 'child': 'GeoCircle'},
#  {'parent': 'GeospatialGeometry', 'child': 'GeoCircle'},
#  {'parent': 'GeospatialGeometry', 'child': 'GeoShape'},
#  {'parent': 'Grant', 'child': 'MonetaryGrant'},
#  {'parent': 'HowToSection', 'child': 'HowToDirection'},
#  {'parent': 'HowToSection', 'child': 'HowToItem'},
#  {'parent': 'HowToSection', 'child': 'HowToStep'},
#  {'parent': 'HowToSection', 'child': 'HowToTip'},
#  {'parent': 'HowToSection', 'child': 'HowToTool'},
#  {'parent': 'Intangible', 'child': 'APIReference'},
#  {'parent': 'Intangible', 'child': 'Audience'},
#  {'parent': 'Intangible', 'child': 'BedDetails'},
#  {'parent': 'Intangible', 'child': 'BroadcastChannel'},
#  {'parent': 'Intangible', 'child': 'BroadcastService'},
#  {'parent': 'Intangible', 'child': 'BusinessAudience'},
#  {'parent': 'Intangible', 'child': 'BusinessFunction'},
#  {'parent': 'Intangible', 'child': 'CableOrSatelliteService'},
#  {'parent': 'Intangible', 'child': 'Certification'},
#  {'parent': 'Intangible', 'child': 'Collection'},
#  {'parent': 'Intangible', 'child': 'ContactPoint'},
#  {'parent': 'Intangible', 'child': 'ConstraintNode'},
#  {'parent': 'Intangible', 'child': 'CourseInstance'},
#  {'parent': 'Intangible', 'child': 'DataFeedItem'},
#  {'parent': 'Intangible', 'child': 'DatedMoneySpecification'},
#  {'parent': 'Intangible', 'child': 'DefinedRegion'},
#  {'parent': 'Intangible', 'child': 'DeliveryChargeSpecification'},
#  {'parent': 'Intangible', 'child': 'DigitalDocumentPermissionType'},
#  {'parent': 'Intangible', 'child': 'DoseSchedule'},
#  {'parent': 'Intangible', 'child': 'EducationalAudience'},
#  {'parent': 'Intangible', 'child': 'EducationalOccupationalCredential'},
#  {'parent': 'Intangible', 'child': 'EducationalOccupationalProgram'},
#  {'parent': 'Intangible', 'child': 'EmployerAggregateRating'},
#  {'parent': 'Intangible', 'child': 'EndorsementRating'},
#  {'parent': 'Intangible', 'child': 'EnergyConsumptionDetails'},
#  {'parent': 'Intangible', 'child': 'EngineSpecification'},
#  {'parent': 'Intangible', 'child': 'EntryPoint'},
#  {'parent': 'Intangible', 'child': 'Enumeration'},
#  {'parent': 'Intangible', 'child': 'Flight'},
#  {'parent': 'Intangible', 'child': 'FoodService'},
#  {'parent': 'Intangible', 'child': 'GeoCircle'},
#  {'parent': 'Intangible', 'child': 'GeoCoordinates'},
#  {'parent': 'Intangible', 'child': 'GeoShape'},
#  {'parent': 'Intangible', 'child': 'GeospatialGeometry'},
#  {'parent': 'Intangible', 'child': 'GovernmentBenefitsType'},
#  {'parent': 'Intangible', 'child': 'GovernmentPermit'},
#  {'parent': 'Intangible', 'child': 'GovernmentService'},
#  {'parent': 'Intangible', 'child': 'Grant'},
#  {'parent': 'Intangible', 'child': 'HealthInsurancePlan'},
#  {'parent': 'Intangible', 'child': 'HealthPlanFormulary'},
#  {'parent': 'Intangible', 'child': 'HyperTocEntry'},
#  {'parent': 'Intangible', 'child': 'Invoice'},
#  {'parent': 'Intangible', 'child': 'ItemList'},
#  {'parent': 'Intangible', 'child': 'JobPosting'},
#  {'parent': 'Intangible', 'child': 'LegalForceStatus'},
#  {'parent': 'Intangible', 'child': 'LegalValueLevel'},
#  {'parent': 'Intangible', 'child': 'ListItem'},
#  {'parent': 'Intangible', 'child': 'LocationFeatureSpecification'},
#  {'parent': 'Intangible', 'child': 'MedicalAudience'},
#  {'parent': 'Intangible', 'child': 'MedicalIntangible'},
#  {'parent': 'Intangible', 'child': 'MediaSubscription'},
#  {'parent': 'Intangible', 'child': 'MemberProgram'},
#  {'parent': 'Intangible', 'child': 'Menu'},
#  {'parent': 'Intangible', 'child': 'MenuItem'},
#  {'parent': 'Intangible', 'child': 'MerchantReturnPolicySeasonalOverride'},
#  {'parent': 'Intangible', 'child': 'MonetaryAmount'},
#  {'parent': 'Intangible', 'child': 'MonetaryAmountDistribution'},
#  {'parent': 'Intangible', 'child': 'MonetaryGrant'},
#  {'parent': 'Intangible', 'child': 'Occupation'},
#  {'parent': 'Intangible', 'child': 'OccupationalExperienceRequirements'},
#  {'parent': 'Intangible', 'child': 'OfferCatalog'},
#  {'parent': 'Intangible', 'child': 'OfferShippingDetails'},
#  {'parent': 'Intangible', 'child': 'OpeningHoursSpecification'},
#  {'parent': 'Intangible', 'child': 'OrderItem'},
#  {'parent': 'Intangible', 'child': 'OwnershipInfo'},
#  {'parent': 'Intangible', 'child': 'ParcelDelivery'},
#  {'parent': 'Intangible', 'child': 'ParentAudience'},
#  {'parent': 'Intangible', 'child': 'PaymentChargeSpecification'},
#  {'parent': 'Intangible', 'child': 'Permit'},
#  {'parent': 'Intangible', 'child': 'PeopleAudience'},
#  {'parent': 'Intangible', 'child': 'PostalAddress'},
#  {'parent': 'Intangible', 'child': 'PriceSpecification'},
#  {'parent': 'Intangible', 'child': 'Property'},
#  {'parent': 'Intangible', 'child': 'PropertyValue'},
#  {'parent': 'Intangible', 'child': 'QuantitativeValue'},
#  {'parent': 'Intangible', 'child': 'QuantitativeValueDistribution'},
#  {'parent': 'Intangible', 'child': 'RadioBroadcastService'},
#  {'parent': 'Intangible', 'child': 'Rating'},
#  {'parent': 'Intangible', 'child': 'Reservation'},
#  {'parent': 'Intangible', 'child': 'Schedule'},
#  {'parent': 'Intangible', 'child': 'Seat'},
#  {'parent': 'Intangible', 'child': 'Series'},
#  {'parent': 'Intangible', 'child': 'Service'},
#  {'parent': 'Intangible', 'child': 'ShippingDeliveryTime'},
#  {'parent': 'Intangible', 'child': 'SpeakableSpecification'},
#  {'parent': 'Intangible', 'child': 'Specialty'},
#  {'parent': 'Intangible', 'child': 'StatisticalVariable'},
#  {'parent': 'Intangible', 'child': 'StructuredValue'},
#  {'parent': 'Intangible', 'child': 'TaxiService'},
#  {'parent': 'Intangible', 'child': 'TelevisionChannel'},
#  {'parent': 'Intangible', 'child': 'Ticket'},
#  {'parent': 'Intangible', 'child': 'TouristTrip'},
#  {'parent': 'Intangible', 'child': 'TrainTrip'},
#  {'parent': 'Intangible', 'child': 'Trip'},
#  {'parent': 'Intangible', 'child': 'TypeAndQuantityNode'},
#  {'parent': 'Intangible', 'child': 'UnitPriceSpecification'},
#  {'parent': 'Intangible', 'child': 'VirtualLocation'},
#  {'parent': 'Intangible', 'child': 'WarrantyScope'},
#  {'parent': 'Intangible', 'child': 'WorkBasedProgram'},
#  {'parent': 'ItemList', 'child': 'ListItem'},
#  {'parent': 'LegalValueLevel', 'child': 'LegalForceStatus'},
#  {'parent': 'LifestyleModification', 'child': 'Diet'},
#  {'parent': 'LifestyleModification', 'child': 'ExercisePlan'},
#  {'parent': 'LifestyleModification', 'child': 'PhysicalActivity'},
#  {'parent': 'LifestyleModification', 'child': 'PhysicalActivityCategory'},
#  {'parent': 'LifestyleModification', 'child': 'RestrictedDiet'},
#  {'parent': 'MediaObject', 'child': 'MusicVideoObject'},
#  {'parent': 'MedicalEntity', 'child': 'AnatomicalStructure'},
#  {'parent': 'MedicalEntity', 'child': 'ApprovedIndication'},
#  {'parent': 'MedicalEntity', 'child': 'Bone'},
#  {'parent': 'MedicalEntity', 'child': 'BrainStructure'},
#  {'parent': 'MedicalEntity', 'child': 'Diet'},
#  {'parent': 'MedicalEntity', 'child': 'DiagnosticProcedure'},
#  {'parent': 'MedicalEntity', 'child': 'DrugClass'},
#  {'parent': 'MedicalEntity', 'child': 'DrugCost'},
#  {'parent': 'MedicalEntity', 'child': 'DrugCostCategory'},
#  {'parent': 'MedicalEntity', 'child': 'DrugLegalStatus'},
#  {'parent': 'MedicalEntity', 'child': 'DrugPrescriptionStatus'},
#  {'parent': 'MedicalEntity', 'child': 'ExercisePlan'},
#  {'parent': 'MedicalEntity', 'child': 'InfectiousAgentClass'},
#  {'parent': 'MedicalEntity', 'child': 'Joint'},
#  {'parent': 'MedicalEntity', 'child': 'LifestyleModification'},
#  {'parent': 'MedicalEntity', 'child': 'LymphaticVessel'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalCause'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalCode'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalConditionStage'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalDevice'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalDevicePurpose'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalGuideline'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalGuidelineContraindication'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalImagingTechnique'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalIndication'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalIntangible'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalObservationalStudyDesign'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalProcedure'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalRiskEstimator'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalRiskFactor'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalRiskScore'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalScholarlyArticle'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalSpecialty'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalStudy'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalTherapy'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalTrial'},
#  {'parent': 'MedicalEntity', 'child': 'MedicalTrialDesign'},
#  {'parent': 'MedicalEntity', 'child': 'MedicineSystem'},
#  {'parent': 'MedicalEntity', 'child': 'Observation'},
#  {'parent': 'MedicalEntity', 'child': 'OccupationalTherapy'},
#  {'parent': 'MedicalEntity', 'child': 'PalliativeProcedure'},
#  {'parent': 'MedicalEntity', 'child': 'PhysicalActivity'},
#  {'parent': 'MedicalEntity', 'child': 'PhysicalActivityCategory'},
#  {'parent': 'MedicalEntity', 'child': 'PhysicalExam'},
#  {'parent': 'MedicalEntity', 'child': 'PsychologicalTreatment'},
#  {'parent': 'MedicalEntity', 'child': 'RadiationTherapy'},
#  {'parent': 'MedicalEntity', 'child': 'RestrictedDiet'},
#  {'parent': 'MedicalEntity', 'child': 'SurgicalProcedure'},
#  {'parent': 'MedicalEntity', 'child': 'SuperficialAnatomy'},
#  {'parent': 'MedicalEntity', 'child': 'TherapeuticProcedure'},
#  {'parent': 'MedicalEntity', 'child': 'Vein'},
#  {'parent': 'MedicalEntity', 'child': 'Vessel'},
#  {'parent': 'MedicalEnumeration', 'child': 'MedicalDevicePurpose'},
#  {'parent': 'MedicalGuideline', 'child': 'MedicalGuidelineContraindication'},
#  {'parent': 'MedicalIndication', 'child': 'ApprovedIndication'},
#  {'parent': 'MedicalIntangible', 'child': 'ApprovedIndication'},
#  {'parent': 'MedicalIntangible', 'child': 'DrugClass'},
#  {'parent': 'MedicalIntangible', 'child': 'DrugCost'},
#  {'parent': 'MedicalIntangible', 'child': 'DrugCostCategory'},
#  {'parent': 'MedicalIntangible', 'child': 'DrugLegalStatus'},
#  {'parent': 'MedicalIntangible', 'child': 'DrugPrescriptionStatus'},
#  {'parent': 'MedicalIntangible', 'child': 'InfectiousAgentClass'},
#  {'parent': 'MedicalIntangible', 'child': 'MedicalCode'},
#  {'parent': 'MedicalIntangible', 'child': 'MedicalDevicePurpose'},
#  {'parent': 'MedicalIntangible', 'child': 'MedicalIndication'},
#  {'parent': 'MedicalIntangible', 'child': 'MedicalRiskEstimator'},
#  {'parent': 'MedicalIntangible', 'child': 'MedicalRiskFactor'},
#  {'parent': 'MedicalIntangible', 'child': 'MedicalRiskScore'},
#  {'parent': 'MedicalIntangible', 'child': 'MedicineSystem'},
#  {'parent': 'MedicalIntangible', 'child': 'Observation'},
#  {'parent': 'MedicalProcedure', 'child': 'DiagnosticProcedure'},
#  {'parent': 'MedicalProcedure', 'child': 'MedicalImagingTechnique'},
#  {'parent': 'MedicalProcedure', 'child': 'MedicalTherapy'},
#  {'parent': 'MedicalProcedure', 'child': 'OccupationalTherapy'},
#  {'parent': 'MedicalProcedure', 'child': 'PalliativeProcedure'},
#  {'parent': 'MedicalProcedure', 'child': 'PhysicalExam'},
#  {'parent': 'MedicalProcedure', 'child': 'PsychologicalTreatment'},
#  {'parent': 'MedicalProcedure', 'child': 'RadiationTherapy'},
#  {'parent': 'MedicalProcedure', 'child': 'SurgicalProcedure'},
#  {'parent': 'MedicalProcedure', 'child': 'TherapeuticProcedure'},
#  {'parent': 'MedicalStudy', 'child': 'MedicalObservationalStudyDesign'},
#  {'parent': 'MedicalStudy', 'child': 'MedicalTrial'},
#  {'parent': 'MedicalStudy', 'child': 'MedicalTrialDesign'},
#  {'parent': 'MedicalTherapy', 'child': 'OccupationalTherapy'},
#  {'parent': 'MedicalTherapy', 'child': 'PhysicalActivity'},
#  {'parent': 'MedicalTherapy', 'child': 'PsychologicalTreatment'},
#  {'parent': 'MedicalTherapy', 'child': 'RadiationTherapy'},
#  {'parent': 'MedicalTrial', 'child': 'MedicalTrialDesign'},
#  {'parent': 'Menu', 'child': 'MenuItem'},
#  {'parent': 'MonetaryAmount', 'child': 'MonetaryAmountDistribution'},
#  {'parent': 'MusicPlaylist', 'child': 'MusicAlbum'},
#  {'parent': 'MusicPlaylist', 'child': 'MusicRelease'},
#  {'parent': 'Permit', 'child': 'GovernmentPermit'},
#  {'parent': 'Person', 'child': 'Patient'},
#  {'parent': 'Person', 'child': 'Researcher'},
#  {'parent': 'PriceSpecification', 'child': 'CompoundPriceSpecification'},
#  {'parent': 'PriceSpecification', 'child': 'DatedMoneySpecification'},
#  {'parent': 'PriceSpecification', 'child': 'DeliveryChargeSpecification'},
#  {'parent': 'PriceSpecification', 'child': 'PaymentChargeSpecification'},
#  {'parent': 'PriceSpecification', 'child': 'UnitPriceSpecification'},
#  {'parent': 'QuantitativeValue', 'child': 'QuantitativeValueDistribution'},
#  {'parent': 'Rating', 'child': 'AggregateRating'},
#  {'parent': 'Rating', 'child': 'EmployerAggregateRating'},
#  {'parent': 'Rating', 'child': 'EndorsementRating'},
#  {'parent': 'Reservation', 'child': 'BoatReservation'},
#  {'parent': 'Reservation', 'child': 'EventReservation'},
#  {'parent': 'Reservation', 'child': 'FlightReservation'},
#  {'parent': 'Reservation', 'child': 'LodgingReservation'},
#  {'parent': 'Reservation', 'child': 'ReservationPackage'},
#  {'parent': 'ScholarlyArticle', 'child': 'MedicalScholarlyArticle'},
#  {'parent': 'Series', 'child': 'BookSeries'},
#  {'parent': 'Series', 'child': 'CreativeWorkSeason'},
#  {'parent': 'Series', 'child': 'CreativeWorkSeries'},
#  {'parent': 'Series', 'child': 'EventSeries'},
#  {'parent': 'Series', 'child': 'MovieSeries'},
#  {'parent': 'Series', 'child': 'PodcastSeason'},
#  {'parent': 'Series', 'child': 'PodcastSeries'},
#  {'parent': 'Series', 'child': 'RadioSeason'},
#  {'parent': 'Series', 'child': 'RadioSeries'},
#  {'parent': 'Series', 'child': 'TVSeason'},
#  {'parent': 'Series', 'child': 'TVSeries'},
#  {'parent': 'Series', 'child': 'Trip'},
#  {'parent': 'Series', 'child': 'VideoGameSeries'},
#  {'parent': 'Service', 'child': 'BroadcastService'},
#  {'parent': 'Service', 'child': 'CableOrSatelliteService'},
#  {'parent': 'Service', 'child': 'FoodService'},
#  {'parent': 'Service', 'child': 'GovernmentService'},
#  {'parent': 'Service', 'child': 'RadioBroadcastService'},
#  {'parent': 'Service', 'child': 'TaxiService'},
#  {'parent': 'Service', 'child': 'TelevisionChannel'},
#  {'parent': 'SoftwareApplication', 'child': 'MobileApplication'},
#  {'parent': 'StructuredValue', 'child': 'MonetaryAmount'},
#  {'parent': 'StructuredValue', 'child': 'MonetaryAmountDistribution'},
#  {'parent': 'StructuredValue', 'child': 'OpeningHoursSpecification'},
#  {'parent': 'StructuredValue', 'child': 'PropertyValue'},
#  {'parent': 'StructuredValue', 'child': 'QuantitativeValue'},
#  {'parent': 'StructuredValue', 'child': 'QuantitativeValueDistribution'},
#  {'parent': 'StructuredValue', 'child': 'TypeAndQuantityNode'},
#  {'parent': 'Trip', 'child': 'BoatTrip'},
#  {'parent': 'Trip', 'child': 'BusTrip'},
#  {'parent': 'Trip', 'child': 'Flight'},
#  {'parent': 'Trip', 'child': 'TouristTrip'},
#  {'parent': 'Trip', 'child': 'TrainTrip'},
#  {'parent': 'VisualArtwork', 'child': 'ComicCoverArt'},
#  {'parent': 'VisualArtwork', 'child': 'CoverArt'},
#  {'parent': 'VisualArtwork', 'child': 'Drawing'},
#  {'parent': 'VisualArtwork', 'child': 'Painting'},
#  {'parent': 'VisualArtwork', 'child': 'Photograph'},
#  {'parent': 'VisualArtwork', 'child': 'Sculpture'},
#  {'parent': 'Vessel', 'child': 'Vein'},
#  {'parent': 'WebPage', 'child': 'AboutPage'},
#  {'parent': 'WebPage', 'child': 'AmpStory'},
#  {'parent': 'WebPage', 'child': 'CheckoutPage'},
#  {'parent': 'WebPage', 'child': 'CollectionPage'},
#  {'parent': 'WebPage', 'child': 'ContactPage'},
#  {'parent': 'WebPage', 'child': 'FAQPage'},
#  {'parent': 'WebPage', 'child': 'ItemPage'},
#  {'parent': 'WebPage', 'child': 'MedicalWebPage'},
#  {'parent': 'WebPage', 'child': 'ProfilePage'},
#  {'parent': 'WebPage', 'child': 'QAPage'},
#  {'parent': 'WebPage', 'child': 'SearchResultsPage'},
#  {'parent': 'Accommodation', 'child': 'Apartment'},
#  {'parent': 'Accommodation', 'child': 'CampingPitch'},
#  {'parent': 'Accommodation', 'child': 'House'},
#  {'parent': 'Accommodation', 'child': 'MeetingRoom'},
#  {'parent': 'Accommodation', 'child': 'Room'},
#  {'parent': 'Accommodation', 'child': 'SingleFamilyResidence'},
#  {'parent': 'Accommodation', 'child': 'Suite'},
#  {'parent': 'Apartment', 'child': 'MeetingRoom'},
#  {'parent': 'Apartment', 'child': 'Room'},
#  {'parent': 'Apartment', 'child': 'Suite'},
#  {'parent': 'House', 'child': 'MeetingRoom'},
#  {'parent': 'House', 'child': 'Room'},
#  {'parent': 'House', 'child': 'SingleFamilyResidence'},
#  {'parent': 'House', 'child': 'Suite'},
#  {'parent': 'Room', 'child': 'MeetingRoom'},
#  {'parent': 'Room', 'child': 'Suite'},
#  {'parent': 'Action', 'child': 'AchieveAction'},
#  {'parent': 'Action', 'child': 'ActivateAction'},
#  {'parent': 'Action', 'child': 'AllocateAction'},
#  {'parent': 'Action', 'child': 'ApplyAction'},
#  {'parent': 'Action', 'child': 'AssignAction'},
#  {'parent': 'Action', 'child': 'AuthorizeAction'},
#  {'parent': 'Action', 'child': 'BookmarkAction'},
#  {'parent': 'Action', 'child': 'CheckAction'},
#  {'parent': 'Action', 'child': 'ConsumeAction'},
#  {'parent': 'Action', 'child': 'ControlAction'},
#  {'parent': 'Action', 'child': 'CookAction'},
#  {'parent': 'Action', 'child': 'CreateAction'},
#  {'parent': 'Action', 'child': 'DeactivateAction'},
#  {'parent': 'Action', 'child': 'DepartAction'},
#  {'parent': 'Action', 'child': 'DiscoverAction'},
#  {'parent': 'Action', 'child': 'DrawAction'},
#  {'parent': 'Action', 'child': 'DrinkAction'},
#  {'parent': 'Action', 'child': 'EatAction'},
#  {'parent': 'Action', 'child': 'ExerciseAction'},
#  {'parent': 'Action', 'child': 'FindAction'},
#  {'parent': 'Action', 'child': 'InstallAction'},
#  {'parent': 'Action', 'child': 'MoveAction'},
#  {'parent': 'MoveAction', 'child': 'TravelAction'},
#  {'parent': 'Action', 'child': 'OrderAction'},
#  {'parent': 'Action', 'child': 'OrganizeAction'},
#  {'parent': 'Action', 'child': 'PaintAction'},
#  {'parent': 'Action', 'child': 'PerformAction'},
#  {'parent': 'Action', 'child': 'PlayAction'},
#  {'parent': 'Action', 'child': 'QuoteAction'},
#  {'parent': 'Action', 'child': 'ReadAction'},
#  {'parent': 'Action', 'child': 'RejectAction'},
#  {'parent': 'Action', 'child': 'ReplaceAction'},
#  {'parent': 'Action', 'child': 'ResumeAction'},
#  {'parent': 'Action', 'child': 'SearchAction'},
#  {'parent': 'Action', 'child': 'SuspendAction'},
#  {'parent': 'Action', 'child': 'TakeAction'},
#  {'parent': 'TransferAction', 'child': 'TakeAction'},
#  {'parent': 'Action', 'child': 'TieAction'},
#  {'parent': 'Action', 'child': 'TrackAction'},
#  {'parent': 'Action', 'child': 'TradeAction'},
#  {'parent': 'TradeAction', 'child': 'BuyAction'},
#  {'parent': 'TradeAction', 'child': 'SellAction'},
#  {'parent': 'Action', 'child': 'TransferAction'},
#  {'parent': 'TransferAction', 'child': 'MoneyTransfer'},
#  {'parent': 'TransferAction', 'child': 'BorrowAction'},
#  {'parent': 'TransferAction', 'child': 'GiveAction'},
#  {'parent': 'TransferAction', 'child': 'ReturnAction'},
#  {'parent': 'MoneyTransfer', 'child': 'PayAction'},
#  {'parent': 'MoneyTransfer', 'child': 'TipAction'},
#  {'parent': 'Action', 'child': 'UpdateAction'},
#  {'parent': 'Action', 'child': 'UseAction'},
#  {'parent': 'Action', 'child': 'ViewAction'},
#  {'parent': 'Action', 'child': 'WatchAction'},
#  {'parent': 'Action', 'child': 'WearAction'},
#  {'parent': 'Action', 'child': 'WinAction'},
#  {'parent': 'Action', 'child': 'WriteAction'},
#  {'parent': 'BioChemEntity', 'child': 'Protein'},
#  {'parent': 'DataType', 'child': 'Boolean'},
#  {'parent': 'DataType', 'child': 'Date'},
#  {'parent': 'DataType', 'child': 'DateTime'},
#  {'parent': 'DataType', 'child': 'Text'},
#  {'parent': 'DataType', 'child': 'Time'},
#  {'parent': 'DataType', 'child': 'URL'},
#  {'parent': 'Text', 'child': 'PronounceableText'},
#  {'parent': 'Text', 'child': 'URL'},
#  {'parent': 'DateTime', 'child': 'Date'},
#  {'parent': 'DateTime', 'child': 'Time'},
#  {'parent': 'Product', 'child': 'DietarySupplement'},
#  {'parent': 'Product', 'child': 'Drug'},
#  {'parent': 'Product', 'child': 'Vehicle'},
#  {'parent': 'Product', 'child': 'ProductModel'},
#  {'parent': 'Product', 'child': 'ProductCollection'},
#  {'parent': 'Substance', 'child': 'DietarySupplement'},
#  {'parent': 'Substance', 'child': 'Drug'},
#  {'parent': 'Vehicle', 'child': 'BusOrCoach'},
#  {'parent': 'ProductCollection', 'child': 'ProductGroup'},
#  {'parent': 'ProductCollection', 'child': 'SomeProducts'},
#  {'parent': 'ProductCollection', 'child': 'Product'},
#  {'parent': 'ProductGroup', 'child': 'Product'},
#  {'parent': 'AdministrativeArea', 'child': 'Country'},
#  {'parent': 'AdministrativeArea', 'child': 'State'},
#  {'parent': 'AdministrativeArea', 'child': 'City'},
#  {'parent': 'AdministrativeArea', 'child': 'SchoolDistrict'},
#  {'parent': 'Country', 'child': 'State'},
#  {'parent': 'State', 'child': 'City'},
#  {'parent': 'State', 'child': 'SchoolDistrict'},
#  {'parent': 'FinancialProduct', 'child': 'InvestmentOrDeposit'},
#  {'parent': 'FinancialProduct', 'child': 'LoanOrCredit'},
#  {'parent': 'InvestmentOrDeposit', 'child': 'DepositAccount'},
#  {'parent': 'InvestmentOrDeposit', 'child': 'BrokerageAccount'},
#  {'parent': 'LoanOrCredit', 'child': 'MortgageLoan'},
#  {'parent': 'LoanOrCredit', 'child': 'CreditCard'},
#  {'parent': 'DepositAccount', 'child': 'BankAccount'},
#  {'parent': 'PaymentService', 'child': 'PaymentMethod'},
#  {'parent': 'PaymentService', 'child': 'CurrencyConversionService'},
#  {'parent': 'PaymentMethod', 'child': 'PaymentCard'},
#  {'parent': 'PaymentMethod', 'child': 'BankAccount'},
#  {'parent': 'PaymentMethod', 'child': 'CreditCard'},
#  {'parent': 'PaymentCard', 'child': 'CreditCard'},
#  {'parent': 'WebPageElement', 'child': 'SiteNavigationElement'},
#  {'parent': 'WebPageElement', 'child': 'WPAdBlock'},
#  {'parent': 'WebPageElement', 'child': 'WPFooter'},
#  {'parent': 'WebPageElement', 'child': 'WPSideBar'},
#  {'parent': 'Episode', 'child': 'RadioEpisode'},
#  {'parent': 'Episode', 'child': 'TVEpisode'},
#  {'parent': 'HowTo', 'child': 'Recipe'},
#  {'parent': 'FinancialService', 'child': 'BankOrCreditUnion'},
#  {'parent': 'FinancialService', 'child': 'InsuranceAgency'},
#  {'parent': 'BankOrCreditUnion', 'child': 'AutomatedTeller'},
#  {'parent': 'InteractAction', 'child': 'CommunicateAction'},
#  {'parent': 'InteractAction', 'child': 'JoinAction'},
#  {'parent': 'InteractAction', 'child': 'AskAction'},
#  {'parent': 'InteractAction', 'child': 'InformAction'},
#  {'parent': 'InteractAction', 'child': 'ReplyAction'},
#  {'parent': 'InteractAction', 'child': 'ShareAction'},
#  {'parent': 'InteractAction', 'child': 'InviteAction'},
#  {'parent': 'InteractAction', 'child': 'RsvpAction'},
#  {'parent': 'InteractAction', 'child': 'CheckInAction'},
#  {'parent': 'InteractAction', 'child': 'CheckOutAction'},
#  {'parent': 'InteractAction', 'child': 'SubscribeAction'},
#  {'parent': 'InteractAction', 'child': 'MarryAction'},
#  {'parent': 'CommunicateAction', 'child': 'AskAction'},
#  {'parent': 'CommunicateAction', 'child': 'InformAction'},
#  {'parent': 'CommunicateAction', 'child': 'ReplyAction'},
#  {'parent': 'CommunicateAction', 'child': 'ShareAction'},
#  {'parent': 'CommunicateAction', 'child': 'InviteAction'},
#  {'parent': 'CommunicateAction', 'child': 'RsvpAction'},
#  {'parent': 'CommunicateAction', 'child': 'CheckInAction'},
#  {'parent': 'CommunicateAction', 'child': 'CheckOutAction'},
#  {'parent': 'CommunicateAction', 'child': 'SubscribeAction'},
#  {'parent': 'InformAction', 'child': 'CheckInAction'},
#  {'parent': 'InformAction', 'child': 'CheckOutAction'},
#  {'parent': 'InformAction', 'child': 'SubscribeAction'},
#  {'parent': 'JoinAction', 'child': 'MarryAction'},
#  {'parent': 'DataFeed', 'child': 'CompleteDataFeed'},
#  {'parent': 'DataFeed', 'child': 'Dataset'},
#  {'parent': 'WebContent', 'child': 'HealthTopicContent'},
#  {'parent': 'Quantity', 'child': 'Distance'},
#  {'parent': 'Quantity', 'child': 'Energy'},
#  {'parent': 'Quantity', 'child': 'Mass'},
#  {'parent': 'Clip', 'child': 'MovieClip'},
#  {'parent': 'Clip', 'child': 'RadioClip'},
#  {'parent': 'Clip', 'child': 'TVClip'},
#  {'parent': 'Clip', 'child': 'VideoGameClip'},
#  {'parent': 'Review', 'child': 'ClaimReview'},
#  {'parent': 'Review', 'child': 'EmployerReview'},
#  {'parent': 'Review', 'child': 'UserReview'},
#  {'parent': 'MedicalSign', 'child': 'VitalSign'},
#  {'parent': 'Message', 'child': 'EmailMessage'},
#  {'parent': 'GovernmentBuilding', 'child': 'CityHall'},
#  {'parent': 'GovernmentBuilding', 'child': 'Courthouse'},
#  {'parent': 'GovernmentBuilding', 'child': 'DefenceEstablishment'},
#  {'parent': 'GovernmentBuilding', 'child': 'Embassy'},
#  {'parent': 'GovernmentBuilding', 'child': 'LegislativeBuilding'},
#  {'parent': 'SportsOrganization', 'child': 'SportsTeam'},
#  {'parent': 'QualitativeValue', 'child': 'BedType'},
#  {'parent': 'QualitativeValue', 'child': 'DriveWheelConfigurationValue'},
#  {'parent': 'Comment', 'child': 'CorrectionComment'},
#  {'parent': 'Offer', 'child': 'AggregateOffer'},
#  {'parent': 'Offer', 'child': 'OfferForPurchase'},
#  {'parent': 'MedicalTest', 'child': 'ImagingTest'},
#  {'parent': 'RadioChannel', 'child': 'AMRadioChannel'},
#  {'parent': 'RadioChannel', 'child': 'FMRadioChannel'},
#  {'parent': 'VideoObject', 'child': 'VideoObjectSnapshot'},
#  {'parent': 'AddAction', 'child': 'InsertAction'},
#  {'parent': 'InsertAction', 'child': 'PrependAction'},
#  {'parent': 'SizeSystemEnumeration', 'child': 'WearableSizeSystemEnumeration'},
#  {'parent': 'Role', 'child': 'OrganizationRole'},
#  {'parent': 'OrganizationRole', 'child': 'EmployeeRole'},
#  {'parent': 'EnergyEfficiencyEnumeration',
#   'child': 'EnergyStarEnergyEfficiencyEnumeration'},
#  {'parent': 'PlanAction', 'child': 'ReserveAction'},
#  {'parent': 'PlanAction', 'child': 'ScheduleAction'},
#  {'parent': 'ReactAction', 'child': 'AssessAction'},
#  {'parent': 'ReactAction', 'child': 'ChooseAction'},
#  {'parent': 'ReactAction', 'child': 'EndorseAction'},
#  {'parent': 'ReactAction', 'child': 'IgnoreAction'},
#  {'parent': 'ReactAction', 'child': 'LikeAction'},
#  {'parent': 'ReactAction', 'child': 'ReviewAction'},
#  {'parent': 'ImageObject', 'child': 'ImageObjectSnapshot'},
#  {'parent': 'Church', 'child': 'CatholicChurch'},
#  {'parent': 'DefinedTermSet', 'child': 'CategoryCodeSet'},
#  {'parent': 'Periodical', 'child': 'ComicSeries'},
#  {'parent': 'MedicalSignOrSymptom', 'child': 'MedicalSymptom'}]

# %%
with open("predictions_c_SchemaOrg_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

# %%
import json

# Save final_clusters_list to JSON file
with open("final_result_keywords_c_po.json", "w", encoding="utf-8") as f:
    json.dump(final_result, f, indent=2, ensure_ascii=False)

print("Clusters saved to final_clusters.json ✅")
# Out:
# Clusters saved to final_clusters.json ✅

# %%
with open("_pairs.jsonl", "w", encoding="utf-8") as f:
    for entry in final_result:
        json.dump(entry, f)
        f.write("\n")
