# %%
import json
def load_json(data_path):
    with open(data_path, "r", encoding="utf-8") as file_1:
        data = json.load(file_1)
    return data

# %%
data = load_json("PO/train/po_train_pairs.json")

# %%
len(data), data[:5]
# Out:
# (2005,
#  [{'ID': 'TR_32576b74',
#    'parent': 'leaf lamina vein',
#    'child': 'primary leaf vein'},
#   {'ID': 'TR_8bdc58cb', 'parent': 'whole plant', 'child': 'thallus'},
#   {'ID': 'TR_e4c6e138', 'parent': 'plant organ', 'child': 'coleorhiza'},
#   {'ID': 'TR_81b052e4', 'parent': 'native plant cell', 'child': 'brachycyte'},
#   {'ID': 'TR_bfbc72dc',
#    'parent': 'inflorescence',
#    'child': 'compound drepanium inflorescence'}])

# %%
from collections import defaultdict

class UnionFind:
    def __init__(self):
        self.parent = {}

    def find(self, x):
        # Path compression
        if x != self.parent.setdefault(x, x):
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        self.parent[self.find(x)] = self.find(y)

def build_clusters(relationships):
    uf = UnionFind()
    
    for rel in relationships:
        parent = rel["parent"]
        child = rel["child"]
        uf.union(parent, child)

    clusters = defaultdict(set)
    for term in set([item for rel in relationships for item in (rel["parent"], rel["child"])]):
        root = uf.find(term)
        clusters[root].add(term)

    # Add isolated nodes (no parent/child relationship)
    all_terms = set()
    for rel in relationships:
        all_terms.add(rel["parent"])
        all_terms.add(rel["child"])
    for term in all_terms:
        if term not in uf.parent:
            clusters[term].add(term)

    return list(clusters.values())

# %%
clusters = build_clusters(data)

# %%
len(clusters)
# Out:
# 75

# %%
clusters
# Out:
# [{'SE.01 one node or internode visible stage',
#   'SE.02 two nodes or internodes visible stage',
#   'SE.03 three nodes or internodes visible stage',
#   'SE.04 four nodes or internodes visible stage',
#   'SE.05 five nodes or internodes visible stage',
#   'SE.06 six nodes or internodes visible stage',
#   'SE.07 seven nodes or internodes visible stage',
#   'SE.09 nine nodes or internodes visible stage',
#   'SE.10 ten nodes or internodes visible stage',
#   'SE.11 eleven nodes or internodes visible stage',
#   'SE.12 twelve nodes or internodes visible stage',
#   'SE.14 fourteen nodes or internodes visible stage',
#   'SE.15 fifteen nodes or internodes visible stage',
#   'SE.97 flag leaf visible stage',
#   'stem elongation stage'},
#  {'PO_0025349',
#   'abaxial nucellar projection',
#   'abaxial protoderm',
#   'abscission zone',
#   'adaxial nucellar projection',
#   'adult vascular leaf',
#   'adventitious root nodule',
#   'aerenchyma',
#   'aerial tuber cortex',
#   'aerial tuber interfascicular region',
#   'aerial tuber periderm',
#   'aerial tuber perimedullary zone',
#   'aerial tuber pith',
#   'alar cell',
#   'albuminous cell',
#   'aleurone layer',
#   'androecium',
#   'anther',
#   'anther dehiscence zone',
#   'anther septum',
#   'anther theca',
#   'anther wall',
#   'anther wall exothecium',
#   'anther wall middle layer',
#   'anther wall outer secondary parietal cell layer',
#   'anther wall primary parietal cell layer',
#   'anther wall secondary parietal cell layer',
#   'anther wall tapetum',
#   'antheridium',
#   'antheridium head',
#   'antheridium jacket layer',
#   'antheridium jacket layer cell',
#   'antheridium microgametophyte',
#   'antheridium sperm cell',
#   'antiraphe',
#   'apical hook',
#   'apical meristem',
#   'archegonium',
#   'archegonium central cell',
#   'archegonium egg cell',
#   'archegonium head',
#   'archegonium megagametophyte',
#   'archegonium neck',
#   'archegonium neck canal cell',
#   'archesporial cell',
#   'archesporium',
#   'aril',
#   'arillode',
#   'arilloid',
#   'articulated laticifer',
#   'axial secondary xylem parenchyma',
#   'axial secondary xylem parenchyma cell',
#   'axillary hair',
#   'axillary hair basal cell',
#   'axillary hair base',
#   'axillary hair terminal cell',
#   'bark',
#   'basal endosperm transfer cell',
#   'berry fruit',
#   'brachycyte',
#   'bract',
#   'bract abaxial epidermis',
#   'bract adaxial epidermis',
#   'bract anlagen',
#   'bract base',
#   'bract epidermis',
#   'bract margin',
#   'bracteole',
#   'branch epidermis',
#   'branch internode differentiation zone',
#   'branch internode elongation zone',
#   'branch stele',
#   'branch trichome',
#   'bulliform cell',
#   'bundle sheath',
#   'bundle sheath cell',
#   'bundle sheath chlorenchyma cell',
#   'callus parenchyma cell',
#   'calyptra corolla',
#   'calyx',
#   'cambial zone',
#   'cambium',
#   'capsule fruit',
#   'cardinal organ part',
#   'cardinal part of multi-tissue plant structure',
#   'carpel',
#   'carpel abaxial epidermis',
#   'carpel adaxial epidermis',
#   'carpel anlagen',
#   'carpel epidermis',
#   'carpel margin',
#   'caruncle',
#   'caryopsis fruit',
#   'caryopsis hull',
#   'cauline leaf',
#   'caulonema',
#   'caulonema cell',
#   'cellular endosperm',
#   'central endosperm',
#   'central root cap',
#   'central root cap of lateral root',
#   'central root cap of primary root',
#   'central strand',
#   'central zone',
#   'central zone of the leaf lamina',
#   'central zone of the petiole',
#   'ceonosorus',
#   'chalaza',
#   'chalazal cyst',
#   'chlorenchyma',
#   'chlorenchyma cell',
#   'chloronema cell',
#   'cigar leaf',
#   'cigar leaf lamina abaxial epidermis',
#   'circumscissile capsule fruit',
#   'coccarium capsule fruit',
#   'coleoptile',
#   'coleorhiza',
#   'collective organ part structure',
#   'collective phyllome structure',
#   'collective plant organ structure',
#   'collective plant structure',
#   'collective tepal structure',
#   'collenchyma',
#   'columella',
#   'columella root cap cell',
#   'coma',
#   'companion cell',
#   'compound leaf',
#   'connective',
#   'cork cambium',
#   'corolla',
#   'corolla spur',
#   'cortex',
#   'cotyledon',
#   'cotyledon abaxial epidermis',
#   'cotyledon adaxial epidermis',
#   'cotyledon anlagen',
#   'cotyledon epidermis',
#   'cotyledon margin',
#   'cultured plant callus',
#   'cultured plant cell',
#   'cultured plant embryo',
#   'cultured somatic plant embryo',
#   'cultured zygote-derived plant embryo',
#   'cuticular wax',
#   'cutin',
#   'dehiscence zone',
#   'drupe fruit',
#   'ear apical meristem',
#   'ear inflorescence axillary meristem',
#   'ear meristem',
#   'ear spikelet meristem',
#   'ear spikelet pair meristem',
#   'early wood tracheary element',
#   'egg apparatus',
#   'embryo basal cell',
#   'embryo coleorhiza',
#   'embryo cortex',
#   'embryo hypocotyl',
#   'embryo hypophysis',
#   'embryo leaf',
#   'embryo mesocotyl',
#   'embryo plant cell',
#   'embryo plant structure',
#   'embryo sac',
#   'embryo sac egg cell',
#   'embryogenic callus',
#   'endocarp',
#   'endodermis cell',
#   'endosperm',
#   'endotegmen',
#   'endotesta',
#   'endothelium',
#   'ensiform vascular leaf',
#   'epiblast',
#   'epicalyx',
#   'epicalyx bract',
#   'epicotyl',
#   'epidermal cork cell',
#   'epidermal rhizoid',
#   'epiphragm',
#   'epithem cell',
#   'exocarp',
#   'exodermis',
#   'exotegmen',
#   'exothecium',
#   'female archesporial cell',
#   'fertile lemma',
#   'filament epidermis',
#   'flag leaf',
#   'floral organ',
#   'floral organ abscission zone',
#   'flower bract',
#   'flower meristem',
#   'flower nectary',
#   'flower pedicel abscission zone',
#   'follicle fruit',
#   'free sepal',
#   'free tepal',
#   'fruit',
#   'fruit columella',
#   'fruit dehiscence zone',
#   'fruit distal end',
#   'fruit pedicel abscission zone',
#   'fruit placenta',
#   'fruit proximal end',
#   'fruit replum',
#   'fruit septum',
#   'fused calyx',
#   'fused collective tepal structure',
#   'fused corolla',
#   'fused perianth',
#   'fused petal',
#   'fused sepal',
#   'fused tepal',
#   'gametophore axillary hair',
#   'gametophore axillary hair basal cell',
#   'gametophore axillary hair base',
#   'gametophore axillary hair terminal cell',
#   'gametophyte coma',
#   'gametophyte perianth',
#   'glume',
#   'glume awn',
#   'glume of ear spikelet',
#   'glume of tassel spikelet',
#   'ground tissue cell',
#   'guard cell',
#   'guard mother cell',
#   'gynoecium',
#   'helobial endosperm',
#   'hesperidium fruit',
#   'hilum',
#   'hydroid',
#   'hyperphyll',
#   'hypocotyl',
#   'hypocotyl epidermis',
#   'hypodermis',
#   'in vitro plant structure',
#   'inflorescence apical meristem',
#   'inflorescence axillary meristem',
#   'inflorescence axis internode',
#   'inflorescence bract',
#   'inflorescence branch pulvinus',
#   'inflorescence meristem',
#   'intercuticular wax',
#   'interfascicular cambium',
#   'interfascicular region',
#   'involucre',
#   'juice sac tissue',
#   'juvenile vascular leaf',
#   'keel',
#   'keel petal',
#   'lamina',
#   'late wood tracheary element',
#   'lateral meristem',
#   'lateral root apical meristem',
#   'lateral root cap',
#   'lateral root cap of lateral root',
#   'lateral root cap of primary root',
#   'lateral root differentiation zone',
#   'lateral root tip',
#   'leaf',
#   'leaf abaxial epidermis',
#   'leaf abaxial pavement cell',
#   'leaf abscission zone',
#   'leaf adaxial epidermis',
#   'leaf aerenchyma',
#   'leaf base',
#   'leaf collar',
#   'leaf epidermis',
#   'leaf guard cell',
#   'leaf lamina',
#   'leaf lamina abaxial epidermis',
#   'leaf lamina adaxial epidermis',
#   'leaf lamina areole',
#   'leaf lamina base',
#   'leaf lamina crena',
#   'leaf lamina epidermis',
#   'leaf lamina lobe',
#   'leaf lamina margin',
#   'leaf margin',
#   'leaf marginal meristem',
#   'leaf mesophyll',
#   'leaf papilla cell',
#   'leaf pavement cell',
#   'leaf plate meristem',
#   'leaf procambial cell',
#   'leaf sheath',
#   'leaf sheath adaxial epidermis',
#   'leaf sheath auricle',
#   'leaf sheath epidermis',
#   'leaf sheath margin',
#   'leaf sheath pulvinus',
#   'leaf tendril',
#   'leaf tip',
#   'leaf-derived cultured plant cell',
#   'leaflet',
#   'leaflet margin',
#   'legume fruit',
#   'lemma',
#   'lemma apiculus',
#   'lemma awn',
#   'lenticel',
#   'leptoid',
#   'leptome',
#   'ligule',
#   'loculicidal capsule fruit',
#   'lodicule',
#   'lodicule anlagen',
#   'loment fruit',
#   'long cell',
#   'long lateral tassel branch meristem',
#   'lower glume',
#   'lower glume of ear spikelet',
#   'lower glume of pedicellate spikelet of ear',
#   'lower glume of pedicellate spikelet of tassel',
#   'lower glume of sessile spikelet of ear',
#   'lower glume of sessile spikelet of tassel',
#   'lower glume of tassel spikelet',
#   'male archesporial cell',
#   'megagametophyte',
#   'megasporangium endothecium',
#   'megasporangium exothecium',
#   'megasporangium tapetum',
#   'megasporangium tapetum cell',
#   'megasporangium wall',
#   'megasporocyte',
#   'megasporophyll',
#   'mericarp',
#   'meristem L1 layer',
#   'meristem L2 layer',
#   'meristem L3 layer',
#   'meristematic cell',
#   'mesocarp',
#   'mesocotyl',
#   'mesophyll',
#   'mesophyll cell',
#   'metaxylem tracheary element',
#   'metaxylem vessel member',
#   'microgametophyte',
#   'micropylar endosperm',
#   'microsporangium',
#   'microsporangium exothecium',
#   'microsporangium tapetum',
#   'microsporangium tapetum cell',
#   'microsporangium wall',
#   'microspore-derived cultured plant embryo',
#   'microsporocyte',
#   'multi-tissue plant structure',
#   'multicellular plant gametangium',
#   'multicellular trichome',
#   'multicellular trichome branch cell',
#   'multicellular trichome tip',
#   'myrosin cell',
#   'native plant cell',
#   'nectary',
#   'nectary epidermis',
#   'nectary parenchyma',
#   'non-hair root epidermal cell',
#   'non-vascular leaf',
#   'nucellar epidermis',
#   'nucellar projection',
#   'nut fruit',
#   'ordinary companion cell',
#   'organogenic callus',
#   'ovuliferous scale ovule',
#   'palea',
#   'palea apiculus',
#   'palea awn',
#   'palisade mesophyll',
#   'palisade mesophyll cell',
#   'palmate leaf',
#   'papilla cell',
#   'pappus',
#   'pappus element',
#   'paraclade cortex',
#   'paraphyllium',
#   'paraphysis',
#   'parenchyma',
#   'parenchyma cell',
#   'pedicel cortex',
#   'peduncle epidermis',
#   'peduncle trichome',
#   'pepo fruit',
#   'perianth',
#   'pericarp',
#   'perichaetal bract',
#   'pericycle',
#   'periderm',
#   'perigonial bract',
#   'perimedullary zone',
#   'peripheral zone',
#   'perisperm',
#   'peristome',
#   'peristome tooth',
#   'persistent sepal',
#   'persistent stamen',
#   'persistent tepal',
#   'petal',
#   'petal abaxial epidermis',
#   'petal adaxial epidermis',
#   'petal apex',
#   'petal base',
#   'petal epidermis',
#   'petal margin',
#   'petal mesophyll',
#   'petal parenchyma',
#   'petal tip',
#   'petiole abaxial epidermis',
#   'petiole cortex',
#   'petiole distal end',
#   'petiole epidermis',
#   'petiole lamina',
#   'petiole margin',
#   'petiole parenchyma',
#   'petiole proximal end',
#   'petiole pulvinus',
#   'phellem',
#   'phelloderm',
#   'phloem sap',
#   'phyllode leaf',
#   'phyllome',
#   'phyllome abaxial meristem',
#   'phyllome adaxial meristem',
#   'phyllome anlagen',
#   'phyllome apex',
#   'phyllome base',
#   'phyllome epidermis',
#   'phyllome founder cell',
#   'phyllome guard cell',
#   'phyllome lamina',
#   'phyllome lamina areole',
#   'phyllome lamina crena',
#   'phyllome lamina lobe',
#   'phyllome lamina tooth',
#   'phyllome margin',
#   'phyllome marginal meristem',
#   'phyllome plate meristem',
#   'phyllome tip',
#   'pinnate leaf',
#   'pistillode',
#   'pith',
#   'placenta',
#   'placentoid',
#   'plant anatomical entity',
#   'plant axis differentiation zone',
#   'plant axis elongation zone',
#   'plant callus',
#   'plant cell',
#   'plant cuticle proper',
#   'plant egg cell',
#   'plant embryo',
#   'plant embryo coleoptile',
#   'plant embryo proper',
#   'plant epidermal cell',
#   'plant epidermis',
#   'plant gall',
#   'plant gamete',
#   'plant organ',
#   'plant organ lamina',
#   'plant organ margin',
#   'plant ovary',
#   'plant ovary epidermis',
#   'plant ovary ovule',
#   'plant ovary placenta',
#   'plant ovary septum',
#   'plant ovary wall',
#   'plant ovary wall middle layer',
#   'plant ovule',
#   'plant ovule inner integument',
#   'plant ovule integument',
#   'plant ovule outer integument',
#   'plant sap',
#   'plant sperm cell',
#   'plant structure',
#   'plant zygote',
#   'plerome',
#   'pollen sac',
#   'pollen sperm cell',
#   'pollen tube cell',
#   'pome fruit',
#   'portion of embryo plant tissue',
#   'portion of ground tissue',
#   'portion of meristem tissue',
#   'portion of plant substance',
#   'portion of plant tissue',
#   'portion of secretory tissue',
#   'portion of transfusion tissue',
#   'portion of transmitting tissue',
#   'primary parietal cell',
#   'primary phloem sieve cell',
#   'primary phloem sieve element',
#   'primary root differentiation zone',
#   'primary root elongation zone',
#   'primary root tip',
#   'primary sporogenous cell',
#   'primary xylem tracheary element',
#   'primary xylem vessel member',
#   'procambial cell',
#   'procumbent ray secondary xylem parenchyma cell',
#   'prophyll',
#   'prophyll margin',
#   'prophyll tendril',
#   'protective layer',
#   'prothallial cell',
#   'protoderm',
#   'protonema',
#   'protosporangium endothecium',
#   'protoxylem tracheary element',
#   'pseudostem',
#   'pulvinus',
#   'quiescent center',
#   'raphe',
#   'ray secondary xylem parenchyma',
#   'ray secondary xylem parenchyma cell',
#   'receptacle cortex',
#   'reproductive shoot apical meristem',
#   'resin cell',
#   'rhizoid',
#   'rhizome internode',
#   'rib zone',
#   'root aerenchyma',
#   'root anlagen',
#   'root apical meristem',
#   'root cap',
#   'root cap of lateral root',
#   'root cap of primary root',
#   'root cork cambium',
#   'root cortex',
#   'root differentiation zone',
#   'root elongation zone',
#   'root epidermal cell',
#   'root epidermis',
#   'root giant cell',
#   'root hair cell',
#   'root lateral meristem',
#   'root meristem',
#   'root nodule',
#   'root nodule meristem',
#   'root parenchyma',
#   'root periderm',
#   'root periderm scar',
#   'root perimedullary zone',
#   'root pith',
#   'root secondary thickening meristem',
#   'root stele',
#   'root syncytium cell',
#   'root system phloem sap',
#   'root system xylem sap',
#   'root tip',
#   'root vascular cambium',
#   'root-derived cultured plant cell',
#   'rosette leaf',
#   'salt gland',
#   'samara fruit',
#   'scale leaf margin',
#   'schizocarp fruit',
#   'sclerenchyma',
#   'scutellar epithelium',
#   'scutellum',
#   'secondary phloem sieve cell',
#   'secondary phloem sieve element',
#   'secondary thickening meristem',
#   'secondary xylem parenchyma',
#   'secondary xylem parenchyma cell',
#   'secondary xylem tracheary element',
#   'secondary xylem tracheid',
#   'secondary xylem vessel member',
#   'seed',
#   'seed chalaza',
#   'seed coat',
#   'seed coat epidermis',
#   'seed funicle',
#   'seed obturator',
#   'seed operculum',
#   'seed raphe',
#   'seed trichome',
#   'seedling',
#   'seedling coleoptile',
#   'seedling coleorhiza',
#   'seedling cotyledon',
#   'seedling epicotyl',
#   'seedling hypocotyl',
#   'seedling mesocotyl',
#   'sepal',
#   'sepal abaxial epidermis',
#   'sepal anlagen',
#   'sepal apex',
#   'sepal base',
#   'sepal epidermis',
#   'sepal epidermis giant cell',
#   'sepal margin',
#   'sepal mesophyll',
#   'sepal parenchyma',
#   'sepal tip',
#   'separation layer',
#   'septicidal capsule fruit',
#   'septum',
#   'shoot apical meristem',
#   'shoot axis cambial zone',
#   'shoot axis cork cambium',
#   'shoot axis cortex',
#   'shoot axis epidermis',
#   'shoot axis hypodermis',
#   'shoot axis internode',
#   'shoot axis internode elongation zone',
#   'shoot axis periderm',
#   'shoot axis perimedullary zone',
#   'shoot axis pith',
#   'shoot axis stele',
#   'shoot axis tegument layer',
#   'shoot axis trichome',
#   'shoot axis tuber epidermis',
#   'shoot axis tuber periderm',
#   'shoot epidermal cell',
#   'shoot epidermal pavement cell',
#   'shoot internode differentiation zone',
#   'shoot system epidermis',
#   'shoot system meristem',
#   'shoot system phloem sap',
#   'shoot-borne root epidermis',
#   'short cell',
#   'short tassel branch meristem',
#   'sieve cell',
#   'sieve element',
#   'silica cell',
#   'silk',
#   'silk scar',
#   'simple leaf',
#   'somatic plant embryo',
#   'sorus',
#   'spikelet meristem',
#   'spikelet pair meristem',
#   'spine leaf',
#   'spine stipule',
#   'spongy mesophyll',
#   'spongy mesophyll cell',
#   'sporangium',
#   'sporangium theca',
#   'sporangium wall',
#   'sporangium wall endothecium',
#   'spore capsule annulus',
#   'spore capsule calyptra',
#   'spore capsule columella',
#   'spore capsule operculum',
#   'spore capsule valve',
#   'sporocyte',
#   'sporophyll',
#   'sporophyll margin',
#   'sporophyte foot',
#   'stamen anlagen',
#   'stamen epidermis',
#   'stamen margin',
#   'stele',
#   'stem aerenchyma',
#   'stem base',
#   'stem epidermis',
#   'stem hypodermis',
#   'stem internode',
#   'stem internode differentiation zone',
#   'stem internode elongation zone',
#   'stem secondary thickening meristem',
#   'stem stele',
#   'stem tegument layer',
#   'stem trichome',
#   'stereid',
#   'stereome',
#   'sterile lemma',
#   'stigma',
#   'stigma epidermis',
#   'stigma papilla cell',
#   'stipel',
#   'stipule',
#   'strophiole',
#   'style',
#   'style epidermis',
#   'subsidiary cell',
#   'subterranean tuber cortex',
#   'subterranean tuber epidermis',
#   'subterranean tuber interfascicular region',
#   'subterranean tuber periderm',
#   'subterranean tuber pith',
#   'suspensor',
#   'tapetum',
#   'tapetum cell',
#   'tassel apical meristem',
#   'tassel inflorescence axillary meristem',
#   'tassel meristem',
#   'tassel spikelet meristem',
#   'tassel spikelet pair meristem',
#   'tepal',
#   'tepal abaxial epidermis',
#   'tepal adaxial epidermis',
#   'tepal apex',
#   'tepal base',
#   'tepal epidermis',
#   'tepal margin',
#   'tepal tip',
#   'terete vascular leaf',
#   'testa',
#   'tetrad of megaspores',
#   'tetrad of microspores',
#   'thallus',
#   'tile cell',
#   'tmema',
#   'tmema cell',
#   'tracheary element',
#   'tracheid',
#   'transfer cell',
#   'transfer companion cell',
#   'transition phyllode leaf',
#   'transition vascular leaf',
#   'transition zone',
#   'trichoblast',
#   'trichome',
#   'trichome apex',
#   'trichome cell',
#   'trichome tip',
#   'tuber cortex',
#   'tuber interfascicular region',
#   'tuber perimedullary zone',
#   'tuber pith',
#   'tubercle',
#   'unicellular plant gametangium',
#   'unicellular trichome',
#   'unifacial vascular leaf',
#   'upright ray secondary xylem parenchyma cell',
#   'utricle capsule fruit',
#   'valve',
#   'vascular cambium',
#   'vascular leaf',
#   'vascular leaf abaxial meristem',
#   'vascular leaf adaxial meristem',
#   'vascular leaf founder cell',
#   'velamen',
#   'venter',
#   'whole plant',
#   'wing petal',
#   'xylem sap',
#   'xylem vessel member',
#   'zygotic plant embryo'},
#  {'PO_0000055',
#   'aerial tuber axillary vegetative bud',
#   'areole bud',
#   'axillary bud',
#   'axillary flower bud',
#   'axillary inflorescence bud',
#   'axillary reproductive bud',
#   'axillary shoot system',
#   'axillary strobilus bud',
#   'axillary vegetative bud',
#   'bostryx inflorescence',
#   'bulb',
#   'capitulum inflorescence',
#   'catkin inflorescence',
#   'cincinnus inflorescence',
#   'compound cincinnus inflorescence',
#   'compound drepanium inflorescence',
#   'compound raceme inflorescence',
#   'compound spike inflorescence',
#   'compound umbel inflorescence',
#   'corm',
#   'corymb inflorescence',
#   'cyme inflorescence',
#   'determinate thyrse inflorescence',
#   'disk flower',
#   'ear floret',
#   'ear inflorescence',
#   'ear infructescence',
#   'ear sessile spikelet',
#   'ear spikelet',
#   'flower',
#   'flower bud',
#   'gametophore',
#   'gametophore bud',
#   'indeterminate thyrse inflorescence',
#   'inflorescence',
#   'inflorescence branch crown',
#   'inflorescence bud',
#   'infructescence',
#   'long shoot',
#   'lower floret of pedicellate spikelet of ear',
#   'lower floret of pedicellate spikelet of tassel',
#   'lower floret of sessile spikelet of ear',
#   'lower floret of sessile spikelet of tassel',
#   'megasporangiate strobilus',
#   'microsporangiate strobilus',
#   'pistillate flower',
#   'pistillate inflorescence',
#   'primary shoot system',
#   'ray flower',
#   'reproductive bud',
#   'reproductive shoot system',
#   'rhipidium inflorescence',
#   'second order inflorescence',
#   'second order infructescence',
#   'shoot axis tuber axillary vegetative bud',
#   'shoot system',
#   'shoot-borne shoot system',
#   'spike inflorescence',
#   'spikelet',
#   'spikelet floret',
#   'staminate flower',
#   'staminate inflorescence',
#   'strobilus',
#   'strobilus bud',
#   'subterranean tuber axillary vegetative bud',
#   'tassel floret',
#   'tassel inflorescence',
#   'tassel pedicellate spikelet',
#   'tassel spikelet',
#   'terminal bud',
#   'terminal flower bud',
#   'terminal inflorescence bud',
#   'terminal reproductive bud',
#   'terminal strobilus bud',
#   'terminal vegetative bud',
#   'umbel inflorescence',
#   'upper floret of pedicellate spikelet of ear',
#   'upper floret of pedicellate spikelet of tassel',
#   'upper floret of sessile spikelet of ear',
#   'upper floret of sessile spikelet of tassel',
#   'vegetative bud',
#   'vegetative shoot system'},
#  {'anther primordium',
#   'basal root primordium',
#   'bract primordium',
#   'carpel primordium',
#   'cotyledon primordium',
#   'floral organ primordium',
#   'flower bract primordium',
#   'gynoecium primordium',
#   'leaflet primordium',
#   'lodicule primordium',
#   'ovule primordium',
#   'petal primordium',
#   'phyllome primordium',
#   'primordium',
#   'root primordium',
#   'sepal primordium',
#   'shoot-borne root primordium',
#   'stamen primordium',
#   'vascular leaf primordium',
#   'vascular leaf primordium abaxial side',
#   'vascular leaf primordium adaxial side'},
#  {'anther vascular system',
#   'carpel vascular system',
#   'centarch protoxylem',
#   'compression wood',
#   'cotyledon vascular system',
#   'diarch protoxylem',
#   'early wood',
#   'exarch protoxylem',
#   'filament vascular system',
#   'flower vascular system',
#   'fruit vascular system',
#   'growth ring',
#   'growth ring boundary',
#   'heartwood',
#   'hypocotyl vascular system',
#   'late wood',
#   'leaf lamina vascular system',
#   'mesarch protoxylem',
#   'metaxylem',
#   'pedicel vascular system',
#   'pentarch protoxylem',
#   'petal vascular system',
#   'petiole vascular system',
#   'phyllome vascular system',
#   'plant embryo vascular system',
#   'portion of vascular tissue',
#   'primary vascular tissue',
#   'primary xylem',
#   'primary xylem vessel',
#   'protoxylem',
#   'ray system',
#   'reaction wood',
#   'root system exarch protoxylem',
#   'root vascular system',
#   'sapwood',
#   'scutellum vascular system',
#   'secondary vascular tissue',
#   'secondary xylem',
#   'secondary xylem vessel',
#   'sepal vascular system',
#   'shoot axis vascular system',
#   'shoot system exarch protoxylem',
#   'shoot system vascular system',
#   'stamen vascular system',
#   'stigma vascular system',
#   'tepal vascular system',
#   'tetrarch protoxylem',
#   'triarch protoxylem',
#   'vascular system',
#   'xylem',
#   'xylem vessel'},
#  {'upper glume',
#   'upper glume of ear spikelet',
#   'upper glume of pedicellate spikelet of ear',
#   'upper glume of pedicellate spikelet of tassel',
#   'upper glume of sessile spikelet of ear',
#   'upper glume of sessile spikelet of tassel',
#   'upper glume of tassel spikelet'},
#  {'1 main shoot growth stage',
#   '1 pattern formation stage',
#   '2 endoreduplication stage',
#   '2 formation of axillary shoot stage',
#   '2.01 main shoot and axillary shoots visible at one node stage',
#   '2.02 main shoot and axillary shoots visible at two nodes stage',
#   '2.04 main shoot and axillary shoots visible at four nodes stage',
#   '2.05 main shoot and axillary shoots visible at five nodes stage',
#   '2.06 main shoot and axillary shoots visible at six nodes stage',
#   '2.07 main shoot and axillary shoots visible at seven nodes stage',
#   '2.08 main shoot and axillary shoots visible at eight nodes stage',
#   '2.09 main shoot and axillary shoots visible at nine or more nodes stage',
#   '3 branch formation stage',
#   'A megaspore mother cell enlarges stage',
#   'A microsporogenous mass stage',
#   'B meiosis of megaspore mother cell stage',
#   'BFO_0000015',
#   'C callose wall formation in pollen mother cells stage',
#   'C tetrad of megaspores stage',
#   'D megaspore degeneration stage',
#   'D pollen mother cell meiosis stage',
#   'FL.00 first flower(s) open stage',
#   'FL.02 1/2 of flowers open stage',
#   'FL.03 3/4 of flowers open stage',
#   'FL.04 end of flowering stage',
#   'G early unicellular microspore stage',
#   'H late unicellular microspore stage',
#   'I first mitotic division stage',
#   'IL.00 inflorescence just visible stage',
#   'J bicellular pollen stage',
#   'LP.01 one leaf visible stage',
#   'LP.03 three leaves visible stage',
#   'LP.07 seven leaves visible stage',
#   'LP.08 eight leaves visible stage',
#   'LP.10 ten leaves visible stage',
#   'LP.11 eleven leaves visible stage',
#   'LP.12 twelve leaves visible stage',
#   'LP.13 thirteen leaves visible stage',
#   'LP.14 fourteen leaves visible stage',
#   'LP.15 fifteen leaves visible stage',
#   'LP.16 sixteen leaves visible stage',
#   'LP.17 seventeen leaves visible stage',
#   'LP.18 eighteen leaves visible stage',
#   'LP.19 nineteen leaves visible stage',
#   'LP.20 twenty or more leaves whorls visible stage',
#   'bud development stage',
#   'cell death stage of secondary xylem',
#   'cell differentiation stage of secondary xylem',
#   'cell division stage of secondary xylem',
#   'chalazal and micropylar domain establishment stage',
#   'coleoptile emergence stage',
#   'collective plant organ structure development stage',
#   'developing seed stage',
#   'dry seed stage',
#   'early rosette growth stage',
#   'early whole plant fruit ripening stage',
#   'endosperm development stage',
#   'epicotyl emergence stage',
#   'fertilized ovule stage',
#   'floral organ differentiation stage',
#   'floral organ formation stage',
#   'floral organ meristem development stage',
#   'floral organ primordium development stage',
#   'formation of aleurone and starchy layers stage',
#   'fruit development stage',
#   'fruit formation stage',
#   'fruit initiation stage',
#   'fruit ripening stage',
#   'fruit size 10 to 30% stage',
#   'fruit size 30 to 50% stage',
#   'fruit size 50 to 70% stage',
#   'fruit size 70% to final size stage',
#   'fully expanded lemma stage',
#   'fully expanded lodicule stage',
#   'fully expanded palea stage',
#   'functional specialization of the endosperm stage',
#   'gametophore vegetative whole plant development stage',
#   'gametophyte development stage',
#   'gametophyte reproductive stage',
#   'gametophyte senescent stage',
#   'gametophyte vegetative stage',
#   'late rosette growth stage',
#   'leaf development stage',
#   'leaf production stage',
#   'leaf trichome development stage',
#   'lemma development stage',
#   'lemma differentiation and expansion stage',
#   'lemma primordia visible stage',
#   'lodicule development stage',
#   'lodicule differentiation and expansion stage',
#   'lodicule primordia visible stage',
#   'mature plant embryo stage',
#   'megagametophyte development stage',
#   'microgametophyte development stage',
#   'mid whole plant fruit ripening stage',
#   'multi-tissue plant structure development stage',
#   'palea development stage',
#   'palea primordia visible stage',
#   'phloem development stage',
#   'phyllome development stage',
#   'plant embryo bilateral stage',
#   'plant embryo coleoptilar stage',
#   'plant embryo cotyledonary stage',
#   'plant embryo development stage',
#   'plant embryo dormant stage',
#   'plant embryo globular stage',
#   'plant embryo true leaf formation stage',
#   'plant organ development stage',
#   'plant proembryo stage',
#   'plant spore stage',
#   'plant structure development stage',
#   'plant tissue development stage',
#   'plant zygote stage',
#   'pollen development stage',
#   'primary endosperm cell stage',
#   'protonema whole plant development stage',
#   'rosette growth complete stage',
#   'rosette growth stage',
#   'secondary xylem development stage',
#   'secondary xylem parenchyma cell death stage of secondary xylem',
#   'seed development stage',
#   'seed dormant stage',
#   'seed germination stage',
#   'seed imbibition stage',
#   'seed maturation stage',
#   'seed trichome development stage',
#   'seed trichome initiation stage',
#   'seed trichome maturation stage',
#   'seed trichome secondary wall biosynthesis stage',
#   'seedling development stage',
#   'seedling shoot emergence stage',
#   'shoot system development stage',
#   'sporophyte development stage',
#   'sporophyte dormant stage',
#   'sporophyte reproductive stage',
#   'sporophyte senescent stage',
#   'sporophyte vegetative stage',
#   'thallus vegetative whole plant development stage',
#   'tracheary element death stage of secondary xylem',
#   'trichome development stage',
#   'vascular leaf development stage',
#   'vascular leaf differentiation stage',
#   'vascular leaf post-expansion stage',
#   'vascular leaf senescent stage',
#   'vascular tissue development stage',
#   'whole plant development stage',
#   'whole plant flowering stage',
#   'whole plant fruit development stage',
#   'whole plant fruit formation stage',
#   'whole plant fruit formation stage 10 to 30%',
#   'whole plant fruit formation stage 50 to 70%',
#   'whole plant fruit formation stage 70% to final size',
#   'whole plant fruit ripening complete stage',
#   'whole plant fruit ripening stage',
#   'whole plant inflorescence detectable stage',
#   'xylem development stage'},
#  {'basal root', 'shoot-borne internode root'},
#  {'accessory paraclade',
#   'adventitious shoot axis',
#   'cauline paraclade',
#   'cladode',
#   'ear infructescence axis',
#   'ear spikelet rachilla',
#   'eighth order inflorescence axis',
#   'fifth order inflorescence axis',
#   'first order inflorescence axis',
#   'first order infructescence axis',
#   'first order tassel inflorescence axis',
#   'flower pedicel',
#   'fourth order inflorescence axis',
#   'gametophore axis',
#   'gametophore stem',
#   'gynophore',
#   'higher order inflorescence axis',
#   'inflorescence axis',
#   'inflorescence flower pedicel',
#   'infructescence axis',
#   'pedicel',
#   'pedicel of ear spikelet',
#   'pedicel of tassel spikelet',
#   'plant axis',
#   'plant embryo axis',
#   'pseudopodium',
#   'rachilla of pedicellate spikelet of ear',
#   'rachilla of pedicellate spikelet of tassel',
#   'rachilla of sessile spikelet of tassel',
#   'rosette paraclade',
#   'second order inflorescence axis',
#   'shoot axis',
#   'shoot axis tuber',
#   'spikelet pedicel',
#   'spikelet rachilla',
#   'stem',
#   'stem apex tendril',
#   'subterranean shoot axis tuber',
#   'tassel inflorescence branch',
#   'tassel spikelet rachilla',
#   'third order inflorescence axis',
#   'tuber',
#   'tuberous root tuber'},
#  {'fifth order infructescence axis',
#   'fourth order infructescence axis',
#   'higher order infructescence axis',
#   'ninth order infructescence axis',
#   'second order infructescence axis',
#   'sixth order infructescence axis',
#   'third order infructescence axis'},
#  {'B formation of primary parietal and sporogenous cells stage',
#   'D locules established stage',
#   'G anther dehiscence stage',
#   'H anther senescence stage',
#   'androecium development stage',
#   'anther development stage',
#   'calyx development stage',
#   'collective phyllome structure development stage',
#   'corolla development stage',
#   'fully expanded petal stage',
#   'fully expanded sepal stage',
#   'petal primordium visible stage',
#   'sepal differentiation and expansion stage',
#   'sepals enclosing flower bud stage',
#   'sepals enclosing meristem stage',
#   'stamen primordium visible stage'},
#  {'leaf abaxial stomatal complex',
#   'leaf adaxial stomatal complex',
#   'leaf stomatal complex',
#   'petiole stomatal complex'},
#  {'axil', 'bract axil', 'branch axil', 'leaf axil'},
#  {'anther pore',
#   'hydathode pore',
#   'intercellular space',
#   'leaf mesophyll intercellular space',
#   'leaf sinus',
#   'leaf stomatal pore',
#   'leaf substomatal cavity',
#   'palisade mesophyll intercellular space',
#   'phyllome sinus',
#   'phyllome stomatal pore',
#   'phyllome substomatal cavity',
#   'plant anatomical space',
#   'plant ovule micropyle',
#   'seed micropyle',
#   'spongy mesophyll intercellular space',
#   'spore capsule mouth',
#   'stomatal pore',
#   'stomium',
#   'substomatal cavity'},
#  {'internal phloem',
#   'metaphloem',
#   'phloem',
#   'primary phloem',
#   'protophloem',
#   'secondary phloem',
#   'sieve tube'},
#  {'branch node',
#   'cotyledonary node',
#   'inflorescence axis node',
#   'scutellar node',
#   'shoot axis node',
#   'stem node'},
#  {'antheridiophore',
#   'antheridium stalk',
#   'archegoniophore',
#   'archegonium stalk',
#   'funicle',
#   'petiole',
#   'petiolule',
#   'seta',
#   'stalk'},
#  {'crown root',
#   'prop root',
#   'shoot-borne nodal root',
#   'shoot-borne root',
#   'shoot-borne root spine'},
#  {'archegonium initial cell',
#   'columella root cap initial cell',
#   'cortex-endodermis initial cell',
#   'epidermal rhizoid initial cell',
#   'initial cell',
#   'lateral root cap epidermal initial cell',
#   'non-vascular leaf initial cell',
#   'plant epidermal initial cell',
#   'protonema side branch initial cell',
#   'protonema sub-apical initial cell',
#   'protonemal side branch rhizoid initial cell',
#   'root initial cell',
#   'stomatal initial cell'},
#  {'axillary bud meristem',
#   'shoot axis tuber axillary bud meristem',
#   'subterranean tuber axillary bud meristem'},
#  {'vascular leaf anlagen formation stage',
#   'vascular leaf initiation stage',
#   'vascular leaf primordium formation stage',
#   'vascular leaf primordium polarity determination stage'},
#  {'articulated laticifer cell', 'laticifer cell'},
#  {'bract stomatal complex',
#   'carpel stomatal complex',
#   'petal stomatal complex',
#   'phyllome stomatal complex',
#   'sepal stomatal complex',
#   'stamen stomatal complex',
#   'stomatal complex',
#   'tepal stomatal complex'},
#  {'branch apex',
#   'plumule',
#   'reproductive shoot apex',
#   'shoot axis apex',
#   'vegetative shoot apex'},
#  {'1 root primordium formation stage',
#   '2 root meristem formation stage',
#   '3 establishment of tissue systems stage',
#   '4 root elongation stage',
#   '5 root hair formation stage',
#   'coleorhiza emergence stage',
#   'lateral root primordium formation stage',
#   'primary root primordium formation stage',
#   'radicle emergence stage',
#   'root cap formation stage',
#   'root cortex differentiation stage',
#   'root development stage',
#   'root vascular cylinder differentiation stage'},
#  {'abaxial petiole canal',
#   'adaxial petiole canal',
#   'archegonium neck canal',
#   'canal',
#   'hilum groove',
#   'petiole canal',
#   'resin canal'},
#  {'lateral leaf vein', 'secondary leaf vein'},
#  {'fiber tracheid',
#   'gelatinous fiber cell',
#   'libriform fiber cell',
#   'phloem fiber cell',
#   'plant fiber cell',
#   'septate fiber cell',
#   'septate fiber tracheid',
#   'septate libriform fiber cell',
#   'septate phloem fiber cell',
#   'xylem fiber cell'},
#  {'embryo root', 'radicle', 'seedling radicle', 'seminal root'},
#  {'cambial initial cell', 'phloem mother cell', 'ray initial cell'},
#  {'leaf lamina intramarginal vein',
#   'leaf lamina vein',
#   'leaf midvein',
#   'pericarp vascular bundle',
#   'petiole vascular bundle',
#   'phyllome lamina vein',
#   'primary leaf vein',
#   'quaternary leaf vein',
#   'vascular bundle'},
#  {'embryo endodermis',
#   'endodermis',
#   'hypocotyl endodermis',
#   'leaf endodermis',
#   'root endodermis',
#   'shoot axis endodermis'},
#  {'lateral root',
#   'lateral root spine',
#   'non-pericyclic lateral root',
#   'pericyclic lateral root',
#   'pneumatophore'},
#  {'leaf prickle', 'prickle', 'root prickle', 'shoot axis prickle'},
#  {'formation of ligule primordium stage',
#   'formation of vascular leaflet primordia stage',
#   'vascular leaf expansion stage'},
#  {'antipodal cell',
#   'embryo sac cell',
#   'embryo sac central cell',
#   'primary endosperm cell',
#   'synergid'},
#  {'bud scale leaf', 'scale leaf'},
#  {'bract trichome',
#   'carpel trichome',
#   'leaf abaxial trichome',
#   'leaf adaxial trichome',
#   'leaf trichome',
#   'petal trichome',
#   'phyllome trichome',
#   'sepal trichome',
#   'stamen trichome',
#   'tepal trichome'},
#  {'degenerate megaspore',
#   'functional megaspore',
#   'megaspore',
#   'microspore',
#   'plant spore'},
#  {'branch', 'branch tendril', 'gametophore branch', 'stolon'},
#  {'anther locule',
#   'fruit locule',
#   'locule',
#   'plant ovary locule',
#   'sporangium locule'},
#  {'lateral root primordium',
#   'non-pericyclic lateral root primordium',
#   'pericyclic lateral root primordium'},
#  {'carpel primordium visible stage',
#   'closure of carpel(s) stage',
#   'gynoecium development stage',
#   'gynoecium differentiation and expansion stage',
#   'ovule development stage',
#   'ovule primordium visible stage',
#   'stigma cell differentiation stage'},
#  {'fruit pedicel', 'infructescence fruit pedicel'},
#  {'branch procambium',
#   'leaf procambium',
#   'procambium',
#   'root procambium',
#   'shoot axis procambium',
#   'shoot procambium',
#   'stem procambium'},
#  {'IE.00 inflorescence tip just visible above flag leaf sheath stage',
#   'IE.02 1/2 of inflorescence emerged from flag leaf sheath stage',
#   'IE.04 inflorescence fully emerged from flag leaf sheath stage',
#   'inflorescence emergence stage'},
#  {'chloronema meristematic apical cell',
#   'embryo apical cell',
#   'gametophore axis meristematic apical cell',
#   'gametophore meristematic apical cell',
#   'gametophyte meristematic apical cell',
#   'leaf meristematic apical cell',
#   'meristematic apical cell',
#   'non-vascular leaf meristematic apical cell',
#   'protonema meristematic apical cell',
#   'rhizoid meristematic apical cell',
#   'root meristematic apical cell',
#   'seta meristematic apical cell',
#   'shoot axis meristematic apical cell',
#   'shoot meristematic apical cell',
#   'sporophyte meristematic apical cell',
#   'thallus meristematic apical cell',
#   'vascular leaf meristematic apical cell',
#   'vascular shoot axis meristematic apical cell'},
#  {'embryo shoot apical meristem', 'vegetative shoot apical meristem'},
#  {'BO.00 booting begins stage',
#   'BO.02 mid boot stage',
#   'BO.03 late boot stage',
#   'BO.04 flag leaf sheath opening stage',
#   'booting stage'},
#  {'flower development stage',
#   'flower meristem transition stage',
#   'flowering stage',
#   'reproductive shoot system development stage'},
#  {'anther wall endothecium', 'microsporangium endothecium'},
#  {'aerial tuber axillary shoot',
#   'subterranean tuber axillary shoot',
#   'tuber axillary shoot'},
#  {'endodermal passage cell', 'exodermal passage cell', 'passage cell'},
#  {'megasporangium', 'nucellus'},
#  {'leaf rachis', 'leaf rachis tendril'},
#  {'aerial tuber storage parenchyma',
#   'endosperm parenchyma',
#   'seed storage parenchyma',
#   'storage parenchyma',
#   'subterranean tuber storage parenchyma',
#   'tuber storage parenchyma'},
#  {'sclerenchyma cell', 'sclerid cell'},
#  {'embryo hypocotyl-root junction',
#   'hypocotyl-root junction',
#   'seedling hypocotyl-root junction'},
#  {'primary phloem sieve tube element',
#   'secondary phloem sieve tube element',
#   'sieve tube element'},
#  {'collective leaf structure', 'rosette'},
#  {'leaf apex', 'leaf apex tendril'},
#  {'plant cuticle', 'plant cuticle ridge'},
#  {'integument initiation stage', 'ovule differentiation and expansion stage'},
#  {'primary thickening meristem', 'shoot lateral meristem'},
#  {'inner integument epidermis',
#   'integument epidermis',
#   'outer integument epidermis'},
#  {'generative cell', 'spermatogenous cell'},
#  {'ear peduncle', 'peduncle'},
#  {'pericycle cell', 'phloem pole pericycle cell', 'xylem pole pericycle cell'},
#  {'intercalary meristem',
#   'leaf intercalary meristem',
#   'stem intercalary meristem'},
#  {'ground meristem',
#   'root system ground meristem',
#   'shoot system ground meristem'},
#  {'inflorescence development stage', 'inflorescence initiation stage'},
#  {'glandular trichome', 'lupulin gland'},
#  {'gametophyte dormant stage', 'plant spore dormant stage'},
#  {'microsporophyll', 'stamen', 'staminode'},
#  {'crown root emergence stage', 'root emergence stage'}]

# %%
# Load a text file in Python
final_content = []
with open("PO/test/po_test_types.txt", "r", encoding="utf-8") as f:
    contents = f.readlines()
    for content in contents:
        final_content.append(content.strip('\n'))


print(contents[:500])  # Print first 500 characters
# Out:
# ['leaf lamina tooth\n', 'parenchyma cell\n', 'vascular leaf initiation stage\n', 'embryo hypocotyl\n', 'basal endosperm transfer layer\n', 'phloem\n', 'phyllome abaxial meristem\n', 'root cap\n', 'socket cell\n', 'root apical meristem\n', 'anthela inflorescence\n', 'axillary hair basal cell\n', 'thorn\n', 'xylem vessel\n', 'seminal root\n', 'root lateral meristem\n', 'microsporophyll\n', 'papilla cell\n', 'megasporangium endothecium\n', 'modified aleurone\n', 'plant axis differentiation zone\n', 'anther theca\n', 'stem base\n', 'tassel spikelet pair meristem\n', 'rhizoid meristematic apical cell\n', 'monarch protoxylem\n', 'endodermis\n', 'sporangium\n', 'portion of vascular tissue\n', 'intermediary companion cell\n', 'axillary inflorescence bud\n', 'root emergence stage\n', 'leaf substomatal cavity\n', 'plant ovule micropyle\n', 'xylem\n', 'scale leaf margin\n', 'seed chalaza\n', 'phyllome development stage\n', 'persistent sepal\n', 'plant structure\n', 'gynoecium ridge\n', 'apical meristem\n', 'embryo apical cell\n', 'leaf vascular system\n', 'intercalary meristem\n', 'leaf adaxial epidermis\n', 'shoot-borne root\n', 'flower pedicel abscission zone\n', 'adaxial nucellar projection\n', 'LP.04 four leaves visible stage\n', 'LP.06 six leaves visible stage\n', 'crown root primordium formation stage\n', 'leaf trichome development stage\n', 'hypocotyl epidermis\n', 'locule\n', 'ear spikelet pair meristem\n', 'root cap of primary root\n', 'megasporangium\n', 'palisade mesophyll intercellular space\n', 'leaf lamina adaxial epidermis\n', 'integument epidermis\n', 'leaf abaxial trichome\n', 'tuberous root tuber\n', 'sieve element\n', 'cambial zone\n', 'drepanium inflorescence\n', 'shoot axis pith\n', '1 root primordium formation stage\n', 'plant ovary wall\n', 'secondary phloem\n', 'seed coat epidermis\n', 'root differentiation zone\n', 'stigma vascular system\n', 'phyllome founder cell\n', 'petiole cortex\n', 'axillary shoot system\n', 'gametophyte reproductive stage\n', 'fused calyx\n', 'ventral canal cell\n', 'vegetative bud\n', 'SE.16 sixteen or more nodes or internodes visible stage\n', 'cotyledon emergence stage\n', 'plant organ margin\n', 'vascular leaf adaxial meristem\n', 'phelloderm\n', 'fruit storage parenchyma\n', 'ear inflorescence axillary meristem\n', 'hypocotyl-root junction\n', 'trichome tip\n', 'lower glume of tassel spikelet\n', 'upper glume\n', 'seedling development stage\n', 'phyllome margin\n', 'root cortex\n', 'plant embryo coleoptile\n', 'stem hypodermis\n', 'sepal parenchyma\n', 'cambial initial cell\n', 'chlorenchyma\n', 'inflorescence axis\n', 'ceonosorus\n', 'peristome tooth\n', 'ear spikelet meristem\n', 'fruit replum\n', 'spikelet pair meristem\n', 'LP.09 nine leaves visible stage\n', 'exotegmen\n', 'seta\n', 'IL.03 full inflorescence length reached stage\n', 'articulated laticifer cell\n', 'septate phloem fiber cell\n', 'basal axillary shoot system\n', 'plant anatomical space\n', 'eighth order infructescence axis\n', 'phyllome primordium\n', 'tuber pith\n', 'fascicular cambium\n', 'callus parenchyma cell\n', 'cotyledonary node rhizoid\n', 'phyllome guard cell\n', 'root initial cell\n', 'developing seed stage\n', 'aerial tuber storage parenchyma\n', 'parenchyma\n', 'unicellular trichome\n', 'sporophyte foot\n', 'tepal margin\n', 'whole plant fruit formation stage\n', 'subterranean tuber pith\n', 'ear meristem\n', 'fiber tracheid\n', 'plant zygote\n', 'peduncle trichome\n', 'phyllome lamina\n', 'BFO_0000040\n', 'mature plant embryo stage\n', 'cardinal organ part\n', 'pericycle cell\n', 'septum\n', 'IL.00 inflorescence just visible stage\n', 'leaf mesophyll intercellular space\n', 'plant organ\n', 'sheath cell\n', 'bud burst stage\n', 'leaf stomatal pore\n', 'tassel inflorescence branch\n', 'spermatogenous cell\n', 'bract\n', 'inflorescence axis internode\n', 'tassel floret\n', 'septate fiber tracheid\n', 'peristome\n', 'fusiform initial cell\n', 'bract base\n', 'plant embryo true leaf formation stage\n', ' ...

# %%
len(contents), contents[0]
# Out:
# (916, 'leaf lamina tooth\n')

# %%
len(final_content), final_content[0]
# Out:
# (916, 'leaf lamina tooth')

# %%
# Step 3: Assign function
from collections import Counter
from tqdm.notebook import tqdm
def assign_term_to_cluster(new_term, clusters):
    new_words = new_term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for term in cluster:
            for word in term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)
    
    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]
    
    if max_score == 0:
        return None  # No match
    return best_cluster_index

# Step 4: Assign all new terms
final_clusters = [set(cluster) for cluster in clusters]  # copy original clusters

for term in tqdm(final_content):
    assigned_idx = assign_term_to_cluster(term, final_clusters)
    if assigned_idx is not None:
        final_clusters[assigned_idx].add(term)
    else:
        # Create new cluster if no match found
        final_clusters.append(set([term]))

# Step 5: Convert to list of lists and return
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

# Display final clusters
for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")
# Out:
#   0%|          | 0/916 [00:00<?, ?it/s]
# Cluster 1: ['SE.01 one node or internode visible stage', 'SE.02 two nodes or internodes visible stage', 'SE.03 three nodes or internodes visible stage', 'SE.04 four nodes or internodes visible stage', 'SE.05 five nodes or internodes visible stage', 'SE.06 six nodes or internodes visible stage', 'SE.07 seven nodes or internodes visible stage', 'SE.09 nine nodes or internodes visible stage', 'SE.10 ten nodes or internodes visible stage', 'SE.11 eleven nodes or internodes visible stage', 'SE.12 twelve nodes or internodes visible stage', 'SE.14 fourteen nodes or internodes visible stage', 'SE.15 fifteen nodes or internodes visible stage', 'SE.97 flag leaf visible stage', 'stem elongation stage']
# Cluster 2: ['PO_0025349', 'abaxial nucellar projection', 'abaxial protoderm', 'abscission zone', 'achene fruit', 'adaxial nucellar projection', 'adaxial protoderm', 'adult vascular leaf', 'adventitious root nodule', 'aerenchyma', 'aerial tuber', 'aerial tuber axillary bud meristem', 'aerial tuber axillary shoot', 'aerial tuber cortex', 'aerial tuber epidermis', 'aerial tuber interfascicular region', 'aerial tuber periderm', 'aerial tuber perimedullary zone', 'aerial tuber pith', 'aerial tuber storage parenchyma', 'alar cell', 'albuminous cell', 'aleurone layer', 'androecium', 'anther', 'anther dehiscence zone', 'anther locule', 'anther septum', 'anther theca', 'anther wall', 'anther wall exothecium', 'anther wall inner secondary parietal cell layer', 'anther wall middle layer', 'anther wall outer secondary parietal cell layer', 'anther wall primary parietal cell layer', 'anther wall secondary parietal cell layer', 'anther wall tapetum', 'anther wall tapetum cell', 'antheridium', 'antheridium head', 'antheridium jacket layer', 'antheridium jacket layer cell', 'antheridium microgametophyte', 'antheridium sperm cell', 'antheridium stalk', 'antiraphe', 'apical hook', 'apical meristem', 'archegonium', 'archegonium central cell', 'archegonium egg cell', 'archegonium head', 'archegonium megagametophyte', 'archegonium neck', 'archegonium neck canal cell', 'archesporial cell', 'archesporium', 'aril', 'arillode', 'arilloid', 'articulated laticifer', 'articulated laticifer cell', 'axial secondary xylem parenchyma', 'axial secondary xylem parenchyma cell', 'axillary bud meristem', 'axillary hair', 'axillary hair basal cell', 'axillary hair base', 'axillary hair terminal cell', 'axillary shoot system', 'banner petal', 'bark', 'basal axillary shoot system', 'basal endosperm transfer cell', 'basal endosperm transfer layer', 'berry fruit', 'body cell', 'brachycyte', 'bract', 'bract abaxial epidermis', 'bract adaxial epidermis', 'bract anlagen', 'bract apex', 'bract base', 'bract epidermis', 'bract margin', 'bract tip', 'bract trichome', 'bracteole', 'branch', 'branch epidermis', 'branch internode', 'branch internode differentiation zone', 'branch internode elongation zone', 'branch node', 'branch stele', 'branch trichome', 'bulliform cell', 'bundle sheath', 'bundle sheath cell', 'bundle sheath chlorenchyma cell', 'bundle sheath extension', 'callus parenchyma cell', 'calyptra calyx', 'calyptra corolla', 'calyx', 'cambial initial cell', 'cambial zone', 'cambium', 'capsule fruit', 'cardinal organ part', 'cardinal part of multi-tissue plant structure', 'carpel', 'carpel abaxial epidermis', 'carpel adaxial epidermis', 'carpel anlagen', 'carpel epidermis', 'carpel margin', 'caruncle', 'caryopsis fruit', 'caryopsis hull', 'cauline axillary shoot', 'cauline leaf', 'caulonema', 'caulonema cell', 'caulonema meristematic apical cell', 'cellular endosperm', 'central endosperm', 'central root cap', 'central root cap of lateral root', 'central root cap of primary root', 'central strand', 'central zone', 'central zone of the leaf lamina', 'central zone of the petiole', 'ceonosorus', 'chalaza', 'chalazal cyst', 'chlorenchyma', 'chlorenchyma cell', 'chloronema', 'chloronema cell', 'cigar leaf', 'cigar leaf lamina abaxial epidermis', 'circumscissile capsule fruit', 'coccarium capsule fruit', 'coleoptile', 'coleorhiza', 'collective leaf structure', 'collective organ part structure', 'collective phyllome structure', 'collective plant organ structure', 'collective plant structure', 'collective tepal structure', 'collenchyma', 'collenchyma cell', 'columella', 'columella root cap cell', 'coma', 'companion cell', 'compound leaf', 'connective', 'cork cambium', 'corolla', 'corolla spur', 'cortex', 'cotyledon', 'cotyledon abaxial epidermis', 'cotyledon adaxial epidermis', 'cotyledon anlagen', 'cotyledon epidermis', 'cotyledon margin', 'cultured plant callus', 'cultured plant cell', 'cultured plant embryo', 'cultured somatic plant embryo', 'cultured zygote-derived plant ...
# Cluster 3: ['PO_0000055', 'aerial tuber axillary vegetative bud', 'anthela inflorescence', 'areole bud', 'axillary bud', 'axillary flower bud', 'axillary inflorescence bud', 'axillary reproductive bud', 'axillary shoot system', 'axillary strobilus bud', 'axillary vegetative bud', 'bostryx inflorescence', 'bulb', 'capitulum inflorescence', 'catkin inflorescence', 'cincinnus inflorescence', 'compound capitulum inflorescence', 'compound cincinnus inflorescence', 'compound drepanium inflorescence', 'compound raceme inflorescence', 'compound spike inflorescence', 'compound umbel inflorescence', 'corm', 'corymb inflorescence', 'cyme inflorescence', 'determinate thyrse inflorescence', 'disk flower', 'drepanium inflorescence', 'ear floret', 'ear inflorescence', 'ear infructescence', 'ear sessile spikelet', 'ear spikelet', 'flower', 'flower bud', 'flower fascicle', 'gametophore', 'gametophore bud', 'indeterminate thyrse inflorescence', 'inflorescence', 'inflorescence bract', 'inflorescence bract primordium', 'inflorescence branch crown', 'inflorescence bud', 'infructescence', 'long shoot', 'lower floret of pedicellate spikelet of ear', 'lower floret of pedicellate spikelet of tassel', 'lower floret of sessile spikelet of ear', 'lower floret of sessile spikelet of tassel', 'megasporangiate strobilus', 'microsporangiate strobilus', 'panicle inflorescence', 'pistillate flower', 'pistillate inflorescence', 'primary shoot system', 'raceme inflorescence', 'ray flower', 'reproductive bud', 'reproductive shoot system', 'rhipidium inflorescence', 'second order inflorescence', 'second order infructescence', 'shoot axis tuber axillary vegetative bud', 'shoot system', 'shoot-borne shoot system', 'spadix inflorescence', 'spike inflorescence', 'spikelet', 'spikelet floret', 'staminate flower', 'staminate inflorescence', 'strobilus', 'strobilus bud', 'subterranean tuber axillary vegetative bud', 'tassel floret', 'tassel inflorescence', 'tassel inflorescence branch', 'tassel pedicellate spikelet', 'tassel spikelet', 'terminal bud', 'terminal flower bud', 'terminal inflorescence bud', 'terminal reproductive bud', 'terminal strobilus bud', 'terminal vegetative bud', 'umbel inflorescence', 'upper floret of pedicellate spikelet of ear', 'upper floret of pedicellate spikelet of tassel', 'upper floret of sessile spikelet of ear', 'upper floret of sessile spikelet of tassel', 'vegetative bud', 'vegetative shoot system']
# Cluster 4: ['androecium primordium', 'anther primordium', 'basal root primordium', 'bract primordium', 'carpel primordium', 'cotyledon primordium', 'floral organ primordium', 'flower bract primordium', 'gynoecium primordium', 'leaflet primordium', 'lodicule primordium', 'ovule primordium', 'petal primordium', 'phyllome primordium', 'primordium', 'root primordium', 'sepal primordium', 'shoot-borne root primordium', 'stamen primordium', 'vascular leaf primordium', 'vascular leaf primordium abaxial side', 'vascular leaf primordium adaxial side']
# Cluster 5: ['anther vascular system', 'axial system', 'carpel vascular system', 'centarch protoxylem', 'compression wood', 'cotyledon vascular system', 'diarch protoxylem', 'early wood', 'endarch protoxylem', 'exarch protoxylem', 'filament vascular system', 'flower vascular system', 'fruit vascular system', 'growth ring', 'growth ring boundary', 'heartwood', 'hypocotyl vascular system', 'included vascular cambium', 'inflorescence vascular system', 'late wood', 'leaf lamina vascular system', 'mesarch protoxylem', 'metaxylem', 'monarch protoxylem', 'pedicel vascular system', 'pentarch protoxylem', 'petal vascular system', 'petiole vascular system', 'phyllome vascular system', 'plant embryo vascular system', 'polyarch protoxylem', 'portion of vascular tissue', 'primary vascular tissue', 'primary xylem', 'primary xylem vessel', 'protoxylem', 'ray system', 'reaction wood', 'root system exarch protoxylem', 'root vascular system', 'sapwood', 'scutellum vascular system', 'secondary vascular tissue', 'secondary xylem', 'secondary xylem vessel', 'sepal vascular system', 'shoot axis vascular system', 'shoot system exarch protoxylem', 'shoot system vascular system', 'stamen vascular system', 'stigma vascular system', 'tension wood', 'tepal vascular system', 'tetrarch protoxylem', 'triarch protoxylem', 'vascular bundle', 'vascular cambium', 'vascular system', 'xylem', 'xylem vessel']
# Cluster 6: ['upper glume', 'upper glume of ear spikelet', 'upper glume of pedicellate spikelet of ear', 'upper glume of pedicellate spikelet of tassel', 'upper glume of sessile spikelet of ear', 'upper glume of sessile spikelet of tassel', 'upper glume of tassel spikelet']
# Cluster 7: ['1 main shoot growth stage', '1 pattern formation stage', '1 root primordium formation stage', '2 endoreduplication stage', '2 formation of axillary shoot stage', '2.01 main shoot and axillary shoots visible at one node stage', '2.02 main shoot and axillary shoots visible at two nodes stage', '2.03 main shoot and axillary shoots visible at three nodes stage', '2.04 main shoot and axillary shoots visible at four nodes stage', '2.05 main shoot and axillary shoots visible at five nodes stage', '2.06 main shoot and axillary shoots visible at six nodes stage', '2.07 main shoot and axillary shoots visible at seven nodes stage', '2.08 main shoot and axillary shoots visible at eight nodes stage', '2.09 main shoot and axillary shoots visible at nine or more nodes stage', '3 branch formation stage', '3 establishment of tissue systems stage', '4 growth directionality stage', '4 root elongation stage', 'A archesporial cells visible stage', 'A megaspore mother cell enlarges stage', 'A microsporogenous mass stage', 'B enlarged microsporocyte stage', 'B meiosis of megaspore mother cell stage', 'BFO_0000015', 'BO.01 early boot stage', 'BO.05 flag leaf sheath opened stage', 'C callose wall formation in pollen mother cells stage', 'C four anther lobes formed stage', 'C tetrad of megaspores stage', 'D megaspore degeneration stage', 'D pollen mother cell meiosis stage', 'E anther wall tapetum degeneration initiated stage', 'E tetrad stage', 'E two nucleate megagametophyte stage', 'F bilocular anther stage', 'F four nucleate megagametophyte stage', 'F microspore release stage', 'FL.00 first flower(s) open stage', 'FL.01 1/4 of flowers open stage', 'FL.02 1/2 of flowers open stage', 'FL.03 3/4 of flowers open stage', 'FL.04 end of flowering stage', 'G early unicellular microspore stage', 'G eight nucleate megagametophyte stage', 'H late unicellular microspore stage', 'I first mitotic division stage', 'IE.01 1/4 of inflorescence emerged from flag leaf sheath stage', 'IE.03 3/4 of inflorescence emerged from flag leaf sheath stage', 'IL.00 inflorescence just visible stage', 'IL.01 1/4 inflorescence length reached stage', 'IL.02 1/2 inflorescence length reached stage', 'IL.03 full inflorescence length reached stage', 'J bicellular pollen stage', 'K second mitotic division stage', 'L mature pollen stage', 'LP.01 one leaf visible stage', 'LP.02 two leaves visible stage', 'LP.03 three leaves visible stage', 'LP.04 four leaves visible stage', 'LP.05 five leaves visible stage', 'LP.06 six leaves visible stage', 'LP.07 seven leaves visible stage', 'LP.08 eight leaves visible stage', 'LP.09 nine leaves visible stage', 'LP.10 ten leaves visible stage', 'LP.11 eleven leaves visible stage', 'LP.12 twelve leaves visible stage', 'LP.13 thirteen leaves visible stage', 'LP.14 fourteen leaves visible stage', 'LP.15 fifteen leaves visible stage', 'LP.16 sixteen leaves visible stage', 'LP.17 seventeen leaves visible stage', 'LP.18 eighteen leaves visible stage', 'LP.19 nineteen leaves visible stage', 'LP.20 twenty or more leaves whorls visible stage', 'M germinated pollen stage', 'SE.00 stem elongation begins stage', 'SE.08 eight nodes or internodes visible stage', 'SE.13 thirteen nodes or internodes visible stage', 'SE.16 sixteen or more nodes or internodes visible stage', 'SE.99 maximum stem length reached stage', 'androecium development stage', 'anther development stage', 'beginning of whole plant fruit ripening stage', 'booting stage', 'bud burst stage', 'bud development stage', 'bud dormancy stage', 'bud swell stage', 'calyx development stage', 'cell death stage of secondary xylem', 'cell differentiation stage of secondary xylem', 'cell division stage of secondary xylem', 'cell expansion stage of secondary xylem', 'chalazal and micropylar domain establishment stage', 'coleoptile emergence stage', 'collective phyllome structure development stage', 'collective plant organ structure development stage', 'corolla development stage', 'cotyledon emergence sta ...
# Cluster 8: ['basal root', 'shoot-borne internode root']
# Cluster 9: ['accessory paraclade', 'adventitious shoot axis', 'cauline paraclade', 'cladode', 'ear infructescence axis', 'ear spikelet rachilla', 'eighth order inflorescence axis', 'eighth order infructescence axis', 'fifth order inflorescence axis', 'first order ear inflorescence axis', 'first order inflorescence axis', 'first order infructescence axis', 'first order tassel inflorescence axis', 'flower pedicel', 'fourth order inflorescence axis', 'gametophore axis', 'gametophore stem', 'gynophore', 'higher order inflorescence axis', 'higher order infructescence axis', 'inflorescence axis', 'inflorescence axis node', 'inflorescence flower pedicel', 'infructescence axis', 'ninth order inflorescence axis', 'pedicel', 'pedicel of ear spikelet', 'pedicel of tassel spikelet', 'plant axis', 'plant embryo axis', 'pseudopodium', 'rachilla of pedicellate spikelet of ear', 'rachilla of pedicellate spikelet of tassel', 'rachilla of sessile spikelet of tassel', 'rosette paraclade', 'second order inflorescence axis', 'second order infructescence', 'seventh order inflorescence axis', 'seventh order infructescence axis', 'shoot axis', 'shoot axis tuber', 'sixth order inflorescence axis', 'spikelet pedicel', 'spikelet rachilla', 'stem', 'stem apex tendril', 'subterranean shoot axis tuber', 'tassel inflorescence branch', 'tassel spikelet rachilla', 'tenth order inflorescence axis', 'tenth order infructescence axis', 'third order inflorescence axis', 'tuber', 'tuberous root tuber']
# Cluster 10: ['fifth order infructescence axis', 'fourth order infructescence axis', 'higher order infructescence axis', 'ninth order infructescence axis', 'second order infructescence axis', 'sixth order infructescence axis', 'third order infructescence axis']
# Cluster 11: ['B formation of primary parietal and sporogenous cells stage', 'D locules established stage', 'G anther dehiscence stage', 'H anther senescence stage', 'androecium development stage', 'anther development stage', 'calyx development stage', 'collective phyllome structure development stage', 'corolla development stage', 'fully expanded petal stage', 'fully expanded sepal stage', 'petal primordium visible stage', 'sepal differentiation and expansion stage', 'sepals enclosing flower bud stage', 'sepals enclosing meristem stage', 'stamen primordium visible stage']
# Cluster 12: ['leaf abaxial stomatal complex', 'leaf adaxial stomatal complex', 'leaf stomatal complex', 'petiole stomatal complex']
# Cluster 13: ['axil', 'bract axil', 'branch axil', 'leaf axil']
# Cluster 14: ['anther pore', 'hydathode', 'hydathode pore', 'intercellular space', 'leaf mesophyll intercellular space', 'leaf sinus', 'leaf stomatal pore', 'leaf substomatal cavity', 'palisade mesophyll intercellular space', 'phyllome sinus', 'phyllome stomatal pore', 'phyllome substomatal cavity', 'plant anatomical space', 'plant ovule micropyle', 'seed micropyle', 'spongy mesophyll intercellular space', 'spore capsule mouth', 'stomatal pore', 'stomium', 'substomatal cavity']
# Cluster 15: ['internal phloem', 'metaphloem', 'phloem', 'primary phloem', 'protophloem', 'secondary phloem', 'sieve tube']
# Cluster 16: ['branch node', 'cotyledonary node', 'cotyledonary node rhizoid', 'inflorescence axis node', 'scutellar node', 'shoot axis node', 'stem node']
# Cluster 17: ['antheridiophore', 'antheridium stalk', 'archegoniophore', 'archegonium stalk', 'funicle', 'petiole', 'petiolule', 'seta', 'stalk']
# Cluster 18: ['crown root', 'prop root', 'shoot-borne nodal root', 'shoot-borne root', 'shoot-borne root spine']
# Cluster 19: ['archegonium initial cell', 'columella root cap initial cell', 'cortex-endodermis initial cell', 'epidermal rhizoid initial cell', 'initial cell', 'lateral root cap epidermal initial cell', 'non-vascular leaf initial cell', 'plant epidermal initial cell', 'protonema side branch initial cell', 'protonema sub-apical initial cell', 'protonemal side branch rhizoid initial cell', 'root initial cell', 'stomatal initial cell']
# Cluster 20: ['axillary bud meristem', 'shoot axis tuber axillary bud meristem', 'subterranean tuber axillary bud meristem']
# Cluster 21: ['vascular leaf anlagen formation stage', 'vascular leaf initiation stage', 'vascular leaf primordium formation stage', 'vascular leaf primordium polarity determination stage']
# Cluster 22: ['articulated laticifer cell', 'laticifer cell']
# Cluster 23: ['bract stomatal complex', 'carpel stomatal complex', 'petal stomatal complex', 'phyllome stomatal complex', 'sepal stomatal complex', 'stamen stomatal complex', 'stomatal complex', 'tepal stomatal complex']
# Cluster 24: ['branch apex', 'plumule', 'reproductive shoot apex', 'shoot axis apex', 'vegetative shoot apex']
# Cluster 25: ['1 root primordium formation stage', '2 root meristem formation stage', '3 establishment of tissue systems stage', '4 root elongation stage', '5 root hair formation stage', 'coleorhiza emergence stage', 'lateral root primordium formation stage', 'primary root primordium formation stage', 'radicle emergence stage', 'root cap formation stage', 'root cortex differentiation stage', 'root development stage', 'root vascular cylinder differentiation stage']
# Cluster 26: ['abaxial petiole canal', 'adaxial petiole canal', 'archegonium neck canal', 'canal', 'hilum groove', 'petiole canal', 'resin canal']
# Cluster 27: ['lateral leaf vein', 'secondary leaf vein']
# Cluster 28: ['fiber tracheid', 'gelatinous fiber cell', 'libriform fiber cell', 'phloem fiber cell', 'plant fiber cell', 'septate fiber cell', 'septate fiber tracheid', 'septate libriform fiber cell', 'septate phloem fiber cell', 'xylem fiber cell']
# Cluster 29: ['embryo root', 'radicle', 'seedling radicle', 'seminal root']
# Cluster 30: ['cambial initial cell', 'phloem mother cell', 'ray initial cell']
# Cluster 31: ['leaf lamina intramarginal vein', 'leaf lamina vein', 'leaf midvein', 'pericarp vascular bundle', 'petiole vascular bundle', 'phyllome lamina vein', 'primary leaf vein', 'quaternary leaf vein', 'vascular bundle']
# Cluster 32: ['embryo endodermis', 'endodermis', 'hypocotyl endodermis', 'leaf endodermis', 'root endodermis', 'shoot axis endodermis']
# Cluster 33: ['lateral root', 'lateral root spine', 'non-pericyclic lateral root', 'pericyclic lateral root', 'pneumatophore']
# Cluster 34: ['leaf prickle', 'prickle', 'root prickle', 'shoot axis prickle']
# Cluster 35: ['formation of ligule primordium stage', 'formation of vascular leaflet primordia stage', 'vascular leaf expansion stage']
# Cluster 36: ['antipodal cell', 'embryo sac cell', 'embryo sac central cell', 'primary endosperm cell', 'synergid']
# Cluster 37: ['bud scale leaf', 'scale leaf']
# Cluster 38: ['bract trichome', 'carpel trichome', 'leaf abaxial trichome', 'leaf adaxial trichome', 'leaf trichome', 'petal trichome', 'phyllome trichome', 'sepal trichome', 'stamen trichome', 'tepal trichome']
# Cluster 39: ['degenerate megaspore', 'functional megaspore', 'megaspore', 'microspore', 'plant spore']
# Cluster 40: ['branch', 'branch tendril', 'gametophore branch', 'stolon']
# Cluster 41: ['anther locule', 'fruit locule', 'locule', 'plant ovary locule', 'sporangium locule']
# Cluster 42: ['lateral root primordium', 'non-pericyclic lateral root primordium', 'pericyclic lateral root primordium']
# Cluster 43: ['carpel primordium visible stage', 'closure of carpel(s) stage', 'gynoecium', 'gynoecium development stage', 'gynoecium differentiation and expansion stage', 'gynoecium ridge', 'ovule development stage', 'ovule primordium visible stage', 'stigma cell differentiation stage']
# Cluster 44: ['fruit pedicel', 'infructescence fruit pedicel']
# Cluster 45: ['branch procambium', 'leaf procambium', 'procambium', 'root procambium', 'shoot axis procambium', 'shoot procambium', 'stem procambium']
# Cluster 46: ['IE.00 inflorescence tip just visible above flag leaf sheath stage', 'IE.02 1/2 of inflorescence emerged from flag leaf sheath stage', 'IE.04 inflorescence fully emerged from flag leaf sheath stage', 'inflorescence emergence stage']
# Cluster 47: ['chloronema meristematic apical cell', 'embryo apical cell', 'gametophore axis meristematic apical cell', 'gametophore meristematic apical cell', 'gametophyte meristematic apical cell', 'leaf meristematic apical cell', 'meristematic apical cell', 'non-vascular leaf meristematic apical cell', 'protonema meristematic apical cell', 'rhizoid meristematic apical cell', 'root meristematic apical cell', 'seta meristematic apical cell', 'shoot axis meristematic apical cell', 'shoot meristematic apical cell', 'sporophyte meristematic apical cell', 'thallus meristematic apical cell', 'vascular leaf meristematic apical cell', 'vascular shoot axis meristematic apical cell']
# Cluster 48: ['embryo shoot apical meristem', 'vegetative shoot apical meristem']
# Cluster 49: ['BO.00 booting begins stage', 'BO.02 mid boot stage', 'BO.03 late boot stage', 'BO.04 flag leaf sheath opening stage', 'booting stage']
# Cluster 50: ['flower development stage', 'flower meristem transition stage', 'flowering stage', 'reproductive shoot system development stage']
# Cluster 51: ['anther wall endothecium', 'microsporangium endothecium']
# Cluster 52: ['aerial tuber axillary shoot', 'subterranean tuber axillary shoot', 'tuber axillary shoot']
# Cluster 53: ['endodermal passage cell', 'exodermal passage cell', 'passage cell']
# Cluster 54: ['megasporangium', 'nucellus']
# Cluster 55: ['leaf rachis', 'leaf rachis tendril']
# Cluster 56: ['aerial tuber storage parenchyma', 'endosperm parenchyma', 'seed storage parenchyma', 'storage parenchyma', 'subterranean tuber storage parenchyma', 'tuber storage parenchyma']
# Cluster 57: ['sclerenchyma cell', 'sclerid cell']
# Cluster 58: ['embryo hypocotyl-root junction', 'hypocotyl-root junction', 'seedling hypocotyl-root junction']
# Cluster 59: ['primary phloem sieve tube element', 'secondary phloem sieve tube element', 'sieve tube element']
# Cluster 60: ['collective leaf structure', 'rosette']
# Cluster 61: ['leaf apex', 'leaf apex tendril']
# Cluster 62: ['plant cuticle', 'plant cuticle ridge']
# Cluster 63: ['integument initiation stage', 'ovule differentiation and expansion stage']
# Cluster 64: ['primary thickening meristem', 'shoot lateral meristem']
# Cluster 65: ['inner integument epidermis', 'integument epidermis', 'outer integument epidermis']
# Cluster 66: ['generative cell', 'spermatogenous cell']
# Cluster 67: ['ear peduncle', 'peduncle']
# Cluster 68: ['pericycle cell', 'phloem pole pericycle cell', 'xylem pole pericycle cell']
# Cluster 69: ['intercalary meristem', 'leaf intercalary meristem', 'stem intercalary meristem']
# Cluster 70: ['ground meristem', 'root system ground meristem', 'shoot system ground meristem']
# Cluster 71: ['inflorescence development stage', 'inflorescence initiation stage']
# Cluster 72: ['glandular trichome', 'lupulin gland']
# Cluster 73: ['gametophyte dormant stage', 'plant spore dormant stage']
# Cluster 74: ['microsporophyll', 'stamen', 'staminode']
# Cluster 75: ['crown root emergence stage', 'root emergence stage']
# Cluster 76: ['thorn']
# Cluster 77: ['BFO_0000040']
# Cluster 78: ['costa']
# Cluster 79: ['pneumatorhiza']
# Cluster 80: ['hypanthium']
# Cluster 81: ['exotesta']
# Cluster 82: ['periblem']
# Cluster 83: ['amphithecium']
# Cluster 84: ['gemma']
# Cluster 85: ['idioblast']
# Cluster 86: ['elaiosome']
# Cluster 87: ['tegmen']
# Cluster 88: ['perigynium']
# Cluster 89: ['hydrome']

# %%
from google import genai
model = "gemini-2.5-pro"
from together import Together
client = Together(api_key="")

# %%
final_ans = []
for i, list_of_elements in tqdm(enumerate(final_clusters_list)):
    if len(list_of_elements)>1:
        prompt = f""""Analyze the following list of biological terms and identify all direct and indirect **parent-child relationships**.

        A **parent-child relationship** exists when one term (the parent) is a broader, more general category or a whole that conceptually encompasses or contains another term (the child). The child term is a more specific instance, a part, or a developmental stage of the parent term.

        **Guidelines for identifying relationships:**
        * **"Is-a" relationship:** e.g., "A 'leaf procambium' **is a** type of 'procambium'." (Parent: procambium, Child: leaf procambium)
        * **"Part-of" relationship:** e.g., "A 'petal' **is part of** a 'flower'." (Parent: flower, Child: petal)
        * **Developmental sequence:** e.g., "'Petal primordium visible stage' **is a stage in** 'petal development'." (Parent: petal development, Child: petal primordium visible stage)
        * **Anatomical hierarchy:** e.g., "'Root endodermis' **is part of** 'root' and **is a type of** 'endodermis'." (Parent: root and endodermis, Child: root endodermis)

        **List of Elements:**
        {list_of_elements}
        **Output Format:**
        Provide the output as a single JSON array. Each element in the array must be a JSON object with two keys: `"parent"` and `"child"`, whose values are the corresponding terms.

        **Example Output (Illustrative, showing the expected JSON structure):**
        {json.dumps({"Answer":[
        {
            "parent": "procambium",
            "child": "branch procambium"
        },
        {
            "parent": "procambium",
            "child": "leaf procambium"
        },
        {
            "parent": "shoot system",
            "child": "axillary shoot system"
        },
        {
            "parent": "flower",
            "child": "petal"
        },
        {
            "parent": "flower development",
            "child": "petal primordium visible stage"
        }
        ]})}
        """
        # generation_config = {"response_mime_type": "application/json"}

        response = client.chat.completions.create(
            model="deepseek-ai/DeepSeek-V3",
            messages=[
            {
                "role": "user",
                "content": prompt
            }
            ]
        )
        final_ans.append(response.choices[0].message.content)
        if i%20==0:
            print(response.choices[0].message.content)
# Out:
# 0it [00:00, ?it/s]
# ```json
# {
#   "Answer": [
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.01 one node or internode visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.02 two nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.03 three nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.04 four nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.05 five nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.06 six nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.07 seven nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.09 nine nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.10 ten nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.11 eleven nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.12 twelve nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.14 fourteen nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.15 fifteen nodes or internodes visible stage"
#     },
#     {
#       "parent": "stem elongation stage",
#       "child": "SE.97 flag leaf visible stage"
#     }
#   ]
# }
# ```
# ```json
# {
#   "Answer": [
#     {
#       "parent": "vascular leaf anlagen formation stage",
#       "child": "vascular leaf initiation stage"
#     },
#     {
#       "parent": "vascular leaf initiation stage",
#       "child": "vascular leaf primordium formation stage"
#     },
#     {
#       "parent": "vascular leaf primordium formation stage",
#       "child": "vascular leaf primordium polarity determination stage"
#     }
#   ]
# }
# ```
# ```json
# {
#   "Answer": [
#     {
#       "parent": "locule",
#       "child": "anther locule"
#     },
#     {
#       "parent": "locule",
#       "child": "fruit locule"
#     },
#     {
#       "parent": "locule",
#       "child": "plant ovary locule"
#     },
#     {
#       "parent": "locule",
#       "child": "sporangium locule"
#     }
#   ]
# }
# ```
# ```json
# {
#   "Answer": [
#     {
#       "parent": "leaf apex",
#       "child": "leaf apex tendril"
#     }
#   ]
# }
# ```

# %%
final_ans = []
for i, list_of_elements in tqdm(enumerate(final_clusters_list)):
    if len(list_of_elements)>1:
        prompt = f""""Analyze the following list of biological terms and identify all direct and indirect **parent-child relationships**.

        A **parent-child relationship** exists when one term (the parent) is a broader, more general category or a whole that conceptually encompasses or contains another term (the child). The child term is a more specific instance, a part, or a developmental stage of the parent term.

        **Guidelines for identifying relationships:**
        * **"Is-a" relationship:** e.g., "A 'leaf procambium' **is a** type of 'procambium'." (Parent: procambium, Child: leaf procambium)
        * **"Part-of" relationship:** e.g., "A 'petal' **is part of** a 'flower'." (Parent: flower, Child: petal)
        * **Developmental sequence:** e.g., "'Petal primordium visible stage' **is a stage in** 'petal development'." (Parent: petal development, Child: petal primordium visible stage)
        * **Anatomical hierarchy:** e.g., "'Root endodermis' **is part of** 'root' and **is a type of** 'endodermis'." (Parent: root and endodermis, Child: root endodermis)

        **List of Elements:**
        {list_of_elements}
        **Output Format:**
        Provide the output as a single JSON array. Each element in the array must be a JSON object with two keys: `"parent"` and `"child"`, whose values are the corresponding terms.

        **Example Output (Illustrative, showing the expected JSON structure):**
        {json.dumps({"Answer":[
        {
            "parent": "procambium",
            "child": "branch procambium"
        },
        {
            "parent": "procambium",
            "child": "leaf procambium"
        },
        {
            "parent": "shoot system",
            "child": "axillary shoot system"
        },
        {
            "parent": "flower",
            "child": "petal"
        },
        {
            "parent": "flower development",
            "child": "petal primordium visible stage"
        }
        ]})}
        """
        generation_config = {"response_mime_type": "application/json"}

        response = client.models.generate_content(
                contents= prompt,
                config=generation_config,
                model=model
            )
        final_ans.append(response.text)
        if i%20==0:
            print(response.text)
# Out:
# 0it [00:00, ?it/s]
