# %%
import json
def load_json(data_path):
    with open(data_path, "r", encoding="utf-8") as file_1:
        data = json.load(file_1)
    return data

# %%
data = load_json("FoodOn/train/foodon_train_pairs.json")

# %%
len(data), data[:5]
# Out:
# (53020,
#  [{'ID': 'TR_148e834b', 'parent': 'steroid', 'child': 'steroid hormone'},
#   {'ID': 'TR_b89bbe1d',
#    'parent': 'molecular entity',
#    'child': 'elemental molecular entity'},
#   {'ID': 'TR_a99a497b',
#    'parent': 'florida pompano fillet (skinless)',
#    'child': 'florida pompano fillet (skinless, raw)'},
#   {'ID': 'TR_9edca995',
#    'parent': 'food mix product',
#    'child': 'chicken tetrazzini mix'},
#   {'ID': 'TR_2e4152bf', 'parent': 'carboxylic acid', 'child': 'amino acid'}])

# %%
from collections import defaultdict

class UnionFind:
    def __init__(self):
        self.parent = {}

    def find(self, x):
        # Path compression
        if x != self.parent.setdefault(x, x):
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, x, y):
        self.parent[self.find(x)] = self.find(y)

def build_clusters(relationships):
    uf = UnionFind()
    
    for rel in relationships:
        parent = rel["parent"]
        child = rel["child"]
        uf.union(parent, child)

    clusters = defaultdict(set)
    for term in set([item for rel in relationships for item in (rel["parent"], rel["child"])]):
        root = uf.find(term)
        clusters[root].add(term)

    # Add isolated nodes (no parent/child relationship)
    all_terms = set()
    for rel in relationships:
        all_terms.add(rel["parent"])
        all_terms.add(rel["child"])
    for term in all_terms:
        if term not in uf.parent:
            clusters[term].add(term)

    return list(clusters.values())

# %%
clusters = build_clusters(data)

# %%
len(clusters)
# Out:
# 1086

# %%
clusters
# Out:
# [{'Valerianella',
#   'wombat berry plant',
#   'bone meal wafer',
#   'butchery cut of european anchovy',
#   'Ditammari',
#   'raspberry spread',
#   'piece of dark animal meat',
#   'veal sub-primal cut',
#   'Coleoidea',
#   'chocolate chip ice cream',
#   '10000105 - baby/infant - specialised beverages (shelf stable) (gs1 gpc)',
#   'egg simulated product',
#   'State of Vermont',
#   'pink shrimp (cooked)',
#   'Paeonol',
#   'icicle, no sugar added except lactose',
#   'South Asian',
#   'light purple',
#   'lemon savory plant',
#   'swartzia plant',
#   'Enteroctopus dofleini',
#   'turkey eggshell',
#   'hemp seed (dehulled, raw)',
#   'huckleberry',
#   'sponge crab family',
#   'red cayenne pepper paste',
#   '21870 - cooked bratwurst-type sausage (efsa foodex2)',
#   'piece of animal back',
#   'rainbow smelt (dressed)',
#   'Trachurus japonicus',
#   'cape hope squid',
#   'blackberry pie',
#   'oat flakes',
#   '38080 - mixed supplements/formulations (efsa foodex2)',
#   'kidney bean (canned)',
#   'shrimp and fish frankfurter',
#   'hemp seed (with hull, raw)',
#   'papaya juice (canned)',
#   'gray morel mushroom (raw)',
#   'piece(s) of beef stomach',
#   'Sao Tome and Principe',
#   'swiss and ham roll',
#   'custard dessert food product',
#   'sockeye salmon fillet (skinless, raw)',
#   'Venerida',
#   'pineapple juice (liquid)',
#   'lilac',
#   'stilbenoid',
#   'fruit punch homemade prepared with fruit',
#   'hare (jugged, with vegetables and wine sauce)',
#   'arctic pike (raw)',
#   'Atherina',
#   'barley egg noodle',
#   'common oat cereal food product',
#   'Fratercula cirrhata',
#   'rock shell snail (raw)',
#   'Muraenesox bagio',
#   'vegetable (seasoned with butter, canned)',
#   'pheasant carcass',
#   '10006091 - spinach (gs1 gpc)',
#   'piece of pork stomach (raw)',
#   'glaze (us cfr)',
#   'vegetable soup food product',
#   'mild climatic zone',
#   'beef top round roast (boneless, raw)',
#   'Mourvèdre wine',
#   'Macrobrachium rosenbergii',
#   'cottonseed oil',
#   'weaner pig',
#   'barquillo',
#   'corn snack (puffed, cheese-flavored)',
#   'pepper (liquid)',
#   'antifoaming agent (ec)',
#   'red raspberry',
#   'Ancylopsetta dilecta',
#   'herring tidbit in wine sauce',
#   'lobster (stuffed)',
#   'small-leaved tamarind plant',
#   'flavour enhancer (codex)',
#   'beef steak',
#   'gumbo base (shrimp-flavored)',
#   'bavarian mousse',
#   'grape juice drink',
#   'Uranoscopidae',
#   'garlic (dehydrated)',
#   'Percophis brasiliensis',
#   'queen crab (raw)',
#   'chocolate-coated banana (frozen)',
#   'copper complexes of chlorophyllins',
#   'alimentary paste product',
#   'stevia leaf',
#   'Osmanthus fragrans',
#   '30600 - fudge (efsa foodex2)',
#   'spleen',
#   'Pleuronectes quadrituberculatus',
#   'wine (canned)',
#   'UBERON_0000978',
#   'pennywort juice food product',
#   'clam (frozen)',
#   'mollusc food product',
#   '10006751 - ready-made combination meals - ready to eat (perishable) (gs1 gpc)',
#   'sour cream blue cheese dressing',
#   'iceberg lettuce plant',
#   'spotted fish (fried, canned)',
#   'USDA SR soups, sauces, and gravies (0600)',
#   'Carangidae',
#   'C4-dicarboxylic acid',
#   'piece of goat meat (with bone, raw)',
#   'Ilisha',
#   'Penaeus brevirostris',
#   'bramble berry (raw)',
#   'apple cider (fermented)',
#   'Ganda',
#   'wafer bar sandwich cookie',
#   'animal thigh (skinless, raw)',
#   'glucose derived from amylopectin derived from starch',
#   'Arca noae',
#   'okra seed',
#   'imitation ham-flavored seasoning',
#   'jam, jelly or marmalade substitute',
#   'giant water vine plant',
#   'Merlucciidae',
#   'saltbush plant',
#   '21890 - bockwurst (efsa foodex2)',
#   'diplectrum',
#   'Chaenomeles sinensis',
#   'pumpkin flower',
#   'Dimocarpus longan',
#   'plum wine',
#   'piece of goat (with skin)',
#   'subdivision of organism along appendicular axis',
#   'lamb foreshank',
#   'Macanese',
#   'organic aromatic compound',
#   'mustard seed (raw)',
#   'imitation mozzarella cheese',
#   'red kuri squash plant',
#   'turkey wing (raw)',
#   'piece(s) of giraffe',
#   'silk worm pupae for animal feed',
#   'piece of chicken kidney',
#   'Papua Province',
#   'hawaiian shrimp with pineapple (dish)',
#   'coffee (instant with coffee creamer)',
#   'polymer',
#   'bread mix (low gluten)',
#   'beef chuck (roast cooked)',
#   'piece(s) of guinea fowl',
#   '10006090 - sorrel (gs1 gpc)',
#   'abdominal segment element',
#   'Echinometridae',
#   'Stenodus leucichthys',
#   'retinyl palmitate',
#   'poultry roll (cooked)',
#   'citric acid esters of mono- and diglycerides of fatty acids',
#   'ridge gourd (raw)',
#   'krachai powder',
#   'cracker',
#   'honey cake',
#   'piece of veal spleen (raw)',
#   'butchery cut of beef',
#   '10005833 - beef sausages - prepared/processed (gs1 gpc)',
#   'frozen dairy dessert (artificially sweetened)',
#   'spanish olive (stuffed with spanish sweet pepper)',
#   'imitation cheese',
#   'piece of beefalo (raw)',
#   'heart',
#   'oyster (in shell, raw)',
#   'crispbread (starch-reduced)',
#   'mineral substance as food supplement product category',
#   'cucumber pickle',
#   'sesterterpenoid',
#   'Chanidae',
#   '41190 - herbs/spices sauces (efsa foodex2)',
#   'beef back rib (raw)',
#   'oyster (raw)',
#   'korean red ginseng drink',
#   'caerphilly cheese',
#   'piece(s) of turkey wing (skinless)',
#   'american cheese',
#   '50122100 - shellfish prepared/processed (gs1 gpc)',
#   'plant based refined or partially-refined food product',
#   'beef chuck flap/edge roast',
#   'tomato multi-component product',
#   'lobster carcass (raw)',
#   'Rana <genus>',
#   'Cancer',
#   'pistachio nut',
#   'shake mix (artificially sweetened, dry)',
#   'old road oyster mushroom (raw)',
#   'jam mix',
#   'fruit preparation (energy reduced)',
#   'skim milk food product',
#   'animal based salad food product',
#   'oyster liquor (frozen)',
#   'jamaican cricket material',
#   'milk or milk based food product',
#   'Brassica oleracea var. capitata',
#   'Malbec grape plant',
#   'pasture',
#   'Lansium domesticum',
#   'cornmeal (degerminated, enriched)',
#   'Osphronemidae',
#   'margarine',
#   'cocoa',
#   'piece of animal leg (raw)',
#   'piece(s) of animal lung (raw)',
#   'piece of turkey skin (raw)',
#   'Africa',
#   'Triglidae',
#   'citron (raw)',
#   'Equidae',
#   'mum-khai-pla',
#   'Tandem soft white winter wheat kernel (raw)',
#   'herring (canned)',
#   'chinese white pear plant',
#   'Faroese',
#   '10000026 - milk/milk substitutes (shelf stable) (gs1 gpc)',
#   'Centella asiatica',
#   'watermelon rind (preserved in syrup)',
#   'cheese fondue',
#   'buffalo organ',
#   'hot pepper food product',
#   'cis-caffeic acid',
#   'juniper ash',
#   'rat',
#   'cation',
#   'piece of nutria meat',
#   'Sardinops ocellatus',
#   'Han Chinese in Beijing, China',
#   'beef brisket flat half',
#   'animal testicle (raw)',
#   'piece(s) of buffalo',
#   'Serraninae',
#   'elephant material',
#   'vegetable carbon',
#   'apple jelly (rum-flavored)',
#   'monocyclic compound',
#   'Pterotolithus',
#   'Plectorhinchus macrolepis',
#   'royal royce strawberry (raw)',
#   'cow milk (high temperature short time)',
#   'brown sugar cookie',
#   'Piranha soft white winter wheat kernel',
#   'sausage and biscuit sandwich',
#   'baby lima bean (mature)',
#   'wurstel (smoked)',
#   'apple drink mix (artificially flavored)',
#   'brown pine plant',
#   'metalloporphyrin',
#   'white potato (canned)',
#   'chicken burger',
#   'chicken thigh (skinless, raw)',
#   'mustard greens (frozen)',
#   'Cervus',
#   'Leucoraja naevus',
#   'kangaroo food product',
#   'solution for injection',
#   'baicalein',
#   'pink bean',
#   'Tragelaphus',
#   'Mugil thoburni',
#   'Yukon Gold potato',
#   'chicken pieces (marinated, raw)',
#   '21710 - sliceable or firm cooked sausages (efsa foodex2)',
#   'ice cream (artificially sweetened)',
#   'lima bean (whole pod or pieces)',
#   '37590 - infant formula, based on protein hydrolysates, liquid (efsa foodex2)',
#   'plaa tuu',
#   'sausage (raw, smoked)',
#   'Genipa americana',
#   'bear carcass (raw)',
#   'spice or herb (us cfr)',
#   'harengula',
#   'Bouvet Island',
#   'piece of chicken organ',
#   'sturgeon roe semi-preserved',
#   'broiler chicken',
#   'Micropogonias furnieri',
#   'essential fatty acid',
#   'jicama tuber',
#   'tomato wedge (artificially sweetened, canned)',
#   'copper group molecular entity',
#   'animal muscle tissue cut',
#   'hot pepper',
#   'kola nut pod',
#   'Tuscan in Italy (HGDP)',
#   'piece(s) of animal lung',
#   'Thymallus',
#   'Bulgarian',
#   'Eriphia smithii',
#   'tarragon (dried)',
#   'pastry food product',
#   'sheep material',
#   'Uraspis secunda',
#   'Mahafaly',
#   'lamb rennet paste',
#   'Heterotis niloticus',
#   'ostrich egg white',
#   'Guaiacum officinale',
#   'butchery cut of lamb',
#   'food material by component concentration',
#   'hazelnut food product',
#   'coconut meat',
#   'layer cake',
#   'tea food product',
#   'nut',
#   'elderberry',
#   'pork liver (raw)',
#   'Aspleniineae',
#   'halibut (raw)',
#   'sweet corn kernel',
#   'piece of seal',
#   'black cumin plant',
#   'chia seed',
#   'imitation milk (liquid)',
#   'lotus seed (dried)',
#   'animal wing (skinless)',
#   'Penaeidae',
#   'oyster food product',
#   'slender sole (raw)',
#   'jurel (green jack) (raw)',
#   'Phyllantheae',
#   'seedling cotyledon',
#   'pineapple (canned)',
#   '38200 - protein and amino acids supplements (efsa foodex2)',
#   'atlantic cod fillet (skinless, raw)',
#   'animal back',
#   'gametophore',
#   'spice mixture (whole or pieces)',
#   'raisin rye bread',
#   'Centrolophidae',
#   'Cupressaceae',
#   'tilapia',
#   'caryophanales',
#   'fonio food product',
#   'poultry-based soup',
#   'pasteurized process cheese with fruits vegetables or meats',
#   'Cornus',
#   'receptacle',
#   'pu dong',
#   'sucrose esters of fatty acids',
#   'milk-based product with fruit preparations (calorie reduced)',
#   'Todarodes',
#   'fruit jelly (us cfr)',
#   'spiny lobster',
#   'salad',
#   'meat tenderizer',
#   'mandarin orange food product',
#   'lamb roast',
#   'orange squash beverage',
#   'Lepidochelys',
#   'turkey ham',
#   'piece of chicken back (skinless, raw)',
#   'Saint Vincent and the Grenadines',
#   'rhubarb food product',
#   'artichoke (marinated, quartered)',
#   'meat-based soup',
#   'rasam (dish)',
#   'soft drink food product',
#   'candy (low calorie)',
#   'fruit (canned, not in contact with tin)',
#   'Sub-Saharan African',
#   'sourdough starter',
#   'Hexagrammos decagrammus',
#   '10000257 - shellfish prepared/processed (perishable) (gs1 gpc)',
#   'Indian',
#   'Averrhoa carambola',
#   'cucumber',
#   'poultry meat product extender',
#   'Lottioidea',
#   'anthropogenic environmental material',
#   'piece(s) of beefalo organ',
#   'Epinephelus latifasciatus',
#   'Yoruba in Nigeria (SGDP)',
#   'mango (canned)',
#   'Orthopristis chrysoptera',
#   'Shine soft white winter wheat kernel (raw)',
#   'poultry foot',
#   'frog carcass (raw)',
#   'wax',
#   'shop',
#   'Crataegus',
#   'flavan',
#   '35760 - chamomile and similar- (efsa foodex2)',
#   'USDA SR beverages (1400)',
#   'animal egg white',
#   'Sebastes paucispinis',
#   'hushpuppy',
#   'granadilla de quijo pulp',
#   'piece of turkey back',
#   'hawkfish family',
#   'Modoc potato (raw)',
#   'black pepper (whole or pieces)',
#   'yellow sweet corn kernel',
#   'lupine bean in brine',
#   'lubimin',
#   'Coregonus pollan',
#   'chicken carcass (with giblets, raw)',
#   'grape spread',
#   'animal by-product',
#   'walnut (in oil)',
#   'Mugil gaimardianus',
#   'fish (minced, raw)',
#   '(+)-exo-5-hydroxycamphor',
#   'lemon- and lime-flavored juice drink',
#   'pressed grape juice',
#   '22620 - pacu (piaractus mesopotamicus) (efsa foodex2)',
#   'Samoan',
#   '21900 - cervelat (swiss type) (efsa foodex2)',
#   'blue swimmer crab carcass (raw)',
#   'ice cream (lowfat)',
#   'Croatian',
#   'chicken-flavored consommé (instant)',
#   'stag chicken',
#   'animal wing (raw)',
#   'atlantic salmon fillet (raw)',
#   'seabird',
#   'piece(s) of chicken meat (boneless)',
#   'piece(s) of animal ovary (raw)',
#   'Urophycis tenuis',
#   'fish or related organism (eurofir)',
#   'morocco bean',
#   'macaroon (artificially sweetened)',
#   'poultry (canned)',
#   'knockwurst',
#   'piece(s) of lobster meat',
#   'Centropristis ocyurus',
#   'imitation crabmeat from artificially-flavored pollock',
#   'Georgia',
#   'Hyperoglyphe antarctica',
#   'mutton curry',
#   'seafood (breaded)',
#   'polystyrene surface',
#   'porgy',
#   'common mallow leaf (raw)',
#   'Cape Verde',
#   '1,4-naphthoquinones',
#   'Hyperoglyphe pringlei',
#   'Sukuma',
#   '37800 - cereals with an added high protein food which have to be reconstituted with water or other protein-free liquid (efsa foodex2)',
#   'Cinnamomum burmanni',
#   'shrimp (fully preserved)',
#   '37760 - ready-to-eat fruit-based meal for children (efsa foodex2)',
#   'fish, amiiform',
#   'aloe honey',
#   'chinese chestnut (dried)',
#   'Bemba',
#   'gecko',
#   'navy bean',
#   'Cucumis melo var. inodorus',
#   'john dory (raw)',
#   'beef testicle',
#   'basil leaf',
#   'dinitrogen oxide',
#   'animal chop (boneless)',
#   'lemon pie filling',
#   'Mytilus galloprovincialis',
#   'cherry nectar',
#   'Typha angustifolia',
#   'corn kernel',
#   'horseradish plant food product',
#   'pico de gallo',
#   'donkey milk (raw)',
#   'kola nut (raw)',
#   '10000166 - dried breads (shelf stable) (gs1 gpc)',
#   'animal fat',
#   'pork jowl (raw)',
#   'Lontra canadensis',
#   'plant product based flavoring or seasoning',
#   'imitation black cherry carbonated beverage',
#   'Timor-Leste',
#   'lamb meat (minced, raw)',
#   'marrow (ginger added)',
#   'beef loin (raw)',
#   'okra (cut, canned)',
#   'calamus plant',
#   'camel',
#   'catfish fillet (frozen)',
#   'brussels sprout food product',
#   'jelly ear (raw)',
#   'pear juice (fermented)',
#   'pacific ocean islands',
#   'hare',
#   'cow milk (lactose-reduced)',
#   'rhea',
#   '37830 - simple cereals for infants or children, reconstituted (efsa foodex2)',
#   'pasta (dried)',
#   'lemon peel',
#   'snail (in shell, canned)',
#   'poultry cured meat',
#   'yellowtail tuna (in cottonseed oil, smoked)',
#   'peanut spread',
#   'longhorn cheddar cheese',
#   'flavoring agent by taste',
#   'wasabi (food product)',
#   'Grossulariaceae',
#   'shrimp (canned)',
#   'sunflower seed flour',
#   'pussytoes plant',
#   'Gardenieae',
#   'butter-like edible fat',
#   '21730 - mortadella-type sausage (efsa foodex2)',
#   'haddock (raw, breaded)',
#   'piece of kangaroo (raw)',
#   'zucchini squash (raw)',
#   'cabbage plant',
#   'Lutjanus',
#   'germ oil',
#   'Araucariaceae',
#   'Struthionidae',
#   'wheat flour (agglomerated)',
#   'decoration (us cfr)',
#   'magnesium diglutamate',
#   'mandoo',
#   'lupine bean (raw)',
#   'beef pie (frozen)',
#   '01990 - yeast leavened bread doughs (efsa foodex2)',
#   'broth or stock food product',
#   'mammalian milk (flavor modified)',
#   'cassava (raw)',
#   'huckleberry food product',
#   'elderberry food product',
#   'Metapenaeus joyneri',
#   'beef rib sub-primal',
#   'asian pear',
#   'sauce, sweet',
#   'bison chuck (raw)',
#   'longan drink',
#   'sheep',
#   'Carya ovalis',
#   'roquefort-flavored dressing',
#   'piece(s) of animal thymus (raw)',
#   'lamb meat (ground, fresh frozen)',
#   'turkey leg',
#   'chicken egg (shell off, solids, dried, ground)',
#   'animal pancreas (raw)',
#   'piece(s) of pork stomach',
#   'bajra millet meal',
#   'piece of veal lung',
#   'piece of chicken tongue',
#   'citron food product',
#   'all-trans-retinal',
#   'live water buffalo',
#   'sweet cherry (frozen)',
#   'hamburger seasoning mix',
#   'killifish family',
#   'processed oil',
#   'parsnip (microwaved)',
#   'turbot food product',
#   'pea soup',
#   '26500 - milk, whey and cream (efsa foodex2)',
#   'Ostreidae',
#   'sea turtle carcass (raw)',
#   'brown sugar',
#   '08860 - spearmint (efsa foodex2)',
#   'duck',
#   'elephant carcass',
#   'aztec marigold plant',
#   'camel milk beverage',
#   'cod fillet (smoked, frozen)',
#   'Slovenia',
#   'dragon lizard',
#   'Fragaria x ananassa',
#   '03560 - rye popped (efsa foodex2)',
#   'greengage plum plant',
#   'Antigonia',
#   '02980 - dumpling, sweet (efsa foodex2)',
#   '10000627 - aquatic invertebrates/fish/shellfish/seafood mixes - prepared/processed (perishable) (gs1 gpc)',
#   'butterscotch candy (artificially-flavored)',
#   'Cambodian in Cambodia (SGDP)',
#   'Iguana',
#   'turkey leg (skinless)',
#   'coffee (instant, spray-dried)',
#   'leaf sauce',
#   'curly kale leaf (raw)',
#   'dolphin family',
#   'shoyu sauce',
#   'bullhead',
#   'eggnog pecan cake',
#   'piece of kangaroo meat (raw)',
#   '03570 - wheat, popped (efsa foodex2)',
#   'Antiguan or Barbudan',
#   'acetate salt',
#   'candy (filled)',
#   'argentine sea bass (raw)',
#   'yogurt (nonfat, sweetened with aspartame)',
#   'chicken and noodles',
#   'white kidney bean (dried)',
#   'd-block molecular entity',
#   'Knipowitschia panizzae',
#   'wheat germ oil',
#   'peanut (skin off, partially defatted)',
#   'sesbania plant',
#   'Copt',
#   'red wine must',
#   'heterotricyclic compound',
#   'shrimp (western-style, breaded)',
#   'hydrogenated poly-1-decene',
#   'Rubus crataegifolius',
#   'cottage cheese with cream dressing',
#   'olive oil (extracted from pomace and pits, refined)',
#   'winter flounder (raw)',
#   'spiny dogfish (canned)',
#   'rhodamnia plant',
#   'pakora',
#   'Linum usitatissimum',
#   'piece of animal breast (skinless, boneless)',
#   'Punjabi in Lahore, Pakistan',
#   'greek yogurt',
#   'crab carcass (raw)',
#   'tubeti macaroni',
#   'food harvested by gathering',
#   'spiny lobster tail (raw)',
#   'squid raw',
#   'dense connective tissue',
#   'beef bottom round (raw)',
#   'butchery cut of catfish',
#   'Rosales',
#   'clove ground',
#   'corn-based snack food',
#   '22390 - mozambique tilapia (efsa foodex2)',
#   'pancake syrup',
#   'Fulmarus',
#   'black olive',
#   'Conodon nobilis',
#   'Palmaria',
#   '31930 - juice, prune (efsa foodex2)',
#   'Pteriidae',
#   'Coregonus wartmanni',
#   'filled milk (evaporated)',
#   'Lama glama',
#   'Panulirus gracilis',
#   'plant derived beverage',
#   '36760 - fir (infusion shoots) (efsa foodex2)',
#   'deep sea lobster (raw)',
#   '36730 - cocoa (infusion husks) (efsa foodex2)',
#   'human construction',
#   'potato (peeled, raw)',
#   'pollock fillet (with skin, raw)',
#   'Rheum palmatum',
#   'poultry food product',
#   'runner',
#   'rice (coated, fortified)',
#   'Aplodinotus',
#   'Cucurbita',
#   'vegetable leaf (raw)',
#   'piece of bear (raw)',
#   'Iranian',
#   'ravioli in brine',
#   '22830 - dagaas (efsa foodex2)',
#   'biscuit (hard) food product',
#   'glucose syrup (liquid)',
#   '38170 - algae based formulations (e.g. spirulina, chlorella) (efsa foodex2)',
#   'beef top round roast (cooked)',
#   'soup animal component',
#   'head cheese',
#   'Province of New Brunswick',
#   'piece of nile tilapia',
#   'salad dressing, low fat',
#   'Artdedo soft white winter wheat kernel (dried raw)',
#   'Ficus sycomorus',
#   'cow whole milk (spray-dried)',
#   'spätzle',
#   'lactone',
#   'Melanogrammus aeglefinus',
#   'benzopyran',
#   'cut of meat, composite',
#   'ucuhuba seed oil',
#   'margarine (nondairy)',
#   'mannose',
#   'drink with no added sugar (flavored, water-based)',
#   'Aphanopus carbo',
#   'ice, edible, energy reduced',
#   'morwong family',
#   'orange ice on a stick',
#   'sweet yellow bell pepper',
#   'mint bunch',
#   'cowpea plant',
#   'parmesan cheese food product',
#   'Red California kidney bean (raw, mature)',
#   'Claytonia lanceolata',
#   'king crab family',
#   '50170000 - seasonings/preservatives/extracts (gs1 gpc)',
#   'honey (whipped)',
#   'black currant jam',
#   'gulper shark family',
#   'pheasant thigh (skinless, raw)',
#   'confectionery coating',
#   'piece of goose meat',
#   'fermented meat product',
#   'pork organ (raw)',
#   'cream dessert',
#   'Rumex arcticus',
#   'okra (raw)',
#   'cereal flour',
#   'coconut oil press cake',
#   'Mayan in Mexico (SGDP)',
#   'protein-containing macromolecular complex',
#   'Argentina',
#   'indigoberry plant',
#   'peach puree',
#   'Zapotec in Mexico (SGDP)',
#   'freshwater bass',
#   'rose hip jelly',
#   'horsfieldia plant',
#   'grappa invecchiata',
#   'Flavoxanthin',
#   'jarlsburg cheese',
#   'cauliflower (pickled, canned)',
#   'white bean flatbread',
#   'cardinalfish',
#   'animal thigh (raw)',
#   'Etmopteridae',
#   'nasturtium leaf (raw)',
#   '29430 - frozen yoghurt (efsa foodex2)',
#   'chicken breast (bone-in)',
#   'piece of pork meat',
#   'jellied fruit candy',
#   'ostrich fan fillet (raw)',
#   '10006441 - mandarin hybrids (gs1 gpc)',
#   'apple pie (baked)',
#   'cherry (raw)',
#   'pork (processed)',
#   'tilefish fillet',
#   'hard red wheat plant',
#   'tapioca cookie',
#   'lancashire cheese',
#   'trans-2-coumaric acid',
#   'pork loin (raw)',
#   'milk chocolate candy (hollow)',
#   'okazi leaf',
#   'fish, gasterosteiform',
#   'Etroplus suratensis',
#   'straight-chain saturated fatty acid',
#   'beef (dehydrated)',
#   'mammalian milk butter',
#   'Equus zebra',
#   'beef ribeye cap roll',
#   'Malpighiales',
#   'sweet potato flakes',
#   'organic iron compound',
#   'pine nut extract',
#   'red bliss potato (raw)',
#   'wild caia plant',
#   'blackberry jelly',
#   'formula dietary food',
#   'skeletal meat part, without bone, with skin',
#   'indian chutney',
#   'german bread',
#   'creme-filled cookie',
#   'beet juice',
#   'Equisetaceae',
#   'cereal grain food product',
#   'rainbow smelt carcass (raw)',
#   'alfalfa meal for animal feed',
#   'beta-lactoglobulin',
#   'cookie food product',
#   'roll or bun',
#   'fruit ((whole or pieces), raw)',
#   'meatloaf',
#   'Osteoglossidae',
#   '41310 - mushrooms cooked sauce (efsa foodex2)',
#   'Triticum aestivum',
#   'calcium hydrogen sulphite',
#   'chicken egg yolk (low cholesterol, low fat)',
#   'organic ion',
#   'diarylheptanoid',
#   'cholines',
#   'vegetable pie (baked)',
#   'Salmo salar',
#   'oxtail soup (thickened)',
#   'whisker sheatfish',
#   'monkfish fillet (with skin, raw)',
#   'glycosyl compound',
#   'Trichodontidae',
#   'cupuaçu fruit food product',
#   '25250 - abalones, winkles, conchs (efsa foodex2)',
#   'barbeque seasoning (dry)',
#   '10005778 - mixed species meat/poultry/other animal - alternative meat - prepared/processed (gs1 gpc)',
#   'She in China (HGDP)',
#   'beef petite sirloin roast (raw)',
#   'Scolopacidae',
#   'crayfish (cooked)',
#   'crabmeat (canned)',
#   'betel leaf',
#   'Pleuronichthys ritteri',
#   'microsclerotium',
#   'rice buds (dried)',
#   'star fruit food product',
#   'cranberry juice drink',
#   'Isopisthus parvipinnis',
#   'western pacific crab (raw)',
#   'halide salt',
#   'CIAA dairy products',
#   'japanese scallop',
#   'city',
#   'pumpkin seed (shell off)',
#   'pheasant leg',
#   'chilipepper rockfish meat (raw)',
#   'cow milk (semi-skimmed, pasteurized)',
#   'olive',
#   'Trachurus symmetricus',
#   'Epinephelus itajara',
#   'piece(s) of turkey heart',
#   'nile tilapia fillet (with skin, raw)',
#   'palm kernel oil',
#   'cottonseed (shelled)',
#   'avian animal processed carcass (raw)',
#   'lollo bionda',
#   'agricultural ecosystem',
#   'Wolof',
#   'Sperata aor',
#   'white icicle radish',
#   'billabong tree',
#   'salt or salt substitute (us cfr)',
#   'eremophila plant',
#   'vegetable juice (canned)',
#   'bourbon biscuit',
#   '32210 - mixed fruit and vegetable juices (efsa foodex2)',
#   'Fuji apple (raw)',
#   'cheddar cheese sandwich',
#   'copper(II) sulfate',
#   'Sciaena',
#   'Ranoidea <superfamily>',
#   'butter cream bread',
#   'lemon balm food product',
#   'lemongrass stalk',
#   'cottage cheese',
#   'fruit juice (sparkling)',
#   'confectionery (dried fruit-based, no added sugar)',
#   'steroid',
#   'soup (condensed)',
#   '38210 - coenzyme q10 formulations (efsa foodex2)',
#   'cockle (frozen)',
#   'food (sugar-free)',
#   'butternut (dried)',
#   'balsam apple plant',
#   'glucose derived from amylose derived from starch',
#   'northern anchovy (raw)',
#   'kahawai (raw)',
#   'Cenchrus americanus',
#   'piece of turkey back (with skin)',
#   'Chaenomeles japonica',
#   'food (liquid, high viscosity, with small particles)',
#   'Paralabrax',
#   'marine protein supplement',
#   'custard apple peel (raw)',
#   'scallion (raw)',
#   'imitation ice milk (artificially sweetened)',
#   'Hemitripterus americanus',
#   'cap, button',
#   'Brassica carinata',
#   'beef pepperpot (dry mix)',
#   'cabbage-leaf mustard plant',
#   'baltic herring',
#   'poultry sausage',
#   'salmon pattie',
#   'piece(s) of turkey meat (boneless)',
#   'Mugiloides fasciatus',
#   '25260 - abalone (efsa foodex2)',
#   'Orchidaceae',
#   'piece(s) of bearded seal',
#   'Scyllarides brasiliensis',
#   'pet food (canned)',
#   'malted milk shake',
#   'bakery product (creme-filled)',
#   'pumpkin and pecan cake',
#   'Byrsonima crassifolia',
#   'calf milk replacer',
#   'palm kernel (ground)',
#   'piece of walrus organ (raw)',
#   'roquefort dressing',
#   'Ocyurus chrysurus',
#   'piece of poultry meat (mechanically deboned, raw)',
#   'toaster pastry',
#   'summer orange plant',
#   'Ribes divaricatum',
#   'phosphoric ester',
#   'lime juice (sweetened, diluted)',
#   'Dioscorea japonica',
#   '(20S)-ginsenoside Rg3',
#   'paraben',
#   'chinese cabbage food product',
#   '23560 - pollack (efsa foodex2)',
#   'animal thigh (skinless, with bone)',
#   'goose material',
#   'Tharaka',
#   '40800 - miscellaneous savoury extracts (efsa foodex2)',
#   'Sesbania',
#   'rice with husk',
#   'snack dip mix',
#   'food (fried)',
#   'piece(s) of animal wing (skinless)',
#   'Rouge De Bordeaux hard red winter wheat kernel',
#   'brussels sprout (frozen)',
#   '10680 - pulses (dried legume seeds) (efsa foodex2)',
#   'fountain syrup',
#   'Perna canaliculus',
#   'black crappie (raw)',
#   'Solanaceae',
#   'piece(s) of chicken wing (raw)',
#   'Iraqi Jew in Iraq (SGDP)',
#   '(R)-propane-1,2-diol',
#   'Potentilleae incertae sedis',
#   'Qatari',
#   'water chestnut (canned)',
#   'king orange plant',
#   'chick',
#   'Paralichthys olivaceus',
#   'western omelet mix',
#   'piece of gazelle meat',
#   'Salmo salmon ground (raw)',
#   'beef chuck short rib (raw)',
#   'Fry muscadine cultivar',
#   'Alcea rosea',
#   'piece of dark turkey meat (with skin)',
#   'stylopod',
#   'cheese for manufacturing use',
#   'blood',
#   'piece(s) of capon',
#   'Cantareus apertus',
#   'atlantic cod',
#   'chicken kidney',
#   'anadromous fish',
#   'piece(s) of sheep',
#   'pork (cut fresh)',
#   'zanha golungensis plant',
#   'slipper lobster',
#   'heirloom tomato (raw)',
#   'glucan derivative',
#   'plant sweetener',
#   'frozen nondairy dessert (artificially sweetened)',
#   'Rubus parviflorus',
#   'poutassou (raw)',
#   'tropical fruit',
#   'dichapetalum plant',
#   'cream cheese',
#   'chrysanthemum tea (dry)',
#   'Origanum vulgare',
#   'cheese herrgardsost',
#   'Allium ursinum',
#   'imitation vinegar (tablet)',
#   'Atlantic potato cultivar',
#   'papaya-flavored beverage syrup',
#   'food (fat or oil coated)',
#   '08980 - thai basil (efsa foodex2)',
#   'calcium bis(dihydrogenphosphate)',
#   'white rice (cooked)',
#   'dietary wafer',
#   'Syrah grape plant',
#   'lobster (whole, precooked, frozen)',
#   'piece(s) of bison organ (raw)',
#   'sage derby cheese',
#   'mace (dried)',
#   'poultry product (cured)',
#   'dried milk food product',
#   '23380 - plaice, alaska (efsa foodex2)',
#   'corn flour',
#   'piece(s) of beef (frozen)',
#   'Phoenix',
#   '37710 - ready-to-eat meal for infants and young children (efsa foodex2)',
#   'Osmeridae',
#   'mint sauce',
#   '10006216 - soups - prepared variety packs (gs1 gpc)',
#   'white grape',
#   'blackfin tuna (raw)',
#   'rockweed (dried)',
#   'prepared seafood product',
#   'Anseranas semipalmata',
#   'cockle (raw)',
#   '31860 - juice, lime (efsa foodex2)',
#   'AfPO_0000286',
#   'wafer, table',
#   'food (blend)',
#   'beef retail cut (raw)',
#   'kievitone',
#   '13620 - temulawak roots (efsa foodex2)',
#   'jalapeno pepper',
#   'Rexea solandri',
#   'loganberry food product',
#   'malvidin 3-O-beta-D-glucoside',
#   'fruit (canned, energy reduced)',
#   'pomelo fruit (raw)',
#   'neet fish (smoked)',
#   'pecorino cheese',
#   'hare (jugged, in wine sauce)',
#   'sorrel food product',
#   '(R,R,S)-alpha-tocopherol',
#   'cheese product analog',
#   'piece of turkey heart',
#   'non-chocolate confectionery or other sugar product (eurofir)',
#   'beet plant',
#   '31770 - other fruit juices (efsa foodex2)',
#   'animal fillet (with skin, raw)',
#   'asadero cheese',
#   'lingcod material',
#   'Brotula clarkae',
#   'distilled vinegar',
#   'water buffalo milk (raw)',
#   ...},
#  {'14230 - citrus fruits (efsa foodex2)',
#   '14240 - grapefruits and similar- (efsa foodex2)',
#   '14260 - natsudaidais (efsa foodex2)',
#   '14270 - shaddocks (efsa foodex2)',
#   '14290 - sweeties (efsa foodex2)',
#   '14300 - tangelolos (efsa foodex2)',
#   '14310 - tangelos (except minneolas) (efsa foodex2)',
#   '14450 - lemons and similar- (efsa foodex2)',
#   '14460 - lemons (efsa foodex2)',
#   "14470 - buddha's hands (efsa foodex2)",
#   '14480 - citrons (efsa foodex2)',
#   '14550 - mandarins and similar- (efsa foodex2)',
#   '14580 - calamondins (efsa foodex2)',
#   '14610 - minneolas (efsa foodex2)',
#   '14620 - satsumas (efsa foodex2)',
#   '14640 - tangors (efsa foodex2)',
#   '14650 - mediterranean mandarins (efsa foodex2)',
#   '14660 - tankan mandarin (efsa foodex2)',
#   '14670 - other hybrids of citrus reticulata, not elsewhere mentioned (efsa foodex2)',
#   '14680 - other citrus fruits (efsa foodex2)',
#   '14690 - australian finger lime (efsa foodex2)',
#   '14700 - other miscellaneous citrus fruit (efsa foodex2)'},
#  {'concentration of myoglobin in material entity',
#   'concentration of Isocaryophyllene in material entity',
#   'decreased size',
#   'divided into halves',
#   'concentration of procyanidin in material entity',
#   'concentration of coumaric acid in material entity',
#   'concentration of all-trans-phytoene in material entity',
#   'concentration of oleic acid in material entity',
#   'concentration of (-)-epicatechin-3-O-gallate in material entity',
#   'concentration of organic chloride salt in material entity',
#   'concentration of fucoxanthin in material entity',
#   'concentration of iron(2+) sulfate (anhydrous) in material entity',
#   'uniform diameter',
#   'concentration of amino acid derived from non-proteinacious in material entity',
#   'concentration of (−)-α-thujone in material entity',
#   'concentration of (3,4-dihydroxyphenyl)acetic acid in material entity',
#   'concentration of lithium chloride in material entity',
#   'concentration of delta7-avenasterol in material entity',
#   'concentration of cyanin in material entity',
#   'heat-treated',
#   'concentration of magnesium(2+) in material entity',
#   'concentration of sulfide(2−) in material entity',
#   'concentration of Carnosol in material entity',
#   'concentration of sucrose in material entity',
#   'concentration of hydrolysable tannin in material entity',
#   'concentration of organic acid in material entity',
#   'concentration of galactose derived from stachyose derived from raffinose family oligosaccharide in material entity',
#   'food material characteristic',
#   'concentration of carbohydrate in material entity',
#   'concentration of serotonin in material entity',
#   'concentration of (2-cis,6-cis)-farnesol in material entity',
#   'decreased flexibility',
#   'concentration of cholesterol in material entity',
#   'concentration of Azukisaponin III in material entity',
#   'concentration of hydroxyflavone in material entity',
#   'concentration of xanthones in material entity',
#   'concentration of D-galacturonic acid in material entity',
#   'concentration of cyanidin cation in material entity',
#   'concentration of lucenin-2 in material entity',
#   'concentration of inorganic zinc salt in material entity',
#   'concentration of psicose in material entity',
#   'concentration of Dalbergin in material entity',
#   'concentration of 9-cis-β-carotene in material entity',
#   'concentration of dopamine 3-O-sulfate in material entity',
#   'concentration of hydroxyflavanone in material entity',
#   'concentration of 2-methoxy-4-vinylphenol in material entity',
#   'normal viscosity',
#   'concentration of coumestrol in material entity',
#   'concentration of elastin in material entity',
#   'color of poultry meat',
#   'concentration of Melanin in material entity',
#   'concentration of aluminium(3+) in material entity',
#   'concentration of hydroxybenzaldehyde in material entity',
#   'concentration of apigenin in material entity',
#   'concentration of fibrin in material entity',
#   'concentration of naringin in material entity',
#   'concentration of propionic acid in material entity',
#   'radius',
#   'concentration of kaempferol 3-O-β-D-galactoside in material entity',
#   'concentration of dietary copper in material entity',
#   'concentration of glucan in material entity',
#   'concentration of cirsimaritin in material entity',
#   'concentration of cyanin chloride in material entity',
#   'concentration of pinocembrin in material entity',
#   'concentration of trace element in material entity',
#   'concentration of selenium(6+) in material entity',
#   "concentration of 4'-methoxy-5,7-dihydroxyflavanone in material entity",
#   'concentration of vitamin B9 in material entity',
#   'scirrhous',
#   'concentration of Matricin in material entity',
#   'concentration of 3,4-dihydroxybenzoic acid in material entity',
#   'concentration of bismuth(3+) in material entity',
#   'concentration of starch in material entity',
#   'quality of a liquid',
#   'concentration of fructose derived from inulin derived from fructan in material entity',
#   'concentration of 4-hydroxy-all-trans-β-carotene in material entity',
#   'concentration of Mutatochrome in material entity',
#   'concentration of calcium stearate in material entity',
#   'concentration of kievitone in material entity',
#   'concentration of vanillin in material entity',
#   'concentration of calcium sulfate in material entity',
#   'normal diameter',
#   'commercial grade',
#   'solid configuration',
#   'mature',
#   'orange skin',
#   'concentration of valine in material entity',
#   'concentration of glucose derived from amylopectin derived from starch in material entity',
#   'concentration of (R)-rosmarinic acid in material entity',
#   'concentration of 1,2-napthoquinone in material entity',
#   'concentration of organic magnesium salt in material entity',
#   'concentration of lysine in material entity',
#   'concentration of glucose derived from raffinose derived from raffinose family oligosaccharide in material entity',
#   'concentration of glutamic acid in material entity',
#   'concentration of globulin type in material entity',
#   'concentration of glucoberteroin(1-) in material entity',
#   'concentration of eriodictyol in material entity',
#   'concentration of pelargonidin in material entity',
#   'concentration of (S)-lactic acid in material entity',
#   'concentration of sodium(1+) in material entity',
#   'concentration of linoleic acid in material entity',
#   'increased concentration',
#   'concentration of sinigrin(1-) in material entity',
#   'solid containing medium or small particles (4-8 mm.)',
#   'concentration of inorganic fluoride salt in material entity',
#   'concentration of capsidiol in material entity',
#   'concentration of fructose derived from verbascose derived from raffinose family oligosaccharide in material entity',
#   'concentration of vitamin D in material entity',
#   'physical object quality',
#   'concentration of elaidic acid in material entity',
#   'concentration of galacturonic acid in material entity',
#   'concentration of lambertianin C in material entity',
#   'concentration of 2,4,6-Trihydroxybenzoic acid in material entity',
#   'concentration of limonene-1,2-diol in material entity',
#   'concentration of hydroquinone in material entity',
#   'maturity',
#   'thickness of 1.5 cm to less than 7.0 cm',
#   'concentration of Ineketone in material entity',
#   'concentration of benzenediols in material entity',
#   'concentration of resveratrol in material entity',
#   'concentration of docosadienoic acid in material entity',
#   'concentration of 4-hydroxymandelic acid in material entity',
#   'concentration of caesium(1+) in material entity',
#   'concentration of naphthoquinone in material entity',
#   'decreased thickness',
#   'concentration of acteoside in material entity',
#   'concentration of glucoputranjivin(1-) in material entity',
#   'concentration of formononetin in material entity',
#   'concentration of folic acid in material entity',
#   'concentration of gallotannin in material entity',
#   'concentration of theogallin in material entity',
#   'concentration of terpene in material entity',
#   'concentration of succinic acid in material entity',
#   'concentration of quercetin 4ʼ-O-β-D-glucopyranoside in material entity',
#   'inflexible',
#   'color of fruit or vegetable skin',
#   'increased diameter',
#   'concentration of quercetin 3-O-beta-D-glucofuranoside in material entity',
#   'concentration of capsaicin in material entity',
#   'concentration of rosmarinic acid in material entity',
#   'concentration of chrysin in material entity',
#   'concentration of myricetin in material entity',
#   'concentration of vitamin B1 in material entity',
#   'concentration of steviol glycoside in material entity',
#   'concentration of trans-rhaponticin in material entity',
#   'concentration of fucose derived from rhamnogalacturonan derived from pectin in material entity',
#   'concentration of phenols in material entity',
#   'concentration of sterol in material entity',
#   'characteristic',
#   'concentration of organic calcium salt in material entity',
#   'concentration of coniferyl aldehyde in material entity',
#   'not heat-treated',
#   'concentration of dietary magnesium in material entity',
#   'concentration of pectin in material entity',
#   'concentration of deoxyhumulone in material entity',
#   'concentration of (+)-valencene in material entity',
#   'concentration of dietary sulfur in material entity',
#   'concentration of glucose derived from stachyose derived from raffinose family oligosaccharide in material entity',
#   'concentration of sodium cyanide in material entity',
#   'concentration of cinnamtannin A2 in material entity',
#   'concentration of sodium hydrogensulfite in material entity',
#   'normal perimeter',
#   'concentration of phytosterols in material entity',
#   'concentration of petunidin in material entity',
#   'concentration of gallic acid in material entity',
#   'concentration of all-trans-retinol in material entity',
#   'concentration of Nobilin in material entity',
#   'whole and pieces',
#   'concentration of maltodextrin in material entity',
#   '1-D extent',
#   'concentration of myo-inositol hexakisphosphate in material entity',
#   'concentration of flavonols in material entity',
#   'concentration of amylopectin in material entity',
#   'concentration of luteolin 7-O-beta-D-glucoside in material entity',
#   'concentration of galactose derived from raffinose derived from raffinose family oligosaccharide in material entity',
#   "concentration of 3'-O-methylepicatechin in material entity",
#   'concentration of 4-hydroxybenzaldehyde in material entity',
#   'thickness of 1.5 cm or more',
#   'concentration of (6R)-5,10-methenyltetrahydrofolate in material entity',
#   'concentration of fructan in material entity',
#   'food component',
#   'concentration of Obacunone in material entity',
#   'moderate increased temperature',
#   'concentration of ginsenoside Rc in material entity',
#   'concentration of dextrins in material entity',
#   'concentration of galacturonic acid derived from rhamnogalacturonan derived from pectin in material entity',
#   'concentration of galactomannan in material entity',
#   'concentration of organosulfur compound in material entity',
#   'concentration of ketohexose in material entity',
#   'concentration of 3-methylcatechol in material entity',
#   'concentration of Trachelogenin in material entity',
#   'concentration of tin(2+) in material entity',
#   'concentration of polyol in material entity',
#   'concentration of chloride in material entity',
#   'concentration of cyanidin 3-O-β-D-galactoside chloride in material entity',
#   'concentration of serine in material entity',
#   'increased width and length',
#   'concentration of inorganic magnesium salt in material entity',
#   'concentration of 2-hydroxypropanoic acid in material entity',
#   'concentration of organic phosphate compound in material entity',
#   'concentration of brassicasterol in material entity',
#   'concentration of sodium formate in material entity',
#   'concentration of quercetin 3-O-β-D-glucopyranoside in material entity',
#   'concentration of tripotassium phosphate in material entity',
#   'concentration of xanthone glycoside in material entity',
#   'concentration of hydroxyproline in material entity',
#   'concentration of rebaudioside D in material entity',
#   'concentration of anthoxanthin in material entity',
#   'concentration of vitamin A in material entity',
#   'concentration of neoeriocitrin in material entity',
#   'concentration of borneol in material entity',
#   'concentration of potassium formate in material entity',
#   'concentration of strontium(2+) in material entity',
#   'concentration of verbascose in material entity',
#   'concentration of tetrahydrofolate in material entity',
#   'concentration of fucose in material entity',
#   'concentration of Flavoxanthin in material entity',
#   'concentration of nicotinic acid in material entity',
#   'concentration of acetophenone in material entity',
#   'concentration of calciol in material entity',
#   'concentration of stachyose in material entity',
#   'concentration of trehalose in material entity',
#   'concentration of tetraterpene in material entity',
#   'concentration of (2E,6E)-farnesyl monophosphate in material entity',
#   'concentration of beta-lactoglobulin in material entity',
#   'crystal configuration',
#   'increased circumference',
#   'yellow skin',
#   'concentration of erythritol in material entity',
#   'hardness',
#   'concentration of xyloglucan derived from hemicellulose in material entity',
#   'concentration of (11Z)-icos-11-enoic acid in material entity',
#   'increased thickness',
#   'concentration of flavone in material entity',
#   'concentration of organic fluoride salt in material entity',
#   'whole, natural shape',
#   'plan',
#   'concentration of glucose derived from maltose in material entity',
#   'concentration of 3-(2-hydroxyphenyl)propanoic acid in material entity',
#   'concentration of thiol in material entity',
#   'concentration of β-carotene in material entity',
#   'concentration of capsanthin in material entity',
#   'concentration of isopeonidin 3-rutinoside in material entity',
#   'concentration of Chebulinic acid in material entity',
#   'concentration of plant secondary metabolite in material entity',
#   'grade o, europe',
#   'concentration of citric acid in material entity',
#   'concentration of Pedunculagin in material entity',
#   'decreased anterior-posterior diameter',
#   'concentration of cyanocob(III)alamin in material entity',
#   'concentration of choline in material entity',
#   'quality',
#   'concentration of kaempferol 3-O-glucuronide in material entity',
#   'concentration of diarylheptanoid in material entity',
#   'deviation (from_normal)',
#   'concentration of farnesol in material entity',
#   'concentration of inulin derived from fructan in material entity',
#   'solid containing medium or large chunks (>8 mm.)',
#   'concentration of isoflavanone in material entity',
#   'concentration of glycine betaine in material entity',
#   'concentration of α-carotene in material entity',
#   'concentration of citrulline in material entity',
#   'concentration of n-propyl gallate in material entity',
#   'concentration of magnesium carbonate in material entity',
#   'concentration of aurone in material entity',
#   'concentration of lactucaxanthin in material entity',
#   'concentration of stigmasterol in material entity',
#   'concentration of trilobatin in material entity',
#   'concentration of magnesium dichloride in material entity',
#   'concentration of malvidin 3-O-β-D-glucoside in material entity',
#   'concentration of magnesium sulfate in material entity',
#   'concentration of cadmium(2+) in material entity',
#   'concentration of calcium citrate in material entity',
#   'concentration of 5-heptadecylresorcinol in material entity',
#   'concentration of organic potassium salt in material entity',
#   'concentration of demethoxycurcumin in material entity',
#   'concentration of arabinan in material entity',
#   'concentration of naringenin in material entity',
#   'concentration of resveratrol sulfate in material entity',
#   'concentration of glucoiberverin(1-) in material entity',
#   'concentration of arsenic(3+) in material entity',
#   'concentration of Rishitin in material entity',
#   'concentration of 4-methylumbelliferone β-D-glucuronide in material entity',
#   'concentration of 3-hydroxy-4-methoxybenzoic acid in material entity',
#   'concentration of 1,8-cineole in material entity',
#   'concentration of L-fucose in material entity',
#   'size',
#   'concentration of lactulose in material entity',
#   'concentration of Physalien in material entity',
#   'structure',
#   'concentration of glutathione in material entity',
#   'concentration of antheraxanthin in material entity',
#   'concentration of vitamin D2 in material entity',
#   'concentration of amylodextrin in material entity',
#   'grade r, europe',
#   'concentration of anthocyanidin in material entity',
#   'concentration of methionine in material entity',
#   'concentration of pyrogallol in material entity',
#   'concentration of pyruvic acid in material entity',
#   'concentration of cyanidin 3-O-β-D-galactoside in material entity',
#   'concentration of glucose derived from xyloglucan derived from hemicellulose in material entity',
#   'concentration of crocetin in material entity',
#   'concentration of phenolic acid in material entity',
#   'color of fish flesh',
#   'concentration of 4-methylumbelliferone sulfate in material entity',
#   'anterior-posterior diameter',
#   'concentration of sodium oxalate in material entity',
#   'concentration of D-apiose in material entity',
#   'concentration of procyanidin B5 in material entity',
#   'concentration of 2-O-sulfate-4-hydroxyacetophenone in material entity',
#   'concentration of (R)-lactic acid in material entity',
#   'concentration of Chicoric acid in material entity',
#   'concentration of absinthin in material entity',
#   'concentration of glycyrrhizinic acid in material entity',
#   'concentration of α-cryptoxanthin in material entity',
#   'concentration of coumarin in material entity',
#   'food packaging integrity',
#   "concentration of 4'-O-methylepigallocatechin-3-O-gallate in material entity",
#   'concentration of caffeic acid in material entity',
#   'concentration of rebaudioside B(1−) in material entity',
#   'concentration of galacturonic acid derived from galacturonan derived from pectin in material entity',
#   'concentration of arabinoxylan in material entity',
#   'concentration of vestitone in material entity',
#   'concentration of trans-2-coumaric acid in material entity',
#   'concentration of sinapic acid in material entity',
#   'concentration of digallic acid in material entity',
#   'concentration of octadecanoic acid in material entity',
#   'concentration of mercury(2+) in material entity',
#   'concentration of terpenoid in material entity',
#   'concentration of quercetin 3-O-β-D-glucosyl-(1→2)-β-D-glucoside in material entity',
#   'concentration of triterpenoid in material entity',
#   'decreased object quality',
#   'decreased quality',
#   'concentration of water in material entity',
#   'concentration of gentisyl alcohol in material entity',
#   'concentration of avenacin A-1 in material entity',
#   'concentration of glycosyloxyisoflavone in material entity',
#   'concentration of (20S)-ginsenoside Rg3 in material entity',
#   'concentration of scutellarein in material entity',
#   'concentration of diglyceride in material entity',
#   'concentration of 2,5-dihydroxybenzoic acid in material entity',
#   'concentration of 6-prenylnaringenin in material entity',
#   'concentration of glycosinolate in material entity',
#   'concentration of all-cis-icosa-8,11,14-trienoic acid in material entity',
#   'concentration of Sesamolinol in material entity',
#   'extent of food heat treatment',
#   'concentration of sulfite in material entity',
#   'concentration of 6-hydroxyluteolin 7-O-laminaribioside in material entity',
#   'concentration of glucose derived from glucomannan derived from hemicellulose in material entity',
#   'concentration of ginsenoside Rb2 in material entity',
#   'concentration of ferric ammonium citrate in material entity',
#   'concentration of 7,10,13,16-docosatetraenoic acid in material entity',
#   'pink skin',
#   'concentration of tetracosanoic acid in material entity',
#   'concentration of (1S,4R)-fenchone in material entity',
#   'concentration of hydroxyflavan in material entity',
#   'normal length',
#   'concentration of ascorbic acid in material entity',
#   'concentration of kaempferol 3-O-β-D-glucosyl-(1→2)-β-D-glucoside in material entity',
#   'gold skin',
#   'concentration of peltogynoid in material entity',
#   'concentration of fructose derived from sucrose in material entity',
#   'concentration of xanthohumol in material entity',
#   'environmental food contaminant',
#   'concentration of luteolin 7-O-beta-D-glucosiduronic acid in material entity',
#   'depth',
# ...
#   'piece(s) of buffalo meat (boneless)'},
#  {'Galine eggplant cultivar', 'Solanum virginianum'},
#  {'compound leaf', 'pinnate leaf'},
#  {'Brassica rapa subsp. nipposinica', 'Brassica rapa var. perviridis'},
#  {'bakery product (us cfr)',
#   'bakery product, unsweetened (us cfr)',
#   'bread (us cfr)',
#   'cracker (us cfr)',
#   'pastry shell, unsweetened (us cfr)'},
#  {'Tricholoma', 'Tricholoma magnivelare', 'Tricholoma matsutake'},
#  {'durum wheat pasta food product', 'wheat pasta food product'},
#  {'green bean plant',
#   'phaseolus vulgaris plant',
#   'phaseolus vulgaris, edible pod cultivar (plant)',
#   'wax bean plant'},
#  {'compound feed premix',
#   'compound feed premix (medicated)',
#   'feedstuff (food for agricultural animals)',
#   'fodder (animal feed)',
#   'timothy fodder silage'},
#  {'argentine', 'argentine family'},
#  {'01810 - dried pasta (efsa foodex2)',
#   '01820 - dried egg pasta (efsa foodex2)',
#   '01830 - dried durum pasta (efsa foodex2)'},
#  {'Bolinus brandaris',
#   'Concholepas concholepas',
#   'Haustellum',
#   'Murex',
#   'Muricidae',
#   'Trophon geversianus'},
#  {'Prionotus', 'Prionotus carolinus', 'Prionotus stephanophrys'},
#  {'spaghetti squash', 'spaghetti squash (raw)'},
#  {'dolichos plant', 'horse gram bean plant', 'hyacinth bean plant'},
#  {'ochre', 'yellow orange'},
#  {'Beryx',
#   'Beryx decadactylus',
#   'Beryx splendens',
#   'alfonsino family',
#   'alfonsinos'},
#  {'Strongylocentrotus', 'Strongylocentrotus droebachiensis'},
#  {'10130 - starchy root and tuber products (efsa foodex2)',
#   '10140 - dried starchy roots and tuber products (efsa foodex2)',
#   '10150 - dried potato products (efsa foodex2)',
#   '10170 - potato flour (efsa foodex2)',
#   '10180 - potato flakes (efsa foodex2)',
#   '10190 - canned starchy root products (efsa foodex2)'},
#  {'Aroideae', 'Colocasia esculenta', 'Typhonium'},
#  {'Kryptopterus', 'Kryptopterus limpok'},
#  {'27050 - traditional sour milk products (efsa foodex2)',
#   '27080 - traditional nordic fermented milks (efsa foodex2)',
#   '27090 - långfil (efsa foodex2)',
#   '27100 - filmjölk (efsa foodex2)',
#   '27110 - viili (efsa foodex2)'},
#  {'Chondrus',
#   'Chondrus crispus',
#   'Gracilariaceae',
#   'Rhodymenia',
#   'Rhodymeniophycidae'},
#  {'vermicelli (egg, vegetable)', 'vermicelli (egg, vegetable, enriched)'},
#  {'excreta', 'feces'},
#  {'Macadamia', 'Macadamia integrifolia'},
#  {'plastic squeeze bottle or tube',
#   'plastic squeeze bottle or tube, top lined with cork',
#   'plastic squeeze bottle or tube, top lined with foil',
#   'plastic squeeze bottle or tube, unlined top'},
#  {'Apocryptes bato',
#   'Oxudercinae',
#   'Periophthalmus',
#   'Periophthalmus barbarus',
#   'Pseudapocryptes'},
#  {'citron melon food product',
#   'citron melon jam',
#   'citrullus lanatus fruit food product'},
#  {'potassium atom', 'potassium-39 atom'},
#  {'cow milk feta cheese', 'feta cheese', 'feta cheese food product'},
#  {'23460 - cod (efsa foodex2)',
#   '23480 - cod, greenland (efsa foodex2)',
#   '23490 - cod, pacific (efsa foodex2)'},
#  {'embryo root', 'radicle', 'seedling radicle'},
#  {'agricultural field', 'field'},
#  {'carbohydrate removal process', 'lactose removal process'},
#  {'seafood sandwich', 'tuna salad sandwich'},
#  {'skeletal meat part, with bone, without skin',
#   'skeletal meat part, with bone, without skin, with separable fat',
#   'skeletal meat part, with bone, without skin, without separable fat'},
#  {'Lampetra fluviatilis',
#   'Petromyzon marinus',
#   'Petromyzontidae',
#   'lamprey family'},
#  {'38380 - dairy imitates other than milks (efsa foodex2)',
#   '38390 - imitation cream (efsa foodex2)',
#   '38400 - non dairy coffee creamer (efsa foodex2)',
#   '38420 - soya yoghurt (efsa foodex2)',
#   '38440 - imitation yoghurt, non soy (efsa foodex2)'},
#  {'Hystricomorpha', 'Myocastor coypus'},
#  {'Gnetum', 'Gnetum gnemon'},
#  {'00200 - finger millet grain (efsa foodex2)',
#   '00210 - african millet grain (efsa foodex2)'},
#  {'tofu (cooked, dried)', 'tofu food product'},
#  {'22770 - pike (efsa foodex2)', '22790 - northern pike (efsa foodex2)'},
#  {'4-hydroxybenzaldehyde', 'hydroxybenzaldehyde'},
#  {'15690 - aronia berries (efsa foodex2)',
#   '15700 - aronia berries (red) (efsa foodex2)',
#   '15710 - aronia berries (black) (efsa foodex2)'},
#  {'10000202 - drinks flavoured - not ready to drink (gs1 gpc)',
#   '10000264 - sports drinks - rehydration (not ready to drink) (gs1 gpc)',
#   '10000307 - juice - not ready to drink (frozen) (gs1 gpc)',
#   '10000308 - juice - not ready to drink (shelf stable) (gs1 gpc)',
#   '10000309 - juice drinks - not ready to drink (shelf stable) (gs1 gpc)',
#   '10000310 - dairy/dairy substitute based drinks - not ready to drink (shelf stable) (gs1 gpc)',
#   '10006253 - vegetable juice - not ready to drink (frozen) (gs1 gpc)',
#   '10006254 - vegetable juice - not ready to drink (shelf stable) (gs1 gpc)',
#   '10006257 - vegetable juice drinks - not ready to drink (shelf stable) (gs1 gpc)',
#   '50202400 - non alcoholic beverages - not ready to drink (gs1 gpc)'},
#  {'ice cap climatic zone', 'polar climatic zone', 'tundra climatic zone'},
#  {'african lungfish family', 'fish, lepidosireniform'},
#  {'beaked hazelnut', 'hazelnut'},
#  {'Osmerus mordax', 'Osmerus mordax dentex', 'Osmerus mordax mordax'},
#  {'chicken bone', 'chicken bone (cooked)'},
#  {'sporophyte development stage', 'sporophyte vegetative stage'},
#  {'fat', 'fat (enzyme-modified)', 'fat (water removed)', 'frying fat'},
#  {'butter (eurofir)',
#   'butter or other animal fat (eurofir)',
#   'other animal fats (eurofir)'},
#  {'hachis parmentier', "shepherd's pie"},
#  {'Fusarium venenatum', 'Pezizomycotina', 'leotiomyceta'},
#  {'21370 - cooked cured (or seasoned) ovine meat (efsa foodex2)',
#   '21380 - pastrami, lamb (efsa foodex2)'},
#  {'cannibalism', 'intrauterine cannibalism'},
#  {'hesperetin', 'neohesperidin'},
#  {'heterocyclic antibiotic', 'organooxygen heterocyclic antibiotic'},
#  {'00060 - barley grains (efsa foodex2)',
#   '00070 - barley grain, pearled (efsa foodex2)'},
#  {'Minianka', 'Senufo'},
#  {'00490 - rye and similar- (efsa foodex2)',
#   '00500 - rye grain (efsa foodex2)'},
#  {'high omega-3 fatty acids',
#   'high polyunsaturated fat',
#   'omega-3 fatty acids claim',
#   'polyunsaturated fat claim'},
#  {'15330 - wine grapes and similar- (efsa foodex2)',
#   '15340 - wine grapes (efsa foodex2)',
#   '15350 - amur river grapes (efsa foodex2)',
#   '15360 - muscadine grapes (efsa foodex2)'},
#  {'Arhynchobatidae',
#   'Bathyraja',
#   'Bathyraja aleutica',
#   'Bathyraja interrupta',
#   'Bathyraja parmifera'},
#  {'barley sprout', 'barley vegetable food product'},
#  {'10006261 - edible flowers (gs1 gpc)',
#   '50262000 - edible flowers (gs1 gpc)'},
#  {'10000614 - seafood variety packs (gs1 gpc)',
#   '50122400 - seafood variety packs (gs1 gpc)'},
#  {'2171 corn cultivar',
#   'Allure corn cultivar',
#   'Festivity corn cultivar',
#   'Zea mays',
#   'Zea mays subsp. huehuetenangensis',
#   'Zea mays subsp. mays',
#   'Zea mays subsp. parviglumis'},
#  {'25780 - frog meat (rana genus) (efsa foodex2)',
#   '25790 - bullfrog (efsa foodex2)',
#   '25800 - frog, agile (efsa foodex2)',
#   '25810 - frog, common (efsa foodex2)'},
#  {'Tetrapturus', 'Tetrapturus angustirostris', 'Tetrapturus pfluegeri'},
#  {'atlantic halibut (raw)', 'atlantic halibut food product'},
#  {'seedless white grape', 'seedless white grape (raw)'},
#  {'isoflavanone', 'isoflavans'},
#  {'green acorn squash', 'green acorn squash (raw)'},
#  {'halfbeak family', 'new zealand garfish'},
#  {'Atherinidae',
#   'Atheriniformes',
#   'Atherinopsidae',
#   'Atherinopsinae',
#   'Atherinopsis californiensis',
#   'Chirostoma jordani',
#   'Leuresthes tenuis',
#   'Menidia menidia',
#   'Menidiinae',
#   'Odontesthes regia',
#   'neotropical silverside family'},
#  {'10000148 - aquatic invertebrates - unprepared/unprocessed (frozen) (gs1 gpc)',
#   '10000149 - aquatic invertebrates - unprepared/unprocessed (perishable) (gs1 gpc)',
#   '50122300 - aquatic invertebrates - unprepared/unprocessed (gs1 gpc)'},
#  {'extra firm tofu', 'extra firm tofu (sauteed)'},
#  {'Kajikia', 'Kajikia albida', 'Kajikia audax'},
#  {'fruit, peel removed', 'fruit, peel removed, core, pit or seed present'},
#  {'salsify root', 'salsify root (raw)'},
#  {'Polyodontinae', 'Psephurus gladius'},
#  {'food packing medium compromised',
#   'food packing medium drained',
#   'food packing medium integrity'},
#  {'kidney bean plant', 'red kidney bean plant'},
#  {'cloud ear mushroom', 'cloud ear mushroom (dried)'},
#  {'apple based alcoholic beverage',
#   'apple brandy',
#   'hard cider (artificially carbonated)',
#   'hard cider (sugar added)'},
#  {'Berberis', 'Berberis vulgaris'},
#  {'alcohol-free beer',
#   'barley alcoholic beverage analog',
#   'beer (dealcoholized)',
#   'malt beverage (nonalcoholic)'},
#  {'cheddar cheese (filled)',
#   'cheddar cheese (filled, containing margarine)',
#   'cheese (natural with margarine)',
#   'cheese and parsley spread',
#   'cow milk cheese analog',
#   'dairy spread (low calorie)',
#   'filled cheese',
#   'imitation semisoft part skim cheese',
#   'swiss cheese (filled, containing butter)'},
#  {'female pseudohermaphrodite',
#   'male pseudohermaphrodite',
#   'pseudohermaphrodite'},
#  {'alfalfa plant', 'bastard medic plant'},
#  {'cholesterol special claim',
#   'low in cholesterol claim',
#   'no or reduced cholesterol claim'},
#  {'beverage analog',
#   'imitation lemonade drink',
#   'imitation nonalcoholic beverage'},
#  {'smooth moon turban', 'top shell'},
#  {'17170 - prickly pears and similar- (efsa foodex2)',
#   '17180 - prickly pears (efsa foodex2)',
#   '17210 - saguaro fruits (efsa foodex2)'},
#  {'piece(s) of gazelle organ', 'piece(s) of gazelle organ (raw)'},
#  {'food aeration by creaming', 'food aeration process'},
#  {'Krameria', 'Krameriaceae', 'Zygophyllales'},
#  {'bakery product (fine)',
#   'bakery product, fine, energy reduced',
#   'bakery product, fine, flat',
#   'bakery product, fine, for special nutritional uses'},
#  {'spinose chiton', 'spiny chiton'},
#  {'32680 - bottled water (efsa foodex2)',
#   '32750 - flavoured bottled water (efsa foodex2)',
#   '32760 - fortified bottled water (efsa foodex2)'},
#  {'30560 - hard candies (efsa foodex2)',
#   '30570 - dragée, sugar coated (efsa foodex2)'},
#  {'Malacanthidae', 'Malacanthus plumieri'},
#  {'Duration', 'Temporal Duration'},
#  {'Squilla mantis', 'Squillidae'},
#  {'new zealand spider crab', 'spider crab family'},
#  {'Carnosol',
#   'Ineketone',
#   'crocetin',
#   'diterpenoid',
#   'steviol glycoside',
#   'stevioside'},
#  {'09410 - fermented vegetables (efsa foodex2)',
#   '09420 - sauerkraut (efsa foodex2)'},
#  {'dressing, mayonnaise (eurofir)',
#   'flavouring or essence (eurofir)',
#   'herb or spice (eurofir)',
#   'spice, condiment or other ingredient (eurofir)'},
#  {'13750 - caraway fruit and similar- (efsa foodex2)',
#   '13760 - caraway fruit (efsa foodex2)',
#   '13770 - ajowan fruit (efsa foodex2)'},
#  {'Aphareus', 'Aphareus furca', 'Aphareus rutilans'},
#  {'Prochilodus', 'Prochilodus reticulatus'},
#  {'Grewia', 'Grewioideae'},
#  {'12870 - saffron and similar- (efsa foodex2)',
#   '12880 - saffron (efsa foodex2)'},
#  {'cheese blended pasteurized',
#   'pasteurized blended cheese food product',
#   'pasteurized blended cheese with fruits vegetables or meats'},
#  {'Phasianinae', 'Phasianus'},
#  {'Anadara', 'Anadara baughmani'},
#  {'dark magenta', 'desaturated magenta', 'light magenta', 'magenta'},
#  {'apple cider (alcoholic)', 'cider (aromatized)', 'cidre bouche'},
#  {'10006361 - ferns (cinnamon) (gs1 gpc)',
#   '10006824 - fiddlehead ferns (gs1 gpc)',
#   '50262400 - ferns (gs1 gpc)'},
#  {'cassytha plant', 'coarse dodderlaurel plant'},
#  {'Canthidermis', 'Canthidermis maculata'},
#  {'dessert (jelly-like)', 'mizu yōkan', 'yokan'},
#  {'effervescent tablet', 'non-chewable tablet'},
#  {'Majoidea', 'Oregoniidae'},
#  {'kim chee', 'kim chee (refrigerated)'},
#  {'almond bark (artificially sweetened)',
#   'almond candy food product',
#   'jordan almond',
#   'marzipan',
#   'marzipan candy'},
#  {'shrimp cocktail', 'shrimp cocktail (curried, canned)'},
#  {'0800000 - spices (ec)',
#   '0810000 - spices, seeds (ec)',
#   '0820000 - spices, fruits and berries (ec)',
#   '0850000 - spices, buds (ec)',
#   '0860000 - spices, flower stigma (ec)',
#   '0870000 - spices, aril (ec)'},
#  {'reduced salt claim', 'reduced salt or sodium claim'},
#  {'arrowroot flour', 'arrowroot flour food product'},
#  {'50330000 - nuts/seeds - unprepared/unprocessed (perishable) (gs1 gpc)',
#   '50330100 - nuts/seeds - unprepared/unprocessed (perishable) (gs1 gpc)'},
#  {'cusk (raw)', 'cusk fillet (frozen)', 'cusk food product', 'moonfish (raw)'},
#  {'lumpfish (raw)',
#   'lumpfish food product',
#   'lumpfish roe (chilled)',
#   'lumpfish roe semi-preserved'},
#  {'caprine cheese food product',
#   'goat milk cheese',
#   'goat milk cheese (marinated in olive oil)',
#   'goat milk cheese (unpasteurized)',
#   'goat milk cheese food product'},
#  {'Chitala', 'Chitala chitala', 'Chitala lopis'},
#  {'01880 - dried stuffed pasta (efsa foodex2)',
#   '01890 - dried stuffed egg pasta (efsa foodex2)'},
#  {'atlantic croaker (raw)', 'croaker (raw)'},
#  {'05780 - onions and similar- (efsa foodex2)',
#   '05790 - onions (efsa foodex2)',
#   '05800 - onion bulbs for fresh consumption (efsa foodex2)',
#   '05820 - rakkyo (efsa foodex2)',
#   '05830 - silverskin onions (efsa foodex2)'},
#  {'4-8 cell stage embryo', '8-cell stage embryo'},
#  {'05840 - shallots and similar- (efsa foodex2)',
#   '05850 - shallots (efsa foodex2)',
#   '05870 - persian shallots (efsa foodex2)'},
#  {'10000207 - fruit/nuts/seeds mixes - prepared/processed (shelf stable) (gs1 gpc)',
#   '10000604 - fruit/nuts/seeds combination variety packs (gs1 gpc)',
#   '50101900 - fruit/nuts/seeds combination (gs1 gpc)'},
#  {'13-cis-retinal', 'retinal'},
#  {'Rhinoceros', 'Rhinocerotidae'},
#  {'fish cake', 'fish cake (raw)', 'fish cake (raw, breaded)'},
#  {'aluminium can, drum or barrel, plastic coated',
#   'aluminum can, drum or barrel'},
#  {'high density polyethylene container', 'polyethylene container'},
#  {'Zosterisessor', 'Zosterisessor ophiocephalus', 'zosterisessor'},
#  {'cow whole milk 3.5% fat', 'cow whole milk 3.5% fat (vitamin D fortified)'},
#  {'Gruiformes', 'Grus americana'},
#  {'malnutrition supplement food product',
#   'moderate malnutrition supplement food product'},
#  {'Pseudorhombus',
#   'Pseudorhombus arsius',
#   'Pseudorhombus jenynsii',
#   'Pseudorhombus pentophthalmus'},
#  {'imide', 'mixed diacylamine'},
#  {'32720 - bottled drinking water (efsa foodex2)',
#   '32740 - carbonated bottled drinking water (efsa foodex2)'},
#  {'20280 - goose liver (efsa foodex2)', '20290 - foie gras (efsa foodex2)'},
#  {'cow milk (sterilized)', 'cow milk (sterilized, yogurt-flavored)'},
#  {'Chloroscombrus', 'Chloroscombrus chrysurus', 'Chloroscombrus orqueta'},
#  {'Pollicipes', 'Pollicipes pollicipes', 'Pollicipes polymerus'},
#  {'hass avocado', 'hass avocado (raw)'},
#  {'spirochaetae', 'spirochaetes'},
#  {'pineapple and grapefruit juice drink (canned, diluted)',
#   'pineapple and grapefruit juice drink (diluted)'},
#  {'lotic water body', 'watercourse'},
#  {'14080 - processed legumes, nuts, oilseeds and spices (efsa foodex2)',
#   '14160 - canned or jarred legumes (efsa foodex2)',
#   '14180 - canned or jarred peas (efsa foodex2)',
#   '14200 - canned or jarred chickpea (efsa foodex2)'},
#  {'Fasciolariidae', 'Triplofusus giganteus'},
#  {'meat product (canned)', 'meat product (minced or diced, canned)'},
#  {'Saurida', 'Saurida filamentosa'},
#  {'Taraxacum', 'Taraxacum officinale'},
#  {'27130 - probiotic milk-like drinks (efsa foodex2)',
#   '27140 - acidophilus milk (efsa foodex2)'},
#  {'globulin type', 'glutenin', 'prolamin'},
#  {'chicken roast (boneless)',
#   'chicken roast (boneless, seasoned, fresh frozen)'},
#  {'biaxial oriented polypropylene container',
#   'polyolefin container',
#   'polypropylene container'},
#  {'22070 - canned-tinned meat (efsa foodex2)',
#   '22100 - tinned bulk sausages (efsa foodex2)'},
#  {'whole grain bread', 'whole oat bread'},
#  {'Bathycongrus', 'Bathycongrus aequoreus'},
#  {'29650 - egg mixed whole (efsa foodex2)',
#   '29660 - hen egg mixed whole (efsa foodex2)'},
#  {'yellow variety sweet potato (raw)',
#   'yellow variety sweet potato (raw, skin on)'},
#  {'potato (pre-fried, deep-frozen)',
#   'potato (pre-fried, frozen)',
#   'potato (precooked)'},
#  ...]

# %%
# Load a text file in Python
final_content = []
with open("FoodOn/train/foodon_train_types.txt", "r", encoding="utf-8") as f:
    contents = f.readlines()
    for content in contents:
        final_content.append(content.strip('\n'))


print(contents[:500])  # Print first 500 characters
# Out:
 'Lampris guttatus\n', 'commercial grade\n', 'scallop (russian, raw)\n', 'butter-flavored table syrup\n', 'microbial/enzymatic modification process\n', 'bison top round steak\n', '21070 - processed whole meat products (efsa foodex2)\n', 'antifoaming agent (ec)\n', '20870 - pig trotters and feet (efsa foodex2)\n', '09440 - vegetable puree or paste (efsa foodex2)\n', '36620 - materials for infusions or hot drinks of miscellaneous origin (efsa foodex2)\n', 'Haliotis fulgens\n', 'Berycidae\n', 'Eubrachyura\n', 'd.  processed food of plant origin (ccpr)\n', 'concentration of L-dehydroascorbic acid in material entity\n', 'piece of animal ovary (raw)\n', 'pomfret\n', 'pigeon\n', '39690 - pasta, filled with meat mix, cooked (efsa foodex2)\n', 'Codex Alimentarius food classification for  ...

# %%
len(contents), contents[0]
# Out:
# (31076, '25000 - edible crab (efsa foodex2)\n')

# %%
len(final_content), final_content[0]
# Out:
# (31076, '25000 - edible crab (efsa foodex2)')

# %%
from collections import Counter
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.notebook import tqdm
import copy

# --- Sample Input (Replace with your data) ---


# --- Assignment Function ---
def assign_term_to_cluster(term, clusters):
    new_words = term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for cluster_term in cluster:
            for word in cluster_term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)

    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]

    if max_score == 0:
        return None, term
    return best_cluster_index, term

# --- Parallel Execution with tqdm ---
def parallel_assign_terms(terms, clusters):
    results = []
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(assign_term_to_cluster, term, clusters): term for term in terms}
        for future in tqdm(as_completed(futures), total=len(futures), desc="Assigning terms"):
            results.append(future.result())
    return results

# --- Cluster Assignment ---
final_clusters = [set(cluster) for cluster in copy.deepcopy(clusters)]
assignments = parallel_assign_terms(final_content, final_clusters)

# --- Update Final Clusters ---
for cluster_idx, term in assignments:
    if cluster_idx is not None:
        final_clusters[cluster_idx].add(term)
    else:
        final_clusters.append(set([term]))

# --- Output ---
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")

# %%
from collections import Counter
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm
import copy

# Sample clusters and final_content (replace with your data)
# clusters = [
#     {'steroid', 'steroid hormone'},
#     {'molecular entity', 'elemental molecular entity'},
#     {'carboxylic acid', 'amino acid'},
# ]

# final_content = [
#     "acid molecule", "entity class", "steroid precursor",
#     "amino acid derivative", "biological steroid", "unknown compound"
# ]

# Step 3: Assign function
def assign_term_to_cluster(args):
    new_term, clusters = args
    new_words = new_term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for term in cluster:
            for word in term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)
    
    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]

    if max_score == 0:
        return None, new_term  # No match
    return best_cluster_index, new_term

# Step 4: Parallel assignment
def parallel_assign(final_content, clusters):
    results = []
    with ThreadPoolExecutor() as executor:
        futures = list(tqdm(executor.map(assign_term_to_cluster, [(term, clusters) for term in final_content]), total=len(final_content)))
        results.extend(futures)
    return results

# Final clusters copy
final_clusters = [set(cluster) for cluster in copy.deepcopy(clusters)]

# Assign
results = parallel_assign(final_content, final_clusters)

# Step 5: Update clusters
for cluster_idx, term in results:
    if cluster_idx is not None:
        final_clusters[cluster_idx].add(term)
    else:
        final_clusters.append(set([term]))

# Step 6: Convert to list of lists
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

# Display final clusters
for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")

# %%
from collections import Counter
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.notebook import tqdm
import copy

# --- Sample Input (Replace with your data) ---
clusters = [
    {'steroid', 'steroid hormone'},
    {'molecular entity', 'elemental molecular entity'},
    {'carboxylic acid', 'amino acid'},
]

final_content = [
    "acid molecule", "entity class", "steroid precursor",
    "amino acid derivative", "biological steroid", "unknown compound"
]

# --- Assignment Function ---
def assign_term_to_cluster(term, clusters):
    new_words = term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for cluster_term in cluster:
            for word in cluster_term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)

    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]

    if max_score == 0:
        return None, term
    return best_cluster_index, term

# --- Parallel Execution with tqdm ---
def parallel_assign_terms(terms, clusters):
    results = []
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(assign_term_to_cluster, term, clusters): term for term in terms}
        for future in tqdm(as_completed(futures), total=len(futures), desc="Assigning terms"):
            results.append(future.result())
    return results

# --- Cluster Assignment ---
final_clusters = [set(cluster) for cluster in copy.deepcopy(clusters)]
assignments = parallel_assign_terms(final_content, final_clusters)

# --- Update Final Clusters ---
for cluster_idx, term in assignments:
    if cluster_idx is not None:
        final_clusters[cluster_idx].add(term)
    else:
        final_clusters.append(set([term]))

# --- Output ---
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")
# Out:
# Assigning terms:   0%|          | 0/6 [00:00<?, ?it/s]
# Cluster 1: ['biological steroid', 'steroid', 'steroid hormone', 'steroid precursor']
# Cluster 2: ['elemental molecular entity', 'entity class', 'molecular entity']
# Cluster 3: ['acid molecule', 'amino acid', 'amino acid derivative', 'carboxylic acid']
# Cluster 4: ['unknown compound']

# %%
# Step 3: Assign function
from collections import Counter
from tqdm.notebook import tqdm
def assign_term_to_cluster(new_term, clusters):
    new_words = new_term.lower().split()
    cluster_scores = []

    for cluster in clusters:
        word_count = Counter()
        for term in cluster:
            for word in term.lower().split():
                word_count[word] += 1
        score = sum(word_count[word] for word in new_words)
        cluster_scores.append(score)
    
    best_cluster_index = max(range(len(cluster_scores)), key=lambda i: cluster_scores[i])
    max_score = cluster_scores[best_cluster_index]
    
    if max_score == 0:
        return None  # No match
    return best_cluster_index

# Step 4: Assign all new terms
final_clusters = [set(cluster) for cluster in clusters]  # copy original clusters

for term in tqdm(final_content):
    assigned_idx = assign_term_to_cluster(term, final_clusters)
    if assigned_idx is not None:
        final_clusters[assigned_idx].add(term)
    else:
        # Create new cluster if no match found
        final_clusters.append(set([term]))

# Step 5: Convert to list of lists and return
final_clusters_list = [sorted(list(cluster)) for cluster in final_clusters]

# Display final clusters
for i, cluster in enumerate(final_clusters_list, 1):
    print(f"Cluster {i}: {cluster}")
# Out:
#   0%|          | 0/31076 [00:00<?, ?it/s]
# Cluster 1: ['!Kung', "'hyacinth bean (dried)'", "(+)-catechin-3'-methyl ether", '(+)-exo-5-hydroxycamphor', '(+)-nootkatone', '(+)-pinoresinol', '(+)-taxifolin', '(-)-Variabilin', '(-)-alpha-thujone', '(-)-lariciresinol', '(-)-matairesinol', '(-)-menthol', '(-)-secoisolariciresinol', '(1->4)-beta-D-glucan', '(11Z)-icos-11-enoic acid', '(1S,4R)-fenchone', '(20S)-ginsenoside Rg3', '(2E,6E)-farnesyl monophosphate', '(2S)-poncirin', '(6R)-5,10-methenyltetrahydrofolate', '(6Z,9Z,12Z,15Z,18Z,21Z)-tetracosahexaenoic acid', '(E)-sinapaldehyde', '(E)-trans-miyabenol C', '(R)-camphor', '(R)-propane-1,2-diol', '(R)-rosmarinic acid', '(R,R,R)-alpha-tocopherol', '(R,R,S)-alpha-tocopherol', '(R,S,S)-alpha-tocopherol', '(S)-(-)-perillyl alcohol', '(S)-naringenin', '(S,R,S)-alpha-tocopherol', '(S,S,R)-alpha-tocopherol', '(S,S,S)-alpha-tocopherol', '(percent) fat free claim', '00010 - grains and grain-based products (efsa foodex2)', '00020 - cereals and cereal primary derivatives (efsa foodex2)', '00030 - cereal grains (and cereal-like grains) (efsa foodex2)', '00040 - mixture of grains (efsa foodex2)', '00050 - barley and similar- (efsa foodex2)', '00060 - barley grains (efsa foodex2)', '00070 - barley grain, pearled (efsa foodex2)', '00080 - buckwheat and other pseudo-cereals and similar- (efsa foodex2)', '00090 - buckwheat (efsa foodex2)', '001  citrus fruits (fc) (ccpr)', '00100 - amaranth grains (efsa foodex2)', '00110 - foxtail amaranth grain (efsa foodex2)', '00120 - red amaranth grains (efsa foodex2)', '00160 - common millet and similar- (efsa foodex2)', '00170 - common millet grain (efsa foodex2)', '00180 - black fonio grain (efsa foodex2)', '00190 - canary grass grain (efsa foodex2)', '00200 - finger millet grain (efsa foodex2)', '00210 - african millet grain (efsa foodex2)', '00220 - foxtail millet grain (efsa foodex2)', '00240 - little millet grain (efsa foodex2)', '00250 - pearl millet grain (efsa foodex2)', '00270 - white fonio grain (efsa foodex2)', '00280 - barnyard millet (efsa foodex2)', '00290 - maize and similar- (efsa foodex2)', '00310 - te
# Cluster 15: ['36300 - roots used for herbal infusions (efsa foodex2)', '36310 - valerian infusion roots and similar- (efsa foodex2)', '36320 - valerian infusion roots (efsa foodex2)', '36330 - blue flag infusion roots (efsa foodex2)', '36350 - couch grass infusion roots (efsa foodex2)', '36360 - cowslip infusion roots (efsa foodex2)', '36370 - echinacea infusion roots (efsa foodex2)', '36400 - purple echinacea infusion roots (efsa foodex2)', '36430 - golden root infusion roots (efsa foodex2)', '36440 - herb bennet infusion roots (efsa foodex2)', '36450 - marshmallow infusion roots (efsa foodex2)', '36470 - pimpernel infusion roots (efsa foodex2)', '36480 - rhatany infusion roots (efsa foodex2)', '36530 - ginseng and similar- (efsa foodex2)', '36540 - ginseng infusion roots (efsa foodex2)', '36550 - asian ginseng infusion roots (efsa foodex2)', '36560 - american ginseng infusion roots (efsa foodex2)', '36570 - siberian ginseng infusion roots (efsa foodex2)', '36580 - other herbal infusion materials from roots (efsa foodex2)']
# Cluster 16: ['Breakfast', 'Lunch', 'Supper', 'acetic acid fermentation', 'acidification process', 'adding liquid to container', 'adding material to container', 'adding solid to container', 'agricultural food production', 'agricultural process', 'alcohol fermentation', 'alcohol removal process', 'alcohol-acetic acid fermentation', 'alcoholization process', 'alkaloid or purine removal process', 'analyte assay', 'aquaculture open-pen rearing', 'aquaculture production', 'artificial carbonation process', 'artificial heat drying', 'assay', 'autotrophy', 'bacterial food-curing process', 'bactivory', 'biological process involved in interspecies interaction between organisms', 'biological_process', 'blind baking', 'broiling or grilling', 'carbohydrate fermentation', 'carbohydrate removal process', 'carbonation by fermentation', 'carbonation process', 'carbonic maceration', 'carnivory', 'carob coating or covering process', 'chemical food preservation process', 'chemosymbiosis', 'commissary food preparation process', 'component substitution process', 'concentration by reverse osmosis', 'controlled atmosphere storage process', 'controlled environment agriculture (CEA) production', 'conventional maceration', 'conventional outdoor/open-air cultivation', 'cooking by dry heat', 'cooking by microwave', 'cooking by moist heat', 'cooking in steam', 'corn husking', 'crop cultivation process', 'debittering process', 'decaffeination process', 'decomposition', 'deep-frying process', 'dehydration or drying', 'demineralizing process', 'deposit feeding', 'destemmed grape pressing', 'detritivory', 'dilution process to 50-99% of single strength', 'direct heating of container', 'domestic or cultivated food production', 'drying by radiation', 'drying under reduced pressure', 'durophagy', 'egg predation', 'environmental system process', 'enzymatic modification process', 'extended maceration', 'fat removal process', 'fat substitution process', 'filling conditions for pasteurization', 'food alkalization process', 'food animal rearing', 'food animal rendering', 'food baking', 'food blanching', 'food bleaching process', 'food bromination process', 'food canning', 'food certified color addition process', 'food cleaning', 'food coating or covering process', 'food color addition process', 'food component addition process', 'food component separation process', 'food cooking', 'food cubing', 'food cutting process', 'food dehulling', 'food dry salting', 'food evaporation process', 'food facility preparation process', 'food fermentation', 'food filling process', 'food filtration', 'food flaking process', 'food flattening process', 'food grinding', 'food harvesting', 'food homogenization or emulsification process', 'food hydrogenation process', 'food hydrolyzation process', 'food instantizing', 'food irradiation process', 'food meat liquid injection process', 'food micro-encapsulation process', 'food milling', 'food mincing', 'food modification process', 'food noncertified color addition process', 'food packaging process', 'food parboiling process (grain)', 'food peeling', 'food physical forming', 'food plant cultivation', 'food preservation process', 'food production', 'food puffing process', 'food recipe process', 'food reheating', 'food reheating by dry heat', 'food reheating by microwave', 'food reheating in pan or cooking utensil', 'food rolling process', 'food salting', 'food seasoning process', 'food smoking', 'food solvent extraction', 'food sterilization after filling', 'food sterilization by heating', 'food thawing process', 'food toasting', 'food transformation process', 'food treatment process', 'food ultraviolet radiation process', 'free-range food animal rearing', 'freeze-drying', 'fruit crushing', 'full alcohol removal process', 'full fat removal process', 'fungivory', 'gluten removal process', 'grape crushing and destemming', 'grape destemming', 'grape pressing', 'griddle cooking', 'harvest process', 'heat drying process', 'heat treatment food preservat ...
# Cluster 17: ['22860 - diadromous fish (efsa foodex2)', '22870 - sturgeons, paddlefishes (efsa foodex2)', '22880 - sturgeon (efsa foodex2)', '22890 - paddle fish (efsa foodex2)', '22900 - river eels (efsa foodex2)', '22910 - eel, american (efsa foodex2)', '22930 - eel, european (efsa foodex2)', '23200 - shads (efsa foodex2)', '23210 - hilsa shad (efsa foodex2)', '23220 - miscellaneous diadromous fishes (efsa foodex2)', '23230 - barramundi (efsa foodex2)', '23240 - milkfish (efsa foodex2)', '23250 - perch, white (efsa foodex2)']
# Cluster 18: ['Apogonidae', 'Ostorhinchus', 'Ostorhinchus maculiferus']
# Cluster 19: ['Carcharhinidae', 'Carcharhinus', 'Carcharhinus albimarginatus', 'Carcharhinus altimus', 'Carcharhinus amblyrhynchos', 'Carcharhinus brachyurus', 'Carcharhinus brevipinna', 'Carcharhinus falciformis', 'Carcharhinus melanopterus', 'Carcharhinus obscurus', 'Carcharhinus perezii', 'Carcharhinus plumbeus', 'Carcharhinus porosus', 'Carcharhinus signatus', 'Galeocerdo cuvier', 'Prionace glauca', 'Sphyrna', 'Sphyrna lewini', 'Sphyrna mokarran', 'Sphyrna tiburo', 'Sphyrna tudes', 'Sphyrna zygaena', 'Triaenodon obesus', 'grey sharks', 'hammerhead shark', 'requiem shark family']
# Cluster 20: ['40420 - puffs/curls-type extruded snack (efsa foodex2)', '40430 - corn curls (efsa foodex2)']
# Cluster 21: ['030  meat (from mammals other than marine mammals) (mm) (ccpr)', '033  milks (ml) (ccpr)', '06  mammalian products (ccpr)']
# Cluster 22: ['pecan (chopped)', 'pecan (dry roasted)', 'pecan (ground)', 'pecan (kernel)', 'pecan (oil roasted)', 'pecan (whole or pieces)', 'pecan meal']
# Cluster 23: ['Flammulina velutipes', 'Lentinula edodes', 'Marasmiineae', 'Marasmius oreades', 'Physalacriaceae']
# Cluster 24: ['14220 - fruit used as fruit (efsa foodex2)', '14710 - pome fruits (efsa foodex2)', '14760 - pears and similar- (efsa foodex2)', '14770 - pears (efsa foodex2)', '14780 - nashi pears (efsa foodex2)', '14790 - wild pears (efsa foodex2)', '14810 - quinces and similar- (efsa foodex2)', '14820 - quinces (efsa foodex2)', '14830 - chinese quinces (efsa foodex2)', '14840 - japanese quinces (efsa foodex2)', '14850 - medlars and similar- (efsa foodex2)', '14860 - medlars (efsa foodex2)', '14870 - loquats and similar- (efsa foodex2)', '14880 - loquats (efsa foodex2)', '14890 - other pome fruits (efsa foodex2)', '15270 - berries and small fruits (ef
# Cluster 46: ['Commonwealth of Kentucky', 'District of Columbia', 'State of Delaware', 'State of Maryland', 'State of New Jersey', 'State of Ohio', 'State of West Virginia', 'middle atlantic states']
# Cluster 47: ['aluminum tube', 'aluminum tube, top lined with laminate']
# Cluster 48: ["concentration of 2'-hydroxyformononetin in material entity", 'concentration of Irisolidone in material entity', 'concentration of biochanin A in material entity', 'concentration of calycosin in material entity', 'concentration of methoxyisoflavone in material entity']
# Cluster 49: ['Sillaginidae', 'Sillaginodes punctatus', 'Sillaginopsis domina', 'Sillago', 'Sillago japonica', 'Sillago sihama', 'sillago', 'sillago-whiting family']
# Cluster 50: ['Amhara', 'Baggara', 'Egyptian', 'Gurage', 'Habesha', 'Maghrebi', 'Moor', 'Rashaida', 'Semite Central', 'Semite Northern', 'Semitic Eastern', 'Tigrinya', 'Tigré']
# Cluster 51: ['"fresh frozen" label claim', '"fresh" label claim', '"less" label claim', '"more" label claim', '"naturally/natural" label claim', 'American Viticultural Area', "Appellation d'origine contrôlée", 'Denominación de Origen Calificada', 'Denominación de Origen Protegida', 'Denominazione di origine controllata', 'Duration', 'Indicación geográfica protegida', 'Protected Designation of Origin', 'Protected Geographical Indication', 'Protected Geographical Status', 'Quality Wines Produced in Specified Regions', 'Spanish wine production framework', 'Table Wine (deprecated EU standard)', 'Traditional Speciality Guaranteed', 'Vino de Pago', 'Vintners Quality Alliance', 'antibiotic-free food product claim', 'apparent nutrient retention factor', 'artificial ingredient-related claim', 'authentic ethnic food claim', 'caffeine free claim', 'calcium added claim', 'calcium and osteoporosis related claim', 'chloride added claim', 'cholesterol special claim', 'chromium added claim', 'color-related claim', 'contains {name of the nutrient or other substance} nutrition claim', 'copper added claim', 'diabetic or suitable for diabetics claim', 'dietary claim', 'egg free claim', 'energy free food claim', 'energy special claim', 'enriched food claim', 'ethnic food claim', 'fiber special claim', 'flavor- or taste-related claim', 'food allergen labelling', 'food allergen labelling about carrot and products thereof', 'food allergen labelling about celery and products thereof', 'food allergen labelling about cereals containing gluten and products thereof', 'food allergen labelling about cocoa and products thereof', 'food allergen labelling about corn and products thereof', 'food allergen labelling about crustaceans and products thereof', 'food allergen labelling about fish and products thereof', 'food allergen labelling about lupine and products thereof', 'food allergen labelling about milk and products thereof, including lactose', 'food allergen labelling about molluscs and products thereof', 'food allergen labelling about peanuts and products thereof', 'food allergen labelling about pod fruits and products thereof', 'food allergen labelling about sesame seeds and products thereof', 'food datum', 'food freeze-by date', 'food packaging date', 'food preservation applied', 'food preservation planned', 'food product appellation framework', 'food production date', 'food quality date', 'fortified food claim', 'general label claim', 'grass-fed food product claim', 'halal claim', 'health-related claim', 'high energy food claim', 'high protein food', 'increased {name of nutrient} nutrition claim', 'iodized claim', 'iron added claim', 'kosher claim', 'kosher for passover claim', 'label claim', 'label claim in food name', 'label claim separate from food name', 'low energy food claim', 'low sodium claim', 'magnesium added claim', 'manganese added claim', 'mineral added claim', 'modified ethnic food claim', 'molybdenum added claim', 'natural source of vitamins and or minerals claim', 'naturally caffeine free claim', 'no artificial additives claim', 'no artificial colors claim', 'no artificial flavors claim', 'no artificial ingredients claim', 'no artificial preservatives claim', 'no artificial sweeteners claim', 'no beef added claim', 'no color added claim', 'no flavor added claim', 'no food preservation planned', 'no msg added claim', 'no nitrite/nitrate added claim', 'no or reduced energy claim', 'no preservatives claim', 'no starch added claim', 'no sugars added claim', 'no sulfite added claim', 'no tropical oils added claim', 'no vitamin or mineral added claim', 'noncarbonated claim', 'nutrition-related claim', 'omega-3 fatty acids claim', 'organic food claim', 'other ingredient- or constituent-related claim', 'other special claim', 'pasture-raised food product claim', 'phosphorus added claim', 'phytosterol claim', 'potassium added claim', 'preservative-related claim', 'probiotic claim', 'processing-related claim', 'protein special claim', 'recipe ingr ...
# Cluster 52: ['10005900 - apples (gs1 gpc)', '10005901 - japanese medlars (gs1 gpc)', '10006173 - quinces (gs1 gpc)', '10006414 - medlar (gs1 gpc)', '10006415 - ya pear (shandong) (gs1 gpc)', '50250800 - pome fruits (gs1 gpc)']
# Cluster 53: ['00020 - cereals and cereal primary derivatives (efsa foodex2)', '00960 - groats (efsa foodex2)', '00970 - barley groats (efsa foodex2)', '00980 - buckwheat groats (efsa foodex2)', '00990 - millet groats (efsa foodex2)', '01010 - rye groats (efsa foodex2)', '01020 - wheat groats (efsa foodex2)', '01030 - bulgur (efsa foodex2)', '01040 - semolina (efsa foodex2)', '01050 - maize semolina (efsa foodex2)', '01060 - wheat semolina (efsa foodex2)', '01070 - rice semolina (efsa foodex2)', '01080 - cereal bran (efsa foodex2)', '01090 - oat bran (efsa foodex2)', '01100 - rye bran (efsa foodex2)', '01110 - wheat bran (efsa foodex2)', '01130 - cereal germ (efsa foodex2)', '01140 - maize germ (efsa foodex2)']
# ...
# Cluster 901: ['extra firm tofu', 'extra firm tofu (sauteed)']
# Cluster 902: ['Kajikia', 'Kajikia albida', 'Kajikia audax']
# Cluster 903: ['fruit, peel removed', 'fruit, peel removed, core, pit or seed present']
# Cluster 904: ['salsify root', 'salsify root (raw)']
# Cluster 905: ['Polyodontinae', 'Psephurus gladius']
# Cluster 906: ['food packing medium compromised', 'food packing medium drained', 'food packing medium integrity']
# Cluster 907: ['kidney bean plant', 'red kidney bean plant']
# Cluster 908: ['cloud ear mushroom', 'cloud ear mushroom (dried)']
# Cluster 909: ['apple based alcoholic beverage', 'apple brandy', 'hard cider (artificially carbonated)', 'hard cider (sugar added)']
# Cluster 910: ['Berberis', 'Berberis vulgaris']
# Cluster 911: ['alcohol-free beer', 'barley alcoholic beverage analog', 'beer (dealcoholized)', 'malt beverage (nonalcoholic)']
# Cluster 912: ['cheddar cheese (filled)', 'cheddar cheese (filled, containing margarine)', 'cheese (natural with margarine)', 'cheese and parsley spread', 'cow milk cheese analog', 'dairy spread (low calorie)', 'filled cheese', 'imitation semisoft part skim cheese', 'swiss cheese (filled, containing butter)']
# Cluster 913: ['female pseudohermaphrodite', 'male pseudohermaphrodite', 'pseudohermaphrodite']
# Cluster 914: ['alfalfa plant', 'bastard medic plant']
# Cluster 915: ['cholesterol', 'cholesterol special claim', 'low in cholesterol claim', 'no or reduced cholesterol claim']
# Cluster 916: ['beverage analog', 'imitation lemonade drink', 'imitation nonalcoholic beverage']
# Cluster 917: ['smooth moon turban', 'top shell']
# Cluster 918: ['17170 - prickly pears and similar- (efsa foodex2)', '17180 - prickly pears (efsa foodex2)', '17210 - saguaro fruits (efsa foodex2)']
# Cluster 919: ['piece(s) of gazelle organ', 'piece(s) of gazelle organ (raw)']
# Cluster 920: ['food aeration by creaming', 'food aeration process']
# Cluster 921: ['Krameria', 'Krameriaceae', 'Zygophyllales']
# Cluster 922: ['bakery product (fine)', 'bakery product, fine, energy reduced', 'bakery product, fine, flat', 'bakery product, fine, for special nutritional uses']
# Cluster 923: ['spinose chiton', 'spiny chiton']
# Cluster 924: ['32680 - bottled water (efsa foodex2)', '32750 - flavoured bottled water (efsa foodex2)', '32760 - fortified bottled water (efsa foodex2)']
# Cluster 925: ['30560 - hard candies (efsa foodex2)', '30570 - dragée, sugar coated (efsa foodex2)']
# Cluster 926: ['Malacanthidae', 'Malacanthus plumieri']
# Cluster 927: ['Duration', 'Temporal Duration']
# Cluster 928: ['Squilla mantis', 'Squillidae']
# Cluster 929: ['new zealand spider crab', 'spider crab family']
# Cluster 930: ['Carnosol', 'Ineketone', 'crocetin', 'diterpenoid', 'steviol glycoside', 'stevioside']
# Cluster 931: ['09410 - fermented vegetables (efsa foodex2)', '09420 - sauerkraut (efsa foodex2)']
# Cluster 932: ['dressing, mayonnaise (eurofir)', 'flavouring or essence (eurofir)', 'herb or spice (eurofir)', 'spice, condiment or other ingredient (eurofir)']
# Cluster 933: ['13750 - caraway fruit and similar- (efsa foodex2)', '13760 - caraway fruit (efsa foodex2)', '13770 - ajowan fruit (efsa foodex2)']
# Cluster 934: ['Aphareus', 'Aphareus furca', 'Aphareus rutilans']
# Cluster 935: ['Prochilodus', 'Prochilodus reticulatus']
# Cluster 936: ['Grewia', 'Grewioideae']
# Cluster 937: ['12870 - saffron and similar- (efsa foodex2)', '12880 - saffron (efsa foodex2)']
# Cluster 938: ['cheese blended pasteurized', 'pasteurized blended cheese food product', 'pasteurized blended cheese with fruits vegetables or meats']
# Cluster 939: ['Phasianinae', 'Phasianus']
# Cluster 940: ['Anadara', 'Anadara baughmani']
# Cluster 941: ['dark magenta', 'desaturated magenta', 'light magenta', 'magenta']
# Cluster 942: ['apple cider (alcoholic)', 'cider (aromatized)', 'cidre bouche']
# Cluster 943: ['10006361 - ferns (cinnamon) (gs1 gpc)', '10006824 - fiddlehead ferns (gs1 gpc)', '50262400 - ferns (gs1 gpc)']
# Cluster 944: ['cassytha plant', 'coarse dodderlaurel plant']
# Cluster 945: ['Canthidermis', 'Canthidermis maculata']
# Cluster 946: ['dessert (jelly-like)', 'mizu yōkan', 'yokan']
# Cluster 947: ['effervescent tablet', 'non-chewable tablet']
# Cluster 948: ['Majoidea', 'Oregoniidae']
# Cluster 949: ['kim chee', 'kim chee (refrigerated)']
# Cluster 950: ['almond bark (artificially sweetened)', 'almond candy food product', 'jordan almond', 'marzipan', 'marzipan candy']
# Cluster 951: ['shrimp cocktail', 'shrimp cocktail (curried, canned)']
# Cluster 952: ['0800000 - spices (ec)', '0810000 - spices, seeds (ec)', '0820000 - spices, fruits and berries (ec)', '0850000 - spices, buds (ec)', '0860000 - spices, flower stigma (ec)', '0870000 - spices, aril (ec)']
# Cluster 953: ['reduced salt claim', 'reduced salt or sodium claim']
# Cluster 954: ['arrowroot flour', 'arrowroot flour food product']
# Cluster 955: ['50330000 - nuts/seeds - unprepared/unprocessed (perishable) (gs1 gpc)', '50330100 - nuts/seeds - unprepared/unprocessed (perishable) (gs1 gpc)']
# Cluster 956: ['cusk (raw)', 'cusk fillet (frozen)', 'cusk food product', 'moonfish (raw)']
# Cluster 957: ['lumpfish (raw)', 'lumpfish food product', 'lumpfish roe (chilled)', 'lumpfish roe semi-preserved']
# Cluster 958: ['caprine cheese food product', 'goat milk cheese', 'goat milk cheese (marinated in olive oil)', 'goat milk cheese (unpasteurized)', 'goat milk cheese food product']
# Cluster 959: ['Chitala', 'Chitala chitala', 'Chitala lopis']
# Cluster 960: ['01880 - dried stuffed pasta (efsa foodex2)', '01890 - dried stuffed egg pasta (efsa foodex2)']
# Cluster 961: ['atlantic croaker (raw)', 'croaker (raw)']
# Cluster 962: ['05780 - onions and similar- (efsa foodex2)', '05790 - onions (efsa foodex2)', '05800 - onion bulbs for fresh consumption (efsa foodex2)', '05820 - rakkyo (efsa foodex2)', '05830 - silverskin onions (efsa foodex2)']
# Cluster 963: ['4-8 cell stage embryo', '8-cell stage embryo']
# Cluster 964: ['05840 - shallots and similar- (efsa foodex2)', '05850 - shallots (efsa foodex2)', '05870 - persian shallots (efsa foodex2)']
# Cluster 965: ['10000207 - fruit/nuts/seeds mixes - prepared/processed (shelf stable) (gs1 gpc)', '10000604 - fruit/nuts/seeds combination variety packs (gs1 gpc)', '50101900 - fruit/nuts/seeds combination (gs1 gpc)']
# Cluster 966: ['13-cis-retinal', 'retinal']
# Cluster 967: ['Rhinoceros', 'Rhinocerotidae']
# Cluster 968: ['fish cake', 'fish cake (raw)', 'fish cake (raw, breaded)']
# Cluster 969: ['aluminium can, drum or barrel, plastic coated', 'aluminum can, drum or barrel']
# Cluster 970: ['high density polyethylene container', 'polyethylene container']
# Cluster 971: ['Zosterisessor', 'Zosterisessor ophiocephalus', 'zosterisessor']
# Cluster 972: ['cow whole milk 3.5% fat', 'cow whole milk 3.5% fat (vitamin D fortified)']
# Cluster 973: ['Gruiformes', 'Grus americana']
# Cluster 974: ['malnutrition supplement food product', 'moderate malnutrition supplement food product']
# Cluster 975: ['Pseudorhombus', 'Pseudorhombus arsius', 'Pseudorhombus jenynsii', 'Pseudorhombus pentophthalmus']
# Cluster 976: ['imide', 'mixed diacylamine']
# Cluster 977: ['32720 - bottled drinking water (efsa foodex2)', '32740 - carbonated bottled drinking water (efsa foodex2)']
# Cluster 978: ['20280 - goose liver (efsa foodex2)', '20290 - foie gras (efsa foodex2)']
# Cluster 979: ['cow milk (sterilized)', 'cow milk (sterilized, yogurt-flavored)']
# Cluster 980: ['Chloroscombrus', 'Chloroscombrus chrysurus', 'Chloroscombrus orqueta']
# Cluster 981: ['Pollicipes', 'Pollicipes pollicipes', 'Pollicipes polymerus']
# Cluster 982: ['hass avocado', 'hass avocado (raw)']
# Cluster 983: ['spirochaetae', 'spirochaetes']
# Cluster 984: ['pineapple and grapefruit juice drink (canned, diluted)', 'pineapple and grapefruit juice drink (diluted)']
# Cluster 985: ['lotic water body', 'watercourse']
# Cluster 986: ['14080 - processed legumes, nuts, oilseeds and spices (efsa foodex2)', '14160 - canned or jarred legumes (efsa foodex2)', '14180 - canned or jarred peas (efsa foodex2)', '14200 - canned or jarred chickpea (efsa foodex2)']
# Cluster 987: ['Fasciolariidae', 'Triplofusus giganteus']
# Cluster 988: ['meat product (canned)', 'meat product (minced or diced, canned)']
# Cluster 989: ['Saurida', 'Saurida filamentosa']
# Cluster 990: ['Taraxacum', 'Taraxacum officinale']
# Cluster 991: ['27130 - probiotic milk-like drinks (efsa foodex2)', '27140 - acidophilus milk (efsa foodex2)']
# Cluster 992: ['globulin type', 'glutenin', 'prolamin']
# Cluster 993: ['chicken roast (boneless)', 'chicken roast (boneless, seasoned, fresh frozen)']
# Cluster 994: ['biaxial oriented polypropylene container', 'polyolefin container', 'polypropylene container']
# Cluster 995: ['22070 - canned-tinned meat (efsa foodex2)', '22100 - tinned bulk sausages (efsa foodex2)']
# Cluster 996: ['whole grain bread', 'whole oat bread']
# Cluster 997: ['Bathycongrus', 'Bathycongrus aequoreus']
# Cluster 998: ['29650 - egg mixed whole (efsa foodex2)', '29660 - hen egg mixed whole (efsa foodex2)']
# Cluster 999: ['yellow variety sweet potato (raw)', 'yellow variety sweet potato (raw, skin on)']
# Cluster 1000: ['potato (pre-fried, deep-frozen)', 'potato (pre-fried, frozen)', 'potato (precooked)']
# Cluster 1001: ['37930 - food for weight reduction (efsa foodex2)', '37940 - total daily diet replacement for weight reduction (efsa foodex2)']
# Cluster 1002: ['01530 - wheat crisp bread (efsa foodex2)', '01550 - crisp bread, wheat, refined flour (efsa foodex2)']
# Cluster 1003: ['landform', 'slope', 'solid astronomical body part', 'watershed']
# Cluster 1004: ['10000601 - cereal/grain/pulse products variety packs (gs1 gpc)', '50221300 - cereal/grain/pulse products variety packs (gs1 gpc)']
# Cluster 1005: ['concentration of 3,5,7-trihydroxy-2-[3-(4-hydroxy-3-methoxyphenyl)-2-(hydroxymethyl)-2,3-dihydro-1,4-benzodioxin-6-yl]-3,4-dihydro-2H-1-benzopyran-4-one in material entity', 'concentration of lignan in material entity']
# Cluster 1006: ['Apodidae', 'Apodinae', 'Collocalia']
# Cluster 1007: ['gum stabilizer', 'microbial gum', 'plant exudate gum']
# Cluster 1008: ['mannan', 'mannan derived from hemicellulose']
# Cluster 1009: ['Vitis rotundifolia', 'Vitis rotundifolia var. munsoniana']
# Cluster 1010: ['soup (us cfr)', 'soup, thick (us cfr)', 'soup, thin (us cfr)']
# Cluster 1011: ['glass container, aluminum lid', 'glass container, aluminum lid, plastic lining']
# Cluster 1012: ['dairy product based dressing', 'milk product based dressing']
# Cluster 1013: ['food quality claim', 'other special claim']
# Cluster 1014: ['Aulopidae', 'Aulopoidei']
# Cluster 1015: ['Cephalophinae', 'Cephalophus']
# Cluster 1016: ['moringa pod', 'moringa pod (raw)']
# Cluster 1017: ['artichoke heart', 'artichoke heart in lemon water (canned)']
# Cluster 1018: ['grape (raw)', 'muscadine grape (raw)']
# Cluster 1019: ['24070 - herring, atlantic (efsa foodex2)', '24080 - herring, baltic (efsa foodex2)']
# Cluster 1020: ['icelandic lichen (food product)', 'lichen', 'lichen (food product)']
# Cluster 1021: ['allspice', 'allspice (ground)']
# Cluster 1022: ['Sauria', 'Squamata']
# Cluster 1023: ['compressed yeast (fresh, refrigerated)', 'compressed yeast food product']
# Cluster 1024: ['Tremella', 'Tremella fuciformis', 'Tremella mesenterica']
# Cluster 1025: ['paperboard container, untreated', 'recycled paperboard container']
# Cluster 1026: ['detarium plant', 'sweet dattock plant', 'tallow tree (detarium) plant']
# Cluster 1027: ['11630 - pistachios and similar- (efsa foodex2)', '11640 - pistachios (efsa foodex2)']
# Cluster 1028: ['concentration of rhamnose derived from rhamnogalacturonan derived from pectin in material entity', 'concentration of rhamnose in material entity']
# Cluster 1029: ['brazilnut (shell off)', 'brazilnut (shell off, dried)']
# Cluster 1030: ['devils tongue plant', 'konjac plant']
# Cluster 1031: ['Aulopiformes', 'Chlorophthalmus albatrossis', 'Eurypterygia']
# Cluster 1032: ["O's cereal", 'breakfast cereal (extruded)']
# Cluster 1033: ['pretzel', 'pretzel (salt-free)']
# Cluster 1034: ['05990 - slicing bean (young pods) (efsa foodex2)', '06010 - runner beans (with pods) (efsa foodex2)']
# Cluster 1035: ['nut or seed product (eurofir)', 'nut, seed or kernel (eurofir)']
# Cluster 1036: ['Plagioscion', 'Plagioscion squamosissimus']
# Cluster 1037: ['egg roll', 'shrimp egg roll']
# Cluster 1038: ['Ompok pabda', 'Siluridae']
# Cluster 1039: ['Acheta domesticus', 'Gryllinae']
# Cluster 1040: ['D-apiose', 'D-apiose derived from rhamnogalacturonan derived from pectin']
# Cluster 1041: ['45020 - special fatty acids (efsa foodex2)', '45030 - omega-3 fatty acids (efsa foodex2)']
# Cluster 1042: ['tomato paste', 'tomato paste (powdered, dehydrated, canned)']
# Cluster 1043: ['19350 - horse fresh meat (efsa foodex2)', '19360 - horse, minced meat (efsa foodex2)']
# Cluster 1044: ['white potato', 'white potato (raw)']
# Cluster 1045: ['Pittosporaceae', 'Pittosporum']
# Cluster 1046: ['wrinkled pea', 'wrinkled pea (raw)']
# Cluster 1047: ['sugar kelp (dried)', 'sugar kelp food product']
# Cluster 1048: ['quail carcass (raw, skinless)', 'quail processed carcass (raw)']
# Cluster 1049: ['Branta', 'Branta canadensis']
# Cluster 1050: ['giant keyhole limpet', 'keyhole limpet', 'limpet']
# Cluster 1051: ['delicata squash', 'delicata squash (raw)']
# Cluster 1052: ['sair date', 'sair date (raw)']
# Cluster 1053: ['Variola', 'Variola albimarginata', 'Variola louti']
# Cluster 1054: ['buffalo roast (boneless)', 'buffalo roast (boneless, raw)']
# Cluster 1055: ['amide', 'secondary amide']
# Cluster 1056: ['13790 - cardamom fruit and similar- (efsa foodex2)', '13800 - cardamom fruit (efsa foodex2)', '13810 - marjoram fruit (efsa foodex2)', '13820 - star anise fruit (efsa foodex2)']
# Cluster 1057: ['nut or nut product (us cfr)', 'nut or seed product (us cfr)', 'seed or seed product (us cfr)']
# Cluster 1058: ['17220 - star apples and similar- (efsa foodex2)', '17230 - star apples (efsa foodex2)']
# Cluster 1059: ['25080 - king crabs, squat-lobsters (efsa foodex2)', '25090 - squat lobsters (efsa foodex2)']
# Cluster 1060: ['Haliporoides', 'Haliporoides triarthrus']
# Cluster 1061: ['02770 - croissant (efsa foodex2)', '02780 - croissant, filled with chocolate (efsa foodex2)', '02800 - croissant, filled with jam (efsa foodex2)']
# Cluster 1062: ['food (semisolid)', 'semisolid with smooth consistency']
# Cluster 1063: ['Monopterus albus', 'Synbranchidae', 'fish, synbranchiform']
# Cluster 1064: ['41450 - salad dressing (efsa foodex2)', '41460 - salad dressing, low fat (efsa foodex2)']
# Cluster 1065: ['UO_0000033', 'day based unit']
# Cluster 1066: ['cheese hardness class (codex)', 'hard cheese (codex)', 'semihard cheese (codex)']
# Cluster 1067: ['Felis catus', 'kitten']
# Cluster 1068: ['Bonasa umbellus', 'Tetraoninae']
# Cluster 1069: ['river', 'stream']
# Cluster 1070: ['acetophenone', 'methyl ketone']
# Cluster 1071: ['40360 - potato crisps or sticks (efsa foodex2)', '40370 - potato crisps from potato slices (efsa foodex2)']
# Cluster 1072: ['lamb sirloin chop (boneless)', 'lamb sirloin chop (boneless, raw)']
# Cluster 1073: ['Characoidei', 'Megaleporinus obtusidens']
# Cluster 1074: ['leavening agent addition process', 'yeast addition process']
# Cluster 1075: ['Cactineae', 'Montiaceae']
# Cluster 1076: ['botanical supplement with mineral(s)', 'botanical supplement with vitamin/mineral']
# Cluster 1077: ['32640 - tap water (efsa foodex2)', '32650 - ice from tap water (efsa foodex2)']
# Cluster 1078: ['coleorhiza emergence stage', 'root development stage']
# Cluster 1079: ['10000607 - milk/butter/cream/yogurts/cheese/eggs/substitutes variety packs (gs1 gpc)', '50132200 - milk/butter/cream/yoghurts/cheese/eggs/substitutes variety packs (gs1 gpc)']
# Cluster 1080: ['digestible food material', 'palatable food']
# Cluster 1081: ['14050 - peppers, dried (efsa foodex2)', '14060 - paprika powder (efsa foodex2)']
# Cluster 1082: ['yuzu', 'yuzu (raw)']
# Cluster 1083: ['alive', 'viability']
# Cluster 1084: ['25930 - other amphibians and reptiles (efsa foodex2)', '25940 - lizards (efsa foodex2)']
# Cluster 1085: ['macaroni (enriched with fortified protein)', 'macaroni (enriched)']
# Cluster 1086: ['giant freshwater prawn (raw)', 'prawn (raw)']
