# %%
import json
def load_json(data_path):
    with open(data_path, "r") as file_1:
        data = json.load(file_1)
    return data

# %%
test_data = []
with open("C10-Blind-Types.txt", "r", encoding="utf-8") as file:
    content = file.readlines()
    for con in content:
        test_data.append(con.strip('\n'))

print(test_data)
# Out:
# ['semi colon', 'part of speech', 'intransitive interrogative frame', 'ditransitive frame_ to', 'question mark', 'adjective scale frame', 'negative particle', 'nominal complement frame', 'interrogative frame', 'subjectless frame', 'complement', 'diminutive noun', 'noun phrase', 'adjective phrase', 'prepositional adverb', 'definite article', 'weak personal pronoun', 'possessive infinitive clause', 'indefinite pronoun', 'participle adjective', 'gerund clause', 'reflexive transitive pp frame', 'intransitive pp declarative frame', 'adverbial pronoun', 'particle', 'arbitrary control', 'AbbreviatedForm', 'demonstrative determiner', 'conjunction', 'determiner', 'coordinating conjunction', 'coordination particle', 'present participle adjective', 'preposition frame', 'noun predicate frame', 'ditransitive frame', 'light verb', 'DativePostPositiveArg', 'interrogative pronoun', 'conditional particle', 'Affix', 'existential pronoun', 'SyntacticFrame', 'LexicalEntry', 'generic numeral', 'numeral fraction', 'relation noun', 'suspension points', 'Word', 'intransitive nominal complement frame', 'subject', 'intransitive infinitive rs frame', 'infinitive frame', 'interrogative multiplicative numeral', 'morphological stem', 'adjective-na', 'possessive adjective', 'zero morph', 'colon', 'preposition', 'impersonal pronoun', 'article', 'affirmative particle', 'transitive declarative frame', 'relative particle', 'fused pronoun auxiliary', 'future particle', 'object control', 'indefinite cardinal numeral', 'possessive determiner', 'reflexive determiner', 'transitive pp frame', 'interjection', 'prepositional object', 'exclamative point', 'object complement', 'possessive pronoun', 'indefinite multiplicative numeral', 'pp frame', 'common noun', 'intransitive interrogative infinitive frame', 'copulative arg', 'post positive arg', 'adjective dative post positive frame', 'prepositional adjunct', 'point', 'intransitive declarative frame', 'dative transitive frame', 'interrogative particle', 'indirect object', 'relative determiner', 'adverbial complement', 'adjective impersonal frame', 'prepositional frame', 'reflexive possessive pronoun', 'copulative subject', 'gerund sc frame', 'verb frame', 'letter', 'subordinating conjunction', 'predicative adverb', 'transitive frame', 'clausal arg', 'intransitive frame', 'adpositional object', 'intransitive pp frame', 'bullet', 'qualifier adjective', 'partitive article', 'declarative clause', 'genitive ditransitive frame', 'past participle adjective', 'genitive transitive frame', 'reflexive personal pronoun', 'interrogative clause', 'numeral', 'morphological root', 'intransitive adjectival complement frame', 'interrogative infinitive clause', 'reciprocal frame', 'impersonal transitive frame', 'reflexive transitive frame', 'proper noun', 'reflexive reciprocal frame', 'suffix', 'reflexive frame', 'sentential frame', 'MultiWordExpression', 'adjunct', 'adverbial complement frame', 'subject control', 'collective pronoun', 'reflexive dative transitive frame', 'adjective superlative frame', 'sentential clause', 'subjectless intransitive pp frame', 'noun', 'comparative particle', 'control', 'plain verb', 'exclamative determiner', 'raising subject', 'adposition', 'unclassified particle', 'subjectless intransitive frame', 'transitive adjectival complement frame', 'comparative adjunct', 'impersonal frame', 'transitive infinitive oc frame', 'prepositional phrase frame', 'close parenthesis', 'auxiliary', 'RaisableArgument', 'interrogative cardinal numeral', 'postposition', 'subjectless transitive frame', 'transitive infinitive ac frame', 'ditransitive double accusative frame', 'indefinite ordinal numeral', 'preposition phrase', 'attributive arg', 'infinitive clause', 'intransitive sentential frame', 'adjective comparative frame', 'intransitive infinitive ac frame', 'reflexive ditransitive frame', 'transitive interrogative infinitive frame', 'interrogative determiner', 'noun frame', 'symbol', 'adjective pp frame', 'indefinite determine ...

# %%
len(test_data)
# Out:
# 266

# %%
from google import genai
model = "gemini-2.5-pro"
client= genai.Client(api_key="")

# %%
prompt_domain_extraction = f"""You are an expert AI assistant specializing in knowledge representation, ontology, and domain analysis. Your task is to analyze a given list of terms to identify the specific knowledge domain they belong to.

**Instructions:**

1.  **Analyze Input:** You will be given a single list of terms. Carefully examine these terms to find the common theme or scientific field that connects them. Consider what subject matter these terms represent (e.g., biology, geography, technology, food production).
2.  **Generate Domain Name:** Based on your analysis, create a concise and descriptive name for the domain. For example, "Food Science and Production" or "Earth and Environmental Science."
3.  **Generate Domain Description:** Write a 4-5 line description of this domain. This description should explain:
    *   The general area of study or industry it covers.
    *   The types of concepts the terms represent within this domain.
    *   How concepts within this domain are typically related (e.g., one can be a part of another, one can be transformed into another, or one can be an ingredient of another).
    *   The overall purpose of structuring knowledge in this domain (e.g., for scientific analysis, traceability, data interoperability).
4.  **Format the Output:** Return a Python dictionary containing two keys: `domain_name` and `domain_description`.

**Task:**
Analyze the following list of terms and generate a domain name and description.

-   **List of Terms:** {test_data}

Return the result as a Python dictionary."""

# %%
generation_config = {"response_mime_type": "application/json"}

response = client.models.generate_content(
        contents= prompt_domain_extraction,
        config=generation_config,
        model=model
    )
domain= json.loads(response.text)

# %%
domain
# Out:
# {'domain_name': 'Linguistics and Computational Grammar',
#  'domain_description': "This domain encompasses the formal description of language structure, central to linguistics and computational grammar. The terms represent a detailed hierarchy of linguistic units, from morphological components like affixes and roots to lexical items like words and syntactic structures such as phrases, clauses, and complex grammatical patterns known as 'syntactic frames.' Relationships are primarily compositional and functional, where smaller units build larger ones and elements take on specific roles (e.g., subject, object) within a sentence. The purpose of this structured knowledge is to enable the computational analysis, parsing, and understanding of human language, forming the foundation for Natural Language Processing (NLP)."}

# %%
prompt_cluster = f"""You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning. You will be provided with a domain name and a description to set the context for your task.

Your primary task is to group a list of terms into clusters by identifying their **parent-child relationships**. In this context, a **parent-child relationship** is a fundamental connection where one term is a direct 'parent' (a broader category) or a 'child' (a more specific instance or part) of another. This includes:
*   **'is-a' relationships (Type/Subtype):** Where the child term is a specific type of the parent term (e.g., 'River' is-a 'Body of Water').
*   **'part-of' relationships (Whole/Part):** Where the child term is a component or part of the parent term (e.g., 'Sea' is-part-of 'Ocean').

You will cluster terms that are linked directly or indirectly by these fundamental parent-child connections.

**Context (Provided as Input):**
-   **Domain Name:** {domain['domain_name']}
-   **Domain Description:** {domain['domain_description']}

**Instructions:**

1.  **Build the Graph:**
    *   Treat each term from the input list as a point (node) in a graph.
    *   Using your knowledge of the **identified domain** (contextualized by the provided name and description), check every pair of terms to see if a **parent-child relationship** ('is-a' or 'part-of') exists between them.
    *   If such a relationship exists, create a two-way (undirected) link between the parent and child terms for clustering purposes.
2.  **Form Clusters:**
    *   Group terms into clusters where terms are connected either directly or indirectly through the identified **parent-child** links.
    *   Terms with no identifiable parent-child connections to other terms in the list will form their own single-term clusters.
    *   Ensure every term from the input list appears in the output.
3.  **Handle Special Cases:**
    *   If the terms list is empty, return an empty list of clusters: [].
4.  **Format the Output:**
    *   Return a Python list of lists, where each inner list contains the terms in a cluster.
    *   Do not include the relationships in the output, only the grouped terms.
    *   Sort the clusters alphabetically by the first term in each cluster.
    *   Within each cluster, sort the terms alphabetically.

**Task:**
Group the following terms into clusters by identifying all direct and indirect **parent-child ('is-a' and 'part-of') relationships** between them, guided by the provided domain context.

-   **List of Terms:** {test_data}

Return the result as a Python list of lists, where each inner list represents a cluster of terms."""

# %%
generation_config = {"response_mime_type": "application/json"}

response = client.models.generate_content(
        contents= prompt_cluster,
        config=generation_config,
        model=model
    )
clusters_list= json.loads(response.text)

# %%
clusters_list
# Out:
# [['AbbreviatedForm',
#   'AccusativePostPositiveArg',
#   'Affix',
#   'affirmative particle',
#   'adjective',
#   'adjective accusative post positive frame',
#   'adjective attributive frame',
#   'adjective comparative frame',
#   'adjective dative post positive frame',
#   'adjective frame',
#   'adjective genitive post positive frame',
#   'adjective impersonal frame',
#   'adjective post positive frame',
#   'adjective pp frame',
#   'adjective predicate frame',
#   'adjective predicative frame',
#   'adjective scale frame',
#   'adjective superlative frame',
#   'adjective phrase',
#   'adjective-i',
#   'adjective-na',
#   'adjectival complement frame',
#   'adjunct',
#   'adposition',
#   'adpositional object',
#   'adverb',
#   'adverbial complement',
#   'adverbial complement frame',
#   'adverbial pronoun',
#   'affixed personal pronoun',
#   'allusive pronoun',
#   'arbitrary control',
#   'article',
#   'attributive arg',
#   'auxiliary',
#   'cardinal numeral',
#   'circumposition',
#   'clausal arg',
#   'collective pronoun',
#   'common noun',
#   'comparative adjunct',
#   'comparative particle',
#   'complement',
#   'compound preposition',
#   'conditional particle',
#   'conditional pronoun',
#   'conjunction',
#   'control',
#   'coordinating conjunction',
#   'coordination particle',
#   'copula',
#   'copulative arg',
#   'copulative subject',
#   'DativePostPositiveArg',
#   'declarative clause',
#   'declarative frame',
#   'deficient verb',
#   'definite article',
#   'demonstrative determiner',
#   'demonstrative pronoun',
#   'determiner',
#   'diminutive noun',
#   'direct object',
#   'distinctive particle',
#   'ditransitive double accusative frame',
#   'ditransitive frame',
#   'ditransitive frame_ for',
#   'ditransitive frame_ to',
#   'emphatic pronoun',
#   'existential pronoun',
#   'exclamative determiner',
#   'exclamative pronoun',
#   'fused preposition',
#   'fused preposition determiner',
#   'fused preposition pronoun',
#   'fused pronoun auxiliary',
#   'future particle',
#   'general adverb',
#   'generalization word',
#   'generic numeral',
#   'genitive ditransitive frame',
#   'genitive object',
#   'genitive transitive frame',
#   'GenitivePostPositiveArg',
#   'gerund ac frame',
#   'gerund clause',
#   'gerund frame',
#   'gerund oc frame',
#   'gerund sc frame',
#   'impersonal frame',
#   'impersonal intransitive frame',
#   'impersonal intransitive pp frame',
#   'impersonal pronoun',
#   'impersonal transitive frame',
#   'indefinite article',
#   'indefinite cardinal numeral',
#   'indefinite determiner',
#   'indefinite multiplicative numeral',
#   'indefinite ordinal numeral',
#   'indefinite pronoun',
#   'indirect object',
#   'infix',
#   'infinitive clause',
#   'infinitive frame',
#   'infinitive particle',
#   'interjection',
#   'interrogative cardinal numeral',
#   'interrogative clause',
#   'interrogative determiner',
#   'interrogative frame',
#   'interrogative infinitive clause',
#   'interrogative infinitive frame',
#   'interrogative multiplicative numeral',
#   'interrogative ordinal numeral',
#   'interrogative particle',
#   'interrogative pronoun',
#   'interrogative relative pronoun',
#   'intransitive adjectival complement frame',
#   'intransitive adverbial complement frame',
#   'intransitive declarative frame',
#   'intransitive frame',
#   'intransitive infinitive ac frame',
#   'intransitive infinitive rs frame',
#   'intransitive infinitive sc frame',
#   'intransitive interrogative frame',
#   'intransitive interrogative infinitive frame',
#   'intransitive nominal complement frame',
#   'intransitive pp declarative frame',
#   'intransitive pp frame',
#   'intransitive sentential frame',
#   'irreflexive personal pronoun',
#   'LexicalEntry',
#   'light verb',
#   'main verb',
#   'modal',
#   'morphological root',
#   'morphological stem',
#   'MultiWordExpression',
#   'multiplicative numeral',
#   'negative particle',
#   'negative pronoun',
#   'noun',
#   'noun frame',
#   'noun pp frame',
#   'noun phrase',
#   'noun predicate frame',
#   'noun possessive frame',
#   'numeral',
#   'numeral fraction',
#   'object',
#   'object complement',
#   'object control',
#   'ordinal adjective',
#   'part of speech',
#   'participle adjective',
#   'particle',
#   'partitive article',
#   'past participle adjective',
#   'personal pronoun',
#   'plain verb',
#   'possessive adjective',
#   'possessive adjunct',
#   'possessive determiner',
#   'possessive infinitive clause',
#   'possessive particle',
#   'possessive pronoun',
#   'possessive relative pronoun',
#   'post positive arg',
#   'postposition',
#   'pp frame',
#   'predicative adjective',
#   'predicative adjunct',
#   'predicative adverb',
#   'predicative nominative',
#   'prefix',
#   'preposition',
#   'preposition frame',
#   'preposition phrase',
#   'preposition phrase frame',
#   'prepositional adjunct',
#   'prepositional adverb',
#   'prepositional gerund clause',
#   'prepositional interrogative clause',
#   'prepositional interrogative frame',
#   'prepositional object',
#   'present participle adjective',
#   'presentative pronoun',
#   'pronominal adverb',
#   'proper noun',
#   'pronoun',
#   'qualifier adjective',
#   'raising subject',
#   'RaisableArgument',
#   'reciprocal frame',
#   'reciprocal pronoun',
#   'reflexive determiner',
#   'reflexive dative transitive frame',
#   'reflexive ditransitive frame',
#   'reflexive frame',
#   'reflexive object',
#   'reflexive personal pronoun',
#   'reflexive possessive pronoun',
#   'reflexive reciprocal frame',
#   'reflexive transitive frame',
#   'reflexive transitive pp frame',
#   'relation noun',
#   'relative determiner',
#   'relative particle',
#   'relative pronoun',
#   'sentential clause',
#   'sentential frame',
#   'simulfix',
#   'strong personal pronoun',
#   'subject',
#   'subject control',
#   'subjectless frame',
#   'subjectless intransitive frame',
#   'subjectless intransitive pp frame',
#   'subjectless transitive frame',
#   'subjectless transitive pp frame',
#   'subjunctive clause',
#   'subordinating conjunction',
#   'suffix',
#   'superlative adjunct',
#   'superlative particle',
#   'SyntacticArgument',
#   'SyntacticFrame',
#   'transfix',
#   'transitive adjectival complement frame',
#   'transitive adverbial complement frame',
#   'transitive declarative frame',
#   'transitive frame',
#   'transitive infinitive ac frame',
#   'transitive infinitive oc frame',
#   'transitive infinitive sc frame',
#   'transitive interrogative frame',
#   'transitive interrogative infinitive frame',
#   'transitive nominal complement frame',
#   'transitive pp frame',
#   'transitive sentential frame',
#   'unclassified particle',
#   'verb',
#   'verb frame',
#   'verb phrase',
#   'weak personal pronoun',
#   'Word',
#   'zero morph'],
#  ['bullet',
#   'close parenthesis',
#   'colon',
#   'comma',
#   'exclamative point',
#   'inverted comma',
#   'letter',
#   'open parenthesis',
#   'point',
#   'punctuation',
#   'question mark',
#   'semi colon',
#   'slash',
#   'suspension points',
#   'symbol'],
#  ['term type']]

# %%
for cluser in clusters_list:
    print(len(cluser))
# Out:
# 247
# 15
# 1

# %%
model= "gemini-2.5-pro"

# %%
from tqdm import tqdm

response_final = []

# Assume 'final_output' is a list of clusters (e.g., [['Ocean', 'Sea', 'Water'], ['Glacier', 'Ice']])
# Assume 'domain' is a dictionary like {'domain_name': '...', 'domain_description': '...'}
# Assume 'client' and 'model' are already initialized

for i, term_cluster in tqdm(enumerate(clusters_list)):
    # This prompt asks the model to discover the relationship itself
    # instead of just checking against a predefined list.
    if len(term_cluster)>1:
        prompt = f"""You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning. Your task will be guided by a specific domain context provided to you.

    **Context (Provided as Input):**
    -   **Domain Name:** {domain['domain_name']}
    -   **Domain Description:** {domain['domain_description']}

    Your task is to take a single cluster of terms and discover all possible **parent-child relationship triples** (head, relation, tail) *between terms within that cluster*. A parent-child relationship can be either:
    *   **'is-a' (Type/Subtype):** Where the child term is a specific type of the parent term.
    *   **'part-of' (Whole/Part):** Where the child term is a component or part of the parent term.

    **Instructions:**

    1.  **Process the Cluster:**
        *   Examine all possible pairs of terms within the given input cluster.
        *   Using your knowledge of the **identified domain**, determine if a direct **parent-child ('is-a' or 'part-of') relationship** exists between them.
        *   If a relationship is found, create a triple `(head, relation, tail)`. The `relation` in the triple should be a string that describes the discovered relationship (e.g., 'is-a', 'part-of').
        *   Only include triples where both the `head` and `tail` are terms from the input cluster.

    2.  **Handle Special Cases:**
        *   If the cluster contains one or zero terms, return an empty list.
        *   If no parent-child relationships can be inferred for any pair in the cluster, return an empty list.

    3.  **Format the Output:**
        *   Return a Python list containing the generated triples, where each triple is a tuple.
        *   Each triple must be in the format `(head, relation, tail)`.
        *   Sort the final list of triples alphabetically by head, then by relation, and then by tail.

    **Task:**
    For the given cluster of terms, and guided by the provided domain context, discover and generate all possible parent-child relationship triples.

    -   **Cluster of Terms:** {term_cluster}

    Return the result as a Python list of triples.
    """
        print(len(prompt), model)
        generation_config = {"response_mime_type": "application/json"}
        
        # This print statement is for debugging the model object if needed
        # print(model) 

        response = client.models.generate_content(
                contents=prompt,
                config=generation_config,
                model=model
            )
            
        response_final.append(response.text)
        
        # Print progress every 10 iterations
        if i % 10 == 0:
            print(f"--- Response for cluster {i} ---")
            print(response.text)

    # After the loop, response_final will contain a list of JSON strings,
    # each string being a list of discovered triples for the corresponding cluster.
# Out:
# 0it [00:00, ?it/s]
# 8736 gemini-2.5-pro
# 1it [02:40, 160.46s/it]
# --- Response for cluster 0 ---
# [
#   [
#     "AbbreviatedForm",
#     "is-a",
#     "Word"
#   ],
#   [
#     "AccusativePostPositiveArg",
#     "is-a",
#     "post positive arg"
#   ],
#   [
#     "AccusativePostPositiveArg",
#     "part-of",
#     "adjective accusative post positive frame"
#   ],
#   [
#     "Affix",
#     "is-a",
#     "zero morph"
#   ],
#   [
#     "Affix",
#     "part-of",
#     "Word"
#   ],
#   [
#     "DativePostPositiveArg",
#     "is-a",
#     "post positive arg"
#   ],
#   [
#     "DativePostPositiveArg",
#     "part-of",
#     "adjective dative post positive frame"
#   ],
#   [
#     "GenitivePostPositiveArg",
#     "is-a",
#     "post positive arg"
#   ],
#   [
#     "GenitivePostPositiveArg",
#     "part-of",
#     "adjective genitive post positive frame"
#   ],
#   [
#     "LexicalEntry",
#     "is-a",
#     "MultiWordExpression"
#   ],
#   [
#     "LexicalEntry",
#     "is-a",
#     "Word"
#   ],
#   [
#     "MultiWordExpression",
#     "is-a",
#     "fused preposition determiner"
#   ],
#   [
#     "MultiWordExpression",
#     "is-a",
#     "fused preposition pronoun"
#   ],
#   [
#     "MultiWordExpression",
#     "is-a",
#     "fused pronoun auxiliary"
#   ],
#   [
#     "RaisableArgument",
#     "is-a",
#     "raising subject"
#   ],
#   [
#     "SyntacticArgument",
#     "is-a",
#     "RaisableArgument"
#   ],
#   [
#     "SyntacticArgument",
#     "is-a",
#     "adjunct"
#   ],
#   [
#     "SyntacticArgument",
#     "is-a",
#     "clausal arg"
#   ],
#   [
#     "SyntacticArgument",
#     "is-a",
#     "complement"
#   ],
#   [
#     "SyntacticArgument",
#     "is-a",
#     "copulative arg"
#   ],
#   [
#     "SyntacticArgument",
#     "is-a",
#     "object"
#   ],
#   [
#     "SyntacticArgument",
#     "is-a",
#     "post positive arg"
#   ],
#   [
#     "SyntacticArgument",
#     "is-a",
#     "subject"
#   ],
#   [
#     "SyntacticFrame",
#     "is-a",
#     "adjective frame"
#   ],
#   [
#     "SyntacticFrame",
#     "is-a",
#     "adverbial complement frame"
#   ],
#   [
#     "SyntacticFrame",
#     "is-a",
#     "noun frame"
#   ],
#   [
#     "SyntacticFrame",
#     "is-a",
#     "pp frame"
#   ],
#   [
#     "SyntacticFrame",
#     "is-a",
#     "preposition frame"
#   ],
#   [
#     "SyntacticFrame",
#     "is-a",
#     "preposition phrase frame"
#   ],
#   [
#     "SyntacticFrame",
#     "is-a",
#     "verb frame"
#   ],
#   [
#     "Word",
#     "is-a",
#     "AbbreviatedForm"
#   ],
#   [
#     "Word",
#     "is-a",
#     "adjective"
#   ],
#   [
#     "Word",
#     "is-a",
#     "adposition"
#   ],
#   [
#     "Word",
#     "is-a",
#     "adverb"
#   ],
#   [
#     "Word",
#     "is-a",
#     "conjunction"
#   ],
#   [
#     "Word",
#     "is-a",
#     "determiner"
#   ],
#   [
#     "Word",
#     "is-a",
#     "interjection"
#   ],
#   [
#     "Word",
#     "is-a",
#     "noun"
#   ],
#   [
#     "Word",
#     "is-a",
#     "particle"
#   ],
#   [
#     "Word",
#     "is-a",
#     "pronoun"
#   ],
#   [
#     "Word",
#     "is-a",
#     "verb"
#   ],
#   [
#     "Word",
#     "part-of",
#     "adjective phrase"
#   ],
#   [
#     "Word",
#     "part-of",
#     "noun phrase"
#   ],
#   [
#     "Word",
#     "part-of",
#     "preposition phrase"
#   ],
#   [
#     "Word",
#     "part-of",
#     "verb phrase"
#   ],
#   [
#     "adjective",
#     "is-a",
#     "adjective-i"
#   ],
#   [
#     "adjective",
#     "is-a",
#     "adjective-na"
#   ],
#   [
#     "adjective",
#     "is-a",
#     "ordinal adjective"
#   ],
#   [
#     "adjective",
#     "is-a",
#     "participle adjective"
#   ],
#   [
#     "adjective",
#     "is-a",
#     "possessive adjective"
#   ],
#   [
#     "adjective",
#     "is-a",
#     "predicative adjective"
#   ],
#   [
#     "adjective",
#     "is-a",
#     "qualifier adjective"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective attributive frame"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective comparative frame"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective impersonal frame"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective post positive frame"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective pp frame"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective predicate frame"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective predicative frame"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective scale frame"
#   ],
#   [
#     "adjective frame",
#     "is-a",
#     "adjective superlative frame"
#   ],
#   [
#     "adjective post positive frame",
#     "is-a",
#     "adjective accusative post positive frame"
#   ],
#   [
#     "adjective post positive frame",
#     "is-a",
#     "adjective dative post positive frame"
#   ],
#   [
#     "adjective post positive frame",
#     "is-a",
#     "adjective genitive post positive frame"
#   ],
#   [
#     "adjunct",
#     "is-a",
#     "comparative adjunct"
#   ],
#   [
#     "adjunct",
#     "is-a",
#     "possessive adjunct"
#   ],
#   [
#     "adjunct",
#     "is-a",
#     "predicative adjunct"
#   ],
#   [
#     "adjunct",
#     "is-a",
#     "prepositional adjunct"
#   ],
#   [
#     "adjunct",
#     "is-a",
#     "superlative adjunct"
#   ],
#   [
#     "adposition",
#     "is-a",
#     "circumposition"
#   ],
#   [
#     "adposition",
#     "is-a",
#     "postposition"
#   ],
#   [
#     "adposition",
#     "is-a",
#     "preposition"
#   ],
#   [
#     "adverb",
#     "is-a",
#     "adverbial pronoun"
#   ],
#   [
#     "adverb",
#     "is-a",
#     "general adverb"
#   ],
#   [
#     "adverb",
#     "is-a",
#     "predicative adverb"
#   ],
#   [
#     "adverb",
#     "is-a",
#     "prepositional adverb"
#   ],
#   [
#     "adverb",
#     "is-a",
#     "pronominal adverb"
#   ],
#   [
#     "auxiliary",
#     "is-a",
#     "fused pronoun auxiliary"
#   ],
#   [
#     "auxiliary",
#     "is-a",
#     "modal"
#   ],
#   [
#     "cardinal numeral",
#     "is-a",
#     "indefinite cardinal numeral"
#   ],
#   [
#     "cardinal numeral",
#     "is-a",
#     "interrogative cardinal numeral"
#   ],
#   [
#     "complement",
#     "is-a",
#     "adverbial complement"
#   ],
#   [
#     "complement",
#     "is-a",
#     "object complement"
#   ],
#   [
#     "conjunction",
#     "is-a",
#     "coordinating conjunction"
#   ],
#   [
#     "conjunction",
#     "is-a",
#     "subordinating conjunction"
#   ],
#   [
#     "control",
#     "is-a",
#     "arbitrary control"
#   ],
#   [
#     "control",
#     "is-a",
#     "object control"
#   ],
#   [
#     "control",
#     "is-a",
#     "subject control"
#   ],
#   [
#     "copulative arg",
#     "is-a",
#     "copulative subject"
#   ],
#   [
#     "declarative frame",
#     "is-a",
#     "intransitive declarative frame"
#   ],
#   [
#     "declarative frame",
#     "is-a",
#     "intransitive pp declarative frame"
#   ],
#   [
#     "declarative frame",
#     "is-a",
#     "transitive declarative frame"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "article"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "demonstrative determiner"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "exclamative determiner"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "fused preposition determiner"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "indefinite determiner"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "interrogative determiner"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "possessive determiner"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "reflexive determiner"
#   ],
#   [
#     "determiner",
#     "is-a",
#     "relative determiner"
#   ],
#   [
#     "ditransitive frame",
#     "is-a",
#     "ditransitive double accusative frame"
#   ],
#   [
#     "ditransitive frame",
#     "is-a",
#     "ditransitive frame_ for"
#   ],
#   [
#     "ditransitive frame",
#     "is-a",
#     "ditransitive frame_ to"
#   ],
#   [
#     "ditransitive frame",
#     "is-a",
#     "genitive ditransitive frame"
#   ],
#   [
#     "ditransitive frame",
#     "is-a",
#     "reflexive ditransitive frame"
#   ],
#   [
#     "ditransitive frame",
#     "part-of",
#     "direct object"
#   ],
#   [
#     "ditransitive frame",
#     "part-of",
#     "indirect object"
#   ],
#   [
#     "ditransitive frame",
#     "part-of",
#     "subject"
#   ],
#   [
#     "gerund frame",
#     "is-a",
#     "gerund ac frame"
#   ],
#   [
#     "gerund frame",
#     "is-a",
#     "gerund oc frame"
#   ],
#   [
#     "gerund frame",
#     "is-a",
#     "gerund sc frame"
#   ],
#   [
#     "impersonal frame",
#     "is-a",
#     "adjective impersonal frame"
#   ],
#   [
#     "impersonal frame",
#     "is-a",
#     "impersonal intransitive frame"
#   ],
#   [
#     "impersonal frame",
#     "is-a",
#     "impersonal transitive frame"
#   ],
#   [
#     "impersonal intransitive frame",
#     "is-a",
#     "impersonal intransitive pp frame"
#   ],
#   [
#     "infinitive clause",
#     "is-a",
#     "interrogative infinitive clause"
#   ],
#   [
#     "infinitive clause",
#     "is-a",
#     "possessive infinitive clause"
#   ],
#   [
#     "infinitive frame",
#     "is-a",
#     "interrogative infinitive frame"
#   ],
#   [
#     "infinitive frame",
#     "is-a",
#     "intransitive infinitive ac frame"
#   ],
#   [
#     "infinitive frame",
#     "is-a",
#     "intransitive infinitive rs frame"
#   ],
#   [
#     "infinitive frame",
#     "is-a",
#     "intransitive infinitive sc frame"
#   ],
#   [
#     "infinitive frame",
#     "is-a",
#     "transitive infinitive ac frame"
#   ],
#   [
#     "infinitive frame",
#     "is-a",
#     "transitive infinitive oc frame"
#   ],
#   [
#     "infinitive frame",
#     "is-a",
#     "transitive infinitive sc frame"
#   ],
#   [
#     "interrogative clause",
#     "is-a",
#     "interrogative infinitive clause"
#   ],
#   [
#     "interrogative clause",
#     "is-a",
#     "prepositional interrogative clause"
#   ],
#   [
#     "interrogative frame",
#     "is-a",
#     "interrogative infinitive frame"
#   ],
#   [
#     "interrogative frame",
#     "is-a",
#     "intransitive interrogative frame"
#   ],
#   [
#     "interrogative frame",
#     "is-a",
#     "prepositional interrogative frame"
#   ],
#   [
#     "interrogative frame",
#     "is-a",
#     "transitive interrogative frame"
#   ],
#   [
#     "interrogative pronoun",
#     "is-a",
#     "interrogative relative pronoun"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "impersonal intransitive frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive adjectival complement frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive adverbial complement frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive declarative frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive infinitive ac frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive infinitive rs frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive infinitive sc frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive interrogative frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive nominal complement frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive pp frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "intransitive sentential frame"
#   ],
#   [
#     "intransitive frame",
#     "is-a",
#     "subjectless intransitive frame"
#   ],
#   [
#     "intransitive frame",
#     "part-of",
#     "subject"
#   ],
#   [
#     "intransitive interrogative frame",
#     "is-a",
#     "intransitive interrogative infinitive frame"
#   ],
#   [
#     "intransitive pp frame",
#     "is-a",
#     "intransitive pp declarative frame"
#   ],
#   [
#     "morphological stem",
#     "part-of",
#     "Word"
#   ],
#   [
#     "multiplicative numeral",
#     "is-a",
#     "indefinite multiplicative numeral"
#   ],
#   [
#     "multiplicative numeral",
#     "is-a",
#     "interrogative multiplicative numeral"
#   ],
#   [
#     "noun",
#     "is-a",
#     "common noun"
#   ],
#   [
#     "noun",
#     "is-a",
#     "diminutive noun"
#   ],
#   [
#     "noun",
#     "is-a",
#     "proper noun"
#   ],
#   [
#     "noun",
#     "is-a",
#     "relation noun"
#   ],
#   [
#     "noun frame",
#     "is-a",
#     "noun pp frame"
#   ],
#   [
#     "noun frame",
#     "is-a",
#     "noun predicate frame"
#   ],
#   [
#     "noun frame",
#     "is-a",
#     "noun possessive frame"
#   ],
#   [
#     "numeral",
#     "is-a",
#     "cardinal numeral"
#   ],
#   [
#     "numeral",
#     "is-a",
#     "generic numeral"
#   ],
#   [
#     "numeral",
#     "is-a",
#     "multiplicative numeral"
#   ],
#   [
#     "numeral",
#     "is-a",
#     "numeral fraction"
#   ],
#   [
#     "numeral",
#     "is-a",
#     "ordinal adjective"
#   ],
#   [
#     "object",
#     "is-a",
#     "adpositional object"
#   ],
#   [
#     "object",
#     "is-a",
#     "direct object"
#   ],
#   [
#     "object",
#     "is-a",
#     "genitive object"
#   ],
#   [
#     "object",
#     "is-a",
#     "indirect object"
#   ],
#   [
#     "object",
#     "is-a",
#     "prepositional object"
#   ],
#   [
#     "object",
#     "is-a",
#     "reflexive object"
#   ],
#   [
#     "ordinal adjective",
#     "is-a",
#     "indefinite ordinal numeral"
#   ],
#   [
#     "ordinal adjective",
#     "is-a",
#     "interrogative ordinal numeral"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "adjective"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "adposition"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "adverb"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "conjunction"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "determiner"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "interjection"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "noun"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "numeral"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "particle"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "pronoun"
#   ],
#   [
#     "part of speech",
#     "is-a",
#     "verb"
#   ],
#   [
#     "participle adjective",
#     "is-a",
#     "past participle adjective"
#   ],
#   [
#     "participle adjective",
#     "is-a",
#     "present participle adjective"
#   ],
#   [
#     "particle",
#     "is-a",
#     "affirmative particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "comparative particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "conditional particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "coordination particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "distinctive particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "future particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "infinitive particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "interrogative particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "negative particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "possessive particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "relative particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "superlative particle"
#   ],
#   [
#     "particle",
#     "is-a",
#     "unclassified particle"
#   ],
#   [
#     "personal pronoun",
#     "is-a",
#     "affixed personal pronoun"
#   ],
#   [
#     "personal pronoun",
#     "is-a",
#     "irreflexive personal pronoun"
#   ],
#   [
#     "personal pronoun",
#     "is-a",
#     "reflexive personal pronoun"
#   ],
#   [
#     "personal pronoun",
#     "is-a",
#     "strong personal pronoun"
#   ],
#   [
#     "personal pronoun",
#     "is-a",
#     "weak personal pronoun"
#   ],
#   [
#     "possessive pronoun",
#     "is-a",
#     "possessive relative pronoun"
#   ],
#   [
#     "possessive pronoun",
#     "is-a",
#     "reflexive possessive pronoun"
#   ],
#   [
#     "post positive arg",
#     "is-a",
#     "AccusativePostPositiveArg"
#   ],
#   [
#     "post positive arg",
#     "is-a",
#     "DativePostPositiveArg"
#   ],
#   [
#     "post positive arg",
#     "is-a",
#     "GenitivePostPositiveArg"
#   ],
#   [
#     "pp frame",
#     "is-a",
#     "adjective pp frame"
#   ],
#   [
#     "pp frame",
#     "is-a",
#     "impersonal intransitive pp frame"
#   ],
#   [
#     "pp frame",
#     "is-a",
#     "intransitive pp frame"
#   ],
#   [
#     "pp frame",
#     "is-a",
#     "reflexive transitive pp frame"
#   ],
#   [
#     "pp frame",
#     "is-a",
#     "subjectless intransitive pp frame"
#   ],
#   [
#     "pp frame",
#     "is-a",
#     "subjectless transitive pp frame"
#   ],
#   [
#     "pp frame",
#     "is-a",
#     "transitive pp frame"
#   ],
#   [
#     "preposition",
#     "is-a",
#     "compound preposition"
#   ],
#   [
#     "preposition",
#     "is-a",
#     "fused preposition"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "adverbial pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "allusive pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "collective pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "conditional pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "demonstrative pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "emphatic pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "existential pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "exclamative pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "fused preposition pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "fused pronoun auxiliary"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "impersonal pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "indefinite pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "interrogative pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "negative pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "personal pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "possessive pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "presentative pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "pronominal adverb"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "reciprocal pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "reflexive pronoun"
#   ],
#   [
#     "pronoun",
#     "is-a",
#     "relative pronoun"
#   ],
#   [
#     "reciprocal frame",
#     "is-a",
#     "reflexive reciprocal frame"
#   ],
#   [
#     "reflexive frame",
#     "is-a",
#     "reciprocal frame"
#   ],
#   [
#     "reflexive frame",
#     "is-a",
#     "reflexive dative transitive frame"
#   ],
#   [
#     "reflexive frame",
#     "is-a",
#     "reflexive ditransitive frame"
#   ],
#   [
#     "reflexive frame",
#     "is-a",
#     "reflexive reciprocal frame"
#   ],
#   [
#     "reflexive frame",
#     "is-a",
#     "reflexive transitive frame"
#   ],
#   [
#     "reflexive frame",
#     "part-of",
#     "reflexive object"
#   ],
#   [
#     "reflexive frame",
#     "part-of",
#     "subject"
#   ],
#   [
#     "reflexive pronoun",
#     "is-a",
#     "reflexive personal pronoun"
#   ],
#   [
#     "reflexive pronoun",
#     "is-a",
#     "reflexive possessive pronoun"
#   ],
#   [
#     "reflexive transitive frame",
#     "is-a",
#     "reflexive dative transitive frame"
#   ],
#   [
#     "reflexive transitive frame",
#     "is-a",
#     "reflexive transitive pp frame"
#   ],
#   [
#     "relative pronoun",
#     "is-a",
#     "interrogative relative pronoun"
#   ],
#   [
#     "relative pronoun",
#     "is-a",
#     "possessive relative pronoun"
#   ],
#   [
#     "subject",
#     "is-a",
#     "copulative subject"
#   ],
#   [
#     "subject",
#     "is-a",
#     "raising subject"
#   ],
#   [
#     "subjectless frame",
#     "is-a",
#     "subjectless intransitive frame"
#   ],
#   [
#     "subjectless frame",
#     "is-a",
#     "subjectless transitive frame"
#   ],
#   [
#     "subjectless intransitive frame",
#     "is-a",
#     "subjectless intransitive pp frame"
#   ],
#   [
#     "subjectless transitive frame",
#     "is-a",
#     "subjectless transitive pp frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "ditransitive frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "genitive transitive frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "impersonal transitive frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "reflexive transitive frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "subjectless transitive frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive adjectival complement frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive adverbial complement frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive declarative frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive infinitive ac frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive infinitive oc frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive infinitive sc frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive interrogative frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive nominal complement frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive pp frame"
#   ],
#   [
#     "transitive frame",
#     "is-a",
#     "transitive sentential frame"
#   ],
#   [
#     "transitive frame",
#     "part-of",
#     "direct object"
#   ],
#   [
#     "transitive frame",
#     "part-of",
#     "subject"
#   ],
#   [
#     "transitive interrogative frame",
#     "is-a",
#     "transitive interrogative infinitive frame"
#   ],
#   [
#     "verb",
#     "is-a",
#     "auxiliary"
#   ],
#   [
#     "verb",
#     "is-a",
#     "copula"
#   ],
#   [
#     "verb",
#     "is-a",
#     "deficient verb"
#   ],
#   [
#     "verb",
#     "is-a",
#     "light verb"
#   ],
#   [
#     "verb",
#     "is-a",
#     "main verb"
#   ],
#   [
#     "verb",
#     "is-a",
#     "plain verb"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "declarative frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "gerund frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "impersonal frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "infinitive frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "interrogative frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "intransitive frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "reciprocal frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "reflexive frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "sentential frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "subjectless frame"
#   ],
#   [
#     "verb frame",
#     "is-a",
#     "transitive frame"
#   ],
#   [
#     "zero morph",
#     "is-a",
#     "Affix"
#   ],
#   [
#     "zero morph",
#     "is-a",
#     "infix"
#   ],
#   [
#     "zero morph",
#     "is-a",
#     "prefix"
#   ],
#   [
#     "zero morph",
#     "is-a",
#     "simulfix"
#   ],
#   [
#     "zero morph",
#     "is-a",
#     "suffix"
#   ],
#   [
#     "zero morph",
#     "is-a",
#     "transfix"
#   ]
# ]
# 3042 gemini-2.5-pro
# 3it [03:10, 63.62s/it]

# %%
len(response_final)
# Out:
# 2

# %%
final_ans = []
for resp in response_final:
    resp_list = json.loads(resp)
    for lst in resp_list:
        final_ans.append({"child":lst[0], "parent":lst[-1]})

# %%
len(final_ans)
# Out:
# 311

# %%
final_ans
# Out:
# [{'child': 'AbbreviatedForm', 'parent': 'Word'},
#  {'child': 'AccusativePostPositiveArg', 'parent': 'post positive arg'},
#  {'child': 'AccusativePostPositiveArg',
#   'parent': 'adjective accusative post positive frame'},
#  {'child': 'Affix', 'parent': 'zero morph'},
#  {'child': 'Affix', 'parent': 'Word'},
#  {'child': 'DativePostPositiveArg', 'parent': 'post positive arg'},
#  {'child': 'DativePostPositiveArg',
#   'parent': 'adjective dative post positive frame'},
#  {'child': 'GenitivePostPositiveArg', 'parent': 'post positive arg'},
#  {'child': 'GenitivePostPositiveArg',
#   'parent': 'adjective genitive post positive frame'},
#  {'child': 'LexicalEntry', 'parent': 'MultiWordExpression'},
#  {'child': 'LexicalEntry', 'parent': 'Word'},
#  {'child': 'MultiWordExpression', 'parent': 'fused preposition determiner'},
#  {'child': 'MultiWordExpression', 'parent': 'fused preposition pronoun'},
#  {'child': 'MultiWordExpression', 'parent': 'fused pronoun auxiliary'},
#  {'child': 'RaisableArgument', 'parent': 'raising subject'},
#  {'child': 'SyntacticArgument', 'parent': 'RaisableArgument'},
#  {'child': 'SyntacticArgument', 'parent': 'adjunct'},
#  {'child': 'SyntacticArgument', 'parent': 'clausal arg'},
#  {'child': 'SyntacticArgument', 'parent': 'complement'},
#  {'child': 'SyntacticArgument', 'parent': 'copulative arg'},
#  {'child': 'SyntacticArgument', 'parent': 'object'},
#  {'child': 'SyntacticArgument', 'parent': 'post positive arg'},
#  {'child': 'SyntacticArgument', 'parent': 'subject'},
#  {'child': 'SyntacticFrame', 'parent': 'adjective frame'},
#  {'child': 'SyntacticFrame', 'parent': 'adverbial complement frame'},
#  {'child': 'SyntacticFrame', 'parent': 'noun frame'},
#  {'child': 'SyntacticFrame', 'parent': 'pp frame'},
#  {'child': 'SyntacticFrame', 'parent': 'preposition frame'},
#  {'child': 'SyntacticFrame', 'parent': 'preposition phrase frame'},
#  {'child': 'SyntacticFrame', 'parent': 'verb frame'},
#  {'child': 'Word', 'parent': 'AbbreviatedForm'},
#  {'child': 'Word', 'parent': 'adjective'},
#  {'child': 'Word', 'parent': 'adposition'},
#  {'child': 'Word', 'parent': 'adverb'},
#  {'child': 'Word', 'parent': 'conjunction'},
#  {'child': 'Word', 'parent': 'determiner'},
#  {'child': 'Word', 'parent': 'interjection'},
#  {'child': 'Word', 'parent': 'noun'},
#  {'child': 'Word', 'parent': 'particle'},
#  {'child': 'Word', 'parent': 'pronoun'},
#  {'child': 'Word', 'parent': 'verb'},
#  {'child': 'Word', 'parent': 'adjective phrase'},
#  {'child': 'Word', 'parent': 'noun phrase'},
#  {'child': 'Word', 'parent': 'preposition phrase'},
#  {'child': 'Word', 'parent': 'verb phrase'},
#  {'child': 'adjective', 'parent': 'adjective-i'},
#  {'child': 'adjective', 'parent': 'adjective-na'},
#  {'child': 'adjective', 'parent': 'ordinal adjective'},
#  {'child': 'adjective', 'parent': 'participle adjective'},
#  {'child': 'adjective', 'parent': 'possessive adjective'},
#  {'child': 'adjective', 'parent': 'predicative adjective'},
#  {'child': 'adjective', 'parent': 'qualifier adjective'},
#  {'child': 'adjective frame', 'parent': 'adjective attributive frame'},
#  {'child': 'adjective frame', 'parent': 'adjective comparative frame'},
#  {'child': 'adjective frame', 'parent': 'adjective impersonal frame'},
#  {'child': 'adjective frame', 'parent': 'adjective post positive frame'},
#  {'child': 'adjective frame', 'parent': 'adjective pp frame'},
#  {'child': 'adjective frame', 'parent': 'adjective predicate frame'},
#  {'child': 'adjective frame', 'parent': 'adjective predicative frame'},
#  {'child': 'adjective frame', 'parent': 'adjective scale frame'},
#  {'child': 'adjective frame', 'parent': 'adjective superlative frame'},
#  {'child': 'adjective post positive frame',
#   'parent': 'adjective accusative post positive frame'},
#  {'child': 'adjective post positive frame',
#   'parent': 'adjective dative post positive frame'},
#  {'child': 'adjective post positive frame',
#   'parent': 'adjective genitive post positive frame'},
#  {'child': 'adjunct', 'parent': 'comparative adjunct'},
#  {'child': 'adjunct', 'parent': 'possessive adjunct'},
#  {'child': 'adjunct', 'parent': 'predicative adjunct'},
#  {'child': 'adjunct', 'parent': 'prepositional adjunct'},
#  {'child': 'adjunct', 'parent': 'superlative adjunct'},
#  {'child': 'adposition', 'parent': 'circumposition'},
#  {'child': 'adposition', 'parent': 'postposition'},
#  {'child': 'adposition', 'parent': 'preposition'},
#  {'child': 'adverb', 'parent': 'adverbial pronoun'},
#  {'child': 'adverb', 'parent': 'general adverb'},
#  {'child': 'adverb', 'parent': 'predicative adverb'},
#  {'child': 'adverb', 'parent': 'prepositional adverb'},
#  {'child': 'adverb', 'parent': 'pronominal adverb'},
#  {'child': 'auxiliary', 'parent': 'fused pronoun auxiliary'},
#  {'child': 'auxiliary', 'parent': 'modal'},
#  {'child': 'cardinal numeral', 'parent': 'indefinite cardinal numeral'},
#  {'child': 'cardinal numeral', 'parent': 'interrogative cardinal numeral'},
#  {'child': 'complement', 'parent': 'adverbial complement'},
#  {'child': 'complement', 'parent': 'object complement'},
#  {'child': 'conjunction', 'parent': 'coordinating conjunction'},
#  {'child': 'conjunction', 'parent': 'subordinating conjunction'},
#  {'child': 'control', 'parent': 'arbitrary control'},
#  {'child': 'control', 'parent': 'object control'},
#  {'child': 'control', 'parent': 'subject control'},
#  {'child': 'copulative arg', 'parent': 'copulative subject'},
#  {'child': 'declarative frame', 'parent': 'intransitive declarative frame'},
#  {'child': 'declarative frame', 'parent': 'intransitive pp declarative frame'},
#  {'child': 'declarative frame', 'parent': 'transitive declarative frame'},
#  {'child': 'determiner', 'parent': 'article'},
#  {'child': 'determiner', 'parent': 'demonstrative determiner'},
#  {'child': 'determiner', 'parent': 'exclamative determiner'},
#  {'child': 'determiner', 'parent': 'fused preposition determiner'},
#  {'child': 'determiner', 'parent': 'indefinite determiner'},
#  {'child': 'determiner', 'parent': 'interrogative determiner'},
#  {'child': 'determiner', 'parent': 'possessive determiner'},
#  {'child': 'determiner', 'parent': 'reflexive determiner'},
#  {'child': 'determiner', 'parent': 'relative determiner'},
#  {'child': 'ditransitive frame',
#   'parent': 'ditransitive double accusative frame'},
#  {'child': 'ditransitive frame', 'parent': 'ditransitive frame_ for'},
#  {'child': 'ditransitive frame', 'parent': 'ditransitive frame_ to'},
#  {'child': 'ditransitive frame', 'parent': 'genitive ditransitive frame'},
#  {'child': 'ditransitive frame', 'parent': 'reflexive ditransitive frame'},
#  {'child': 'ditransitive frame', 'parent': 'direct object'},
#  {'child': 'ditransitive frame', 'parent': 'indirect object'},
#  {'child': 'ditransitive frame', 'parent': 'subject'},
#  {'child': 'gerund frame', 'parent': 'gerund ac frame'},
#  {'child': 'gerund frame', 'parent': 'gerund oc frame'},
#  {'child': 'gerund frame', 'parent': 'gerund sc frame'},
#  {'child': 'impersonal frame', 'parent': 'adjective impersonal frame'},
#  {'child': 'impersonal frame', 'parent': 'impersonal intransitive frame'},
#  {'child': 'impersonal frame', 'parent': 'impersonal transitive frame'},
#  {'child': 'impersonal intransitive frame',
#   'parent': 'impersonal intransitive pp frame'},
#  {'child': 'infinitive clause', 'parent': 'interrogative infinitive clause'},
#  {'child': 'infinitive clause', 'parent': 'possessive infinitive clause'},
#  {'child': 'infinitive frame', 'parent': 'interrogative infinitive frame'},
#  {'child': 'infinitive frame', 'parent': 'intransitive infinitive ac frame'},
#  {'child': 'infinitive frame', 'parent': 'intransitive infinitive rs frame'},
#  {'child': 'infinitive frame', 'parent': 'intransitive infinitive sc frame'},
#  {'child': 'infinitive frame', 'parent': 'transitive infinitive ac frame'},
#  {'child': 'infinitive frame', 'parent': 'transitive infinitive oc frame'},
#  {'child': 'infinitive frame', 'parent': 'transitive infinitive sc frame'},
#  {'child': 'interrogative clause',
#   'parent': 'interrogative infinitive clause'},
#  {'child': 'interrogative clause',
#   'parent': 'prepositional interrogative clause'},
#  {'child': 'interrogative frame', 'parent': 'interrogative infinitive frame'},
#  {'child': 'interrogative frame',
#   'parent': 'intransitive interrogative frame'},
#  {'child': 'interrogative frame',
#   'parent': 'prepositional interrogative frame'},
#  {'child': 'interrogative frame', 'parent': 'transitive interrogative frame'},
#  {'child': 'interrogative pronoun',
#   'parent': 'interrogative relative pronoun'},
#  {'child': 'intransitive frame', 'parent': 'impersonal intransitive frame'},
#  {'child': 'intransitive frame',
#   'parent': 'intransitive adjectival complement frame'},
#  {'child': 'intransitive frame',
#   'parent': 'intransitive adverbial complement frame'},
#  {'child': 'intransitive frame', 'parent': 'intransitive declarative frame'},
#  {'child': 'intransitive frame', 'parent': 'intransitive infinitive ac frame'},
#  {'child': 'intransitive frame', 'parent': 'intransitive infinitive rs frame'},
#  {'child': 'intransitive frame', 'parent': 'intransitive infinitive sc frame'},
#  {'child': 'intransitive frame', 'parent': 'intransitive interrogative frame'},
#  {'child': 'intransitive frame',
#   'parent': 'intransitive nominal complement frame'},
#  {'child': 'intransitive frame', 'parent': 'intransitive pp frame'},
#  {'child': 'intransitive frame', 'parent': 'intransitive sentential frame'},
#  {'child': 'intransitive frame', 'parent': 'subjectless intransitive frame'},
#  {'child': 'intransitive frame', 'parent': 'subject'},
#  {'child': 'intransitive interrogative frame',
#   'parent': 'intransitive interrogative infinitive frame'},
#  {'child': 'intransitive pp frame',
#   'parent': 'intransitive pp declarative frame'},
#  {'child': 'morphological stem', 'parent': 'Word'},
#  {'child': 'multiplicative numeral',
#   'parent': 'indefinite multiplicative numeral'},
#  {'child': 'multiplicative numeral',
#   'parent': 'interrogative multiplicative numeral'},
#  {'child': 'noun', 'parent': 'common noun'},
#  {'child': 'noun', 'parent': 'diminutive noun'},
#  {'child': 'noun', 'parent': 'proper noun'},
#  {'child': 'noun', 'parent': 'relation noun'},
#  {'child': 'noun frame', 'parent': 'noun pp frame'},
#  {'child': 'noun frame', 'parent': 'noun predicate frame'},
#  {'child': 'noun frame', 'parent': 'noun possessive frame'},
#  {'child': 'numeral', 'parent': 'cardinal numeral'},
#  {'child': 'numeral', 'parent': 'generic numeral'},
#  {'child': 'numeral', 'parent': 'multiplicative numeral'},
#  {'child': 'numeral', 'parent': 'numeral fraction'},
#  {'child': 'numeral', 'parent': 'ordinal adjective'},
#  {'child': 'object', 'parent': 'adpositional object'},
#  {'child': 'object', 'parent': 'direct object'},
#  {'child': 'object', 'parent': 'genitive object'},
#  {'child': 'object', 'parent': 'indirect object'},
#  {'child': 'object', 'parent': 'prepositional object'},
#  {'child': 'object', 'parent': 'reflexive object'},
#  {'child': 'ordinal adjective', 'parent': 'indefinite ordinal numeral'},
#  {'child': 'ordinal adjective', 'parent': 'interrogative ordinal numeral'},
#  {'child': 'part of speech', 'parent': 'adjective'},
#  {'child': 'part of speech', 'parent': 'adposition'},
#  {'child': 'part of speech', 'parent': 'adverb'},
#  {'child': 'part of speech', 'parent': 'conjunction'},
#  {'child': 'part of speech', 'parent': 'determiner'},
#  {'child': 'part of speech', 'parent': 'interjection'},
#  {'child': 'part of speech', 'parent': 'noun'},
#  {'child': 'part of speech', 'parent': 'numeral'},
#  {'child': 'part of speech', 'parent': 'particle'},
#  {'child': 'part of speech', 'parent': 'pronoun'},
#  {'child': 'part of speech', 'parent': 'verb'},
#  {'child': 'participle adjective', 'parent': 'past participle adjective'},
#  {'child': 'participle adjective', 'parent': 'present participle adjective'},
#  {'child': 'particle', 'parent': 'affirmative particle'},
#  {'child': 'particle', 'parent': 'comparative particle'},
#  {'child': 'particle', 'parent': 'conditional particle'},
#  {'child': 'particle', 'parent': 'coordination particle'},
#  {'child': 'particle', 'parent': 'distinctive particle'},
#  {'child': 'particle', 'parent': 'future particle'},
#  {'child': 'particle', 'parent': 'infinitive particle'},
#  {'child': 'particle', 'parent': 'interrogative particle'},
#  {'child': 'particle', 'parent': 'negative particle'},
#  {'child': 'particle', 'parent': 'possessive particle'},
#  {'child': 'particle', 'parent': 'relative particle'},
#  {'child': 'particle', 'parent': 'superlative particle'},
#  {'child': 'particle', 'parent': 'unclassified particle'},
#  {'child': 'personal pronoun', 'parent': 'affixed personal pronoun'},
#  {'child': 'personal pronoun', 'parent': 'irreflexive personal pronoun'},
#  {'child': 'personal pronoun', 'parent': 'reflexive personal pronoun'},
#  {'child': 'personal pronoun', 'parent': 'strong personal pronoun'},
#  {'child': 'personal pronoun', 'parent': 'weak personal pronoun'},
#  {'child': 'possessive pronoun', 'parent': 'possessive relative pronoun'},
#  {'child': 'possessive pronoun', 'parent': 'reflexive possessive pronoun'},
#  {'child': 'post positive arg', 'parent': 'AccusativePostPositiveArg'},
#  {'child': 'post positive arg', 'parent': 'DativePostPositiveArg'},
#  {'child': 'post positive arg', 'parent': 'GenitivePostPositiveArg'},
#  {'child': 'pp frame', 'parent': 'adjective pp frame'},
#  {'child': 'pp frame', 'parent': 'impersonal intransitive pp frame'},
#  {'child': 'pp frame', 'parent': 'intransitive pp frame'},
#  {'child': 'pp frame', 'parent': 'reflexive transitive pp frame'},
#  {'child': 'pp frame', 'parent': 'subjectless intransitive pp frame'},
#  {'child': 'pp frame', 'parent': 'subjectless transitive pp frame'},
#  {'child': 'pp frame', 'parent': 'transitive pp frame'},
#  {'child': 'preposition', 'parent': 'compound preposition'},
#  {'child': 'preposition', 'parent': 'fused preposition'},
#  {'child': 'pronoun', 'parent': 'adverbial pronoun'},
#  {'child': 'pronoun', 'parent': 'allusive pronoun'},
#  {'child': 'pronoun', 'parent': 'collective pronoun'},
#  {'child': 'pronoun', 'parent': 'conditional pronoun'},
#  {'child': 'pronoun', 'parent': 'demonstrative pronoun'},
#  {'child': 'pronoun', 'parent': 'emphatic pronoun'},
#  {'child': 'pronoun', 'parent': 'existential pronoun'},
#  {'child': 'pronoun', 'parent': 'exclamative pronoun'},
#  {'child': 'pronoun', 'parent': 'fused preposition pronoun'},
#  {'child': 'pronoun', 'parent': 'fused pronoun auxiliary'},
#  {'child': 'pronoun', 'parent': 'impersonal pronoun'},
#  {'child': 'pronoun', 'parent': 'indefinite pronoun'},
#  {'child': 'pronoun', 'parent': 'interrogative pronoun'},
#  {'child': 'pronoun', 'parent': 'negative pronoun'},
#  {'child': 'pronoun', 'parent': 'personal pronoun'},
#  {'child': 'pronoun', 'parent': 'possessive pronoun'},
#  {'child': 'pronoun', 'parent': 'presentative pronoun'},
#  {'child': 'pronoun', 'parent': 'pronominal adverb'},
#  {'child': 'pronoun', 'parent': 'reciprocal pronoun'},
#  {'child': 'pronoun', 'parent': 'reflexive pronoun'},
#  {'child': 'pronoun', 'parent': 'relative pronoun'},
#  {'child': 'reciprocal frame', 'parent': 'reflexive reciprocal frame'},
#  {'child': 'reflexive frame', 'parent': 'reciprocal frame'},
#  {'child': 'reflexive frame', 'parent': 'reflexive dative transitive frame'},
#  {'child': 'reflexive frame', 'parent': 'reflexive ditransitive frame'},
#  {'child': 'reflexive frame', 'parent': 'reflexive reciprocal frame'},
#  {'child': 'reflexive frame', 'parent': 'reflexive transitive frame'},
#  {'child': 'reflexive frame', 'parent': 'reflexive object'},
#  {'child': 'reflexive frame', 'parent': 'subject'},
#  {'child': 'reflexive pronoun', 'parent': 'reflexive personal pronoun'},
#  {'child': 'reflexive pronoun', 'parent': 'reflexive possessive pronoun'},
#  {'child': 'reflexive transitive frame',
#   'parent': 'reflexive dative transitive frame'},
#  {'child': 'reflexive transitive frame',
#   'parent': 'reflexive transitive pp frame'},
#  {'child': 'relative pronoun', 'parent': 'interrogative relative pronoun'},
#  {'child': 'relative pronoun', 'parent': 'possessive relative pronoun'},
#  {'child': 'subject', 'parent': 'copulative subject'},
#  {'child': 'subject', 'parent': 'raising subject'},
#  {'child': 'subjectless frame', 'parent': 'subjectless intransitive frame'},
#  {'child': 'subjectless frame', 'parent': 'subjectless transitive frame'},
#  {'child': 'subjectless intransitive frame',
#   'parent': 'subjectless intransitive pp frame'},
#  {'child': 'subjectless transitive frame',
#   'parent': 'subjectless transitive pp frame'},
#  {'child': 'transitive frame', 'parent': 'ditransitive frame'},
#  {'child': 'transitive frame', 'parent': 'genitive transitive frame'},
#  {'child': 'transitive frame', 'parent': 'impersonal transitive frame'},
#  {'child': 'transitive frame', 'parent': 'reflexive transitive frame'},
#  {'child': 'transitive frame', 'parent': 'subjectless transitive frame'},
#  {'child': 'transitive frame',
#   'parent': 'transitive adjectival complement frame'},
#  {'child': 'transitive frame',
#   'parent': 'transitive adverbial complement frame'},
#  {'child': 'transitive frame', 'parent': 'transitive declarative frame'},
#  {'child': 'transitive frame', 'parent': 'transitive infinitive ac frame'},
#  {'child': 'transitive frame', 'parent': 'transitive infinitive oc frame'},
#  {'child': 'transitive frame', 'parent': 'transitive infinitive sc frame'},
#  {'child': 'transitive frame', 'parent': 'transitive interrogative frame'},
#  {'child': 'transitive frame',
#   'parent': 'transitive nominal complement frame'},
#  {'child': 'transitive frame', 'parent': 'transitive pp frame'},
#  {'child': 'transitive frame', 'parent': 'transitive sentential frame'},
#  {'child': 'transitive frame', 'parent': 'direct object'},
#  {'child': 'transitive frame', 'parent': 'subject'},
#  {'child': 'transitive interrogative frame',
#   'parent': 'transitive interrogative infinitive frame'},
#  {'child': 'verb', 'parent': 'auxiliary'},
#  {'child': 'verb', 'parent': 'copula'},
#  {'child': 'verb', 'parent': 'deficient verb'},
#  {'child': 'verb', 'parent': 'light verb'},
#  {'child': 'verb', 'parent': 'main verb'},
#  {'child': 'verb', 'parent': 'plain verb'},
#  {'child': 'verb frame', 'parent': 'declarative frame'},
#  {'child': 'verb frame', 'parent': 'gerund frame'},
#  {'child': 'verb frame', 'parent': 'impersonal frame'},
#  {'child': 'verb frame', 'parent': 'infinitive frame'},
#  {'child': 'verb frame', 'parent': 'interrogative frame'},
#  {'child': 'verb frame', 'parent': 'intransitive frame'},
#  {'child': 'verb frame', 'parent': 'reciprocal frame'},
#  {'child': 'verb frame', 'parent': 'reflexive frame'},
#  {'child': 'verb frame', 'parent': 'sentential frame'},
#  {'child': 'verb frame', 'parent': 'subjectless frame'},
#  {'child': 'verb frame', 'parent': 'transitive frame'},
#  {'child': 'zero morph', 'parent': 'Affix'},
#  {'child': 'zero morph', 'parent': 'infix'},
#  {'child': 'zero morph', 'parent': 'prefix'},
#  {'child': 'zero morph', 'parent': 'simulfix'},
#  {'child': 'zero morph', 'parent': 'suffix'},
#  {'child': 'zero morph', 'parent': 'transfix'},
#  {'child': 'bullet', 'parent': 'punctuation'},
#  {'child': 'close parenthesis', 'parent': 'punctuation'},
#  {'child': 'colon', 'parent': 'punctuation'},
#  {'child': 'comma', 'parent': 'punctuation'},
#  {'child': 'exclamative point', 'parent': 'punctuation'},
#  {'child': 'inverted comma', 'parent': 'punctuation'},
#  {'child': 'letter', 'parent': 'symbol'},
#  {'child': 'open parenthesis', 'parent': 'punctuation'},
#  {'child': 'point', 'parent': 'punctuation'},
#  {'child': 'punctuation', 'parent': 'symbol'},
#  {'child': 'question mark', 'parent': 'punctuation'},
#  {'child': 'semi colon', 'parent': 'punctuation'},
#  {'child': 'slash', 'parent': 'punctuation'},
#  {'child': 'suspension points', 'parent': 'punctuation'}]

# %%
with open("predictions_pro_model_c10_clustering_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_ans, f, indent=2, ensure_ascii=False)
