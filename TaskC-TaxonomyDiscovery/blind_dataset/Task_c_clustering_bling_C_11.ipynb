# %%
import json
def load_json(data_path):
    with open(data_path, "r") as file_1:
        data = json.load(file_1)
    return data

# %%
test_data = []
with open("C11-Blind-Types.txt", "r", encoding="utf-8") as file:
    content = file.readlines()
    for con in content:
        test_data.append(con.strip('\n'))

print(test_data)
# Out:
# ['protein mass fraction', 'area unit', 'carbon dioxide equivalent mass per energy unit', 'number manual firmness 3.5', 'reddening (U-B)', 'prefixed hertz', 'Streptococcus uberis count (specific)', 'starch mass fraction', 'white light magnitude', 'prefixed metre per prefixed secon (time) squared', 'quantity of dimension one', 'color area fraction', 'quantity', 'magnetic field', 'admittance', 'radiant intensity', 'power unit', 'coverage', 'prefixed litre', 'potential difference', 'I magnitude', 'mustard powder mass fraction', 'area fraction unit', 'information capacity', 'Réaumur temperature', 'Staphylococcus aureus count (volumetric)', 'number malformed flowers', 'permeability (earth science) unit', 'mass unit', 'half-life', 'number color 4', 'responsivity unit', 'Stanton number for mass transfer unit', 'radiant flux', 'right ascension', 'Cousins magnitude', 'total density parameter', 'Streptococcus uberis count (volumetric)', 'number leaves', 'Strouhal number', 'number wilted flowers', 'solid angle unit', 'number manual firmness 0', 'exposure', 'modulus of elasticity', 'amount of substance concentration unit', 'aberration in latitude', 'pressure unit', 'first Cowling number unit', 'number color', 'Thuan and Gunn magnitude', 'prefixed electronvolt', 'Péclet number', 'luminous energy unit', 'weight', 'prefixed sievert', 'electric dipole moment unit', 'volumetric heat capacity', 'Knudsen number unit', 'prefixed volt', 'specific cost', 'cause end of vase life dry flowers', 'pixel count', 'galactic longitude', 'disodium ethylene diamine tetra acetate mass fraction', 'number external browning', 'quantum efficiency unit', 'Rankine temperature scale', 'stress', 'loss modulus', 'dry matter mass fraction', 'time constant', 'secular aberration', 'ecliptic longitude', 'cause end of vase life rotten flowers', 'Grashof number for mass transfer', 'acidity', 'colour temperature', 'thermal insulance unit', 'number Botrytis 0', 'bud stadium day 0', 'epoch at maximum brightness', 'potassium sorbate mass fraction', 'number flowers', 'Corynebacterium count (volumetric)', 'angular displacement', 'binary prefix', 'neck ring mass', 'apparent distance modulus', 'area density unit', 'B magnitude at maximum brightness', 'cubic prefixed metre', 'cause end of vase life malformed buds', 'density parameter for radiation', 'reddening (B-V)', 'catalytic activity unit', 'gelatin mass fraction', 'area density', 'eccentricity', 'Lewis number unit', 'epoch', 'electric current', 'Tycho broadband magnitude', 'area fraction', 'permeance (electromagnetic)', 'prefixed henry', 'detectivity', 'thermal conductivity', 'dark noise', 'number vascular browning', 'prefixed katal', 'normal albedo', 'Reynolds number unit', 'radiance', 'bolometric magnitude', 'radiance unit', 'quality mark', 'temperature', 'quantity of dimension one unit', 'number density unit', 'Strömgren magnitude', 'Alfvén number', 'magnitude', 'prefixed degree Celsius', 'time unit', 'number bud stadium 3', 'average speed', 'viable count', 'viable count (volumetric)', 'column number density', 'fixed point', 'Celsius temperature', 'cost', 'carbon dioxide equivalent mass unit', 'Weber number unit', 'Serratia marcescens count (volumetric)', 'thermal diffusivity', 'Fahrenheit temperature unit', 'Froude number unit', 'amount of substance unit', 'amount of substance fraction flow', 'specific heat capacity unit', 'magnetomotive force', 'prefixed pascal', 'coliform bacteria count (specific)', 'Jeans mass', 'force', 'molar entropy', 'Hartmann number unit', 'bolometric correction', 'percentage unit', 'number external browning 3', 'gravitational acceleration', 'Mach number unit', 'Schmidt number unit', 'number dry buds', 'distance modulus', 'cold gas mass fraction', 'density parameter for baryonic matter', 'dynamic viscosity unit', 'magnitude unit', 'shear rate', 'wetting angle', 'angular size', 'luminous intensity', 'illuminance unit', 'number nonturgid flowers', 'permeability of free space', 'dynamic range', 'electric ...

# %%
len(test_data)
# Out:
# 798

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")

# %%
prompt_domain_extraction = f"""You are an expert AI assistant specializing in knowledge representation, ontology, and domain analysis. Your task is to analyze a given list of terms to identify the specific knowledge domain they belong to.

**Instructions:**

1.  **Analyze Input:** You will be given a single list of terms. Carefully examine these terms to find the common theme or scientific field that connects them. Consider what subject matter these terms represent (e.g., biology, geography, technology, food production).
2.  **Generate Domain Name:** Based on your analysis, create a concise and descriptive name for the domain. For example, "Food Science and Production" or "Earth and Environmental Science."
3.  **Generate Domain Description:** Write a 4-5 line description of this domain. This description should explain:
    *   The general area of study or industry it covers.
    *   The types of concepts the terms represent within this domain.
    *   How concepts within this domain are typically related (e.g., one can be a part of another, one can be transformed into another, or one can be an ingredient of another).
    *   The overall purpose of structuring knowledge in this domain (e.g., for scientific analysis, traceability, data interoperability).
4.  **Format the Output:** Return a Python dictionary containing two keys: `domain_name` and `domain_description`.

**Task:**
Analyze the following list of terms and generate a domain name and description.

-   **List of Terms:** {test_data}

Return the result as a Python dictionary."""

# %%
generation_config = {"response_mime_type": "application/json"}
print(len(prompt_domain_extraction))
response = client.models.generate_content(
        contents= prompt_domain_extraction,
        config=generation_config,
        model=model
    )
domain= json.loads(response.text)
# Out:
# 20052

# %%
domain
# Out:
# {'domain_name': 'Scientific and Technical Quantification Systems',
#  'domain_description': 'This domain focuses on the systematic representation and definition of measurable physical quantities, dimensionless numbers, and observable attributes across diverse scientific and technical fields. It encompasses fundamental units, derived quantities, and specialized metrics found in areas like astrophysics, fluid dynamics, food science, and microbiology, alongside qualitative observations often assigned numerical scales. Concepts are typically related by measurement relationships, part-whole compositions for complex quantities, or categorizations of observed phenomena. The primary purpose is to ensure consistent data interpretation, enable interoperability across different scientific and industrial datasets, and facilitate rigorous quantitative analysis.'}

# %%
prompt_cluster = f"""You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning. You will be provided with a domain name and a description to set the context for your task.

Your primary task is to group a list of terms into clusters by identifying their **parent-child relationships**. In this context, a **parent-child relationship** is a fundamental connection where one term is a direct 'parent' (a broader category) or a 'child' (a more specific instance or part) of another. This includes:
*   **'is-a' relationships (Type/Subtype):** Where the child term is a specific type of the parent term (e.g., 'River' is-a 'Body of Water').
*   **'part-of' relationships (Whole/Part):** Where the child term is a component or part of the parent term (e.g., 'Sea' is-part-of 'Ocean').

You will cluster terms that are linked directly or indirectly by these fundamental parent-child connections.

**Context (Provided as Input):**
-   **Domain Name:** {domain['domain_name']}
-   **Domain Description:** {domain['domain_description']}

**Instructions:**

1.  **Build the Graph:**
    *   Treat each term from the input list as a point (node) in a graph.
    *   Using your knowledge of the **identified domain** (contextualized by the provided name and description), check every pair of terms to see if a **parent-child relationship** ('is-a' or 'part-of') exists between them.
    *   If such a relationship exists, create a two-way (undirected) link between the parent and child terms for clustering purposes.
2.  **Form Clusters:**
    *   Group terms into clusters where terms are connected either directly or indirectly through the identified **parent-child** links.
    *   Terms with no identifiable parent-child connections to other terms in the list will form their own single-term clusters.
    *   Ensure every term from the input list appears in the output.
3.  **Handle Special Cases:**
    *   If the terms list is empty, return an empty list of clusters: [].
4.  **Format the Output:**
    *   Return a Python list of lists, where each inner list contains the terms in a cluster.
    *   Do not include the relationships in the output, only the grouped terms.
    *   Sort the clusters alphabetically by the first term in each cluster.
    *   Within each cluster, sort the terms alphabetically.

**Task:**
Group the following terms into clusters by identifying all direct and indirect **parent-child (e.g:-'is-a' and 'part-of') relationships** between them, guided by the provided domain context.

-   **List of Terms:** {test_data}

Return the result as a Python list of lists, where each inner list represents a cluster of terms."""

# %%
print(len(prompt_cluster))
# Out:
# 21965

# %%
generation_config = {"response_mime_type": "application/json"}

response = client.models.generate_content(
        contents= prompt_cluster,
        config=generation_config,
        model=model
    )
clusters_list= json.loads(response.text)

# %%
clusters_list
# Out:
# [['1040 nm Lockwood magnitude',
#   'Alfvén number',
#   'Alfvén number unit',
#   'absolute bolometric magnitude',
#   'absolute magnitude',
#   'absorbed dose',
#   'absorbed dose rate',
#   'absorbed dose rate unit',
#   'absorbed dose unit',
#   'acceleration',
#   'acceleration unit',
#   'acidity',
#   'action',
#   'action unit',
#   'activity',
#   'activity unit',
#   'admittance',
#   'albedo',
#   'altitude',
#   'amount of money',
#   'amount of money unit',
#   'amount of substance',
#   'amount of substance concentration',
#   'amount of substance concentration unit',
#   'amount of substance flow',
#   'amount of substance flow unit',
#   'amount of substance fraction',
#   'amount of substance fraction flow',
#   'amount of substance fraction unit',
#   'amount of substance unit',
#   'amphiphilicity',
#   'amplitude',
#   'angle',
#   'angle unit',
#   'angular acceleration',
#   'angular acceleration unit',
#   'angular displacement',
#   'angular momentum',
#   'angular momentum unit',
#   'angular speed',
#   'angular speed unit',
#   'angular size',
#   'annual aberration',
#   'apparent diameter',
#   'apparent distance modulus',
#   'apparent magnitude',
#   'area',
#   'area density',
#   'area density rate',
#   'area density rate unit',
#   'area density unit',
#   'area fraction',
#   'area fraction unit',
#   'area unit',
#   'atomic mass',
#   'average speed',
#   'azimuth',
#   'B magnitude',
#   'B magnitude at maximum brightness',
#   'B magnitude at minimum brightness',
#   'β_narrow magnitude',
#   'β_wide magnitude',
#   'binary prefix',
#   'body mass',
#   'body label mass',
#   'bolometric correction',
#   'bolometric magnitude',
#   'bond albedo',
#   'breadth',
#   'brightness temperature',
#   'bud stadium',
#   'bud stadium day 0',
#   'bud stadium day 4',
#   'bud stadium day 7',
#   'bulk modulus',
#   'cap mass',
#   'carbon dioxide equivalent mass',
#   'carbon dioxide equivalent mass per energy',
#   'carbon dioxide equivalent mass per energy unit',
#   'carbon dioxide equivalent mass unit',
#   'carton mass',
#   'catalytic activity',
#   'catalytic activity concentration',
#   'catalytic activity concentration unit',
#   'catalytic activity unit',
#   'cause end of vase life',
#   'cause end of vase life abscised buds',
#   'cause end of vase life abscised flowers',
#   'cause end of vase life abscised leaves',
#   'cause end of vase life blue flowers',
#   'cause end of vase life Botrytis',
#   'cause end of vase life dry buds',
#   'cause end of vase life dry flowers',
#   'cause end of vase life dry leaves',
#   'cause end of vase life malformed buds',
#   'cause end of vase life malformed flowers',
#   'cause end of vase life nonturgid flowers',
#   'cause end of vase life nonturgid leaves',
#   'cause end of vase life rotten flowers',
#   'cause end of vase life rotten leaves',
#   'cause end of vase life wilted flowers',
#   'cause end of vase life wilted leaves',
#   'cause end of vase life yellow leaves',
#   'Celsius temperature',
#   'Celsius temperature scale',
#   'Celsius temperature unit',
#   'circumference',
#   'co-rotation radius',
#   'cold gas mass fraction',
#   'coliform bacteria count (specific)',
#   'coliform bacteria count (volumetric)',
#   'collision frequency',
#   'color area fraction',
#   'colour index',
#   'colour temperature',
#   'column number density',
#   'column number density unit',
#   'compound unit',
#   'compressive stress',
#   'contact angle',
#   'Corynebacterium bovis count (specific)',
#   'Corynebacterium bovis count (volumetric)',
#   'Corynebacterium count (specific)',
#   'Corynebacterium count (volumetric)',
#   'cosmological constant',
#   'cost',
#   'coverage',
#   'Cowling number',
#   'Cowling number unit',
#   'critical density',
#   'cubic prefixed metre',
#   'current density',
#   'current density unit',
#   'curvature constant',
#   'curvature constant unit',
#   'cut-off wavelength',
#   'Cousins magnitude',
#   'dark noise',
#   'date',
#   'deceleration parameter',
#   'deceleration parameter unit',
#   'declination',
#   'density',
#   'density parameter',
#   'density parameter for baryonic matter',
#   'density parameter for matter',
#   'density parameter for radiation',
#   'density parameter for vacuum',
#   'density parameter unit',
#   'depth',
#   'detective quantum efficiency',
#   'detectivity',
#   'detectivity unit',
#   'diameter',
#   'diameter (angle)',
#   'directional dose equivalent',
#   'disodium ethylene diamine tetra acetate mass fraction',
#   'distance',
#   'distance modulus',
#   'diurnal aberration',
#   'dose equivalent',
#   'dose equivalent unit',
#   'drainage speed',
#   'dry body mass',
#   'dry mass',
#   'dry matter mass fraction',
#   'duration',
#   'dynamic modulus',
#   'dynamic modulus unit',
#   'dynamic range',
#   'dynamic range unit',
#   'dynamic viscosity',
#   'dynamic viscosity unit',
#   'eccentricity',
#   'egg mass fraction',
#   'ecliptic latitude',
#   'ecliptic longitude',
#   'electric charge',
#   'electric charge density',
#   'electric charge density unit',
#   'electric charge unit',
#   'electric current',
#   'electric current unit',
#   'electric dipole moment',
#   'electric dipole moment unit',
#   'electric field',
#   'electric field unit',
#   'electric flux density',
#   'electric flux density unit',
#   'electric potential',
#   'electric potential unit',
#   'electrical conductance',
#   'electrical conductance unit',
#   'electrical conductivity',
#   'electrical conductivity unit',
#   'electrical resistance',
#   'electrical resistance unit',
#   'electrical resistivity',
#   'electrical resistivity unit',
#   'electron temperature',
#   'ellipticity',
#   'electromotive force',
#   'energy',
#   'energy density',
#   'energy density unit',
#   'energy unit',
#   'Enterobacteriaceae count (specific)',
#   'Enterobacteriaceae count (volumetric)',
#   'Enterococcus count (specific)',
#   'Enterococcus count (volumetric)',
#   'entropy',
#   'entropy unit',
#   'epoch',
#   'epoch at maximum brightness',
#   'Escherichia coli count (specific)',
#   'Escherichia coli count (volumetric)',
#   'Euler number',
#   'Euler number unit',
#   'exposure',
#   'exposure to x and γ rays',
#   'exposure to x and γ rays unit',
#   'exposure unit',
#   'extinction',
#   'extinction at waveband',
#   'extinction at wavelength',
#   'extinction in B',
#   'extinction in U',
#   'extinction in V',
#   'external browning',
#   'Fahrenheit temperature',
#   'Fahrenheit temperature scale',
#   'Fahrenheit temperature unit',
#   'fat mass fraction',
#   'firmness (penetrometer) (method 1)',
#   'firmness (penetrometer) (method 2)',
#   'first Cowling number',
#   'first Cowling number unit',
#   'fixed point',
#   'fixed zero point',
#   'fluidity',
#   'fluidity unit',
#   'flowpack mass',
#   'font size',
#   'font size unit',
#   'force',
#   'force unit',
#   'Fourier number',
#   'Fourier number for mass transfer',
#   'Fourier number for mass transfer unit',
#   'Fourier number unit',
#   'frequency',
#   'frequency unit',
#   'friction',
#   'Froude number',
#   'Froude number unit',
#   'g magnitude',
#   'galactic cylindrical polar angle coordinate',
#   'galactic latitude',
#   'galactic longitude',
#   'gas constant',
#   'gas constant unit',
#   'gelatin mass fraction',
#   'geometrical albedo',
#   'gram per prefixed litre',
#   'gravitational acceleration',
#   'Grashof number',
#   'Grashof number for mass transfer',
#   'Grashof number for mass transfer unit',
#   'Grashof number unit',
#   'guar gum mass fraction',
#   'half-life',
#   'Hartmann number',
#   'Hartmann number unit',
#   'heat',
#   'heat capacity',
#   'heat capacity unit',
#   'heat flow rate',
#   'heat flux density',
#   'heat transfer coefficient',
#   'heat transfer coefficient unit',
#   'height',
#   'hour angle',
#   'Hubble constant',
#   'Hubble constant at present epoch',
#   'Hubble constant unit',
#   'hydrophilicity',
#   'hydrophobicity',
#   'I magnitude',
#   'illuminance',
#   'illuminance unit',
#   'impulse',
#   'inductance',
#   'inductance unit',
#   'information capacity',
#   'information capacity unit',
#   'initial mass function',
#   'internal energy',
#   'interval scale',
#   'intrinsic colour index',
#   'ionization temperature',
#   'irradiance',
#   'Jeans mass',
#   'Johnson magnitude',
#   'kerma',
#   'kinematic viscosity',
#   'kinematic viscosity unit',
#   'kinetic energy',
#   'Klebsiella count (specific)',
#   'Klebsiella count (volumetric)',
#   'Knudsen number',
#   'Knudsen number unit',
#   'label mass',
#   'lactose mass fraction',
#   'length',
#   'length fraction',
#   'length unit',
#   'Lewis number',
#   'Lewis number unit',
#   'light time',
#   'limiting magnitude',
#   'linear strain',
#   'lipophilicity',
#   'Listeria monocytogenes count (specific)',
#   'Listeria monocytogenes count (volumetric)',
#   'locust bean gum mass fraction',
#   'loss modulus',
#   'luminance',
#   'luminance unit',
#   'luminosity function',
#   'luminous efficacy',
#   'luminous efficacy unit',
#   'luminous energy',
#   'luminous energy unit',
#   'luminous flux',
#   'luminous flux unit',
#   'luminous intensity',
#   'luminous intensity unit',
#   'Mach number',
#   'Mach number unit',
#   'magnetic field',
#   'magnetic field unit',
#   'magnetic flux',
#   'magnetic flux density',
#   'magnetic flux density unit',
#   'magnetic flux unit',
#   'magnetic Reynolds number',
#   'magnetic Reynolds number unit',
#   'magnetomotive force',
#   'magnetomotive force unit',
#   'magnitude',
#   'magnitude at maximum brightness',
#   'magnitude at minimum brightness',
#   'magnitude unit',
#   'manual firmness',
#   'mass',
#   'mass flow',
#   'mass flow unit',
#   'mass fraction',
#   'mass fraction unit',
#   'mass per energy',
#   'mass per energy unit',
#   'mass unit',
#   'metallicity',
#   'metre per prefixed second (time)',
#   'metre per prefixed second (time) squared',
#   'molar energy',
#   'molar energy unit',
#   'molar entropy',
#   'molar entropy unit',
#   'molar heat capacity',
#   'molar heat capacity unit',
#   'molar mass',
#   'molar mass unit',
#   'molar volume',
#   'molar volume unit',
#   'molality',
#   'molality unit',
#   'moment of force',
#   'moment of force unit',
#   'moment of inertia',
#   'moment of inertia unit',
#   'momentum',
#   'momentum unit',
#   'moderated starch mass fraction',
#   'mole per prefixed litre',
#   'mole per prefixed metre',
#   'mustard powder mass fraction',
#   'neck ring mass',
#   'noise equivalent power',
#   'normal albedo',
#   'normal stress',
#   'normal strain',
#   'normalised detectivity',
#   'Nusselt number',
#   'Nusselt number for mass transfer',
#   'Nusselt number for mass transfer unit',
#   'Nusselt number unit',
#   'number',
#   'number abscised buds',
#   'number abscised flowers',
#   'number abscised leaves',
#   'number blue-discolored flowers',
#   'number Botrytis',
#   'number Botrytis 0',
#   'number Botrytis 1',
#   'number Botrytis 2',
#   'number Botrytis 3',
#   'number Botrytis 4',
#   'number bud stadium',
#   'number bud stadium 1',
#   'number bud stadium 2',
#   'number bud stadium 3',
#   'number bud stadium 4',
#   'number bud stadium 5',
#   'number buds',
#   'number color',
#   'number color 1',
#   'number color 2',
#   'number color 3',
#   'number color 4',
#   'number color 5',
#   'number dry buds',
#   'number dry flowers',
#   'number dry leaves',
#   'number external browning',
#   'number external browning 1',
#   'number external browning 2',
#   'number external browning 3',
#   'number external browning 4',
#   'number external browning 5',
#   'number flowers',
#   'number leaves',
#   'number malformed buds',
#   'number malformed flowers',
#   'number manual firmness',
#   'number manual firmness 0',
#   'number manual firmness 0.5',
#   'number manual firmness 1',
#   'number manual firmness 1.5',
#   'number manual firmness 2',
#   'number manual firmness 2.5',
#   'number manual firmness 3',
#   'number manual firmness 3.5',
#   'number manual firmness 4',
#   'number manual firmness 4.5',
#   'number manual firmness 5',
#   'number nonturgid flowers',
#   'number nonturgid leaves',
#   'number pulp browning',
#   'number pulp browning 1',
#   'number pulp browning 2',
#   'number pulp browning 3',
#   'number pulp browning 4',
#   'number pulp browning 5',
#   'number rotten flowers',
#   'number rotten leaves',
#   'number unit',
#   'number vascular browning',
#   'number vascular browning 1',
#   'number vascular browning 2',
#   'number vascular browning 3',
#   'number vascular browning 4',
#   'number vascular browning 5',
#   'number wilted flowers',
#   'number wilted leaves',
#   'number yellow leaves',
#   'organ dose equivalent',
#   'overrun',
#   'Péclet number',
#   'Péclet number for mass transfer',
#   'Péclet number for mass transfer unit',
#   'Péclet number unit',
#   'percentage',
#   'percentage unit',
#   'period',
#   'period of variability',
#   'permeability (earth science)',
#   'permeability (earth science) unit',
#   'permeability of free space',
#   'permeability of free space unit',
#   'permeance (electromagnetic)',
#   'permeance (electromagnetic) unit',
#   'permeance (materials science)',
#   'permeance (materials science) unit',
#   'permittivity',
#   'permittivity unit',
#   'personal dose equivalent',
#   'photographic amplitude',
#   'photographic magnitude',
#   'photographic magnitude at maximum brightness',
#   'photographic magnitude at minimum brightness',
#   'pixel count',
#   'pixel count unit',
#   'planetary aberration',
#   'point',
#   'potassium sorbate mass fraction',
#   'potential difference',
#   'potential energy',
#   'power',
#   'power density',
#   'power density unit',
#   'power unit',
#   'Prandtl number',
#   'Prandtl number unit',
#   'prefix',
#   'prefixed ampere',
#   'prefixed are',
#   'prefixed becquerel',
#   'prefixed bit',
#   'prefixed calorie (mean)',
#   'prefixed candela',
#   'prefixed coulomb',
#   'prefixed degree Celsius',
#   'prefixed electronvolt',
#   'prefixed farad',
#   'prefixed gram',
#   'prefixed gram per litre',
#   'prefixed gram per prefixed litre',
#   'prefixed gray',
#   'prefixed henry',
#   'prefixed hertz',
#   'prefixed joule',
#   'prefixed katal',
#   'prefixed kelvin',
#   'prefixed litre',
#   'prefixed lumen',
#   'prefixed lux',
#   'prefixed metre',
#   'prefixed metre per prefixed secon (time) squared',
#   'prefixed metre per prefixed second (time)',
#   'prefixed metre per second (time)',
#   'prefixed metre per second (time) squared',
#   'prefixed molar',
#   'prefixed mole',
#   'prefixed mole per litre',
#   'prefixed mole per metre',
#   'prefixed mole per prefixed litre',
#   'prefixed mole per prefixed metre',
#   'prefixed newton',
#   'prefixed ohm',
#   'prefixed pascal',
#   'prefixed poise',
#   'prefixed radian',
#   'prefixed second (time)',
#   'prefixed second (time) squared',
#   'prefixed siemens',
#   'prefixed sievert',
#   'prefixed steradian',
#   'prefixed stokes',
#   'prefixed tesla',
#   'prefixed tonne',
#   'prefixed unified atomic mass unit',
#   'prefixed unit',
#   'prefixed volt',
#   'prefixed watt',
#   'prefixed weber',
#   'pressure',
#   'pressure unit',
#   'protein mass fraction',
#   'pulp browning',
#   'quality mark',
#   'quality mark flower(s)',
#   'quality mark leafs',
#   'quality mark total',
#   'quantity',
#   'quantity of dimension one',
#   'quantity of dimension one unit',
#   'quantum efficiency',
#   'quantum efficiency unit',
#   'R magnitude',
#   'radiance',
#   'radiance unit',
#   'radiant energy',
#   'radiant flux',
#   'radiant intensity',
#   'radiant intensity unit',
#   'radius',
#   'radius (angle)',
#   'Rankine temperature',
#   'Rankine temperature scale',
#   'Rankine temperature unit',
#   'ratio',
#   'ratio scale',
#   'ratio unit',
#   'Rayleigh number',
#   'Rayleigh number unit',
#   'red magnitude',
#   'reddening',
#   'reddening (B-V)',
#   'reddening (U-B)',
#   'reluctance',
#   'reluctance unit',
#   'relative humidity',
#   'relative humidity unit',
#   'Réaumur temperature',
#   'Réaumur temperature scale',
#   'Réaumur temperature unit',
#   'resonance energy',
#   'responsivity',
#   'responsivity unit',
#   'Reynolds number',
#   'Reynolds number unit',
#   'right ascension',
#   'salt mass fraction',
#   'salt strength',
#   'Salmonella count (specific)',
#   'Salmonella count (volumetric)',
#   'scale',
#   'scale factor',
#   'scale height',
#   'scale length',
#   'Schmidt number',
#   'Schmidt number unit',
#   'secular aberration',
#   'Serratia marcescens count (specific)',
#   'Serratia marcescens count (volumetric)',
#   'shear loss modulus',
#   'shear modulus',
#   'shear rate',
#   'shear rate unit',
#   'shear storage modulus',
#   'shear strain',
#   'shear stress',
#   'SI prefix',
#   'singular unit',
#   'slope',
#   'solid angle',
#   'solid angle unit',
#   'soy bean mass fraction',
#   'specific amount of money',
#   'specific amount of money unit',
#   'specific amylase activity',
#   'specific catalytic activity',
#   'specific catalytic activity unit',
#   'specific cost',
#   'specific energy',
#   'specific energy imparted',
#   'specific energy unit',
#   'specific entropy',
#   'specific entropy unit',
#   'specific heat capacity',
#   'specific heat capacity unit',
#   'specific protease activity',
#   'specific volume',
#   'specific volume unit',
#   'specific viable count unit',
#   'speed',
#   'speed unit',
#   'spectral response',
#   'square prefixed metre',
#   'Staphylococcus aureus count (specific)',
#   'Staphylococcus aureus count (volumetric)',
#   'Stanton number',
#   'Stanton number for mass transfer',
#   'Stanton number for mass transfer unit',
#   'Stanton number unit',
#   'starch mass fraction',
#   'starch VA40 mass fraction',
#   'starch VA85 mass fraction',
#   'stem end rot',
#   'stem end rot area fraction',
#   'stellar aberration',
#   'stick stone',
#   'storage modulus',
#   'strain',
#   'strain unit',
#   'strain tensor',
#   'straw mass',
#   'Streptococcus agalactiae count (specific)',
#   'Streptococcus agalactiae count (volumetric)',
#   'Streptococcus dysgalactiae count (specific)',
#   'Streptococcus dysgalactiae count (volumetric)',
#   'Streptococcus uberis count (specific)',
#   'Streptococcus uberis count (volumetric)',
#   'stress',
#   'stress unit',
#   'stress tensor',
#   'Strömgren magnitude',
#   'Strouhal number',
#   'Strouhal number unit',
#   'sugar mass fraction',
#   'supergalactic latitude',
#   'supergalactic longitude',
#   'surface tension',
#   'surface tension unit',
#   'symbol rate',
#   'symbol rate unit',
#   'temperature',
#   'temperature rate',
#   'temperature rate unit',
#   'temperature unit',
#   'Temperature_scale',
#   'thermal conductivity',
#   'thermal conductivity unit',
#   'thermal diffusivity',
#   'thermal diffusivity unit',
#   'thermal insulance',
#   'thermal insulance unit',
#   'thermal resistance',
#   'thermal resistance unit',
#   'thickness',
#   'Thuan and Gunn magnitude',
#   'thermodynamic temperature',
#   'thermodynamic temperature scale',
#   'thermodynamic temperature unit',
#   'time',
#   'time constant',
#   'time unit',
#   'top mass',
#   'torque',
#   'torque unit',
#   'total 3D start-end distance',
#   'total distance travelled',
#   'total number buds',
#   'total number flowers',
#   'total number leaves',
#   'true distance modulus',
#   'tween mass fraction',
#   'Tycho broadband magnitude',
#   'U magnitude',
#   'u magnitude',
#   'unit',
#   'unit division',
#   'unit exponentiation',
#   'unit multiplication',
#   'unit multiple',
#   'V amplitude',
#   'V magnitude',
#   'V magnitude at maximum brightness',
#   'V magnitude at minimum brightness',
#   'vase life',
#   'vase plus water mass',
#   'vase plus water plus flower mass',
#   'vascular browning',
#   'velocity',
#   'viable count',
#   'viable count (specific)',
#   'viable count (volumetric)',
#   'visual albedo',
#   'volume',
#   'volume fraction',
#   'volume fraction unit',
#   'volume unit',
#   'volume strain',
#   'volumetric heat capacity',
#   'volumetric heat capacity unit',
#   'volumetric flow rate',
#   'volumetric flow rate unit',
#   'volumetric viable count unit',
#   'water mass fraction',
#   'wavelength',
#   'wave number unit',
#   'Weber number',
#   'Weber number unit',
#   'weight',
#   'wetting angle',
#   'whey protein aggregate mass fraction',
#   'whey protein beads mass fraction',
#   'whey protein mass fraction',
#   'white light magnitude',
#   'white light magnitude at maximum brightness',
#   'white light magnitude at minimum brightness',
#   'width',
#   'work',
#   'xanthan mass fraction',
#   'x range',
#   'xy 2D start-end distance',
#   'xy distance travelled',
#   'y magnitude',
#   'yeast and fungi count (specific)',
#   'yeast and fungi count (volumetric)',
#   'z range',
#   'zenith distance']]

# %%
for cluser in clusters_list:
    print(len(cluser))
# Out:
# 773

# %%
model= "gemini-2.5-pro"

# %%
from tqdm import tqdm

response_final = []

# Assume 'final_output' is a list of clusters (e.g., [['Ocean', 'Sea', 'Water'], ['Glacier', 'Ice']])
# Assume 'domain' is a dictionary like {'domain_name': '...', 'domain_description': '...'}
# Assume 'client' and 'model' are already initialized

for i, term_cluster in tqdm(enumerate(clusters_list)):
    # This prompt asks the model to discover the relationship itself
    # instead of just checking against a predefined list.
    if len(term_cluster)>1:
        prompt = f"""You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning. Your task will be guided by a specific domain context provided to you.

    **Context (Provided as Input):**
    -   **Domain Name:** {domain['domain_name']}
    -   **Domain Description:** {domain['domain_description']}

    Your task is to take a single cluster of terms and discover all possible **parent-child relationship triples** (head, relation, tail) *between terms within that cluster*. A parent-child relationship can be either:
    *   **'is-a' (Type/Subtype):** Where the child term is a specific type of the parent term.
    *   **'part-of' (Whole/Part):** Where the child term is a component or part of the parent term.

    **Instructions:**

    1.  **Process the Cluster:**
        *   Examine all possible pairs of terms within the given input cluster.
        *   Using your knowledge of the **identified domain**, determine if a direct **parent-child ('is-a' or 'part-of') relationship** exists between them.
        *   If a relationship is found, create a triple `(head, relation, tail)`. The `relation` in the triple should be a string that describes the discovered relationship (e.g., 'is-a', 'part-of').
        *   Only include triples where both the `head` and `tail` are terms from the input cluster.

    2.  **Handle Special Cases:**
        *   If the cluster contains one or zero terms, return an empty list.
        *   If no parent-child relationships can be inferred for any pair in the cluster, return an empty list.

    3.  **Format the Output:**
        *   Return a Python list containing the generated triples, where each triple is a tuple.
        *   Each triple must be in the format `(head, relation, tail)`.
        *   Sort the final list of triples alphabetically by head, then by relation, and then by tail.

    **Task:**
    For the given cluster of terms, and guided by the provided domain context, discover and generate all possible parent-child relationship triples.

    -   **Cluster of Terms:** {term_cluster}

    Return the result as a Python list of triples.
    """
        print(len(prompt), model)
        generation_config = {"response_mime_type": "application/json"}
        
        # This print statement is for debugging the model object if needed
        # print(model) 

        response = client.models.generate_content(
                contents=prompt,
                config=generation_config,
                model=model
            )
            
        response_final.append(response.text)
        
        # Print progress every 10 iterations
        if i % 10 == 0:
            print(f"--- Response for cluster {i} ---")
            print(response.text)

    # After the loop, response_final will contain a list of JSON strings,
    # each string being a list of discovered triples for the corresponding cluster.
# Out:
# 0it [00:00, ?it/s]
# 20946 gemini-2.5-pro
# 1it [04:22, 262.18s/it]
# --- Response for cluster 0 ---
# [
#   [
#     "1040 nm Lockwood magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "Alfvén number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Alfvén number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "absolute bolometric magnitude",
#     "is-a",
#     "absolute magnitude"
#   ],
#   [
#     "absolute bolometric magnitude",
#     "is-a",
#     "bolometric magnitude"
#   ],
#   [
#     "absolute magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "absorbed dose rate unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "absorbed dose unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "acceleration unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "action unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "activity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "albedo",
#     "is-a",
#     "ratio"
#   ],
#   [
#     "altitude",
#     "is-a",
#     "angle"
#   ],
#   [
#     "amount of money unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "amount of substance concentration unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "amount of substance flow unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "amount of substance fraction",
#     "is-a",
#     "ratio"
#   ],
#   [
#     "amount of substance fraction unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "amount of substance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "angle unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "angular acceleration unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "angular displacement",
#     "is-a",
#     "angle"
#   ],
#   [
#     "angular momentum unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "angular size",
#     "is-a",
#     "diameter (angle)"
#   ],
#   [
#     "angular speed",
#     "is-a",
#     "speed"
#   ],
#   [
#     "angular speed unit",
#     "is-a",
#     "speed unit"
#   ],
#   [
#     "annual aberration",
#     "is-a",
#     "angle"
#   ],
#   [
#     "apparent diameter",
#     "is-a",
#     "diameter (angle)"
#   ],
#   [
#     "apparent distance modulus",
#     "is-a",
#     "distance modulus"
#   ],
#   [
#     "apparent magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "area density rate unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "area density unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "area fraction",
#     "is-a",
#     "ratio"
#   ],
#   [
#     "area fraction unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "area unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "atomic mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "average speed",
#     "is-a",
#     "speed"
#   ],
#   [
#     "azimuth",
#     "is-a",
#     "angle"
#   ],
#   [
#     "B magnitude",
#     "is-a",
#     "Johnson magnitude"
#   ],
#   [
#     "B magnitude at maximum brightness",
#     "is-a",
#     "B magnitude"
#   ],
#   [
#     "B magnitude at maximum brightness",
#     "is-a",
#     "magnitude at maximum brightness"
#   ],
#   [
#     "B magnitude at minimum brightness",
#     "is-a",
#     "B magnitude"
#   ],
#   [
#     "B magnitude at minimum brightness",
#     "is-a",
#     "magnitude at minimum brightness"
#   ],
#   [
#     "binary prefix",
#     "is-a",
#     "prefix"
#   ],
#   [
#     "body label mass",
#     "is-a",
#     "label mass"
#   ],
#   [
#     "body mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "bolometric correction",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "bolometric magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "bond albedo",
#     "is-a",
#     "albedo"
#   ],
#   [
#     "breadth",
#     "is-a",
#     "length"
#   ],
#   [
#     "brightness temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "bud stadium day 0",
#     "is-a",
#     "bud stadium"
#   ],
#   [
#     "bud stadium day 4",
#     "is-a",
#     "bud stadium"
#   ],
#   [
#     "bud stadium day 7",
#     "is-a",
#     "bud stadium"
#   ],
#   [
#     "cap mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "carbon dioxide equivalent mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "carbon dioxide equivalent mass per energy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "carbon dioxide equivalent mass unit",
#     "is-a",
#     "mass unit"
#   ],
#   [
#     "carton mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "catalytic activity concentration unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "catalytic activity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "cause end of vase life Botrytis",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life abscised buds",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life abscised flowers",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life abscised leaves",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life blue flowers",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life dry buds",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life dry flowers",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life dry leaves",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life malformed buds",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life malformed flowers",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life nonturgid flowers",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life nonturgid leaves",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life rotten flowers",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life rotten leaves",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life wilted flowers",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life wilted leaves",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "cause end of vase life yellow leaves",
#     "is-a",
#     "cause end of vase life"
#   ],
#   [
#     "Celsius temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "Celsius temperature scale",
#     "is-a",
#     "Temperature_scale"
#   ],
#   [
#     "Celsius temperature unit",
#     "is-a",
#     "temperature unit"
#   ],
#   [
#     "circumference",
#     "is-a",
#     "length"
#   ],
#   [
#     "co-rotation radius",
#     "is-a",
#     "radius"
#   ],
#   [
#     "cold gas mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "coliform bacteria count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "coliform bacteria count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "colour temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "column number density unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "compound unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "compressive stress",
#     "is-a",
#     "stress"
#   ],
#   [
#     "contact angle",
#     "is-a",
#     "angle"
#   ],
#   [
#     "Corynebacterium bovis count (specific)",
#     "is-a",
#     "Corynebacterium count (specific)"
#   ],
#   [
#     "Corynebacterium bovis count (volumetric)",
#     "is-a",
#     "Corynebacterium count (volumetric)"
#   ],
#   [
#     "Corynebacterium count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Corynebacterium count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "cost",
#     "is-a",
#     "amount of money"
#   ],
#   [
#     "Cowling number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Cowling number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "Cousins magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "cubic prefixed metre",
#     "is-a",
#     "prefixed metre"
#   ],
#   [
#     "cubic prefixed metre",
#     "is-a",
#     "volume unit"
#   ],
#   [
#     "current density unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "curvature constant unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "deceleration parameter unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "declination",
#     "is-a",
#     "angle"
#   ],
#   [
#     "density parameter for baryonic matter",
#     "is-a",
#     "density parameter"
#   ],
#   [
#     "density parameter for matter",
#     "is-a",
#     "density parameter"
#   ],
#   [
#     "density parameter for radiation",
#     "is-a",
#     "density parameter"
#   ],
#   [
#     "density parameter for vacuum",
#     "is-a",
#     "density parameter"
#   ],
#   [
#     "density parameter unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "depth",
#     "is-a",
#     "length"
#   ],
#   [
#     "detectivity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "diameter",
#     "is-a",
#     "length"
#   ],
#   [
#     "diameter (angle)",
#     "is-a",
#     "angle"
#   ],
#   [
#     "directional dose equivalent",
#     "is-a",
#     "dose equivalent"
#   ],
#   [
#     "disodium ethylene diamine tetra acetate mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "distance",
#     "is-a",
#     "length"
#   ],
#   [
#     "distance modulus",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "diurnal aberration",
#     "is-a",
#     "angle"
#   ],
#   [
#     "dose equivalent unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "drainage speed",
#     "is-a",
#     "speed"
#   ],
#   [
#     "dry body mass",
#     "is-a",
#     "body mass"
#   ],
#   [
#     "dry body mass",
#     "is-a",
#     "dry mass"
#   ],
#   [
#     "dry mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "dry matter mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "duration",
#     "is-a",
#     "time"
#   ],
#   [
#     "dynamic modulus unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "dynamic range unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "dynamic viscosity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "ecliptic latitude",
#     "is-a",
#     "angle"
#   ],
#   [
#     "ecliptic longitude",
#     "is-a",
#     "angle"
#   ],
#   [
#     "egg mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "electric charge density unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electric charge unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electric current unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electric dipole moment unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electric field unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electric flux density unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electric potential unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electrical conductance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electrical conductivity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electrical resistance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electrical resistivity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "electromotive force",
#     "is-a",
#     "electric potential"
#   ],
#   [
#     "electron temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "energy density unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "energy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Enterobacteriaceae count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Enterobacteriaceae count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "Enterococcus count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Enterococcus count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "entropy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "epoch",
#     "is-a",
#     "time"
#   ],
#   [
#     "epoch at maximum brightness",
#     "is-a",
#     "epoch"
#   ],
#   [
#     "Escherichia coli count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Escherichia coli count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "Euler number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Euler number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "exposure to x and γ rays",
#     "is-a",
#     "exposure"
#   ],
#   [
#     "exposure to x and γ rays unit",
#     "is-a",
#     "exposure unit"
#   ],
#   [
#     "exposure unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "extinction",
#     "is-a",
#     "quantity"
#   ],
#   [
#     "extinction at waveband",
#     "is-a",
#     "extinction"
#   ],
#   [
#     "extinction at wavelength",
#     "is-a",
#     "extinction"
#   ],
#   [
#     "extinction in B",
#     "is-a",
#     "extinction at waveband"
#   ],
#   [
#     "extinction in U",
#     "is-a",
#     "extinction at waveband"
#   ],
#   [
#     "extinction in V",
#     "is-a",
#     "extinction at waveband"
#   ],
#   [
#     "Fahrenheit temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "Fahrenheit temperature scale",
#     "is-a",
#     "Temperature_scale"
#   ],
#   [
#     "Fahrenheit temperature unit",
#     "is-a",
#     "temperature unit"
#   ],
#   [
#     "fat mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "first Cowling number",
#     "is-a",
#     "Cowling number"
#   ],
#   [
#     "first Cowling number unit",
#     "is-a",
#     "Cowling number unit"
#   ],
#   [
#     "fixed point",
#     "part-of",
#     "scale"
#   ],
#   [
#     "fixed zero point",
#     "part-of",
#     "interval scale"
#   ],
#   [
#     "flowpack mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "fluidity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "font size",
#     "is-a",
#     "length"
#   ],
#   [
#     "font size unit",
#     "is-a",
#     "length unit"
#   ],
#   [
#     "force unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Fourier number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Fourier number for mass transfer",
#     "is-a",
#     "Fourier number"
#   ],
#   [
#     "Fourier number for mass transfer unit",
#     "is-a",
#     "Fourier number unit"
#   ],
#   [
#     "Fourier number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "frequency unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Froude number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Froude number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "g magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "galactic cylindrical polar angle coordinate",
#     "is-a",
#     "angle"
#   ],
#   [
#     "galactic latitude",
#     "is-a",
#     "angle"
#   ],
#   [
#     "galactic longitude",
#     "is-a",
#     "angle"
#   ],
#   [
#     "gas constant unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "gelatin mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "geometrical albedo",
#     "is-a",
#     "albedo"
#   ],
#   [
#     "gram per prefixed litre",
#     "is-a",
#     "compound unit"
#   ],
#   [
#     "gravitational acceleration",
#     "is-a",
#     "acceleration"
#   ],
#   [
#     "Grashof number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Grashof number for mass transfer",
#     "is-a",
#     "Grashof number"
#   ],
#   [
#     "Grashof number for mass transfer unit",
#     "is-a",
#     "Grashof number unit"
#   ],
#   [
#     "Grashof number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "guar gum mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "half-life",
#     "is-a",
#     "time"
#   ],
#   [
#     "Hartmann number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Hartmann number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "heat",
#     "is-a",
#     "energy"
#   ],
#   [
#     "heat capacity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "heat transfer coefficient unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "height",
#     "is-a",
#     "length"
#   ],
#   [
#     "hour angle",
#     "is-a",
#     "angle"
#   ],
#   [
#     "Hubble constant at present epoch",
#     "is-a",
#     "Hubble constant"
#   ],
#   [
#     "Hubble constant unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "I magnitude",
#     "is-a",
#     "Johnson magnitude"
#   ],
#   [
#     "illuminance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "inductance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "information capacity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "internal energy",
#     "is-a",
#     "energy"
#   ],
#   [
#     "interval scale",
#     "is-a",
#     "scale"
#   ],
#   [
#     "intrinsic colour index",
#     "is-a",
#     "colour index"
#   ],
#   [
#     "ionization temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "Jeans mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "Johnson magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "kinematic viscosity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "kinetic energy",
#     "is-a",
#     "energy"
#   ],
#   [
#     "Klebsiella count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Klebsiella count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "Knudsen number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Knudsen number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "label mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "lactose mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "length fraction",
#     "is-a",
#     "ratio"
#   ],
#   [
#     "length unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Lewis number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Lewis number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "light time",
#     "is-a",
#     "time"
#   ],
#   [
#     "limiting magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "linear strain",
#     "is-a",
#     "strain"
#   ],
#   [
#     "Listeria monocytogenes count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Listeria monocytogenes count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "locust bean gum mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "luminance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "luminous efficacy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "luminous energy",
#     "is-a",
#     "energy"
#   ],
#   [
#     "luminous energy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "luminous flux unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "luminous intensity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Mach number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Mach number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "magnetic field unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "magnetic flux density unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "magnetic flux unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "magnetic Reynolds number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "magnetic Reynolds number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "magnetomotive force unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "magnitude at maximum brightness",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "magnitude at minimum brightness",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "magnitude unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "mass flow unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "mass fraction",
#     "is-a",
#     "ratio"
#   ],
#   [
#     "mass fraction unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "mass per energy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "mass unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "metre per prefixed second (time)",
#     "is-a",
#     "speed unit"
#   ],
#   [
#     "metre per prefixed second (time) squared",
#     "is-a",
#     "acceleration unit"
#   ],
#   [
#     "molar energy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "molar entropy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "molar heat capacity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "molar mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "molar mass unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "molar volume unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "molality unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "mole per prefixed litre",
#     "is-a",
#     "amount of substance concentration unit"
#   ],
#   [
#     "mole per prefixed metre",
#     "is-a",
#     "amount of substance concentration unit"
#   ],
#   [
#     "moment of force unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "moment of inertia unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "momentum unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "moderated starch mass fraction",
#     "is-a",
#     "starch mass fraction"
#   ],
#   [
#     "mustard powder mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "neck ring mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "normal albedo",
#     "is-a",
#     "albedo"
#   ],
#   [
#     "normal strain",
#     "is-a",
#     "strain"
#   ],
#   [
#     "normal strain",
#     "part-of",
#     "strain tensor"
#   ],
#   [
#     "normal stress",
#     "is-a",
#     "stress"
#   ],
#   [
#     "normal stress",
#     "part-of",
#     "stress tensor"
#   ],
#   [
#     "Nusselt number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Nusselt number for mass transfer",
#     "is-a",
#     "Nusselt number"
#   ],
#   [
#     "Nusselt number for mass transfer unit",
#     "is-a",
#     "Nusselt number unit"
#   ],
#   [
#     "Nusselt number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "number Botrytis 0",
#     "is-a",
#     "number Botrytis"
#   ],
#   [
#     "number Botrytis 1",
#     "is-a",
#     "number Botrytis"
#   ],
#   [
#     "number Botrytis 2",
#     "is-a",
#     "number Botrytis"
#   ],
#   [
#     "number Botrytis 3",
#     "is-a",
#     "number Botrytis"
#   ],
#   [
#     "number Botrytis 4",
#     "is-a",
#     "number Botrytis"
#   ],
#   [
#     "number bud stadium 1",
#     "is-a",
#     "number bud stadium"
#   ],
#   [
#     "number bud stadium 2",
#     "is-a",
#     "number bud stadium"
#   ],
#   [
#     "number bud stadium 3",
#     "is-a",
#     "number bud stadium"
#   ],
#   [
#     "number bud stadium 4",
#     "is-a",
#     "number bud stadium"
#   ],
#   [
#     "number bud stadium 5",
#     "is-a",
#     "number bud stadium"
#   ],
#   [
#     "number color 1",
#     "is-a",
#     "number color"
#   ],
#   [
#     "number color 2",
#     "is-a",
#     "number color"
#   ],
#   [
#     "number color 3",
#     "is-a",
#     "number color"
#   ],
#   [
#     "number color 4",
#     "is-a",
#     "number color"
#   ],
#   [
#     "number color 5",
#     "is-a",
#     "number color"
#   ],
#   [
#     "number external browning 1",
#     "is-a",
#     "number external browning"
#   ],
#   [
#     "number external browning 2",
#     "is-a",
#     "number external browning"
#   ],
#   [
#     "number external browning 3",
#     "is-a",
#     "number external browning"
#   ],
#   [
#     "number external browning 4",
#     "is-a",
#     "number external browning"
#   ],
#   [
#     "number external browning 5",
#     "is-a",
#     "number external browning"
#   ],
#   [
#     "number manual firmness 0",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 0.5",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 1",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 1.5",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 2",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 2.5",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 3",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 3.5",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 4",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 4.5",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number manual firmness 5",
#     "is-a",
#     "number manual firmness"
#   ],
#   [
#     "number pulp browning 1",
#     "is-a",
#     "number pulp browning"
#   ],
#   [
#     "number pulp browning 2",
#     "is-a",
#     "number pulp browning"
#   ],
#   [
#     "number pulp browning 3",
#     "is-a",
#     "number pulp browning"
#   ],
#   [
#     "number pulp browning 4",
#     "is-a",
#     "number pulp browning"
#   ],
#   [
#     "number pulp browning 5",
#     "is-a",
#     "number pulp browning"
#   ],
#   [
#     "number unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "number vascular browning 1",
#     "is-a",
#     "number vascular browning"
#   ],
#   [
#     "number vascular browning 2",
#     "is-a",
#     "number vascular browning"
#   ],
#   [
#     "number vascular browning 3",
#     "is-a",
#     "number vascular browning"
#   ],
#   [
#     "number vascular browning 4",
#     "is-a",
#     "number vascular browning"
#   ],
#   [
#     "number vascular browning 5",
#     "is-a",
#     "number vascular browning"
#   ],
#   [
#     "organ dose equivalent",
#     "is-a",
#     "dose equivalent"
#   ],
#   [
#     "Péclet number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Péclet number for mass transfer",
#     "is-a",
#     "Péclet number"
#   ],
#   [
#     "Péclet number for mass transfer unit",
#     "is-a",
#     "Péclet number unit"
#   ],
#   [
#     "Péclet number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "percentage",
#     "is-a",
#     "ratio"
#   ],
#   [
#     "percentage unit",
#     "is-a",
#     "ratio unit"
#   ],
#   [
#     "period",
#     "is-a",
#     "time"
#   ],
#   [
#     "period of variability",
#     "is-a",
#     "period"
#   ],
#   [
#     "permeability (earth science) unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "permeability of free space unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "permeance (electromagnetic) unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "permeance (materials science) unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "permittivity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "personal dose equivalent",
#     "is-a",
#     "dose equivalent"
#   ],
#   [
#     "photographic magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "photographic magnitude at maximum brightness",
#     "is-a",
#     "magnitude at maximum brightness"
#   ],
#   [
#     "photographic magnitude at maximum brightness",
#     "is-a",
#     "photographic magnitude"
#   ],
#   [
#     "photographic magnitude at minimum brightness",
#     "is-a",
#     "magnitude at minimum brightness"
#   ],
#   [
#     "photographic magnitude at minimum brightness",
#     "is-a",
#     "photographic magnitude"
#   ],
#   [
#     "pixel count",
#     "is-a",
#     "number"
#   ],
#   [
#     "pixel count unit",
#     "is-a",
#     "number unit"
#   ],
#   [
#     "planetary aberration",
#     "is-a",
#     "angle"
#   ],
#   [
#     "potential difference",
#     "is-a",
#     "electric potential"
#   ],
#   [
#     "potential energy",
#     "is-a",
#     "energy"
#   ],
#   [
#     "power density unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "power unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Prandtl number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Prandtl number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "prefixed ampere",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed are",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed becquerel",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed bit",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed calorie (mean)",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed candela",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed coulomb",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed degree Celsius",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed electronvolt",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed farad",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed gram",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed gram per litre",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed gram per prefixed litre",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed gray",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed henry",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed hertz",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed joule",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed katal",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed kelvin",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed litre",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed lumen",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed lux",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed metre",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed metre per prefixed second (time)",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed metre per second (time)",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed metre per second (time) squared",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed molar",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed mole",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed mole per litre",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed mole per metre",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed mole per prefixed litre",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed mole per prefixed metre",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed newton",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed ohm",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed pascal",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed poise",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed radian",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed second (time)",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed second (time) squared",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed siemens",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed sievert",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed steradian",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed stokes",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed tesla",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed tonne",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed unified atomic mass unit",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "prefixed volt",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed watt",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "prefixed weber",
#     "is-a",
#     "prefixed unit"
#   ],
#   [
#     "pressure unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "protein mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "quality mark flower(s)",
#     "is-a",
#     "quality mark"
#   ],
#   [
#     "quality mark leafs",
#     "is-a",
#     "quality mark"
#   ],
#   [
#     "quality mark total",
#     "is-a",
#     "quality mark"
#   ],
#   [
#     "quantity of dimension one",
#     "is-a",
#     "quantity"
#   ],
#   [
#     "quantity of dimension one unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "quantum efficiency unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "R magnitude",
#     "is-a",
#     "Johnson magnitude"
#   ],
#   [
#     "radiance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "radiant energy",
#     "is-a",
#     "energy"
#   ],
#   [
#     "radiant intensity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "radius",
#     "is-a",
#     "length"
#   ],
#   [
#     "radius (angle)",
#     "is-a",
#     "angle"
#   ],
#   [
#     "Rankine temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "Rankine temperature scale",
#     "is-a",
#     "Temperature_scale"
#   ],
#   [
#     "Rankine temperature unit",
#     "is-a",
#     "temperature unit"
#   ],
#   [
#     "ratio",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "ratio scale",
#     "is-a",
#     "scale"
#   ],
#   [
#     "ratio unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "Rayleigh number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Rayleigh number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "red magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "reddening",
#     "is-a",
#     "extinction"
#   ],
#   [
#     "reddening (B-V)",
#     "is-a",
#     "intrinsic colour index"
#   ],
#   [
#     "reddening (B-V)",
#     "is-a",
#     "reddening"
#   ],
#   [
#     "reddening (U-B)",
#     "is-a",
#     "intrinsic colour index"
#   ],
#   [
#     "reddening (U-B)",
#     "is-a",
#     "reddening"
#   ],
#   [
#     "reluctance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "relative humidity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "resonance energy",
#     "is-a",
#     "energy"
#   ],
#   [
#     "responsivity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Reynolds number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Reynolds number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "right ascension",
#     "is-a",
#     "angle"
#   ],
#   [
#     "Réaumur temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "Réaumur temperature scale",
#     "is-a",
#     "Temperature_scale"
#   ],
#   [
#     "Réaumur temperature unit",
#     "is-a",
#     "temperature unit"
#   ],
#   [
#     "SI prefix",
#     "is-a",
#     "prefix"
#   ],
#   [
#     "Salmonella count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Salmonella count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "salt mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "scale height",
#     "is-a",
#     "length"
#   ],
#   [
#     "scale length",
#     "is-a",
#     "length"
#   ],
#   [
#     "Schmidt number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Schmidt number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "secular aberration",
#     "is-a",
#     "angle"
#   ],
#   [
#     "Serratia marcescens count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Serratia marcescens count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "shear loss modulus",
#     "is-a",
#     "loss modulus"
#   ],
#   [
#     "shear rate unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "shear storage modulus",
#     "is-a",
#     "storage modulus"
#   ],
#   [
#     "shear strain",
#     "is-a",
#     "strain"
#   ],
#   [
#     "shear strain",
#     "part-of",
#     "strain tensor"
#   ],
#   [
#     "shear stress",
#     "is-a",
#     "stress"
#   ],
#   [
#     "shear stress",
#     "part-of",
#     "stress tensor"
#   ],
#   [
#     "singular unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "solid angle unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "soy bean mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "specific amount of money unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "specific catalytic activity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "specific energy imparted",
#     "is-a",
#     "specific energy"
#   ],
#   [
#     "specific energy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "specific entropy unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "specific heat capacity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "specific viable count unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "specific volume unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "speed unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "square prefixed metre",
#     "is-a",
#     "area unit"
#   ],
#   [
#     "square prefixed metre",
#     "is-a",
#     "prefixed metre"
#   ],
#   [
#     "Staphylococcus aureus count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Staphylococcus aureus count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "Stanton number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Stanton number for mass transfer",
#     "is-a",
#     "Stanton number"
#   ],
#   [
#     "Stanton number for mass transfer unit",
#     "is-a",
#     "Stanton number unit"
#   ],
#   [
#     "Stanton number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "starch VA40 mass fraction",
#     "is-a",
#     "starch mass fraction"
#   ],
#   [
#     "starch VA85 mass fraction",
#     "is-a",
#     "starch mass fraction"
#   ],
#   [
#     "starch mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "strain",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "strain unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "straw mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "Streptococcus agalactiae count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Streptococcus agalactiae count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "Streptococcus dysgalactiae count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Streptococcus dysgalactiae count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "Streptococcus uberis count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "Streptococcus uberis count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "stress unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Strömgren magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "Strouhal number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Strouhal number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "sugar mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "supergalactic latitude",
#     "is-a",
#     "angle"
#   ],
#   [
#     "supergalactic longitude",
#     "is-a",
#     "angle"
#   ],
#   [
#     "surface tension unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "symbol rate unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "temperature rate unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "temperature unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "Temperature_scale",
#     "is-a",
#     "scale"
#   ],
#   [
#     "thermal conductivity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "thermal diffusivity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "thermal insulance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "thermal resistance unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "thermodynamic temperature",
#     "is-a",
#     "temperature"
#   ],
#   [
#     "thermodynamic temperature scale",
#     "is-a",
#     "Temperature_scale"
#   ],
#   [
#     "thermodynamic temperature unit",
#     "is-a",
#     "temperature unit"
#   ],
#   [
#     "thickness",
#     "is-a",
#     "length"
#   ],
#   [
#     "Thuan and Gunn magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "time constant",
#     "is-a",
#     "time"
#   ],
#   [
#     "time unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "top mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "torque",
#     "is-a",
#     "moment of force"
#   ],
#   [
#     "torque unit",
#     "is-a",
#     "moment of force unit"
#   ],
#   [
#     "total number buds",
#     "is-a",
#     "number buds"
#   ],
#   [
#     "total number flowers",
#     "is-a",
#     "number flowers"
#   ],
#   [
#     "total number leaves",
#     "is-a",
#     "number leaves"
#   ],
#   [
#     "true distance modulus",
#     "is-a",
#     "distance modulus"
#   ],
#   [
#     "tween mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "Tycho broadband magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "U magnitude",
#     "is-a",
#     "Johnson magnitude"
#   ],
#   [
#     "u magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "V magnitude",
#     "is-a",
#     "Johnson magnitude"
#   ],
#   [
#     "V magnitude at maximum brightness",
#     "is-a",
#     "V magnitude"
#   ],
#   [
#     "V magnitude at maximum brightness",
#     "is-a",
#     "magnitude at maximum brightness"
#   ],
#   [
#     "V magnitude at minimum brightness",
#     "is-a",
#     "V magnitude"
#   ],
#   [
#     "V magnitude at minimum brightness",
#     "is-a",
#     "magnitude at minimum brightness"
#   ],
#   [
#     "vase plus water mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "vase plus water plus flower mass",
#     "is-a",
#     "mass"
#   ],
#   [
#     "viable count (specific)",
#     "is-a",
#     "viable count"
#   ],
#   [
#     "viable count (volumetric)",
#     "is-a",
#     "viable count"
#   ],
#   [
#     "visual albedo",
#     "is-a",
#     "albedo"
#   ],
#   [
#     "volume fraction",
#     "is-a",
#     "ratio"
#   ],
#   [
#     "volume fraction unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "volume strain",
#     "is-a",
#     "strain"
#   ],
#   [
#     "volume unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "volumetric heat capacity unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "volumetric flow rate unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "volumetric viable count unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "water mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "wave number unit",
#     "is-a",
#     "unit"
#   ],
#   [
#     "wavelength",
#     "is-a",
#     "length"
#   ],
#   [
#     "Weber number",
#     "is-a",
#     "quantity of dimension one"
#   ],
#   [
#     "Weber number unit",
#     "is-a",
#     "quantity of dimension one unit"
#   ],
#   [
#     "weight",
#     "is-a",
#     "force"
#   ],
#   [
#     "wetting angle",
#     "is-a",
#     "contact angle"
#   ],
#   [
#     "whey protein aggregate mass fraction",
#     "is-a",
#     "whey protein mass fraction"
#   ],
#   [
#     "whey protein beads mass fraction",
#     "is-a",
#     "whey protein mass fraction"
#   ],
#   [
#     "whey protein mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "white light magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "white light magnitude at maximum brightness",
#     "is-a",
#     "magnitude at maximum brightness"
#   ],
#   [
#     "white light magnitude at maximum brightness",
#     "is-a",
#     "white light magnitude"
#   ],
#   [
#     "white light magnitude at minimum brightness",
#     "is-a",
#     "magnitude at minimum brightness"
#   ],
#   [
#     "white light magnitude at minimum brightness",
#     "is-a",
#     "white light magnitude"
#   ],
#   [
#     "width",
#     "is-a",
#     "length"
#   ],
#   [
#     "work",
#     "is-a",
#     "energy"
#   ],
#   [
#     "xanthan mass fraction",
#     "is-a",
#     "mass fraction"
#   ],
#   [
#     "y magnitude",
#     "is-a",
#     "magnitude"
#   ],
#   [
#     "yeast and fungi count (specific)",
#     "is-a",
#     "viable count (specific)"
#   ],
#   [
#     "yeast and fungi count (volumetric)",
#     "is-a",
#     "viable count (volumetric)"
#   ],
#   [
#     "zenith distance",
#     "is-a",
#     "angle"
#   ],
#   [
#     "β_narrow magnitude",
#     "is-a",
#     "Strömgren magnitude"
#   ],
#   [
#     "β_wide magnitude",
#     "is-a",
#     "Strömgren magnitude"
#   ]
# ]

# %%
len(response_final)
# Out:
# 1

# %%
final_ans = []
for resp in response_final:
    resp_list = json.loads(resp)
    for lst in resp_list:
        final_ans.append({"child":lst[0], "parent":lst[-1]})

# %%
len(final_ans)
# Out:
# 571

# %%
final_ans
# Out:
# [{'child': '1040 nm Lockwood magnitude', 'parent': 'magnitude'},
#  {'child': 'Alfvén number', 'parent': 'quantity of dimension one'},
#  {'child': 'Alfvén number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'absolute bolometric magnitude', 'parent': 'absolute magnitude'},
#  {'child': 'absolute bolometric magnitude', 'parent': 'bolometric magnitude'},
#  {'child': 'absolute magnitude', 'parent': 'magnitude'},
#  {'child': 'absorbed dose rate unit', 'parent': 'unit'},
#  {'child': 'absorbed dose unit', 'parent': 'unit'},
#  {'child': 'acceleration unit', 'parent': 'unit'},
#  {'child': 'action unit', 'parent': 'unit'},
#  {'child': 'activity unit', 'parent': 'unit'},
#  {'child': 'albedo', 'parent': 'ratio'},
#  {'child': 'altitude', 'parent': 'angle'},
#  {'child': 'amount of money unit', 'parent': 'unit'},
#  {'child': 'amount of substance concentration unit', 'parent': 'unit'},
#  {'child': 'amount of substance flow unit', 'parent': 'unit'},
#  {'child': 'amount of substance fraction', 'parent': 'ratio'},
#  {'child': 'amount of substance fraction unit', 'parent': 'unit'},
#  {'child': 'amount of substance unit', 'parent': 'unit'},
#  {'child': 'angle unit', 'parent': 'unit'},
#  {'child': 'angular acceleration unit', 'parent': 'unit'},
#  {'child': 'angular displacement', 'parent': 'angle'},
#  {'child': 'angular momentum unit', 'parent': 'unit'},
#  {'child': 'angular size', 'parent': 'diameter (angle)'},
#  {'child': 'angular speed', 'parent': 'speed'},
#  {'child': 'angular speed unit', 'parent': 'speed unit'},
#  {'child': 'annual aberration', 'parent': 'angle'},
#  {'child': 'apparent diameter', 'parent': 'diameter (angle)'},
#  {'child': 'apparent distance modulus', 'parent': 'distance modulus'},
#  {'child': 'apparent magnitude', 'parent': 'magnitude'},
#  {'child': 'area density rate unit', 'parent': 'unit'},
#  {'child': 'area density unit', 'parent': 'unit'},
#  {'child': 'area fraction', 'parent': 'ratio'},
#  {'child': 'area fraction unit', 'parent': 'unit'},
#  {'child': 'area unit', 'parent': 'unit'},
#  {'child': 'atomic mass', 'parent': 'mass'},
#  {'child': 'average speed', 'parent': 'speed'},
#  {'child': 'azimuth', 'parent': 'angle'},
#  {'child': 'B magnitude', 'parent': 'Johnson magnitude'},
#  {'child': 'B magnitude at maximum brightness', 'parent': 'B magnitude'},
#  {'child': 'B magnitude at maximum brightness',
#   'parent': 'magnitude at maximum brightness'},
#  {'child': 'B magnitude at minimum brightness', 'parent': 'B magnitude'},
#  {'child': 'B magnitude at minimum brightness',
#   'parent': 'magnitude at minimum brightness'},
#  {'child': 'binary prefix', 'parent': 'prefix'},
#  {'child': 'body label mass', 'parent': 'label mass'},
#  {'child': 'body mass', 'parent': 'mass'},
#  {'child': 'bolometric correction', 'parent': 'magnitude'},
#  {'child': 'bolometric magnitude', 'parent': 'magnitude'},
#  {'child': 'bond albedo', 'parent': 'albedo'},
#  {'child': 'breadth', 'parent': 'length'},
#  {'child': 'brightness temperature', 'parent': 'temperature'},
#  {'child': 'bud stadium day 0', 'parent': 'bud stadium'},
#  {'child': 'bud stadium day 4', 'parent': 'bud stadium'},
#  {'child': 'bud stadium day 7', 'parent': 'bud stadium'},
#  {'child': 'cap mass', 'parent': 'mass'},
#  {'child': 'carbon dioxide equivalent mass', 'parent': 'mass'},
#  {'child': 'carbon dioxide equivalent mass per energy unit', 'parent': 'unit'},
#  {'child': 'carbon dioxide equivalent mass unit', 'parent': 'mass unit'},
#  {'child': 'carton mass', 'parent': 'mass'},
#  {'child': 'catalytic activity concentration unit', 'parent': 'unit'},
#  {'child': 'catalytic activity unit', 'parent': 'unit'},
#  {'child': 'cause end of vase life Botrytis',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life abscised buds',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life abscised flowers',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life abscised leaves',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life blue flowers',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life dry buds',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life dry flowers',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life dry leaves',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life malformed buds',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life malformed flowers',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life nonturgid flowers',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life nonturgid leaves',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life rotten flowers',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life rotten leaves',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life wilted flowers',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life wilted leaves',
#   'parent': 'cause end of vase life'},
#  {'child': 'cause end of vase life yellow leaves',
#   'parent': 'cause end of vase life'},
#  {'child': 'Celsius temperature', 'parent': 'temperature'},
#  {'child': 'Celsius temperature scale', 'parent': 'Temperature_scale'},
#  {'child': 'Celsius temperature unit', 'parent': 'temperature unit'},
#  {'child': 'circumference', 'parent': 'length'},
#  {'child': 'co-rotation radius', 'parent': 'radius'},
#  {'child': 'cold gas mass fraction', 'parent': 'mass fraction'},
#  {'child': 'coliform bacteria count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'coliform bacteria count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'colour temperature', 'parent': 'temperature'},
#  {'child': 'column number density unit', 'parent': 'unit'},
#  {'child': 'compound unit', 'parent': 'unit'},
#  {'child': 'compressive stress', 'parent': 'stress'},
#  {'child': 'contact angle', 'parent': 'angle'},
#  {'child': 'Corynebacterium bovis count (specific)',
#   'parent': 'Corynebacterium count (specific)'},
#  {'child': 'Corynebacterium bovis count (volumetric)',
#   'parent': 'Corynebacterium count (volumetric)'},
#  {'child': 'Corynebacterium count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Corynebacterium count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'cost', 'parent': 'amount of money'},
#  {'child': 'Cowling number', 'parent': 'quantity of dimension one'},
#  {'child': 'Cowling number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'Cousins magnitude', 'parent': 'magnitude'},
#  {'child': 'cubic prefixed metre', 'parent': 'prefixed metre'},
#  {'child': 'cubic prefixed metre', 'parent': 'volume unit'},
#  {'child': 'current density unit', 'parent': 'unit'},
#  {'child': 'curvature constant unit', 'parent': 'unit'},
#  {'child': 'deceleration parameter unit', 'parent': 'unit'},
#  {'child': 'declination', 'parent': 'angle'},
#  {'child': 'density parameter for baryonic matter',
#   'parent': 'density parameter'},
#  {'child': 'density parameter for matter', 'parent': 'density parameter'},
#  {'child': 'density parameter for radiation', 'parent': 'density parameter'},
#  {'child': 'density parameter for vacuum', 'parent': 'density parameter'},
#  {'child': 'density parameter unit', 'parent': 'unit'},
#  {'child': 'depth', 'parent': 'length'},
#  {'child': 'detectivity unit', 'parent': 'unit'},
#  {'child': 'diameter', 'parent': 'length'},
#  {'child': 'diameter (angle)', 'parent': 'angle'},
#  {'child': 'directional dose equivalent', 'parent': 'dose equivalent'},
#  {'child': 'disodium ethylene diamine tetra acetate mass fraction',
#   'parent': 'mass fraction'},
#  {'child': 'distance', 'parent': 'length'},
#  {'child': 'distance modulus', 'parent': 'magnitude'},
#  {'child': 'diurnal aberration', 'parent': 'angle'},
#  {'child': 'dose equivalent unit', 'parent': 'unit'},
#  {'child': 'drainage speed', 'parent': 'speed'},
#  {'child': 'dry body mass', 'parent': 'body mass'},
#  {'child': 'dry body mass', 'parent': 'dry mass'},
#  {'child': 'dry mass', 'parent': 'mass'},
#  {'child': 'dry matter mass fraction', 'parent': 'mass fraction'},
#  {'child': 'duration', 'parent': 'time'},
#  {'child': 'dynamic modulus unit', 'parent': 'unit'},
#  {'child': 'dynamic range unit', 'parent': 'unit'},
#  {'child': 'dynamic viscosity unit', 'parent': 'unit'},
#  {'child': 'ecliptic latitude', 'parent': 'angle'},
#  {'child': 'ecliptic longitude', 'parent': 'angle'},
#  {'child': 'egg mass fraction', 'parent': 'mass fraction'},
#  {'child': 'electric charge density unit', 'parent': 'unit'},
#  {'child': 'electric charge unit', 'parent': 'unit'},
#  {'child': 'electric current unit', 'parent': 'unit'},
#  {'child': 'electric dipole moment unit', 'parent': 'unit'},
#  {'child': 'electric field unit', 'parent': 'unit'},
#  {'child': 'electric flux density unit', 'parent': 'unit'},
#  {'child': 'electric potential unit', 'parent': 'unit'},
#  {'child': 'electrical conductance unit', 'parent': 'unit'},
#  {'child': 'electrical conductivity unit', 'parent': 'unit'},
#  {'child': 'electrical resistance unit', 'parent': 'unit'},
#  {'child': 'electrical resistivity unit', 'parent': 'unit'},
#  {'child': 'electromotive force', 'parent': 'electric potential'},
#  {'child': 'electron temperature', 'parent': 'temperature'},
#  {'child': 'energy density unit', 'parent': 'unit'},
#  {'child': 'energy unit', 'parent': 'unit'},
#  {'child': 'Enterobacteriaceae count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Enterobacteriaceae count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'Enterococcus count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Enterococcus count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'entropy unit', 'parent': 'unit'},
#  {'child': 'epoch', 'parent': 'time'},
#  {'child': 'epoch at maximum brightness', 'parent': 'epoch'},
#  {'child': 'Escherichia coli count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Escherichia coli count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'Euler number', 'parent': 'quantity of dimension one'},
#  {'child': 'Euler number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'exposure to x and γ rays', 'parent': 'exposure'},
#  {'child': 'exposure to x and γ rays unit', 'parent': 'exposure unit'},
#  {'child': 'exposure unit', 'parent': 'unit'},
#  {'child': 'extinction', 'parent': 'quantity'},
#  {'child': 'extinction at waveband', 'parent': 'extinction'},
#  {'child': 'extinction at wavelength', 'parent': 'extinction'},
#  {'child': 'extinction in B', 'parent': 'extinction at waveband'},
#  {'child': 'extinction in U', 'parent': 'extinction at waveband'},
#  {'child': 'extinction in V', 'parent': 'extinction at waveband'},
#  {'child': 'Fahrenheit temperature', 'parent': 'temperature'},
#  {'child': 'Fahrenheit temperature scale', 'parent': 'Temperature_scale'},
#  {'child': 'Fahrenheit temperature unit', 'parent': 'temperature unit'},
#  {'child': 'fat mass fraction', 'parent': 'mass fraction'},
#  {'child': 'first Cowling number', 'parent': 'Cowling number'},
#  {'child': 'first Cowling number unit', 'parent': 'Cowling number unit'},
#  {'child': 'fixed point', 'parent': 'scale'},
#  {'child': 'fixed zero point', 'parent': 'interval scale'},
#  {'child': 'flowpack mass', 'parent': 'mass'},
#  {'child': 'fluidity unit', 'parent': 'unit'},
#  {'child': 'font size', 'parent': 'length'},
#  {'child': 'font size unit', 'parent': 'length unit'},
#  {'child': 'force unit', 'parent': 'unit'},
#  {'child': 'Fourier number', 'parent': 'quantity of dimension one'},
#  {'child': 'Fourier number for mass transfer', 'parent': 'Fourier number'},
#  {'child': 'Fourier number for mass transfer unit',
#   'parent': 'Fourier number unit'},
#  {'child': 'Fourier number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'frequency unit', 'parent': 'unit'},
#  {'child': 'Froude number', 'parent': 'quantity of dimension one'},
#  {'child': 'Froude number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'g magnitude', 'parent': 'magnitude'},
#  {'child': 'galactic cylindrical polar angle coordinate', 'parent': 'angle'},
#  {'child': 'galactic latitude', 'parent': 'angle'},
#  {'child': 'galactic longitude', 'parent': 'angle'},
#  {'child': 'gas constant unit', 'parent': 'unit'},
#  {'child': 'gelatin mass fraction', 'parent': 'mass fraction'},
#  {'child': 'geometrical albedo', 'parent': 'albedo'},
#  {'child': 'gram per prefixed litre', 'parent': 'compound unit'},
#  {'child': 'gravitational acceleration', 'parent': 'acceleration'},
#  {'child': 'Grashof number', 'parent': 'quantity of dimension one'},
#  {'child': 'Grashof number for mass transfer', 'parent': 'Grashof number'},
#  {'child': 'Grashof number for mass transfer unit',
#   'parent': 'Grashof number unit'},
#  {'child': 'Grashof number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'guar gum mass fraction', 'parent': 'mass fraction'},
#  {'child': 'half-life', 'parent': 'time'},
#  {'child': 'Hartmann number', 'parent': 'quantity of dimension one'},
#  {'child': 'Hartmann number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'heat', 'parent': 'energy'},
#  {'child': 'heat capacity unit', 'parent': 'unit'},
#  {'child': 'heat transfer coefficient unit', 'parent': 'unit'},
#  {'child': 'height', 'parent': 'length'},
#  {'child': 'hour angle', 'parent': 'angle'},
#  {'child': 'Hubble constant at present epoch', 'parent': 'Hubble constant'},
#  {'child': 'Hubble constant unit', 'parent': 'unit'},
#  {'child': 'I magnitude', 'parent': 'Johnson magnitude'},
#  {'child': 'illuminance unit', 'parent': 'unit'},
#  {'child': 'inductance unit', 'parent': 'unit'},
#  {'child': 'information capacity unit', 'parent': 'unit'},
#  {'child': 'internal energy', 'parent': 'energy'},
#  {'child': 'interval scale', 'parent': 'scale'},
#  {'child': 'intrinsic colour index', 'parent': 'colour index'},
#  {'child': 'ionization temperature', 'parent': 'temperature'},
#  {'child': 'Jeans mass', 'parent': 'mass'},
#  {'child': 'Johnson magnitude', 'parent': 'magnitude'},
#  {'child': 'kinematic viscosity unit', 'parent': 'unit'},
#  {'child': 'kinetic energy', 'parent': 'energy'},
#  {'child': 'Klebsiella count (specific)', 'parent': 'viable count (specific)'},
#  {'child': 'Klebsiella count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'Knudsen number', 'parent': 'quantity of dimension one'},
#  {'child': 'Knudsen number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'label mass', 'parent': 'mass'},
#  {'child': 'lactose mass fraction', 'parent': 'mass fraction'},
#  {'child': 'length fraction', 'parent': 'ratio'},
#  {'child': 'length unit', 'parent': 'unit'},
#  {'child': 'Lewis number', 'parent': 'quantity of dimension one'},
#  {'child': 'Lewis number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'light time', 'parent': 'time'},
#  {'child': 'limiting magnitude', 'parent': 'magnitude'},
#  {'child': 'linear strain', 'parent': 'strain'},
#  {'child': 'Listeria monocytogenes count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Listeria monocytogenes count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'locust bean gum mass fraction', 'parent': 'mass fraction'},
#  {'child': 'luminance unit', 'parent': 'unit'},
#  {'child': 'luminous efficacy unit', 'parent': 'unit'},
#  {'child': 'luminous energy', 'parent': 'energy'},
#  {'child': 'luminous energy unit', 'parent': 'unit'},
#  {'child': 'luminous flux unit', 'parent': 'unit'},
#  {'child': 'luminous intensity unit', 'parent': 'unit'},
#  {'child': 'Mach number', 'parent': 'quantity of dimension one'},
#  {'child': 'Mach number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'magnetic field unit', 'parent': 'unit'},
#  {'child': 'magnetic flux density unit', 'parent': 'unit'},
#  {'child': 'magnetic flux unit', 'parent': 'unit'},
#  {'child': 'magnetic Reynolds number', 'parent': 'quantity of dimension one'},
#  {'child': 'magnetic Reynolds number unit',
#   'parent': 'quantity of dimension one unit'},
#  {'child': 'magnetomotive force unit', 'parent': 'unit'},
#  {'child': 'magnitude at maximum brightness', 'parent': 'magnitude'},
#  {'child': 'magnitude at minimum brightness', 'parent': 'magnitude'},
#  {'child': 'magnitude unit', 'parent': 'unit'},
#  {'child': 'mass flow unit', 'parent': 'unit'},
#  {'child': 'mass fraction', 'parent': 'ratio'},
#  {'child': 'mass fraction unit', 'parent': 'unit'},
#  {'child': 'mass per energy unit', 'parent': 'unit'},
#  {'child': 'mass unit', 'parent': 'unit'},
#  {'child': 'metre per prefixed second (time)', 'parent': 'speed unit'},
#  {'child': 'metre per prefixed second (time) squared',
#   'parent': 'acceleration unit'},
#  {'child': 'molar energy unit', 'parent': 'unit'},
#  {'child': 'molar entropy unit', 'parent': 'unit'},
#  {'child': 'molar heat capacity unit', 'parent': 'unit'},
#  {'child': 'molar mass', 'parent': 'mass'},
#  {'child': 'molar mass unit', 'parent': 'unit'},
#  {'child': 'molar volume unit', 'parent': 'unit'},
#  {'child': 'molality unit', 'parent': 'unit'},
#  {'child': 'mole per prefixed litre',
#   'parent': 'amount of substance concentration unit'},
#  {'child': 'mole per prefixed metre',
#   'parent': 'amount of substance concentration unit'},
#  {'child': 'moment of force unit', 'parent': 'unit'},
#  {'child': 'moment of inertia unit', 'parent': 'unit'},
#  {'child': 'momentum unit', 'parent': 'unit'},
#  {'child': 'moderated starch mass fraction', 'parent': 'starch mass fraction'},
#  {'child': 'mustard powder mass fraction', 'parent': 'mass fraction'},
#  {'child': 'neck ring mass', 'parent': 'mass'},
#  {'child': 'normal albedo', 'parent': 'albedo'},
#  {'child': 'normal strain', 'parent': 'strain'},
#  {'child': 'normal strain', 'parent': 'strain tensor'},
#  {'child': 'normal stress', 'parent': 'stress'},
#  {'child': 'normal stress', 'parent': 'stress tensor'},
#  {'child': 'Nusselt number', 'parent': 'quantity of dimension one'},
#  {'child': 'Nusselt number for mass transfer', 'parent': 'Nusselt number'},
#  {'child': 'Nusselt number for mass transfer unit',
#   'parent': 'Nusselt number unit'},
#  {'child': 'Nusselt number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'number Botrytis 0', 'parent': 'number Botrytis'},
#  {'child': 'number Botrytis 1', 'parent': 'number Botrytis'},
#  {'child': 'number Botrytis 2', 'parent': 'number Botrytis'},
#  {'child': 'number Botrytis 3', 'parent': 'number Botrytis'},
#  {'child': 'number Botrytis 4', 'parent': 'number Botrytis'},
#  {'child': 'number bud stadium 1', 'parent': 'number bud stadium'},
#  {'child': 'number bud stadium 2', 'parent': 'number bud stadium'},
#  {'child': 'number bud stadium 3', 'parent': 'number bud stadium'},
#  {'child': 'number bud stadium 4', 'parent': 'number bud stadium'},
#  {'child': 'number bud stadium 5', 'parent': 'number bud stadium'},
#  {'child': 'number color 1', 'parent': 'number color'},
#  {'child': 'number color 2', 'parent': 'number color'},
#  {'child': 'number color 3', 'parent': 'number color'},
#  {'child': 'number color 4', 'parent': 'number color'},
#  {'child': 'number color 5', 'parent': 'number color'},
#  {'child': 'number external browning 1', 'parent': 'number external browning'},
#  {'child': 'number external browning 2', 'parent': 'number external browning'},
#  {'child': 'number external browning 3', 'parent': 'number external browning'},
#  {'child': 'number external browning 4', 'parent': 'number external browning'},
#  {'child': 'number external browning 5', 'parent': 'number external browning'},
#  {'child': 'number manual firmness 0', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 0.5', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 1', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 1.5', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 2', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 2.5', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 3', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 3.5', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 4', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 4.5', 'parent': 'number manual firmness'},
#  {'child': 'number manual firmness 5', 'parent': 'number manual firmness'},
#  {'child': 'number pulp browning 1', 'parent': 'number pulp browning'},
#  {'child': 'number pulp browning 2', 'parent': 'number pulp browning'},
#  {'child': 'number pulp browning 3', 'parent': 'number pulp browning'},
#  {'child': 'number pulp browning 4', 'parent': 'number pulp browning'},
#  {'child': 'number pulp browning 5', 'parent': 'number pulp browning'},
#  {'child': 'number unit', 'parent': 'unit'},
#  {'child': 'number vascular browning 1', 'parent': 'number vascular browning'},
#  {'child': 'number vascular browning 2', 'parent': 'number vascular browning'},
#  {'child': 'number vascular browning 3', 'parent': 'number vascular browning'},
#  {'child': 'number vascular browning 4', 'parent': 'number vascular browning'},
#  {'child': 'number vascular browning 5', 'parent': 'number vascular browning'},
#  {'child': 'organ dose equivalent', 'parent': 'dose equivalent'},
#  {'child': 'Péclet number', 'parent': 'quantity of dimension one'},
#  {'child': 'Péclet number for mass transfer', 'parent': 'Péclet number'},
#  {'child': 'Péclet number for mass transfer unit',
#   'parent': 'Péclet number unit'},
#  {'child': 'Péclet number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'percentage', 'parent': 'ratio'},
#  {'child': 'percentage unit', 'parent': 'ratio unit'},
#  {'child': 'period', 'parent': 'time'},
#  {'child': 'period of variability', 'parent': 'period'},
#  {'child': 'permeability (earth science) unit', 'parent': 'unit'},
#  {'child': 'permeability of free space unit', 'parent': 'unit'},
#  {'child': 'permeance (electromagnetic) unit', 'parent': 'unit'},
#  {'child': 'permeance (materials science) unit', 'parent': 'unit'},
#  {'child': 'permittivity unit', 'parent': 'unit'},
#  {'child': 'personal dose equivalent', 'parent': 'dose equivalent'},
#  {'child': 'photographic magnitude', 'parent': 'magnitude'},
#  {'child': 'photographic magnitude at maximum brightness',
#   'parent': 'magnitude at maximum brightness'},
#  {'child': 'photographic magnitude at maximum brightness',
#   'parent': 'photographic magnitude'},
#  {'child': 'photographic magnitude at minimum brightness',
#   'parent': 'magnitude at minimum brightness'},
#  {'child': 'photographic magnitude at minimum brightness',
#   'parent': 'photographic magnitude'},
#  {'child': 'pixel count', 'parent': 'number'},
#  {'child': 'pixel count unit', 'parent': 'number unit'},
#  {'child': 'planetary aberration', 'parent': 'angle'},
#  {'child': 'potential difference', 'parent': 'electric potential'},
#  {'child': 'potential energy', 'parent': 'energy'},
#  {'child': 'power density unit', 'parent': 'unit'},
#  {'child': 'power unit', 'parent': 'unit'},
#  {'child': 'Prandtl number', 'parent': 'quantity of dimension one'},
#  {'child': 'Prandtl number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'prefixed ampere', 'parent': 'prefixed unit'},
#  {'child': 'prefixed are', 'parent': 'prefixed unit'},
#  {'child': 'prefixed becquerel', 'parent': 'prefixed unit'},
#  {'child': 'prefixed bit', 'parent': 'prefixed unit'},
#  {'child': 'prefixed calorie (mean)', 'parent': 'prefixed unit'},
#  {'child': 'prefixed candela', 'parent': 'prefixed unit'},
#  {'child': 'prefixed coulomb', 'parent': 'prefixed unit'},
#  {'child': 'prefixed degree Celsius', 'parent': 'prefixed unit'},
#  {'child': 'prefixed electronvolt', 'parent': 'prefixed unit'},
#  {'child': 'prefixed farad', 'parent': 'prefixed unit'},
#  {'child': 'prefixed gram', 'parent': 'prefixed unit'},
#  {'child': 'prefixed gram per litre', 'parent': 'prefixed unit'},
#  {'child': 'prefixed gram per prefixed litre', 'parent': 'prefixed unit'},
#  {'child': 'prefixed gray', 'parent': 'prefixed unit'},
#  {'child': 'prefixed henry', 'parent': 'prefixed unit'},
#  {'child': 'prefixed hertz', 'parent': 'prefixed unit'},
#  {'child': 'prefixed joule', 'parent': 'prefixed unit'},
#  {'child': 'prefixed katal', 'parent': 'prefixed unit'},
#  {'child': 'prefixed kelvin', 'parent': 'prefixed unit'},
#  {'child': 'prefixed litre', 'parent': 'prefixed unit'},
#  {'child': 'prefixed lumen', 'parent': 'prefixed unit'},
#  {'child': 'prefixed lux', 'parent': 'prefixed unit'},
#  {'child': 'prefixed metre', 'parent': 'prefixed unit'},
#  {'child': 'prefixed metre per prefixed second (time)',
#   'parent': 'prefixed unit'},
#  {'child': 'prefixed metre per second (time)', 'parent': 'prefixed unit'},
#  {'child': 'prefixed metre per second (time) squared',
#   'parent': 'prefixed unit'},
#  {'child': 'prefixed molar', 'parent': 'prefixed unit'},
#  {'child': 'prefixed mole', 'parent': 'prefixed unit'},
#  {'child': 'prefixed mole per litre', 'parent': 'prefixed unit'},
#  {'child': 'prefixed mole per metre', 'parent': 'prefixed unit'},
#  {'child': 'prefixed mole per prefixed litre', 'parent': 'prefixed unit'},
#  {'child': 'prefixed mole per prefixed metre', 'parent': 'prefixed unit'},
#  {'child': 'prefixed newton', 'parent': 'prefixed unit'},
#  {'child': 'prefixed ohm', 'parent': 'prefixed unit'},
#  {'child': 'prefixed pascal', 'parent': 'prefixed unit'},
#  {'child': 'prefixed poise', 'parent': 'prefixed unit'},
#  {'child': 'prefixed radian', 'parent': 'prefixed unit'},
#  {'child': 'prefixed second (time)', 'parent': 'prefixed unit'},
#  {'child': 'prefixed second (time) squared', 'parent': 'prefixed unit'},
#  {'child': 'prefixed siemens', 'parent': 'prefixed unit'},
#  {'child': 'prefixed sievert', 'parent': 'prefixed unit'},
#  {'child': 'prefixed steradian', 'parent': 'prefixed unit'},
#  {'child': 'prefixed stokes', 'parent': 'prefixed unit'},
#  {'child': 'prefixed tesla', 'parent': 'prefixed unit'},
#  {'child': 'prefixed tonne', 'parent': 'prefixed unit'},
#  {'child': 'prefixed unified atomic mass unit', 'parent': 'prefixed unit'},
#  {'child': 'prefixed unit', 'parent': 'unit'},
#  {'child': 'prefixed volt', 'parent': 'prefixed unit'},
#  {'child': 'prefixed watt', 'parent': 'prefixed unit'},
#  {'child': 'prefixed weber', 'parent': 'prefixed unit'},
#  {'child': 'pressure unit', 'parent': 'unit'},
#  {'child': 'protein mass fraction', 'parent': 'mass fraction'},
#  {'child': 'quality mark flower(s)', 'parent': 'quality mark'},
#  {'child': 'quality mark leafs', 'parent': 'quality mark'},
#  {'child': 'quality mark total', 'parent': 'quality mark'},
#  {'child': 'quantity of dimension one', 'parent': 'quantity'},
#  {'child': 'quantity of dimension one unit', 'parent': 'unit'},
#  {'child': 'quantum efficiency unit', 'parent': 'unit'},
#  {'child': 'R magnitude', 'parent': 'Johnson magnitude'},
#  {'child': 'radiance unit', 'parent': 'unit'},
#  {'child': 'radiant energy', 'parent': 'energy'},
#  {'child': 'radiant intensity unit', 'parent': 'unit'},
#  {'child': 'radius', 'parent': 'length'},
#  {'child': 'radius (angle)', 'parent': 'angle'},
#  {'child': 'Rankine temperature', 'parent': 'temperature'},
#  {'child': 'Rankine temperature scale', 'parent': 'Temperature_scale'},
#  {'child': 'Rankine temperature unit', 'parent': 'temperature unit'},
#  {'child': 'ratio', 'parent': 'quantity of dimension one'},
#  {'child': 'ratio scale', 'parent': 'scale'},
#  {'child': 'ratio unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'Rayleigh number', 'parent': 'quantity of dimension one'},
#  {'child': 'Rayleigh number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'red magnitude', 'parent': 'magnitude'},
#  {'child': 'reddening', 'parent': 'extinction'},
#  {'child': 'reddening (B-V)', 'parent': 'intrinsic colour index'},
#  {'child': 'reddening (B-V)', 'parent': 'reddening'},
#  {'child': 'reddening (U-B)', 'parent': 'intrinsic colour index'},
#  {'child': 'reddening (U-B)', 'parent': 'reddening'},
#  {'child': 'reluctance unit', 'parent': 'unit'},
#  {'child': 'relative humidity unit', 'parent': 'unit'},
#  {'child': 'resonance energy', 'parent': 'energy'},
#  {'child': 'responsivity unit', 'parent': 'unit'},
#  {'child': 'Reynolds number', 'parent': 'quantity of dimension one'},
#  {'child': 'Reynolds number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'right ascension', 'parent': 'angle'},
#  {'child': 'Réaumur temperature', 'parent': 'temperature'},
#  {'child': 'Réaumur temperature scale', 'parent': 'Temperature_scale'},
#  {'child': 'Réaumur temperature unit', 'parent': 'temperature unit'},
#  {'child': 'SI prefix', 'parent': 'prefix'},
#  {'child': 'Salmonella count (specific)', 'parent': 'viable count (specific)'},
#  {'child': 'Salmonella count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'salt mass fraction', 'parent': 'mass fraction'},
#  {'child': 'scale height', 'parent': 'length'},
#  {'child': 'scale length', 'parent': 'length'},
#  {'child': 'Schmidt number', 'parent': 'quantity of dimension one'},
#  {'child': 'Schmidt number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'secular aberration', 'parent': 'angle'},
#  {'child': 'Serratia marcescens count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Serratia marcescens count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'shear loss modulus', 'parent': 'loss modulus'},
#  {'child': 'shear rate unit', 'parent': 'unit'},
#  {'child': 'shear storage modulus', 'parent': 'storage modulus'},
#  {'child': 'shear strain', 'parent': 'strain'},
#  {'child': 'shear strain', 'parent': 'strain tensor'},
#  {'child': 'shear stress', 'parent': 'stress'},
#  {'child': 'shear stress', 'parent': 'stress tensor'},
#  {'child': 'singular unit', 'parent': 'unit'},
#  {'child': 'solid angle unit', 'parent': 'unit'},
#  {'child': 'soy bean mass fraction', 'parent': 'mass fraction'},
#  {'child': 'specific amount of money unit', 'parent': 'unit'},
#  {'child': 'specific catalytic activity unit', 'parent': 'unit'},
#  {'child': 'specific energy imparted', 'parent': 'specific energy'},
#  {'child': 'specific energy unit', 'parent': 'unit'},
#  {'child': 'specific entropy unit', 'parent': 'unit'},
#  {'child': 'specific heat capacity unit', 'parent': 'unit'},
#  {'child': 'specific viable count unit', 'parent': 'unit'},
#  {'child': 'specific volume unit', 'parent': 'unit'},
#  {'child': 'speed unit', 'parent': 'unit'},
#  {'child': 'square prefixed metre', 'parent': 'area unit'},
#  {'child': 'square prefixed metre', 'parent': 'prefixed metre'},
#  {'child': 'Staphylococcus aureus count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Staphylococcus aureus count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'Stanton number', 'parent': 'quantity of dimension one'},
#  {'child': 'Stanton number for mass transfer', 'parent': 'Stanton number'},
#  {'child': 'Stanton number for mass transfer unit',
#   'parent': 'Stanton number unit'},
#  {'child': 'Stanton number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'starch VA40 mass fraction', 'parent': 'starch mass fraction'},
#  {'child': 'starch VA85 mass fraction', 'parent': 'starch mass fraction'},
#  {'child': 'starch mass fraction', 'parent': 'mass fraction'},
#  {'child': 'strain', 'parent': 'quantity of dimension one'},
#  {'child': 'strain unit', 'parent': 'unit'},
#  {'child': 'straw mass', 'parent': 'mass'},
#  {'child': 'Streptococcus agalactiae count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Streptococcus agalactiae count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'Streptococcus dysgalactiae count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Streptococcus dysgalactiae count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'Streptococcus uberis count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'Streptococcus uberis count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'stress unit', 'parent': 'unit'},
#  {'child': 'Strömgren magnitude', 'parent': 'magnitude'},
#  {'child': 'Strouhal number', 'parent': 'quantity of dimension one'},
#  {'child': 'Strouhal number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'sugar mass fraction', 'parent': 'mass fraction'},
#  {'child': 'supergalactic latitude', 'parent': 'angle'},
#  {'child': 'supergalactic longitude', 'parent': 'angle'},
#  {'child': 'surface tension unit', 'parent': 'unit'},
#  {'child': 'symbol rate unit', 'parent': 'unit'},
#  {'child': 'temperature rate unit', 'parent': 'unit'},
#  {'child': 'temperature unit', 'parent': 'unit'},
#  {'child': 'Temperature_scale', 'parent': 'scale'},
#  {'child': 'thermal conductivity unit', 'parent': 'unit'},
#  {'child': 'thermal diffusivity unit', 'parent': 'unit'},
#  {'child': 'thermal insulance unit', 'parent': 'unit'},
#  {'child': 'thermal resistance unit', 'parent': 'unit'},
#  {'child': 'thermodynamic temperature', 'parent': 'temperature'},
#  {'child': 'thermodynamic temperature scale', 'parent': 'Temperature_scale'},
#  {'child': 'thermodynamic temperature unit', 'parent': 'temperature unit'},
#  {'child': 'thickness', 'parent': 'length'},
#  {'child': 'Thuan and Gunn magnitude', 'parent': 'magnitude'},
#  {'child': 'time constant', 'parent': 'time'},
#  {'child': 'time unit', 'parent': 'unit'},
#  {'child': 'top mass', 'parent': 'mass'},
#  {'child': 'torque', 'parent': 'moment of force'},
#  {'child': 'torque unit', 'parent': 'moment of force unit'},
#  {'child': 'total number buds', 'parent': 'number buds'},
#  {'child': 'total number flowers', 'parent': 'number flowers'},
#  {'child': 'total number leaves', 'parent': 'number leaves'},
#  {'child': 'true distance modulus', 'parent': 'distance modulus'},
#  {'child': 'tween mass fraction', 'parent': 'mass fraction'},
#  {'child': 'Tycho broadband magnitude', 'parent': 'magnitude'},
#  {'child': 'U magnitude', 'parent': 'Johnson magnitude'},
#  {'child': 'u magnitude', 'parent': 'magnitude'},
#  {'child': 'V magnitude', 'parent': 'Johnson magnitude'},
#  {'child': 'V magnitude at maximum brightness', 'parent': 'V magnitude'},
#  {'child': 'V magnitude at maximum brightness',
#   'parent': 'magnitude at maximum brightness'},
#  {'child': 'V magnitude at minimum brightness', 'parent': 'V magnitude'},
#  {'child': 'V magnitude at minimum brightness',
#   'parent': 'magnitude at minimum brightness'},
#  {'child': 'vase plus water mass', 'parent': 'mass'},
#  {'child': 'vase plus water plus flower mass', 'parent': 'mass'},
#  {'child': 'viable count (specific)', 'parent': 'viable count'},
#  {'child': 'viable count (volumetric)', 'parent': 'viable count'},
#  {'child': 'visual albedo', 'parent': 'albedo'},
#  {'child': 'volume fraction', 'parent': 'ratio'},
#  {'child': 'volume fraction unit', 'parent': 'unit'},
#  {'child': 'volume strain', 'parent': 'strain'},
#  {'child': 'volume unit', 'parent': 'unit'},
#  {'child': 'volumetric heat capacity unit', 'parent': 'unit'},
#  {'child': 'volumetric flow rate unit', 'parent': 'unit'},
#  {'child': 'volumetric viable count unit', 'parent': 'unit'},
#  {'child': 'water mass fraction', 'parent': 'mass fraction'},
#  {'child': 'wave number unit', 'parent': 'unit'},
#  {'child': 'wavelength', 'parent': 'length'},
#  {'child': 'Weber number', 'parent': 'quantity of dimension one'},
#  {'child': 'Weber number unit', 'parent': 'quantity of dimension one unit'},
#  {'child': 'weight', 'parent': 'force'},
#  {'child': 'wetting angle', 'parent': 'contact angle'},
#  {'child': 'whey protein aggregate mass fraction',
#   'parent': 'whey protein mass fraction'},
#  {'child': 'whey protein beads mass fraction',
#   'parent': 'whey protein mass fraction'},
#  {'child': 'whey protein mass fraction', 'parent': 'mass fraction'},
#  {'child': 'white light magnitude', 'parent': 'magnitude'},
#  {'child': 'white light magnitude at maximum brightness',
#   'parent': 'magnitude at maximum brightness'},
#  {'child': 'white light magnitude at maximum brightness',
#   'parent': 'white light magnitude'},
#  {'child': 'white light magnitude at minimum brightness',
#   'parent': 'magnitude at minimum brightness'},
#  {'child': 'white light magnitude at minimum brightness',
#   'parent': 'white light magnitude'},
#  {'child': 'width', 'parent': 'length'},
#  {'child': 'work', 'parent': 'energy'},
#  {'child': 'xanthan mass fraction', 'parent': 'mass fraction'},
#  {'child': 'y magnitude', 'parent': 'magnitude'},
#  {'child': 'yeast and fungi count (specific)',
#   'parent': 'viable count (specific)'},
#  {'child': 'yeast and fungi count (volumetric)',
#   'parent': 'viable count (volumetric)'},
#  {'child': 'zenith distance', 'parent': 'angle'},
#  {'child': 'β_narrow magnitude', 'parent': 'Strömgren magnitude'},
#  {'child': 'β_wide magnitude', 'parent': 'Strömgren magnitude'}]

# %%
with open("predictions_flash_clustering_pro_final_c_10_model_clustering_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_ans, f, indent=2, ensure_ascii=False)
