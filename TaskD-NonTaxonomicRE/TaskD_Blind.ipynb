# %%
import json
def load_json(data_path):
    with open(data_path, "r") as file_1:
        data = json.load(file_1)
    return data

# %%
test_data = []
with open("blind domain/D4-Blind-Types.txt", "r", encoding="utf-8") as file:
    content = file.readlines()
    for con in content:
        test_data.append(con.strip('\n'))

print(test_data)
# Out:
# ['acellular anatomical structure', 'adipose tissue', 'aerobic', 'aggregated', 'amictic lake', 'anaerobic', 'anterior segment of eyeball', 'anterior uvea', 'articular system', 'biome', 'blood vessel', 'bone element', 'bone tissue', 'caldera', 'circulatory system', 'clay', 'closed', 'collective plant organ structure', 'continental shelf', 'continuant', 'continuant fiat boundary', 'cowpea (pulse) food product', 'cowpea vegetable food product', 'crevasse', 'crevice', 'dead cave', 'dense connective tissue', 'digestive system', 'dimictic lake', 'disposition', 'distributed', 'ecoregion', 'ecozone', 'edible', 'elastic', 'entire sense organ system', 'excretory system', 'fluid astronomical body part', 'formal settlement', 'generically dependent continuant', 'glacier', 'hematopoietic system', 'holomictic lake', 'hydroform', 'hydrophilicity', 'hydrophobicity', 'illegal settlement', 'immaterial anatomical entity', 'immaterial entity', 'immune system', 'impermeable', 'independent continuant', 'inedible', 'inelastic', 'informal settlement', 'integumental system', 'landlocked sea', 'legal settlement', 'lime mudstone', 'live cave', 'loose connective tissue', 'lymphatic vessel', 'marine biome', 'marine ecosystem', 'marine neritic zone', 'marine water body', 'marine water mass', 'material anatomical entity', 'material entity', 'meromictic lake', 'mineral material', 'monomictic lake', 'mudstone', 'multi organ part structure', 'multicellular anatomical structure', 'muscle organ', 'muscle structure', 'muscle tissue', 'musculoskeletal system', 'neritic pelagic zone biome', 'nervous system', 'neural tissue', 'non-porous', 'nonsynovial joint', 'nuclear power reactor', 'obsolete glacial feature', 'obsolete marine benthic feature', 'obsolete marine pelagic feature', 'occurrent', 'ocean', 'oceanic island', 'oceanic pelagic zone biome', 'oceanic zone', 'one-dimensional continuant fiat boundary', 'open', 'optic choroid', 'organ', 'particle of sand', 'pectoral girdle region', 'pectoral girdle skeleton', 'permeable', 'physical object quality', 'plant cell', 'plant organ', 'polymictic lake', 'porous', 'portion of plant tissue', 'posterior segment of eyeball', 'process', 'process boundary', 'process quality', 'quality', 'realizable entity', 'reproductive system', 'research nuclear reactor', 'respiratory system', 'rock', 'role', 'root system', 'sand', 'shoot system', 'silt', 'site', 'skeletal joint', 'skeletal system', 'skeletal tissue', 'skeleton', 'snow', 'solid astronomical body part', 'spatial region', 'spatiotemporal region', 'specifically dependent continuant', 'synovial joint', 'temporal region', 'two-dimensional continuant fiat boundary', 'volcanic crater', 'water ice']

# %%
test_relations = ['consider', 'disconnected_from', 'disjointWith','equivalentClass', 'seeAlso']

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")

# %%
prompt_domain_extraction= f"""You are an expert AI assistant specializing in knowledge representation, ontology, and domain analysis. Your task is to analyze a given list of terms and a list of relationship names to identify the specific knowledge domain they belong to.

**Instructions:**

1.  **Analyze Inputs:** You will be given a list of terms and a list of potential relationships. Carefully examine these items to find the common theme or scientific field that connects them. Consider what subject matter these terms represent (e.g., biology, geography, technology, food production).
2.  **Generate Domain Name:** Based on your analysis, create a concise and descriptive name for the domain. For example, "Food Science and Production" or "Earth and Environmental Science."
3.  **Generate Domain Description:** Write a 4-5 line description of this domain. This description should explain:
    *   The general area of study or industry it covers.
    *   The types of concepts the terms represent within this domain.
    *   How the relationships typically connect these concepts.
    *   The overall purpose of structuring knowledge in this domain (e.g., for scientific analysis, traceability, data interoperability).
4.  **Format the Output:** Return a Python dictionary containing two keys: `domain_name` and `domain_description`.

**Task:**
Analyze the following inputs and generate a domain name and description.

-   **List of Terms:** {test_data}
-   **List of Relationships:** {test_relations}

Return the result as a Python dictionary."""

# %%
generation_config = {"response_mime_type": "application/json"}

response = client.models.generate_content(
        contents= prompt_domain_extraction,
        config=generation_config,
        model=model
    )
domain= json.loads(response.text)

# %%
domain
# Out:
# {'domain_name': 'Natural Systems Ontology',
#  'domain_description': 'This domain focuses on the formal representation of knowledge spanning biological and Earth sciences. It integrates concepts related to living organisms (e.g., anatomy, tissues, systems, biological processes) and the physical environment (e.g., geological features, water bodies, biomes, material properties). Leveraging foundational ontological principles, it defines precise relationships to structure and categorize entities. The primary purpose is to establish a coherent, machine-readable framework for semantic interoperability, data integration, and robust reasoning across diverse scientific disciplines.'}

# %%
prompt = f"""You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning. You will be provided with a domain name and a description to set the context for your task.

Your primary task is to group a list of terms into clusters based on a specific set of relationships, using your knowledge of the identified domain to determine the connections.

**Context (Provided as Input):**
-   **Domain Name:** {domain['domain_name']}
-   **Domain Description:** {domain['domain_description']}

**Instructions:**

1.  **Build the Graph:**
    *   Treat each term from the input list as a point (node) in a graph.
    *   Using your knowledge of the **identified domain** (contextualized by the provided name and description), check every pair of terms to see if they could be connected by any of the **clustering relationships**. If a valid connection exists, create a two-way (undirected) link between them.
2.  **Form Clusters:**
    *   Group terms into clusters where terms are connected either directly or indirectly through the specified clustering relationships.
    *   Terms with no connections form their own single-term clusters.
    *   Ensure every term from the input list appears in the output.
3.  **Handle Special Cases:**
    *   If the terms list is empty, return an empty list of clusters: [].
    *   If the clustering relationships list is empty, place each term in its own cluster.
4.  **Format the Output:**
    *   Return a Python list of lists, where each inner list contains the terms in a cluster.
    *   Do not include the relationships in the output, only the grouped terms.
    *   Sort the clusters alphabetically by the first term in each cluster.
    *   Within each cluster, sort the terms alphabetically.

**Task:**
Group the following terms into clusters using the provided clustering relationships and the domain context. For each pair of terms, use your knowledge of the domain to determine if they can be connected by the specified relationships.

-   **List of Terms:** {test_data}
-   **List of Clustering Relationships:** {test_relations}

Return the result as a Python list of lists, where each inner list represents a cluster of terms."""

# %%
len(prompt), print(prompt)
# Out:
# You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning. You will be provided with a domain name and a description to set the context for your task.
#
# Your primary task is to group a list of terms into clusters based on a specific set of relationships, using your knowledge of the identified domain to determine the connections.
#
# **Context (Provided as Input):**
# -   **Domain Name:** Natural Systems Ontology
# -   **Domain Description:** This domain focuses on the formal representation of knowledge spanning biological and Earth sciences. It integrates concepts related to living organisms (e.g., anatomy, tissues, systems, biological processes) and the physical environment (e.g., geological features, water bodies, biomes, material properties). Leveraging foundational ontological principles, it defines precise relationships to structure and categorize entities. The primary purpose is to establish a coherent, machine-readable framework for semantic interoperability, data integration, and robust reasoning across diverse scientific disciplines.
#
# **Instructions:**
#
# 1.  **Build the Graph:**
#     *   Treat each term from the input list as a point (node) in a graph.
#     *   Using your knowledge of the **identified domain** (contextualized by the provided name and description), check every pair of terms to see if they could be connected by any of the **clustering relationships**. If a valid connection exists, create a two-way (undirected) link between them.
# 2.  **Form Clusters:**
#     *   Group terms into clusters where terms are connected either directly or indirectly through the specified clustering relationships.
#     *   Terms with no connections form their own single-term clusters.
#     *   Ensure every term from the input list appears in the output.
# 3.  **Handle Special Cases:**
#     *   If the terms list is empty, return an empty list of clusters: [].
#     *   If the clustering relationships list is empty, place each term in its own cluster.
# 4.  **Format the Output:**
#     *   Return a Python list of lists, where each inner list contains the terms in a cluster.
#     *   Do not include the relationships in the output, only the grouped terms.
#     *   Sort the clusters alphabetically by the first term in each cluster.
#     *   Within each cluster, sort the terms alphabetically.
#
# **Task:**
# Group the following terms into clusters using the provided clustering relationships and the domain context. For each pair of terms, use your knowledge of the domain to determine if they can be connected by the specified relationships.
#
# -   **List of Terms:** ['acellular anatomical structure', 'adipose tissue', 'aerobic', 'aggregated', 'amictic lake', 'anaerobic', 'anterior segment of eyeball', 'anterior uvea', 'articular system', 'biome', 'blood vessel', 'bone element', 'bone tissue', 'caldera', 'circulatory system', 'clay', 'closed', 'collective plant organ structure', 'continental shelf', 'continuant', 'continuant fiat boundary', 'cowpea (pulse) food product', 'cowpea vegetable food product', 'crevasse', 'crevice', 'dead cave', 'dense connective tissue', 'digestive system', 'dimictic lake', 'disposition', 'distributed', 'ecoregion', 'ecozone', 'edible', 'elastic', 'entire sense organ system', 'excretory system', 'fluid astronomical body part', 'formal settlement', 'generically dependent continuant', 'glacier', 'hematopoietic system', 'holomictic lake', 'hydroform', 'hydrophilicity', 'hydrophobicity', 'illegal settlement', 'immaterial anatomical entity', 'immaterial entity', 'immune system', 'impermeable', 'independent continuant', 'inedible', 'inelastic', 'informal settlement', 'integumental system', 'landlocked sea', 'legal settlement', 'lime mudstone', 'live cave', 'loose connective tissue', 'lymphatic vessel', 'marine biome', 'marine ecosystem', 'marine neritic zone', 'marine water body', 'marine water mass', 'material anatomical entity', 'material entity', 'meromictic lake', 'mineral material', 'monomictic lake', 'mudstone', 'multi organ part structure', 'multicellular anatomical structure', 'muscle organ', 'muscle structure', 'muscle tissue', 'musculoskeletal system', 'neritic pelagic zone biome', 'nervous system', 'neural tissue', 'non-porous', 'nonsynovial joint', 'nuclear power reactor', 'obsolete glacial feature', 'obsolete marine benthic feature', 'obsolete marine pelagic feature', 'occurrent', 'ocean', 'oceanic island', 'oceanic pelagic zone biome', 'oceanic zone', 'one-dimensional continuant fiat boundary', 'open', 'optic choroid', 'organ', 'particle of sand', 'pectoral girdle region', 'pectoral girdle skeleton', 'permeable', 'physical object quality', 'plant cell', 'plant organ', 'polymictic lake', 'porous', 'portion of plant tissue', 'posterior segment of eyeball', 'process', 'process boundary', 'process quality', 'quality', 'realizable entity', 'reproductive system', 'research nuclear reactor', 'respiratory system', 'rock', 'role', 'root system', 'sand', 'shoot system', 'silt', 'site', 'skeletal joint', 'skeletal system', 'skeletal tissue', 'skeleton', 'snow', 'solid astronomical body part', 'spatial region', 'spatiotemporal region', 'specifically dependent continuant', 'synovial joint', 'temporal region', 'two-dimensional continuant fiat boundary', 'volcanic crater', 'water ice']
# -   **List of Clustering Relationships:** ['consider', 'disconnected_from', 'disjointWith', 'equivalentClass', 'seeAlso']
#
# Return the result as a Python list of lists, where each inner list represents a cluster of terms.
# (5517, None)

# %%
generation_config = {"response_mime_type": "application/json"}

response = client.models.generate_content(
        contents= prompt,
        config=generation_config,
        model=model
    )

# %%
response_1 = response.text
response_1
# Out:
# '[\n  [\n    "acellular anatomical structure",\n    "adipose tissue",\n    "aerobic",\n    "aggregated",\n    "amictic lake",\n    "anaerobic",\n    "anterior segment of eyeball",\n    "anterior uvea",\n    "articular system",\n    "biome",\n    "blood vessel",\n    "bone element",\n    "bone tissue",\n    "caldera",\n    "circulatory system",\n    "clay",\n    "closed",\n    "collective plant organ structure",\n    "continental shelf",\n    "continuant",\n    "continuant fiat boundary",\n    "cowpea (pulse) food product",\n    "cowpea vegetable food product",\n    "crevasse",\n    "crevice",\n    "dead cave",\n    "dense connective tissue",\n    "digestive system",\n    "dimictic lake",\n    "disposition",\n    "distributed",\n    "ecoregion",\n    "ecozone",\n    "edible",\n    "elastic",\n    "entire sense organ system",\n    "excretory system",\n    "fluid astronomical body part",\n    "formal settlement",\n    "generically dependent continuant",\n    "glacier",\n    "hematopoietic system",\n    "holomictic lake",\n    "hydroform",\n    "hydrophilicity",\n    "hydrophobicity",\n    "illegal settlement",\n    "immaterial anatomical entity",\n    "immaterial entity",\n    "immune system",\n    "impermeable",\n    "independent continuant",\n    "inedible",\n    "inelastic",\n    "informal settlement",\n    "integumental system",\n    "landlocked sea",\n    "legal settlement",\n    "lime mudstone",\n    "live cave",\n    "loose connective tissue",\n    "lymphatic vessel",\n    "marine biome",\n    "marine ecosystem",\n    "marine neritic zone",\n    "marine water body",\n    "marine water mass",\n    "material anatomical entity",\n    "material entity",\n    "meromictic lake",\n    "mineral material",\n    "monomictic lake",\n    "mudstone",\n    "multi organ part structure",\n    "multicellular anatomical structure",\n    "muscle organ",\n    "muscle structure",\n    "muscle tissue",\n    "musculoskeletal system",\n    "neritic pelagic zone biome",\n    "nervous system",\n    "neural tissue",\n    "non-porous",\n    "nonsynovial joint",\n    "nuclear power reactor",\n    "obsolete glacial feature",\n    "obsolete marine benthic feature",\n    "obsolete marine pelagic feature",\n    "occurrent",\n    "ocean",\n    "oceanic island",\n    "oceanic pelagic zone biome",\n    "oceanic zone",\n    "one-dimensional continuant fiat boundary",\n    "open",\n    "optic choroid",\n    "organ",\n    "particle of sand",\n    "pectoral girdle region",\n    "pectoral girdle skeleton",\n    "permeable",\n    "physical object quality",\n    "plant cell",\n    "plant organ",\n    "polymictic lake",\n    "porous",\n    "portion of plant tissue",\n    "posterior segment of eyeball",\n    "process",\n    "process boundary",\n    "process quality",\n    "quality",\n    "realizable entity",\n    "reproductive system",\n    "research nuclear reactor",\n    "respiratory system",\n    "rock",\n    "role",\n    "root system",\n    "sand",\n    "shoot system",\n    "silt",\n    "site",\n    "skeletal joint",\n    "skeletal system",\n    "skeletal tissue",\n    "skeleton",\n    "snow",\n    "solid astronomical body part",\n    "spatial region",\n    "spatiotemporal region",\n    "specifically dependent continuant",\n    "synovial joint",\n    "temporal region",\n    "two-dimensional continuant fiat boundary",\n    "volcanic crater",\n    "water ice"\n  ]\n]'

# %%
final_output = json.loads(response_1)

# %%
final_output
# Out:
# [['acellular anatomical structure',
#   'adipose tissue',
#   'aerobic',
#   'aggregated',
#   'amictic lake',
#   'anaerobic',
#   'anterior segment of eyeball',
#   'anterior uvea',
#   'articular system',
#   'biome',
#   'blood vessel',
#   'bone element',
#   'bone tissue',
#   'caldera',
#   'circulatory system',
#   'clay',
#   'closed',
#   'collective plant organ structure',
#   'continental shelf',
#   'continuant',
#   'continuant fiat boundary',
#   'cowpea (pulse) food product',
#   'cowpea vegetable food product',
#   'crevasse',
#   'crevice',
#   'dead cave',
#   'dense connective tissue',
#   'digestive system',
#   'dimictic lake',
#   'disposition',
#   'distributed',
#   'ecoregion',
#   'ecozone',
#   'edible',
#   'elastic',
#   'entire sense organ system',
#   'excretory system',
#   'fluid astronomical body part',
#   'formal settlement',
#   'generically dependent continuant',
#   'glacier',
#   'hematopoietic system',
#   'holomictic lake',
#   'hydroform',
#   'hydrophilicity',
#   'hydrophobicity',
#   'illegal settlement',
#   'immaterial anatomical entity',
#   'immaterial entity',
#   'immune system',
#   'impermeable',
#   'independent continuant',
#   'inedible',
#   'inelastic',
#   'informal settlement',
#   'integumental system',
#   'landlocked sea',
#   'legal settlement',
#   'lime mudstone',
#   'live cave',
#   'loose connective tissue',
#   'lymphatic vessel',
#   'marine biome',
#   'marine ecosystem',
#   'marine neritic zone',
#   'marine water body',
#   'marine water mass',
#   'material anatomical entity',
#   'material entity',
#   'meromictic lake',
#   'mineral material',
#   'monomictic lake',
#   'mudstone',
#   'multi organ part structure',
#   'multicellular anatomical structure',
#   'muscle organ',
#   'muscle structure',
#   'muscle tissue',
#   'musculoskeletal system',
#   'neritic pelagic zone biome',
#   'nervous system',
#   'neural tissue',
#   'non-porous',
#   'nonsynovial joint',
#   'nuclear power reactor',
#   'obsolete glacial feature',
#   'obsolete marine benthic feature',
#   'obsolete marine pelagic feature',
#   'occurrent',
#   'ocean',
#   'oceanic island',
#   'oceanic pelagic zone biome',
#   'oceanic zone',
#   'one-dimensional continuant fiat boundary',
#   'open',
#   'optic choroid',
#   'organ',
#   'particle of sand',
#   'pectoral girdle region',
#   'pectoral girdle skeleton',
#   'permeable',
#   'physical object quality',
#   'plant cell',
#   'plant organ',
#   'polymictic lake',
#   'porous',
#   'portion of plant tissue',
#   'posterior segment of eyeball',
#   'process',
#   'process boundary',
#   'process quality',
#   'quality',
#   'realizable entity',
#   'reproductive system',
#   'research nuclear reactor',
#   'respiratory system',
#   'rock',
#   'role',
#   'root system',
#   'sand',
#   'shoot system',
#   'silt',
#   'site',
#   'skeletal joint',
#   'skeletal system',
#   'skeletal tissue',
#   'skeleton',
#   'snow',
#   'solid astronomical body part',
#   'spatial region',
#   'spatiotemporal region',
#   'specifically dependent continuant',
#   'synovial joint',
#   'temporal region',
#   'two-dimensional continuant fiat boundary',
#   'volcanic crater',
#   'water ice']]

# %%
model="gemini-2.5-pro"

# %%
response_final = []
from tqdm import tqdm
for i, term_cluster in tqdm(enumerate(final_output)):
    prompt=f"""You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning. Your task will be guided by a specific domain context provided to you.

**Context (Provided as Input):**
-   **Domain Name:** {domain['domain_name']}
-   **Domain Description:** {domain['domain_description']}

Your task is to take a single cluster of terms and a list of relationships, and generate all possible relationship triples (head, relation, tail) *between terms within that cluster*. You must use your knowledge of the identified domain and only use the specified relationships.

**Instructions:**

1.  **Process the Cluster:**
    *   Examine all possible pairs of terms within the given input cluster.
    *   Using your knowledge of the **identified domain** (as described in the provided context), determine if a pair can be connected by one of the clustering relationships. If a valid connection exists, create a relationship triple `(head, relation, tail)`.
    *   Only include triples where both the `head` and `tail` are terms from the input cluster and the `relation` is in the provided list of clustering relationships.
2.  **Handle Special Cases:**
    *   If the cluster contains one or zero terms, return an empty list, as no pairs are possible.
    *   If no valid relationships can be inferred for any pair in the cluster based on your knowledge of the domain, return an empty list.
    *   If the list of clustering relationships is empty, return an empty list.
3.  **Format the Output:**
    *   Return a Python list containing the generated triples, where each triple is a tuple.
    *   Each triple must be in the format `(head, relation, tail)`.
    *   Sort the final list of triples alphabetically by head, then by relation, and then by tail.

**Task:**
For the given cluster of terms, and guided by the provided domain context, generate all possible relationship triples using the given clustering relationships {test_relations}. Use your knowledge of the identified domain to infer valid relationships only between terms within the cluster.

-   **Cluster of Terms:** {term_cluster}
-   **List of Clustering Relationships:** {test_relations}

Return the result as a Python list of triples.
"""
    generation_config = {"response_mime_type": "application/json"}
    print(model)
    response = client.models.generate_content(
            contents= prompt,
            config=generation_config,
            model=model
        )
    response_final.append(response.text)
    if i%10==0:
        print(response.text)
# Out:
# 0it [00:00, ?it/s]
# gemini-2.5-pro
# 1it [01:49, 109.14s/it]
# [
#   [
#     "aerobic",
#     "disjointWith",
#     "anaerobic"
#   ],
#   [
#     "aggregated",
#     "disjointWith",
#     "distributed"
#   ],
#   [
#     "amictic lake",
#     "disjointWith",
#     "holomictic lake"
#   ],
#   [
#     "amictic lake",
#     "disjointWith",
#     "meromictic lake"
#   ],
#   [
#     "anaerobic",
#     "disjointWith",
#     "aerobic"
#   ],
#   [
#     "articular system",
#     "seeAlso",
#     "musculoskeletal system"
#   ],
#   [
#     "articular system",
#     "seeAlso",
#     "skeletal system"
#   ],
#   [
#     "biome",
#     "seeAlso",
#     "ecoregion"
#   ],
#   [
#     "biome",
#     "seeAlso",
#     "ecozone"
#   ],
#   [
#     "biome",
#     "seeAlso",
#     "marine ecosystem"
#   ],
#   [
#     "bone element",
#     "seeAlso",
#     "bone tissue"
#   ],
#   [
#     "bone tissue",
#     "disjointWith",
#     "muscle tissue"
#   ],
#   [
#     "bone tissue",
#     "disjointWith",
#     "neural tissue"
#   ],
#   [
#     "bone tissue",
#     "seeAlso",
#     "bone element"
#   ],
#   [
#     "caldera",
#     "seeAlso",
#     "volcanic crater"
#   ],
#   [
#     "circulatory system",
#     "disjointWith",
#     "digestive system"
#   ],
#   [
#     "circulatory system",
#     "disjointWith",
#     "excretory system"
#   ],
#   [
#     "circulatory system",
#     "disjointWith",
#     "immune system"
#   ],
#   [
#     "circulatory system",
#     "disjointWith",
#     "integumental system"
#   ],
#   [
#     "circulatory system",
#     "disjointWith",
#     "musculoskeletal system"
#   ],
#   [
#     "circulatory system",
#     "disjointWith",
#     "nervous system"
#   ],
#   [
#     "circulatory system",
#     "disjointWith",
#     "reproductive system"
#   ],
#   [
#     "circulatory system",
#     "disjointWith",
#     "respiratory system"
#   ],
#   [
#     "clay",
#     "seeAlso",
#     "mudstone"
#   ],
#   [
#     "closed",
#     "disjointWith",
#     "open"
#   ],
#   [
#     "collective plant organ structure",
#     "seeAlso",
#     "plant organ"
#   ],
#   [
#     "continental shelf",
#     "disconnected_from",
#     "oceanic island"
#   ],
#   [
#     "continuant",
#     "disjointWith",
#     "occurrent"
#   ],
#   [
#     "cowpea (pulse) food product",
#     "disjointWith",
#     "cowpea vegetable food product"
#   ],
#   [
#     "cowpea vegetable food product",
#     "disjointWith",
#     "cowpea (pulse) food product"
#   ],
#   [
#     "crevasse",
#     "seeAlso",
#     "crevice"
#   ],
#   [
#     "crevice",
#     "seeAlso",
#     "crevasse"
#   ],
#   [
#     "dead cave",
#     "disjointWith",
#     "live cave"
#   ],
#   [
#     "digestive system",
#     "disjointWith",
#     "circulatory system"
#   ],
#   [
#     "digestive system",
#     "disjointWith",
#     "excretory system"
#   ],
#   [
#     "digestive system",
#     "disjointWith",
#     "immune system"
#   ],
#   [
#     "digestive system",
#     "disjointWith",
#     "integumental system"
#   ],
#   [
#     "digestive system",
#     "disjointWith",
#     "musculoskeletal system"
#   ],
#   [
#     "digestive system",
#     "disjointWith",
#     "nervous system"
#   ],
#   [
#     "digestive system",
#     "disjointWith",
#     "reproductive system"
#   ],
#   [
#     "digestive system",
#     "disjointWith",
#     "respiratory system"
#   ],
#   [
#     "dimictic lake",
#     "disjointWith",
#     "monomictic lake"
#   ],
#   [
#     "dimictic lake",
#     "disjointWith",
#     "polymictic lake"
#   ],
#   [
#     "dimictic lake",
#     "seeAlso",
#     "holomictic lake"
#   ],
#   [
#     "disposition",
#     "disjointWith",
#     "process"
#   ],
#   [
#     "disposition",
#     "disjointWith",
#     "quality"
#   ],
#   [
#     "disposition",
#     "disjointWith",
#     "role"
#   ],
#   [
#     "distributed",
#     "disjointWith",
#     "aggregated"
#   ],
#   [
#     "ecoregion",
#     "seeAlso",
#     "biome"
#   ],
#   [
#     "ecoregion",
#     "seeAlso",
#     "ecozone"
#   ],
#   [
#     "ecozone",
#     "seeAlso",
#     "biome"
#   ],
#   [
#     "ecozone",
#     "seeAlso",
#     "ecoregion"
#   ],
#   [
#     "edible",
#     "disjointWith",
#     "inedible"
#   ],
#   [
#     "elastic",
#     "disjointWith",
#     "inelastic"
#   ],
#   [
#     "entire sense organ system",
#     "seeAlso",
#     "nervous system"
#   ],
#   [
#     "excretory system",
#     "disjointWith",
#     "circulatory system"
#   ],
#   [
#     "excretory system",
#     "disjointWith",
#     "digestive system"
#   ],
#   [
#     "excretory system",
#     "disjointWith",
#     "immune system"
#   ],
#   [
#     "excretory system",
#     "disjointWith",
#     "integumental system"
#   ],
#   [
#     "excretory system",
#     "disjointWith",
#     "musculoskeletal system"
#   ],
#   [
#     "excretory system",
#     "disjointWith",
#     "nervous system"
#   ],
#   [
#     "excretory system",
#     "disjointWith",
#     "reproductive system"
#   ],
#   [
#     "excretory system",
#     "disjointWith",
#     "respiratory system"
#   ],
#   [
#     "formal settlement",
#     "disjointWith",
#     "informal settlement"
#   ],
#   [
#     "generically dependent continuant",
#     "disjointWith",
#     "independent continuant"
#   ],
#   [
#     "generically dependent continuant",
#     "disjointWith",
#     "specifically dependent continuant"
#   ],
#   [
#     "glacier",
#     "seeAlso",
#     "snow"
#   ],
#   [
#     "glacier",
#     "seeAlso",
#     "water ice"
#   ],
#   [
#     "holomictic lake",
#     "disjointWith",
#     "amictic lake"
#   ],
#   [
#     "holomictic lake",
#     "disjointWith",
#     "meromictic lake"
#   ],
#   [
#     "holomictic lake",
#     "seeAlso",
#     "dimictic lake"
#   ],
#   [
#     "holomictic lake",
#     "seeAlso",
#     "monomictic lake"
#   ],
#   [
#     "holomictic lake",
#     "seeAlso",
#     "polymictic lake"
#   ],
#   [
#     "hydrophilicity",
#     "disjointWith",
#     "hydrophobicity"
#   ],
#   [
#     "hydrophobicity",
#     "disjointWith",
#     "hydrophilicity"
#   ],
#   [
#     "illegal settlement",
#     "disjointWith",
#     "legal settlement"
#   ],
#   [
#     "immaterial entity",
#     "disjointWith",
#     "material entity"
#   ],
#   [
#     "immune system",
#     "disjointWith",
#     "circulatory system"
#   ],
#   [
#     "immune system",
#     "disjointWith",
#     "digestive system"
#   ],
#   [
#     "immune system",
#     "disjointWith",
#     "excretory system"
#   ],
#   [
#     "immune system",
#     "disjointWith",
#     "integumental system"
#   ],
#   [
#     "immune system",
#     "disjointWith",
#     "musculoskeletal system"
#   ],
#   [
#     "immune system",
#     "disjointWith",
#     "nervous system"
#   ],
#   [
#     "immune system",
#     "disjointWith",
#     "reproductive system"
#   ],
#   [
#     "immune system",
#     "disjointWith",
#     "respiratory system"
#   ],
#   [
#     "impermeable",
#     "disjointWith",
#     "permeable"
#   ],
#   [
#     "independent continuant",
#     "disjointWith",
#     "generically dependent continuant"
#   ],
#   [
#     "independent continuant",
#     "disjointWith",
#     "specifically dependent continuant"
#   ],
#   [
#     "inedible",
#     "disjointWith",
#     "edible"
#   ],
#   [
#     "inelastic",
#     "disjointWith",
#     "elastic"
#   ],
#   [
#     "informal settlement",
#     "disjointWith",
#     "formal settlement"
#   ],
#   [
#     "integumental system",
#     "disjointWith",
#     "circulatory system"
#   ],
#   [
#     "integumental system",
#     "disjointWith",
#     "digestive system"
#   ],
#   [
#     "integumental system",
#     "disjointWith",
#     "excretory system"
#   ],
#   [
#     "integumental system",
#     "disjointWith",
#     "immune system"
#   ],
#   [
#     "integumental system",
#     "disjointWith",
#     "musculoskeletal system"
#   ],
#   [
#     "integumental system",
#     "disjointWith",
#     "nervous system"
#   ],
#   [
#     "integumental system",
#     "disjointWith",
#     "reproductive system"
#   ],
#   [
#     "integumental system",
#     "disjointWith",
#     "respiratory system"
#   ],
#   [
#     "landlocked sea",
#     "seeAlso",
#     "ocean"
#   ],
#   [
#     "legal settlement",
#     "disjointWith",
#     "illegal settlement"
#   ],
#   [
#     "lime mudstone",
#     "seeAlso",
#     "mudstone"
#   ],
#   [
#     "live cave",
#     "disjointWith",
#     "dead cave"
#   ],
#   [
#     "marine biome",
#     "seeAlso",
#     "marine ecosystem"
#   ],
#   [
#     "marine biome",
#     "seeAlso",
#     "neritic pelagic zone biome"
#   ],
#   [
#     "marine biome",
#     "seeAlso",
#     "oceanic pelagic zone biome"
#   ],
#   [
#     "marine ecosystem",
#     "seeAlso",
#     "biome"
#   ],
#   [
#     "marine ecosystem",
#     "seeAlso",
#     "marine biome"
#   ],
#   [
#     "marine water body",
#     "seeAlso",
#     "ocean"
#   ],
#   [
#     "material entity",
#     "disjointWith",
#     "immaterial entity"
#   ],
#   [
#     "meromictic lake",
#     "disjointWith",
#     "amictic lake"
#   ],
#   [
#     "meromictic lake",
#     "disjointWith",
#     "holomictic lake"
#   ],
#   [
#     "mineral material",
#     "seeAlso",
#     "rock"
#   ],
#   [
#     "monomictic lake",
#     "disjointWith",
#     "dimictic lake"
#   ],
#   [
#     "monomictic lake",
#     "disjointWith",
#     "polymictic lake"
#   ],
#   [
#     "monomictic lake",
#     "seeAlso",
#     "holomictic lake"
#   ],
#   [
#     "mudstone",
#     "seeAlso",
#     "clay"
#   ],
#   [
#     "mudstone",
#     "seeAlso",
#     "lime mudstone"
#   ],
#   [
#     "mudstone",
#     "seeAlso",
#     "silt"
#   ],
#   [
#     "muscle organ",
#     "seeAlso",
#     "muscle tissue"
#   ],
#   [
#     "muscle tissue",
#     "disjointWith",
#     "bone tissue"
#   ],
#   [
#     "muscle tissue",
#     "disjointWith",
#     "neural tissue"
#   ],
#   [
#     "muscle tissue",
#     "seeAlso",
#     "muscle organ"
#   ],
#   [
#     "musculoskeletal system",
#     "disjointWith",
#     "circulatory system"
#   ],
#   [
#     "musculoskeletal system",
#     "disjointWith",
#     "digestive system"
#   ],
#   [
#     "musculoskeletal system",
#     "disjointWith",
#     "excretory system"
#   ],
#   [
#     "musculoskeletal system",
#     "disjointWith",
#     "immune system"
#   ],
#   [
#     "musculoskeletal system",
#     "disjointWith",
#     "integumental system"
#   ],
#   [
#     "musculoskeletal system",
#     "disjointWith",
#     "nervous system"
#   ],
#   [
#     "musculoskeletal system",
#     "disjointWith",
#     "reproductive system"
#   ],
#   [
#     "musculoskeletal system",
#     "disjointWith",
#     "respiratory system"
#   ],
#   [
#     "musculoskeletal system",
#     "seeAlso",
#     "articular system"
#   ],
#   [
#     "musculoskeletal system",
#     "seeAlso",
#     "skeletal system"
#   ],
#   [
#     "musculoskeletal system",
#     "seeAlso",
#     "skeleton"
#   ],
#   [
#     "neritic pelagic zone biome",
#     "seeAlso",
#     "marine biome"
#   ],
#   [
#     "nervous system",
#     "disjointWith",
#     "circulatory system"
#   ],
#   [
#     "nervous system",
#     "disjointWith",
#     "digestive system"
#   ],
#   [
#     "nervous system",
#     "disjointWith",
#     "excretory system"
#   ],
#   [
#     "nervous system",
#     "disjointWith",
#     "immune system"
#   ],
#   [
#     "nervous system",
#     "disjointWith",
#     "integumental system"
#   ],
#   [
#     "nervous system",
#     "disjointWith",
#     "musculoskeletal system"
#   ],
#   [
#     "nervous system",
#     "disjointWith",
#     "reproductive system"
#   ],
#   [
#     "nervous system",
#     "disjointWith",
#     "respiratory system"
#   ],
#   [
#     "nervous system",
#     "seeAlso",
#     "entire sense organ system"
#   ],
#   [
#     "neural tissue",
#     "disjointWith",
#     "bone tissue"
#   ],
#   [
#     "neural tissue",
#     "disjointWith",
#     "muscle tissue"
#   ],
#   [
#     "non-porous",
#     "disjointWith",
#     "porous"
#   ],
#   [
#     "nonsynovial joint",
#     "disjointWith",
#     "synovial joint"
#   ],
#   [
#     "nonsynovial joint",
#     "seeAlso",
#     "skeletal joint"
#   ],
#   [
#     "occurrent",
#     "disjointWith",
#     "continuant"
#   ],
#   [
#     "ocean",
#     "seeAlso",
#     "landlocked sea"
#   ],
#   [
#     "ocean",
#     "seeAlso",
#     "marine water body"
#   ],
#   [
#     "oceanic island",
#     "disconnected_from",
#     "continental shelf"
#   ],
#   [
#     "oceanic pelagic zone biome",
#     "seeAlso",
#     "marine biome"
#   ],
#   [
#     "open",
#     "disjointWith",
#     "closed"
#   ],
#   [
#     "particle of sand",
#     "seeAlso",
#     "sand"
#   ],
#   [
#     "permeable",
#     "disjointWith",
#     "impermeable"
#   ],
#   [
#     "plant organ",
#     "seeAlso",
#     "collective plant organ structure"
#   ],
#   [
#     "plant organ",
#     "seeAlso",
#     "portion of plant tissue"
#   ],
#   [
#     "polymictic lake",
#     "disjointWith",
#     "dimictic lake"
#   ],
#   [
#     "polymictic lake",
#     "disjointWith",
#     "monomictic lake"
#   ],
#   [
#     "polymictic lake",
#     "seeAlso",
#     "holomictic lake"
#   ],
#   [
#     "porous",
#     "disjointWith",
#     "non-porous"
#   ],
#   [
#     "portion of plant tissue",
#     "seeAlso",
#     "plant organ"
#   ],
#   [
#     "process",
#     "disjointWith",
#     "disposition"
#   ],
#   [
#     "process",
#     "disjointWith",
#     "quality"
#   ],
#   [
#     "process",
#     "disjointWith",
#     "role"
#   ],
#   [
#     "quality",
#     "disjointWith",
#     "disposition"
#   ],
#   [
#     "quality",
#     "disjointWith",
#     "process"
#   ],
#   [
#     "quality",
#     "disjointWith",
#     "role"
#   ],
#   [
#     "reproductive system",
#     "disjointWith",
#     "circulatory system"
#   ],
#   [
#     "reproductive system",
#     "disjointWith",
#     "digestive system"
#   ],
#   [
#     "reproductive system",
#     "disjointWith",
#     "excretory system"
#   ],
#   [
#     "reproductive system",
#     "disjointWith",
#     "immune system"
#   ],
#   [
#     "reproductive system",
#     "disjointWith",
#     "integumental system"
#   ],
#   [
#     "reproductive system",
#     "disjointWith",
#     "musculoskeletal system"
#   ],
#   [
#     "reproductive system",
#     "disjointWith",
#     "nervous system"
#   ],
#   [
#     "reproductive system",
#     "disjointWith",
#     "respiratory system"
#   ],
#   [
#     "respiratory system",
#     "disjointWith",
#     "circulatory system"
#   ],
#   [
#     "respiratory system",
#     "disjointWith",
#     "digestive system"
#   ],
#   [
#     "respiratory system",
#     "disjointWith",
#     "excretory system"
#   ],
#   [
#     "respiratory system",
#     "disjointWith",
#     "immune system"
#   ],
#   [
#     "respiratory system",
#     "disjointWith",
#     "integumental system"
#   ],
#   [
#     "respiratory system",
#     "disjointWith",
#     "musculoskeletal system"
#   ],
#   [
#     "respiratory system",
#     "disjointWith",
#     "nervous system"
#   ],
#   [
#     "respiratory system",
#     "disjointWith",
#     "reproductive system"
#   ],
#   [
#     "rock",
#     "seeAlso",
#     "mineral material"
#   ],
#   [
#     "role",
#     "disjointWith",
#     "disposition"
#   ],
#   [
#     "role",
#     "disjointWith",
#     "process"
#   ],
#   [
#     "role",
#     "disjointWith",
#     "quality"
#   ],
#   [
#     "root system",
#     "disjointWith",
#     "shoot system"
#   ],
#   [
#     "sand",
#     "seeAlso",
#     "particle of sand"
#   ],
#   [
#     "shoot system",
#     "disjointWith",
#     "root system"
#   ],
#   [
#     "silt",
#     "seeAlso",
#     "mudstone"
#   ],
#   [
#     "skeletal joint",
#     "seeAlso",
#     "nonsynovial joint"
#   ],
#   [
#     "skeletal joint",
#     "seeAlso",
#     "synovial joint"
#   ],
#   [
#     "skeletal system",
#     "equivalentClass",
#     "skeleton"
#   ],
#   [
#     "skeletal system",
#     "seeAlso",
#     "articular system"
#   ],
#   [
#     "skeletal system",
#     "seeAlso",
#     "musculoskeletal system"
#   ],
#   [
#     "skeleton",
#     "equivalentClass",
#     "skeletal system"
#   ],
#   [
#     "skeleton",
#     "seeAlso",
#     "musculoskeletal system"
#   ],
#   [
#     "snow",
#     "seeAlso",
#     "glacier"
#   ],
#   [
#     "specifically dependent continuant",
#     "disjointWith",
#     "generically dependent continuant"
#   ],
#   [
#     "specifically dependent continuant",
#     "disjointWith",
#     "independent continuant"
#   ],
#   [
#     "synovial joint",
#     "disjointWith",
#     "nonsynovial joint"
#   ],
#   [
#     "synovial joint",
#     "seeAlso",
#     "skeletal joint"
#   ],
#   [
#     "volcanic crater",
#     "seeAlso",
#     "caldera"
#   ],
#   [
#     "water ice",
#     "seeAlso",
#     "glacier"
#   ]
# ]

# %%
response_final
# Out:
# ['[\n  [\n    "aerobic",\n    "disjointWith",\n    "anaerobic"\n  ],\n  [\n    "aggregated",\n    "disjointWith",\n    "distributed"\n  ],\n  [\n    "amictic lake",\n    "disjointWith",\n    "holomictic lake"\n  ],\n  [\n    "amictic lake",\n    "disjointWith",\n    "meromictic lake"\n  ],\n  [\n    "anaerobic",\n    "disjointWith",\n    "aerobic"\n  ],\n  [\n    "articular system",\n    "seeAlso",\n    "musculoskeletal system"\n  ],\n  [\n    "articular system",\n    "seeAlso",\n    "skeletal system"\n  ],\n  [\n    "biome",\n    "seeAlso",\n    "ecoregion"\n  ],\n  [\n    "biome",\n    "seeAlso",\n    "ecozone"\n  ],\n  [\n    "biome",\n    "seeAlso",\n    "marine ecosystem"\n  ],\n  [\n    "bone element",\n    "seeAlso",\n    "bone tissue"\n  ],\n  [\n    "bone tissue",\n    "disjointWith",\n    "muscle tissue"\n  ],\n  [\n    "bone tissue",\n    "disjointWith",\n    "neural tissue"\n  ],\n  [\n    "bone tissue",\n    "seeAlso",\n    "bone element"\n  ],\n  [\n    "caldera",\n    "seeAlso",\n    "volcanic crater"\n  ],\n  [\n    "circulatory system",\n    "disjointWith",\n    "digestive system"\n  ],\n  [\n    "circulatory system",\n    "disjointWith",\n    "excretory system"\n  ],\n  [\n    "circulatory system",\n    "disjointWith",\n    "immune system"\n  ],\n  [\n    "circulatory system",\n    "disjointWith",\n    "integumental system"\n  ],\n  [\n    "circulatory system",\n    "disjointWith",\n    "musculoskeletal system"\n  ],\n  [\n    "circulatory system",\n    "disjointWith",\n    "nervous system"\n  ],\n  [\n    "circulatory system",\n    "disjointWith",\n    "reproductive system"\n  ],\n  [\n    "circulatory system",\n    "disjointWith",\n    "respiratory system"\n  ],\n  [\n    "clay",\n    "seeAlso",\n    "mudstone"\n  ],\n  [\n    "closed",\n    "disjointWith",\n    "open"\n  ],\n  [\n    "collective plant organ structure",\n    "seeAlso",\n    "plant organ"\n  ],\n  [\n    "continental shelf",\n    "disconnected_from",\n    "oceanic island"\n  ],\n  [\n    "continuant",\n    "disjointWith",\n    "occurrent"\n  ],\n  [\n    "cowpea (pulse) food product",\n    "disjointWith",\n    "cowpea vegetable food product"\n  ],\n  [\n    "cowpea vegetable food product",\n    "disjointWith",\n    "cowpea (pulse) food product"\n  ],\n  [\n    "crevasse",\n    "seeAlso",\n    "crevice"\n  ],\n  [\n    "crevice",\n    "seeAlso",\n    "crevasse"\n  ],\n  [\n    "dead cave",\n    "disjointWith",\n    "live cave"\n  ],\n  [\n    "digestive system",\n    "disjointWith",\n    "circulatory system"\n  ],\n  [\n    "digestive system",\n    "disjointWith",\n    "excretory system"\n  ],\n  [\n    "digestive system",\n    "disjointWith",\n    "immune system"\n  ],\n  [\n    "digestive system",\n    "disjointWith",\n    "integumental system"\n  ],\n  [\n    "digestive system",\n    "disjointWith",\n    "musculoskeletal system"\n  ],\n  [\n    "digestive system",\n    "disjointWith",\n    "nervous system"\n  ],\n  [\n    "digestive system",\n    "disjointWith",\n    "reproductive system"\n  ],\n  [\n    "digestive system",\n    "disjointWith",\n    "respiratory system"\n  ],\n  [\n    "dimictic lake",\n    "disjointWith",\n    "monomictic lake"\n  ],\n  [\n    "dimictic lake",\n    "disjointWith",\n    "polymictic lake"\n  ],\n  [\n    "dimictic lake",\n    "seeAlso",\n    "holomictic lake"\n  ],\n  [\n    "disposition",\n    "disjointWith",\n    "process"\n  ],\n  [\n    "disposition",\n    "disjointWith",\n    "quality"\n  ],\n  [\n    "disposition",\n    "disjointWith",\n    "role"\n  ],\n  [\n    "distributed",\n    "disjointWith",\n    "aggregated"\n  ],\n  [\n    "ecoregion",\n    "seeAlso",\n    "biome"\n  ],\n  [\n    "ecoregion",\n    "seeAlso",\n    "ecozone"\n  ],\n  [\n    "ecozone",\n    "seeAlso",\n    "biome"\n  ],\n  [\n    "ecozone",\n    "seeAlso",\n    "ecoregion"\n  ],\n  [\n    "edible",\n    "disjointWith",\n    "inedible"\n  ],\n  [\n    "elastic",\n    "disjointWith",\n    "inelastic"\n  ],\n  [\n    "entire sense  ...

# %%
final_prep_output = []
for output_1 in response_final:
    response_dict = json.loads(output_1)
    for ind_output in response_dict:
        final_prep_output.append({
            "head":ind_output[0],
            "relation":ind_output[1],
            "tail":ind_output[2]
        })

# %%
len(final_prep_output)
# Out:
# 208

# %%
final_prep_output
# Out:
# [{'head': 'aerobic', 'relation': 'disjointWith', 'tail': 'anaerobic'},
#  {'head': 'aggregated', 'relation': 'disjointWith', 'tail': 'distributed'},
#  {'head': 'amictic lake',
#   'relation': 'disjointWith',
#   'tail': 'holomictic lake'},
#  {'head': 'amictic lake',
#   'relation': 'disjointWith',
#   'tail': 'meromictic lake'},
#  {'head': 'anaerobic', 'relation': 'disjointWith', 'tail': 'aerobic'},
#  {'head': 'articular system',
#   'relation': 'seeAlso',
#   'tail': 'musculoskeletal system'},
#  {'head': 'articular system',
#   'relation': 'seeAlso',
#   'tail': 'skeletal system'},
#  {'head': 'biome', 'relation': 'seeAlso', 'tail': 'ecoregion'},
#  {'head': 'biome', 'relation': 'seeAlso', 'tail': 'ecozone'},
#  {'head': 'biome', 'relation': 'seeAlso', 'tail': 'marine ecosystem'},
#  {'head': 'bone element', 'relation': 'seeAlso', 'tail': 'bone tissue'},
#  {'head': 'bone tissue', 'relation': 'disjointWith', 'tail': 'muscle tissue'},
#  {'head': 'bone tissue', 'relation': 'disjointWith', 'tail': 'neural tissue'},
#  {'head': 'bone tissue', 'relation': 'seeAlso', 'tail': 'bone element'},
#  {'head': 'caldera', 'relation': 'seeAlso', 'tail': 'volcanic crater'},
#  {'head': 'circulatory system',
#   'relation': 'disjointWith',
#   'tail': 'digestive system'},
#  {'head': 'circulatory system',
#   'relation': 'disjointWith',
#   'tail': 'excretory system'},
#  {'head': 'circulatory system',
#   'relation': 'disjointWith',
#   'tail': 'immune system'},
#  {'head': 'circulatory system',
#   'relation': 'disjointWith',
#   'tail': 'integumental system'},
#  {'head': 'circulatory system',
#   'relation': 'disjointWith',
#   'tail': 'musculoskeletal system'},
#  {'head': 'circulatory system',
#   'relation': 'disjointWith',
#   'tail': 'nervous system'},
#  {'head': 'circulatory system',
#   'relation': 'disjointWith',
#   'tail': 'reproductive system'},
#  {'head': 'circulatory system',
#   'relation': 'disjointWith',
#   'tail': 'respiratory system'},
#  {'head': 'clay', 'relation': 'seeAlso', 'tail': 'mudstone'},
#  {'head': 'closed', 'relation': 'disjointWith', 'tail': 'open'},
#  {'head': 'collective plant organ structure',
#   'relation': 'seeAlso',
#   'tail': 'plant organ'},
#  {'head': 'continental shelf',
#   'relation': 'disconnected_from',
#   'tail': 'oceanic island'},
#  {'head': 'continuant', 'relation': 'disjointWith', 'tail': 'occurrent'},
#  {'head': 'cowpea (pulse) food product',
#   'relation': 'disjointWith',
#   'tail': 'cowpea vegetable food product'},
#  {'head': 'cowpea vegetable food product',
#   'relation': 'disjointWith',
#   'tail': 'cowpea (pulse) food product'},
#  {'head': 'crevasse', 'relation': 'seeAlso', 'tail': 'crevice'},
#  {'head': 'crevice', 'relation': 'seeAlso', 'tail': 'crevasse'},
#  {'head': 'dead cave', 'relation': 'disjointWith', 'tail': 'live cave'},
#  {'head': 'digestive system',
#   'relation': 'disjointWith',
#   'tail': 'circulatory system'},
#  {'head': 'digestive system',
#   'relation': 'disjointWith',
#   'tail': 'excretory system'},
#  {'head': 'digestive system',
#   'relation': 'disjointWith',
#   'tail': 'immune system'},
#  {'head': 'digestive system',
#   'relation': 'disjointWith',
#   'tail': 'integumental system'},
#  {'head': 'digestive system',
#   'relation': 'disjointWith',
#   'tail': 'musculoskeletal system'},
#  {'head': 'digestive system',
#   'relation': 'disjointWith',
#   'tail': 'nervous system'},
#  {'head': 'digestive system',
#   'relation': 'disjointWith',
#   'tail': 'reproductive system'},
#  {'head': 'digestive system',
#   'relation': 'disjointWith',
#   'tail': 'respiratory system'},
#  {'head': 'dimictic lake',
#   'relation': 'disjointWith',
#   'tail': 'monomictic lake'},
#  {'head': 'dimictic lake',
#   'relation': 'disjointWith',
#   'tail': 'polymictic lake'},
#  {'head': 'dimictic lake', 'relation': 'seeAlso', 'tail': 'holomictic lake'},
#  {'head': 'disposition', 'relation': 'disjointWith', 'tail': 'process'},
#  {'head': 'disposition', 'relation': 'disjointWith', 'tail': 'quality'},
#  {'head': 'disposition', 'relation': 'disjointWith', 'tail': 'role'},
#  {'head': 'distributed', 'relation': 'disjointWith', 'tail': 'aggregated'},
#  {'head': 'ecoregion', 'relation': 'seeAlso', 'tail': 'biome'},
#  {'head': 'ecoregion', 'relation': 'seeAlso', 'tail': 'ecozone'},
#  {'head': 'ecozone', 'relation': 'seeAlso', 'tail': 'biome'},
#  {'head': 'ecozone', 'relation': 'seeAlso', 'tail': 'ecoregion'},
#  {'head': 'edible', 'relation': 'disjointWith', 'tail': 'inedible'},
#  {'head': 'elastic', 'relation': 'disjointWith', 'tail': 'inelastic'},
#  {'head': 'entire sense organ system',
#   'relation': 'seeAlso',
#   'tail': 'nervous system'},
#  {'head': 'excretory system',
#   'relation': 'disjointWith',
#   'tail': 'circulatory system'},
#  {'head': 'excretory system',
#   'relation': 'disjointWith',
#   'tail': 'digestive system'},
#  {'head': 'excretory system',
#   'relation': 'disjointWith',
#   'tail': 'immune system'},
#  {'head': 'excretory system',
#   'relation': 'disjointWith',
#   'tail': 'integumental system'},
#  {'head': 'excretory system',
#   'relation': 'disjointWith',
#   'tail': 'musculoskeletal system'},
#  {'head': 'excretory system',
#   'relation': 'disjointWith',
#   'tail': 'nervous system'},
#  {'head': 'excretory system',
#   'relation': 'disjointWith',
#   'tail': 'reproductive system'},
#  {'head': 'excretory system',
#   'relation': 'disjointWith',
#   'tail': 'respiratory system'},
#  {'head': 'formal settlement',
#   'relation': 'disjointWith',
#   'tail': 'informal settlement'},
#  {'head': 'generically dependent continuant',
#   'relation': 'disjointWith',
#   'tail': 'independent continuant'},
#  {'head': 'generically dependent continuant',
#   'relation': 'disjointWith',
#   'tail': 'specifically dependent continuant'},
#  {'head': 'glacier', 'relation': 'seeAlso', 'tail': 'snow'},
#  {'head': 'glacier', 'relation': 'seeAlso', 'tail': 'water ice'},
#  {'head': 'holomictic lake',
#   'relation': 'disjointWith',
#   'tail': 'amictic lake'},
#  {'head': 'holomictic lake',
#   'relation': 'disjointWith',
#   'tail': 'meromictic lake'},
#  {'head': 'holomictic lake', 'relation': 'seeAlso', 'tail': 'dimictic lake'},
#  {'head': 'holomictic lake', 'relation': 'seeAlso', 'tail': 'monomictic lake'},
#  {'head': 'holomictic lake', 'relation': 'seeAlso', 'tail': 'polymictic lake'},
#  {'head': 'hydrophilicity',
#   'relation': 'disjointWith',
#   'tail': 'hydrophobicity'},
#  {'head': 'hydrophobicity',
#   'relation': 'disjointWith',
#   'tail': 'hydrophilicity'},
#  {'head': 'illegal settlement',
#   'relation': 'disjointWith',
#   'tail': 'legal settlement'},
#  {'head': 'immaterial entity',
#   'relation': 'disjointWith',
#   'tail': 'material entity'},
#  {'head': 'immune system',
#   'relation': 'disjointWith',
#   'tail': 'circulatory system'},
#  {'head': 'immune system',
#   'relation': 'disjointWith',
#   'tail': 'digestive system'},
#  {'head': 'immune system',
#   'relation': 'disjointWith',
#   'tail': 'excretory system'},
#  {'head': 'immune system',
#   'relation': 'disjointWith',
#   'tail': 'integumental system'},
#  {'head': 'immune system',
#   'relation': 'disjointWith',
#   'tail': 'musculoskeletal system'},
#  {'head': 'immune system',
#   'relation': 'disjointWith',
#   'tail': 'nervous system'},
#  {'head': 'immune system',
#   'relation': 'disjointWith',
#   'tail': 'reproductive system'},
#  {'head': 'immune system',
#   'relation': 'disjointWith',
#   'tail': 'respiratory system'},
#  {'head': 'impermeable', 'relation': 'disjointWith', 'tail': 'permeable'},
#  {'head': 'independent continuant',
#   'relation': 'disjointWith',
#   'tail': 'generically dependent continuant'},
#  {'head': 'independent continuant',
#   'relation': 'disjointWith',
#   'tail': 'specifically dependent continuant'},
#  {'head': 'inedible', 'relation': 'disjointWith', 'tail': 'edible'},
#  {'head': 'inelastic', 'relation': 'disjointWith', 'tail': 'elastic'},
#  {'head': 'informal settlement',
#   'relation': 'disjointWith',
#   'tail': 'formal settlement'},
#  {'head': 'integumental system',
#   'relation': 'disjointWith',
#   'tail': 'circulatory system'},
#  {'head': 'integumental system',
#   'relation': 'disjointWith',
#   'tail': 'digestive system'},
#  {'head': 'integumental system',
#   'relation': 'disjointWith',
#   'tail': 'excretory system'},
#  {'head': 'integumental system',
#   'relation': 'disjointWith',
#   'tail': 'immune system'},
#  {'head': 'integumental system',
#   'relation': 'disjointWith',
#   'tail': 'musculoskeletal system'},
#  {'head': 'integumental system',
#   'relation': 'disjointWith',
#   'tail': 'nervous system'},
#  {'head': 'integumental system',
#   'relation': 'disjointWith',
#   'tail': 'reproductive system'},
#  {'head': 'integumental system',
#   'relation': 'disjointWith',
#   'tail': 'respiratory system'},
#  {'head': 'landlocked sea', 'relation': 'seeAlso', 'tail': 'ocean'},
#  {'head': 'legal settlement',
#   'relation': 'disjointWith',
#   'tail': 'illegal settlement'},
#  {'head': 'lime mudstone', 'relation': 'seeAlso', 'tail': 'mudstone'},
#  {'head': 'live cave', 'relation': 'disjointWith', 'tail': 'dead cave'},
#  {'head': 'marine biome', 'relation': 'seeAlso', 'tail': 'marine ecosystem'},
#  {'head': 'marine biome',
#   'relation': 'seeAlso',
#   'tail': 'neritic pelagic zone biome'},
#  {'head': 'marine biome',
#   'relation': 'seeAlso',
#   'tail': 'oceanic pelagic zone biome'},
#  {'head': 'marine ecosystem', 'relation': 'seeAlso', 'tail': 'biome'},
#  {'head': 'marine ecosystem', 'relation': 'seeAlso', 'tail': 'marine biome'},
#  {'head': 'marine water body', 'relation': 'seeAlso', 'tail': 'ocean'},
#  {'head': 'material entity',
#   'relation': 'disjointWith',
#   'tail': 'immaterial entity'},
#  {'head': 'meromictic lake',
#   'relation': 'disjointWith',
#   'tail': 'amictic lake'},
#  {'head': 'meromictic lake',
#   'relation': 'disjointWith',
#   'tail': 'holomictic lake'},
#  {'head': 'mineral material', 'relation': 'seeAlso', 'tail': 'rock'},
#  {'head': 'monomictic lake',
#   'relation': 'disjointWith',
#   'tail': 'dimictic lake'},
#  {'head': 'monomictic lake',
#   'relation': 'disjointWith',
#   'tail': 'polymictic lake'},
#  {'head': 'monomictic lake', 'relation': 'seeAlso', 'tail': 'holomictic lake'},
#  {'head': 'mudstone', 'relation': 'seeAlso', 'tail': 'clay'},
#  {'head': 'mudstone', 'relation': 'seeAlso', 'tail': 'lime mudstone'},
#  {'head': 'mudstone', 'relation': 'seeAlso', 'tail': 'silt'},
#  {'head': 'muscle organ', 'relation': 'seeAlso', 'tail': 'muscle tissue'},
#  {'head': 'muscle tissue', 'relation': 'disjointWith', 'tail': 'bone tissue'},
#  {'head': 'muscle tissue',
#   'relation': 'disjointWith',
#   'tail': 'neural tissue'},
#  {'head': 'muscle tissue', 'relation': 'seeAlso', 'tail': 'muscle organ'},
#  {'head': 'musculoskeletal system',
#   'relation': 'disjointWith',
#   'tail': 'circulatory system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'disjointWith',
#   'tail': 'digestive system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'disjointWith',
#   'tail': 'excretory system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'disjointWith',
#   'tail': 'immune system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'disjointWith',
#   'tail': 'integumental system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'disjointWith',
#   'tail': 'nervous system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'disjointWith',
#   'tail': 'reproductive system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'disjointWith',
#   'tail': 'respiratory system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'seeAlso',
#   'tail': 'articular system'},
#  {'head': 'musculoskeletal system',
#   'relation': 'seeAlso',
#   'tail': 'skeletal system'},
#  {'head': 'musculoskeletal system', 'relation': 'seeAlso', 'tail': 'skeleton'},
#  {'head': 'neritic pelagic zone biome',
#   'relation': 'seeAlso',
#   'tail': 'marine biome'},
#  {'head': 'nervous system',
#   'relation': 'disjointWith',
#   'tail': 'circulatory system'},
#  {'head': 'nervous system',
#   'relation': 'disjointWith',
#   'tail': 'digestive system'},
#  {'head': 'nervous system',
#   'relation': 'disjointWith',
#   'tail': 'excretory system'},
#  {'head': 'nervous system',
#   'relation': 'disjointWith',
#   'tail': 'immune system'},
#  {'head': 'nervous system',
#   'relation': 'disjointWith',
#   'tail': 'integumental system'},
#  {'head': 'nervous system',
#   'relation': 'disjointWith',
#   'tail': 'musculoskeletal system'},
#  {'head': 'nervous system',
#   'relation': 'disjointWith',
#   'tail': 'reproductive system'},
#  {'head': 'nervous system',
#   'relation': 'disjointWith',
#   'tail': 'respiratory system'},
#  {'head': 'nervous system',
#   'relation': 'seeAlso',
#   'tail': 'entire sense organ system'},
#  {'head': 'neural tissue', 'relation': 'disjointWith', 'tail': 'bone tissue'},
#  {'head': 'neural tissue',
#   'relation': 'disjointWith',
#   'tail': 'muscle tissue'},
#  {'head': 'non-porous', 'relation': 'disjointWith', 'tail': 'porous'},
#  {'head': 'nonsynovial joint',
#   'relation': 'disjointWith',
#   'tail': 'synovial joint'},
#  {'head': 'nonsynovial joint',
#   'relation': 'seeAlso',
#   'tail': 'skeletal joint'},
#  {'head': 'occurrent', 'relation': 'disjointWith', 'tail': 'continuant'},
#  {'head': 'ocean', 'relation': 'seeAlso', 'tail': 'landlocked sea'},
#  {'head': 'ocean', 'relation': 'seeAlso', 'tail': 'marine water body'},
#  {'head': 'oceanic island',
#   'relation': 'disconnected_from',
#   'tail': 'continental shelf'},
#  {'head': 'oceanic pelagic zone biome',
#   'relation': 'seeAlso',
#   'tail': 'marine biome'},
#  {'head': 'open', 'relation': 'disjointWith', 'tail': 'closed'},
#  {'head': 'particle of sand', 'relation': 'seeAlso', 'tail': 'sand'},
#  {'head': 'permeable', 'relation': 'disjointWith', 'tail': 'impermeable'},
#  {'head': 'plant organ',
#   'relation': 'seeAlso',
#   'tail': 'collective plant organ structure'},
#  {'head': 'plant organ',
#   'relation': 'seeAlso',
#   'tail': 'portion of plant tissue'},
#  {'head': 'polymictic lake',
#   'relation': 'disjointWith',
#   'tail': 'dimictic lake'},
#  {'head': 'polymictic lake',
#   'relation': 'disjointWith',
#   'tail': 'monomictic lake'},
#  {'head': 'polymictic lake', 'relation': 'seeAlso', 'tail': 'holomictic lake'},
#  {'head': 'porous', 'relation': 'disjointWith', 'tail': 'non-porous'},
#  {'head': 'portion of plant tissue',
#   'relation': 'seeAlso',
#   'tail': 'plant organ'},
#  {'head': 'process', 'relation': 'disjointWith', 'tail': 'disposition'},
#  {'head': 'process', 'relation': 'disjointWith', 'tail': 'quality'},
#  {'head': 'process', 'relation': 'disjointWith', 'tail': 'role'},
#  {'head': 'quality', 'relation': 'disjointWith', 'tail': 'disposition'},
#  {'head': 'quality', 'relation': 'disjointWith', 'tail': 'process'},
#  {'head': 'quality', 'relation': 'disjointWith', 'tail': 'role'},
#  {'head': 'reproductive system',
#   'relation': 'disjointWith',
#   'tail': 'circulatory system'},
#  {'head': 'reproductive system',
#   'relation': 'disjointWith',
#   'tail': 'digestive system'},
#  {'head': 'reproductive system',
#   'relation': 'disjointWith',
#   'tail': 'excretory system'},
#  {'head': 'reproductive system',
#   'relation': 'disjointWith',
#   'tail': 'immune system'},
#  {'head': 'reproductive system',
#   'relation': 'disjointWith',
#   'tail': 'integumental system'},
#  {'head': 'reproductive system',
#   'relation': 'disjointWith',
#   'tail': 'musculoskeletal system'},
#  {'head': 'reproductive system',
#   'relation': 'disjointWith',
#   'tail': 'nervous system'},
#  {'head': 'reproductive system',
#   'relation': 'disjointWith',
#   'tail': 'respiratory system'},
#  {'head': 'respiratory system',
#   'relation': 'disjointWith',
#   'tail': 'circulatory system'},
#  {'head': 'respiratory system',
#   'relation': 'disjointWith',
#   'tail': 'digestive system'},
#  {'head': 'respiratory system',
#   'relation': 'disjointWith',
#   'tail': 'excretory system'},
#  {'head': 'respiratory system',
#   'relation': 'disjointWith',
#   'tail': 'immune system'},
#  {'head': 'respiratory system',
#   'relation': 'disjointWith',
#   'tail': 'integumental system'},
#  {'head': 'respiratory system',
#   'relation': 'disjointWith',
#   'tail': 'musculoskeletal system'},
#  {'head': 'respiratory system',
#   'relation': 'disjointWith',
#   'tail': 'nervous system'},
#  {'head': 'respiratory system',
#   'relation': 'disjointWith',
#   'tail': 'reproductive system'},
#  {'head': 'rock', 'relation': 'seeAlso', 'tail': 'mineral material'},
#  {'head': 'role', 'relation': 'disjointWith', 'tail': 'disposition'},
#  {'head': 'role', 'relation': 'disjointWith', 'tail': 'process'},
#  {'head': 'role', 'relation': 'disjointWith', 'tail': 'quality'},
#  {'head': 'root system', 'relation': 'disjointWith', 'tail': 'shoot system'},
#  {'head': 'sand', 'relation': 'seeAlso', 'tail': 'particle of sand'},
#  {'head': 'shoot system', 'relation': 'disjointWith', 'tail': 'root system'},
#  {'head': 'silt', 'relation': 'seeAlso', 'tail': 'mudstone'},
#  {'head': 'skeletal joint',
#   'relation': 'seeAlso',
#   'tail': 'nonsynovial joint'},
#  {'head': 'skeletal joint', 'relation': 'seeAlso', 'tail': 'synovial joint'},
#  {'head': 'skeletal system',
#   'relation': 'equivalentClass',
#   'tail': 'skeleton'},
#  {'head': 'skeletal system',
#   'relation': 'seeAlso',
#   'tail': 'articular system'},
#  {'head': 'skeletal system',
#   'relation': 'seeAlso',
#   'tail': 'musculoskeletal system'},
#  {'head': 'skeleton',
#   'relation': 'equivalentClass',
#   'tail': 'skeletal system'},
#  {'head': 'skeleton', 'relation': 'seeAlso', 'tail': 'musculoskeletal system'},
#  {'head': 'snow', 'relation': 'seeAlso', 'tail': 'glacier'},
#  {'head': 'specifically dependent continuant',
#   'relation': 'disjointWith',
#   'tail': 'generically dependent continuant'},
#  {'head': 'specifically dependent continuant',
#   'relation': 'disjointWith',
#   'tail': 'independent continuant'},
#  {'head': 'synovial joint',
#   'relation': 'disjointWith',
#   'tail': 'nonsynovial joint'},
#  {'head': 'synovial joint', 'relation': 'seeAlso', 'tail': 'skeletal joint'},
#  {'head': 'volcanic crater', 'relation': 'seeAlso', 'tail': 'caldera'},
#  {'head': 'water ice', 'relation': 'seeAlso', 'tail': 'glacier'}]

# %%
# final_prepared_train_data = []
# for data_1 in train_data:
import json
with open("predictions_BILND_llm_re_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_prep_output, f, indent=2, ensure_ascii=False)
