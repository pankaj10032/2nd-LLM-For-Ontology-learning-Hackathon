# %%
import json
def load_json(data_path):
    with open(data_path, "r") as file_1:
        data = json.load(file_1)
    return data

# %%
test_data = []
with open("FoodOn/test/foodon_test_re_types.txt", "r", encoding="utf-8") as file:
    content = file.readlines()
    for con in content:
        test_data.append(con.strip('\n'))

print(test_data)
# Out:
# ['obsolete: hollyhock plant', 'Selar crumenophthalmus', 'Lycium chinense', 'Metanephrops australiensis', 'Pseudupeneus prayensis', 'Oxynotus centrina', 'Haliotis asinina', 'obsolete: taimen', 'Conodon nobilis', 'obsolete: sodium chloride', 'Psophocarpus tetragonolobus', 'obsolete: yellow perch', 'Corbicula fluminea', 'obsolete: long grain brown rice kernel (uncooked)', 'obsolete: red cod', 'Coregonus artedi', 'obsolete: cape hake', 'obsolete: actinomycetales', 'obsolete: ocean sunfish', 'obsolete: sweet basil plant', 'Conger conger', 'field corn kernel (dried)', 'obsolete: thorn-apple plant', 'obsolete: red hawaiian porgy', 'obsolete: spanish cherry plant', 'langostino amarillo (raw)', 'Pseudocaranx wrighti', 'obsolete: common snook', 'Amaranthus blitum', 'Oncorhynchus gorbuscha', 'Coregonus pidschian', 'obsolete: black gram bean plant', 'Gymnachirus melas', 'Chaceon granulatus', 'obsolete: red kingklip', 'Dioscorea bulbifera', 'obsolete: chicken-flavored soup cube', 'Opisthonema libertate', 'Phaseolus acutifolius', 'obsolete: slime flounder', 'obsolete: butternut squash plant', 'obsolete: horse-eye jack', 'obsolete: common quail', 'Mustelus lenticulatus', 'Gobius niger', 'obsolete: nursehound', 'obsolete: sago palm plant', 'obsolete: atlantic lizardfish', 'obsolete: common rye plant', 'Acanthopagrus australis', 'Haliotis corrugata', 'obsolete: capelin', 'obsolete: widow rockfish', 'Levisticum officinale', 'obsolete: muster john henry plant', 'Menticirrhus saxatilis', 'obsolete: greater rhea', 'cabbage plant', 'Urophycis chuss', 'Atractoscion aequidens', 'obsolete: black raspberry plant', 'berry juice', 'obsolete: herb bennet plant', 'obsolete: sea aster plant', 'Linospadix monostachyos', 'Littorina littorea', 'obsolete: cape verde spiny lobster', 'fruit seed (anatomical part)', 'obsolete cape hake', 'obsolete: cunene horse mackerel', 'Isurus paucus', 'Helix pomatia', 'obsolete: kawakawa', 'obsolete: oil sardine', 'obsolete: common vetch plant', 'Arca imbricata', 'obsolete: burnet-saxifrage plant', 'obsolete: nile perch', 'obsolete: jonah crab', 'Simmondsia chinensis', 'obsolete: orange roughy', 'obsolete: barbados aloe plant', 'carbohydrates and carbohydrate derivatives', 'Avena sativa', 'Atriplex hortensis', 'obsolete: sweet violet plant', 'obsolete: amarillo snapper', 'Metanephrops sibogae', 'obsolete: african weakfish', 'obsolete: california cockle', 'obsolete: wineberry plant', 'obsolete: common millet plant', 'obsolete: no dietary claim or use', 'obsolete: monantha vetch plant', 'Penaeus monodon', 'obsolete: northern australian snapping turtle', 'skeletal meat part, without bone, with skin', 'Scomberomorus maculatus', 'Scorpaena cardinalis', 'Seriola dumerili', 'Dallia pectoralis', 'concentration of calcium dichloride in material entity', 'Mimusops elengi', 'Casimiroa edulis', 'obsolete: brazilian catfish', 'obsolete: california halibut', 'Etelis oculatus', 'Epinephelus malabaricus', 'Galeopsis segetum', 'Spisula solidissima', 'glucosamine supplement', 'obsolete: oregano plant', 'Scomberomorus plurilineatus', 'obsolete: flat abalone', 'Coregonus albula', 'Lutjanus griseus', 'obsolete: snow crab', 'Scardinius graecus', 'Hordeum vulgare subsp. vulgare', 'obsolete: starry skate', 'Origanum majorana', 'Rana dalmatina', 'Tagetes minuta', 'chickpea (dried)', 'obsolete: chinese chestnut tree', 'obsolete: red swamp crayfish', 'Vigna radiata', 'obsolete: silver barb', 'obsolete: black abalone', 'Squatina californica', 'Himanthalia elongata', 'obsolete: pigeon pea plant', 'Valerianella locusta', 'obsolete: zebra', 'Belone belone', 'obsolete: juan fernandez rock lobster', 'Prionace glauca', 'concentration of lysophosphatidylcholine in material entity', 'obsolete: european smelt', 'Boletaceae', 'obsolete: sweet marjoram plant', 'Viola odorata', 'Diospyros texana', 'somiviki', 'obsolete: chilean horse mackerel', 'Sander canadensis', 'Nematalosa come', 'obsolete: neptune lobster', 'Nemapteryx nenga', 'Lepomis macrochirus', 'Ascophyllu ...

# %%
test_relations = ['database_cross_reference', 'disjointWith', 'term replaced by','seeAlso']

# %%
from google import genai
model = "gemini-2.5-flash"
client= genai.Client(api_key="")

# %%
# prompt = f"""
# You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning, specializing in the SWEET (Semantic Web for Earth and Environmental Terminology) ontology. Developed by NASA’s Jet Propulsion Laboratory, SWEET is a user-friendly, standardized framework for organizing Earth and environmental science concepts. It includes terms like Earth realms (e.g., 'Ocean', 'Atmosphere'), substances (e.g., 'Water', 'Ice'), natural phenomena, and processes, connected by relationships such as 'hasState' (e.g., Water turns into Ice), 'hasPart' (e.g., Ocean includes Sea), and 'isComposedOf'. This structure makes scientific data clear and computer-readable, enabling better connections across environmental information.

# Your task is to group a list of terms into clusters based on specific relationships from the SWEET ontology, using your domain knowledge to determine connections. You’ll receive two inputs:
# 1. A list of terms: ['Ocean', 'Sea', 'River', 'Lake', 'Water', 'Ice', 'Glacier', 'Atmosphere', 'Oxygen', 'CarbonDioxide', 'Rock', 'Magma'].
# 2. A list of clustering relationships: ['hasPart', 'isComposedOf', 'hasState'].

# Here’s what you need to do:
# - Build the Graph:
#   - Treat each term as a point (node) in a graph.
#   - Using your knowledge of the SWEET ontology, check every pair of terms in the input list to see if they could be connected by any of the clustering relationships ('hasPart', 'isComposedOf', 'hasState'). If a pair can be connected by one of these relationships (e.g., 'Ocean' and 'Sea' via 'hasPart', or 'Water' and 'Ice' via 'hasState'), create a two-way (undirected) link between them.
#   - Handle special cases:
#     - If the terms list is empty, return an empty list of clusters: [].
#     - If the clustering relationships list is empty, place each term in its own cluster.
#     - If no valid connections can be inferred between any pairs based on SWEET ontology knowledge, each term forms its own cluster.
# - Form Clusters:
#   - Group terms into clusters where terms are connected directly or indirectly through the clustering relationships.
#   - Terms with no connections form their own single-term clusters.
#   - Ensure every term from the input list appears in the output, even if alone.
# - Output:
#   - Return a Python list of lists, where each inner list contains the terms in a cluster.
#   - Don’t include relationships in the output, only the grouped terms.
#   - Sort clusters alphabetically by the first term in each cluster.
#   - Within each cluster, sort terms alphabetically.

# Task:
# Group the following terms into clusters using the provided clustering relationships. For each pair of terms, use your SWEET ontology knowledge to determine if they can be connected by 'hasPart', 'isComposedOf', or 'hasState'. If they can, place them in the same cluster. Repeat for all pairs:
# - List of Terms: {test_data}
# - List of Clustering Relationships: {test_relations}

# Based on SWEET ontology patterns, infer connections such as: 'Ocean' hasPart 'Sea', 'Water' hasState 'Ice', 'Glacier' isComposedOf 'Ice', 'River' isComposedOf 'Water', 'Lake' isComposedOf 'Water', 'Sea' isComposedOf 'Water', 'Magma' hasState 'Rock', 'Atmosphere' isComposedOf 'Oxygen', 'Atmosphere' isComposedOf 'CarbonDioxide'.

# Return the result as a Python list of lists, where each inner list represents a cluster of terms.
# """

# %%
prompt = f"""You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning, specializing in the **FoodOn ontology**. FoodOn is a comprehensive, farm-to-fork ontology for describing food, covering its origins from plants and animals, its ingredients, and the processes it undergoes. It connects concepts like 'Cow', 'Milk', and 'Cheese' using relationships such as **'is derived from'**, **'has ingredient'**, and **'is part of'**. This structure enables clear, computer-readable data for food traceability, safety analysis, and nutritional research.

Your task is to group a list of food-related terms into clusters based on specific relationships from the FoodOn ontology, using your domain knowledge to determine the connections. You’ll receive two inputs:
1.  A list of terms.
2.  A list of clustering relationships.

Here’s what you need to do:
- **Build the Graph:**
  - Treat each term as a point (node) in a graph.
  - Using your knowledge of the FoodOn ontology, check every pair of terms in the input list to see if they could be connected by any of the **clustering relationships**. If a pair can be connected by one of these relationships (e.g., 'Milk' and 'Cow' via 'is derived from', or 'Bread' and 'Flour' via 'has ingredient'), create a two-way (undirected) link between them.
  - **Handle special cases:**
    - If the terms list is empty, return an empty list of clusters: [].
    - If the clustering relationships list is empty, place each term in its own cluster.
    - If no valid connections can be inferred between any pairs based on FoodOn ontology knowledge, each term forms its own cluster.
- **Form Clusters:**
  - Group terms into clusters where terms are connected directly or indirectly through the specified clustering relationships.
  - Terms with no connections form their own single-term clusters.
  - Ensure every term from the input list appears in the output, even if alone.
- **Output:**
  - Return a Python list of lists, where each inner list contains the terms in a cluster.
  - Do not include the relationships in the output, only the grouped terms.
  - Sort the clusters alphabetically by the first term in each cluster.
  - Within each cluster, sort the terms alphabetically.

**Task:**
Group the following terms into clusters using the provided clustering relationships. For each pair of terms, use your FoodOn ontology knowledge to determine if they can be connected by 'is derived from', 'has ingredient', or 'is part of'. If they can, place them in the same cluster. Repeat for all pairs:
- **List of Terms:** {test_data}
- **List of Clustering Relationships:** {test_relations}

Return the result as a Python list of lists, where each inner list represents a cluster of terms."""

# %%
len(prompt)
# Out:
# 35724

# %%
generation_config = {"response_mime_type": "application/json"}

response = client.models.generate_content(
        contents= prompt,
        config=generation_config,
        model=model
    )

# %%
response_1 = response.text
response_1
# Out:
# '[\n  [\n    "Acanthopagrus australis"\n  ],\n  [\n    "Acipenser naccarii",\n    "obsolete: adriatic sturgeon"\n  ],\n  [\n    "Acipenser ruthenus",\n    "obsolete: sterlet"\n  ],\n  [\n    "Acipenser transmontanus",\n    "obsolete: white sturgeon"\n  ],\n  [\n    "Actinidia chinensis",\n    "obsolete: kiwifruit plant (A. chinensis)"\n  ],\n  [\n    "Actinidia deliciosa",\n    "obsolete: kiwifruit plant (A. deliciosa)"\n  ],\n  [\n    "Actinomycetales",\n    "Bacteria",\n    "Homo sapiens",\n    "Rickettsiales",\n    "amphibian",\n    "obsolete: actinomycetales",\n    "obsolete: bacteria",\n    "obsolete: rickettsiales",\n    "reptile"\n  ],\n  [\n    "Adansonia digitata"\n  ],\n  [\n    "Aframomum melegueta",\n    "obsolete: grains-of-paradise plant"\n  ],\n  [\n    "Alectis ciliaris",\n    "obsolete: african pompano",\n    "obsolete: alexandria pompano",\n    "obsolete: skipjack trevally"\n  ],\n  [\n    "Aldrichetta forsteri",\n    "obsolete: dusky sea perch",\n    "obsolete: velvet leatherjacket"\n  ],\n  [\n    "Alepocephalus bairdii"\n  ],\n  [\n    "Alcea rosea",\n    "obsolete: hollyhock plant"\n  ],\n  [\n    "alcoholic beverage (distilled)",\n    "flaxseed oil",\n    "obsolete: plant derived distilled spirit",\n    "obsolete: spirits"\n  ],\n  [\n    "Alligator sinensis",\n    "obsolete: chinese alligator"\n  ],\n  [\n    "Allium chinense",\n    "obsolete: chinese onion plant"\n  ],\n  [\n    "Allocyttus folletti",\n    "obsolete: oxeye oreo"\n  ],\n  [\n    "Allocyttus niger",\n    "obsolete: black oreo dory"\n  ],\n  [\n    "Aloe vera",\n    "obsolete: barbados aloe plant"\n  ],\n  [\n    "Alosa alosa",\n    "obsolete: allis shad"\n  ],\n  [\n    "Amaranthus blitum"\n  ],\n  [\n    "Amaranthus cruentus"\n  ],\n  [\n    "Amaranthus hypochondriacus",\n    "obsolete: red amaranth plant"\n  ],\n  [\n    "ambarella plant",\n    "Spondias dulcis"\n  ],\n  [\n    "Ammodytes americanus",\n    "obsolete: american sand lance"\n  ],\n  [\n    "Ammodytes hexapterus",\n    "obsolete: pacific sand lance"\n  ],\n  [\n    "Amorphophallus paeoniifolius",\n    "obsolete: air potato plant",\n    "obsolete: tarovine plant"\n  ],\n  [\n    "Anacardium occidentale",\n    "nut food product",\n    "obsolete: cashew plant",\n    "obsolete: oriental cashew plant"\n  ],\n  [\n    "Anarhichas minor"\n  ],\n  [\n    "Anchoa mitchilli",\n    "obsolete: bay anchovy"\n  ],\n  [\n    "Anguilla rostrata",\n    "obsolete: american eel"\n  ],\n  [\n    "animal as food consumer",\n    "Bison",\n    "Bos frontalis",\n    "Chaceon granulatus",\n    "Chionoecetes opilio",\n    "Conodon nobilis",\n    "Coregonus albula",\n    "Coregonus artedi",\n    "Coregonus clupeaformis",\n    "Coregonus lavaretus",\n    "Coregonus pidschian",\n    "Cornu aspersum",\n    "Coturnix coturnix",\n    "crab",\n    "Crangon crangon",\n    "Crangon franciscorum",\n    "Dama dama",\n    "Decapterus maruadsi",\n    "Decapterus russelli",\n    "Decapterus trecae",\n    "Dormitator latifrons",\n    "Dromaius novaehollandiae",\n    "Echinorhinus brucus",\n    "Echinus esculentus",\n    "Eledone moschata",\n    "Elephas maximus",\n    "Elseya dentata",\n    "Engraulis anchoita",\n    "Engraulis australis",\n    "Engraulis encrasicolus",\n    "Epinephelus areolatus",\n    "Epinephelus caninus",\n    "Epinephelus itajara",\n    "Epinephelus malabaricus",\n    "Epinephelus marginatus",\n    "Equus zebra",\n    "Eriphia verrucosa",\n    "Etelis oculatus",\n    "Etmopterus baxteri",\n    "Etrumeus micropus",\n    "Euphausia pacifica",\n    "Euphausia superba",\n    "Euphausia vallentini",\n    "Euthynnus affinis",\n    "Genipa americana",\n    "Genyonemus lineatus",\n    "Genypterus chilensis",\n    "Gobius niger",\n    "Gymnachirus melas",\n    "Haliotis asinina",\n    "Haliotis corrugata",\n    "Haliotis cracherodii",\n    "Haliotis fulgens",\n    "Haliotis kamtschatkana",\n    "Haliotis tuberculata",\n    "Harengula humeralis",\n    "Helix pomatia",\n    "Hippopotamus amphibius",\n ...

# %%
final_output = json.loads(response_1)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 final_output = json.loads(response_1)
#
# File c:\Users\panka\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\panka\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\panka\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 369 column 1 (char 8546)

# %%
final_output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 final_output
#
# NameError: name 'final_output' is not defined

# %%
model="gemini-2.5-flash"

# %%
response_final = []
from tqdm import tqdm
for i, term_cluster in tqdm(enumerate(final_output)):
    prompt=f"""
You are an expert AI assistant with deep expertise in knowledge graphs and ontology reasoning, specializing in the SWEET (Semantic Web for Earth and Environmental Terminology) ontology. Developed by NASA’s Jet Propulsion Laboratory, SWEET is a user-friendly, standardized framework for organizing Earth and environmental science concepts. It includes terms like Earth realms (e.g., 'Ocean', 'Atmosphere'), substances (e.g., 'Water', 'Ice'), natural phenomena, and processes, linked by relationships such as 'hasState' (e.g., Water turns into Ice), 'hasPart' (e.g., Ocean includes Sea), and 'isComposedOf'. This structure makes scientific data clear and computer-readable, enabling better connections across environmental information.

Your task is to take a single cluster of terms and a list of clustering relationships, and generate all possible relationship triples (head, relation, tail) between terms within that cluster, using only the specified relationships. You’ll receive two inputs:
1. A single cluster, which is a list of terms (e.g., ['abyssal trench', 'deep sea trench']).
2. A list of clustering relationships: ['hasPart', 'isComposedOf', 'hasState'].

Here’s what you need to do:
- Process the Cluster:
  - Examine all pairs of terms within the given cluster.
  - Using your knowledge of the SWEET ontology, determine if a pair can be connected by one of the clustering relationships ('hasPart', 'isComposedOf', 'hasState'). If so, create a triple (head, relation, tail).
  - Only include triples where both head and tail are terms within the cluster and the relation is in the clustering relationships list.
- Handle Special Cases:
  - If the cluster has only one term, return an empty list, as no pairs are possible.
  - If no valid relationships can be inferred for any pair in the cluster based on SWEET ontology knowledge, return an empty list.
  - If the cluster is empty, return an empty list: [].
  - If the clustering relationships list is empty, return an empty list.
- Output:
  - Return a Python list containing triples (as tuples) for the given cluster.
  - Each triple is in the format (head, relation, tail), where head and tail are terms from the cluster, and relation is one of the clustering relationships.
  - Sort the triples alphabetically by head, then relation, then tail.

Task:
For the given cluster of terms, generate all possible relationship triples (head, relation, tail) using the given clustering relationships {test_relations}. Use your SWEET ontology knowledge to infer valid relationships within the cluster.

Here is the list of terms {term_cluster}

Return the result as a Python list of triples for the given cluster.
"""
    generation_config = {"response_mime_type": "application/json"}

    response = client.models.generate_content(
            contents= prompt,
            config=generation_config,
            model=model
        )
    response_final.append(response.text)
    if i%10==0:
        print(response.text)

# %%
response_final
# Out:
# ['[\n  [\n    "abyssal trench",\n    "equivalentClass",\n    "deep sea trench"\n  ],\n  [\n    "deep sea trench",\n    "equivalentClass",\n    "abyssal trench"\n  ]\n]',
#  '[\n    [\n        "acoustic wave",\n        "equivalentClass",\n        "sound wave"\n    ],\n    [\n        "sound wave",\n        "equivalentClass",\n        "acoustic wave"\n    ]\n]',
#  '[]',
#  '[\n  [\n    "aeolian",\n    "equivalentClass",\n    "eolian"\n  ],\n  [\n    "eolian",\n    "equivalentClass",\n    "aeolian"\n  ]\n]',
#  '[\n  [\n    "air sea exchange",\n    "equivalentClass",\n    "atmosphere ocean exchange"\n  ],\n  [\n    "atmosphere ocean exchange",\n    "equivalentClass",\n    "air sea exchange"\n  ]\n]',
#  '[\n  [\n    "airborne toxic control measure",\n    "equivalentClass",\n    "atcm"\n  ],\n  [\n    "atcm",\n    "equivalentClass",\n    "airborne toxic control measure"\n  ]\n]',
#  '[\n  [\n    "archive",\n    "disjointWith",\n    "archiving"\n  ],\n  [\n    "archiving",\n    "disjointWith",\n    "archive"\n  ]\n]',
#  '[\n    [\n        "attenuation coefficient",\n        "equivalentClass",\n        "extinction coefficient"\n    ],\n    [\n        "extinction coefficient",\n        "equivalentClass",\n        "attenuation coefficient"\n    ]\n]',
#  '[\n  [\n    "autotroph",\n    "disjointWith",\n    "heterotroph"\n  ],\n  [\n    "heterotroph",\n    "disjointWith",\n    "autotroph"\n  ]\n]',
#  '[\n  [\n    "average",\n    "equivalentClass",\n    "mean"\n  ],\n  [\n    "mean",\n    "equivalentClass",\n    "average"\n  ]\n]',
#  '[\n  [\n    "bag",\n    "equivalentClass",\n    "multiset"\n  ],\n  [\n    "multiset",\n    "equivalentClass",\n    "bag"\n  ]\n]',
#  '[\n  [\n    "bdoc",\n    "equivalentClass",\n    "biodegradable dissolved organic carbon"\n  ],\n  [\n    "biodegradable dissolved organic carbon",\n    "equivalentClass",\n    "bdoc"\n  ],\n  [\n    "dissolved organic carbon",\n    "equivalentClass",\n    "doc"\n  ],\n  [\n    "doc",\n    "equivalentClass",\n    "dissolved organic carbon"\n  ]\n]',
#  '[]',
#  '[\n  [\n    "bed load",\n    "disjointWith",\n    "suspended load"\n  ],\n  [\n    "bed load",\n    "disjointWith",\n    "wash load"\n  ],\n  [\n    "suspended load",\n    "disjointWith",\n    "bed load"\n  ],\n  [\n    "wash load",\n    "disjointWith",\n    "bed load"\n  ]\n]',
#  '[]',
#  '[]',
#  '[\n  [\n    "brightness",\n    "disjointWith",\n    "specific intensity"\n  ],\n  [\n    "specific intensity",\n    "disjointWith",\n    "brightness"\n  ]\n]',
#  '[]',
#  '[\n    [\n        "budget",\n        "disjointWith",\n        "budget equation"\n    ],\n    [\n        "budget equation",\n        "disjointWith",\n        "budget"\n    ]\n]',
#  '[\n  [\n    "c horizon",\n    "disjointWith",\n    "parent rock"\n  ],\n  [\n    "c horizon",\n    "disjointWith",\n    "surface soil"\n  ],\n  [\n    "c horizon",\n    "disjointWith",\n    "topsoil"\n  ],\n  [\n    "horizon",\n    "disjointWith",\n    "parent rock"\n  ],\n  [\n    "parent rock",\n    "disjointWith",\n    "c horizon"\n  ],\n  [\n    "parent rock",\n    "disjointWith",\n    "horizon"\n  ],\n  [\n    "parent rock",\n    "disjointWith",\n    "surface soil"\n  ],\n  [\n    "parent rock",\n    "disjointWith",\n    "topsoil"\n  ],\n  [\n    "substrata",\n    "disjointWith",\n    "surface soil"\n  ],\n  [\n    "substrata",\n    "disjointWith",\n    "topsoil"\n  ],\n  [\n    "substrata",\n    "equivalentClass",\n    "substratum"\n  ],\n  [\n    "substratum",\n    "disjointWith",\n    "surface soil"\n  ],\n  [\n    "substratum",\n    "disjointWith",\n    "topsoil"\n  ],\n  [\n    "substratum",\n    "equivalentClass",\n    "substrata"\n  ],\n  [\n    "surface soil",\n    "disjointWith",\n    "c horizon"\n  ],\n  [\n    "surface soil",\n    "disjointWith",\n    "parent rock"\n  ],\n  [\n    "surface soil",\n    "disjointWith",\n    "substrata"\n  ],\n  [\n    "surface soil",\n    "disjointWith",\n    "substratum"\n  ],\n  [\n    "surface soil",\n    "equivalentClass",\n    "topsoil"\n  ],\n  [\n    "topsoil",\n    "disjointWith",\n    "c horizon"\n  ],\n  [\n    "topsoil",\n    "disjointWith",\n    "parent rock"\n  ],\n  [\n    "topsoil",\n    "disjointWith",\n    "substrata"\n  ],\n  [\n    "topsoil",\n    "disjointWith",\n    "substratum"\n  ],\n  [\n    "topsoil",\n    "equivalentClass",\n    "surface soil"\n  ]\n]',
#  '[\n    [\n        "calving",\n        "equivalentClass",\n        "ice calving"\n    ],\n    [\n        "ice calving",\n        "equivalentClass",\n        "calving"\n    ]\n]',
#  '[\n    [\n        "capillary",\n        "disjointWith",\n        "capillary action"\n    ],\n    [\n        "capillary action",\n        "disjointWith",\n        "capillary"\n    ]\n]',
#  '[\n  [\n    "carbon neutral",\n    "equivalentClass",\n    "carbon neutrality"\n  ],\n  [\n    "carbon neutrality",\n    "equivalentClass",\n    "carbon neutral"\n  ]\n]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[\n    [\n        "clumping",\n        "disjointWith",\n        "clump"\n    ],\n    [\n        "clumping",\n        "disjointWith",\n        "cluster"\n    ],\n    [\n        "clumping",\n        "disjointWith",\n        "swarm"\n    ],\n    [\n        "clump",\n        "disjointWith",\n        "clumping"\n    ],\n    [\n        "clump",\n        "equivalentClass",\n        "cluster"\n    ],\n    [\n        "cluster",\n        "disjointWith",\n        "clumping"\n    ],\n    [\n        "cluster",\n        "equivalentClass",\n        "clump"\n    ],\n    [\n        "swarm",\n        "disjointWith",\n        "clumping"\n    ]\n]',
#  '[\n    [\n        "coastal",\n        "equivalentClass",\n        "coastal region"\n    ],\n    [\n        "coastal region",\n        "equivalentClass",\n        "coastal"\n    ],\n    [\n        "coastal region",\n        "equivalentClass",\n        "littoral zone"\n    ],\n    [\n        "littoral zone",\n        "equivalentClass",\n        "coastal region"\n    ]\n]',
#  '[\n  [\n    "coefficient of thermal expansion",\n    "equivalentClass",\n    "thermal expansion coefficient"\n  ],\n  [\n    "thermal expansion coefficient",\n    "equivalentClass",\n    "coefficient of thermal expansion"\n  ]\n]',
#  '[\n  [\n    "compression",\n    "disjointWith",\n    "decompression"\n  ],\n  [\n    "compression",\n    "disjointWith",\n    "rareification"\n  ],\n  [\n    "decompression",\n    "disjointWith",\n    "compression"\n  ],\n  [\n    "rareification",\n    "disjointWith",\n    "compression"\n  ]\n]',
#  '[\n  [\n    "conic",\n    "equivalentClass",\n    "conic section"\n  ],\n  [\n    "conic section",\n    "equivalentClass",\n    "conic"\n  ]\n]',
#  '[\n  [\n    "continuous",\n    "disjointWith",\n    "discontinuous"\n  ],\n  [\n    "continuous",\n    "disjointWith",\n    "discrete"\n  ],\n  [\n    "continuous",\n    "disjointWith",\n    "discrete function"\n  ],\n  [\n    "discontinuous",\n    "disjointWith",\n    "continuous"\n  ],\n  [\n    "discrete",\n    "disjointWith",\n    "continuous"\n  ],\n  [\n    "discrete function",\n    "disjointWith",\n    "continuous"\n  ]\n]',
#  '[\n    [\n        "convergent boundary",\n        "disjointWith",\n        "divergent boundary"\n    ],\n    [\n        "convergent boundary",\n        "disjointWith",\n        "divergent plate boundary"\n    ],\n    [\n        "convergent boundary",\n        "disjointWith",\n        "plate convergence"\n    ],\n    [\n        "convergent boundary",\n        "disjointWith",\n        "plate divergence"\n    ],\n    [\n        "convergent boundary",\n        "disjointWith",\n        "transform boundary"\n    ],\n    [\n        "convergent boundary",\n        "disjointWith",\n        "transform plate boundary"\n    ],\n    [\n        "convergent boundary",\n        "equivalentClass",\n        "convergent margin"\n    ],\n    [\n        "convergent margin",\n        "disjointWith",\n        "divergent boundary"\n    ],\n    [\n        "convergent margin",\n        "disjointWith",\n        "divergent plate boundary"\n    ],\n    [\n        "convergent margin",\n        "disjointWith",\n        "plate convergence"\n    ],\n    [\n        "convergent margin",\n        "disjointWith",\n        "plate divergence"\n    ],\n    [\n        "convergent margin",\n        "disjointWith",\n        "transform boundary"\n    ],\n    [\n        "convergent margin",\n        "disjointWith",\n        "transform plate boundary"\n    ],\n    [\n        "convergent margin",\n        "equivalentClass",\n        "convergent boundary"\n    ],\n    [\n        "divergent boundary",\n        "disjointWith",\n        "convergent boundary"\n    ],\n    [\n        "divergent boundary",\n        "disjointWith",\n        "convergent margin"\n    ],\n    [\n        "divergent boundary",\n        "disjointWith",\n        "plate convergence"\n    ],\n    [\n        "divergent boundary",\n        "disjointWith",\n        "plate divergence"\n    ],\n    [\n        "divergent boundary",\n        "disjointWith",\n        "transform boundary"\n    ],\n    [\n        "divergent boundary",\n        "disjointWith",\n        "transform plate boundary"\n    ],\n    [\n        "divergent boundary",\n        "equivalentClass",\n        "divergent plate boundary"\n    ],\n    [\n        "divergent plate boundary",\n        "disjointWith",\n        "convergent boundary"\n    ],\n    [\n        "divergent plate boundary",\n        "disjointWith",\n        "convergent margin"\n    ],\n    [\n        "divergent plate boundary",\n        "disjointWith",\n        "plate convergence"\n    ],\n    [\n        "divergent plate boundary",\n        "disjointWith",\n        "plate divergence"\n    ],\n    [\n        "divergent plate boundary",\n        "disjointWith",\n        "transform boundary"\n    ],\n    [\n        "divergent plate boundary",\n        "disjointWith",\n        "transform plate boundary"\n    ],\n    [\n        "divergent plate boundary",\n        "equivalentClass",\n        "divergent boundary"\n    ],\n    [\n        "plate convergence",\n        "disjointWith",\n        "convergent boundary"\n    ],\n    [\n        "plate convergence",\n        "disjointWith",\n        "convergent margin"\n    ],\n    [\n        "plate convergence",\n        "disjointWith",\n        "divergent boundary"\n    ],\n    [\n        "plate convergence",\n        "disjointWith",\n        "divergent plate boundary"\n    ],\n    [\n        "plate convergence",\n        "disjointWith",\n        "plate divergence"\n    ],\n    [\n        "plate convergence",\n        "disjointWith",\n        "transform boundary"\n    ],\n    [\n        "plate convergence",\n        "disjointWith",\n        "transform plate boundary"\n    ],\n    [\n        "plate divergence",\n        "disjointWith",\n        "convergent boundary"\n    ],\n    [\n        "plate divergence",\n        "disjointWith",\n        "convergent margin"\n    ],\n    [\n        "plate divergence",\n        "disjointWith",\n        "divergent boundary"\n    ],\n    [\n        "plate divergence",\n        "disjointWith",\n        "diverg ...
#  '[\n  [\n    "core mantle boundary",\n    "equivalentClass",\n    "guttenburg discontinuity"\n  ],\n  [\n    "guttenburg discontinuity",\n    "equivalentClass",\n    "core mantle boundary"\n  ]\n]',
#  '[]',
#  '[]',
#  '[\n    [\n        "curate",\n        "equivalentClass",\n        "curation"\n    ],\n    [\n        "curation",\n        "equivalentClass",\n        "curate"\n    ]\n]',
#  '[\n  [\n    "cyclotron frequency",\n    "equivalentClass",\n    "gyrofrequency"\n  ],\n  [\n    "gyrofrequency",\n    "equivalentClass",\n    "cyclotron frequency"\n  ]\n]',
#  '[\n    [\n        "decision support system",\n        "equivalentClass",\n        "dss"\n    ],\n    [\n        "dss",\n        "equivalentClass",\n        "decision support system"\n    ]\n]',
#  '[\n  [\n    "deep focus earthquake",\n    "disjointWith",\n    "shallow focus earthquake"\n  ],\n  [\n    "shallow focus earthquake",\n    "disjointWith",\n    "deep focus earthquake"\n  ]\n]',
#  '[]',
#  '[]',
#  '[]',
#  '[\n  [\n    "directed graph",\n    "disjointWith",\n    "undirected graph"\n  ]\n]',
#  '[]',
#  '[\n  [\n    "discover",\n    "disjointWith",\n    "discovery service"\n  ],\n  [\n    "discovery service",\n    "disjointWith",\n    "discover"\n  ]\n]',
#  '[\n    [\n        "division",\n        "disjointWith",\n        "quotient"\n    ],\n    [\n        "quotient",\n        "disjointWith",\n        "division"\n    ]\n]',
#  '[\n  [\n    "dry lake",\n    "equivalentClass",\n    "playa"\n  ],\n  [\n    "playa",\n    "equivalentClass",\n    "dry lake"\n  ]\n]',
#  '[]',
#  '[]',
#  '[\n    [\n        "electromagnetic radiation",\n        "equivalentClass",\n        "electromagnetic wave"\n    ],\n    [\n        "electromagnetic wave",\n        "equivalentClass",\n        "electromagnetic radiation"\n    ]\n]',
#  '[\n    [\n        "elongate",\n        "equivalentClass",\n        "stretch"\n    ],\n    [\n        "stretch",\n        "equivalentClass",\n        "elongate"\n    ]\n]',
#  '[]',
#  '[\n  [\n    "emissivity",\n    "disjointWith",\n    "emittance"\n  ],\n  [\n    "emittance",\n    "disjointWith",\n    "emissivity"\n  ]\n]',
#  '[]',
#  '[]',
#  '[\n  [\n    "environmental sustainability index",\n    "equivalentClass",\n    "esi"\n  ],\n  [\n    "esi",\n    "equivalentClass",\n    "environmental sustainability index"\n  ]\n]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[\n  [\n    "felsic",\n    "disjointWith",\n    "mafic"\n  ],\n  [\n    "mafic",\n    "disjointWith",\n    "felsic"\n  ]\n]',
#  '[]',
#  '[]',
#  '[\n    [\n        "geodetic science",\n        "equivalentClass",\n        "geodesy"\n    ],\n    [\n        "geodetic science",\n        "equivalentClass",\n        "geodetics"\n    ],\n    [\n        "geodesy",\n        "equivalentClass",\n        "geodetic science"\n    ],\n    [\n        "geodesy",\n        "equivalentClass",\n        "geodetics"\n    ],\n    [\n        "geodetics",\n        "equivalentClass",\n        "geodetic science"\n    ],\n    [\n        "geodetics",\n        "equivalentClass",\n        "geodesy"\n    ]\n]',
#  '[]',
#  '[\n  [\n    "geomagnetic storm",\n    "equivalentClass",\n    "magnetic storm"\n  ],\n  [\n    "magnetic storm",\n    "equivalentClass",\n    "geomagnetic storm"\n  ]\n]',
#  '[\n  [\n    "geometrical object 0d",\n    "equivalentClass",\n    "point"\n  ],\n  [\n    "point",\n    "equivalentClass",\n    "geometrical object 0d"\n  ]\n]',
#  '[]',
#  '[\n  [\n    "geosphere",\n    "equivalentClass",\n    "solid earth"\n  ],\n  [\n    "solid earth",\n    "equivalentClass",\n    "geosphere"\n  ]\n]',
#  '[\n    [\n        "glaciation",\n        "disjointWith",\n        "glacier retreat"\n    ],\n    [\n        "glacier retreat",\n        "disjointWith",\n        "glaciation"\n    ]\n]',
#  '[\n  [\n    "gpp",\n    "equivalentClass",\n    "gross primary productivity"\n  ],\n  [\n    "gross primary productivity",\n    "equivalentClass",\n    "gpp"\n  ]\n]',
#  '[\n  [\n    "gravity",\n    "equivalentClass",\n    "gravity force"\n  ],\n  [\n    "gravity force",\n    "equivalentClass",\n    "gravity"\n  ]\n]',
#  '[\n    [\n        "great circle",\n        "disjointWith",\n        "small circle"\n    ],\n    [\n        "small circle",\n        "disjointWith",\n        "great circle"\n    ]\n]',
#  '[\n  [\n    "gust",\n    "equivalentClass",\n    "wind gust"\n  ],\n  [\n    "wind gust",\n    "equivalentClass",\n    "gust"\n  ]\n]',
#  '[\n  [\n    "gyroradius",\n    "equivalentClass",\n    "larmor radius"\n  ],\n  [\n    "larmor radius",\n    "equivalentClass",\n    "gyroradius"\n  ]\n]',
#  '[\n    [\n        "hcfc",\n        "equivalentClass",\n        "hydrochlorofluorocarbon"\n    ],\n    [\n        "hydrochlorofluorocarbon",\n        "equivalentClass",\n        "hcfc"\n    ]\n]',
#  '[\n  [\n    "heat flow",\n    "equivalentClass",\n    "heat flux"\n  ],\n  [\n    "heat flow",\n    "equivalentClass",\n    "thermal flux"\n  ],\n  [\n    "heat flux",\n    "equivalentClass",\n    "heat flow"\n  ],\n  [\n    "heat flux",\n    "equivalentClass",\n    "thermal flux"\n  ],\n  [\n    "thermal flux",\n    "equivalentClass",\n    "heat flow"\n  ],\n  [\n    "thermal flux",\n    "equivalentClass",\n    "heat flux"\n  ]\n]',
#  '[\n    [\n        "ice pellet",\n        "equivalentClass",\n        "sleet"\n    ],\n    [\n        "sleet",\n        "equivalentClass",\n        "ice pellet"\n    ]\n]',
#  '[]',
#  '[\n  [\n    "increase",\n    "equivalentClass",\n    "rise"\n  ],\n  [\n    "rise",\n    "equivalentClass",\n    "increase"\n  ]\n]',
#  '[\n  [\n    "index of biological integrity",\n    "equivalentClass",\n    "index of biotic integrity"\n  ],\n  [\n    "index of biotic integrity",\n    "equivalentClass",\n    "index of biological integrity"\n  ]\n]',
#  '[]',
#  '[\n    [\n        "intertropical convergence zone",\n        "equivalentClass",\n        "itcz"\n    ],\n    [\n        "itcz",\n        "equivalentClass",\n        "intertropical convergence zone"\n    ]\n]',
#  '[]',
#  '[\n  [\n    "investigate",\n    "equivalentClass",\n    "investigation"\n  ],\n  [\n    "investigation",\n    "equivalentClass",\n    "investigate"\n  ]\n]',
#  '[]',
#  '[\n    [\n        "laboratory environment",\n        "disjointWith",\n        "representative environment"\n    ],\n    [\n        "representative environment",\n        "disjointWith",\n        "laboratory environment"\n    ]\n]',
#  '[\n    [\n        "linear",\n        "disjointWith",\n        "nonlinear"\n    ],\n    [\n        "nonlinear",\n        "disjointWith",\n        "linear"\n    ]\n]',
#  '[\n  [\n    "liquid water equivalent",\n    "equivalentClass",\n    "lwe"\n  ],\n  [\n    "lwe",\n    "equivalentClass",\n    "liquid water equivalent"\n  ]\n]',
#  '[\n  [\n    "mact",\n    "equivalentClass",\n    "maximum achievable control technology"\n  ],\n  [\n    "maximum achievable control technology",\n    "equivalentClass",\n    "mact"\n  ]\n]',
#  '[]',
#  '[\n  [\n    "mesosphere",\n    "equivalentClass",\n    "middle atmosphere"\n  ],\n  [\n    "middle atmosphere",\n    "equivalentClass",\n    "mesosphere"\n  ]\n]',
#  '[\n    [\n        "metalloid",\n        "disjointWith",\n        "nonmetal"\n    ],\n    [\n        "nonmetal",\n        "disjointWith",\n        "metalloid"\n    ]\n]',
#  '[\n  [\n    "methane clathrate",\n    "equivalentClass",\n    "methane hydrate"\n  ],\n  [\n    "methane hydrate",\n    "equivalentClass",\n    "methane clathrate"\n  ]\n]',
#  '[\n    [\n        "mix",\n        "equivalentClass",\n        "mixing"\n    ],\n    [\n        "mixing",\n        "equivalentClass",\n        "mix"\n    ]\n]',
#  '[]',
#  '[\n    [\n        "modulus of elasticity",\n        "equivalentClass",\n        "youngs modulus"\n    ],\n    [\n        "youngs modulus",\n        "equivalentClass",\n        "modulus of elasticity"\n    ]\n]',
#  '[\n  [\n    "mountain",\n    "disjointWith",\n    "orography"\n  ],\n  [\n    "orography",\n    "disjointWith",\n    "mountain"\n  ]\n]',
#  '[\n    [\n        "mountain fog",\n        "equivalentClass",\n        "orographic fog"\n    ],\n    [\n        "orographic fog",\n        "equivalentClass",\n        "mountain fog"\n    ]\n]',
#  '[\n  [\n    "natural resource management index",\n    "equivalentClass",\n    "nrmi"\n  ],\n  [\n    "nrmi",\n    "equivalentClass",\n    "natural resource management index"\n  ]\n]',
#  '[\n  [\n    "net primary productivity",\n    "equivalentClass",\n    "npp"\n  ],\n  [\n    "npp",\n    "equivalentClass",\n    "net primary productivity"\n  ]\n]',
#  '[\n    [\n        "nmvoc",\n        "equivalentClass",\n        "non methane volatile organic compound"\n    ],\n    [\n        "non methane volatile organic compound",\n        "equivalentClass",\n        "nmvoc"\n    ]\n]',
#  '[\n  [\n    "no observed effect level",\n    "equivalentClass",\n    "noel"\n  ],\n  [\n    "noel",\n    "equivalentClass",\n    "no observed effect level"\n  ]\n]',
#  '[\n  [\n    "old growth",\n    "disjointWith",\n    "second growth"\n  ],\n  [\n    "second growth",\n    "disjointWith",\n    "old growth"\n  ]\n]',
#  '[\n    [\n        "ols",\n        "equivalentClass",\n        "ordinary least squares"\n    ],\n    [\n        "ordinary least squares",\n        "equivalentClass",\n        "ols"\n    ]\n]',
#  '[]',
#  '[]',
#  '[\n  [\n    "p wave",\n    "equivalentClass",\n    "primary wave"\n  ],\n  [\n    "primary wave",\n    "equivalentClass",\n    "p wave"\n  ]\n]',
#  '[\n  [\n    "palmer drought severity index",\n    "equivalentClass",\n    "pdsi"\n  ],\n  [\n    "pdsi",\n    "equivalentClass",\n    "palmer drought severity index"\n  ]\n]',
#  '[\n  [\n    "pdf",\n    "equivalentClass",\n    "probability density function"\n  ],\n  [\n    "probability density function",\n    "equivalentClass",\n    "pdf"\n  ]\n]',
#  '[\n    [\n        "percolate",\n        "equivalentClass",\n        "percolation"\n    ],\n    [\n        "percolation",\n        "equivalentClass",\n        "percolate"\n    ]\n]',
#  '[]',
#  '[\n  [\n    "photodissociation",\n    "equivalentClass",\n    "photolysis"\n  ],\n  [\n    "photolysis",\n    "equivalentClass",\n    "photodissociation"\n  ]\n]',
#  '[]',
#  '[]',
#  '[]',
#  '[\n  [\n    "location",\n    "equivalentClass",\n    "position"\n  ],\n  [\n    "position",\n    "equivalentClass",\n    "location"\n  ]\n]',
#  '[]',
#  '[\n  [\n    "radiational heating",\n    "equivalentClass",\n    "radiative heating"\n  ],\n  [\n    "radiative heating",\n    "equivalentClass",\n    "radiational heating"\n  ]\n]',
#  '[\n  [\n    "radioisotope",\n    "equivalentClass",\n    "radionuclide"\n  ],\n  [\n    "radionuclide",\n    "equivalentClass",\n    "radioisotope"\n  ]\n]',
#  '[\n  [\n    "rainout",\n    "equivalentClass",\n    "washout"\n  ],\n  [\n    "washout",\n    "equivalentClass",\n    "rainout"\n  ]\n]',
#  '[]',
#  '[\n  [\n    "resonance",\n    "equivalentClass",\n    "resonant"\n  ],\n  [\n    "resonant",\n    "equivalentClass",\n    "resonance"\n  ]\n]',
#  '[\n  [\n    "rock cycle",\n    "equivalentClass",\n    "rock cycle process"\n  ],\n  [\n    "rock cycle process",\n    "equivalentClass",\n    "rock cycle"\n  ]\n]',
#  '[\n  [\n    "scalar",\n    "disjointWith",\n    "vector"\n  ],\n  [\n    "vector",\n    "disjointWith",\n    "scalar"\n  ]\n]',
#  '[\n  [\n    "sea floor",\n    "equivalentClass",\n    "seabed"\n  ],\n  [\n    "seabed",\n    "equivalentClass",\n    "sea floor"\n  ]\n]',
#  '[]',
#  '[\n  [\n    "seq",\n    "equivalentClass",\n    "sequence"\n  ],\n  [\n    "sequence",\n    "equivalentClass",\n    "seq"\n  ]\n]',
#  '[\n  [\n    "shore platform",\n    "equivalentClass",\n    "wave cut platform"\n  ],\n  [\n    "wave cut platform",\n    "equivalentClass",\n    "shore platform"\n  ]\n]',
#  '[\n  [\n    "smi",\n    "equivalentClass",\n    "surface moisture index"\n  ],\n  [\n    "surface moisture index",\n    "equivalentClass",\n    "smi"\n  ]\n]',
#  '[]',
#  '[\n  [\n    "sum",\n    "equivalentClass",\n    "summation"\n  ],\n  [\n    "summation",\n    "equivalentClass",\n    "sum"\n  ]\n]',
#  '[]',
#  '[]',
#  '[]',
#  '[\n  [\n    "time average",\n    "equivalentClass",\n    "time mean"\n  ],\n  [\n    "time mean",\n    "equivalentClass",\n    "time average"\n  ]\n]',
#  '[\n    [\n        "unit risk factor",\n        "equivalentClass",\n        "urf"\n    ],\n    [\n        "urf",\n        "equivalentClass",\n        "unit risk factor"\n    ]\n]',
#  '[]',
#  '[\n    [\n        "verification",\n        "equivalentClass",\n        "verify"\n    ],\n    [\n        "verify",\n        "equivalentClass",\n        "verification"\n    ]\n]',
#  '[\n  [\n    "voc",\n    "equivalentClass",\n    "volatile organic compound"\n  ],\n  [\n    "volatile organic compound",\n    "equivalentClass",\n    "voc"\n  ]\n]',
#  '[\n  [\n    "volcanism",\n    "equivalentClass",\n    "vulcanism"\n  ],\n  [\n    "vulcanism",\n    "equivalentClass",\n    "volcanism"\n  ]\n]',
#  '[]']

# %%
final_prep_output = []
for output_1 in response_final:
    response_dict = json.loads(output_1)
    for ind_output in response_dict:
        final_prep_output.append({
            "head":ind_output[0],
            "relation":ind_output[1],
            "tail":ind_output[2]
        })

# %%
len(final_prep_output)
# Out:
# 291

# %%
final_prep_output
# Out:
# [{'head': 'abyssal trench',
#   'relation': 'equivalentClass',
#   'tail': 'deep sea trench'},
#  {'head': 'deep sea trench',
#   'relation': 'equivalentClass',
#   'tail': 'abyssal trench'},
#  {'head': 'acoustic wave',
#   'relation': 'equivalentClass',
#   'tail': 'sound wave'},
#  {'head': 'sound wave',
#   'relation': 'equivalentClass',
#   'tail': 'acoustic wave'},
#  {'head': 'aeolian', 'relation': 'equivalentClass', 'tail': 'eolian'},
#  {'head': 'eolian', 'relation': 'equivalentClass', 'tail': 'aeolian'},
#  {'head': 'air sea exchange',
#   'relation': 'equivalentClass',
#   'tail': 'atmosphere ocean exchange'},
#  {'head': 'atmosphere ocean exchange',
#   'relation': 'equivalentClass',
#   'tail': 'air sea exchange'},
#  {'head': 'airborne toxic control measure',
#   'relation': 'equivalentClass',
#   'tail': 'atcm'},
#  {'head': 'atcm',
#   'relation': 'equivalentClass',
#   'tail': 'airborne toxic control measure'},
#  {'head': 'archive', 'relation': 'disjointWith', 'tail': 'archiving'},
#  {'head': 'archiving', 'relation': 'disjointWith', 'tail': 'archive'},
#  {'head': 'attenuation coefficient',
#   'relation': 'equivalentClass',
#   'tail': 'extinction coefficient'},
#  {'head': 'extinction coefficient',
#   'relation': 'equivalentClass',
#   'tail': 'attenuation coefficient'},
#  {'head': 'autotroph', 'relation': 'disjointWith', 'tail': 'heterotroph'},
#  {'head': 'heterotroph', 'relation': 'disjointWith', 'tail': 'autotroph'},
#  {'head': 'average', 'relation': 'equivalentClass', 'tail': 'mean'},
#  {'head': 'mean', 'relation': 'equivalentClass', 'tail': 'average'},
#  {'head': 'bag', 'relation': 'equivalentClass', 'tail': 'multiset'},
#  {'head': 'multiset', 'relation': 'equivalentClass', 'tail': 'bag'},
#  {'head': 'bdoc',
#   'relation': 'equivalentClass',
#   'tail': 'biodegradable dissolved organic carbon'},
#  {'head': 'biodegradable dissolved organic carbon',
#   'relation': 'equivalentClass',
#   'tail': 'bdoc'},
#  {'head': 'dissolved organic carbon',
#   'relation': 'equivalentClass',
#   'tail': 'doc'},
#  {'head': 'doc',
#   'relation': 'equivalentClass',
#   'tail': 'dissolved organic carbon'},
#  {'head': 'bed load', 'relation': 'disjointWith', 'tail': 'suspended load'},
#  {'head': 'bed load', 'relation': 'disjointWith', 'tail': 'wash load'},
#  {'head': 'suspended load', 'relation': 'disjointWith', 'tail': 'bed load'},
#  {'head': 'wash load', 'relation': 'disjointWith', 'tail': 'bed load'},
#  {'head': 'brightness',
#   'relation': 'disjointWith',
#   'tail': 'specific intensity'},
#  {'head': 'specific intensity',
#   'relation': 'disjointWith',
#   'tail': 'brightness'},
#  {'head': 'budget', 'relation': 'disjointWith', 'tail': 'budget equation'},
#  {'head': 'budget equation', 'relation': 'disjointWith', 'tail': 'budget'},
#  {'head': 'c horizon', 'relation': 'disjointWith', 'tail': 'parent rock'},
#  {'head': 'c horizon', 'relation': 'disjointWith', 'tail': 'surface soil'},
#  {'head': 'c horizon', 'relation': 'disjointWith', 'tail': 'topsoil'},
#  {'head': 'horizon', 'relation': 'disjointWith', 'tail': 'parent rock'},
#  {'head': 'parent rock', 'relation': 'disjointWith', 'tail': 'c horizon'},
#  {'head': 'parent rock', 'relation': 'disjointWith', 'tail': 'horizon'},
#  {'head': 'parent rock', 'relation': 'disjointWith', 'tail': 'surface soil'},
#  {'head': 'parent rock', 'relation': 'disjointWith', 'tail': 'topsoil'},
#  {'head': 'substrata', 'relation': 'disjointWith', 'tail': 'surface soil'},
#  {'head': 'substrata', 'relation': 'disjointWith', 'tail': 'topsoil'},
#  {'head': 'substrata', 'relation': 'equivalentClass', 'tail': 'substratum'},
#  {'head': 'substratum', 'relation': 'disjointWith', 'tail': 'surface soil'},
#  {'head': 'substratum', 'relation': 'disjointWith', 'tail': 'topsoil'},
#  {'head': 'substratum', 'relation': 'equivalentClass', 'tail': 'substrata'},
#  {'head': 'surface soil', 'relation': 'disjointWith', 'tail': 'c horizon'},
#  {'head': 'surface soil', 'relation': 'disjointWith', 'tail': 'parent rock'},
#  {'head': 'surface soil', 'relation': 'disjointWith', 'tail': 'substrata'},
#  {'head': 'surface soil', 'relation': 'disjointWith', 'tail': 'substratum'},
#  {'head': 'surface soil', 'relation': 'equivalentClass', 'tail': 'topsoil'},
#  {'head': 'topsoil', 'relation': 'disjointWith', 'tail': 'c horizon'},
#  {'head': 'topsoil', 'relation': 'disjointWith', 'tail': 'parent rock'},
#  {'head': 'topsoil', 'relation': 'disjointWith', 'tail': 'substrata'},
#  {'head': 'topsoil', 'relation': 'disjointWith', 'tail': 'substratum'},
#  {'head': 'topsoil', 'relation': 'equivalentClass', 'tail': 'surface soil'},
#  {'head': 'calving', 'relation': 'equivalentClass', 'tail': 'ice calving'},
#  {'head': 'ice calving', 'relation': 'equivalentClass', 'tail': 'calving'},
#  {'head': 'capillary', 'relation': 'disjointWith', 'tail': 'capillary action'},
#  {'head': 'capillary action', 'relation': 'disjointWith', 'tail': 'capillary'},
#  {'head': 'carbon neutral',
#   'relation': 'equivalentClass',
#   'tail': 'carbon neutrality'},
#  {'head': 'carbon neutrality',
#   'relation': 'equivalentClass',
#   'tail': 'carbon neutral'},
#  {'head': 'clumping', 'relation': 'disjointWith', 'tail': 'clump'},
#  {'head': 'clumping', 'relation': 'disjointWith', 'tail': 'cluster'},
#  {'head': 'clumping', 'relation': 'disjointWith', 'tail': 'swarm'},
#  {'head': 'clump', 'relation': 'disjointWith', 'tail': 'clumping'},
#  {'head': 'clump', 'relation': 'equivalentClass', 'tail': 'cluster'},
#  {'head': 'cluster', 'relation': 'disjointWith', 'tail': 'clumping'},
#  {'head': 'cluster', 'relation': 'equivalentClass', 'tail': 'clump'},
#  {'head': 'swarm', 'relation': 'disjointWith', 'tail': 'clumping'},
#  {'head': 'coastal', 'relation': 'equivalentClass', 'tail': 'coastal region'},
#  {'head': 'coastal region', 'relation': 'equivalentClass', 'tail': 'coastal'},
#  {'head': 'coastal region',
#   'relation': 'equivalentClass',
#   'tail': 'littoral zone'},
#  {'head': 'littoral zone',
#   'relation': 'equivalentClass',
#   'tail': 'coastal region'},
#  {'head': 'coefficient of thermal expansion',
#   'relation': 'equivalentClass',
#   'tail': 'thermal expansion coefficient'},
#  {'head': 'thermal expansion coefficient',
#   'relation': 'equivalentClass',
#   'tail': 'coefficient of thermal expansion'},
#  {'head': 'compression', 'relation': 'disjointWith', 'tail': 'decompression'},
#  {'head': 'compression', 'relation': 'disjointWith', 'tail': 'rareification'},
#  {'head': 'decompression', 'relation': 'disjointWith', 'tail': 'compression'},
#  {'head': 'rareification', 'relation': 'disjointWith', 'tail': 'compression'},
#  {'head': 'conic', 'relation': 'equivalentClass', 'tail': 'conic section'},
#  {'head': 'conic section', 'relation': 'equivalentClass', 'tail': 'conic'},
#  {'head': 'continuous', 'relation': 'disjointWith', 'tail': 'discontinuous'},
#  {'head': 'continuous', 'relation': 'disjointWith', 'tail': 'discrete'},
#  {'head': 'continuous',
#   'relation': 'disjointWith',
#   'tail': 'discrete function'},
#  {'head': 'discontinuous', 'relation': 'disjointWith', 'tail': 'continuous'},
#  {'head': 'discrete', 'relation': 'disjointWith', 'tail': 'continuous'},
#  {'head': 'discrete function',
#   'relation': 'disjointWith',
#   'tail': 'continuous'},
#  {'head': 'convergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'divergent boundary'},
#  {'head': 'convergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'divergent plate boundary'},
#  {'head': 'convergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate convergence'},
#  {'head': 'convergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate divergence'},
#  {'head': 'convergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'transform boundary'},
#  {'head': 'convergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'transform plate boundary'},
#  {'head': 'convergent boundary',
#   'relation': 'equivalentClass',
#   'tail': 'convergent margin'},
#  {'head': 'convergent margin',
#   'relation': 'disjointWith',
#   'tail': 'divergent boundary'},
#  {'head': 'convergent margin',
#   'relation': 'disjointWith',
#   'tail': 'divergent plate boundary'},
#  {'head': 'convergent margin',
#   'relation': 'disjointWith',
#   'tail': 'plate convergence'},
#  {'head': 'convergent margin',
#   'relation': 'disjointWith',
#   'tail': 'plate divergence'},
#  {'head': 'convergent margin',
#   'relation': 'disjointWith',
#   'tail': 'transform boundary'},
#  {'head': 'convergent margin',
#   'relation': 'disjointWith',
#   'tail': 'transform plate boundary'},
#  {'head': 'convergent margin',
#   'relation': 'equivalentClass',
#   'tail': 'convergent boundary'},
#  {'head': 'divergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'convergent boundary'},
#  {'head': 'divergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'convergent margin'},
#  {'head': 'divergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate convergence'},
#  {'head': 'divergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate divergence'},
#  {'head': 'divergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'transform boundary'},
#  {'head': 'divergent boundary',
#   'relation': 'disjointWith',
#   'tail': 'transform plate boundary'},
#  {'head': 'divergent boundary',
#   'relation': 'equivalentClass',
#   'tail': 'divergent plate boundary'},
#  {'head': 'divergent plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'convergent boundary'},
#  {'head': 'divergent plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'convergent margin'},
#  {'head': 'divergent plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate convergence'},
#  {'head': 'divergent plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate divergence'},
#  {'head': 'divergent plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'transform boundary'},
#  {'head': 'divergent plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'transform plate boundary'},
#  {'head': 'divergent plate boundary',
#   'relation': 'equivalentClass',
#   'tail': 'divergent boundary'},
#  {'head': 'plate convergence',
#   'relation': 'disjointWith',
#   'tail': 'convergent boundary'},
#  {'head': 'plate convergence',
#   'relation': 'disjointWith',
#   'tail': 'convergent margin'},
#  {'head': 'plate convergence',
#   'relation': 'disjointWith',
#   'tail': 'divergent boundary'},
#  {'head': 'plate convergence',
#   'relation': 'disjointWith',
#   'tail': 'divergent plate boundary'},
#  {'head': 'plate convergence',
#   'relation': 'disjointWith',
#   'tail': 'plate divergence'},
#  {'head': 'plate convergence',
#   'relation': 'disjointWith',
#   'tail': 'transform boundary'},
#  {'head': 'plate convergence',
#   'relation': 'disjointWith',
#   'tail': 'transform plate boundary'},
#  {'head': 'plate divergence',
#   'relation': 'disjointWith',
#   'tail': 'convergent boundary'},
#  {'head': 'plate divergence',
#   'relation': 'disjointWith',
#   'tail': 'convergent margin'},
#  {'head': 'plate divergence',
#   'relation': 'disjointWith',
#   'tail': 'divergent boundary'},
#  {'head': 'plate divergence',
#   'relation': 'disjointWith',
#   'tail': 'divergent plate boundary'},
#  {'head': 'plate divergence',
#   'relation': 'disjointWith',
#   'tail': 'plate convergence'},
#  {'head': 'plate divergence',
#   'relation': 'disjointWith',
#   'tail': 'transform boundary'},
#  {'head': 'plate divergence',
#   'relation': 'disjointWith',
#   'tail': 'transform plate boundary'},
#  {'head': 'transform boundary',
#   'relation': 'disjointWith',
#   'tail': 'convergent boundary'},
#  {'head': 'transform boundary',
#   'relation': 'disjointWith',
#   'tail': 'convergent margin'},
#  {'head': 'transform boundary',
#   'relation': 'disjointWith',
#   'tail': 'divergent boundary'},
#  {'head': 'transform boundary',
#   'relation': 'disjointWith',
#   'tail': 'divergent plate boundary'},
#  {'head': 'transform boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate convergence'},
#  {'head': 'transform boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate divergence'},
#  {'head': 'transform boundary',
#   'relation': 'equivalentClass',
#   'tail': 'transform plate boundary'},
#  {'head': 'transform plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'convergent boundary'},
#  {'head': 'transform plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'convergent margin'},
#  {'head': 'transform plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'divergent boundary'},
#  {'head': 'transform plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'divergent plate boundary'},
#  {'head': 'transform plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate convergence'},
#  {'head': 'transform plate boundary',
#   'relation': 'disjointWith',
#   'tail': 'plate divergence'},
#  {'head': 'transform plate boundary',
#   'relation': 'equivalentClass',
#   'tail': 'transform boundary'},
#  {'head': 'core mantle boundary',
#   'relation': 'equivalentClass',
#   'tail': 'guttenburg discontinuity'},
#  {'head': 'guttenburg discontinuity',
#   'relation': 'equivalentClass',
#   'tail': 'core mantle boundary'},
#  {'head': 'curate', 'relation': 'equivalentClass', 'tail': 'curation'},
#  {'head': 'curation', 'relation': 'equivalentClass', 'tail': 'curate'},
#  {'head': 'cyclotron frequency',
#   'relation': 'equivalentClass',
#   'tail': 'gyrofrequency'},
#  {'head': 'gyrofrequency',
#   'relation': 'equivalentClass',
#   'tail': 'cyclotron frequency'},
#  {'head': 'decision support system',
#   'relation': 'equivalentClass',
#   'tail': 'dss'},
#  {'head': 'dss',
#   'relation': 'equivalentClass',
#   'tail': 'decision support system'},
#  {'head': 'deep focus earthquake',
#   'relation': 'disjointWith',
#   'tail': 'shallow focus earthquake'},
#  {'head': 'shallow focus earthquake',
#   'relation': 'disjointWith',
#   'tail': 'deep focus earthquake'},
#  {'head': 'directed graph',
#   'relation': 'disjointWith',
#   'tail': 'undirected graph'},
#  {'head': 'discover', 'relation': 'disjointWith', 'tail': 'discovery service'},
#  {'head': 'discovery service', 'relation': 'disjointWith', 'tail': 'discover'},
#  {'head': 'division', 'relation': 'disjointWith', 'tail': 'quotient'},
#  {'head': 'quotient', 'relation': 'disjointWith', 'tail': 'division'},
#  {'head': 'dry lake', 'relation': 'equivalentClass', 'tail': 'playa'},
#  {'head': 'playa', 'relation': 'equivalentClass', 'tail': 'dry lake'},
#  {'head': 'electromagnetic radiation',
#   'relation': 'equivalentClass',
#   'tail': 'electromagnetic wave'},
#  {'head': 'electromagnetic wave',
#   'relation': 'equivalentClass',
#   'tail': 'electromagnetic radiation'},
#  {'head': 'elongate', 'relation': 'equivalentClass', 'tail': 'stretch'},
#  {'head': 'stretch', 'relation': 'equivalentClass', 'tail': 'elongate'},
#  {'head': 'emissivity', 'relation': 'disjointWith', 'tail': 'emittance'},
#  {'head': 'emittance', 'relation': 'disjointWith', 'tail': 'emissivity'},
#  {'head': 'environmental sustainability index',
#   'relation': 'equivalentClass',
#   'tail': 'esi'},
#  {'head': 'esi',
#   'relation': 'equivalentClass',
#   'tail': 'environmental sustainability index'},
#  {'head': 'felsic', 'relation': 'disjointWith', 'tail': 'mafic'},
#  {'head': 'mafic', 'relation': 'disjointWith', 'tail': 'felsic'},
#  {'head': 'geodetic science',
#   'relation': 'equivalentClass',
#   'tail': 'geodesy'},
#  {'head': 'geodetic science',
#   'relation': 'equivalentClass',
#   'tail': 'geodetics'},
#  {'head': 'geodesy',
#   'relation': 'equivalentClass',
#   'tail': 'geodetic science'},
#  {'head': 'geodesy', 'relation': 'equivalentClass', 'tail': 'geodetics'},
#  {'head': 'geodetics',
#   'relation': 'equivalentClass',
#   'tail': 'geodetic science'},
#  {'head': 'geodetics', 'relation': 'equivalentClass', 'tail': 'geodesy'},
#  {'head': 'geomagnetic storm',
#   'relation': 'equivalentClass',
#   'tail': 'magnetic storm'},
#  {'head': 'magnetic storm',
#   'relation': 'equivalentClass',
#   'tail': 'geomagnetic storm'},
#  {'head': 'geometrical object 0d',
#   'relation': 'equivalentClass',
#   'tail': 'point'},
#  {'head': 'point',
#   'relation': 'equivalentClass',
#   'tail': 'geometrical object 0d'},
#  {'head': 'geosphere', 'relation': 'equivalentClass', 'tail': 'solid earth'},
#  {'head': 'solid earth', 'relation': 'equivalentClass', 'tail': 'geosphere'},
#  {'head': 'glaciation', 'relation': 'disjointWith', 'tail': 'glacier retreat'},
#  {'head': 'glacier retreat', 'relation': 'disjointWith', 'tail': 'glaciation'},
#  {'head': 'gpp',
#   'relation': 'equivalentClass',
#   'tail': 'gross primary productivity'},
#  {'head': 'gross primary productivity',
#   'relation': 'equivalentClass',
#   'tail': 'gpp'},
#  {'head': 'gravity', 'relation': 'equivalentClass', 'tail': 'gravity force'},
#  {'head': 'gravity force', 'relation': 'equivalentClass', 'tail': 'gravity'},
#  {'head': 'great circle', 'relation': 'disjointWith', 'tail': 'small circle'},
#  {'head': 'small circle', 'relation': 'disjointWith', 'tail': 'great circle'},
#  {'head': 'gust', 'relation': 'equivalentClass', 'tail': 'wind gust'},
#  {'head': 'wind gust', 'relation': 'equivalentClass', 'tail': 'gust'},
#  {'head': 'gyroradius',
#   'relation': 'equivalentClass',
#   'tail': 'larmor radius'},
#  {'head': 'larmor radius',
#   'relation': 'equivalentClass',
#   'tail': 'gyroradius'},
#  {'head': 'hcfc',
#   'relation': 'equivalentClass',
#   'tail': 'hydrochlorofluorocarbon'},
#  {'head': 'hydrochlorofluorocarbon',
#   'relation': 'equivalentClass',
#   'tail': 'hcfc'},
#  {'head': 'heat flow', 'relation': 'equivalentClass', 'tail': 'heat flux'},
#  {'head': 'heat flow', 'relation': 'equivalentClass', 'tail': 'thermal flux'},
#  {'head': 'heat flux', 'relation': 'equivalentClass', 'tail': 'heat flow'},
#  {'head': 'heat flux', 'relation': 'equivalentClass', 'tail': 'thermal flux'},
#  {'head': 'thermal flux', 'relation': 'equivalentClass', 'tail': 'heat flow'},
#  {'head': 'thermal flux', 'relation': 'equivalentClass', 'tail': 'heat flux'},
#  {'head': 'ice pellet', 'relation': 'equivalentClass', 'tail': 'sleet'},
#  {'head': 'sleet', 'relation': 'equivalentClass', 'tail': 'ice pellet'},
#  {'head': 'increase', 'relation': 'equivalentClass', 'tail': 'rise'},
#  {'head': 'rise', 'relation': 'equivalentClass', 'tail': 'increase'},
#  {'head': 'index of biological integrity',
#   'relation': 'equivalentClass',
#   'tail': 'index of biotic integrity'},
#  {'head': 'index of biotic integrity',
#   'relation': 'equivalentClass',
#   'tail': 'index of biological integrity'},
#  {'head': 'intertropical convergence zone',
#   'relation': 'equivalentClass',
#   'tail': 'itcz'},
#  {'head': 'itcz',
#   'relation': 'equivalentClass',
#   'tail': 'intertropical convergence zone'},
#  {'head': 'investigate',
#   'relation': 'equivalentClass',
#   'tail': 'investigation'},
#  {'head': 'investigation',
#   'relation': 'equivalentClass',
#   'tail': 'investigate'},
#  {'head': 'laboratory environment',
#   'relation': 'disjointWith',
#   'tail': 'representative environment'},
#  {'head': 'representative environment',
#   'relation': 'disjointWith',
#   'tail': 'laboratory environment'},
#  {'head': 'linear', 'relation': 'disjointWith', 'tail': 'nonlinear'},
#  {'head': 'nonlinear', 'relation': 'disjointWith', 'tail': 'linear'},
#  {'head': 'liquid water equivalent',
#   'relation': 'equivalentClass',
#   'tail': 'lwe'},
#  {'head': 'lwe',
#   'relation': 'equivalentClass',
#   'tail': 'liquid water equivalent'},
#  {'head': 'mact',
#   'relation': 'equivalentClass',
#   'tail': 'maximum achievable control technology'},
#  {'head': 'maximum achievable control technology',
#   'relation': 'equivalentClass',
#   'tail': 'mact'},
#  {'head': 'mesosphere',
#   'relation': 'equivalentClass',
#   'tail': 'middle atmosphere'},
#  {'head': 'middle atmosphere',
#   'relation': 'equivalentClass',
#   'tail': 'mesosphere'},
#  {'head': 'metalloid', 'relation': 'disjointWith', 'tail': 'nonmetal'},
#  {'head': 'nonmetal', 'relation': 'disjointWith', 'tail': 'metalloid'},
#  {'head': 'methane clathrate',
#   'relation': 'equivalentClass',
#   'tail': 'methane hydrate'},
#  {'head': 'methane hydrate',
#   'relation': 'equivalentClass',
#   'tail': 'methane clathrate'},
#  {'head': 'mix', 'relation': 'equivalentClass', 'tail': 'mixing'},
#  {'head': 'mixing', 'relation': 'equivalentClass', 'tail': 'mix'},
#  {'head': 'modulus of elasticity',
#   'relation': 'equivalentClass',
#   'tail': 'youngs modulus'},
#  {'head': 'youngs modulus',
#   'relation': 'equivalentClass',
#   'tail': 'modulus of elasticity'},
#  {'head': 'mountain', 'relation': 'disjointWith', 'tail': 'orography'},
#  {'head': 'orography', 'relation': 'disjointWith', 'tail': 'mountain'},
#  {'head': 'mountain fog',
#   'relation': 'equivalentClass',
#   'tail': 'orographic fog'},
#  {'head': 'orographic fog',
#   'relation': 'equivalentClass',
#   'tail': 'mountain fog'},
#  {'head': 'natural resource management index',
#   'relation': 'equivalentClass',
#   'tail': 'nrmi'},
#  {'head': 'nrmi',
#   'relation': 'equivalentClass',
#   'tail': 'natural resource management index'},
#  {'head': 'net primary productivity',
#   'relation': 'equivalentClass',
#   'tail': 'npp'},
#  {'head': 'npp',
#   'relation': 'equivalentClass',
#   'tail': 'net primary productivity'},
#  {'head': 'nmvoc',
#   'relation': 'equivalentClass',
#   'tail': 'non methane volatile organic compound'},
#  {'head': 'non methane volatile organic compound',
#   'relation': 'equivalentClass',
#   'tail': 'nmvoc'},
#  {'head': 'no observed effect level',
#   'relation': 'equivalentClass',
#   'tail': 'noel'},
#  {'head': 'noel',
#   'relation': 'equivalentClass',
#   'tail': 'no observed effect level'},
#  {'head': 'old growth', 'relation': 'disjointWith', 'tail': 'second growth'},
#  {'head': 'second growth', 'relation': 'disjointWith', 'tail': 'old growth'},
#  {'head': 'ols',
#   'relation': 'equivalentClass',
#   'tail': 'ordinary least squares'},
#  {'head': 'ordinary least squares',
#   'relation': 'equivalentClass',
#   'tail': 'ols'},
#  {'head': 'p wave', 'relation': 'equivalentClass', 'tail': 'primary wave'},
#  {'head': 'primary wave', 'relation': 'equivalentClass', 'tail': 'p wave'},
#  {'head': 'palmer drought severity index',
#   'relation': 'equivalentClass',
#   'tail': 'pdsi'},
#  {'head': 'pdsi',
#   'relation': 'equivalentClass',
#   'tail': 'palmer drought severity index'},
#  {'head': 'pdf',
#   'relation': 'equivalentClass',
#   'tail': 'probability density function'},
#  {'head': 'probability density function',
#   'relation': 'equivalentClass',
#   'tail': 'pdf'},
#  {'head': 'percolate', 'relation': 'equivalentClass', 'tail': 'percolation'},
#  {'head': 'percolation', 'relation': 'equivalentClass', 'tail': 'percolate'},
#  {'head': 'photodissociation',
#   'relation': 'equivalentClass',
#   'tail': 'photolysis'},
#  {'head': 'photolysis',
#   'relation': 'equivalentClass',
#   'tail': 'photodissociation'},
#  {'head': 'location', 'relation': 'equivalentClass', 'tail': 'position'},
#  {'head': 'position', 'relation': 'equivalentClass', 'tail': 'location'},
#  {'head': 'radiational heating',
#   'relation': 'equivalentClass',
#   'tail': 'radiative heating'},
#  {'head': 'radiative heating',
#   'relation': 'equivalentClass',
#   'tail': 'radiational heating'},
#  {'head': 'radioisotope',
#   'relation': 'equivalentClass',
#   'tail': 'radionuclide'},
#  {'head': 'radionuclide',
#   'relation': 'equivalentClass',
#   'tail': 'radioisotope'},
#  {'head': 'rainout', 'relation': 'equivalentClass', 'tail': 'washout'},
#  {'head': 'washout', 'relation': 'equivalentClass', 'tail': 'rainout'},
#  {'head': 'resonance', 'relation': 'equivalentClass', 'tail': 'resonant'},
#  {'head': 'resonant', 'relation': 'equivalentClass', 'tail': 'resonance'},
#  {'head': 'rock cycle',
#   'relation': 'equivalentClass',
#   'tail': 'rock cycle process'},
#  {'head': 'rock cycle process',
#   'relation': 'equivalentClass',
#   'tail': 'rock cycle'},
#  {'head': 'scalar', 'relation': 'disjointWith', 'tail': 'vector'},
#  {'head': 'vector', 'relation': 'disjointWith', 'tail': 'scalar'},
#  {'head': 'sea floor', 'relation': 'equivalentClass', 'tail': 'seabed'},
#  {'head': 'seabed', 'relation': 'equivalentClass', 'tail': 'sea floor'},
#  {'head': 'seq', 'relation': 'equivalentClass', 'tail': 'sequence'},
#  {'head': 'sequence', 'relation': 'equivalentClass', 'tail': 'seq'},
#  {'head': 'shore platform',
#   'relation': 'equivalentClass',
#   'tail': 'wave cut platform'},
#  {'head': 'wave cut platform',
#   'relation': 'equivalentClass',
#   'tail': 'shore platform'},
#  {'head': 'smi',
#   'relation': 'equivalentClass',
#   'tail': 'surface moisture index'},
#  {'head': 'surface moisture index',
#   'relation': 'equivalentClass',
#   'tail': 'smi'},
#  {'head': 'sum', 'relation': 'equivalentClass', 'tail': 'summation'},
#  {'head': 'summation', 'relation': 'equivalentClass', 'tail': 'sum'},
#  {'head': 'time average', 'relation': 'equivalentClass', 'tail': 'time mean'},
#  {'head': 'time mean', 'relation': 'equivalentClass', 'tail': 'time average'},
#  {'head': 'unit risk factor', 'relation': 'equivalentClass', 'tail': 'urf'},
#  {'head': 'urf', 'relation': 'equivalentClass', 'tail': 'unit risk factor'},
#  {'head': 'verification', 'relation': 'equivalentClass', 'tail': 'verify'},
#  {'head': 'verify', 'relation': 'equivalentClass', 'tail': 'verification'},
#  {'head': 'voc',
#   'relation': 'equivalentClass',
#   'tail': 'volatile organic compound'},
#  {'head': 'volatile organic compound',
#   'relation': 'equivalentClass',
#   'tail': 'voc'},
#  {'head': 'volcanism', 'relation': 'equivalentClass', 'tail': 'vulcanism'},
#  {'head': 'vulcanism', 'relation': 'equivalentClass', 'tail': 'volcanism'}]

# %%
# final_prepared_train_data = []
# for data_1 in train_data:
import json
with open("predictions_SWEET_cluster_llm_re_pairs.json", "w", encoding="utf-8") as f:
    json.dump(final_prep_output, f, indent=2, ensure_ascii=False)
